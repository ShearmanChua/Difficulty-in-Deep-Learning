# %%
import os
seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
experiment = 'Variation 7 Experiments results - JPM'

# %%
import requests
import lxml
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.utils import compute_class_weight
import tensorflow as tf
from pil import Image
from sklearn import preprocessing
import tensorflow_addons as tfa

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
# gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
np.random.seed(seed)
tf.random.set_seed(seed)

session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, 
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), 
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)

# %% [markdown]
# ## First BanCorp.  (Small Cap)

# %% [markdown]
# ### Test Performance

# %% [markdown]
# ### non-recession

# %%
column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
log  = pd.DataFrame(columns = column_names)
logger = []

# %%
seed = 10
df = pd.read_csv("data/variation 7/initial_indicators/FBP_data_test.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d    EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22         9.50  9.028269  -2.255619  11013900.0     2.0
# 2019-01-23         9.40  9.085459 -15.384672   9894000.0     2.0
# 2019-01-24         9.41  9.135388 -14.615424  11127300.0     2.0
# 2019-01-25         9.64  9.213021  -0.854639  12071100.0     2.0
# 2019-01-28         9.74  9.294094  -9.599991  13124000.0     2.0

# %%
#%matplotlib notebook
df['previous_1d'].shift(-1).plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['labels'].plot(figsize=(16,6),x='Date', y='labels')

# %%
# willr_data = []
# price_data = []
# ema_data = []
# obv_data = []
# labels = []
# data_15_price = []
# data_15_willr = []
# data_15_ema = []
# data_15_obv = []
# count = 0

# for i in df.values:
#     if count == 14:
#         data_15_price.append([i[0]])
#         data_15_ema.append([i[1]])
#         data_15_willr.append([i[2]])
#         data_15_obv.append([i[3]])
#         price_data.append(data_15_price)
#         willr_data.append(data_15_willr)
#         ema_data.append(data_15_ema)
#         obv_data.append(data_15_obv)
#         labels.append(i[-1])
#         data_15_price = data_15_price[1:]
#         data_15_willr = data_15_willr[1:]
#         data_15_obv = data_15_obv[1:]
#         data_15_ema = data_15_ema[1:]
    
#     else:
#         data_15_price.append([i[0]])
#         data_15_ema.append([i[1]])
#         data_15_willr.append([i[2]])
#         data_15_obv.append([i[3]])
#         count += 1

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1

# %%
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/JPM_image_cnn_buy_hold_sell.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1]) ; logger.append(score[1])
# Out:
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1294 - accuracy: 0.7477 - mean_squared_error: 2.7964 - weighted_accuracy: 0.7477 - weighted_mean_squared_error: 2.7964
# Test loss: 0.12944388389587402
# Test accuracy: 0.747706413269043

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 175, 1: 20, 0: 23})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]
Counter(actual)
# Out:
# Counter({2: 198, 0: 12, 1: 8})

# %%
df = pd.read_csv("data/variation 7/initial_indicators/FBP_data_test.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels  \
# Date
# 2019-02-11        10.97  10.368433 -10.526309  20920800.0     2.0
# 2019-02-12        11.19  10.460982  -1.226963  21991800.0     2.0
# 2019-02-13        11.20  10.573138  -2.673807  23276900.0     2.0
# 2019-02-14        11.15  10.669578  -6.432784  24558900.0     2.0
# 2019-02-15        11.15  10.743489  -9.815999  23333100.0     2.0
#
#             predictions  actual
# Date
# 2019-02-11            2       2
# 2019-02-12            2       2
# 2019-02-13            2       2
# 2019-02-14            2       2
# 2019-02-15            2       2

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['predictions'].plot(figsize=(16,6),x='Date', y='predictions')
#df['actual'].plot(figsize=(16,6),x='Date', y='actual')

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold)) ; logger.append(str(100*buy_buy/buy) + "%") ; logger.append(str(100*sell_sell/sell) + "%") ; logger.append(str(100*hold_hold/hold) + "%")
# Out:
# number of predictions: 218
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 0
# actual predicted sells: 3
# actual sells but predicted hold: 9
# actual holds but predicted buy: 19
# actual holds but predicted sell: 20
# actual predicted holds: 159
# Percentage buys correct: 12.5%
# Percentage sells correct: 25.0%
# Percentage holds correct: 80.3030303030303%
# actual buys: 8
# actual sells: 12
# actual holds: 198

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%") ; logger.append(str(100*correct_minima/buy) + "%") ; logger.append(str(100*correct_maxima/sell) + "%") ; logger.append(str(100*correct_hold/hold) + "%")
# Out:
# [10.970000267028807, 11.149999618530273, 11.149999618530273, 11.1899995803833, 11.199999809265137, 11.359999656677244, 11.460000038146973, 11.529999732971193, 11.579999923706055]
# [11.229999542236328, 11.34000015258789, 11.40999984741211, 11.43000030517578, 11.460000038146973, 11.510000228881836, 11.510000228881836, 11.529999732971193, 11.579999923706055]
# Percentage buys correct: 60.0%
# Percentage sells correct: 52.17391304347826%
# Percentage holds correct: 82.75862068965517%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $11.40999984741211
# Shares owned at the moment: 874
# Cash capital at the moment: $0.23619872856033908
#
#
# Stop Loss Activated!
#
# Share price: $11.050000190734863
# Shares owned at the moment: 0
# Cash capital at the moment: $9631.3776899724
#
#
# Share price: $10.850000381469727
# Shares owned at the moment: 885
# Cash capital at the moment: $2.7211639432898664
#
#
# Price increase from previously bought: 6.619239245357522%
# Share price: $11.600000381469727
# Shares owned at the moment: 0
# Cash capital at the moment: $10240.490000615595
#
#
# Share price: $11.449999809265135
# Shares owned at the moment: 891
# Cash capital at the moment: $10.484808527708083
#
#
# Stop Loss Activated!
#
# Share price: $11.119999885559082
# Shares owned at the moment: 0
# Cash capital at the moment: $9891.157926841259
#
#
# Share price: $11.279999732971193
# Shares owned at the moment: 874
# Cash capital at the moment: $5.326680866239258
#
#
# Stop Loss Activated!
#
# Share price: $10.5600004196167
# Shares owned at the moment: 0
# Cash capital at the moment: $9209.386086602686
#
#
# Share price: $10.470000267028807
# Shares owned at the moment: 877
# Cash capital at the moment: $1.9448292744164064
#
#
# Stop Loss Activated!
#
# Share price: $10.010000228881836
# Shares owned at the moment: 0
# Cash capital at the moment: $8756.57341195178
#
#
# Share price: $10.119999885559082
# Shares owned at the moment: 862
# Cash capital at the moment: $9.144050871133004
#
#
# Stop Loss Activated!
#
# Share price: $9.84000015258789
# Shares owned at the moment: 0
# Cash capital at the moment: $8467.898462040184
#
#
# Share price: $10.06999969482422
# Shares owned at the moment: 838
# Cash capital at the moment: $6.032403480763605
#
#
# Price increase from previously bought: 7.945453368277633%
# Share price: $10.899999618530273
# Shares owned at the moment: 0
# Cash capital at the moment: $9115.11303468823
#
#
# Share price: $10.600000381469727
# Shares owned at the moment: 857
# Cash capital at the moment: $5.931156869644838
#
#
# Stop Loss Activated!
#
# Share price: $10.1899995803833
# Shares owned at the moment: 0
# Cash capital at the moment: $8714.745515747065
#
#
# Share price: $9.850000381469727
# Shares owned at the moment: 882
# Cash capital at the moment: $3.1540033655110165
#
#
# Stop Loss Activated!
#
# Share price: $9.420000076293944
# Shares owned at the moment: 0
# Cash capital at the moment: $8288.745860471718
#
#
# Share price: $9.65999984741211
# Shares owned at the moment: 855
# Cash capital at the moment: $6.732916293136441
#
#
# Stop Loss Activated!
#
# Share price: $9.34000015258789
# Shares owned at the moment: 0
# Cash capital at the moment: $7970.472371397011
#
#
# Share price: $9.359999656677246
# Shares owned at the moment: 849
# Cash capital at the moment: $1.9794036796010914
#
#
# Price increase from previously bought: 7.503516213819084%
# Share price: $10.09000015258789
# Shares owned at the moment: 0
# Cash capital at the moment: $8544.831905370465
#
#
# Share price: $9.899999618530273
# Shares owned at the moment: 860
# Cash capital at the moment: $7.418734336606576
#
#
# Price increase from previously bought: 8.489541364847986%
# Share price: $10.770000457763672
# Shares owned at the moment: 0
# Cash capital at the moment: $9244.148076930753
#
#
# Share price: $10.68000030517578
# Shares owned at the moment: 863
# Cash capital at the moment: $1.9615028397965943
#
#
# Stop Loss Activated!
#
# Share price: $10.350000381469727
# Shares owned at the moment: 0
# Cash capital at the moment: $8909.448693642848
#
#
#
#
# Capital at the end of test period: $8909.448693642848
# profit gained: -10.905513063571524%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $9718.53042116499
# profit gained: -2.814695788350109%

# %%
df_length = len(log)
log.loc[df_length] = logger
log.head(20)
# Out:
#    Test_accuracy correct_buys correct_sells      correct_holds  \
# 0       0.747706        12.5%         25.0%  80.3030303030303%
#
#   correct_low_buys  correct_high_sells   correct_mid_holds  \
# 0            60.0%  52.17391304347826%  82.75862068965517%
#
#           Profit gained    buy_n_hold profit
# 0  -10.905513063571524%  -2.814695788350109%

# %% [markdown]
# ### Recession

# %%
logger = []

# %%
seed = 10
df = pd.read_csv("data/variation 7/initial_indicators/FBP_data_test2.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels
# Date
# 2020-01-22        10.16  10.378210 -80.303008 -2725500.0     2.0
# 2020-01-23        10.12  10.338485 -84.615464 -4799800.0     2.0
# 2020-01-24        10.17  10.312565 -73.770502 -3020800.0     2.0
# 2020-01-27        10.01  10.266016 -83.561649 -4665400.0     2.0
# 2020-01-28         9.87  10.205091 -87.209337 -6089900.0     2.0

# %%
#%matplotlib notebook
df['previous_1d'].shift(-1).plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['labels'].plot(figsize=(16,6),x='Date', y='labels')

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1

# %%
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/JPM_image_cnn_buy_hold_sell.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1]) ; logger.append(score[1])
# Out:
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1187 - accuracy: 0.7854 - mean_squared_error: 2.6914 - weighted_accuracy: 0.7854 - weighted_mean_squared_error: 2.6914
# Test loss: 0.11871974915266037
# Test accuracy: 0.7853881120681763

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 186, 1: 17, 0: 16})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]

# %%
df = pd.read_csv("data/variation 7/initial_indicators/FBP_data_test2.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d    EMA_12   willr_14       OBV_7  labels  predictions  \
# Date
# 2020-02-11         9.34  9.482039 -90.677990 -10973800.0     2.0            2
# 2020-02-12         9.19  9.460187 -75.438607  -9769800.0     2.0            2
# 2020-02-13         9.20  9.418620 -88.288360 -11300700.0     2.0            2
# 2020-02-14         9.11  9.384986 -84.782661  -9851300.0     2.0            2
# 2020-02-18         9.03  9.342680 -94.565295 -11123300.0     2.0            2
#
#             actual
# Date
# 2020-02-11       2
# 2020-02-12       2
# 2020-02-13       2
# 2020-02-14       2
# 2020-02-18       2

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['predictions'].plot(figsize=(16,6),x='Date', y='predictions')
#df['actual'].plot(figsize=(16,6),x='Date', y='actual')

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold)) ; logger.append(str(100*buy_buy/buy) + "%") ; logger.append(str(100*sell_sell/sell) + "%") ; logger.append(str(100*hold_hold/hold) + "%")
# Out:
# number of predictions: 219
# actual predicted buys: 3
# actual buys but predicted sell: 0
# actual buys but predicted hold: 9
# actual sells but predicted buy: 0
# actual predicted sells: 1
# actual sells but predicted hold: 9
# actual holds but predicted buy: 14
# actual holds but predicted sell: 15
# actual predicted holds: 168
# Percentage buys correct: 25.0%
# Percentage sells correct: 10.0%
# Percentage holds correct: 85.27918781725889%
# actual buys: 12
# actual sells: 10
# actual holds: 197

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%") ; logger.append(str(100*correct_minima/buy) + "%") ; logger.append(str(100*correct_maxima/sell) + "%") ; logger.append(str(100*correct_hold/hold) + "%")
# Out:
# [8.640000343322754, 9.020000457763672, 9.029999732971193, 9.109999656677246, 9.1899995803833, 9.1899995803833, 9.199999809265137, 9.270000457763672, 9.34000015258789]
# [7.820000171661378, 7.940000057220459, 8.140000343322754, 8.300000190734862, 8.310000419616701, 8.399999618530272, 8.640000343322754, 9.020000457763672, 9.1899995803833]
# Percentage buys correct: 64.70588235294117%
# Percentage sells correct: 56.25%
# Percentage holds correct: 83.24324324324324%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $8.640000343322754
# Shares owned at the moment: 1154
# Cash capital at the moment: $2.0205627160066797
#
#
# Stop Loss Activated!
#
# Share price: $8.399999618530272
# Shares owned at the moment: 0
# Cash capital at the moment: $9668.962723710534
#
#
# Share price: $7.239999771118164
# Shares owned at the moment: 1331
# Cash capital at the moment: $6.0228191900223464
#
#
# Stop Loss Activated!
#
# Share price: $6.309999942779541
# Shares owned at the moment: 0
# Cash capital at the moment: $8381.536565739032
#
#
# Share price: $3.7300000190734863
# Shares owned at the moment: 2240
# Cash capital at the moment: $3.3597228969301796
#
#
# Price increase from previously bought: 43.84036625633658%
# Share price: $5.380000114440918
# Shares owned at the moment: 0
# Cash capital at the moment: $12021.41917853963
#
#
# Share price: $5.110000133514403
# Shares owned at the moment: 2346
# Cash capital at the moment: $0.39169945347202884
#
#
# Price increase from previously bought: 14.362606167753956%
# Share price: $5.860000133514402
# Shares owned at the moment: 0
# Cash capital at the moment: $13710.14622181689
#
#
# Share price: $5.559999942779541
# Shares owned at the moment: 2459
# Cash capital at the moment: $0.5082529089377203
#
#
# Price increase from previously bought: 5.286002090830966%
# Share price: $5.869999885559082
# Shares owned at the moment: 0
# Cash capital at the moment: $14395.143564772598
#
#
# Share price: $5.510000228881836
# Shares owned at the moment: 2605
# Cash capital at the moment: $2.1207043957620044
#
#
# Stop Loss Activated!
#
# Share price: $5.28000020980835
# Shares owned at the moment: 0
# Cash capital at the moment: $13718.696649443498
#
#
# Share price: $5.079999923706055
# Shares owned at the moment: 2693
# Cash capital at the moment: $0.6356454681063042
#
#
# Price increase from previously bought: 17.786325598913244%
# Share price: $6.0
# Shares owned at the moment: 0
# Cash capital at the moment: $16114.201145468105
#
#
# Share price: $6.230000019073486
# Shares owned at the moment: 2579
# Cash capital at the moment: $2.8463786423089914
#
#
# Price increase from previously bought: 13.652141728953726%
# Share price: $7.099999904632568
# Shares owned at the moment: 0
# Cash capital at the moment: $18263.39115836607
#
#
# Share price: $7.860000133514402
# Shares owned at the moment: 2317
# Cash capital at the moment: $1.6888931624816905
#
#
# Price increase from previously bought: 10.00283481266755%
# Share price: $8.670000076293945
# Shares owned at the moment: 0
# Cash capital at the moment: $20034.835996949427
#
#
#
#
# Capital at the end of test period: $20034.835996949427
# profit gained: 100.34835996949427%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $9476.998710832118
# profit gained: -5.2300128916788164%

# %%
df_length = len(log)
log.loc[df_length] = logger
log.head()
# Out:
#    Test_accuracy correct_buys correct_sells       correct_holds  \
# 0       0.747706        12.5%         25.0%   80.3030303030303%
# 1       0.785388        25.0%         10.0%  85.27918781725889%
#
#      correct_low_buys  correct_high_sells   correct_mid_holds  \
# 0               60.0%  52.17391304347826%  82.75862068965517%
# 1  64.70588235294117%              56.25%  83.24324324324324%
#
#           Profit gained     buy_n_hold profit
# 0  -10.905513063571524%   -2.814695788350109%
# 1   100.34835996949427%  -5.2300128916788164%

# %% [markdown]
# ## American Financial Group, Inc. (Mid Cap)

# %% [markdown]
# ### Test Performance

# %% [markdown]
# #### Non-Recession

# %%
logger = []

# %%
seed = 10
df = pd.read_csv("data/variation 7/initial_indicators/AFG_data_test.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels
# Date
# 2019-01-22    95.959999  92.750365  -1.891883  2019300.0     2.0
# 2019-01-23    95.279999  93.139539 -17.336730  1754000.0     2.0
# 2019-01-24    95.690002  93.531918 -12.247481  2036400.0     2.0
# 2019-01-25    95.019997  93.760853 -21.494180  1640100.0     2.0
# 2019-01-28    94.750000  93.913030 -25.032797  1462200.0     2.0

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['labels'].plot(figsize=(16,6),x='Date', y='labels')

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['labels'].shift(1).values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
# willr_data = []
# price_data = []
# ema_data = []
# obv_data = []
# labels = []
# data_15_price = []
# data_15_willr = []
# data_15_ema = []
# data_15_obv = []
# count = 0

# for i in df.values:
#     if count == 14:
#         data_15_price.append([i[0]])
#         data_15_ema.append([i[1]])
#         data_15_willr.append([i[2]])
#         data_15_obv.append([i[3]])
#         price_data.append(data_15_price)
#         willr_data.append(data_15_willr)
#         ema_data.append(data_15_ema)
#         obv_data.append(data_15_obv)
#         labels.append(i[-1])
#         data_15_price = data_15_price[1:]
#         data_15_willr = data_15_willr[1:]
#         data_15_obv = data_15_obv[1:]
#         data_15_ema = data_15_ema[1:]
    
#     else:
#         data_15_price.append([i[0]])
#         data_15_ema.append([i[1]])
#         data_15_willr.append([i[2]])
#         data_15_obv.append([i[3]])
#         count += 1
        
# willr_data = np.array(willr_data)
# price_data = np.array(price_data)
# ema_data = np.array(ema_data)
# obv_data = np.array(obv_data)

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/JPM_image_cnn_buy_hold_sell.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1]) ; logger.append(score[1])
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1315 - accuracy: 0.7523 - mean_squared_error: 2.7494 - weighted_accuracy: 0.7523 - weighted_mean_squared_error: 2.7494
# Test loss: 0.1314588040113449
# Test accuracy: 0.752293586730957

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 181, 0: 21, 1: 16})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]
Counter(actual)
# Out:
# Counter({2: 197, 0: 12, 1: 9})

# %%
df = pd.read_csv("data/variation 7/initial_indicators/AFG_data_test.csv")
df.set_index('Date', inplace=True)

# %%
# df['previous_1d'] = df['previous_1d'].shift(-1)
# df.dropna(inplace=True)
# df = df.iloc[13:]
# df['predictions'] = predictions
# df['actual'] = actual
# df.head()

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels  predictions  \
# Date
# 2019-02-11    96.739998  95.059703  -9.133179  1855500.0     2.0            2
# 2019-02-12    97.730003  95.318210  -3.111098  2267700.0     2.0            0
# 2019-02-13    97.580002  95.689255  -5.992454  2702600.0     2.0            2
# 2019-02-14    96.660004  95.980139 -17.449632  2348300.0     2.0            2
# 2019-02-15    98.099998  96.084734 -27.740437  1928300.0     2.0            2
#
#             actual
# Date
# 2019-02-11       2
# 2019-02-12       2
# 2019-02-13       2
# 2019-02-14       2
# 2019-02-15       2

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['predictions'].plot(figsize=(16,6),x='Date', y='predictions')
#df['actual'].plot(figsize=(16,6),x='Date', y='actual')

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold)) ; logger.append(str(100*buy_buy/buy) + "%") ; logger.append(str(100*sell_sell/sell) + "%") ; logger.append(str(100*hold_hold/hold) + "%")
# Out:
# number of predictions: 218
# actual predicted buys: 0
# actual buys but predicted sell: 0
# actual buys but predicted hold: 9
# actual sells but predicted buy: 0
# actual predicted sells: 2
# actual sells but predicted hold: 10
# actual holds but predicted buy: 16
# actual holds but predicted sell: 19
# actual predicted holds: 162
# Percentage buys correct: 0.0%
# Percentage sells correct: 16.666666666666668%
# Percentage holds correct: 82.23350253807106%
# actual buys: 9
# actual sells: 12
# actual holds: 197

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%") ; logger.append(str(100*correct_minima/buy) + "%") ; logger.append(str(100*correct_maxima/sell) + "%") ; logger.append(str(100*correct_hold/hold) + "%")
# Out:
# [96.66000366210938, 96.73999786376952, 97.58000183105469, 97.7300033569336, 98.0999984741211, 98.6999969482422, 99.26000213623048, 99.70999908447266, 99.8499984741211]
# [98.62000274658205, 99.04000091552734, 99.26000213623048, 99.3000030517578, 99.62000274658205, 99.66000366210938, 99.70999908447266, 99.7699966430664, 99.8499984741211]
# Percentage buys correct: 62.5%
# Percentage sells correct: 52.38095238095238%
# Percentage holds correct: 82.77777777777777%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
#         print(i)
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $97.31999969482422
# Shares owned at the moment: 102
# Cash capital at the moment: $46.061771213531756
#
#
# Stop Loss Activated!
#
# Share price: $94.45999908447266
# Shares owned at the moment: 0
# Cash capital at the moment: $9654.485648086547
#
#
# Share price: $95.26000213623048
# Shares owned at the moment: 101
# Cash capital at the moment: $6.766966733930531
#
#
# Price increase from previously bought: 5.87093239293317%
# Share price: $101.12999725341795
# Shares owned at the moment: 0
# Cash capital at the moment: $10192.807832592007
#
#
# Share price: $102.01000213623048
# Shares owned at the moment: 99
# Cash capital at the moment: $66.04539802359977
#
#
# Stop Loss Activated!
#
# Share price: $99.0
# Shares owned at the moment: 0
# Cash capital at the moment: $9840.0926480236
#
#
# Share price: $99.30999755859376
# Shares owned at the moment: 98
# Cash capital at the moment: $80.94884293936957
#
#
# Price increase from previously bought: 5.811129289696093%
# Share price: $105.37000274658205
# Shares owned at the moment: 0
# Cash capital at the moment: $10378.811896364206
#
#
# Share price: $102.37999725341795
# Shares owned at the moment: 101
# Cash capital at the moment: $9.996129531855331
#
#
# Stop Loss Activated!
#
# Share price: $97.87999725341795
# Shares owned at the moment: 0
# Cash capital at the moment: $9868.689682889932
#
#
# Share price: $99.6999969482422
# Shares owned at the moment: 98
# Cash capital at the moment: $71.22083278464379
#
#
# Price increase from previously bought: 8.377990406672842%
# Share price: $108.3499984741211
# Shares owned at the moment: 0
# Cash capital at the moment: $10660.320358659736
#
#
# Share price: $106.77999877929688
# Shares owned at the moment: 99
# Cash capital at the moment: $60.02962484168165
#
#
# Stop Loss Activated!
#
# Share price: $102.91999816894531
# Shares owned at the moment: 0
# Cash capital at the moment: $10221.089474065771
#
#
# Share price: $102.91999816894531
# Shares owned at the moment: 99
# Cash capital at the moment: $3.9896858386891836
#
#
# Price increase from previously bought: 7.312742630093916%
# Share price: $110.75
# Shares owned at the moment: 0
# Cash capital at the moment: $10938.08799833869
#
#
#
#
# Capital at the end of test period: $10938.08799833869
# profit gained: 9.380879983386894%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $11382.204687950136
# profit gained: 13.82204687950136%

# %%
df_length = len(log)
log.loc[df_length] = logger
log.head()
# Out:
#    Test_accuracy correct_buys        correct_sells       correct_holds  \
# 0       0.747706        12.5%                25.0%   80.3030303030303%
# 1       0.785388        25.0%                10.0%  85.27918781725889%
# 2       0.752294         0.0%  16.666666666666668%  82.23350253807106%
#
#      correct_low_buys  correct_high_sells   correct_mid_holds  \
# 0               60.0%  52.17391304347826%  82.75862068965517%
# 1  64.70588235294117%              56.25%  83.24324324324324%
# 2               62.5%  52.38095238095238%  82.77777777777777%
#
#           Profit gained     buy_n_hold profit
# 0  -10.905513063571524%   -2.814695788350109%
# 1   100.34835996949427%  -5.2300128916788164%
# 2    9.380879983386894%    13.82204687950136%

# %% [markdown]
# #### Recession

# %%
logger = []

# %%
seed = 10
df = pd.read_csv("data/variation 7/initial_indicators/AFG_data_test2.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d      EMA_12   willr_14     OBV_7  labels
# Date
# 2020-01-22   110.709999  110.318220 -37.234155  495600.0     2.0
# 2020-01-23   110.660004  110.370802 -39.007042   43700.0     2.0
# 2020-01-24   110.239998  110.350678 -53.900867 -231100.0     2.0
# 2020-01-27   110.489998  110.372112 -45.035617   27900.0     1.0
# 2020-01-28   108.529999  110.088710 -98.475749 -331600.0     2.0

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['labels'].plot(figsize=(16,6),x='Date', y='labels')

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['labels'].shift(1).values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/JPM_image_cnn_buy_hold_sell.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1]) ; logger.append(score[1])
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1282 - accuracy: 0.7854 - mean_squared_error: 2.7012 - weighted_accuracy: 0.7854 - weighted_mean_squared_error: 2.7012
# Test loss: 0.12823085486888885
# Test accuracy: 0.7853881120681763

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 186, 1: 14, 0: 19})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]
Counter(actual)
# Out:
# Counter({0: 11, 2: 197, 1: 11})

# %%
df = pd.read_csv("data/variation 7/initial_indicators/AFG_data_test2.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d      EMA_12   willr_14      OBV_7  labels  \
# Date
# 2020-02-11   114.529999  111.202616  -8.193579  1034000.0     0.0
# 2020-02-12   113.339996  111.714521  -7.122511  1370400.0     2.0
# 2020-02-13   112.809998  111.964594 -24.074120  1072300.0     2.0
# 2020-02-14   112.809998  112.094656 -31.623964   742100.0     2.0
# 2020-02-18   112.129997  112.204709 -31.623964   742100.0     2.0
#
#             predictions  actual
# Date
# 2020-02-11            2       0
# 2020-02-12            2       2
# 2020-02-13            2       2
# 2020-02-14            2       2
# 2020-02-18            2       2

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['predictions'].plot(figsize=(16,6),x='Date', y='predictions')
#df['actual'].plot(figsize=(16,6),x='Date', y='actual')

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold)) ; logger.append(str(100*buy_buy/buy) + "%") ; logger.append(str(100*sell_sell/sell) + "%") ; logger.append(str(100*hold_hold/hold) + "%")
# Out:
# number of predictions: 219
# actual predicted buys: 2
# actual buys but predicted sell: 0
# actual buys but predicted hold: 9
# actual sells but predicted buy: 0
# actual predicted sells: 2
# actual sells but predicted hold: 9
# actual holds but predicted buy: 12
# actual holds but predicted sell: 17
# actual predicted holds: 168
# Percentage buys correct: 18.181818181818183%
# Percentage sells correct: 18.181818181818183%
# Percentage holds correct: 85.27918781725889%
# actual buys: 11
# actual sells: 11
# actual holds: 197

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%") ; logger.append(str(100*correct_minima/buy) + "%") ; logger.append(str(100*correct_maxima/sell) + "%") ; logger.append(str(100*correct_hold/hold) + "%")
# Out:
# [106.4000015258789, 110.33999633789062, 112.12999725341795, 112.1500015258789, 112.3000030517578, 112.80999755859376, 112.80999755859376, 113.33999633789062, 114.52999877929688]
# [91.75, 92.41999816894531, 97.19000244140624, 97.4000015258789, 100.27999877929688, 101.80999755859376, 106.4000015258789, 110.33999633789062, 112.3000030517578]
# Percentage buys correct: 57.142857142857146%
# Percentage sells correct: 57.89473684210526%
# Percentage holds correct: 82.70270270270271%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
#         print(i)
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
#         print(i)
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $97.19000244140624
# Shares owned at the moment: 102
# Cash capital at the moment: $59.35795529174902
#
#
# Stop Loss Activated!
#
# Share price: $92.41999816894531
# Shares owned at the moment: 0
# Cash capital at the moment: $9460.273959037782
#
#
# Share price: $92.41999816894531
# Shares owned at the moment: 102
# Cash capital at the moment: $7.510336318971895
#
#
# Stop Loss Activated!
#
# Share price: $84.72000122070312
# Shares owned at the moment: 0
# Cash capital at the moment: $8625.186500488284
#
#
# Share price: $62.02000045776367
# Shares owned at the moment: 138
# Cash capital at the moment: $42.88984714317485
#
#
# Stop Loss Activated!
#
# Share price: $58.5
# Shares owned at the moment: 0
# Cash capital at the moment: $8093.689097143175
#
#
# Share price: $54.43999862670898
# Shares owned at the moment: 148
# Cash capital at the moment: $14.412220949175207
#
#
# Price increase from previously bought: 37.18702898184753%
# Share price: $74.88999938964844
# Shares owned at the moment: 0
# Cash capital at the moment: $11067.651900865556
#
#
# Share price: $64.27999877929689
# Shares owned at the moment: 171
# Cash capital at the moment: $45.54444017982314
#
#
# Stop Loss Activated!
#
# Share price: $60.34000015258789
# Shares owned at the moment: 0
# Cash capital at the moment: $10335.309581200598
#
#
# Share price: $56.83000183105469
# Shares owned at the moment: 181
# Cash capital at the moment: $20.792116368291317
#
#
# Price increase from previously bought: 8.727915508666806%
# Share price: $61.959999084472656
# Shares owned at the moment: 0
# Cash capital at the moment: $11204.711361113545
#
#
# Share price: $61.93000030517578
# Shares owned at the moment: 180
# Cash capital at the moment: $26.65595603084148
#
#
# Price increase from previously bought: 9.661289742472047%
# Share price: $68.09999847412111
# Shares owned at the moment: 0
# Cash capital at the moment: $12250.94618212795
#
#
# Share price: $67.41999816894531
# Shares owned at the moment: 181
# Cash capital at the moment: $14.368209460255457
#
#
# Stop Loss Activated!
#
# Share price: $65.41999816894531
# Shares owned at the moment: 0
# Cash capital at the moment: $11822.825073950764
#
#
# Share price: $84.13999938964844
# Shares owned at the moment: 140
# Cash capital at the moment: $10.831259634967864
#
#
# Price increase from previously bought: 6.173440771261518%
# Share price: $89.58000183105469
# Shares owned at the moment: 0
# Cash capital at the moment: $12517.543215277668
#
#
# Share price: $90.1500015258789
# Shares owned at the moment: 138
# Cash capital at the moment: $42.63107912730811
#
#
# Stop Loss Activated!
#
# Share price: $87.43000030517578
# Shares owned at the moment: 0
# Cash capital at the moment: $12074.791436125752
#
#
#
#
# Capital at the end of test period: $12074.791436125752
# profit gained: 20.747914361257518%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $7413.518684106826
# profit gained: -25.86481315893174%

# %%
df_length = len(log)
log.loc[df_length] = logger
log.head()
# Out:
#    Test_accuracy         correct_buys        correct_sells  \
# 0       0.747706                12.5%                25.0%
# 1       0.785388                25.0%                10.0%
# 2       0.752294                 0.0%  16.666666666666668%
# 3       0.785388  18.181818181818183%  18.181818181818183%
#
#         correct_holds     correct_low_buys  correct_high_sells  \
# 0   80.3030303030303%                60.0%  52.17391304347826%
# 1  85.27918781725889%   64.70588235294117%              56.25%
# 2  82.23350253807106%                62.5%  52.38095238095238%
# 3  85.27918781725889%  57.142857142857146%  57.89473684210526%
#
#     correct_mid_holds         Profit gained     buy_n_hold profit
# 0  82.75862068965517%  -10.905513063571524%   -2.814695788350109%
# 1  83.24324324324324%   100.34835996949427%  -5.2300128916788164%
# 2  82.77777777777777%    9.380879983386894%    13.82204687950136%
# 3  82.70270270270271%   20.747914361257518%   -25.86481315893174%

# %% [markdown]
# ## JPMorgan Chase & Co. (Large Cap)

# %% [markdown]
# ### Test Performance

# %% [markdown]
# #### Non-Recession

# %%
logger = []

# %%
seed = 10
df = pd.read_csv("data/variation 7/initial_indicators/JPM_data_test.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22   104.589996  101.198442  -3.459880  84335200.0     2.0
# 2019-01-23   102.940002  101.466374 -21.874992  67251500.0     2.0
# 2019-01-24   102.680000  101.653086 -27.040213  55104800.0     2.0
# 2019-01-25   102.739998  101.820303 -32.628441  66401600.0     2.0
# 2019-01-28   103.389999  102.061795 -23.968276  80771000.0     2.0

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['labels'].plot(figsize=(16,6),x='Date', y='labels')

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/JPM_image_cnn_buy_hold_sell.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1]) ; logger.append(score[1])
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1204 - accuracy: 0.7569 - mean_squared_error: 2.5974 - weighted_accuracy: 0.7569 - weighted_mean_squared_error: 2.5974
# Test loss: 0.12044297158718109
# Test accuracy: 0.7568807601928711

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({1: 20, 2: 178, 0: 20})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]

# %%
df = pd.read_csv("data/variation 7/initial_indicators/JPM_data_test.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d      EMA_12   willr_14       OBV_7  labels  \
# Date
# 2019-02-11   100.879997  102.975915 -74.903417  73097300.0     1.0
# 2019-02-12   102.599998  102.653466 -84.169891  62118800.0     2.0
# 2019-02-13   103.089996  102.645240 -50.965236  74971100.0     2.0
# 2019-02-14   102.419998  102.713664 -41.505819  85725200.0     2.0
# 2019-02-15   105.550003  102.668485 -54.440145  74206700.0     2.0
#
#             predictions  actual
# Date
# 2019-02-11            1       1
# 2019-02-12            2       2
# 2019-02-13            2       2
# 2019-02-14            2       2
# 2019-02-15            2       2

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['predictions'].plot(figsize=(16,6),x='Date', y='predictions')
#df['actual'].plot(figsize=(16,6),x='Date', y='actual')

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold)) ; logger.append(str(100*buy_buy/buy) + "%") ; logger.append(str(100*sell_sell/sell) + "%") ; logger.append(str(100*hold_hold/hold) + "%")
# Out:
# number of predictions: 218
# actual predicted buys: 2
# actual buys but predicted sell: 0
# actual buys but predicted hold: 9
# actual sells but predicted buy: 0
# actual predicted sells: 0
# actual sells but predicted hold: 6
# actual holds but predicted buy: 18
# actual holds but predicted sell: 20
# actual predicted holds: 163
# Percentage buys correct: 18.181818181818183%
# Percentage sells correct: 0.0%
# Percentage holds correct: 81.09452736318408%
# actual buys: 11
# actual sells: 6
# actual holds: 201

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%") ; logger.append(str(100*correct_minima/buy) + "%") ; logger.append(str(100*correct_maxima/sell) + "%") ; logger.append(str(100*correct_hold/hold) + "%")
# Out:
# [100.87999725341795, 102.41999816894531, 102.5999984741211, 103.08999633789062, 105.0, 105.18000030517578, 105.47000122070312, 105.5500030517578, 105.69000244140624]
# [104.19000244140624, 104.36000061035156, 104.43000030517578, 105.0, 105.16000366210938, 105.29000091552734, 105.47000122070312, 105.69000244140624, 106.0999984741211]
# Percentage buys correct: 50.0%
# Percentage sells correct: 30.0%
# Percentage holds correct: 84.18079096045197%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
#         print(i)
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $100.87999725341795
# Shares owned at the moment: 98
# Cash capital at the moment: $86.57310990524456
#
#
# Price increase from previously bought: 5.578024785052116%
# Share price: $106.8000030517578
# Shares owned at the moment: 0
# Cash capital at the moment: $10524.19080815506
#
#
# Share price: $98.93000030517578
# Shares owned at the moment: 106
# Cash capital at the moment: $8.772680717467665
#
#
# Price increase from previously bought: 15.219387157538723%
# Share price: $114.3000030517578
# Shares owned at the moment: 0
# Cash capital at the moment: $12091.254553314206
#
#
# Share price: $115.08999633789062
# Shares owned at the moment: 104
# Cash capital at the moment: $88.97919522094344
#
#
# Stop Loss Activated!
#
# Share price: $109.4499969482422
# Shares owned at the moment: 0
# Cash capital at the moment: $11440.476178710935
#
#
# Share price: $110.31999969482422
# Shares owned at the moment: 103
# Cash capital at the moment: $46.26807023048059
#
#
# Stop Loss Activated!
#
# Share price: $107.05999755859376
# Shares owned at the moment: 0
# Cash capital at the moment: $11043.123074457166
#
#
# Share price: $108.4800033569336
# Shares owned at the moment: 101
# Cash capital at the moment: $56.5124144744841
#
#
# Stop Loss Activated!
#
# Share price: $104.8000030517578
# Shares owned at the moment: 0
# Cash capital at the moment: $10612.204521854395
#
#
# Share price: $107.72000122070312
# Shares owned at the moment: 98
# Cash capital at the moment: $26.61386189650875
#
#
# Price increase from previously bought: 10.79816333984227%
# Share price: $119.68000030517578
# Shares owned at the moment: 0
# Cash capital at the moment: $11723.00013172149
#
#
# Share price: $128.60000610351562
# Shares owned at the moment: 90
# Cash capital at the moment: $117.17108089446265
#
#
#
#
# Capital at the end of test period: $12506.605578308096
# profit gained: 25.066055783080955%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $13577.290673755644
# profit gained: 35.77290673755644%

# %%
df_length = len(log)
log.loc[df_length] = logger
log.head(20)
# Out:
#    Test_accuracy         correct_buys        correct_sells  \
# 0       0.747706                12.5%                25.0%
# 1       0.785388                25.0%                10.0%
# 2       0.752294                 0.0%  16.666666666666668%
# 3       0.785388  18.181818181818183%  18.181818181818183%
# 4       0.756881  18.181818181818183%                 0.0%
#
#         correct_holds     correct_low_buys  correct_high_sells  \
# 0   80.3030303030303%                60.0%  52.17391304347826%
# 1  85.27918781725889%   64.70588235294117%              56.25%
# 2  82.23350253807106%                62.5%  52.38095238095238%
# 3  85.27918781725889%  57.142857142857146%  57.89473684210526%
# 4  81.09452736318408%                50.0%               30.0%
#
#     correct_mid_holds         Profit gained     buy_n_hold profit
# 0  82.75862068965517%  -10.905513063571524%   -2.814695788350109%
# 1  83.24324324324324%   100.34835996949427%  -5.2300128916788164%
# 2  82.77777777777777%    9.380879983386894%    13.82204687950136%
# 3  82.70270270270271%   20.747914361257518%   -25.86481315893174%
# 4  84.18079096045197%   25.066055783080955%    35.77290673755644%

# %% [markdown]
# ### Recession

# %%
logger = []

# %%
seed = 10
df = pd.read_csv("data/variation 7/initial_indicators/JPM_data_test2.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22   136.839996  137.690058 -77.454723  33776700.0     2.0
# 2020-01-23   136.679993  137.534664 -80.363881  26227600.0     2.0
# 2020-01-24   136.539993  137.381637 -69.867648  16881900.0     2.0
# 2020-01-27   133.149994  136.730615 -90.166021   1715500.0     1.0
# 2020-01-28   132.029999  136.007444 -79.004573 -11145000.0     2.0

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/JPM_image_cnn_buy_hold_sell.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1]) ; logger.append(score[1])
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.7671 - mean_squared_error: 2.6839 - weighted_accuracy: 0.7671 - weighted_mean_squared_error: 2.6839
# Test loss: 0.12319300323724747
# Test accuracy: 0.767123281955719

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 182, 0: 22, 1: 15})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]

# %%
df = pd.read_csv("data/variation 7/initial_indicators/JPM_data_test2.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d      EMA_12   willr_14       OBV_7  labels  \
# Date
# 2020-02-11   138.000000  136.179383  -6.410124  26757600.0     0.0
# 2020-02-12   138.000000  136.459478  -9.001177  33336200.0     2.0
# 2020-02-13   137.880005  136.696481 -13.465502  33336200.0     2.0
# 2020-02-14   137.460007  136.878562 -14.718062  25888700.0     2.0
# 2020-02-18   135.639999  136.968015 -23.401387  19261100.0     2.0
#
#             predictions  actual
# Date
# 2020-02-11            2       0
# 2020-02-12            0       2
# 2020-02-13            2       2
# 2020-02-14            1       2
# 2020-02-18            2       2

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold)) ; logger.append(str(100*buy_buy/buy) + "%") ; logger.append(str(100*sell_sell/sell) + "%") ; logger.append(str(100*hold_hold/hold) + "%")
# Out:
# number of predictions: 219
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 9
# actual sells but predicted buy: 0
# actual predicted sells: 3
# actual sells but predicted hold: 9
# actual holds but predicted buy: 14
# actual holds but predicted sell: 19
# actual predicted holds: 164
# Percentage buys correct: 10.0%
# Percentage sells correct: 25.0%
# Percentage holds correct: 83.248730964467%
# actual buys: 10
# actual sells: 12
# actual holds: 197

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%") ; logger.append(str(100*correct_minima/buy) + "%") ; logger.append(str(100*correct_maxima/sell) + "%") ; logger.append(str(100*correct_hold/hold) + "%")
# Out:
# [132.16000366210938, 135.63999938964844, 135.80999755859378, 137.46000671386722, 137.49000549316406, 137.49000549316406, 137.8800048828125, 138.0, 138.0]
# [116.11000061035156, 116.95999908447266, 121.37000274658205, 121.5199966430664, 126.26000213623048, 126.63999938964844, 132.16000366210938, 135.80999755859378, 137.49000549316406]
# Percentage buys correct: 33.333333333333336%
# Percentage sells correct: 63.63636363636363%
# Percentage holds correct: 83.42541436464089%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
#         print(i)
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $137.46000671386722
# Shares owned at the moment: 72
# Cash capital at the moment: $75.66243527221377
#
#
# Stop Loss Activated!
#
# Share price: $132.16000366210938
# Shares owned at the moment: 0
# Cash capital at the moment: $9565.01501821899
#
#
# Share price: $126.63999938964844
# Shares owned at the moment: 75
# Cash capital at the moment: $40.89556412124148
#
#
# Stop Loss Activated!
#
# Share price: $121.37000274658205
# Shares owned at the moment: 0
# Cash capital at the moment: $9118.613207048413
#
#
# Share price: $121.37000274658205
# Shares owned at the moment: 74
# Cash capital at the moment: $112.53420824241039
#
#
# Stop Loss Activated!
#
# Share price: $116.11000061035156
# Shares owned at the moment: 0
# Cash capital at the moment: $8681.04586828422
#
#
# Share price: $119.8499984741211
# Shares owned at the moment: 72
# Cash capital at the moment: $28.115678449625193
#
#
# Stop Loss Activated!
#
# Share price: $113.97000122070312
# Shares owned at the moment: 0
# Cash capital at the moment: $8211.389706098551
#
#
# Share price: $87.51000213623047
# Shares owned at the moment: 93
# Cash capital at the moment: $50.578824382776475
#
#
# Stop Loss Activated!
#
# Share price: $84.05000305175781
# Shares owned at the moment: 0
# Cash capital at the moment: $7845.733319915766
#
#
# Share price: $84.02999877929688
# Shares owned at the moment: 93
# Cash capital at the moment: $9.452761253351127
#
#
# Price increase from previously bought: 7.0126288477769805%
# Share price: $90.16999816894531
# Shares owned at the moment: 0
# Cash capital at the moment: $8372.201613933557
#
#
# Share price: $106.05999755859376
# Shares owned at the moment: 78
# Cash capital at the moment: $76.77193488692501
#
#
# Stop Loss Activated!
#
# Share price: $97.20999908447266
# Shares owned at the moment: 0
# Cash capital at the moment: $7638.300318672173
#
#
# Share price: $97.93000030517578
# Shares owned at the moment: 77
# Cash capital at the moment: $76.95361760901596
#
#
# Stop Loss Activated!
#
# Share price: $94.66000366210938
# Shares owned at the moment: 0
# Cash capital at the moment: $7345.729643815986
#
#
# Share price: $99.41000366210938
# Shares owned at the moment: 73
# Cash capital at the moment: $68.8428182468324
#
#
# Stop Loss Activated!
#
# Share price: $96.63999938964844
# Shares owned at the moment: 0
# Cash capital at the moment: $7104.162293813696
#
#
# Share price: $97.20999908447266
# Shares owned at the moment: 72
# Cash capital at the moment: $85.7947799129388
#
#
# Price increase from previously bought: 6.506818903713585%
# Share price: $103.81999969482422
# Shares owned at the moment: 0
# Cash capital at the moment: $7540.278398000707
#
#
# Share price: $100.5
# Shares owned at the moment: 74
# Cash capital at the moment: $82.82664800070688
#
#
# Stop Loss Activated!
#
# Share price: $95.30999755859376
# Shares owned at the moment: 0
# Cash capital at the moment: $7116.370882833471
#
#
# Share price: $117.87999725341795
# Shares owned at the moment: 60
# Cash capital at the moment: $24.120848081579425
#
#
#
#
# Capital at the end of test period: $7149.272757642736
# profit gained: -28.507272423572637%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $8586.858291473387
# profit gained: -14.13141708526613%

# %%
df_length = len(log)
log.loc[df_length] = logger
log.head(20)
# Out:
#    Test_accuracy         correct_buys        correct_sells  \
# 0       0.747706                12.5%                25.0%
# 1       0.785388                25.0%                10.0%
# 2       0.752294                 0.0%  16.666666666666668%
# 3       0.785388  18.181818181818183%  18.181818181818183%
# 4       0.756881  18.181818181818183%                 0.0%
# 5       0.767123                10.0%                25.0%
#
#         correct_holds     correct_low_buys  correct_high_sells  \
# 0   80.3030303030303%                60.0%  52.17391304347826%
# 1  85.27918781725889%   64.70588235294117%              56.25%
# 2  82.23350253807106%                62.5%  52.38095238095238%
# 3  85.27918781725889%  57.142857142857146%  57.89473684210526%
# 4  81.09452736318408%                50.0%               30.0%
# 5    83.248730964467%  33.333333333333336%  63.63636363636363%
#
#     correct_mid_holds         Profit gained     buy_n_hold profit
# 0  82.75862068965517%  -10.905513063571524%   -2.814695788350109%
# 1  83.24324324324324%   100.34835996949427%  -5.2300128916788164%
# 2  82.77777777777777%    9.380879983386894%    13.82204687950136%
# 3  82.70270270270271%   20.747914361257518%   -25.86481315893174%
# 4  84.18079096045197%   25.066055783080955%    35.77290673755644%
# 5  83.42541436464089%  -28.507272423572637%   -14.13141708526613%

# %%
experiment
# Out:
# 'Variation 7 Experiments results - JPM'

# %%
log.to_csv('{}.csv'.format(experiment))
