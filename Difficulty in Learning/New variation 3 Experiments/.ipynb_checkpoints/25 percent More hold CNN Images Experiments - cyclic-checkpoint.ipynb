# %%
import os
seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
experiment = '25 percent More hold CNN Images Experiments - cyclic'

# %%
import requests
import lxml
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.utils import compute_class_weight
import tensorflow as tf
from pil import Image
from sklearn import preprocessing
import tensorflow_addons as tfa
import glob
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
import math

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
# gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
np.random.seed(seed)
tf.random.set_seed(seed)

session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, 
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), 
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)

# %% [markdown]
# ## Prepare Test Data

# %%
nr_test_sets = ['C6L.SI','O39.SI','0883.HK','JPM','AXL']
nr_test_data = {}

for name in nr_test_sets:

    df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    willr_data = []
    price_data = []
    ema_data = []
    obv_data = []
    labels = []
    data_15_price = []
    data_15_willr = []
    data_15_ema = []
    data_15_obv = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
            data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
            data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
            data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
            price_data.append(data_15_price_arr)
            willr_data.append(data_15_willr_arr)
            ema_data.append(data_15_ema_arr)
            obv_data.append(data_15_obv_arr)
            labels.append(i[-1])
            data_15_price = data_15_price[1:]
            data_15_willr = data_15_willr[1:]
            data_15_obv = data_15_obv[1:]
            data_15_ema = data_15_ema[1:]

        else:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            count += 1

    willr_data = np.array(willr_data)
    price_data = np.array(price_data)
    ema_data = np.array(ema_data)
    obv_data = np.array(obv_data)
    
    sequential_data = []
    
    for i in range(0,len(willr_data)):
        j = willr_data[i]
        k = price_data[i]
        l = ema_data[i]
        m = obv_data[i]
        fig, ax = plt.subplots()
        fig.set_size_inches((5,5))

        ax.plot(k)
        ax.plot(j)
        ax.plot(l)
        ax.plot(m)

        ax.axis('off')

        fig.add_axes(ax)
        fig.canvas.draw()

        # this rasterized the figure
        X = np.array(fig.canvas.renderer._renderer)
        X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
        X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
        sequential_data.append(X)
        plt.close()
        
    X = sequential_data
    y = labels

    X  = np.array(X).reshape(-1, 64, 64, 1)
    X = X/255
    y = np.array(y)
    
    y = to_categorical(y, 3)
    
    nr_test_data['{}_X'.format(name)] = X
    nr_test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2019-01-21         9.59  9.538960 -32.758553  6890900.0     2.0
# 2019-01-22         9.63  9.552966 -25.862007  7759500.0     2.0
# 2019-01-23         9.61  9.561740 -29.310362  7108100.0     1.0
# 2019-01-24         9.50  9.552242 -48.275822  6126400.0     2.0
# 2019-01-25         9.74  9.581128  -8.888884  8160300.0     2.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-21        11.75  11.523654 -10.869606  21160951.0     2.0
# 2019-01-22        11.73  11.555399 -13.978517  18040951.0     2.0
# 2019-01-23        11.50  11.546876 -38.709667  14286851.0     1.0
# 2019-01-24        11.38  11.521203 -51.612890   8454651.0     2.0
# 2019-01-25        11.41  11.504095 -80.357185  12469051.0     2.0
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2019-01-22        13.12  12.552209  -3.030323  489168111.0     2.0
# 2019-01-23        12.94  12.611869 -13.043517  449876554.0     2.0
# 2019-01-24        12.62  12.613120 -33.333352  395082483.0     2.0
# 2019-01-25        12.80  12.641871 -37.254896  441807090.0     2.0
# 2019-01-28        13.06  12.706198 -11.764689  494043477.0     2.0
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22   104.589996  101.198442  -3.459880  84335200.0     2.0
# 2019-01-23   102.940002  101.466374 -21.874992  67251500.0     2.0
# 2019-01-24   102.680000  101.653086 -27.040213  55104800.0     2.0
# 2019-01-25   102.739998  101.820303 -32.628441  66401600.0     2.0
# 2019-01-28   103.389999  102.061795 -23.968276  80771000.0     2.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22        14.61  13.028180  -0.258404  23356600.0     2.0
# 2019-01-23        14.52  13.257691  -3.886001  21174700.0     2.0
# 2019-01-24        14.18  13.399585 -13.535906  19629300.0     2.0
# 2019-01-25        14.38  13.550418  -8.579880  20903300.0     2.0
# 2019-01-28        14.71  13.728815  -4.790414  22287500.0     2.0

# %%
r_test_sets = ['C6L.SI','O39.SI','0883.HK','JPM','AXL']
r_test_data = {}

for name in r_test_sets:

    df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test2.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    willr_data = []
    price_data = []
    ema_data = []
    obv_data = []
    labels = []
    data_15_price = []
    data_15_willr = []
    data_15_ema = []
    data_15_obv = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
            data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
            data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
            data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
            price_data.append(data_15_price_arr)
            willr_data.append(data_15_willr_arr)
            ema_data.append(data_15_ema_arr)
            obv_data.append(data_15_obv_arr)
            labels.append(i[-1])
            data_15_price = data_15_price[1:]
            data_15_willr = data_15_willr[1:]
            data_15_obv = data_15_obv[1:]
            data_15_ema = data_15_ema[1:]

        else:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            count += 1

    willr_data = np.array(willr_data)
    price_data = np.array(price_data)
    ema_data = np.array(ema_data)
    obv_data = np.array(obv_data)
    
    sequential_data = []
    
    for i in range(0,len(willr_data)):
        j = willr_data[i]
        k = price_data[i]
        l = ema_data[i]
        m = obv_data[i]
        fig, ax = plt.subplots()
        fig.set_size_inches((5,5))

        ax.plot(k)
        ax.plot(j)
        ax.plot(l)
        ax.plot(m)

        ax.axis('off')

        fig.add_axes(ax)
        fig.canvas.draw()

        # this rasterized the figure
        X = np.array(fig.canvas.renderer._renderer)
        X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
        X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
        sequential_data.append(X)
        plt.close()
        
    X = sequential_data
    y = labels

    X  = np.array(X).reshape(-1, 64, 64, 1)
    X = X/255
    y = np.array(y)
    
    y = to_categorical(y, 3)
    
    r_test_data['{}_X'.format(name)] = X
    r_test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2020-01-22         8.84  8.979182 -96.551645  -851200.0     2.0
# 2020-01-23         8.93  8.971615 -65.517105  1644900.0     2.0
# 2020-01-24         8.85  8.952905 -92.307523  -246900.0     2.0
# 2020-01-28         8.82  8.932458 -75.000000 -1718200.0     2.0
# 2020-01-29         8.56  8.875157 -86.885115 -5499900.0     2.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22        11.12  11.072811 -24.444379  27489400.0     2.0
# 2020-01-23        11.19  11.090840  -8.888884  31751200.0     2.0
# 2020-01-24        11.11  11.093787 -26.666653  27359800.0     2.0
# 2020-01-28        11.10  11.094743 -28.888715  24699300.0     2.0
# 2020-01-29        10.90  11.064783 -71.739257  16499235.0     2.0
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2020-01-22        13.00  13.393678 -83.870980  104646165.0     2.0
# 2020-01-23        13.34  13.385420 -57.377021  145802714.0     2.0
# 2020-01-24        13.00  13.326125 -85.245880   96260120.0     2.0
# 2020-01-29        13.04  13.282106 -80.645176  122828433.0     2.0
# 2020-01-30        12.46  13.155628 -90.804605   53693706.0     2.0
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22   136.839996  137.690058 -77.454723  33776700.0     2.0
# 2020-01-23   136.679993  137.534664 -80.363881  26227600.0     2.0
# 2020-01-24   136.539993  137.381637 -69.867648  16881900.0     2.0
# 2020-01-27   133.149994  136.730615 -90.166021   1715500.0     1.0
# 2020-01-28   132.029999  136.007444 -79.004573 -11145000.0     2.0
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2020-01-22         9.39  9.715390 -73.059349 -3592400.0     2.0
# 2020-01-23         9.34  9.657637 -75.342463 -4550300.0     2.0
# 2020-01-24         9.50  9.633386 -65.000010 -3092000.0     2.0
# 2020-01-27         9.31  9.583634 -66.883101 -4332600.0     2.0
# 2020-01-28         9.39  9.553844 -61.688301 -2300800.0     2.0

# %% [markdown]
# ## Train Stock Data

# %%
def pred_acc(actual, predictions, logger):

    hold = 0
    sell = 0
    buy = 0
    pred_hold = 0
    pred_sell = 0
    pred_buy = 0
    buy_buy = 0
    buy_sell = 0
    buy_hold = 0
    sell_buy = 0
    sell_sell = 0
    sell_hold = 0
    hold_buy = 0
    hold_sell = 0
    hold_hold = 0

    for i in range (0,len(actual)):
        if actual[i]==1 and predictions[i] == 1:
            buy_buy += 1
            buy += 1
            pred_buy += 1
        elif actual[i]==1 and predictions[i] == 0:
            buy_sell += 1
            buy += 1
            pred_sell += 1
        elif actual[i]==1 and predictions[i] == 2:
            buy_hold += 1
            buy += 1
            pred_hold += 1
        elif actual[i]==0 and predictions[i] == 1:
            sell_buy += 1
            sell += 1
            pred_buy += 1
        elif actual[i]==0 and predictions[i] == 0:
            sell_sell += 1
            sell += 1
            pred_sell += 1
        elif actual[i]==0 and predictions[i] == 2:
            sell_hold += 1
            sell += 1
            pred_hold += 1
        elif actual[i]==2 and predictions[i] == 1:
            hold_buy += 1
            hold += 1
            pred_buy += 1
        elif actual[i]==2 and predictions[i] == 0:
            hold_sell += 1
            hold += 1
            pred_sell += 1
        elif actual[i]==2 and predictions[i] == 2:
            hold_hold += 1
            hold += 1
            pred_hold += 1

    print("number of predictions: " + str(len(actual)))
    print("actual predicted buys: " + str(buy_buy) )
    print("actual buys but predicted sell: " + str(buy_sell) )
    print("actual buys but predicted hold: " + str(buy_hold))
    print("actual sells but predicted buy: " + str(sell_buy) )
    print("actual predicted sells: " + str(sell_sell))
    print("actual sells but predicted hold: " + str(sell_hold) )
    print("actual holds but predicted buy: " + str(hold_buy) )
    print("actual holds but predicted sell: " + str(hold_sell))
    print("actual predicted holds: " + str(hold_hold) )
    
    if pred_buy !=0:
        Percentage_buys_correct = 100*buy_buy/pred_buy
    else:
        Percentage_buys_correct = 0
        
    if pred_sell !=0:
        Percentage_sells_correct = 100*sell_sell/pred_sell
    else:
        Percentage_sells_correct = 0
        
    if pred_hold !=0:
        Percentage_holds_correct = 100*hold_hold/pred_hold
    else:
        Percentage_holds_correct = 0

    print("Percentage buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage holds correct: " + str(Percentage_holds_correct) + "%")

    print("actual buys: " + str(buy))
    print("actual sells: " + str(sell))
    print("actual holds: " + str(hold))
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def correct_maxima_minima(predictions, price, logger):
    correct_maxima = 0 
    correct_minima = 0
    correct_hold = 0

    hold = 0
    buy = 0
    sell = 0

#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):
        if i < 4:
            prices = price[i:i+9]
            prices.sort(key = float)
#             if i == 0:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1

        else:
            prices = price[i:i+5]
            prices = prices + price[i-4:i] 
            prices.sort(key = float)
#             if i == 10:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1
                    
    if buy !=0:
        Percentage_buys_correct = 100*correct_minima/buy
    else:
        Percentage_buys_correct = 0
        
    if sell !=0:
        Percentage_sells_correct = 100*correct_maxima/sell
    else:
        Percentage_sells_correct = 0
        
    if hold !=0:
        Percentage_holds_correct = 100*correct_hold/hold
    else:
        Percentage_holds_correct = 0

    print("Percentage low buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage high sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage mid holds correct: " + str(Percentage_holds_correct) + "%")
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %% [markdown]
# ### Creating Training Data and Model

# %%
sequential_data = []
labels = []

train_sets = ['C6L.SI','O39.SI','600104.SS','0883.HK','1398.HK','ANF','AXL','JPM','CTB','TROX']

for name in train_sets:
    seed = 10
    df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    plt.figure(figsize=(15,5))
    plt.plot(df['previous_1d'].values)
    plt.plot(df['EMA_12'].values)
    plt.show()

    willr_data = []
    price_data = []
    ema_data = []
    obv_data = []
    data_15_price = []
    data_15_willr = []
    data_15_ema = []
    data_15_obv = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
            data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
            data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
            data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
            price_data.append(data_15_price_arr)
            willr_data.append(data_15_willr_arr)
            ema_data.append(data_15_ema_arr)
            obv_data.append(data_15_obv_arr)
            labels.append(i[-1])
            data_15_price = data_15_price[1:]
            data_15_willr = data_15_willr[1:]
            data_15_obv = data_15_obv[1:]
            data_15_ema = data_15_ema[1:]

        else:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            count += 1
            
    willr_data = np.array(willr_data)
    price_data = np.array(price_data)
    ema_data = np.array(ema_data)
    obv_data = np.array(obv_data)
        
    for i in range(0,len(willr_data)):
        j = willr_data[i]
        k = price_data[i]
        l = ema_data[i]
        m = obv_data[i]
        fig, ax = plt.subplots()
        fig.set_size_inches((5,5))

        ax.plot(k)
        ax.plot(j)
        ax.plot(l)
        ax.plot(m)

        ax.axis('off')

        fig.add_axes(ax)
        fig.canvas.draw()

        # this rasterized the figure
        X = np.array(fig.canvas.renderer._renderer)
        X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
        X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
        sequential_data.append(X)
        plt.close()
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels
# Date
# 2000-01-21    19.000000  19.215335 -37.499990   388000.0     2.0
# 2000-01-24    18.400000  19.089899 -50.000000 -2311000.0     2.0
# 2000-01-25    18.100000  18.937607 -48.780483 -3542000.0     2.0
# 2000-01-26    17.700001  18.747206 -85.714237 -6261000.0     2.0
# 2000-01-27    17.799999  18.601482 -82.142864 -4565000.0     2.0
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2000-01-21     6.793788  7.018572 -90.000010 -1965914.0     2.0
# 2000-01-24     6.890842  6.998922 -77.777802  6276910.0     2.0
# 2000-01-25     6.793788  6.967363 -85.714286  -511055.0     2.0
# 2000-01-26     6.745261  6.933193 -86.666549 -7435027.0     2.0
# 2000-01-27     6.890842  6.926678 -66.666601 -3725757.0     2.0
#             previous_1d    EMA_12   willr_14        OBV_7  labels
# Date
# 2000-01-24     3.189194  3.249583 -69.696967   61394527.0     2.0
# 2000-01-25     3.205140  3.242745 -79.136806   75032521.0     2.0
# 2000-01-26     3.402870  3.267380 -34.532549  127274101.0     2.0
# 2000-01-27     3.284870  3.270071 -62.500055   91746305.0     2.0
# 2000-01-28     3.252978  3.267441 -69.852957   65314909.0     2.0
#             previous_1d    EMA_12   willr_14       OBV_7  labels
# Date
# 2004-04-07        3.250  3.264699 -57.142857  31539206.0     2.0
# 2004-04-08        3.200  3.254745 -78.947368 -24878594.0     2.0
# 2004-04-13        3.250  3.254015 -52.631579  10937473.0     0.0
# 2004-04-14        3.375  3.272628 -10.416706  98972973.0     2.0
# 2004-04-15        3.275  3.272993 -52.083331  47190715.0     2.0
#             previous_1d    EMA_12   willr_14         OBV_7  labels
# Date
# 2006-11-17     3.953848  3.652647 -15.942120  1.897904e+10     2.0
# 2006-11-20     3.934226  3.695967 -18.840636  1.837444e+10     2.0
# 2006-11-21     3.934226  3.732622 -19.403036  1.837444e+10     2.0
# 2006-11-22     3.934226  3.763638 -19.697025  1.837444e+10     0.0
# 2006-11-23     4.051959  3.807995  -1.562480  1.907354e+10     2.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2000-01-21      21.5000  24.211693 -82.142857  -6805500.0     2.0
# 2000-01-24      20.2500  23.602201 -92.465753  -8986800.0     1.0
# 2000-01-25      20.1875  23.076863 -92.307692 -11383100.0     2.0
# 2000-01-26      20.8750  22.738115 -82.786885  -9392500.0     2.0
# 2000-01-27      22.8750  22.759174 -56.557377  -6811000.0     2.0
#             previous_1d     EMA_12   willr_14     OBV_7  labels
# Date
# 2000-01-21      16.0625  14.895987 -18.478261  298700.0     2.0
# 2000-01-24      15.8750  15.046605 -22.222222  293100.0     2.0
# 2000-01-25      15.7500  15.154819 -26.190476  286300.0     2.0
# 2000-01-26      15.7500  15.246386 -29.729730  286300.0     2.0
# 2000-01-27      16.0000  15.362326 -25.000000  311700.0     0.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2000-01-21    49.375000  48.388499 -42.592593  -2894250.0     2.0
# 2000-01-24    48.625000  48.424884 -39.516144  -8054850.0     2.0
# 2000-01-25    48.666668  48.462081 -38.709668  -1595700.0     2.0
# 2000-01-26    49.750000  48.660222 -17.741956   5984250.0     2.0
# 2000-01-27    52.291668  49.218906  -5.232557  14370900.0     2.0
#             previous_1d     EMA_12    willr_14     OBV_7  labels
# Date
# 2000-01-21      13.7500  14.817184  -97.297297 -827200.0     2.0
# 2000-01-24      14.0625  14.701079  -77.500000 -518900.0     2.0
# 2000-01-25      13.6875  14.545144  -92.500000 -906100.0     2.0
# 2000-01-26      13.7500  14.422814  -90.000000 -652700.0     2.0
# 2000-01-27      13.5000  14.280843 -100.000000 -848400.0     2.0
#             previous_1d     EMA_12  willr_14      OBV_7  labels
# Date
# 2010-12-21    18.799999  18.175961      -0.0  1579000.0     0.0
# 2010-12-22    19.000000  18.302736      -0.0  1699000.0     2.0
# 2010-12-23    19.000000  18.410008      -0.0  1699000.0     2.0
# 2010-12-27    19.000000  18.500776      -0.0  1699000.0     2.0
# 2010-12-28    19.000000  18.577580      -0.0  1699000.0     2.0

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
y = np.array(y)

X.shape
# Out:
# (41550, 64, 64, 1)

# %%
from collections import Counter

Counter(y)
# Out:
# Counter({2.0: 37853, 0.0: 1852, 1.0: 1845})

# %%
X = sequential_data
y = labels

class_0 = []
class_1 = []
class_2 = []

class_0_labels = []
class_1_labels = []
class_2_labels = []

for i in range (0,len(y)):
    if y[i] == 0:
        class_0.append(X[i])
        class_0_labels.append(y[i])
    if y[i] == 1:
        class_1.append(X[i])
        class_1_labels.append(y[i])
    if y[i] == 2:
        class_2.append(X[i])
        class_2_labels.append(y[i])
        
class_0 = class_0[0:1384]
class_1 = class_1[0:1384]
class_2 = class_2[0:1845]

class_0_labels = class_0_labels[0:1384]
class_1_labels = class_1_labels[0:1384]
class_2_labels = class_2_labels[0:1845]

X = class_0 + class_1 + class_2
y = class_0_labels + class_1_labels + class_2_labels

X  = np.array(X).reshape(-1, 64, 64, 1)
y = np.array(y)

print(X.shape)

Counter(y)
# Out:
# (4613, 64, 64, 1)
# Counter({0.0: 1384, 1.0: 1384, 2.0: 1845})

# %%
# plot the image array X
i = X[0].reshape(64, 64)
fig2, ax2 = plt.subplots()
plt.imshow(i, interpolation="none", cmap="gray")

ax2.axis('off')

plt.show()

# %%
X = X/255

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten,BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.regularizers import l2
import efficientnet.tfkeras as efn
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(Conv2D(16, (3, 3), padding='same', kernel_initializer='he_uniform',kernel_regularizer=l2(1e-5), input_shape=X_train.shape[1:]))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))

model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_uniform',kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

# model.add(Dense(128, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))
# model.add(Dropout(0.25, seed=seed))

model.add(Dense(64, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))
model.add(Dropout(0.25, seed=seed))

model.add(Dense(32, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))
model.add(Dropout(0.25, seed=seed))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "DBS_CNN_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))
print(d_class_weights)

epochs = 0 
histories = {}
nr_log_hist = {}
r_log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    nr_log  = pd.DataFrame(columns = column_names)
    r_log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['C6L.SI','O39.SI','0883.HK','JPM','AXL']
    
    for name in test_sets:
        
        print('\n')
        print(name)
        print('\n')
        
        print('Non-Recession Test')
        print('\n')
        
        X = nr_test_data['{}_X'.format(name)]
        y = nr_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(nr_log)
        nr_log.loc[df_length] = logger
        print(nr_log.head(20))
        logger = []
        
        print('Recession Test')
        print('\n')
        
        X = r_test_data['{}_X'.format(name)]
        y = r_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test2.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(r_log)
        r_log.loc[df_length] = logger
        print(r_log.head(20))
        logger = []

    nr_log.to_csv('non_recession_{}_{}epochs.csv'.format(experiment,epochs))
    nr_log_hist['{}_epochs_logs'.format(epochs)] = nr_log
    r_log.to_csv('recession_{}_{}epochs.csv'.format(experiment,epochs))
    r_log_hist['{}_epochs_logs'.format(epochs)] = r_log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 0 2 ... 2 2 0] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# {0: 1.1111111111111112, 1: 1.1111111111111112, 2: 0.8333333333333334}
#
#
#
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  1/29 [>.............................] - ETA: 0s - loss: 0.4746 - accuracy: 0.3594 - mse: 6.0383 - weighted_accuracy: 0.3190 - weighted_mse: 6.0851WARNING:tensorflow:From C:\Users\Shearman Chua\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/29 [=>............................] - ETA: 1s - loss: 0.4259 - accuracy: 0.3359 - mse: 4.8045 - weighted_accuracy: 0.3126 - weighted_mse: 4.8107WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0197s vs `on_train_batch_end` time: 0.1018s). Check your callbacks.
# 29/29 [==============================] - 1s 27ms/step - loss: 0.2343 - accuracy: 0.3423 - mse: 1.6188 - weighted_accuracy: 0.3409 - weighted_mse: 1.6263 - val_loss: 0.1962 - val_accuracy: 0.3055 - val_mse: 0.9901 - val_weighted_accuracy: 0.3055 - val_weighted_mse: 0.9901
# Epoch 2/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.2043 - accuracy: 0.3279 - mse: 1.1699 - weighted_accuracy: 0.3337 - weighted_mse: 1.1686 - val_loss: 0.1978 - val_accuracy: 0.3142 - val_mse: 0.9308 - val_weighted_accuracy: 0.3142 - val_weighted_mse: 0.9308
# Epoch 3/20
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2028 - accuracy: 0.3507 - mse: 1.1689 - weighted_accuracy: 0.3511 - weighted_mse: 1.1702 - val_loss: 0.1959 - val_accuracy: 0.3099 - val_mse: 0.9684 - val_weighted_accuracy: 0.3099 - val_weighted_mse: 0.9684
# Epoch 4/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.2023 - accuracy: 0.3266 - mse: 1.1678 - weighted_accuracy: 0.3329 - weighted_mse: 1.1665 - val_loss: 0.1954 - val_accuracy: 0.4020 - val_mse: 0.9693 - val_weighted_accuracy: 0.4020 - val_weighted_mse: 0.9693
# Epoch 5/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2003 - accuracy: 0.3577 - mse: 1.1742 - weighted_accuracy: 0.3619 - weighted_mse: 1.1749 - val_loss: 0.1933 - val_accuracy: 0.3781 - val_mse: 1.0061 - val_weighted_accuracy: 0.3781 - val_weighted_mse: 1.0061
# Epoch 6/20
# 29/29 [==============================] - ETA: 0s - loss: 0.1999 - accuracy: 0.3651 - mse: 1.1814 - weighted_accuracy: 0.3742 - weighted_mse: 1.181 - 0s 10ms/step - loss: 0.1996 - accuracy: 0.3699 - mse: 1.1815 - weighted_accuracy: 0.3784 - weighted_mse: 1.1815 - val_loss: 0.1936 - val_accuracy: 0.4160 - val_mse: 0.9484 - val_weighted_accuracy: 0.4160 - val_weighted_mse: 0.9484
# Epoch 7/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1986 - accuracy: 0.3626 - mse: 1.1721 - weighted_accuracy: 0.3738 - weighted_mse: 1.1712 - val_loss: 0.1943 - val_accuracy: 0.3597 - val_mse: 0.9561 - val_weighted_accuracy: 0.3597 - val_weighted_mse: 0.9561
# Epoch 8/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1966 - accuracy: 0.3756 - mse: 1.1883 - weighted_accuracy: 0.3890 - weighted_mse: 1.1871 - val_loss: 0.1928 - val_accuracy: 0.4225 - val_mse: 0.9953 - val_weighted_accuracy: 0.4225 - val_weighted_mse: 0.9953
# Epoch 9/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1976 - accuracy: 0.3650 - mse: 1.1866 - weighted_accuracy: 0.3792 - weighted_mse: 1.1856 - val_loss: 0.1934 - val_accuracy: 0.4323 - val_mse: 0.9285 - val_weighted_accuracy: 0.4323 - val_weighted_mse: 0.9285
# Epoch 10/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1961 - accuracy: 0.3835 - mse: 1.1876 - weighted_accuracy: 0.3974 - weighted_mse: 1.1860 - val_loss: 0.1922 - val_accuracy: 0.4420 - val_mse: 0.9278 - val_weighted_accuracy: 0.4420 - val_weighted_mse: 0.9278
# Epoch 11/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1935 - accuracy: 0.4130 - mse: 1.1981 - weighted_accuracy: 0.4316 - weighted_mse: 1.1954 - val_loss: 0.1883 - val_accuracy: 0.4453 - val_mse: 1.0138 - val_weighted_accuracy: 0.4453 - val_weighted_mse: 1.0138
# Epoch 12/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1942 - accuracy: 0.3992 - mse: 1.2074 - weighted_accuracy: 0.4211 - weighted_mse: 1.2031 - val_loss: 0.1869 - val_accuracy: 0.4030 - val_mse: 1.0628 - val_weighted_accuracy: 0.4030 - val_weighted_mse: 1.0628
# Epoch 13/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1911 - accuracy: 0.4211 - mse: 1.2122 - weighted_accuracy: 0.4456 - weighted_mse: 1.2108 - val_loss: 0.1890 - val_accuracy: 0.4572 - val_mse: 0.9582 - val_weighted_accuracy: 0.4572 - val_weighted_mse: 0.9582
# Epoch 14/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1902 - accuracy: 0.4301 - mse: 1.2255 - weighted_accuracy: 0.4581 - weighted_mse: 1.2227 - val_loss: 0.1854 - val_accuracy: 0.4561 - val_mse: 1.0244 - val_weighted_accuracy: 0.4561 - val_weighted_mse: 1.0244
# Epoch 15/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1883 - accuracy: 0.4317 - mse: 1.2302 - weighted_accuracy: 0.4593 - weighted_mse: 1.2261 - val_loss: 0.1838 - val_accuracy: 0.4485 - val_mse: 1.0401 - val_weighted_accuracy: 0.4485 - val_weighted_mse: 1.0401
# Epoch 16/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1870 - accuracy: 0.4472 - mse: 1.2353 - weighted_accuracy: 0.4760 - weighted_mse: 1.2304 - val_loss: 0.1826 - val_accuracy: 0.4670 - val_mse: 1.0183 - val_weighted_accuracy: 0.4670 - val_weighted_mse: 1.0183
# Epoch 17/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1868 - accuracy: 0.4477 - mse: 1.2534 - weighted_accuracy: 0.4778 - weighted_mse: 1.2485 - val_loss: 0.1798 - val_accuracy: 0.4735 - val_mse: 1.1067 - val_weighted_accuracy: 0.4735 - val_weighted_mse: 1.1067
# Epoch 18/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1841 - accuracy: 0.4629 - mse: 1.2689 - weighted_accuracy: 0.4980 - weighted_mse: 1.2635 - val_loss: 0.1808 - val_accuracy: 0.4648 - val_mse: 1.0199 - val_weighted_accuracy: 0.4648 - val_weighted_mse: 1.0199
# Epoch 19/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1842 - accuracy: 0.4501 - mse: 1.2815 - weighted_accuracy: 0.4846 - weighted_mse: 1.2776 - val_loss: 0.1819 - val_accuracy: 0.4724 - val_mse: 0.9974 - val_weighted_accuracy: 0.4724 - val_weighted_mse: 0.9974
# Epoch 20/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1839 - accuracy: 0.4612 - mse: 1.2741 - weighted_accuracy: 0.4979 - weighted_mse: 1.2709 - val_loss: 0.1807 - val_accuracy: 0.4778 - val_mse: 1.0118 - val_weighted_accuracy: 0.4778 - val_weighted_mse: 1.0118
# Validation loss: 0.1806623786687851
# Validation accuracy: 0.47778981924057007
#
#
# C6L.SI
#
#
# Non-Recession Test
#
#
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1987 - accuracy: 0.1250 - mse: 1.1074 - weighted_accuracy: 0.1250 - weighted_mse: 1.1074WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0026s vs `on_test_batch_end` time: 0.0060s). Check your callbacks.
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1988 - accuracy: 0.0688 - mse: 1.0825 - weighted_accuracy: 0.0688 - weighted_mse: 1.0825
# Test loss: 0.19875465333461761
# Test accuracy: 0.06880734115839005
#
#
# number of predictions: 218
# actual predicted buys: 9
# actual buys but predicted sell: 0
# actual buys but predicted hold: 0
# actual sells but predicted buy: 4
# actual predicted sells: 5
# actual sells but predicted hold: 0
# actual holds but predicted buy: 91
# actual holds but predicted sell: 108
# actual predicted holds: 1
# Percentage buys correct: 8.653846153846153%
# Percentage sells correct: 4.424778761061947%
# Percentage holds correct: 100.0%
# actual buys: 9
# actual sells: 9
# actual holds: 200
#
#
# Percentage low buys correct: 52.42718446601942%
# Percentage high sells correct: 44.24778761061947%
# Percentage mid holds correct: 100.0%
#
#
# Capital: 100
# Share price: $0.7012750947593986
# Shares owned at the moment: 142
# Cash capital at the moment: $0.14508861966184838
#
#
# Price increase from previously bought: 2.589034750858943%
# Share price: $0.7214097868761586
# Shares owned at the moment: 0
# Cash capital at the moment: $102.30356783430123
#
#
# Share price: $0.7885235071154348
# Shares owned at the moment: 129
# Cash capital at the moment: $0.3043067022609449
#
#
# Price increase from previously bought: -9.611040587192122%
# Share price: $0.7146982228372389
# Shares owned at the moment: 0
# Cash capital at the moment: $92.24683825371326
#
#
# Share price: $0.5871817063476314
# Shares owned at the moment: 156
# Cash capital at the moment: $0.39459111145961856
#
#
# Price increase from previously bought: 17.963374888785587%
# Share price: $0.694564170770452
# Shares owned at the moment: 0
# Cash capital at the moment: $108.44863372238959
#
#
# Share price: $0.7482554029818644
# Shares owned at the moment: 144
# Cash capital at the moment: $0.4035465534202842
#
#
# Price increase from previously bought: -5.6411711644784095%
# Share price: $0.7079866587983183
# Shares owned at the moment: 0
# Cash capital at the moment: $102.07326270349398
#
#
# Share price: $0.5871817063476314
# Shares owned at the moment: 173
# Cash capital at the moment: $0.21147580855884485
#
#
# Price increase from previously bought: -48.14805454740222%
# Share price: $0.305302417212735
# Shares owned at the moment: 0
# Cash capital at the moment: $52.883546361373035
#
#
# Share price: $0.285167725095975
# Shares owned at the moment: 184
# Cash capital at the moment: $0.2683900748150734
#
#
# Price increase from previously bought: 2.0728493294265737%
# Share price: $0.2918792891348947
# Shares owned at the moment: 0
# Cash capital at the moment: $53.82648835533344
#
#
# Share price: $0.6274498104812019
# Shares owned at the moment: 85
# Cash capital at the moment: $0.3465880712312952
#
#
# Price increase from previously bought: 5.0592725579509334%
# Share price: $0.6610069906258265
# Shares owned at the moment: 0
# Cash capital at the moment: $56.37767189036776
#
#
# Share price: $0.285167725095975
# Shares owned at the moment: 197
# Cash capital at the moment: $0.04514043138993884
#
#
# Price increase from previously bought: -40.173968106713495%
# Share price: $0.1710736966342321
# Shares owned at the moment: 0
# Cash capital at the moment: $33.65397949318207
#
#
# Share price: $0.1375171565395814
# Shares owned at the moment: 244
# Cash capital at the moment: $0.007519285486146998
#
#
# Price increase from previously bought: -14.875677434212486%
# Share price: $0.1173824644228214
# Shares owned at the moment: 0
# Cash capital at the moment: $28.570076971026854
#
#
# Share price: $0.01
# Shares owned at the moment: 2849
# Cash capital at the moment: $0.0017294710268522806
#
#
# Price increase from previously bought: 936.7487050107794%
# Share price: $0.1039599763949559
# Shares owned at the moment: 0
# Cash capital at the moment: $295.36920179519586
#
#
# Share price: $0.3589936494241448
# Shares owned at the moment: 820
# Cash capital at the moment: $0.1848785879457182
#
#
# Price increase from previously bought: -5.867512890592607%
# Share price: $0.3388589573073857
# Shares owned at the moment: 0
# Cash capital at the moment: $277.2850966312738
#
#
# Share price: $0.3120133412016799
# Shares owned at the moment: 886
# Cash capital at the moment: $0.08105582074756512
#
#
# Price increase from previously bought: -23.87029502991531%
# Share price: $0.238188056923484
# Shares owned at the moment: 0
# Cash capital at the moment: $210.5353290542603
#
#
# Share price: $0.42610736966342366
# Shares owned at the moment: 492
# Cash capital at the moment: $0.31397990870124204
#
#
# Price increase from previously bought: -17.55224352141275%
# Share price: $0.352282085385226
# Shares owned at the moment: 0
# Cash capital at the moment: $173.1601282567062
#
#
# Share price: $0.3724161374520112
# Shares owned at the moment: 463
# Cash capital at the moment: $0.2572777694142303
#
#
# Price increase from previously bought: -18.245986823747806%
# Share price: $0.305302417212735
# Shares owned at the moment: 0
# Cash capital at the moment: $141.2235706361944
#
#
# Share price: $0.2516111850013243
# Shares owned at the moment: 559
# Cash capital at the moment: $0.18612892631085742
#
#
# Price increase from previously bought: 15.685962995578251%
# Share price: $0.2918792891348947
# Shares owned at the moment: 0
# Cash capital at the moment: $162.89796011549436
#
#
#
#
# Capital at the end of test period: $162.89796011549436
# profit gained: 62.89796011549436%
#
#
# Capital at the end of test period if Buy and Hold: $35.84540016707856
# profit gained: -64.15459983292143%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.068807      8.653846       4.424779          100.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         52.427184           44.247788              100.0       62.89796
#
#    buy_n_hold profit
# 0           -64.1546
# Recession Test
#
#
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1992 - accuracy: 0.0651 - mse: 1.0428 - weighted_accuracy: 0.0651 - weighted_mse: 1.0428
# Test loss: 0.19920043647289276
# Test accuracy: 0.0651162788271904
#
#
# number of predictions: 215
# actual predicted buys: 7
# actual buys but predicted sell: 1
# actual buys but predicted hold: 0
# actual sells but predicted buy: 2
# actual predicted sells: 7
# actual sells but predicted hold: 0
# actual holds but predicted buy: 114
# actual holds but predicted sell: 84
# actual predicted holds: 0
# Percentage buys correct: 5.691056910569106%
# Percentage sells correct: 7.608695652173913%
# Percentage holds correct: 0%
# actual buys: 8
# actual sells: 9
# actual holds: 198
#
#
# Percentage low buys correct: 44.71544715447155%
# Percentage high sells correct: 54.94505494505494%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $1.0062617748699323
# Shares owned at the moment: 99
# Cash capital at the moment: $0.10612951966835737
#
#
# Price increase from previously bought: -0.6447409640047974%
# Share price: $1.0025233714829802
# Shares owned at the moment: 0
# Cash capital at the moment: $99.08300630859716
#
#
# Share price: $0.9931775412724846
# Shares owned at the moment: 99
# Cash capital at the moment: $0.48803713700975493
#
#
# Price increase from previously bought: -39.124775678263624%
# Share price: $0.6062617035671785
# Shares owned at the moment: 0
# Cash capital at the moment: $60.342891041364254
#
#
# Share price: $0.46420558348692387
# Shares owned at the moment: 129
# Cash capital at the moment: $0.29569384080908634
#
#
# Price increase from previously bought: 9.363043241172587%
# Share price: $0.5090654437174831
# Shares owned at the moment: 0
# Cash capital at the moment: $65.78454511420563
#
#
# Share price: $0.5557944165130759
# Shares owned at the moment: 118
# Cash capital at the moment: $0.020448677504177226
#
#
# Price increase from previously bought: -0.27424582398404285%
# Share price: $0.5557944165130759
# Shares owned at the moment: 0
# Cash capital at the moment: $65.42383453788864
#
#
# Share price: $0.5146729596694688
# Shares owned at the moment: 126
# Cash capital at the moment: $0.3967074390101004
#
#
# Price increase from previously bought: -67.13229828091349%
# Share price: $0.16962636643929108
# Shares owned at the moment: 0
# Cash capital at the moment: $21.710854074389562
#
#
# Share price: $0.2137383499098866
# Shares owned at the moment: 101
# Cash capital at the moment: $0.06391490680354295
#
#
# Price increase from previously bought: 0.5978422232308045%
# Share price: $0.21560746247492013
# Shares owned at the moment: 0
# Cash capital at the moment: $21.780383644068067
#
#
# Share price: $0.12028040431870078
# Shares owned at the moment: 180
# Cash capital at the moment: $0.07037206656416828
#
#
# Price increase from previously bought: -12.672186184715395%
# Share price: $0.10532710272044075
# Shares owned at the moment: 0
# Cash capital at the moment: $18.977113640396887
#
#
# Share price: $0.16887848967932728
# Shares owned at the moment: 112
# Cash capital at the moment: $0.01070822149099726
#
#
# Price increase from previously bought: -32.28361825341083%
# Share price: $0.11467288836671506
# Shares owned at the moment: 0
# Cash capital at the moment: $12.818752468946135
#
#
# Share price: $0.09224300281565666
# Shares owned at the moment: 138
# Cash capital at the moment: $0.05421186081697371
#
#
# Price increase from previously bought: -44.73152296771694%
# Share price: $0.05112150140782833
# Shares owned at the moment: 0
# Cash capital at the moment: $7.089578445313013
#
#
# Share price: $0.07915890291087245
# Shares owned at the moment: 89
# Cash capital at the moment: $0.025061944757928778
#
#
# Price increase from previously bought: 27.983311701535985%
# Share price: $0.10158878846193097
# Shares owned at the moment: 0
# Cash capital at the moment: $9.041600261893727
#
#
# Share price: $0.07915890291087245
# Shares owned at the moment: 113
# Cash capital at the moment: $0.07204560388558612
#
#
# Price increase from previously bought: -42.66063825504%
# Share price: $0.045514030020063705
# Shares owned at the moment: 0
# Cash capital at the moment: $5.200987511324049
#
#
# Share price: $0.03056077298602477
# Shares owned at the moment: 169
# Cash capital at the moment: $0.022013757440608295
#
#
# Price increase from previously bought: -18.572517056226147%
# Share price: $0.02495330159826014
# Shares owned at the moment: 0
# Cash capital at the moment: $4.227524680628781
#
#
# Share price: $0.03056077298602477
# Shares owned at the moment: 137
# Cash capital at the moment: $0.02918501032090237
#
#
# Price increase from previously bought: 30.222872896418473%
# Share price: $0.039906558632298854
# Shares owned at the moment: 0
# Cash capital at the moment: $5.481348746981126
#
#
# Share price: $0.047383187149318544
# Shares owned at the moment: 115
# Cash capital at the moment: $0.017297291873521914
#
#
# Price increase from previously bought: 7.593654821914253%
# Share price: $0.05112150140782833
# Shares owned at the moment: 0
# Cash capital at the moment: $5.880102778953554
#
#
# Share price: $0.047383187149318544
# Shares owned at the moment: 123
# Cash capital at the moment: $0.03594339653411627
#
#
# Price increase from previously bought: 27.263406436659608%
# Share price: $0.06046728705410264
# Shares owned at the moment: 0
# Cash capital at the moment: $7.45296664434269
#
#
# Share price: $0.03429908724453445
# Shares owned at the moment: 216
# Cash capital at the moment: $0.023990141699996137
#
#
# Price increase from previously bought: -5.708883284143584%
# Share price: $0.0324299301152795
# Shares owned at the moment: 0
# Cash capital at the moment: $7.009591668111891
#
#
# Share price: $0.21000003565137693
# Shares owned at the moment: 33
# Cash capital at the moment: $0.060532988381089226
#
#
# Price increase from previously bought: 3.2762888949313007%
# Share price: $0.2174766641683964
# Shares owned at the moment: 0
# Cash capital at the moment: $7.217526898664888
#
#
# Share price: $0.21000003565137693
# Shares owned at the moment: 34
# Cash capital at the moment: $0.05789068318466839
#
#
# Price increase from previously bought: -2.9371680260268374%
# Share price: $0.2043925196993911
# Shares owned at the moment: 0
# Cash capital at the moment: $6.988125652372072
#
#
# Share price: $0.21186914821641079
# Shares owned at the moment: 32
# Cash capital at the moment: $0.18966842440388287
#
#
#
#
# Capital at the end of test period: $7.189430851521101
# profit gained: -92.8105691484789%
#
#
# Capital at the end of test period if Buy and Hold: $21.761644528562254
# profit gained: -78.23835547143774%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.065116      5.691057       7.608696            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         44.715447           54.945055                0.0     -92.810569
#
#    buy_n_hold profit
# 0         -78.238355
#
#
# O39.SI
#
#
# Non-Recession Test
#
#
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1985 - accuracy: 0.0938 - mse: 1.1576 - weighted_accuracy: 0.0938 - weighted_mse: 1.1576WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_test_batch_end` time: 0.0060s). Check your callbacks.
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2000 - accuracy: 0.0780 - mse: 1.1087 - weighted_accuracy: 0.0780 - weighted_mse: 1.1087
# Test loss: 0.2000281810760498
# Test accuracy: 0.07798165082931519
#
#
# number of predictions: 218
# actual predicted buys: 8
# actual buys but predicted sell: 0
# actual buys but predicted hold: 0
# actual sells but predicted buy: 1
# actual predicted sells: 8
# actual sells but predicted hold: 0
# actual holds but predicted buy: 102
# actual holds but predicted sell: 98
# actual predicted holds: 1
# Percentage buys correct: 7.207207207207207%
# Percentage sells correct: 7.547169811320755%
# Percentage holds correct: 100.0%
# actual buys: 8
# actual sells: 9
# actual holds: 201
#
#
# Percentage low buys correct: 51.351351351351354%
# Percentage high sells correct: 51.42857142857143%
# Percentage mid holds correct: 100.0%
#
#
# Capital: 100
# Share price: $0.6357665229914489
# Shares owned at the moment: 156
# Cash capital at the moment: $0.5476785749706323
#
#
# Price increase from previously bought: -4.123544547624158%
# Share price: $0.611226670816807
# Shares owned at the moment: 0
# Cash capital at the moment: $95.63682298061212
#
#
# Share price: $0.513067262118245
# Shares owned at the moment: 185
# Cash capital at the moment: $0.4583565191341279
#
#
# Price increase from previously bought: -14.583803923911931%
# Share price: $0.4394477055943231
# Shares owned at the moment: 0
# Cash capital at the moment: $81.53261303386279
#
#
# Share price: $0.3290180782703287
# Shares owned at the moment: 247
# Cash capital at the moment: $0.041662171426480654
#
#
# Price increase from previously bought: 59.23038861423%
# Share price: $0.5253374807436784
# Shares owned at the moment: 0
# Cash capital at the moment: $129.44318443131988
#
#
# Share price: $0.7216562981408023
# Shares owned at the moment: 178
# Cash capital at the moment: $0.6351126043171291
#
#
# Price increase from previously bought: 1.4212960320358015%
# Share price: $0.73392593169001
# Shares owned at the moment: 0
# Cash capital at the moment: $130.91467170157662
#
#
# Share price: $0.8198157068393652
# Shares owned at the moment: 159
# Cash capital at the moment: $0.20550989630203276
#
#
# Price increase from previously bought: 0.47205410422999083%
# Share price: $0.8259508161520819
# Shares owned at the moment: 0
# Cash capital at the moment: $131.17054267012054
#
#
# Share price: $0.8075460732901576
# Shares owned at the moment: 161
# Cash capital at the moment: $0.7980838464559667
#
#
# Price increase from previously bought: 21.69677954335214%
# Share price: $0.9854601478253582
# Shares owned at the moment: 0
# Cash capital at the moment: $159.02085516588895
#
#
# Share price: $0.6603063751660889
# Shares owned at the moment: 240
# Cash capital at the moment: $0.11152291841798956
#
#
# Price increase from previously bought: -78.10541761814493%
# Share price: $0.14496889442240968
# Shares owned at the moment: 0
# Cash capital at the moment: $34.80837810947752
#
#
# Share price: $0.611226670816807
# Shares owned at the moment: 56
# Cash capital at the moment: $0.48555563643054
#
#
# Price increase from previously bought: 2.7287075763249957%
# Share price: $0.629631998754957
# Shares owned at the moment: 0
# Cash capital at the moment: $35.64798423889987
#
#
# Share price: $0.7277914074535181
# Shares owned at the moment: 48
# Cash capital at the moment: $0.6179282153471348
#
#
# Price increase from previously bought: 4.769580864608103%
# Share price: $0.7646008931773667
# Shares owned at the moment: 0
# Cash capital at the moment: $37.21784376996133
#
#
# Share price: $0.6419016323041646
# Shares owned at the moment: 57
# Cash capital at the moment: $0.5288326477602681
#
#
# Price increase from previously bought: -95.58704284032893%
# Share price: $0.028404742861924286
# Shares owned at the moment: 0
# Cash capital at the moment: $2.1434505474463457
#
#
# Share price: $0.05294459503656523
# Shares owned at the moment: 40
# Cash capital at the moment: $0.01984284052971441
#
#
# Price increase from previously bought: 57.50471473911387%
# Share price: $0.08361955652392193
# Shares owned at the moment: 0
# Cash capital at the moment: $3.3554269502689604
#
#
# Share price: $0.2799383739210459
# Shares owned at the moment: 11
# Cash capital at the moment: $0.2676367013263432
#
#
# Price increase from previously bought: -39.61368816924777%
# Share price: $0.1695093316732772
# Shares owned at the moment: 0
# Cash capital at the moment: $2.127111692449276
#
#
# Share price: $0.07748444721120527
# Shares owned at the moment: 27
# Cash capital at the moment: $0.02927839754130135
#
#
# Price increase from previously bought: 126.06105647549914%
# Share price: $0.17564385590976817
# Shares owned at the moment: 0
# Cash capital at the moment: $4.758620950803742
#
#
# Share price: $0.13269926087320294
# Shares owned at the moment: 35
# Cash capital at the moment: $0.10137451638259343
#
#
# Price increase from previously bought: 87.32569895162653%
# Share price: $0.2492634124336892
# Shares owned at the moment: 0
# Cash capital at the moment: $8.801602348114974
#
#
# Share price: $0.40263763479424886
# Shares owned at the moment: 21
# Cash capital at the moment: $0.32295969402638036
#
#
# Price increase from previously bought: 5.803813090539878%
# Share price: $0.4271774869688898
# Shares owned at the moment: 0
# Cash capital at the moment: $9.269017420500612
#
#
# Share price: $0.38423289193232546
# Shares owned at the moment: 24
# Cash capital at the moment: $0.022068643257266984
#
#
# Price increase from previously bought: -24.158699371468085%
# Share price: $0.29220859254647835
# Shares owned at the moment: 0
# Cash capital at the moment: $7.01578909726468
#
#
#
#
# Capital at the end of test period: $7.01578909726468
# profit gained: -92.98421090273533%
#
#
# Capital at the end of test period if Buy and Hold: $44.097971344241664
# profit gained: -55.90202865575834%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.068807      8.653846       4.424779          100.0
# 1       0.077982      7.207207       7.547170          100.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         52.427184           44.247788              100.0      62.897960
# 1         51.351351           51.428571              100.0     -92.984211
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# Recession Test
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1957 - accuracy: 0.0625 - mse: 1.0458 - weighted_accuracy: 0.0625 - weighted_mse: 1.0458WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_test_batch_end` time: 0.0083s). Check your callbacks.
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1983 - accuracy: 0.0884 - mse: 1.0726 - weighted_accuracy: 0.0884 - weighted_mse: 1.0726
# Test loss: 0.19828683137893677
# Test accuracy: 0.08837209641933441
#
#
# number of predictions: 215
# actual predicted buys: 10
# actual buys but predicted sell: 2
# actual buys but predicted hold: 0
# actual sells but predicted buy: 2
# actual predicted sells: 8
# actual sells but predicted hold: 0
# actual holds but predicted buy: 110
# actual holds but predicted sell: 82
# actual predicted holds: 1
# Percentage buys correct: 8.19672131147541%
# Percentage sells correct: 8.695652173913043%
# Percentage holds correct: 100.0%
# actual buys: 12
# actual sells: 10
# actual holds: 193
#
#
# Percentage low buys correct: 51.63934426229508%
# Percentage high sells correct: 52.747252747252745%
# Percentage mid holds correct: 100.0%
#
#
# Capital: 100
# Share price: $0.9886586309918834
# Shares owned at the moment: 100
# Cash capital at the moment: $0.8622557772888797
#
#
# Price increase from previously bought: 0.9558718911797381%
# Share price: $1.0008537405328568
# Shares owned at the moment: 0
# Cash capital at the moment: $100.67239505192802
#
#
# Share price: $0.9581707117622773
# Shares owned at the moment: 104
# Cash capital at the moment: $0.7486042050871617
#
#
# Price increase from previously bought: -69.13159749526733%
# Share price: $0.2965853649672121
# Shares owned at the moment: 0
# Cash capital at the moment: $31.5086587472966
#
#
# Share price: $0.3301218435163016
# Shares owned at the moment: 95
# Cash capital at the moment: $0.060839281629316844
#
#
# Price increase from previously bought: 0.6467743355536681%
# Share price: $0.3331706935901313
# Shares owned at the moment: 0
# Cash capital at the moment: $31.62501432899137
#
#
# Share price: $0.29048766481955224
# Shares owned at the moment: 108
# Cash capital at the moment: $0.16607169202831784
#
#
# Price increase from previously bought: 16.472403241645004%
# Share price: $0.3392683937377907
# Shares owned at the moment: 0
# Cash capital at the moment: $36.70629550276959
#
#
# Share price: $0.2539023361966335
# Shares owned at the moment: 144
# Cash capital at the moment: $0.043813765320507514
#
#
# Price increase from previously bought: 82.35165127838442%
# Share price: $0.4642683392213509
# Shares owned at the moment: 0
# Cash capital at the moment: $66.71460435086338
#
#
# Share price: $0.3545120625982474
# Shares owned at the moment: 187
# Cash capital at the moment: $0.2385408167999543
#
#
# Price increase from previously bought: 15.163208379364956%
# Share price: $0.4093902009097994
# Shares owned at the moment: 0
# Cash capital at the moment: $76.58397947611456
#
#
# Share price: $0.3849999818278531
# Shares owned at the moment: 198
# Cash capital at the moment: $0.14435058409438284
#
#
# Price increase from previously bought: 10.781851411277055%
# Share price: $0.4276830105984313
# Shares owned at the moment: 0
# Cash capital at the moment: $84.59271328331293
#
#
# Share price: $0.4215853104507723
# Shares owned at the moment: 200
# Cash capital at the moment: $0.043779272410546355
#
#
# Price increase from previously bought: 0.4469578457005685%
# Share price: $0.42463416052460157
# Shares owned at the moment: 0
# Cash capital at the moment: $84.73706258904232
#
#
# Share price: $0.4276830105984313
# Shares owned at the moment: 197
# Cash capital at the moment: $0.2518122301596577
#
#
# Price increase from previously bought: -7.383321151001276%
# Share price: $0.3971950913688269
# Shares owned at the moment: 0
# Cash capital at the moment: $78.28406478906949
#
#
# Share price: $0.36670717213922077
# Shares owned at the moment: 212
# Cash capital at the moment: $0.3283540141975294
#
#
# Price increase from previously bought: -18.514688715818217%
# Share price: $0.2996342150410418
# Shares owned at the moment: 0
# Cash capital at the moment: $63.67612085552946
#
#
# Share price: $0.2539023361966335
# Shares owned at the moment: 250
# Cash capital at the moment: $0.025978950235902687
#
#
# Price increase from previously bought: -19.433841036070586%
# Share price: $0.20512189803274183
# Shares owned at the moment: 0
# Cash capital at the moment: $51.165432153523845
#
#
# Share price: $0.2447560767294903
# Shares owned at the moment: 208
# Cash capital at the moment: $0.11616771790059488
#
#
# Price increase from previously bought: -0.27424582398404285%
# Share price: $0.2447560767294903
# Shares owned at the moment: 0
# Cash capital at the moment: $50.8854312017453
#
#
# Share price: $0.2935365148933824
# Shares owned at the moment: 172
# Cash capital at the moment: $0.2583078685389495
#
#
# Price increase from previously bought: -3.381585377912033%
# Share price: $0.2843902554262392
# Shares owned at the moment: 0
# Cash capital at the moment: $49.03891521103548
#
#
# Share price: $0.2081707481065711
# Shares owned at the moment: 234
# Cash capital at the moment: $0.19300227769125655
#
#
# Price increase from previously bought: 68.37122049384143%
# Share price: $0.3514635032787641
# Shares owned at the moment: 0
# Cash capital at the moment: $82.20929528056217
#
#
# Share price: $0.7112193801146416
# Shares owned at the moment: 115
# Cash capital at the moment: $0.194143438417143
#
#
# Price increase from previously bought: 6.993152959609028%
# Share price: $0.7630486683523638
# Shares owned at the moment: 0
# Cash capital at the moment: $87.70342615757254
#
#
# Share price: $0.6990242705736691
# Shares owned at the moment: 125
# Cash capital at the moment: $0.08510274285418973
#
#
#
#
# Capital at the end of test period: $93.30363346642069
# profit gained: -6.696366533579308%
#
#
# Capital at the end of test period if Buy and Hold: $75.43708035614208
# profit gained: -24.562919643857924%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.065116      5.691057       7.608696            0.0
# 1       0.088372      8.196721       8.695652          100.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         44.715447           54.945055                0.0     -92.810569
# 1         51.639344           52.747253              100.0      -6.696367
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
#
#
# 0883.HK
#
#
# Non-Recession Test
#
#
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2069 - accuracy: 0.0625 - mse: 1.1087 - weighted_accuracy: 0.0625 - weighted_mse: 1.1087WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0030s vs `on_test_batch_end` time: 0.0050s). Check your callbacks.
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2020 - accuracy: 0.0474 - mse: 1.0935 - weighted_accuracy: 0.0474 - weighted_mse: 1.0935
# Test loss: 0.20198753476142883
# Test accuracy: 0.04739336669445038
#
#
# number of predictions: 211
# actual predicted buys: 5
# actual buys but predicted sell: 3
# actual buys but predicted hold: 0
# actual sells but predicted buy: 4
# actual predicted sells: 5
# actual sells but predicted hold: 0
# actual holds but predicted buy: 111
# actual holds but predicted sell: 83
# actual predicted holds: 0
# Percentage buys correct: 4.166666666666667%
# Percentage sells correct: 5.4945054945054945%
# Percentage holds correct: 0%
# actual buys: 8
# actual sells: 9
# actual holds: 194
#
#
# Percentage low buys correct: 45.833333333333336%
# Percentage high sells correct: 50.0%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.6441463755029468
# Shares owned at the moment: 154
# Cash capital at the moment: $0.5286621825206907
#
#
# Price increase from previously bought: 17.850859998140113%
# Share price: $0.7612196562958087
# Shares owned at the moment: 0
# Cash capital at the moment: $117.43411272763394
#
#
# Share price: $0.8441462824615587
# Shares owned at the moment: 138
# Cash capital at the moment: $0.6215722337446863
#
#
# Price increase from previously bought: -1.4268104788451863%
# Share price: $0.8343901951124433
# Shares owned at the moment: 0
# Cash capital at the moment: $115.45076808021669
#
#
# Share price: $0.9758535779763593
# Shares owned at the moment: 117
# Cash capital at the moment: $0.9619185682687572
#
#
# Price increase from previously bought: 0.22426972548585944%
# Share price: $0.9807317379526521
# Shares owned at the moment: 0
# Cash capital at the moment: $115.39198147204279
#
#
# Share price: $0.9904878253017684
# Shares owned at the moment: 116
# Cash capital at the moment: $0.1794281207663886
#
#
# Price increase from previously bought: -39.07421284698541%
# Share price: $0.6051220261064831
# Shares owned at the moment: 0
# Cash capital at the moment: $70.18054922279046
#
#
# Share price: $0.5417073420354945
# Shares owned at the moment: 129
# Cash capital at the moment: $0.1081314206245736
#
#
# Price increase from previously bought: -30.807129137448975%
# Share price: $0.3758536244970532
# Shares owned at the moment: 0
# Cash capital at the moment: $48.459914907454106
#
#
# Share price: $0.35146352242599854
# Shares owned at the moment: 137
# Cash capital at the moment: $0.17699845301830663
#
#
# Price increase from previously bought: 12.182838846416244%
# Share price: $0.3953660317987555
# Shares owned at the moment: 0
# Cash capital at the moment: $54.19319065696763
#
#
# Share price: $0.5173172399644399
# Shares owned at the moment: 104
# Cash capital at the moment: $0.24424497003604984
#
#
# Price increase from previously bought: 5.3679390494481005%
# Share price: $0.5465855020117878
# Shares owned at the moment: 0
# Cash capital at the moment: $56.93281372568661
#
#
# Share price: $0.5270733273135557
# Shares owned at the moment: 107
# Cash capital at the moment: $0.380876376574129
#
#
# Price increase from previously bought: 20.953811940444123%
# Share price: $0.6392684481301243
# Shares owned at the moment: 0
# Cash capital at the moment: $68.59449558563514
#
#
# Share price: $0.48317081794079875
# Shares owned at the moment: 141
# Cash capital at the moment: $0.28006077132596374
#
#
# Price increase from previously bought: 13.821249864081686%
# Share price: $0.5514634293846103
# Shares owned at the moment: 0
# Cash capital at the moment: $77.82257436981214
#
#
# Share price: $0.5417073420354945
# Shares owned at the moment: 143
# Cash capital at the moment: $0.14539804648096322
#
#
# Price increase from previously bought: -68.52416739260417%
# Share price: $0.17097579016561837
# Shares owned at the moment: 0
# Cash capital at the moment: $24.52769981068176
#
#
# Share price: $0.01
# Shares owned at the moment: 2446
# Cash capital at the moment: $0.00043481068176021154
#
#
# Price increase from previously bought: 1507.7756451408882%
# Share price: $0.16121970281650255
# Shares owned at the moment: 0
# Cash capital at the moment: $393.25938356885183
#
#
# Share price: $0.4587804832662743
# Shares owned at the moment: 854
# Cash capital at the moment: $0.38340489450268933
#
#
# Price increase from previously bought: 3.967142832180537%
# Share price: $0.4782926579645055
# Shares owned at the moment: 0
# Cash capital at the moment: $407.72206448896077
#
#
# Share price: $0.3709756971242302
# Shares owned at the moment: 1096
# Cash capital at the moment: $0.014579689672075347
#
#
# Price increase from previously bought: -35.67982488890703%
# Share price: $0.23926840160942997
# Shares owned at the moment: 0
# Cash capital at the moment: $261.5315928911565
#
#
# Share price: $0.28317091098218694
# Shares owned at the moment: 921
# Cash capital at the moment: $0.013982751772175561
#
#
# Price increase from previously bought: 10.033308352287262%
# Share price: $0.3124391730295344
# Shares owned at the moment: 0
# Cash capital at the moment: $286.9791307964828
#
#
# Share price: $0.25878057630766205
# Shares owned at the moment: 1105
# Cash capital at the moment: $0.24022450026137676
#
#
# Price increase from previously bought: 48.601644992614546%
# Share price: $0.385609711846169
# Shares owned at the moment: 0
# Cash capital at the moment: $425.1671845784055
#
#
# Share price: $0.2539024163313688
# Shares owned at the moment: 1669
# Cash capital at the moment: $0.23870310599409095
#
#
# Price increase from previously bought: -63.50093391047509%
# Share price: $0.09292685876922112
# Shares owned at the moment: 0
# Cash capital at the moment: $154.9071193417881
#
#
#
#
# Capital at the end of test period: $154.9071193417881
# profit gained: 54.9071193417881%
#
#
# Capital at the end of test period if Buy and Hold: $45.31039913308918
# profit gained: -54.68960086691082%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.068807      8.653846       4.424779          100.0
# 1       0.077982      7.207207       7.547170          100.0
# 2       0.047393      4.166667       5.494505            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         52.427184           44.247788              100.0      62.897960
# 1         51.351351           51.428571              100.0     -92.984211
# 2         45.833333           50.000000                0.0      54.907119
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# 2         -54.689601
# Recession Test
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1970 - accuracy: 0.0312 - mse: 1.0658 - weighted_accuracy: 0.0312 - weighted_mse: 1.0658WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0030s vs `on_test_batch_end` time: 0.0060s). Check your callbacks.
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2001 - accuracy: 0.0704 - mse: 1.0715 - weighted_accuracy: 0.0704 - weighted_mse: 1.0715
# Test loss: 0.20009618997573853
# Test accuracy: 0.07042253762483597
#
#
# number of predictions: 213
# actual predicted buys: 7
# actual buys but predicted sell: 3
# actual buys but predicted hold: 0
# actual sells but predicted buy: 2
# actual predicted sells: 8
# actual sells but predicted hold: 0
# actual holds but predicted buy: 112
# actual holds but predicted sell: 81
# actual predicted holds: 0
# Percentage buys correct: 5.785123966942149%
# Percentage sells correct: 8.695652173913043%
# Percentage holds correct: 0%
# actual buys: 10
# actual sells: 10
# actual holds: 193
#
#
# Percentage low buys correct: 45.45454545454545%
# Percentage high sells correct: 49.45054945054945%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.9965319995058233
# Shares owned at the moment: 100
# Cash capital at the moment: $0.07275374955355574
#
#
# Price increase from previously bought: -9.034835858054713%
# Share price: $0.9089898357424446
# Shares owned at the moment: 0
# Cash capital at the moment: $90.72176511896885
#
#
# Share price: $0.8786869149061622
# Shares owned at the moment: 102
# Cash capital at the moment: $0.8492281189091102
#
#
# Price increase from previously bought: -76.3191027758567%
# Share price: $0.20865316784033627
# Shares owned at the moment: 0
# Cash capital at the moment: $22.073324025044197
#
#
# Share price: $0.3450168735329129
# Shares owned at the moment: 63
# Cash capital at the moment: $0.2774868191311093
#
#
# Price increase from previously bought: 6.538256871330672%
# Share price: $0.3685857941221071
# Shares owned at the moment: 0
# Cash capital at the moment: $23.434534359992202
#
#
# Share price: $0.35006733358042164
# Shares owned at the moment: 66
# Cash capital at the moment: $0.2665531226395288
#
#
# Price increase from previously bought: 42.88875384641568%
# Share price: $0.5015824194155247
# Shares owned at the moment: 0
# Cash capital at the moment: $33.27995559494024
#
#
# Share price: $0.4207744164504643
# Shares owned at the moment: 78
# Cash capital at the moment: $0.36929499947540023
#
#
# Price increase from previously bought: 11.296716902307203%
# Share price: $0.4695959583796625
# Shares owned at the moment: 0
# Cash capital at the moment: $36.89705142001664
#
#
# Share price: $0.38205379461628364
# Shares owned at the moment: 96
# Cash capital at the moment: $0.11902493507470524
#
#
# Price increase from previously bought: 15.984908470475734%
# Share price: $0.44434333703965856
# Shares owned at the moment: 0
# Cash capital at the moment: $42.65867864990346
#
#
# Share price: $0.41404041620337595
# Shares owned at the moment: 102
# Cash capital at the moment: $0.31041786041406283
#
#
# Price increase from previously bought: 15.53976643253614%
# Share price: $0.4796968784746798
# Shares owned at the moment: 0
# Cash capital at the moment: $49.10494449041926
#
#
# Share price: $0.39215487526253145
# Shares owned at the moment: 124
# Cash capital at the moment: $0.34401514540083156
#
#
# Price increase from previously bought: -1.5585877229250422%
# Share price: $0.3871044152150227
# Shares owned at the moment: 0
# Cash capital at the moment: $48.21296002647532
#
#
# Share price: $0.4174073360513051
# Shares owned at the moment: 115
# Cash capital at the moment: $0.07911131054900977
#
#
# Price increase from previously bought: -18.776245551928895%
# Share price: $0.33996625293417404
# Shares owned at the moment: 0
# Cash capital at the moment: $39.067716070488586
#
#
# Share price: $0.2440067092753575
# Shares owned at the moment: 159
# Cash capital at the moment: $0.163957362076097
#
#
# Price increase from previously bought: -9.90691696404613%
# Share price: $0.22043770841054844
# Shares owned at the moment: 0
# Cash capital at the moment: $35.11716661135078
#
#
# Share price: $0.1598316259111383
# Shares owned at the moment: 219
# Cash capital at the moment: $0.017781940106509353
#
#
# Price increase from previously bought: -3.425442805823342%
# Share price: $0.15478116586362956
# Shares owned at the moment: 0
# Cash capital at the moment: $33.82164030710001
#
#
# Share price: $0.11774408422902848
# Shares owned at the moment: 286
# Cash capital at the moment: $0.05422649535173463
#
#
# Price increase from previously bought: 195.07076100762907%
# Share price: $0.34838379338084224
# Shares owned at the moment: 0
# Cash capital at the moment: $99.41798754877857
#
#
# Share price: $0.23727270902826936
# Shares owned at the moment: 417
# Cash capital at the moment: $0.20317540491207353
#
#
# Price increase from previously bought: -35.65304562655914%
# Share price: $0.15309762566404994
# Shares owned at the moment: 0
# Cash capital at the moment: $63.86932060459065
#
#
#
#
# Capital at the end of test period: $63.86932060459065
# profit gained: -36.13067939540935%
#
#
# Capital at the end of test period if Buy and Hold: $15.710112504960433
# profit gained: -84.28988749503957%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.065116      5.691057       7.608696            0.0
# 1       0.088372      8.196721       8.695652          100.0
# 2       0.070423      5.785124       8.695652            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         44.715447           54.945055                0.0     -92.810569
# 1         51.639344           52.747253              100.0      -6.696367
# 2         45.454545           49.450549                0.0     -36.130679
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
# 2         -84.289887
#
#
# JPM
#
#
# Non-Recession Test
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2002 - accuracy: 0.0688 - mse: 1.0979 - weighted_accuracy: 0.0688 - weighted_mse: 1.0979
# Test loss: 0.20016369223594666
# Test accuracy: 0.06880734115839005
#
#
# number of predictions: 218
# actual predicted buys: 9
# actual buys but predicted sell: 2
# actual buys but predicted hold: 0
# actual sells but predicted buy: 1
# actual predicted sells: 5
# actual sells but predicted hold: 0
# actual holds but predicted buy: 85
# actual holds but predicted sell: 115
# actual predicted holds: 1
# Percentage buys correct: 9.473684210526315%
# Percentage sells correct: 4.098360655737705%
# Percentage holds correct: 100.0%
# actual buys: 11
# actual sells: 6
# actual holds: 201
#
#
# Percentage low buys correct: 45.26315789473684%
# Percentage high sells correct: 43.80165289256198%
# Percentage mid holds correct: 100.0%
#
#
# Capital: 100
# Share price: $0.05968146056768497
# Shares owned at the moment: 1670
# Cash capital at the moment: $0.05787374430900627
#
#
# Price increase from previously bought: 182.78727815537374%
# Share price: $0.1692356997419615
# Shares owned at the moment: 0
# Cash capital at the moment: $281.90427736231976
#
#
# Share price: $0.1926751480928941
# Shares owned at the moment: 1459
# Cash capital at the moment: $0.01817543185154591
#
#
# Price increase from previously bought: 5.65991050077439%
# Share price: $0.20414023510202495
# Shares owned at the moment: 0
# Cash capital at the moment: $297.03971678741783
#
#
# Share price: $0.031146547576816667
# Shares owned at the moment: 9510
# Cash capital at the moment: $0.021489246388625816
#
#
# Price increase from previously bought: 397.81222282835154%
# Share price: $0.15547771195871385
# Shares owned at the moment: 0
# Cash capital at the moment: $1474.5483991117571
#
#
# Share price: $0.429872778606591
# Shares owned at the moment: 3420
# Cash capital at the moment: $0.340542794421026
#
#
# Price increase from previously bought: -31.48198141619706%
# Share price: $0.2953502961857881
# Shares owned at the moment: 0
# Cash capital at the moment: $1007.660786214189
#
#
# Share price: $0.2874522676800322
# Shares owned at the moment: 3495
# Cash capital at the moment: $0.2523350647368261
#
#
# Price increase from previously bought: -5.57761865604447%
# Share price: $0.27216567938070724
# Shares owned at the moment: 0
# Cash capital at the moment: $948.8555321143608
#
#
# Share price: $0.23496824324652743
# Shares owned at the moment: 4027
# Cash capital at the moment: $0.036319492821917265
#
#
# Price increase from previously bought: 65.03814581788818%
# Share price: $0.3888536468027002
# Shares owned at the moment: 0
# Cash capital at the moment: $1561.6436926691908
#
#
# Share price: $0.36898086819611
# Shares owned at the moment: 4220
# Cash capital at the moment: $0.26240590619090653
#
#
# Price increase from previously bought: 15.425765729675467%
# Share price: $0.4270702147407708
# Shares owned at the moment: 0
# Cash capital at the moment: $1797.5425622701769
#
#
# Share price: $0.40082800814450237
# Shares owned at the moment: 4472
# Cash capital at the moment: $0.11032700380110327
#
#
# ...
# Cash capital at the moment: $97.82843639628372
#
#
#
#
# Capital at the end of test period: $97.82843639628372
# profit gained: -2.1715636037162795%
#
#
# Capital at the end of test period if Buy and Hold: $68.09965200824497
# profit gained: -31.90034799175503%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.348837      5.063291       6.349206      91.780822
# 1       0.344186      5.263158      10.447761      87.500000
# 2       0.295775      8.433735       7.792208      94.339623
# 3       0.333333      9.859155      11.494253      91.803279
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         46.835443           56.451613          80.821918     -91.818021
# 1         52.631579           59.701493          84.507042     -54.008487
# 2         46.987952           51.315789          84.905660     -84.871230
# 3         47.887324           51.162791          83.606557      -2.171564
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
# 2         -84.289887
# 3         -31.900348
#
#
# AXL
#
#
# Non-Recession Test
# 1/7 [===>..........................] - ETA: 0s - loss: 0.3959 - accuracy: 0.1875 - mse: 3.6980 - weighted_accuracy: 0.1875 - weighted_mse: 3.6980WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0040s vs `on_test_batch_end` time: 0.0063s). Check your callbacks.
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4462 - accuracy: 0.2156 - mse: 3.9429 - weighted_accuracy: 0.2156 - weighted_mse: 3.9429
# Test loss: 0.44618141651153564
# Test accuracy: 0.21559633314609528
#
#
# number of predictions: 218
# actual predicted buys: 4
# actual buys but predicted sell: 1
# actual buys but predicted hold: 3
# actual sells but predicted buy: 0
# actual predicted sells: 7
# actual sells but predicted hold: 1
# actual holds but predicted buy: 84
# actual holds but predicted sell: 82
# actual predicted holds: 36
# Percentage buys correct: 4.545454545454546%
# Percentage sells correct: 7.777777777777778%
# Percentage holds correct: 90.0%
# actual buys: 8
# actual sells: 8
# actual holds: 202
#
#
# Percentage low buys correct: 46.59090909090909%
# Percentage high sells correct: 53.93258426966292%
# Percentage mid holds correct: 82.5%
#
#
# Capital: 100
# Share price: $0.7426007274823263
# Shares owned at the moment: 134
# Cash capital at the moment: $0.21785414929102842
#
#
# Price increase from previously bought: 5.136804586257004%
# Share price: $0.7828937290674167
# Shares owned at the moment: 0
# Cash capital at the moment: $104.83711750516353
#
#
# Share price: $0.9339926815103341
# Shares owned at the moment: 111
# Cash capital at the moment: $0.8788285914854157
#
#
# Price increase from previously bought: -19.927629001619863%
# Share price: $0.7499267277705246
# Shares owned at the moment: 0
# Cash capital at the moment: $83.8917802403617
#
#
# Share price: $0.7719047286351195
# Shares owned at the moment: 108
# Cash capital at the moment: $0.2968138433641627
#
#
# Price increase from previously bought: -1.930588101658648%
# Share price: $0.7590841844643663
# Shares owned at the moment: 0
# Cash capital at the moment: $82.0524577627298
#
#
# Share price: $0.9175091371954818
# Shares owned at the moment: 89
# Cash capital at the moment: $0.16958419100332378
#
#
# Price increase from previously bought: -43.87042329550316%
# Share price: $0.5164102284189707
# Shares owned at the moment: 0
# Cash capital at the moment: $46.00370311688617
#
#
# Share price: $0.5530402298599622
# Shares owned at the moment: 82
# Cash capital at the moment: $0.5296936965358512
#
#
# Price increase from previously bought: -19.594529537547935%
# Share price: $0.4458974538118591
# Shares owned at the moment: 0
# Cash capital at the moment: $36.992735033273725
#
#
# Share price: $0.38545782043500487
# Shares owned at the moment: 95
# Cash capital at the moment: $0.2735412363596126
#
#
# Price increase from previously bought: 26.498093083750042%
# Share price: $0.4889376836718209
# Shares owned at the moment: 0
# Cash capital at the moment: $46.594886215323335
#
#
# Share price: $0.5017582278425741
# Shares owned at the moment: 92
# Cash capital at the moment: $0.306184422162346
#
#
# Price increase from previously bought: -0.8202645963781063%
# Share price: $0.4990109995677028
# Shares owned at the moment: 0
# Cash capital at the moment: $46.08894659950037
#
#
# Share price: $0.5356410010086943
# Shares owned at the moment: 85
# Cash capital at the moment: $0.4342554297755754
#
#
# Price increase from previously bought: 2.9651462613982105%
# Share price: $0.5530402298599622
# Shares owned at the moment: 0
# Cash capital at the moment: $47.31340181414259
#
#
# Share price: $0.5502930015850909
# Shares owned at the moment: 85
# Cash capital at the moment: $0.40986569028934383
#
#
# Price increase from previously bought: 1.2193529348202725%
# Share price: $0.5585347737425168
# Shares owned at the moment: 0
# Cash capital at the moment: $47.754763955040964
#
#
# Share price: $0.5860073184896668
# Shares owned at the moment: 81
# Cash capital at the moment: $0.15763802718437603
#
#
# Price increase from previously bought: 5.336023815186386%
# Share price: $0.6189743197865589
# Shares owned at the moment: 0
# Cash capital at the moment: $50.15668140016319
#
#
# Share price: $0.4687912265456817
# Shares owned at the moment: 106
# Cash capital at the moment: $0.3281587437828577
#
#
# Price increase from previously bought: -83.45696907760525%
# Share price: $0.0777655463322403
# Shares owned at the moment: 0
# Cash capital at the moment: $8.54863799824448
#
#
# Share price: $0.09608054705273604
# Shares owned at the moment: 88
# Cash capital at the moment: $0.07029836521694577
#
#
# Price increase from previously bought: -89.62060924556569%
# Share price: $0.01
# Shares owned at the moment: 0
# Cash capital at the moment: $0.9478783652169458
#
#
# Share price: $0.19681318201468057
# Shares owned at the moment: 4
# Cash capital at the moment: $0.15846069215606207
#
#
# Price increase from previously bought: -3.9863714601878875%
# Share price: $0.18948713806007633
# Shares owned at the moment: 0
# Cash capital at the moment: $0.9143248858777066
#
#
# Share price: $0.117142819714509
# Shares owned at the moment: 7
# Cash capital at the moment: $0.0920701485966392
#
#
# Price increase from previously bought: 18.43605218241331%
# Share price: $0.13912086424551007
# Shares owned at the moment: 0
# Cash capital at the moment: $1.0632381216784834
#
#
# Share price: $0.225201411298246
# Shares owned at the moment: 4
# Cash capital at the moment: $0.1599552609612187
#
#
# Price increase from previously bought: 108.81098283924987%
# Share price: $0.47153845482055323
# Shares owned at the moment: 0
# Cash capital at the moment: $2.0409221572404057
#
#
# Share price: $0.38362636402936146
# Shares owned at the moment: 5
# Cash capital at the moment: $0.11751547458819478
#
#
# Price increase from previously bought: -4.797292442520263%
# Share price: $0.3662270478452814
# Shares owned at the moment: 0
# Cash capital at the moment: $1.943615091906729
#
#
# Share price: $0.32868127453506213
# Shares owned at the moment: 5
# Cash capital at the moment: $0.2956893517065611
#
#
# Price increase from previously bought: 28.62210816701005%
# Share price: $0.4239193656144522
# Shares owned at the moment: 0
# Cash capital at the moment: $2.409457288501623
#
#
#
#
# Capital at the end of test period: $2.409457288501623
# profit gained: -97.59054271149837%
#
#
# Capital at the end of test period if Buy and Hold: $59.80379974835048
# profit gained: -40.19620025164952%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.344037     10.447761       7.058824      93.939394
# 1       0.261468      6.493506       6.741573      88.461538
# 2       0.284360      7.058824       5.479452      94.339623
# 3       0.220183     13.846154       3.389831     100.000000
# 4       0.215596      4.545455       7.777778      90.000000
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         53.731343           50.000000          84.848485     -71.888154
# 1         61.038961           52.272727          80.769231     -89.525646
# 2         54.117647           55.555556          88.679245     502.254685
# 3         55.384615           47.008547          97.142857     290.773911
# 4         46.590909           53.932584          82.500000     -97.590543
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# 2         -54.689601
# 3        1576.179166
# 4         -40.196200
# Recession Test
#
#
# 1/7 [===>..........................] - ETA: 0s - loss: 0.3425 - accuracy: 0.3125 - mse: 3.5703 - weighted_accuracy: 0.3125 - weighted_mse: 3.5703WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0038s vs `on_test_batch_end` time: 0.0153s). Check your callbacks.
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4228 - accuracy: 0.3242 - mse: 3.9130 - weighted_accuracy: 0.3242 - weighted_mse: 3.9130
# Test loss: 0.4228459596633911
# Test accuracy: 0.32420089840888977
#
#
# number of predictions: 219
# actual predicted buys: 7
# actual buys but predicted sell: 1
# actual buys but predicted hold: 3
# actual sells but predicted buy: 0
# actual predicted sells: 9
# actual sells but predicted hold: 2
# actual holds but predicted buy: 61
# actual holds but predicted sell: 81
# actual predicted holds: 55
# Percentage buys correct: 10.294117647058824%
# Percentage sells correct: 9.89010989010989%
# Percentage holds correct: 91.66666666666667%
# actual buys: 11
# actual sells: 11
# actual holds: 197
#
#
# Percentage low buys correct: 60.294117647058826%
# Percentage high sells correct: 53.84615384615385%
# Percentage mid holds correct: 84.7457627118644%
#
#
# Capital: 100
# Share price: $0.6915789433232307
# Shares owned at the moment: 144
# Cash capital at the moment: $0.13876689989878344
#
#
# Price increase from previously bought: -36.703746041331385%
# Share price: $0.438947359092348
# Shares owned at the moment: 0
# Cash capital at the moment: $63.17336345499633
#
#
# Share price: $0.4060526228694045
# Shares owned at the moment: 155
# Cash capital at the moment: $0.06212697974054038
#
#
# Price increase from previously bought: -28.388761361355964%
# Share price: $0.2915789558715766
# Shares owned at the moment: 0
# Cash capital at the moment: $45.132579609894655
#
#
# Share price: $0.17842104569696665
# Shares owned at the moment: 252
# Cash capital at the moment: $0.046830309591058494
#
#
# Price increase from previously bought: 12.963673786949226%
# Share price: $0.20210523319046308
# Shares owned at the moment: 0
# Cash capital at the moment: $50.83729014698676
#
#
# Share price: $0.07447368425180377
# Shares owned at the moment: 680
# Cash capital at the moment: $0.05591906620932008
#
#
# Price increase from previously bought: 103.6801451022086%
# Share price: $0.15210525044443896
# Shares owned at the moment: 0
# Cash capital at the moment: $103.20305255009671
#
#
# Share price: $0.11263157325107974
# Shares owned at the moment: 913
# Cash capital at the moment: $0.08763644932075465
#
#
# Price increase from previously bought: 9.045909525232364%
# Share price: $0.12315787880374483
# Shares owned at the moment: 0
# Cash capital at the moment: $112.22156115293328
#
#
# Share price: $0.17052631653246791
# Shares owned at the moment: 656
# Cash capital at the moment: $0.048668032609754164
#
#
# Price increase from previously bought: 127.46088756952356%
# Share price: $0.38894734497545874
# Shares owned at the moment: 0
# Cash capital at the moment: $254.49646532617496
#
#
# Share price: $0.6415789292063412
# Shares owned at the moment: 395
# Cash capital at the moment: $0.37587317781981255
#
#
# Price increase from previously bought: 5.043375003976314%
# Share price: $0.6757894849942327
# Shares owned at the moment: 0
# Cash capital at the moment: $266.57864342246677
#
#
# Share price: $0.5863157623131194
# Shares owned at the moment: 453
# Cash capital at the moment: $0.24720023372208288
#
#
# Price increase from previously bought: -1.1694492513874666%
# Share price: $0.581052609536787
# Shares owned at the moment: 0
# Cash capital at the moment: $262.74018606555614
#
#
# Share price: $0.5850000054899009
# Shares owned at the moment: 447
# Cash capital at the moment: $0.526072354821963
#
#
# Price increase from previously bought: 7.127798787202977%
# Share price: $0.6284210472655098
# Shares owned at the moment: 0
# Cash capital at the moment: $280.65779391015377
#
#
# Share price: $0.5784210331486206
# Shares owned at the moment: 483
# Cash capital at the moment: $0.5121471620904003
#
#
# Price increase from previously bought: 10.841687979461433%
# Share price: $0.6428947487712893
# Shares owned at the moment: 0
# Cash capital at the moment: $310.1763858685676
#
#
# Share price: $0.5902631582662341
# Shares owned at the moment: 524
# Cash capital at the moment: $0.027921725999249247
#
#
# Price increase from previously bought: 17.73240901438802%
# Share price: $0.6968420960995632
# Shares owned at the moment: 0
# Cash capital at the moment: $364.16903062169087
#
#
# Share price: $0.6744736654292847
# Shares owned at the moment: 538
# Cash capital at the moment: $0.30431483273309823
#
#
# Price increase from previously bought: -43.269548695989776%
# Share price: $0.38368419219912614
# Shares owned at the moment: 0
# Cash capital at the moment: $206.15874947350437
#
#
# Share price: $0.40868419925757077
# Shares owned at the moment: 503
# Cash capital at the moment: $0.025284828323236752
#
#
# Price increase from previously bought: 9.357996782514544%
# Share price: $0.44815790782179515
# Shares owned at the moment: 0
# Cash capital at the moment: $224.8287980366917
#
#
# Share price: $0.5402631441493446
# Shares owned at the moment: 415
# Cash capital at the moment: $0.0030179014532336623
#
#
# Price increase from previously bought: -2.94590835364833%
# Share price: $0.525789442643565
# Shares owned at the moment: 0
# Cash capital at the moment: $217.60557939711572
#
#
# Share price: $0.5271052622085133
# Shares owned at the moment: 411
# Cash capital at the moment: $0.36955590680557293
#
#
# Price increase from previously bought: 2.9619896315619787%
# Share price: $0.5442105401024591
# Shares owned at the moment: 0
# Cash capital at the moment: $223.42499392596542
#
#
# Share price: $0.5034210119732866
# Shares owned at the moment: 442
# Cash capital at the moment: $0.300998393719226
#
#
# Price increase from previously bought: 10.673173662896707%
# Share price: $0.5586841788665085
# Shares owned at the moment: 0
# Cash capital at the moment: $246.56032483330372
#
#
# Share price: $0.7389473183102233
# Shares owned at the moment: 332
# Cash capital at the moment: $0.5551562526923419
#
#
# Price increase from previously bought: -10.928705568719765%
# Share price: $0.659999963923505
# Shares owned at the moment: 0
# Cash capital at the moment: $219.07256430823386
#
#
# Share price: $0.6902631237582821
# Shares owned at the moment: 316
# Cash capital at the moment: $0.34957854607077365
#
#
# Price increase from previously bought: 6.949505445632309%
# Share price: $0.7402631378751716
# Shares owned at the moment: 0
# Cash capital at the moment: $233.62944144781147
#
#
# Share price: $0.6836842141587314
# Shares owned at the moment: 340
# Cash capital at the moment: $0.5375638936043856
#
#
#
#
# Capital at the end of test period: $217.1822480768989
# profit gained: 117.1822480768989%
#
#
# Capital at the end of test period if Buy and Hold: $67.49022981476901
# profit gained: -32.50977018523099%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.348837      5.063291       6.349206      91.780822
# 1       0.344186      5.263158      10.447761      87.500000
# 2       0.295775      8.433735       7.792208      94.339623
# 3       0.333333      9.859155      11.494253      91.803279
# 4       0.324201     10.294118       9.890110      91.666667
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         46.835443           56.451613          80.821918     -91.818021
# 1         52.631579           59.701493          84.507042     -54.008487
# 2         46.987952           51.315789          84.905660     -84.871230
# 3         47.887324           51.162791          83.606557      -2.171564
# 4         60.294118           53.846154          84.745763     117.182248
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
# 2         -84.289887
# 3         -31.900348
# 4         -32.509770

# %%
df = nr_log_hist['0_epochs_logs']
df['Profit gained']
# Out:
# 0      62.897960
# 1     -92.984211
# 2      54.907119
# 3    1386.469160
# 4     -84.529284
# Name: Profit gained, dtype: float64

# %%
C6LSI_acc = []
O39SI_acc = []
CNOOC_acc = []
JPM_acc = []
AXL_acc = []

C6LSI_correct_buys = []
O39SI_correct_buys = []
CNOOC_correct_buys = []
JPM_correct_buys = []
AXL_correct_buys = []

C6LSI_correct_sells = []
O39SI_correct_sells = []
CNOOC_correct_sells = []
JPM_correct_sells = []
AXL_correct_sells = []

C6LSI_correct_holds = []
O39SI_correct_holds = []
CNOOC_correct_holds = []
JPM_correct_holds = []
AXL_correct_holds = []

C6LSI_correct_low_buys = []
O39SI_correct_low_buys = []
CNOOC_correct_low_buys = []
JPM_correct_low_buys = []
AXL_correct_low_buys = []

C6LSI_correct_high_sells = []
O39SI_correct_high_sells = []
CNOOC_correct_high_sells = []
JPM_correct_high_sells = []
AXL_correct_high_sells = []

C6LSI_correct_mid_holds = []
O39SI_correct_mid_holds = []
CNOOC_correct_mid_holds = []
JPM_correct_mid_holds = []
AXL_correct_mid_holds = []

C6LSI_profit = []
O39SI_profit = []
CNOOC_profit = []
JPM_profit = []
AXL_profit = []

for key,value in nr_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    C6LSI_acc.append(acc[0])
    O39SI_acc.append(acc[1])
    CNOOC_acc.append(acc[2])
    JPM_acc.append(acc[3]) 
    AXL_acc.append(acc[4]) 

    C6LSI_correct_buys.append(correct_buys[0])
    O39SI_correct_buys.append(correct_buys[1]) 
    CNOOC_correct_buys.append(correct_buys[2]) 
    JPM_correct_buys.append(correct_buys[3]) 
    AXL_correct_buys.append(correct_buys[4])
    

    C6LSI_correct_sells.append(correct_sells[0]) 
    O39SI_correct_sells.append(correct_sells[1]) 
    CNOOC_correct_sells.append(correct_sells[2]) 
    JPM_correct_sells.append(correct_sells[3]) 
    AXL_correct_sells.append(correct_sells[4]) 
    

    C6LSI_correct_holds.append(correct_holds[0]) 
    O39SI_correct_holds.append(correct_holds[1])  
    CNOOC_correct_holds.append(correct_holds[2])  
    JPM_correct_holds.append(correct_holds[3])  
    AXL_correct_holds.append(correct_holds[4])  
     

    C6LSI_correct_low_buys.append(correct_low_buys[0])  
    O39SI_correct_low_buys.append(correct_low_buys[1])  
    CNOOC_correct_low_buys.append(correct_low_buys[2])  
    JPM_correct_low_buys.append(correct_low_buys[3])   
    AXL_correct_low_buys.append(correct_low_buys[4])   
    

    C6LSI_correct_high_sells.append(correct_high_sells[0]) 
    O39SI_correct_high_sells.append(correct_high_sells[1]) 
    CNOOC_correct_high_sells.append(correct_high_sells[2]) 
    JPM_correct_high_sells.append(correct_high_sells[3]) 
    AXL_correct_high_sells.append(correct_high_sells[4]) 
    

    C6LSI_correct_mid_holds.append(correct_mid_holds[0])  
    O39SI_correct_mid_holds.append(correct_mid_holds[1])  
    CNOOC_correct_mid_holds.append(correct_mid_holds[2])   
    JPM_correct_mid_holds.append(correct_mid_holds[3])   
    AXL_correct_mid_holds.append(correct_mid_holds[4])   
    

    C6LSI_profit.append(profit[0]) 
    O39SI_profit.append(profit[1]) 
    CNOOC_profit.append(profit[2]) 
    JPM_profit.append(profit[3])  
    AXL_profit.append(profit[4])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(C6LSI_acc)
plt.plot(O39SI_acc)
plt.plot(CNOOC_acc)
plt.plot(JPM_acc)
plt.plot(AXL_acc)
plt.title('Non-Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['C6L.SI_acc','O39.SI_acc','CNOOC_acc','JPM_acc','AXL_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_low_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_low_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_high_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_high_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_mid_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_mid_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_profit")

plt.subplot(3, 4, 2)
plt.plot(O39SI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_profit")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_profit")

plt.subplot(3, 4, 4)
plt.plot(JPM_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_profit")

plt.subplot(3, 4, 5)
plt.plot(AXL_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_profit")
# Out:
# Text(0.5, 1.0, 'AXL_profit')

# %%
C6LSI_acc = []
O39SI_acc = []
CNOOC_acc = []
JPM_acc = []
AXL_acc = []

C6LSI_correct_buys = []
O39SI_correct_buys = []
CNOOC_correct_buys = []
JPM_correct_buys = []
AXL_correct_buys = []

C6LSI_correct_sells = []
O39SI_correct_sells = []
CNOOC_correct_sells = []
JPM_correct_sells = []
AXL_correct_sells = []

C6LSI_correct_holds = []
O39SI_correct_holds = []
CNOOC_correct_holds = []
JPM_correct_holds = []
AXL_correct_holds = []

C6LSI_correct_low_buys = []
O39SI_correct_low_buys = []
CNOOC_correct_low_buys = []
JPM_correct_low_buys = []
AXL_correct_low_buys = []

C6LSI_correct_high_sells = []
O39SI_correct_high_sells = []
CNOOC_correct_high_sells = []
JPM_correct_high_sells = []
AXL_correct_high_sells = []

C6LSI_correct_mid_holds = []
O39SI_correct_mid_holds = []
CNOOC_correct_mid_holds = []
JPM_correct_mid_holds = []
AXL_correct_mid_holds = []

C6LSI_profit = []
O39SI_profit = []
CNOOC_profit = []
JPM_profit = []
AXL_profit = []

for key,value in r_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    C6LSI_acc.append(acc[0])
    O39SI_acc.append(acc[1])
    CNOOC_acc.append(acc[2])
    JPM_acc.append(acc[3]) 
    AXL_acc.append(acc[4]) 

    C6LSI_correct_buys.append(correct_buys[0])
    O39SI_correct_buys.append(correct_buys[1]) 
    CNOOC_correct_buys.append(correct_buys[2]) 
    JPM_correct_buys.append(correct_buys[3]) 
    AXL_correct_buys.append(correct_buys[4])
    

    C6LSI_correct_sells.append(correct_sells[0]) 
    O39SI_correct_sells.append(correct_sells[1]) 
    CNOOC_correct_sells.append(correct_sells[2]) 
    JPM_correct_sells.append(correct_sells[3]) 
    AXL_correct_sells.append(correct_sells[4]) 
    

    C6LSI_correct_holds.append(correct_holds[0]) 
    O39SI_correct_holds.append(correct_holds[1])  
    CNOOC_correct_holds.append(correct_holds[2])  
    JPM_correct_holds.append(correct_holds[3])  
    AXL_correct_holds.append(correct_holds[4])  
     

    C6LSI_correct_low_buys.append(correct_low_buys[0])  
    O39SI_correct_low_buys.append(correct_low_buys[1])  
    CNOOC_correct_low_buys.append(correct_low_buys[2])  
    JPM_correct_low_buys.append(correct_low_buys[3])   
    AXL_correct_low_buys.append(correct_low_buys[4])   
    

    C6LSI_correct_high_sells.append(correct_high_sells[0]) 
    O39SI_correct_high_sells.append(correct_high_sells[1]) 
    CNOOC_correct_high_sells.append(correct_high_sells[2]) 
    JPM_correct_high_sells.append(correct_high_sells[3]) 
    AXL_correct_high_sells.append(correct_high_sells[4]) 
    

    C6LSI_correct_mid_holds.append(correct_mid_holds[0])  
    O39SI_correct_mid_holds.append(correct_mid_holds[1])  
    CNOOC_correct_mid_holds.append(correct_mid_holds[2])   
    JPM_correct_mid_holds.append(correct_mid_holds[3])   
    AXL_correct_mid_holds.append(correct_mid_holds[4])   
    

    C6LSI_profit.append(profit[0]) 
    O39SI_profit.append(profit[1]) 
    CNOOC_profit.append(profit[2]) 
    JPM_profit.append(profit[3])  
    AXL_profit.append(profit[4])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(C6LSI_acc)
plt.plot(O39SI_acc)
plt.plot(CNOOC_acc)
plt.plot(JPM_acc)
plt.plot(AXL_acc)
plt.title('Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['C6L.SI_acc','O39.SI_acc','CNOOC_acc','JPM_acc','AXL_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_low_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_low_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_high_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_high_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_mid_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_mid_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_profit")

plt.subplot(3, 4, 2)
plt.plot(O39SI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_profit")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_profit")

plt.subplot(3, 4, 4)
plt.plot(JPM_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_profit")

plt.subplot(3, 4, 5)
plt.plot(AXL_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_profit")
# Out:
# Text(0.5, 1.0, 'AXL_profit')
