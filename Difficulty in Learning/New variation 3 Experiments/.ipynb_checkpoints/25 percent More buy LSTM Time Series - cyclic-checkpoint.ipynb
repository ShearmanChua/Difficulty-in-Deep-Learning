# %%
import os
seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
experiment = '25 percent More buy LSTM Time Series - cyclic'

# %%
import requests
import lxml
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.utils import compute_class_weight
import tensorflow as tf
from pil import Image
from sklearn import preprocessing
import tensorflow_addons as tfa
import glob
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
import math

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
# gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
np.random.seed(seed)
tf.random.set_seed(seed)

session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, 
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), 
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)

# %% [markdown]
# ## Prepare Test Data

# %%
nr_test_sets = ['C6L.SI','O39.SI','0883.HK','JPM','AXL']
nr_test_data = {}

for name in nr_test_sets:

    df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    labels = []
    data_15 = []
    sequential = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15.append(np.array(i[0:-1]))
            labels.append(i[-1])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_arr = min_max_scaler.fit_transform(data_15)
            sequential.append(data_15_arr)
            data_15 = data_15[1:15]
        else:
            data_15.append(np.array(i[0:-1]))
            count+= 1
            
    X = sequential
    X  = np.array(X).reshape(-1, 15, 4)
    y = labels
    y = np.array(y)
    print(X.shape)
    
    y = to_categorical(y, 3)
    
    nr_test_data['{}_X'.format(name)] = X
    nr_test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2019-01-21         9.59  9.538960 -32.758553  6890900.0     2.0
# 2019-01-22         9.63  9.552966 -25.862007  7759500.0     2.0
# 2019-01-23         9.61  9.561740 -29.310362  7108100.0     1.0
# 2019-01-24         9.50  9.552242 -48.275822  6126400.0     2.0
# 2019-01-25         9.74  9.581128  -8.888884  8160300.0     2.0
# (218, 15, 4)
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-21        11.75  11.523654 -10.869606  21160951.0     2.0
# 2019-01-22        11.73  11.555399 -13.978517  18040951.0     2.0
# 2019-01-23        11.50  11.546876 -38.709667  14286851.0     1.0
# 2019-01-24        11.38  11.521203 -51.612890   8454651.0     2.0
# 2019-01-25        11.41  11.504095 -80.357185  12469051.0     2.0
# (218, 15, 4)
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2019-01-22        13.12  12.552209  -3.030323  489168111.0     2.0
# 2019-01-23        12.94  12.611869 -13.043517  449876554.0     2.0
# 2019-01-24        12.62  12.613120 -33.333352  395082483.0     2.0
# 2019-01-25        12.80  12.641871 -37.254896  441807090.0     2.0
# 2019-01-28        13.06  12.706198 -11.764689  494043477.0     2.0
# (211, 15, 4)
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22   104.589996  101.198442  -3.459880  84335200.0     2.0
# 2019-01-23   102.940002  101.466374 -21.874992  67251500.0     2.0
# 2019-01-24   102.680000  101.653086 -27.040213  55104800.0     2.0
# 2019-01-25   102.739998  101.820303 -32.628441  66401600.0     2.0
# 2019-01-28   103.389999  102.061795 -23.968276  80771000.0     2.0
# (218, 15, 4)
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22        14.61  13.028180  -0.258404  23356600.0     2.0
# 2019-01-23        14.52  13.257691  -3.886001  21174700.0     2.0
# 2019-01-24        14.18  13.399585 -13.535906  19629300.0     2.0
# 2019-01-25        14.38  13.550418  -8.579880  20903300.0     2.0
# 2019-01-28        14.71  13.728815  -4.790414  22287500.0     2.0
# (218, 15, 4)

# %%
r_test_sets = ['C6L.SI','O39.SI','0883.HK','JPM','AXL']
r_test_data = {}

for name in nr_test_sets:

    df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test2.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    labels = []
    data_15 = []
    sequential = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15.append(np.array(i[0:-1]))
            labels.append(i[-1])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_arr = min_max_scaler.fit_transform(data_15)
            sequential.append(data_15_arr)
            data_15 = data_15[1:15]
        else:
            data_15.append(np.array(i[0:-1]))
            count+= 1
            
    X = sequential
    X  = np.array(X).reshape(-1, 15, 4)
    y = labels
    y = np.array(y)
    print(X.shape)
    
    y = to_categorical(y, 3)
    
    r_test_data['{}_X'.format(name)] = X
    r_test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2020-01-22         8.84  8.979182 -96.551645  -851200.0     2.0
# 2020-01-23         8.93  8.971615 -65.517105  1644900.0     2.0
# 2020-01-24         8.85  8.952905 -92.307523  -246900.0     2.0
# 2020-01-28         8.82  8.932458 -75.000000 -1718200.0     2.0
# 2020-01-29         8.56  8.875157 -86.885115 -5499900.0     2.0
# (215, 15, 4)
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22        11.12  11.072811 -24.444379  27489400.0     2.0
# 2020-01-23        11.19  11.090840  -8.888884  31751200.0     2.0
# 2020-01-24        11.11  11.093787 -26.666653  27359800.0     2.0
# 2020-01-28        11.10  11.094743 -28.888715  24699300.0     2.0
# 2020-01-29        10.90  11.064783 -71.739257  16499235.0     2.0
# (215, 15, 4)
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2020-01-22        13.00  13.393678 -83.870980  104646165.0     2.0
# 2020-01-23        13.34  13.385420 -57.377021  145802714.0     2.0
# 2020-01-24        13.00  13.326125 -85.245880   96260120.0     2.0
# 2020-01-29        13.04  13.282106 -80.645176  122828433.0     2.0
# 2020-01-30        12.46  13.155628 -90.804605   53693706.0     2.0
# (213, 15, 4)
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22   136.839996  137.690058 -77.454723  33776700.0     2.0
# 2020-01-23   136.679993  137.534664 -80.363881  26227600.0     2.0
# 2020-01-24   136.539993  137.381637 -69.867648  16881900.0     2.0
# 2020-01-27   133.149994  136.730615 -90.166021   1715500.0     1.0
# 2020-01-28   132.029999  136.007444 -79.004573 -11145000.0     2.0
# (219, 15, 4)
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2020-01-22         9.39  9.715390 -73.059349 -3592400.0     2.0
# 2020-01-23         9.34  9.657637 -75.342463 -4550300.0     2.0
# 2020-01-24         9.50  9.633386 -65.000010 -3092000.0     2.0
# 2020-01-27         9.31  9.583634 -66.883101 -4332600.0     2.0
# 2020-01-28         9.39  9.553844 -61.688301 -2300800.0     2.0
# (219, 15, 4)

# %% [markdown]
# ## Train Accumulation Phase Stock Data

# %%
def pred_acc(actual, predictions, logger):

    hold = 0
    sell = 0
    buy = 0
    pred_hold = 0
    pred_sell = 0
    pred_buy = 0
    buy_buy = 0
    buy_sell = 0
    buy_hold = 0
    sell_buy = 0
    sell_sell = 0
    sell_hold = 0
    hold_buy = 0
    hold_sell = 0
    hold_hold = 0

    for i in range (0,len(actual)):
        if actual[i]==1 and predictions[i] == 1:
            buy_buy += 1
            buy += 1
            pred_buy += 1
        elif actual[i]==1 and predictions[i] == 0:
            buy_sell += 1
            buy += 1
            pred_sell += 1
        elif actual[i]==1 and predictions[i] == 2:
            buy_hold += 1
            buy += 1
            pred_hold += 1
        elif actual[i]==0 and predictions[i] == 1:
            sell_buy += 1
            sell += 1
            pred_buy += 1
        elif actual[i]==0 and predictions[i] == 0:
            sell_sell += 1
            sell += 1
            pred_sell += 1
        elif actual[i]==0 and predictions[i] == 2:
            sell_hold += 1
            sell += 1
            pred_hold += 1
        elif actual[i]==2 and predictions[i] == 1:
            hold_buy += 1
            hold += 1
            pred_buy += 1
        elif actual[i]==2 and predictions[i] == 0:
            hold_sell += 1
            hold += 1
            pred_sell += 1
        elif actual[i]==2 and predictions[i] == 2:
            hold_hold += 1
            hold += 1
            pred_hold += 1

    print("number of predictions: " + str(len(actual)))
    print("actual predicted buys: " + str(buy_buy) )
    print("actual buys but predicted sell: " + str(buy_sell) )
    print("actual buys but predicted hold: " + str(buy_hold))
    print("actual sells but predicted buy: " + str(sell_buy) )
    print("actual predicted sells: " + str(sell_sell))
    print("actual sells but predicted hold: " + str(sell_hold) )
    print("actual holds but predicted buy: " + str(hold_buy) )
    print("actual holds but predicted sell: " + str(hold_sell))
    print("actual predicted holds: " + str(hold_hold) )
    
    if pred_buy !=0:
        Percentage_buys_correct = 100*buy_buy/pred_buy
    else:
        Percentage_buys_correct = 0
        
    if pred_sell !=0:
        Percentage_sells_correct = 100*sell_sell/pred_sell
    else:
        Percentage_sells_correct = 0
        
    if pred_hold !=0:
        Percentage_holds_correct = 100*hold_hold/pred_hold
    else:
        Percentage_holds_correct = 0

    print("Percentage buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage holds correct: " + str(Percentage_holds_correct) + "%")

    print("actual buys: " + str(buy))
    print("actual sells: " + str(sell))
    print("actual holds: " + str(hold))
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def correct_maxima_minima(predictions, price, logger):
    correct_maxima = 0 
    correct_minima = 0
    correct_hold = 0

    hold = 0
    buy = 0
    sell = 0

#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):
        if i < 4:
            prices = price[i:i+9]
            prices.sort(key = float)
#             if i == 0:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1

        else:
            prices = price[i:i+5]
            prices = prices + price[i-4:i] 
            prices.sort(key = float)
#             if i == 10:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1
                    
    if buy !=0:
        Percentage_buys_correct = 100*correct_minima/buy
    else:
        Percentage_buys_correct = 0
        
    if sell !=0:
        Percentage_sells_correct = 100*correct_maxima/sell
    else:
        Percentage_sells_correct = 0
        
    if hold !=0:
        Percentage_holds_correct = 100*correct_hold/hold
    else:
        Percentage_holds_correct = 0

    print("Percentage low buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage high sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage mid holds correct: " + str(Percentage_holds_correct) + "%")
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %% [markdown]
# ### Creating Training Data and Model

# %%
labels = []
sequential = []

train_sets = ['C6L.SI','O39.SI','600104.SS','0883.HK','1398.HK','ANF','AXL','JPM','CTB','TROX']

for name in train_sets:
    seed = 10
    df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    plt.figure(figsize=(15,5))
    plt.plot(df['previous_1d'].values)
    plt.plot(df['EMA_12'].values)
    plt.show()

    data_15 = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15.append(np.array(i[0:-1]))
            labels.append(i[-1])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_arr = min_max_scaler.fit_transform(data_15)
            sequential.append(data_15_arr)
            data_15 = data_15[1:15]
        else:
            data_15.append(np.array(i[0:-1]))
            count+= 1
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels
# Date
# 2000-01-21    19.000000  19.215335 -37.499990   388000.0     2.0
# 2000-01-24    18.400000  19.089899 -50.000000 -2311000.0     2.0
# 2000-01-25    18.100000  18.937607 -48.780483 -3542000.0     2.0
# 2000-01-26    17.700001  18.747206 -85.714237 -6261000.0     2.0
# 2000-01-27    17.799999  18.601482 -82.142864 -4565000.0     2.0
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2000-01-21     6.793788  7.018572 -90.000010 -1965914.0     2.0
# 2000-01-24     6.890842  6.998922 -77.777802  6276910.0     2.0
# 2000-01-25     6.793788  6.967363 -85.714286  -511055.0     2.0
# 2000-01-26     6.745261  6.933193 -86.666549 -7435027.0     2.0
# 2000-01-27     6.890842  6.926678 -66.666601 -3725757.0     2.0
#             previous_1d    EMA_12   willr_14        OBV_7  labels
# Date
# 2000-01-24     3.189194  3.249583 -69.696967   61394527.0     2.0
# 2000-01-25     3.205140  3.242745 -79.136806   75032521.0     2.0
# 2000-01-26     3.402870  3.267380 -34.532549  127274101.0     2.0
# 2000-01-27     3.284870  3.270071 -62.500055   91746305.0     2.0
# 2000-01-28     3.252978  3.267441 -69.852957   65314909.0     2.0
#             previous_1d    EMA_12   willr_14       OBV_7  labels
# Date
# 2004-04-07        3.250  3.264699 -57.142857  31539206.0     2.0
# 2004-04-08        3.200  3.254745 -78.947368 -24878594.0     2.0
# 2004-04-13        3.250  3.254015 -52.631579  10937473.0     0.0
# 2004-04-14        3.375  3.272628 -10.416706  98972973.0     2.0
# 2004-04-15        3.275  3.272993 -52.083331  47190715.0     2.0
#             previous_1d    EMA_12   willr_14         OBV_7  labels
# Date
# 2006-11-17     3.953848  3.652647 -15.942120  1.897904e+10     2.0
# 2006-11-20     3.934226  3.695967 -18.840636  1.837444e+10     2.0
# 2006-11-21     3.934226  3.732622 -19.403036  1.837444e+10     2.0
# 2006-11-22     3.934226  3.763638 -19.697025  1.837444e+10     0.0
# 2006-11-23     4.051959  3.807995  -1.562480  1.907354e+10     2.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2000-01-21      21.5000  24.211693 -82.142857  -6805500.0     2.0
# 2000-01-24      20.2500  23.602201 -92.465753  -8986800.0     1.0
# 2000-01-25      20.1875  23.076863 -92.307692 -11383100.0     2.0
# 2000-01-26      20.8750  22.738115 -82.786885  -9392500.0     2.0
# 2000-01-27      22.8750  22.759174 -56.557377  -6811000.0     2.0
#             previous_1d     EMA_12   willr_14     OBV_7  labels
# Date
# 2000-01-21      16.0625  14.895987 -18.478261  298700.0     2.0
# 2000-01-24      15.8750  15.046605 -22.222222  293100.0     2.0
# 2000-01-25      15.7500  15.154819 -26.190476  286300.0     2.0
# 2000-01-26      15.7500  15.246386 -29.729730  286300.0     2.0
# 2000-01-27      16.0000  15.362326 -25.000000  311700.0     0.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2000-01-21    49.375000  48.388499 -42.592593  -2894250.0     2.0
# 2000-01-24    48.625000  48.424884 -39.516144  -8054850.0     2.0
# 2000-01-25    48.666668  48.462081 -38.709668  -1595700.0     2.0
# 2000-01-26    49.750000  48.660222 -17.741956   5984250.0     2.0
# 2000-01-27    52.291668  49.218906  -5.232557  14370900.0     2.0
#             previous_1d     EMA_12    willr_14     OBV_7  labels
# Date
# 2000-01-21      13.7500  14.817184  -97.297297 -827200.0     2.0
# 2000-01-24      14.0625  14.701079  -77.500000 -518900.0     2.0
# 2000-01-25      13.6875  14.545144  -92.500000 -906100.0     2.0
# 2000-01-26      13.7500  14.422814  -90.000000 -652700.0     2.0
# 2000-01-27      13.5000  14.280843 -100.000000 -848400.0     2.0
#             previous_1d     EMA_12  willr_14      OBV_7  labels
# Date
# 2010-12-21    18.799999  18.175961      -0.0  1579000.0     0.0
# 2010-12-22    19.000000  18.302736      -0.0  1699000.0     2.0
# 2010-12-23    19.000000  18.410008      -0.0  1699000.0     2.0
# 2010-12-27    19.000000  18.500776      -0.0  1699000.0     2.0
# 2010-12-28    19.000000  18.577580      -0.0  1699000.0     2.0

# %%
X = sequential
X  = np.array(X).reshape(-1, 15, 4)
X.shape
# Out:
# (41550, 15, 4)

# %%
y = labels
y = np.array(y)
y.shape
# Out:
# (41550,)

# %%
from collections import Counter

Counter(y)
# Out:
# Counter({2.0: 37853, 0.0: 1852, 1.0: 1845})

# %%
X = sequential
y = labels

class_0 = []
class_1 = []
class_2 = []

class_0_labels = []
class_1_labels = []
class_2_labels = []

for i in range (0,len(y)):
    if y[i] == 0:
        class_0.append(X[i])
        class_0_labels.append(y[i])
    if y[i] == 1:
        class_1.append(X[i])
        class_1_labels.append(y[i])
    if y[i] == 2:
        class_2.append(X[i])
        class_2_labels.append(y[i])
        
class_0 = class_0[0:1384]
class_1 = class_1[0:1845]
class_2 = class_2[0:1384]

class_0_labels = class_0_labels[0:1384]
class_1_labels = class_1_labels[0:1845]
class_2_labels = class_2_labels[0:1384]

X = class_0 + class_1 + class_2
y = class_0_labels + class_1_labels + class_2_labels

X  = np.array(X).reshape(-1, 15, 4)
y = np.array(y)

print(X.shape)

Counter(y)
# Out:
# (4613, 15, 4)
# Counter({0.0: 1384, 1.0: 1845, 2.0: 1384})

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization,Activation
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(LSTM(100, input_shape=(X_train.shape[1:]), return_sequences=True,kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(LSTM(100, kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# model.add(Dense(100, kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))

model.add(Dense(75, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(50, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "LSTM_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))

epochs = 0 
histories = {}
log_hist = {}

epochs = 0 
histories = {}
nr_log_hist = {}
r_log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    nr_log  = pd.DataFrame(columns = column_names)
    r_log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['C6L.SI','O39.SI','0883.HK','JPM','AXL']
    
    for name in test_sets:
        
        print('\n')
        print(name)
        print('\n')
        
        print('Non-Recession Test')
        print('\n')
        
        X = nr_test_data['{}_X'.format(name)]
        y = nr_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(nr_log)
        nr_log.loc[df_length] = logger
        print(nr_log.head(20))
        logger = []
        
        print('Recession Test')
        print('\n')
        
        X = r_test_data['{}_X'.format(name)]
        y = r_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test2.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(r_log)
        r_log.loc[df_length] = logger
        print(r_log.head(20))
        logger = []

    nr_log.to_csv('non_recession_{}_{}epochs.csv'.format(experiment,epochs))
    nr_log_hist['{}_epochs_logs'.format(epochs)] = nr_log
    r_log.to_csv('recession_{}_{}epochs.csv'.format(experiment,epochs))
    r_log_hist['{}_epochs_logs'.format(epochs)] = r_log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[1 1 1 ... 0 2 1] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  1/29 [>.............................] - ETA: 0s - loss: 0.3633 - accuracy: 0.2812 - mse: 0.4526 - weighted_accuracy: 0.2926 - weighted_mse: 0.4478WARNING:tensorflow:From C:\Users\Shearman Chua\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/29 [=>............................] - ETA: 1s - loss: 0.3541 - accuracy: 0.3086 - mse: 0.4450 - weighted_accuracy: 0.3126 - weighted_mse: 0.4416WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0090s vs `on_train_batch_end` time: 0.1107s). Check your callbacks.
# 29/29 [==============================] - 1s 36ms/step - loss: 0.2702 - accuracy: 0.3699 - mse: 0.5496 - weighted_accuracy: 0.3695 - weighted_mse: 0.5502 - val_loss: 0.2967 - val_accuracy: 0.3944 - val_mse: 0.3498 - val_weighted_accuracy: 0.3944 - val_weighted_mse: 0.3498
# Epoch 2/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1951 - accuracy: 0.4959 - mse: 0.8693 - weighted_accuracy: 0.4853 - weighted_mse: 0.8736 - val_loss: 0.2848 - val_accuracy: 0.3998 - val_mse: 0.3729 - val_weighted_accuracy: 0.3998 - val_weighted_mse: 0.3729
# Epoch 3/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1794 - accuracy: 0.5304 - mse: 1.1059 - weighted_accuracy: 0.5173 - weighted_mse: 1.1109 - val_loss: 0.2710 - val_accuracy: 0.3998 - val_mse: 0.4067 - val_weighted_accuracy: 0.3998 - val_weighted_mse: 0.4067
# Epoch 4/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1733 - accuracy: 0.5444 - mse: 1.2189 - weighted_accuracy: 0.5303 - weighted_mse: 1.2240 - val_loss: 0.2586 - val_accuracy: 0.3998 - val_mse: 0.4440 - val_weighted_accuracy: 0.3998 - val_weighted_mse: 0.4440
# Epoch 5/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1696 - accuracy: 0.5659 - mse: 1.2496 - weighted_accuracy: 0.5537 - weighted_mse: 1.2559 - val_loss: 0.2474 - val_accuracy: 0.3998 - val_mse: 0.4853 - val_weighted_accuracy: 0.3998 - val_weighted_mse: 0.4853
# Epoch 6/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1666 - accuracy: 0.5843 - mse: 1.2766 - weighted_accuracy: 0.5687 - weighted_mse: 1.2835 - val_loss: 0.2366 - val_accuracy: 0.3998 - val_mse: 0.5346 - val_weighted_accuracy: 0.3998 - val_weighted_mse: 0.5346
# Epoch 7/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1635 - accuracy: 0.5959 - mse: 1.2820 - weighted_accuracy: 0.5799 - weighted_mse: 1.2891 - val_loss: 0.2268 - val_accuracy: 0.3998 - val_mse: 0.5888 - val_weighted_accuracy: 0.3998 - val_weighted_mse: 0.5888
# Epoch 8/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1607 - accuracy: 0.6103 - mse: 1.3112 - weighted_accuracy: 0.5950 - weighted_mse: 1.3183 - val_loss: 0.2182 - val_accuracy: 0.3998 - val_mse: 0.6506 - val_weighted_accuracy: 0.3998 - val_weighted_mse: 0.6506
# Epoch 9/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1585 - accuracy: 0.6133 - mse: 1.3231 - weighted_accuracy: 0.5965 - weighted_mse: 1.3311 - val_loss: 0.2095 - val_accuracy: 0.3998 - val_mse: 0.7235 - val_weighted_accuracy: 0.3998 - val_weighted_mse: 0.7235
# Epoch 10/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1561 - accuracy: 0.6339 - mse: 1.3450 - weighted_accuracy: 0.6167 - weighted_mse: 1.3525 - val_loss: 0.2028 - val_accuracy: 0.3987 - val_mse: 0.8000 - val_weighted_accuracy: 0.3987 - val_weighted_mse: 0.8000
# Epoch 11/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1543 - accuracy: 0.6350 - mse: 1.3757 - weighted_accuracy: 0.6205 - weighted_mse: 1.3834 - val_loss: 0.1968 - val_accuracy: 0.4106 - val_mse: 0.8810 - val_weighted_accuracy: 0.4106 - val_weighted_mse: 0.8810
# Epoch 12/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1522 - accuracy: 0.6458 - mse: 1.3971 - weighted_accuracy: 0.6301 - weighted_mse: 1.4050 - val_loss: 0.1925 - val_accuracy: 0.4312 - val_mse: 0.9469 - val_weighted_accuracy: 0.4312 - val_weighted_mse: 0.9469
# Epoch 13/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1506 - accuracy: 0.6504 - mse: 1.4188 - weighted_accuracy: 0.6348 - weighted_mse: 1.4269 - val_loss: 0.1881 - val_accuracy: 0.4236 - val_mse: 1.0344 - val_weighted_accuracy: 0.4236 - val_weighted_mse: 1.0344
# Epoch 14/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1493 - accuracy: 0.6577 - mse: 1.4429 - weighted_accuracy: 0.6442 - weighted_mse: 1.4497 - val_loss: 0.1848 - val_accuracy: 0.4225 - val_mse: 1.1256 - val_weighted_accuracy: 0.4225 - val_weighted_mse: 1.1256
# Epoch 15/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1471 - accuracy: 0.6623 - mse: 1.4693 - weighted_accuracy: 0.6474 - weighted_mse: 1.4773 - val_loss: 0.1822 - val_accuracy: 0.4507 - val_mse: 1.1648 - val_weighted_accuracy: 0.4507 - val_weighted_mse: 1.1648
# Epoch 16/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1460 - accuracy: 0.6707 - mse: 1.4933 - weighted_accuracy: 0.6576 - weighted_mse: 1.4997 - val_loss: 0.1787 - val_accuracy: 0.4821 - val_mse: 1.2204 - val_weighted_accuracy: 0.4821 - val_weighted_mse: 1.2204
# Epoch 17/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1449 - accuracy: 0.6718 - mse: 1.5099 - weighted_accuracy: 0.6588 - weighted_mse: 1.5156 - val_loss: 0.1746 - val_accuracy: 0.5211 - val_mse: 1.2439 - val_weighted_accuracy: 0.5211 - val_weighted_mse: 1.2439
# Epoch 18/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1434 - accuracy: 0.6824 - mse: 1.5359 - weighted_accuracy: 0.6703 - weighted_mse: 1.5420 - val_loss: 0.1705 - val_accuracy: 0.5493 - val_mse: 1.2936 - val_weighted_accuracy: 0.5493 - val_weighted_mse: 1.2936
# Epoch 19/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1431 - accuracy: 0.6764 - mse: 1.5552 - weighted_accuracy: 0.6638 - weighted_mse: 1.5611 - val_loss: 0.1680 - val_accuracy: 0.5601 - val_mse: 1.3365 - val_weighted_accuracy: 0.5601 - val_weighted_mse: 1.3365
# Epoch 20/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1420 - accuracy: 0.6813 - mse: 1.5773 - weighted_accuracy: 0.6692 - weighted_mse: 1.5835 - val_loss: 0.1652 - val_accuracy: 0.5569 - val_mse: 1.3185 - val_weighted_accuracy: 0.5569 - val_weighted_mse: 1.3185
# Validation loss: 0.16520176827907562
# Validation accuracy: 0.5568797588348389
#
#
# C6L.SI
#
#
# Non-Recession Test
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1836 - accuracy: 0.4220 - mse: 1.3547 - weighted_accuracy: 0.4220 - weighted_mse: 1.3547
# Test loss: 0.18361693620681763
# Test accuracy: 0.4220183491706848
#
#
# number of predictions: 218
# actual predicted buys: 6
# actual buys but predicted sell: 0
# actual buys but predicted hold: 3
# actual sells but predicted buy: 1
# actual predicted sells: 3
# actual sells but predicted hold: 5
# actual holds but predicted buy: 87
# actual holds but predicted sell: 30
# actual predicted holds: 83
# Percentage buys correct: 6.382978723404255%
# Percentage sells correct: 9.090909090909092%
# Percentage holds correct: 91.20879120879121%
# actual buys: 9
# actual sells: 9
# actual holds: 200
#
#
# Percentage low buys correct: 47.87234042553192%
# Percentage high sells correct: 39.39393939393939%
# Percentage mid holds correct: 78.88888888888889%
#
#
# Capital: 100
# Share price: $0.7885235071154348
# Shares owned at the moment: 126
# Cash capital at the moment: $0.37281470823971574
#
#
# Price increase from previously bought: 3.969781231322722%
# Share price: $0.8220806872600612
# Shares owned at the moment: 0
# Cash capital at the moment: $103.67013034487181
#
#
# Share price: $0.7952350711543554
# Shares owned at the moment: 130
# Cash capital at the moment: $0.005274556867902902
#
#
# Price increase from previously bought: -65.0803699395077%
# Share price: $0.2784568011070292
# Shares owned at the moment: 0
# Cash capital at the moment: $36.10511039438594
#
#
# Share price: $0.5402013981251648
# Shares owned at the moment: 66
# Cash capital at the moment: $0.3537715643653456
#
#
# Price increase from previously bought: 4.681682320135816%
# Share price: $0.5670470142308714
# Shares owned at the moment: 0
# Cash capital at the moment: $37.67595547051996
#
#
# Share price: $0.285167725095975
# Shares owned at the moment: 131
# Cash capital at the moment: $0.21625180998141502
#
#
# Price increase from previously bought: -21.397430710740682%
# Share price: $0.2247655688956185
# Shares owned at the moment: 0
# Cash capital at the moment: $29.579569539112793
#
#
# Share price: $0.3724161374520112
# Shares owned at the moment: 79
# Cash capital at the moment: $0.07778727454245882
#
#
# Price increase from previously bought: -23.637663377249773%
# Share price: $0.285167725095975
# Shares owned at the moment: 0
# Cash capital at the moment: $22.54408486884738
#
#
# Share price: $0.3589936494241448
# Shares owned at the moment: 62
# Cash capital at the moment: $0.22527018732358428
#
#
# Price increase from previously bought: -31.96871466369301%
# Share price: $0.2448996209624037
# Shares owned at the moment: 0
# Cash capital at the moment: $15.367291301618524
#
#
#
#
# Capital at the end of test period: $15.367291301618524
# profit gained: -84.63270869838148%
#
#
# Capital at the end of test period if Buy and Hold: $35.84540016707856
# profit gained: -64.15459983292143%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.422018      6.382979       9.090909      91.208791
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0          47.87234           39.393939          78.888889     -84.632709
#
#    buy_n_hold profit
# 0           -64.1546
# Recession Test
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1907 - accuracy: 0.3535 - mse: 1.3937 - weighted_accuracy: 0.3535 - weighted_mse: 1.3937
# Test loss: 0.19073134660720825
# Test accuracy: 0.35348838567733765
#
#
# number of predictions: 215
# actual predicted buys: 7
# actual buys but predicted sell: 0
# actual buys but predicted hold: 1
# actual sells but predicted buy: 2
# actual predicted sells: 4
# actual sells but predicted hold: 3
# actual holds but predicted buy: 111
# actual holds but predicted sell: 22
# actual predicted holds: 65
# Percentage buys correct: 5.833333333333333%
# Percentage sells correct: 15.384615384615385%
# Percentage holds correct: 94.20289855072464%
# actual buys: 8
# actual sells: 9
# actual holds: 198
#
#
# Percentage low buys correct: 43.333333333333336%
# Percentage high sells correct: 57.69230769230769%
# Percentage mid holds correct: 88.23529411764706%
#
#
# Capital: 100
# Share price: $1.0062617748699323
# Shares owned at the moment: 99
# Cash capital at the moment: $0.10612951966835737
#
#
# Price increase from previously bought: 0.09623164985612664%
# Share price: $1.01
# Shares owned at the moment: 0
# Cash capital at the moment: $99.82115701966835
#
#
# Share price: $0.9931775412724846
# Shares owned at the moment: 100
# Cash capital at the moment: $0.23027906856994207
#
#
# Price increase from previously bought: -46.06907216098063%
# Share price: $0.5371028452205273
# Shares owned at the moment: 0
# Cash capital at the moment: $53.792860308187024
#
#
# Share price: $0.5557944165130759
# Shares owned at the moment: 96
# Cash capital at the moment: $0.28986659697228134
#
#
# Price increase from previously bought: -62.319859087985094%
# Share price: $0.21000003565137693
# Shares owned at the moment: 0
# Cash capital at the moment: $20.394430010092503
#
#
# Share price: $0.16887848967932728
# Shares owned at the moment: 120
# Cash capital at the moment: $0.07328134697904787
#
#
# Price increase from previously bought: -38.90624158723038%
# Share price: $0.1034579455911858
# Shares owned at the moment: 0
# Cash capital at the moment: $12.454093695876253
#
#
# Share price: $0.08663553142789203
# Shares owned at the moment: 143
# Cash capital at the moment: $0.031143278953674525
#
#
# Price increase from previously bought: 14.786800252762822%
# Share price: $0.09971963133267613
# Shares owned at the moment: 0
# Cash capital at the moment: $14.251835814504785
#
#
# Share price: $0.0716822743938531
# Shares owned at the moment: 198
# Cash capital at the moment: $0.019714486114420282
#
#
# Price increase from previously bought: 30.930640901162%
# Share price: $0.0941121599449115
# Shares owned at the moment: 0
# Cash capital at the moment: $18.602678084116892
#
#
# Share price: $0.07915890291087245
# Shares owned at the moment: 234
# Cash capital at the moment: $0.02855604894959285
#
#
# Price increase from previously bought: -54.43462055733992%
# Share price: $0.0361682443737894
# Shares owned at the moment: 0
# Cash capital at the moment: $8.468650967161778
#
#
# Share price: $0.047383187149318544
# Shares owned at the moment: 178
# Cash capital at the moment: $0.011249584473485896
#
#
# Price increase from previously bought: 220.0272536394872%
# Share price: $0.15205612008025482
# Shares owned at the moment: 0
# Cash capital at the moment: $27.00280748797956
#
#
# Share price: $0.2043925196993911
# Shares owned at the moment: 131
# Cash capital at the moment: $0.15375500213762194
#
#
#
#
# Capital at the end of test period: $28.809032438148737
# profit gained: -71.19096756185127%
#
#
# Capital at the end of test period if Buy and Hold: $21.761644528562254
# profit gained: -78.23835547143774%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.353488      5.833333      15.384615      94.202899
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.333333           57.692308          88.235294     -71.190968
#
#    buy_n_hold profit
# 0         -78.238355
#
#
# O39.SI
#
#
# Non-Recession Test
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1995 - accuracy: 0.2706 - mse: 1.3924 - weighted_accuracy: 0.2706 - weighted_mse: 1.3924
# Test loss: 0.199459508061409
# Test accuracy: 0.2706421911716461
#
#
# number of predictions: 218
# actual predicted buys: 8
# actual buys but predicted sell: 0
# actual buys but predicted hold: 0
# actual sells but predicted buy: 0
# actual predicted sells: 3
# actual sells but predicted hold: 6
# actual holds but predicted buy: 97
# actual holds but predicted sell: 56
# actual predicted holds: 48
# Percentage buys correct: 7.619047619047619%
# Percentage sells correct: 5.084745762711864%
# Percentage holds correct: 88.88888888888889%
# actual buys: 8
# actual sells: 9
# actual holds: 201
#
#
# Percentage low buys correct: 54.285714285714285%
# Percentage high sells correct: 50.847457627118644%
# Percentage mid holds correct: 84.90566037735849%
#
#
# Capital: 100
# Share price: $0.6357665229914489
# Shares owned at the moment: 156
# Cash capital at the moment: $0.5476785749706323
#
#
# Price increase from previously bought: -25.294641640383343%
# Share price: $0.47625777639439737
# Shares owned at the moment: 0
# Cash capital at the moment: $74.63957710642343
#
#
# Share price: $0.30447822609568687
# Shares owned at the moment: 244
# Cash capital at the moment: $0.14258504936563554
#
#
# Price increase from previously bought: 112.25147564805465%
# Share price: $0.6480367416168822
# Shares owned at the moment: 0
# Cash capital at the moment: $157.82871735025995
#
#
# Share price: $0.73392593169001
# Shares owned at the moment: 214
# Cash capital at the moment: $0.33665255779823156
#
#
# Price increase from previously bought: 12.230082759703432%
# Share price: $0.8259508161520819
# Shares owned at the moment: 0
# Cash capital at the moment: $176.60405515903827
#
#
# Share price: $0.8075460732901576
# Shares owned at the moment: 218
# Cash capital at the moment: $0.0748873108464636
#
#
# Price increase from previously bought: 23.21198530018631%
# Share price: $0.9977297813745658
# Shares owned at the moment: 0
# Cash capital at the moment: $216.98184064656775
#
#
# Share price: $0.6603063751660889
# Shares owned at the moment: 327
# Cash capital at the moment: $0.4678754593885799
#
#
# Price increase from previously bought: -70.69284511813727%
# Share price: $0.19404918384791725
# Shares owned at the moment: 0
# Cash capital at the moment: $63.747459849082276
#
#
# Share price: $0.5007976285690374
# Shares owned at the moment: 126
# Cash capital at the moment: $0.47343227108439123
#
#
# Price increase from previously bought: 25.381036864343763%
# Share price: $0.629631998754957
# Shares owned at the moment: 0
# Cash capital at the moment: $79.58889662664038
#
#
# Share price: $0.5682820757802427
# Shares owned at the moment: 139
# Cash capital at the moment: $0.3804622697196436
#
#
# Price increase from previously bought: -70.2534240275299%
# Share price: $0.1695093316732772
# Shares owned at the moment: 0
# Cash capital at the moment: $23.87746443027306
#
#
# Share price: $0.2799383739210459
# Shares owned at the moment: 85
# Cash capital at the moment: $0.017267052080111256
#
#
# Price increase from previously bought: -46.17043558397225%
# Share price: $0.15110400373512634
# Shares owned at the moment: 0
# Cash capital at the moment: $12.825786808692765
#
#
# Share price: $0.09588919007312867
# Shares owned at the moment: 133
# Cash capital at the moment: $0.03745305769740348
#
#
# Price increase from previously bought: 159.23653932710607%
# Share price: $0.2492634124336892
# Shares owned at the moment: 0
# Cash capital at the moment: $33.09831881828045
#
#
# Share price: $0.3658281490704012
# Shares owned at the moment: 90
# Cash capital at the moment: $0.08324293504941949
#
#
# Price increase from previously bought: 4.742937427181881%
# Share price: $0.38423289193232546
# Shares owned at the moment: 0
# Cash capital at the moment: $34.56910556820546
#
#
# Share price: $0.38423289193232546
# Shares owned at the moment: 89
# Cash capital at the moment: $0.2783371859280592
#
#
# Price increase from previously bought: -33.71257190265244%
# Share price: $0.25539852174640587
# Shares owned at the moment: 0
# Cash capital at the moment: $22.946296833160748
#
#
#
#
# Capital at the end of test period: $22.946296833160748
# profit gained: -77.05370316683926%
#
#
# Capital at the end of test period if Buy and Hold: $44.097971344241664
# profit gained: -55.90202865575834%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.422018      6.382979       9.090909      91.208791
# 1       0.270642      7.619048       5.084746      88.888889
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.872340           39.393939          78.888889     -84.632709
# 1         54.285714           50.847458          84.905660     -77.053703
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# Recession Test
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1894 - accuracy: 0.3535 - mse: 1.3561 - weighted_accuracy: 0.3535 - weighted_mse: 1.3561
# Test loss: 0.18935397267341614
# Test accuracy: 0.35348838567733765
#
#
# number of predictions: 215
# actual predicted buys: 9
# actual buys but predicted sell: 0
# actual buys but predicted hold: 3
# actual sells but predicted buy: 1
# actual predicted sells: 3
# actual sells but predicted hold: 6
# actual holds but predicted buy: 88
# actual holds but predicted sell: 41
# actual predicted holds: 64
# Percentage buys correct: 9.183673469387756%
# Percentage sells correct: 6.818181818181818%
# Percentage holds correct: 87.67123287671232%
# actual buys: 12
# actual sells: 10
# actual holds: 193
#
#
# Percentage low buys correct: 47.95918367346939%
# Percentage high sells correct: 54.54545454545455%
# Percentage mid holds correct: 80.55555555555556%
#
#
# Capital: 100
# Share price: $0.9886586309918834
# Shares owned at the moment: 100
# Cash capital at the moment: $0.8622557772888797
#
#
# Price increase from previously bought: 0.9558718911797381%
# Share price: $1.0008537405328568
# Shares owned at the moment: 0
# Cash capital at the moment: $100.67239505192802
#
#
# Share price: $0.9581707117622773
# Shares owned at the moment: 104
# Cash capital at the moment: $0.7486042050871617
#
#
# Price increase from previously bought: -76.42982736033191%
# Share price: $0.22646355779520433
# Shares owned at the moment: 0
# Cash capital at the moment: $24.236045638258986
#
#
# Share price: $0.2843902554262392
# Shares owned at the moment: 84
# Cash capital at the moment: $0.2815700334514304
#
#
# Price increase from previously bought: 20.03862881907603%
# Share price: $0.3423169530572745
# Shares owned at the moment: 0
# Cash capital at the moment: $28.957118874106257
#
#
# Share price: $0.30878047450818547
# Shares owned at the moment: 93
# Cash capital at the moment: $0.16156413848953832
#
#
# Price increase from previously bought: 40.09655111569881%
# Share price: $0.4337804199917452
# Shares owned at the moment: 0
# Cash capital at the moment: $40.39220385530895
#
#
# Share price: $0.4551220797542077
# Shares owned at the moment: 88
# Cash capital at the moment: $0.23132129363815324
#
#
# Price increase from previously bought: -21.651721007811975%
# Share price: $0.35756091267207757
# Shares owned at the moment: 0
# Cash capital at the moment: $31.610151867914333
#
#
# Share price: $0.3209755840491584
# Shares owned at the moment: 98
# Cash capital at the moment: $0.06804171119556202
#
#
# Price increase from previously bought: -23.95532385019973%
# Share price: $0.2447560767294903
# Shares owned at the moment: 0
# Cash capital at the moment: $23.988175468007015
#
#
# Share price: $0.23560981726234664
# Shares owned at the moment: 101
# Cash capital at the moment: $0.1261432977653847
#
#
# Price increase from previously bought: 48.7627440022671%
# Share price: $0.3514635032787641
# Shares owned at the moment: 0
# Cash capital at the moment: $35.526338140884874
#
#
# Share price: $0.7234144896556145
# Shares owned at the moment: 48
# Cash capital at the moment: $0.7069519247808387
#
#
#
#
# Capital at the end of test period: $36.50286772263037
# profit gained: -63.49713227736963%
#
#
# Capital at the end of test period if Buy and Hold: $75.43708035614208
# profit gained: -24.562919643857924%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.353488      5.833333      15.384615      94.202899
# 1       0.353488      9.183673       6.818182      87.671233
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.333333           57.692308          88.235294     -71.190968
# 1         47.959184           54.545455          80.555556     -63.497132
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
#
#
# 0883.HK
#
#
# Non-Recession Test
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1923 - accuracy: 0.2938 - mse: 1.3760 - weighted_accuracy: 0.2938 - weighted_mse: 1.3760
# Test loss: 0.1922725886106491
# Test accuracy: 0.29383885860443115
#
#
# number of predictions: 211
# actual predicted buys: 5
# actual buys but predicted sell: 1
# actual buys but predicted hold: 2
# actual sells but predicted buy: 2
# actual predicted sells: 5
# actual sells but predicted hold: 2
# actual holds but predicted buy: 96
# actual holds but predicted sell: 46
# actual predicted holds: 52
# Percentage buys correct: 4.854368932038835%
# Percentage sells correct: 9.615384615384615%
# Percentage holds correct: 92.85714285714286%
# actual buys: 8
# actual sells: 9
# actual holds: 194
#
#
# Percentage low buys correct: 50.48543689320388%
# Percentage high sells correct: 58.8235294117647%
# Percentage mid holds correct: 87.5%
#
#
# Capital: 100
# Share price: $0.6782927975265876
# Shares owned at the moment: 147
# Cash capital at the moment: $0.016758900191504722
#
#
# Price increase from previously bought: 36.30259457670804%
# Share price: $0.9270731412307789
# Shares owned at the moment: 0
# Cash capital at the moment: $135.92174134377342
#
#
# Share price: $0.9319513012070721
# Shares owned at the moment: 145
# Cash capital at the moment: $0.4171870873916248
#
#
# Price increase from previously bought: -32.63749762016279%
# Share price: $0.6295121281775378
# Shares owned at the moment: 0
# Cash capital at the moment: $91.44542771202381
#
#
# Share price: $0.5953659387573673
# Shares owned at the moment: 153
# Cash capital at the moment: $0.10393886341444158
#
#
# Price increase from previously bought: 7.079568985368145%
# Share price: $0.6392684481301243
# Shares owned at the moment: 0
# Cash capital at the moment: $97.6430392277727
#
#
# Share price: $0.5417073420354945
# Shares owned at the moment: 179
# Cash capital at the moment: $0.410769564302214
#
#
# Price increase from previously bought: -98.15904739630645%
# Share price: $0.01
# Shares owned at the moment: 0
# Cash capital at the moment: $2.195847064302214
#
#
# Share price: $0.01
# Shares owned at the moment: 218
# Cash capital at the moment: $0.009852064302213748
#
#
# Price increase from previously bought: 1507.7756451408882%
# Share price: $0.16121970281650255
# Shares owned at the moment: 0
# Cash capital at the moment: $35.05909606646128
#
#
# Share price: $0.39048787182246225
# Shares owned at the moment: 89
# Cash capital at the moment: $0.21010356763358828
#
#
# Price increase from previously bought: -38.893820979313475%
# Share price: $0.23926840160942997
# Shares owned at the moment: 0
# Cash capital at the moment: $21.446430369578948
#
#
# Share price: $0.28317091098218694
# Shares owned at the moment: 75
# Cash capital at the moment: $0.15020804552485245
#
#
# Price increase from previously bought: 1.4436389134818262%
# Share price: $0.28804883835500994
# Shares owned at the moment: 0
# Cash capital at the moment: $21.694460849239874
#
#
# Share price: $0.21000013956208208
# Shares owned at the moment: 103
# Cash capital at the moment: $0.004963934814458781
#
#
# Price increase from previously bought: 83.11997035643364%
# Share price: $0.385609711846169
# Shares owned at the moment: 0
# Cash capital at the moment: $39.61354030408944
#
#
# Share price: $0.2636585036804846
# Shares owned at the moment: 149
# Cash capital at the moment: $0.22038918381414874
#
#
# Price increase from previously bought: -22.41500339750171%
# Share price: $0.20512197958578926
# Shares owned at the moment: 0
# Cash capital at the moment: $30.699515410961467
#
#
#
#
# Capital at the end of test period: $30.699515410961467
# profit gained: -69.30048458903853%
#
#
# Capital at the end of test period if Buy and Hold: $45.31039913308918
# profit gained: -54.68960086691082%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.422018      6.382979       9.090909      91.208791
# 1       0.270642      7.619048       5.084746      88.888889
# 2       0.293839      4.854369       9.615385      92.857143
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.872340           39.393939          78.888889     -84.632709
# 1         54.285714           50.847458          84.905660     -77.053703
# 2         50.485437           58.823529          87.500000     -69.300485
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# 2         -54.689601
# Recession Test
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1890 - accuracy: 0.3521 - mse: 1.4111 - weighted_accuracy: 0.3521 - weighted_mse: 1.4111
# Test loss: 0.18901486694812775
# Test accuracy: 0.35211268067359924
# number of predictions: 213
# actual predicted buys: 7
# actual buys but predicted sell: 1
# actual buys but predicted hold: 2
# actual sells but predicted buy: 3
# actual predicted sells: 3
# actual sells but predicted hold: 4
# actual holds but predicted buy: 98
# actual holds but predicted sell: 30
# actual predicted holds: 65
# Percentage buys correct: 6.481481481481482%
# Percentage sells correct: 8.823529411764707%
# Percentage holds correct: 91.54929577464789%
# actual buys: 10
# actual sells: 10
# actual holds: 193
#
#
# Percentage low buys correct: 48.148148148148145%
# Percentage high sells correct: 61.76470588235294%
# Percentage mid holds correct: 85.71428571428571%
#
#
# Capital: 100
# Share price: $0.9662289181183106
# Shares owned at the moment: 103
# Cash capital at the moment: $0.20473709275698582
#
#
# Price increase from previously bought: -68.90802665762199%
# Share price: $0.30124579165122367
# Shares owned at the moment: 0
# Cash capital at the moment: $31.147725762347815
#
#
# Share price: $0.33996625293417404
# Shares owned at the moment: 91
# Cash capital at the moment: $0.1257201905411982
#
#
# Price increase from previously bought: 18.985478254850353%
# Share price: $0.40562287575670797
# Shares owned at the moment: 0
# Cash capital at the moment: $36.935894759743505
#
#
# Share price: $0.35006733358042164
# Shares owned at the moment: 105
# Cash capital at the moment: $0.07774279122788386
#
#
# Price increase from previously bought: 53.91932666531842%
# Share price: $0.5403030412497052
# Shares owned at the moment: 0
# Cash capital at the moment: $56.653549619286075
#
#
# Share price: $0.38205379461628364
# Shares owned at the moment: 147
# Cash capital at the moment: $0.33719656421874333
#
#
# Price increase from previously bought: 12.46941791534677%
# Share price: $0.4308753365454818
# Shares owned at the moment: 0
# Cash capital at the moment: $63.50168968160606
#
#
# Share price: $0.42414133629839346
# Shares owned at the moment: 149
# Cash capital at the moment: $0.13083866059716343
#
#
# Price increase from previously bought: 4.475726855806195%
# Share price: $0.44434333703965856
# Shares owned at the moment: 0
# Cash capital at the moment: $66.15592619715429
#
#
# Share price: $0.4460268772392382
# Shares owned at the moment: 147
# Cash capital at the moment: $0.4096688778623019
#
#
# Price increase from previously bought: 5.7482903731084445%
# Share price: $0.4729628782275914
# Shares owned at the moment: 0
# Cash capital at the moment: $69.74401673379474
#
#
# Share price: $0.40562287575670797
# Shares owned at the moment: 171
# Cash capital at the moment: $0.19176082207309264
#
#
# Price increase from previously bought: -0.27424582398405395%
# Share price: $0.40562287575670797
# Shares owned at the moment: 0
# Cash capital at the moment: $69.36252841914556
#
#
# Share price: $0.23727270902826936
# Shares owned at the moment: 291
# Cash capital at the moment: $0.12629260651929997
#
#
#
#
# Capital at the end of test period: $44.555185299820174
# profit gained: -55.444814700179826%
#
#
# Capital at the end of test period if Buy and Hold: $15.710112504960433
# profit gained: -84.28988749503957%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.353488      5.833333      15.384615      94.202899
# 1       0.353488      9.183673       6.818182      87.671233
# 2       0.352113      6.481481       8.823529      91.549296
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.333333           57.692308          88.235294     -71.190968
# 1         47.959184           54.545455          80.555556     -63.497132
# 2         48.148148           61.764706          85.714286     -55.444815
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
# 2         -84.289887
#
#
# JPM
#
#
# Non-Recession Test
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2052 - accuracy: 0.2477 - mse: 1.3797 - weighted_accuracy: 0.2477 - weighted_mse: 1.3797
# Test loss: 0.2052069455385208
# Test accuracy: 0.24770642817020416
#
#
# number of predictions: 218
# actual predicted buys: 8
# actual buys but predicted sell: 2
# actual buys but predicted hold: 1
# actual sells but predicted buy: 1
# actual predicted sells: 2
# actual sells but predicted hold: 3
# actual holds but predicted buy: 81
# actual holds but predicted sell: 76
# actual predicted holds: 44
# Percentage buys correct: 8.88888888888889%
# Percentage sells correct: 2.5%
# Percentage holds correct: 91.66666666666667%
# actual buys: 11
# actual sells: 6
# actual holds: 201
#
#
# Percentage low buys correct: 48.888888888888886%
# Percentage high sells correct: 46.835443037974684%
# Percentage mid holds correct: 85.41666666666667%
#
#
# Capital: 100
# Share price: $0.05968146056768497
# Shares owned at the moment: 1670
# Cash capital at the moment: $0.05787374430900627
#
#
# Price increase from previously bought: 204.49930188356814%
# Share price: $0.18222938726716964
# Shares owned at the moment: 0
# Cash capital at the moment: $303.5440620194578
#
#
# Share price: $0.148343983710997
# Shares owned at the moment: 2040
# Cash capital at the moment: $0.09012550040517908
#
#
# Price increase from previously bought: 2.4661104491699337%
# Share price: $0.15242031654704236
# Shares owned at the moment: 0
# Cash capital at the moment: $310.17249328054265
#
#
# Share price: $0.01
# Shares owned at the moment: 30932
# Cash capital at the moment: $0.001863280542636403
#
#
# Price increase from previously bought: 1620.7452736970201%
# Share price: $0.17254773231996867
# Shares owned at the moment: 0
# Cash capital at the moment: $5322.57089164748
#
#
# Share price: $0.429872778606591
# Shares owned at the moment: 12347
# Cash capital at the moment: $0.335686398897451
#
#
# Price increase from previously bought: -2.165664733126149%
# Share price: $0.4217197241754669
# Shares owned at the moment: 0
# Cash capital at the moment: $5192.989943848802
#
#
# Share price: $0.3738216956697109
# Shares owned at the moment: 13853
# Cash capital at the moment: $0.1969758734867355
#
#
# Price increase from previously bought: -22.703590609356205%
# Share price: $0.28974536283366503
# Shares owned at the moment: 0
# Cash capital at the moment: $4003.001420302078
#
#
# Share price: $0.2968790910813819
# Shares owned at the moment: 13446
# Cash capital at the moment: $0.18761191044586667
#
#
# Price increase from previously bought: 30.621267568025566%
# Share price: $0.3888536468027002
# Shares owned at the moment: 0
# Cash capital at the moment: $5214.335299948552
#
#
# Share price: $0.41101913180389116
# Shares owned at the moment: 12651
# Cash capital at the moment: $0.23280514728503476
#
#
# Price increase from previously bought: 6.154695125583554%
# Share price: $0.43751597556649524
# Shares owned at the moment: 0
# Cash capital at the moment: $5520.026121870063
#
#
# Share price: $0.44490453536006425
# Shares owned at the moment: 12373
# Cash capital at the moment: $0.08409536596082035
#
#
# Price increase from previously bought: -41.849242790366795%
# Share price: $0.25942682340135037
# Shares owned at the moment: 0
# Cash capital at the moment: $3201.1449890745203
#
#
# Share price: $0.21229309515363348
# Shares owned at the moment: 15037
# Cash capital at the moment: $0.11502625181447002
#
#
# Price increase from previously bought: 19.952091931054827%
# Share price: $0.25535029618578853
# Shares owned at the moment: 0
# Cash capital at the moment: $3829.258248387216
#
#
# Share price: $0.518280275824534
# Shares owned at the moment: 7368
# Cash capital at the moment: $0.06778116329269324
#
#
# Price increase from previously bought: 3.6476379143724813%
# Share price: $0.5386625231433115
# Shares owned at the moment: 0
# Cash capital at the moment: $3958.0188716392818
#
#
# Share price: $0.7455416142246933
# Shares owned at the moment: 5294
# Cash capital at the moment: $0.2675983430649467
#
#
# Price increase from previously bought: 3.201898936430214%
# Share price: $0.7715289892751118
# Shares owned at the moment: 0
# Cash capital at the moment: $4073.509762775145
#
#
# Share price: $0.7659238615434714
# Shares owned at the moment: 5303
# Cash capital at the moment: $0.6458658562628443
#
#
# Price increase from previously bought: 6.2939547451828615%
# Share price: $0.8163696223691963
# Shares owned at the moment: 0
# Cash capital at the moment: $4317.948650984696
#
#
# Share price: $0.799808876340611
# Shares owned at the moment: 5383
# Cash capital at the moment: $0.7376988944970435
#
#
# Price increase from previously bought: 5.2532974640536745%
# Share price: $0.8441402351020251
# Shares owned at the moment: 0
# Cash capital at the moment: $4532.248565513424
#
#
# Share price: $0.8612102554632799
# Shares owned at the moment: 5248
# Cash capital at the moment: $0.1881584352850041
#
#
# Price increase from previously bought: 7.69141541841436%
# Share price: $0.9299999999999999
# Shares owned at the moment: 0
# Cash capital at the moment: $4867.406398435284
#
#
#
#
# Capital at the end of test period: $4867.406398435284
# profit gained: 4767.406398435284%
#
#
# Capital at the end of test period if Buy and Hold: $1676.1791664809543
# profit gained: 1576.1791664809543%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.422018      6.382979       9.090909      91.208791
# 1       0.270642      7.619048       5.084746      88.888889
# 2       0.293839      4.854369       9.615385      92.857143
# 3       0.247706      8.888889       2.500000      91.666667
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.872340           39.393939          78.888889     -84.632709
# 1         54.285714           50.847458          84.905660     -77.053703
# 2         50.485437           58.823529          87.500000     -69.300485
# 3         48.888889           46.835443          85.416667    4767.406398
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# 2         -54.689601
# 3        1576.179166
# Recession Test
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1780 - accuracy: 0.4566 - mse: 1.3125 - weighted_accuracy: 0.4566 - weighted_mse: 1.3125
# Test loss: 0.17799435555934906
# Test accuracy: 0.456620991230011
#
#
# number of predictions: 219
# actual predicted buys: 6
# actual buys but predicted sell: 0
# actual buys but predicted hold: 4
# actual sells but predicted buy: 1
# actual predicted sells: 4
# actual sells but predicted hold: 7
# actual holds but predicted buy: 73
# actual holds but predicted sell: 34
# actual predicted holds: 90
# Percentage buys correct: 7.5%
# Percentage sells correct: 10.526315789473685%
# Percentage holds correct: 89.10891089108911%
# actual buys: 10
# actual sells: 12
# actual holds: 197
#
#
# Percentage low buys correct: 48.10126582278481%
# Percentage high sells correct: 65.78947368421052%
# Percentage mid holds correct: 84.15841584158416%
#
#
# Capital: 100
# Share price: $0.9699796411480657
# Shares owned at the moment: 102
# Cash capital at the moment: $0.7899973135552756
#
#
# Price increase from previously bought: -77.87593749544502%
# Share price: $0.21518904906980119
# Shares owned at the moment: 0
# Cash capital at the moment: $22.678919790410916
#
#
# Share price: $0.15380198713573123
# Shares owned at the moment: 147
# Cash capital at the moment: $0.007853228158804626
#
#
# Price increase from previously bought: 117.15749826784622%
# Share price: $0.33491102705595166
# Shares owned at the moment: 0
# Cash capital at the moment: $49.10438642269634
#
#
# Share price: $0.15397147173178083
# Shares owned at the moment: 318
# Cash capital at the moment: $0.006810359960589096
#
#
# Price increase from previously bought: 151.845606937853%
# Share price: $0.38883675605965684
# Shares owned at the moment: 0
# Cash capital at the moment: $123.31686104375729
#
#
# Share price: $0.36340009387635375
# Shares owned at the moment: 338
# Cash capital at the moment: $0.14984892629163937
#
#
# Price increase from previously bought: -0.9257501438866722%
# Share price: $0.36102601575611626
# Shares owned at the moment: 0
# Cash capital at the moment: $121.84106857021362
#
#
# Share price: $0.33643716468572404
# Shares owned at the moment: 361
# Cash capital at the moment: $0.0532541234254893
#
#
# Price increase from previously bought: 27.572988211654128%
# Share price: $0.43038325254136356
# Shares owned at the moment: 0
# Cash capital at the moment: $154.9943453168973
#
#
# Share price: $0.3411853209261988
# Shares owned at the moment: 453
# Cash capital at the moment: $0.012363323785422153
#
#
# Price increase from previously bought: -2.950826577739929%
# Share price: $0.33202810701490293
# Shares owned at the moment: 0
# Cash capital at the moment: $150.0074717872226
#
#
# Share price: $0.36221305481623456
# Shares owned at the moment: 413
# Cash capital at the moment: $0.0020966711101948476
#
#
# Price increase from previously bought: 6.448907583177044%
# Share price: $0.3866321625354687
# Shares owned at the moment: 0
# Cash capital at the moment: $159.2420623196591
#
#
# Share price: $0.3176140243198753
# Shares owned at the moment: 499
# Cash capital at the moment: $0.31681833916840674
#
#
# Price increase from previously bought: 16.125136722166687%
# Share price: $0.36984400172020404
# Shares owned at the moment: 0
# Cash capital at the moment: $184.36145676618966
#
#
# Share price: $0.43937085247905516
# Shares owned at the moment: 418
# Cash capital at the moment: $0.1993836350199274
#
#
# Price increase from previously bought: -5.6243169944065645%
# Share price: $0.4157995558727319
# Shares owned at the moment: 0
# Cash capital at the moment: $173.52563640034614
#
#
# Share price: $0.6686400400759915
# Shares owned at the moment: 258
# Cash capital at the moment: $0.5421059523064287
#
#
# Price increase from previously bought: 13.509906758118028%
# Share price: $0.7610598609243047
# Shares owned at the moment: 0
# Cash capital at the moment: $196.35557809945124
#
#
# Share price: $0.7093385960672332
# Shares owned at the moment: 276
# Cash capital at the moment: $0.03973759047983094
#
#
#
#
# Capital at the end of test period: $189.72453120553712
# profit gained: 89.72453120553712%
#
#
# Capital at the end of test period if Buy and Hold: $68.09965200824497
# profit gained: -31.90034799175503%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.353488      5.833333      15.384615      94.202899
# 1       0.353488      9.183673       6.818182      87.671233
# 2       0.352113      6.481481       8.823529      91.549296
# 3       0.456621      7.500000      10.526316      89.108911
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.333333           57.692308          88.235294     -71.190968
# 1         47.959184           54.545455          80.555556     -63.497132
# 2         48.148148           61.764706          85.714286     -55.444815
# 3         48.101266           65.789474          84.158416      89.724531
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
# 2         -84.289887
# 3         -31.900348
#
#
# AXL
#
#
# Non-Recession Test
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1969 - accuracy: 0.2844 - mse: 1.3765 - weighted_accuracy: 0.2844 - weighted_mse: 1.3765
# Test loss: 0.1968800127506256
# Test accuracy: 0.2844036817550659
#
#
# number of predictions: 218
# actual predicted buys: 6
# actual buys but predicted sell: 0
# actual buys but predicted hold: 2
# actual sells but predicted buy: 0
# actual predicted sells: 3
# actual sells but predicted hold: 5
# actual holds but predicted buy: 109
# actual holds but predicted sell: 40
# actual predicted holds: 53
# Percentage buys correct: 5.217391304347826%
# Percentage sells correct: 6.976744186046512%
# Percentage holds correct: 88.33333333333333%
# actual buys: 8
# actual sells: 8
# actual holds: 202
#
#
# Percentage low buys correct: 46.95652173913044%
# Percentage high sells correct: 55.81395348837209%
# Percentage mid holds correct: 84.7457627118644%
#
#
# Capital: 100
# Share price: $0.7426007274823263
# Shares owned at the moment: 134
# Cash capital at the moment: $0.21785414929102842
#
#
# Price increase from previously bought: 35.63548753751158%
# Share price: $1.01
# Shares owned at the moment: 0
# Cash capital at the moment: $135.18566914929102
#
#
# Share price: $0.9339926815103341
# Shares owned at the moment: 144
# Cash capital at the moment: $0.32086190992481534
#
#
# Price increase from previously bought: -17.776510068909744%
# Share price: $0.7700732722294761
# Shares owned at the moment: 0
# Cash capital at the moment: $110.9064640951665
#
#
# Share price: $0.9175091371954818
# Shares owned at the moment: 120
# Cash capital at the moment: $0.5025896164341788
#
#
# Price increase from previously bought: -47.65274110269767%
# Share price: $0.4816116833836226
# Shares owned at the moment: 0
# Cash capital at the moment: $58.13705976695229
#
#
# Share price: $0.5017582278425741
# Shares owned at the moment: 115
# Cash capital at the moment: $0.2761825255010564
#
#
# Price increase from previously bought: 9.918185596282658%
# Share price: $0.5530402298599622
# Shares owned at the moment: 0
# Cash capital at the moment: $63.70090998670349
#
#
# Share price: $0.48069591151439495
# Shares owned at the moment: 132
# Cash capital at the moment: $0.07455705092363019
#
#
# Price increase from previously bought: 22.333716248391532%
# Share price: $0.5896703186337657
# Shares owned at the moment: 0
# Cash capital at the moment: $77.69698878491664
#
#
# Share price: $0.4687912265456817
# Shares owned at the moment: 165
# Cash capital at the moment: $0.13372238583404794
#
#
# Price increase from previously bought: -54.62549855317186%
# Share price: $0.21329663899672058
# Shares owned at the moment: 0
# Cash capital at the moment: $35.23088447034818
#
#
# Share price: $0.19681318201468057
# Shares owned at the moment: 178
# Cash capital at the moment: $0.10179801913884745
#
#
# Price increase from previously bought: 13.182140463873338%
# Share price: $0.22336995489260247
# Shares owned at the moment: 0
# Cash capital at the moment: $39.75231039710216
#
#
# Share price: $0.225201411298246
# Shares owned at the moment: 176
# Cash capital at the moment: $0.007864525542508716
#
#
# Price increase from previously bought: 108.81098283924987%
# Share price: $0.47153845482055323
# Shares owned at the moment: 0
# Cash capital at the moment: $82.77040796182672
#
#
# Share price: $0.38362636402936146
# Shares owned at the moment: 215
# Cash capital at the moment: $0.06392060778163966
#
#
# Price increase from previously bought: 10.20013849330712%
# Share price: $0.4239193656144522
# Shares owned at the moment: 0
# Cash capital at the moment: $90.95594188996931
#
#
#
#
# Capital at the end of test period: $90.95594188996931
# profit gained: -9.04405811003069%
#
#
# Capital at the end of test period if Buy and Hold: $59.80379974835048
# profit gained: -40.19620025164952%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.422018      6.382979       9.090909      91.208791
# 1       0.270642      7.619048       5.084746      88.888889
# 2       0.293839      4.854369       9.615385      92.857143
# 3       0.247706      8.888889       2.500000      91.666667
# 4       0.284404      5.217391       6.976744      88.333333
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.872340           39.393939          78.888889     -84.632709
# 1         54.285714           50.847458          84.905660     -77.053703
# 2         50.485437           58.823529          87.500000     -69.300485
# 3         48.888889           46.835443          85.416667    4767.406398
# 4         46.956522           55.813953          84.745763      -9.044058
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# 2         -54.689601
# 3        1576.179166
# 4         -40.196200
# Recession Test
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1736 - accuracy: 0.4749 - mse: 1.3303 - weighted_accuracy: 0.4749 - weighted_mse: 1.3303
# Test loss: 0.1736224740743637
# Test accuracy: 0.47488585114479065
#
#
# number of predictions: 219
# actual predicted buys: 8
# actual buys but predicted sell: 0
# actual buys but predicted hold: 3
# actual sells but predicted buy: 2
# actual predicted sells: 5
# actual sells but predicted hold: 4
# actual holds but predicted buy: 74
# actual holds but predicted sell: 32
# actual predicted holds: 91
# Percentage buys correct: 9.523809523809524%
# Percentage sells correct: 13.513513513513514%
# Percentage holds correct: 92.85714285714286%
# actual buys: 11
# actual sells: 11
# actual holds: 197
#
#
# Percentage low buys correct: 53.01204819277108%
# Percentage high sells correct: 62.16216216216216%
# Percentage mid holds correct: 85.71428571428571%
#
#
# Capital: 100
# Share price: $0.7376316242287357
# Shares owned at the moment: 135
# Cash capital at the moment: $0.1458849886257525
#
#
# Price increase from previously bought: -80.1473547855927%
# Share price: $0.14684209766810635
# Shares owned at the moment: 0
# Cash capital at the moment: $19.915053045060827
#
#
# Share price: $0.08499998980446886
# Shares owned at the moment: 233
# Cash capital at the moment: $0.05559167715236768
#
#
# Price increase from previously bought: 135.5751101546378%
# Share price: $0.20078947636724503
# Shares owned at the moment: 0
# Cash capital at the moment: $46.71088381373815
#
#
# Share price: $0.5863157623131194
# Shares owned at the moment: 79
# Cash capital at the moment: $0.26456149163918496
#
#
# Price increase from previously bought: 2.1875689372086837%
# Share price: $0.6007894638188991
# Shares owned at the moment: 0
# Cash capital at the moment: $47.59640762231756
#
#
# Share price: $0.6113157693715641
# Shares owned at the moment: 77
# Cash capital at the moment: $0.3956472665426958
#
#
# Price increase from previously bought: -3.2793238408005188%
# Share price: $0.5928947346544002
# Shares owned at the moment: 0
# ...
#
#
# Share price: $0.6126793315217027
# Shares owned at the moment: 124
# Cash capital at the moment: $0.4728268960950146
#
#
# Price increase from previously bought: 23.877638266766986%
# Share price: $0.7610598609243047
# Shares owned at the moment: 0
# Cash capital at the moment: $94.5847282381336
#
#
# Share price: $0.7003509961295409
# Shares owned at the moment: 134
# Cash capital at the moment: $0.4796154147013709
#
#
# Price increase from previously bought: 3.3477813223602437%
# Share price: $0.7257876583128442
# Shares owned at the moment: 0
# Cash capital at the moment: $97.4677088765342
#
#
# Share price: $0.7444411847050891
# Shares owned at the moment: 130
# Cash capital at the moment: $0.42421714134054866
#
#
# Price increase from previously bought: -1.3192132874917162%
# Share price: $0.7366406238275158
# Shares owned at the moment: 0
# Cash capital at the moment: $95.92414921589928
#
#
# Share price: $0.7386756033780997
# Shares owned at the moment: 129
# Cash capital at the moment: $0.37295120982604146
#
#
#
#
# Capital at the end of test period: $89.02997431251588
# profit gained: -10.970025687484124%
#
#
# Capital at the end of test period if Buy and Hold: $68.09965200824497
# profit gained: -31.90034799175503%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.237209      7.079646       8.064516      95.000000
# 1       0.167442      7.377049       8.823529      84.000000
# 2       0.291080      7.272727      13.207547      94.000000
# 3       0.237443      6.603774      10.294118      84.444444
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         45.132743           56.451613          82.051282     -88.003716
# 1         48.360656           53.731343          80.000000     -15.404043
# 2         50.909091           54.716981          79.591837     -67.974745
# 3         47.619048           54.411765          80.000000     -10.970026
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
# 2         -84.289887
# 3         -31.900348
#
#
# AXL
#
#
# Non-Recession Test
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9951 - accuracy: 0.2661 - mse: 7.0002 - weighted_accuracy: 0.2661 - weighted_mse: 7.0002
# Test loss: 0.9950855374336243
# Test accuracy: 0.26605504751205444
#
#
# number of predictions: 218
# actual predicted buys: 7
# actual buys but predicted sell: 1
# actual buys but predicted hold: 0
# actual sells but predicted buy: 0
# actual predicted sells: 5
# actual sells but predicted hold: 3
# actual holds but predicted buy: 95
# actual holds but predicted sell: 61
# actual predicted holds: 46
# Percentage buys correct: 6.862745098039215%
# Percentage sells correct: 7.462686567164179%
# Percentage holds correct: 93.87755102040816%
# actual buys: 8
# actual sells: 8
# actual holds: 202
#
#
# Percentage low buys correct: 47.05882352941177%
# Percentage high sells correct: 50.74626865671642%
# Percentage mid holds correct: 87.5%
#
#
# Capital: 100
# Share price: $0.7426007274823263
# Shares owned at the moment: 134
# Cash capital at the moment: $0.21785414929102842
#
#
# Price increase from previously bought: 8.211267978658032%
# Share price: $0.8057875018012395
# Shares owned at the moment: 0
# Cash capital at the moment: $107.89644669624336
#
#
# Share price: $0.9642124545323547
# Shares owned at the moment: 111
# Cash capital at the moment: $0.5745383914059801
#
#
# Price increase from previously bought: -22.43720960860307%
# Share price: $0.7499267277705246
# Shares owned at the moment: 0
# Cash capital at the moment: $83.58749004028226
#
#
# Share price: $0.7719047286351195
# Shares owned at the moment: 107
# Cash capital at the moment: $0.7665511099235829
#
#
# Price increase from previously bought: -10.448890802219935%
# Share price: $0.6931501818705816
# Shares owned at the moment: 0
# Cash capital at the moment: $74.72966112906039
#
#
# Share price: $0.6986446384203246
# Shares owned at the moment: 106
# Cash capital at the moment: $0.46967454440645895
#
#
# Price increase from previously bought: 8.35300038937894%
# Share price: $0.7590841844643663
# Shares owned at the moment: 0
# Cash capital at the moment: $80.71132505785793
#
#
# Share price: $0.8799633638852624
# Shares owned at the moment: 91
# Cash capital at the moment: $0.4144481124867525
#
#
# Price increase from previously bought: 1.1786893543621169%
# Share price: $0.8927838207232035
# Shares owned at the moment: 0
# Cash capital at the moment: $81.43435664716229
#
#
# Share price: $0.8735530481334799
# Shares owned at the moment: 92
# Cash capital at the moment: $0.8464672977043648
#
#
# Price increase from previously bought: -41.46422572660977%
# Share price: $0.5127472282748715
# Shares owned at the moment: 0
# Cash capital at the moment: $47.889487250239
#
#
# Share price: $0.4990109995677028
# Shares owned at the moment: 95
# Cash capital at the moment: $0.3530756676701685
#
#
# Price increase from previously bought: 7.412171114957378%
# Share price: $0.53747254474715
# Shares owned at the moment: 0
# Cash capital at the moment: $51.27255271633422
#
#
# Share price: $0.5530402298599622
# Shares owned at the moment: 92
# Cash capital at the moment: $0.25293239106312626
#
#
# Price increase from previously bought: 2.5329782515115085%
# Share price: $0.5686080023055864
# Shares owned at the moment: 0
# Cash capital at the moment: $52.42101077859376
#
#
# Share price: $0.49992668410411834
# Shares owned at the moment: 104
# Cash capital at the moment: $0.2856566001116718
#
#
# Price increase from previously bought: 6.119375156662077%
# Share price: $0.5319780008645951
# Shares owned at the moment: 0
# Cash capital at the moment: $55.45922298178229
#
#
# Share price: $0.5292307725897236
# Shares owned at the moment: 104
# Cash capital at the moment: $0.2678626314903667
#
#
# Price increase from previously bought: 11.114697569847575%
# Share price: $0.5896703186337657
# Shares owned at the moment: 0
# Cash capital at the moment: $61.42493005827274
#
#
# Share price: $0.2325274115864442
# Shares owned at the moment: 263
# Cash capital at the moment: $0.10204536060802383
#
#
# Price increase from previously bought: -74.50300393894513%
# Share price: $0.05945054561174445
# Shares owned at the moment: 0
# Cash capital at the moment: $15.69454124938312
#
#
# Share price: $0.0420512730940703
# Shares owned at the moment: 372
# Cash capital at the moment: $0.00844920601373289
#
#
# Price increase from previously bought: 286.39385565368866%
# Share price: $0.16293036518215442
# Shares owned at the moment: 0
# Cash capital at the moment: $60.45186729019383
#
#
# Share price: $0.19956041028955207
# Shares owned at the moment: 302
# Cash capital at the moment: $0.018888462003637585
#
#
# Price increase from previously bought: 6.132528117401326%
# Share price: $0.21238095446030514
# Shares owned at the moment: 0
# Cash capital at the moment: $63.98155432633651
#
#
# Share price: $0.08326004654838902
# Shares owned at the moment: 766
# Cash capital at the moment: $0.028971382216333552
#
#
# Price increase from previously bought: 115.99206180423485%
# Share price: $0.18032963769982846
# Shares owned at the moment: 0
# Cash capital at the moment: $137.78160947847024
#
#
# Share price: $0.2682417284910201
# Shares owned at the moment: 512
# Cash capital at the moment: $0.0641601373525873
#
#
# Price increase from previously bought: 75.30653524530628%
# Share price: $0.47153845482055323
# Shares owned at the moment: 0
# Cash capital at the moment: $240.8279228610885
#
#
# Share price: $0.3918681361867874
# Shares owned at the moment: 612
# Cash capital at the moment: $0.345109441572248
#
#
# Price increase from previously bought: -4.2360577311416625%
# Share price: $0.37630036374116316
# Shares owned at the moment: 0
# Cash capital at the moment: $230.0076185389877
#
#
# Share price: $0.32868127453506213
# Shares owned at the moment: 697
# Cash capital at the moment: $0.2867703550843146
#
#
# Price increase from previously bought: 14.451800347681898%
# Share price: $0.377216135610391
# Shares owned at the moment: 0
# Cash capital at the moment: $262.4833878475956
#
#
#
#
# Capital at the end of test period: $262.4833878475956
# profit gained: 162.48338784759562%
#
#
# Capital at the end of test period if Buy and Hold: $59.80379974835048
# profit gained: -40.19620025164952%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.256881      6.930693       6.060606      88.235294
# 1       0.178899      7.619048       5.952381      89.655172
# 2       0.194313      5.217391       9.090909      96.666667
# 3       0.155963     11.111111       2.857143      91.304348
# 4       0.266055      6.862745       7.462687      93.877551
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         49.504950           43.939394          82.000000     -82.937820
# 1         57.142857           55.421687          86.206897     -56.427400
# 2         53.043478           66.153846          96.666667    2286.027531
# 3         50.000000           48.076923          86.956522     732.057765
# 4         47.058824           50.746269          87.500000     162.483388
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# 2         -54.689601
# 3        1576.179166
# 4         -40.196200
# Recession Test
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9719 - accuracy: 0.2283 - mse: 6.6838 - weighted_accuracy: 0.2283 - weighted_mse: 6.6838
# Test loss: 0.971863329410553
# Test accuracy: 0.2283104956150055
#
#
# number of predictions: 219
# actual predicted buys: 11
# actual buys but predicted sell: 0
# actual buys but predicted hold: 0
# actual sells but predicted buy: 2
# actual predicted sells: 7
# actual sells but predicted hold: 2
# actual holds but predicted buy: 88
# actual holds but predicted sell: 77
# actual predicted holds: 32
# Percentage buys correct: 10.891089108910892%
# Percentage sells correct: 8.333333333333334%
# Percentage holds correct: 94.11764705882354%
# actual buys: 11
# actual sells: 11
# actual holds: 197
#
#
# Percentage low buys correct: 59.0%
# Percentage high sells correct: 57.142857142857146%
# Percentage mid holds correct: 85.29411764705883%
#
#
# Capital: 100
# Share price: $0.7376316242287357
# Shares owned at the moment: 135
# Cash capital at the moment: $0.1458849886257525
#
#
# Price increase from previously bought: -72.67593180550986%
# Share price: $0.20210523319046308
# Shares owned at the moment: 0
# Cash capital at the moment: $27.35505990151631
#
#
# Share price: $0.07447368425180377
# Shares owned at the moment: 366
# Cash capital at the moment: $0.022733702156685354
#
#
# Price increase from previously bought: 75.4891466180351%
# Share price: $0.13105263933910882
# Shares owned at the moment: 0
# Cash capital at the moment: $47.8560952187757
#
#
# Share price: $0.08499998980446886
# Shares owned at the moment: 561
# Cash capital at the moment: $0.03996720419782207
#
#
# Price increase from previously bought: 155.6437800719888%
# Share price: $0.21789475426119093
# Shares owned at the moment: 0
# Cash capital at the moment: $121.94276721258949
#
#
# Share price: $0.17052631653246791
# Shares owned at the moment: 713
# Cash capital at the moment: $0.023144049798816013
#
#
# Price increase from previously bought: 127.46088756952356%
# Share price: $0.38894734497545874
# Shares owned at the moment: 0
# Cash capital at the moment: $276.5799725106403
#
#
# Share price: $0.6415789292063412
# Shares owned at the moment: 429
# Cash capital at the moment: $0.5857091393887117
#
#
# Price increase from previously bought: 17.519313557360583%
# Share price: $0.7560525962041695
# Shares owned at the moment: 0
# Cash capital at the moment: $324.04031986060556
#
#
# Share price: $0.5863157623131194
# Shares owned at the moment: 551
# Cash capital at the moment: $0.09191986723175205
#
#
# Price increase from previously bought: 8.006391215330888%
# Share price: $0.6349999568650604
# Shares owned at the moment: 0
# Cash capital at the moment: $349.01471241524024
#
#
# Share price: $0.581052609536787
# Shares owned at the moment: 599
# Cash capital at the moment: $0.007060391645381969
#
#
# Price increase from previously bought: 1.5323784690615572%
# Share price: $0.5915789150894519
# Shares owned at the moment: 0
# Cash capital at the moment: $353.388352162346
#
#
# Share price: $0.6678946930880041
# Shares owned at the moment: 527
# Cash capital at the moment: $0.4399025210100831
#
#
# Price increase from previously bought: -3.0247566438532436%
# Share price: $0.6494736583708398
# Shares owned at the moment: 0
# Cash capital at the moment: $341.7712707830487
#
#
# Share price: $0.6113157693715641
# Shares owned at the moment: 557
# Cash capital at the moment: $0.3320043133525701
#
#
# Price increase from previously bought: -2.850026981255327%
# Share price: $0.5955263110425664
# Shares owned at the moment: 0
# Cash capital at the moment: $331.12796213712255
#
#
# Share price: $0.5850000054899009
# Shares owned at the moment: 564
# Cash capital at the moment: $0.28062403230359223
#
#
# Price increase from previously bought: 7.127798787202977%
# Share price: $0.6284210472655098
# Shares owned at the moment: 0
# Cash capital at the moment: $353.73541364574237
#
#
# Share price: $0.5547368456551243
# Shares owned at the moment: 635
# Cash capital at the moment: $0.508807438013207
#
#
# Price increase from previously bought: 6.112364955496119%
# Share price: $0.5902631582662341
# Shares owned at the moment: 0
# Cash capital at the moment: $374.2951658969494
#
#
# Share price: $0.6113157693715641
# Shares owned at the moment: 610
# Cash capital at the moment: $0.367064377174529
#
#
# Price increase from previously bought: 3.160129052377658%
# Share price: $0.6323683804768943
# Shares owned at the moment: 0
# Cash capital at the moment: $385.05097850983003
#
#
# Share price: $0.6744736654292847
# Shares owned at the moment: 569
# Cash capital at the moment: $0.22008021258653798
#
#
# Price increase from previously bought: -43.269548695989776%
# Share price: $0.38368419219912614
# Shares owned at the moment: 0
# Cash capital at the moment: $217.9360157341457
#
#
# Share price: $0.525789442643565
# Shares owned at the moment: 413
# Cash capital at the moment: $0.18781056287093634
#
#
# Price increase from previously bought: 17.19523847587119%
# Share price: $0.6178947417128444
# Shares owned at the moment: 0
# Cash capital at the moment: $254.6765649373753
#
#
# Share price: $0.5034210119732866
# Shares owned at the moment: 504
# Cash capital at the moment: $0.25463338024388804
#
#
# Price increase from previously bought: 7.54534307490049%
# Share price: $0.542894720537511
# Shares owned at the moment: 0
# Cash capital at the moment: $273.1211204484844
#
#
# Share price: $0.7376316242287357
# Shares owned at the moment: 369
# Cash capital at the moment: $0.1865394173947834
#
#
# Price increase from previously bought: 7.375059595943578%
# Share price: $0.7942104852034455
# Shares owned at the moment: 0
# Cash capital at the moment: $292.444283367606
#
#
# Share price: $0.7389473183102233
# Shares owned at the moment: 394
# Cash capital at the moment: $0.4983905339888679
#
#
# Price increase from previously bought: -0.9845425758060689%
# Share price: $0.7336841655338908
# Shares owned at the moment: 0
# Cash capital at the moment: $288.7750049609859
#
#
# Share price: $0.6836842141587314
# Shares owned at the moment: 421
# Cash capital at the moment: $0.15241540121769503
#
#
#
#
# Capital at the end of test period: $268.40950963994413
# profit gained: 168.40950963994413%
#
#
# Capital at the end of test period if Buy and Hold: $67.49022981476901
# profit gained: -32.50977018523099%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.237209      7.079646       8.064516      95.000000
# 1       0.167442      7.377049       8.823529      84.000000
# 2       0.291080      7.272727      13.207547      94.000000
# 3       0.237443      6.603774      10.294118      84.444444
# 4       0.228310     10.891089       8.333333      94.117647
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         45.132743           56.451613          82.051282     -88.003716
# 1         48.360656           53.731343          80.000000     -15.404043
# 2         50.909091           54.716981          79.591837     -67.974745
# 3         47.619048           54.411765          80.000000     -10.970026
# 4         59.000000           57.142857          85.294118     168.409510
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
# 2         -84.289887
# 3         -31.900348
# 4         -32.509770

# %%
df = nr_log_hist['0_epochs_logs']
df['Profit gained']
# Out:
# 0     -84.632709
# 1     -77.053703
# 2     -69.300485
# 3    4767.406398
# 4      -9.044058
# Name: Profit gained, dtype: float64

# %%
C6LSI_acc = []
O39SI_acc = []
CNOOC_acc = []
JPM_acc = []
AXL_acc = []

C6LSI_correct_buys = []
O39SI_correct_buys = []
CNOOC_correct_buys = []
JPM_correct_buys = []
AXL_correct_buys = []

C6LSI_correct_sells = []
O39SI_correct_sells = []
CNOOC_correct_sells = []
JPM_correct_sells = []
AXL_correct_sells = []

C6LSI_correct_holds = []
O39SI_correct_holds = []
CNOOC_correct_holds = []
JPM_correct_holds = []
AXL_correct_holds = []

C6LSI_correct_low_buys = []
O39SI_correct_low_buys = []
CNOOC_correct_low_buys = []
JPM_correct_low_buys = []
AXL_correct_low_buys = []

C6LSI_correct_high_sells = []
O39SI_correct_high_sells = []
CNOOC_correct_high_sells = []
JPM_correct_high_sells = []
AXL_correct_high_sells = []

C6LSI_correct_mid_holds = []
O39SI_correct_mid_holds = []
CNOOC_correct_mid_holds = []
JPM_correct_mid_holds = []
AXL_correct_mid_holds = []

C6LSI_profit = []
O39SI_profit = []
CNOOC_profit = []
JPM_profit = []
AXL_profit = []

for key,value in nr_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    C6LSI_acc.append(acc[0])
    O39SI_acc.append(acc[1])
    CNOOC_acc.append(acc[2])
    JPM_acc.append(acc[3]) 
    AXL_acc.append(acc[4]) 

    C6LSI_correct_buys.append(correct_buys[0])
    O39SI_correct_buys.append(correct_buys[1]) 
    CNOOC_correct_buys.append(correct_buys[2]) 
    JPM_correct_buys.append(correct_buys[3]) 
    AXL_correct_buys.append(correct_buys[4])
    

    C6LSI_correct_sells.append(correct_sells[0]) 
    O39SI_correct_sells.append(correct_sells[1]) 
    CNOOC_correct_sells.append(correct_sells[2]) 
    JPM_correct_sells.append(correct_sells[3]) 
    AXL_correct_sells.append(correct_sells[4]) 
    

    C6LSI_correct_holds.append(correct_holds[0]) 
    O39SI_correct_holds.append(correct_holds[1])  
    CNOOC_correct_holds.append(correct_holds[2])  
    JPM_correct_holds.append(correct_holds[3])  
    AXL_correct_holds.append(correct_holds[4])  
     

    C6LSI_correct_low_buys.append(correct_low_buys[0])  
    O39SI_correct_low_buys.append(correct_low_buys[1])  
    CNOOC_correct_low_buys.append(correct_low_buys[2])  
    JPM_correct_low_buys.append(correct_low_buys[3])   
    AXL_correct_low_buys.append(correct_low_buys[4])   
    

    C6LSI_correct_high_sells.append(correct_high_sells[0]) 
    O39SI_correct_high_sells.append(correct_high_sells[1]) 
    CNOOC_correct_high_sells.append(correct_high_sells[2]) 
    JPM_correct_high_sells.append(correct_high_sells[3]) 
    AXL_correct_high_sells.append(correct_high_sells[4]) 
    

    C6LSI_correct_mid_holds.append(correct_mid_holds[0])  
    O39SI_correct_mid_holds.append(correct_mid_holds[1])  
    CNOOC_correct_mid_holds.append(correct_mid_holds[2])   
    JPM_correct_mid_holds.append(correct_mid_holds[3])   
    AXL_correct_mid_holds.append(correct_mid_holds[4])   
    

    C6LSI_profit.append(profit[0]) 
    O39SI_profit.append(profit[1]) 
    CNOOC_profit.append(profit[2]) 
    JPM_profit.append(profit[3])  
    AXL_profit.append(profit[4])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(C6LSI_acc)
plt.plot(O39SI_acc)
plt.plot(CNOOC_acc)
plt.plot(JPM_acc)
plt.plot(AXL_acc)
plt.title('Non-Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['C6L.SI_acc','O39.SI_acc','CNOOC_acc','JPM_acc','AXL_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_low_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_low_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_high_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_high_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_mid_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_mid_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_profit")

plt.subplot(3, 4, 2)
plt.plot(O39SI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_profit")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_profit")

plt.subplot(3, 4, 4)
plt.plot(JPM_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_profit")

plt.subplot(3, 4, 5)
plt.plot(AXL_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_profit")
# Out:
# Text(0.5, 1.0, 'AXL_profit')

# %%
C6LSI_acc = []
O39SI_acc = []
CNOOC_acc = []
JPM_acc = []
AXL_acc = []

C6LSI_correct_buys = []
O39SI_correct_buys = []
CNOOC_correct_buys = []
JPM_correct_buys = []
AXL_correct_buys = []

C6LSI_correct_sells = []
O39SI_correct_sells = []
CNOOC_correct_sells = []
JPM_correct_sells = []
AXL_correct_sells = []

C6LSI_correct_holds = []
O39SI_correct_holds = []
CNOOC_correct_holds = []
JPM_correct_holds = []
AXL_correct_holds = []

C6LSI_correct_low_buys = []
O39SI_correct_low_buys = []
CNOOC_correct_low_buys = []
JPM_correct_low_buys = []
AXL_correct_low_buys = []

C6LSI_correct_high_sells = []
O39SI_correct_high_sells = []
CNOOC_correct_high_sells = []
JPM_correct_high_sells = []
AXL_correct_high_sells = []

C6LSI_correct_mid_holds = []
O39SI_correct_mid_holds = []
CNOOC_correct_mid_holds = []
JPM_correct_mid_holds = []
AXL_correct_mid_holds = []

C6LSI_profit = []
O39SI_profit = []
CNOOC_profit = []
JPM_profit = []
AXL_profit = []

for key,value in r_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    C6LSI_acc.append(acc[0])
    O39SI_acc.append(acc[1])
    CNOOC_acc.append(acc[2])
    JPM_acc.append(acc[3]) 
    AXL_acc.append(acc[4]) 

    C6LSI_correct_buys.append(correct_buys[0])
    O39SI_correct_buys.append(correct_buys[1]) 
    CNOOC_correct_buys.append(correct_buys[2]) 
    JPM_correct_buys.append(correct_buys[3]) 
    AXL_correct_buys.append(correct_buys[4])
    

    C6LSI_correct_sells.append(correct_sells[0]) 
    O39SI_correct_sells.append(correct_sells[1]) 
    CNOOC_correct_sells.append(correct_sells[2]) 
    JPM_correct_sells.append(correct_sells[3]) 
    AXL_correct_sells.append(correct_sells[4]) 
    

    C6LSI_correct_holds.append(correct_holds[0]) 
    O39SI_correct_holds.append(correct_holds[1])  
    CNOOC_correct_holds.append(correct_holds[2])  
    JPM_correct_holds.append(correct_holds[3])  
    AXL_correct_holds.append(correct_holds[4])  
     

    C6LSI_correct_low_buys.append(correct_low_buys[0])  
    O39SI_correct_low_buys.append(correct_low_buys[1])  
    CNOOC_correct_low_buys.append(correct_low_buys[2])  
    JPM_correct_low_buys.append(correct_low_buys[3])   
    AXL_correct_low_buys.append(correct_low_buys[4])   
    

    C6LSI_correct_high_sells.append(correct_high_sells[0]) 
    O39SI_correct_high_sells.append(correct_high_sells[1]) 
    CNOOC_correct_high_sells.append(correct_high_sells[2]) 
    JPM_correct_high_sells.append(correct_high_sells[3]) 
    AXL_correct_high_sells.append(correct_high_sells[4]) 
    

    C6LSI_correct_mid_holds.append(correct_mid_holds[0])  
    O39SI_correct_mid_holds.append(correct_mid_holds[1])  
    CNOOC_correct_mid_holds.append(correct_mid_holds[2])   
    JPM_correct_mid_holds.append(correct_mid_holds[3])   
    AXL_correct_mid_holds.append(correct_mid_holds[4])   
    

    C6LSI_profit.append(profit[0]) 
    O39SI_profit.append(profit[1]) 
    CNOOC_profit.append(profit[2]) 
    JPM_profit.append(profit[3])  
    AXL_profit.append(profit[4])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(C6LSI_acc)
plt.plot(O39SI_acc)
plt.plot(CNOOC_acc)
plt.plot(JPM_acc)
plt.plot(AXL_acc)
plt.title('Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['C6L.SI_acc','O39.SI_acc','CNOOC_acc','JPM_acc','AXL_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_low_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_low_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_high_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_high_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_mid_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_mid_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_profit")

plt.subplot(3, 4, 2)
plt.plot(O39SI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_profit")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_profit")

plt.subplot(3, 4, 4)
plt.plot(JPM_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_profit")

plt.subplot(3, 4, 5)
plt.plot(AXL_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_profit")
# Out:
# Text(0.5, 1.0, 'AXL_profit')
