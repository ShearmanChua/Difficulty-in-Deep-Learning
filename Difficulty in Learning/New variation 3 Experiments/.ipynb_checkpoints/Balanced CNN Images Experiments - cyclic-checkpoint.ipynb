# %%
import os
seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
experiment = 'Balanced CNN Images Experiments - cyclic'

# %%
import requests
import lxml
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.utils import compute_class_weight
import tensorflow as tf
from pil import Image
from sklearn import preprocessing
import tensorflow_addons as tfa
import glob
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
import math

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
# gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
np.random.seed(seed)
tf.random.set_seed(seed)

session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, 
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), 
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)

# %% [markdown]
# ## Prepare Test Data

# %%
nr_test_sets = ['C6L.SI','O39.SI','0883.HK','JPM','AXL']
nr_test_data = {}

for name in nr_test_sets:

    df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    willr_data = []
    price_data = []
    ema_data = []
    obv_data = []
    labels = []
    data_15_price = []
    data_15_willr = []
    data_15_ema = []
    data_15_obv = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
            data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
            data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
            data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
            price_data.append(data_15_price_arr)
            willr_data.append(data_15_willr_arr)
            ema_data.append(data_15_ema_arr)
            obv_data.append(data_15_obv_arr)
            labels.append(i[-1])
            data_15_price = data_15_price[1:]
            data_15_willr = data_15_willr[1:]
            data_15_obv = data_15_obv[1:]
            data_15_ema = data_15_ema[1:]

        else:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            count += 1

    willr_data = np.array(willr_data)
    price_data = np.array(price_data)
    ema_data = np.array(ema_data)
    obv_data = np.array(obv_data)
    
    sequential_data = []
    
    for i in range(0,len(willr_data)):
        j = willr_data[i]
        k = price_data[i]
        l = ema_data[i]
        m = obv_data[i]
        fig, ax = plt.subplots()
        fig.set_size_inches((5,5))

        ax.plot(k)
        ax.plot(j)
        ax.plot(l)
        ax.plot(m)

        ax.axis('off')

        fig.add_axes(ax)
        fig.canvas.draw()

        # this rasterized the figure
        X = np.array(fig.canvas.renderer._renderer)
        X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
        X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
        sequential_data.append(X)
        plt.close()
        
    X = sequential_data
    y = labels

    X  = np.array(X).reshape(-1, 64, 64, 1)
    X = X/255
    y = np.array(y)
    
    y = to_categorical(y, 3)
    
    nr_test_data['{}_X'.format(name)] = X
    nr_test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2019-01-21         9.59  9.538960 -32.758553  6890900.0     2.0
# 2019-01-22         9.63  9.552966 -25.862007  7759500.0     2.0
# 2019-01-23         9.61  9.561740 -29.310362  7108100.0     1.0
# 2019-01-24         9.50  9.552242 -48.275822  6126400.0     2.0
# 2019-01-25         9.74  9.581128  -8.888884  8160300.0     2.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-21        11.75  11.523654 -10.869606  21160951.0     2.0
# 2019-01-22        11.73  11.555399 -13.978517  18040951.0     2.0
# 2019-01-23        11.50  11.546876 -38.709667  14286851.0     1.0
# 2019-01-24        11.38  11.521203 -51.612890   8454651.0     2.0
# 2019-01-25        11.41  11.504095 -80.357185  12469051.0     2.0
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2019-01-22        13.12  12.552209  -3.030323  489168111.0     2.0
# 2019-01-23        12.94  12.611869 -13.043517  449876554.0     2.0
# 2019-01-24        12.62  12.613120 -33.333352  395082483.0     2.0
# 2019-01-25        12.80  12.641871 -37.254896  441807090.0     2.0
# 2019-01-28        13.06  12.706198 -11.764689  494043477.0     2.0
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22   104.589996  101.198442  -3.459880  84335200.0     2.0
# 2019-01-23   102.940002  101.466374 -21.874992  67251500.0     2.0
# 2019-01-24   102.680000  101.653086 -27.040213  55104800.0     2.0
# 2019-01-25   102.739998  101.820303 -32.628441  66401600.0     2.0
# 2019-01-28   103.389999  102.061795 -23.968276  80771000.0     2.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22        14.61  13.028180  -0.258404  23356600.0     2.0
# 2019-01-23        14.52  13.257691  -3.886001  21174700.0     2.0
# 2019-01-24        14.18  13.399585 -13.535906  19629300.0     2.0
# 2019-01-25        14.38  13.550418  -8.579880  20903300.0     2.0
# 2019-01-28        14.71  13.728815  -4.790414  22287500.0     2.0

# %%
r_test_sets = ['C6L.SI','O39.SI','0883.HK','JPM','AXL']
r_test_data = {}

for name in r_test_sets:

    df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test2.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    willr_data = []
    price_data = []
    ema_data = []
    obv_data = []
    labels = []
    data_15_price = []
    data_15_willr = []
    data_15_ema = []
    data_15_obv = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
            data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
            data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
            data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
            price_data.append(data_15_price_arr)
            willr_data.append(data_15_willr_arr)
            ema_data.append(data_15_ema_arr)
            obv_data.append(data_15_obv_arr)
            labels.append(i[-1])
            data_15_price = data_15_price[1:]
            data_15_willr = data_15_willr[1:]
            data_15_obv = data_15_obv[1:]
            data_15_ema = data_15_ema[1:]

        else:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            count += 1

    willr_data = np.array(willr_data)
    price_data = np.array(price_data)
    ema_data = np.array(ema_data)
    obv_data = np.array(obv_data)
    
    sequential_data = []
    
    for i in range(0,len(willr_data)):
        j = willr_data[i]
        k = price_data[i]
        l = ema_data[i]
        m = obv_data[i]
        fig, ax = plt.subplots()
        fig.set_size_inches((5,5))

        ax.plot(k)
        ax.plot(j)
        ax.plot(l)
        ax.plot(m)

        ax.axis('off')

        fig.add_axes(ax)
        fig.canvas.draw()

        # this rasterized the figure
        X = np.array(fig.canvas.renderer._renderer)
        X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
        X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
        sequential_data.append(X)
        plt.close()
        
    X = sequential_data
    y = labels

    X  = np.array(X).reshape(-1, 64, 64, 1)
    X = X/255
    y = np.array(y)
    
    y = to_categorical(y, 3)
    
    r_test_data['{}_X'.format(name)] = X
    r_test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2020-01-22         8.84  8.979182 -96.551645  -851200.0     2.0
# 2020-01-23         8.93  8.971615 -65.517105  1644900.0     2.0
# 2020-01-24         8.85  8.952905 -92.307523  -246900.0     2.0
# 2020-01-28         8.82  8.932458 -75.000000 -1718200.0     2.0
# 2020-01-29         8.56  8.875157 -86.885115 -5499900.0     2.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22        11.12  11.072811 -24.444379  27489400.0     2.0
# 2020-01-23        11.19  11.090840  -8.888884  31751200.0     2.0
# 2020-01-24        11.11  11.093787 -26.666653  27359800.0     2.0
# 2020-01-28        11.10  11.094743 -28.888715  24699300.0     2.0
# 2020-01-29        10.90  11.064783 -71.739257  16499235.0     2.0
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2020-01-22        13.00  13.393678 -83.870980  104646165.0     2.0
# 2020-01-23        13.34  13.385420 -57.377021  145802714.0     2.0
# 2020-01-24        13.00  13.326125 -85.245880   96260120.0     2.0
# 2020-01-29        13.04  13.282106 -80.645176  122828433.0     2.0
# 2020-01-30        12.46  13.155628 -90.804605   53693706.0     2.0
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22   136.839996  137.690058 -77.454723  33776700.0     2.0
# 2020-01-23   136.679993  137.534664 -80.363881  26227600.0     2.0
# 2020-01-24   136.539993  137.381637 -69.867648  16881900.0     2.0
# 2020-01-27   133.149994  136.730615 -90.166021   1715500.0     1.0
# 2020-01-28   132.029999  136.007444 -79.004573 -11145000.0     2.0
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2020-01-22         9.39  9.715390 -73.059349 -3592400.0     2.0
# 2020-01-23         9.34  9.657637 -75.342463 -4550300.0     2.0
# 2020-01-24         9.50  9.633386 -65.000010 -3092000.0     2.0
# 2020-01-27         9.31  9.583634 -66.883101 -4332600.0     2.0
# 2020-01-28         9.39  9.553844 -61.688301 -2300800.0     2.0

# %% [markdown]
# ## Train Stock Data

# %%
def pred_acc(actual, predictions, logger):

    hold = 0
    sell = 0
    buy = 0
    pred_hold = 0
    pred_sell = 0
    pred_buy = 0
    buy_buy = 0
    buy_sell = 0
    buy_hold = 0
    sell_buy = 0
    sell_sell = 0
    sell_hold = 0
    hold_buy = 0
    hold_sell = 0
    hold_hold = 0

    for i in range (0,len(actual)):
        if actual[i]==1 and predictions[i] == 1:
            buy_buy += 1
            buy += 1
            pred_buy += 1
        elif actual[i]==1 and predictions[i] == 0:
            buy_sell += 1
            buy += 1
            pred_sell += 1
        elif actual[i]==1 and predictions[i] == 2:
            buy_hold += 1
            buy += 1
            pred_hold += 1
        elif actual[i]==0 and predictions[i] == 1:
            sell_buy += 1
            sell += 1
            pred_buy += 1
        elif actual[i]==0 and predictions[i] == 0:
            sell_sell += 1
            sell += 1
            pred_sell += 1
        elif actual[i]==0 and predictions[i] == 2:
            sell_hold += 1
            sell += 1
            pred_hold += 1
        elif actual[i]==2 and predictions[i] == 1:
            hold_buy += 1
            hold += 1
            pred_buy += 1
        elif actual[i]==2 and predictions[i] == 0:
            hold_sell += 1
            hold += 1
            pred_sell += 1
        elif actual[i]==2 and predictions[i] == 2:
            hold_hold += 1
            hold += 1
            pred_hold += 1

    print("number of predictions: " + str(len(actual)))
    print("actual predicted buys: " + str(buy_buy) )
    print("actual buys but predicted sell: " + str(buy_sell) )
    print("actual buys but predicted hold: " + str(buy_hold))
    print("actual sells but predicted buy: " + str(sell_buy) )
    print("actual predicted sells: " + str(sell_sell))
    print("actual sells but predicted hold: " + str(sell_hold) )
    print("actual holds but predicted buy: " + str(hold_buy) )
    print("actual holds but predicted sell: " + str(hold_sell))
    print("actual predicted holds: " + str(hold_hold) )
    
    if pred_buy !=0:
        Percentage_buys_correct = 100*buy_buy/pred_buy
    else:
        Percentage_buys_correct = 0
        
    if pred_sell !=0:
        Percentage_sells_correct = 100*sell_sell/pred_sell
    else:
        Percentage_sells_correct = 0
        
    if pred_hold !=0:
        Percentage_holds_correct = 100*hold_hold/pred_hold
    else:
        Percentage_holds_correct = 0

    print("Percentage buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage holds correct: " + str(Percentage_holds_correct) + "%")

    print("actual buys: " + str(buy))
    print("actual sells: " + str(sell))
    print("actual holds: " + str(hold))
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def correct_maxima_minima(predictions, price, logger):
    correct_maxima = 0 
    correct_minima = 0
    correct_hold = 0

    hold = 0
    buy = 0
    sell = 0

#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):
        if i < 4:
            prices = price[i:i+9]
            prices.sort(key = float)
#             if i == 0:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1

        else:
            prices = price[i:i+5]
            prices = prices + price[i-4:i] 
            prices.sort(key = float)
#             if i == 10:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1
                    
    if buy !=0:
        Percentage_buys_correct = 100*correct_minima/buy
    else:
        Percentage_buys_correct = 0
        
    if sell !=0:
        Percentage_sells_correct = 100*correct_maxima/sell
    else:
        Percentage_sells_correct = 0
        
    if hold !=0:
        Percentage_holds_correct = 100*correct_hold/hold
    else:
        Percentage_holds_correct = 0

    print("Percentage low buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage high sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage mid holds correct: " + str(Percentage_holds_correct) + "%")
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %% [markdown]
# ### Creating Training Data and Model

# %%
sequential_data = []
labels = []

train_sets = ['C6L.SI','O39.SI','600104.SS','0883.HK','1398.HK','ANF','AXL','JPM','CTB','TROX']

for name in train_sets:
    seed = 10
    df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    plt.figure(figsize=(15,5))
    plt.plot(df['previous_1d'].values)
    plt.plot(df['EMA_12'].values)
    plt.show()

    willr_data = []
    price_data = []
    ema_data = []
    obv_data = []
    data_15_price = []
    data_15_willr = []
    data_15_ema = []
    data_15_obv = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
            data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
            data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
            data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
            price_data.append(data_15_price_arr)
            willr_data.append(data_15_willr_arr)
            ema_data.append(data_15_ema_arr)
            obv_data.append(data_15_obv_arr)
            labels.append(i[-1])
            data_15_price = data_15_price[1:]
            data_15_willr = data_15_willr[1:]
            data_15_obv = data_15_obv[1:]
            data_15_ema = data_15_ema[1:]

        else:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            count += 1
            
    willr_data = np.array(willr_data)
    price_data = np.array(price_data)
    ema_data = np.array(ema_data)
    obv_data = np.array(obv_data)
        
    for i in range(0,len(willr_data)):
        j = willr_data[i]
        k = price_data[i]
        l = ema_data[i]
        m = obv_data[i]
        fig, ax = plt.subplots()
        fig.set_size_inches((5,5))

        ax.plot(k)
        ax.plot(j)
        ax.plot(l)
        ax.plot(m)

        ax.axis('off')

        fig.add_axes(ax)
        fig.canvas.draw()

        # this rasterized the figure
        X = np.array(fig.canvas.renderer._renderer)
        X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
        X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
        sequential_data.append(X)
        plt.close()
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels
# Date
# 2000-01-21    19.000000  19.215335 -37.499990   388000.0     2.0
# 2000-01-24    18.400000  19.089899 -50.000000 -2311000.0     2.0
# 2000-01-25    18.100000  18.937607 -48.780483 -3542000.0     2.0
# 2000-01-26    17.700001  18.747206 -85.714237 -6261000.0     2.0
# 2000-01-27    17.799999  18.601482 -82.142864 -4565000.0     2.0
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2000-01-21     6.793788  7.018572 -90.000010 -1965914.0     2.0
# 2000-01-24     6.890842  6.998922 -77.777802  6276910.0     2.0
# 2000-01-25     6.793788  6.967363 -85.714286  -511055.0     2.0
# 2000-01-26     6.745261  6.933193 -86.666549 -7435027.0     2.0
# 2000-01-27     6.890842  6.926678 -66.666601 -3725757.0     2.0
#             previous_1d    EMA_12   willr_14        OBV_7  labels
# Date
# 2000-01-24     3.189194  3.249583 -69.696967   61394527.0     2.0
# 2000-01-25     3.205140  3.242745 -79.136806   75032521.0     2.0
# 2000-01-26     3.402870  3.267380 -34.532549  127274101.0     2.0
# 2000-01-27     3.284870  3.270071 -62.500055   91746305.0     2.0
# 2000-01-28     3.252978  3.267441 -69.852957   65314909.0     2.0
#             previous_1d    EMA_12   willr_14       OBV_7  labels
# Date
# 2004-04-07        3.250  3.264699 -57.142857  31539206.0     2.0
# 2004-04-08        3.200  3.254745 -78.947368 -24878594.0     2.0
# 2004-04-13        3.250  3.254015 -52.631579  10937473.0     0.0
# 2004-04-14        3.375  3.272628 -10.416706  98972973.0     2.0
# 2004-04-15        3.275  3.272993 -52.083331  47190715.0     2.0
#             previous_1d    EMA_12   willr_14         OBV_7  labels
# Date
# 2006-11-17     3.953848  3.652647 -15.942120  1.897904e+10     2.0
# 2006-11-20     3.934226  3.695967 -18.840636  1.837444e+10     2.0
# 2006-11-21     3.934226  3.732622 -19.403036  1.837444e+10     2.0
# 2006-11-22     3.934226  3.763638 -19.697025  1.837444e+10     0.0
# 2006-11-23     4.051959  3.807995  -1.562480  1.907354e+10     2.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2000-01-21      21.5000  24.211693 -82.142857  -6805500.0     2.0
# 2000-01-24      20.2500  23.602201 -92.465753  -8986800.0     1.0
# 2000-01-25      20.1875  23.076863 -92.307692 -11383100.0     2.0
# 2000-01-26      20.8750  22.738115 -82.786885  -9392500.0     2.0
# 2000-01-27      22.8750  22.759174 -56.557377  -6811000.0     2.0
#             previous_1d     EMA_12   willr_14     OBV_7  labels
# Date
# 2000-01-21      16.0625  14.895987 -18.478261  298700.0     2.0
# 2000-01-24      15.8750  15.046605 -22.222222  293100.0     2.0
# 2000-01-25      15.7500  15.154819 -26.190476  286300.0     2.0
# 2000-01-26      15.7500  15.246386 -29.729730  286300.0     2.0
# 2000-01-27      16.0000  15.362326 -25.000000  311700.0     0.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2000-01-21    49.375000  48.388499 -42.592593  -2894250.0     2.0
# 2000-01-24    48.625000  48.424884 -39.516144  -8054850.0     2.0
# 2000-01-25    48.666668  48.462081 -38.709668  -1595700.0     2.0
# 2000-01-26    49.750000  48.660222 -17.741956   5984250.0     2.0
# 2000-01-27    52.291668  49.218906  -5.232557  14370900.0     2.0
#             previous_1d     EMA_12    willr_14     OBV_7  labels
# Date
# 2000-01-21      13.7500  14.817184  -97.297297 -827200.0     2.0
# 2000-01-24      14.0625  14.701079  -77.500000 -518900.0     2.0
# 2000-01-25      13.6875  14.545144  -92.500000 -906100.0     2.0
# 2000-01-26      13.7500  14.422814  -90.000000 -652700.0     2.0
# 2000-01-27      13.5000  14.280843 -100.000000 -848400.0     2.0
#             previous_1d     EMA_12  willr_14      OBV_7  labels
# Date
# 2010-12-21    18.799999  18.175961      -0.0  1579000.0     0.0
# 2010-12-22    19.000000  18.302736      -0.0  1699000.0     2.0
# 2010-12-23    19.000000  18.410008      -0.0  1699000.0     2.0
# 2010-12-27    19.000000  18.500776      -0.0  1699000.0     2.0
# 2010-12-28    19.000000  18.577580      -0.0  1699000.0     2.0

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
y = np.array(y)

X.shape
# Out:
# (41550, 64, 64, 1)

# %%
from collections import Counter

Counter(y)
# Out:
# Counter({2.0: 37853, 0.0: 1852, 1.0: 1845})

# %%
X = sequential_data
y = labels

class_0 = []
class_1 = []
class_2 = []

class_0_labels = []
class_1_labels = []
class_2_labels = []

for i in range (0,len(y)):
    if y[i] == 0:
        class_0.append(X[i])
        class_0_labels.append(y[i])
    if y[i] == 1:
        class_1.append(X[i])
        class_1_labels.append(y[i])
    if y[i] == 2:
        class_2.append(X[i])
        class_2_labels.append(y[i])
        
class_0 = class_0[0:1845]
class_1 = class_1[0:1845]
class_2 = class_2[0:1845]

class_0_labels = class_0_labels[0:1845]
class_1_labels = class_1_labels[0:1845]
class_2_labels = class_2_labels[0:1845]

X = class_0 + class_1 + class_2
y = class_0_labels + class_1_labels + class_2_labels

X  = np.array(X).reshape(-1, 64, 64, 1)
y = np.array(y)

print(X.shape)

Counter(y)
# Out:
# (5535, 64, 64, 1)
# Counter({0.0: 1845, 1.0: 1845, 2.0: 1845})

# %%
# plot the image array X
i = X[0].reshape(64, 64)
fig2, ax2 = plt.subplots()
plt.imshow(i, interpolation="none", cmap="gray")

ax2.axis('off')

plt.show()

# %%
X = X/255

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten,BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.regularizers import l2
import efficientnet.tfkeras as efn
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(Conv2D(16, (3, 3), padding='same', kernel_initializer='he_uniform',kernel_regularizer=l2(1e-5), input_shape=X_train.shape[1:]))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))

model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_uniform',kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

# model.add(Dense(128, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))
# model.add(Dropout(0.25, seed=seed))

model.add(Dense(64, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))
model.add(Dropout(0.25, seed=seed))

model.add(Dense(32, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))
model.add(Dropout(0.25, seed=seed))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "DBS_CNN_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))
print(d_class_weights)

epochs = 0 
histories = {}
nr_log_hist = {}
r_log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    nr_log  = pd.DataFrame(columns = column_names)
    r_log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['C6L.SI','O39.SI','0883.HK','JPM','AXL']
    
    for name in test_sets:
        
        print('\n')
        print(name)
        print('\n')
        
        print('Non-Recession Test')
        print('\n')
        
        X = nr_test_data['{}_X'.format(name)]
        y = nr_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(nr_log)
        nr_log.loc[df_length] = logger
        print(nr_log.head(20))
        logger = []
        
        print('Recession Test')
        print('\n')
        
        X = r_test_data['{}_X'.format(name)]
        y = r_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test2.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(r_log)
        r_log.loc[df_length] = logger
        print(r_log.head(20))
        logger = []

    nr_log.to_csv('non_recession_{}_{}epochs.csv'.format(experiment,epochs))
    nr_log_hist['{}_epochs_logs'.format(epochs)] = nr_log
    r_log.to_csv('recession_{}_{}epochs.csv'.format(experiment,epochs))
    r_log_hist['{}_epochs_logs'.format(epochs)] = r_log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 1 ... 0 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# {0: 1.0, 1: 1.0, 2: 1.0}
#
#
#
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  1/35 [..............................] - ETA: 0s - loss: 0.4587 - accuracy: 0.3281 - mse: 6.0627 - weighted_accuracy: 0.3281 - weighted_mse: 6.0627WARNING:tensorflow:From C:\Users\Shearman Chua\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/35 [>.............................] - ETA: 2s - loss: 0.4044 - accuracy: 0.3477 - mse: 4.7710 - weighted_accuracy: 0.3477 - weighted_mse: 4.7710WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0110s vs `on_train_batch_end` time: 0.1147s). Check your callbacks.
# 35/35 [==============================] - 1s 29ms/step - loss: 0.2273 - accuracy: 0.3313 - mse: 1.5287 - weighted_accuracy: 0.3313 - weighted_mse: 1.5287 - val_loss: 0.1991 - val_accuracy: 0.3333 - val_mse: 0.9254 - val_weighted_accuracy: 0.3333 - val_weighted_mse: 0.9254
# Epoch 2/20
# 35/35 [==============================] - 1s 17ms/step - loss: 0.2037 - accuracy: 0.3358 - mse: 1.1697 - weighted_accuracy: 0.3358 - weighted_mse: 1.1697 - val_loss: 0.1968 - val_accuracy: 0.3333 - val_mse: 0.9617 - val_weighted_accuracy: 0.3333 - val_weighted_mse: 0.9617
# Epoch 3/20
# 35/35 [==============================] - 1s 19ms/step - loss: 0.2033 - accuracy: 0.3374 - mse: 1.1689 - weighted_accuracy: 0.3374 - weighted_mse: 1.1689 - val_loss: 0.1991 - val_accuracy: 0.3478 - val_mse: 0.8846 - val_weighted_accuracy: 0.3478 - val_weighted_mse: 0.8846
# Epoch 4/20
# 35/35 [==============================] - 1s 17ms/step - loss: 0.2013 - accuracy: 0.3500 - mse: 1.1762 - weighted_accuracy: 0.3500 - weighted_mse: 1.1762 - val_loss: 0.1972 - val_accuracy: 0.3966 - val_mse: 0.9072 - val_weighted_accuracy: 0.3966 - val_weighted_mse: 0.9072
# Epoch 5/20
# 35/35 [==============================] - 0s 13ms/step - loss: 0.1998 - accuracy: 0.3539 - mse: 1.1747 - weighted_accuracy: 0.3539 - weighted_mse: 1.1747 - val_loss: 0.1957 - val_accuracy: 0.3767 - val_mse: 0.9262 - val_weighted_accuracy: 0.3767 - val_weighted_mse: 0.9262
# Epoch 6/20
# 35/35 [==============================] - 1s 16ms/step - loss: 0.2000 - accuracy: 0.3462 - mse: 1.1811 - weighted_accuracy: 0.3462 - weighted_mse: 1.1811 - val_loss: 0.1935 - val_accuracy: 0.3957 - val_mse: 0.9744 - val_weighted_accuracy: 0.3957 - val_weighted_mse: 0.9744
# Epoch 7/20
# 35/35 [==============================] - 1s 17ms/step - loss: 0.1991 - accuracy: 0.3401 - mse: 1.1778 - weighted_accuracy: 0.3401 - weighted_mse: 1.1778 - val_loss: 0.1954 - val_accuracy: 0.4065 - val_mse: 0.8903 - val_weighted_accuracy: 0.4065 - val_weighted_mse: 0.8903
# Epoch 8/20
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1983 - accuracy: 0.3699 - mse: 1.1785 - weighted_accuracy: 0.3699 - weighted_mse: 1.1785 - val_loss: 0.1906 - val_accuracy: 0.3948 - val_mse: 1.0448 - val_weighted_accuracy: 0.3948 - val_weighted_mse: 1.0448
# Epoch 9/20
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1981 - accuracy: 0.3645 - mse: 1.1837 - weighted_accuracy: 0.3645 - weighted_mse: 1.1837 - val_loss: 0.1916 - val_accuracy: 0.4905 - val_mse: 0.9500 - val_weighted_accuracy: 0.4905 - val_weighted_mse: 0.9500
# Epoch 10/20
# 35/35 [==============================] - 0s 13ms/step - loss: 0.1968 - accuracy: 0.3821 - mse: 1.1910 - weighted_accuracy: 0.3821 - weighted_mse: 1.1910 - val_loss: 0.1908 - val_accuracy: 0.4408 - val_mse: 0.9866 - val_weighted_accuracy: 0.4408 - val_weighted_mse: 0.9866
# Epoch 11/20
# 35/35 [==============================] - 0s 13ms/step - loss: 0.1963 - accuracy: 0.3864 - mse: 1.1976 - weighted_accuracy: 0.3864 - weighted_mse: 1.1976 - val_loss: 0.1911 - val_accuracy: 0.4905 - val_mse: 0.9568 - val_weighted_accuracy: 0.4905 - val_weighted_mse: 0.9568
# Epoch 12/20
# 35/35 [==============================] - 0s 13ms/step - loss: 0.1946 - accuracy: 0.4070 - mse: 1.1903 - weighted_accuracy: 0.4070 - weighted_mse: 1.1903 - val_loss: 0.1911 - val_accuracy: 0.4941 - val_mse: 0.9145 - val_weighted_accuracy: 0.4941 - val_weighted_mse: 0.9145
# Epoch 13/20
# 35/35 [==============================] - 0s 12ms/step - loss: 0.1943 - accuracy: 0.4013 - mse: 1.2063 - weighted_accuracy: 0.4013 - weighted_mse: 1.2063 - val_loss: 0.1897 - val_accuracy: 0.5077 - val_mse: 0.9533 - val_weighted_accuracy: 0.5077 - val_weighted_mse: 0.9533
# Epoch 14/20
# 35/35 [==============================] - 0s 12ms/step - loss: 0.1932 - accuracy: 0.4232 - mse: 1.1995 - weighted_accuracy: 0.4232 - weighted_mse: 1.1995 - val_loss: 0.1857 - val_accuracy: 0.5077 - val_mse: 1.0323 - val_weighted_accuracy: 0.5077 - val_weighted_mse: 1.0323
# Epoch 15/20
# 35/35 [==============================] - 0s 12ms/step - loss: 0.1927 - accuracy: 0.4232 - mse: 1.2151 - weighted_accuracy: 0.4232 - weighted_mse: 1.2151 - val_loss: 0.1875 - val_accuracy: 0.5176 - val_mse: 0.9500 - val_weighted_accuracy: 0.5176 - val_weighted_mse: 0.9500
# Epoch 16/20
# 35/35 [==============================] - 0s 13ms/step - loss: 0.1916 - accuracy: 0.4381 - mse: 1.2065 - weighted_accuracy: 0.4381 - weighted_mse: 1.2065 - val_loss: 0.1854 - val_accuracy: 0.5230 - val_mse: 0.9766 - val_weighted_accuracy: 0.5230 - val_weighted_mse: 0.9766
# Epoch 17/20
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1897 - accuracy: 0.4485 - mse: 1.2241 - weighted_accuracy: 0.4485 - weighted_mse: 1.2241 - val_loss: 0.1843 - val_accuracy: 0.5212 - val_mse: 0.9777 - val_weighted_accuracy: 0.5212 - val_weighted_mse: 0.9777
# Epoch 18/20
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1897 - accuracy: 0.4553 - mse: 1.2325 - weighted_accuracy: 0.4553 - weighted_mse: 1.2325 - val_loss: 0.1829 - val_accuracy: 0.5194 - val_mse: 0.9793 - val_weighted_accuracy: 0.5194 - val_weighted_mse: 0.9793
# Epoch 19/20
# 35/35 [==============================] - 1s 16ms/step - loss: 0.1877 - accuracy: 0.4736 - mse: 1.2355 - weighted_accuracy: 0.4736 - weighted_mse: 1.2355 - val_loss: 0.1796 - val_accuracy: 0.5276 - val_mse: 1.0424 - val_weighted_accuracy: 0.5276 - val_weighted_mse: 1.0424
# Epoch 20/20
# 35/35 [==============================] - 0s 14ms/step - loss: 0.1859 - accuracy: 0.4826 - mse: 1.2486 - weighted_accuracy: 0.4826 - weighted_mse: 1.2486 - val_loss: 0.1799 - val_accuracy: 0.5348 - val_mse: 1.0181 - val_weighted_accuracy: 0.5348 - val_weighted_mse: 1.0181
# Validation loss: 0.17987783253192902
# Validation accuracy: 0.5347786545753479
#
#
# C6L.SI
#
#
# Non-Recession Test
#
#
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2002 - accuracy: 0.0780 - mse: 1.0920 - weighted_accuracy: 0.0780 - weighted_mse: 1.0920
# Test loss: 0.20024338364601135
# Test accuracy: 0.07798165082931519
#
#
# number of predictions: 218
# actual predicted buys: 8
# actual buys but predicted sell: 1
# actual buys but predicted hold: 0
# actual sells but predicted buy: 3
# actual predicted sells: 6
# actual sells but predicted hold: 0
# actual holds but predicted buy: 79
# actual holds but predicted sell: 118
# actual predicted holds: 3
# Percentage buys correct: 8.88888888888889%
# Percentage sells correct: 4.8%
# Percentage holds correct: 100.0%
# actual buys: 9
# actual sells: 9
# actual holds: 200
#
#
# Percentage low buys correct: 53.333333333333336%
# Percentage high sells correct: 44.354838709677416%
# Percentage mid holds correct: 66.66666666666667%
#
#
# Capital: 100
# Share price: $0.7952350711543554
# Shares owned at the moment: 125
# Cash capital at the moment: $0.3222540499962605
#
#
# Price increase from previously bought: -9.532240621943512%
# Share price: $0.7214097868761586
# Shares owned at the moment: 0
# Cash capital at the moment: $90.2504927952774
#
#
# Share price: $0.7885235071154348
# Shares owned at the moment: 114
# Cash capital at the moment: $0.11161086463712877
#
#
# Price increase from previously bought: -5.367013531885457%
# Share price: $0.7482554029818644
# Shares owned at the moment: 0
# Cash capital at the moment: $85.17814873573485
#
#
# Share price: $0.5871817063476314
# Shares owned at the moment: 144
# Cash capital at the moment: $0.3914590659622661
#
#
# Price increase from previously bought: 17.963374888785587%
# Share price: $0.694564170770452
# Shares owned at the moment: 0
# Cash capital at the moment: $100.13365224528225
#
#
# Share price: $0.7482554029818644
# Shares owned at the moment: 133
# Cash capital at the moment: $0.3420092350536521
#
#
# Price increase from previously bought: -5.6411711644784095%
# Share price: $0.7079866587983183
# Shares owned at the moment: 0
# Cash capital at the moment: $94.2452887347745
#
#
# Share price: $0.5938926303365772
# Shares owned at the moment: 158
# Cash capital at the moment: $0.15220679371405765
#
#
# Price increase from previously bought: -48.73397605381011%
# Share price: $0.305302417212735
# Shares owned at the moment: 0
# Cash capital at the moment: $48.25733481304725
#
#
# Share price: $0.285167725095975
# Shares owned at the moment: 168
# Cash capital at the moment: $0.21740950792911207
#
#
# Price increase from previously bought: 2.0728493294265737%
# Share price: $0.2918792891348947
# Shares owned at the moment: 0
# Cash capital at the moment: $49.1182818510111
#
#
# Share price: $0.285167725095975
# Shares owned at the moment: 171
# Cash capital at the moment: $0.22050073687299232
#
#
# Price increase from previously bought: -40.173968106713495%
# Share price: $0.1710736966342321
# Shares owned at the moment: 0
# Cash capital at the moment: $29.39365545548443
#
#
# Share price: $0.1375171565395814
# Shares owned at the moment: 213
# Cash capital at the moment: $0.021950438110529547
#
#
# Price increase from previously bought: -14.875677434212486%
# Share price: $0.1173824644228214
# Shares owned at the moment: 0
# Cash capital at the moment: $24.955658581635817
#
#
# Share price: $0.01
# Shares owned at the moment: 2488
# Cash capital at the moment: $0.007238581635817809
#
#
# Price increase from previously bought: 535.1656166682604%
# Share price: $0.0636912322114098
# Shares owned at the moment: 0
# Cash capital at the moment: $158.03524891283294
#
#
# Share price: $0.3589936494241448
# Shares owned at the moment: 439
# Cash capital at the moment: $0.0036417323660771217
#
#
# Price increase from previously bought: -5.867512890592607%
# Share price: $0.3388589573073857
# Shares owned at the moment: 0
# Cash capital at the moment: $148.35363651409904
#
#
# Share price: $0.3120133412016799
# Shares owned at the moment: 474
# Cash capital at the moment: $0.0526033942463755
#
#
# Price increase from previously bought: 1.87090535097596%
# Share price: $0.3187249052406005
# Shares owned at the moment: 0
# Cash capital at the moment: $150.71275056430989
#
#
# Share price: $0.42610736966342366
# Shares owned at the moment: 352
# Cash capital at the moment: $0.3104845089505375
#
#
# Price increase from previously bought: -17.55224352141275%
# Share price: $0.352282085385226
# Shares owned at the moment: 0
# Cash capital at the moment: $123.97276950589719
#
#
# Share price: $0.3724161374520112
# Shares owned at the moment: 331
# Cash capital at the moment: $0.3640362201657865
#
#
# Price increase from previously bought: -16.448932698772655%
# Share price: $0.3120133412016799
# Shares owned at the moment: 0
# Cash capital at the moment: $103.35644201409299
#
#
# Share price: $0.305302417212735
# Shares owned at the moment: 337
# Cash capital at the moment: $0.1865883982493841
#
#
# Price increase from previously bought: -0.27424582398405395%
# Share price: $0.305302417212735
# Shares owned at the moment: 0
# Cash capital at the moment: $102.79056398378917
#
#
# Share price: $0.2516111850013243
# Shares owned at the moment: 407
# Cash capital at the moment: $0.10319586943744241
#
#
# Price increase from previously bought: 15.685962995578251%
# Share price: $0.2918792891348947
# Shares owned at the moment: 0
# Cash capital at the moment: $118.57138065297535
#
#
#
#
# Capital at the end of test period: $118.57138065297535
# profit gained: 18.57138065297535%
#
#
# Capital at the end of test period if Buy and Hold: $35.84540016707856
# profit gained: -64.15459983292143%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.077982      8.888889            4.8          100.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         53.333333           44.354839          66.666667      18.571381
#
#    buy_n_hold profit
# 0           -64.1546
# Recession Test
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1995 - accuracy: 0.0791 - mse: 1.0475 - weighted_accuracy: 0.0791 - weighted_mse: 1.0475
# Test loss: 0.19949935376644135
# Test accuracy: 0.07906977087259293
#
#
# number of predictions: 215
# actual predicted buys: 7
# actual buys but predicted sell: 1
# actual buys but predicted hold: 0
# actual sells but predicted buy: 2
# actual predicted sells: 7
# actual sells but predicted hold: 0
# actual holds but predicted buy: 103
# actual holds but predicted sell: 92
# actual predicted holds: 3
# Percentage buys correct: 6.25%
# Percentage sells correct: 7.0%
# Percentage holds correct: 100.0%
# actual buys: 8
# actual sells: 9
# actual holds: 198
#
#
# Percentage low buys correct: 48.214285714285715%
# Percentage high sells correct: 54.54545454545455%
# Percentage mid holds correct: 100.0%
#
#
# Capital: 100
# Share price: $1.0062617748699323
# Shares owned at the moment: 99
# Cash capital at the moment: $0.10612951966835737
#
#
# Price increase from previously bought: -0.6447409640047974%
# Share price: $1.0025233714829802
# Shares owned at the moment: 0
# Cash capital at the moment: $99.08300630859716
#
#
# Share price: $0.9931775412724846
# Shares owned at the moment: 99
# Cash capital at the moment: $0.48803713700975493
#
#
# Price increase from previously bought: -23.359338085536553%
# Share price: $0.7632710806814724
# Shares owned at the moment: 0
# Cash capital at the moment: $75.84407357276
#
#
# Share price: $0.7371027917434618
# Shares owned at the moment: 102
# Cash capital at the moment: $0.4528314818428498
#
#
# Price increase from previously bought: -17.976290018834572%
# Share price: $0.6062617035671785
# Shares owned at the moment: 0
# Cash capital at the moment: $62.12146883784446
#
#
# Share price: $0.46420558348692387
# Shares owned at the moment: 133
# Cash capital at the moment: $0.2123430419232406
#
#
# Price increase from previously bought: 9.363043241172587%
# Share price: $0.5090654437174831
# Shares owned at the moment: 0
# Cash capital at the moment: $67.73185637030883
#
#
# Share price: $0.5146729596694688
# Shares owned at the moment: 131
# Cash capital at the moment: $0.12428771988749077
#
#
# Price increase from previously bought: -67.13229828091349%
# Share price: $0.16962636643929108
# Shares owned at the moment: 0
# Cash capital at the moment: $22.28423382492487
#
#
# Share price: $0.2137383499098866
# Shares owned at the moment: 103
# Cash capital at the moment: $0.20864239659456985
#
#
# Price increase from previously bought: 0.5978422232308045%
# Share price: $0.21560746247492013
# Shares owned at the moment: 0
# Cash capital at the moment: $22.35514021776532
#
#
# Share price: $0.12028040431870078
# Shares owned at the moment: 185
# Cash capital at the moment: $0.04207276310853558
#
#
# Price increase from previously bought: -12.672186184715395%
# Share price: $0.10532710272044075
# Shares owned at the moment: 0
# Cash capital at the moment: $19.474001602881053
#
#
# Share price: $0.1427102898697593
# Shares owned at the moment: 136
# Cash capital at the moment: $0.012028532182494445
#
#
# Price increase from previously bought: -12.029725691811578%
# Share price: $0.1258878757064653
# Shares owned at the moment: 0
# Cash capital at the moment: $17.08569756274756
#
#
# Share price: $0.09224300281565666
# Shares owned at the moment: 184
# Cash capital at the moment: $0.06631008524200865
#
#
# Price increase from previously bought: -44.73152296771694%
# Share price: $0.05112150140782833
# Shares owned at the moment: 0
# Cash capital at the moment: $9.44679886457006
#
#
# Share price: $0.07355143152310793
# Shares owned at the moment: 128
# Cash capital at the moment: $0.006325525716109226
#
#
# Price increase from previously bought: -38.28915528429011%
# Share price: $0.045514030020063705
# Shares owned at the moment: 0
# Cash capital at the moment: $5.816100429717201
#
#
# Share price: $0.03056077298602477
# Shares owned at the moment: 189
# Cash capital at the moment: $0.024230373599032795
#
#
# Price increase from previously bought: -18.572517056226147%
# Share price: $0.02495330159826014
# Shares owned at the moment: 0
# Cash capital at the moment: $4.727434897164504
#
#
# Share price: $0.047383187149318544
# Shares owned at the moment: 99
# Cash capital at the moment: $0.023599296680566262
#
#
# Price increase from previously bought: 7.593654821914253%
# Share price: $0.05112150140782833
# Shares owned at the moment: 0
# Cash capital at the moment: $5.070710107297289
#
#
# Share price: $0.047383187149318544
# Shares owned at the moment: 106
# Cash capital at the moment: $0.0342800704154973
#
#
# Price increase from previously bought: 27.263406436659608%
# Share price: $0.06046728705410264
# Shares owned at the moment: 0
# Cash capital at the moment: $6.426186283974106
#
#
# Share price: $0.02495330159826014
# Shares owned at the moment: 256
# Cash capital at the moment: $0.020573950494334525
#
#
# Price increase from previously bought: 29.60606538924837%
# Share price: $0.0324299301152795
# Shares owned at the moment: 0
# Cash capital at the moment: $8.299805389204728
#
#
# Share price: $0.21000003565137693
# Shares owned at the moment: 39
# Cash capital at the moment: $0.08728149497741633
#
#
# Price increase from previously bought: 0.6133666928886283%
# Share price: $0.21186914821641079
# Shares owned at the moment: 0
# Cash capital at the moment: $8.327455309271226
#
#
# Share price: $0.21000003565137693
# Shares owned at the moment: 39
# Cash capital at the moment: $0.11493141504391424
#
#
# Price increase from previously bought: -2.9371680260268374%
# Share price: $0.2043925196993911
# Shares owned at the moment: 0
# Cash capital at the moment: $8.064318585582406
#
#
# Share price: $0.21186914821641079
# Shares owned at the moment: 37
# Cash capital at the moment: $0.2036024157441867
#
#
#
#
# Capital at the end of test period: $8.297077722098471
# profit gained: -91.70292227790154%
#
#
# Capital at the end of test period if Buy and Hold: $21.761644528562254
# profit gained: -78.23835547143774%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0        0.07907          6.25            7.0          100.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         48.214286           54.545455              100.0     -91.702922
#
#    buy_n_hold profit
# 0         -78.238355
#
#
# O39.SI
#
#
# Non-Recession Test
#
#
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1952 - accuracy: 0.0938 - mse: 1.1367 - weighted_accuracy: 0.0938 - weighted_mse: 1.1367WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0040s vs `on_test_batch_end` time: 0.0070s). Check your callbacks.
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2001 - accuracy: 0.0688 - mse: 1.1053 - weighted_accuracy: 0.0688 - weighted_mse: 1.1053
# Test loss: 0.20009735226631165
# Test accuracy: 0.06880734115839005
#
#
# number of predictions: 218
# actual predicted buys: 7
# actual buys but predicted sell: 1
# actual buys but predicted hold: 0
# actual sells but predicted buy: 1
# actual predicted sells: 8
# actual sells but predicted hold: 0
# actual holds but predicted buy: 92
# actual holds but predicted sell: 109
# actual predicted holds: 0
# Percentage buys correct: 7.0%
# Percentage sells correct: 6.779661016949152%
# Percentage holds correct: 0%
# actual buys: 8
# actual sells: 9
# actual holds: 201
#
#
# Percentage low buys correct: 53.0%
# Percentage high sells correct: 49.572649572649574%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.6357665229914489
# Shares owned at the moment: 156
# Cash capital at the moment: $0.5476785749706323
#
#
# Price increase from previously bought: -4.123544547624158%
# Share price: $0.611226670816807
# Shares owned at the moment: 0
# Cash capital at the moment: $95.63682298061212
#
#
# Share price: $0.513067262118245
# Shares owned at the moment: 185
# Cash capital at the moment: $0.4583565191341279
#
#
# Price increase from previously bought: -24.12350932386378%
# Share price: $0.3903680012450421
# Shares owned at the moment: 0
# Cash capital at the moment: $72.4778370288335
#
#
# Share price: $0.3290180782703287
# Shares owned at the moment: 219
# Cash capital at the moment: $0.2247267499932093
#
#
# Price increase from previously bought: 59.23038861423%
# Share price: $0.5253374807436784
# Shares owned at the moment: 0
# Cash capital at the moment: $114.95725053508089
#
#
# Share price: $0.7891407453520085
# Shares owned at the moment: 145
# Cash capital at the moment: $0.21717258683052876
#
#
# Price increase from previously bought: 4.377537895753303%
# Share price: $0.8259508161520819
# Shares owned at the moment: 0
# Cash capital at the moment: $119.65069304094176
#
#
# Share price: $0.6603063751660889
# Shares owned at the moment: 180
# Cash capital at the moment: $0.46869385533854313
#
#
# Price increase from previously bought: -32.7038418290306%
# Share price: $0.4455828149070389
# Shares owned at the moment: 0
# Cash capital at the moment: $80.45303704522655
#
#
# Share price: $0.40263763479424886
# Shares owned at the moment: 199
# Cash capital at the moment: $0.1078042755298867
# Price increase from previously bought: -77.76946075607404%
# Share price: $0.08975466583663859
# Shares owned at the moment: 0
# Cash capital at the moment: $17.919864536141866
#
#
# Share price: $0.5007976285690374
# Shares owned at the moment: 35
# Cash capital at the moment: $0.3437457644757842
#
#
# Price increase from previously bought: 24.159328996215113%
# Share price: $0.6234968894422404
# Shares owned at the moment: 0
# Cash capital at the moment: $22.10612531934538
#
#
# Share price: $0.7277914074535181
# Shares owned at the moment: 30
# Cash capital at the moment: $0.21234030462492015
#
#
# Price increase from previously bought: 4.769580864608103%
# Share price: $0.7646008931773667
# Shares owned at the moment: 0
# Cash capital at the moment: $23.087287526258788
#
#
# Share price: $0.6419016323041646
# Shares owned at the moment: 35
# Cash capital at the moment: $0.5589473635037514
#
#
# Price increase from previously bought: -87.0088765652793%
# Share price: $0.08361955652392193
# Shares owned at the moment: 0
# Cash capital at the moment: $3.4775834595255914
#
#
# Share price: $0.05294459503656523
# Shares owned at the moment: 65
# Cash capital at the moment: $0.026720935786065603
#
#
# Price increase from previously bought: 57.50471473911387%
# Share price: $0.08361955652392193
# Shares owned at the moment: 0
# Cash capital at the moment: $5.44704511411234
#
#
# Share price: $0.2185890360225582
# Shares owned at the moment: 24
# Cash capital at the moment: $0.18648137319345448
#
#
# Price increase from previously bought: -22.665627478015537%
# Share price: $0.1695093316732772
# Shares owned at the moment: 0
# Cash capital at the moment: $4.243517717461671
#
#
# Share price: $0.07748444721120527
# Shares owned at the moment: 54
# Cash capital at the moment: $0.04785112764572208
#
#
# Price increase from previously bought: 126.06105647549914%
# Share price: $0.17564385590976817
# Shares owned at the moment: 0
# Cash capital at the moment: $9.506536234170603
#
#
# Share price: $0.13269926087320294
# Shares owned at the moment: 71
# Cash capital at the moment: $0.05897918148770209
#
#
# Price increase from previously bought: 87.32569895162653%
# Share price: $0.2492634124336892
# Shares owned at the moment: 0
# Cash capital at the moment: $17.708012783001955
#
#
# Share price: $0.40263763479424886
# Shares owned at the moment: 43
# Cash capital at the moment: $0.34698258653483194
#
#
# Price increase from previously bought: 5.803813090539878%
# Share price: $0.4271774869688898
# Shares owned at the moment: 0
# Cash capital at the moment: $18.66510078836302
#
#
# Share price: $0.38423289193232546
# Shares owned at the moment: 48
# Cash capital at the moment: $0.17120323387633007
#
#
# Price increase from previously bought: -79.88929345379904%
# Share price: $0.07748444721120527
# Shares owned at the moment: 0
# Cash capital at the moment: $3.880228752982304
#
#
# Share price: $0.11429451801127775
# Shares owned at the moment: 33
# Cash capital at the moment: $0.09813743110061468
#
#
# Price increase from previously bought: 90.7261769965815%
# Share price: $0.2185890360225582
# Shares owned at the moment: 0
# Cash capital at the moment: $7.291738664825987
#
#
#
#
# Capital at the end of test period: $7.291738664825987
# profit gained: -92.70826133517402%
#
#
# Capital at the end of test period if Buy and Hold: $44.097971344241664
# profit gained: -55.90202865575834%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.077982      8.888889       4.800000          100.0
# 1       0.068807      7.000000       6.779661            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         53.333333           44.354839          66.666667      18.571381
# 1         53.000000           49.572650           0.000000     -92.708261
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# Recession Test
#
#
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1987 - accuracy: 0.0837 - mse: 1.0770 - weighted_accuracy: 0.0837 - weighted_mse: 1.0770
# Test loss: 0.19871048629283905
# Test accuracy: 0.08372092992067337
#
#
# number of predictions: 215
# actual predicted buys: 9
# actual buys but predicted sell: 2
# actual buys but predicted hold: 1
# actual sells but predicted buy: 1
# actual predicted sells: 9
# actual sells but predicted hold: 0
# actual holds but predicted buy: 95
# actual holds but predicted sell: 98
# actual predicted holds: 0
# Percentage buys correct: 8.571428571428571%
# Percentage sells correct: 8.256880733944953%
# Percentage holds correct: 0.0%
# actual buys: 12
# actual sells: 10
# actual holds: 193
#
#
# Percentage low buys correct: 50.476190476190474%
# Percentage high sells correct: 50.925925925925924%
# Percentage mid holds correct: 0.0%
#
#
# Capital: 100
# Share price: $0.9886586309918834
# Shares owned at the moment: 100
# Cash capital at the moment: $0.8622557772888797
#
#
# Price increase from previously bought: 0.9558718911797381%
# Share price: $1.0008537405328568
# Shares owned at the moment: 0
# Cash capital at the moment: $100.67239505192802
#
#
# Share price: $0.9734146713770804
# Shares owned at the moment: 103
# Cash capital at the moment: $0.1349641944211868
#
#
# Price increase from previously bought: -83.35820466169072%
# Share price: $0.1624391600165096
# Shares owned at the moment: 0
# Cash capital at the moment: $16.820186784047
#
#
# Share price: $0.30878047450818547
# Shares owned at the moment: 54
# Cash capital at the moment: $0.10018726014051893
#
#
# Price increase from previously bought: 7.602978266494587%
# Share price: $0.3331706935901313
# Shares owned at the moment: 0
# Cash capital at the moment: $18.041928866009474
#
#
# Share price: $0.29048766481955224
# Shares owned at the moment: 61
# Cash capital at the moment: $0.273452006243307
#
#
# Price increase from previously bought: 16.472403241645004%
# Share price: $0.3392683937377907
# Shares owned at the moment: 0
# Cash capital at the moment: $20.911911751199025
#
#
# Share price: $0.2539023361966335
# Shares owned at the moment: 82
# Cash capital at the moment: $0.03466520626273706
#
#
# Price increase from previously bought: 89.53644238281913%
# Share price: $0.4825608581556373
# Shares owned at the moment: 0
# Cash capital at the moment: $39.495838101510905
#
#
# Share price: $0.3545120625982474
# Shares owned at the moment: 111
# Cash capital at the moment: $0.03678434599732583
#
#
# Price increase from previously bought: 15.163208379364956%
# Share price: $0.4093902009097994
# Shares owned at the moment: 0
# Cash capital at the moment: $45.354130288157336
#
#
# Share price: $0.3849999818278531
# Shares owned at the moment: 117
# Cash capital at the moment: $0.18525867014540864
#
#
# Price increase from previously bought: 10.781851411277055%
# Share price: $0.4276830105984313
# Shares owned at the moment: 0
# Cash capital at the moment: $50.08656390150182
#
#
# Share price: $0.4551220797542077
# Shares owned at the moment: 109
# Cash capital at the moment: $0.34183436488685714
#
#
# Price increase from previously bought: -6.954718764501333%
# Share price: $0.42463416052460157
# Shares owned at the moment: 0
# Cash capital at the moment: $46.49967377245118
#
#
# Share price: $0.4276830105984313
# Shares owned at the moment: 108
# Cash capital at the moment: $0.18288677367286965
#
#
# Price increase from previously bought: -7.383321151001276%
# Share price: $0.3971950913688269
# Shares owned at the moment: 0
# Cash capital at the moment: $42.96198969936964
#
#
# Share price: $0.3697560222130505
# Shares owned at the moment: 115
# Cash capital at the moment: $0.3231118028439539
#
#
# Price increase from previously bought: -19.186581754470787%
# Share price: $0.2996342150410418
# Shares owned at the moment: 0
# Cash capital at the moment: $34.68628721205703
#
#
# Share price: $0.2539023361966335
# Shares owned at the moment: 136
# Cash capital at the moment: $0.06061001557733903
#
#
# Price increase from previously bought: -9.854043430027314%
# Share price: $0.22951211711468766
# Shares owned at the moment: 0
# Cash capital at the moment: $31.188420411373965
#
#
# Share price: $0.22036585764754446
# Shares owned at the moment: 141
# Cash capital at the moment: $0.0313876217673581
#
#
# Price increase from previously bought: 2.4852458343706862%
# Share price: $0.22646355779520433
# Shares owned at the moment: 0
# Cash capital at the moment: $31.874938026356077
#
#
# Share price: $0.1959756385655982
# Shares owned at the moment: 162
# Cash capital at the moment: $0.039577431748195835
#
#
# Price increase from previously bought: 78.848571109961%
# Share price: $0.3514635032787641
# Shares owned at the moment: 0
# Cash capital at the moment: $56.820087972197285
#
#
# Share price: $0.7112193801146416
# Shares owned at the moment: 79
# Cash capital at the moment: $0.47924453281068935
#
#
# Price increase from previously bought: 6.993152959609028%
# Share price: $0.7630486683523638
# Shares owned at the moment: 0
# Cash capital at the moment: $60.59431700944788
#
#
# Share price: $0.6990242705736691
# Shares owned at the moment: 86
# Cash capital at the moment: $0.3129105001216601
#
#
# Price increase from previously bought: -2.014051646798498%
# Share price: $0.6868291610326958
# Shares owned at the moment: 0
# Cash capital at the moment: $59.217783252349264
#
#
# Share price: $0.6624389419507495
# Shares owned at the moment: 89
# Cash capital at the moment: $0.09858548769011577
#
#
# Price increase from previously bought: 12.576999678822665%
# Share price: $0.7478047087375603
# Shares owned at the moment: 0
# Cash capital at the moment: $66.47017936286946
#
#
#
#
# Capital at the end of test period: $66.47017936286946
# profit gained: -33.52982063713054%
#
#
# Capital at the end of test period if Buy and Hold: $75.43708035614208
# profit gained: -24.562919643857924%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.079070      6.250000       7.000000          100.0
# 1       0.083721      8.571429       8.256881            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         48.214286           54.545455              100.0     -91.702922
# 1         50.476190           50.925926                0.0     -33.529821
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
#
#
# 0883.HK
#
#
# Non-Recession Test
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2036 - accuracy: 0.0625 - mse: 1.1002 - weighted_accuracy: 0.0625 - weighted_mse: 1.1002WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0030s vs `on_test_batch_end` time: 0.0050s). Check your callbacks.
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2010 - accuracy: 0.0427 - mse: 1.0886 - weighted_accuracy: 0.0427 - weighted_mse: 1.0886
# Test loss: 0.20101723074913025
# Test accuracy: 0.04265403002500534
#
#
# number of predictions: 211
# actual predicted buys: 3
# actual buys but predicted sell: 5
# actual buys but predicted hold: 0
# actual sells but predicted buy: 4
# actual predicted sells: 5
# actual sells but predicted hold: 0
# actual holds but predicted buy: 95
# actual holds but predicted sell: 98
# actual predicted holds: 1
# Percentage buys correct: 2.9411764705882355%
# Percentage sells correct: 4.62962962962963%
# Percentage holds correct: 100.0%
# actual buys: 8
# actual sells: 9
# actual holds: 194
#
#
# Percentage low buys correct: 47.05882352941177%
# Percentage high sells correct: 50.467289719626166%
# Percentage mid holds correct: 100.0%
#
#
# Capital: 100
# Share price: $0.6441463755029468
# Shares owned at the moment: 154
# Cash capital at the moment: $0.5286621825206907
#
#
# Price increase from previously bought: 17.850859998140113%
# Share price: $0.7612196562958087
# Shares owned at the moment: 0
# Cash capital at the moment: $117.43411272763394
#
#
# Share price: $0.9758535779763593
# Shares owned at the moment: 120
# Cash capital at the moment: $0.009651689738632285
#
#
# Price increase from previously bought: 0.22426972548585944%
# Share price: $0.9807317379526521
# Shares owned at the moment: 0
# Cash capital at the moment: $117.37381877053251
#
#
# Share price: $0.9904878253017684
# Shares owned at the moment: 118
# Cash capital at the moment: $0.1748420856134203
#
#
# Price increase from previously bought: -39.07421284698541%
# Share price: $0.6051220261064831
# Shares owned at the moment: 0
# Cash capital at the moment: $71.38287906870688
#
#
# Share price: $0.5417073420354945
# Shares owned at the moment: 131
# Cash capital at the moment: $0.22406719208881043
#
#
# Price increase from previously bought: -43.37947522250071%
# Share price: $0.30756101305324157
# Shares owned at the moment: 0
# Cash capital at the moment: $40.40376104711102
#
#
# Share price: $0.45390255589345085
# Shares owned at the moment: 88
# Cash capital at the moment: $0.3504917099611262
#
#
# Price increase from previously bought: -4.561215157226006%
# Share price: $0.4343903811952188
# Shares owned at the moment: 0
# Cash capital at the moment: $38.471722782891135
#
#
# Share price: $0.3953660317987555
# Shares owned at the moment: 97
# Cash capital at the moment: $0.0157538094295262
#
#
# Price increase from previously bought: -0.27424582398404285%
# Share price: $0.3953660317987555
# Shares owned at the moment: 0
# Cash capital at the moment: $38.26079500492649
#
#
# Share price: $0.5270733273135557
# Shares owned at the moment: 72
# Cash capital at the moment: $0.20715491954239695
#
#
# Price increase from previously bought: 20.953811940444123%
# Share price: $0.6392684481301243
# Shares owned at the moment: 0
# Cash capital at the moment: $46.107908032181584
#
#
# Share price: $0.5417073420354945
# Shares owned at the moment: 84
# Cash capital at the moment: $0.47935690518983876
#
#
# Price increase from previously bought: 1.5218036167376159%
# Share price: $0.5514634293846103
# Shares owned at the moment: 0
# Cash capital at the moment: $46.67489692130926
#
#
# Share price: $0.5417073420354945
# Shares owned at the moment: 85
# Cash capital at the moment: $0.5031487570914308
#
#
# Price increase from previously bought: -67.62616408284153%
# Share price: $0.17585371753844137
# Shares owned at the moment: 0
# Cash capital at the moment: $15.409608941384336
#
#
# Share price: $0.01
# Shares owned at the moment: 1536
# Cash capital at the moment: $0.007368941384337191
#
#
# Price increase from previously bought: 1507.7756451408882%
# Share price: $0.16121970281650255
# Shares owned at the moment: 0
# Cash capital at the moment: $246.95984044283534
#
#
# Share price: $0.39048787182246225
# Shares owned at the moment: 630
# Cash capital at the moment: $0.27596095675167476
#
#
# Price increase from previously bought: -42.6312260477819%
# Share price: $0.22463415428402134
# Shares owned at the moment: 0
# Cash capital at the moment: $141.40629948338804
#
#
# Share price: $0.28804883835500994
# Shares owned at the moment: 489
# Cash capital at the moment: $0.16306385241026078
#
#
# Price increase from previously bought: 8.169962921703045%
# Share price: $0.3124391730295344
# Shares owned at the moment: 0
# Cash capital at the moment: $152.5256668859211
#
#
# Share price: $0.25878057630766205
# Shares owned at the moment: 587
# Cash capital at the moment: $0.2037320480188498
#
#
# Price increase from previously bought: 52.36141853951888%
# Share price: $0.3953660317987555
# Shares owned at the moment: 0
# Cash capital at the moment: $231.6453730970572
#
#
# Share price: $0.2539024163313688
# Shares owned at the moment: 909
# Cash capital at the moment: $0.21338408661861763
#
#
# Price increase from previously bought: -63.50093391047509%
# Share price: $0.09292685876922112
# Shares owned at the moment: 0
# Cash capital at the moment: $84.45160479263225
#
#
#
#
# Capital at the end of test period: $84.45160479263225
# profit gained: -15.548395207367745%
#
#
# Capital at the end of test period if Buy and Hold: $45.31039913308918
# profit gained: -54.68960086691082%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.077982      8.888889       4.800000          100.0
# 1       0.068807      7.000000       6.779661            0.0
# 2       0.042654      2.941176       4.629630          100.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         53.333333           44.354839          66.666667      18.571381
# 1         53.000000           49.572650           0.000000     -92.708261
# 2         47.058824           50.467290         100.000000     -15.548395
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# 2         -54.689601
# Recession Test
#
#
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1996 - accuracy: 0.0939 - mse: 1.0792 - weighted_accuracy: 0.0939 - weighted_mse: 1.0792
# Test loss: 0.19957105815410614
# Test accuracy: 0.09389671683311462
#
#
# number of predictions: 213
# actual predicted buys: 7
# actual buys but predicted sell: 3
# actual buys but predicted hold: 0
# actual sells but predicted buy: 2
# actual predicted sells: 8
# actual sells but predicted hold: 0
# actual holds but predicted buy: 96
# actual holds but predicted sell: 92
# actual predicted holds: 5
# Percentage buys correct: 6.666666666666667%
# Percentage sells correct: 7.766990291262136%
# Percentage holds correct: 100.0%
# actual buys: 10
# actual sells: 10
# actual holds: 193
#
#
# Percentage low buys correct: 42.857142857142854%
# Percentage high sells correct: 50.0%
# Percentage mid holds correct: 80.0%
#
#
# Capital: 100
# Share price: $0.9897979992587349
# Shares owned at the moment: 100
# Cash capital at the moment: $0.7480056243303466
#
#
# Price increase from previously bought: -8.415962675580069%
# Share price: $0.9089898357424446
# Shares owned at the moment: 0
# Cash capital at the moment: $91.39701699374564
#
#
# Share price: $0.8786869149061622
# Shares owned at the moment: 103
# Cash capital at the moment: $0.6433766897637554
#
#
# Price increase from previously bought: -76.3191027758567%
# Share price: $0.20865316784033627
# Shares owned at the moment: 0
# Cash capital at the moment: $22.075551967527616
#
#
# Share price: $0.3450168735329129
# Shares owned at the moment: 63
# Cash capital at the moment: $0.27971476161452813
#
#
# Price increase from previously bought: 6.538256871330672%
# Share price: $0.3685857941221071
# Shares owned at the moment: 0
# Cash capital at the moment: $23.43676230247562
#
#
# Share price: $0.46117841793299474
# Shares owned at the moment: 50
# Cash capital at the moment: $0.31442937336009535
#
#
# Price increase from previously bought: 8.462762160113769%
# Share price: $0.5015824194155247
# Shares owned at the moment: 0
# Cash capital at the moment: $25.324582761466697
#
#
# Share price: $0.4207744164504643
# Shares owned at the moment: 60
# Cash capital at the moment: $0.008689995724509458
#
#
# Price increase from previously bought: -1.8702393706625742%
# Share price: $0.41404041620337595
# Shares owned at the moment: 0
# Cash capital at the moment: $24.78279829925351
#
#
# Share price: $0.45276087748632676
# Shares owned at the moment: 54
# Cash capital at the moment: $0.266475924685146
#
#
# Price increase from previously bought: 3.43387301354261%
# Share price: $0.4695959583796625
# Shares owned at the moment: 0
# Cash capital at the moment: $25.55492267736754
#
#
# Share price: $0.38205379461628364
# Shares owned at the moment: 66
# Cash capital at the moment: $0.27002946896996605
#
#
# Price increase from previously bought: 15.984908470475734%
# Share price: $0.44434333703965856
# Shares owned at the moment: 0
# Cash capital at the moment: $29.51604139791473
#
#
# Share price: $0.3786868747683543
# Shares owned at the moment: 77
# Cash capital at the moment: $0.27696509501924993
#
#
# Price increase from previously bought: 26.326356071968625%
# Share price: $0.4796968784746798
# Shares owned at the moment: 0
# Cash capital at the moment: $37.11204892355258
#
#
# Share price: $0.39215487526253145
# Shares owned at the moment: 94
# Cash capital at the moment: $0.14811861361925338
#
#
# Price increase from previously bought: -1.1305009756066964%
# Share price: $0.3887877948633718
# Shares owned at the moment: 0
# Cash capital at the moment: $36.59366968580402
#
#
# Share price: $0.3786868747683543
# Shares owned at the moment: 96
# Cash capital at the moment: $0.13975637310316102
#
#
# Price increase from previously bought: 1.9424815708183774%
# Share price: $0.3871044152150227
# Shares owned at the moment: 0
# Cash capital at the moment: $37.19958466812857
#
#
# Share price: $0.4174073360513051
# Shares owned at the moment: 88
# Cash capital at the moment: $0.36672652028930486
#
#
# Price increase from previously bought: -18.776245551928895%
# Share price: $0.33996625293417404
# Shares owned at the moment: 0
# Cash capital at the moment: $30.20148494528655
#
#
# Share price: $0.2440067092753575
# Shares owned at the moment: 123
# Cash capital at the moment: $0.10612443500518509
#
#
# Price increase from previously bought: -9.90691696404613%
# Share price: $0.22043770841054844
# Shares owned at the moment: 0
# Cash capital at the moment: $27.14539951463277
#
#
# Share price: $0.1598316259111383
# Shares owned at the moment: 169
# Cash capital at the moment: $0.05957298750819717
#
#
# Price increase from previously bought: 7.07863061259546%
# Share price: $0.1716161664813498
# Shares owned at the moment: 0
# Cash capital at the moment: $28.982946509484105
#
#
# Share price: $0.11774408422902848
# Shares owned at the moment: 245
# Cash capital at the moment: $0.05631579662281894
#
#
# Price increase from previously bought: 195.07076100762907%
# Share price: $0.34838379338084224
# Shares owned at the moment: 0
# Cash capital at the moment: $85.17562159413882
#
#
# Share price: $0.23727270902826936
# Shares owned at the moment: 357
# Cash capital at the moment: $0.23632198895815293
#
#
# Price increase from previously bought: -53.34244552784675%
# Share price: $0.11101008398194011
# Shares owned at the moment: 0
# Cash capital at the moment: $39.7579378205615
#
#
#
#
# Capital at the end of test period: $39.7579378205615
# profit gained: -60.24206217943849%
#
#
# Capital at the end of test period if Buy and Hold: $15.710112504960433
# profit gained: -84.28988749503957%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.079070      6.250000       7.000000          100.0
# 1       0.083721      8.571429       8.256881            0.0
# 2       0.093897      6.666667       7.766990          100.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         48.214286           54.545455              100.0     -91.702922
# 1         50.476190           50.925926                0.0     -33.529821
# 2         42.857143           50.000000               80.0     -60.242062
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
# 2         -84.289887
#
#
# JPM
#
#
# Non-Recession Test
#
#
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2025 - accuracy: 0.0734 - mse: 1.1106 - weighted_accuracy: 0.0734 - weighted_mse: 1.1106
# Test loss: 0.2025410681962967
# Test accuracy: 0.07339449226856232
#
#
# number of predictions: 218
# actual predicted buys: 9
# actual buys but predicted sell: 2
# actual buys but predicted hold: 0
# actual sells but predicted buy: 1
# actual predicted sells: 5
# actual sells but predicted hold: 0
# actual holds but predicted buy: 76
# actual holds but predicted sell: 123
# actual predicted holds: 2
# Percentage buys correct: 10.465116279069768%
# Percentage sells correct: 3.8461538461538463%
# Percentage holds correct: 100.0%
# actual buys: 11
# actual sells: 6
# actual holds: 201
#
#
# Percentage low buys correct: 47.674418604651166%
# Percentage high sells correct: 45.736434108527135%
# Percentage mid holds correct: 100.0%
#
#
# Capital: 100
# Share price: $0.05968146056768497
# Shares owned at the moment: 1670
# Cash capital at the moment: $0.05787374430900627
#
#
# Price increase from previously bought: 182.78727815537374%
# Share price: $0.1692356997419615
# Shares owned at the moment: 0
# Cash capital at the moment: $281.90427736231976
#
#
# Share price: $0.1926751480928941
# Shares owned at the moment: 1459
# Cash capital at the moment: $0.01817543185154591
#
#
# Price increase from previously bought: -10.296302726664674%
# Share price: $0.1733120325780073
# Shares owned at the moment: 0
# Cash capital at the moment: $252.1850597604531
#
#
# Share price: $0.01
# Shares owned at the moment: 25149
# Cash capital at the moment: $0.0034622604530909484
#
#
# Price increase from previously bought: 1450.5132082644113%
# Share price: $0.15547771195871385
# Shares owned at the moment: 0
# Cash capital at the moment: $3899.3596406205106
#
#
# Share price: $0.429872778606591
# Shares owned at the moment: 9046
# Cash capital at the moment: $0.03675516828116088
#
#
# Price increase from previously bought: -27.40368830769977%
# Share price: $0.3129299796387459
# Shares owned at the moment: 0
# Cash capital at the moment: $2823.0167483418936
#
#
# Share price: $0.2573885597935692
# Shares owned at the moment: 10937
# Cash capital at the moment: $0.21665851385569113
#
#
# Price increase from previously bought: 14.434111045417609%
# Share price: $0.2953502961857881
# Shares owned at the moment: 0
# Cash capital at the moment: $3221.579670877014
#
#
# Share price: $0.23496824324652743
# Shares owned at the moment: 13673
# Cash capital at the moment: $0.023898794992874173
#
#
# Price increase from previously bought: 65.03814581788818%
# Share price: $0.3888536468027002
# Shares owned at the moment: 0
# Cash capital at the moment: $5302.1986227682955
#
#
# Share price: $0.40082800814450237
# Shares owned at the moment: 13191
# Cash capital at the moment: $0.336231131720524
#
#
# Price increase from previously bought: 15.95321381252841%
# Share price: $0.46605108293688047
# Shares owned at the moment: 0
# Cash capital at the moment: $6131.109946605804
#
#
# Share price: $0.3666879674219936
# Shares owned at the moment: 16674
# Cash capital at the moment: $0.14085109729876422
#
#
# Price increase from previously bought: -39.21529257368965%
# Share price: $0.22350315623739658
# Shares owned at the moment: 0
# Cash capital at the moment: $3716.5840762251178
#
#
# Share price: $0.21050966309170316
# Shares owned at the moment: 17606
# Cash capital at the moment: $0.15880672951243469
#
#
# Price increase from previously bought: 36.65894215608001%
# Share price: $0.28847139948392253
# Shares owned at the moment: 0
# Cash capital at the moment: $5065.01949053034
#
#
# Share price: $0.47878993891623733
# Shares owned at the moment: 10549
# Cash capital at the moment: $0.37484847247651487
#
#
# Price increase from previously bought: -4.944148383389646%
# Share price: $0.4563694279896795
# Shares owned at the moment: 0
# Cash capital at the moment: $4801.376781321982
#
#
# Share price: $0.7628662717522834
# Shares owned at the moment: 6276
# Cash capital at the moment: $0.46175082047830074
#
#
# Price increase from previously bought: 6.719983949682029%
# Share price: $0.8163696223691963
# Shares owned at the moment: 0
# Cash capital at the moment: $5109.907777497085
#
#
# Share price: $0.8217197241754663
# Shares owned at the moment: 6201
# Cash capital at the moment: $0.4111868585841876
#
#
# Price increase from previously bought: 1.890214625165254%
# Share price: $0.8395544335537928
# Shares owned at the moment: 0
# Cash capital at the moment: $5192.171517458869
#
#
# Share price: $0.8612102554632799
# Shares owned at the moment: 6012
# Cash capital at the moment: $0.337072460055424
#
#
# Price increase from previously bought: 7.69141541841436%
# Share price: $0.9299999999999999
# Shares owned at the moment: 0
# Cash capital at the moment: $5576.121382460055
#
#
#
#
# ...
# profit gained: -31.90034799175503%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.306977      6.451613       6.666667      90.322581
# 1       0.344186      6.493506       7.812500      86.486486
# 2       0.328638      9.090909       8.955224      96.551724
# 3       0.374429      9.459459      13.157895      94.202899
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         50.537634           62.711864          82.258065     -29.890720
# 1         54.545455           57.142857          83.783784      19.213921
# 2         50.000000           50.000000          86.206897     -76.779635
# 3         47.297297           55.263158          82.352941     406.413497
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
# 2         -84.289887
# 3         -31.900348
#
#
# AXL
#
#
# Non-Recession Test
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6839 - accuracy: 0.2202 - mse: 4.7464 - weighted_accuracy: 0.2202 - weighted_mse: 4.7464
# Test loss: 0.683864951133728
# Test accuracy: 0.22018349170684814
#
#
# number of predictions: 218
# actual predicted buys: 6
# actual buys but predicted sell: 0
# actual buys but predicted hold: 2
# actual sells but predicted buy: 0
# actual predicted sells: 4
# actual sells but predicted hold: 4
# actual holds but predicted buy: 86
# actual holds but predicted sell: 78
# actual predicted holds: 38
# Percentage buys correct: 6.521739130434782%
# Percentage sells correct: 4.878048780487805%
# Percentage holds correct: 86.36363636363636%
# actual buys: 8
# actual sells: 8
# actual holds: 202
#
#
# Percentage low buys correct: 47.82608695652174%
# Percentage high sells correct: 50.617283950617285%
# Percentage mid holds correct: 81.81818181818181%
#
#
# Capital: 100
# Share price: $0.7426007274823263
# Shares owned at the moment: 134
# Cash capital at the moment: $0.21785414929102842
#
#
# Price increase from previously bought: 5.136804586257004%
# Share price: $0.7828937290674167
# Shares owned at the moment: 0
# Cash capital at the moment: $104.83711750516353
#
#
# Share price: $0.9339926815103341
# Shares owned at the moment: 111
# Cash capital at the moment: $0.8788285914854157
#
#
# Price increase from previously bought: -19.927629001619863%
# Share price: $0.7499267277705246
# Shares owned at the moment: 0
# Cash capital at the moment: $83.8917802403617
#
#
# Share price: $0.7719047286351195
# Shares owned at the moment: 108
# Cash capital at the moment: $0.2968138433641627
#
#
# Price increase from previously bought: -5.953114291024908%
# Share price: $0.7279487269059297
# Shares owned at the moment: 0
# Cash capital at the moment: $78.69907557731351
#
#
# Share price: $0.9175091371954818
# Shares owned at the moment: 85
# Cash capital at the moment: $0.4963311548781064
#
#
# Price increase from previously bought: -38.29647876585762%
# Share price: $0.5676923177691708
# Shares owned at the moment: 0
# Cash capital at the moment: $48.61748008597908
#
#
# Share price: $0.5164102284189707
# Shares owned at the moment: 93
# Cash capital at the moment: $0.45925692709665356
#
#
# Price increase from previously bought: -13.891210089518536%
# Share price: $0.4458974538118591
# Shares owned at the moment: 0
# Cash capital at the moment: $41.81368185778717
#
#
# Share price: $0.38545782043500487
# Shares owned at the moment: 108
# Cash capital at the moment: $0.06975627813744012
#
#
# Price increase from previously bought: 26.498093083750042%
# Share price: $0.4889376836718209
# Shares owned at the moment: 0
# Cash capital at the moment: $52.72981162264356
#
#
# Share price: $0.5017582278425741
# Shares owned at the moment: 104
# Cash capital at the moment: $0.4034530738528801
#
#
# Price increase from previously bought: 6.824067647633858%
# Share price: $0.53747254474715
# Shares owned at the moment: 0
# Cash capital at the moment: $56.14688057975879
#
#
# Share price: $0.5347252291394664
# Shares owned at the moment: 104
# Cash capital at the moment: $0.38252533372039466
#
#
# Price increase from previously bought: 4.166211934008501%
# Share price: $0.5585347737425168
# Shares owned at the moment: 0
# Cash capital at the moment: $58.310400857651786
#
#
# Share price: $0.5860073184896668
# Shares owned at the moment: 99
# Cash capital at the moment: $0.13613583471595803
#
#
# Price increase from previously bought: 5.336023815186386%
# Share price: $0.6189743197865589
# Shares owned at the moment: 0
# Cash capital at the moment: $61.2460777350234
#
#
# Share price: $0.4687912265456817
# Shares owned at the moment: 130
# Cash capital at the moment: $0.1356254205946854
#
#
# Price increase from previously bought: -83.45696907760525%
# Share price: $0.0777655463322403
# Shares owned at the moment: 0
# Cash capital at the moment: $10.217345260972147
#
#
# Share price: $0.09608054705273604
# Shares owned at the moment: 106
# Cash capital at the moment: $0.004799793916253847
#
#
# Price increase from previously bought: -38.29395565313841%
# Share price: $0.05945054561174445
# Shares owned at the moment: 0
# Cash capital at the moment: $6.289227794715342
#
#
# Share price: $0.024652000576396597
# Shares owned at the moment: 254
# Cash capital at the moment: $0.0104002259079925
#
#
# Price increase from previously bought: 384.9963300768602%
# Share price: $0.11989009165578655
# Shares owned at the moment: 0
# Cash capital at the moment: $30.37874027745621
#
#
# Share price: $0.19681318201468057
# Shares owned at the moment: 153
# Cash capital at the moment: $0.1835142828774039
#
#
# Price increase from previously bought: -15.12268199115302%
# Share price: $0.16750913719548155
# Shares owned at the moment: 0
# Cash capital at the moment: $25.74193280431108
#
#
# Share price: $0.1189743197865588
# Shares owned at the moment: 215
# Cash capital at the moment: $0.0921104836271347
#
#
# Price increase from previously bought: 51.154544545123%
# Share price: $0.18032963769982846
# Shares owned at the moment: 0
# Cash capital at the moment: $38.75636269080023
#
#
# Share price: $0.225201411298246
# Shares owned at the moment: 171
# Cash capital at the moment: $0.14102039513716136
#
#
# Price increase from previously bought: 108.81098283924987%
# Share price: $0.47153845482055323
# Shares owned at the moment: 0
# Cash capital at the moment: $80.5523552110724
#
#
# Share price: $0.3918681361867874
# Shares owned at the moment: 204
# Cash capital at the moment: $0.3914174045669796
#
#
# Price increase from previously bought: -6.799596156453247%
# Share price: $0.3662270478452814
# Shares owned at the moment: 0
# Cash capital at the moment: $74.89628179116318
#
#
# Share price: $0.32868127453506213
# Shares owned at the moment: 227
# Cash capital at the moment: $0.08045318607555885
#
#
# Price increase from previously bought: 14.451800347681898%
# Share price: $0.377216135610391
# Shares owned at the moment: 0
# Cash capital at the moment: $85.47303879697954
#
#
#
#
# Capital at the end of test period: $85.47303879697954
# profit gained: -14.526961203020464%
#
#
# Capital at the end of test period if Buy and Hold: $59.80379974835048
# profit gained: -40.19620025164952%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.366972      8.000000       9.859155      93.055556
# 1       0.261468      6.172840       8.045977      90.000000
# 2       0.322275      4.597701       9.836066      92.063492
# 3       0.183486     11.250000       4.504505      96.296296
# 4       0.220183      6.521739       4.878049      86.363636
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         52.702703           43.661972          83.333333     -81.206352
# 1         54.320988           52.873563          81.632653     -97.130868
# 2         57.471264           55.000000          80.952381      31.619966
# 3         51.250000           47.272727          85.185185     685.749775
# 4         47.826087           50.617284          81.818182     -14.526961
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# 2         -54.689601
# 3        1576.179166
# 4         -40.196200
# Recession Test
#
#
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5929 - accuracy: 0.3014 - mse: 4.3880 - weighted_accuracy: 0.3014 - weighted_mse: 4.3880
# Test loss: 0.5929203629493713
# Test accuracy: 0.30136987566947937
#
#
# number of predictions: 219
# actual predicted buys: 6
# actual buys but predicted sell: 0
# actual buys but predicted hold: 5
# actual sells but predicted buy: 2
# actual predicted sells: 6
# actual sells but predicted hold: 3
# actual holds but predicted buy: 65
# actual holds but predicted sell: 78
# actual predicted holds: 54
# Percentage buys correct: 8.219178082191782%
# Percentage sells correct: 7.142857142857143%
# Percentage holds correct: 87.09677419354838%
# actual buys: 11
# actual sells: 11
# actual holds: 197
#
#
# Percentage low buys correct: 54.794520547945204%
# Percentage high sells correct: 58.333333333333336%
# Percentage mid holds correct: 78.68852459016394%
#
#
# Capital: 100
# Share price: $0.6915789433232307
# Shares owned at the moment: 144
# Cash capital at the moment: $0.13876689989878344
#
#
# Price increase from previously bought: -36.703746041331385%
# Share price: $0.438947359092348
# Shares owned at the moment: 0
# Cash capital at the moment: $63.17336345499633
#
#
# Share price: $0.4060526228694045
# Shares owned at the moment: 155
# Cash capital at the moment: $0.06212697974054038
#
#
# Price increase from previously bought: -28.388761361355964%
# Share price: $0.2915789558715766
# Shares owned at the moment: 0
# Cash capital at the moment: $45.132579609894655
#
#
# Share price: $0.17842104569696665
# Shares owned at the moment: 252
# Cash capital at the moment: $0.046830309591058494
#
#
# Price increase from previously bought: 20.31810863934542%
# Share price: $0.21526317787302457
# Shares owned at the moment: 0
# Cash capital at the moment: $54.14397375132724
#
#
# Share price: $0.1547368268326052
# Shares owned at the moment: 348
# Cash capital at the moment: $0.14747487030182072
#
#
# Price increase from previously bought: 30.254039813304125%
# Share price: $0.20210523319046308
# Shares owned at the moment: 0
# Cash capital at the moment: $70.2866813124197
#
#
# Share price: $0.08499998980446886
# Shares owned at the moment: 824
# Cash capital at the moment: $0.054079736640431975
#
#
# Price increase from previously bought: 78.45661922545268%
# Share price: $0.15210525044443896
# Shares owned at the moment: 0
# Cash capital at the moment: $125.04413560535103
#
#
# Share price: $0.08499998980446886
# Shares owned at the moment: 1467
# Cash capital at the moment: $0.006239353326520813
#
#
# Price increase from previously bought: 44.49428023079713%
# Share price: $0.12315787880374483
# Shares owned at the moment: 0
# Cash capital at the moment: $180.18199788585616
#
#
# Share price: $0.4021052269162901
# Shares owned at the moment: 446
# Cash capital at the moment: $0.3498846203779351
#
#
# Price increase from previously bought: 29.747909932780225%
# Share price: $0.5231578662553991
# Shares owned at the moment: 0
# Cash capital at the moment: $233.03663984732367
#
#
# Share price: $0.6415789292063412
# Shares owned at the moment: 362
# Cash capital at the moment: $0.14637565060323254
#
#
# Price increase from previously bought: 17.519313557360583%
# Share price: $0.7560525962041695
# Shares owned at the moment: 0
# Cash capital at the moment: $273.0847651169913
#
#
# Share price: $0.5863157623131194
# Shares owned at the moment: 464
# Cash capital at the moment: $0.2861124909923092
#
#
# Price increase from previously bought: 8.006391215330888%
# Share price: $0.6349999568650604
# Shares owned at the moment: 0
# Cash capital at the moment: $294.1158325314205
#
#
# Share price: $0.6678946930880041
# Shares owned at the moment: 439
# Cash capital at the moment: $0.103746397556165
#
#
# Price increase from previously bought: -10.29396849474672%
# Share price: $0.6007894638188991
# Shares owned at the moment: 0
# Cash capital at the moment: $263.12501793385746
#
#
# Share price: $0.6113157693715641
# Shares owned at the moment: 429
# Cash capital at the moment: $0.14935309454034496
#
#
# Price increase from previously bought: -2.850026981255327%
# Share price: $0.5955263110425664
# Shares owned at the moment: 0
# Cash capital at the moment: $254.92756836634885
#
#
# Share price: $0.5850000054899009
# Shares owned at the moment: 434
# Cash capital at the moment: $0.33936847717964724
#
#
# Price increase from previously bought: 7.127798787202977%
# Share price: $0.6284210472655098
# Shares owned at the moment: 0
# Cash capital at the moment: $272.32408247049955
#
#
# Share price: $0.6836842141587314
# Shares owned at the moment: 397
# Cash capital at the moment: $0.1550372086754237
#
#
# Price increase from previously bought: -0.27424582398404285%
# Share price: $0.6836842141587314
# Shares owned at the moment: 0
# Cash capital at the moment: $270.831257988884
#
#
# Share price: $0.703421068440844
# Shares owned at the moment: 383
# Cash capital at the moment: $0.6801105357054098
#
#
# Price increase from previously bought: -17.4361795429271%
# Share price: $0.5823684291017353
# Shares owned at the moment: 0
# Cash capital at the moment: $223.1138393337186
#
#
# Share price: $0.5784210331486206
# Shares owned at the moment: 384
# Cash capital at the moment: $0.38934999364335
#
#
# Price increase from previously bought: 10.841687979461433%
# Share price: $0.6428947487712893
# Shares owned at the moment: 0
# Cash capital at the moment: $246.58203666711594
#
#
# Share price: $0.5586841788665085
# Shares owned at the moment: 440
# Cash capital at the moment: $0.08499010942375662
#
#
# Price increase from previously bought: 24.387097762668787%
# Share price: $0.6968420960995632
# Shares owned at the moment: 0
# Cash capital at the moment: $305.85233345695104
#
#
# Share price: $0.6744736654292847
# Shares owned at the moment: 452
# Cash capital at the moment: $0.15186591678576633
#
#
# Price increase from previously bought: -43.269548695989776%
# Share price: $0.38368419219912614
# Shares owned at the moment: 0
# Cash capital at the moment: $173.10020133988726
#
#
# Share price: $0.5402631441493446
# Shares owned at the moment: 319
# Cash capital at the moment: $0.28231251304129046
#
#
# Price increase from previously bought: 14.055566784460138%
# Share price: $0.6178947417128444
# Shares owned at the moment: 0
# Cash capital at the moment: $196.84868695727107
#
#
# Share price: $0.5034210119732866
# Shares owned at the moment: 389
# Cash capital at the moment: $0.4793786721041613
#
#
# Price increase from previously bought: 10.673173662896707%
# Share price: $0.5586841788665085
# Shares owned at the moment: 0
# Cash capital at the moment: $217.2098718508335
#
#
# Share price: $0.7389473183102233
# Shares owned at the moment: 293
# Cash capital at the moment: $0.10290078420959503
#
#
# Price increase from previously bought: -0.9845425758060689%
# Share price: $0.7336841655338908
# Shares owned at the moment: 0
# Cash capital at the moment: $214.48119526926067
#
#
# Share price: $0.6836842141587314
# Shares owned at the moment: 312
# Cash capital at the moment: $0.5851193959883005
#
#
# Price increase from previously bought: -1.8096677895451219%
# Share price: $0.6731579086060666
# Shares owned at the moment: 0
# Cash capital at the moment: $210.0328173954971
#
#
#
#
# Capital at the end of test period: $210.0328173954971
# profit gained: 110.03281739549709%
#
#
# Capital at the end of test period if Buy and Hold: $67.49022981476901
# profit gained: -32.50977018523099%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.306977      6.451613       6.666667      90.322581
# 1       0.344186      6.493506       7.812500      86.486486
# 2       0.328638      9.090909       8.955224      96.551724
# 3       0.374429      9.459459      13.157895      94.202899
# 4       0.301370      8.219178       7.142857      87.096774
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         50.537634           62.711864          82.258065     -29.890720
# 1         54.545455           57.142857          83.783784      19.213921
# 2         50.000000           50.000000          86.206897     -76.779635
# 3         47.297297           55.263158          82.352941     406.413497
# 4         54.794521           58.333333          78.688525     110.032817
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
# 2         -84.289887
# 3         -31.900348
# 4         -32.509770

# %%
df = nr_log_hist['0_epochs_logs']
df['Profit gained']
# Out:
# 0      18.571381
# 1     -92.708261
# 2     -15.548395
# 3    5476.121382
# 4     -58.591094
# Name: Profit gained, dtype: float64

# %%
C6LSI_acc = []
O39SI_acc = []
CNOOC_acc = []
JPM_acc = []
AXL_acc = []

C6LSI_correct_buys = []
O39SI_correct_buys = []
CNOOC_correct_buys = []
JPM_correct_buys = []
AXL_correct_buys = []

C6LSI_correct_sells = []
O39SI_correct_sells = []
CNOOC_correct_sells = []
JPM_correct_sells = []
AXL_correct_sells = []

C6LSI_correct_holds = []
O39SI_correct_holds = []
CNOOC_correct_holds = []
JPM_correct_holds = []
AXL_correct_holds = []

C6LSI_correct_low_buys = []
O39SI_correct_low_buys = []
CNOOC_correct_low_buys = []
JPM_correct_low_buys = []
AXL_correct_low_buys = []

C6LSI_correct_high_sells = []
O39SI_correct_high_sells = []
CNOOC_correct_high_sells = []
JPM_correct_high_sells = []
AXL_correct_high_sells = []

C6LSI_correct_mid_holds = []
O39SI_correct_mid_holds = []
CNOOC_correct_mid_holds = []
JPM_correct_mid_holds = []
AXL_correct_mid_holds = []

C6LSI_profit = []
O39SI_profit = []
CNOOC_profit = []
JPM_profit = []
AXL_profit = []

for key,value in nr_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    C6LSI_acc.append(acc[0])
    O39SI_acc.append(acc[1])
    CNOOC_acc.append(acc[2])
    JPM_acc.append(acc[3]) 
    AXL_acc.append(acc[4]) 

    C6LSI_correct_buys.append(correct_buys[0])
    O39SI_correct_buys.append(correct_buys[1]) 
    CNOOC_correct_buys.append(correct_buys[2]) 
    JPM_correct_buys.append(correct_buys[3]) 
    AXL_correct_buys.append(correct_buys[4])
    

    C6LSI_correct_sells.append(correct_sells[0]) 
    O39SI_correct_sells.append(correct_sells[1]) 
    CNOOC_correct_sells.append(correct_sells[2]) 
    JPM_correct_sells.append(correct_sells[3]) 
    AXL_correct_sells.append(correct_sells[4]) 
    

    C6LSI_correct_holds.append(correct_holds[0]) 
    O39SI_correct_holds.append(correct_holds[1])  
    CNOOC_correct_holds.append(correct_holds[2])  
    JPM_correct_holds.append(correct_holds[3])  
    AXL_correct_holds.append(correct_holds[4])  
     

    C6LSI_correct_low_buys.append(correct_low_buys[0])  
    O39SI_correct_low_buys.append(correct_low_buys[1])  
    CNOOC_correct_low_buys.append(correct_low_buys[2])  
    JPM_correct_low_buys.append(correct_low_buys[3])   
    AXL_correct_low_buys.append(correct_low_buys[4])   
    

    C6LSI_correct_high_sells.append(correct_high_sells[0]) 
    O39SI_correct_high_sells.append(correct_high_sells[1]) 
    CNOOC_correct_high_sells.append(correct_high_sells[2]) 
    JPM_correct_high_sells.append(correct_high_sells[3]) 
    AXL_correct_high_sells.append(correct_high_sells[4]) 
    

    C6LSI_correct_mid_holds.append(correct_mid_holds[0])  
    O39SI_correct_mid_holds.append(correct_mid_holds[1])  
    CNOOC_correct_mid_holds.append(correct_mid_holds[2])   
    JPM_correct_mid_holds.append(correct_mid_holds[3])   
    AXL_correct_mid_holds.append(correct_mid_holds[4])   
    

    C6LSI_profit.append(profit[0]) 
    O39SI_profit.append(profit[1]) 
    CNOOC_profit.append(profit[2]) 
    JPM_profit.append(profit[3])  
    AXL_profit.append(profit[4])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(C6LSI_acc)
plt.plot(O39SI_acc)
plt.plot(CNOOC_acc)
plt.plot(JPM_acc)
plt.plot(AXL_acc)
plt.title('Non-Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['C6L.SI_acc','O39.SI_acc','CNOOC_acc','JPM_acc','AXL_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_low_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_low_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_high_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_high_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_mid_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_mid_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_profit")

plt.subplot(3, 4, 2)
plt.plot(O39SI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_profit")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_profit")

plt.subplot(3, 4, 4)
plt.plot(JPM_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_profit")

plt.subplot(3, 4, 5)
plt.plot(AXL_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_profit")
# Out:
# Text(0.5, 1.0, 'AXL_profit')

# %%
C6LSI_acc = []
O39SI_acc = []
CNOOC_acc = []
JPM_acc = []
AXL_acc = []

C6LSI_correct_buys = []
O39SI_correct_buys = []
CNOOC_correct_buys = []
JPM_correct_buys = []
AXL_correct_buys = []

C6LSI_correct_sells = []
O39SI_correct_sells = []
CNOOC_correct_sells = []
JPM_correct_sells = []
AXL_correct_sells = []

C6LSI_correct_holds = []
O39SI_correct_holds = []
CNOOC_correct_holds = []
JPM_correct_holds = []
AXL_correct_holds = []

C6LSI_correct_low_buys = []
O39SI_correct_low_buys = []
CNOOC_correct_low_buys = []
JPM_correct_low_buys = []
AXL_correct_low_buys = []

C6LSI_correct_high_sells = []
O39SI_correct_high_sells = []
CNOOC_correct_high_sells = []
JPM_correct_high_sells = []
AXL_correct_high_sells = []

C6LSI_correct_mid_holds = []
O39SI_correct_mid_holds = []
CNOOC_correct_mid_holds = []
JPM_correct_mid_holds = []
AXL_correct_mid_holds = []

C6LSI_profit = []
O39SI_profit = []
CNOOC_profit = []
JPM_profit = []
AXL_profit = []

for key,value in r_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    C6LSI_acc.append(acc[0])
    O39SI_acc.append(acc[1])
    CNOOC_acc.append(acc[2])
    JPM_acc.append(acc[3]) 
    AXL_acc.append(acc[4]) 

    C6LSI_correct_buys.append(correct_buys[0])
    O39SI_correct_buys.append(correct_buys[1]) 
    CNOOC_correct_buys.append(correct_buys[2]) 
    JPM_correct_buys.append(correct_buys[3]) 
    AXL_correct_buys.append(correct_buys[4])
    

    C6LSI_correct_sells.append(correct_sells[0]) 
    O39SI_correct_sells.append(correct_sells[1]) 
    CNOOC_correct_sells.append(correct_sells[2]) 
    JPM_correct_sells.append(correct_sells[3]) 
    AXL_correct_sells.append(correct_sells[4]) 
    

    C6LSI_correct_holds.append(correct_holds[0]) 
    O39SI_correct_holds.append(correct_holds[1])  
    CNOOC_correct_holds.append(correct_holds[2])  
    JPM_correct_holds.append(correct_holds[3])  
    AXL_correct_holds.append(correct_holds[4])  
     

    C6LSI_correct_low_buys.append(correct_low_buys[0])  
    O39SI_correct_low_buys.append(correct_low_buys[1])  
    CNOOC_correct_low_buys.append(correct_low_buys[2])  
    JPM_correct_low_buys.append(correct_low_buys[3])   
    AXL_correct_low_buys.append(correct_low_buys[4])   
    

    C6LSI_correct_high_sells.append(correct_high_sells[0]) 
    O39SI_correct_high_sells.append(correct_high_sells[1]) 
    CNOOC_correct_high_sells.append(correct_high_sells[2]) 
    JPM_correct_high_sells.append(correct_high_sells[3]) 
    AXL_correct_high_sells.append(correct_high_sells[4]) 
    

    C6LSI_correct_mid_holds.append(correct_mid_holds[0])  
    O39SI_correct_mid_holds.append(correct_mid_holds[1])  
    CNOOC_correct_mid_holds.append(correct_mid_holds[2])   
    JPM_correct_mid_holds.append(correct_mid_holds[3])   
    AXL_correct_mid_holds.append(correct_mid_holds[4])   
    

    C6LSI_profit.append(profit[0]) 
    O39SI_profit.append(profit[1]) 
    CNOOC_profit.append(profit[2]) 
    JPM_profit.append(profit[3])  
    AXL_profit.append(profit[4])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(C6LSI_acc)
plt.plot(O39SI_acc)
plt.plot(CNOOC_acc)
plt.plot(JPM_acc)
plt.plot(AXL_acc)
plt.title('Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['C6L.SI_acc','O39.SI_acc','CNOOC_acc','JPM_acc','AXL_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_low_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_low_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_high_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_high_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_mid_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_mid_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_profit")

plt.subplot(3, 4, 2)
plt.plot(O39SI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_profit")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_profit")

plt.subplot(3, 4, 4)
plt.plot(JPM_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_profit")

plt.subplot(3, 4, 5)
plt.plot(AXL_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_profit")
# Out:
# Text(0.5, 1.0, 'AXL_profit')
