# %%
import os
seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
experiment = '50 percent More buy LSTM Time Series - cyclic'

# %%
import requests
import lxml
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.utils import compute_class_weight
import tensorflow as tf
from pil import Image
from sklearn import preprocessing
import tensorflow_addons as tfa
import glob
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
import math

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
# gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
np.random.seed(seed)
tf.random.set_seed(seed)

session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, 
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), 
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)

# %% [markdown]
# ## Prepare Test Data

# %%
nr_test_sets = ['C6L.SI','O39.SI','0883.HK','JPM','AXL']
nr_test_data = {}

for name in nr_test_sets:

    df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    labels = []
    data_15 = []
    sequential = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15.append(np.array(i[0:-1]))
            labels.append(i[-1])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_arr = min_max_scaler.fit_transform(data_15)
            sequential.append(data_15_arr)
            data_15 = data_15[1:15]
        else:
            data_15.append(np.array(i[0:-1]))
            count+= 1
            
    X = sequential
    X  = np.array(X).reshape(-1, 15, 4)
    y = labels
    y = np.array(y)
    print(X.shape)
    
    y = to_categorical(y, 3)
    
    nr_test_data['{}_X'.format(name)] = X
    nr_test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2019-01-21         9.59  9.538960 -32.758553  6890900.0     2.0
# 2019-01-22         9.63  9.552966 -25.862007  7759500.0     2.0
# 2019-01-23         9.61  9.561740 -29.310362  7108100.0     1.0
# 2019-01-24         9.50  9.552242 -48.275822  6126400.0     2.0
# 2019-01-25         9.74  9.581128  -8.888884  8160300.0     2.0
# (218, 15, 4)
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-21        11.75  11.523654 -10.869606  21160951.0     2.0
# 2019-01-22        11.73  11.555399 -13.978517  18040951.0     2.0
# 2019-01-23        11.50  11.546876 -38.709667  14286851.0     1.0
# 2019-01-24        11.38  11.521203 -51.612890   8454651.0     2.0
# 2019-01-25        11.41  11.504095 -80.357185  12469051.0     2.0
# (218, 15, 4)
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2019-01-22        13.12  12.552209  -3.030323  489168111.0     2.0
# 2019-01-23        12.94  12.611869 -13.043517  449876554.0     2.0
# 2019-01-24        12.62  12.613120 -33.333352  395082483.0     2.0
# 2019-01-25        12.80  12.641871 -37.254896  441807090.0     2.0
# 2019-01-28        13.06  12.706198 -11.764689  494043477.0     2.0
# (211, 15, 4)
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22   104.589996  101.198442  -3.459880  84335200.0     2.0
# 2019-01-23   102.940002  101.466374 -21.874992  67251500.0     2.0
# 2019-01-24   102.680000  101.653086 -27.040213  55104800.0     2.0
# 2019-01-25   102.739998  101.820303 -32.628441  66401600.0     2.0
# 2019-01-28   103.389999  102.061795 -23.968276  80771000.0     2.0
# (218, 15, 4)
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22        14.61  13.028180  -0.258404  23356600.0     2.0
# 2019-01-23        14.52  13.257691  -3.886001  21174700.0     2.0
# 2019-01-24        14.18  13.399585 -13.535906  19629300.0     2.0
# 2019-01-25        14.38  13.550418  -8.579880  20903300.0     2.0
# 2019-01-28        14.71  13.728815  -4.790414  22287500.0     2.0
# (218, 15, 4)

# %%
r_test_sets = ['C6L.SI','O39.SI','0883.HK','JPM','AXL']
r_test_data = {}

for name in nr_test_sets:

    df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test2.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    labels = []
    data_15 = []
    sequential = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15.append(np.array(i[0:-1]))
            labels.append(i[-1])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_arr = min_max_scaler.fit_transform(data_15)
            sequential.append(data_15_arr)
            data_15 = data_15[1:15]
        else:
            data_15.append(np.array(i[0:-1]))
            count+= 1
            
    X = sequential
    X  = np.array(X).reshape(-1, 15, 4)
    y = labels
    y = np.array(y)
    print(X.shape)
    
    y = to_categorical(y, 3)
    
    r_test_data['{}_X'.format(name)] = X
    r_test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2020-01-22         8.84  8.979182 -96.551645  -851200.0     2.0
# 2020-01-23         8.93  8.971615 -65.517105  1644900.0     2.0
# 2020-01-24         8.85  8.952905 -92.307523  -246900.0     2.0
# 2020-01-28         8.82  8.932458 -75.000000 -1718200.0     2.0
# 2020-01-29         8.56  8.875157 -86.885115 -5499900.0     2.0
# (215, 15, 4)
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22        11.12  11.072811 -24.444379  27489400.0     2.0
# 2020-01-23        11.19  11.090840  -8.888884  31751200.0     2.0
# 2020-01-24        11.11  11.093787 -26.666653  27359800.0     2.0
# 2020-01-28        11.10  11.094743 -28.888715  24699300.0     2.0
# 2020-01-29        10.90  11.064783 -71.739257  16499235.0     2.0
# (215, 15, 4)
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2020-01-22        13.00  13.393678 -83.870980  104646165.0     2.0
# 2020-01-23        13.34  13.385420 -57.377021  145802714.0     2.0
# 2020-01-24        13.00  13.326125 -85.245880   96260120.0     2.0
# 2020-01-29        13.04  13.282106 -80.645176  122828433.0     2.0
# 2020-01-30        12.46  13.155628 -90.804605   53693706.0     2.0
# (213, 15, 4)
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22   136.839996  137.690058 -77.454723  33776700.0     2.0
# 2020-01-23   136.679993  137.534664 -80.363881  26227600.0     2.0
# 2020-01-24   136.539993  137.381637 -69.867648  16881900.0     2.0
# 2020-01-27   133.149994  136.730615 -90.166021   1715500.0     1.0
# 2020-01-28   132.029999  136.007444 -79.004573 -11145000.0     2.0
# (219, 15, 4)
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2020-01-22         9.39  9.715390 -73.059349 -3592400.0     2.0
# 2020-01-23         9.34  9.657637 -75.342463 -4550300.0     2.0
# 2020-01-24         9.50  9.633386 -65.000010 -3092000.0     2.0
# 2020-01-27         9.31  9.583634 -66.883101 -4332600.0     2.0
# 2020-01-28         9.39  9.553844 -61.688301 -2300800.0     2.0
# (219, 15, 4)

# %% [markdown]
# ## Train Accumulation Phase Stock Data

# %%
def pred_acc(actual, predictions, logger):

    hold = 0
    sell = 0
    buy = 0
    pred_hold = 0
    pred_sell = 0
    pred_buy = 0
    buy_buy = 0
    buy_sell = 0
    buy_hold = 0
    sell_buy = 0
    sell_sell = 0
    sell_hold = 0
    hold_buy = 0
    hold_sell = 0
    hold_hold = 0

    for i in range (0,len(actual)):
        if actual[i]==1 and predictions[i] == 1:
            buy_buy += 1
            buy += 1
            pred_buy += 1
        elif actual[i]==1 and predictions[i] == 0:
            buy_sell += 1
            buy += 1
            pred_sell += 1
        elif actual[i]==1 and predictions[i] == 2:
            buy_hold += 1
            buy += 1
            pred_hold += 1
        elif actual[i]==0 and predictions[i] == 1:
            sell_buy += 1
            sell += 1
            pred_buy += 1
        elif actual[i]==0 and predictions[i] == 0:
            sell_sell += 1
            sell += 1
            pred_sell += 1
        elif actual[i]==0 and predictions[i] == 2:
            sell_hold += 1
            sell += 1
            pred_hold += 1
        elif actual[i]==2 and predictions[i] == 1:
            hold_buy += 1
            hold += 1
            pred_buy += 1
        elif actual[i]==2 and predictions[i] == 0:
            hold_sell += 1
            hold += 1
            pred_sell += 1
        elif actual[i]==2 and predictions[i] == 2:
            hold_hold += 1
            hold += 1
            pred_hold += 1

    print("number of predictions: " + str(len(actual)))
    print("actual predicted buys: " + str(buy_buy) )
    print("actual buys but predicted sell: " + str(buy_sell) )
    print("actual buys but predicted hold: " + str(buy_hold))
    print("actual sells but predicted buy: " + str(sell_buy) )
    print("actual predicted sells: " + str(sell_sell))
    print("actual sells but predicted hold: " + str(sell_hold) )
    print("actual holds but predicted buy: " + str(hold_buy) )
    print("actual holds but predicted sell: " + str(hold_sell))
    print("actual predicted holds: " + str(hold_hold) )
    
    if pred_buy !=0:
        Percentage_buys_correct = 100*buy_buy/pred_buy
    else:
        Percentage_buys_correct = 0
        
    if pred_sell !=0:
        Percentage_sells_correct = 100*sell_sell/pred_sell
    else:
        Percentage_sells_correct = 0
        
    if pred_hold !=0:
        Percentage_holds_correct = 100*hold_hold/pred_hold
    else:
        Percentage_holds_correct = 0

    print("Percentage buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage holds correct: " + str(Percentage_holds_correct) + "%")

    print("actual buys: " + str(buy))
    print("actual sells: " + str(sell))
    print("actual holds: " + str(hold))
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def correct_maxima_minima(predictions, price, logger):
    correct_maxima = 0 
    correct_minima = 0
    correct_hold = 0

    hold = 0
    buy = 0
    sell = 0

#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):
        if i < 4:
            prices = price[i:i+9]
            prices.sort(key = float)
#             if i == 0:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1

        else:
            prices = price[i:i+5]
            prices = prices + price[i-4:i] 
            prices.sort(key = float)
#             if i == 10:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1
                    
    if buy !=0:
        Percentage_buys_correct = 100*correct_minima/buy
    else:
        Percentage_buys_correct = 0
        
    if sell !=0:
        Percentage_sells_correct = 100*correct_maxima/sell
    else:
        Percentage_sells_correct = 0
        
    if hold !=0:
        Percentage_holds_correct = 100*correct_hold/hold
    else:
        Percentage_holds_correct = 0

    print("Percentage low buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage high sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage mid holds correct: " + str(Percentage_holds_correct) + "%")
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %% [markdown]
# ### Creating Training Data and Model

# %%
labels = []
sequential = []

train_sets = ['C6L.SI','O39.SI','600104.SS','0883.HK','1398.HK','ANF','AXL','JPM','CTB','TROX']

for name in train_sets:
    seed = 10
    df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    plt.figure(figsize=(15,5))
    plt.plot(df['previous_1d'].values)
    plt.plot(df['EMA_12'].values)
    plt.show()

    data_15 = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15.append(np.array(i[0:-1]))
            labels.append(i[-1])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_arr = min_max_scaler.fit_transform(data_15)
            sequential.append(data_15_arr)
            data_15 = data_15[1:15]
        else:
            data_15.append(np.array(i[0:-1]))
            count+= 1
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels
# Date
# 2000-01-21    19.000000  19.215335 -37.499990   388000.0     2.0
# 2000-01-24    18.400000  19.089899 -50.000000 -2311000.0     2.0
# 2000-01-25    18.100000  18.937607 -48.780483 -3542000.0     2.0
# 2000-01-26    17.700001  18.747206 -85.714237 -6261000.0     2.0
# 2000-01-27    17.799999  18.601482 -82.142864 -4565000.0     2.0
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2000-01-21     6.793788  7.018572 -90.000010 -1965914.0     2.0
# 2000-01-24     6.890842  6.998922 -77.777802  6276910.0     2.0
# 2000-01-25     6.793788  6.967363 -85.714286  -511055.0     2.0
# 2000-01-26     6.745261  6.933193 -86.666549 -7435027.0     2.0
# 2000-01-27     6.890842  6.926678 -66.666601 -3725757.0     2.0
#             previous_1d    EMA_12   willr_14        OBV_7  labels
# Date
# 2000-01-24     3.189194  3.249583 -69.696967   61394527.0     2.0
# 2000-01-25     3.205140  3.242745 -79.136806   75032521.0     2.0
# 2000-01-26     3.402870  3.267380 -34.532549  127274101.0     2.0
# 2000-01-27     3.284870  3.270071 -62.500055   91746305.0     2.0
# 2000-01-28     3.252978  3.267441 -69.852957   65314909.0     2.0
#             previous_1d    EMA_12   willr_14       OBV_7  labels
# Date
# 2004-04-07        3.250  3.264699 -57.142857  31539206.0     2.0
# 2004-04-08        3.200  3.254745 -78.947368 -24878594.0     2.0
# 2004-04-13        3.250  3.254015 -52.631579  10937473.0     0.0
# 2004-04-14        3.375  3.272628 -10.416706  98972973.0     2.0
# 2004-04-15        3.275  3.272993 -52.083331  47190715.0     2.0
#             previous_1d    EMA_12   willr_14         OBV_7  labels
# Date
# 2006-11-17     3.953848  3.652647 -15.942120  1.897904e+10     2.0
# 2006-11-20     3.934226  3.695967 -18.840636  1.837444e+10     2.0
# 2006-11-21     3.934226  3.732622 -19.403036  1.837444e+10     2.0
# 2006-11-22     3.934226  3.763638 -19.697025  1.837444e+10     0.0
# 2006-11-23     4.051959  3.807995  -1.562480  1.907354e+10     2.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2000-01-21      21.5000  24.211693 -82.142857  -6805500.0     2.0
# 2000-01-24      20.2500  23.602201 -92.465753  -8986800.0     1.0
# 2000-01-25      20.1875  23.076863 -92.307692 -11383100.0     2.0
# 2000-01-26      20.8750  22.738115 -82.786885  -9392500.0     2.0
# 2000-01-27      22.8750  22.759174 -56.557377  -6811000.0     2.0
#             previous_1d     EMA_12   willr_14     OBV_7  labels
# Date
# 2000-01-21      16.0625  14.895987 -18.478261  298700.0     2.0
# 2000-01-24      15.8750  15.046605 -22.222222  293100.0     2.0
# 2000-01-25      15.7500  15.154819 -26.190476  286300.0     2.0
# 2000-01-26      15.7500  15.246386 -29.729730  286300.0     2.0
# 2000-01-27      16.0000  15.362326 -25.000000  311700.0     0.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2000-01-21    49.375000  48.388499 -42.592593  -2894250.0     2.0
# 2000-01-24    48.625000  48.424884 -39.516144  -8054850.0     2.0
# 2000-01-25    48.666668  48.462081 -38.709668  -1595700.0     2.0
# 2000-01-26    49.750000  48.660222 -17.741956   5984250.0     2.0
# 2000-01-27    52.291668  49.218906  -5.232557  14370900.0     2.0
#             previous_1d     EMA_12    willr_14     OBV_7  labels
# Date
# 2000-01-21      13.7500  14.817184  -97.297297 -827200.0     2.0
# 2000-01-24      14.0625  14.701079  -77.500000 -518900.0     2.0
# 2000-01-25      13.6875  14.545144  -92.500000 -906100.0     2.0
# 2000-01-26      13.7500  14.422814  -90.000000 -652700.0     2.0
# 2000-01-27      13.5000  14.280843 -100.000000 -848400.0     2.0
#             previous_1d     EMA_12  willr_14      OBV_7  labels
# Date
# 2010-12-21    18.799999  18.175961      -0.0  1579000.0     0.0
# 2010-12-22    19.000000  18.302736      -0.0  1699000.0     2.0
# 2010-12-23    19.000000  18.410008      -0.0  1699000.0     2.0
# 2010-12-27    19.000000  18.500776      -0.0  1699000.0     2.0
# 2010-12-28    19.000000  18.577580      -0.0  1699000.0     2.0

# %%
X = sequential
X  = np.array(X).reshape(-1, 15, 4)
X.shape
# Out:
# (41550, 15, 4)

# %%
y = labels
y = np.array(y)
y.shape
# Out:
# (41550,)

# %%
from collections import Counter

Counter(y)
# Out:
# Counter({2.0: 37853, 0.0: 1852, 1.0: 1845})

# %%
X = sequential
y = labels

class_0 = []
class_1 = []
class_2 = []

class_0_labels = []
class_1_labels = []
class_2_labels = []

for i in range (0,len(y)):
    if y[i] == 0:
        class_0.append(X[i])
        class_0_labels.append(y[i])
    if y[i] == 1:
        class_1.append(X[i])
        class_1_labels.append(y[i])
    if y[i] == 2:
        class_2.append(X[i])
        class_2_labels.append(y[i])
        
class_0 = class_0[0:923]
class_1 = class_1[0:1845]
class_2 = class_2[0:923]

class_0_labels = class_0_labels[0:923]
class_1_labels = class_1_labels[0:1845]
class_2_labels = class_2_labels[0:923]

X = class_0 + class_1 + class_2
y = class_0_labels + class_1_labels + class_2_labels

X  = np.array(X).reshape(-1, 15, 4)
y = np.array(y)

print(X.shape)

Counter(y)
# Out:
# (3691, 15, 4)
# Counter({0.0: 923, 1.0: 1845, 2.0: 923})

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization,Activation
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(LSTM(100, input_shape=(X_train.shape[1:]), return_sequences=True,kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(LSTM(100, kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# model.add(Dense(100, kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))

model.add(Dense(75, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(50, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "LSTM_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))

epochs = 0 
histories = {}
log_hist = {}

epochs = 0 
histories = {}
nr_log_hist = {}
r_log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    nr_log  = pd.DataFrame(columns = column_names)
    r_log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['C6L.SI','O39.SI','0883.HK','JPM','AXL']
    
    for name in test_sets:
        
        print('\n')
        print(name)
        print('\n')
        
        print('Non-Recession Test')
        print('\n')
        
        X = nr_test_data['{}_X'.format(name)]
        y = nr_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(nr_log)
        nr_log.loc[df_length] = logger
        print(nr_log.head(20))
        logger = []
        
        print('Recession Test')
        print('\n')
        
        X = r_test_data['{}_X'.format(name)]
        y = r_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test2.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(r_log)
        r_log.loc[df_length] = logger
        print(r_log.head(20))
        logger = []

    nr_log.to_csv('non_recession_{}_{}epochs.csv'.format(experiment,epochs))
    nr_log_hist['{}_epochs_logs'.format(epochs)] = nr_log
    r_log.to_csv('recession_{}_{}epochs.csv'.format(experiment,epochs))
    r_log_hist['{}_epochs_logs'.format(epochs)] = r_log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[0 0 1 ... 2 2 1] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  1/24 [>.............................] - ETA: 0s - loss: 0.3701 - accuracy: 0.2500 - mse: 0.4767 - weighted_accuracy: 0.2486 - weighted_mse: 0.4751WARNING:tensorflow:From C:\Users\Shearman Chua\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/24 [=>............................] - ETA: 1s - loss: 0.3820 - accuracy: 0.2852 - mse: 0.4776 - weighted_accuracy: 0.2912 - weighted_mse: 0.4771WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0120s vs `on_train_batch_end` time: 0.1271s). Check your callbacks.
# 24/24 [==============================] - 1s 59ms/step - loss: 0.2836 - accuracy: 0.3635 - mse: 0.5111 - weighted_accuracy: 0.3670 - weighted_mse: 0.5124 - val_loss: 0.2975 - val_accuracy: 0.4790 - val_mse: 0.3459 - val_weighted_accuracy: 0.4790 - val_weighted_mse: 0.3459
# Epoch 2/20
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2042 - accuracy: 0.4922 - mse: 0.7756 - weighted_accuracy: 0.4664 - weighted_mse: 0.7903 - val_loss: 0.2875 - val_accuracy: 0.4993 - val_mse: 0.3595 - val_weighted_accuracy: 0.4993 - val_weighted_mse: 0.3595
# Epoch 3/20
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1841 - accuracy: 0.5366 - mse: 0.9950 - weighted_accuracy: 0.5036 - weighted_mse: 1.0093 - val_loss: 0.2754 - val_accuracy: 0.4993 - val_mse: 0.3827 - val_weighted_accuracy: 0.4993 - val_weighted_mse: 0.3827
# Epoch 4/20
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1757 - accuracy: 0.5644 - mse: 1.1319 - weighted_accuracy: 0.5375 - weighted_mse: 1.1467 - val_loss: 0.2638 - val_accuracy: 0.4993 - val_mse: 0.4099 - val_weighted_accuracy: 0.4993 - val_weighted_mse: 0.4099
# Epoch 5/20
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1714 - accuracy: 0.5962 - mse: 1.1861 - weighted_accuracy: 0.5571 - weighted_mse: 1.2044 - val_loss: 0.2528 - val_accuracy: 0.4993 - val_mse: 0.4404 - val_weighted_accuracy: 0.4993 - val_weighted_mse: 0.4404
# Epoch 6/20
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1677 - accuracy: 0.6081 - mse: 1.2275 - weighted_accuracy: 0.5847 - weighted_mse: 1.2444 - val_loss: 0.2426 - val_accuracy: 0.4993 - val_mse: 0.4747 - val_weighted_accuracy: 0.4993 - val_weighted_mse: 0.4747
# Epoch 7/20
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1647 - accuracy: 0.6345 - mse: 1.2510 - weighted_accuracy: 0.5949 - weighted_mse: 1.2724 - val_loss: 0.2329 - val_accuracy: 0.4993 - val_mse: 0.5130 - val_weighted_accuracy: 0.4993 - val_weighted_mse: 0.5130
# Epoch 8/20
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1615 - accuracy: 0.6433 - mse: 1.2579 - weighted_accuracy: 0.6116 - weighted_mse: 1.2763 - val_loss: 0.2243 - val_accuracy: 0.4993 - val_mse: 0.5542 - val_weighted_accuracy: 0.4993 - val_weighted_mse: 0.5542
# Epoch 9/20
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1592 - accuracy: 0.6430 - mse: 1.2892 - weighted_accuracy: 0.6068 - weighted_mse: 1.3109 - val_loss: 0.2155 - val_accuracy: 0.4993 - val_mse: 0.6082 - val_weighted_accuracy: 0.4993 - val_weighted_mse: 0.6082
# Epoch 10/20
# 24/24 [==============================] - 0s 13ms/step - loss: 0.1569 - accuracy: 0.6606 - mse: 1.2909 - weighted_accuracy: 0.6274 - weighted_mse: 1.3128 - val_loss: 0.2076 - val_accuracy: 0.4993 - val_mse: 0.6679 - val_weighted_accuracy: 0.4993 - val_weighted_mse: 0.6679
# Epoch 11/20
# 24/24 [==============================] - 0s 12ms/step - loss: 0.1547 - accuracy: 0.6616 - mse: 1.3130 - weighted_accuracy: 0.6332 - weighted_mse: 1.3324 - val_loss: 0.2015 - val_accuracy: 0.4993 - val_mse: 0.7244 - val_weighted_accuracy: 0.4993 - val_weighted_mse: 0.7244
# Epoch 12/20
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1530 - accuracy: 0.6701 - mse: 1.3190 - weighted_accuracy: 0.6391 - weighted_mse: 1.3367 - val_loss: 0.1956 - val_accuracy: 0.4993 - val_mse: 0.7916 - val_weighted_accuracy: 0.4993 - val_weighted_mse: 0.7916
# Epoch 13/20
# 24/24 [==============================] - 0s 12ms/step - loss: 0.1514 - accuracy: 0.6724 - mse: 1.3245 - weighted_accuracy: 0.6400 - weighted_mse: 1.3437 - val_loss: 0.1912 - val_accuracy: 0.4993 - val_mse: 0.8532 - val_weighted_accuracy: 0.4993 - val_weighted_mse: 0.8532
# Epoch 14/20
# 24/24 [==============================] - 0s 12ms/step - loss: 0.1495 - accuracy: 0.6829 - mse: 1.3607 - weighted_accuracy: 0.6486 - weighted_mse: 1.3814 - val_loss: 0.1869 - val_accuracy: 0.4993 - val_mse: 0.9320 - val_weighted_accuracy: 0.4993 - val_weighted_mse: 0.9320
# Epoch 15/20
# 24/24 [==============================] - 0s 12ms/step - loss: 0.1474 - accuracy: 0.6816 - mse: 1.3845 - weighted_accuracy: 0.6540 - weighted_mse: 1.4021 - val_loss: 0.1844 - val_accuracy: 0.5088 - val_mse: 1.0084 - val_weighted_accuracy: 0.5088 - val_weighted_mse: 1.0084
# Epoch 16/20
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1464 - accuracy: 0.6911 - mse: 1.4053 - weighted_accuracy: 0.6603 - weighted_mse: 1.4244 - val_loss: 0.1824 - val_accuracy: 0.5061 - val_mse: 1.0642 - val_weighted_accuracy: 0.5061 - val_weighted_mse: 1.0642
# Epoch 17/20
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1455 - accuracy: 0.7012 - mse: 1.4152 - weighted_accuracy: 0.6725 - weighted_mse: 1.4309 - val_loss: 0.1778 - val_accuracy: 0.5332 - val_mse: 1.1263 - val_weighted_accuracy: 0.5332 - val_weighted_mse: 1.1263
# Epoch 18/20
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1439 - accuracy: 0.7012 - mse: 1.4370 - weighted_accuracy: 0.6673 - weighted_mse: 1.4536 - val_loss: 0.1770 - val_accuracy: 0.5277 - val_mse: 1.1819 - val_weighted_accuracy: 0.5277 - val_weighted_mse: 1.1819
# Epoch 19/20
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1426 - accuracy: 0.6972 - mse: 1.4424 - weighted_accuracy: 0.6660 - weighted_mse: 1.4581 - val_loss: 0.1736 - val_accuracy: 0.5399 - val_mse: 1.2398 - val_weighted_accuracy: 0.5399 - val_weighted_mse: 1.2398
# Epoch 20/20
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1419 - accuracy: 0.7124 - mse: 1.4642 - weighted_accuracy: 0.6822 - weighted_mse: 1.4788 - val_loss: 0.1725 - val_accuracy: 0.5345 - val_mse: 1.3091 - val_weighted_accuracy: 0.5345 - val_weighted_mse: 1.3091
# Validation loss: 0.17253002524375916
# Validation accuracy: 0.53450608253479
#
#
# C6L.SI
#
#
# Non-Recession Test
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1764 - accuracy: 0.4266 - mse: 1.2926 - weighted_accuracy: 0.4266 - weighted_mse: 1.2926
# Test loss: 0.17644308507442474
# Test accuracy: 0.4266054928302765
#
#
# number of predictions: 218
# actual predicted buys: 7
# actual buys but predicted sell: 0
# actual buys but predicted hold: 2
# actual sells but predicted buy: 2
# actual predicted sells: 1
# actual sells but predicted hold: 6
# actual holds but predicted buy: 102
# actual holds but predicted sell: 13
# actual predicted holds: 85
# Percentage buys correct: 6.306306306306307%
# Percentage sells correct: 7.142857142857143%
# Percentage holds correct: 91.39784946236558%
# actual buys: 9
# actual sells: 9
# actual holds: 200
#
#
# Percentage low buys correct: 49.549549549549546%
# Percentage high sells correct: 57.142857142857146%
# Percentage mid holds correct: 77.17391304347827%
#
#
# Capital: 100
# Share price: $0.6878526067315331
# Shares owned at the moment: 144
# Cash capital at the moment: $0.6768349983935451
#
#
# Price increase from previously bought: 19.18631364952388%
# Share price: $0.8220806872600612
# Shares owned at the moment: 0
# Cash capital at the moment: $118.73091001168737
#
#
# Share price: $0.7952350711543554
# Shares owned at the moment: 148
# Cash capital at the moment: $0.7124588068829496
#
#
# Price increase from previously bought: -49.93093120329246%
# Share price: $0.39926175355771787
# Shares owned at the moment: 0
# Cash capital at the moment: $59.6406987997272
#
#
# Share price: $0.5402013981251648
# Shares owned at the moment: 110
# Cash capital at the moment: $0.05513408302621059
#
#
# Price increase from previously bought: 19.54946675249456%
# Share price: $0.647583862547987
# Shares owned at the moment: 0
# Cash capital at the moment: $71.09346484488401
#
#
# Share price: $0.6677185546647462
# Shares owned at the moment: 106
# Cash capital at the moment: $0.12065809173614639
#
#
# Price increase from previously bought: -64.42590452748372%
# Share price: $0.238188056923484
# Shares owned at the moment: 0
# Cash capital at the moment: $25.299160307032256
#
#
# Share price: $0.3724161374520112
# Shares owned at the moment: 67
# Cash capital at the moment: $0.2786614244219727
#
#
# Price increase from previously bought: -21.84043785941586%
# Share price: $0.2918792891348947
# Shares owned at the moment: 0
# Cash capital at the moment: $19.780795037436814
#
#
#
#
# Capital at the end of test period: $19.780795037436814
# profit gained: -80.21920496256318%
#
#
# Capital at the end of test period if Buy and Hold: $35.84540016707856
# profit gained: -64.15459983292143%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.426605      6.306306       7.142857      91.397849
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0          49.54955           57.142857          77.173913     -80.219205
#
#    buy_n_hold profit
# 0           -64.1546
# Recession Test
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1827 - accuracy: 0.2884 - mse: 1.3492 - weighted_accuracy: 0.2884 - weighted_mse: 1.3492
# Test loss: 0.18268771469593048
# Test accuracy: 0.28837209939956665
#
#
# number of predictions: 215
# actual predicted buys: 7
# actual buys but predicted sell: 0
# actual buys but predicted hold: 1
# actual sells but predicted buy: 2
# actual predicted sells: 2
# actual sells but predicted hold: 5
# actual holds but predicted buy: 120
# actual holds but predicted sell: 25
# actual predicted holds: 53
# Percentage buys correct: 5.426356589147287%
# Percentage sells correct: 7.407407407407407%
# Percentage holds correct: 89.83050847457628%
# actual buys: 8
# actual sells: 9
# actual holds: 198
#
#
# Percentage low buys correct: 43.41085271317829%
# Percentage high sells correct: 59.25925925925926%
# Percentage mid holds correct: 86.20689655172414%
#
#
# Capital: 100
# Share price: $1.0062617748699323
# Shares owned at the moment: 99
# Cash capital at the moment: $0.10612951966835737
#
#
# Price increase from previously bought: -44.54740808416909%
# Share price: $0.5595327307715856
# Shares owned at the moment: 0
# Cash capital at the moment: $55.34753708010277
#
#
# Share price: $0.524018700751522
# Shares owned at the moment: 105
# Cash capital at the moment: $0.17426310135095235
#
#
# Price increase from previously bought: -61.81359188616127%
# Share price: $0.20065420544088153
# Shares owned at the moment: 0
# Cash capital at the moment: $21.18501577082246
#
#
# Share price: $0.16887848967932728
# Shares owned at the moment: 125
# Cash capital at the moment: $0.01715258007928
#
#
# Price increase from previously bought: -49.94394714359627%
# Share price: $0.08476637429863708
# Shares owned at the moment: 0
# Cash capital at the moment: $10.583810926243757
#
#
# Share price: $0.06981311726459814
# Shares owned at the moment: 151
# Cash capital at the moment: $0.013040322345311495
#
#
# Price increase from previously bought: -34.98469704285292%
# Share price: $0.045514030020063705
# Shares owned at the moment: 0
# Cash capital at the moment: $6.8667591544091
#
#
# Share price: $0.043644872890808865
# Shares owned at the moment: 156
# Cash capital at the moment: $0.039435332972759696
#
#
# Price increase from previously bought: 255.9803576408395%
# Share price: $0.15579443433876483
# Shares owned at the moment: 0
# Cash capital at the moment: $24.276531277488743
#
#
# Share price: $0.21000003565137693
# Shares owned at the moment: 115
# Cash capital at the moment: $0.060114666305647546
#
#
#
#
# Capital at the end of test period: $25.215510888758153
# profit gained: -74.78448911124184%
#
#
# Capital at the end of test period if Buy and Hold: $21.761644528562254
# profit gained: -78.23835547143774%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.288372      5.426357       7.407407      89.830508
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.410853           59.259259          86.206897     -74.784489
#
#    buy_n_hold profit
# 0         -78.238355
#
#
# O39.SI
#
#
# Non-Recession Test
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1900 - accuracy: 0.2752 - mse: 1.3163 - weighted_accuracy: 0.2752 - weighted_mse: 1.3163
# Test loss: 0.18999065458774567
# Test accuracy: 0.2752293646335602
#
#
# number of predictions: 218
# actual predicted buys: 8
# actual buys but predicted sell: 0
# actual buys but predicted hold: 0
# actual sells but predicted buy: 3
# actual predicted sells: 0
# actual sells but predicted hold: 6
# actual holds but predicted buy: 120
# actual holds but predicted sell: 29
# actual predicted holds: 52
# Percentage buys correct: 6.106870229007634%
# Percentage sells correct: 0.0%
# Percentage holds correct: 89.65517241379311%
# actual buys: 8
# actual sells: 9
# actual holds: 201
#
#
# Percentage low buys correct: 50.0%
# Percentage high sells correct: 51.724137931034484%
# Percentage mid holds correct: 89.65517241379311%
#
#
# Capital: 100
# Share price: $0.6357665229914489
# Shares owned at the moment: 156
# Cash capital at the moment: $0.5476785749706323
#
#
# Price increase from previously bought: -33.95558671220359%
# Share price: $0.42104296273239794
# Shares owned at the moment: 0
# Cash capital at the moment: $66.04975333021251
#
#
# Share price: $0.30447822609568687
# Shares owned at the moment: 216
# Cash capital at the moment: $0.10159642724330809
#
#
# Price increase from previously bought: 154.4485972463165%
# Share price: $0.7768711118028009
# Shares owned at the moment: 0
# Cash capital at the moment: $167.44429513623743
#
#
# Share price: $0.73392593169001
# Shares owned at the moment: 227
# Cash capital at the moment: $0.3849553797476517
#
#
# Price increase from previously bought: 22.23349792660725%
# Share price: $0.8995703726760029
# Shares owned at the moment: 0
# Cash capital at the moment: $204.02587317205732
#
#
# Share price: $0.611226670816807
# Shares owned at the moment: 332
# Cash capital at the moment: $0.5405685104216502
#
#
# Price increase from previously bought: -72.34340916701181%
# Share price: $0.1695093316732772
# Shares owned at the moment: 0
# Cash capital at the moment: $56.662904606131974
#
#
# Share price: $0.611226670816807
# Shares owned at the moment: 92
# Cash capital at the moment: $0.275410543269075
#
#
# Price increase from previously bought: 26.751762024001025%
# Share price: $0.7768711118028009
# Shares owned at the moment: 0
# Cash capital at the moment: $71.55100443784065
#
#
# Share price: $0.5682820757802427
# Shares owned at the moment: 125
# Cash capital at the moment: $0.3203980017608501
#
#
# Price increase from previously bought: -70.2534240275299%
# Share price: $0.1695093316732772
# Shares owned at the moment: 0
# Cash capital at the moment: $21.45079562815781
#
#
# Share price: $0.25539852174640587
# Shares owned at the moment: 83
# Cash capital at the moment: $0.1944236106175019
#
#
# Price increase from previously bought: -40.99824608043933%
# Share price: $0.15110400373512634
# Shares owned at the moment: 0
# Cash capital at the moment: $12.701566431780444
#
#
# Share price: $0.09588919007312867
# Shares owned at the moment: 132
# Cash capital at the moment: $0.009385566130914569
#
#
# Price increase from previously bought: 305.98677807849344%
# Share price: $0.3903680012450421
# Shares owned at the moment: 0
# Cash capital at the moment: $51.39625814602452
#
#
# Share price: $0.3658281490704012
# Shares owned at the moment: 140
# Cash capital at the moment: $0.03947343877625542
#
#
# Price increase from previously bought: -33.72239998738905%
# Share price: $0.24312888819719825
# Shares owned at the moment: 0
# Cash capital at the moment: $33.98391316442808
#
#
# Share price: $0.2860734832337626
# Shares owned at the moment: 118
# Cash capital at the moment: $0.13441129753474002
#
#
# Price increase from previously bought: -2.412956466602456%
# Share price: $0.2799383739210459
# Shares owned at the moment: 0
# Cash capital at the moment: $33.076299417880776
#
#
#
#
# Capital at the end of test period: $33.076299417880776
# profit gained: -66.92370058211922%
#
#
# Capital at the end of test period if Buy and Hold: $44.097971344241664
# profit gained: -55.90202865575834%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.426605      6.306306       7.142857      91.397849
# 1       0.275229      6.106870       0.000000      89.655172
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0          49.54955           57.142857          77.173913     -80.219205
# 1          50.00000           51.724138          89.655172     -66.923701
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# Recession Test
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1860 - accuracy: 0.2977 - mse: 1.3304 - weighted_accuracy: 0.2977 - weighted_mse: 1.3304
# Test loss: 0.18602736294269562
# Test accuracy: 0.29767441749572754
#
#
# number of predictions: 215
# actual predicted buys: 9
# actual buys but predicted sell: 1
# actual buys but predicted hold: 2
# actual sells but predicted buy: 1
# actual predicted sells: 4
# actual sells but predicted hold: 5
# actual holds but predicted buy: 111
# actual holds but predicted sell: 31
# actual predicted holds: 51
# Percentage buys correct: 7.43801652892562%
# Percentage sells correct: 11.11111111111111%
# Percentage holds correct: 87.93103448275862%
# actual buys: 12
# actual sells: 10
# actual holds: 193
#
#
# Percentage low buys correct: 49.586776859504134%
# Percentage high sells correct: 58.333333333333336%
# Percentage mid holds correct: 80.70175438596492%
#
#
# Capital: 100
# Share price: $0.9886586309918834
# Shares owned at the moment: 100
# Cash capital at the moment: $0.8622557772888797
#
#
# Price increase from previously bought: -0.5817825848549063%
# Share price: $0.9856097809180537
# Shares owned at the moment: 0
# Cash capital at the moment: $99.15219117934178
#
#
# Share price: $0.9734146713770804
# Shares owned at the moment: 101
# Cash capital at the moment: $0.5669434452816802
#
#
# Price increase from previously bought: -76.7989431856818%
# Share price: $0.22646355779520433
# Shares owned at the moment: 0
# Cash capital at the moment: $23.376862529419697
#
#
# Share price: $0.2843902554262392
# Shares owned at the moment: 81
# Cash capital at the moment: $0.2779039104981287
#
#
# Price increase from previously bought: 25.384154343276897%
# Share price: $0.35756091267207757
# Shares owned at the moment: 0
# Cash capital at the moment: $29.160691143638704
#
#
# Share price: $0.3484146532049339
# Shares owned at the moment: 83
# Cash capital at the moment: $0.16274928303516134
#
#
# Price increase from previously bought: -2.01957352582115%
# Share price: $0.3423169530572745
# Shares owned at the moment: 0
# Cash capital at the moment: $28.49692254225362
#
#
# Share price: $0.30878047450818547
# Shares owned at the moment: 92
# Cash capital at the moment: $0.010997427449986219
#
#
# Price increase from previously bought: 52.89706373870644%
# Share price: $0.47341459868849456
# Shares owned at the moment: 0
# Cash capital at the moment: $43.445366613323294
#
#
# Share price: $0.47341459868849456
# Shares owned at the moment: 91
# Cash capital at the moment: $0.24616612934848803
#
#
# Price increase from previously bought: -24.67906190710778%
# Share price: $0.35756091267207757
# Shares owned at the moment: 0
# Cash capital at the moment: $32.694729564111356
#
#
# Share price: $0.2721951458852663
# Shares owned at the moment: 119
# Cash capital at the moment: $0.21443134227371274
#
#
# Price increase from previously bought: -10.327260753945511%
# Share price: $0.2447560767294903
# Shares owned at the moment: 0
# Cash capital at the moment: $29.260308046973332
#
#
# Share price: $0.2935365148933824
# Shares owned at the moment: 99
# Cash capital at the moment: $0.12027775634874871
#
#
# Price increase from previously bought: 6.976344842572546%
# Share price: $0.3148781746558449
# Shares owned at the moment: 0
# Cash capital at the moment: $31.207491464227335
#
#
# Share price: $0.2721951458852663
# Shares owned at the moment: 114
# Cash capital at the moment: $0.09191165507194654
#
#
# Price increase from previously bought: 115.89372548537229%
# Share price: $0.5892682847049111
# Shares owned at the moment: 0
# Cash capital at the moment: $67.08376050417681
#
#
# Share price: $0.6990242705736691
# Shares owned at the moment: 95
# Cash capital at the moment: $0.49383470899086035
#
#
#
#
# Capital at the end of test period: $71.3399180589014
# profit gained: -28.660081941098596%
#
#
# Capital at the end of test period if Buy and Hold: $75.43708035614208
# profit gained: -24.562919643857924%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.288372      5.426357       7.407407      89.830508
# 1       0.297674      7.438017      11.111111      87.931034
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.410853           59.259259          86.206897     -74.784489
# 1         49.586777           58.333333          80.701754     -28.660082
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
#
#
# 0883.HK
#
#
# Non-Recession Test
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1857 - accuracy: 0.2938 - mse: 1.3191 - weighted_accuracy: 0.2938 - weighted_mse: 1.3191
# Test loss: 0.1857100874185562
# Test accuracy: 0.29383885860443115
#
#
# number of predictions: 211
# actual predicted buys: 5
# actual buys but predicted sell: 0
# actual buys but predicted hold: 3
# actual sells but predicted buy: 3
# actual predicted sells: 2
# actual sells but predicted hold: 4
# actual holds but predicted buy: 107
# actual holds but predicted sell: 32
# actual predicted holds: 55
# Percentage buys correct: 4.3478260869565215%
# Percentage sells correct: 5.882352941176471%
# Percentage holds correct: 88.70967741935483%
# actual buys: 8
# actual sells: 9
# actual holds: 194
#
#
# Percentage low buys correct: 50.43478260869565%
# Percentage high sells correct: 60.60606060606061%
# Percentage mid holds correct: 79.03225806451613%
#
#
# Capital: 100
# Share price: $0.6782927975265876
# Shares owned at the moment: 147
# Cash capital at the moment: $0.016758900191504722
#
#
# Price increase from previously bought: 36.30259457670804%
# Share price: $0.9270731412307789
# Shares owned at the moment: 0
# Cash capital at the moment: $135.92174134377342
#
#
# Share price: $0.9758535779763593
# Shares owned at the moment: 138
# Cash capital at the moment: $0.8836111501937864
#
#
# Price increase from previously bought: -35.66804163833825%
# Share price: $0.6295121281775378
# Shares owned at the moment: 0
# Cash capital at the moment: $87.51738498605062
#
#
# Share price: $0.5953659387573673
# Shares owned at the moment: 146
# Cash capital at the moment: $0.3549185030638995
#
#
# Price increase from previously bought: -65.64139333371118%
# Share price: $0.20512197958578926
# Shares owned at the moment: 0
# Cash capital at the moment: $30.220371047785434
#
#
# Share price: $0.3709756971242302
# Shares owned at the moment: 81
# Cash capital at the moment: $0.08870474418836594
#
#
# Price increase from previously bought: -35.67982488890703%
# Share price: $0.23926840160942997
# Shares owned at the moment: 0
# Cash capital at the moment: $19.41614823809369
#
#
# Share price: $0.21000013956208208
# Shares owned at the moment: 92
# Cash capital at the moment: $0.04300536307293257
#
#
# Price increase from previously bought: 108.60159164142078%
# Share price: $0.43926830856804133
# Shares owned at the moment: 0
# Cash capital at the moment: $40.344554869265025
#
#
# Share price: $0.2343902416331367
# Shares owned at the moment: 171
# Cash capital at the moment: $0.1536015388706673
#
#
# Price increase from previously bought: -12.726980569918734%
# Share price: $0.20512197958578926
# Shares owned at the moment: 0
# Cash capital at the moment: $35.13300143714041
#
#
#
#
# Capital at the end of test period: $35.13300143714041
# profit gained: -64.86699856285959%
#
#
# Capital at the end of test period if Buy and Hold: $45.31039913308918
# profit gained: -54.68960086691082%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.426605      6.306306       7.142857      91.397849
# 1       0.275229      6.106870       0.000000      89.655172
# 2       0.293839      4.347826       5.882353      88.709677
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         49.549550           57.142857          77.173913     -80.219205
# 1         50.000000           51.724138          89.655172     -66.923701
# 2         50.434783           60.606061          79.032258     -64.866999
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# 2         -54.689601
# Recession Test
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1857 - accuracy: 0.3286 - mse: 1.3574 - weighted_accuracy: 0.3286 - weighted_mse: 1.3574
# Test loss: 0.18574371933937073
# Test accuracy: 0.32863849401474
#
#
# number of predictions: 213
# actual predicted buys: 8
# actual buys but predicted sell: 0
# actual buys but predicted hold: 2
# actual sells but predicted buy: 4
# actual predicted sells: 2
# actual sells but predicted hold: 4
# actual holds but predicted buy: 111
# actual holds but predicted sell: 22
# actual predicted holds: 60
# Percentage buys correct: 6.504065040650406%
# Percentage sells correct: 8.333333333333334%
# Percentage holds correct: 90.9090909090909%
# actual buys: 10
# actual sells: 10
# actual holds: 193
#
#
# Percentage low buys correct: 43.08943089430894%
# Percentage high sells correct: 50.0%
# Percentage mid holds correct: 81.53846153846153%
#
#
# Capital: 100
# Share price: $1.01
# Shares owned at the moment: 98
# Cash capital at the moment: $0.7478049999999996
#
#
# Price increase from previously bought: -70.25548142102053%
# Share price: $0.30124579165122367
# Shares owned at the moment: 0
# Cash capital at the moment: $30.188706840969914
#
#
# Share price: $0.3180807119933291
# Shares owned at the moment: 94
# Cash capital at the moment: $0.2068960495466996
#
#
# Price increase from previously bought: 54.09096287587711%
# Share price: $0.491481499320507
# Shares owned at the moment: 0
# Cash capital at the moment: $46.2791090181
#
#
# Share price: $0.38205379461628364
# Shares owned at the moment: 120
# Cash capital at the moment: $0.30657591192259304
#
#
# Price increase from previously bought: 12.46941791534677%
# Share price: $0.4308753365454818
# Shares owned at the moment: 0
# Cash capital at the moment: $51.8694274363204
#
#
# Share price: $0.42414133629839346
# Shares owned at the moment: 121
# Cash capital at the moment: $0.4071927145615035
#
#
# Price increase from previously bought: 4.871567349812178%
# Share price: $0.4460268772392382
# Shares owned at the moment: 0
# Cash capital at the moment: $54.22802941710797
#
#
# Share price: $0.4493939576383974
# Shares owned at the moment: 120
# Cash capital at the moment: $0.15245449447960624
#
#
# Price increase from previously bought: -6.998852583513571%
# Share price: $0.4190908762508847
# Shares owned at the moment: 0
# Cash capital at the moment: $50.30505965542297
#
#
# Share price: $0.40562287575670797
# Shares owned at the moment: 123
# Cash capital at the moment: $0.27624399962318336
#
#
# Price increase from previously bought: 4.278671563264269%
# Share price: $0.42414133629839346
# Shares owned at the moment: 0
# Cash capital at the moment: $52.302162557322646
#
#
# Share price: $0.5352525812021964
# Shares owned at the moment: 97
# Cash capital at the moment: $0.23988355467390932
#
#
# Price increase from previously bought: 2.2350489532743323%
# Share price: $0.5487205816963732
# Shares owned at the moment: 0
# Cash capital at the moment: $53.31940876405459
#
#
# Share price: $0.30124579165122367
# Shares owned at the moment: 176
# Cash capital at the moment: $0.15434647028003212
#
#
#
#
# Capital at the end of test period: $27.02542933633142
# profit gained: -72.97457066366857%
#
#
# Capital at the end of test period if Buy and Hold: $15.710112504960433
# profit gained: -84.28988749503957%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.288372      5.426357       7.407407      89.830508
# 1       0.297674      7.438017      11.111111      87.931034
# 2       0.328638      6.504065       8.333333      90.909091
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.410853           59.259259          86.206897     -74.784489
# 1         49.586777           58.333333          80.701754     -28.660082
# 2         43.089431           50.000000          81.538462     -72.974571
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
# 2         -84.289887
#
#
# JPM
#
#
# Non-Recession Test
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1911 - accuracy: 0.3073 - mse: 1.2842 - weighted_accuracy: 0.3073 - weighted_mse: 1.2842
# Test loss: 0.1910683512687683
# Test accuracy: 0.30733945965766907
#
#
# number of predictions: 218
# actual predicted buys: 10
# actual buys but predicted sell: 0
# actual buys but predicted hold: 1
# actual sells but predicted buy: 1
# actual predicted sells: 3
# actual sells but predicted hold: 2
# actual holds but predicted buy: 101
# actual holds but predicted sell: 46
# actual predicted holds: 54
# Percentage buys correct: 8.928571428571429%
# Percentage sells correct: 6.122448979591836%
# Percentage holds correct: 94.73684210526316%
# actual buys: 11
# actual sells: 6
# actual holds: 201
#
#
# Percentage low buys correct: 45.535714285714285%
# Percentage high sells correct: 41.666666666666664%
# Percentage mid holds correct: 89.47368421052632%
#
#
# Capital: 100
# Share price: $0.05968146056768497
# Shares owned at the moment: 1670
# Cash capital at the moment: $0.05787374430900627
#
#
# Price increase from previously bought: 195.13331812623903%
# Share price: $0.17662425953553051
# Shares owned at the moment: 0
# Cash capital at the moment: $294.20924025672804
#
#
# Share price: $0.16872623102977413
# Shares owned at the moment: 1738
# Cash capital at the moment: $0.1566237057738249
#
#
# Price increase from previously bought: 1.984455125615292%
# Share price: $0.17254773231996867
# Shares owned at the moment: 0
# Cash capital at the moment: $299.21989059125605
#
#
# Share price: $0.40592366716395456
# Shares owned at the moment: 735
# Cash capital at the moment: $0.04552201349429197
#
#
# Price increase from previously bought: 10.053551941113748%
# Share price: $0.4479619307717362
# Shares owned at the moment: 0
# Cash capital at the moment: $328.392098078148
#
#
# Share price: $0.42350335061691236
# Shares owned at the moment: 773
# Cash capital at the moment: $0.12374580370089916
# Price increase from previously bought: -27.151768778161678%
# Share price: $0.3093631155148875
# Shares owned at the moment: 0
# Cash capital at the moment: $238.60380545390316
#
#
# Share price: $0.2874522676800322
# Shares owned at the moment: 827
# Cash capital at the moment: $0.22704176274521615
#
#
# Price increase from previously bought: 26.24268577236255%
# Share price: $0.3638854035561738
# Shares owned at the moment: 0
# Cash capital at the moment: $300.33270412466334
#
#
# Share price: $0.41101913180389116
# Shares owned at the moment: 728
# Cash capital at the moment: $0.28791586955918547
#
#
# Price increase from previously bought: 7.020124949334239%
# Share price: $0.4410828396903541
# Shares owned at the moment: 0
# Cash capital at the moment: $320.5131753190769
#
#
# Share price: $0.43445858015482375
# Shares owned at the moment: 735
# Cash capital at the moment: $0.3079695001434857
#
#
# Price increase from previously bought: -41.38681561514541%
# Share price: $0.25535029618578853
# Shares owned at the moment: 0
# Cash capital at the moment: $187.47431041053252
#
#
# Share price: $0.2887262310297747
# Shares owned at the moment: 647
# Cash capital at the moment: $0.1547227877085504
#
#
# Price increase from previously bought: 23.83767090910185%
# Share price: $0.3585351073703855
# Shares owned at the moment: 0
# Cash capital at the moment: $231.48901366655923
#
#
# Share price: $0.5187899389162374
# Shares owned at the moment: 444
# Cash capital at the moment: $0.5128382723331129
#
#
# Price increase from previously bought: 3.5458137045631055%
# Share price: $0.5386625231433115
# Shares owned at the moment: 0
# Cash capital at the moment: $239.02129160720543
#
#
# Share price: $0.6721656793807076
# Shares owned at the moment: 354
# Cash capital at the moment: $0.4202878175578064
#
#
# Price increase from previously bought: 20.364561453960818%
# Share price: $0.8112741577292593
# Shares owned at the moment: 0
# Cash capital at the moment: $286.82156426116615
#
#
# Share price: $0.780191318038906
# Shares owned at the moment: 366
# Cash capital at the moment: $0.4862792973204364
#
#
# Price increase from previously bought: 8.192927661634307%
# Share price: $0.8464331358761423
# Shares owned at the moment: 0
# Cash capital at the moment: $309.4288720767292
#
#
# Share price: $0.8612102554632799
# Shares owned at the moment: 358
# Cash capital at the moment: $0.2677391243714169
#
#
# Price increase from previously bought: 5.8327896394246626%
# Share price: $0.9139493058221533
# Shares owned at the moment: 0
# Cash capital at the moment: $326.56180751712037
#
#
# Share price: $1.0059238615434716
# Shares owned at the moment: 323
# Cash capital at the moment: $0.7548883685630585
#
#
# Price increase from previously bought: -3.3305067042870173%
# Share price: $0.9750956590194539
# Shares owned at the moment: 0
# Cash capital at the moment: $314.8446575127226
#
#
#
#
# Capital at the end of test period: $314.8446575127226
# profit gained: 214.84465751272262%
#
#
# Capital at the end of test period if Buy and Hold: $1676.1791664809543
# profit gained: 1576.1791664809543%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.426605      6.306306       7.142857      91.397849
# 1       0.275229      6.106870       0.000000      89.655172
# 2       0.293839      4.347826       5.882353      88.709677
# 3       0.307339      8.928571       6.122449      94.736842
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         49.549550           57.142857          77.173913     -80.219205
# 1         50.000000           51.724138          89.655172     -66.923701
# 2         50.434783           60.606061          79.032258     -64.866999
# 3         45.535714           41.666667          89.473684     214.844658
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# 2         -54.689601
# 3        1576.179166
# Recession Test
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1778 - accuracy: 0.4475 - mse: 1.3190 - weighted_accuracy: 0.4475 - weighted_mse: 1.3190
# Test loss: 0.177824005484581
# Test accuracy: 0.44748857617378235
#
#
# number of predictions: 219
# actual predicted buys: 8
# actual buys but predicted sell: 0
# actual buys but predicted hold: 2
# actual sells but predicted buy: 6
# actual predicted sells: 2
# actual sells but predicted hold: 4
# actual holds but predicted buy: 95
# actual holds but predicted sell: 14
# actual predicted holds: 88
# Percentage buys correct: 7.339449541284404%
# Percentage sells correct: 12.5%
# Percentage holds correct: 93.61702127659575%
# actual buys: 10
# actual sells: 12
# actual holds: 197
#
#
# Percentage low buys correct: 43.11926605504587%
# Percentage high sells correct: 62.5%
# Percentage mid holds correct: 84.94623655913979%
#
#
# Capital: 100
# Share price: $0.9699796411480657
# Shares owned at the moment: 102
# Cash capital at the moment: $0.7899973135552756
#
#
# Price increase from previously bought: -73.74391741964567%
# Share price: $0.25537902189534
# Shares owned at the moment: 0
# Cash capital at the moment: $26.767023731238314
#
#
# Share price: $0.10038497067528372
# Shares owned at the moment: 265
# Cash capital at the moment: $0.0918509549085158
#
#
# Price increase from previously bought: 232.7117050525%
# Share price: $0.33491102705595166
# Shares owned at the moment: 0
# Cash capital at the moment: $88.5992067137687
#
#
# Share price: $0.28929457147307747
# Shares owned at the moment: 305
# Cash capital at the moment: $0.12171659265702317
#
#
# Price increase from previously bought: 24.453049758631586%
# Share price: $0.36102601575611626
# Shares owned at the moment: 0
# Cash capital at the moment: $109.93184082755702
#
#
# Share price: $0.33643716468572404
# Shares owned at the moment: 325
# Cash capital at the moment: $0.28907158875883
#
#
# Price increase from previously bought: -1.5811662465209597%
# Share price: $0.33202810701490293
# Shares owned at the moment: 0
# Cash capital at the moment: $107.90145624795771
#
#
# Share price: $0.3947719513602499
# Shares owned at the moment: 272
# Cash capital at the moment: $0.22819605835226753
#
#
# Price increase from previously bought: 61.369735433274755%
# Share price: $0.6387943202218671
# Shares owned at the moment: 0
# Cash capital at the moment: $173.50243300717418
#
#
# Share price: $0.6294674923369679
# Shares owned at the moment: 274
# Cash capital at the moment: $0.5540363513690636
#
#
#
#
# Capital at the end of test period: $188.86430247646217
# profit gained: 88.86430247646217%
#
#
# Capital at the end of test period if Buy and Hold: $68.09965200824497
# profit gained: -31.90034799175503%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.288372      5.426357       7.407407      89.830508
# 1       0.297674      7.438017      11.111111      87.931034
# 2       0.328638      6.504065       8.333333      90.909091
# 3       0.447489      7.339450      12.500000      93.617021
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.410853           59.259259          86.206897     -74.784489
# 1         49.586777           58.333333          80.701754     -28.660082
# 2         43.089431           50.000000          81.538462     -72.974571
# 3         43.119266           62.500000          84.946237      88.864302
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
# 2         -84.289887
# 3         -31.900348
#
#
# AXL
#
#
# Non-Recession Test
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1887 - accuracy: 0.2477 - mse: 1.3122 - weighted_accuracy: 0.2477 - weighted_mse: 1.3122
# Test loss: 0.18868021667003632
# Test accuracy: 0.24770642817020416
#
#
# number of predictions: 218
# actual predicted buys: 7
# actual buys but predicted sell: 0
# actual buys but predicted hold: 1
# actual sells but predicted buy: 3
# actual predicted sells: 1
# actual sells but predicted hold: 4
# actual holds but predicted buy: 124
# actual holds but predicted sell: 32
# actual predicted holds: 46
# Percentage buys correct: 5.223880597014926%
# Percentage sells correct: 3.0303030303030303%
# Percentage holds correct: 90.19607843137256%
# actual buys: 8
# actual sells: 8
# actual holds: 202
#
#
# Percentage low buys correct: 43.28358208955224%
# Percentage high sells correct: 60.60606060606061%
# Percentage mid holds correct: 84.0%
#
#
# Capital: 100
# Share price: $0.7426007274823263
# Shares owned at the moment: 134
# Cash capital at the moment: $0.21785414929102842
#
#
# Price increase from previously bought: 12.26955871837565%
# Share price: $0.8360072748232608
# Shares owned at the moment: 0
# Cash capital at the moment: $111.93476029483558
#
#
# Share price: $0.8799633638852624
# Shares owned at the moment: 126
# Cash capital at the moment: $0.7544691397062735
#
#
# Price increase from previously bought: 1.1786893543621169%
# Share price: $0.8927838207232035
# Shares owned at the moment: 0
# Cash capital at the moment: $112.93588095694932
# Share price: $0.9175091371954818
# Shares owned at the moment: 122
# Cash capital at the moment: $0.6919419035714469
#
#
# Price increase from previously bought: -46.956001596128395%
# Share price: $0.48802191180259324
# Shares owned at the moment: 0
# Cash capital at the moment: $60.06688379207805
#
#
# Share price: $0.4990109995677028
# Shares owned at the moment: 120
# Cash capital at the moment: $0.02089021409636871
#
#
# Price increase from previously bought: 7.229157032319833%
# Share price: $0.5365567728779221
# Shares owned at the moment: 0
# Cash capital at the moment: $64.23063922439731
#
#
# Share price: $0.5502930015850909
# Shares owned at the moment: 116
# Cash capital at the moment: $0.22110757302112916
#
#
# Price increase from previously bought: -55.371346004761556%
# Share price: $0.24626372762642512
# Shares owned at the moment: 0
# Cash capital at the moment: $28.709141848573612
#
#
# Share price: $0.19681318201468057
# Shares owned at the moment: 145
# Cash capital at the moment: $0.09275120011657734
#
#
# Price increase from previously bought: 13.182140463873338%
# Share price: $0.22336995489260247
# Shares owned at the moment: 0
# Cash capital at the moment: $32.392325890030506
#
#
# Share price: $0.225201411298246
# Shares owned at the moment: 143
# Cash capital at the moment: $0.09996361938829068
#
#
# Price increase from previously bought: 82.85761111608446%
# Share price: $0.41293036518215465
# Shares owned at the moment: 0
# Cash capital at the moment: $58.98662097432852
#
#
# Share price: $0.4532234541000574
# Shares owned at the moment: 129
# Cash capital at the moment: $0.3600143750791176
#
#
# Price increase from previously bought: -0.27424582398405395%
# Share price: $0.4532234541000574
# Shares owned at the moment: 0
# Cash capital at the moment: $58.66505893364452
#
#
# Share price: $0.3918681361867874
# Shares owned at the moment: 149
# Cash capital at the moment: $0.11613867301065284
#
#
#
#
# Capital at the end of test period: $66.37215280927825
# profit gained: -33.62784719072175%
#
#
# Capital at the end of test period if Buy and Hold: $59.80379974835048
# profit gained: -40.19620025164952%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.426605      6.306306       7.142857      91.397849
# 1       0.275229      6.106870       0.000000      89.655172
# 2       0.293839      4.347826       5.882353      88.709677
# 3       0.307339      8.928571       6.122449      94.736842
# 4       0.247706      5.223881       3.030303      90.196078
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         49.549550           57.142857          77.173913     -80.219205
# 1         50.000000           51.724138          89.655172     -66.923701
# 2         50.434783           60.606061          79.032258     -64.866999
# 3         45.535714           41.666667          89.473684     214.844658
# 4         43.283582           60.606061          84.000000     -33.627847
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# 2         -54.689601
# 3        1576.179166
# 4         -40.196200
# Recession Test
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1753 - accuracy: 0.4429 - mse: 1.3204 - weighted_accuracy: 0.4429 - weighted_mse: 1.3204
# Test loss: 0.1752980500459671
# Test accuracy: 0.4429223835468292
#
#
# number of predictions: 219
# actual predicted buys: 9
# actual buys but predicted sell: 0
# actual buys but predicted hold: 2
# actual sells but predicted buy: 5
# actual predicted sells: 1
# actual sells but predicted hold: 5
# actual holds but predicted buy: 93
# actual holds but predicted sell: 17
# actual predicted holds: 87
# Percentage buys correct: 8.411214953271028%
# Percentage sells correct: 5.555555555555555%
# Percentage holds correct: 92.55319148936171%
# actual buys: 11
# actual sells: 11
# actual holds: 197
#
#
# Percentage low buys correct: 50.943396226415096%
# Percentage high sells correct: 50.0%
# Percentage mid holds correct: 84.04255319148936%
#
#
# Capital: 100
# Share price: $0.944210527554113
# Shares owned at the moment: 105
# Cash capital at the moment: $0.585253816986878
#
#
# Price increase from previously bought: -86.71435244542477%
# Share price: $0.12578945519191115
# Shares owned at the moment: 0
# Cash capital at the moment: $13.756824906950882
#
#
# Share price: $0.12447366699782796
# Shares owned at the moment: 110
# Cash capital at the moment: $0.02706825292296422
#
#
# Price increase from previously bought: 401.3697149272711%
# Share price: $0.6257894708773437
# Shares owned at the moment: 0
# Cash capital at the moment: $68.67460873449038
#
#
# Share price: $0.6415789292063412
# Shares owned at the moment: 106
# Cash capital at the moment: $0.480221980754564
#
#
# Price increase from previously bought: 15.678597154997354%
# Share price: $0.744210471086556
# Shares owned at the moment: 0
# Cash capital at the moment: $79.14959456360776
#
#
# Share price: $0.8626315967792284
# Shares owned at the moment: 91
# Cash capital at the moment: $0.4342456996039772
#
#
# Price increase from previously bought: -25.06878278245678%
# Share price: $0.6481579015476222
# Shares owned at the moment: 0
# Cash capital at the moment: $59.2544132255753
#
#
# Share price: $0.5784210331486206
# Shares owned at the moment: 102
# Cash capital at the moment: $0.09322074461780971
#
#
# Price increase from previously bought: 15.151936325327164%
# Share price: $0.6678946930880041
# Shares owned at the moment: 0
# Cash capital at the moment: $68.03113497818305
#
#
# Share price: $0.6994736724877293
# Shares owned at the moment: 96
# Cash capital at the moment: $0.6970013698242781
#
#
# Price increase from previously bought: -26.350014203189776%
# Share price: $0.5165789566558485
# Shares owned at the moment: 0
# Cash capital at the moment: $50.15220436422859
#
#
# Share price: $0.525789442643565
# Shares owned at the moment: 95
# Cash capital at the moment: $0.06484482119928003
#
#
#
#
# Capital at the end of test period: $60.597918343002156
# profit gained: -39.402081656997844%
#
#
# Capital at the end of test period if Buy and Hold: $67.49022981476901
# profit gained: -32.50977018523099%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.288372      5.426357       7.407407      89.830508
# 1       0.297674      7.438017      11.111111      87.931034
# 2       0.328638      6.504065       8.333333      90.909091
# 3       0.447489      7.339450      12.500000      93.617021
# 4       0.442922      8.411215       5.555556      92.553191
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.410853           59.259259          86.206897     -74.784489
# 1         49.586777           58.333333          80.701754     -28.660082
# 2         43.089431           50.000000          81.538462     -72.974571
# 3         43.119266           62.500000          84.946237      88.864302
# 4         50.943396           50.000000          84.042553     -39.402082
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
# 2         -84.289887
# 3         -31.900348
# 4         -32.509770
#
#
#
# RUNNING EPOCHS 20 - 40
#
#
#
# Epoch 1/20
#  2/24 [=>............................] - ETA: 15s - loss: 0.1391 - accuracy: 0.7227 - mse: 1.4939 - weighted_accuracy: 0.6856 - weighted_mse: 1.5025WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0144s vs `on_train_batch_end` time: 1.3774s). Check your callbacks.
# 24/24 [==============================] - 2s 69ms/step - loss: 0.1402 - accuracy: 0.7053 - mse: 1.4987 - weighted_accuracy: 0.6859 - weighted_mse: 1.5108 - val_loss: 0.1674 - val_accuracy: 0.5710 - val_mse: 1.3187 - val_weighted_accuracy: 0.5710 - val_weighted_mse: 1.3187
# Epoch 2/20
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1390 - accuracy: 0.7212 - mse: 1.4985 - weighted_accuracy: 0.6877 - weighted_mse: 1.5171 - val_loss: 0.1668 - val_accuracy: 0.5616 - val_mse: 1.4084 - val_weighted_accuracy: 0.5616 - val_weighted_mse: 1.4084
# Epoch 3/20
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1381 - accuracy: 0.7195 - mse: 1.5238 - weighted_accuracy: 0.6965 - weighted_mse: 1.5367 - val_loss: 0.1622 - val_accuracy: 0.5913 - val_mse: 1.4648 - val_weighted_accuracy: 0.5913 - val_weighted_mse: 1.4648
# Epoch 4/20
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1375 - accuracy: 0.7171 - mse: 1.5570 - weighted_accuracy: 0.6917 - weighted_mse: 1.5680 - val_loss: 0.1618 - val_accuracy: 0.5765 - val_mse: 1.4192 - val_weighted_accuracy: 0.5765 - val_weighted_mse: 1.4192
# Epoch 5/20
# ...
# Shares owned at the moment: 0
# Cash capital at the moment: $51.16169745489371
#
#
# Share price: $0.3947719513602499
# Shares owned at the moment: 129
# Cash capital at the moment: $0.0960703796764264
#
#
# Price increase from previously bought: -1.1738413887055876%
# Share price: $0.3912108341798941
# Shares owned at the moment: 0
# Cash capital at the moment: $50.42348594545745
#
#
# Share price: $0.36221305481623456
# Shares owned at the moment: 138
# Cash capital at the moment: $0.30062452651431926
#
#
# Price increase from previously bought: 6.448907583177044%
# Share price: $0.3866321625354687
# Shares owned at the moment: 0
# Cash capital at the moment: $53.50913605072679
#
#
# Share price: $0.3069306727788075
# Shares owned at the moment: 173
# Cash capital at the moment: $0.2641073924185804
#
#
# Price increase from previously bought: 37.578101108329264%
# Share price: $0.42343063215425536
# Shares owned at the moment: 0
# Cash capital at the moment: $73.31615963185736
#
#
# Share price: $0.6126793315217027
# Shares owned at the moment: 119
# Cash capital at the moment: $0.20681986953425735
#
#
# Price increase from previously bought: 20.316957970906515%
# Share price: $0.7391843159213574
# Shares owned at the moment: 0
# Cash capital at the moment: $87.92785539679052
#
#
# Share price: $0.6688095246720407
# Shares owned at the moment: 131
# Cash capital at the moment: $0.072869033490079
#
#
# Price increase from previously bought: 8.221726705200982%
# Share price: $0.7257876583128442
# Shares owned at the moment: 0
# Cash capital at the moment: $94.88958726856546
#
#
# Share price: $0.7444411847050891
# Shares owned at the moment: 127
# Cash capital at the moment: $0.0855607272608978
#
#
# Price increase from previously bought: -1.3192132874917162%
# Share price: $0.7366406238275158
# Shares owned at the moment: 0
# Cash capital at the moment: $93.38164821548365
#
#
# Share price: $0.7386756033780997
# Shares owned at the moment: 126
# Cash capital at the moment: $0.05257109327257581
#
#
# Price increase from previously bought: -6.959301307575139%
# Share price: $0.689158932045216
# Shares owned at the moment: 0
# Cash capital at the moment: $86.64780296101613
#
#
#
#
# Capital at the end of test period: $86.64780296101613
# profit gained: -13.352197038983874%
#
#
# Capital at the end of test period if Buy and Hold: $68.09965200824497
# profit gained: -31.90034799175503%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.297674      7.216495      10.606061      96.153846
# 1       0.213953      7.216495       9.756098      86.111111
# 2       0.300469      6.593407       9.375000      89.655172
# 3       0.237443      7.000000       9.210526      88.372093
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         48.453608           59.090909          92.156863     -70.597242
# 1         53.608247           58.536585          85.714286     -47.952346
# 2         47.252747           57.812500          82.456140     -86.147587
# 3         52.525253           57.894737          81.395349     -13.352197
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
# 2         -84.289887
# 3         -31.900348
#
#
# AXL
#
#
# Non-Recession Test
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0811 - accuracy: 0.2110 - mse: 7.5296 - weighted_accuracy: 0.2110 - weighted_mse: 7.5296
# Test loss: 1.0810941457748413
# Test accuracy: 0.2110091745853424
#
#
# number of predictions: 218
# actual predicted buys: 5
# actual buys but predicted sell: 2
# actual buys but predicted hold: 1
# actual sells but predicted buy: 0
# actual predicted sells: 8
# actual sells but predicted hold: 0
# actual holds but predicted buy: 93
# actual holds but predicted sell: 76
# actual predicted holds: 33
# Percentage buys correct: 5.1020408163265305%
# Percentage sells correct: 9.30232558139535%
# Percentage holds correct: 97.05882352941177%
# actual buys: 8
# actual sells: 8
# actual holds: 202
#
#
# Percentage low buys correct: 45.91836734693877%
# Percentage high sells correct: 55.81395348837209%
# Percentage mid holds correct: 90.9090909090909%
#
#
# Capital: 100
# Share price: $0.7426007274823263
# Shares owned at the moment: 134
# Cash capital at the moment: $0.21785414929102842
#
#
# Price increase from previously bought: 8.211267978658032%
# Share price: $0.8057875018012395
# Shares owned at the moment: 0
# Cash capital at the moment: $107.89644669624336
#
#
# Share price: $0.9642124545323547
# Shares owned at the moment: 111
# Cash capital at the moment: $0.5745383914059801
#
#
# Price increase from previously bought: -22.43720960860307%
# Share price: $0.7499267277705246
# Shares owned at the moment: 0
# Cash capital at the moment: $83.58749004028226
#
#
# Share price: $0.6986446384203246
# Shares owned at the moment: 119
# Cash capital at the moment: $0.2201466103405778
#
#
# Price increase from previously bought: 8.35300038937894%
# Share price: $0.7590841844643663
# Shares owned at the moment: 0
# Cash capital at the moment: $90.3027542622342
#
#
# Share price: $0.9339926815103341
# Shares owned at the moment: 96
# Cash capital at the moment: $0.39288276932340693
#
#
# Price increase from previously bought: -2.4253647566941594%
# Share price: $0.9138461370513826
# Shares owned at the moment: 0
# Cash capital at the moment: $87.88085654607457
#
#
# Share price: $0.9175091371954818
# Shares owned at the moment: 95
# Cash capital at the moment: $0.47778925041149023
#
#
# Price increase from previously bought: -46.85646466880028%
# Share price: $0.4889376836718209
# Shares owned at the moment: 0
# Cash capital at the moment: $46.79913422937521
#
#
# Share price: $0.4990109995677028
# Shares owned at the moment: 93
# Cash capital at the moment: $0.26348920643940943
#
#
# Price increase from previously bought: 10.523323253877903%
# Share price: $0.5530402298599622
# Shares owned at the moment: 0
# Cash capital at the moment: $51.554790544629206
#
#
# Share price: $0.5420512294276649
# Shares owned at the moment: 94
# Cash capital at the moment: $0.4618547356216496
#
#
# Price increase from previously bought: -2.127502971837403%
# Share price: $0.5319780008645951
# Shares owned at the moment: 0
# Cash capital at the moment: $50.33027050367009
#
#
# Share price: $0.5292307725897236
# Shares owned at the moment: 94
# Cash capital at the moment: $0.4457717255216309
#
#
# Price increase from previously bought: 16.63660552889712%
# Share price: $0.6189743197865589
# Shares owned at the moment: 0
# Cash capital at the moment: $58.469352923793345
#
#
# Share price: $0.4687912265456817
# Shares owned at the moment: 124
# Cash capital at the moment: $0.17938302387673133
#
#
# Price increase from previously bought: -74.49583283223002%
# Share price: $0.11989009165578655
# Shares owned at the moment: 0
# Cash capital at the moment: $15.004871867939642
#
#
# Share price: $0.19681318201468057
# Shares owned at the moment: 76
# Cash capital at the moment: $0.005936079782848935
#
#
# Price increase from previously bought: 7.613985198390805%
# Share price: $0.21238095446030514
# Shares owned at the moment: 0
# Cash capital at the moment: $16.102500999283833
#
#
# Share price: $0.1189743197865588
# Shares owned at the moment: 134
# Cash capital at the moment: $0.11610011104360751
#
#
# Price increase from previously bought: 55.760102945109914%
# Share price: $0.18582413791597718
# Shares owned at the moment: 0
# Cash capital at the moment: $24.94805839696251
#
#
# Share price: $0.39278382072320317
# Shares owned at the moment: 63
# Cash capital at the moment: $0.13462789446041157
#
#
# Price increase from previously bought: 19.721143155515385%
# Share price: $0.47153845482055323
# Shares owned at the moment: 0
# Cash capital at the moment: $29.759856510857603
#
#
# Share price: $0.3918681361867874
# Shares owned at the moment: 75
# Cash capital at the moment: $0.28892349376002
#
#
# Price increase from previously bought: -12.159681545457012%
# Share price: $0.34516481884991423
# Shares owned at the moment: 0
# Cash capital at the moment: $26.10509466361579
#
#
# Share price: $0.37630036374116316
# Shares owned at the moment: 69
# Cash capital at the moment: $0.06896657145564689
#
#
# Price increase from previously bought: 12.345568910474558%
# Share price: $0.4239193656144522
# Shares owned at the moment: 0
# Cash capital at the moment: $29.238964099227505
#
#
#
#
# Capital at the end of test period: $29.238964099227505
# profit gained: -70.7610359007725%
#
#
# Capital at the end of test period if Buy and Hold: $59.80379974835048
# profit gained: -40.19620025164952%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.247706      7.291667      10.000000      92.857143
# 1       0.220183      8.695652       6.666667      94.444444
# 2       0.189573      5.050505       7.407407      93.548387
# 3       0.160550      9.210526       3.508772      85.714286
# 4       0.211009      5.102041       9.302326      97.058824
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         50.000000           42.500000          85.365854     -89.341225
# 1         57.608696           56.179775          91.666667     -83.289165
# 2         56.565657           58.750000          87.096774     -80.976213
# 3         52.631579           46.017699          82.142857    2745.026056
# 4         45.918367           55.813953          90.909091     -70.761036
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# 2         -54.689601
# 3        1576.179166
# 4         -40.196200
# Recession Test
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.9377 - accuracy: 0.2237 - mse: 6.8851 - weighted_accuracy: 0.2237 - weighted_mse: 6.8851
# Test loss: 0.9377118349075317
# Test accuracy: 0.22374428808689117
#
#
# number of predictions: 219
# actual predicted buys: 10
# actual buys but predicted sell: 0
# actual buys but predicted hold: 1
# actual sells but predicted buy: 2
# actual predicted sells: 8
# actual sells but predicted hold: 1
# actual holds but predicted buy: 81
# actual holds but predicted sell: 85
# actual predicted holds: 31
# Percentage buys correct: 10.75268817204301%
# Percentage sells correct: 8.602150537634408%
# Percentage holds correct: 93.93939393939394%
# actual buys: 11
# actual sells: 11
# actual holds: 197
#
#
# Percentage low buys correct: 53.26086956521739%
# Percentage high sells correct: 58.064516129032256%
# Percentage mid holds correct: 87.87878787878788%
#
#
# Capital: 100
# Share price: $0.944210527554113
# Shares owned at the moment: 105
# Cash capital at the moment: $0.585253816986878
#
#
# Price increase from previously bought: 5.006662375095994%
# Share price: $0.9942105416710021
# Shares owned at the moment: 0
# Cash capital at the moment: $104.6902823985346
#
#
# Share price: $0.7376316242287357
# Shares owned at the moment: 141
# Cash capital at the moment: $0.3982067199881669
#
#
# Price increase from previously bought: -72.67593180550986%
# Share price: $0.20210523319046308
# Shares owned at the moment: 0
# Cash capital at the moment: $28.81667829567386
#
#
# Share price: $0.08499998980446886
# Shares owned at the moment: 338
# Cash capital at the moment: $0.007674251240132435
#
#
# Price increase from previously bought: 78.45661922545268%
# Share price: $0.15210525044443896
# Shares owned at the moment: 0
# Cash capital at the moment: $51.277867071172395
#
#
# Share price: $0.08499998980446886
# Shares owned at the moment: 601
# Cash capital at the moment: $0.0523894655372672
#
#
# Price increase from previously bought: 44.49428023079713%
# Share price: $0.12315787880374483
# Shares owned at the moment: 0
# Cash capital at the moment: $73.86672544239502
#
#
# Share price: $0.17052631653246791
# Shares owned at the moment: 431
# Cash capital at the moment: $0.1677667002312404
#
#
# Price increase from previously bought: 153.62351939887776%
# Share price: $0.4336842063160155
# Shares owned at the moment: 0
# Cash capital at the moment: $186.5716354168979
#
#
# Share price: $0.5863157623131194
# Shares owned at the moment: 317
# Cash capital at the moment: $0.19841799784254022
#
#
# Price increase from previously bought: 8.006391215330888%
# Share price: $0.6349999568650604
# Shares owned at the moment: 0
# Cash capital at the moment: $200.93984311166957
#
#
# Share price: $0.6113157693715641
# Shares owned at the moment: 327
# Cash capital at the moment: $0.4898608215607396
#
#
# Price increase from previously bought: 2.51618888068208%
# Share price: $0.6284210472655098
# Shares owned at the moment: 0
# Cash capital at the moment: $205.41843565062896
#
#
# Share price: $0.5784210331486206
# Shares owned at the moment: 354
# Cash capital at the moment: $0.09429704024708485
#
#
# Price increase from previously bought: 1.7674587315577694%
# Share price: $0.5902631582662341
# Shares owned at the moment: 0
# Cash capital at the moment: $208.4728338819218
#
#
# Share price: $0.6047368597720135
# Shares owned at the moment: 343
# Cash capital at the moment: $0.4776729371411932
#
#
# Price increase from previously bought: 14.914615261460495%
# Share price: $0.6968420960995632
# Shares owned at the moment: 0
# Cash capital at the moment: $238.83721559214544
#
#
# Share price: $0.6744736654292847
# Shares owned at the moment: 353
# Cash capital at the moment: $0.09326638489244488
#
#
# Price increase from previously bought: -20.89642582282629%
# Share price: $0.5349999913730121
# Shares owned at the moment: 0
# Cash capital at the moment: $188.42891209794038
#
#
# Share price: $0.4744736717034577
# Shares owned at the moment: 396
# Cash capital at the moment: $0.020636274886044248
#
#
# Price increase from previously bought: -19.35654660225804%
# Share price: $0.38368419219912614
# Shares owned at the moment: 0
# Cash capital at the moment: $151.54174430043514
#
#
# Share price: $0.525789442643565
# Shares owned at the moment: 287
# Cash capital at the moment: $0.22519494412554764
#
#
# Price increase from previously bought: 17.19523847587119%
# Share price: $0.6178947417128444
# Shares owned at the moment: 0
# Cash capital at the moment: $177.07331239081503
#
#
# Share price: $0.542894720537511
# Shares owned at the moment: 325
# Cash capital at the moment: $0.14731605964357186
#
#
# Price increase from previously bought: -0.27424582398404285%
# Share price: $0.542894720537511
# Shares owned at the moment: 0
# Cash capital at the moment: $176.10288807785423
#
#
# Share price: $0.7376316242287357
# Shares owned at the moment: 238
# Cash capital at the moment: $0.06378161335740629
#
#
# Price increase from previously bought: 7.375059595943578%
# Share price: $0.7942104852034455
# Shares owned at the moment: 0
# Cash capital at the moment: $188.56606632921176
#
#
# Share price: $0.7389473183102233
# Shares owned at the moment: 254
# Cash capital at the moment: $0.3572927765753491
#
#
# Price increase from previously bought: -0.9845425758060689%
# Share price: $0.7336841655338908
# Shares owned at the moment: 0
# Cash capital at the moment: $186.2005924325582
#
#
# Share price: $0.6836842141587314
# Shares owned at the moment: 271
# Cash capital at the moment: $0.41265473494019034
#
#
# Price increase from previously bought: 4.523943242476114%
# Share price: $0.716578887639945
# Shares owned at the moment: 0
# Cash capital at the moment: $194.0715028693516
#
#
# Share price: $0.638947352818175
# Shares owned at the moment: 302
# Cash capital at the moment: $0.5787565417472251
#
#
#
#
# Capital at the end of test period: $193.01021131632058
# profit gained: 93.01021131632058%
#
#
# Capital at the end of test period if Buy and Hold: $67.49022981476901
# profit gained: -32.50977018523099%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.297674      7.216495      10.606061      96.153846
# 1       0.213953      7.216495       9.756098      86.111111
# 2       0.300469      6.593407       9.375000      89.655172
# 3       0.237443      7.000000       9.210526      88.372093
# 4       0.223744     10.752688       8.602151      93.939394
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         48.453608           59.090909          92.156863     -70.597242
# 1         53.608247           58.536585          85.714286     -47.952346
# 2         47.252747           57.812500          82.456140     -86.147587
# 3         52.525253           57.894737          81.395349     -13.352197
# 4         53.260870           58.064516          87.878788      93.010211
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
# 2         -84.289887
# 3         -31.900348
# 4         -32.509770

# %%
df = nr_log_hist['0_epochs_logs']
df['Profit gained']
# Out:
# 0    -80.219205
# 1    -66.923701
# 2    -64.866999
# 3    214.844658
# 4    -33.627847
# Name: Profit gained, dtype: float64

# %%
C6LSI_acc = []
O39SI_acc = []
CNOOC_acc = []
JPM_acc = []
AXL_acc = []

C6LSI_correct_buys = []
O39SI_correct_buys = []
CNOOC_correct_buys = []
JPM_correct_buys = []
AXL_correct_buys = []

C6LSI_correct_sells = []
O39SI_correct_sells = []
CNOOC_correct_sells = []
JPM_correct_sells = []
AXL_correct_sells = []

C6LSI_correct_holds = []
O39SI_correct_holds = []
CNOOC_correct_holds = []
JPM_correct_holds = []
AXL_correct_holds = []

C6LSI_correct_low_buys = []
O39SI_correct_low_buys = []
CNOOC_correct_low_buys = []
JPM_correct_low_buys = []
AXL_correct_low_buys = []

C6LSI_correct_high_sells = []
O39SI_correct_high_sells = []
CNOOC_correct_high_sells = []
JPM_correct_high_sells = []
AXL_correct_high_sells = []

C6LSI_correct_mid_holds = []
O39SI_correct_mid_holds = []
CNOOC_correct_mid_holds = []
JPM_correct_mid_holds = []
AXL_correct_mid_holds = []

C6LSI_profit = []
O39SI_profit = []
CNOOC_profit = []
JPM_profit = []
AXL_profit = []

for key,value in nr_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    C6LSI_acc.append(acc[0])
    O39SI_acc.append(acc[1])
    CNOOC_acc.append(acc[2])
    JPM_acc.append(acc[3]) 
    AXL_acc.append(acc[4]) 

    C6LSI_correct_buys.append(correct_buys[0])
    O39SI_correct_buys.append(correct_buys[1]) 
    CNOOC_correct_buys.append(correct_buys[2]) 
    JPM_correct_buys.append(correct_buys[3]) 
    AXL_correct_buys.append(correct_buys[4])
    

    C6LSI_correct_sells.append(correct_sells[0]) 
    O39SI_correct_sells.append(correct_sells[1]) 
    CNOOC_correct_sells.append(correct_sells[2]) 
    JPM_correct_sells.append(correct_sells[3]) 
    AXL_correct_sells.append(correct_sells[4]) 
    

    C6LSI_correct_holds.append(correct_holds[0]) 
    O39SI_correct_holds.append(correct_holds[1])  
    CNOOC_correct_holds.append(correct_holds[2])  
    JPM_correct_holds.append(correct_holds[3])  
    AXL_correct_holds.append(correct_holds[4])  
     

    C6LSI_correct_low_buys.append(correct_low_buys[0])  
    O39SI_correct_low_buys.append(correct_low_buys[1])  
    CNOOC_correct_low_buys.append(correct_low_buys[2])  
    JPM_correct_low_buys.append(correct_low_buys[3])   
    AXL_correct_low_buys.append(correct_low_buys[4])   
    

    C6LSI_correct_high_sells.append(correct_high_sells[0]) 
    O39SI_correct_high_sells.append(correct_high_sells[1]) 
    CNOOC_correct_high_sells.append(correct_high_sells[2]) 
    JPM_correct_high_sells.append(correct_high_sells[3]) 
    AXL_correct_high_sells.append(correct_high_sells[4]) 
    

    C6LSI_correct_mid_holds.append(correct_mid_holds[0])  
    O39SI_correct_mid_holds.append(correct_mid_holds[1])  
    CNOOC_correct_mid_holds.append(correct_mid_holds[2])   
    JPM_correct_mid_holds.append(correct_mid_holds[3])   
    AXL_correct_mid_holds.append(correct_mid_holds[4])   
    

    C6LSI_profit.append(profit[0]) 
    O39SI_profit.append(profit[1]) 
    CNOOC_profit.append(profit[2]) 
    JPM_profit.append(profit[3])  
    AXL_profit.append(profit[4])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(C6LSI_acc)
plt.plot(O39SI_acc)
plt.plot(CNOOC_acc)
plt.plot(JPM_acc)
plt.plot(AXL_acc)
plt.title('Non-Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['C6L.SI_acc','O39.SI_acc','CNOOC_acc','JPM_acc','AXL_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_low_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_low_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_high_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_high_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_mid_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_mid_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_profit")

plt.subplot(3, 4, 2)
plt.plot(O39SI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_profit")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_profit")

plt.subplot(3, 4, 4)
plt.plot(JPM_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_profit")

plt.subplot(3, 4, 5)
plt.plot(AXL_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_profit")
# Out:
# Text(0.5, 1.0, 'AXL_profit')

# %%
C6LSI_acc = []
O39SI_acc = []
CNOOC_acc = []
JPM_acc = []
AXL_acc = []

C6LSI_correct_buys = []
O39SI_correct_buys = []
CNOOC_correct_buys = []
JPM_correct_buys = []
AXL_correct_buys = []

C6LSI_correct_sells = []
O39SI_correct_sells = []
CNOOC_correct_sells = []
JPM_correct_sells = []
AXL_correct_sells = []

C6LSI_correct_holds = []
O39SI_correct_holds = []
CNOOC_correct_holds = []
JPM_correct_holds = []
AXL_correct_holds = []

C6LSI_correct_low_buys = []
O39SI_correct_low_buys = []
CNOOC_correct_low_buys = []
JPM_correct_low_buys = []
AXL_correct_low_buys = []

C6LSI_correct_high_sells = []
O39SI_correct_high_sells = []
CNOOC_correct_high_sells = []
JPM_correct_high_sells = []
AXL_correct_high_sells = []

C6LSI_correct_mid_holds = []
O39SI_correct_mid_holds = []
CNOOC_correct_mid_holds = []
JPM_correct_mid_holds = []
AXL_correct_mid_holds = []

C6LSI_profit = []
O39SI_profit = []
CNOOC_profit = []
JPM_profit = []
AXL_profit = []

for key,value in r_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    C6LSI_acc.append(acc[0])
    O39SI_acc.append(acc[1])
    CNOOC_acc.append(acc[2])
    JPM_acc.append(acc[3]) 
    AXL_acc.append(acc[4]) 

    C6LSI_correct_buys.append(correct_buys[0])
    O39SI_correct_buys.append(correct_buys[1]) 
    CNOOC_correct_buys.append(correct_buys[2]) 
    JPM_correct_buys.append(correct_buys[3]) 
    AXL_correct_buys.append(correct_buys[4])
    

    C6LSI_correct_sells.append(correct_sells[0]) 
    O39SI_correct_sells.append(correct_sells[1]) 
    CNOOC_correct_sells.append(correct_sells[2]) 
    JPM_correct_sells.append(correct_sells[3]) 
    AXL_correct_sells.append(correct_sells[4]) 
    

    C6LSI_correct_holds.append(correct_holds[0]) 
    O39SI_correct_holds.append(correct_holds[1])  
    CNOOC_correct_holds.append(correct_holds[2])  
    JPM_correct_holds.append(correct_holds[3])  
    AXL_correct_holds.append(correct_holds[4])  
     

    C6LSI_correct_low_buys.append(correct_low_buys[0])  
    O39SI_correct_low_buys.append(correct_low_buys[1])  
    CNOOC_correct_low_buys.append(correct_low_buys[2])  
    JPM_correct_low_buys.append(correct_low_buys[3])   
    AXL_correct_low_buys.append(correct_low_buys[4])   
    

    C6LSI_correct_high_sells.append(correct_high_sells[0]) 
    O39SI_correct_high_sells.append(correct_high_sells[1]) 
    CNOOC_correct_high_sells.append(correct_high_sells[2]) 
    JPM_correct_high_sells.append(correct_high_sells[3]) 
    AXL_correct_high_sells.append(correct_high_sells[4]) 
    

    C6LSI_correct_mid_holds.append(correct_mid_holds[0])  
    O39SI_correct_mid_holds.append(correct_mid_holds[1])  
    CNOOC_correct_mid_holds.append(correct_mid_holds[2])   
    JPM_correct_mid_holds.append(correct_mid_holds[3])   
    AXL_correct_mid_holds.append(correct_mid_holds[4])   
    

    C6LSI_profit.append(profit[0]) 
    O39SI_profit.append(profit[1]) 
    CNOOC_profit.append(profit[2]) 
    JPM_profit.append(profit[3])  
    AXL_profit.append(profit[4])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(C6LSI_acc)
plt.plot(O39SI_acc)
plt.plot(CNOOC_acc)
plt.plot(JPM_acc)
plt.plot(AXL_acc)
plt.title('Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['C6L.SI_acc','O39.SI_acc','CNOOC_acc','JPM_acc','AXL_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_low_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_low_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_high_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_high_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_mid_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_mid_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_profit")

plt.subplot(3, 4, 2)
plt.plot(O39SI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_profit")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_profit")

plt.subplot(3, 4, 4)
plt.plot(JPM_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_profit")

plt.subplot(3, 4, 5)
plt.plot(AXL_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_profit")
# Out:
# Text(0.5, 1.0, 'AXL_profit')
