# %%
import os
seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
experiment = '50 percent More buy CNN Images Experiments - cyclic'

# %%
import requests
import lxml
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.utils import compute_class_weight
import tensorflow as tf
from pil import Image
from sklearn import preprocessing
import tensorflow_addons as tfa
import glob
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
import math

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
# gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
np.random.seed(seed)
tf.random.set_seed(seed)

session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, 
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), 
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)

# %% [markdown]
# ## Prepare Test Data

# %%
nr_test_sets = ['C6L.SI','O39.SI','0883.HK','JPM','AXL']
nr_test_data = {}

for name in nr_test_sets:

    df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    willr_data = []
    price_data = []
    ema_data = []
    obv_data = []
    labels = []
    data_15_price = []
    data_15_willr = []
    data_15_ema = []
    data_15_obv = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
            data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
            data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
            data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
            price_data.append(data_15_price_arr)
            willr_data.append(data_15_willr_arr)
            ema_data.append(data_15_ema_arr)
            obv_data.append(data_15_obv_arr)
            labels.append(i[-1])
            data_15_price = data_15_price[1:]
            data_15_willr = data_15_willr[1:]
            data_15_obv = data_15_obv[1:]
            data_15_ema = data_15_ema[1:]

        else:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            count += 1

    willr_data = np.array(willr_data)
    price_data = np.array(price_data)
    ema_data = np.array(ema_data)
    obv_data = np.array(obv_data)
    
    sequential_data = []
    
    for i in range(0,len(willr_data)):
        j = willr_data[i]
        k = price_data[i]
        l = ema_data[i]
        m = obv_data[i]
        fig, ax = plt.subplots()
        fig.set_size_inches((5,5))

        ax.plot(k)
        ax.plot(j)
        ax.plot(l)
        ax.plot(m)

        ax.axis('off')

        fig.add_axes(ax)
        fig.canvas.draw()

        # this rasterized the figure
        X = np.array(fig.canvas.renderer._renderer)
        X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
        X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
        sequential_data.append(X)
        plt.close()
        
    X = sequential_data
    y = labels

    X  = np.array(X).reshape(-1, 64, 64, 1)
    X = X/255
    y = np.array(y)
    
    y = to_categorical(y, 3)
    
    nr_test_data['{}_X'.format(name)] = X
    nr_test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2019-01-21         9.59  9.538960 -32.758553  6890900.0     2.0
# 2019-01-22         9.63  9.552966 -25.862007  7759500.0     2.0
# 2019-01-23         9.61  9.561740 -29.310362  7108100.0     1.0
# 2019-01-24         9.50  9.552242 -48.275822  6126400.0     2.0
# 2019-01-25         9.74  9.581128  -8.888884  8160300.0     2.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-21        11.75  11.523654 -10.869606  21160951.0     2.0
# 2019-01-22        11.73  11.555399 -13.978517  18040951.0     2.0
# 2019-01-23        11.50  11.546876 -38.709667  14286851.0     1.0
# 2019-01-24        11.38  11.521203 -51.612890   8454651.0     2.0
# 2019-01-25        11.41  11.504095 -80.357185  12469051.0     2.0
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2019-01-22        13.12  12.552209  -3.030323  489168111.0     2.0
# 2019-01-23        12.94  12.611869 -13.043517  449876554.0     2.0
# 2019-01-24        12.62  12.613120 -33.333352  395082483.0     2.0
# 2019-01-25        12.80  12.641871 -37.254896  441807090.0     2.0
# 2019-01-28        13.06  12.706198 -11.764689  494043477.0     2.0
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22   104.589996  101.198442  -3.459880  84335200.0     2.0
# 2019-01-23   102.940002  101.466374 -21.874992  67251500.0     2.0
# 2019-01-24   102.680000  101.653086 -27.040213  55104800.0     2.0
# 2019-01-25   102.739998  101.820303 -32.628441  66401600.0     2.0
# 2019-01-28   103.389999  102.061795 -23.968276  80771000.0     2.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22        14.61  13.028180  -0.258404  23356600.0     2.0
# 2019-01-23        14.52  13.257691  -3.886001  21174700.0     2.0
# 2019-01-24        14.18  13.399585 -13.535906  19629300.0     2.0
# 2019-01-25        14.38  13.550418  -8.579880  20903300.0     2.0
# 2019-01-28        14.71  13.728815  -4.790414  22287500.0     2.0

# %%
r_test_sets = ['C6L.SI','O39.SI','0883.HK','JPM','AXL']
r_test_data = {}

for name in r_test_sets:

    df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test2.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    willr_data = []
    price_data = []
    ema_data = []
    obv_data = []
    labels = []
    data_15_price = []
    data_15_willr = []
    data_15_ema = []
    data_15_obv = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
            data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
            data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
            data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
            price_data.append(data_15_price_arr)
            willr_data.append(data_15_willr_arr)
            ema_data.append(data_15_ema_arr)
            obv_data.append(data_15_obv_arr)
            labels.append(i[-1])
            data_15_price = data_15_price[1:]
            data_15_willr = data_15_willr[1:]
            data_15_obv = data_15_obv[1:]
            data_15_ema = data_15_ema[1:]

        else:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            count += 1

    willr_data = np.array(willr_data)
    price_data = np.array(price_data)
    ema_data = np.array(ema_data)
    obv_data = np.array(obv_data)
    
    sequential_data = []
    
    for i in range(0,len(willr_data)):
        j = willr_data[i]
        k = price_data[i]
        l = ema_data[i]
        m = obv_data[i]
        fig, ax = plt.subplots()
        fig.set_size_inches((5,5))

        ax.plot(k)
        ax.plot(j)
        ax.plot(l)
        ax.plot(m)

        ax.axis('off')

        fig.add_axes(ax)
        fig.canvas.draw()

        # this rasterized the figure
        X = np.array(fig.canvas.renderer._renderer)
        X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
        X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
        sequential_data.append(X)
        plt.close()
        
    X = sequential_data
    y = labels

    X  = np.array(X).reshape(-1, 64, 64, 1)
    X = X/255
    y = np.array(y)
    
    y = to_categorical(y, 3)
    
    r_test_data['{}_X'.format(name)] = X
    r_test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2020-01-22         8.84  8.979182 -96.551645  -851200.0     2.0
# 2020-01-23         8.93  8.971615 -65.517105  1644900.0     2.0
# 2020-01-24         8.85  8.952905 -92.307523  -246900.0     2.0
# 2020-01-28         8.82  8.932458 -75.000000 -1718200.0     2.0
# 2020-01-29         8.56  8.875157 -86.885115 -5499900.0     2.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22        11.12  11.072811 -24.444379  27489400.0     2.0
# 2020-01-23        11.19  11.090840  -8.888884  31751200.0     2.0
# 2020-01-24        11.11  11.093787 -26.666653  27359800.0     2.0
# 2020-01-28        11.10  11.094743 -28.888715  24699300.0     2.0
# 2020-01-29        10.90  11.064783 -71.739257  16499235.0     2.0
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2020-01-22        13.00  13.393678 -83.870980  104646165.0     2.0
# 2020-01-23        13.34  13.385420 -57.377021  145802714.0     2.0
# 2020-01-24        13.00  13.326125 -85.245880   96260120.0     2.0
# 2020-01-29        13.04  13.282106 -80.645176  122828433.0     2.0
# 2020-01-30        12.46  13.155628 -90.804605   53693706.0     2.0
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22   136.839996  137.690058 -77.454723  33776700.0     2.0
# 2020-01-23   136.679993  137.534664 -80.363881  26227600.0     2.0
# 2020-01-24   136.539993  137.381637 -69.867648  16881900.0     2.0
# 2020-01-27   133.149994  136.730615 -90.166021   1715500.0     1.0
# 2020-01-28   132.029999  136.007444 -79.004573 -11145000.0     2.0
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2020-01-22         9.39  9.715390 -73.059349 -3592400.0     2.0
# 2020-01-23         9.34  9.657637 -75.342463 -4550300.0     2.0
# 2020-01-24         9.50  9.633386 -65.000010 -3092000.0     2.0
# 2020-01-27         9.31  9.583634 -66.883101 -4332600.0     2.0
# 2020-01-28         9.39  9.553844 -61.688301 -2300800.0     2.0

# %% [markdown]
# ## Train Stock Data

# %%
def pred_acc(actual, predictions, logger):

    hold = 0
    sell = 0
    buy = 0
    pred_hold = 0
    pred_sell = 0
    pred_buy = 0
    buy_buy = 0
    buy_sell = 0
    buy_hold = 0
    sell_buy = 0
    sell_sell = 0
    sell_hold = 0
    hold_buy = 0
    hold_sell = 0
    hold_hold = 0

    for i in range (0,len(actual)):
        if actual[i]==1 and predictions[i] == 1:
            buy_buy += 1
            buy += 1
            pred_buy += 1
        elif actual[i]==1 and predictions[i] == 0:
            buy_sell += 1
            buy += 1
            pred_sell += 1
        elif actual[i]==1 and predictions[i] == 2:
            buy_hold += 1
            buy += 1
            pred_hold += 1
        elif actual[i]==0 and predictions[i] == 1:
            sell_buy += 1
            sell += 1
            pred_buy += 1
        elif actual[i]==0 and predictions[i] == 0:
            sell_sell += 1
            sell += 1
            pred_sell += 1
        elif actual[i]==0 and predictions[i] == 2:
            sell_hold += 1
            sell += 1
            pred_hold += 1
        elif actual[i]==2 and predictions[i] == 1:
            hold_buy += 1
            hold += 1
            pred_buy += 1
        elif actual[i]==2 and predictions[i] == 0:
            hold_sell += 1
            hold += 1
            pred_sell += 1
        elif actual[i]==2 and predictions[i] == 2:
            hold_hold += 1
            hold += 1
            pred_hold += 1

    print("number of predictions: " + str(len(actual)))
    print("actual predicted buys: " + str(buy_buy) )
    print("actual buys but predicted sell: " + str(buy_sell) )
    print("actual buys but predicted hold: " + str(buy_hold))
    print("actual sells but predicted buy: " + str(sell_buy) )
    print("actual predicted sells: " + str(sell_sell))
    print("actual sells but predicted hold: " + str(sell_hold) )
    print("actual holds but predicted buy: " + str(hold_buy) )
    print("actual holds but predicted sell: " + str(hold_sell))
    print("actual predicted holds: " + str(hold_hold) )
    
    if pred_buy !=0:
        Percentage_buys_correct = 100*buy_buy/pred_buy
    else:
        Percentage_buys_correct = 0
        
    if pred_sell !=0:
        Percentage_sells_correct = 100*sell_sell/pred_sell
    else:
        Percentage_sells_correct = 0
        
    if pred_hold !=0:
        Percentage_holds_correct = 100*hold_hold/pred_hold
    else:
        Percentage_holds_correct = 0

    print("Percentage buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage holds correct: " + str(Percentage_holds_correct) + "%")

    print("actual buys: " + str(buy))
    print("actual sells: " + str(sell))
    print("actual holds: " + str(hold))
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def correct_maxima_minima(predictions, price, logger):
    correct_maxima = 0 
    correct_minima = 0
    correct_hold = 0

    hold = 0
    buy = 0
    sell = 0

#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):
        if i < 4:
            prices = price[i:i+9]
            prices.sort(key = float)
#             if i == 0:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1

        else:
            prices = price[i:i+5]
            prices = prices + price[i-4:i] 
            prices.sort(key = float)
#             if i == 10:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1
                    
    if buy !=0:
        Percentage_buys_correct = 100*correct_minima/buy
    else:
        Percentage_buys_correct = 0
        
    if sell !=0:
        Percentage_sells_correct = 100*correct_maxima/sell
    else:
        Percentage_sells_correct = 0
        
    if hold !=0:
        Percentage_holds_correct = 100*correct_hold/hold
    else:
        Percentage_holds_correct = 0

    print("Percentage low buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage high sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage mid holds correct: " + str(Percentage_holds_correct) + "%")
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %% [markdown]
# ### Creating Training Data and Model

# %%
sequential_data = []
labels = []

train_sets = ['C6L.SI','O39.SI','600104.SS','0883.HK','1398.HK','ANF','AXL','JPM','CTB','TROX']

for name in train_sets:
    seed = 10
    df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    plt.figure(figsize=(15,5))
    plt.plot(df['previous_1d'].values)
    plt.plot(df['EMA_12'].values)
    plt.show()

    willr_data = []
    price_data = []
    ema_data = []
    obv_data = []
    data_15_price = []
    data_15_willr = []
    data_15_ema = []
    data_15_obv = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
            data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
            data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
            data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
            price_data.append(data_15_price_arr)
            willr_data.append(data_15_willr_arr)
            ema_data.append(data_15_ema_arr)
            obv_data.append(data_15_obv_arr)
            labels.append(i[-1])
            data_15_price = data_15_price[1:]
            data_15_willr = data_15_willr[1:]
            data_15_obv = data_15_obv[1:]
            data_15_ema = data_15_ema[1:]

        else:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            count += 1
            
    willr_data = np.array(willr_data)
    price_data = np.array(price_data)
    ema_data = np.array(ema_data)
    obv_data = np.array(obv_data)
        
    for i in range(0,len(willr_data)):
        j = willr_data[i]
        k = price_data[i]
        l = ema_data[i]
        m = obv_data[i]
        fig, ax = plt.subplots()
        fig.set_size_inches((5,5))

        ax.plot(k)
        ax.plot(j)
        ax.plot(l)
        ax.plot(m)

        ax.axis('off')

        fig.add_axes(ax)
        fig.canvas.draw()

        # this rasterized the figure
        X = np.array(fig.canvas.renderer._renderer)
        X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
        X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
        sequential_data.append(X)
        plt.close()
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels
# Date
# 2000-01-21    19.000000  19.215335 -37.499990   388000.0     2.0
# 2000-01-24    18.400000  19.089899 -50.000000 -2311000.0     2.0
# 2000-01-25    18.100000  18.937607 -48.780483 -3542000.0     2.0
# 2000-01-26    17.700001  18.747206 -85.714237 -6261000.0     2.0
# 2000-01-27    17.799999  18.601482 -82.142864 -4565000.0     2.0
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2000-01-21     6.793788  7.018572 -90.000010 -1965914.0     2.0
# 2000-01-24     6.890842  6.998922 -77.777802  6276910.0     2.0
# 2000-01-25     6.793788  6.967363 -85.714286  -511055.0     2.0
# 2000-01-26     6.745261  6.933193 -86.666549 -7435027.0     2.0
# 2000-01-27     6.890842  6.926678 -66.666601 -3725757.0     2.0
#             previous_1d    EMA_12   willr_14        OBV_7  labels
# Date
# 2000-01-24     3.189194  3.249583 -69.696967   61394527.0     2.0
# 2000-01-25     3.205140  3.242745 -79.136806   75032521.0     2.0
# 2000-01-26     3.402870  3.267380 -34.532549  127274101.0     2.0
# 2000-01-27     3.284870  3.270071 -62.500055   91746305.0     2.0
# 2000-01-28     3.252978  3.267441 -69.852957   65314909.0     2.0
#             previous_1d    EMA_12   willr_14       OBV_7  labels
# Date
# 2004-04-07        3.250  3.264699 -57.142857  31539206.0     2.0
# 2004-04-08        3.200  3.254745 -78.947368 -24878594.0     2.0
# 2004-04-13        3.250  3.254015 -52.631579  10937473.0     0.0
# 2004-04-14        3.375  3.272628 -10.416706  98972973.0     2.0
# 2004-04-15        3.275  3.272993 -52.083331  47190715.0     2.0
#             previous_1d    EMA_12   willr_14         OBV_7  labels
# Date
# 2006-11-17     3.953848  3.652647 -15.942120  1.897904e+10     2.0
# 2006-11-20     3.934226  3.695967 -18.840636  1.837444e+10     2.0
# 2006-11-21     3.934226  3.732622 -19.403036  1.837444e+10     2.0
# 2006-11-22     3.934226  3.763638 -19.697025  1.837444e+10     0.0
# 2006-11-23     4.051959  3.807995  -1.562480  1.907354e+10     2.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2000-01-21      21.5000  24.211693 -82.142857  -6805500.0     2.0
# 2000-01-24      20.2500  23.602201 -92.465753  -8986800.0     1.0
# 2000-01-25      20.1875  23.076863 -92.307692 -11383100.0     2.0
# 2000-01-26      20.8750  22.738115 -82.786885  -9392500.0     2.0
# 2000-01-27      22.8750  22.759174 -56.557377  -6811000.0     2.0
#             previous_1d     EMA_12   willr_14     OBV_7  labels
# Date
# 2000-01-21      16.0625  14.895987 -18.478261  298700.0     2.0
# 2000-01-24      15.8750  15.046605 -22.222222  293100.0     2.0
# 2000-01-25      15.7500  15.154819 -26.190476  286300.0     2.0
# 2000-01-26      15.7500  15.246386 -29.729730  286300.0     2.0
# 2000-01-27      16.0000  15.362326 -25.000000  311700.0     0.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2000-01-21    49.375000  48.388499 -42.592593  -2894250.0     2.0
# 2000-01-24    48.625000  48.424884 -39.516144  -8054850.0     2.0
# 2000-01-25    48.666668  48.462081 -38.709668  -1595700.0     2.0
# 2000-01-26    49.750000  48.660222 -17.741956   5984250.0     2.0
# 2000-01-27    52.291668  49.218906  -5.232557  14370900.0     2.0
#             previous_1d     EMA_12    willr_14     OBV_7  labels
# Date
# 2000-01-21      13.7500  14.817184  -97.297297 -827200.0     2.0
# 2000-01-24      14.0625  14.701079  -77.500000 -518900.0     2.0
# 2000-01-25      13.6875  14.545144  -92.500000 -906100.0     2.0
# 2000-01-26      13.7500  14.422814  -90.000000 -652700.0     2.0
# 2000-01-27      13.5000  14.280843 -100.000000 -848400.0     2.0
#             previous_1d     EMA_12  willr_14      OBV_7  labels
# Date
# 2010-12-21    18.799999  18.175961      -0.0  1579000.0     0.0
# 2010-12-22    19.000000  18.302736      -0.0  1699000.0     2.0
# 2010-12-23    19.000000  18.410008      -0.0  1699000.0     2.0
# 2010-12-27    19.000000  18.500776      -0.0  1699000.0     2.0
# 2010-12-28    19.000000  18.577580      -0.0  1699000.0     2.0

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
y = np.array(y)

X.shape
# Out:
# (41550, 64, 64, 1)

# %%
from collections import Counter

Counter(y)
# Out:
# Counter({2.0: 37853, 0.0: 1852, 1.0: 1845})

# %%
X = sequential_data
y = labels

class_0 = []
class_1 = []
class_2 = []

class_0_labels = []
class_1_labels = []
class_2_labels = []

for i in range (0,len(y)):
    if y[i] == 0:
        class_0.append(X[i])
        class_0_labels.append(y[i])
    if y[i] == 1:
        class_1.append(X[i])
        class_1_labels.append(y[i])
    if y[i] == 2:
        class_2.append(X[i])
        class_2_labels.append(y[i])
        
class_0 = class_0[0:923]
class_1 = class_1[0:1845]
class_2 = class_2[0:923]

class_0_labels = class_0_labels[0:923]
class_1_labels = class_1_labels[0:1845]
class_2_labels = class_2_labels[0:923]

X = class_0 + class_1 + class_2
y = class_0_labels + class_1_labels + class_2_labels

X  = np.array(X).reshape(-1, 64, 64, 1)
y = np.array(y)

print(X.shape)

Counter(y)
# Out:
# (3691, 64, 64, 1)
# Counter({0.0: 923, 1.0: 1845, 2.0: 923})

# %%
# plot the image array X
i = X[0].reshape(64, 64)
fig2, ax2 = plt.subplots()
plt.imshow(i, interpolation="none", cmap="gray")

ax2.axis('off')

plt.show()

# %%
X = X/255

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten,BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.regularizers import l2
import efficientnet.tfkeras as efn
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(Conv2D(16, (3, 3), padding='same', kernel_initializer='he_uniform',kernel_regularizer=l2(1e-5), input_shape=X_train.shape[1:]))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))

model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_uniform',kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

# model.add(Dense(128, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))
# model.add(Dropout(0.25, seed=seed))

model.add(Dense(64, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))
model.add(Dropout(0.25, seed=seed))

model.add(Dense(32, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))
model.add(Dropout(0.25, seed=seed))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "DBS_CNN_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))
print(d_class_weights)

epochs = 0 
histories = {}
nr_log_hist = {}
r_log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    nr_log  = pd.DataFrame(columns = column_names)
    r_log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['C6L.SI','O39.SI','0883.HK','JPM','AXL']
    
    for name in test_sets:
        
        print('\n')
        print(name)
        print('\n')
        
        print('Non-Recession Test')
        print('\n')
        
        X = nr_test_data['{}_X'.format(name)]
        y = nr_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(nr_log)
        nr_log.loc[df_length] = logger
        print(nr_log.head(20))
        logger = []
        
        print('Recession Test')
        print('\n')
        
        X = r_test_data['{}_X'.format(name)]
        y = r_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("data/cyclic_tickers/initial_indicators/{}_data_test2.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(r_log)
        r_log.loc[df_length] = logger
        print(r_log.head(20))
        logger = []

    nr_log.to_csv('non_recession_{}_{}epochs.csv'.format(experiment,epochs))
    nr_log_hist['{}_epochs_logs'.format(epochs)] = nr_log
    r_log.to_csv('recession_{}_{}epochs.csv'.format(experiment,epochs))
    r_log_hist['{}_epochs_logs'.format(epochs)] = r_log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[0 0 1 ... 2 2 1] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# {0: 1.3333333333333333, 1: 0.6666666666666666, 2: 1.3333333333333333}
#
#
#
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  1/24 [>.............................] - ETA: 0s - loss: 0.4972 - accuracy: 0.2422 - mse: 6.2675 - weighted_accuracy: 0.3027 - weighted_mse: 6.1790WARNING:tensorflow:From C:\Users\Shearman Chua\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/24 [=>............................] - ETA: 1s - loss: 0.4380 - accuracy: 0.2617 - mse: 4.8780 - weighted_accuracy: 0.3247 - weighted_mse: 4.7091WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0258s vs `on_train_batch_end` time: 0.1250s). Check your callbacks.
# 24/24 [==============================] - 1s 35ms/step - loss: 0.2397 - accuracy: 0.3564 - mse: 1.6656 - weighted_accuracy: 0.3261 - weighted_mse: 1.6618 - val_loss: 0.1960 - val_accuracy: 0.4912 - val_mse: 0.9292 - val_weighted_accuracy: 0.4912 - val_weighted_mse: 0.9292
# Epoch 2/20
# 24/24 [==============================] - 0s 13ms/step - loss: 0.2037 - accuracy: 0.3655 - mse: 1.1731 - weighted_accuracy: 0.3383 - weighted_mse: 1.1793 - val_loss: 0.1945 - val_accuracy: 0.5101 - val_mse: 0.9744 - val_weighted_accuracy: 0.5101 - val_weighted_mse: 0.9744
# Epoch 3/20
# 24/24 [==============================] - 0s 14ms/step - loss: 0.2056 - accuracy: 0.3967 - mse: 1.1588 - weighted_accuracy: 0.3336 - weighted_mse: 1.1692 - val_loss: 0.1944 - val_accuracy: 0.5332 - val_mse: 0.9647 - val_weighted_accuracy: 0.5332 - val_weighted_mse: 0.9647
# Epoch 4/20
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2044 - accuracy: 0.3543 - mse: 1.1695 - weighted_accuracy: 0.3270 - weighted_mse: 1.1751 - val_loss: 0.1986 - val_accuracy: 0.2463 - val_mse: 0.9752 - val_weighted_accuracy: 0.2463 - val_weighted_mse: 0.9752
# Epoch 5/20
# 24/24 [==============================] - 0s 13ms/step - loss: 0.2041 - accuracy: 0.3472 - mse: 1.1736 - weighted_accuracy: 0.3360 - weighted_mse: 1.1805 - val_loss: 0.1955 - val_accuracy: 0.2558 - val_mse: 0.9771 - val_weighted_accuracy: 0.2558 - val_weighted_mse: 0.9771
# Epoch 6/20
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2030 - accuracy: 0.3462 - mse: 1.1710 - weighted_accuracy: 0.3417 - weighted_mse: 1.1792 - val_loss: 0.1971 - val_accuracy: 0.3681 - val_mse: 0.9192 - val_weighted_accuracy: 0.3681 - val_weighted_mse: 0.9192
# Epoch 7/20
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2024 - accuracy: 0.3581 - mse: 1.1599 - weighted_accuracy: 0.3446 - weighted_mse: 1.1640 - val_loss: 0.1999 - val_accuracy: 0.2571 - val_mse: 0.8957 - val_weighted_accuracy: 0.2571 - val_weighted_mse: 0.8957
# Epoch 8/20
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2022 - accuracy: 0.3564 - mse: 1.1555 - weighted_accuracy: 0.3311 - weighted_mse: 1.1564 - val_loss: 0.1941 - val_accuracy: 0.2517 - val_mse: 1.0595 - val_weighted_accuracy: 0.2517 - val_weighted_mse: 1.0595
# Epoch 9/20
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2025 - accuracy: 0.3767 - mse: 1.1763 - weighted_accuracy: 0.3530 - weighted_mse: 1.1825 - val_loss: 0.1970 - val_accuracy: 0.3329 - val_mse: 0.9342 - val_weighted_accuracy: 0.3329 - val_weighted_mse: 0.9342
# Epoch 10/20
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2007 - accuracy: 0.3540 - mse: 1.1676 - weighted_accuracy: 0.3473 - weighted_mse: 1.1713 - val_loss: 0.1939 - val_accuracy: 0.4804 - val_mse: 0.9605 - val_weighted_accuracy: 0.4804 - val_weighted_mse: 0.9605
# Epoch 11/20
# 24/24 [==============================] - 0s 14ms/step - loss: 0.2006 - accuracy: 0.3642 - mse: 1.1644 - weighted_accuracy: 0.3579 - weighted_mse: 1.1685 - val_loss: 0.1932 - val_accuracy: 0.3383 - val_mse: 1.0255 - val_weighted_accuracy: 0.3383 - val_weighted_mse: 1.0255
# Epoch 12/20
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2008 - accuracy: 0.3747 - mse: 1.1734 - weighted_accuracy: 0.3663 - weighted_mse: 1.1763 - val_loss: 0.1933 - val_accuracy: 0.4817 - val_mse: 0.9718 - val_weighted_accuracy: 0.4817 - val_weighted_mse: 0.9718
# Epoch 13/20
# 24/24 [==============================] - 0s 12ms/step - loss: 0.1993 - accuracy: 0.3828 - mse: 1.1660 - weighted_accuracy: 0.3559 - weighted_mse: 1.1732 - val_loss: 0.1979 - val_accuracy: 0.4208 - val_mse: 0.8684 - val_weighted_accuracy: 0.4208 - val_weighted_mse: 0.8684
# Epoch 14/20
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2003 - accuracy: 0.3747 - mse: 1.1700 - weighted_accuracy: 0.3564 - weighted_mse: 1.1787 - val_loss: 0.1978 - val_accuracy: 0.2950 - val_mse: 0.9265 - val_weighted_accuracy: 0.2950 - val_weighted_mse: 0.9265
# Epoch 15/20
# 24/24 [==============================] - 0s 12ms/step - loss: 0.1992 - accuracy: 0.3720 - mse: 1.1770 - weighted_accuracy: 0.3604 - weighted_mse: 1.1822 - val_loss: 0.1956 - val_accuracy: 0.4574 - val_mse: 0.9094 - val_weighted_accuracy: 0.4574 - val_weighted_mse: 0.9094
# Epoch 16/20
# 24/24 [==============================] - 0s 12ms/step - loss: 0.1988 - accuracy: 0.4007 - mse: 1.1697 - weighted_accuracy: 0.3747 - weighted_mse: 1.1715 - val_loss: 0.1943 - val_accuracy: 0.5291 - val_mse: 0.8752 - val_weighted_accuracy: 0.5291 - val_weighted_mse: 0.8752
# Epoch 17/20
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1994 - accuracy: 0.3726 - mse: 1.1718 - weighted_accuracy: 0.3616 - weighted_mse: 1.1746 - val_loss: 0.1928 - val_accuracy: 0.3965 - val_mse: 0.9896 - val_weighted_accuracy: 0.3965 - val_weighted_mse: 0.9896
# Epoch 18/20
# 24/24 [==============================] - 0s 13ms/step - loss: 0.1992 - accuracy: 0.3835 - mse: 1.1674 - weighted_accuracy: 0.3659 - weighted_mse: 1.1741 - val_loss: 0.1883 - val_accuracy: 0.5129 - val_mse: 1.0430 - val_weighted_accuracy: 0.5129 - val_weighted_mse: 1.0430
# Epoch 19/20
# 24/24 [==============================] - 0s 12ms/step - loss: 0.1976 - accuracy: 0.4634 - mse: 1.1906 - weighted_accuracy: 0.3952 - weighted_mse: 1.1973 - val_loss: 0.1866 - val_accuracy: 0.5629 - val_mse: 1.0143 - val_weighted_accuracy: 0.5629 - val_weighted_mse: 1.0143
# Epoch 20/20
# 24/24 [==============================] - 0s 12ms/step - loss: 0.1956 - accuracy: 0.4722 - mse: 1.1808 - weighted_accuracy: 0.4194 - weighted_mse: 1.1875 - val_loss: 0.1873 - val_accuracy: 0.5643 - val_mse: 0.9616 - val_weighted_accuracy: 0.5643 - val_weighted_mse: 0.9616
# Validation loss: 0.187295600771904
# Validation accuracy: 0.5642760396003723
#
#
# C6L.SI
#
#
# Non-Recession Test
#
#
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2003 - accuracy: 0.0826 - mse: 0.9906 - weighted_accuracy: 0.0826 - weighted_mse: 0.9906
# Test loss: 0.20026513934135437
# Test accuracy: 0.08256880939006805
#
#
# number of predictions: 218
# actual predicted buys: 8
# actual buys but predicted sell: 1
# actual buys but predicted hold: 0
# actual sells but predicted buy: 3
# actual predicted sells: 6
# actual sells but predicted hold: 0
# actual holds but predicted buy: 95
# actual holds but predicted sell: 101
# actual predicted holds: 4
# Percentage buys correct: 7.547169811320755%
# Percentage sells correct: 5.555555555555555%
# Percentage holds correct: 100.0%
# actual buys: 9
# actual sells: 9
# actual holds: 200
#
#
# Percentage low buys correct: 50.943396226415096%
# Percentage high sells correct: 42.99065420560748%
# Percentage mid holds correct: 75.0%
#
#
# Capital: 100
# Share price: $0.7012750947593986
# Shares owned at the moment: 142
# Cash capital at the moment: $0.14508861966184838
#
#
# Price increase from previously bought: 2.589034750858943%
# Share price: $0.7214097868761586
# Shares owned at the moment: 0
# Cash capital at the moment: $102.30356783430123
#
#
# Share price: $0.7885235071154348
# Shares owned at the moment: 129
# Cash capital at the moment: $0.3043067022609449
#
#
# Price increase from previously bought: -1.1229864765787911%
# Share price: $0.7818125831264899
# Shares owned at the moment: 0
# Cash capital at the moment: $100.88078191171402
#
#
# Share price: $0.7146982228372389
# Shares owned at the moment: 140
# Cash capital at the moment: $0.5478718987082374
#
#
# Price increase from previously bought: -0.27424582398404285%
# Share price: $0.7146982228372389
# Shares owned at the moment: 0
# Cash capital at the moment: $100.33046428012935
#
#
# Share price: $0.5871817063476314
# Shares owned at the moment: 170
# Cash capital at the moment: $0.23506675331447013
#
#
# Price increase from previously bought: 32.78146889410984%
# Share price: $0.7818125831264899
# Shares owned at the moment: 0
# Cash capital at the moment: $132.7777085022061
#
#
# Share price: $0.801946635193276
# Shares owned at the moment: 165
# Cash capital at the moment: $0.09263040959663726
#
#
# Price increase from previously bought: -24.47749092898168%
# Share price: $0.6073157584144167
# Shares owned at the moment: 0
# Cash capital at the moment: $100.02416102259484
#
#
# Share price: $0.5938926303365772
# Shares owned at the moment: 167
# Cash capital at the moment: $0.5713465659043635
#
#
# Price increase from previously bought: -48.73397605381011%
# Share price: $0.305302417212735
# Shares owned at the moment: 0
# Cash capital at the moment: $51.41664010532615
#
#
# Share price: $0.2717452370681095
# Shares owned at the moment: 188
# Cash capital at the moment: $0.18804324895735647
#
#
# Price increase from previously bought: 12.040652990983759%
# Share price: $0.305302417212735
# Shares owned at the moment: 0
# Cash capital at the moment: $57.42705633525255
#
#
# Share price: $0.4932217299526729
# Shares owned at the moment: 116
# Cash capital at the moment: $0.05599792888759225
#
#
# Price increase from previously bought: 3.796709296286438%
# Share price: $0.5133557820194599
# Shares owned at the moment: 0
# Cash capital at the moment: $59.44150814868073
#
#
# Share price: $0.5603360902419257
# Shares owned at the moment: 105
# Cash capital at the moment: $0.44442162722118184
#
#
# Price increase from previously bought: 0.9201301365695302%
# Share price: $0.5670470142308714
# Shares owned at the moment: 0
# Cash capital at the moment: $59.82062329610352
#
#
# Share price: $0.6677185546647462
# Shares owned at the moment: 89
# Cash capital at the moment: $0.23024781468691202
#
#
# Price increase from previously bought: -1.276637895922128%
# Share price: $0.6610069906258265
# Shares owned at the moment: 0
# Cash capital at the moment: $58.89808851942979
#
#
# Share price: $0.285167725095975
# Shares owned at the moment: 205
# Cash capital at the moment: $0.2779415697320644
#
#
# Price increase from previously bought: -40.173968106713495%
# Share price: $0.1710736966342321
# Shares owned at the moment: 0
# Cash capital at the moment: $35.2516065832721
#
#
# Share price: $0.1375171565395814
# Shares owned at the moment: 255
# Cash capital at the moment: $0.08829775965545394
#
#
# Price increase from previously bought: -14.875677434212486%
# Share price: $0.1173824644228214
# Shares owned at the moment: 0
# Cash capital at the moment: $29.938511734298405
#
#
# Share price: $0.01
# Shares owned at the moment: 2985
# Cash capital at the moment: $0.006424234298403775
#
#
# Price increase from previously bought: 936.7487050107794%
# Share price: $0.1039599763949559
# Shares owned at the moment: 0
# Cash capital at the moment: $309.4735723170096
#
#
# Share price: $0.3724161374520112
# Shares owned at the moment: 828
# Cash capital at the moment: $0.2650189617660885
#
#
# Price increase from previously bought: -14.651707180938512%
# Share price: $0.3187249052406005
# Shares owned at the moment: 0
# Cash capital at the moment: $263.4435038917504
#
#
# Share price: $0.3120133412016799
# Shares owned at the moment: 842
# Cash capital at the moment: $0.005803708383496087
#
#
# Price increase from previously bought: 1.87090535097596%
# Share price: $0.3187249052406005
# Shares owned at the moment: 0
# Cash capital at the moment: $267.6341664028845
#
#
# Share price: $0.3724161374520112
# Shares owned at the moment: 716
# Cash capital at the moment: $0.2509246126014659
#
#
# Price increase from previously bought: -0.27424582398404285%
# Share price: $0.3724161374520112
# Shares owned at the moment: 0
# Cash capital at the moment: $266.1675916535985
#
#
# Share price: $0.3724161374520112
# Shares owned at the moment: 712
# Cash capital at the moment: $0.27811099063552547
#
#
# Price increase from previously bought: -18.245986823747806%
# Share price: $0.305302417212735
# Shares owned at the moment: 0
# Cash capital at the moment: $217.05564991320028
#
#
# Share price: $0.238188056923484
# Shares owned at the moment: 908
# Cash capital at the moment: $0.18613864853887208
#
#
# Price increase from previously bought: 22.205464930961938%
# Share price: $0.2918792891348947
# Shares owned at the moment: 0
# Cash capital at the moment: $264.4837105980534
#
#
#
#
# Capital at the end of test period: $264.4837105980534
# profit gained: 164.4837105980534%
#
#
# Capital at the end of test period if Buy and Hold: $35.84540016707856
# profit gained: -64.15459983292143%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.082569       7.54717       5.555556          100.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         50.943396           42.990654               75.0     164.483711
#
#    buy_n_hold profit
# 0           -64.1546
# Recession Test
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1975 - accuracy: 0.1875 - mse: 0.9690 - weighted_accuracy: 0.1875 - weighted_mse: 0.9690WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0049s vs `on_test_batch_end` time: 0.0081s). Check your callbacks.
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2003 - accuracy: 0.1070 - mse: 0.9742 - weighted_accuracy: 0.1070 - weighted_mse: 0.9742
# Test loss: 0.20031675696372986
# Test accuracy: 0.10697674751281738
#
#
# number of predictions: 215
# actual predicted buys: 7
# actual buys but predicted sell: 1
# actual buys but predicted hold: 0
# actual sells but predicted buy: 1
# actual predicted sells: 6
# actual sells but predicted hold: 2
# actual holds but predicted buy: 108
# actual holds but predicted sell: 80
# actual predicted holds: 10
# Percentage buys correct: 6.0344827586206895%
# Percentage sells correct: 6.896551724137931%
# Percentage holds correct: 83.33333333333333%
# actual buys: 8
# actual sells: 9
# actual holds: 198
#
#
# Percentage low buys correct: 41.73913043478261%
# Percentage high sells correct: 50.57471264367816%
# Percentage mid holds correct: 83.33333333333333%
#
#
# Capital: 100
# Share price: $1.0062617748699323
# Shares owned at the moment: 99
# Cash capital at the moment: $0.10612951966835737
#
#
# Price increase from previously bought: 0.09623164985612664%
# Share price: $1.01
# Shares owned at the moment: 0
# Cash capital at the moment: $99.82115701966835
#
#
# Share price: $0.9931775412724846
# Shares owned at the moment: 100
# Cash capital at the moment: $0.23027906856994207
#
#
# Price increase from previously bought: -39.124775678263624%
# Share price: $0.6062617035671785
# Shares owned at the moment: 0
# Cash capital at the moment: $60.68972745680681
#
#
# Share price: $0.46420558348692387
# Shares owned at the moment: 130
# Cash capital at the moment: $0.17704810741012977
#
#
# Price increase from previously bought: 9.363043241172587%
# Share price: $0.5090654437174831
# Shares owned at the moment: 0
# Cash capital at the moment: $66.17356489455392
#
#
# Share price: $0.5146729596694688
# Shares owned at the moment: 128
# Cash capital at the moment: $0.11426117505826028
#
#
# Price increase from previously bought: -67.13229828091349%
# Share price: $0.16962636643929108
# Shares owned at the moment: 0
# Cash capital at the moment: $21.766727598300886
#
#
# Share price: $0.2137383499098866
# Shares owned at the moment: 101
# Cash capital at the moment: $0.11978843071486622
#
#
# Price increase from previously bought: 0.5978422232308045%
# Share price: $0.21560746247492013
# Shares owned at the moment: 0
# Cash capital at the moment: $21.83625716797939
#
#
# Share price: $0.08663553142789203
# Shares owned at the moment: 251
# Cash capital at the moment: $0.030938604010387394
#
#
# Price increase from previously bought: 21.24153428565434%
# Share price: $0.10532710272044075
# Shares owned at the moment: 0
# Cash capital at the moment: $26.39533935418823
#
#
# Share price: $0.17635511819634686
# Shares owned at the moment: 149
# Cash capital at the moment: $0.04616523325159605
#
#
# Price increase from previously bought: -4.502149301804003%
# Share price: $0.16887848967932728
# Shares owned at the moment: 0
# Cash capital at the moment: $25.139862234325257
#
#
# Share price: $0.1427102898697593
# Shares owned at the moment: 175
# Cash capital at the moment: $0.09688218011755367
#
#
# Price increase from previously bought: -19.86674341177952%
# Share price: $0.11467288836671506
# Shares owned at the moment: 0
# Cash capital at the moment: $20.109451316766208
#
#
# Share price: $0.08663553142789203
# Shares owned at the moment: 231
# Cash capital at the moment: $0.04160833558357879
#
#
# Price increase from previously bought: -49.76059137381837%
# Share price: $0.043644872890808865
# Shares owned at the moment: 0
# Cash capital at the moment: $10.09584856785654
#
#
# Share price: $0.0941121599449115
# Shares owned at the moment: 106
# Cash capital at the moment: $0.0925259190719796
#
#
# Price increase from previously bought: -26.022675766171023%
# Share price: $0.06981311726459814
# Shares owned at the moment: 0
# Cash capital at the moment: $7.472365825436753
#
#
# Share price: $0.07915890291087245
# Shares owned at the moment: 94
# Cash capital at the moment: $0.010966375412281515
#
#
# Price increase from previously bought: -68.56339932009993%
# Share price: $0.02495330159826014
# Shares owned at the moment: 0
# Cash capital at the moment: $2.3501262971855845
#
#
# Share price: $0.05112150140782833
# Shares owned at the moment: 45
# Cash capital at the moment: $0.04333244803409064
#
#
# Price increase from previously bought: 17.957134246542772%
# Share price: $0.06046728705410264
# Shares owned at the moment: 0
# Cash capital at the moment: $2.7568775386957642
#
#
# Share price: $0.02495330159826014
# Shares owned at the moment: 110
# Cash capital at the moment: $0.004465989153675132
#
#
# Price increase from previously bought: 29.60606538924837%
# Share price: $0.0324299301152795
# Shares owned at the moment: 0
# Cash capital at the moment: $3.5619482479745477
#
#
# Share price: $0.21000003565137693
# Shares owned at the moment: 16
# Cash capital at the moment: $0.19270767598385596
#
#
# Price increase from previously bought: -0.27424582398405395%
# Share price: $0.21000003565137693
# Shares owned at the moment: 0
# Cash capital at the moment: $3.543468244837226
#
#
# Share price: $0.2137383499098866
# Shares owned at the moment: 16
# Cash capital at the moment: $0.11425015888300516
#
#
#
#
# Capital at the end of test period: $3.6141313724416144
# profit gained: -96.38586862755838%
#
#
# Capital at the end of test period if Buy and Hold: $21.761644528562254
# profit gained: -78.23835547143774%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.106977      6.034483       6.896552      83.333333
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0          41.73913           50.574713          83.333333     -96.385869
#
#    buy_n_hold profit
# 0         -78.238355
#
#
# O39.SI
#
#
# Non-Recession Test
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2005 - accuracy: 0.0780 - mse: 1.0057 - weighted_accuracy: 0.0780 - weighted_mse: 1.0057
# Test loss: 0.2005096822977066
# Test accuracy: 0.07798165082931519
#
#
# number of predictions: 218
# actual predicted buys: 7
# actual buys but predicted sell: 0
# actual buys but predicted hold: 1
# actual sells but predicted buy: 2
# actual predicted sells: 7
# actual sells but predicted hold: 0
# actual holds but predicted buy: 103
# actual holds but predicted sell: 95
# actual predicted holds: 3
# Percentage buys correct: 6.25%
# Percentage sells correct: 6.862745098039215%
# Percentage holds correct: 75.0%
# actual buys: 8
# actual sells: 9
# actual holds: 201
#
#
# Percentage low buys correct: 50.0%
# Percentage high sells correct: 49.504950495049506%
# Percentage mid holds correct: 75.0%
#
#
# Capital: 100
# Share price: $0.6357665229914489
# Shares owned at the moment: 156
# Cash capital at the moment: $0.5476785749706323
#
#
# Price increase from previously bought: 11.273650346935483%
# Share price: $0.709386079515369
# Shares owned at the moment: 0
# Cash capital at the moment: $110.9075803512561
#
#
# Share price: $0.513067262118245
# Shares owned at the moment: 215
# Cash capital at the moment: $0.2947679771060052
#
#
# Price increase from previously bought: -14.583803923911931%
# Share price: $0.4394477055943231
# Shares owned at the moment: 0
# Cash capital at the moment: $94.51620122395283
#
#
# Share price: $0.3290180782703287
# Shares owned at the moment: 286
# Cash capital at the moment: $0.15825812007921058
#
#
# Price increase from previously bought: 59.23038861423%
# Share price: $0.5253374807436784
# Shares owned at the moment: 0
# Cash capital at the moment: $149.99159968416632
#
#
# Share price: $0.7216562981408023
# Shares owned at the moment: 207
# Cash capital at the moment: $0.19794312130355252
#
#
# Price increase from previously bought: 1.4212960320358015%
# Share price: $0.73392593169001
# Shares owned at the moment: 0
# Cash capital at the moment: $151.7028236445211
#
#
# Share price: $0.752331259628159
# Shares owned at the moment: 201
# Cash capital at the moment: $0.06838935550163683
#
#
# Price increase from previously bought: 3.7918934324906006%
# Share price: $0.7830062211155175
# Shares owned at the moment: 0
# Cash capital at the moment: $157.01983311099906
#
#
# Share price: $0.8075460732901576
# Shares owned at the moment: 193
# Cash capital at the moment: $0.7348358875998713
#
#
# Price increase from previously bought: 21.69677954335214%
# Share price: $0.9854601478253582
# Shares owned at the moment: 0
# Cash capital at the moment: $190.40561144443566
#
#
# Share price: $0.6603063751660889
# Shares owned at the moment: 287
# Cash capital at the moment: $0.37653496516830387
#
#
# Price increase from previously bought: -78.10541761814493%
# Share price: $0.14496889442240968
# Shares owned at the moment: 0
# Cash capital at the moment: $41.86819096447699
#
#
# Share price: $0.611226670816807
# Shares owned at the moment: 68
# Cash capital at the moment: $0.19047796149136786
#
#
# Price increase from previously bought: 2.7287075763249957%
# Share price: $0.629631998754957
# Shares owned at the moment: 0
# Cash capital at the moment: $42.88771269306127
#
#
# Share price: $0.7277914074535181
# Shares owned at the moment: 58
# Cash capital at the moment: $0.5597283312683814
#
#
# Price increase from previously bought: 4.769580864608103%
# Share price: $0.7646008931773667
# Shares owned at the moment: 0
# Cash capital at the moment: $44.78462629309386
#
#
# Share price: $0.6419016323041646
# Shares owned at the moment: 69
# Cash capital at the moment: $0.37161282937677953
#
#
# Price increase from previously bought: -84.14951810605163%
# Share price: $0.10202429938584533
# Shares owned at the moment: 0
# Cash capital at the moment: $7.391930376191643
#
#
# Share price: $0.05294459503656523
# Shares owned at the moment: 139
# Cash capital at the moment: $0.012393594656348483
#
#
# Price increase from previously bought: 57.50471473911387%
# Share price: $0.08361955652392193
# Shares owned at the moment: 0
# Cash capital at the moment: $11.603548376000228
#
#
# Share price: $0.2799383739210459
# Shares owned at the moment: 41
# Cash capital at the moment: $0.09451199357774698
#
#
# Price increase from previously bought: -52.72697457008003%
# Share price: $0.13269926087320294
# Shares owned at the moment: 0
# Cash capital at the moment: $5.520219847715613
#
#
# Share price: $0.07748444721120527
# Shares owned at the moment: 71
# Cash capital at the moment: $0.003695257402050345
#
#
# Price increase from previously bought: 126.06105647549914%
# Share price: $0.17564385590976817
# Shares owned at the moment: 0
# Cash capital at the moment: $12.440114564129207
#
#
# Share price: $0.09588919007312867
# Shares owned at the moment: 129
# Cash capital at the moment: $0.03639235451716516
#
#
# Price increase from previously bought: 159.23653932710607%
# Share price: $0.2492634124336892
# Shares owned at the moment: 0
# Cash capital at the moment: $32.10294636290223
#
#
# Share price: $0.40263763479424886
# Shares owned at the moment: 79
# Cash capital at the moment: $0.2071001879975185
#
#
# Price increase from previously bought: -4.832753781788024%
# Share price: $0.38423289193232546
# Shares owned at the moment: 0
# Cash capital at the moment: $30.478024054878933
#
#
# Share price: $0.38423289193232546
# Shares owned at the moment: 79
# Cash capital at the moment: $0.04015099645292253
#
#
# Price increase from previously bought: -24.158699371468085%
# Share price: $0.29220859254647835
# Shares owned at the moment: 0
# Cash capital at the moment: $23.061147490893987
#
#
#
#
# Capital at the end of test period: $23.061147490893987
# profit gained: -76.93885250910601%
#
#
# Capital at the end of test period if Buy and Hold: $44.097971344241664
# profit gained: -55.90202865575834%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.082569       7.54717       5.555556          100.0
# 1       0.077982       6.25000       6.862745           75.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         50.943396           42.990654               75.0     164.483711
# 1         50.000000           49.504950               75.0     -76.938853
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# Recession Test
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1996 - accuracy: 0.0977 - mse: 0.9961 - weighted_accuracy: 0.0977 - weighted_mse: 0.9961
# Test loss: 0.19959796965122223
# Test accuracy: 0.0976744219660759
#
#
# number of predictions: 215
# actual predicted buys: 10
# actual buys but predicted sell: 2
# actual buys but predicted hold: 0
# actual sells but predicted buy: 3
# actual predicted sells: 7
# actual sells but predicted hold: 0
# actual holds but predicted buy: 108
# actual holds but predicted sell: 81
# actual predicted holds: 4
# Percentage buys correct: 8.264462809917354%
# Percentage sells correct: 7.777777777777778%
# Percentage holds correct: 100.0%
# actual buys: 12
# actual sells: 10
# actual holds: 193
#
#
# Percentage low buys correct: 50.413223140495866%
# Percentage high sells correct: 51.68539325842696%
# Percentage mid holds correct: 100.0%
#
#
# Capital: 100
# Share price: $0.9886586309918834
# Shares owned at the moment: 100
# Cash capital at the moment: $0.8622557772888797
#
#
# Price increase from previously bought: -0.5817825848549063%
# Share price: $0.9856097809180537
# Shares owned at the moment: 0
# Cash capital at the moment: $99.15219117934178
#
#
# Share price: $0.9581707117622773
# Shares owned at the moment: 103
# Cash capital at the moment: $0.18920601372055046
#
#
# Price increase from previously bought: -69.13159749526733%
# Share price: $0.2965853649672121
# Shares owned at the moment: 0
# Cash capital at the moment: $30.653490800716433
#
#
# Share price: $0.30878047450818547
# Shares owned at the moment: 99
# Cash capital at the moment: $0.00015834022121907765
#
#
# Price increase from previously bought: 7.602978266494587%
# Share price: $0.3331706935901313
# Shares owned at the moment: 0
# Cash capital at the moment: $32.893351284314306
#
#
# Share price: $0.29048766481955224
# Shares owned at the moment: 112
# Cash capital at the moment: $0.26926262376002796
#
#
# Price increase from previously bought: 16.472403241645004%
# Share price: $0.3392683937377907
# Shares owned at the moment: 0
# Cash capital at the moment: $38.16282805712135
#
#
# Share price: $0.2539023361966335
# Shares owned at the moment: 149
# Cash capital at the moment: $0.22734348156638617
#
#
# Price increase from previously bought: 82.35165127838442%
# Share price: $0.4642683392213509
# Shares owned at the moment: 0
# Cash capital at the moment: $69.21309207355173
#
#
# Share price: $0.3545120625982474
# Shares owned at the moment: 194
# Cash capital at the moment: $0.24861974409557774
#
#
# Price increase from previously bought: 20.309053710626657%
# Share price: $0.4276830105984313
# Shares owned at the moment: 0
# Cash capital at the moment: $82.99095491403698
#
#
# Share price: $0.4551220797542077
# Shares owned at the moment: 181
# Cash capital at the moment: $0.3873214633277229
#
#
# Price increase from previously bought: -12.967131669024202%
# Share price: $0.3971950913688269
# Shares owned at the moment: 0
# Cash capital at the moment: $72.08192914435656
#
#
# Share price: $0.36670717213922077
# Shares owned at the moment: 196
# Cash capital at the moment: $0.009668239286241942
#
#
# Price increase from previously bought: -18.514688715818217%
# Share price: $0.2996342150410418
# Shares owned at the moment: 0
# Cash capital at the moment: $58.57647154542332
#
#
# Share price: $0.2539023361966335
# Shares owned at the moment: 230
# Cash capital at the moment: $0.01834099255324162
#
#
# Price increase from previously bought: -23.026236588288107%
# Share price: $0.1959756385655982
# Shares owned at the moment: 0
# Cash capital at the moment: $44.968783271248085
#
#
# Share price: $0.2935365148933824
# Shares owned at the moment: 152
# Cash capital at the moment: $0.2285347442285257
#
#
# Price increase from previously bought: 0.7615669541730652%
# Share price: $0.2965853649672121
# Shares owned at the moment: 0
# Cash capital at the moment: $45.18553753668847
#
#
# Share price: $0.2843902554262392
# Shares owned at the moment: 158
# Cash capital at the moment: $0.12830961335997415
#
#
# Price increase from previously bought: 4.002154203892716%
# Share price: $0.2965853649672121
# Shares owned at the moment: 0
# Cash capital at the moment: $46.85993093710123
#
#
# Share price: $0.1959756385655982
# Shares owned at the moment: 238
# Cash capital at the moment: $0.08946290304767501
#
#
# Price increase from previously bought: 78.848571109961%
# Share price: $0.3514635032787641
# Shares owned at the moment: 0
# Cash capital at the moment: $83.50774382049757
#
#
# Share price: $0.7112193801146416
# Shares owned at the moment: 117
# Cash capital at the moment: $0.06624151153260982
#
#
# Price increase from previously bought: 6.993152959609028%
# Share price: $0.7630486683523638
# Shares owned at the moment: 0
# Cash capital at the moment: $89.0974247997168
#
#
# Share price: $0.717317080262301
# Shares owned at the moment: 123
# Cash capital at the moment: $0.624791425055065
#
#
#
#
# Capital at the end of test period: $92.3518256570445
# profit gained: -7.6481743429555%
#
#
# Capital at the end of test period if Buy and Hold: $75.43708035614208
# profit gained: -24.562919643857924%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.106977      6.034483       6.896552      83.333333
# 1       0.097674      8.264463       7.777778     100.000000
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         41.739130           50.574713          83.333333     -96.385869
# 1         50.413223           51.685393         100.000000      -7.648174
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
#
#
# 0883.HK
#
#
# Non-Recession Test
#
#
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2027 - accuracy: 0.0625 - mse: 0.9879 - weighted_accuracy: 0.0625 - weighted_mse: 0.9879WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0040s vs `on_test_batch_end` time: 0.0079s). Check your callbacks.
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2008 - accuracy: 0.0569 - mse: 1.0030 - weighted_accuracy: 0.0569 - weighted_mse: 1.0030
# Test loss: 0.20075275003910065
# Test accuracy: 0.056872036308050156
#
#
# number of predictions: 211
# actual predicted buys: 3
# actual buys but predicted sell: 5
# actual buys but predicted hold: 0
# actual sells but predicted buy: 5
# actual predicted sells: 4
# actual sells but predicted hold: 0
# actual holds but predicted buy: 108
# actual holds but predicted sell: 81
# actual predicted holds: 5
# Percentage buys correct: 2.586206896551724%
# Percentage sells correct: 4.444444444444445%
# Percentage holds correct: 100.0%
# actual buys: 8
# actual sells: 9
# actual holds: 194
#
#
# Percentage low buys correct: 46.55172413793103%
# Percentage high sells correct: 48.31460674157304%
# Percentage mid holds correct: 80.0%
#
#
# Capital: 100
# Share price: $0.6782927975265876
# Shares owned at the moment: 147
# Cash capital at the moment: $0.016758900191504722
#
#
# Price increase from previously bought: 11.918045709060543%
# Share price: $0.7612196562958087
# Shares owned at the moment: 0
# Cash capital at the moment: $111.60832532961778
#
#
# Share price: $0.9758535779763593
# Shares owned at the moment: 114
# Cash capital at the moment: $0.055087343617231
#
#
# Price increase from previously bought: -8.250304451265066%
# Share price: $0.8978048791834319
# Shares owned at the moment: 0
# Cash capital at the moment: $102.12338174090446
#
#
# Share price: $0.9368292285798956
# Shares owned at the moment: 108
# Cash capital at the moment: $0.6675867733875123
#
#
# Price increase from previously bought: 2.3221126646484347%
# Share price: $0.9612195632544205
# Shares owned at the moment: 0
# Cash capital at the moment: $104.19381739457836
#
#
# Share price: $0.9368292285798956
# Shares owned at the moment: 110
# Cash capital at the moment: $0.8592114091444216
#
#
# Price increase from previously bought: -35.584577657270074%
# Share price: $0.6051220261064831
# Shares owned at the moment: 0
# Cash capital at the moment: $67.23958486796035
#
#
# Share price: $0.5417073420354945
# Shares owned at the moment: 123
# Cash capital at the moment: $0.42634928915100545
#
#
# Price increase from previously bought: -43.37947522250071%
# Share price: $0.30756101305324157
# Shares owned at the moment: 0
# Cash capital at the moment: $38.15232138203446
#
#
# Share price: $0.45390255589345085
# Shares owned at the moment: 83
# Cash capital at the moment: $0.3748059844953531
#
#
# Price increase from previously bought: -17.422174261657318%
# Share price: $0.3758536244970532
# Shares owned at the moment: 0
# Cash capital at the moment: $31.484868227959314
#
#
# Share price: $0.3953660317987555
# Shares owned at the moment: 79
# Cash capital at the moment: $0.1650584454493469
#
#
# Price increase from previously bought: 37.86882793600024%
# Share price: $0.5465855020117878
# Shares owned at the moment: 0
# Cash capital at the moment: $43.22656740406852
#
#
# Share price: $0.5953659387573673
# Shares owned at the moment: 72
# Cash capital at the moment: $0.24233735766411257
#
#
# Price increase from previously bought: 2.9941076553176016%
# Share price: $0.614878113455599
# Shares owned at the moment: 0
# Cash capital at the moment: $44.391815660003026
#
#
# Share price: $0.5417073420354945
# Shares owned at the moment: 81
# Cash capital at the moment: $0.39285564468956125
# Price increase from previously bought: -3.866344705427427%
# Share price: $0.5221951673372625
# Shares owned at the moment: 0
# Cash capital at the moment: $42.57434522548344
#
#
# Share price: $0.4685365706153901
# Shares owned at the moment: 90
# Cash capital at the moment: $0.2900910688710212
#
#
# Price increase from previously bought: -63.60862590147093%
# Share price: $0.17097579016561837
# Shares owned at the moment: 0
# Cash capital at the moment: $15.635595675710684
#
#
# Share price: $0.01
# Shares owned at the moment: 1559
# Cash capital at the moment: $0.0027231757106847
#
#
# Price increase from previously bought: 1507.7756451408882%
# Share price: $0.16121970281650255
# Shares owned at the moment: 0
# Cash capital at the moment: $250.6530506957381
#
#
# Share price: $0.39048787182246225
# Shares owned at the moment: 640
# Cash capital at the moment: $0.05355407495471809
#
#
# Price increase from previously bought: -40.13964247014913%
# Share price: $0.2343902416331367
# Shares owned at the moment: 0
# Cash capital at the moment: $149.6507818948879
#
#
# Share price: $0.28804883835500994
# Shares owned at the moment: 518
# Cash capital at the moment: $0.03115805675602701
#
#
# Price increase from previously bought: -0.27424582398405395%
# Share price: $0.28804883835500994
# Shares owned at the moment: 0
# Cash capital at the moment: $148.83013075441445
#
#
# Share price: $0.25878057630766205
# Shares owned at the moment: 573
# Cash capital at the moment: $0.14108703700730985
#
#
# Price increase from previously bought: 48.601644992614546%
# Share price: $0.385609711846169
# Shares owned at the moment: 0
# Cash capital at the moment: $220.48782742142055
#
#
# Share price: $0.2539024163313688
# Shares owned at the moment: 866
# Cash capital at the moment: $0.003666273962011246
#
#
# Price increase from previously bought: -55.837098467271886%
# Share price: $0.1124390334674523
# Shares owned at the moment: 0
# Cash capital at the moment: $97.10809569857298
#
#
#
#
# Capital at the end of test period: $97.10809569857298
# profit gained: -2.8919043014270187%
#
#
# Capital at the end of test period if Buy and Hold: $45.31039913308918
# profit gained: -54.68960086691082%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.082569      7.547170       5.555556          100.0
# 1       0.077982      6.250000       6.862745           75.0
# 2       0.056872      2.586207       4.444444          100.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         50.943396           42.990654               75.0     164.483711
# 1         50.000000           49.504950               75.0     -76.938853
# 2         46.551724           48.314607               80.0      -2.891904
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# 2         -54.689601
# Recession Test
#
#
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2000 - accuracy: 0.1033 - mse: 0.9916 - weighted_accuracy: 0.1033 - weighted_mse: 0.9916
# Test loss: 0.19996902346611023
# Test accuracy: 0.10328638553619385
#
#
# number of predictions: 213
# actual predicted buys: 6
# actual buys but predicted sell: 3
# actual buys but predicted hold: 1
# actual sells but predicted buy: 3
# actual predicted sells: 7
# actual sells but predicted hold: 0
# actual holds but predicted buy: 108
# actual holds but predicted sell: 76
# actual predicted holds: 9
# Percentage buys correct: 5.128205128205129%
# Percentage sells correct: 8.13953488372093%
# Percentage holds correct: 90.0%
# actual buys: 10
# actual sells: 10
# actual holds: 193
#
#
# Percentage low buys correct: 41.02564102564103%
# Percentage high sells correct: 48.23529411764706%
# Percentage mid holds correct: 90.0%
#
#
# Capital: 100
# Share price: $0.9662289181183106
# Shares owned at the moment: 103
# Cash capital at the moment: $0.20473709275698582
#
#
# Price increase from previously bought: -78.46463282778242%
# Share price: $0.20865316784033627
# Shares owned at the moment: 0
# Cash capital at the moment: $21.636912370520847
#
#
# Share price: $0.3450168735329129
# Shares owned at the moment: 62
# Cash capital at the moment: $0.18704083454288423
#
#
# Price increase from previously bought: 19.190113886478066%
# Share price: $0.41235687600379634
# Shares owned at the moment: 0
# Cash capital at the moment: $25.68286029941961
#
#
# Share price: $0.35006733358042164
# Shares owned at the moment: 73
# Cash capital at the moment: $0.057668930832559084
#
#
# Price increase from previously bought: 35.69493581374212%
# Share price: $0.4763299586267504
# Shares owned at the moment: 0
# Cash capital at the moment: $34.73413267139101
#
#
# Share price: $0.4207744164504643
# Shares owned at the moment: 82
# Cash capital at the moment: $0.13574589154335115
#
#
# Price increase from previously bought: 11.296716902307203%
# Share price: $0.4695959583796625
# Shares owned at the moment: 0
# Cash capital at the moment: $38.53672059006106
#
#
# Share price: $0.38205379461628364
# Shares owned at the moment: 100
# Cash capital at the moment: $0.22627633491321575
#
#
# Price increase from previously bought: 25.213081654677527%
# Share price: $0.4796968784746798
# Shares owned at the moment: 0
# Cash capital at the moment: $48.06404754080066
#
#
# Share price: $0.4275084166975527
# Shares owned at the moment: 112
# Cash capital at the moment: $0.051432278331908776
#
#
# Price increase from previously bought: -14.411930705255404%
# Share price: $0.3669024144737578
# Shares owned at the moment: 0
# Cash capital at the moment: $41.031496755734864
#
#
# Share price: $0.3786868747683543
# Shares owned at the moment: 108
# Cash capital at the moment: $0.02084427894639873
#
#
# Price increase from previously bought: 1.9424815708183774%
# Share price: $0.3871044152150227
# Shares owned at the moment: 0
# Cash capital at the moment: $41.71315111084999
#
#
# Share price: $0.4695959583796625
# Shares owned at the moment: 88
# Cash capital at the moment: $0.27506455151181086
#
#
# Price increase from previously bought: 0.4407701702836109%
# Share price: $0.4729628782275914
# Shares owned at the moment: 0
# Cash capital at the moment: $41.78134081900878
#
#
# Share price: $0.40562287575670797
# Shares owned at the moment: 102
# Cash capital at the moment: $0.29403027517481206
#
#
# Price increase from previously bought: -16.416472061625274%
# Share price: $0.33996625293417404
# Shares owned at the moment: 0
# Cash capital at the moment: $34.875227540512526
#
#
# Share price: $0.2440067092753575
# Shares owned at the moment: 142
# Cash capital at the moment: $0.13099020343973677
#
#
# Price increase from previously bought: -9.90691696404613%
# Share price: $0.22043770841054844
# Shares owned at the moment: 0
# Cash capital at the moment: $31.347063872603297
#
#
# Share price: $0.1598316259111383
# Shares owned at the moment: 195
# Cash capital at the moment: $0.09418711053647755
#
#
# Price increase from previously bought: 7.07863061259546%
# Share price: $0.1716161664813498
# Shares owned at the moment: 0
# Cash capital at the moment: $33.46731040512407
#
#
# Share price: $0.11774408422902848
# Shares owned at the moment: 283
# Cash capital at the moment: $0.05410023475776882
#
#
# Price increase from previously bought: 195.07076100762907%
# Share price: $0.34838379338084224
# Shares owned at the moment: 0
# Cash capital at the moment: $98.37558407433748
#
#
# Share price: $0.5352525812021964
# Shares owned at the moment: 183
# Cash capital at the moment: $0.15499585284553064
#
#
# Price increase from previously bought: 2.2350489532743323%
# Share price: $0.5487205816963732
# Shares owned at the moment: 0
# Cash capital at the moment: $100.2947186705431
#
#
# Share price: $0.5234679603563692
# Shares owned at the moment: 191
# Cash capital at the moment: $0.03738669629939295
#
#
# Price increase from previously bought: -70.83340846398569%
# Share price: $0.15309762566404994
# Shares owned at the moment: 0
# Cash capital at the moment: $29.198618670252888
#
#
#
#
# Capital at the end of test period: $29.198618670252888
# profit gained: -70.80138132974712%
#
#
# Capital at the end of test period if Buy and Hold: $15.710112504960433
# profit gained: -84.28988749503957%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.106977      6.034483       6.896552      83.333333
# 1       0.097674      8.264463       7.777778     100.000000
# 2       0.103286      5.128205       8.139535      90.000000
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         41.739130           50.574713          83.333333     -96.385869
# 1         50.413223           51.685393         100.000000      -7.648174
# 2         41.025641           48.235294          90.000000     -70.801381
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
# 2         -84.289887
#
#
# JPM
#
#
# Non-Recession Test
#
#
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2018 - accuracy: 0.0780 - mse: 1.0094 - weighted_accuracy: 0.0780 - weighted_mse: 1.0094
# Test loss: 0.2017747163772583
# Test accuracy: 0.07798165082931519
#
#
# number of predictions: 218
# actual predicted buys: 9
# actual buys but predicted sell: 2
# actual buys but predicted hold: 0
# actual sells but predicted buy: 2
# actual predicted sells: 4
# actual sells but predicted hold: 0
# actual holds but predicted buy: 90
# actual holds but predicted sell: 107
# actual predicted holds: 4
# Percentage buys correct: 8.910891089108912%
# Percentage sells correct: 3.5398230088495577%
# Percentage holds correct: 100.0%
# actual buys: 11
# actual sells: 6
# actual holds: 201
#
#
# Percentage low buys correct: 44.0%
# Percentage high sells correct: 44.24778761061947%
# Percentage mid holds correct: 100.0%
#
#
# Capital: 100
# Share price: $0.05968146056768497
# Shares owned at the moment: 1670
# Cash capital at the moment: $0.05787374430900627
#
#
# Price increase from previously bought: 204.49930188356814%
# Share price: $0.18222938726716964
# Shares owned at the moment: 0
# Cash capital at the moment: $303.5440620194578
#
#
# Share price: $0.148343983710997
# Shares owned at the moment: 2040
# Cash capital at the moment: $0.09012550040517908
#
#
# Price increase from previously bought: 37.235352549787734%
# Share price: $0.20414023510202495
# Shares owned at the moment: 0
# Cash capital at the moment: $415.39097838961374
#
#
# Share price: $0.01
# Shares owned at the moment: 41425
# Cash capital at the moment: $0.0017908896137441843
#
#
# Price increase from previously bought: 1450.5132082644113%
# Share price: $0.15547771195871385
# Shares owned at the moment: 0
# Cash capital at the moment: $6422.954182180138
#
#
# Share price: $0.4479619307717362
# Shares owned at the moment: 14298
# Cash capital at the moment: $0.38085686887461634
#
#
# Price increase from previously bought: -0.6712753373877667%
# Share price: $0.44617849870980586
# Shares owned at the moment: 0
# Cash capital at the moment: $6362.297515941658
#
#
# Share price: $0.429872778606591
# Shares owned at the moment: 14759
# Cash capital at the moment: $0.3578225534811281
#
#
# Price increase from previously bought: -27.40368830769977%
# Share price: $0.3129299796387459
# Shares owned at the moment: 0
# Cash capital at the moment: $4606.190424725639
#
#
# Share price: $0.2573885597935692
# Shares owned at the moment: 17846
# Cash capital at the moment: $0.20245699489260005
#
#
# Price increase from previously bought: 14.434111045417609%
# Share price: $0.2953502961857881
# Shares owned at the moment: 0
# Cash capital at the moment: $5256.529083915706
#
#
# Share price: $0.2968790910813819
# Shares owned at the moment: 17657
# Cash capital at the moment: $0.11948888587994588
#
#
# Price increase from previously bought: 30.621267568025566%
# Share price: $0.3888536468027002
# Shares owned at the moment: 0
# Cash capital at the moment: $6847.2268611667705
#
#
# Share price: $0.42248421881302245
# Shares owned at the moment: 16162
# Cash capital at the moment: $0.25939436344742717
#
#
# Price increase from previously bought: -2.980534953295355%
# Share price: $0.41101913180389116
# Shares owned at the moment: 0
# Cash capital at the moment: $6624.882651755346
#
#
# Share price: $0.38222938726717026
# Shares owned at the moment: 17284
# Cash capital at the moment: $0.26217722337878513
#
#
# Price increase from previously bought: 14.15032983041289%
# Share price: $0.43751597556649524
# Shares owned at the moment: 0
# Cash capital at the moment: $7541.492727080032
#
#
# Share price: $0.3669427989678449
# Shares owned at the moment: 20495
# Cash capital at the moment: $0.31870740572503564
#
#
# Price increase from previously bought: -39.25750585870611%
# Share price: $0.22350315623739658
# Shares owned at the moment: 0
# Cash capital at the moment: $4568.418977226683
#
#
# Share price: $0.21050966309170316
# Shares owned at the moment: 21642
# Cash capital at the moment: $0.04026074230841914
#
#
# Price increase from previously bought: 20.968322746797785%
# Share price: $0.25535029618578853
# Shares owned at the moment: 0
# Cash capital at the moment: $5511.134070242499
#
#
# Share price: $0.518280275824534
# Shares owned at the moment: 10604
# Cash capital at the moment: $0.17645427582101547
#
#
# Price increase from previously bought: -12.186923732061905%
# Share price: $0.4563694279896795
# Shares owned at the moment: 0
# Cash capital at the moment: $4826.209679788775
#
#
# Share price: $0.7106370788646299
# Shares owned at the moment: 6772
# Cash capital at the moment: $0.5411873978055155
#
#
# Price increase from previously bought: -2.7769875565395785%
# Share price: $0.6928027582453369
# Shares owned at the moment: 0
# Cash capital at the moment: $4679.299400468423
#
#
# Share price: $0.7715289892751118
# Shares owned at the moment: 6048
# Cash capital at the moment: $0.2600031829233558
#
#
# Price increase from previously bought: 1.3064666322399%
# Share price: $0.7837581821627635
# Shares owned at the moment: 0
# Cash capital at the moment: $4727.394022817586
#
#
# Share price: $0.7628662717522834
# Shares owned at the moment: 6179
# ...
# Shares owned at the moment: 0
# Cash capital at the moment: $173.18721131351188
#
#
# Share price: $0.7093385960672332
# Shares owned at the moment: 243
# Cash capital at the moment: $0.3439169523522878
#
#
# Price increase from previously bought: -3.1113002642354948%
# Share price: $0.689158932045216
# Shares owned at the moment: 0
# Cash capital at the moment: $167.34900698300055
#
#
#
#
# Capital at the end of test period: $167.34900698300055
# profit gained: 67.34900698300055%
#
#
# Capital at the end of test period if Buy and Hold: $68.09965200824497
# profit gained: -31.90034799175503%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.260465      4.950495       7.936508      90.196078
# 1       0.302326      6.896552       6.250000      85.937500
# 2       0.267606      8.602151       5.633803      91.836735
# 3       0.337900      7.777778      13.432836      93.548387
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         45.544554           62.903226          80.392157     -86.644623
# 1         51.724138           56.250000          85.714286     -35.195400
# 2         46.236559           51.428571          81.632653     -82.584469
# 3         46.666667           56.060606          80.645161      67.349007
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
# 2         -84.289887
# 3         -31.900348
#
#
# AXL
#
#
# Non-Recession Test
#
#
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3328 - accuracy: 0.2110 - mse: 2.6136 - weighted_accuracy: 0.2110 - weighted_mse: 2.6136
# Test loss: 0.3327602744102478
# Test accuracy: 0.2110091745853424
#
#
# number of predictions: 218
# actual predicted buys: 3
# actual buys but predicted sell: 2
# actual buys but predicted hold: 3
# actual sells but predicted buy: 0
# actual predicted sells: 6
# actual sells but predicted hold: 2
# actual holds but predicted buy: 95
# actual holds but predicted sell: 70
# actual predicted holds: 37
# Percentage buys correct: 3.061224489795918%
# Percentage sells correct: 7.6923076923076925%
# Percentage holds correct: 88.0952380952381%
# actual buys: 8
# actual sells: 8
# actual holds: 202
#
#
# Percentage low buys correct: 44.89795918367347%
# Percentage high sells correct: 53.84615384615385%
# Percentage mid holds correct: 78.04878048780488%
#
#
# Capital: 100
# Share price: $0.7426007274823263
# Shares owned at the moment: 134
# Cash capital at the moment: $0.21785414929102842
#
#
# Price increase from previously bought: 8.211267978658032%
# Share price: $0.8057875018012395
# Shares owned at the moment: 0
# Cash capital at the moment: $107.89644669624336
#
#
# Share price: $0.9339926815103341
# Shares owned at the moment: 115
# Cash capital at the moment: $0.19191313702728507
#
#
# Price increase from previously bought: -25.989864789404614%
# Share price: $0.6931501818705816
# Shares owned at the moment: 0
# Cash capital at the moment: $79.6849753071276
#
#
# Share price: $0.6986446384203246
# Shares owned at the moment: 113
# Cash capital at the moment: $0.5210273442418014
#
#
# Price increase from previously bought: 8.35300038937894%
# Share price: $0.7590841844643663
# Shares owned at the moment: 0
# Cash capital at the moment: $86.06165477839288
#
#
# Share price: $0.8927838207232035
# Shares owned at the moment: 96
# Cash capital at the moment: $0.11871306029442508
#
#
# Price increase from previously bought: -1.706316721067569%
# Share price: $0.8799633638852624
# Shares owned at the moment: 0
# Cash capital at the moment: $84.36288566521391
#
#
# Share price: $0.9175091371954818
# Shares owned at the moment: 91
# Cash capital at the moment: $0.6399475188418933
#
#
# Price increase from previously bought: -51.53458634485645%
# Share price: $0.4458974538118591
# Shares owned at the moment: 0
# Cash capital at the moment: $41.10502997790465
#
#
# Share price: $0.38545782043500487
# Shares owned at the moment: 106
# Cash capital at the moment: $0.1341400571373228
#
#
# Price increase from previously bought: 24.60270825796085%
# Share price: $0.4816116833836226
# Shares owned at the moment: 0
# Cash capital at the moment: $51.04458869009499
#
#
# Share price: $0.5017582278425741
# Shares owned at the moment: 101
# Cash capital at the moment: $0.22764433021173858
#
#
# Price increase from previously bought: 9.918185596282658%
# Share price: $0.5530402298599622
# Shares owned at the moment: 0
# Cash capital at the moment: $55.931100622224314
#
#
# Share price: $0.5502930015850909
# Shares owned at the moment: 101
# Cash capital at the moment: $0.19866358093987913
#
#
# Price increase from previously bought: -17.5335793641502%
# Share price: $0.4550549105057009
# Shares owned at the moment: 0
# Cash capital at the moment: $46.032818040622715
#
#
# Share price: $0.5045054561174454
# Shares owned at the moment: 90
# Cash capital at the moment: $0.5024618896635644
#
#
# Price increase from previously bought: 5.1562608451174%
# Share price: $0.5319780008645951
# Shares owned at the moment: 0
# Cash capital at the moment: $48.248817412263136
#
#
# Share price: $0.4687912265456817
# Shares owned at the moment: 102
# Cash capital at the moment: $0.3006163655575307
#
#
# Price increase from previously bought: -74.49583283223002%
# Share price: $0.11989009165578655
# Shares owned at the moment: 0
# Cash capital at the moment: $12.49577654373831
#
#
# Share price: $0.16293036518215442
# Shares owned at the moment: 76
# Cash capital at the moment: $0.07901634357150478
#
#
# Price increase from previously bought: 30.553737870632247%
# Share price: $0.21329663899672058
# Shares owned at the moment: 0
# Cash capital at the moment: $16.24498190977196
#
#
# Share price: $0.19681318201468057
# Shares owned at the moment: 82
# Cash capital at the moment: $0.06191961202383922
#
#
# Price increase from previously bought: -15.12268199115302%
# Share price: $0.16750913719548155
# Shares owned at the moment: 0
# Cash capital at the moment: $13.759895551615745
#
#
# Share price: $0.1189743197865588
# Shares owned at the moment: 115
# Cash capital at the moment: $0.040223147528983816
#
#
# Price increase from previously bought: 51.154544545123%
# Share price: $0.18032963769982846
# Shares owned at the moment: 0
# Cash capital at the moment: $20.721102235086686
#
#
# Share price: $0.2618315000720497
# Shares owned at the moment: 78
# Cash capital at the moment: $0.24208237270135768
#
#
# Price increase from previously bought: 9.491837182515761%
# Share price: $0.28747250108074374
# Shares owned at the moment: 0
# Cash capital at the moment: $22.603274605517548
#
#
# Share price: $0.225201411298246
# Shares owned at the moment: 100
# Cash capital at the moment: $0.021203087585927705
#
#
# Price increase from previously bought: 108.81098283924987%
# Share price: $0.47153845482055323
# Shares owned at the moment: 0
# Cash capital at the moment: $47.045375494565604
#
#
# Share price: $0.43490836604674943
# Shares owned at the moment: 107
# Cash capital at the moment: $0.38220854085415823
#
#
# Price increase from previously bought: 3.925457174417102%
# Share price: $0.4532234541000574
# Shares owned at the moment: 0
# Cash capital at the moment: $48.74375712819135
#
#
# Share price: $0.3918681361867874
# Shares owned at the moment: 124
# Cash capital at the moment: $0.0184812065900104
#
#
# Price increase from previously bought: -6.799596156453247%
# Share price: $0.3662270478452814
# Shares owned at the moment: 0
# Cash capital at the moment: $45.30575171608966
#
#
# Share price: $0.32868127453506213
# Shares owned at the moment: 137
# Cash capital at the moment: $0.1525864346050625
#
#
# Price increase from previously bought: 28.62210816701005%
# Share price: $0.4239193656144522
# Shares owned at the moment: 0
# Cash capital at the moment: $58.06982790278977
#
#
#
#
# Capital at the end of test period: $58.06982790278977
# profit gained: -41.93017209721023%
#
#
# Capital at the end of test period if Buy and Hold: $59.80379974835048
# profit gained: -40.19620025164952%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.325688      7.954545      11.267606      94.915254
# 1       0.197248      8.421053       5.617978      88.235294
# 2       0.260664      4.081633       6.666667      88.679245
# 3       0.220183     10.344828       4.255319      94.594595
# 4       0.211009      3.061224       7.692308      88.095238
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         52.272727           50.704225          81.034483     455.984361
# 1         55.789474           53.932584          78.787879     -54.864746
# 2         53.061224           49.152542          75.471698      66.476565
# 3         51.162791           46.808511          89.189189     730.572514
# 4         44.897959           53.846154          78.048780     -41.930172
#
#    buy_n_hold profit
# 0         -64.154600
# 1         -55.902029
# 2         -54.689601
# 3        1576.179166
# 4         -40.196200
# Recession Test
#
#
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3154 - accuracy: 0.2968 - mse: 2.5664 - weighted_accuracy: 0.2968 - weighted_mse: 2.5664
# Test loss: 0.31539785861968994
# Test accuracy: 0.29680365324020386
#
#
# number of predictions: 219
# actual predicted buys: 7
# actual buys but predicted sell: 2
# actual buys but predicted hold: 2
# actual sells but predicted buy: 0
# actual predicted sells: 6
# actual sells but predicted hold: 5
# actual holds but predicted buy: 75
# actual holds but predicted sell: 70
# actual predicted holds: 52
# Percentage buys correct: 8.536585365853659%
# Percentage sells correct: 7.6923076923076925%
# Percentage holds correct: 88.13559322033899%
# actual buys: 11
# actual sells: 11
# actual holds: 197
#
#
# Percentage low buys correct: 51.851851851851855%
# Percentage high sells correct: 52.56410256410256%
# Percentage mid holds correct: 83.05084745762711%
#
#
# Capital: 100
# Share price: $0.6915789433232307
# Shares owned at the moment: 144
# Cash capital at the moment: $0.13876689989878344
#
#
# Price increase from previously bought: -30.442427387855542%
# Share price: $0.48236840086795657
# Shares owned at the moment: 0
# Cash capital at the moment: $69.40879873814082
#
#
# Share price: $0.48894737320923726
# Shares owned at the moment: 141
# Cash capital at the moment: $0.27762977167647307
#
#
# Price increase from previously bought: -58.778596824134176%
# Share price: $0.20210523319046308
# Shares owned at the moment: 0
# Cash capital at the moment: $28.696101347362166
#
#
# Share price: $0.08499998980446886
# Shares owned at the moment: 336
# Cash capital at the moment: $0.05756478248129682
#
#
# Price increase from previously bought: 78.45661922545268%
# Share price: $0.15210525044443896
# Shares owned at the moment: 0
# Cash capital at the moment: $51.024383680402124
#
#
# Share price: $0.13631579211544126
# Shares owned at the moment: 373
# Cash capital at the moment: $0.03876729758011521
#
#
# Price increase from previously bought: 78.65925672710799%
# Share price: $0.2442105181428536
# Shares owned at the moment: 0
# Cash capital at the moment: $90.87879162587947
#
#
# Share price: $0.17052631653246791
# Shares owned at the moment: 531
# Cash capital at the moment: $0.08030649342246932
#
#
# Price increase from previously bought: 127.46088756952356%
# Share price: $0.38894734497545874
# Shares owned at the moment: 0
# Cash capital at the moment: $206.04338631489065
#
#
# Share price: $0.6415789292063412
# Shares owned at the moment: 320
# Cash capital at the moment: $0.17353951115990185
#
#
# Price increase from previously bought: 17.519313557360583%
# Share price: $0.7560525962041695
# Shares owned at the moment: 0
# Cash capital at the moment: $241.44504401183448
#
#
# Share price: $0.5863157623131194
# Shares owned at the moment: 410
# Cash capital at the moment: $0.3945104414474656
#
#
# Price increase from previously bought: 8.006391215330888%
# Share price: $0.6349999568650604
# Shares owned at the moment: 0
# Cash capital at the moment: $260.0285303047568
#
#
# Share price: $0.6113157693715641
# Shares owned at the moment: 424
# Cash capital at the moment: $0.11784990412644447
#
#
# Price increase from previously bought: -2.850026981255327%
# Share price: $0.5955263110425664
# Shares owned at the moment: 0
# Cash capital at the moment: $251.92662210749893
#
#
# Share price: $0.5850000054899009
# Shares owned at the moment: 429
# Cash capital at the moment: $0.27146599585469744
#
#
# Price increase from previously bought: 1.0715794966255965%
# Share price: $0.5928947346544002
# Shares owned at the moment: 0
# Cash capital at the moment: $253.92383959938385
#
#
# Share price: $0.5784210331486206
# Shares owned at the moment: 437
# Cash capital at the moment: $0.4587306368502766
#
#
# Price increase from previously bought: 20.823328253101757%
# Share price: $0.7007894293109473
# Shares owned at the moment: 0
# Cash capital at the moment: $305.8615375490598
#
#
# Share price: $0.6113157693715641
# Shares owned at the moment: 498
# Cash capital at the moment: $0.5890874558664905
#
#
# Price increase from previously bought: 13.677917464102073%
# Share price: $0.6968420960995632
# Shares owned at the moment: 0
# Cash capital at the moment: $346.66212606284057
#
#
# Share price: $0.7100000407821248
# Shares owned at the moment: 486
# Cash capital at the moment: $0.6531911882225927
#
#
# Price increase from previously bought: -56.08814506312265%
# Share price: $0.3126315669769067
# Shares owned at the moment: 0
# Cash capital at the moment: $152.17430064973462
#
#
# Share price: $0.5402631441493446
# Shares owned at the moment: 280
# Cash capital at the moment: $0.48461766692312835
#
#
# Price increase from previously bought: -2.94590835364833%
# Share price: $0.525789442643565
# Shares owned at the moment: 0
# Cash capital at the moment: $147.3008037362858
#
#
# Share price: $0.5271052622085133
# Shares owned at the moment: 278
# Cash capital at the moment: $0.3625688693606719
#
#
# Price increase from previously bought: 17.649498774432516%
# Share price: $0.6218420749242295
# Shares owned at the moment: 0
# Cash capital at the moment: $172.7592674320169
#
#
# Share price: $0.5955263110425664
# Shares owned at the moment: 289
# Cash capital at the moment: $0.1788690050141497
#
#
# Price increase from previously bought: -9.087836356048262%
# Share price: $0.542894720537511
# Shares owned at the moment: 0
# Cash capital at the moment: $156.64397766120763
#
#
# Share price: $0.716578887639945
# Shares owned at the moment: 218
# Cash capital at the moment: $0.00019111255946313577
#
#
# Price increase from previously bought: 1.3738139762289547%
# Share price: $0.7284210127575586
# Shares owned at the moment: 0
# Cash capital at the moment: $158.35928349655904
#
#
# Share price: $0.7389473183102233
# Shares owned at the moment: 213
# Cash capital at the moment: $0.5306663047812492
#
#
# Price increase from previously bought: -10.928705568719765%
# Share price: $0.659999963923505
# Shares owned at the moment: 0
# Cash capital at the moment: $140.7240636416196
#
#
# Share price: $0.6902631237582821
# Shares owned at the moment: 203
# Cash capital at the moment: $0.215310129850252
#
#
# Price increase from previously bought: 5.999008517931559%
# Share price: $0.7336841655338908
# Shares owned at the moment: 0
# Cash capital at the moment: $148.7436165478208
#
#
# Share price: $0.7073684016522281
# Shares owned at the moment: 209
# Cash capital at the moment: $0.49706061365549203
#
#
#
#
# Capital at the end of test period: $133.6698223616218
# profit gained: 33.66982236162181%
#
#
# Capital at the end of test period if Buy and Hold: $67.49022981476901
# profit gained: -32.50977018523099%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.260465      4.950495       7.936508      90.196078
# 1       0.302326      6.896552       6.250000      85.937500
# 2       0.267606      8.602151       5.633803      91.836735
# 3       0.337900      7.777778      13.432836      93.548387
# 4       0.296804      8.536585       7.692308      88.135593
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         45.544554           62.903226          80.392157     -86.644623
# 1         51.724138           56.250000          85.714286     -35.195400
# 2         46.236559           51.428571          81.632653     -82.584469
# 3         46.666667           56.060606          80.645161      67.349007
# 4         51.851852           52.564103          83.050847      33.669822
#
#    buy_n_hold profit
# 0         -78.238355
# 1         -24.562920
# 2         -84.289887
# 3         -31.900348
# 4         -32.509770

# %%
df = nr_log_hist['0_epochs_logs']
df['Profit gained']
# Out:
# 0     164.483711
# 1     -76.938853
# 2      -2.891904
# 3    5388.757245
# 4     -94.189352
# Name: Profit gained, dtype: float64

# %%
C6LSI_acc = []
O39SI_acc = []
CNOOC_acc = []
JPM_acc = []
AXL_acc = []

C6LSI_correct_buys = []
O39SI_correct_buys = []
CNOOC_correct_buys = []
JPM_correct_buys = []
AXL_correct_buys = []

C6LSI_correct_sells = []
O39SI_correct_sells = []
CNOOC_correct_sells = []
JPM_correct_sells = []
AXL_correct_sells = []

C6LSI_correct_holds = []
O39SI_correct_holds = []
CNOOC_correct_holds = []
JPM_correct_holds = []
AXL_correct_holds = []

C6LSI_correct_low_buys = []
O39SI_correct_low_buys = []
CNOOC_correct_low_buys = []
JPM_correct_low_buys = []
AXL_correct_low_buys = []

C6LSI_correct_high_sells = []
O39SI_correct_high_sells = []
CNOOC_correct_high_sells = []
JPM_correct_high_sells = []
AXL_correct_high_sells = []

C6LSI_correct_mid_holds = []
O39SI_correct_mid_holds = []
CNOOC_correct_mid_holds = []
JPM_correct_mid_holds = []
AXL_correct_mid_holds = []

C6LSI_profit = []
O39SI_profit = []
CNOOC_profit = []
JPM_profit = []
AXL_profit = []

for key,value in nr_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    C6LSI_acc.append(acc[0])
    O39SI_acc.append(acc[1])
    CNOOC_acc.append(acc[2])
    JPM_acc.append(acc[3]) 
    AXL_acc.append(acc[4]) 

    C6LSI_correct_buys.append(correct_buys[0])
    O39SI_correct_buys.append(correct_buys[1]) 
    CNOOC_correct_buys.append(correct_buys[2]) 
    JPM_correct_buys.append(correct_buys[3]) 
    AXL_correct_buys.append(correct_buys[4])
    

    C6LSI_correct_sells.append(correct_sells[0]) 
    O39SI_correct_sells.append(correct_sells[1]) 
    CNOOC_correct_sells.append(correct_sells[2]) 
    JPM_correct_sells.append(correct_sells[3]) 
    AXL_correct_sells.append(correct_sells[4]) 
    

    C6LSI_correct_holds.append(correct_holds[0]) 
    O39SI_correct_holds.append(correct_holds[1])  
    CNOOC_correct_holds.append(correct_holds[2])  
    JPM_correct_holds.append(correct_holds[3])  
    AXL_correct_holds.append(correct_holds[4])  
     

    C6LSI_correct_low_buys.append(correct_low_buys[0])  
    O39SI_correct_low_buys.append(correct_low_buys[1])  
    CNOOC_correct_low_buys.append(correct_low_buys[2])  
    JPM_correct_low_buys.append(correct_low_buys[3])   
    AXL_correct_low_buys.append(correct_low_buys[4])   
    

    C6LSI_correct_high_sells.append(correct_high_sells[0]) 
    O39SI_correct_high_sells.append(correct_high_sells[1]) 
    CNOOC_correct_high_sells.append(correct_high_sells[2]) 
    JPM_correct_high_sells.append(correct_high_sells[3]) 
    AXL_correct_high_sells.append(correct_high_sells[4]) 
    

    C6LSI_correct_mid_holds.append(correct_mid_holds[0])  
    O39SI_correct_mid_holds.append(correct_mid_holds[1])  
    CNOOC_correct_mid_holds.append(correct_mid_holds[2])   
    JPM_correct_mid_holds.append(correct_mid_holds[3])   
    AXL_correct_mid_holds.append(correct_mid_holds[4])   
    

    C6LSI_profit.append(profit[0]) 
    O39SI_profit.append(profit[1]) 
    CNOOC_profit.append(profit[2]) 
    JPM_profit.append(profit[3])  
    AXL_profit.append(profit[4])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(C6LSI_acc)
plt.plot(O39SI_acc)
plt.plot(CNOOC_acc)
plt.plot(JPM_acc)
plt.plot(AXL_acc)
plt.title('Non-Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['C6L.SI_acc','O39.SI_acc','CNOOC_acc','JPM_acc','AXL_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_low_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_low_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_high_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_high_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_mid_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_mid_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_profit")

plt.subplot(3, 4, 2)
plt.plot(O39SI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_profit")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_profit")

plt.subplot(3, 4, 4)
plt.plot(JPM_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_profit")

plt.subplot(3, 4, 5)
plt.plot(AXL_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_profit")
# Out:
# Text(0.5, 1.0, 'AXL_profit')

# %%
C6LSI_acc = []
O39SI_acc = []
CNOOC_acc = []
JPM_acc = []
AXL_acc = []

C6LSI_correct_buys = []
O39SI_correct_buys = []
CNOOC_correct_buys = []
JPM_correct_buys = []
AXL_correct_buys = []

C6LSI_correct_sells = []
O39SI_correct_sells = []
CNOOC_correct_sells = []
JPM_correct_sells = []
AXL_correct_sells = []

C6LSI_correct_holds = []
O39SI_correct_holds = []
CNOOC_correct_holds = []
JPM_correct_holds = []
AXL_correct_holds = []

C6LSI_correct_low_buys = []
O39SI_correct_low_buys = []
CNOOC_correct_low_buys = []
JPM_correct_low_buys = []
AXL_correct_low_buys = []

C6LSI_correct_high_sells = []
O39SI_correct_high_sells = []
CNOOC_correct_high_sells = []
JPM_correct_high_sells = []
AXL_correct_high_sells = []

C6LSI_correct_mid_holds = []
O39SI_correct_mid_holds = []
CNOOC_correct_mid_holds = []
JPM_correct_mid_holds = []
AXL_correct_mid_holds = []

C6LSI_profit = []
O39SI_profit = []
CNOOC_profit = []
JPM_profit = []
AXL_profit = []

for key,value in r_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    C6LSI_acc.append(acc[0])
    O39SI_acc.append(acc[1])
    CNOOC_acc.append(acc[2])
    JPM_acc.append(acc[3]) 
    AXL_acc.append(acc[4]) 

    C6LSI_correct_buys.append(correct_buys[0])
    O39SI_correct_buys.append(correct_buys[1]) 
    CNOOC_correct_buys.append(correct_buys[2]) 
    JPM_correct_buys.append(correct_buys[3]) 
    AXL_correct_buys.append(correct_buys[4])
    

    C6LSI_correct_sells.append(correct_sells[0]) 
    O39SI_correct_sells.append(correct_sells[1]) 
    CNOOC_correct_sells.append(correct_sells[2]) 
    JPM_correct_sells.append(correct_sells[3]) 
    AXL_correct_sells.append(correct_sells[4]) 
    

    C6LSI_correct_holds.append(correct_holds[0]) 
    O39SI_correct_holds.append(correct_holds[1])  
    CNOOC_correct_holds.append(correct_holds[2])  
    JPM_correct_holds.append(correct_holds[3])  
    AXL_correct_holds.append(correct_holds[4])  
     

    C6LSI_correct_low_buys.append(correct_low_buys[0])  
    O39SI_correct_low_buys.append(correct_low_buys[1])  
    CNOOC_correct_low_buys.append(correct_low_buys[2])  
    JPM_correct_low_buys.append(correct_low_buys[3])   
    AXL_correct_low_buys.append(correct_low_buys[4])   
    

    C6LSI_correct_high_sells.append(correct_high_sells[0]) 
    O39SI_correct_high_sells.append(correct_high_sells[1]) 
    CNOOC_correct_high_sells.append(correct_high_sells[2]) 
    JPM_correct_high_sells.append(correct_high_sells[3]) 
    AXL_correct_high_sells.append(correct_high_sells[4]) 
    

    C6LSI_correct_mid_holds.append(correct_mid_holds[0])  
    O39SI_correct_mid_holds.append(correct_mid_holds[1])  
    CNOOC_correct_mid_holds.append(correct_mid_holds[2])   
    JPM_correct_mid_holds.append(correct_mid_holds[3])   
    AXL_correct_mid_holds.append(correct_mid_holds[4])   
    

    C6LSI_profit.append(profit[0]) 
    O39SI_profit.append(profit[1]) 
    CNOOC_profit.append(profit[2]) 
    JPM_profit.append(profit[3])  
    AXL_profit.append(profit[4])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(C6LSI_acc)
plt.plot(O39SI_acc)
plt.plot(CNOOC_acc)
plt.plot(JPM_acc)
plt.plot(AXL_acc)
plt.title('Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['C6L.SI_acc','O39.SI_acc','CNOOC_acc','JPM_acc','AXL_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_low_buys")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_low_buys")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'AXL_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_high_sells")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_high_sells")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'AXL_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(O39SI_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_correct_mid_holds")

plt.subplot(3, 4, 4)
plt.plot(JPM_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_correct_mid_holds")

plt.subplot(3, 4, 5)
plt.plot(AXL_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'AXL_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(C6LSI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("C6L.SI_profit")

plt.subplot(3, 4, 2)
plt.plot(O39SI_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("O39.SI_profit")

plt.subplot(3, 4, 3)
plt.plot(CNOOC_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("CNOOC_profit")

plt.subplot(3, 4, 4)
plt.plot(JPM_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("JPM_profit")

plt.subplot(3, 4, 5)
plt.plot(AXL_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("AXL_profit")
# Out:
# Text(0.5, 1.0, 'AXL_profit')
