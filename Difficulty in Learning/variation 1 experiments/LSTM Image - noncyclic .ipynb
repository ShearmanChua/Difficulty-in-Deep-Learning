# %%
import os
seed = 10
os.environ['PYTHONHASHSEED']=str(seed)

# %%
import requests
import lxml
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.utils import compute_class_weight
import tensorflow as tf
from pil import Image
from sklearn import preprocessing

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)


np.random.seed(seed)
tf.random.set_seed(seed)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Non-Cyclic Stocks

# %% [markdown]
# ### Kweichow Moutai Co., Ltd.

# %%
seed = 10
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/600519.SS_data.csv")
print(df.head())
# Out:
#          Date  previous_1d    EMA_12   willr_14        OBV_7  labels
# 0  2001-09-14     7.142585  7.257483 -41.873824  204624213.0     2.0
# 1  2001-09-17     7.224180  7.252359 -51.296847  208479649.0     2.0
# 2  2001-09-18     7.132634  7.233940 -72.964156  203965392.0     2.0
# 3  2001-09-19     7.214230  7.230908 -59.609037  209378730.0     2.0
# 4  2001-09-20     7.347568  7.248855 -37.785092  213725440.0     2.0

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['labels'].plot(figsize=(16,6),x='Date', y='labels')

# %%
df.set_index('Date', inplace=True)
df.head()
# Out:
#             previous_1d    EMA_12   willr_14        OBV_7  labels
# Date
# 2001-09-14     7.142585  7.257483 -41.873824  204624213.0     2.0
# 2001-09-17     7.224180  7.252359 -51.296847  208479649.0     2.0
# 2001-09-18     7.132634  7.233940 -72.964156  203965392.0     2.0
# 2001-09-19     7.214230  7.230908 -59.609037  209378730.0     2.0
# 2001-09-20     7.347568  7.248855 -37.785092  213725440.0     2.0

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1

# %%
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64)
y = np.array(y)

X.shape
# Out:
# (4106, 64, 64)

# %%
X[0]
# Out:
# array([[225.9045, 225.9045, 225.9045, ..., 225.9045, 225.9045, 225.9045],
#        [225.9045, 225.9045, 225.9045, ..., 225.9045, 225.9045, 225.9045],
#        [225.9045, 225.9045, 225.9045, ..., 225.9045, 225.9045, 225.9045],
#        ...,
#        [225.9045, 225.9045, 225.9045, ..., 225.9045, 225.9045, 225.9045],
#        [225.9045, 225.9045, 225.9045, ..., 225.9045, 225.9045, 225.9045],
#        [225.9045, 225.9045, 225.9045, ..., 225.9045, 225.9045, 225.9045]])

# %%
# plot the image array X
i = X[0].reshape(64, 64)
fig2, ax2 = plt.subplots()
plt.imshow(i, interpolation="none", cmap="gray")

ax2.axis('off')

plt.show()

# %%
X = X/255

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
RATIO_TO_PREDICT = "Close"

# %%
import time

EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization,Activation
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(LSTM(100, input_shape=(X_train.shape[1:]), return_sequences=True,kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(LSTM(100, kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# model.add(Dense(100, kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))

model.add(Dense(75, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(50, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa
opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

#tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "LSTM_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))

# Train model
history = model.fit(
    train_x, train_y,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    shuffle = True,
    validation_data=(validation_x, validation_y),
    #callbacks=[tensorboard],
    class_weight=d_class_weights
)
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 2 ... 2 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# Epoch 1/200
# 26/26 [==============================] - 1s 45ms/step - loss: 0.2835 - accuracy: 0.4881 - mse: 0.4193 - weighted_accuracy: 0.3845 - weighted_mse: 0.4612 - val_loss: 0.2908 - val_accuracy: 0.9100 - val_mse: 0.3401 - val_weighted_accuracy: 0.9100 - val_weighted_mse: 0.3401
# Epoch 2/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.2179 - accuracy: 0.3898 - mse: 0.6536 - weighted_accuracy: 0.4822 - weighted_mse: 0.6608 - val_loss: 0.2884 - val_accuracy: 0.4611 - val_mse: 0.3654 - val_weighted_accuracy: 0.4611 - val_weighted_mse: 0.3654
# Epoch 3/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1931 - accuracy: 0.3928 - mse: 0.8508 - weighted_accuracy: 0.5173 - weighted_mse: 0.8561 - val_loss: 0.2871 - val_accuracy: 0.0450 - val_mse: 0.3864 - val_weighted_accuracy: 0.0450 - val_weighted_mse: 0.3864
# Epoch 4/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1808 - accuracy: 0.3514 - mse: 1.0408 - weighted_accuracy: 0.5668 - weighted_mse: 1.0317 - val_loss: 0.2722 - val_accuracy: 0.1010 - val_mse: 0.4006 - val_weighted_accuracy: 0.1010 - val_weighted_mse: 0.4006
# Epoch 5/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1744 - accuracy: 0.3429 - mse: 1.1402 - weighted_accuracy: 0.5742 - weighted_mse: 1.1136 - val_loss: 0.2627 - val_accuracy: 0.1350 - val_mse: 0.4297 - val_weighted_accuracy: 0.1350 - val_weighted_mse: 0.4297
# Epoch 6/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1694 - accuracy: 0.3569 - mse: 1.2284 - weighted_accuracy: 0.5947 - weighted_mse: 1.2005 - val_loss: 0.2496 - val_accuracy: 0.9088 - val_mse: 0.4658 - val_weighted_accuracy: 0.9088 - val_weighted_mse: 0.4658
# Epoch 7/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1653 - accuracy: 0.3721 - mse: 1.2858 - weighted_accuracy: 0.6000 - weighted_mse: 1.2585 - val_loss: 0.2472 - val_accuracy: 0.4063 - val_mse: 0.4976 - val_weighted_accuracy: 0.4063 - val_weighted_mse: 0.4976
# Epoch 8/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1620 - accuracy: 0.3590 - mse: 1.3308 - weighted_accuracy: 0.6103 - weighted_mse: 1.2875 - val_loss: 0.2379 - val_accuracy: 0.6484 - val_mse: 0.5316 - val_weighted_accuracy: 0.6484 - val_weighted_mse: 0.5316
# Epoch 9/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1592 - accuracy: 0.3764 - mse: 1.3462 - weighted_accuracy: 0.6231 - weighted_mse: 1.3172 - val_loss: 0.2286 - val_accuracy: 0.3832 - val_mse: 0.5823 - val_weighted_accuracy: 0.3832 - val_weighted_mse: 0.5823
# Epoch 10/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1555 - accuracy: 0.3733 - mse: 1.3899 - weighted_accuracy: 0.6478 - weighted_mse: 1.3488 - val_loss: 0.2212 - val_accuracy: 0.7640 - val_mse: 0.6009 - val_weighted_accuracy: 0.7640 - val_weighted_mse: 0.6009
# Epoch 11/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1538 - accuracy: 0.3828 - mse: 1.4049 - weighted_accuracy: 0.6490 - weighted_mse: 1.3536 - val_loss: 0.2109 - val_accuracy: 0.4842 - val_mse: 0.6652 - val_weighted_accuracy: 0.4842 - val_weighted_mse: 0.6652
# Epoch 12/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1513 - accuracy: 0.4099 - mse: 1.4305 - weighted_accuracy: 0.6613 - weighted_mse: 1.3879 - val_loss: 0.2032 - val_accuracy: 0.8224 - val_mse: 0.6820 - val_weighted_accuracy: 0.8224 - val_weighted_mse: 0.6820
# Epoch 13/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1490 - accuracy: 0.4348 - mse: 1.4482 - weighted_accuracy: 0.6768 - weighted_mse: 1.4122 - val_loss: 0.1863 - val_accuracy: 0.8929 - val_mse: 0.7386 - val_weighted_accuracy: 0.8929 - val_weighted_mse: 0.7386
# Epoch 14/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1455 - accuracy: 0.4364 - mse: 1.4606 - weighted_accuracy: 0.6903 - weighted_mse: 1.4245 - val_loss: 0.2022 - val_accuracy: 0.6350 - val_mse: 0.6267 - val_weighted_accuracy: 0.6350 - val_weighted_mse: 0.6267
# Epoch 15/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.1434 - accuracy: 0.4504 - mse: 1.4885 - weighted_accuracy: 0.7062 - weighted_mse: 1.4525 - val_loss: 0.1676 - val_accuracy: 0.9051 - val_mse: 0.6948 - val_weighted_accuracy: 0.9051 - val_weighted_mse: 0.6948
# Epoch 16/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1405 - accuracy: 0.4738 - mse: 1.5042 - weighted_accuracy: 0.7256 - weighted_mse: 1.4649 - val_loss: 0.1664 - val_accuracy: 0.8394 - val_mse: 0.9133 - val_weighted_accuracy: 0.8394 - val_weighted_mse: 0.9133
# Epoch 17/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1380 - accuracy: 0.5033 - mse: 1.5210 - weighted_accuracy: 0.7127 - weighted_mse: 1.5062 - val_loss: 0.1568 - val_accuracy: 0.8820 - val_mse: 0.9213 - val_weighted_accuracy: 0.8820 - val_weighted_mse: 0.9213
# Epoch 18/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1366 - accuracy: 0.4799 - mse: 1.5630 - weighted_accuracy: 0.7278 - weighted_mse: 1.5321 - val_loss: 0.1269 - val_accuracy: 0.9100 - val_mse: 0.9313 - val_weighted_accuracy: 0.9100 - val_weighted_mse: 0.9313
# Epoch 19/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1322 - accuracy: 0.5311 - mse: 1.5607 - weighted_accuracy: 0.7465 - weighted_mse: 1.5488 - val_loss: 0.1319 - val_accuracy: 0.8978 - val_mse: 1.0607 - val_weighted_accuracy: 0.8978 - val_weighted_mse: 1.0607
# Epoch 20/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1299 - accuracy: 0.5505 - mse: 1.5924 - weighted_accuracy: 0.7602 - weighted_mse: 1.5837 - val_loss: 0.1208 - val_accuracy: 0.9112 - val_mse: 0.6869 - val_weighted_accuracy: 0.9112 - val_weighted_mse: 0.6869
# Epoch 21/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1294 - accuracy: 0.5347 - mse: 1.6294 - weighted_accuracy: 0.7479 - weighted_mse: 1.6093 - val_loss: 0.1414 - val_accuracy: 0.8151 - val_mse: 0.7276 - val_weighted_accuracy: 0.8151 - val_weighted_mse: 0.7276
# Epoch 22/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1245 - accuracy: 0.5731 - mse: 1.6135 - weighted_accuracy: 0.7835 - weighted_mse: 1.6190 - val_loss: 0.1439 - val_accuracy: 0.7421 - val_mse: 1.2630 - val_weighted_accuracy: 0.7421 - val_weighted_mse: 1.2630
# Epoch 23/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1224 - accuracy: 0.5792 - mse: 1.6493 - weighted_accuracy: 0.7942 - weighted_mse: 1.6492 - val_loss: 0.1547 - val_accuracy: 0.6788 - val_mse: 1.9504 - val_weighted_accuracy: 0.6788 - val_weighted_mse: 1.9504
# Epoch 24/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1177 - accuracy: 0.5950 - mse: 1.6795 - weighted_accuracy: 0.7959 - weighted_mse: 1.7024 - val_loss: 0.1398 - val_accuracy: 0.6946 - val_mse: 2.0642 - val_weighted_accuracy: 0.6946 - val_weighted_mse: 2.0642
# Epoch 25/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1158 - accuracy: 0.6130 - mse: 1.7131 - weighted_accuracy: 0.8132 - weighted_mse: 1.7289 - val_loss: 0.1218 - val_accuracy: 0.9100 - val_mse: 2.0055 - val_weighted_accuracy: 0.9100 - val_weighted_mse: 2.0055
# Epoch 26/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.1123 - accuracy: 0.6309 - mse: 1.7284 - weighted_accuracy: 0.8240 - weighted_mse: 1.7633 - val_loss: 0.1140 - val_accuracy: 0.8358 - val_mse: 1.8525 - val_weighted_accuracy: 0.8358 - val_weighted_mse: 1.8525
# Epoch 27/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1100 - accuracy: 0.6608 - mse: 1.7504 - weighted_accuracy: 0.8328 - weighted_mse: 1.8025 - val_loss: 0.2700 - val_accuracy: 0.4100 - val_mse: 5.2675 - val_weighted_accuracy: 0.4100 - val_weighted_mse: 5.2675
# Epoch 28/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1074 - accuracy: 0.6401 - mse: 1.8111 - weighted_accuracy: 0.8360 - weighted_mse: 1.8634 - val_loss: 0.1791 - val_accuracy: 0.9100 - val_mse: 4.8999 - val_weighted_accuracy: 0.9100 - val_weighted_mse: 4.8999
# Epoch 29/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.1033 - accuracy: 0.6632 - mse: 1.8571 - weighted_accuracy: 0.8402 - weighted_mse: 1.9408 - val_loss: 0.2160 - val_accuracy: 0.5170 - val_mse: 3.6983 - val_weighted_accuracy: 0.5170 - val_weighted_mse: 3.6983
# Epoch 30/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1012 - accuracy: 0.6924 - mse: 1.8497 - weighted_accuracy: 0.8487 - weighted_mse: 1.9482 - val_loss: 0.1464 - val_accuracy: 0.8893 - val_mse: 8.4829 - val_weighted_accuracy: 0.8893 - val_weighted_mse: 8.4829
# Epoch 31/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0979 - accuracy: 0.7049 - mse: 1.9089 - weighted_accuracy: 0.8640 - weighted_mse: 2.0099 - val_loss: 0.1763 - val_accuracy: 0.9100 - val_mse: 3.7890 - val_weighted_accuracy: 0.9100 - val_weighted_mse: 3.7890
# Epoch 32/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0943 - accuracy: 0.7129 - mse: 1.9625 - weighted_accuracy: 0.8648 - weighted_mse: 2.0636 - val_loss: 0.1428 - val_accuracy: 0.8394 - val_mse: 6.9168 - val_weighted_accuracy: 0.8394 - val_weighted_mse: 6.9168
# Epoch 33/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0909 - accuracy: 0.7226 - mse: 1.9989 - weighted_accuracy: 0.8769 - weighted_mse: 2.1402 - val_loss: 0.1150 - val_accuracy: 0.8990 - val_mse: 4.2671 - val_weighted_accuracy: 0.8990 - val_weighted_mse: 4.2671
# Epoch 34/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0885 - accuracy: 0.7460 - mse: 2.0297 - weighted_accuracy: 0.8877 - weighted_mse: 2.1818 - val_loss: 0.2901 - val_accuracy: 0.4100 - val_mse: 5.8829 - val_weighted_accuracy: 0.4100 - val_weighted_mse: 5.8829
# Epoch 35/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0842 - accuracy: 0.7479 - mse: 2.0993 - weighted_accuracy: 0.8840 - weighted_mse: 2.2744 - val_loss: 0.2210 - val_accuracy: 0.9088 - val_mse: 6.8373 - val_weighted_accuracy: 0.9088 - val_weighted_mse: 6.8373
# Epoch 36/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0803 - accuracy: 0.7701 - mse: 2.1400 - weighted_accuracy: 0.8965 - weighted_mse: 2.3414 - val_loss: 0.1531 - val_accuracy: 0.8382 - val_mse: 5.9104 - val_weighted_accuracy: 0.8382 - val_weighted_mse: 5.9104
# Epoch 37/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0767 - accuracy: 0.7792 - mse: 2.1986 - weighted_accuracy: 0.9041 - weighted_mse: 2.4067 - val_loss: 0.1708 - val_accuracy: 0.9063 - val_mse: 9.7744 - val_weighted_accuracy: 0.9063 - val_weighted_mse: 9.7744
# Epoch 38/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0748 - accuracy: 0.7945 - mse: 2.2908 - weighted_accuracy: 0.9119 - weighted_mse: 2.5236 - val_loss: 0.3199 - val_accuracy: 0.3893 - val_mse: 5.4880 - val_weighted_accuracy: 0.3893 - val_weighted_mse: 5.4880
# Epoch 39/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0713 - accuracy: 0.8039 - mse: 2.3816 - weighted_accuracy: 0.9153 - weighted_mse: 2.6522 - val_loss: 0.2492 - val_accuracy: 0.9100 - val_mse: 10.9455 - val_weighted_accuracy: 0.9100 - val_weighted_mse: 10.9455
# Epoch 40/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0681 - accuracy: 0.8155 - mse: 2.4503 - weighted_accuracy: 0.9196 - weighted_mse: 2.7093 - val_loss: 0.1345 - val_accuracy: 0.8321 - val_mse: 8.7787 - val_weighted_accuracy: 0.8321 - val_weighted_mse: 8.7787
# Epoch 41/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0638 - accuracy: 0.8240 - mse: 2.5263 - weighted_accuracy: 0.9270 - weighted_mse: 2.8494 - val_loss: 0.1523 - val_accuracy: 0.9039 - val_mse: 7.9601 - val_weighted_accuracy: 0.9039 - val_weighted_mse: 7.9601
# Epoch 42/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0617 - accuracy: 0.8380 - mse: 2.6014 - weighted_accuracy: 0.9321 - weighted_mse: 2.8904 - val_loss: 0.1353 - val_accuracy: 0.8577 - val_mse: 8.7246 - val_weighted_accuracy: 0.8577 - val_weighted_mse: 8.7246
# Epoch 43/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0581 - accuracy: 0.8554 - mse: 2.7485 - weighted_accuracy: 0.9406 - weighted_mse: 3.1094 - val_loss: 0.1862 - val_accuracy: 0.7640 - val_mse: 9.0314 - val_weighted_accuracy: 0.7640 - val_weighted_mse: 9.0314
# Epoch 44/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0564 - accuracy: 0.8523 - mse: 2.8415 - weighted_accuracy: 0.9395 - weighted_mse: 3.2416 - val_loss: 0.2278 - val_accuracy: 0.7056 - val_mse: 13.0328 - val_weighted_accuracy: 0.7056 - val_weighted_mse: 13.0328
# Epoch 45/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0557 - accuracy: 0.8523 - mse: 2.9404 - weighted_accuracy: 0.9395 - weighted_mse: 3.3248 - val_loss: 0.3908 - val_accuracy: 0.9100 - val_mse: 21.5869 - val_weighted_accuracy: 0.9100 - val_weighted_mse: 21.5869
# Epoch 46/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0522 - accuracy: 0.8752 - mse: 3.0348 - weighted_accuracy: 0.9457 - weighted_mse: 3.4531 - val_loss: 0.2188 - val_accuracy: 0.9051 - val_mse: 14.2671 - val_weighted_accuracy: 0.9051 - val_weighted_mse: 14.2671
# Epoch 47/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0479 - accuracy: 0.8837 - mse: 3.1503 - weighted_accuracy: 0.9531 - weighted_mse: 3.6160 - val_loss: 0.3283 - val_accuracy: 0.9100 - val_mse: 19.5988 - val_weighted_accuracy: 0.9100 - val_weighted_mse: 19.5988
# Epoch 48/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0451 - accuracy: 0.8922 - mse: 3.2413 - weighted_accuracy: 0.9584 - weighted_mse: 3.7077 - val_loss: 0.2869 - val_accuracy: 0.9075 - val_mse: 16.8201 - val_weighted_accuracy: 0.9075 - val_weighted_mse: 16.8201
# Epoch 49/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0408 - accuracy: 0.9035 - mse: 3.4077 - weighted_accuracy: 0.9604 - weighted_mse: 3.9382 - val_loss: 0.2951 - val_accuracy: 0.8978 - val_mse: 16.1186 - val_weighted_accuracy: 0.8978 - val_weighted_mse: 16.1186
# Epoch 50/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0399 - accuracy: 0.9090 - mse: 3.5626 - weighted_accuracy: 0.9645 - weighted_mse: 4.0511 - val_loss: 0.1900 - val_accuracy: 0.8467 - val_mse: 8.6968 - val_weighted_accuracy: 0.8467 - val_weighted_mse: 8.6968
# Epoch 51/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0358 - accuracy: 0.9217 - mse: 3.7482 - weighted_accuracy: 0.9713 - weighted_mse: 4.2929 - val_loss: 0.1467 - val_accuracy: 0.8905 - val_mse: 10.3931 - val_weighted_accuracy: 0.8905 - val_weighted_mse: 10.3931
# Epoch 52/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0343 - accuracy: 0.9272 - mse: 3.9501 - weighted_accuracy: 0.9734 - weighted_mse: 4.5332 - val_loss: 0.2202 - val_accuracy: 0.9075 - val_mse: 12.1722 - val_weighted_accuracy: 0.9075 - val_weighted_mse: 12.1722
# Epoch 53/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0335 - accuracy: 0.9248 - mse: 4.1032 - weighted_accuracy: 0.9725 - weighted_mse: 4.7617 - val_loss: 0.2622 - val_accuracy: 0.9063 - val_mse: 16.9872 - val_weighted_accuracy: 0.9063 - val_weighted_mse: 16.9872
# Epoch 54/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0300 - accuracy: 0.9400 - mse: 4.3050 - weighted_accuracy: 0.9780 - weighted_mse: 4.9325 - val_loss: 0.4413 - val_accuracy: 0.9088 - val_mse: 26.4174 - val_weighted_accuracy: 0.9088 - val_weighted_mse: 26.4174
# Epoch 55/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0273 - accuracy: 0.9440 - mse: 4.5508 - weighted_accuracy: 0.9795 - weighted_mse: 5.2327 - val_loss: 0.2687 - val_accuracy: 0.5182 - val_mse: 5.0433 - val_weighted_accuracy: 0.5182 - val_weighted_mse: 5.0433
# Epoch 56/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0255 - accuracy: 0.9528 - mse: 4.7301 - weighted_accuracy: 0.9827 - weighted_mse: 5.3573 - val_loss: 0.1893 - val_accuracy: 0.7737 - val_mse: 8.9532 - val_weighted_accuracy: 0.7737 - val_weighted_mse: 8.9532
# Epoch 57/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0252 - accuracy: 0.9504 - mse: 4.9398 - weighted_accuracy: 0.9818 - weighted_mse: 5.6141 - val_loss: 0.2958 - val_accuracy: 0.9088 - val_mse: 19.4161 - val_weighted_accuracy: 0.9088 - val_weighted_mse: 19.4161
# Epoch 58/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0218 - accuracy: 0.9635 - mse: 5.2019 - weighted_accuracy: 0.9866 - weighted_mse: 6.0138 - val_loss: 0.2892 - val_accuracy: 0.9027 - val_mse: 17.7927 - val_weighted_accuracy: 0.9027 - val_weighted_mse: 17.7927
# Epoch 59/200
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0195 - accuracy: 0.9692 - mse: 5.5336 - weighted_accuracy: 0.9887 - weighted_mse: 6.2656 - val_loss: 0.3074 - val_accuracy: 0.9075 - val_mse: 18.8619 - val_weighted_accuracy: 0.9075 - val_weighted_mse: 18.8619
# Epoch 60/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0182 - accuracy: 0.9759 - mse: 5.7214 - weighted_accuracy: 0.9912 - weighted_mse: 6.4283 - val_loss: 0.2449 - val_accuracy: 0.8893 - val_mse: 14.3775 - val_weighted_accuracy: 0.8893 - val_weighted_mse: 14.3775
# Epoch 61/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0167 - accuracy: 0.9744 - mse: 5.9464 - weighted_accuracy: 0.9906 - weighted_mse: 6.7090 - val_loss: 0.2891 - val_accuracy: 0.9063 - val_mse: 16.8384 - val_weighted_accuracy: 0.9063 - val_weighted_mse: 16.8384
# Epoch 62/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0155 - accuracy: 0.9802 - mse: 6.2821 - weighted_accuracy: 0.9928 - weighted_mse: 6.9986 - val_loss: 0.2550 - val_accuracy: 0.8990 - val_mse: 11.9265 - val_weighted_accuracy: 0.8990 - val_weighted_mse: 11.9265
# Epoch 63/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0149 - accuracy: 0.9839 - mse: 6.5670 - weighted_accuracy: 0.9941 - weighted_mse: 7.4309 - val_loss: 0.2145 - val_accuracy: 0.8054 - val_mse: 8.2931 - val_weighted_accuracy: 0.8054 - val_weighted_mse: 8.2931
# Epoch 64/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0144 - accuracy: 0.9836 - mse: 6.7380 - weighted_accuracy: 0.9940 - weighted_mse: 7.6146 - val_loss: 0.3347 - val_accuracy: 0.8954 - val_mse: 19.5818 - val_weighted_accuracy: 0.8954 - val_weighted_mse: 19.5818
# Epoch 65/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0126 - accuracy: 0.9878 - mse: 6.9855 - weighted_accuracy: 0.9955 - weighted_mse: 7.7468 - val_loss: 0.2773 - val_accuracy: 0.7762 - val_mse: 11.7832 - val_weighted_accuracy: 0.7762 - val_weighted_mse: 11.7832
# Epoch 66/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0126 - accuracy: 0.9890 - mse: 7.3366 - weighted_accuracy: 0.9960 - weighted_mse: 8.2026 - val_loss: 0.2678 - val_accuracy: 0.8662 - val_mse: 13.4725 - val_weighted_accuracy: 0.8662 - val_weighted_mse: 13.4725
# Epoch 67/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0118 - accuracy: 0.9884 - mse: 7.5455 - weighted_accuracy: 0.9958 - weighted_mse: 8.3564 - val_loss: 0.3583 - val_accuracy: 0.7007 - val_mse: 10.4197 - val_weighted_accuracy: 0.7007 - val_weighted_mse: 10.4197
# Epoch 68/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0105 - accuracy: 0.9909 - mse: 7.8453 - weighted_accuracy: 0.9967 - weighted_mse: 8.6810 - val_loss: 0.2734 - val_accuracy: 0.8273 - val_mse: 12.9178 - val_weighted_accuracy: 0.8273 - val_weighted_mse: 12.9178
# Epoch 69/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0101 - accuracy: 0.9921 - mse: 8.0970 - weighted_accuracy: 0.9971 - weighted_mse: 9.1011 - val_loss: 0.2706 - val_accuracy: 0.8723 - val_mse: 15.8433 - val_weighted_accuracy: 0.8723 - val_weighted_mse: 15.8433
# Epoch 70/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0095 - accuracy: 0.9939 - mse: 8.3540 - weighted_accuracy: 0.9978 - weighted_mse: 9.3600 - val_loss: 0.2744 - val_accuracy: 0.8358 - val_mse: 17.2922 - val_weighted_accuracy: 0.8358 - val_weighted_mse: 17.2922
# Epoch 71/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0091 - accuracy: 0.9942 - mse: 8.7184 - weighted_accuracy: 0.9979 - weighted_mse: 9.5349 - val_loss: 0.2991 - val_accuracy: 0.8212 - val_mse: 13.4078 - val_weighted_accuracy: 0.8212 - val_weighted_mse: 13.4078
# Epoch 72/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0088 - accuracy: 0.9948 - mse: 8.9576 - weighted_accuracy: 0.9981 - weighted_mse: 9.9857 - val_loss: 0.3483 - val_accuracy: 0.8820 - val_mse: 20.2982 - val_weighted_accuracy: 0.8820 - val_weighted_mse: 20.2982
# Epoch 73/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0079 - accuracy: 0.9985 - mse: 9.2443 - weighted_accuracy: 0.9994 - weighted_mse: 10.0854 - val_loss: 0.3399 - val_accuracy: 0.7591 - val_mse: 11.0869 - val_weighted_accuracy: 0.7591 - val_weighted_mse: 11.0869
# Epoch 74/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0077 - accuracy: 0.9970 - mse: 9.4950 - weighted_accuracy: 0.9989 - weighted_mse: 10.3797 - val_loss: 0.3553 - val_accuracy: 0.9039 - val_mse: 23.0974 - val_weighted_accuracy: 0.9039 - val_weighted_mse: 23.0974
# Epoch 75/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0073 - accuracy: 0.9985 - mse: 9.6521 - weighted_accuracy: 0.9994 - weighted_mse: 10.7114 - val_loss: 0.2874 - val_accuracy: 0.8601 - val_mse: 14.6530 - val_weighted_accuracy: 0.8601 - val_weighted_mse: 14.6530
# Epoch 76/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0068 - accuracy: 0.9994 - mse: 9.9481 - weighted_accuracy: 0.9998 - weighted_mse: 11.0131 - val_loss: 0.2567 - val_accuracy: 0.8808 - val_mse: 14.0130 - val_weighted_accuracy: 0.8808 - val_weighted_mse: 14.0130
# Epoch 77/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0071 - accuracy: 0.9976 - mse: 10.2029 - weighted_accuracy: 0.9991 - weighted_mse: 11.1091 - val_loss: 0.3108 - val_accuracy: 0.7737 - val_mse: 13.2025 - val_weighted_accuracy: 0.7737 - val_weighted_mse: 13.2025
# Epoch 78/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0072 - accuracy: 0.9976 - mse: 10.4135 - weighted_accuracy: 0.9991 - weighted_mse: 11.4367 - val_loss: 0.3616 - val_accuracy: 0.8552 - val_mse: 19.8094 - val_weighted_accuracy: 0.8552 - val_weighted_mse: 19.8094
# Epoch 79/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0066 - accuracy: 0.9988 - mse: 10.6960 - weighted_accuracy: 0.9996 - weighted_mse: 11.6492 - val_loss: 0.2980 - val_accuracy: 0.8431 - val_mse: 18.5243 - val_weighted_accuracy: 0.8431 - val_weighted_mse: 18.5243
# Epoch 80/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0064 - accuracy: 0.9991 - mse: 10.8484 - weighted_accuracy: 0.9997 - weighted_mse: 11.8456 - val_loss: 0.2539 - val_accuracy: 0.8406 - val_mse: 13.4591 - val_weighted_accuracy: 0.8406 - val_weighted_mse: 13.4591
# Epoch 81/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0063 - accuracy: 0.9988 - mse: 11.0833 - weighted_accuracy: 0.9996 - weighted_mse: 12.1183 - val_loss: 0.3345 - val_accuracy: 0.8978 - val_mse: 19.0891 - val_weighted_accuracy: 0.8978 - val_weighted_mse: 19.0891
# Epoch 82/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0060 - accuracy: 0.9994 - mse: 11.3399 - weighted_accuracy: 0.9998 - weighted_mse: 12.4029 - val_loss: 0.2926 - val_accuracy: 0.8467 - val_mse: 14.7075 - val_weighted_accuracy: 0.8467 - val_weighted_mse: 14.7075
# Epoch 83/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0057 - accuracy: 0.9997 - mse: 11.5167 - weighted_accuracy: 0.9999 - weighted_mse: 12.5957 - val_loss: 0.3623 - val_accuracy: 0.8601 - val_mse: 19.6184 - val_weighted_accuracy: 0.8601 - val_weighted_mse: 19.6184
# Epoch 84/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0056 - accuracy: 0.9997 - mse: 11.7447 - weighted_accuracy: 0.9999 - weighted_mse: 12.8252 - val_loss: 0.3119 - val_accuracy: 0.8637 - val_mse: 16.5344 - val_weighted_accuracy: 0.8637 - val_weighted_mse: 16.5344
# Epoch 85/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0055 - accuracy: 1.0000 - mse: 11.9540 - weighted_accuracy: 1.0000 - weighted_mse: 13.0758 - val_loss: 0.2983 - val_accuracy: 0.8869 - val_mse: 16.0718 - val_weighted_accuracy: 0.8869 - val_weighted_mse: 16.0718
# Epoch 86/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0054 - accuracy: 1.0000 - mse: 12.1328 - weighted_accuracy: 1.0000 - weighted_mse: 13.1857 - val_loss: 0.3088 - val_accuracy: 0.8686 - val_mse: 16.6702 - val_weighted_accuracy: 0.8686 - val_weighted_mse: 16.6702
# Epoch 87/200
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0053 - accuracy: 1.0000 - mse: 12.3720 - weighted_accuracy: 1.0000 - weighted_mse: 13.5075 - val_loss: 0.3406 - val_accuracy: 0.8698 - val_mse: 18.2617 - val_weighted_accuracy: 0.8698 - val_weighted_mse: 18.2617
# Epoch 88/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0053 - accuracy: 1.0000 - mse: 12.5306 - weighted_accuracy: 1.0000 - weighted_mse: 13.5305 - val_loss: 0.3404 - val_accuracy: 0.8297 - val_mse: 16.8779 - val_weighted_accuracy: 0.8297 - val_weighted_mse: 16.8779
# Epoch 89/200
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0054 - accuracy: 0.9997 - mse: 12.6692 - weighted_accuracy: 0.9999 - weighted_mse: 13.7669 - val_loss: 0.3341 - val_accuracy: 0.8759 - val_mse: 18.8530 - val_weighted_accuracy: 0.8759 - val_weighted_mse: 18.8530
# Epoch 90/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0052 - accuracy: 1.0000 - mse: 12.8518 - weighted_accuracy: 1.0000 - weighted_mse: 14.0614 - val_loss: 0.3021 - val_accuracy: 0.8601 - val_mse: 16.4508 - val_weighted_accuracy: 0.8601 - val_weighted_mse: 16.4508
# Epoch 91/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0051 - accuracy: 1.0000 - mse: 13.0894 - weighted_accuracy: 1.0000 - weighted_mse: 14.3330 - val_loss: 0.2836 - val_accuracy: 0.8528 - val_mse: 14.9294 - val_weighted_accuracy: 0.8528 - val_weighted_mse: 14.9294
# Epoch 92/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0050 - accuracy: 1.0000 - mse: 13.3666 - weighted_accuracy: 1.0000 - weighted_mse: 14.5594 - val_loss: 0.3056 - val_accuracy: 0.8637 - val_mse: 17.7265 - val_weighted_accuracy: 0.8637 - val_weighted_mse: 17.7265
# Epoch 93/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0051 - accuracy: 1.0000 - mse: 13.4225 - weighted_accuracy: 1.0000 - weighted_mse: 14.5580 - val_loss: 0.3672 - val_accuracy: 0.8917 - val_mse: 21.6559 - val_weighted_accuracy: 0.8917 - val_weighted_mse: 21.6559
# Epoch 94/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 13.6084 - weighted_accuracy: 1.0000 - weighted_mse: 14.6803 - val_loss: 0.3053 - val_accuracy: 0.8662 - val_mse: 16.6409 - val_weighted_accuracy: 0.8662 - val_weighted_mse: 16.6409
# Epoch 95/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 13.8111 - weighted_accuracy: 1.0000 - weighted_mse: 14.9351 - val_loss: 0.3953 - val_accuracy: 0.8966 - val_mse: 24.2886 - val_weighted_accuracy: 0.8966 - val_weighted_mse: 24.2886
# Epoch 96/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 14.0087 - weighted_accuracy: 1.0000 - weighted_mse: 15.0089 - val_loss: 0.3125 - val_accuracy: 0.8686 - val_mse: 18.1727 - val_weighted_accuracy: 0.8686 - val_weighted_mse: 18.1727
# Epoch 97/200
# 26/26 [==============================] - 0s 19ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 14.2004 - weighted_accuracy: 1.0000 - weighted_mse: 15.1852 - val_loss: 0.3186 - val_accuracy: 0.8723 - val_mse: 18.0819 - val_weighted_accuracy: 0.8723 - val_weighted_mse: 18.0819
# Epoch 98/200
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 14.3625 - weighted_accuracy: 1.0000 - weighted_mse: 15.3566 - val_loss: 0.3142 - val_accuracy: 0.8650 - val_mse: 18.0814 - val_weighted_accuracy: 0.8650 - val_weighted_mse: 18.0814
# Epoch 99/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 14.4179 - weighted_accuracy: 1.0000 - weighted_mse: 15.3123 - val_loss: 0.2991 - val_accuracy: 0.8273 - val_mse: 15.0692 - val_weighted_accuracy: 0.8273 - val_weighted_mse: 15.0692
# Epoch 100/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 14.6028 - weighted_accuracy: 1.0000 - weighted_mse: 15.6793 - val_loss: 0.3429 - val_accuracy: 0.8589 - val_mse: 17.2634 - val_weighted_accuracy: 0.8589 - val_weighted_mse: 17.2634
# Epoch 101/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0052 - accuracy: 0.9994 - mse: 14.6544 - weighted_accuracy: 0.9998 - weighted_mse: 15.9186 - val_loss: 0.4247 - val_accuracy: 0.7968 - val_mse: 26.8006 - val_weighted_accuracy: 0.7968 - val_weighted_mse: 26.8006
# Epoch 102/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0732 - accuracy: 0.9306 - mse: 13.7731 - weighted_accuracy: 0.9292 - weighted_mse: 14.7189 - val_loss: 1.2315 - val_accuracy: 0.2202 - val_mse: 60.1921 - val_weighted_accuracy: 0.2202 - val_weighted_mse: 60.1921
# Epoch 103/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.1669 - accuracy: 0.7378 - mse: 8.0430 - weighted_accuracy: 0.7941 - weighted_mse: 8.8269 - val_loss: 0.5156 - val_accuracy: 0.9100 - val_mse: 70.2927 - val_weighted_accuracy: 0.9100 - val_weighted_mse: 70.2927
# Epoch 104/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0834 - accuracy: 0.7859 - mse: 5.1681 - weighted_accuracy: 0.8678 - weighted_mse: 5.9870 - val_loss: 0.2723 - val_accuracy: 0.6521 - val_mse: 15.1264 - val_weighted_accuracy: 0.6521 - val_weighted_mse: 15.1264
# Epoch 105/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0405 - accuracy: 0.8858 - mse: 5.1154 - weighted_accuracy: 0.9409 - weighted_mse: 5.9914 - val_loss: 0.1887 - val_accuracy: 0.9015 - val_mse: 15.1847 - val_weighted_accuracy: 0.9015 - val_weighted_mse: 15.1847
# Epoch 106/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0224 - accuracy: 0.9467 - mse: 5.6655 - weighted_accuracy: 0.9805 - weighted_mse: 6.7304 - val_loss: 0.3086 - val_accuracy: 0.9100 - val_mse: 23.8125 - val_weighted_accuracy: 0.9100 - val_weighted_mse: 23.8125
# Epoch 107/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0169 - accuracy: 0.9705 - mse: 6.2754 - weighted_accuracy: 0.9892 - weighted_mse: 7.1797 - val_loss: 0.4184 - val_accuracy: 0.9100 - val_mse: 28.6671 - val_weighted_accuracy: 0.9100 - val_weighted_mse: 28.6671
# Epoch 108/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0140 - accuracy: 0.9808 - mse: 6.7544 - weighted_accuracy: 0.9930 - weighted_mse: 7.5809 - val_loss: 0.3527 - val_accuracy: 0.9100 - val_mse: 23.3475 - val_weighted_accuracy: 0.9100 - val_weighted_mse: 23.3475
# Epoch 109/200
# 26/26 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9819 - mse: 7.1849 - weighted_accuracy: 0.9934 - weighted_mse: 8.172 - 0s 16ms/step - loss: 0.0122 - accuracy: 0.9823 - mse: 7.1758 - weighted_accuracy: 0.9935 - weighted_mse: 8.1409 - val_loss: 0.3240 - val_accuracy: 0.8942 - val_mse: 25.2194 - val_weighted_accuracy: 0.8942 - val_weighted_mse: 25.2194
# Epoch 110/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0104 - accuracy: 0.9909 - mse: 7.5880 - weighted_accuracy: 0.9967 - weighted_mse: 8.5135 - val_loss: 0.2827 - val_accuracy: 0.8832 - val_mse: 19.2422 - val_weighted_accuracy: 0.8832 - val_weighted_mse: 19.2422
# Epoch 111/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0095 - accuracy: 0.9945 - mse: 7.9326 - weighted_accuracy: 0.9980 - weighted_mse: 8.7097 - val_loss: 0.2669 - val_accuracy: 0.8041 - val_mse: 17.1967 - val_weighted_accuracy: 0.8041 - val_weighted_mse: 17.1967
# Epoch 112/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0086 - accuracy: 0.9939 - mse: 8.2522 - weighted_accuracy: 0.9978 - weighted_mse: 9.2587 - val_loss: 0.3200 - val_accuracy: 0.8869 - val_mse: 21.7530 - val_weighted_accuracy: 0.8869 - val_weighted_mse: 21.7530
# Epoch 113/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0082 - accuracy: 0.9973 - mse: 8.5806 - weighted_accuracy: 0.9990 - weighted_mse: 9.4704 - val_loss: 0.2666 - val_accuracy: 0.8771 - val_mse: 16.6355 - val_weighted_accuracy: 0.8771 - val_weighted_mse: 16.6355
# Epoch 114/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0079 - accuracy: 0.9970 - mse: 8.7533 - weighted_accuracy: 0.9989 - weighted_mse: 9.8935 - val_loss: 0.2366 - val_accuracy: 0.8637 - val_mse: 13.4598 - val_weighted_accuracy: 0.8637 - val_weighted_mse: 13.4598
# Epoch 115/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0073 - accuracy: 0.9988 - mse: 9.0613 - weighted_accuracy: 0.9996 - weighted_mse: 10.1113 - val_loss: 0.2952 - val_accuracy: 0.8200 - val_mse: 15.6950 - val_weighted_accuracy: 0.8200 - val_weighted_mse: 15.6950
# Epoch 116/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0070 - accuracy: 0.9982 - mse: 9.3147 - weighted_accuracy: 0.9993 - weighted_mse: 10.3102 - val_loss: 0.2620 - val_accuracy: 0.8479 - val_mse: 14.7954 - val_weighted_accuracy: 0.8479 - val_weighted_mse: 14.7954
# Epoch 117/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0068 - accuracy: 0.9988 - mse: 9.5656 - weighted_accuracy: 0.9996 - weighted_mse: 10.6266 - val_loss: 0.2808 - val_accuracy: 0.8747 - val_mse: 16.4389 - val_weighted_accuracy: 0.8747 - val_weighted_mse: 16.4389
# Epoch 118/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0067 - accuracy: 0.9988 - mse: 9.8177 - weighted_accuracy: 0.9996 - weighted_mse: 10.8294 - val_loss: 0.2763 - val_accuracy: 0.8844 - val_mse: 16.1571 - val_weighted_accuracy: 0.8844 - val_weighted_mse: 16.1571
# Epoch 119/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0063 - accuracy: 0.9997 - mse: 9.9353 - weighted_accuracy: 0.9999 - weighted_mse: 11.1919 - val_loss: 0.2641 - val_accuracy: 0.8467 - val_mse: 13.8550 - val_weighted_accuracy: 0.8467 - val_weighted_mse: 13.8550
# Epoch 120/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0061 - accuracy: 0.9994 - mse: 10.1117 - weighted_accuracy: 0.9998 - weighted_mse: 11.3541 - val_loss: 0.2517 - val_accuracy: 0.8406 - val_mse: 12.4475 - val_weighted_accuracy: 0.8406 - val_weighted_mse: 12.4475
# Epoch 121/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0061 - accuracy: 0.9994 - mse: 10.4050 - weighted_accuracy: 0.9998 - weighted_mse: 11.4805 - val_loss: 0.2828 - val_accuracy: 0.8370 - val_mse: 13.8290 - val_weighted_accuracy: 0.8370 - val_weighted_mse: 13.8290
# Epoch 122/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0060 - accuracy: 0.9991 - mse: 10.5988 - weighted_accuracy: 0.9997 - weighted_mse: 11.7036 - val_loss: 0.2875 - val_accuracy: 0.8382 - val_mse: 14.1596 - val_weighted_accuracy: 0.8382 - val_weighted_mse: 14.1596
# Epoch 123/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0057 - accuracy: 1.0000 - mse: 10.7553 - weighted_accuracy: 1.0000 - weighted_mse: 11.8852 - val_loss: 0.2550 - val_accuracy: 0.8455 - val_mse: 12.2896 - val_weighted_accuracy: 0.8455 - val_weighted_mse: 12.2896
# Epoch 124/200
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0058 - accuracy: 1.0000 - mse: 10.8602 - weighted_accuracy: 1.0000 - weighted_mse: 11.9635 - val_loss: 0.2805 - val_accuracy: 0.8333 - val_mse: 13.4940 - val_weighted_accuracy: 0.8333 - val_weighted_mse: 13.4940
# Epoch 125/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0057 - accuracy: 0.9997 - mse: 11.0830 - weighted_accuracy: 0.9999 - weighted_mse: 12.1773 - val_loss: 0.2964 - val_accuracy: 0.8625 - val_mse: 15.4141 - val_weighted_accuracy: 0.8625 - val_weighted_mse: 15.4141
# Epoch 126/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0056 - accuracy: 1.0000 - mse: 11.2789 - weighted_accuracy: 1.0000 - weighted_mse: 12.3547 - val_loss: 0.2932 - val_accuracy: 0.8577 - val_mse: 15.1631 - val_weighted_accuracy: 0.8577 - val_weighted_mse: 15.1631
# Epoch 127/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0054 - accuracy: 1.0000 - mse: 11.4279 - weighted_accuracy: 1.0000 - weighted_mse: 12.5728 - val_loss: 0.2876 - val_accuracy: 0.8564 - val_mse: 14.8127 - val_weighted_accuracy: 0.8564 - val_weighted_mse: 14.8127
# Epoch 128/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0053 - accuracy: 1.0000 - mse: 11.5585 - weighted_accuracy: 1.0000 - weighted_mse: 12.7375 - val_loss: 0.2753 - val_accuracy: 0.8406 - val_mse: 13.4640 - val_weighted_accuracy: 0.8406 - val_weighted_mse: 13.4640
# Epoch 129/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0054 - accuracy: 0.9997 - mse: 11.7350 - weighted_accuracy: 0.9999 - weighted_mse: 12.8596 - val_loss: 0.2638 - val_accuracy: 0.8285 - val_mse: 12.3427 - val_weighted_accuracy: 0.8285 - val_weighted_mse: 12.3427
# Epoch 130/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0053 - accuracy: 0.9997 - mse: 11.8560 - weighted_accuracy: 0.9999 - weighted_mse: 12.9552 - val_loss: 0.2648 - val_accuracy: 0.8333 - val_mse: 12.9749 - val_weighted_accuracy: 0.8333 - val_weighted_mse: 12.9749
# Epoch 131/200
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0052 - accuracy: 1.0000 - mse: 11.9964 - weighted_accuracy: 1.0000 - weighted_mse: 13.1788 - val_loss: 0.2605 - val_accuracy: 0.8394 - val_mse: 13.1944 - val_weighted_accuracy: 0.8394 - val_weighted_mse: 13.1944
# Epoch 132/200
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0051 - accuracy: 1.0000 - mse: 12.1637 - weighted_accuracy: 1.0000 - weighted_mse: 13.3649 - val_loss: 0.2865 - val_accuracy: 0.8577 - val_mse: 14.6481 - val_weighted_accuracy: 0.8577 - val_weighted_mse: 14.6481
# Epoch 133/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0051 - accuracy: 1.0000 - mse: 12.3088 - weighted_accuracy: 1.0000 - weighted_mse: 13.4973 - val_loss: 0.2771 - val_accuracy: 0.8625 - val_mse: 14.2762 - val_weighted_accuracy: 0.8625 - val_weighted_mse: 14.2762
# Epoch 134/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0051 - accuracy: 1.0000 - mse: 12.4436 - weighted_accuracy: 1.0000 - weighted_mse: 13.5871 - val_loss: 0.2689 - val_accuracy: 0.8516 - val_mse: 13.7193 - val_weighted_accuracy: 0.8516 - val_weighted_mse: 13.7193
# Epoch 135/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0051 - accuracy: 1.0000 - mse: 12.5659 - weighted_accuracy: 1.0000 - weighted_mse: 13.7135 - val_loss: 0.3060 - val_accuracy: 0.8224 - val_mse: 12.5364 - val_weighted_accuracy: 0.8224 - val_weighted_mse: 12.5364
# Epoch 136/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0051 - accuracy: 1.0000 - mse: 12.6907 - weighted_accuracy: 1.0000 - weighted_mse: 13.7740 - val_loss: 0.2836 - val_accuracy: 0.8418 - val_mse: 13.8130 - val_weighted_accuracy: 0.8418 - val_weighted_mse: 13.8130
# Epoch 137/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 12.8467 - weighted_accuracy: 1.0000 - weighted_mse: 13.9955 - val_loss: 0.2917 - val_accuracy: 0.8333 - val_mse: 14.2338 - val_weighted_accuracy: 0.8333 - val_weighted_mse: 14.2338
# Epoch 138/200
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0049 - accuracy: 0.9997 - mse: 12.9768 - weighted_accuracy: 0.9999 - weighted_mse: 14.1832 - val_loss: 0.2849 - val_accuracy: 0.8564 - val_mse: 15.1740 - val_weighted_accuracy: 0.8564 - val_weighted_mse: 15.1740
# Epoch 139/200
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 13.0839 - weighted_accuracy: 1.0000 - weighted_mse: 14.2583 - val_loss: 0.2821 - val_accuracy: 0.8394 - val_mse: 14.4806 - val_weighted_accuracy: 0.8394 - val_weighted_mse: 14.4806
# Epoch 140/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 13.1946 - weighted_accuracy: 1.0000 - weighted_mse: 14.4740 - val_loss: 0.2995 - val_accuracy: 0.8041 - val_mse: 12.6257 - val_weighted_accuracy: 0.8041 - val_weighted_mse: 12.6257
# Epoch 141/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 13.3334 - weighted_accuracy: 1.0000 - weighted_mse: 14.5448 - val_loss: 0.2837 - val_accuracy: 0.8528 - val_mse: 14.2456 - val_weighted_accuracy: 0.8528 - val_weighted_mse: 14.2456
# Epoch 142/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 13.4331 - weighted_accuracy: 1.0000 - weighted_mse: 14.6665 - val_loss: 0.2802 - val_accuracy: 0.8504 - val_mse: 14.0086 - val_weighted_accuracy: 0.8504 - val_weighted_mse: 14.0086
# Epoch 143/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 13.5742 - weighted_accuracy: 1.0000 - weighted_mse: 14.7201 - val_loss: 0.2880 - val_accuracy: 0.8382 - val_mse: 13.7542 - val_weighted_accuracy: 0.8382 - val_weighted_mse: 13.7542
# Epoch 144/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 13.6355 - weighted_accuracy: 1.0000 - weighted_mse: 14.9932 - val_loss: 0.3089 - val_accuracy: 0.8516 - val_mse: 15.1347 - val_weighted_accuracy: 0.8516 - val_weighted_mse: 15.1347
# Epoch 145/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 13.7493 - weighted_accuracy: 1.0000 - weighted_mse: 15.0290 - val_loss: 0.3072 - val_accuracy: 0.8540 - val_mse: 16.0189 - val_weighted_accuracy: 0.8540 - val_weighted_mse: 16.0189
# Epoch 146/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 13.9004 - weighted_accuracy: 1.0000 - weighted_mse: 15.0659 - val_loss: 0.2951 - val_accuracy: 0.8516 - val_mse: 15.5475 - val_weighted_accuracy: 0.8516 - val_weighted_mse: 15.5475
# Epoch 147/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 13.9838 - weighted_accuracy: 1.0000 - weighted_mse: 15.1924 - val_loss: 0.3019 - val_accuracy: 0.8443 - val_mse: 15.0664 - val_weighted_accuracy: 0.8443 - val_weighted_mse: 15.0664
# Epoch 148/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 14.0933 - weighted_accuracy: 1.0000 - weighted_mse: 15.1332 - val_loss: 0.2977 - val_accuracy: 0.8431 - val_mse: 14.8686 - val_weighted_accuracy: 0.8431 - val_weighted_mse: 14.8686
# Epoch 149/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 14.1916 - weighted_accuracy: 1.0000 - weighted_mse: 15.5675 - val_loss: 0.2954 - val_accuracy: 0.8674 - val_mse: 15.6770 - val_weighted_accuracy: 0.8674 - val_weighted_mse: 15.6770
# Epoch 150/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 14.3266 - weighted_accuracy: 1.0000 - weighted_mse: 15.4688 - val_loss: 0.3002 - val_accuracy: 0.8601 - val_mse: 15.4310 - val_weighted_accuracy: 0.8601 - val_weighted_mse: 15.4310
# Epoch 151/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 14.4811 - weighted_accuracy: 1.0000 - weighted_mse: 15.5762 - val_loss: 0.3060 - val_accuracy: 0.8723 - val_mse: 16.3916 - val_weighted_accuracy: 0.8723 - val_weighted_mse: 16.3916
# Epoch 152/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 14.4923 - weighted_accuracy: 1.0000 - weighted_mse: 15.5782 - val_loss: 0.2948 - val_accuracy: 0.8285 - val_mse: 13.7597 - val_weighted_accuracy: 0.8285 - val_weighted_mse: 13.7597
# Epoch 153/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 14.6427 - weighted_accuracy: 1.0000 - weighted_mse: 15.7007 - val_loss: 0.3209 - val_accuracy: 0.8710 - val_mse: 19.0296 - val_weighted_accuracy: 0.8710 - val_weighted_mse: 19.0296
# Epoch 154/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 14.6896 - weighted_accuracy: 1.0000 - weighted_mse: 15.8881 - val_loss: 0.3295 - val_accuracy: 0.8260 - val_mse: 16.6594 - val_weighted_accuracy: 0.8260 - val_weighted_mse: 16.6594
# Epoch 155/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 14.7966 - weighted_accuracy: 1.0000 - weighted_mse: 16.0437 - val_loss: 0.3058 - val_accuracy: 0.8297 - val_mse: 15.2904 - val_weighted_accuracy: 0.8297 - val_weighted_mse: 15.2904
# Epoch 156/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 14.9435 - weighted_accuracy: 1.0000 - weighted_mse: 16.1741 - val_loss: 0.2980 - val_accuracy: 0.8431 - val_mse: 15.0706 - val_weighted_accuracy: 0.8431 - val_weighted_mse: 15.0706
# Epoch 157/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 15.0487 - weighted_accuracy: 1.0000 - weighted_mse: 16.1395 - val_loss: 0.2897 - val_accuracy: 0.8552 - val_mse: 15.0601 - val_weighted_accuracy: 0.8552 - val_weighted_mse: 15.0601
# Epoch 158/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 15.1254 - weighted_accuracy: 1.0000 - weighted_mse: 16.4359 - val_loss: 0.2902 - val_accuracy: 0.8504 - val_mse: 15.1417 - val_weighted_accuracy: 0.8504 - val_weighted_mse: 15.1417
# Epoch 159/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 15.2234 - weighted_accuracy: 1.0000 - weighted_mse: 16.4540 - val_loss: 0.2987 - val_accuracy: 0.8589 - val_mse: 15.9703 - val_weighted_accuracy: 0.8589 - val_weighted_mse: 15.9703
# Epoch 160/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 15.3204 - weighted_accuracy: 1.0000 - weighted_mse: 16.3601 - val_loss: 0.3014 - val_accuracy: 0.8467 - val_mse: 15.0307 - val_weighted_accuracy: 0.8467 - val_weighted_mse: 15.0307
# Epoch 161/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 15.4360 - weighted_accuracy: 1.0000 - weighted_mse: 16.6391 - val_loss: 0.2935 - val_accuracy: 0.8345 - val_mse: 14.2007 - val_weighted_accuracy: 0.8345 - val_weighted_mse: 14.2007
# Epoch 162/200
# 26/26 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000 - mse: 15.5321 - weighted_accuracy: 1.0000 - weighted_mse: 16.782 - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 15.5258 - weighted_accuracy: 1.0000 - weighted_mse: 16.7425 - val_loss: 0.3061 - val_accuracy: 0.8163 - val_mse: 14.6003 - val_weighted_accuracy: 0.8163 - val_weighted_mse: 14.6003
# Epoch 163/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 15.6454 - weighted_accuracy: 1.0000 - weighted_mse: 16.9186 - val_loss: 0.2955 - val_accuracy: 0.8382 - val_mse: 14.8316 - val_weighted_accuracy: 0.8382 - val_weighted_mse: 14.8316
# Epoch 164/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 15.7252 - weighted_accuracy: 1.0000 - weighted_mse: 16.9089 - val_loss: 0.3091 - val_accuracy: 0.8309 - val_mse: 15.1144 - val_weighted_accuracy: 0.8309 - val_weighted_mse: 15.1144
# Epoch 165/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 15.8603 - weighted_accuracy: 1.0000 - weighted_mse: 17.1309 - val_loss: 0.3118 - val_accuracy: 0.8540 - val_mse: 16.1875 - val_weighted_accuracy: 0.8540 - val_weighted_mse: 16.1875
# Epoch 166/200
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 15.9127 - weighted_accuracy: 1.0000 - weighted_mse: 17.1056 - val_loss: 0.3118 - val_accuracy: 0.8345 - val_mse: 15.6247 - val_weighted_accuracy: 0.8345 - val_weighted_mse: 15.6247
# Epoch 167/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 16.0321 - weighted_accuracy: 1.0000 - weighted_mse: 17.2337 - val_loss: 0.3199 - val_accuracy: 0.8479 - val_mse: 16.7543 - val_weighted_accuracy: 0.8479 - val_weighted_mse: 16.7543
# Epoch 168/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 16.1343 - weighted_accuracy: 1.0000 - weighted_mse: 17.3894 - val_loss: 0.3182 - val_accuracy: 0.8479 - val_mse: 16.6813 - val_weighted_accuracy: 0.8479 - val_weighted_mse: 16.6813
# Epoch 169/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 16.2058 - weighted_accuracy: 1.0000 - weighted_mse: 17.2908 - val_loss: 0.3105 - val_accuracy: 0.8674 - val_mse: 17.1757 - val_weighted_accuracy: 0.8674 - val_weighted_mse: 17.1757
# Epoch 170/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 16.2843 - weighted_accuracy: 1.0000 - weighted_mse: 17.4047 - val_loss: 0.3138 - val_accuracy: 0.8443 - val_mse: 16.0800 - val_weighted_accuracy: 0.8443 - val_weighted_mse: 16.0800
# Epoch 171/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 16.3594 - weighted_accuracy: 1.0000 - weighted_mse: 17.5909 - val_loss: 0.3216 - val_accuracy: 0.8528 - val_mse: 17.1419 - val_weighted_accuracy: 0.8528 - val_weighted_mse: 17.1419
# Epoch 172/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 16.4694 - weighted_accuracy: 1.0000 - weighted_mse: 17.7629 - val_loss: 0.3291 - val_accuracy: 0.8479 - val_mse: 17.3888 - val_weighted_accuracy: 0.8479 - val_weighted_mse: 17.3888
# Epoch 173/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 16.5781 - weighted_accuracy: 1.0000 - weighted_mse: 17.8478 - val_loss: 0.3251 - val_accuracy: 0.8528 - val_mse: 17.7562 - val_weighted_accuracy: 0.8528 - val_weighted_mse: 17.7562
# Epoch 174/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 16.6613 - weighted_accuracy: 1.0000 - weighted_mse: 17.9242 - val_loss: 0.3201 - val_accuracy: 0.8637 - val_mse: 17.7856 - val_weighted_accuracy: 0.8637 - val_weighted_mse: 17.7856
# Epoch 175/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 16.7057 - weighted_accuracy: 1.0000 - weighted_mse: 17.9345 - val_loss: 0.3096 - val_accuracy: 0.8516 - val_mse: 15.9828 - val_weighted_accuracy: 0.8516 - val_weighted_mse: 15.9828
# Epoch 176/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 16.8075 - weighted_accuracy: 1.0000 - weighted_mse: 18.2458 - val_loss: 0.3257 - val_accuracy: 0.8431 - val_mse: 16.1844 - val_weighted_accuracy: 0.8431 - val_weighted_mse: 16.1844
# Epoch 177/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 16.9003 - weighted_accuracy: 1.0000 - weighted_mse: 18.0581 - val_loss: 0.3197 - val_accuracy: 0.8455 - val_mse: 16.7956 - val_weighted_accuracy: 0.8455 - val_weighted_mse: 16.7956
# Epoch 178/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 16.9646 - weighted_accuracy: 1.0000 - weighted_mse: 17.9970 - val_loss: 0.3218 - val_accuracy: 0.8491 - val_mse: 16.3943 - val_weighted_accuracy: 0.8491 - val_weighted_mse: 16.3943
# Epoch 179/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 17.0277 - weighted_accuracy: 1.0000 - weighted_mse: 18.3719 - val_loss: 0.3161 - val_accuracy: 0.8601 - val_mse: 16.4829 - val_weighted_accuracy: 0.8601 - val_weighted_mse: 16.4829
# Epoch 180/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 17.1595 - weighted_accuracy: 1.0000 - weighted_mse: 18.4536 - val_loss: 0.3247 - val_accuracy: 0.8443 - val_mse: 16.4064 - val_weighted_accuracy: 0.8443 - val_weighted_mse: 16.4064
# Epoch 181/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 17.2661 - weighted_accuracy: 1.0000 - weighted_mse: 18.5195 - val_loss: 0.3223 - val_accuracy: 0.8589 - val_mse: 17.3681 - val_weighted_accuracy: 0.8589 - val_weighted_mse: 17.3681
# Epoch 182/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 17.3323 - weighted_accuracy: 1.0000 - weighted_mse: 18.5890 - val_loss: 0.3252 - val_accuracy: 0.8491 - val_mse: 16.8223 - val_weighted_accuracy: 0.8491 - val_weighted_mse: 16.8223
# Epoch 183/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 17.3325 - weighted_accuracy: 1.0000 - weighted_mse: 18.4023 - val_loss: 0.3230 - val_accuracy: 0.8601 - val_mse: 17.4788 - val_weighted_accuracy: 0.8601 - val_weighted_mse: 17.4788
# Epoch 184/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 17.4693 - weighted_accuracy: 1.0000 - weighted_mse: 18.7844 - val_loss: 0.3321 - val_accuracy: 0.8613 - val_mse: 18.8686 - val_weighted_accuracy: 0.8613 - val_weighted_mse: 18.8686
# Epoch 185/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 17.6388 - weighted_accuracy: 1.0000 - weighted_mse: 18.7839 - val_loss: 0.3253 - val_accuracy: 0.8479 - val_mse: 17.3934 - val_weighted_accuracy: 0.8479 - val_weighted_mse: 17.3934
# Epoch 186/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 17.7081 - weighted_accuracy: 1.0000 - weighted_mse: 18.7939 - val_loss: 0.3272 - val_accuracy: 0.8552 - val_mse: 17.7963 - val_weighted_accuracy: 0.8552 - val_weighted_mse: 17.7963
# Epoch 187/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 17.7602 - weighted_accuracy: 1.0000 - weighted_mse: 18.6675 - val_loss: 0.3292 - val_accuracy: 0.8552 - val_mse: 17.4423 - val_weighted_accuracy: 0.8552 - val_weighted_mse: 17.4423
# Epoch 188/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 17.7764 - weighted_accuracy: 1.0000 - weighted_mse: 18.9765 - val_loss: 0.3429 - val_accuracy: 0.8358 - val_mse: 17.4284 - val_weighted_accuracy: 0.8358 - val_weighted_mse: 17.4284
# Epoch 189/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 17.8554 - weighted_accuracy: 1.0000 - weighted_mse: 19.2130 - val_loss: 0.3333 - val_accuracy: 0.8297 - val_mse: 16.2032 - val_weighted_accuracy: 0.8297 - val_weighted_mse: 16.2032
# Epoch 190/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 17.9399 - weighted_accuracy: 1.0000 - weighted_mse: 19.3473 - val_loss: 0.3283 - val_accuracy: 0.8285 - val_mse: 16.3847 - val_weighted_accuracy: 0.8285 - val_weighted_mse: 16.3847
# Epoch 191/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 18.0470 - weighted_accuracy: 1.0000 - weighted_mse: 19.3716 - val_loss: 0.3313 - val_accuracy: 0.8467 - val_mse: 17.8673 - val_weighted_accuracy: 0.8467 - val_weighted_mse: 17.8673
# Epoch 192/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 18.1379 - weighted_accuracy: 1.0000 - weighted_mse: 19.3492 - val_loss: 0.3344 - val_accuracy: 0.8613 - val_mse: 18.2675 - val_weighted_accuracy: 0.8613 - val_weighted_mse: 18.2675
# Epoch 193/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 18.2458 - weighted_accuracy: 1.0000 - weighted_mse: 19.4693 - val_loss: 0.3348 - val_accuracy: 0.8467 - val_mse: 18.2664 - val_weighted_accuracy: 0.8467 - val_weighted_mse: 18.2664
# Epoch 194/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 18.2863 - weighted_accuracy: 1.0000 - weighted_mse: 19.5740 - val_loss: 0.3276 - val_accuracy: 0.8443 - val_mse: 17.3352 - val_weighted_accuracy: 0.8443 - val_weighted_mse: 17.3352
# Epoch 195/200
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 18.3748 - weighted_accuracy: 1.0000 - weighted_mse: 19.5340 - val_loss: 0.3362 - val_accuracy: 0.8552 - val_mse: 18.1609 - val_weighted_accuracy: 0.8552 - val_weighted_mse: 18.1609
# Epoch 196/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 18.4176 - weighted_accuracy: 1.0000 - weighted_mse: 19.6976 - val_loss: 0.3365 - val_accuracy: 0.8552 - val_mse: 18.3029 - val_weighted_accuracy: 0.8552 - val_weighted_mse: 18.3029
# Epoch 197/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 18.4803 - weighted_accuracy: 1.0000 - weighted_mse: 19.6312 - val_loss: 0.3369 - val_accuracy: 0.8589 - val_mse: 18.3568 - val_weighted_accuracy: 0.8589 - val_weighted_mse: 18.3568
# Epoch 198/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 18.6070 - weighted_accuracy: 1.0000 - weighted_mse: 20.0391 - val_loss: 0.3351 - val_accuracy: 0.8637 - val_mse: 18.9655 - val_weighted_accuracy: 0.8637 - val_weighted_mse: 18.9655
# Epoch 199/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 18.6686 - weighted_accuracy: 1.0000 - weighted_mse: 19.7366 - val_loss: 0.3350 - val_accuracy: 0.8662 - val_mse: 19.0293 - val_weighted_accuracy: 0.8662 - val_weighted_mse: 19.0293
# Epoch 200/200
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 18.7562 - weighted_accuracy: 1.0000 - weighted_mse: 20.0817 - val_loss: 0.3436 - val_accuracy: 0.8321 - val_mse: 17.6910 - val_weighted_accuracy: 0.8321 - val_weighted_mse: 17.6910

# %%
# Score model
score = model.evaluate(validation_x, validation_y, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.34357213973999023
# Test accuracy: 0.8321167826652527

# %%
predictions = model.predict(validation_x)
print(predictions)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
from collections import Counter

Counter(predictions)
# Out:
# [[-2.0834374  -6.926262    1.9293512 ]
#  [-3.1515431  -6.2800074   2.7338202 ]
#  [-4.5597243  -7.321776    4.9958544 ]
#  ...
#  [-1.1427779  -4.405236    0.36017486]
#  [-4.059888   -6.125905    3.7902026 ]
#  [-6.005215   -5.803027    5.747685  ]]
# Counter({2: 749, 0: 50, 1: 23})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in validation_y]
Counter(actual)
# Out:
# Counter({2: 748, 1: 37, 0: 37})

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold))
# Out:
# number of predictions: 822
# actual predicted buys: 2
# actual buys but predicted sell: 1
# actual buys but predicted hold: 34
# actual sells but predicted buy: 0
# actual predicted sells: 2
# actual sells but predicted hold: 35
# actual holds but predicted buy: 21
# actual holds but predicted sell: 47
# actual predicted holds: 680
# Percentage buys correct: 5.405405405405405%
# Percentage sells correct: 5.405405405405405%
# Percentage holds correct: 90.9090909090909%
# actual buys: 37
# actual sells: 37
# actual holds: 748

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.figure(figsize=(20,10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Save model
model.save("models/{}".format('moutai_image_lstm_buy_hold_sell_original.model'))
# Out:
# WARNING:tensorflow:From C:\Users\Shearman Chua\anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\Shearman Chua\anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: models/moutai_image_lstm_buy_hold_sell_original.model\assets

# %% [markdown]
# ### Test Performance

# %% [markdown]
# ### non-recession

# %%
seed = 10
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/600519.SS_data_test.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22   686.979980  640.790403 -10.183147  35030093.0     2.0
# 2019-01-23   671.000000  645.438034 -23.857615  30817872.0     2.0
# 2019-01-24   665.659973  648.549101 -28.427209  27455391.0     2.0
# 2019-01-25   672.500000  652.233855 -26.754575  30370918.0     2.0
# 2019-01-28   679.700012  656.459418 -19.452330  33269553.0     2.0

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1

# %%
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/moutai_image_lstm_buy_hold_sell_original.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4092 - accuracy: 0.8309 - mean_squared_error: 17.8197 - weighted_accuracy: 0.8309 - weighted_mean_squared_error: 17.8197
# Test loss: 0.40915825963020325
# Test accuracy: 0.8309178948402405

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 184, 1: 10, 0: 13})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]
Counter(actual)
# Out:
# Counter({2: 185, 0: 11, 1: 11})

# %%
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/600519.SS_data_test.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d      EMA_12   willr_14       OBV_7  labels  \
# Date
# 2019-02-18    740.00000  704.389763 -23.444619  43919901.0     2.0
# 2019-02-19    730.76001  709.868261  -6.049880  47694490.0     2.0
# 2019-02-20    722.00000  713.082376 -17.677836  44744340.0     2.0
# 2019-02-21    720.25000  714.454318 -29.824573  40956103.0     2.0
# 2019-02-22    726.01001  715.345962 -32.098776  37971063.0     2.0
#
#             predictions  actual
# Date
# 2019-02-18            2       2
# 2019-02-19            2       2
# 2019-02-20            2       2
# 2019-02-21            1       2
# 2019-02-22            2       2

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold))
# Out:
# number of predictions: 207
# actual predicted buys: 3
# actual buys but predicted sell: 0
# actual buys but predicted hold: 8
# actual sells but predicted buy: 0
# actual predicted sells: 2
# actual sells but predicted hold: 9
# actual holds but predicted buy: 7
# actual holds but predicted sell: 11
# actual predicted holds: 167
# Percentage buys correct: 27.272727272727273%
# Percentage sells correct: 18.181818181818183%
# Percentage holds correct: 90.27027027027027%
# actual buys: 11
# actual sells: 11
# actual holds: 185

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%")
# Out:
# [720.25, 722.0, 726.010009765625, 727.3499755859375, 730.760009765625, 740.0, 740.7000122070312, 742.3300170898438, 755.010009765625]
# [727.3499755859375, 737.5, 740.7000122070312, 748.5999755859375, 755.010009765625, 768.0, 779.780029296875, 781.8599853515625, 789.2999877929688]
# Percentage buys correct: 50.0%
# Percentage sells correct: 69.23076923076923%
# Percentage holds correct: 86.88524590163935%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $720.25
# Shares owned at the moment: 13
# Cash capital at the moment: $611.0010624999995
#
#
# Price increase from previously bought: 12.164996707574648%
# Share price: $810.0900268554688
# Shares owned at the moment: 0
# Cash capital at the moment: $11113.21069316101
#
#
# Share price: $806.7999877929688
# Shares owned at the moment: 13
# Cash capital at the moment: $595.9677522888178
#
#
# Price increase from previously bought: 6.17801702195846%
# Share price: $859.0
# Shares owned at the moment: 0
# Cash capital at the moment: $11732.258502288818
#
#
# Share price: $858.8099975585938
# Shares owned at the moment: 13
# Cash capital at the moment: $537.0260766143783
#
#
# Price increase from previously bought: 5.297230697247479%
# Share price: $906.7899780273438
# Shares owned at the moment: 0
# Cash capital at the moment: $12292.878049255369
#
#
# Share price: $910.8900146484376
# Shares owned at the moment: 13
# Cash capital at the moment: $418.74354080199737
#
#
# Price increase from previously bought: 12.2187052076405%
# Share price: $1025.0
# Shares owned at the moment: 0
# Cash capital at the moment: $13707.099790801996
#
#
# Share price: $984.8599853515624
# Shares owned at the moment: 13
# Cash capital at the moment: $868.7112367553673
#
#
# Stop Loss Activated!
#
# Share price: $947.5
# Shares owned at the moment: 0
# Cash capital at the moment: $13152.338111755367
#
#
# Share price: $946.3599853515624
# Shares owned at the moment: 13
# Cash capital at the moment: $815.825932708738
#
#
# Price increase from previously bought: 18.55158017671863%
# Share price: $1125.010009765625
# Shares owned at the moment: 0
# Cash capital at the moment: $15400.736951812742
#
#
#
#
# Capital at the end of test period: $15400.736951812742
# profit gained: 54.00736951812741%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $15358.36826651001
# profit gained: 53.5836826651001%

# %% [markdown]
# ### Recession

# %%
seed = 10
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/600519.SS_data_test2.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d       EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22  1075.300049  1097.577291 -89.711935   1200864.0     2.0
# 2020-01-23  1075.510010  1094.182325 -70.779503   4820868.0     2.0
# 2020-02-03  1052.800049  1087.815821 -81.895216   -525975.0     1.0
# 2020-02-04  1003.919983  1074.908769 -83.419991 -12870263.0     2.0
# 2020-02-05  1038.010010  1069.232037 -59.790669  -6607845.0     2.0

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1

# %%
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/moutai_image_lstm_buy_hold_sell_original.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2613 - accuracy: 0.8654 - mean_squared_error: 18.2474 - weighted_accuracy: 0.8654 - weighted_mean_squared_error: 18.2474
# Test loss: 0.26130568981170654
# Test accuracy: 0.8653846383094788

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 196, 0: 8, 1: 4})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]

# %%
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/600519.SS_data_test2.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d       EMA_12   willr_14      OBV_7  labels  \
# Date
# 2020-02-19  1096.500000  1082.513705 -22.324305  -423291.0     2.0
# 2020-02-20  1118.000000  1084.665443 -12.988283  3281856.0     0.0
# 2020-02-21  1112.880005  1089.793836  -4.166667  7962118.0     2.0
# 2020-02-24  1087.180054  1093.345554 -10.201830  5068110.0     2.0
# 2020-02-25  1074.810059  1092.397016 -40.474836  1203074.0     2.0
#
#             predictions  actual
# Date
# 2020-02-19            2       2
# 2020-02-20            2       0
# 2020-02-21            2       2
# 2020-02-24            2       2
# 2020-02-25            2       2

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold))
# Out:
# number of predictions: 208
# actual predicted buys: 1
# actual buys but predicted sell: 1
# actual buys but predicted hold: 7
# actual sells but predicted buy: 0
# actual predicted sells: 0
# actual sells but predicted hold: 10
# actual holds but predicted buy: 3
# actual holds but predicted sell: 7
# actual predicted holds: 179
# Percentage buys correct: 11.11111111111111%
# Percentage sells correct: 0.0%
# Percentage holds correct: 94.70899470899471%
# actual buys: 9
# actual sells: 10
# actual holds: 189

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%")
# Out:
# [1057.0, 1073.699951171875, 1074.81005859375, 1086.010009765625, 1087.1800537109377, 1087.3900146484377, 1096.5, 1112.8800048828123, 1118.0]
# [1057.0, 1086.010009765625, 1087.3900146484377, 1113.0, 1114.010009765625, 1128.9200439453125, 1155.5, 1156.0, 1171.0]
# Percentage buys correct: 50.0%
# Percentage sells correct: 62.5%
# Percentage holds correct: 85.64102564102564%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $1405.0
# Shares owned at the moment: 7
# Cash capital at the moment: $137.95375000000058
#
#
# Price increase from previously bought: 18.67719642868233%
# Share price: $1672.0
# Shares owned at the moment: 0
# Cash capital at the moment: $11809.76775
#
#
# Share price: $1661.0
# Shares owned at the moment: 7
# Cash capital at the moment: $150.79349999999977
#
#
# Price increase from previously bought: 10.77303820273896%
# Share price: $1845.0
# Shares owned at the moment: 0
# Cash capital at the moment: $13030.27725
#
#
#
#
# Capital at the end of test period: $13030.27725
# profit gained: 30.302772499999993%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $16641.259749999997
# profit gained: 66.41259749999998%

# %% [markdown]
# ## Midea Group

# %%
seed = 10
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/000333.SZ_data.csv")
print(df.head())
# Out:
#          Date  previous_1d     EMA_12   willr_14        OBV_7  labels
# 0  2013-10-17    11.912000  11.900182 -34.022038  235647532.0     1.0
# 1  2013-10-18    11.896000  11.899539 -39.103542  214825024.0     2.0
# 2  2013-10-21    12.269333  11.956430 -24.093825  253903732.0     2.0
# 3  2013-10-22    12.760000  12.080056  -4.424713  304775737.0     2.0
# 4  2013-10-23    12.645333  12.167022 -15.187657  273970459.0     2.0

# %%
df.set_index('Date', inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2013-10-17    11.912000  11.900182 -34.022038  235647532.0     1.0
# 2013-10-18    11.896000  11.899539 -39.103542  214825024.0     2.0
# 2013-10-21    12.269333  11.956430 -24.093825  253903732.0     2.0
# 2013-10-22    12.760000  12.080056  -4.424713  304775737.0     2.0
# 2013-10-23    12.645333  12.167022 -15.187657  273970459.0     2.0

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1

# %%
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64)
y = np.array(y)

X.shape
# Out:
# (1253, 64, 64)

# %%
# plot the image array X
i = X[0].reshape(64, 64)
fig2, ax2 = plt.subplots()
plt.imshow(i, interpolation="none", cmap="gray")

ax2.axis('off')

plt.show()

# %%
X = X/255

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization,Activation
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(LSTM(100, input_shape=(X_train.shape[1:]), return_sequences=True,kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(LSTM(100, kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# model.add(Dense(100, kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))

model.add(Dense(75, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(50, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa
opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

#tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "LSTM_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))

# Train model
history = model.fit(
    train_x, train_y,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    shuffle = True,
    validation_data=(validation_x, validation_y),
    #callbacks=[tensorboard],
    class_weight=d_class_weights
)
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 2 ... 2 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# Epoch 1/200
# 8/8 [==============================] - 1s 110ms/step - loss: 0.3291 - accuracy: 0.5449 - mse: 0.3358 - weighted_accuracy: 0.3395 - weighted_mse: 0.4051 - val_loss: 0.2964 - val_accuracy: 0.9084 - val_mse: 0.3037 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 0.3037
# Epoch 2/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.2738 - accuracy: 0.4890 - mse: 0.4099 - weighted_accuracy: 0.4083 - weighted_mse: 0.4434 - val_loss: 0.2943 - val_accuracy: 0.9084 - val_mse: 0.3181 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 0.3181
# Epoch 3/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2458 - accuracy: 0.4202 - mse: 0.4848 - weighted_accuracy: 0.4853 - weighted_mse: 0.4953 - val_loss: 0.2924 - val_accuracy: 0.9084 - val_mse: 0.3301 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 0.3301
# Epoch 4/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2251 - accuracy: 0.4062 - mse: 0.5503 - weighted_accuracy: 0.5222 - weighted_mse: 0.5540 - val_loss: 0.2902 - val_accuracy: 0.9084 - val_mse: 0.3417 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 0.3417
# Epoch 5/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2086 - accuracy: 0.4212 - mse: 0.6117 - weighted_accuracy: 0.5977 - weighted_mse: 0.6030 - val_loss: 0.2880 - val_accuracy: 0.9084 - val_mse: 0.3524 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 0.3524
# Epoch 6/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1972 - accuracy: 0.4281 - mse: 0.6747 - weighted_accuracy: 0.6166 - weighted_mse: 0.6710 - val_loss: 0.2878 - val_accuracy: 0.9084 - val_mse: 0.3624 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 0.3624
# Epoch 7/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1871 - accuracy: 0.4611 - mse: 0.7296 - weighted_accuracy: 0.6362 - weighted_mse: 0.7348 - val_loss: 0.2893 - val_accuracy: 0.0518 - val_mse: 0.3683 - val_weighted_accuracy: 0.0518 - val_weighted_mse: 0.3683
# Epoch 8/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1800 - accuracy: 0.4641 - mse: 0.7874 - weighted_accuracy: 0.6600 - weighted_mse: 0.7885 - val_loss: 0.2906 - val_accuracy: 0.0518 - val_mse: 0.3749 - val_weighted_accuracy: 0.0518 - val_weighted_mse: 0.3749
# Epoch 9/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1740 - accuracy: 0.4701 - mse: 0.8417 - weighted_accuracy: 0.6827 - weighted_mse: 0.8504 - val_loss: 0.2918 - val_accuracy: 0.0518 - val_mse: 0.3828 - val_weighted_accuracy: 0.0518 - val_weighted_mse: 0.3828
# Epoch 10/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1684 - accuracy: 0.4910 - mse: 0.8891 - weighted_accuracy: 0.7108 - weighted_mse: 0.8961 - val_loss: 0.2896 - val_accuracy: 0.0518 - val_mse: 0.3862 - val_weighted_accuracy: 0.0518 - val_weighted_mse: 0.3862
# Epoch 11/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1632 - accuracy: 0.4980 - mse: 0.9299 - weighted_accuracy: 0.7016 - weighted_mse: 0.9427 - val_loss: 0.2843 - val_accuracy: 0.0518 - val_mse: 0.3898 - val_weighted_accuracy: 0.0518 - val_weighted_mse: 0.3898
# Epoch 12/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1579 - accuracy: 0.5000 - mse: 0.9730 - weighted_accuracy: 0.7088 - weighted_mse: 0.9798 - val_loss: 0.2796 - val_accuracy: 0.0518 - val_mse: 0.3932 - val_weighted_accuracy: 0.0518 - val_weighted_mse: 0.3932
# Epoch 13/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1546 - accuracy: 0.4990 - mse: 1.0029 - weighted_accuracy: 0.7149 - weighted_mse: 1.0098 - val_loss: 0.2764 - val_accuracy: 0.0518 - val_mse: 0.3974 - val_weighted_accuracy: 0.0518 - val_weighted_mse: 0.3974
# Epoch 14/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1505 - accuracy: 0.5160 - mse: 1.0378 - weighted_accuracy: 0.7287 - weighted_mse: 1.0468 - val_loss: 0.2724 - val_accuracy: 0.0518 - val_mse: 0.4057 - val_weighted_accuracy: 0.0518 - val_weighted_mse: 0.4057
# Epoch 15/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1474 - accuracy: 0.5110 - mse: 1.0693 - weighted_accuracy: 0.7431 - weighted_mse: 1.0738 - val_loss: 0.2693 - val_accuracy: 0.0598 - val_mse: 0.4143 - val_weighted_accuracy: 0.0598 - val_weighted_mse: 0.4143
# Epoch 16/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1427 - accuracy: 0.5289 - mse: 1.1000 - weighted_accuracy: 0.7550 - weighted_mse: 1.1118 - val_loss: 0.2661 - val_accuracy: 0.2271 - val_mse: 0.4205 - val_weighted_accuracy: 0.2271 - val_weighted_mse: 0.4205
# Epoch 17/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1408 - accuracy: 0.5200 - mse: 1.1265 - weighted_accuracy: 0.7517 - weighted_mse: 1.1305 - val_loss: 0.2651 - val_accuracy: 0.1594 - val_mse: 0.4297 - val_weighted_accuracy: 0.1594 - val_weighted_mse: 0.4297
# Epoch 18/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1372 - accuracy: 0.5539 - mse: 1.1465 - weighted_accuracy: 0.7933 - weighted_mse: 1.1510 - val_loss: 0.2582 - val_accuracy: 0.7410 - val_mse: 0.4398 - val_weighted_accuracy: 0.7410 - val_weighted_mse: 0.4398
# Epoch 19/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1346 - accuracy: 0.5449 - mse: 1.1740 - weighted_accuracy: 0.7847 - weighted_mse: 1.1767 - val_loss: 0.2592 - val_accuracy: 0.5418 - val_mse: 0.4486 - val_weighted_accuracy: 0.5418 - val_weighted_mse: 0.4486
# Epoch 20/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1317 - accuracy: 0.5479 - mse: 1.2014 - weighted_accuracy: 0.7760 - weighted_mse: 1.2055 - val_loss: 0.2547 - val_accuracy: 0.5697 - val_mse: 0.4609 - val_weighted_accuracy: 0.5697 - val_weighted_mse: 0.4609
# Epoch 21/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1279 - accuracy: 0.5699 - mse: 1.2057 - weighted_accuracy: 0.8143 - weighted_mse: 1.2138 - val_loss: 0.2550 - val_accuracy: 0.7171 - val_mse: 0.4594 - val_weighted_accuracy: 0.7171 - val_weighted_mse: 0.4594
# Epoch 22/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1244 - accuracy: 0.5808 - mse: 1.2228 - weighted_accuracy: 0.8323 - weighted_mse: 1.2327 - val_loss: 0.2482 - val_accuracy: 0.8606 - val_mse: 0.4712 - val_weighted_accuracy: 0.8606 - val_weighted_mse: 0.4712
# Epoch 23/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1220 - accuracy: 0.5988 - mse: 1.2340 - weighted_accuracy: 0.8313 - weighted_mse: 1.2494 - val_loss: 0.2455 - val_accuracy: 0.8446 - val_mse: 0.4829 - val_weighted_accuracy: 0.8446 - val_weighted_mse: 0.4829
# Epoch 24/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1201 - accuracy: 0.6148 - mse: 1.2488 - weighted_accuracy: 0.8372 - weighted_mse: 1.2643 - val_loss: 0.2449 - val_accuracy: 0.7410 - val_mse: 0.4853 - val_weighted_accuracy: 0.7410 - val_weighted_mse: 0.4853
# Epoch 25/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1174 - accuracy: 0.5958 - mse: 1.2716 - weighted_accuracy: 0.8302 - weighted_mse: 1.2775 - val_loss: 0.2415 - val_accuracy: 0.4821 - val_mse: 0.5005 - val_weighted_accuracy: 0.4821 - val_weighted_mse: 0.5005
# Epoch 26/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1146 - accuracy: 0.6128 - mse: 1.2855 - weighted_accuracy: 0.8365 - weighted_mse: 1.3031 - val_loss: 0.2344 - val_accuracy: 0.7888 - val_mse: 0.5149 - val_weighted_accuracy: 0.7888 - val_weighted_mse: 0.5149
# Epoch 27/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1121 - accuracy: 0.6248 - mse: 1.2994 - weighted_accuracy: 0.8408 - weighted_mse: 1.3282 - val_loss: 0.2313 - val_accuracy: 0.8486 - val_mse: 0.5232 - val_weighted_accuracy: 0.8486 - val_weighted_mse: 0.5232
# Epoch 28/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1098 - accuracy: 0.6437 - mse: 1.3120 - weighted_accuracy: 0.8478 - weighted_mse: 1.3375 - val_loss: 0.2272 - val_accuracy: 0.8606 - val_mse: 0.5240 - val_weighted_accuracy: 0.8606 - val_weighted_mse: 0.5240
# Epoch 29/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1073 - accuracy: 0.6747 - mse: 1.3231 - weighted_accuracy: 0.8656 - weighted_mse: 1.3631 - val_loss: 0.2245 - val_accuracy: 0.8725 - val_mse: 0.5319 - val_weighted_accuracy: 0.8725 - val_weighted_mse: 0.5319
# Epoch 30/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1051 - accuracy: 0.6707 - mse: 1.3421 - weighted_accuracy: 0.8717 - weighted_mse: 1.3718 - val_loss: 0.2195 - val_accuracy: 0.8805 - val_mse: 0.5499 - val_weighted_accuracy: 0.8805 - val_weighted_mse: 0.5499
# Epoch 31/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1027 - accuracy: 0.6946 - mse: 1.3663 - weighted_accuracy: 0.8880 - weighted_mse: 1.4132 - val_loss: 0.2142 - val_accuracy: 0.8884 - val_mse: 0.5627 - val_weighted_accuracy: 0.8884 - val_weighted_mse: 0.5627
# Epoch 32/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1011 - accuracy: 0.7026 - mse: 1.3751 - weighted_accuracy: 0.8834 - weighted_mse: 1.4208 - val_loss: 0.2079 - val_accuracy: 0.9084 - val_mse: 0.5798 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 0.5798
# Epoch 33/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0979 - accuracy: 0.7086 - mse: 1.4020 - weighted_accuracy: 0.8932 - weighted_mse: 1.4580 - val_loss: 0.2010 - val_accuracy: 0.9044 - val_mse: 0.6091 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 0.6091
# Epoch 34/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0954 - accuracy: 0.7126 - mse: 1.4224 - weighted_accuracy: 0.8871 - weighted_mse: 1.4907 - val_loss: 0.2041 - val_accuracy: 0.8526 - val_mse: 0.6092 - val_weighted_accuracy: 0.8526 - val_weighted_mse: 0.6092
# Epoch 35/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0931 - accuracy: 0.7285 - mse: 1.4468 - weighted_accuracy: 0.9005 - weighted_mse: 1.5043 - val_loss: 0.2044 - val_accuracy: 0.8367 - val_mse: 0.6095 - val_weighted_accuracy: 0.8367 - val_weighted_mse: 0.6095
# Epoch 36/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0906 - accuracy: 0.7385 - mse: 1.4648 - weighted_accuracy: 0.9041 - weighted_mse: 1.5483 - val_loss: 0.1897 - val_accuracy: 0.9044 - val_mse: 0.6578 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 0.6578
# Epoch 37/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0876 - accuracy: 0.7515 - mse: 1.4693 - weighted_accuracy: 0.9089 - weighted_mse: 1.5572 - val_loss: 0.1867 - val_accuracy: 0.8845 - val_mse: 0.6505 - val_weighted_accuracy: 0.8845 - val_weighted_mse: 0.6505
# Epoch 38/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0865 - accuracy: 0.7665 - mse: 1.4969 - weighted_accuracy: 0.9144 - weighted_mse: 1.5941 - val_loss: 0.1945 - val_accuracy: 0.8008 - val_mse: 0.6216 - val_weighted_accuracy: 0.8008 - val_weighted_mse: 0.6216
# Epoch 39/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0848 - accuracy: 0.7725 - mse: 1.5180 - weighted_accuracy: 0.9166 - weighted_mse: 1.6324 - val_loss: 0.1772 - val_accuracy: 0.8884 - val_mse: 0.6982 - val_weighted_accuracy: 0.8884 - val_weighted_mse: 0.6982
# Epoch 40/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0816 - accuracy: 0.7864 - mse: 1.5281 - weighted_accuracy: 0.9153 - weighted_mse: 1.6462 - val_loss: 0.1752 - val_accuracy: 0.8884 - val_mse: 0.6754 - val_weighted_accuracy: 0.8884 - val_weighted_mse: 0.6754
# Epoch 41/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0793 - accuracy: 0.7934 - mse: 1.5500 - weighted_accuracy: 0.9243 - weighted_mse: 1.6780 - val_loss: 0.1690 - val_accuracy: 0.9004 - val_mse: 0.7468 - val_weighted_accuracy: 0.9004 - val_weighted_mse: 0.7468
# Epoch 42/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0779 - accuracy: 0.8134 - mse: 1.5700 - weighted_accuracy: 0.9316 - weighted_mse: 1.7050 - val_loss: 0.1711 - val_accuracy: 0.8765 - val_mse: 0.7337 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 0.7337
# Epoch 43/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0759 - accuracy: 0.8154 - mse: 1.5935 - weighted_accuracy: 0.9259 - weighted_mse: 1.7263 - val_loss: 0.1488 - val_accuracy: 0.9044 - val_mse: 0.7693 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 0.7693
# Epoch 44/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0733 - accuracy: 0.8224 - mse: 1.6101 - weighted_accuracy: 0.9349 - weighted_mse: 1.7644 - val_loss: 0.1465 - val_accuracy: 0.9084 - val_mse: 0.6915 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 0.6915
# Epoch 45/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0718 - accuracy: 0.8363 - mse: 1.6319 - weighted_accuracy: 0.9400 - weighted_mse: 1.7856 - val_loss: 0.1547 - val_accuracy: 0.8924 - val_mse: 0.7032 - val_weighted_accuracy: 0.8924 - val_weighted_mse: 0.7032
# Epoch 46/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0700 - accuracy: 0.8403 - mse: 1.6451 - weighted_accuracy: 0.9415 - weighted_mse: 1.8033 - val_loss: 0.1387 - val_accuracy: 0.9084 - val_mse: 0.7595 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 0.7595
# Epoch 47/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0671 - accuracy: 0.8493 - mse: 1.6817 - weighted_accuracy: 0.9447 - weighted_mse: 1.8661 - val_loss: 0.1440 - val_accuracy: 0.8964 - val_mse: 0.7767 - val_weighted_accuracy: 0.8964 - val_weighted_mse: 0.7767
# Epoch 48/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0658 - accuracy: 0.8573 - mse: 1.7239 - weighted_accuracy: 0.9477 - weighted_mse: 1.9148 - val_loss: 0.1399 - val_accuracy: 0.8964 - val_mse: 0.7663 - val_weighted_accuracy: 0.8964 - val_weighted_mse: 0.7663
# Epoch 49/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0648 - accuracy: 0.8503 - mse: 1.7340 - weighted_accuracy: 0.9451 - weighted_mse: 1.9128 - val_loss: 0.1194 - val_accuracy: 0.9044 - val_mse: 0.8889 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 0.8889
# Epoch 50/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0621 - accuracy: 0.8703 - mse: 1.7632 - weighted_accuracy: 0.9524 - weighted_mse: 1.9623 - val_loss: 0.1157 - val_accuracy: 0.9084 - val_mse: 0.8314 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 0.8314
# Epoch 51/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0602 - accuracy: 0.8673 - mse: 1.7846 - weighted_accuracy: 0.9513 - weighted_mse: 1.9912 - val_loss: 0.1103 - val_accuracy: 0.9044 - val_mse: 1.0405 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 1.0405
# Epoch 52/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0568 - accuracy: 0.8832 - mse: 1.8055 - weighted_accuracy: 0.9572 - weighted_mse: 2.0482 - val_loss: 0.1319 - val_accuracy: 0.8964 - val_mse: 0.8636 - val_weighted_accuracy: 0.8964 - val_weighted_mse: 0.8636
# Epoch 53/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0555 - accuracy: 0.8852 - mse: 1.8440 - weighted_accuracy: 0.9579 - weighted_mse: 2.0662 - val_loss: 0.1055 - val_accuracy: 0.9044 - val_mse: 0.9192 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 0.9192
# Epoch 54/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0538 - accuracy: 0.8882 - mse: 1.8849 - weighted_accuracy: 0.9590 - weighted_mse: 2.1247 - val_loss: 0.1086 - val_accuracy: 0.9044 - val_mse: 0.8392 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 0.8392
# Epoch 55/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0515 - accuracy: 0.8992 - mse: 1.9131 - weighted_accuracy: 0.9630 - weighted_mse: 2.1783 - val_loss: 0.0966 - val_accuracy: 0.9084 - val_mse: 1.0104 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 1.0104
# Epoch 56/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0495 - accuracy: 0.9072 - mse: 1.9526 - weighted_accuracy: 0.9660 - weighted_mse: 2.2152 - val_loss: 0.0970 - val_accuracy: 0.9084 - val_mse: 1.1191 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 1.1191
# Epoch 57/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0491 - accuracy: 0.9092 - mse: 1.9752 - weighted_accuracy: 0.9667 - weighted_mse: 2.2173 - val_loss: 0.0941 - val_accuracy: 0.9044 - val_mse: 1.2460 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 1.2460
# Epoch 58/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0474 - accuracy: 0.9092 - mse: 2.0311 - weighted_accuracy: 0.9667 - weighted_mse: 2.2990 - val_loss: 0.0931 - val_accuracy: 0.9084 - val_mse: 1.5715 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 1.5715
# Epoch 59/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0445 - accuracy: 0.9152 - mse: 2.0681 - weighted_accuracy: 0.9689 - weighted_mse: 2.3790 - val_loss: 0.0924 - val_accuracy: 0.9084 - val_mse: 1.3595 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 1.3595
# Epoch 60/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0425 - accuracy: 0.9341 - mse: 2.1018 - weighted_accuracy: 0.9759 - weighted_mse: 2.4005 - val_loss: 0.0999 - val_accuracy: 0.9084 - val_mse: 1.7669 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 1.7669
# Epoch 61/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0407 - accuracy: 0.9351 - mse: 2.1520 - weighted_accuracy: 0.9762 - weighted_mse: 2.4477 - val_loss: 0.1002 - val_accuracy: 0.9084 - val_mse: 2.0022 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 2.0022
# Epoch 62/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0386 - accuracy: 0.9481 - mse: 2.2100 - weighted_accuracy: 0.9810 - weighted_mse: 2.5390 - val_loss: 0.1369 - val_accuracy: 0.9084 - val_mse: 2.9267 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 2.9267
# Epoch 63/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0372 - accuracy: 0.9501 - mse: 2.2541 - weighted_accuracy: 0.9817 - weighted_mse: 2.5816 - val_loss: 0.1168 - val_accuracy: 0.9044 - val_mse: 2.3698 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 2.3698
# Epoch 64/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0364 - accuracy: 0.9571 - mse: 2.3047 - weighted_accuracy: 0.9843 - weighted_mse: 2.6720 - val_loss: 0.1394 - val_accuracy: 0.9084 - val_mse: 3.4613 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 3.4613
# Epoch 65/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0354 - accuracy: 0.9451 - mse: 2.3582 - weighted_accuracy: 0.9799 - weighted_mse: 2.6755 - val_loss: 0.1611 - val_accuracy: 0.9084 - val_mse: 3.5945 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 3.5945
# Epoch 66/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0338 - accuracy: 0.9571 - mse: 2.4237 - weighted_accuracy: 0.9843 - weighted_mse: 2.7730 - val_loss: 0.1751 - val_accuracy: 0.9044 - val_mse: 4.7264 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 4.7264
# Epoch 67/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0313 - accuracy: 0.9641 - mse: 2.4635 - weighted_accuracy: 0.9868 - weighted_mse: 2.8598 - val_loss: 0.1518 - val_accuracy: 0.9084 - val_mse: 3.6777 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 3.6777
# Epoch 68/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0301 - accuracy: 0.9601 - mse: 2.5332 - weighted_accuracy: 0.9854 - weighted_mse: 2.9154 - val_loss: 0.1492 - val_accuracy: 0.9044 - val_mse: 3.8865 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 3.8865
# Epoch 69/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0281 - accuracy: 0.9750 - mse: 2.5815 - weighted_accuracy: 0.9909 - weighted_mse: 3.0009 - val_loss: 0.1667 - val_accuracy: 0.9084 - val_mse: 4.7503 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 4.7503
# Epoch 70/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0279 - accuracy: 0.9741 - mse: 2.6517 - weighted_accuracy: 0.9905 - weighted_mse: 3.0263 - val_loss: 0.1586 - val_accuracy: 0.9004 - val_mse: 4.2631 - val_weighted_accuracy: 0.9004 - val_weighted_mse: 4.2631
# Epoch 71/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0256 - accuracy: 0.9780 - mse: 2.7020 - weighted_accuracy: 0.9920 - weighted_mse: 3.1310 - val_loss: 0.2356 - val_accuracy: 0.9084 - val_mse: 7.2473 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 7.2473
# Epoch 72/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0254 - accuracy: 0.9750 - mse: 2.7832 - weighted_accuracy: 0.9909 - weighted_mse: 3.1877 - val_loss: 0.1846 - val_accuracy: 0.9044 - val_mse: 4.7910 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 4.7910
# Epoch 73/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0236 - accuracy: 0.9790 - mse: 2.8513 - weighted_accuracy: 0.9923 - weighted_mse: 3.2698 - val_loss: 0.1853 - val_accuracy: 0.9084 - val_mse: 5.9791 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 5.9791
# Epoch 74/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0221 - accuracy: 0.9830 - mse: 2.9362 - weighted_accuracy: 0.9938 - weighted_mse: 3.3721 - val_loss: 0.2164 - val_accuracy: 0.9084 - val_mse: 6.3183 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 6.3183
# Epoch 75/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0209 - accuracy: 0.9840 - mse: 2.9957 - weighted_accuracy: 0.9941 - weighted_mse: 3.4328 - val_loss: 0.2525 - val_accuracy: 0.9084 - val_mse: 7.9323 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 7.9323
# Epoch 76/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0199 - accuracy: 0.9830 - mse: 3.0749 - weighted_accuracy: 0.9938 - weighted_mse: 3.5966 - val_loss: 0.2584 - val_accuracy: 0.9084 - val_mse: 8.3688 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 8.3688
# Epoch 77/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0189 - accuracy: 0.9860 - mse: 3.1472 - weighted_accuracy: 0.9949 - weighted_mse: 3.5930 - val_loss: 0.2483 - val_accuracy: 0.9084 - val_mse: 8.0802 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 8.0802
# Epoch 78/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0182 - accuracy: 0.9870 - mse: 3.2190 - weighted_accuracy: 0.9952 - weighted_mse: 3.6970 - val_loss: 0.2544 - val_accuracy: 0.9084 - val_mse: 8.3301 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 8.3301
# Epoch 79/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0172 - accuracy: 0.9890 - mse: 3.3093 - weighted_accuracy: 0.9960 - weighted_mse: 3.7687 - val_loss: 0.2514 - val_accuracy: 0.9084 - val_mse: 7.7661 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 7.7661
# Epoch 80/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0164 - accuracy: 0.9900 - mse: 3.3836 - weighted_accuracy: 0.9963 - weighted_mse: 3.8385 - val_loss: 0.2857 - val_accuracy: 0.9084 - val_mse: 10.4700 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 10.4700
# Epoch 81/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0158 - accuracy: 0.9910 - mse: 3.4717 - weighted_accuracy: 0.9967 - weighted_mse: 3.9424 - val_loss: 0.2789 - val_accuracy: 0.9084 - val_mse: 9.7498 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 9.7498
# Epoch 82/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0157 - accuracy: 0.9900 - mse: 3.5504 - weighted_accuracy: 0.9963 - weighted_mse: 4.0231 - val_loss: 0.2650 - val_accuracy: 0.9044 - val_mse: 8.6670 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 8.6670
# Epoch 83/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0146 - accuracy: 0.9930 - mse: 3.6395 - weighted_accuracy: 0.9974 - weighted_mse: 4.1140 - val_loss: 0.3565 - val_accuracy: 0.9084 - val_mse: 13.5647 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 13.5647
# Epoch 84/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0141 - accuracy: 0.9920 - mse: 3.7068 - weighted_accuracy: 0.9971 - weighted_mse: 4.1842 - val_loss: 0.3033 - val_accuracy: 0.9044 - val_mse: 10.4286 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 10.4286
# Epoch 85/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0134 - accuracy: 0.9940 - mse: 3.7975 - weighted_accuracy: 0.9978 - weighted_mse: 4.2868 - val_loss: 0.2503 - val_accuracy: 0.8845 - val_mse: 9.5029 - val_weighted_accuracy: 0.8845 - val_weighted_mse: 9.5029
# Epoch 86/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0129 - accuracy: 0.9990 - mse: 3.8790 - weighted_accuracy: 0.9996 - weighted_mse: 4.3721 - val_loss: 0.2732 - val_accuracy: 0.9004 - val_mse: 9.0732 - val_weighted_accuracy: 0.9004 - val_weighted_mse: 9.0732
# Epoch 87/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0124 - accuracy: 0.9950 - mse: 3.9736 - weighted_accuracy: 0.9982 - weighted_mse: 4.4790 - val_loss: 0.2565 - val_accuracy: 0.9044 - val_mse: 8.3356 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 8.3356
# Epoch 88/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0116 - accuracy: 0.9960 - mse: 4.0693 - weighted_accuracy: 0.9985 - weighted_mse: 4.5811 - val_loss: 0.2849 - val_accuracy: 0.9004 - val_mse: 9.9904 - val_weighted_accuracy: 0.9004 - val_weighted_mse: 9.9904
# Epoch 89/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0117 - accuracy: 0.9960 - mse: 4.1161 - weighted_accuracy: 0.9985 - weighted_mse: 4.5478 - val_loss: 0.3032 - val_accuracy: 0.9044 - val_mse: 9.9244 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 9.9244
# Epoch 90/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0108 - accuracy: 0.9950 - mse: 4.2107 - weighted_accuracy: 0.9982 - weighted_mse: 4.7271 - val_loss: 0.2936 - val_accuracy: 0.9004 - val_mse: 10.1271 - val_weighted_accuracy: 0.9004 - val_weighted_mse: 10.1271
# Epoch 91/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0105 - accuracy: 0.9980 - mse: 4.3254 - weighted_accuracy: 0.9993 - weighted_mse: 4.8526 - val_loss: 0.2794 - val_accuracy: 0.9044 - val_mse: 9.9931 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 9.9931
# Epoch 92/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0105 - accuracy: 0.9980 - mse: 4.3898 - weighted_accuracy: 0.9993 - weighted_mse: 4.8541 - val_loss: 0.2656 - val_accuracy: 0.8924 - val_mse: 8.4479 - val_weighted_accuracy: 0.8924 - val_weighted_mse: 8.4479
# Epoch 93/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0098 - accuracy: 1.0000 - mse: 4.4626 - weighted_accuracy: 1.0000 - weighted_mse: 4.9587 - val_loss: 0.3001 - val_accuracy: 0.9084 - val_mse: 10.2868 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 10.2868
# Epoch 94/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0095 - accuracy: 0.9990 - mse: 4.5585 - weighted_accuracy: 0.9996 - weighted_mse: 5.0531 - val_loss: 0.2757 - val_accuracy: 0.9004 - val_mse: 8.9418 - val_weighted_accuracy: 0.9004 - val_weighted_mse: 8.9418
# Epoch 95/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0096 - accuracy: 1.0000 - mse: 4.6187 - weighted_accuracy: 1.0000 - weighted_mse: 5.1266 - val_loss: 0.2969 - val_accuracy: 0.9044 - val_mse: 10.3597 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 10.3597
# Epoch 96/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0088 - accuracy: 0.9990 - mse: 4.7039 - weighted_accuracy: 0.9996 - weighted_mse: 5.3253 - val_loss: 0.3192 - val_accuracy: 0.9044 - val_mse: 11.4118 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 11.4118
# Epoch 97/200
# 8/8 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9987 - mse: 4.7523 - weighted_accuracy: 0.9995 - weighted_mse: 5.156 - 0s 15ms/step - loss: 0.0087 - accuracy: 0.9990 - mse: 4.8020 - weighted_accuracy: 0.9996 - weighted_mse: 5.3111 - val_loss: 0.2676 - val_accuracy: 0.9084 - val_mse: 9.8246 - val_weighted_accuracy: 0.9084 - val_weighted_mse: 9.8246
# Epoch 98/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0085 - accuracy: 1.0000 - mse: 4.8911 - weighted_accuracy: 1.0000 - weighted_mse: 5.4152 - val_loss: 0.2828 - val_accuracy: 0.9044 - val_mse: 9.7245 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 9.7245
# Epoch 99/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0081 - accuracy: 1.0000 - mse: 4.9742 - weighted_accuracy: 1.0000 - weighted_mse: 5.5351 - val_loss: 0.2949 - val_accuracy: 0.8964 - val_mse: 9.8082 - val_weighted_accuracy: 0.8964 - val_weighted_mse: 9.8082
# Epoch 100/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0079 - accuracy: 1.0000 - mse: 5.0827 - weighted_accuracy: 1.0000 - weighted_mse: 5.6918 - val_loss: 0.2927 - val_accuracy: 0.9004 - val_mse: 10.1319 - val_weighted_accuracy: 0.9004 - val_weighted_mse: 10.1319
# Epoch 101/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0078 - accuracy: 1.0000 - mse: 5.1393 - weighted_accuracy: 1.0000 - weighted_mse: 5.6997 - val_loss: 0.2722 - val_accuracy: 0.8964 - val_mse: 9.6208 - val_weighted_accuracy: 0.8964 - val_weighted_mse: 9.6208
# Epoch 102/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0076 - accuracy: 1.0000 - mse: 5.2102 - weighted_accuracy: 1.0000 - weighted_mse: 5.7472 - val_loss: 0.2937 - val_accuracy: 0.9004 - val_mse: 10.3398 - val_weighted_accuracy: 0.9004 - val_weighted_mse: 10.3398
# Epoch 103/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0074 - accuracy: 1.0000 - mse: 5.2847 - weighted_accuracy: 1.0000 - weighted_mse: 5.8847 - val_loss: 0.2845 - val_accuracy: 0.9004 - val_mse: 9.9386 - val_weighted_accuracy: 0.9004 - val_weighted_mse: 9.9386
# Epoch 104/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0072 - accuracy: 1.0000 - mse: 5.3806 - weighted_accuracy: 1.0000 - weighted_mse: 5.9415 - val_loss: 0.2887 - val_accuracy: 0.9004 - val_mse: 10.1519 - val_weighted_accuracy: 0.9004 - val_weighted_mse: 10.1519
# Epoch 105/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0071 - accuracy: 1.0000 - mse: 5.4603 - weighted_accuracy: 1.0000 - weighted_mse: 5.9953 - val_loss: 0.3005 - val_accuracy: 0.9044 - val_mse: 11.3497 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 11.3497
# Epoch 106/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0070 - accuracy: 1.0000 - mse: 5.5369 - weighted_accuracy: 1.0000 - weighted_mse: 6.0602 - val_loss: 0.3047 - val_accuracy: 0.9044 - val_mse: 10.5490 - val_weighted_accuracy: 0.9044 - val_weighted_mse: 10.5490
# Epoch 107/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0068 - accuracy: 1.0000 - mse: 5.6174 - weighted_accuracy: 1.0000 - weighted_mse: 6.2152 - val_loss: 0.2749 - val_accuracy: 0.8924 - val_mse: 9.5332 - val_weighted_accuracy: 0.8924 - val_weighted_mse: 9.5332
# Epoch 108/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0066 - accuracy: 1.0000 - mse: 5.7006 - weighted_accuracy: 1.0000 - weighted_mse: 6.2709 - val_loss: 0.2625 - val_accuracy: 0.8765 - val_mse: 9.3064 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 9.3064
# Epoch 109/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0067 - accuracy: 1.0000 - mse: 5.7805 - weighted_accuracy: 1.0000 - weighted_mse: 6.3600 - val_loss: 0.2810 - val_accuracy: 0.8884 - val_mse: 10.2325 - val_weighted_accuracy: 0.8884 - val_weighted_mse: 10.2325
# Epoch 110/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0065 - accuracy: 1.0000 - mse: 5.8425 - weighted_accuracy: 1.0000 - weighted_mse: 6.3773 - val_loss: 0.2890 - val_accuracy: 0.8845 - val_mse: 10.5739 - val_weighted_accuracy: 0.8845 - val_weighted_mse: 10.5739
# Epoch 111/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0064 - accuracy: 1.0000 - mse: 5.9092 - weighted_accuracy: 1.0000 - weighted_mse: 6.4322 - val_loss: 0.2726 - val_accuracy: 0.8845 - val_mse: 9.8598 - val_weighted_accuracy: 0.8845 - val_weighted_mse: 9.8598
# Epoch 112/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0062 - accuracy: 1.0000 - mse: 5.9974 - weighted_accuracy: 1.0000 - weighted_mse: 6.5786 - val_loss: 0.2678 - val_accuracy: 0.8765 - val_mse: 9.0537 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 9.0537
# Epoch 113/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0060 - accuracy: 1.0000 - mse: 6.1013 - weighted_accuracy: 1.0000 - weighted_mse: 6.7256 - val_loss: 0.2874 - val_accuracy: 0.8845 - val_mse: 9.5200 - val_weighted_accuracy: 0.8845 - val_weighted_mse: 9.5200
# Epoch 114/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0062 - accuracy: 1.0000 - mse: 6.1387 - weighted_accuracy: 1.0000 - weighted_mse: 6.7143 - val_loss: 0.2583 - val_accuracy: 0.8725 - val_mse: 8.6646 - val_weighted_accuracy: 0.8725 - val_weighted_mse: 8.6646
# Epoch 115/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0061 - accuracy: 1.0000 - mse: 6.1952 - weighted_accuracy: 1.0000 - weighted_mse: 6.7054 - val_loss: 0.2436 - val_accuracy: 0.8765 - val_mse: 8.2627 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 8.2627
# Epoch 116/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0058 - accuracy: 1.0000 - mse: 6.2940 - weighted_accuracy: 1.0000 - weighted_mse: 6.9847 - val_loss: 0.2579 - val_accuracy: 0.8566 - val_mse: 7.7026 - val_weighted_accuracy: 0.8566 - val_weighted_mse: 7.7026
# Epoch 117/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0058 - accuracy: 1.0000 - mse: 6.3652 - weighted_accuracy: 1.0000 - weighted_mse: 6.9538 - val_loss: 0.2745 - val_accuracy: 0.8685 - val_mse: 9.0319 - val_weighted_accuracy: 0.8685 - val_weighted_mse: 9.0319
# Epoch 118/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0057 - accuracy: 1.0000 - mse: 6.4502 - weighted_accuracy: 1.0000 - weighted_mse: 6.9901 - val_loss: 0.2876 - val_accuracy: 0.8884 - val_mse: 9.9370 - val_weighted_accuracy: 0.8884 - val_weighted_mse: 9.9370
# Epoch 119/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0057 - accuracy: 1.0000 - mse: 6.4990 - weighted_accuracy: 1.0000 - weighted_mse: 7.1065 - val_loss: 0.2639 - val_accuracy: 0.8845 - val_mse: 9.6543 - val_weighted_accuracy: 0.8845 - val_weighted_mse: 9.6543
# Epoch 120/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0057 - accuracy: 1.0000 - mse: 6.5693 - weighted_accuracy: 1.0000 - weighted_mse: 7.1521 - val_loss: 0.2567 - val_accuracy: 0.8805 - val_mse: 7.8881 - val_weighted_accuracy: 0.8805 - val_weighted_mse: 7.8881
# Epoch 121/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0056 - accuracy: 1.0000 - mse: 6.6463 - weighted_accuracy: 1.0000 - weighted_mse: 7.2203 - val_loss: 0.2787 - val_accuracy: 0.8606 - val_mse: 7.8600 - val_weighted_accuracy: 0.8606 - val_weighted_mse: 7.8600
# Epoch 122/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0055 - accuracy: 1.0000 - mse: 6.7174 - weighted_accuracy: 1.0000 - weighted_mse: 7.3545 - val_loss: 0.2749 - val_accuracy: 0.8765 - val_mse: 8.7628 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 8.7628
# Epoch 123/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0054 - accuracy: 1.0000 - mse: 6.7795 - weighted_accuracy: 1.0000 - weighted_mse: 7.3640 - val_loss: 0.2971 - val_accuracy: 0.8884 - val_mse: 10.9054 - val_weighted_accuracy: 0.8884 - val_weighted_mse: 10.9054
# Epoch 124/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0057 - accuracy: 1.0000 - mse: 6.8136 - weighted_accuracy: 1.0000 - weighted_mse: 7.3608 - val_loss: 0.3019 - val_accuracy: 0.7888 - val_mse: 8.8854 - val_weighted_accuracy: 0.7888 - val_weighted_mse: 8.8854
# Epoch 125/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0055 - accuracy: 1.0000 - mse: 6.8939 - weighted_accuracy: 1.0000 - weighted_mse: 7.4324 - val_loss: 0.3000 - val_accuracy: 0.8884 - val_mse: 10.7295 - val_weighted_accuracy: 0.8884 - val_weighted_mse: 10.7295
# Epoch 126/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0053 - accuracy: 1.0000 - mse: 6.9651 - weighted_accuracy: 1.0000 - weighted_mse: 7.6076 - val_loss: 0.3068 - val_accuracy: 0.8924 - val_mse: 11.0848 - val_weighted_accuracy: 0.8924 - val_weighted_mse: 11.0848
# Epoch 127/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0053 - accuracy: 1.0000 - mse: 7.0132 - weighted_accuracy: 1.0000 - weighted_mse: 7.6463 - val_loss: 0.3306 - val_accuracy: 0.8805 - val_mse: 10.8448 - val_weighted_accuracy: 0.8805 - val_weighted_mse: 10.8448
# Epoch 128/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0052 - accuracy: 1.0000 - mse: 7.0857 - weighted_accuracy: 1.0000 - weighted_mse: 7.8140 - val_loss: 0.3051 - val_accuracy: 0.8765 - val_mse: 10.1826 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 10.1826
# Epoch 129/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0052 - accuracy: 1.0000 - mse: 7.1762 - weighted_accuracy: 1.0000 - weighted_mse: 7.8774 - val_loss: 0.2919 - val_accuracy: 0.8805 - val_mse: 10.1102 - val_weighted_accuracy: 0.8805 - val_weighted_mse: 10.1102
# Epoch 130/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0051 - accuracy: 1.0000 - mse: 7.2475 - weighted_accuracy: 1.0000 - weighted_mse: 7.8388 - val_loss: 0.2909 - val_accuracy: 0.8685 - val_mse: 8.8228 - val_weighted_accuracy: 0.8685 - val_weighted_mse: 8.8228
# Epoch 131/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0051 - accuracy: 1.0000 - mse: 7.2828 - weighted_accuracy: 1.0000 - weighted_mse: 7.9571 - val_loss: 0.2757 - val_accuracy: 0.8645 - val_mse: 8.4906 - val_weighted_accuracy: 0.8645 - val_weighted_mse: 8.4906
# Epoch 132/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0051 - accuracy: 1.0000 - mse: 7.3177 - weighted_accuracy: 1.0000 - weighted_mse: 7.8975 - val_loss: 0.2920 - val_accuracy: 0.8725 - val_mse: 8.9457 - val_weighted_accuracy: 0.8725 - val_weighted_mse: 8.9457
# Epoch 133/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0051 - accuracy: 1.0000 - mse: 7.4132 - weighted_accuracy: 1.0000 - weighted_mse: 8.0487 - val_loss: 0.3000 - val_accuracy: 0.8805 - val_mse: 10.1095 - val_weighted_accuracy: 0.8805 - val_weighted_mse: 10.1095
# Epoch 134/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0050 - accuracy: 1.0000 - mse: 7.4608 - weighted_accuracy: 1.0000 - weighted_mse: 8.0553 - val_loss: 0.2972 - val_accuracy: 0.8725 - val_mse: 9.6456 - val_weighted_accuracy: 0.8725 - val_weighted_mse: 9.6456
# Epoch 135/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0050 - accuracy: 1.0000 - mse: 7.5165 - weighted_accuracy: 1.0000 - weighted_mse: 8.1614 - val_loss: 0.3085 - val_accuracy: 0.8805 - val_mse: 9.4404 - val_weighted_accuracy: 0.8805 - val_weighted_mse: 9.4404
# Epoch 136/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0050 - accuracy: 1.0000 - mse: 7.5901 - weighted_accuracy: 1.0000 - weighted_mse: 8.3078 - val_loss: 0.2985 - val_accuracy: 0.8765 - val_mse: 9.2276 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 9.2276
# Epoch 137/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 7.6551 - weighted_accuracy: 1.0000 - weighted_mse: 8.3981 - val_loss: 0.3008 - val_accuracy: 0.8685 - val_mse: 9.3634 - val_weighted_accuracy: 0.8685 - val_weighted_mse: 9.3634
# Epoch 138/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 7.7105 - weighted_accuracy: 1.0000 - weighted_mse: 8.4157 - val_loss: 0.3013 - val_accuracy: 0.8685 - val_mse: 9.0766 - val_weighted_accuracy: 0.8685 - val_weighted_mse: 9.0766
# Epoch 139/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 7.7454 - weighted_accuracy: 1.0000 - weighted_mse: 8.4742 - val_loss: 0.3023 - val_accuracy: 0.8606 - val_mse: 8.9058 - val_weighted_accuracy: 0.8606 - val_weighted_mse: 8.9058
# Epoch 140/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 7.8037 - weighted_accuracy: 1.0000 - weighted_mse: 8.4715 - val_loss: 0.2994 - val_accuracy: 0.8606 - val_mse: 9.0604 - val_weighted_accuracy: 0.8606 - val_weighted_mse: 9.0604
# Epoch 141/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 7.8379 - weighted_accuracy: 1.0000 - weighted_mse: 8.5299 - val_loss: 0.3094 - val_accuracy: 0.8367 - val_mse: 8.9711 - val_weighted_accuracy: 0.8367 - val_weighted_mse: 8.9711
# Epoch 142/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 7.9103 - weighted_accuracy: 1.0000 - weighted_mse: 8.7830 - val_loss: 0.3004 - val_accuracy: 0.8725 - val_mse: 9.9343 - val_weighted_accuracy: 0.8725 - val_weighted_mse: 9.9343
# Epoch 143/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 7.9613 - weighted_accuracy: 1.0000 - weighted_mse: 8.6842 - val_loss: 0.3009 - val_accuracy: 0.8725 - val_mse: 10.5510 - val_weighted_accuracy: 0.8725 - val_weighted_mse: 10.5510
# Epoch 144/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 7.9841 - weighted_accuracy: 1.0000 - weighted_mse: 8.5633 - val_loss: 0.3314 - val_accuracy: 0.8845 - val_mse: 10.3493 - val_weighted_accuracy: 0.8845 - val_weighted_mse: 10.3493
# Epoch 145/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 8.0833 - weighted_accuracy: 1.0000 - weighted_mse: 8.7732 - val_loss: 0.3135 - val_accuracy: 0.8685 - val_mse: 9.9906 - val_weighted_accuracy: 0.8685 - val_weighted_mse: 9.9906
# Epoch 146/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 8.1202 - weighted_accuracy: 1.0000 - weighted_mse: 8.7783 - val_loss: 0.3067 - val_accuracy: 0.8765 - val_mse: 9.7166 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 9.7166
# Epoch 147/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 8.1684 - weighted_accuracy: 1.0000 - weighted_mse: 8.8168 - val_loss: 0.3219 - val_accuracy: 0.8805 - val_mse: 9.6019 - val_weighted_accuracy: 0.8805 - val_weighted_mse: 9.6019
# Epoch 148/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 8.1849 - weighted_accuracy: 1.0000 - weighted_mse: 8.7948 - val_loss: 0.3264 - val_accuracy: 0.8765 - val_mse: 10.3897 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 10.3897
# Epoch 149/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 8.2512 - weighted_accuracy: 1.0000 - weighted_mse: 8.8445 - val_loss: 0.3177 - val_accuracy: 0.8685 - val_mse: 9.9976 - val_weighted_accuracy: 0.8685 - val_weighted_mse: 9.9976
# Epoch 150/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 8.3181 - weighted_accuracy: 1.0000 - weighted_mse: 8.9432 - val_loss: 0.3141 - val_accuracy: 0.8645 - val_mse: 9.9233 - val_weighted_accuracy: 0.8645 - val_weighted_mse: 9.9233
# Epoch 151/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 8.3699 - weighted_accuracy: 1.0000 - weighted_mse: 9.0690 - val_loss: 0.3247 - val_accuracy: 0.8685 - val_mse: 10.0401 - val_weighted_accuracy: 0.8685 - val_weighted_mse: 10.0401
# Epoch 152/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 8.4282 - weighted_accuracy: 1.0000 - weighted_mse: 9.2611 - val_loss: 0.3217 - val_accuracy: 0.8845 - val_mse: 10.9526 - val_weighted_accuracy: 0.8845 - val_weighted_mse: 10.9526
# Epoch 153/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 8.4599 - weighted_accuracy: 1.0000 - weighted_mse: 9.0954 - val_loss: 0.3105 - val_accuracy: 0.8765 - val_mse: 10.6538 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 10.6538
# Epoch 154/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 8.5822 - weighted_accuracy: 1.0000 - weighted_mse: 9.4004 - val_loss: 0.3439 - val_accuracy: 0.8606 - val_mse: 10.0284 - val_weighted_accuracy: 0.8606 - val_weighted_mse: 10.0284
# Epoch 155/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 8.5848 - weighted_accuracy: 1.0000 - weighted_mse: 9.3894 - val_loss: 0.3233 - val_accuracy: 0.8606 - val_mse: 10.2547 - val_weighted_accuracy: 0.8606 - val_weighted_mse: 10.2547
# Epoch 156/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 8.6243 - weighted_accuracy: 1.0000 - weighted_mse: 9.3979 - val_loss: 0.3135 - val_accuracy: 0.8765 - val_mse: 10.7002 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 10.7002
# Epoch 157/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 8.6627 - weighted_accuracy: 1.0000 - weighted_mse: 9.3658 - val_loss: 0.3111 - val_accuracy: 0.8765 - val_mse: 10.3686 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 10.3686
# Epoch 158/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 8.7768 - weighted_accuracy: 1.0000 - weighted_mse: 9.5628 - val_loss: 0.3151 - val_accuracy: 0.8725 - val_mse: 10.3616 - val_weighted_accuracy: 0.8725 - val_weighted_mse: 10.3616
# Epoch 159/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 8.8027 - weighted_accuracy: 1.0000 - weighted_mse: 9.6087 - val_loss: 0.3206 - val_accuracy: 0.8765 - val_mse: 10.4295 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 10.4295
# Epoch 160/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 8.7653 - weighted_accuracy: 1.0000 - weighted_mse: 9.2795 - val_loss: 0.3333 - val_accuracy: 0.8645 - val_mse: 9.7772 - val_weighted_accuracy: 0.8645 - val_weighted_mse: 9.7772
# Epoch 161/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 8.9334 - weighted_accuracy: 1.0000 - weighted_mse: 9.9003 - val_loss: 0.3280 - val_accuracy: 0.8685 - val_mse: 9.9447 - val_weighted_accuracy: 0.8685 - val_weighted_mse: 9.9447
# Epoch 162/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 8.9467 - weighted_accuracy: 1.0000 - weighted_mse: 9.8851 - val_loss: 0.3224 - val_accuracy: 0.8645 - val_mse: 10.1987 - val_weighted_accuracy: 0.8645 - val_weighted_mse: 10.1987
# Epoch 163/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 8.9644 - weighted_accuracy: 1.0000 - weighted_mse: 9.7139 - val_loss: 0.3209 - val_accuracy: 0.8725 - val_mse: 9.8410 - val_weighted_accuracy: 0.8725 - val_weighted_mse: 9.8410
# Epoch 164/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 9.0390 - weighted_accuracy: 1.0000 - weighted_mse: 9.8351 - val_loss: 0.3234 - val_accuracy: 0.8645 - val_mse: 9.2515 - val_weighted_accuracy: 0.8645 - val_weighted_mse: 9.2515
# Epoch 165/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 9.0729 - weighted_accuracy: 1.0000 - weighted_mse: 9.9330 - val_loss: 0.3268 - val_accuracy: 0.8725 - val_mse: 9.2836 - val_weighted_accuracy: 0.8725 - val_weighted_mse: 9.2836
# Epoch 166/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 9.1025 - weighted_accuracy: 1.0000 - weighted_mse: 9.8271 - val_loss: 0.3266 - val_accuracy: 0.8606 - val_mse: 9.6407 - val_weighted_accuracy: 0.8606 - val_weighted_mse: 9.6407
# Epoch 167/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 9.1497 - weighted_accuracy: 1.0000 - weighted_mse: 9.9419 - val_loss: 0.3285 - val_accuracy: 0.8725 - val_mse: 9.9076 - val_weighted_accuracy: 0.8725 - val_weighted_mse: 9.9076
# Epoch 168/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 9.1809 - weighted_accuracy: 1.0000 - weighted_mse: 9.9671 - val_loss: 0.3366 - val_accuracy: 0.8725 - val_mse: 10.0039 - val_weighted_accuracy: 0.8725 - val_weighted_mse: 10.0039
# Epoch 169/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 9.2451 - weighted_accuracy: 1.0000 - weighted_mse: 10.1453 - val_loss: 0.3376 - val_accuracy: 0.8685 - val_mse: 9.9832 - val_weighted_accuracy: 0.8685 - val_weighted_mse: 9.9832
# Epoch 170/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 9.2954 - weighted_accuracy: 1.0000 - weighted_mse: 10.2376 - val_loss: 0.3215 - val_accuracy: 0.8645 - val_mse: 10.3744 - val_weighted_accuracy: 0.8645 - val_weighted_mse: 10.3744
# Epoch 171/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 9.3257 - weighted_accuracy: 1.0000 - weighted_mse: 10.1270 - val_loss: 0.3317 - val_accuracy: 0.8765 - val_mse: 10.7997 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 10.7997
# Epoch 172/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 9.3624 - weighted_accuracy: 1.0000 - weighted_mse: 10.1237 - val_loss: 0.3522 - val_accuracy: 0.8725 - val_mse: 10.3653 - val_weighted_accuracy: 0.8725 - val_weighted_mse: 10.3653
# Epoch 173/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 9.4325 - weighted_accuracy: 1.0000 - weighted_mse: 10.3003 - val_loss: 0.3419 - val_accuracy: 0.8606 - val_mse: 10.1334 - val_weighted_accuracy: 0.8606 - val_weighted_mse: 10.1334
# Epoch 174/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 9.4667 - weighted_accuracy: 1.0000 - weighted_mse: 10.4143 - val_loss: 0.3361 - val_accuracy: 0.8685 - val_mse: 10.2621 - val_weighted_accuracy: 0.8685 - val_weighted_mse: 10.2621
# Epoch 175/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 9.5141 - weighted_accuracy: 1.0000 - weighted_mse: 10.3738 - val_loss: 0.3357 - val_accuracy: 0.8765 - val_mse: 10.4434 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 10.4434
# Epoch 176/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 9.5808 - weighted_accuracy: 1.0000 - weighted_mse: 10.4684 - val_loss: 0.3390 - val_accuracy: 0.8805 - val_mse: 10.4138 - val_weighted_accuracy: 0.8805 - val_weighted_mse: 10.4138
# Epoch 177/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 9.5737 - weighted_accuracy: 1.0000 - weighted_mse: 10.5394 - val_loss: 0.3433 - val_accuracy: 0.8765 - val_mse: 10.6849 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 10.6849
# Epoch 178/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 9.5888 - weighted_accuracy: 1.0000 - weighted_mse: 10.3602 - val_loss: 0.3541 - val_accuracy: 0.8805 - val_mse: 10.8519 - val_weighted_accuracy: 0.8805 - val_weighted_mse: 10.8519
# Epoch 179/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 9.6439 - weighted_accuracy: 1.0000 - weighted_mse: 10.3900 - val_loss: 0.3585 - val_accuracy: 0.8645 - val_mse: 10.5255 - val_weighted_accuracy: 0.8645 - val_weighted_mse: 10.5255
# Epoch 180/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 9.7012 - weighted_accuracy: 1.0000 - weighted_mse: 10.5640 - val_loss: 0.3436 - val_accuracy: 0.8685 - val_mse: 10.8480 - val_weighted_accuracy: 0.8685 - val_weighted_mse: 10.8480
# Epoch 181/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 9.7569 - weighted_accuracy: 1.0000 - weighted_mse: 10.6779 - val_loss: 0.3438 - val_accuracy: 0.8845 - val_mse: 10.8276 - val_weighted_accuracy: 0.8845 - val_weighted_mse: 10.8276
# Epoch 182/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 9.7811 - weighted_accuracy: 1.0000 - weighted_mse: 10.5987 - val_loss: 0.3437 - val_accuracy: 0.8805 - val_mse: 11.2529 - val_weighted_accuracy: 0.8805 - val_weighted_mse: 11.2529
# Epoch 183/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 9.8244 - weighted_accuracy: 1.0000 - weighted_mse: 10.7340 - val_loss: 0.3487 - val_accuracy: 0.8765 - val_mse: 11.0802 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 11.0802
# Epoch 184/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 9.8843 - weighted_accuracy: 1.0000 - weighted_mse: 10.8769 - val_loss: 0.3560 - val_accuracy: 0.8805 - val_mse: 11.0649 - val_weighted_accuracy: 0.8805 - val_weighted_mse: 11.0649
# Epoch 185/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 9.9025 - weighted_accuracy: 1.0000 - weighted_mse: 10.8609 - val_loss: 0.3646 - val_accuracy: 0.8805 - val_mse: 11.2915 - val_weighted_accuracy: 0.8805 - val_weighted_mse: 11.2915
# Epoch 186/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 9.9381 - weighted_accuracy: 1.0000 - weighted_mse: 10.8028 - val_loss: 0.3523 - val_accuracy: 0.8765 - val_mse: 11.2649 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 11.2649
# Epoch 187/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 9.9388 - weighted_accuracy: 1.0000 - weighted_mse: 10.8274 - val_loss: 0.3546 - val_accuracy: 0.8725 - val_mse: 10.9139 - val_weighted_accuracy: 0.8725 - val_weighted_mse: 10.9139
# Epoch 188/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 10.0107 - weighted_accuracy: 1.0000 - weighted_mse: 10.9142 - val_loss: 0.3400 - val_accuracy: 0.8845 - val_mse: 11.3324 - val_weighted_accuracy: 0.8845 - val_weighted_mse: 11.3324
# Epoch 189/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 10.0306 - weighted_accuracy: 1.0000 - weighted_mse: 10.8117 - val_loss: 0.3383 - val_accuracy: 0.8765 - val_mse: 11.1591 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 11.1591
# Epoch 190/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 10.0615 - weighted_accuracy: 1.0000 - weighted_mse: 10.8590 - val_loss: 0.3449 - val_accuracy: 0.8765 - val_mse: 10.5884 - val_weighted_accuracy: 0.8765 - val_weighted_mse: 10.5884
# Epoch 191/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 10.1173 - weighted_accuracy: 1.0000 - weighted_mse: 11.0211 - val_loss: 0.3549 - val_accuracy: 0.8645 - val_mse: 10.0261 - val_weighted_accuracy: 0.8645 - val_weighted_mse: 10.0261
# Epoch 192/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 10.1946 - weighted_accuracy: 1.0000 - weighted_mse: 11.2379 - val_loss: 0.3582 - val_accuracy: 0.8606 - val_mse: 10.3368 - val_weighted_accuracy: 0.8606 - val_weighted_mse: 10.3368
# Epoch 193/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 10.1848 - weighted_accuracy: 1.0000 - weighted_mse: 10.9290 - val_loss: 0.3607 - val_accuracy: 0.8685 - val_mse: 10.5278 - val_weighted_accuracy: 0.8685 - val_weighted_mse: 10.5278
# Epoch 194/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 10.2506 - weighted_accuracy: 1.0000 - weighted_mse: 11.1088 - val_loss: 0.3583 - val_accuracy: 0.8725 - val_mse: 10.9483 - val_weighted_accuracy: 0.8725 - val_weighted_mse: 10.9483
# Epoch 195/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 10.2937 - weighted_accuracy: 1.0000 - weighted_mse: 11.2084 - val_loss: 0.3554 - val_accuracy: 0.8805 - val_mse: 11.0170 - val_weighted_accuracy: 0.8805 - val_weighted_mse: 11.0170
# Epoch 196/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 10.3164 - weighted_accuracy: 1.0000 - weighted_mse: 11.2973 - val_loss: 0.3587 - val_accuracy: 0.8805 - val_mse: 11.4784 - val_weighted_accuracy: 0.8805 - val_weighted_mse: 11.4784
# Epoch 197/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 10.3885 - weighted_accuracy: 1.0000 - weighted_mse: 11.4280 - val_loss: 0.3633 - val_accuracy: 0.8805 - val_mse: 11.9669 - val_weighted_accuracy: 0.8805 - val_weighted_mse: 11.9669
# Epoch 198/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 10.4090 - weighted_accuracy: 1.0000 - weighted_mse: 11.2542 - val_loss: 0.3640 - val_accuracy: 0.8805 - val_mse: 12.0929 - val_weighted_accuracy: 0.8805 - val_weighted_mse: 12.0929
# Epoch 199/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 10.4484 - weighted_accuracy: 1.0000 - weighted_mse: 11.3091 - val_loss: 0.3724 - val_accuracy: 0.8685 - val_mse: 11.5692 - val_weighted_accuracy: 0.8685 - val_weighted_mse: 11.5692
# Epoch 200/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 10.4633 - weighted_accuracy: 1.0000 - weighted_mse: 11.4002 - val_loss: 0.3687 - val_accuracy: 0.8606 - val_mse: 11.6739 - val_weighted_accuracy: 0.8606 - val_weighted_mse: 11.6739

# %%
# Score model
score = model.evaluate(validation_x, validation_y, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.36866238713264465
# Test accuracy: 0.8605577945709229

# %%
predictions = model.predict(validation_x)
print(predictions)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
from collections import Counter

Counter(predictions)
# Out:
# [[-2.6748793e+00 -4.6449027e+00  2.9361126e+00]
#  [-2.3546481e+00 -3.3101082e+00  2.4144747e+00]
#  [-3.9599922e+00 -3.7155139e+00  4.5304704e+00]
#  [-3.7255862e+00 -2.2925689e+00  2.6307518e+00]
#  [-3.9334149e+00 -3.9521842e+00  4.7663150e+00]
#  [-2.9873557e+00 -1.6486901e+00  9.1836983e-01]
#  [-4.4594169e+00 -3.7342885e+00  3.6681426e+00]
#  [-4.3841801e+00 -2.6338103e+00  2.5118053e+00]
#  [-2.8701737e+00 -3.9476058e+00  3.0894258e+00]
#  [-3.0384271e+00 -3.5512249e+00  3.6162655e+00]
#  [-3.2795928e+00 -4.8465776e+00  3.6869287e+00]
#  [-4.4772586e-01 -4.1865625e+00 -4.8835921e-01]
#  [-4.5519867e+00 -4.4069967e+00  4.3329387e+00]
#  [-4.4726439e+00 -4.6288104e+00  5.0494485e+00]
#  [-3.7255633e+00 -5.3938289e+00  4.1708612e+00]
#  [-2.9941742e+00 -3.7757373e+00  3.5195942e+00]
#  [-4.2807989e+00 -3.6579330e+00  3.0630414e+00]
#  [-4.6142688e+00 -4.3748360e+00  3.8944514e+00]
#  [-4.1791606e+00 -1.6268357e+00  2.0029509e+00]
#  [-3.9717185e+00 -4.0291123e+00  4.4340954e+00]
#  [-6.4326489e-01 -3.8998196e+00  4.3737811e-01]
#  [-5.1607013e+00 -5.5073137e+00  4.7067671e+00]
#  [-2.8359857e+00 -3.4218779e+00  2.4997783e+00]
#  [-2.9015741e+00 -3.3207135e+00  2.4349911e+00]
#  [-2.0486624e+00 -3.6516435e+00  2.0811627e+00]
#  [-4.1398540e+00 -4.5328789e+00  3.9249513e+00]
#  [-2.0462873e+00 -4.6404610e+00  2.2438436e+00]
#  [-3.2899480e+00 -2.1891742e+00  1.6188493e+00]
#  [-3.7005751e+00 -2.3618636e+00  1.9768295e+00]
#  [-1.1568926e-03 -2.8186252e+00 -1.7066369e+00]
#  [-4.6803517e+00 -2.7469046e+00  2.7902772e+00]
#  [-2.9838569e+00 -2.9503894e+00  2.3481185e+00]
#  [-3.0967028e+00 -4.1691031e+00  3.3983757e+00]
#  [ 1.4054390e+00 -4.0749168e+00 -2.4567223e+00]
#  [-1.5486431e+00 -4.0778551e+00  1.5662663e+00]
#  [-4.0999823e+00 -5.1848831e+00  3.6732171e+00]
#  [-1.5472287e+00 -4.8667173e+00  2.2542455e+00]
#  [-2.1050427e+00 -5.3639550e+00  2.7064695e+00]
#  [-3.0969479e+00 -4.0456400e+00  3.1376228e+00]
#  [-2.5744457e+00 -4.2321877e+00  2.8961110e+00]
#  [-4.3701739e+00  2.9624617e+00 -3.0156615e+00]
#  [-3.3927269e+00 -3.3969092e+00  3.2267313e+00]
#  [-2.0078795e+00 -3.3002403e+00  1.7497671e-01]
#  [-3.2850707e+00 -6.0105109e+00  2.8211889e+00]
#  [-2.5612476e+00 -3.7128778e+00  2.8818455e+00]
#  [-6.5891713e-01 -4.8210835e+00  2.2264624e-01]
#  [-3.5302584e+00 -3.5464621e+00  2.9570084e+00]
#  [-3.3108680e+00 -3.8593192e+00  3.8035185e+00]
#  [-3.5193207e+00 -4.2047291e+00  3.6307440e+00]
#  [-2.7914443e+00 -4.4388399e+00  3.0067058e+00]
#  [-3.2638810e+00 -2.3614533e+00  2.3217242e+00]
#  [ 2.3742047e-01 -5.5561895e+00 -1.4563427e+00]
#  [-3.1352465e+00 -3.7948990e+00  2.4752426e+00]
#  [-3.5881619e+00 -4.0432386e+00  4.1267638e+00]
#  [-3.3302641e+00 -3.2621603e+00  3.7258732e+00]
#  [-4.4354887e+00 -5.7211928e+00  4.2772527e+00]
#  [-2.7303154e+00 -3.6739452e+00  3.1092665e+00]
#  [-3.8878241e+00 -4.6410389e+00  4.4130044e+00]
#  [-1.6147975e+00 -4.0514803e+00  7.1933490e-01]
#  [-3.9104416e+00 -4.8676991e+00  4.1802192e+00]
#  [-3.0902870e+00 -3.9793098e+00  3.0665379e+00]
#  [-3.3489487e+00 -4.1972504e+00  3.3876824e+00]
#  [-2.7384689e+00 -3.2389848e+00  2.6593499e+00]
#  [-3.7595875e+00 -3.5606978e+00  3.3306766e+00]
#  [-3.5874550e+00 -5.2059278e+00  2.7314377e+00]
#  [-2.9944834e-01 -4.3159680e+00 -4.0136158e-01]
#  [-1.3434186e+00 -5.0970888e+00  1.5841961e+00]
#  [-2.8615997e+00 -2.6657112e+00  2.2105820e+00]
#  [-5.1184545e+00 -4.4629788e+00  5.2881603e+00]
#  [-2.5572424e+00 -4.4112315e+00  2.0762978e+00]
#  [-2.7857809e+00 -4.8369298e+00  2.8935986e+00]
#  [-3.0640013e+00 -3.0367510e+00  3.3647518e+00]
#  [ 1.3276145e-01 -2.5622342e+00 -9.5958483e-01]
#  [-2.0480294e+00 -3.6593218e+00  2.0421684e+00]
#  [-4.0093675e+00 -2.9186652e+00  4.2498140e+00]
#  [-4.1015105e+00 -4.6306725e+00  4.2502327e+00]
#  [-2.6954451e+00 -3.7131307e+00  3.0379519e+00]
#  [-2.3023481e+00 -5.2551498e+00  3.1273036e+00]
#  [-1.4424859e+00 -3.6797404e+00  8.9560211e-01]
#  [-3.2346013e+00 -3.8667822e+00  3.1412466e+00]
#  [-3.5164425e+00 -4.3900142e+00  3.7231982e+00]
#  [-2.0585680e+00 -3.4003184e+00  2.1694732e+00]
#  [-2.6481833e+00 -1.5292372e+00  1.3776181e+00]
#  [-4.4986887e+00 -2.5287430e+00  1.9401742e+00]
#  [-3.4233000e+00 -1.5171962e+00  2.2175660e+00]
#  [-3.3965483e+00 -3.1806707e+00  2.5047014e+00]
#  [-2.0274994e+00 -2.7951853e+00  1.4066961e+00]
#  [-3.7373855e+00 -4.5771246e+00  3.6322219e+00]
#  [-6.6407437e+00  6.3465118e+00 -7.1495490e+00]
#  [-4.3383508e+00 -2.2841661e+00  3.5646033e+00]
#  [-2.9605603e+00 -4.6291490e+00  3.8218067e+00]
#  [-3.1901889e+00 -4.2104454e+00  3.3954139e+00]
#  [-2.6662405e+00 -3.5010915e+00  3.3931632e+00]
#  [ 5.5650884e-01 -5.2672672e+00 -1.2789447e+00]
#  [-4.7430725e+00 -4.3597736e+00  4.4676089e+00]
#  [-3.0708051e+00 -1.9767821e+00  1.5849289e+00]
#  [-3.6709199e+00 -2.2679212e+00  1.8800359e+00]
#  [-4.0495939e+00 -4.4357195e+00  5.2945027e+00]
#  [-2.4288971e+00 -1.6334790e+00 -3.2614559e-02]
#  [-5.0040865e+00 -4.9964876e+00  4.7676206e+00]
#  [-3.7492709e+00 -4.9488158e+00  4.5645795e+00]
#  [-3.5720088e+00 -3.7763159e+00  3.8098340e+00]
#  [-3.4804902e+00 -2.0443795e+00  2.1737421e+00]
#  [-2.9530334e+00 -4.3823829e+00  3.5918052e+00]
#  [-4.5869255e+00 -4.8394222e+00  5.5166726e+00]
#  [-3.7224939e+00 -3.9755883e+00  3.9201293e+00]
#  [-2.2749116e+00 -2.2677691e+00  1.0480199e+00]
#  [-3.4591463e+00 -3.3171456e+00  4.3166208e+00]
#  [-2.6688061e+00 -1.0926188e+00  7.8862756e-01]
#  [-2.1969569e+00 -4.6690197e+00  2.1456134e+00]
#  [-1.9329295e+00 -2.9503810e+00  1.0989702e+00]
#  [-3.7405403e+00 -5.8001666e+00  4.6719909e+00]
#  [-3.9619260e+00 -4.0323744e+00  3.6624265e+00]
#  [-2.2024462e+00 -4.2586446e+00  3.1847959e+00]
#  [-5.1726599e+00 -4.5142884e+00  5.8919063e+00]
#  [-4.4515233e+00 -3.7311730e+00  2.5047209e+00]
#  [-1.8040314e+00 -4.1955266e+00  1.0480193e+00]
#  [-2.6201003e+00 -5.4313664e+00  3.3179495e+00]
#  [-3.9742379e+00 -5.0930533e+00  4.6615562e+00]
#  [-3.4823339e+00 -4.5337219e+00  3.8998499e+00]
#  [-3.8858020e+00 -2.5627487e+00  2.4497006e+00]
#  [-2.8461452e+00 -3.9637558e+00  3.8545840e+00]
#  [-4.0371675e+00 -4.8431039e+00  4.6027780e+00]
#  [-3.9187858e+00 -3.1700957e+00  3.9702632e+00]
#  [-3.3504655e+00 -4.2666821e+00  2.8769538e+00]
#  [-5.5023851e+00 -4.5059600e+00  4.6208777e+00]
#  [-2.0549624e+00 -3.9243724e+00  2.3902464e+00]
#  [-3.9887865e+00 -4.9749713e+00  4.9334574e+00]
#  [-3.3008473e+00 -2.3764575e+00  1.8133752e+00]
#  [-1.3726692e+00 -5.0191236e+00  1.5263476e+00]
#  [-2.6877980e+00 -4.3332081e+00  3.2530305e+00]
#  [-2.5768638e+00 -1.8308020e+00  1.0921141e+00]
#  [-3.3854015e+00 -3.9643419e+00  3.5582571e+00]
#  [-3.4629667e+00 -3.3573534e+00  3.2716868e+00]
#  [-2.5901520e+00 -3.5711944e+00  2.5603468e+00]
#  [-3.0719619e+00 -4.1383481e+00  3.3862536e+00]
#  [-3.9266438e+00 -4.9907899e+00  3.9215415e+00]
#  [-2.7118571e+00 -1.6288489e+00  3.2322463e-01]
#  [-3.4630201e+00 -2.0892727e+00  1.6630744e+00]
#  [-3.9325776e+00 -1.0298322e+00  9.4475746e-01]
#  [-3.3360617e+00 -2.9786022e+00  3.8168771e+00]
#  [-1.3452317e+00 -3.4707794e+00  1.1504272e+00]
#  [-2.8488052e+00 -4.8097897e+00  3.3580699e+00]
#  [-3.2565997e+00 -4.2619991e+00  3.7464402e+00]
#  [-2.7796743e+00 -3.9822934e+00  1.2736599e+00]
#  [-5.3149853e+00 -3.8733311e+00  4.6200428e+00]
#  [-3.6237528e+00 -3.1978269e+00  3.7248590e+00]
#  [-4.8492193e+00 -1.0409677e+00  5.8299679e-01]
#  [-1.2183172e+00 -6.1719503e+00  7.6833463e-01]
#  [-2.7497201e+00 -4.0422955e+00  3.0478737e+00]
#  [-4.6152363e+00 -5.0690470e+00  4.9608450e+00]
#  [-3.8128426e+00 -5.5122824e+00  4.6741519e+00]
#  [-1.8923690e+00 -3.2842114e+00  7.8856164e-01]
#  [-2.7273443e+00 -4.0464320e+00  3.4531076e+00]
#  [-3.2374442e+00 -5.9417253e+00  4.1450195e+00]
#  [-1.9981315e+00 -3.0908175e+00  2.5966485e+00]
#  [-3.0392942e+00 -3.8482580e+00  3.2629921e+00]
#  [-1.2733557e+00 -3.9313877e+00  1.0995924e+00]
#  [-4.7955031e+00 -4.3802052e+00  5.0556960e+00]
#  [-3.5169823e+00 -4.3744583e+00  3.9405968e+00]
#  [-2.9751675e+00 -4.4599104e+00  2.7423327e+00]
#  [-3.8372109e+00 -4.4233098e+00  3.5909913e+00]
#  [-5.7673130e+00  2.1328256e+00 -2.7206490e+00]
#  [-5.3905096e+00 -2.8099809e+00  3.4899688e+00]
#  [-4.2056584e+00 -3.9782753e+00  4.6711612e+00]
#  [-4.2601180e+00 -3.0152481e+00  1.7544732e+00]
#  [-4.6728725e+00 -4.6377015e+00  4.8842378e+00]
#  [-1.7368102e+00 -5.2545357e+00  1.6183311e+00]
#  [-3.3737366e+00 -5.0584126e+00  3.3709345e+00]
#  [-6.2915931e+00  4.2024374e+00 -4.7112064e+00]
#  [-8.7282240e-01 -4.1532407e+00 -7.6124430e-02]
#  [-2.3069489e+00 -5.0136013e+00  2.9941504e+00]
#  [-3.1565270e+00 -4.3924766e+00  4.0311303e+00]
#  [-4.5085983e+00  1.0296601e+00 -1.0617809e+00]
#  [ 6.8114519e-01 -4.9495993e+00 -1.5129334e+00]
#  [-3.7524993e+00 -3.0270617e+00  3.8602898e+00]
#  [-4.1817446e+00 -3.8333538e+00  3.8411973e+00]
#  [-3.2349885e+00 -5.2497997e+00  3.5391614e+00]
#  [-4.6705132e+00 -3.8804755e+00  4.9178534e+00]
#  [-2.9913228e+00 -3.4994016e+00  3.3720725e+00]
#  [-4.6374235e+00 -3.6026065e+00  4.1886225e+00]
#  [-4.1563387e+00 -3.3976209e+00  3.2023170e+00]
#  [-2.6882646e+00 -3.2679791e+00  2.9686682e+00]
#  [-4.0293026e+00 -4.2704253e+00  3.8424058e+00]
#  [-3.1611416e+00 -3.7060354e+00  3.2001331e+00]
#  [-1.0595834e+00 -5.7684064e+00  5.7523018e-01]
#  [-4.9018211e+00 -3.0264242e+00  4.1141858e+00]
#  [-3.2969356e+00 -4.4002485e+00  3.2658620e+00]
#  [-1.6816121e+00  8.1706643e-01 -3.7275524e+00]
#  [-3.8216584e+00 -4.4351406e+00  4.2404885e+00]
#  [-4.1105194e+00 -3.7659540e+00  5.1548467e+00]
#  [-3.6756217e+00 -2.8758171e+00  2.1129923e+00]
#  [-3.8465509e+00 -2.2289484e+00  2.6027350e+00]
#  [-1.4018546e+00 -3.7701457e+00  1.9383270e+00]
#  [-3.3815553e+00 -8.2382941e-01  1.1932688e+00]
#  [-4.1643124e+00 -3.9164953e+00  4.4739723e+00]
#  [-2.8534620e+00 -4.3967299e+00  2.9887373e+00]
#  [-2.6076168e-01 -5.7251310e+00  4.0016678e-01]
#  [-1.6027185e+00 -3.7766650e+00  2.2132072e+00]
#  [-9.6562231e-01 -2.9711940e+00  1.1929560e+00]
#  [-4.6058741e+00 -4.1124353e+00  5.0279241e+00]
#  [-3.6991804e+00 -4.1497536e+00  3.5019655e+00]
#  [-3.2620647e+00 -2.1692612e+00  2.2860579e+00]
#  [-3.8971987e+00 -4.7107296e+00  4.3853364e+00]
#  [-2.4961252e+00 -4.8559804e+00  2.8063951e+00]
#  [-1.8394740e+00 -2.2961178e+00  1.0012786e+00]
#  [-3.6175065e+00 -4.8151846e+00  4.1298966e+00]
#  [-1.0967007e+00 -3.4633663e+00  1.2584155e+00]
#  [-2.1365337e+00 -3.5818105e+00  2.5045125e+00]
#  [-4.4303269e+00 -4.1026192e+00  3.9027581e+00]
#  [-2.5007558e+00 -4.1183343e+00  2.5105624e+00]
#  [-4.8224201e+00 -4.7870469e+00  5.1671834e+00]
#  [-2.7714937e+00 -6.0819759e+00  3.5816381e+00]
#  [-8.3182454e-01 -4.7858958e+00  8.6316198e-01]
#  [-2.5963500e+00 -3.7506301e+00  2.6353822e+00]
#  [-3.6067259e+00 -3.9006634e+00  4.4451823e+00]
#  [-3.7851040e+00 -3.6032593e+00  4.3545494e+00]
#  [-1.7586812e+00 -3.8306079e+00  1.1056230e+00]
#  [-2.6594541e+00 -3.6592138e+00  2.5377979e+00]
#  [-4.4378386e+00 -4.2503200e+00  4.0650434e+00]
#  [-3.1499128e+00 -3.5717108e+00  3.1085172e+00]
#  [-2.6985829e+00 -3.8073933e+00  1.7917811e+00]
#  [-3.4443915e+00 -4.7405906e+00  3.5179110e+00]
#  [-2.5918775e+00 -4.7718382e+00  3.3644414e+00]
#  [-4.4360995e+00 -4.2817006e+00  3.8292882e+00]
#  [-4.2081399e+00 -3.2722585e+00  4.0943480e+00]
#  [-3.8756187e+00 -3.5489712e+00  2.9797869e+00]
#  [ 7.8987765e-01 -4.1432371e+00 -1.4658873e+00]
#  [-1.5960305e+00 -4.6189008e+00  7.5672936e-01]
#  [-2.8211007e+00 -4.0519705e+00  2.5693676e+00]
#  [-2.9175079e+00 -3.9107530e+00  2.7986710e+00]
#  [-3.8808248e+00 -3.7059467e+00  3.7726672e+00]
#  [-3.5782902e+00 -5.0485177e+00  3.7412241e+00]
#  [-3.1092174e+00 -4.4093709e+00  3.2256713e+00]
#  [-3.8461125e+00 -4.5403495e+00  4.1181326e+00]
#  [-2.5751913e+00 -4.0515332e+00  2.3908579e+00]
#  [-3.3223040e+00 -3.2327793e+00  2.5131602e+00]
#  [-2.7974665e-01 -5.5130730e+00 -5.8238792e-01]
#  [-1.2395052e+00 -6.0839009e+00  1.4743309e+00]
#  [-2.7295179e+00 -3.1929567e+00  3.1317134e+00]
#  [-4.4747796e+00 -3.5655367e+00  4.5707245e+00]
#  [-1.0619447e+00 -2.1267331e+00 -3.0091590e-01]
#  [-3.8860838e+00 -3.3248394e+00  4.2155790e+00]
#  [-5.1346974e+00 -3.7595952e+00  3.8830743e+00]
#  [-4.2677226e+00 -4.1070428e+00  4.4243693e+00]
#  [-4.7464356e+00 -4.7574658e+00  4.4381557e+00]
#  [-3.2917373e+00 -3.7865531e+00  3.0837653e+00]
#  [-4.0023856e+00 -3.7380655e+00  3.3060439e+00]
#  [-3.3268750e+00 -3.3473508e+00  2.7985325e+00]
#  [-4.2990694e+00 -4.5854716e+00  4.0151048e+00]
#  [-4.6101980e+00 -5.1165752e+00  4.5656786e+00]]
# Counter({2: 235, 0: 10, 1: 6})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in validation_y]
Counter(actual)
# Out:
# Counter({2: 228, 1: 13, 0: 10})

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold))
# Out:
# number of predictions: 251
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 12
# actual sells but predicted buy: 0
# actual predicted sells: 1
# actual sells but predicted hold: 9
# actual holds but predicted buy: 5
# actual holds but predicted sell: 9
# actual predicted holds: 214
# Percentage buys correct: 7.6923076923076925%
# Percentage sells correct: 10.0%
# Percentage holds correct: 93.85964912280701%
# actual buys: 13
# actual sells: 10
# actual holds: 228

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.figure(figsize=(20,10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.figure(figsize=(20,10))
plt.plot(history.history['mse'])
plt.plot(history.history['val_mse'])
plt.title('M.S.E')
plt.ylabel('m.s.e')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Save model
model.save("models/{}".format('midea_image_lstm_buy_hold_sell_original.model'))
# Out:
# INFO:tensorflow:Assets written to: models/midea_image_lstm_buy_hold_sell_original.model\assets

# %% [markdown]
# ### Test Performance

# %% [markdown]
# ### non-recession

# %%
seed = 10
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/000333.SZ_data_test.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2019-01-22    42.090000  39.647816 -10.142844  258783172.0     2.0
# 2019-01-23    41.299999  39.901998 -21.428571  234314954.0     2.0
# 2019-01-24    41.459999  40.141691 -19.142859  253542262.0     2.0
# 2019-01-25    41.590000  40.364507 -19.706827  275498548.0     2.0
# 2019-01-28    41.900002  40.600737 -14.705848  302253363.0     2.0

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/midea_image_lstm_buy_hold_sell_original.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3620 - accuracy: 0.8261 - mean_squared_error: 11.8312 - weighted_accuracy: 0.8261 - weighted_mean_squared_error: 11.8312
# Test loss: 0.36204010248184204
# Test accuracy: 0.8260869383811951

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 190, 0: 11, 1: 6})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]
Counter(actual)
# Out:
# Counter({2: 186, 0: 10, 1: 11})

# %%
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/000333.SZ_data_test.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14        OBV_7  labels  \
# Date
# 2019-02-18    46.400002  44.456141 -30.862341  419918481.0     2.0
# 2019-02-19    46.080002  44.755197 -13.767016  452488699.0     2.0
# 2019-02-20    46.080002  44.959013 -18.975880  424412835.0     2.0
# 2019-02-21    45.860001  45.131473 -18.975880  424412835.0     2.0
# 2019-02-22    45.610001  45.243554 -26.174460  382970560.0     2.0
#
#             predictions  actual
# Date
# 2019-02-18            2       2
# 2019-02-19            2       2
# 2019-02-20            2       2
# 2019-02-21            2       2
# 2019-02-22            2       2

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold))
# Out:
# number of predictions: 207
# actual predicted buys: 0
# actual buys but predicted sell: 0
# actual buys but predicted hold: 11
# actual sells but predicted buy: 0
# actual predicted sells: 1
# actual sells but predicted hold: 9
# actual holds but predicted buy: 6
# actual holds but predicted sell: 10
# actual predicted holds: 170
# Percentage buys correct: 0.0%
# Percentage sells correct: 10.0%
# Percentage holds correct: 91.39784946236558%
# actual buys: 11
# actual sells: 10
# actual holds: 186

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%")
# Out:
# [45.61000061035156, 45.86000061035156, 46.08000183105469, 46.08000183105469, 46.4000015258789, 47.36000061035156, 47.63999938964844, 47.77999877929688, 49.16999816894531]
# [45.79999923706055, 47.36000061035156, 47.56000137329102, 47.63999938964844, 47.77999877929688, 48.56999969482422, 48.959999084472656, 49.0, 49.099998474121094]
# Percentage buys correct: 50.0%
# Percentage sells correct: 45.45454545454545%
# Percentage holds correct: 78.3068783068783%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
#         print(i)
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $52.599998474121094
# Shares owned at the moment: 189
# Cash capital at the moment: $31.26143918418893
#
#
# Stop Loss Activated!
#
# Share price: $49.36999893188477
# Shares owned at the moment: 0
# Cash capital at the moment: $9336.531180365564
#
#
# Share price: $49.70000076293945
# Shares owned at the moment: 187
# Cash capital at the moment: $17.072812303544197
#
#
# Price increase from previously bought: 8.534526675902864%
# Share price: $54.09000015258789
# Shares owned at the moment: 0
# Cash capital at the moment: $10104.08705825901
#
#
# Share price: $50.31999969482422
# Shares owned at the moment: 200
# Cash capital at the moment: $12.41111946201272
#
#
# Price increase from previously bought: 7.435077014442637%
# Share price: $54.209999084472656
# Shares owned at the moment: 0
# Cash capital at the moment: $10824.595436860083
#
#
# Share price: $58.88999938964844
# Shares owned at the moment: 183
# Cash capital at the moment: $18.089156361578716
#
#
# Stop Loss Activated!
#
# Share price: $57.20000076293945
# Shares owned at the moment: 0
# Cash capital at the moment: $10456.90339559555
#
#
# Share price: $56.20000076293945
# Shares owned at the moment: 185
# Cash capital at the moment: $31.311504063603934
#
#
# Stop Loss Activated!
#
# Share price: $54.29999923706055
# Shares owned at the moment: 0
# Cash capital at the moment: $10049.18623830795
#
#
#
#
# Capital at the end of test period: $10049.18623830795
# profit gained: 0.4918623830794968%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $12438.033583332062
# profit gained: 24.380335833320625%

# %% [markdown]
# ### recession

# %%
seed = 10
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/000333.SZ_data_test2.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22    58.099998  59.163333 -58.000031  68400881.0     2.0
# 2020-01-23    57.480000  58.904359 -70.400009  27240262.0     2.0
# 2020-02-03    55.029999  58.308304 -99.500020 -27633268.0     1.0
# 2020-02-04    50.189999  57.059334 -94.741468 -98139988.0     2.0
# 2020-02-05    52.790001  56.402513 -71.954419 -57726889.0     2.0

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/midea_image_lstm_buy_hold_sell_original.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2778 - accuracy: 0.8558 - mean_squared_error: 11.1530 - weighted_accuracy: 0.8558 - weighted_mean_squared_error: 11.1530
# Test loss: 0.2777709364891052
# Test accuracy: 0.8557692170143127

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 191, 1: 5, 0: 12})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]
Counter(actual)
# Out:
# Counter({2: 193, 0: 8, 1: 7})

# %%
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/000333.SZ_data_test2.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels  \
# Date
# 2020-02-19    53.540001  54.301035 -52.927131 -33290149.0     2.0
# 2020-02-20    54.860001  54.183953 -44.755246  -9557295.0     2.0
# 2020-02-21    54.279999  54.287960  -8.665511  27483857.0     2.0
# 2020-02-24    54.910000  54.286736 -21.343904  -2296012.0     0.0
# 2020-02-25    54.430000  54.382622 -12.602723  38486402.0     2.0
#
#             predictions  actual
# Date
# 2020-02-19            2       2
# 2020-02-20            1       2
# 2020-02-21            2       2
# 2020-02-24            2       0
# 2020-02-25            2       2

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold))
# Out:
# number of predictions: 208
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 6
# actual sells but predicted buy: 0
# actual predicted sells: 0
# actual sells but predicted hold: 8
# actual holds but predicted buy: 4
# actual holds but predicted sell: 12
# actual predicted holds: 177
# Percentage buys correct: 14.285714285714286%
# Percentage sells correct: 0.0%
# Percentage holds correct: 91.70984455958549%
# actual buys: 7
# actual sells: 8
# actual holds: 193

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%")
# Out:
# [53.04999923706055, 53.540000915527344, 54.27999877929688, 54.29999923706055, 54.34000015258789, 54.43000030517578, 54.86000061035156, 54.90999984741211, 54.90999984741211]
# [53.04999923706055, 53.88999938964844, 54.25, 54.34000015258789, 54.5, 54.90999984741211, 55.54999923706055, 55.79999923706055, 56.540000915527344]
# Percentage buys correct: 80.0%
# Percentage sells correct: 33.333333333333336%
# Percentage holds correct: 84.73684210526316%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
#         print(i)
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
#         print(i)
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $54.86000061035156
# Shares owned at the moment: 181
# Cash capital at the moment: $43.03332422256426
#
#
# Stop Loss Activated!
#
# Share price: $53.04999923706055
# Shares owned at the moment: 0
# Cash capital at the moment: $9618.677549010275
#
#
# Share price: $46.540000915527344
# Shares owned at the moment: 206
# Cash capital at the moment: $5.072449892995792
#
#
# Price increase from previously bought: 7.268399071695075%
# Share price: $50.06000137329102
# Shares owned at the moment: 0
# Cash capital at the moment: $10289.073742012977
#
#
# Share price: $69.37000274658203
# Shares owned at the moment: 147
# Cash capital at the moment: $63.64051465511329
#
#
# Stop Loss Activated!
#
# Share price: $66.69999694824219
# Shares owned at the moment: 0
# Cash capital at the moment: $9841.576592280388
#
#
# Share price: $65.87000274658203
# Shares owned at the moment: 148
# Cash capital at the moment: $66.00709466838816
#
#
# Price increase from previously bought: 6.432678466474706%
# Share price: $70.30000305175781
# Shares owned at the moment: 0
# Cash capital at the moment: $10441.795445086478
#
#
# Share price: $77.0999984741211
# Shares owned at the moment: 135
# Cash capital at the moment: $4.672276646611863
#
#
# Price increase from previously bought: 15.971616881800955%
# Share price: $89.66000366210938
# Shares owned at the moment: 0
# Cash capital at the moment: $12075.486494671819
#
#
#
#
# Capital at the end of test period: $12075.486494671819
# profit gained: 20.75486494671819%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $16487.407351390837
# profit gained: 64.87407351390837%

# %% [markdown]
# ## Walmart

# %%
seed = 10
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/WMT_data.csv")
print(df.head())
# Out:
#          Date  previous_1d     EMA_12   willr_14       OBV_7  labels
# 0  2000-01-21      63.3750  65.176128 -85.271318 -26649200.0     2.0
# 1  2000-01-24      62.4375  64.754801 -94.594595 -33601700.0     2.0
# 2  2000-01-25      59.3750  63.927139 -83.606557 -41401600.0     2.0
# 3  2000-01-26      61.1250  63.496041 -68.306011 -34997800.0     2.0
# 4  2000-01-27      61.9375  63.256265 -61.202186 -30459400.0     2.0

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['labels'].plot(figsize=(16,6),x='Date', y='labels')

# %%
df.set_index('Date', inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2000-01-21      63.3750  65.176128 -85.271318 -26649200.0     2.0
# 2000-01-24      62.4375  64.754801 -94.594595 -33601700.0     2.0
# 2000-01-25      59.3750  63.927139 -83.606557 -41401600.0     2.0
# 2000-01-26      61.1250  63.496041 -68.306011 -34997800.0     2.0
# 2000-01-27      61.9375  63.256265 -61.202186 -30459400.0     2.0

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1

# %%
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64)
y = np.array(y)

X.shape
# Out:
# (4745, 64, 64)

# %%
# plot the image array X
i = X[0].reshape(64, 64)
fig2, ax2 = plt.subplots()
plt.imshow(i, interpolation="none", cmap="gray")

ax2.axis('off')

plt.show()

# %%
X = X/255

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization,Activation
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(LSTM(100, input_shape=(X_train.shape[1:]), return_sequences=True,kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(LSTM(100, kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# model.add(Dense(100, kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))

model.add(Dense(75, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(50, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa
opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

#tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "LSTM_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))

# Train model
history = model.fit(
    train_x, train_y,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    shuffle = True,
    validation_data=(validation_x, validation_y),
    #callbacks=[tensorboard],
    class_weight=d_class_weights
)
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 2 ... 0 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# Epoch 1/200
# 30/30 [==============================] - 1s 43ms/step - loss: 0.2784 - accuracy: 0.5071 - mse: 0.4294 - weighted_accuracy: 0.3724 - weighted_mse: 0.4745 - val_loss: 0.2887 - val_accuracy: 0.9083 - val_mse: 0.3507 - val_weighted_accuracy: 0.9083 - val_weighted_mse: 0.3507
# Epoch 2/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.2169 - accuracy: 0.3783 - mse: 0.7081 - weighted_accuracy: 0.4357 - weighted_mse: 0.6964 - val_loss: 0.2876 - val_accuracy: 0.0453 - val_mse: 0.3847 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.3847
# Epoch 3/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1910 - accuracy: 0.3604 - mse: 0.9698 - weighted_accuracy: 0.4776 - weighted_mse: 0.9409 - val_loss: 0.2768 - val_accuracy: 0.2424 - val_mse: 0.3910 - val_weighted_accuracy: 0.2424 - val_weighted_mse: 0.3910
# Epoch 4/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1800 - accuracy: 0.3193 - mse: 1.1631 - weighted_accuracy: 0.5255 - weighted_mse: 1.1135 - val_loss: 0.2630 - val_accuracy: 0.9083 - val_mse: 0.4011 - val_weighted_accuracy: 0.9083 - val_weighted_mse: 0.4011
# Epoch 5/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1746 - accuracy: 0.2742 - mse: 1.2778 - weighted_accuracy: 0.5430 - weighted_mse: 1.2132 - val_loss: 0.2596 - val_accuracy: 0.0453 - val_mse: 0.4610 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.4610
# Epoch 6/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1703 - accuracy: 0.2792 - mse: 1.3312 - weighted_accuracy: 0.5683 - weighted_mse: 1.2611 - val_loss: 0.2346 - val_accuracy: 0.8577 - val_mse: 0.4967 - val_weighted_accuracy: 0.8577 - val_weighted_mse: 0.4967
# Epoch 7/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1658 - accuracy: 0.2924 - mse: 1.3955 - weighted_accuracy: 0.5915 - weighted_mse: 1.3278 - val_loss: 0.2277 - val_accuracy: 0.1528 - val_mse: 0.5601 - val_weighted_accuracy: 0.1528 - val_weighted_mse: 0.5601
# Epoch 8/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1632 - accuracy: 0.3135 - mse: 1.4061 - weighted_accuracy: 0.6062 - weighted_mse: 1.3488 - val_loss: 0.2157 - val_accuracy: 0.5469 - val_mse: 0.6111 - val_weighted_accuracy: 0.5469 - val_weighted_mse: 0.6111
# Epoch 9/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1598 - accuracy: 0.3188 - mse: 1.4263 - weighted_accuracy: 0.6154 - weighted_mse: 1.3678 - val_loss: 0.2339 - val_accuracy: 0.3604 - val_mse: 0.5389 - val_weighted_accuracy: 0.3604 - val_weighted_mse: 0.5389
# Epoch 10/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1574 - accuracy: 0.3335 - mse: 1.4518 - weighted_accuracy: 0.6154 - weighted_mse: 1.3991 - val_loss: 0.2085 - val_accuracy: 0.8040 - val_mse: 0.6032 - val_weighted_accuracy: 0.8040 - val_weighted_mse: 0.6032
# Epoch 11/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1547 - accuracy: 0.3174 - mse: 1.4966 - weighted_accuracy: 0.6259 - weighted_mse: 1.4228 - val_loss: 0.1889 - val_accuracy: 0.6649 - val_mse: 0.7450 - val_weighted_accuracy: 0.6649 - val_weighted_mse: 0.7450
# Epoch 12/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1517 - accuracy: 0.3517 - mse: 1.5071 - weighted_accuracy: 0.6440 - weighted_mse: 1.4519 - val_loss: 0.1886 - val_accuracy: 0.6175 - val_mse: 0.7873 - val_weighted_accuracy: 0.6175 - val_weighted_mse: 0.7873
# Epoch 13/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1501 - accuracy: 0.3883 - mse: 1.4990 - weighted_accuracy: 0.6539 - weighted_mse: 1.4513 - val_loss: 0.2061 - val_accuracy: 0.3024 - val_mse: 0.8264 - val_weighted_accuracy: 0.3024 - val_weighted_mse: 0.8264
# Epoch 14/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1482 - accuracy: 0.3662 - mse: 1.5346 - weighted_accuracy: 0.6602 - weighted_mse: 1.4733 - val_loss: 0.1896 - val_accuracy: 0.4889 - val_mse: 0.7856 - val_weighted_accuracy: 0.4889 - val_weighted_mse: 0.7856
# Epoch 15/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1445 - accuracy: 0.3638 - mse: 1.5836 - weighted_accuracy: 0.6794 - weighted_mse: 1.5202 - val_loss: 0.2191 - val_accuracy: 0.1128 - val_mse: 1.2341 - val_weighted_accuracy: 0.1128 - val_weighted_mse: 1.2341
# Epoch 16/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1429 - accuracy: 0.4297 - mse: 1.5594 - weighted_accuracy: 0.6872 - weighted_mse: 1.5215 - val_loss: 0.2106 - val_accuracy: 0.1496 - val_mse: 1.0922 - val_weighted_accuracy: 0.1496 - val_weighted_mse: 1.0922
# Epoch 17/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1407 - accuracy: 0.4228 - mse: 1.6063 - weighted_accuracy: 0.6939 - weighted_mse: 1.5651 - val_loss: 0.2543 - val_accuracy: 0.1117 - val_mse: 1.4362 - val_weighted_accuracy: 0.1117 - val_weighted_mse: 1.4362
# Epoch 18/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1383 - accuracy: 0.4110 - mse: 1.6257 - weighted_accuracy: 0.6930 - weighted_mse: 1.5878 - val_loss: 0.3092 - val_accuracy: 0.0580 - val_mse: 1.8338 - val_weighted_accuracy: 0.0580 - val_weighted_mse: 1.8338
# Epoch 19/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1357 - accuracy: 0.4299 - mse: 1.6567 - weighted_accuracy: 0.7109 - weighted_mse: 1.6154 - val_loss: 0.2642 - val_accuracy: 0.2297 - val_mse: 1.3300 - val_weighted_accuracy: 0.2297 - val_weighted_mse: 1.3300
# Epoch 20/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1335 - accuracy: 0.4658 - mse: 1.6720 - weighted_accuracy: 0.7153 - weighted_mse: 1.6510 - val_loss: 0.2005 - val_accuracy: 0.2877 - val_mse: 1.6616 - val_weighted_accuracy: 0.2877 - val_weighted_mse: 1.6616
# Epoch 21/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1318 - accuracy: 0.4918 - mse: 1.7052 - weighted_accuracy: 0.7319 - weighted_mse: 1.6864 - val_loss: 0.2027 - val_accuracy: 0.4394 - val_mse: 2.6228 - val_weighted_accuracy: 0.4394 - val_weighted_mse: 2.6228
# Epoch 22/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1300 - accuracy: 0.5140 - mse: 1.6989 - weighted_accuracy: 0.7401 - weighted_mse: 1.6955 - val_loss: 0.1915 - val_accuracy: 0.4162 - val_mse: 2.8021 - val_weighted_accuracy: 0.4162 - val_weighted_mse: 2.8021
# Epoch 23/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1265 - accuracy: 0.4932 - mse: 1.7681 - weighted_accuracy: 0.7416 - weighted_mse: 1.7540 - val_loss: 0.1406 - val_accuracy: 0.7302 - val_mse: 2.2465 - val_weighted_accuracy: 0.7302 - val_weighted_mse: 2.2465
# Epoch 24/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1232 - accuracy: 0.5219 - mse: 1.8012 - weighted_accuracy: 0.7717 - weighted_mse: 1.7933 - val_loss: 0.1997 - val_accuracy: 0.4742 - val_mse: 2.2724 - val_weighted_accuracy: 0.4742 - val_weighted_mse: 2.2724
# Epoch 25/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1212 - accuracy: 0.5324 - mse: 1.8409 - weighted_accuracy: 0.7721 - weighted_mse: 1.8479 - val_loss: 0.1750 - val_accuracy: 0.6238 - val_mse: 2.1817 - val_weighted_accuracy: 0.6238 - val_weighted_mse: 2.1817
# Epoch 26/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1185 - accuracy: 0.5653 - mse: 1.8479 - weighted_accuracy: 0.7914 - weighted_mse: 1.8742 - val_loss: 0.1762 - val_accuracy: 0.5880 - val_mse: 3.4205 - val_weighted_accuracy: 0.5880 - val_weighted_mse: 3.4205
# Epoch 27/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1155 - accuracy: 0.5659 - mse: 1.9066 - weighted_accuracy: 0.7879 - weighted_mse: 1.9334 - val_loss: 0.1178 - val_accuracy: 0.7987 - val_mse: 2.1011 - val_weighted_accuracy: 0.7987 - val_weighted_mse: 2.1011
# Epoch 28/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1133 - accuracy: 0.5930 - mse: 1.9630 - weighted_accuracy: 0.8125 - weighted_mse: 1.9967 - val_loss: 0.2420 - val_accuracy: 0.4542 - val_mse: 3.2582 - val_weighted_accuracy: 0.4542 - val_weighted_mse: 3.2582
# Epoch 29/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1080 - accuracy: 0.6159 - mse: 1.9957 - weighted_accuracy: 0.8192 - weighted_mse: 2.0613 - val_loss: 0.1573 - val_accuracy: 0.6733 - val_mse: 4.4210 - val_weighted_accuracy: 0.6733 - val_weighted_mse: 4.4210
# Epoch 30/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1056 - accuracy: 0.6322 - mse: 2.0409 - weighted_accuracy: 0.8177 - weighted_mse: 2.1335 - val_loss: 0.1627 - val_accuracy: 0.7524 - val_mse: 4.6448 - val_weighted_accuracy: 0.7524 - val_weighted_mse: 4.6448
# Epoch 31/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1009 - accuracy: 0.6615 - mse: 2.1210 - weighted_accuracy: 0.8412 - weighted_mse: 2.2345 - val_loss: 0.1475 - val_accuracy: 0.7471 - val_mse: 4.3681 - val_weighted_accuracy: 0.7471 - val_weighted_mse: 4.3681
# Epoch 32/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0993 - accuracy: 0.6783 - mse: 2.1312 - weighted_accuracy: 0.8493 - weighted_mse: 2.2617 - val_loss: 0.3178 - val_accuracy: 0.3087 - val_mse: 8.5356 - val_weighted_accuracy: 0.3087 - val_weighted_mse: 8.5356
# Epoch 33/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0950 - accuracy: 0.6957 - mse: 2.2199 - weighted_accuracy: 0.8684 - weighted_mse: 2.3408 - val_loss: 0.3681 - val_accuracy: 0.3066 - val_mse: 6.7746 - val_weighted_accuracy: 0.3066 - val_weighted_mse: 6.7746
# Epoch 34/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0908 - accuracy: 0.7089 - mse: 2.2656 - weighted_accuracy: 0.8731 - weighted_mse: 2.4159 - val_loss: 0.1908 - val_accuracy: 0.9062 - val_mse: 8.7627 - val_weighted_accuracy: 0.9062 - val_weighted_mse: 8.7627
# Epoch 35/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0884 - accuracy: 0.7168 - mse: 2.3834 - weighted_accuracy: 0.8742 - weighted_mse: 2.5684 - val_loss: 0.2231 - val_accuracy: 0.9083 - val_mse: 7.3465 - val_weighted_accuracy: 0.9083 - val_weighted_mse: 7.3465
# Epoch 36/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0847 - accuracy: 0.7471 - mse: 2.4120 - weighted_accuracy: 0.8817 - weighted_mse: 2.6385 - val_loss: 0.1425 - val_accuracy: 0.7903 - val_mse: 4.8402 - val_weighted_accuracy: 0.7903 - val_weighted_mse: 4.8402
# Epoch 37/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0803 - accuracy: 0.7555 - mse: 2.4957 - weighted_accuracy: 0.8958 - weighted_mse: 2.7290 - val_loss: 0.1339 - val_accuracy: 0.7587 - val_mse: 4.0492 - val_weighted_accuracy: 0.7587 - val_weighted_mse: 4.0492
# Epoch 38/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0760 - accuracy: 0.7748 - mse: 2.5796 - weighted_accuracy: 0.9082 - weighted_mse: 2.8432 - val_loss: 0.1327 - val_accuracy: 0.8546 - val_mse: 7.0952 - val_weighted_accuracy: 0.8546 - val_weighted_mse: 7.0952
# Epoch 39/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0740 - accuracy: 0.7908 - mse: 2.6859 - weighted_accuracy: 0.9087 - weighted_mse: 2.9422 - val_loss: 0.2555 - val_accuracy: 0.9083 - val_mse: 18.7493 - val_weighted_accuracy: 0.9083 - val_weighted_mse: 18.7493
# Epoch 40/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0697 - accuracy: 0.7993 - mse: 2.7502 - weighted_accuracy: 0.9117 - weighted_mse: 3.0534 - val_loss: 0.2278 - val_accuracy: 0.9083 - val_mse: 9.9553 - val_weighted_accuracy: 0.9083 - val_weighted_mse: 9.9553
# Epoch 41/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0649 - accuracy: 0.8156 - mse: 2.8770 - weighted_accuracy: 0.9232 - weighted_mse: 3.1855 - val_loss: 0.2069 - val_accuracy: 0.7861 - val_mse: 8.5690 - val_weighted_accuracy: 0.7861 - val_weighted_mse: 8.5690
# Epoch 42/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0624 - accuracy: 0.8303 - mse: 3.0165 - weighted_accuracy: 0.9286 - weighted_mse: 3.3230 - val_loss: 0.2598 - val_accuracy: 0.9062 - val_mse: 13.2567 - val_weighted_accuracy: 0.9062 - val_weighted_mse: 13.2567
# Epoch 43/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0591 - accuracy: 0.8448 - mse: 3.1349 - weighted_accuracy: 0.9321 - weighted_mse: 3.4704 - val_loss: 0.2123 - val_accuracy: 0.8904 - val_mse: 9.9079 - val_weighted_accuracy: 0.8904 - val_weighted_mse: 9.9079
# Epoch 44/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0550 - accuracy: 0.8506 - mse: 3.2455 - weighted_accuracy: 0.9379 - weighted_mse: 3.6008 - val_loss: 0.1997 - val_accuracy: 0.9041 - val_mse: 7.2982 - val_weighted_accuracy: 0.9041 - val_weighted_mse: 7.2982
# Epoch 45/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0543 - accuracy: 0.8662 - mse: 3.4086 - weighted_accuracy: 0.9436 - weighted_mse: 3.7151 - val_loss: 0.2807 - val_accuracy: 0.9041 - val_mse: 18.1915 - val_weighted_accuracy: 0.9041 - val_weighted_mse: 18.1915
# Epoch 46/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0502 - accuracy: 0.8646 - mse: 3.5532 - weighted_accuracy: 0.9430 - weighted_mse: 3.9451 - val_loss: 0.1628 - val_accuracy: 0.8451 - val_mse: 9.4736 - val_weighted_accuracy: 0.8451 - val_weighted_mse: 9.4736
# Epoch 47/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0455 - accuracy: 0.8880 - mse: 3.7039 - weighted_accuracy: 0.9534 - weighted_mse: 4.0870 - val_loss: 0.1803 - val_accuracy: 0.8883 - val_mse: 7.5852 - val_weighted_accuracy: 0.8883 - val_weighted_mse: 7.5852
# Epoch 48/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0433 - accuracy: 0.8999 - mse: 3.9012 - weighted_accuracy: 0.9577 - weighted_mse: 4.2900 - val_loss: 0.1870 - val_accuracy: 0.7197 - val_mse: 4.5219 - val_weighted_accuracy: 0.7197 - val_weighted_mse: 4.5219
# Epoch 49/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0411 - accuracy: 0.8954 - mse: 4.0381 - weighted_accuracy: 0.9580 - weighted_mse: 4.4474 - val_loss: 0.3481 - val_accuracy: 0.9083 - val_mse: 18.3836 - val_weighted_accuracy: 0.9083 - val_weighted_mse: 18.3836
# Epoch 50/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0417 - accuracy: 0.9012 - mse: 4.2102 - weighted_accuracy: 0.9583 - weighted_mse: 4.5691 - val_loss: 0.1774 - val_accuracy: 0.8967 - val_mse: 7.1661 - val_weighted_accuracy: 0.8967 - val_weighted_mse: 7.1661
# Epoch 51/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0373 - accuracy: 0.9067 - mse: 4.3607 - weighted_accuracy: 0.9621 - weighted_mse: 4.7334 - val_loss: 0.1947 - val_accuracy: 0.8145 - val_mse: 7.9517 - val_weighted_accuracy: 0.8145 - val_weighted_mse: 7.9517
# Epoch 52/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0338 - accuracy: 0.9247 - mse: 4.6034 - weighted_accuracy: 0.9705 - weighted_mse: 4.9997 - val_loss: 0.4879 - val_accuracy: 0.4942 - val_mse: 7.6285 - val_weighted_accuracy: 0.4942 - val_weighted_mse: 7.6285
# Epoch 53/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0290 - accuracy: 0.9389 - mse: 4.7939 - weighted_accuracy: 0.9776 - weighted_mse: 5.2159 - val_loss: 0.2120 - val_accuracy: 0.8809 - val_mse: 7.9806 - val_weighted_accuracy: 0.8809 - val_weighted_mse: 7.9806
# Epoch 54/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0269 - accuracy: 0.9455 - mse: 5.0431 - weighted_accuracy: 0.9800 - weighted_mse: 5.3828 - val_loss: 0.2009 - val_accuracy: 0.8504 - val_mse: 7.6709 - val_weighted_accuracy: 0.8504 - val_weighted_mse: 7.6709
# Epoch 55/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0256 - accuracy: 0.9497 - mse: 5.3164 - weighted_accuracy: 0.9815 - weighted_mse: 5.5953 - val_loss: 0.2212 - val_accuracy: 0.8915 - val_mse: 10.5041 - val_weighted_accuracy: 0.8915 - val_weighted_mse: 10.5041
# Epoch 56/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0247 - accuracy: 0.9502 - mse: 5.5170 - weighted_accuracy: 0.9817 - weighted_mse: 5.8252 - val_loss: 0.2894 - val_accuracy: 0.8556 - val_mse: 12.0613 - val_weighted_accuracy: 0.8556 - val_weighted_mse: 12.0613
# Epoch 57/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0211 - accuracy: 0.9589 - mse: 5.7887 - weighted_accuracy: 0.9849 - weighted_mse: 6.1310 - val_loss: 0.1959 - val_accuracy: 0.8894 - val_mse: 8.8400 - val_weighted_accuracy: 0.8894 - val_weighted_mse: 8.8400
# Epoch 58/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0192 - accuracy: 0.9684 - mse: 6.1180 - weighted_accuracy: 0.9884 - weighted_mse: 6.3489 - val_loss: 0.3579 - val_accuracy: 0.6891 - val_mse: 9.7411 - val_weighted_accuracy: 0.6891 - val_weighted_mse: 9.7411
# Epoch 59/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0185 - accuracy: 0.9705 - mse: 6.4016 - weighted_accuracy: 0.9892 - weighted_mse: 6.5208 - val_loss: 0.2313 - val_accuracy: 0.8957 - val_mse: 12.2354 - val_weighted_accuracy: 0.8957 - val_weighted_mse: 12.2354
# Epoch 60/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0169 - accuracy: 0.9726 - mse: 6.5754 - weighted_accuracy: 0.9899 - weighted_mse: 6.8253 - val_loss: 0.2714 - val_accuracy: 0.8820 - val_mse: 12.2566 - val_weighted_accuracy: 0.8820 - val_weighted_mse: 12.2566
# Epoch 61/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0154 - accuracy: 0.9789 - mse: 6.9356 - weighted_accuracy: 0.9923 - weighted_mse: 7.1590 - val_loss: 0.4316 - val_accuracy: 0.7144 - val_mse: 11.8424 - val_weighted_accuracy: 0.7144 - val_weighted_mse: 11.8424
# Epoch 62/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0146 - accuracy: 0.9784 - mse: 7.2540 - weighted_accuracy: 0.9921 - weighted_mse: 7.4026 - val_loss: 0.2617 - val_accuracy: 0.8904 - val_mse: 13.2047 - val_weighted_accuracy: 0.8904 - val_weighted_mse: 13.2047
# Epoch 63/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0134 - accuracy: 0.9852 - mse: 7.5057 - weighted_accuracy: 0.9946 - weighted_mse: 7.5271 - val_loss: 0.2901 - val_accuracy: 0.7787 - val_mse: 10.8204 - val_weighted_accuracy: 0.7787 - val_weighted_mse: 10.8204
# Epoch 64/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0130 - accuracy: 0.9821 - mse: 7.7066 - weighted_accuracy: 0.9934 - weighted_mse: 7.8117 - val_loss: 0.5936 - val_accuracy: 0.5395 - val_mse: 13.1896 - val_weighted_accuracy: 0.5395 - val_weighted_mse: 13.1896
# Epoch 65/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0121 - accuracy: 0.9871 - mse: 8.0847 - weighted_accuracy: 0.9953 - weighted_mse: 8.0982 - val_loss: 0.3766 - val_accuracy: 0.8946 - val_mse: 22.1054 - val_weighted_accuracy: 0.8946 - val_weighted_mse: 22.1054
# Epoch 66/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0205 - accuracy: 0.9626 - mse: 8.1978 - weighted_accuracy: 0.9809 - weighted_mse: 7.8903 - val_loss: 0.2909 - val_accuracy: 0.9052 - val_mse: 29.3894 - val_weighted_accuracy: 0.9052 - val_weighted_mse: 29.3894
# Epoch 67/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0241 - accuracy: 0.9552 - mse: 8.1064 - weighted_accuracy: 0.9710 - weighted_mse: 8.2904 - val_loss: 1.1974 - val_accuracy: 0.1960 - val_mse: 16.8571 - val_weighted_accuracy: 0.1960 - val_weighted_mse: 16.8571
# Epoch 68/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0453 - accuracy: 0.9033 - mse: 7.7826 - weighted_accuracy: 0.9374 - weighted_mse: 7.9921 - val_loss: 0.2700 - val_accuracy: 0.6575 - val_mse: 9.0847 - val_weighted_accuracy: 0.6575 - val_weighted_mse: 9.0847
# Epoch 69/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0436 - accuracy: 0.8891 - mse: 7.3012 - weighted_accuracy: 0.9230 - weighted_mse: 7.7469 - val_loss: 1.6277 - val_accuracy: 0.1233 - val_mse: 21.5235 - val_weighted_accuracy: 0.1233 - val_weighted_mse: 21.5235
# Epoch 70/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0261 - accuracy: 0.9389 - mse: 7.4358 - weighted_accuracy: 0.9684 - weighted_mse: 7.9028 - val_loss: 0.2956 - val_accuracy: 0.7176 - val_mse: 11.1495 - val_weighted_accuracy: 0.7176 - val_weighted_mse: 11.1495
# Epoch 71/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0154 - accuracy: 0.9723 - mse: 7.9595 - weighted_accuracy: 0.9881 - weighted_mse: 8.3220 - val_loss: 1.1702 - val_accuracy: 0.2497 - val_mse: 17.2668 - val_weighted_accuracy: 0.2497 - val_weighted_mse: 17.2668
# Epoch 72/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0124 - accuracy: 0.9852 - mse: 8.2194 - weighted_accuracy: 0.9946 - weighted_mse: 8.3548 - val_loss: 0.2638 - val_accuracy: 0.7840 - val_mse: 12.4751 - val_weighted_accuracy: 0.7840 - val_weighted_mse: 12.4751
# Epoch 73/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0100 - accuracy: 0.9918 - mse: 8.6416 - weighted_accuracy: 0.9970 - weighted_mse: 8.7223 - val_loss: 0.2806 - val_accuracy: 0.8725 - val_mse: 16.9984 - val_weighted_accuracy: 0.8725 - val_weighted_mse: 16.9984
# Epoch 74/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0090 - accuracy: 0.9942 - mse: 8.9880 - weighted_accuracy: 0.9979 - weighted_mse: 8.9356 - val_loss: 0.3182 - val_accuracy: 0.8841 - val_mse: 19.1148 - val_weighted_accuracy: 0.8841 - val_weighted_mse: 19.1148
# Epoch 75/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0084 - accuracy: 0.9976 - mse: 9.2842 - weighted_accuracy: 0.9991 - weighted_mse: 9.2624 - val_loss: 0.2828 - val_accuracy: 0.8851 - val_mse: 15.3191 - val_weighted_accuracy: 0.8851 - val_weighted_mse: 15.3191
# Epoch 76/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0081 - accuracy: 0.9968 - mse: 9.5378 - weighted_accuracy: 0.9988 - weighted_mse: 9.4910 - val_loss: 0.2841 - val_accuracy: 0.8862 - val_mse: 14.6200 - val_weighted_accuracy: 0.8862 - val_weighted_mse: 14.6200
# Epoch 77/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0078 - accuracy: 0.9976 - mse: 9.8228 - weighted_accuracy: 0.9991 - weighted_mse: 9.7094 - val_loss: 0.2798 - val_accuracy: 0.8725 - val_mse: 13.8665 - val_weighted_accuracy: 0.8725 - val_weighted_mse: 13.8665
# Epoch 78/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0076 - accuracy: 0.9971 - mse: 10.0381 - weighted_accuracy: 0.9989 - weighted_mse: 9.9129 - val_loss: 0.3063 - val_accuracy: 0.8967 - val_mse: 16.6370 - val_weighted_accuracy: 0.8967 - val_weighted_mse: 16.6370
# Epoch 79/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0073 - accuracy: 0.9974 - mse: 10.3135 - weighted_accuracy: 0.9990 - weighted_mse: 10.1542 - val_loss: 0.2765 - val_accuracy: 0.8335 - val_mse: 11.3810 - val_weighted_accuracy: 0.8335 - val_weighted_mse: 11.3810
# Epoch 80/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0073 - accuracy: 0.9984 - mse: 10.4609 - weighted_accuracy: 0.9994 - weighted_mse: 10.3992 - val_loss: 0.3116 - val_accuracy: 0.8841 - val_mse: 16.0042 - val_weighted_accuracy: 0.8841 - val_weighted_mse: 16.0042
# Epoch 81/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0070 - accuracy: 0.9995 - mse: 10.7764 - weighted_accuracy: 0.9998 - weighted_mse: 10.5131 - val_loss: 0.3287 - val_accuracy: 0.7956 - val_mse: 15.1726 - val_weighted_accuracy: 0.7956 - val_weighted_mse: 15.1726
# Epoch 82/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0066 - accuracy: 0.9984 - mse: 11.0365 - weighted_accuracy: 0.9994 - weighted_mse: 10.9026 - val_loss: 0.2700 - val_accuracy: 0.8567 - val_mse: 13.0537 - val_weighted_accuracy: 0.8567 - val_weighted_mse: 13.0537
# Epoch 83/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0062 - accuracy: 0.9997 - mse: 11.3107 - weighted_accuracy: 0.9999 - weighted_mse: 10.9819 - val_loss: 0.2737 - val_accuracy: 0.8567 - val_mse: 12.2686 - val_weighted_accuracy: 0.8567 - val_weighted_mse: 12.2686
# Epoch 84/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0062 - accuracy: 0.9989 - mse: 11.5286 - weighted_accuracy: 0.9996 - weighted_mse: 11.1374 - val_loss: 0.2793 - val_accuracy: 0.8567 - val_mse: 12.9598 - val_weighted_accuracy: 0.8567 - val_weighted_mse: 12.9598
# Epoch 85/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0061 - accuracy: 0.9997 - mse: 11.7358 - weighted_accuracy: 0.9999 - weighted_mse: 11.2795 - val_loss: 0.3037 - val_accuracy: 0.8493 - val_mse: 13.4593 - val_weighted_accuracy: 0.8493 - val_weighted_mse: 13.4593
# Epoch 86/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0059 - accuracy: 0.9995 - mse: 11.9335 - weighted_accuracy: 0.9998 - weighted_mse: 11.5662 - val_loss: 0.3165 - val_accuracy: 0.8904 - val_mse: 16.9877 - val_weighted_accuracy: 0.8904 - val_weighted_mse: 16.9877
# Epoch 87/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0058 - accuracy: 0.9992 - mse: 12.1890 - weighted_accuracy: 0.9997 - weighted_mse: 11.7056 - val_loss: 0.3073 - val_accuracy: 0.8325 - val_mse: 14.1891 - val_weighted_accuracy: 0.8325 - val_weighted_mse: 14.1891
# Epoch 88/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0057 - accuracy: 0.9995 - mse: 12.3601 - weighted_accuracy: 0.9998 - weighted_mse: 11.8285 - val_loss: 0.2909 - val_accuracy: 0.8451 - val_mse: 13.1322 - val_weighted_accuracy: 0.8451 - val_weighted_mse: 13.1322
# Epoch 89/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0056 - accuracy: 0.9997 - mse: 12.5479 - weighted_accuracy: 0.9999 - weighted_mse: 12.0424 - val_loss: 0.3077 - val_accuracy: 0.8451 - val_mse: 14.3325 - val_weighted_accuracy: 0.8451 - val_weighted_mse: 14.3325
# Epoch 90/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0055 - accuracy: 1.0000 - mse: 12.7096 - weighted_accuracy: 1.0000 - weighted_mse: 12.2533 - val_loss: 0.2994 - val_accuracy: 0.8609 - val_mse: 14.7025 - val_weighted_accuracy: 0.8609 - val_weighted_mse: 14.7025
# Epoch 91/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0055 - accuracy: 0.9995 - mse: 12.9188 - weighted_accuracy: 0.9998 - weighted_mse: 12.3207 - val_loss: 0.2863 - val_accuracy: 0.8335 - val_mse: 12.8600 - val_weighted_accuracy: 0.8335 - val_weighted_mse: 12.8600
# Epoch 92/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0054 - accuracy: 0.9995 - mse: 13.1070 - weighted_accuracy: 0.9998 - weighted_mse: 12.5462 - val_loss: 0.3058 - val_accuracy: 0.8546 - val_mse: 15.1216 - val_weighted_accuracy: 0.8546 - val_weighted_mse: 15.1216
# Epoch 93/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0052 - accuracy: 1.0000 - mse: 13.3714 - weighted_accuracy: 1.0000 - weighted_mse: 12.7428 - val_loss: 0.3047 - val_accuracy: 0.8683 - val_mse: 15.2842 - val_weighted_accuracy: 0.8683 - val_weighted_mse: 15.2842
# Epoch 94/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0052 - accuracy: 0.9997 - mse: 13.5449 - weighted_accuracy: 0.9999 - weighted_mse: 12.9445 - val_loss: 0.3114 - val_accuracy: 0.8419 - val_mse: 14.0983 - val_weighted_accuracy: 0.8419 - val_weighted_mse: 14.0983
# Epoch 95/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0052 - accuracy: 0.9995 - mse: 13.6510 - weighted_accuracy: 0.9998 - weighted_mse: 12.9498 - val_loss: 0.2933 - val_accuracy: 0.8504 - val_mse: 14.1297 - val_weighted_accuracy: 0.8504 - val_weighted_mse: 14.1297
# Epoch 96/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0050 - accuracy: 1.0000 - mse: 13.8634 - weighted_accuracy: 1.0000 - weighted_mse: 13.2161 - val_loss: 0.3264 - val_accuracy: 0.8577 - val_mse: 15.9428 - val_weighted_accuracy: 0.8577 - val_weighted_mse: 15.9428
# Epoch 97/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0051 - accuracy: 1.0000 - mse: 14.0449 - weighted_accuracy: 1.0000 - weighted_mse: 13.3043 - val_loss: 0.3071 - val_accuracy: 0.8778 - val_mse: 15.4804 - val_weighted_accuracy: 0.8778 - val_weighted_mse: 15.4804
# Epoch 98/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0050 - accuracy: 1.0000 - mse: 14.2167 - weighted_accuracy: 1.0000 - weighted_mse: 13.5389 - val_loss: 0.3120 - val_accuracy: 0.8588 - val_mse: 15.9212 - val_weighted_accuracy: 0.8588 - val_weighted_mse: 15.9212
# Epoch 99/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0050 - accuracy: 1.0000 - mse: 14.3664 - weighted_accuracy: 1.0000 - weighted_mse: 13.6714 - val_loss: 0.3378 - val_accuracy: 0.8556 - val_mse: 17.1034 - val_weighted_accuracy: 0.8556 - val_weighted_mse: 17.1034
# Epoch 100/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 14.5526 - weighted_accuracy: 1.0000 - weighted_mse: 13.7051 - val_loss: 0.3435 - val_accuracy: 0.8704 - val_mse: 18.0631 - val_weighted_accuracy: 0.8704 - val_weighted_mse: 18.0631
# Epoch 101/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 14.7301 - weighted_accuracy: 1.0000 - weighted_mse: 13.8547 - val_loss: 0.3340 - val_accuracy: 0.8472 - val_mse: 15.2611 - val_weighted_accuracy: 0.8472 - val_weighted_mse: 15.2611
# Epoch 102/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 14.9096 - weighted_accuracy: 1.0000 - weighted_mse: 14.0389 - val_loss: 0.3164 - val_accuracy: 0.8556 - val_mse: 15.2719 - val_weighted_accuracy: 0.8556 - val_weighted_mse: 15.2719
# Epoch 103/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 15.0542 - weighted_accuracy: 1.0000 - weighted_mse: 14.2547 - val_loss: 0.3245 - val_accuracy: 0.8409 - val_mse: 14.9242 - val_weighted_accuracy: 0.8409 - val_weighted_mse: 14.9242
# Epoch 104/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 15.1476 - weighted_accuracy: 1.0000 - weighted_mse: 14.3279 - val_loss: 0.3344 - val_accuracy: 0.8693 - val_mse: 16.9087 - val_weighted_accuracy: 0.8693 - val_weighted_mse: 16.9087
# Epoch 105/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 15.4054 - weighted_accuracy: 1.0000 - weighted_mse: 14.5961 - val_loss: 0.3365 - val_accuracy: 0.8567 - val_mse: 17.1821 - val_weighted_accuracy: 0.8567 - val_weighted_mse: 17.1821
# Epoch 106/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 15.5975 - weighted_accuracy: 1.0000 - weighted_mse: 14.5159 - val_loss: 0.3461 - val_accuracy: 0.8577 - val_mse: 17.1408 - val_weighted_accuracy: 0.8577 - val_weighted_mse: 17.1408
# Epoch 107/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 15.7360 - weighted_accuracy: 1.0000 - weighted_mse: 14.7085 - val_loss: 0.3411 - val_accuracy: 0.8599 - val_mse: 17.6815 - val_weighted_accuracy: 0.8599 - val_weighted_mse: 17.6815
# Epoch 108/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 15.8414 - weighted_accuracy: 1.0000 - weighted_mse: 15.0371 - val_loss: 0.3554 - val_accuracy: 0.8535 - val_mse: 17.4188 - val_weighted_accuracy: 0.8535 - val_weighted_mse: 17.4188
# Epoch 109/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 15.9653 - weighted_accuracy: 1.0000 - weighted_mse: 15.0716 - val_loss: 0.3573 - val_accuracy: 0.8398 - val_mse: 16.8964 - val_weighted_accuracy: 0.8398 - val_weighted_mse: 16.8964
# Epoch 110/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 16.2037 - weighted_accuracy: 1.0000 - weighted_mse: 15.2261 - val_loss: 0.3417 - val_accuracy: 0.8409 - val_mse: 15.6253 - val_weighted_accuracy: 0.8409 - val_weighted_mse: 15.6253
# Epoch 111/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 16.2984 - weighted_accuracy: 1.0000 - weighted_mse: 15.3808 - val_loss: 0.3593 - val_accuracy: 0.8230 - val_mse: 17.4797 - val_weighted_accuracy: 0.8230 - val_weighted_mse: 17.4797
# Epoch 112/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 16.4111 - weighted_accuracy: 1.0000 - weighted_mse: 15.5746 - val_loss: 0.3542 - val_accuracy: 0.8588 - val_mse: 18.3213 - val_weighted_accuracy: 0.8588 - val_weighted_mse: 18.3213
# Epoch 113/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 16.6091 - weighted_accuracy: 1.0000 - weighted_mse: 15.5206 - val_loss: 0.3784 - val_accuracy: 0.8599 - val_mse: 19.8145 - val_weighted_accuracy: 0.8599 - val_weighted_mse: 19.8145
# Epoch 114/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 16.7701 - weighted_accuracy: 1.0000 - weighted_mse: 15.7034 - val_loss: 0.3660 - val_accuracy: 0.8483 - val_mse: 19.3995 - val_weighted_accuracy: 0.8483 - val_weighted_mse: 19.3995
# Epoch 115/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 16.9178 - weighted_accuracy: 1.0000 - weighted_mse: 15.6714 - val_loss: 0.3514 - val_accuracy: 0.8714 - val_mse: 18.8752 - val_weighted_accuracy: 0.8714 - val_weighted_mse: 18.8752
# Epoch 116/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 16.9549 - weighted_accuracy: 1.0000 - weighted_mse: 16.1131 - val_loss: 0.3459 - val_accuracy: 0.8693 - val_mse: 18.4593 - val_weighted_accuracy: 0.8693 - val_weighted_mse: 18.4593
# Epoch 117/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 17.1862 - weighted_accuracy: 1.0000 - weighted_mse: 16.1570 - val_loss: 0.3635 - val_accuracy: 0.8483 - val_mse: 17.7227 - val_weighted_accuracy: 0.8483 - val_weighted_mse: 17.7227
# Epoch 118/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 17.2986 - weighted_accuracy: 1.0000 - weighted_mse: 16.1948 - val_loss: 0.3647 - val_accuracy: 0.8535 - val_mse: 17.1641 - val_weighted_accuracy: 0.8535 - val_weighted_mse: 17.1641
# Epoch 119/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 17.4121 - weighted_accuracy: 1.0000 - weighted_mse: 16.3156 - val_loss: 0.3402 - val_accuracy: 0.8462 - val_mse: 16.7711 - val_weighted_accuracy: 0.8462 - val_weighted_mse: 16.7711
# Epoch 120/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 17.5650 - weighted_accuracy: 1.0000 - weighted_mse: 16.3080 - val_loss: 0.3737 - val_accuracy: 0.8388 - val_mse: 17.9420 - val_weighted_accuracy: 0.8388 - val_weighted_mse: 17.9420
# Epoch 121/200
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 17.7346 - weighted_accuracy: 1.0000 - weighted_mse: 16.6389 - val_loss: 0.3611 - val_accuracy: 0.8651 - val_mse: 18.3984 - val_weighted_accuracy: 0.8651 - val_weighted_mse: 18.3984
# Epoch 122/200
# 30/30 [==============================] - 1s 23ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 17.8881 - weighted_accuracy: 1.0000 - weighted_mse: 16.8067 - val_loss: 0.3971 - val_accuracy: 0.7956 - val_mse: 16.7875 - val_weighted_accuracy: 0.7956 - val_weighted_mse: 16.7875
# Epoch 123/200
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 17.9922 - weighted_accuracy: 1.0000 - weighted_mse: 16.8216 - val_loss: 0.3726 - val_accuracy: 0.8472 - val_mse: 18.9051 - val_weighted_accuracy: 0.8472 - val_weighted_mse: 18.9051
# Epoch 124/200
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 18.1755 - weighted_accuracy: 1.0000 - weighted_mse: 16.9779 - val_loss: 0.3834 - val_accuracy: 0.8641 - val_mse: 20.1023 - val_weighted_accuracy: 0.8641 - val_weighted_mse: 20.1023
# Epoch 125/200
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 18.2782 - weighted_accuracy: 1.0000 - weighted_mse: 17.0396 - val_loss: 0.3764 - val_accuracy: 0.8514 - val_mse: 18.8330 - val_weighted_accuracy: 0.8514 - val_weighted_mse: 18.8330
# Epoch 126/200
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 18.3344 - weighted_accuracy: 1.0000 - weighted_mse: 17.0285 - val_loss: 0.3701 - val_accuracy: 0.8472 - val_mse: 19.3164 - val_weighted_accuracy: 0.8472 - val_weighted_mse: 19.3164
# Epoch 127/200
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 18.5581 - weighted_accuracy: 1.0000 - weighted_mse: 17.2711 - val_loss: 0.3900 - val_accuracy: 0.8630 - val_mse: 20.7353 - val_weighted_accuracy: 0.8630 - val_weighted_mse: 20.7353
# Epoch 128/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 18.6763 - weighted_accuracy: 1.0000 - weighted_mse: 17.5347 - val_loss: 0.3788 - val_accuracy: 0.8546 - val_mse: 19.3339 - val_weighted_accuracy: 0.8546 - val_weighted_mse: 19.3339
# Epoch 129/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 18.7813 - weighted_accuracy: 1.0000 - weighted_mse: 17.5965 - val_loss: 0.3561 - val_accuracy: 0.8651 - val_mse: 18.8086 - val_weighted_accuracy: 0.8651 - val_weighted_mse: 18.8086
# Epoch 130/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 18.8947 - weighted_accuracy: 1.0000 - weighted_mse: 17.5448 - val_loss: 0.3834 - val_accuracy: 0.8641 - val_mse: 20.1735 - val_weighted_accuracy: 0.8641 - val_weighted_mse: 20.1735
# Epoch 131/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 19.0605 - weighted_accuracy: 1.0000 - weighted_mse: 17.6497 - val_loss: 0.3962 - val_accuracy: 0.8609 - val_mse: 21.3163 - val_weighted_accuracy: 0.8609 - val_weighted_mse: 21.3163
# Epoch 132/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0045 - accuracy: 0.9997 - mse: 19.1552 - weighted_accuracy: 0.9999 - weighted_mse: 17.8087 - val_loss: 0.6142 - val_accuracy: 0.7671 - val_mse: 22.6322 - val_weighted_accuracy: 0.7671 - val_weighted_mse: 22.6322
# Epoch 133/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0044 - accuracy: 0.9997 - mse: 19.3581 - weighted_accuracy: 0.9999 - weighted_mse: 18.0045 - val_loss: 0.3801 - val_accuracy: 0.8641 - val_mse: 21.3282 - val_weighted_accuracy: 0.8641 - val_weighted_mse: 21.3282
# Epoch 134/200
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 19.4295 - weighted_accuracy: 1.0000 - weighted_mse: 18.0379 - val_loss: 0.3955 - val_accuracy: 0.8525 - val_mse: 20.8777 - val_weighted_accuracy: 0.8525 - val_weighted_mse: 20.8777
# Epoch 135/200
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 19.6110 - weighted_accuracy: 1.0000 - weighted_mse: 18.1429 - val_loss: 0.4022 - val_accuracy: 0.8272 - val_mse: 19.9835 - val_weighted_accuracy: 0.8272 - val_weighted_mse: 19.9835
# Epoch 136/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 19.6546 - weighted_accuracy: 1.0000 - weighted_mse: 18.3296 - val_loss: 0.4023 - val_accuracy: 0.8219 - val_mse: 19.7326 - val_weighted_accuracy: 0.8219 - val_weighted_mse: 19.7326
# Epoch 137/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 19.7649 - weighted_accuracy: 1.0000 - weighted_mse: 18.4472 - val_loss: 0.3942 - val_accuracy: 0.8388 - val_mse: 19.9002 - val_weighted_accuracy: 0.8388 - val_weighted_mse: 19.9002
# Epoch 138/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 19.8149 - weighted_accuracy: 1.0000 - weighted_mse: 18.3405 - val_loss: 0.3944 - val_accuracy: 0.8388 - val_mse: 20.4525 - val_weighted_accuracy: 0.8388 - val_weighted_mse: 20.4525
# Epoch 139/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 19.8444 - weighted_accuracy: 1.0000 - weighted_mse: 18.5524 - val_loss: 0.3860 - val_accuracy: 0.8714 - val_mse: 22.6113 - val_weighted_accuracy: 0.8714 - val_weighted_mse: 22.6113
# Epoch 140/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 20.1633 - weighted_accuracy: 1.0000 - weighted_mse: 18.7207 - val_loss: 0.4021 - val_accuracy: 0.8535 - val_mse: 20.8807 - val_weighted_accuracy: 0.8535 - val_weighted_mse: 20.8807
# Epoch 141/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 20.2432 - weighted_accuracy: 1.0000 - weighted_mse: 18.8572 - val_loss: 0.4225 - val_accuracy: 0.8209 - val_mse: 21.7663 - val_weighted_accuracy: 0.8209 - val_weighted_mse: 21.7663
# Epoch 142/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0305 - accuracy: 0.9697 - mse: 19.6748 - weighted_accuracy: 0.9688 - weighted_mse: 17.6490 - val_loss: 0.9150 - val_accuracy: 0.5037 - val_mse: 54.5031 - val_weighted_accuracy: 0.5037 - val_weighted_mse: 54.5031
# Epoch 143/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.1672 - accuracy: 0.7774 - mse: 12.2367 - weighted_accuracy: 0.8259 - weighted_mse: 12.6104 - val_loss: 0.2946 - val_accuracy: 0.8841 - val_mse: 25.9427 - val_weighted_accuracy: 0.8841 - val_weighted_mse: 25.9427
# Epoch 144/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0965 - accuracy: 0.8016 - mse: 7.9776 - weighted_accuracy: 0.8617 - weighted_mse: 8.5696 - val_loss: 0.5867 - val_accuracy: 0.4584 - val_mse: 11.8204 - val_weighted_accuracy: 0.4584 - val_weighted_mse: 11.8204
# Epoch 145/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0432 - accuracy: 0.8844 - mse: 6.8748 - weighted_accuracy: 0.9376 - weighted_mse: 7.4383 - val_loss: 0.5045 - val_accuracy: 0.3952 - val_mse: 7.9556 - val_weighted_accuracy: 0.3952 - val_weighted_mse: 7.9556
# Epoch 146/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0228 - accuracy: 0.9463 - mse: 7.5359 - weighted_accuracy: 0.9785 - weighted_mse: 7.7632 - val_loss: 0.2367 - val_accuracy: 0.9073 - val_mse: 18.1377 - val_weighted_accuracy: 0.9073 - val_weighted_mse: 18.1377
# Epoch 147/200
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0141 - accuracy: 0.9742 - mse: 8.2286 - weighted_accuracy: 0.9905 - weighted_mse: 8.2717 - val_loss: 0.3344 - val_accuracy: 0.9083 - val_mse: 21.6330 - val_weighted_accuracy: 0.9083 - val_weighted_mse: 21.6330
# Epoch 148/200
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0111 - accuracy: 0.9860 - mse: 8.7525 - weighted_accuracy: 0.9949 - weighted_mse: 8.6056 - val_loss: 0.3499 - val_accuracy: 0.9062 - val_mse: 21.1197 - val_weighted_accuracy: 0.9062 - val_weighted_mse: 21.1197
# Epoch 149/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0100 - accuracy: 0.9887 - mse: 9.1878 - weighted_accuracy: 0.9958 - weighted_mse: 9.0572 - val_loss: 0.2965 - val_accuracy: 0.8978 - val_mse: 16.0274 - val_weighted_accuracy: 0.8978 - val_weighted_mse: 16.0274
# Epoch 150/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0081 - accuracy: 0.9942 - mse: 9.6002 - weighted_accuracy: 0.9979 - weighted_mse: 9.4537 - val_loss: 0.3124 - val_accuracy: 0.8915 - val_mse: 18.0900 - val_weighted_accuracy: 0.8915 - val_weighted_mse: 18.0900
# Epoch 151/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0077 - accuracy: 0.9960 - mse: 10.0239 - weighted_accuracy: 0.9985 - weighted_mse: 9.6629 - val_loss: 0.3301 - val_accuracy: 0.8999 - val_mse: 18.7201 - val_weighted_accuracy: 0.8999 - val_weighted_mse: 18.7201
# Epoch 152/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0073 - accuracy: 0.9974 - mse: 10.2779 - weighted_accuracy: 0.9990 - weighted_mse: 10.0629 - val_loss: 0.3389 - val_accuracy: 0.8957 - val_mse: 18.9094 - val_weighted_accuracy: 0.8957 - val_weighted_mse: 18.9094
# Epoch 153/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0068 - accuracy: 0.9989 - mse: 10.6234 - weighted_accuracy: 0.9996 - weighted_mse: 10.1568 - val_loss: 0.3327 - val_accuracy: 0.8862 - val_mse: 17.7350 - val_weighted_accuracy: 0.8862 - val_weighted_mse: 17.7350
# Epoch 154/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0066 - accuracy: 0.9982 - mse: 10.8727 - weighted_accuracy: 0.9993 - weighted_mse: 10.5554 - val_loss: 0.3308 - val_accuracy: 0.8683 - val_mse: 18.6246 - val_weighted_accuracy: 0.8683 - val_weighted_mse: 18.6246
# Epoch 155/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0063 - accuracy: 0.9982 - mse: 11.1068 - weighted_accuracy: 0.9993 - weighted_mse: 10.6633 - val_loss: 0.3365 - val_accuracy: 0.8693 - val_mse: 18.3761 - val_weighted_accuracy: 0.8693 - val_weighted_mse: 18.3761
# Epoch 156/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0061 - accuracy: 0.9995 - mse: 11.4118 - weighted_accuracy: 0.9998 - weighted_mse: 10.8886 - val_loss: 0.3581 - val_accuracy: 0.8904 - val_mse: 19.7902 - val_weighted_accuracy: 0.8904 - val_weighted_mse: 19.7902
# Epoch 157/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0059 - accuracy: 0.9997 - mse: 11.5974 - weighted_accuracy: 0.9999 - weighted_mse: 11.1102 - val_loss: 0.3236 - val_accuracy: 0.8525 - val_mse: 16.1259 - val_weighted_accuracy: 0.8525 - val_weighted_mse: 16.1259
# Epoch 158/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0058 - accuracy: 0.9997 - mse: 11.8088 - weighted_accuracy: 0.9999 - weighted_mse: 11.3952 - val_loss: 0.3192 - val_accuracy: 0.8788 - val_mse: 15.8359 - val_weighted_accuracy: 0.8788 - val_weighted_mse: 15.8359
# Epoch 159/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0056 - accuracy: 1.0000 - mse: 12.0233 - weighted_accuracy: 1.0000 - weighted_mse: 11.6469 - val_loss: 0.3193 - val_accuracy: 0.8693 - val_mse: 16.7592 - val_weighted_accuracy: 0.8693 - val_weighted_mse: 16.7592
# Epoch 160/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0055 - accuracy: 0.9995 - mse: 12.1924 - weighted_accuracy: 0.9998 - weighted_mse: 11.7064 - val_loss: 0.3200 - val_accuracy: 0.8809 - val_mse: 16.0432 - val_weighted_accuracy: 0.8809 - val_weighted_mse: 16.0432
# Epoch 161/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0053 - accuracy: 0.9997 - mse: 12.4280 - weighted_accuracy: 0.9999 - weighted_mse: 11.9534 - val_loss: 0.3374 - val_accuracy: 0.8651 - val_mse: 17.3557 - val_weighted_accuracy: 0.8651 - val_weighted_mse: 17.3557
# Epoch 162/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0053 - accuracy: 1.0000 - mse: 12.6140 - weighted_accuracy: 1.0000 - weighted_mse: 12.0355 - val_loss: 0.3280 - val_accuracy: 0.8820 - val_mse: 16.6515 - val_weighted_accuracy: 0.8820 - val_weighted_mse: 16.6515
# Epoch 163/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0053 - accuracy: 1.0000 - mse: 12.7858 - weighted_accuracy: 1.0000 - weighted_mse: 12.2891 - val_loss: 0.3739 - val_accuracy: 0.8219 - val_mse: 17.9363 - val_weighted_accuracy: 0.8219 - val_weighted_mse: 17.9363
# Epoch 164/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0052 - accuracy: 0.9997 - mse: 12.9064 - weighted_accuracy: 0.9999 - weighted_mse: 12.4405 - val_loss: 0.3330 - val_accuracy: 0.8767 - val_mse: 16.1522 - val_weighted_accuracy: 0.8767 - val_weighted_mse: 16.1522
# Epoch 165/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0051 - accuracy: 0.9997 - mse: 13.1098 - weighted_accuracy: 0.9999 - weighted_mse: 12.6428 - val_loss: 0.3245 - val_accuracy: 0.8788 - val_mse: 15.4328 - val_weighted_accuracy: 0.8788 - val_weighted_mse: 15.4328
# Epoch 166/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0050 - accuracy: 1.0000 - mse: 13.3003 - weighted_accuracy: 1.0000 - weighted_mse: 12.7220 - val_loss: 0.3180 - val_accuracy: 0.8714 - val_mse: 15.2954 - val_weighted_accuracy: 0.8714 - val_weighted_mse: 15.2954
# Epoch 167/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0050 - accuracy: 1.0000 - mse: 13.4029 - weighted_accuracy: 1.0000 - weighted_mse: 12.9335 - val_loss: 0.3177 - val_accuracy: 0.8514 - val_mse: 14.7068 - val_weighted_accuracy: 0.8514 - val_weighted_mse: 14.7068
# Epoch 168/200
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 13.6082 - weighted_accuracy: 1.0000 - weighted_mse: 13.0807 - val_loss: 0.3251 - val_accuracy: 0.8693 - val_mse: 15.6180 - val_weighted_accuracy: 0.8693 - val_weighted_mse: 15.6180
# Epoch 169/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 13.7721 - weighted_accuracy: 1.0000 - weighted_mse: 13.2097 - val_loss: 0.3260 - val_accuracy: 0.8641 - val_mse: 15.5149 - val_weighted_accuracy: 0.8641 - val_weighted_mse: 15.5149
# Epoch 170/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 13.9607 - weighted_accuracy: 1.0000 - weighted_mse: 13.3775 - val_loss: 0.3270 - val_accuracy: 0.8651 - val_mse: 15.4901 - val_weighted_accuracy: 0.8651 - val_weighted_mse: 15.4901
# Epoch 171/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 14.1109 - weighted_accuracy: 1.0000 - weighted_mse: 13.4980 - val_loss: 0.3240 - val_accuracy: 0.8641 - val_mse: 15.3081 - val_weighted_accuracy: 0.8641 - val_weighted_mse: 15.3081
# Epoch 172/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 14.2094 - weighted_accuracy: 1.0000 - weighted_mse: 13.5151 - val_loss: 0.3260 - val_accuracy: 0.8683 - val_mse: 15.5257 - val_weighted_accuracy: 0.8683 - val_weighted_mse: 15.5257
# Epoch 173/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 14.3601 - weighted_accuracy: 1.0000 - weighted_mse: 13.6759 - val_loss: 0.3336 - val_accuracy: 0.8504 - val_mse: 15.0834 - val_weighted_accuracy: 0.8504 - val_weighted_mse: 15.0834
# Epoch 174/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 14.4962 - weighted_accuracy: 1.0000 - weighted_mse: 13.8953 - val_loss: 0.3237 - val_accuracy: 0.8599 - val_mse: 15.3640 - val_weighted_accuracy: 0.8599 - val_weighted_mse: 15.3640
# Epoch 175/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0047 - accuracy: 0.9997 - mse: 14.6599 - weighted_accuracy: 0.9999 - weighted_mse: 14.1004 - val_loss: 0.3395 - val_accuracy: 0.8303 - val_mse: 15.7462 - val_weighted_accuracy: 0.8303 - val_weighted_mse: 15.7462
# Epoch 176/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 14.7592 - weighted_accuracy: 1.0000 - weighted_mse: 14.1091 - val_loss: 0.3286 - val_accuracy: 0.8609 - val_mse: 15.7431 - val_weighted_accuracy: 0.8609 - val_weighted_mse: 15.7431
# Epoch 177/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 14.9487 - weighted_accuracy: 1.0000 - weighted_mse: 14.2468 - val_loss: 0.3336 - val_accuracy: 0.8599 - val_mse: 16.2131 - val_weighted_accuracy: 0.8599 - val_weighted_mse: 16.2131
# Epoch 178/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 15.0456 - weighted_accuracy: 1.0000 - weighted_mse: 14.3364 - val_loss: 0.3371 - val_accuracy: 0.8567 - val_mse: 16.0072 - val_weighted_accuracy: 0.8567 - val_weighted_mse: 16.0072
# Epoch 179/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 15.1404 - weighted_accuracy: 1.0000 - weighted_mse: 14.5352 - val_loss: 0.3496 - val_accuracy: 0.8546 - val_mse: 16.2538 - val_weighted_accuracy: 0.8546 - val_weighted_mse: 16.2538
# Epoch 180/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 15.2020 - weighted_accuracy: 1.0000 - weighted_mse: 14.5373 - val_loss: 0.3457 - val_accuracy: 0.8609 - val_mse: 16.1985 - val_weighted_accuracy: 0.8609 - val_weighted_mse: 16.1985
# Epoch 181/200
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 15.3805 - weighted_accuracy: 1.0000 - weighted_mse: 14.7984 - val_loss: 0.3541 - val_accuracy: 0.8725 - val_mse: 17.5350 - val_weighted_accuracy: 0.8725 - val_weighted_mse: 17.5350
# Epoch 182/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 15.4596 - weighted_accuracy: 1.0000 - weighted_mse: 14.9111 - val_loss: 0.3466 - val_accuracy: 0.8588 - val_mse: 17.3620 - val_weighted_accuracy: 0.8588 - val_weighted_mse: 17.3620
# Epoch 183/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 15.6419 - weighted_accuracy: 1.0000 - weighted_mse: 15.0560 - val_loss: 0.3485 - val_accuracy: 0.8620 - val_mse: 17.2544 - val_weighted_accuracy: 0.8620 - val_weighted_mse: 17.2544
# Epoch 184/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 15.7447 - weighted_accuracy: 1.0000 - weighted_mse: 15.0369 - val_loss: 0.3563 - val_accuracy: 0.8683 - val_mse: 17.5932 - val_weighted_accuracy: 0.8683 - val_weighted_mse: 17.5932
# Epoch 185/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 15.8711 - weighted_accuracy: 1.0000 - weighted_mse: 15.1998 - val_loss: 0.3534 - val_accuracy: 0.8693 - val_mse: 17.6570 - val_weighted_accuracy: 0.8693 - val_weighted_mse: 17.6570
# Epoch 186/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 15.9735 - weighted_accuracy: 1.0000 - weighted_mse: 15.2687 - val_loss: 0.3438 - val_accuracy: 0.8620 - val_mse: 17.1827 - val_weighted_accuracy: 0.8620 - val_weighted_mse: 17.1827
# Epoch 187/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 16.1257 - weighted_accuracy: 1.0000 - weighted_mse: 15.3542 - val_loss: 0.3497 - val_accuracy: 0.8630 - val_mse: 17.0433 - val_weighted_accuracy: 0.8630 - val_weighted_mse: 17.0433
# Epoch 188/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 16.2270 - weighted_accuracy: 1.0000 - weighted_mse: 15.4009 - val_loss: 0.3473 - val_accuracy: 0.8535 - val_mse: 16.7497 - val_weighted_accuracy: 0.8535 - val_weighted_mse: 16.7497
# Epoch 189/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 16.3159 - weighted_accuracy: 1.0000 - weighted_mse: 15.5114 - val_loss: 0.3523 - val_accuracy: 0.8599 - val_mse: 17.5943 - val_weighted_accuracy: 0.8599 - val_weighted_mse: 17.5943
# Epoch 190/200
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 16.4387 - weighted_accuracy: 1.0000 - weighted_mse: 15.7859 - val_loss: 0.3614 - val_accuracy: 0.8588 - val_mse: 17.9044 - val_weighted_accuracy: 0.8588 - val_weighted_mse: 17.9044
# Epoch 191/200
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 16.5579 - weighted_accuracy: 1.0000 - weighted_mse: 15.8071 - val_loss: 0.3530 - val_accuracy: 0.8641 - val_mse: 17.3703 - val_weighted_accuracy: 0.8641 - val_weighted_mse: 17.3703
# Epoch 192/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 16.6593 - weighted_accuracy: 1.0000 - weighted_mse: 15.9619 - val_loss: 0.3538 - val_accuracy: 0.8567 - val_mse: 17.2990 - val_weighted_accuracy: 0.8567 - val_weighted_mse: 17.2990
# Epoch 193/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 16.8087 - weighted_accuracy: 1.0000 - weighted_mse: 16.0249 - val_loss: 0.3600 - val_accuracy: 0.8535 - val_mse: 17.6074 - val_weighted_accuracy: 0.8535 - val_weighted_mse: 17.6074
# Epoch 194/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 16.8946 - weighted_accuracy: 1.0000 - weighted_mse: 16.1023 - val_loss: 0.3587 - val_accuracy: 0.8546 - val_mse: 17.3245 - val_weighted_accuracy: 0.8546 - val_weighted_mse: 17.3245
# Epoch 195/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 17.0030 - weighted_accuracy: 1.0000 - weighted_mse: 16.2627 - val_loss: 0.3545 - val_accuracy: 0.8567 - val_mse: 17.4209 - val_weighted_accuracy: 0.8567 - val_weighted_mse: 17.4209
# Epoch 196/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 17.0763 - weighted_accuracy: 1.0000 - weighted_mse: 16.3363 - val_loss: 0.3564 - val_accuracy: 0.8567 - val_mse: 17.2039 - val_weighted_accuracy: 0.8567 - val_weighted_mse: 17.2039
# Epoch 197/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 17.1917 - weighted_accuracy: 1.0000 - weighted_mse: 16.3548 - val_loss: 0.3536 - val_accuracy: 0.8535 - val_mse: 17.1401 - val_weighted_accuracy: 0.8535 - val_weighted_mse: 17.1401
# Epoch 198/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 17.3148 - weighted_accuracy: 1.0000 - weighted_mse: 16.4197 - val_loss: 0.3547 - val_accuracy: 0.8535 - val_mse: 17.3626 - val_weighted_accuracy: 0.8535 - val_weighted_mse: 17.3626
# Epoch 199/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 17.4388 - weighted_accuracy: 1.0000 - weighted_mse: 16.6331 - val_loss: 0.3598 - val_accuracy: 0.8630 - val_mse: 18.4593 - val_weighted_accuracy: 0.8630 - val_weighted_mse: 18.4593
# Epoch 200/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 17.4920 - weighted_accuracy: 1.0000 - weighted_mse: 16.7012 - val_loss: 0.3642 - val_accuracy: 0.8525 - val_mse: 17.7530 - val_weighted_accuracy: 0.8525 - val_weighted_mse: 17.7530

# %%
# Score model
score = model.evaluate(validation_x, validation_y, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.3642120659351349
# Test accuracy: 0.8524762988090515

# %%
predictions = model.predict(validation_x)
print(predictions)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
from collections import Counter

Counter(predictions)
# Out:
# [[-6.822394    1.8016788  -2.807776  ]
#  [-4.386925   -5.775112    4.472827  ]
#  [-0.10075453 -6.168413   -0.6215674 ]
#  ...
#  [-5.938877   -4.1854477   4.4263577 ]
#  [-3.3453865  -4.9742794   3.0167248 ]
#  [-4.5519733  -4.5185676   4.0736847 ]]
# Counter({1: 24, 2: 883, 0: 42})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in validation_y]
Counter(actual)
# Out:
# Counter({2: 862, 0: 44, 1: 43})

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold))
# Out:
# number of predictions: 949
# actual predicted buys: 3
# actual buys but predicted sell: 1
# actual buys but predicted hold: 39
# actual sells but predicted buy: 0
# actual predicted sells: 3
# actual sells but predicted hold: 41
# actual holds but predicted buy: 21
# actual holds but predicted sell: 38
# actual predicted holds: 803
# Percentage buys correct: 6.976744186046512%
# Percentage sells correct: 6.818181818181818%
# Percentage holds correct: 93.15545243619489%
# actual buys: 43
# actual sells: 44
# actual holds: 862

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.figure(figsize=(20,10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Save model
model.save("models/{}".format('wmt_image_lstm_buy_hold_sell_original.model'))
# Out:
# INFO:tensorflow:Assets written to: models/wmt_image_lstm_buy_hold_sell_original.model\assets

# %% [markdown]
# ### Test Performance

# %% [markdown]
# ### Non-Recession

# %%
seed = 10
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/WMT_data_test.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22    97.730003  95.334462  -7.164539  58918700.0     2.0
# 2019-01-23    97.489998  95.666083 -13.843922  50855500.0     0.0
# 2019-01-24    98.709999  96.134378  -9.609606  59201300.0     2.0
# 2019-01-25    98.360001  96.476781 -14.864842  51591600.0     2.0
# 2019-01-28    96.940002  96.548046 -38.683751  44373400.0     2.0

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/wmt_image_lstm_buy_hold_sell_original.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2598 - accuracy: 0.8853 - mean_squared_error: 17.1002 - weighted_accuracy: 0.8853 - weighted_mean_squared_error: 17.1002
# Test loss: 0.2597734332084656
# Test accuracy: 0.8853210806846619

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 208, 0: 7, 1: 3})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]

# %%
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/WMT_data_test.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels  \
# Date
# 2019-02-11    96.199997  95.814812 -60.416634  53751900.0     2.0
# 2019-02-12    96.970001  95.874072 -50.480811  59294700.0     2.0
# 2019-02-13    97.940002  96.042676 -33.448300  65176000.0     2.0
# 2019-02-14    98.519997  96.334572 -16.724150  70634500.0     2.0
# 2019-02-15    99.989998  96.670792 -11.165857  77835300.0     2.0
#
#             predictions  actual
# Date
# 2019-02-11            2       2
# 2019-02-12            2       2
# 2019-02-13            2       2
# 2019-02-14            2       2
# 2019-02-15            2       2

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold))
# Out:
# number of predictions: 218
# actual predicted buys: 0
# actual buys but predicted sell: 1
# actual buys but predicted hold: 7
# actual sells but predicted buy: 0
# actual predicted sells: 0
# actual sells but predicted hold: 8
# actual holds but predicted buy: 3
# actual holds but predicted sell: 6
# actual predicted holds: 193
# Percentage buys correct: 0.0%
# Percentage sells correct: 0.0%
# Percentage holds correct: 95.54455445544555%
# actual buys: 8
# actual sells: 8
# actual holds: 202

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%")
# Out:
# [96.1999969482422, 96.97000122070312, 97.94000244140624, 98.5199966430664, 99.38999938964844, 99.5500030517578, 99.87999725341795, 99.98999786376952, 102.1999969482422]
# [97.8499984741211, 97.93000030517578, 98.11000061035156, 98.69000244140624, 98.98999786376952, 99.12000274658205, 99.38999938964844, 99.5500030517578, 99.87999725341795]
# Percentage buys correct: 66.66666666666667%
# Percentage sells correct: 42.857142857142854%
# Percentage holds correct: 86.47342995169082%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
#         print(i)
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $97.19000244140624
# Shares owned at the moment: 102
# Cash capital at the moment: $59.35795529174902
#
#
# Price increase from previously bought: 5.851516694905579%
# Share price: $103.16000366210938
# Shares owned at the moment: 0
# Cash capital at the moment: $10552.741947799683
#
#
# Share price: $116.30999755859376
# Shares owned at the moment: 90
# Cash capital at the moment: $56.05544313049177
#
#
#
#
# Capital at the end of test period: $10813.79014791107
# profit gained: 8.137901479110697%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $12375.78138288879
# profit gained: 23.7578138288879%

# %% [markdown]
# ### recession

# %%
seed = 10
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/WMT_data_test2.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22   115.589996  116.459043 -80.074504 -17684500.0     2.0
# 2020-01-23   116.099998  116.403805 -70.577262 -12758400.0     2.0
# 2020-01-24   115.809998  116.312450 -69.789236 -17063500.0     2.0
# 2020-01-27   114.370003  116.013612 -94.416205 -21446900.0     2.0
# 2020-01-28   115.860001  115.989979 -34.297465 -14428500.0     2.0

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/wmt_image_lstm_buy_hold_sell_original.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3006 - accuracy: 0.8493 - mean_squared_error: 17.5102 - weighted_accuracy: 0.8493 - weighted_mean_squared_error: 17.5102
# Test loss: 0.3006088137626648
# Test accuracy: 0.8493150472640991

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 200, 1: 9, 0: 10})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]

# %%
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/WMT_data_test2.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d      EMA_12   willr_14       OBV_7  labels  \
# Date
# 2020-02-11   115.400002  115.836459 -43.516528 -17373100.0     2.0
# 2020-02-12   115.849998  115.769312 -40.219793 -11576300.0     2.0
# 2020-02-13   117.440002  115.781725 -30.329757  -6840700.0     2.0
# 2020-02-14   117.889999  116.036845  -2.057582  -1507500.0     2.0
# 2020-02-18   119.629997  116.321946 -14.561040   6623100.0     0.0
#
#             predictions  actual
# Date
# 2020-02-11            2       2
# 2020-02-12            2       2
# 2020-02-13            2       2
# 2020-02-14            2       2
# 2020-02-18            2       0

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold))
# Out:
# number of predictions: 219
# actual predicted buys: 0
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 0
# actual predicted sells: 2
# actual sells but predicted hold: 9
# actual holds but predicted buy: 9
# actual holds but predicted sell: 8
# actual predicted holds: 184
# Percentage buys correct: 0.0%
# Percentage sells correct: 18.181818181818183%
# Percentage holds correct: 91.54228855721394%
# actual buys: 7
# actual sells: 11
# actual holds: 201

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%")
# Out:
# [115.4000015258789, 115.8499984741211, 116.31999969482422, 117.44000244140624, 117.68000030517578, 117.69000244140624, 117.88999938964844, 118.58000183105469, 119.62999725341795]
# [107.68000030517578, 110.4000015258789, 112.91000366210938, 113.77999877929688, 114.38999938964844, 115.87999725341795, 116.31999969482422, 117.69000244140624, 118.58000183105469]
# Percentage buys correct: 77.77777777777777%
# Percentage sells correct: 60.0%
# Percentage holds correct: 85.42713567839196%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
#         print(i)
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $114.0999984741211
# Shares owned at the moment: 87
# Cash capital at the moment: $46.00170811653152
#
#
# Stop Loss Activated!
#
# Share price: $106.76000213623048
# Shares owned at the moment: 0
# Cash capital at the moment: $9308.579563457492
#
#
# Share price: $114.13999938964844
# Shares owned at the moment: 81
# Cash capital at the moment: $37.814928031923046
#
#
# Price increase from previously bought: 8.14835987541822%
# Share price: $123.77999877929688
# Shares owned at the moment: 0
# Cash capital at the moment: $10036.422834426881
#
#
# Share price: $117.98999786376952
# Shares owned at the moment: 84
# Cash capital at the moment: $98.00732436371072
#
#
# Price increase from previously bought: 12.124918668713992%
# Share price: $132.66000366210938
# Shares owned at the moment: 0
# Cash capital at the moment: $11210.80317113495
#
#
# Share price: $131.75999450683594
# Shares owned at the moment: 84
# Cash capital at the moment: $112.52707382965309
#
#
# Price increase from previously bought: 11.77519171448289%
# Share price: $147.67999267578125
# Shares owned at the moment: 0
# Cash capital at the moment: $12483.532380287172
#
#
# Share price: $137.32000732421878
# Shares owned at the moment: 90
# Cash capital at the moment: $90.74501929473809
#
#
# Price increase from previously bought: 9.3264896838104%
# Share price: $150.5399932861328
# Shares owned at the moment: 0
# Cash capital at the moment: $13602.085766708373
#
#
# Share price: $145.64999389648438
# Shares owned at the moment: 93
# Cash capital at the moment: $19.38634839629958
#
#
#
#
# Capital at the end of test period: $13555.40935286331
# profit gained: 35.55409352863309%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $12565.490331684112
# profit gained: 25.65490331684112%

# %% [markdown]
# ## Fresh Del Monte Produce Inc

# %%
seed = 10
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/FDP_data.csv")
print(df.head())
# Out:
#          Date  previous_1d    EMA_12   willr_14     OBV_7  labels
# 0  2000-01-21       8.7500  8.946622 -66.666667   78200.0     2.0
# 1  2000-01-24       8.8750  8.935603 -58.333333   99900.0     2.0
# 2  2000-01-25       9.0000  8.945511 -50.000000  123600.0     2.0
# 3  2000-01-26       8.6875  8.905817 -70.833333   87300.0     2.0
# 4  2000-01-27       8.5625  8.852999 -76.000000   32400.0     2.0

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['labels'].plot(figsize=(16,6),x='Date', y='labels')

# %%
df.set_index('Date', inplace=True)
df.head()
# Out:
#             previous_1d    EMA_12   willr_14     OBV_7  labels
# Date
# 2000-01-21       8.7500  8.946622 -66.666667   78200.0     2.0
# 2000-01-24       8.8750  8.935603 -58.333333   99900.0     2.0
# 2000-01-25       9.0000  8.945511 -50.000000  123600.0     2.0
# 2000-01-26       8.6875  8.905817 -70.833333   87300.0     2.0
# 2000-01-27       8.5625  8.852999 -76.000000   32400.0     2.0

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1

# %%
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64)
y = np.array(y)

X.shape
# Out:
# (4745, 64, 64)

# %%
# plot the image array X
i = X[0].reshape(64, 64)
fig2, ax2 = plt.subplots()
plt.imshow(i, interpolation="none", cmap="gray")

ax2.axis('off')

plt.show()

# %%
X = X/255

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization,Activation
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(LSTM(100, input_shape=(X_train.shape[1:]), return_sequences=True,kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(LSTM(100, kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# model.add(Dense(100, kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))

model.add(Dense(75, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(50, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa
opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

#tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "LSTM_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))

# Train model
history = model.fit(
    train_x, train_y,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    shuffle = True,
    validation_data=(validation_x, validation_y),
    #callbacks=[tensorboard],
    class_weight=d_class_weights
)
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 2 ... 0 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# Epoch 1/200
# 30/30 [==============================] - 1s 43ms/step - loss: 0.2789 - accuracy: 0.5153 - mse: 0.4238 - weighted_accuracy: 0.3732 - weighted_mse: 0.4742 - val_loss: 0.2888 - val_accuracy: 0.9083 - val_mse: 0.3464 - val_weighted_accuracy: 0.9083 - val_weighted_mse: 0.3464
# Epoch 2/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.2158 - accuracy: 0.3796 - mse: 0.7104 - weighted_accuracy: 0.4445 - weighted_mse: 0.7027 - val_loss: 0.2859 - val_accuracy: 0.0464 - val_mse: 0.3775 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.3775
# Epoch 3/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1931 - accuracy: 0.3896 - mse: 0.9432 - weighted_accuracy: 0.5044 - weighted_mse: 0.9269 - val_loss: 0.2791 - val_accuracy: 0.1054 - val_mse: 0.3865 - val_weighted_accuracy: 0.1054 - val_weighted_mse: 0.3865
# Epoch 4/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1838 - accuracy: 0.3749 - mse: 1.1131 - weighted_accuracy: 0.5136 - weighted_mse: 1.0941 - val_loss: 0.2668 - val_accuracy: 0.5785 - val_mse: 0.4055 - val_weighted_accuracy: 0.5785 - val_weighted_mse: 0.4055
# Epoch 5/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1784 - accuracy: 0.3293 - mse: 1.2171 - weighted_accuracy: 0.5368 - weighted_mse: 1.1747 - val_loss: 0.2566 - val_accuracy: 0.8830 - val_mse: 0.4303 - val_weighted_accuracy: 0.8830 - val_weighted_mse: 0.4303
# Epoch 6/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1747 - accuracy: 0.3396 - mse: 1.2686 - weighted_accuracy: 0.5514 - weighted_mse: 1.2266 - val_loss: 0.2446 - val_accuracy: 0.9052 - val_mse: 0.4604 - val_weighted_accuracy: 0.9052 - val_weighted_mse: 0.4604
# Epoch 7/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1715 - accuracy: 0.3298 - mse: 1.3025 - weighted_accuracy: 0.5859 - weighted_mse: 1.2539 - val_loss: 0.2400 - val_accuracy: 0.2297 - val_mse: 0.5144 - val_weighted_accuracy: 0.2297 - val_weighted_mse: 0.5144
# Epoch 8/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1692 - accuracy: 0.3543 - mse: 1.3193 - weighted_accuracy: 0.5930 - weighted_mse: 1.2742 - val_loss: 0.2259 - val_accuracy: 0.6428 - val_mse: 0.5511 - val_weighted_accuracy: 0.6428 - val_weighted_mse: 0.5511
# Epoch 9/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1672 - accuracy: 0.3496 - mse: 1.3407 - weighted_accuracy: 0.5968 - weighted_mse: 1.2983 - val_loss: 0.2225 - val_accuracy: 0.0506 - val_mse: 0.6543 - val_weighted_accuracy: 0.0506 - val_weighted_mse: 0.6543
# Epoch 10/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1641 - accuracy: 0.3746 - mse: 1.3404 - weighted_accuracy: 0.6222 - weighted_mse: 1.3039 - val_loss: 0.2088 - val_accuracy: 0.2129 - val_mse: 0.7089 - val_weighted_accuracy: 0.2129 - val_weighted_mse: 0.7089
# Epoch 11/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1618 - accuracy: 0.3477 - mse: 1.3672 - weighted_accuracy: 0.6267 - weighted_mse: 1.3085 - val_loss: 0.1988 - val_accuracy: 0.6502 - val_mse: 0.7471 - val_weighted_accuracy: 0.6502 - val_weighted_mse: 0.7471
# Epoch 12/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1597 - accuracy: 0.3888 - mse: 1.3722 - weighted_accuracy: 0.6418 - weighted_mse: 1.3287 - val_loss: 0.2041 - val_accuracy: 0.1338 - val_mse: 0.8182 - val_weighted_accuracy: 0.1338 - val_weighted_mse: 0.8182
# Epoch 13/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1570 - accuracy: 0.4089 - mse: 1.3751 - weighted_accuracy: 0.6653 - weighted_mse: 1.3373 - val_loss: 0.2108 - val_accuracy: 0.0991 - val_mse: 0.9437 - val_weighted_accuracy: 0.0991 - val_weighted_mse: 0.9437
# Epoch 14/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1558 - accuracy: 0.3475 - mse: 1.4080 - weighted_accuracy: 0.6376 - weighted_mse: 1.3559 - val_loss: 0.1936 - val_accuracy: 0.2086 - val_mse: 1.0577 - val_weighted_accuracy: 0.2086 - val_weighted_mse: 1.0577
# Epoch 15/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1523 - accuracy: 0.3909 - mse: 1.4076 - weighted_accuracy: 0.6588 - weighted_mse: 1.3584 - val_loss: 0.1916 - val_accuracy: 0.5722 - val_mse: 0.7434 - val_weighted_accuracy: 0.5722 - val_weighted_mse: 0.7434
# Epoch 16/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1499 - accuracy: 0.4283 - mse: 1.4023 - weighted_accuracy: 0.6888 - weighted_mse: 1.3692 - val_loss: 0.1710 - val_accuracy: 0.6280 - val_mse: 0.8613 - val_weighted_accuracy: 0.6280 - val_weighted_mse: 0.8613
# Epoch 17/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1479 - accuracy: 0.4268 - mse: 1.4278 - weighted_accuracy: 0.6990 - weighted_mse: 1.3822 - val_loss: 0.2250 - val_accuracy: 0.0769 - val_mse: 1.5357 - val_weighted_accuracy: 0.0769 - val_weighted_mse: 1.5357
# Epoch 18/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1450 - accuracy: 0.4070 - mse: 1.4719 - weighted_accuracy: 0.6917 - weighted_mse: 1.4138 - val_loss: 0.2588 - val_accuracy: 0.1159 - val_mse: 2.0417 - val_weighted_accuracy: 0.1159 - val_weighted_mse: 2.0417
# Epoch 19/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1417 - accuracy: 0.4405 - mse: 1.4689 - weighted_accuracy: 0.7185 - weighted_mse: 1.4309 - val_loss: 0.2718 - val_accuracy: 0.0938 - val_mse: 1.6251 - val_weighted_accuracy: 0.0938 - val_weighted_mse: 1.6251
# Epoch 20/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1394 - accuracy: 0.4652 - mse: 1.4714 - weighted_accuracy: 0.7168 - weighted_mse: 1.4322 - val_loss: 0.3092 - val_accuracy: 0.0548 - val_mse: 2.0802 - val_weighted_accuracy: 0.0548 - val_weighted_mse: 2.0802
# Epoch 21/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1364 - accuracy: 0.4758 - mse: 1.4905 - weighted_accuracy: 0.7423 - weighted_mse: 1.4555 - val_loss: 0.1436 - val_accuracy: 0.7387 - val_mse: 1.3972 - val_weighted_accuracy: 0.7387 - val_weighted_mse: 1.3972
# Epoch 22/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1338 - accuracy: 0.5087 - mse: 1.5125 - weighted_accuracy: 0.7472 - weighted_mse: 1.4784 - val_loss: 0.2567 - val_accuracy: 0.1970 - val_mse: 2.7478 - val_weighted_accuracy: 0.1970 - val_weighted_mse: 2.7478
# Epoch 23/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1313 - accuracy: 0.4860 - mse: 1.5391 - weighted_accuracy: 0.7515 - weighted_mse: 1.5065 - val_loss: 0.1402 - val_accuracy: 0.7281 - val_mse: 1.9890 - val_weighted_accuracy: 0.7281 - val_weighted_mse: 1.9890
# Epoch 24/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1276 - accuracy: 0.4881 - mse: 1.5847 - weighted_accuracy: 0.7559 - weighted_mse: 1.5505 - val_loss: 0.2822 - val_accuracy: 0.1444 - val_mse: 2.7994 - val_weighted_accuracy: 0.1444 - val_weighted_mse: 2.7994
# Epoch 25/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1250 - accuracy: 0.5458 - mse: 1.5856 - weighted_accuracy: 0.7735 - weighted_mse: 1.5759 - val_loss: 0.1880 - val_accuracy: 0.5100 - val_mse: 1.6231 - val_weighted_accuracy: 0.5100 - val_weighted_mse: 1.6231
# Epoch 26/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1239 - accuracy: 0.5308 - mse: 1.6356 - weighted_accuracy: 0.7752 - weighted_mse: 1.6167 - val_loss: 0.1647 - val_accuracy: 0.6375 - val_mse: 3.9252 - val_weighted_accuracy: 0.6375 - val_weighted_mse: 3.9252
# Epoch 27/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1201 - accuracy: 0.5640 - mse: 1.6414 - weighted_accuracy: 0.7946 - weighted_mse: 1.6370 - val_loss: 0.1323 - val_accuracy: 0.8114 - val_mse: 2.0313 - val_weighted_accuracy: 0.8114 - val_weighted_mse: 2.0313
# Epoch 28/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1167 - accuracy: 0.5669 - mse: 1.6778 - weighted_accuracy: 0.8065 - weighted_mse: 1.6695 - val_loss: 0.1561 - val_accuracy: 0.6965 - val_mse: 2.5785 - val_weighted_accuracy: 0.6965 - val_weighted_mse: 2.5785
# Epoch 29/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1133 - accuracy: 0.5938 - mse: 1.7001 - weighted_accuracy: 0.8164 - weighted_mse: 1.7101 - val_loss: 0.2040 - val_accuracy: 0.4362 - val_mse: 1.9752 - val_weighted_accuracy: 0.4362 - val_weighted_mse: 1.9752
# Epoch 30/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1104 - accuracy: 0.5883 - mse: 1.7609 - weighted_accuracy: 0.8089 - weighted_mse: 1.7849 - val_loss: 0.1572 - val_accuracy: 0.8367 - val_mse: 4.9125 - val_weighted_accuracy: 0.8367 - val_weighted_mse: 4.9125
# Epoch 31/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1071 - accuracy: 0.6272 - mse: 1.7959 - weighted_accuracy: 0.8304 - weighted_mse: 1.8248 - val_loss: 0.1276 - val_accuracy: 0.9073 - val_mse: 4.4687 - val_weighted_accuracy: 0.9073 - val_weighted_mse: 4.4687
# Epoch 32/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1035 - accuracy: 0.6367 - mse: 1.8195 - weighted_accuracy: 0.8430 - weighted_mse: 1.8601 - val_loss: 0.1183 - val_accuracy: 0.9041 - val_mse: 5.9098 - val_weighted_accuracy: 0.9041 - val_weighted_mse: 5.9098
# Epoch 33/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1019 - accuracy: 0.6502 - mse: 1.8885 - weighted_accuracy: 0.8462 - weighted_mse: 1.9569 - val_loss: 0.1062 - val_accuracy: 0.9052 - val_mse: 5.3225 - val_weighted_accuracy: 0.9052 - val_weighted_mse: 5.3225
# Epoch 34/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0990 - accuracy: 0.6599 - mse: 1.9386 - weighted_accuracy: 0.8497 - weighted_mse: 2.0023 - val_loss: 0.1622 - val_accuracy: 0.9020 - val_mse: 5.3246 - val_weighted_accuracy: 0.9020 - val_weighted_mse: 5.3246
# Epoch 35/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0955 - accuracy: 0.6857 - mse: 1.9863 - weighted_accuracy: 0.8592 - weighted_mse: 2.0635 - val_loss: 0.2470 - val_accuracy: 0.5227 - val_mse: 5.7813 - val_weighted_accuracy: 0.5227 - val_weighted_mse: 5.7813
# Epoch 36/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0907 - accuracy: 0.7092 - mse: 2.0415 - weighted_accuracy: 0.8750 - weighted_mse: 2.1319 - val_loss: 0.1732 - val_accuracy: 0.7482 - val_mse: 4.5907 - val_weighted_accuracy: 0.7482 - val_weighted_mse: 4.5907
# Epoch 37/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0880 - accuracy: 0.7218 - mse: 2.0873 - weighted_accuracy: 0.8851 - weighted_mse: 2.1953 - val_loss: 0.1239 - val_accuracy: 0.8546 - val_mse: 7.1353 - val_weighted_accuracy: 0.8546 - val_weighted_mse: 7.1353
# Epoch 38/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0844 - accuracy: 0.7424 - mse: 2.2038 - weighted_accuracy: 0.8890 - weighted_mse: 2.3283 - val_loss: 0.1272 - val_accuracy: 0.8978 - val_mse: 6.1070 - val_weighted_accuracy: 0.8978 - val_weighted_mse: 6.1070
# Epoch 39/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0813 - accuracy: 0.7526 - mse: 2.2463 - weighted_accuracy: 0.8892 - weighted_mse: 2.3890 - val_loss: 0.1850 - val_accuracy: 0.8008 - val_mse: 10.5521 - val_weighted_accuracy: 0.8008 - val_weighted_mse: 10.5521
# Epoch 40/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0772 - accuracy: 0.7734 - mse: 2.3294 - weighted_accuracy: 0.9059 - weighted_mse: 2.4800 - val_loss: 0.1625 - val_accuracy: 0.7503 - val_mse: 3.7170 - val_weighted_accuracy: 0.7503 - val_weighted_mse: 3.7170
# Epoch 41/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0737 - accuracy: 0.7713 - mse: 2.4346 - weighted_accuracy: 0.8998 - weighted_mse: 2.6184 - val_loss: 0.1460 - val_accuracy: 0.8430 - val_mse: 5.6469 - val_weighted_accuracy: 0.8430 - val_weighted_mse: 5.6469
# Epoch 42/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0707 - accuracy: 0.8014 - mse: 2.5548 - weighted_accuracy: 0.9162 - weighted_mse: 2.7497 - val_loss: 0.2239 - val_accuracy: 0.6375 - val_mse: 4.9619 - val_weighted_accuracy: 0.6375 - val_weighted_mse: 4.9619
# Epoch 43/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0673 - accuracy: 0.8111 - mse: 2.6566 - weighted_accuracy: 0.9179 - weighted_mse: 2.8519 - val_loss: 0.2736 - val_accuracy: 0.7260 - val_mse: 13.1124 - val_weighted_accuracy: 0.7260 - val_weighted_mse: 13.1124
# Epoch 44/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0658 - accuracy: 0.8090 - mse: 2.7763 - weighted_accuracy: 0.9172 - weighted_mse: 3.0021 - val_loss: 0.1398 - val_accuracy: 0.8472 - val_mse: 5.3334 - val_weighted_accuracy: 0.8472 - val_weighted_mse: 5.3334
# Epoch 45/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0624 - accuracy: 0.8325 - mse: 2.8607 - weighted_accuracy: 0.9276 - weighted_mse: 3.0707 - val_loss: 0.1286 - val_accuracy: 0.8683 - val_mse: 4.6812 - val_weighted_accuracy: 0.8683 - val_weighted_mse: 4.6812
# Epoch 46/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0584 - accuracy: 0.8332 - mse: 2.9964 - weighted_accuracy: 0.9315 - weighted_mse: 3.2446 - val_loss: 0.1900 - val_accuracy: 0.8872 - val_mse: 11.3325 - val_weighted_accuracy: 0.8872 - val_weighted_mse: 11.3325
# Epoch 47/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0550 - accuracy: 0.8562 - mse: 3.1624 - weighted_accuracy: 0.9417 - weighted_mse: 3.3971 - val_loss: 0.1766 - val_accuracy: 0.8409 - val_mse: 10.3636 - val_weighted_accuracy: 0.8409 - val_weighted_mse: 10.3636
# Epoch 48/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0517 - accuracy: 0.8688 - mse: 3.2923 - weighted_accuracy: 0.9410 - weighted_mse: 3.5706 - val_loss: 0.1842 - val_accuracy: 0.8514 - val_mse: 11.0776 - val_weighted_accuracy: 0.8514 - val_weighted_mse: 11.0776
# Epoch 49/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0493 - accuracy: 0.8722 - mse: 3.4042 - weighted_accuracy: 0.9495 - weighted_mse: 3.6849 - val_loss: 0.1556 - val_accuracy: 0.8525 - val_mse: 6.1025 - val_weighted_accuracy: 0.8525 - val_weighted_mse: 6.1025
# Epoch 50/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0454 - accuracy: 0.8965 - mse: 3.6146 - weighted_accuracy: 0.9583 - weighted_mse: 3.8878 - val_loss: 0.2023 - val_accuracy: 0.8240 - val_mse: 5.6193 - val_weighted_accuracy: 0.8240 - val_weighted_mse: 5.6193
# Epoch 51/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0449 - accuracy: 0.8854 - mse: 3.8350 - weighted_accuracy: 0.9525 - weighted_mse: 4.1180 - val_loss: 0.2820 - val_accuracy: 0.6312 - val_mse: 9.0502 - val_weighted_accuracy: 0.6312 - val_weighted_mse: 9.0502
# Epoch 52/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0435 - accuracy: 0.8925 - mse: 3.9871 - weighted_accuracy: 0.9533 - weighted_mse: 4.2737 - val_loss: 0.1874 - val_accuracy: 0.7513 - val_mse: 6.1069 - val_weighted_accuracy: 0.7513 - val_weighted_mse: 6.1069
# Epoch 53/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0383 - accuracy: 0.9094 - mse: 4.1408 - weighted_accuracy: 0.9631 - weighted_mse: 4.5284 - val_loss: 0.2111 - val_accuracy: 0.7629 - val_mse: 7.0244 - val_weighted_accuracy: 0.7629 - val_weighted_mse: 7.0244
# Epoch 54/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0352 - accuracy: 0.9268 - mse: 4.4149 - weighted_accuracy: 0.9695 - weighted_mse: 4.7301 - val_loss: 0.2379 - val_accuracy: 0.7640 - val_mse: 11.3335 - val_weighted_accuracy: 0.7640 - val_weighted_mse: 11.3335
# Epoch 55/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0336 - accuracy: 0.9231 - mse: 4.6691 - weighted_accuracy: 0.9700 - weighted_mse: 5.0195 - val_loss: 0.4446 - val_accuracy: 0.5005 - val_mse: 9.8919 - val_weighted_accuracy: 0.5005 - val_weighted_mse: 9.8919
# Epoch 56/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0308 - accuracy: 0.9294 - mse: 4.8763 - weighted_accuracy: 0.9723 - weighted_mse: 5.2119 - val_loss: 0.2531 - val_accuracy: 0.8809 - val_mse: 11.9243 - val_weighted_accuracy: 0.8809 - val_weighted_mse: 11.9243
# Epoch 57/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0300 - accuracy: 0.9394 - mse: 5.0910 - weighted_accuracy: 0.9760 - weighted_mse: 5.4569 - val_loss: 0.2092 - val_accuracy: 0.9009 - val_mse: 15.9722 - val_weighted_accuracy: 0.9009 - val_weighted_mse: 15.9722
# Epoch 58/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0284 - accuracy: 0.9402 - mse: 5.3612 - weighted_accuracy: 0.9780 - weighted_mse: 5.7337 - val_loss: 0.2872 - val_accuracy: 0.8767 - val_mse: 21.3537 - val_weighted_accuracy: 0.8767 - val_weighted_mse: 21.3537
# Epoch 59/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0270 - accuracy: 0.9523 - mse: 5.5516 - weighted_accuracy: 0.9753 - weighted_mse: 5.8704 - val_loss: 0.2811 - val_accuracy: 0.7903 - val_mse: 17.1754 - val_weighted_accuracy: 0.7903 - val_weighted_mse: 17.1754
# Epoch 60/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0291 - accuracy: 0.9257 - mse: 5.6889 - weighted_accuracy: 0.9727 - weighted_mse: 6.0894 - val_loss: 0.5280 - val_accuracy: 0.9083 - val_mse: 61.1565 - val_weighted_accuracy: 0.9083 - val_weighted_mse: 61.1565
# Epoch 61/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0232 - accuracy: 0.9555 - mse: 6.0785 - weighted_accuracy: 0.9837 - weighted_mse: 6.4156 - val_loss: 0.3869 - val_accuracy: 0.5585 - val_mse: 7.4267 - val_weighted_accuracy: 0.5585 - val_weighted_mse: 7.4267
# Epoch 62/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0204 - accuracy: 0.9655 - mse: 6.3965 - weighted_accuracy: 0.9855 - weighted_mse: 6.7131 - val_loss: 0.3410 - val_accuracy: 0.6481 - val_mse: 11.3099 - val_weighted_accuracy: 0.6481 - val_weighted_mse: 11.3099
# Epoch 63/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0195 - accuracy: 0.9684 - mse: 6.6260 - weighted_accuracy: 0.9884 - weighted_mse: 6.8723 - val_loss: 0.3554 - val_accuracy: 0.8672 - val_mse: 16.8694 - val_weighted_accuracy: 0.8672 - val_weighted_mse: 16.8694
# Epoch 64/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0176 - accuracy: 0.9734 - mse: 6.8579 - weighted_accuracy: 0.9902 - weighted_mse: 7.1602 - val_loss: 0.2937 - val_accuracy: 0.8135 - val_mse: 12.0661 - val_weighted_accuracy: 0.8135 - val_weighted_mse: 12.0661
# Epoch 65/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0153 - accuracy: 0.9837 - mse: 7.2552 - weighted_accuracy: 0.9940 - weighted_mse: 7.4895 - val_loss: 0.3288 - val_accuracy: 0.8883 - val_mse: 19.5594 - val_weighted_accuracy: 0.8883 - val_weighted_mse: 19.5594
# Epoch 66/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0144 - accuracy: 0.9834 - mse: 7.5527 - weighted_accuracy: 0.9939 - weighted_mse: 7.7973 - val_loss: 0.2784 - val_accuracy: 0.7850 - val_mse: 9.0205 - val_weighted_accuracy: 0.7850 - val_weighted_mse: 9.0205
# Epoch 67/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0139 - accuracy: 0.9855 - mse: 7.9253 - weighted_accuracy: 0.9947 - weighted_mse: 8.1536 - val_loss: 0.2909 - val_accuracy: 0.8704 - val_mse: 16.2611 - val_weighted_accuracy: 0.8704 - val_weighted_mse: 16.2611
# Epoch 68/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0153 - accuracy: 0.9810 - mse: 8.1405 - weighted_accuracy: 0.9912 - weighted_mse: 8.3688 - val_loss: 0.2427 - val_accuracy: 0.8377 - val_mse: 11.7912 - val_weighted_accuracy: 0.8377 - val_weighted_mse: 11.7912
# Epoch 69/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0140 - accuracy: 0.9797 - mse: 8.3603 - weighted_accuracy: 0.9926 - weighted_mse: 8.6201 - val_loss: 0.3817 - val_accuracy: 0.7798 - val_mse: 16.6426 - val_weighted_accuracy: 0.7798 - val_weighted_mse: 16.6426
# Epoch 70/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0129 - accuracy: 0.9831 - mse: 8.7014 - weighted_accuracy: 0.9938 - weighted_mse: 8.9276 - val_loss: 0.3207 - val_accuracy: 0.8177 - val_mse: 19.5422 - val_weighted_accuracy: 0.8177 - val_weighted_mse: 19.5422
# Epoch 71/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0119 - accuracy: 0.9900 - mse: 9.0328 - weighted_accuracy: 0.9963 - weighted_mse: 9.1709 - val_loss: 0.4089 - val_accuracy: 0.8672 - val_mse: 24.4902 - val_weighted_accuracy: 0.8672 - val_weighted_mse: 24.4902
# Epoch 72/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0106 - accuracy: 0.9929 - mse: 9.3144 - weighted_accuracy: 0.9974 - weighted_mse: 9.5271 - val_loss: 0.3903 - val_accuracy: 0.7007 - val_mse: 13.2607 - val_weighted_accuracy: 0.7007 - val_weighted_mse: 13.2607
# Epoch 73/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0094 - accuracy: 0.9934 - mse: 9.6588 - weighted_accuracy: 0.9976 - weighted_mse: 9.9768 - val_loss: 0.3874 - val_accuracy: 0.6965 - val_mse: 11.5501 - val_weighted_accuracy: 0.6965 - val_weighted_mse: 11.5501
# Epoch 74/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0089 - accuracy: 0.9966 - mse: 9.9796 - weighted_accuracy: 0.9987 - weighted_mse: 10.0480 - val_loss: 0.3116 - val_accuracy: 0.8704 - val_mse: 15.8428 - val_weighted_accuracy: 0.8704 - val_weighted_mse: 15.8428
# Epoch 75/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0086 - accuracy: 0.9953 - mse: 10.3268 - weighted_accuracy: 0.9983 - weighted_mse: 10.4705 - val_loss: 0.3627 - val_accuracy: 0.8483 - val_mse: 19.4524 - val_weighted_accuracy: 0.8483 - val_weighted_mse: 19.4524
# Epoch 76/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0079 - accuracy: 0.9976 - mse: 10.6779 - weighted_accuracy: 0.9991 - weighted_mse: 10.7034 - val_loss: 0.3433 - val_accuracy: 0.7608 - val_mse: 13.0380 - val_weighted_accuracy: 0.7608 - val_weighted_mse: 13.0380
# Epoch 77/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0075 - accuracy: 0.9987 - mse: 10.9609 - weighted_accuracy: 0.9995 - weighted_mse: 10.9109 - val_loss: 0.3414 - val_accuracy: 0.8767 - val_mse: 17.6672 - val_weighted_accuracy: 0.8767 - val_weighted_mse: 17.6672
# Epoch 78/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0073 - accuracy: 0.9987 - mse: 11.2634 - weighted_accuracy: 0.9995 - weighted_mse: 11.3739 - val_loss: 0.2913 - val_accuracy: 0.8219 - val_mse: 16.7324 - val_weighted_accuracy: 0.8219 - val_weighted_mse: 16.7324
# Epoch 79/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0073 - accuracy: 0.9974 - mse: 11.6384 - weighted_accuracy: 0.9990 - weighted_mse: 11.5255 - val_loss: 0.3466 - val_accuracy: 0.7671 - val_mse: 11.2373 - val_weighted_accuracy: 0.7671 - val_weighted_mse: 11.2373
# Epoch 80/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0072 - accuracy: 0.9974 - mse: 11.8042 - weighted_accuracy: 0.9990 - weighted_mse: 11.8073 - val_loss: 0.3739 - val_accuracy: 0.8620 - val_mse: 22.4425 - val_weighted_accuracy: 0.8620 - val_weighted_mse: 22.4425
# Epoch 81/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0068 - accuracy: 0.9989 - mse: 12.0649 - weighted_accuracy: 0.9996 - weighted_mse: 11.9731 - val_loss: 0.3084 - val_accuracy: 0.7914 - val_mse: 11.5946 - val_weighted_accuracy: 0.7914 - val_weighted_mse: 11.5946
# Epoch 82/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0064 - accuracy: 0.9992 - mse: 12.3533 - weighted_accuracy: 0.9997 - weighted_mse: 12.4208 - val_loss: 0.3624 - val_accuracy: 0.8472 - val_mse: 17.3623 - val_weighted_accuracy: 0.8472 - val_weighted_mse: 17.3623
# Epoch 83/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0061 - accuracy: 0.9995 - mse: 12.7140 - weighted_accuracy: 0.9998 - weighted_mse: 12.5683 - val_loss: 0.4122 - val_accuracy: 0.7387 - val_mse: 13.5144 - val_weighted_accuracy: 0.7387 - val_weighted_mse: 13.5144
# Epoch 84/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0058 - accuracy: 1.0000 - mse: 13.0038 - weighted_accuracy: 1.0000 - weighted_mse: 12.9421 - val_loss: 0.3535 - val_accuracy: 0.8335 - val_mse: 15.9544 - val_weighted_accuracy: 0.8335 - val_weighted_mse: 15.9544
# Epoch 85/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0057 - accuracy: 1.0000 - mse: 13.2673 - weighted_accuracy: 1.0000 - weighted_mse: 13.1497 - val_loss: 0.3585 - val_accuracy: 0.8651 - val_mse: 17.8787 - val_weighted_accuracy: 0.8651 - val_weighted_mse: 17.8787
# Epoch 86/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0057 - accuracy: 1.0000 - mse: 13.4757 - weighted_accuracy: 1.0000 - weighted_mse: 13.3164 - val_loss: 0.3300 - val_accuracy: 0.8514 - val_mse: 15.1981 - val_weighted_accuracy: 0.8514 - val_weighted_mse: 15.1981
# Epoch 87/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0055 - accuracy: 1.0000 - mse: 13.7502 - weighted_accuracy: 1.0000 - weighted_mse: 13.5459 - val_loss: 0.4227 - val_accuracy: 0.8293 - val_mse: 20.9868 - val_weighted_accuracy: 0.8293 - val_weighted_mse: 20.9868
# Epoch 88/200
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0054 - accuracy: 1.0000 - mse: 13.9663 - weighted_accuracy: 1.0000 - weighted_mse: 13.7848 - val_loss: 0.3268 - val_accuracy: 0.8599 - val_mse: 16.8175 - val_weighted_accuracy: 0.8599 - val_weighted_mse: 16.8175
# Epoch 89/200
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0054 - accuracy: 1.0000 - mse: 14.1819 - weighted_accuracy: 1.0000 - weighted_mse: 14.0106 - val_loss: 0.3681 - val_accuracy: 0.8599 - val_mse: 17.4630 - val_weighted_accuracy: 0.8599 - val_weighted_mse: 17.4630
# Epoch 90/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0053 - accuracy: 1.0000 - mse: 14.4753 - weighted_accuracy: 1.0000 - weighted_mse: 14.2138 - val_loss: 0.3768 - val_accuracy: 0.8809 - val_mse: 22.4143 - val_weighted_accuracy: 0.8809 - val_weighted_mse: 22.4143
# Epoch 91/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0052 - accuracy: 1.0000 - mse: 14.6916 - weighted_accuracy: 1.0000 - weighted_mse: 14.4121 - val_loss: 0.3723 - val_accuracy: 0.8325 - val_mse: 16.8157 - val_weighted_accuracy: 0.8325 - val_weighted_mse: 16.8157
# Epoch 92/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0051 - accuracy: 0.9997 - mse: 14.9031 - weighted_accuracy: 0.9999 - weighted_mse: 14.6618 - val_loss: 0.4125 - val_accuracy: 0.8440 - val_mse: 19.1513 - val_weighted_accuracy: 0.8440 - val_weighted_mse: 19.1513
# Epoch 93/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0051 - accuracy: 1.0000 - mse: 15.1816 - weighted_accuracy: 1.0000 - weighted_mse: 14.8738 - val_loss: 0.3527 - val_accuracy: 0.8356 - val_mse: 16.4511 - val_weighted_accuracy: 0.8356 - val_weighted_mse: 16.4511
# Epoch 94/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0050 - accuracy: 1.0000 - mse: 15.3333 - weighted_accuracy: 1.0000 - weighted_mse: 15.1165 - val_loss: 0.3678 - val_accuracy: 0.8693 - val_mse: 21.1196 - val_weighted_accuracy: 0.8693 - val_weighted_mse: 21.1196
# Epoch 95/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0050 - accuracy: 1.0000 - mse: 15.5585 - weighted_accuracy: 1.0000 - weighted_mse: 15.3105 - val_loss: 0.3858 - val_accuracy: 0.8641 - val_mse: 20.1396 - val_weighted_accuracy: 0.8641 - val_weighted_mse: 20.1396
# Epoch 96/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 15.7993 - weighted_accuracy: 1.0000 - weighted_mse: 15.4691 - val_loss: 0.4096 - val_accuracy: 0.8851 - val_mse: 23.5401 - val_weighted_accuracy: 0.8851 - val_weighted_mse: 23.5401
# Epoch 97/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0050 - accuracy: 1.0000 - mse: 15.9567 - weighted_accuracy: 1.0000 - weighted_mse: 15.5419 - val_loss: 0.4698 - val_accuracy: 0.7850 - val_mse: 17.4323 - val_weighted_accuracy: 0.7850 - val_weighted_mse: 17.4323
# Epoch 98/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 16.1961 - weighted_accuracy: 1.0000 - weighted_mse: 15.7878 - val_loss: 0.3944 - val_accuracy: 0.7903 - val_mse: 15.7505 - val_weighted_accuracy: 0.7903 - val_weighted_mse: 15.7505
# Epoch 99/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0049 - accuracy: 0.9997 - mse: 16.4875 - weighted_accuracy: 0.9999 - weighted_mse: 16.1821 - val_loss: 0.4224 - val_accuracy: 0.8978 - val_mse: 27.5872 - val_weighted_accuracy: 0.8978 - val_weighted_mse: 27.5872
# Epoch 100/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 16.6394 - weighted_accuracy: 1.0000 - weighted_mse: 16.1893 - val_loss: 0.3752 - val_accuracy: 0.8567 - val_mse: 18.9424 - val_weighted_accuracy: 0.8567 - val_weighted_mse: 18.9424
# Epoch 101/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 16.9191 - weighted_accuracy: 1.0000 - weighted_mse: 16.3482 - val_loss: 0.3933 - val_accuracy: 0.8251 - val_mse: 17.4517 - val_weighted_accuracy: 0.8251 - val_weighted_mse: 17.4517
# Epoch 102/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 17.0025 - weighted_accuracy: 1.0000 - weighted_mse: 16.7563 - val_loss: 0.4582 - val_accuracy: 0.7524 - val_mse: 16.3171 - val_weighted_accuracy: 0.7524 - val_weighted_mse: 16.3171
# Epoch 103/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 17.2330 - weighted_accuracy: 1.0000 - weighted_mse: 16.8833 - val_loss: 0.4165 - val_accuracy: 0.8388 - val_mse: 20.3052 - val_weighted_accuracy: 0.8388 - val_weighted_mse: 20.3052
# Epoch 104/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 17.4514 - weighted_accuracy: 1.0000 - weighted_mse: 17.1038 - val_loss: 0.4186 - val_accuracy: 0.7956 - val_mse: 16.5616 - val_weighted_accuracy: 0.7956 - val_weighted_mse: 16.5616
# Epoch 105/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 17.7882 - weighted_accuracy: 1.0000 - weighted_mse: 17.2731 - val_loss: 0.4699 - val_accuracy: 0.8641 - val_mse: 24.2217 - val_weighted_accuracy: 0.8641 - val_weighted_mse: 24.2217
# Epoch 106/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 17.9168 - weighted_accuracy: 1.0000 - weighted_mse: 17.2907 - val_loss: 0.4798 - val_accuracy: 0.8166 - val_mse: 21.1591 - val_weighted_accuracy: 0.8166 - val_weighted_mse: 21.1591
# Epoch 107/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 18.0614 - weighted_accuracy: 1.0000 - weighted_mse: 17.4437 - val_loss: 0.6503 - val_accuracy: 0.6681 - val_mse: 17.4065 - val_weighted_accuracy: 0.6681 - val_weighted_mse: 17.4065
# Epoch 108/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 18.2051 - weighted_accuracy: 1.0000 - weighted_mse: 17.7618 - val_loss: 0.4338 - val_accuracy: 0.8103 - val_mse: 18.7151 - val_weighted_accuracy: 0.8103 - val_weighted_mse: 18.7151
# Epoch 109/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 18.4405 - weighted_accuracy: 1.0000 - weighted_mse: 17.8254 - val_loss: 0.4423 - val_accuracy: 0.8651 - val_mse: 25.8888 - val_weighted_accuracy: 0.8651 - val_weighted_mse: 25.8888
# Epoch 110/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 18.6724 - weighted_accuracy: 1.0000 - weighted_mse: 18.0578 - val_loss: 0.4198 - val_accuracy: 0.8061 - val_mse: 18.1337 - val_weighted_accuracy: 0.8061 - val_weighted_mse: 18.1337
# Epoch 111/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 18.7773 - weighted_accuracy: 1.0000 - weighted_mse: 18.1989 - val_loss: 0.4322 - val_accuracy: 0.8599 - val_mse: 23.4068 - val_weighted_accuracy: 0.8599 - val_weighted_mse: 23.4068
# Epoch 112/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 18.9346 - weighted_accuracy: 1.0000 - weighted_mse: 18.3850 - val_loss: 0.4919 - val_accuracy: 0.8030 - val_mse: 20.7533 - val_weighted_accuracy: 0.8030 - val_weighted_mse: 20.7533
# Epoch 113/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 19.1458 - weighted_accuracy: 1.0000 - weighted_mse: 18.6860 - val_loss: 0.4599 - val_accuracy: 0.8282 - val_mse: 20.2147 - val_weighted_accuracy: 0.8282 - val_weighted_mse: 20.2147
# Epoch 114/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 19.2417 - weighted_accuracy: 1.0000 - weighted_mse: 18.5473 - val_loss: 0.4426 - val_accuracy: 0.8198 - val_mse: 20.1338 - val_weighted_accuracy: 0.8198 - val_weighted_mse: 20.1338
# Epoch 115/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 19.2403 - weighted_accuracy: 1.0000 - weighted_mse: 18.4635 - val_loss: 0.6120 - val_accuracy: 0.6670 - val_mse: 16.3560 - val_weighted_accuracy: 0.6670 - val_weighted_mse: 16.3560
# Epoch 116/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 19.3960 - weighted_accuracy: 1.0000 - weighted_mse: 19.1102 - val_loss: 0.4787 - val_accuracy: 0.8704 - val_mse: 30.0731 - val_weighted_accuracy: 0.8704 - val_weighted_mse: 30.0731
# Epoch 117/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 19.6892 - weighted_accuracy: 1.0000 - weighted_mse: 19.1263 - val_loss: 0.5066 - val_accuracy: 0.8072 - val_mse: 23.1549 - val_weighted_accuracy: 0.8072 - val_weighted_mse: 23.1549
# Epoch 118/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 19.8658 - weighted_accuracy: 1.0000 - weighted_mse: 19.4297 - val_loss: 0.4647 - val_accuracy: 0.8556 - val_mse: 22.9405 - val_weighted_accuracy: 0.8556 - val_weighted_mse: 22.9405
# Epoch 119/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 20.0848 - weighted_accuracy: 1.0000 - weighted_mse: 19.5187 - val_loss: 0.4144 - val_accuracy: 0.8788 - val_mse: 25.3556 - val_weighted_accuracy: 0.8788 - val_weighted_mse: 25.3556
# Epoch 120/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 20.2662 - weighted_accuracy: 1.0000 - weighted_mse: 19.6349 - val_loss: 0.4407 - val_accuracy: 0.8303 - val_mse: 20.6660 - val_weighted_accuracy: 0.8303 - val_weighted_mse: 20.6660
# Epoch 121/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 20.4336 - weighted_accuracy: 1.0000 - weighted_mse: 19.8191 - val_loss: 0.4684 - val_accuracy: 0.8430 - val_mse: 23.6207 - val_weighted_accuracy: 0.8430 - val_weighted_mse: 23.6207
# Epoch 122/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 20.6195 - weighted_accuracy: 1.0000 - weighted_mse: 20.0348 - val_loss: 0.4874 - val_accuracy: 0.8693 - val_mse: 27.7405 - val_weighted_accuracy: 0.8693 - val_weighted_mse: 27.7405
# Epoch 123/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 20.7097 - weighted_accuracy: 1.0000 - weighted_mse: 19.9253 - val_loss: 0.4304 - val_accuracy: 0.8599 - val_mse: 22.8460 - val_weighted_accuracy: 0.8599 - val_weighted_mse: 22.8460
# Epoch 124/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 20.9297 - weighted_accuracy: 1.0000 - weighted_mse: 20.4148 - val_loss: 0.4420 - val_accuracy: 0.8293 - val_mse: 22.5021 - val_weighted_accuracy: 0.8293 - val_weighted_mse: 22.5021
# Epoch 125/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 21.0669 - weighted_accuracy: 1.0000 - weighted_mse: 20.4510 - val_loss: 0.8132 - val_accuracy: 0.6502 - val_mse: 19.5981 - val_weighted_accuracy: 0.6502 - val_weighted_mse: 19.5981
# Epoch 126/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 21.1521 - weighted_accuracy: 1.0000 - weighted_mse: 20.4335 - val_loss: 0.4614 - val_accuracy: 0.8693 - val_mse: 27.7021 - val_weighted_accuracy: 0.8693 - val_weighted_mse: 27.7021
# Epoch 127/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 21.3501 - weighted_accuracy: 1.0000 - weighted_mse: 20.6604 - val_loss: 0.5213 - val_accuracy: 0.8145 - val_mse: 23.5436 - val_weighted_accuracy: 0.8145 - val_weighted_mse: 23.5436
# Epoch 128/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 21.4625 - weighted_accuracy: 1.0000 - weighted_mse: 20.7566 - val_loss: 0.5861 - val_accuracy: 0.7460 - val_mse: 18.8383 - val_weighted_accuracy: 0.7460 - val_weighted_mse: 18.8383
# Epoch 129/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 21.6011 - weighted_accuracy: 1.0000 - weighted_mse: 21.1496 - val_loss: 0.5020 - val_accuracy: 0.8367 - val_mse: 24.2219 - val_weighted_accuracy: 0.8367 - val_weighted_mse: 24.2219
# Epoch 130/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 21.7297 - weighted_accuracy: 1.0000 - weighted_mse: 21.1089 - val_loss: 0.4683 - val_accuracy: 0.8219 - val_mse: 23.6268 - val_weighted_accuracy: 0.8219 - val_weighted_mse: 23.6268
# Epoch 131/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 21.8322 - weighted_accuracy: 1.0000 - weighted_mse: 21.1707 - val_loss: 0.5351 - val_accuracy: 0.8303 - val_mse: 24.9304 - val_weighted_accuracy: 0.8303 - val_weighted_mse: 24.9304
# Epoch 132/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 22.0444 - weighted_accuracy: 1.0000 - weighted_mse: 21.4010 - val_loss: 0.4986 - val_accuracy: 0.8483 - val_mse: 25.4720 - val_weighted_accuracy: 0.8483 - val_weighted_mse: 25.4720
# Epoch 133/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 22.1898 - weighted_accuracy: 1.0000 - weighted_mse: 21.5473 - val_loss: 0.4866 - val_accuracy: 0.8335 - val_mse: 22.5618 - val_weighted_accuracy: 0.8335 - val_weighted_mse: 22.5618
# Epoch 134/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0043 - accuracy: 0.9995 - mse: 22.3530 - weighted_accuracy: 0.9998 - weighted_mse: 21.7048 - val_loss: 1.3271 - val_accuracy: 0.4089 - val_mse: 18.6166 - val_weighted_accuracy: 0.4089 - val_weighted_mse: 18.6166
# Epoch 135/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1554 - accuracy: 0.8780 - mse: 18.9998 - weighted_accuracy: 0.8667 - weighted_mse: 17.7524 - val_loss: 11.7239 - val_accuracy: 0.0464 - val_mse: 263.5127 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 263.5127
# Epoch 136/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.1607 - accuracy: 0.7034 - mse: 9.0015 - weighted_accuracy: 0.7935 - weighted_mse: 9.4614 - val_loss: 0.5388 - val_accuracy: 0.6438 - val_mse: 16.6650 - val_weighted_accuracy: 0.6438 - val_weighted_mse: 16.6650
# Epoch 137/200
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0636 - accuracy: 0.8404 - mse: 7.5315 - weighted_accuracy: 0.9034 - weighted_mse: 7.8394 - val_loss: 0.2223 - val_accuracy: 0.9073 - val_mse: 21.3980 - val_weighted_accuracy: 0.9073 - val_weighted_mse: 21.3980
# Epoch 138/200
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0323 - accuracy: 0.9162 - mse: 7.4580 - weighted_accuracy: 0.9548 - weighted_mse: 7.9916 - val_loss: 0.2075 - val_accuracy: 0.8967 - val_mse: 13.8206 - val_weighted_accuracy: 0.8967 - val_weighted_mse: 13.8206
# Epoch 139/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0216 - accuracy: 0.9389 - mse: 8.0535 - weighted_accuracy: 0.9757 - weighted_mse: 8.3329 - val_loss: 0.2367 - val_accuracy: 0.8693 - val_mse: 13.2330 - val_weighted_accuracy: 0.8693 - val_weighted_mse: 13.2330
# Epoch 140/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0145 - accuracy: 0.9784 - mse: 8.7412 - weighted_accuracy: 0.9921 - weighted_mse: 8.7232 - val_loss: 0.3631 - val_accuracy: 0.7935 - val_mse: 18.7161 - val_weighted_accuracy: 0.7935 - val_weighted_mse: 18.7161
# Epoch 141/200
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0120 - accuracy: 0.9826 - mse: 9.2179 - weighted_accuracy: 0.9936 - weighted_mse: 9.2207 - val_loss: 0.4167 - val_accuracy: 0.7587 - val_mse: 19.2240 - val_weighted_accuracy: 0.7587 - val_weighted_mse: 19.2240
# Epoch 142/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0100 - accuracy: 0.9910 - mse: 9.6736 - weighted_accuracy: 0.9967 - weighted_mse: 9.6211 - val_loss: 0.4132 - val_accuracy: 0.8082 - val_mse: 19.6290 - val_weighted_accuracy: 0.8082 - val_weighted_mse: 19.6290
# Epoch 143/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0087 - accuracy: 0.9937 - mse: 10.1098 - weighted_accuracy: 0.9977 - weighted_mse: 10.0003 - val_loss: 0.4006 - val_accuracy: 0.8419 - val_mse: 21.0680 - val_weighted_accuracy: 0.8419 - val_weighted_mse: 21.0680
# Epoch 144/200
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0083 - accuracy: 0.9947 - mse: 10.4613 - weighted_accuracy: 0.9981 - weighted_mse: 10.2479 - val_loss: 0.3828 - val_accuracy: 0.8820 - val_mse: 23.3050 - val_weighted_accuracy: 0.8820 - val_weighted_mse: 23.3050
# Epoch 145/200
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0079 - accuracy: 0.9953 - mse: 10.7596 - weighted_accuracy: 0.9983 - weighted_mse: 10.5908 - val_loss: 0.3808 - val_accuracy: 0.8894 - val_mse: 21.1161 - val_weighted_accuracy: 0.8894 - val_weighted_mse: 21.1161
# Epoch 146/200
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0072 - accuracy: 0.9982 - mse: 11.0227 - weighted_accuracy: 0.9993 - weighted_mse: 10.9098 - val_loss: 0.3940 - val_accuracy: 0.8946 - val_mse: 21.5599 - val_weighted_accuracy: 0.8946 - val_weighted_mse: 21.5599
# Epoch 147/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0069 - accuracy: 0.9984 - mse: 11.3428 - weighted_accuracy: 0.9994 - weighted_mse: 11.1293 - val_loss: 0.3726 - val_accuracy: 0.8872 - val_mse: 19.8645 - val_weighted_accuracy: 0.8872 - val_weighted_mse: 19.8645
# Epoch 148/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0065 - accuracy: 0.9989 - mse: 11.6221 - weighted_accuracy: 0.9996 - weighted_mse: 11.4210 - val_loss: 0.3951 - val_accuracy: 0.8915 - val_mse: 21.2165 - val_weighted_accuracy: 0.8915 - val_weighted_mse: 21.2165
# Epoch 149/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0063 - accuracy: 0.9992 - mse: 11.8239 - weighted_accuracy: 0.9997 - weighted_mse: 11.6040 - val_loss: 0.3836 - val_accuracy: 0.8936 - val_mse: 20.5839 - val_weighted_accuracy: 0.8936 - val_weighted_mse: 20.5839
# Epoch 150/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0062 - accuracy: 0.9992 - mse: 12.0746 - weighted_accuracy: 0.9997 - weighted_mse: 11.8739 - val_loss: 0.3768 - val_accuracy: 0.8841 - val_mse: 19.6120 - val_weighted_accuracy: 0.8841 - val_weighted_mse: 19.6120
# Epoch 151/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0060 - accuracy: 0.9995 - mse: 12.3370 - weighted_accuracy: 0.9998 - weighted_mse: 12.0887 - val_loss: 0.3949 - val_accuracy: 0.8693 - val_mse: 19.8493 - val_weighted_accuracy: 0.8693 - val_weighted_mse: 19.8493
# Epoch 152/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0058 - accuracy: 0.9992 - mse: 12.5599 - weighted_accuracy: 0.9997 - weighted_mse: 12.3689 - val_loss: 0.3851 - val_accuracy: 0.8599 - val_mse: 18.4872 - val_weighted_accuracy: 0.8599 - val_weighted_mse: 18.4872
# Epoch 153/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0057 - accuracy: 0.9997 - mse: 12.8017 - weighted_accuracy: 0.9999 - weighted_mse: 12.5218 - val_loss: 0.3832 - val_accuracy: 0.8830 - val_mse: 20.2322 - val_weighted_accuracy: 0.8830 - val_weighted_mse: 20.2322
# Epoch 154/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0056 - accuracy: 0.9995 - mse: 12.9782 - weighted_accuracy: 0.9998 - weighted_mse: 12.7314 - val_loss: 0.3762 - val_accuracy: 0.8651 - val_mse: 18.1155 - val_weighted_accuracy: 0.8651 - val_weighted_mse: 18.1155
# Epoch 155/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0056 - accuracy: 0.9997 - mse: 13.1738 - weighted_accuracy: 0.9999 - weighted_mse: 12.9524 - val_loss: 0.3704 - val_accuracy: 0.8493 - val_mse: 16.6440 - val_weighted_accuracy: 0.8493 - val_weighted_mse: 16.6440
# Epoch 156/200
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0057 - accuracy: 1.0000 - mse: 13.2767 - weighted_accuracy: 1.0000 - weighted_mse: 13.0773 - val_loss: 0.4086 - val_accuracy: 0.8145 - val_mse: 15.5577 - val_weighted_accuracy: 0.8145 - val_weighted_mse: 15.5577
# Epoch 157/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0054 - accuracy: 0.9997 - mse: 13.4122 - weighted_accuracy: 0.9999 - weighted_mse: 13.3516 - val_loss: 0.3765 - val_accuracy: 0.8609 - val_mse: 18.3799 - val_weighted_accuracy: 0.8609 - val_weighted_mse: 18.3799
# Epoch 158/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0053 - accuracy: 0.9997 - mse: 13.6474 - weighted_accuracy: 0.9999 - weighted_mse: 13.4173 - val_loss: 0.3898 - val_accuracy: 0.8230 - val_mse: 16.7595 - val_weighted_accuracy: 0.8230 - val_weighted_mse: 16.7595
# Epoch 159/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0051 - accuracy: 1.0000 - mse: 13.8628 - weighted_accuracy: 1.0000 - weighted_mse: 13.7030 - val_loss: 0.3760 - val_accuracy: 0.8440 - val_mse: 17.4570 - val_weighted_accuracy: 0.8440 - val_weighted_mse: 17.4570
# Epoch 160/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0052 - accuracy: 1.0000 - mse: 14.0143 - weighted_accuracy: 1.0000 - weighted_mse: 13.7494 - val_loss: 0.3762 - val_accuracy: 0.8398 - val_mse: 17.1659 - val_weighted_accuracy: 0.8398 - val_weighted_mse: 17.1659
# Epoch 161/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0051 - accuracy: 1.0000 - mse: 14.1795 - weighted_accuracy: 1.0000 - weighted_mse: 14.0036 - val_loss: 0.3808 - val_accuracy: 0.8367 - val_mse: 17.2342 - val_weighted_accuracy: 0.8367 - val_weighted_mse: 17.2342
# Epoch 162/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0051 - accuracy: 1.0000 - mse: 14.3485 - weighted_accuracy: 1.0000 - weighted_mse: 14.1208 - val_loss: 0.3840 - val_accuracy: 0.8525 - val_mse: 18.3113 - val_weighted_accuracy: 0.8525 - val_weighted_mse: 18.3113
# Epoch 163/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0050 - accuracy: 1.0000 - mse: 14.5058 - weighted_accuracy: 1.0000 - weighted_mse: 14.2931 - val_loss: 0.3788 - val_accuracy: 0.8388 - val_mse: 17.9871 - val_weighted_accuracy: 0.8388 - val_weighted_mse: 17.9871
# Epoch 164/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0050 - accuracy: 1.0000 - mse: 14.6574 - weighted_accuracy: 1.0000 - weighted_mse: 14.4933 - val_loss: 0.3881 - val_accuracy: 0.8809 - val_mse: 21.4817 - val_weighted_accuracy: 0.8809 - val_weighted_mse: 21.4817
# Epoch 165/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 14.8082 - weighted_accuracy: 1.0000 - weighted_mse: 14.6505 - val_loss: 0.3795 - val_accuracy: 0.8599 - val_mse: 19.7109 - val_weighted_accuracy: 0.8599 - val_weighted_mse: 19.7109
# Epoch 166/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0050 - accuracy: 1.0000 - mse: 14.9308 - weighted_accuracy: 1.0000 - weighted_mse: 14.5794 - val_loss: 0.3829 - val_accuracy: 0.8409 - val_mse: 17.2571 - val_weighted_accuracy: 0.8409 - val_weighted_mse: 17.2571
# Epoch 167/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0049 - accuracy: 1.0000 - mse: 15.0321 - weighted_accuracy: 1.0000 - weighted_mse: 14.8475 - val_loss: 0.3874 - val_accuracy: 0.8356 - val_mse: 17.6381 - val_weighted_accuracy: 0.8356 - val_weighted_mse: 17.6381
# Epoch 168/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 15.1732 - weighted_accuracy: 1.0000 - weighted_mse: 15.0001 - val_loss: 0.4242 - val_accuracy: 0.8072 - val_mse: 16.0038 - val_weighted_accuracy: 0.8072 - val_weighted_mse: 16.0038
# Epoch 169/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 15.3103 - weighted_accuracy: 1.0000 - weighted_mse: 15.1572 - val_loss: 0.3975 - val_accuracy: 0.8209 - val_mse: 16.8977 - val_weighted_accuracy: 0.8209 - val_weighted_mse: 16.8977
# Epoch 170/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 15.4236 - weighted_accuracy: 1.0000 - weighted_mse: 15.1767 - val_loss: 0.4176 - val_accuracy: 0.8219 - val_mse: 17.1785 - val_weighted_accuracy: 0.8219 - val_weighted_mse: 17.1785
# Epoch 171/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 15.5470 - weighted_accuracy: 1.0000 - weighted_mse: 15.3987 - val_loss: 0.4038 - val_accuracy: 0.8462 - val_mse: 18.3992 - val_weighted_accuracy: 0.8462 - val_weighted_mse: 18.3992
# Epoch 172/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 15.6871 - weighted_accuracy: 1.0000 - weighted_mse: 15.5269 - val_loss: 0.3883 - val_accuracy: 0.8493 - val_mse: 18.3997 - val_weighted_accuracy: 0.8493 - val_weighted_mse: 18.3997
# Epoch 173/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 15.8262 - weighted_accuracy: 1.0000 - weighted_mse: 15.6830 - val_loss: 0.4073 - val_accuracy: 0.8209 - val_mse: 16.3342 - val_weighted_accuracy: 0.8209 - val_weighted_mse: 16.3342
# Epoch 174/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 15.9756 - weighted_accuracy: 1.0000 - weighted_mse: 15.8400 - val_loss: 0.3882 - val_accuracy: 0.8462 - val_mse: 18.4738 - val_weighted_accuracy: 0.8462 - val_weighted_mse: 18.4738
# Epoch 175/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0047 - accuracy: 1.0000 - mse: 16.0794 - weighted_accuracy: 1.0000 - weighted_mse: 15.8483 - val_loss: 0.4137 - val_accuracy: 0.8346 - val_mse: 18.2691 - val_weighted_accuracy: 0.8346 - val_weighted_mse: 18.2691
# Epoch 176/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 16.1819 - weighted_accuracy: 1.0000 - weighted_mse: 16.0251 - val_loss: 0.3929 - val_accuracy: 0.8325 - val_mse: 18.4424 - val_weighted_accuracy: 0.8325 - val_weighted_mse: 18.4424
# Epoch 177/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 16.3414 - weighted_accuracy: 1.0000 - weighted_mse: 16.2100 - val_loss: 0.3878 - val_accuracy: 0.8377 - val_mse: 18.6729 - val_weighted_accuracy: 0.8377 - val_weighted_mse: 18.6729
# Epoch 178/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 16.5101 - weighted_accuracy: 1.0000 - weighted_mse: 16.3454 - val_loss: 0.3946 - val_accuracy: 0.8303 - val_mse: 18.8082 - val_weighted_accuracy: 0.8303 - val_weighted_mse: 18.8082
# Epoch 179/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 16.6266 - weighted_accuracy: 1.0000 - weighted_mse: 16.3739 - val_loss: 0.4061 - val_accuracy: 0.8209 - val_mse: 18.0992 - val_weighted_accuracy: 0.8209 - val_weighted_mse: 18.0992
# Epoch 180/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 16.7042 - weighted_accuracy: 1.0000 - weighted_mse: 16.4034 - val_loss: 0.3882 - val_accuracy: 0.8251 - val_mse: 17.4737 - val_weighted_accuracy: 0.8251 - val_weighted_mse: 17.4737
# Epoch 181/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 16.8681 - weighted_accuracy: 1.0000 - weighted_mse: 16.5981 - val_loss: 0.4175 - val_accuracy: 0.8103 - val_mse: 17.0239 - val_weighted_accuracy: 0.8103 - val_weighted_mse: 17.0239
# Epoch 182/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0046 - accuracy: 1.0000 - mse: 16.9683 - weighted_accuracy: 1.0000 - weighted_mse: 16.7432 - val_loss: 0.4187 - val_accuracy: 0.8156 - val_mse: 17.0309 - val_weighted_accuracy: 0.8156 - val_weighted_mse: 17.0309
# Epoch 183/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 17.0840 - weighted_accuracy: 1.0000 - weighted_mse: 16.8880 - val_loss: 0.4129 - val_accuracy: 0.8219 - val_mse: 17.6446 - val_weighted_accuracy: 0.8219 - val_weighted_mse: 17.6446
# Epoch 184/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 17.2027 - weighted_accuracy: 1.0000 - weighted_mse: 16.8918 - val_loss: 0.4024 - val_accuracy: 0.8398 - val_mse: 19.3541 - val_weighted_accuracy: 0.8398 - val_weighted_mse: 19.3541
# Epoch 185/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 17.3087 - weighted_accuracy: 1.0000 - weighted_mse: 17.0435 - val_loss: 0.4241 - val_accuracy: 0.8209 - val_mse: 18.2574 - val_weighted_accuracy: 0.8209 - val_weighted_mse: 18.2574
# Epoch 186/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 17.3562 - weighted_accuracy: 1.0000 - weighted_mse: 17.2078 - val_loss: 0.4184 - val_accuracy: 0.8240 - val_mse: 18.5490 - val_weighted_accuracy: 0.8240 - val_weighted_mse: 18.5490
# Epoch 187/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 17.5200 - weighted_accuracy: 1.0000 - weighted_mse: 17.2841 - val_loss: 0.4242 - val_accuracy: 0.8282 - val_mse: 18.8703 - val_weighted_accuracy: 0.8282 - val_weighted_mse: 18.8703
# Epoch 188/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 17.5847 - weighted_accuracy: 1.0000 - weighted_mse: 17.3895 - val_loss: 0.4251 - val_accuracy: 0.8293 - val_mse: 19.5426 - val_weighted_accuracy: 0.8293 - val_weighted_mse: 19.5426
# Epoch 189/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 17.7290 - weighted_accuracy: 1.0000 - weighted_mse: 17.4543 - val_loss: 0.4289 - val_accuracy: 0.8430 - val_mse: 21.0861 - val_weighted_accuracy: 0.8430 - val_weighted_mse: 21.0861
# Epoch 190/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 17.8959 - weighted_accuracy: 1.0000 - weighted_mse: 17.7098 - val_loss: 0.4334 - val_accuracy: 0.8166 - val_mse: 18.8319 - val_weighted_accuracy: 0.8166 - val_weighted_mse: 18.8319
# Epoch 191/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0045 - accuracy: 1.0000 - mse: 17.9562 - weighted_accuracy: 1.0000 - weighted_mse: 17.6255 - val_loss: 0.4202 - val_accuracy: 0.8303 - val_mse: 19.7847 - val_weighted_accuracy: 0.8303 - val_weighted_mse: 19.7847
# Epoch 192/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 18.0865 - weighted_accuracy: 1.0000 - weighted_mse: 17.8493 - val_loss: 0.4046 - val_accuracy: 0.8430 - val_mse: 20.0195 - val_weighted_accuracy: 0.8430 - val_weighted_mse: 20.0195
# Epoch 193/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 18.2408 - weighted_accuracy: 1.0000 - weighted_mse: 17.9560 - val_loss: 0.4020 - val_accuracy: 0.8419 - val_mse: 20.1635 - val_weighted_accuracy: 0.8419 - val_weighted_mse: 20.1635
# Epoch 194/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 18.2913 - weighted_accuracy: 1.0000 - weighted_mse: 18.0055 - val_loss: 0.4074 - val_accuracy: 0.8293 - val_mse: 19.0702 - val_weighted_accuracy: 0.8293 - val_weighted_mse: 19.0702
# Epoch 195/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 18.4206 - weighted_accuracy: 1.0000 - weighted_mse: 18.1846 - val_loss: 0.4261 - val_accuracy: 0.8261 - val_mse: 20.1419 - val_weighted_accuracy: 0.8261 - val_weighted_mse: 20.1419
# Epoch 196/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 18.5270 - weighted_accuracy: 1.0000 - weighted_mse: 18.3889 - val_loss: 0.4286 - val_accuracy: 0.8261 - val_mse: 19.8126 - val_weighted_accuracy: 0.8261 - val_weighted_mse: 19.8126
# Epoch 197/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 18.5750 - weighted_accuracy: 1.0000 - weighted_mse: 18.1977 - val_loss: 0.4468 - val_accuracy: 0.8219 - val_mse: 20.3458 - val_weighted_accuracy: 0.8219 - val_weighted_mse: 20.3458
# Epoch 198/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 18.7002 - weighted_accuracy: 1.0000 - weighted_mse: 18.4144 - val_loss: 0.4385 - val_accuracy: 0.8061 - val_mse: 18.7931 - val_weighted_accuracy: 0.8061 - val_weighted_mse: 18.7931
# Epoch 199/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0044 - accuracy: 1.0000 - mse: 18.8024 - weighted_accuracy: 1.0000 - weighted_mse: 18.5779 - val_loss: 0.4262 - val_accuracy: 0.8166 - val_mse: 18.6910 - val_weighted_accuracy: 0.8166 - val_weighted_mse: 18.6910
# Epoch 200/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0043 - accuracy: 1.0000 - mse: 18.9028 - weighted_accuracy: 1.0000 - weighted_mse: 18.6559 - val_loss: 0.4424 - val_accuracy: 0.8135 - val_mse: 18.4325 - val_weighted_accuracy: 0.8135 - val_weighted_mse: 18.4325

# %%
# Score model
score = model.evaluate(validation_x, validation_y, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.4423999786376953
# Test accuracy: 0.8134878873825073

# %%
predictions = model.predict(validation_x)
print(predictions)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
from collections import Counter

Counter(predictions)
# Out:
# [[-2.6573808 -4.826957   2.5417616]
#  [ 4.1140814 -8.430445  -3.867737 ]
#  [-2.0523582 -7.66297    1.6668913]
#  ...
#  [-5.4298477 -5.090259   4.0963345]
#  [-3.965393  -6.9507775  4.6989446]
#  [-4.989978  -4.435863   3.5676641]]
# Counter({2: 836, 0: 69, 1: 44})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in validation_y]
Counter(actual)
# Out:
# Counter({2: 862, 0: 43, 1: 44})

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold))
# Out:
# number of predictions: 949
# actual predicted buys: 4
# actual buys but predicted sell: 2
# actual buys but predicted hold: 38
# actual sells but predicted buy: 1
# actual predicted sells: 6
# actual sells but predicted hold: 36
# actual holds but predicted buy: 39
# actual holds but predicted sell: 61
# actual predicted holds: 762
# Percentage buys correct: 9.090909090909092%
# Percentage sells correct: 13.953488372093023%
# Percentage holds correct: 88.39907192575406%
# actual buys: 44
# actual sells: 43
# actual holds: 862

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.figure(figsize=(20,10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Save model
model.save("models/{}".format('fdp_image_lstm_buy_hold_sell_original.model'))
# Out:
# INFO:tensorflow:Assets written to: models/fdp_image_lstm_buy_hold_sell_original.model\assets

# %% [markdown]
# ### Test Performance

# %% [markdown]
# ### non-recession

# %%
seed = 10
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/FDP_data_test.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels
# Date
# 2019-01-22    30.219999  29.918096 -32.033467  1515700.0     2.0
# 2019-01-23    30.480000  30.004543 -24.791121  1646600.0     2.0
# 2019-01-24    30.459999  30.074613 -28.980936  1528300.0     2.0
# 2019-01-25    30.639999  30.161596 -35.265743  1632300.0     2.0
# 2019-01-28    30.879999  30.272119 -23.671560  1731100.0     2.0

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/fdp_image_lstm_buy_hold_sell_original.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3434 - accuracy: 0.8257 - mean_squared_error: 15.6529 - weighted_accuracy: 0.8257 - weighted_mean_squared_error: 15.6529
# Test loss: 0.3434421420097351
# Test accuracy: 0.8256880640983582

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 197, 1: 10, 0: 11})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]

# %%
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/FDP_data_test.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels  predictions  \
# Date
# 2019-02-11    33.880001  31.978904  -0.753738  2502700.0     2.0            2
# 2019-02-12    34.610001  32.271381  -0.536205  2611700.0     2.0            2
# 2019-02-13    34.810001  32.631168  -5.603413  2713000.0     2.0            2
# 2019-02-14    34.430000  32.966373  -5.668932  2794100.0     2.0            2
# 2019-02-15    35.220001  33.191547 -14.285733  2675800.0     0.0            1
#
#             actual
# Date
# 2019-02-11       2
# 2019-02-12       2
# 2019-02-13       2
# 2019-02-14       2
# 2019-02-15       0

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold))
# Out:
# number of predictions: 218
# actual predicted buys: 0
# actual buys but predicted sell: 0
# actual buys but predicted hold: 10
# actual sells but predicted buy: 1
# actual predicted sells: 1
# actual sells but predicted hold: 8
# actual holds but predicted buy: 9
# actual holds but predicted sell: 10
# actual predicted holds: 179
# Percentage buys correct: 0.0%
# Percentage sells correct: 10.0%
# Percentage holds correct: 90.4040404040404%
# actual buys: 10
# actual sells: 10
# actual holds: 198

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%")
# Out:
# [27.709999084472656, 27.8700008392334, 27.989999771118164, 29.209999084472656, 33.880001068115234, 34.43000030517578, 34.610000610351555, 34.810001373291016, 35.220001220703125]
# [26.920000076293945, 27.15999984741211, 27.68000030517578, 27.70000076293945, 27.709999084472656, 27.8700008392334, 27.989999771118164, 28.020000457763672, 28.34000015258789]
# Percentage buys correct: 40.0%
# Percentage sells correct: 18.181818181818183%
# Percentage holds correct: 84.18367346938776%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
#         print(i)
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $35.220001220703125
# Shares owned at the moment: 283
# Cash capital at the moment: $5.329688591004015
#
#
# Stop Loss Activated!
#
# Share price: $29.209999084472656
# Shares owned at the moment: 0
# Cash capital at the moment: $8249.026747709275
#
#
# Share price: $26.34000015258789
# Shares owned at the moment: 312
# Cash capital at the moment: $8.346979970932807
#
#
# Price increase from previously bought: 6.199973893231037%
# Share price: $28.04999923706055
# Shares owned at the moment: 0
# Cash capital at the moment: $8735.879842588427
#
#
# Share price: $29.38999938964844
# Shares owned at the moment: 296
# Cash capital at the moment: $12.516563749313718
#
#
# Stop Loss Activated!
#
# Share price: $28.53000068664551
# Shares owned at the moment: 0
# Cash capital at the moment: $8434.173346437456
#
#
# Share price: $24.88999938964844
# Shares owned at the moment: 337
# Cash capital at the moment: $23.17674519157299
#
#
# Price increase from previously bought: 8.099673282317688%
# Share price: $26.979999542236328
# Shares owned at the moment: 0
# Cash capital at the moment: $9090.432876349449
#
#
# Share price: $27.25
# Shares owned at the moment: 332
# Cash capital at the moment: $18.553626349448678
#
#
# Stop Loss Activated!
#
# Share price: $25.420000076293945
# Shares owned at the moment: 0
# Cash capital at the moment: $8434.785191609382
#
#
# Share price: $24.95000076293945
# Shares owned at the moment: 337
# Cash capital at the moment: $3.5125212917337194
#
#
# Price increase from previously bought: 8.878935385219467%
# Share price: $27.239999771118164
# Shares owned at the moment: 0
# Cash capital at the moment: $9158.147774370671
#
#
# Share price: $30.729999542236328
# Shares owned at the moment: 297
# Cash capital at the moment: $6.239183200359548
#
#
# Price increase from previously bought: 23.286092579534913%
# Share price: $37.9900016784668
# Shares owned at the moment: 0
# Cash capital at the moment: $11258.24134783411
#
#
# Share price: $28.54999923706055
# Shares owned at the moment: 393
# Cash capital at the moment: $7.2362359938597365
#
#
#
#
# Capital at the end of test period: $13516.693261910912
# profit gained: 35.16693261910912%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $10118.19906801033
# profit gained: 1.1819906801032993%

# %% [markdown]
# ### recession

# %%
seed = 10
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/FDP_data_test2.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d     EMA_12   willr_14     OBV_7  labels
# Date
# 2020-01-22    34.250000  34.338683 -60.666656  -55800.0     2.0
# 2020-01-23    34.130001  34.306578 -67.360995 -191000.0     2.0
# 2020-01-24    34.520000  34.339413 -36.764689   18500.0     2.0
# 2020-01-27    32.290001  34.024118 -98.555924 -130500.0     2.0
# 2020-01-28    32.160000  33.737331 -85.885906 -280200.0     2.0

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/fdp_image_lstm_buy_hold_sell_original.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3295 - accuracy: 0.8676 - mean_squared_error: 16.1638 - weighted_accuracy: 0.8676 - weighted_mean_squared_error: 16.1638
# Test loss: 0.3294851779937744
# Test accuracy: 0.8675799369812012

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 206, 1: 8, 0: 5})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]

# %%
df = pd.read_csv("data/noncyclic_tickers/initial_indicators/FDP_data_test2.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14     OBV_7  labels  predictions  \
# Date
# 2020-02-11    33.930000  32.680842 -26.373606  310600.0     2.0            2
# 2020-02-12    34.410000  32.873020 -19.505473  431300.0     2.0            2
# 2020-02-13    34.240002  33.109478 -14.750004  582800.0     2.0            2
# 2020-02-14    34.480000  33.283405 -18.999958  490800.0     0.0            2
# 2020-02-18    34.009998  33.467496 -13.000011  587800.0     2.0            2
#
#             actual
# Date
# 2020-02-11       2
# 2020-02-12       2
# 2020-02-13       2
# 2020-02-14       0
# 2020-02-18       2

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold))
# Out:
# number of predictions: 219
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 9
# actual sells but predicted buy: 0
# actual predicted sells: 1
# actual sells but predicted hold: 9
# actual holds but predicted buy: 7
# actual holds but predicted sell: 4
# actual predicted holds: 188
# Percentage buys correct: 10.0%
# Percentage sells correct: 10.0%
# Percentage holds correct: 94.47236180904522%
# actual buys: 10
# actual sells: 10
# actual holds: 199

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%")
# Out:
# [28.65999984741211, 29.020000457763672, 29.26000022888184, 30.36000061035156, 33.93000030517578, 34.009998321533196, 34.240001678466804, 34.40999984741211, 34.47999954223633]
# [27.420000076293945, 27.81999969482422, 28.6200008392334, 28.65999984741211, 28.739999771118164, 29.0, 29.020000457763672, 30.35000038146973, 30.36000061035156]
# Percentage buys correct: 62.5%
# Percentage sells correct: 60.0%
# Percentage holds correct: 82.92682926829268%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
#         print(i)
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $28.040000915527344
# Shares owned at the moment: 355
# Cash capital at the moment: $18.425624094008526
#
#
# Stop Loss Activated!
#
# Share price: $24.399999618530273
# Shares owned at the moment: 0
# Cash capital at the moment: $8656.604989044665
#
#
# Share price: $24.239999771118164
# Shares owned at the moment: 356
# Cash capital at the moment: $3.434110750673426
#
#
# Stop Loss Activated!
#
# Share price: $21.549999237060547
# Shares owned at the moment: 0
# Cash capital at the moment: $7654.136389891146
#
#
# Share price: $22.200000762939453
# Shares owned at the moment: 343
# Cash capital at the moment: $18.59597748327087
#
#
# Price increase from previously bought: 11.090890557046107%
# Share price: $24.729999542236328
# Shares owned at the moment: 0
# Cash capital at the moment: $8477.659248402117
#
#
# Share price: $24.21999931335449
# Shares owned at the moment: 349
# Cash capital at the moment: $1.6343437004088628
#
#
# Stop Loss Activated!
#
# Share price: $23.239999771118164
# Shares owned at the moment: 0
# Cash capital at the moment: $8090.089674040317
#
#
# Share price: $23.18000030517578
# Shares owned at the moment: 348
# Cash capital at the moment: $1.2663075470918557
#
#
# Stop Loss Activated!
#
# Share price: $22.36000061035156
# Shares owned at the moment: 0
# Cash capital at the moment: $7761.147999365328
#
#
# Share price: $25.43000030517578
# Shares owned at the moment: 304
# Cash capital at the moment: $9.168426336763332
#
#
#
#
# Capital at the end of test period: $7639.806329466341
# profit gained: -23.601936705336595%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $7385.700107630253
# profit gained: -26.14299892369747%
