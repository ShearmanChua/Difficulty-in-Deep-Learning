# %%
import os
seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
experiment = 'Chinese Liquor LSTM Experiment'

# %%
import requests
import lxml
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.utils import compute_class_weight
import tensorflow as tf
from pil import Image
from sklearn import preprocessing
import tensorflow_addons as tfa
import glob
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
import math

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
# gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
np.random.seed(seed)
tf.random.set_seed(seed)

session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, 
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), 
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)

# %%
def pred_acc(actual, predictions, logger):

    hold = 0
    sell = 0
    buy = 0
    pred_hold = 0
    pred_sell = 0
    pred_buy = 0
    buy_buy = 0
    buy_sell = 0
    buy_hold = 0
    sell_buy = 0
    sell_sell = 0
    sell_hold = 0
    hold_buy = 0
    hold_sell = 0
    hold_hold = 0

    for i in range (0,len(actual)):
        if actual[i]==1 and predictions[i] == 1:
            buy_buy += 1
            buy += 1
            pred_buy += 1
        elif actual[i]==1 and predictions[i] == 0:
            buy_sell += 1
            buy += 1
            pred_sell += 1
        elif actual[i]==1 and predictions[i] == 2:
            buy_hold += 1
            buy += 1
            pred_hold += 1
        elif actual[i]==0 and predictions[i] == 1:
            sell_buy += 1
            sell += 1
            pred_buy += 1
        elif actual[i]==0 and predictions[i] == 0:
            sell_sell += 1
            sell += 1
            pred_sell += 1
        elif actual[i]==0 and predictions[i] == 2:
            sell_hold += 1
            sell += 1
            pred_hold += 1
        elif actual[i]==2 and predictions[i] == 1:
            hold_buy += 1
            hold += 1
            pred_buy += 1
        elif actual[i]==2 and predictions[i] == 0:
            hold_sell += 1
            hold += 1
            pred_sell += 1
        elif actual[i]==2 and predictions[i] == 2:
            hold_hold += 1
            hold += 1
            pred_hold += 1

    print("number of predictions: " + str(len(actual)))
    print("actual predicted buys: " + str(buy_buy) )
    print("actual buys but predicted sell: " + str(buy_sell) )
    print("actual buys but predicted hold: " + str(buy_hold))
    print("actual sells but predicted buy: " + str(sell_buy) )
    print("actual predicted sells: " + str(sell_sell))
    print("actual sells but predicted hold: " + str(sell_hold) )
    print("actual holds but predicted buy: " + str(hold_buy) )
    print("actual holds but predicted sell: " + str(hold_sell))
    print("actual predicted holds: " + str(hold_hold) )
    
    if pred_buy !=0:
        Percentage_buys_correct = 100*buy_buy/pred_buy
    else:
        Percentage_buys_correct = 0
        
    if pred_sell !=0:
        Percentage_sells_correct = 100*sell_sell/pred_sell
    else:
        Percentage_sells_correct = 0
        
    if pred_hold !=0:
        Percentage_holds_correct = 100*hold_hold/pred_hold
    else:
        Percentage_holds_correct = 0

    print("Percentage buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage holds correct: " + str(Percentage_holds_correct) + "%")

    print("actual buys: " + str(buy))
    print("actual sells: " + str(sell))
    print("actual holds: " + str(hold))
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def correct_maxima_minima(predictions, price, logger):
    correct_maxima = 0 
    correct_minima = 0
    correct_hold = 0

    hold = 0
    buy = 0
    sell = 0

#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):
        if i < 4:
            prices = price[i:i+9]
            prices.sort(key = float)
#             if i == 0:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1

        else:
            prices = price[i:i+5]
            prices = prices + price[i-4:i] 
            prices.sort(key = float)
#             if i == 10:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1
                    
    if buy !=0:
        Percentage_buys_correct = 100*correct_minima/buy
    else:
        Percentage_buys_correct = 0
        
    if sell !=0:
        Percentage_sells_correct = 100*correct_maxima/sell
    else:
        Percentage_sells_correct = 0
        
    if hold !=0:
        Percentage_holds_correct = 100*correct_hold/hold
    else:
        Percentage_holds_correct = 0

    print("Percentage low buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage high sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage mid holds correct: " + str(Percentage_holds_correct) + "%")
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %% [markdown]
# ## Prepare Test Data

# %%
nr_test_sets = ['600779.SS','000858.SZ','600519.SS']
nr_test_data = {}

for name in nr_test_sets:

    df = pd.read_csv("variation 7/initial_indicators/{}_data_test.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    labels = []
    data_15 = []
    sequential = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15.append(np.array(i[0:-1]))
            labels.append(i[-1])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_arr = min_max_scaler.fit_transform(data_15)
            sequential.append(data_15_arr)
            data_15 = data_15[1:15]
        else:
            data_15.append(np.array(i[0:-1]))
            count+= 1
        
    X = sequential
    X  = np.array(X).reshape(-1, 15, 4)
    y = labels
    y = np.array(y)
    
    y = to_categorical(y, 3)
    
    nr_test_data['{}_X'.format(name)] = X
    nr_test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22    31.600000  30.182096 -19.458106  26955841.0     2.0
# 2019-01-23    30.840000  30.283312 -37.717127  23083639.0     2.0
# 2019-01-24    30.780001  30.359725 -39.205947  19954758.0     2.0
# 2019-01-25    31.190001  30.487460 -32.142848  23689151.0     2.0
# 2019-01-28    30.440001  30.480159 -52.747236  18093372.0     2.0
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22    56.000000  51.668614  -4.420537  97514467.0     2.0
# 2019-01-23    55.209999  52.213443 -13.859020  63945311.0     2.0
# 2019-01-24    55.070000  52.652913 -15.531654  43721083.0     2.0
# 2019-01-25    55.200001  53.044773 -15.620808  63080844.0     2.0
# 2019-01-28    55.250000  53.384039 -14.953261  87254847.0     2.0
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22   686.979980  640.790403 -10.183147  35030093.0     2.0
# 2019-01-23   671.000000  645.438034 -23.857615  30817872.0     2.0
# 2019-01-24   665.659973  648.549101 -28.427209  27455391.0     2.0
# 2019-01-25   672.500000  652.233855 -26.754575  30370918.0     2.0
# 2019-01-28   679.700012  656.459418 -19.452330  33269553.0     2.0

# %%
r_test_sets = ['600779.SS','000858.SZ','600519.SS']
r_test_data = {}

for name in r_test_sets:

    df = pd.read_csv("variation 7/initial_indicators/{}_data_test2.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    labels = []
    data_15 = []
    sequential = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15.append(np.array(i[0:-1]))
            labels.append(i[-1])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_arr = min_max_scaler.fit_transform(data_15)
            sequential.append(data_15_arr)
            data_15 = data_15[1:15]
        else:
            data_15.append(np.array(i[0:-1]))
            count+= 1
        
    X = sequential
    X  = np.array(X).reshape(-1, 15, 4)
    y = labels
    y = np.array(y)
    
    y = to_categorical(y, 3)
    
    r_test_data['{}_X'.format(name)] = X
    r_test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d     EMA_12    willr_14       OBV_7  labels
# Date
# 2020-01-22    49.880001  51.521484  -90.954757   9556447.0     2.0
# 2020-01-23    50.939999  51.432025  -47.232514  14604083.0     2.0
# 2020-02-03    51.389999  51.425560  -43.127187  25428297.0     2.0
# 2020-02-04    46.250000  50.629320 -100.000000  24157097.0     1.0
# 2020-02-05    44.200001  49.640194  -88.990820  13715132.0     2.0
#             previous_1d      EMA_12    willr_14       OBV_7  labels
# Date
# 2020-01-22   132.619995  134.532144  -69.037983  36658288.0     2.0
# 2020-01-23   131.699997  134.096429  -75.271035  10905237.0     2.0
# 2020-02-03   126.160004  132.875441  -93.486784 -30688431.0     1.0
# 2020-02-04   113.540001  129.900758 -100.000000 -47452331.0     2.0
# 2020-02-05   114.500000  127.531410  -83.732622  23569095.0     2.0
#             previous_1d       EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22  1075.300049  1097.577291 -89.711935   1200864.0     2.0
# 2020-01-23  1075.510010  1094.182325 -70.779503   4820868.0     2.0
# 2020-02-03  1052.800049  1087.815821 -81.895216   -525975.0     1.0
# 2020-02-04  1003.919983  1074.908769 -83.419991 -12870263.0     2.0
# 2020-02-05  1038.010010  1069.232037 -59.790669  -6607845.0     2.0

# %% [markdown]
# ## Train Sichuan Swellfun Co.,Ltd Stock Data

# %% [markdown]
# ### Creating Training Data and Model

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []

seed = 10
df = pd.read_csv('variation 7/initial_indicators/600779.SS_data.csv')
df.set_index('Date', inplace=True)
print(df.head())

plt.figure(figsize=(15,5))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
plt.show()

labels = []
data_15 = []
sequential = []
count = 0

for i in df.values:
    if count == 14:
        data_15.append(np.array(i[0:-1]))
        labels.append(i[-1])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_arr = min_max_scaler.fit_transform(data_15)
        sequential.append(data_15_arr)
        data_15 = data_15[1:15]
    else:
        data_15.append(np.array(i[0:-1]))
        count+= 1
        
X = sequential
X  = np.array(X).reshape(-1, 15, 4)
y = labels
y = np.array(y)

X.shape
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels
# Date
# 2000-01-24    14.078787  14.004494 -39.930588 -2698175.0     2.0
# 2000-01-25    14.727272  14.115691  -3.361342  2489423.0     2.0
# 2000-01-26    14.787878  14.219104 -35.135148  7249607.0     2.0
# 2000-01-27    14.284848  14.229219 -57.567561  4991464.0     2.0
# 2000-01-28    14.412121  14.257357 -51.891890  7816168.0     2.0
# (4517, 15, 4)

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization,Activation
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(LSTM(100, input_shape=(X_train.shape[1:]), return_sequences=True,kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(LSTM(100, kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# model.add(Dense(100, kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))

model.add(Dense(75, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(50, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "DBS_CNN_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))
print(d_class_weights)

epochs = 0 
histories = {}
nr_log_hist = {}
r_log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    nr_log  = pd.DataFrame(columns = column_names)
    r_log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['600779.SS','000858.SZ','600519.SS']
    for name in test_sets:
        
        print('\n')
        print("Non-Recession")
        print('\n')
        
        X = nr_test_data['{}_X'.format(name)]
        y = nr_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("variation 7/initial_indicators/{}_data_test.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(nr_log)
        nr_log.loc[df_length] = logger
        print(nr_log.head(20))
        logger = []
        
        print('\n')
        print("Recession")
        print('\n')
        
        X = r_test_data['{}_X'.format(name)]
        y = r_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("variation 7/initial_indicators/{}_data_test2.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(r_log)
        r_log.loc[df_length] = logger
        print(r_log.head(20))
        logger = []

    nr_log.to_csv('{}_{}_{}epochs.csv'.format(experiment,'SichuanModel',epochs))
    nr_log_hist['{}_epochs_logs'.format(epochs)] = nr_log
    r_log.to_csv('{}_{}_{}epochs.csv'.format(experiment,'SichuanModel',epochs))
    r_log_hist['{}_epochs_logs'.format(epochs)] = r_log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 2 ... 2 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# {0: 7.3885480572597135, 1: 7.3885480572597135, 2: 0.36639286076462835}
#
#
#
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  1/29 [>.............................] - ETA: 0s - loss: 0.3766 - accuracy: 0.5469 - mse: 0.3388 - weighted_accuracy: 0.2789 - weighted_mse: 0.4776WARNING:tensorflow:From C:\Users\Shearman Chua\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/29 [=>............................] - ETA: 1s - loss: 0.3428 - accuracy: 0.5469 - mse: 0.3263 - weighted_accuracy: 0.2876 - weighted_mse: 0.4488WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0120s vs `on_train_batch_end` time: 0.1097s). Check your callbacks.
# 29/29 [==============================] - 1s 49ms/step - loss: 0.2983 - accuracy: 0.5156 - mse: 0.4351 - weighted_accuracy: 0.2997 - weighted_mse: 0.5255 - val_loss: 0.3002 - val_accuracy: 0.0454 - val_mse: 0.3544 - val_weighted_accuracy: 0.0454 - val_weighted_mse: 0.3544
# Epoch 2/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.2156 - accuracy: 0.3501 - mse: 0.7660 - weighted_accuracy: 0.4004 - weighted_mse: 0.7504 - val_loss: 0.2928 - val_accuracy: 0.0454 - val_mse: 0.3870 - val_weighted_accuracy: 0.0454 - val_weighted_mse: 0.3870
# Epoch 3/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1932 - accuracy: 0.3197 - mse: 1.0054 - weighted_accuracy: 0.4709 - weighted_mse: 0.9778 - val_loss: 0.2838 - val_accuracy: 0.0454 - val_mse: 0.4283 - val_weighted_accuracy: 0.0454 - val_weighted_mse: 0.4283
# Epoch 4/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1829 - accuracy: 0.3266 - mse: 1.1278 - weighted_accuracy: 0.5123 - weighted_mse: 1.0955 - val_loss: 0.2759 - val_accuracy: 0.0454 - val_mse: 0.4784 - val_weighted_accuracy: 0.0454 - val_weighted_mse: 0.4784
# Epoch 5/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1776 - accuracy: 0.3086 - mse: 1.2165 - weighted_accuracy: 0.5271 - weighted_mse: 1.1809 - val_loss: 0.2693 - val_accuracy: 0.0454 - val_mse: 0.5355 - val_weighted_accuracy: 0.0454 - val_weighted_mse: 0.5355
# Epoch 6/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1742 - accuracy: 0.3036 - mse: 1.2660 - weighted_accuracy: 0.5408 - weighted_mse: 1.2140 - val_loss: 0.2629 - val_accuracy: 0.0454 - val_mse: 0.5994 - val_weighted_accuracy: 0.0454 - val_weighted_mse: 0.5994
# Epoch 7/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1714 - accuracy: 0.2862 - mse: 1.3027 - weighted_accuracy: 0.5616 - weighted_mse: 1.2445 - val_loss: 0.2572 - val_accuracy: 0.0454 - val_mse: 0.6652 - val_weighted_accuracy: 0.0454 - val_weighted_mse: 0.6652
# Epoch 8/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1695 - accuracy: 0.3050 - mse: 1.3029 - weighted_accuracy: 0.5646 - weighted_mse: 1.2479 - val_loss: 0.2539 - val_accuracy: 0.0454 - val_mse: 0.7376 - val_weighted_accuracy: 0.0454 - val_weighted_mse: 0.7376
# Epoch 9/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1665 - accuracy: 0.2917 - mse: 1.3289 - weighted_accuracy: 0.5753 - weighted_mse: 1.2693 - val_loss: 0.2498 - val_accuracy: 0.0454 - val_mse: 0.8137 - val_weighted_accuracy: 0.0454 - val_weighted_mse: 0.8137
# Epoch 10/20
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1645 - accuracy: 0.3136 - mse: 1.3375 - weighted_accuracy: 0.5833 - weighted_mse: 1.2735 - val_loss: 0.2466 - val_accuracy: 0.0454 - val_mse: 0.8964 - val_weighted_accuracy: 0.0454 - val_weighted_mse: 0.8964
# Epoch 11/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1629 - accuracy: 0.3194 - mse: 1.3463 - weighted_accuracy: 0.5893 - weighted_mse: 1.2852 - val_loss: 0.2442 - val_accuracy: 0.0454 - val_mse: 0.9771 - val_weighted_accuracy: 0.0454 - val_weighted_mse: 0.9771
# Epoch 12/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1611 - accuracy: 0.3155 - mse: 1.3745 - weighted_accuracy: 0.5898 - weighted_mse: 1.3027 - val_loss: 0.2398 - val_accuracy: 0.0454 - val_mse: 1.0566 - val_weighted_accuracy: 0.0454 - val_weighted_mse: 1.0566
# Epoch 13/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1588 - accuracy: 0.3316 - mse: 1.3798 - weighted_accuracy: 0.6074 - weighted_mse: 1.3155 - val_loss: 0.2346 - val_accuracy: 0.0442 - val_mse: 1.1246 - val_weighted_accuracy: 0.0442 - val_weighted_mse: 1.1246
# Epoch 14/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1571 - accuracy: 0.3296 - mse: 1.3939 - weighted_accuracy: 0.6319 - weighted_mse: 1.3191 - val_loss: 0.2295 - val_accuracy: 0.0564 - val_mse: 1.1895 - val_weighted_accuracy: 0.0564 - val_weighted_mse: 1.1895
# Epoch 15/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1553 - accuracy: 0.3191 - mse: 1.4217 - weighted_accuracy: 0.6281 - weighted_mse: 1.3450 - val_loss: 0.2232 - val_accuracy: 0.1228 - val_mse: 1.2415 - val_weighted_accuracy: 0.1228 - val_weighted_mse: 1.2415
# Epoch 16/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1551 - accuracy: 0.3216 - mse: 1.4446 - weighted_accuracy: 0.6251 - weighted_mse: 1.3710 - val_loss: 0.2176 - val_accuracy: 0.1759 - val_mse: 1.2936 - val_weighted_accuracy: 0.1759 - val_weighted_mse: 1.2936
# Epoch 17/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1524 - accuracy: 0.3418 - mse: 1.4389 - weighted_accuracy: 0.6539 - weighted_mse: 1.3681 - val_loss: 0.2119 - val_accuracy: 0.2058 - val_mse: 1.3093 - val_weighted_accuracy: 0.2058 - val_weighted_mse: 1.3093
# Epoch 18/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1511 - accuracy: 0.3468 - mse: 1.4737 - weighted_accuracy: 0.6499 - weighted_mse: 1.4048 - val_loss: 0.2062 - val_accuracy: 0.2389 - val_mse: 1.3210 - val_weighted_accuracy: 0.2389 - val_weighted_mse: 1.3210
# Epoch 19/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1507 - accuracy: 0.3557 - mse: 1.4533 - weighted_accuracy: 0.6590 - weighted_mse: 1.3802 - val_loss: 0.2023 - val_accuracy: 0.2566 - val_mse: 1.3671 - val_weighted_accuracy: 0.2566 - val_weighted_mse: 1.3671
# Epoch 20/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1483 - accuracy: 0.3667 - mse: 1.4996 - weighted_accuracy: 0.6572 - weighted_mse: 1.4293 - val_loss: 0.2025 - val_accuracy: 0.2389 - val_mse: 1.3866 - val_weighted_accuracy: 0.2389 - val_weighted_mse: 1.3866
# Validation loss: 0.20252849161624908
# Validation accuracy: 0.23893804848194122
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2010 - accuracy: 0.2367 - mse: 1.3343 - weighted_accuracy: 0.2367 - weighted_mse: 1.3343
# Test loss: 0.2009636014699936
# Test accuracy: 0.23671497404575348
#
#
# number of predictions: 207
# actual predicted buys: 7
# actual buys but predicted sell: 0
# actual buys but predicted hold: 0
# actual sells but predicted buy: 3
# actual predicted sells: 6
# actual sells but predicted hold: 1
# actual holds but predicted buy: 92
# actual holds but predicted sell: 62
# actual predicted holds: 36
# Percentage buys correct: 6.862745098039215%
# Percentage sells correct: 8.823529411764707%
# Percentage holds correct: 97.29729729729729%
# actual buys: 7
# actual sells: 10
# actual holds: 190
#
#
# Percentage low buys correct: 46.53465346534654%
# Percentage high sells correct: 41.1764705882353%
# Percentage mid holds correct: 86.48648648648648%
#
#
# Capital: 100
# Share price: $0.24146997098934775
# Shares owned at the moment: 412
# Cash capital at the moment: $0.24078647525779218
#
#
# Price increase from previously bought: 26.23269387636271%
# Share price: $0.3056522879178516
# Shares owned at the moment: 0
# Cash capital at the moment: $125.82322505520172
#
#
# Share price: $0.2903312641826963
# Shares owned at the moment: 432
# Cash capital at the moment: $0.05520538642787187
#
#
# Price increase from previously bought: 36.84823320438424%
# Share price: $0.39840581678902653
# Shares owned at the moment: 0
# Cash capital at the moment: $171.69321212894198
#
#
# Share price: $0.41621121132347416
# Shares owned at the moment: 411
# Cash capital at the moment: $0.15998155339573827
#
#
# Price increase from previously bought: 10.440969042930991%
# Share price: $0.46093178121235634
# Shares owned at the moment: 0
# Cash capital at the moment: $189.08197548595894
#
#
# Share price: $0.4895031511134966
# Shares owned at the moment: 385
# Cash capital at the moment: $0.1050008460213121
#
#
# Price increase from previously bought: 1.5816763709700643%
# Share price: $0.49861293193348466
# Shares owned at the moment: 0
# Cash capital at the moment: $191.5430731987283
#
#
# Share price: $0.5594823858931717
# Shares owned at the moment: 341
# Cash capital at the moment: $0.2349250017854274
#
#
# Price increase from previously bought: 3.5637763058227856%
# Share price: $0.581014494585026
# Shares owned at the moment: 0
# Cash capital at the moment: $197.81602131298217
#
#
# Share price: $0.5222154022775713
# Shares owned at the moment: 377
# Cash capital at the moment: $0.39940783602648366
#
#
# Price increase from previously bought: -4.93968588231084%
# Share price: $0.4977847556808974
# Shares owned at the moment: 0
# Cash capital at the moment: $187.54818238227264
#
#
# Share price: $0.6422981156502412
# Shares owned at the moment: 291
# Cash capital at the moment: $0.12543166100334702
#
#
# Price increase from previously bought: -22.969135407235473%
# Share price: $0.4961284031757236
# Shares owned at the moment: 0
# Cash capital at the moment: $144.10177023049752
#
#
# Share price: $0.4965424123227826
# Shares owned at the moment: 289
# Cash capital at the moment: $0.20638598701981437
#
#
# Price increase from previously bought: -8.673765834261548%
# Share price: $0.45472053829718884
# Shares owned at the moment: 0
# Cash capital at the moment: $131.25923240709568
#
#
# Share price: $0.46879921867422936
# Shares owned at the moment: 279
# Cash capital at the moment: $0.10456419645785786
#
#
# Price increase from previously bought: 4.041947168425941%
# Share price: $0.4890891419664376
# Shares owned at the moment: 0
# Cash capital at the moment: $136.1851811609202
#
#
# Share price: $0.41621121132347416
# Shares owned at the moment: 326
# Cash capital at the moment: $0.1271929185161298
#
#
# Price increase from previously bought: 11.433101746562468%
# Share price: $0.46507250451682247
# Shares owned at the moment: 0
# Cash capital at the moment: $151.32389189070093
#
#
# Share price: $0.42697734464863557
# Shares owned at the moment: 353
# Cash capital at the moment: $0.1864009724149298
#
#
# Price increase from previously bought: 69.55259220526024%
# Share price: $0.7259420216598973
# Shares owned at the moment: 0
# Cash capital at the moment: $255.7392264008323
#
#
# Share price: $0.9400207652203254
# Shares owned at the moment: 271
# Cash capital at the moment: $0.29304855084365045
#
#
# Price increase from previously bought: -1.3724743702605124%
# Share price: $0.9296687990006918
# Shares owned at the moment: 0
# Cash capital at the moment: $251.54045740757587
#
#
# Share price: $0.8737680866395889
# Shares owned at the moment: 287
# Cash capital at the moment: $0.07939507963354231
#
#
# Price increase from previously bought: 0.38739170429327174%
# Share price: $0.8795651624492282
# Shares owned at the moment: 0
# Cash capital at the moment: $251.820399898099
#
#
# Share price: $0.8696273633351224
# Shares owned at the moment: 288
# Cash capital at the moment: $0.6789743858223289
#
#
#
#
# Capital at the end of test period: $216.31095979650013
# profit gained: 116.31095979650013%
#
#
# Capital at the end of test period if Buy and Hold: $2168.3140506383515
# profit gained: 2068.3140506383515%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.236715      6.862745       8.823529      97.297297
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         46.534653           41.176471          86.486486      116.31096
#
#    buy_n_hold profit
# 0        2068.314051
#
#
# Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1936 - accuracy: 0.3462 - mse: 1.3010 - weighted_accuracy: 0.3462 - weighted_mse: 1.3010
# Test loss: 0.19356149435043335
# Test accuracy: 0.3461538553237915
#
#
# number of predictions: 208
# actual predicted buys: 6
# actual buys but predicted sell: 0
# actual buys but predicted hold: 2
# actual sells but predicted buy: 1
# actual predicted sells: 5
# actual sells but predicted hold: 2
# actual holds but predicted buy: 65
# actual holds but predicted sell: 66
# actual predicted holds: 61
# Percentage buys correct: 8.333333333333334%
# Percentage sells correct: 7.042253521126761%
# Percentage holds correct: 93.84615384615384%
# actual buys: 8
# actual sells: 8
# actual holds: 192
#
#
# Percentage low buys correct: 47.22222222222222%
# Percentage high sells correct: 49.29577464788732%
# Percentage mid holds correct: 90.625%
#
#
# Capital: 100
# Share price: $0.1797417091039999
# Shares owned at the moment: 554
# Cash capital at the moment: $0.14925666256411318
#
#
# Price increase from previously bought: 16.61627391865228%
# Share price: $0.21018450606533334
# Shares owned at the moment: 0
# Cash capital at the moment: $116.27125692776825
#
#
# Share price: $0.20349629316299978
# Shares owned at the moment: 569
# Cash capital at the moment: $0.16344529329457202
#
#
# Price increase from previously bought: -63.11424171211522%
# Share price: $0.07526756898566699
# Shares owned at the moment: 0
# Cash capital at the moment: $42.87291711756876
#
#
# Share price: $0.14376390613733392
# Shares owned at the moment: 297
# Cash capital at the moment: $0.05761782444291441
#
#
# Price increase from previously bought: 26.442538245320456%
# Share price: $0.18227862351366686
# Shares owned at the moment: 0
# Cash capital at the moment: $54.04549294224718
#
#
# Share price: $0.14284137581066703
# Shares owned at the moment: 377
# Cash capital at the moment: $0.046203465253995546
#
#
# Price increase from previously bought: 75.40241372576213%
# Share price: $0.2512362258286671
# Shares owned at the moment: 0
# Cash capital at the moment: $94.50179144553363
#
#
# Share price: $0.7127214204750001
# Shares owned at the moment: 132
# Cash capital at the moment: $0.16384606720119166
#
#
# Price increase from previously bought: -15.989718372888252%
# Share price: $0.6004058605573328
# Shares owned at the moment: 0
# Cash capital at the moment: $79.19947233338681
#
#
# Share price: $0.5951015311223335
# Shares owned at the moment: 132
# Cash capital at the moment: $0.4300483694413657
#
#
# Price increase from previously bought: 16.460343617814743%
# Share price: $0.6949631955620013
# Shares owned at the moment: 0
# Cash capital at the moment: $91.91291854363652
#
#
# Share price: $0.6864299220063337
# Shares owned at the moment: 133
# Cash capital at the moment: $0.3666771728203173
#
#
# Price increase from previously bought: 2.7077810434120053%
# Share price: $0.7069557378993334
# Shares owned at the moment: 0
# Cash capital at the moment: $94.13322125229497
#
#
# Share price: $0.8075092560953336
# Shares owned at the moment: 116
# Cash capital at the moment: $0.20455209254186002
#
#
# Price increase from previously bought: 7.358932072669022%
# Share price: $0.869317380344667
# Shares owned at the moment: 0
# Cash capital at the moment: $100.76805596819328
#
#
# Share price: $0.8416419984086658
# Shares owned at the moment: 119
# Cash capital at the moment: $0.3372308135828064
#
#
# Price increase from previously bought: -12.024807979122764%
# Share price: $0.7424723636800004
# Shares owned at the moment: 0
# Cash capital at the moment: $88.44846801048857
#
#
#
#
# Capital at the end of test period: $88.44846801048857
# profit gained: -11.551531989511432%
#
#
# Capital at the end of test period if Buy and Hold: $500.9406907154986
# profit gained: 400.9406907154986%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.346154      8.333333       7.042254      93.846154
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.222222           49.295775             90.625     -11.551532
#
#    buy_n_hold profit
# 0         400.940691
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1980 - accuracy: 0.2464 - mse: 1.3288 - weighted_accuracy: 0.2464 - weighted_mse: 1.3288
# Test loss: 0.19803237915039062
# Test accuracy: 0.24637681245803833
#
#
# number of predictions: 207
# actual predicted buys: 6
# actual buys but predicted sell: 0
# actual buys but predicted hold: 2
# actual sells but predicted buy: 3
# actual predicted sells: 5
# actual sells but predicted hold: 2
# actual holds but predicted buy: 87
# actual holds but predicted sell: 62
# actual predicted holds: 40
# Percentage buys correct: 6.25%
# Percentage sells correct: 7.462686567164179%
# Percentage holds correct: 90.9090909090909%
# actual buys: 8
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 48.421052631578945%
# Percentage high sells correct: 50.74626865671642%
# Percentage mid holds correct: 84.0909090909091%
#
#
# Capital: 100
# Share price: $0.03722094537543363
# Shares owned at the moment: 2679
# Cash capital at the moment: $0.010871329396152873
#
#
# Price increase from previously bought: 211.63085234880842%
# Share price: $0.116310927186394
# Shares owned at the moment: 0
# Cash capital at the moment: $310.75095358343174
#
#
# Share price: $0.47262185437278803
# Shares owned at the moment: 655
# Cash capital at the moment: $0.3323288540665885
#
#
# Price increase from previously bought: 21.9293401548319%
# Share price: $0.5778494364125477
# Shares owned at the moment: 0
# Cash capital at the moment: $377.78285840694724
#
#
# Share price: $0.46977787963162343
# Shares owned at the moment: 801
# Cash capital at the moment: $0.4559735976582715
#
#
# Price increase from previously bought: 15.853958175197924%
# Share price: $0.5457529729222608
# Shares owned at the moment: 0
# Cash capital at the moment: $436.40194754728464
#
#
# Share price: $0.4928005913400997
# Shares owned at the moment: 883
# Cash capital at the moment: $0.062382358055003806
#
#
# Price increase from previously bought: 38.77919529466076%
# Share price: $0.6857854329805602
# Shares owned at the moment: 0
# Cash capital at the moment: $603.9456612022545
#
#
# Share price: $0.7891170318595431
# Shares owned at the moment: 763
# Cash capital at the moment: $0.19360108132389087
#
#
# Price increase from previously bought: -3.919726872384599%
# Share price: $0.7602708104558256
# Shares owned at the moment: 0
# Cash capital at the moment: $578.6849912310798
#
#
# Share price: $0.7643336905565368
# Shares owned at the moment: 755
# Cash capital at the moment: $0.026107035876520968
#
#
# Price increase from previously bought: 4.2315692133549465%
# Share price: $0.7988678614425837
# Shares owned at the moment: 0
# Cash capital at the moment: $601.512693027707
#
#
# Share price: $0.8699675399417004
# Shares owned at the moment: 689
# Cash capital at the moment: $0.45668701157080704
#
#
# Price increase from previously bought: 0.5485412941242274%
# Share price: $0.8771452052394026
# Shares owned at the moment: 0
# Cash capital at the moment: $603.1477625438919
#
#
# Share price: $0.8963759506263254
# Shares owned at the moment: 671
# Cash capital at the moment: $0.025461950734325
#
#
# Price increase from previously bought: -5.75861621623922%
# Share price: $0.8470801817994709
# Shares owned at the moment: 0
# Cash capital at the moment: $566.8531892327138
#
#
#
#
# Capital at the end of test period: $566.8531892327138
# profit gained: 466.8531892327138%
#
#
# Capital at the end of test period if Buy and Hold: $2431.2017150969914
# profit gained: 2331.2017150969914%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.236715      6.862745       8.823529      97.297297
# 1       0.246377      6.250000       7.462687      90.909091
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         46.534653           41.176471          86.486486     116.310960
# 1         48.421053           50.746269          84.090909     466.853189
#
#    buy_n_hold profit
# 0        2068.314051
# 1        2331.201715
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1919 - accuracy: 0.3029 - mse: 1.2775 - weighted_accuracy: 0.3029 - weighted_mse: 1.2775
# Test loss: 0.19194453954696655
# Test accuracy: 0.30288460850715637
#
#
# number of predictions: 208
# actual predicted buys: 5
# actual buys but predicted sell: 1
# actual buys but predicted hold: 4
# actual sells but predicted buy: 2
# actual predicted sells: 3
# actual sells but predicted hold: 3
# actual holds but predicted buy: 54
# actual holds but predicted sell: 81
# actual predicted holds: 55
# Percentage buys correct: 8.19672131147541%
# Percentage sells correct: 3.5294117647058822%
# Percentage holds correct: 88.70967741935483%
# actual buys: 10
# actual sells: 8
# actual holds: 190
#
#
# Percentage low buys correct: 45.90163934426229%
# Percentage high sells correct: 44.04761904761905%
# Percentage mid holds correct: 83.87096774193549%
#
#
# Capital: 100
# Share price: $0.14258040003765882
# Shares owned at the moment: 699
# Cash capital at the moment: $0.0622251997041019
#
#
# Price increase from previously bought: 15.56366672428613%
# Share price: $0.16522425894403658
# Shares owned at the moment: 0
# Cash capital at the moment: $115.23637986983049
#
#
# Share price: $0.1445276486379956
# Shares owned at the moment: 795
# Cash capital at the moment: $0.020925630789164984
#
#
# Price increase from previously bought: -43.88463841919704%
# Share price: $0.08132524370214166
# Shares owned at the moment: 0
# Cash capital at the moment: $64.49669705994796
#
#
# Share price: $0.09284187679194632
# Shares owned at the moment: 692
# Cash capital at the moment: $0.07344022838603337
#
#
# Price increase from previously bought: 2.4747598417375283%
# Share price: $0.0954011238733654
# Shares owned at the moment: 0
# Cash capital at the moment: $65.90946961002388
#
#
# Share price: $0.13712806150987977
# Shares owned at the moment: 479
# Cash capital at the moment: $0.044496207767565465
#
#
# Price increase from previously bought: 10.528855427448903%
# Share price: $0.1519828835680742
# Shares owned at the moment: 0
# Cash capital at the moment: $72.64409798349506
#
#
# Share price: $0.25524313165624757
# Shares owned at the moment: 283
# Cash capital at the moment: $0.21164875756551282
#
#
# Price increase from previously bought: 25.04986538789713%
# Share price: $0.32005894082749764
# Shares owned at the moment: 0
# Cash capital at the moment: $90.53924314104835
#
#
# Share price: $0.3227295259596784
# Shares owned at the moment: 279
# Cash capital at the moment: $0.25009116950549526
#
#
# Price increase from previously bought: 17.313060624871014%
# Share price: $0.3796450451256558
# Shares owned at the moment: 0
# Cash capital at the moment: $105.87977609869078
#
#
# Share price: $0.6098108059626935
# Shares owned at the moment: 173
# Cash capital at the moment: $0.09238917620804443
#
#
# Price increase from previously bought: 6.749759496249785%
# Share price: $0.6527617405613729
# Shares owned at the moment: 0
# Cash capital at the moment: $112.70961889525348
#
#
# Share price: $0.6043585098817507
# Shares owned at the moment: 185
# Cash capital at the moment: $0.5958271752272566
#
#
# Price increase from previously bought: 11.871596558024633%
# Share price: $0.6779648041023337
# Shares owned at the moment: 0
# Cash capital at the moment: $125.67440134007192
#
#
# Share price: $0.6762401042630121
# Shares owned at the moment: 185
# Cash capital at the moment: $0.2259448983708836
#
#
# Price increase from previously bought: 16.012049301843234%
# Share price: $0.786677433165122
# Shares owned at the moment: 0
# Cash capital at the moment: $145.3610478897957
#
#
# Share price: $0.7789996494740284
# Shares owned at the moment: 186
# Cash capital at the moment: $0.06865476692044581
#
#
# Price increase from previously bought: 2.3111826392143486%
# Share price: $0.7991955144560764
# Shares owned at the moment: 0
# Cash capital at the moment: $148.31023195010638
#
#
# Share price: $0.9352253141723784
# Shares owned at the moment: 158
# Cash capital at the moment: $0.13827691186267543
#
#
# Price increase from previously bought: 1.6953874253023082%
# Share price: $0.9536964793151054
# Shares owned at the moment: 0
# Cash capital at the moment: $150.40793952338691
#
#
# Share price: $0.8913284942808403
# Shares owned at the moment: 168
# Cash capital at the moment: $0.2529587198480101
#
#
# Price increase from previously bought: 5.415222450650425%
# Share price: $0.9421798037784642
# Shares owned at the moment: 0
# Cash capital at the moment: $158.10387868528434
#
#
#
#
# Capital at the end of test period: $158.10387868528434
# profit gained: 58.103878685284336%
#
#
# Capital at the end of test period if Buy and Hold: $704.110752699704
# profit gained: 604.110752699704%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.346154      8.333333       7.042254      93.846154
# 1       0.302885      8.196721       3.529412      88.709677
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.222222           49.295775          90.625000     -11.551532
# 1         45.901639           44.047619          83.870968      58.103879
#
#    buy_n_hold profit
# 0         400.940691
# 1         604.110753
#
#
# Non-Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2004 - accuracy: 0.2415 - mse: 1.3081 - weighted_accuracy: 0.2415 - weighted_mse: 1.3081
# Test loss: 0.20041440427303314
# Test accuracy: 0.2415459007024765
#
#
# number of predictions: 207
# actual predicted buys: 6
# actual buys but predicted sell: 0
# actual buys but predicted hold: 5
# actual sells but predicted buy: 1
# actual predicted sells: 7
# actual sells but predicted hold: 3
# actual holds but predicted buy: 70
# actual holds but predicted sell: 78
# actual predicted holds: 37
# Percentage buys correct: 7.792207792207792%
# Percentage sells correct: 8.235294117647058%
# Percentage holds correct: 82.22222222222223%
# actual buys: 11
# actual sells: 11
# actual holds: 185
#
#
# Percentage low buys correct: 52.63157894736842%
# Percentage high sells correct: 43.529411764705884%
# Percentage mid holds correct: 82.22222222222223%
#
#
# Capital: 100
# Share price: $0.021217156310856737
# Shares owned at the moment: 4700
# Cash capital at the moment: $0.005133593655514801
#
#
# Price increase from previously bought: 11.990920052449262%
# Share price: $0.023826632105038874
# Shares owned at the moment: 0
# Cash capital at the moment: $111.6823452673806
#
#
# Share price: $0.06520930006998536
# Shares owned at the moment: 1707
# Cash capital at the moment: $0.06396129106205706
#
#
# Price increase from previously bought: 85.20081611421408%
# Share price: $0.1211002683407376
# Shares owned at the moment: 0
# Cash capital at the moment: $206.21364441404262
#
#
# Share price: $0.1509152587177458
# Shares owned at the moment: 1362
# Cash capital at the moment: $0.10180893894550991
#
#
# Price increase from previously bought: 85.16088588855695%
# Share price: $0.2802044790652385
# Shares owned at the moment: 0
# Cash capital at the moment: $380.69080354946146
#
#
# Share price: $0.3717332035053553
# Shares owned at the moment: 1021
# Cash capital at the moment: $0.10746886835153191
#
#
# Price increase from previously bought: -8.633268622088918%
# Share price: $0.340574488802337
# Shares owned at the moment: 0
# Cash capital at the moment: $346.8777739146028
#
#
# Share price: $0.34446932814021425
# Shares owned at the moment: 1004
# Cash capital at the moment: $0.07948864683260126
#
#
# Price increase from previously bought: 9.873949756015898%
# Share price: $0.3795228821811101
# Shares owned at the moment: 0
# Cash capital at the moment: $380.0725996789651
#
#
# Share price: $0.5544401311085079
# Shares owned at the moment: 683
# Cash capital at the moment: $0.34861295559966266
#
#
# Price increase from previously bought: -5.0835488634237365%
# Share price: $0.5277020970895205
# Shares owned at the moment: 0
# Cash capital at the moment: $359.7779888038838
#
#
# Share price: $0.48370983446932825
# Shares owned at the moment: 741
# Cash capital at the moment: $0.3633217469216561
#
#
# Price increase from previously bought: -4.096502109686928%
# Share price: $0.4651703611854918
# Shares owned at the moment: 0
# Cash capital at the moment: $344.10665848186534
#
#
# Share price: $0.4827361246348587
# Shares owned at the moment: 710
# Cash capital at the moment: $0.4214677077661122
#
#
# Price increase from previously bought: 6.134494251497324%
# Share price: $0.5137585056977239
# Shares owned at the moment: 0
# Cash capital at the moment: $364.1868932707752
#
#
# Share price: $0.4660857102376461
# Shares owned at the moment: 779
# Cash capital at the moment: $0.10765288289229602
#
#
# Price increase from previously bought: 36.76011596701967%
# Share price: $0.6391722610607355
# Shares owned at the moment: 0
# Cash capital at the moment: $496.6535774729479
#
#
# Share price: $0.7475851996105161
# Shares owned at the moment: 662
# Cash capital at the moment: $0.3911964748953096
#
#
# Price increase from previously bought: 14.90212976100176%
# Share price: $0.8613535422498781
# Shares owned at the moment: 0
# Cash capital at the moment: $569.0391473206488
#
#
# Share price: $0.8874100269291625
# Shares owned at the moment: 639
# Cash capital at the moment: $0.42473884309276855
#
#
# Price increase from previously bought: 1.7413355579064982%
# Share price: $0.905345686009007
# Shares owned at the moment: 0
# Cash capital at the moment: $577.349713496109
#
#
# Share price: $0.9150632911392407
# Shares owned at the moment: 629
# Cash capital at the moment: $0.1920726416784646
#
#
# Price increase from previously bought: 9.276301518282072%
# Share price: $1.00269717624148
# Shares owned at the moment: 0
# Cash capital at the moment: $629.1541810569657
#
#
# Share price: $0.9150632911392407
# Shares owned at the moment: 685
# Cash capital at the moment: $0.612076151902329
#
#
# Price increase from previously bought: -4.646268981384571%
# Share price: $0.8749464935035296
# Shares owned at the moment: 0
# Cash capital at the moment: $598.3022437446828
#
#
# Share price: $0.8722200584225899
# Shares owned at the moment: 684
# Cash capital at the moment: $0.0630778537383776
#
#
#
#
# Capital at the end of test period: $587.5821013557753
# profit gained: 487.5821013557753%
#
#
# Capital at the end of test period if Buy and Hold: $1766.892280786996
# profit gained: 1666.8922807869963%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.236715      6.862745       8.823529      97.297297
# 1       0.246377      6.250000       7.462687      90.909091
# 2       0.241546      7.792208       8.235294      82.222222
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         46.534653           41.176471          86.486486     116.310960
# 1         48.421053           50.746269          84.090909     466.853189
# 2         52.631579           43.529412          82.222222     487.582101
#
#    buy_n_hold profit
# 0        2068.314051
# 1        2331.201715
# 2        1666.892281
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1917 - accuracy: 0.2692 - mse: 1.2639 - weighted_accuracy: 0.2692 - weighted_mse: 1.2639
# Test loss: 0.191726952791214
# Test accuracy: 0.26923078298568726
#
#
# number of predictions: 208
# actual predicted buys: 7
# actual buys but predicted sell: 0
# actual buys but predicted hold: 2
# actual sells but predicted buy: 2
# actual predicted sells: 6
# actual sells but predicted hold: 2
# actual holds but predicted buy: 51
# actual holds but predicted sell: 95
# actual predicted holds: 43
# Percentage buys correct: 11.666666666666666%
# Percentage sells correct: 5.9405940594059405%
# Percentage holds correct: 91.48936170212765%
# actual buys: 9
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 46.666666666666664%
# Percentage high sells correct: 47.524752475247524%
# Percentage mid holds correct: 86.95652173913044%
#
#
# Capital: 100
# Share price: $0.12558233818043063
# Shares owned at the moment: 794
# Cash capital at the moment: $0.013414449321103916
#
#
# Price increase from previously bought: 14.685293009575151%
# Share price: $0.14442053980990632
# Shares owned at the moment: 0
# Cash capital at the moment: $114.36798080971178
#
#
# Share price: $0.09936061724328947
# Shares owned at the moment: 1147
# Cash capital at the moment: $0.08794460471911236
#
#
# Price increase from previously bought: 94.14749987959921%
# Share price: $0.1934366461669521
# Shares owned at the moment: 0
# Cash capital at the moment: $221.34963021704107
#
#
# Share price: $0.02378936423929944
# Shares owned at the moment: 9279
# Cash capital at the moment: $0.0010802859463012737
#
#
# Price increase from previously bought: 660.2704428488119%
# Share price: $0.18136087949138457
# Shares owned at the moment: 0
# Cash capital at the moment: $1678.2208501843022
#
#
# Share price: $0.4790917876756311
# Shares owned at the moment: 3493
# Cash capital at the moment: $0.1511998938576653
#
#
# Price increase from previously bought: 8.133284913801475%
# Share price: $0.5194823464072713
# Shares owned at the moment: 0
# Cash capital at the moment: $1809.7130183454547
#
#
# Share price: $0.7828490672363122
# Shares owned at the moment: 2305
# Cash capital at the moment: $0.28363384081080767
#
#
# Price increase from previously bought: 0.0187656995650487%
# Share price: $0.7851492132697535
# Shares owned at the moment: 0
# Cash capital at the moment: $1805.075705851979
#
#
# Share price: $0.7851377013084047
# Shares owned at the moment: 2292
# Cash capital at the moment: $0.5913715217684512
#
#
# Price increase from previously bought: 4.83997107782137%
# Share price: $0.8254017688549782
# Shares owned at the moment: 0
# Cash capital at the moment: $1887.2097183882856
#
#
# Share price: $0.8058505275707262
# Shares owned at the moment: 2335
# Cash capital at the moment: $0.3741688104764762
#
#
# Price increase from previously bought: 5.00597241174181%
# Share price: $0.8485182084131098
# Shares owned at the moment: 0
# Cash capital at the moment: $1976.215637909315
#
#
# Share price: $0.785747273700812
# Shares owned at the moment: 2508
# Cash capital at the moment: $0.1421765209638579
#
#
# Price increase from previously bought: 11.416116426342349%
# Share price: $0.8778565823008366
# Shares owned at the moment: 0
# Cash capital at the moment: $2195.751908083333
#
#
# Share price: $0.7333959275173219
# Shares owned at the moment: 2985
# Cash capital at the moment: $0.5448006241194889
#
#
# Price increase from previously bought: 11.5515641009994%
# Share price: $0.8203644434261506
# Shares owned at the moment: 0
# Cash capital at the moment: $2442.5984976262043
#
#
# Share price: $0.8428713105918748
# Shares owned at the moment: 2890
# Cash capital at the moment: $0.0016902747570384236
#
#
# Price increase from previously bought: 9.648192164478786%
# Share price: $0.9267346855114666
# Shares owned at the moment: 0
# Cash capital at the moment: $2670.8997074897934
#
#
#
#
# Capital at the end of test period: $2670.8997074897934
# profit gained: 2570.8997074897934%
#
#
# Capital at the end of test period if Buy and Hold: $778.7940878989605
# profit gained: 678.7940878989605%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.346154      8.333333       7.042254      93.846154
# 1       0.302885      8.196721       3.529412      88.709677
# 2       0.269231     11.666667       5.940594      91.489362
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.222222           49.295775          90.625000     -11.551532
# 1         45.901639           44.047619          83.870968      58.103879
# 2         46.666667           47.524752          86.956522    2570.899707
#
#    buy_n_hold profit
# 0         400.940691
# 1         604.110753
# 2         678.794088
#
#
#
# RUNNING EPOCHS 20 - 40
# Epoch 1/20
#  2/29 [=>............................] - ETA: 15s - loss: 0.1360 - accuracy: 0.3594 - mse: 1.5224 - weighted_accuracy: 0.6737 - weighted_mse: 1.4182WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0089s vs `on_train_batch_end` time: 1.1111s). Check your callbacks.
# 29/29 [==============================] - 1s 49ms/step - loss: 0.1469 - accuracy: 0.3667 - mse: 1.5175 - weighted_accuracy: 0.6689 - weighted_mse: 1.4446 - val_loss: 0.1969 - val_accuracy: 0.3108 - val_mse: 1.3987 - val_weighted_accuracy: 0.3108 - val_weighted_mse: 1.3987
# Epoch 2/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1460 - accuracy: 0.3360 - mse: 1.5115 - weighted_accuracy: 0.6809 - weighted_mse: 1.4177 - val_loss: 0.1926 - val_accuracy: 0.3518 - val_mse: 1.3602 - val_weighted_accuracy: 0.3518 - val_weighted_mse: 1.3602
# Epoch 3/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1458 - accuracy: 0.3784 - mse: 1.5311 - weighted_accuracy: 0.6692 - weighted_mse: 1.4637 - val_loss: 0.1918 - val_accuracy: 0.3485 - val_mse: 1.4268 - val_weighted_accuracy: 0.3485 - val_weighted_mse: 1.4268
# Epoch 4/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1430 - accuracy: 0.3927 - mse: 1.5441 - weighted_accuracy: 0.6959 - weighted_mse: 1.4761 - val_loss: 0.1921 - val_accuracy: 0.3706 - val_mse: 1.5073 - val_weighted_accuracy: 0.3706 - val_weighted_mse: 1.5073
# Epoch 5/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1416 - accuracy: 0.3927 - mse: 1.5864 - weighted_accuracy: 0.6920 - weighted_mse: 1.5218 - val_loss: 0.1861 - val_accuracy: 0.3772 - val_mse: 1.4746 - val_weighted_accuracy: 0.3772 - val_weighted_mse: 1.4746
# Epoch 6/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1414 - accuracy: 0.4096 - mse: 1.5815 - weighted_accuracy: 0.7040 - weighted_mse: 1.5089 - val_loss: 0.1878 - val_accuracy: 0.3927 - val_mse: 1.5184 - val_weighted_accuracy: 0.3927 - val_weighted_mse: 1.5184
# Epoch 7/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1410 - accuracy: 0.3880 - mse: 1.6184 - weighted_accuracy: 0.6922 - weighted_mse: 1.5466 - val_loss: 0.1830 - val_accuracy: 0.4237 - val_mse: 1.5901 - val_weighted_accuracy: 0.4237 - val_weighted_mse: 1.5901
# Epoch 8/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1402 - accuracy: 0.3856 - mse: 1.6219 - weighted_accuracy: 0.6991 - weighted_mse: 1.5493 - val_loss: 0.1973 - val_accuracy: 0.3573 - val_mse: 1.5428 - val_weighted_accuracy: 0.3573 - val_weighted_mse: 1.5428
# Epoch 9/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1388 - accuracy: 0.4024 - mse: 1.6255 - weighted_accuracy: 0.7072 - weighted_mse: 1.5670 - val_loss: 0.1909 - val_accuracy: 0.3894 - val_mse: 1.6591 - val_weighted_accuracy: 0.3894 - val_weighted_mse: 1.6591
# Epoch 10/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1375 - accuracy: 0.4226 - mse: 1.6445 - weighted_accuracy: 0.7263 - weighted_mse: 1.5830 - val_loss: 0.1870 - val_accuracy: 0.4015 - val_mse: 1.6503 - val_weighted_accuracy: 0.4015 - val_weighted_mse: 1.6503
# Epoch 11/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1372 - accuracy: 0.4190 - mse: 1.6656 - weighted_accuracy: 0.7133 - weighted_mse: 1.6064 - val_loss: 0.1974 - val_accuracy: 0.3673 - val_mse: 1.6227 - val_weighted_accuracy: 0.3673 - val_weighted_mse: 1.6227
# Epoch 12/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1366 - accuracy: 0.4348 - mse: 1.6990 - weighted_accuracy: 0.7132 - weighted_mse: 1.6395 - val_loss: 0.1924 - val_accuracy: 0.3728 - val_mse: 1.6803 - val_weighted_accuracy: 0.3728 - val_weighted_mse: 1.6803
# Epoch 13/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1358 - accuracy: 0.4221 - mse: 1.7040 - weighted_accuracy: 0.7280 - weighted_mse: 1.6470 - val_loss: 0.1902 - val_accuracy: 0.3971 - val_mse: 1.6736 - val_weighted_accuracy: 0.3971 - val_weighted_mse: 1.6736
# Epoch 14/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1352 - accuracy: 0.4409 - mse: 1.6889 - weighted_accuracy: 0.7232 - weighted_mse: 1.6416 - val_loss: 0.1937 - val_accuracy: 0.3872 - val_mse: 1.6896 - val_weighted_accuracy: 0.3872 - val_weighted_mse: 1.6896
# Epoch 15/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1340 - accuracy: 0.4171 - mse: 1.7330 - weighted_accuracy: 0.7340 - weighted_mse: 1.6685 - val_loss: 0.1963 - val_accuracy: 0.3761 - val_mse: 1.7193 - val_weighted_accuracy: 0.3761 - val_weighted_mse: 1.7193
# Epoch 16/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1355 - accuracy: 0.4273 - mse: 1.7439 - weighted_accuracy: 0.6949 - weighted_mse: 1.6895 - val_loss: 0.1905 - val_accuracy: 0.4137 - val_mse: 1.6989 - val_weighted_accuracy: 0.4137 - val_weighted_mse: 1.6989
# Epoch 17/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1321 - accuracy: 0.4381 - mse: 1.7536 - weighted_accuracy: 0.7281 - weighted_mse: 1.7059 - val_loss: 0.1855 - val_accuracy: 0.4347 - val_mse: 1.7879 - val_weighted_accuracy: 0.4347 - val_weighted_mse: 1.7879
# Epoch 18/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1315 - accuracy: 0.4559 - mse: 1.7639 - weighted_accuracy: 0.7287 - weighted_mse: 1.7265 - val_loss: 0.1918 - val_accuracy: 0.4148 - val_mse: 1.6892 - val_weighted_accuracy: 0.4148 - val_weighted_mse: 1.6892
# Epoch 19/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1319 - accuracy: 0.4467 - mse: 1.7560 - weighted_accuracy: 0.7293 - weighted_mse: 1.7021 - val_loss: 0.1923 - val_accuracy: 0.3971 - val_mse: 1.8473 - val_weighted_accuracy: 0.3971 - val_weighted_mse: 1.8473
# Epoch 20/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1298 - accuracy: 0.4666 - mse: 1.7824 - weighted_accuracy: 0.7385 - weighted_mse: 1.7446 - val_loss: 0.1936 - val_accuracy: 0.4082 - val_mse: 1.8364 - val_weighted_accuracy: 0.4082 - val_weighted_mse: 1.8364
# Validation loss: 0.1935604214668274
# Validation accuracy: 0.40818583965301514
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1927 - accuracy: 0.3623 - mse: 1.7775 - weighted_accuracy: 0.3623 - weighted_mse: 1.7775
# Test loss: 0.1927022486925125
# Test accuracy: 0.36231884360313416
#
#
# number of predictions: 207
# actual predicted buys: 4
# actual buys but predicted sell: 1
# actual buys but predicted hold: 2
# actual sells but predicted buy: 0
# actual predicted sells: 7
# actual sells but predicted hold: 3
# actual holds but predicted buy: 43
# actual holds but predicted sell: 83
# actual predicted holds: 64
# Percentage buys correct: 8.51063829787234%
# Percentage sells correct: 7.6923076923076925%
# Percentage holds correct: 92.7536231884058%
# actual buys: 7
# actual sells: 10
# actual holds: 190
#
#
# Percentage low buys correct: 50.0%
# Percentage high sells correct: 40.65934065934066%
# Percentage mid holds correct: 82.6086956521739%
#
#
# Capital: 100
# Share price: $0.24146997098934775
# Shares owned at the moment: 412
# Cash capital at the moment: $0.24078647525779218
#
#
# Price increase from previously bought: 54.79169620459783%
# Share price: $0.3748033464449394
# Shares owned at the moment: 0
# Cash capital at the moment: $154.2351130190507
#
#
# Share price: $0.459689437854242
# Shares owned at the moment: 334
# Cash capital at the moment: $0.2766160270647333
#
#
# Price increase from previously bought: -0.004729889678845023%
# Share price: $0.46093178121235634
# Shares owned at the moment: 0
# Cash capital at the moment: $153.8044651109482
#
#
# Share price: $0.45886126160165475
# Shares owned at the moment: 334
# Cash capital at the moment: $0.12333966721439538
#
#
# Price increase from previously bought: -16.74294857700844%
# Share price: $0.3830849510123402
# Shares owned at the moment: 0
# Cash capital at the moment: $127.72184977783118
#
#
# Share price: $0.5292546634868573
# Shares owned at the moment: 240
# Cash capital at the moment: $0.3514224630840914
#
#
# Price increase from previously bought: -22.666984322886186%
# Share price: $0.4104141355138342
# Shares owned at the moment: 0
# Cash capital at the moment: $98.57994165696518
#
#
# Share price: $0.3429192715334515
# Shares owned at the moment: 286
# Cash capital at the moment: $0.23532399133699755
#
#
# Price increase from previously bought: 44.76281824469817%
# Share price: $0.4977847556808974
# Shares owned at the moment: 0
# Cash capital at the moment: $142.21025640573063
#
#
# Share price: $0.6671429293524427
# Shares owned at the moment: 212
# Cash capital at the moment: $0.3870110552003041
#
#
# Price increase from previously bought: -2.1311582802789553%
# Share price: $0.6547206014805762
# Shares owned at the moment: 0
# Cash capital at the moment: $138.80607645841928
#
#
# Share price: $0.5830848562372588
# Shares owned at the moment: 237
# Cash capital at the moment: $0.2349399751363137
#
#
# Price increase from previously bought: -34.48048728323915%
# Share price: $0.3830849510123402
# Shares owned at the moment: 0
# Cash capital at the moment: $90.77639774823864
#
#
# Share price: $0.4137266825657131
# Shares owned at the moment: 218
# Cash capital at the moment: $0.3359518027150301
#
#
# Price increase from previously bought: 19.58807894142298%
# Share price: $0.4961284031757236
# Shares owned at the moment: 0
# Cash capital at the moment: $108.19451471731892
#
#
# Share price: $0.4965424123227826
# Shares owned at the moment: 217
# Cash capital at the moment: $0.14849955872146836
#
#
# Price increase from previously bought: -8.673765834261548%
# Share price: $0.45472053829718884
# Shares owned at the moment: 0
# Cash capital at the moment: $98.5515018879826
#
#
# Share price: $0.46879921867422936
# Shares owned at the moment: 209
# Cash capital at the moment: $0.30302283413564624
#
#
# Price increase from previously bought: 4.041947168425941%
# Share price: $0.4890891419664376
# Shares owned at the moment: 0
# Cash capital at the moment: $102.24154952077589
#
#
# Share price: $0.4265631775431078
# Shares owned at the moment: 239
# Cash capital at the moment: $0.012591439532911863
#
#
# Price increase from previously bought: 1.177874088600217%
# Share price: $0.43277442045827574
# Shares owned at the moment: 0
# Cash capital at the moment: $103.16123694121461
#
#
# Share price: $0.3868116651697471
# Shares owned at the moment: 265
# Cash capital at the moment: $0.3742566702391912
#
#
# Price increase from previously bought: 77.76406063100907%
# Share price: $0.6895030563384155
# Shares owned at the moment: 0
# Cash capital at the moment: $182.59009124761266
#
#
# Share price: $0.8986129003417909
# Shares owned at the moment: 202
# Cash capital at the moment: $0.5711059124310225
#
#
# Price increase from previously bought: -1.0554625027101694%
# Share price: $0.8915734811740359
# Shares owned at the moment: 0
# Cash capital at the moment: $180.1736800407941
#
#
# Share price: $0.9288406227481047
# Shares owned at the moment: 193
# Cash capital at the moment: $0.41445768988631926
#
#
# Price increase from previously bought: -0.18532798452138843%
# Share price: $0.9296687990006918
# Shares owned at the moment: 0
# Cash capital at the moment: $179.34711418195022
#
#
# Share price: $0.86755700168289
# Shares owned at the moment: 206
# Cash capital at the moment: $0.13890079382150589
#
#
#
#
# Capital at the end of test period: $154.3756681361813
# profit gained: 54.3756681361813%
#
#
# Capital at the end of test period if Buy and Hold: $2168.3140506383515
# profit gained: 2068.3140506383515%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.362319      8.510638       7.692308      92.753623
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0              50.0           40.659341          82.608696      54.375668
#
#    buy_n_hold profit
# 0        2068.314051
#
#
# Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1796 - accuracy: 0.3990 - mse: 1.8228 - weighted_accuracy: 0.3990 - weighted_mse: 1.8228
# Test loss: 0.1796044409275055
# Test accuracy: 0.3990384638309479
#
#
# number of predictions: 208
# actual predicted buys: 3
# actual buys but predicted sell: 2
# actual buys but predicted hold: 3
# actual sells but predicted buy: 0
# actual predicted sells: 4
# actual sells but predicted hold: 4
# actual holds but predicted buy: 41
# actual holds but predicted sell: 75
# actual predicted holds: 76
# Percentage buys correct: 6.818181818181818%
# Percentage sells correct: 4.938271604938271%
# Percentage holds correct: 91.56626506024097%
# actual buys: 8
# actual sells: 8
# actual holds: 192
#
#
# Percentage low buys correct: 47.72727272727273%
# Percentage high sells correct: 46.25%
# Percentage mid holds correct: 86.74698795180723%
#
#
# Capital: 100
# Share price: $0.19011995533566695
# Shares owned at the moment: 524
# Cash capital at the moment: $0.10318054847182623
#
#
# Price increase from previously bought: 2.7500923744059103%
# ...
# Cash capital at the moment: $0.1419947028469153
#
#
# Price increase from previously bought: -14.027593187845543%
# Share price: $0.3830849510123402
# Shares owned at the moment: 0
# Cash capital at the moment: $94.12173568252275
#
#
# Share price: $0.40296070719902044
# Shares owned at the moment: 232
# Cash capital at the moment: $0.37776268115702294
#
#
# Price increase from previously bought: -3.1435963427993707%
# Share price: $0.3913665555797412
# Shares owned at the moment: 0
# Cash capital at the moment: $90.9251117131971
#
#
# Share price: $0.45637689080236266
# Shares owned at the moment: 198
# Cash capital at the moment: $0.31399011728740334
#
#
# Price increase from previously bought: 8.412104495159078%
# Share price: $0.4961284031757236
# Shares owned at the moment: 0
# Cash capital at the moment: $98.2772720305515
#
#
# Share price: $0.3868116651697471
# Shares owned at the moment: 253
# Cash capital at the moment: $0.14479652656362418
#
#
# Price increase from previously bought: 91.21528712635897%
# Share price: $0.7416770545421119
# Shares owned at the moment: 0
# Cash capital at the moment: $187.27306951502024
#
#
# Share price: $0.8874327578695698
# Shares owned at the moment: 210
# Cash capital at the moment: $0.3996979447409217
#
#
# Price increase from previously bought: 2.3315527652848056%
# Share price: $0.9106210611081291
# Shares owned at the moment: 0
# Cash capital at the moment: $191.1042371146581
#
#
# Share price: $0.86755700168289
# Shares owned at the moment: 219
# Cash capital at the moment: $0.5867675418416809
#
#
#
#
# Capital at the end of test period: $164.5569231145446
# profit gained: 64.55692311454459%
#
#
# Capital at the end of test period if Buy and Hold: $2168.3140506383515
# profit gained: 2068.3140506383515%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0        0.73913          15.0       9.677419      94.230769
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0              60.0           35.483871          83.870968      64.556923
#
#    buy_n_hold profit
# 0        2068.314051
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1616 - accuracy: 0.7548 - mse: 8.3536 - weighted_accuracy: 0.7548 - weighted_mse: 8.3536
# Test loss: 0.1615775227546692
# Test accuracy: 0.754807710647583
#
#
# number of predictions: 208
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 0
# actual predicted sells: 2
# actual sells but predicted hold: 6
# actual holds but predicted buy: 23
# actual holds but predicted sell: 15
# actual predicted holds: 154
# Percentage buys correct: 4.166666666666667%
# Percentage sells correct: 11.764705882352942%
# Percentage holds correct: 92.21556886227545%
# actual buys: 8
# actual sells: 8
# actual holds: 192
#
#
# Percentage low buys correct: 54.166666666666664%
# Percentage high sells correct: 58.8235294117647%
# Percentage mid holds correct: 86.74698795180723%
#
#
# Capital: 100
# Share price: $0.19011995533566695
# Shares owned at the moment: 524
# Cash capital at the moment: $0.10318054847182623
#
#
# Price increase from previously bought: -58.2205767805952%
# Share price: $0.07964945607133332
# Shares owned at the moment: 0
# Cash capital at the moment: $41.724720663651695
#
#
# Share price: $0.15575644847466652
# Shares owned at the moment: 267
# Cash capital at the moment: $0.02338474862320794
#
#
# Price increase from previously bought: 59.82463581490607%
# Share price: $0.24962175376833295
# Shares owned at the moment: 0
# Cash capital at the moment: $66.4891082320637
#
#
# Share price: $0.6004058605573328
# Shares owned at the moment: 110
# Cash capital at the moment: $0.2628407979384946
#
#
# Price increase from previously bought: 19.913326438882706%
# Share price: $0.7219465477870002
# Shares owned at the moment: 0
# Cash capital at the moment: $79.45857222380295
#
#
# Share price: $0.6158580235856674
# Shares owned at the moment: 128
# Cash capital at the moment: $0.4119631805353521
#
#
# Price increase from previously bought: 33.598056600323936%
# Share price: $0.8250369803926674
# Shares owned at the moment: 0
# Cash capital at the moment: $105.72628365369856
#
#
# Share price: $0.8075092560953336
# Shares owned at the moment: 130
# Cash capital at the moment: $0.46139580225109
#
#
# Price increase from previously bought: -1.9262072615535808%
# Share price: $0.7941328302906665
# Shares owned at the moment: 0
# Cash capital at the moment: $103.41476125320881
#
#
# Share price: $0.8022047507056662
# Shares owned at the moment: 128
# Cash capital at the moment: $0.4501770906351368
#
#
# Price increase from previously bought: -6.811079496182881%
# Share price: $0.7496217537683332
# Shares owned at the moment: 0
# Cash capital at the moment: $96.13789471565532
#
#
#
#
# Capital at the end of test period: $96.13789471565532
# profit gained: -3.8621052843446786%
#
#
# Capital at the end of test period if Buy and Hold: $500.9406907154986
# profit gained: 400.9406907154986%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.754808      4.166667      11.764706      92.215569
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         54.166667           58.823529          86.746988      -3.862105
#
#    buy_n_hold profit
# 0         400.940691
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1570 - accuracy: 0.8164 - mse: 8.1206 - weighted_accuracy: 0.8164 - weighted_mse: 8.1206
# Test loss: 0.15702414512634277
# Test accuracy: 0.8164251446723938
#
#
# number of predictions: 207
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 0
# actual predicted sells: 2
# actual sells but predicted hold: 8
# actual holds but predicted buy: 6
# actual holds but predicted sell: 17
# actual predicted holds: 166
# Percentage buys correct: 14.285714285714286%
# Percentage sells correct: 10.526315789473685%
# Percentage holds correct: 91.71270718232044%
# actual buys: 8
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 57.142857142857146%
# Percentage high sells correct: 55.55555555555556%
# Percentage mid holds correct: 84.5303867403315%
#
#
# Capital: 100
# Share price: $0.40599132331978693
# Shares owned at the moment: 245
# Cash capital at the moment: $0.2585891325654899
#
#
# Price increase from previously bought: 34.056132957319065%
# Share price: $0.5457529729222608
# Shares owned at the moment: 0
# Cash capital at the moment: $133.600366433013
#
#
# Share price: $0.7891170318595431
# Shares owned at the moment: 168
# Cash capital at the moment: $0.6641330118906694
#
#
# Price increase from previously bought: 3.6108296558922115%
# Share price: $0.8198591331007044
# Shares owned at the moment: 0
# Cash capital at the moment: $138.02169245331646
#
#
# Share price: $0.8698319797287883
# Shares owned at the moment: 158
# Cash capital at the moment: $0.21029766097572633
#
#
# Price increase from previously bought: -6.857568596361041%
# Share price: $0.8124106573471774
# Shares owned at the moment: 0
# Cash capital at the moment: $128.21818909121242
#
#
# Share price: $0.8235156425326782
# Shares owned at the moment: 155
# Cash capital at the moment: $0.22224095601774252
#
#
# Price increase from previously bought: 10.270966263337634%
# Share price: $0.9105959276554816
# Shares owned at the moment: 0
# Cash capital at the moment: $140.97646822845422
#
#
#
#
# Capital at the end of test period: $140.97646822845422
# profit gained: 40.97646822845422%
#
#
# Capital at the end of test period if Buy and Hold: $2431.2017150969914
# profit gained: 2331.2017150969914%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.739130     15.000000       9.677419      94.230769
# 1       0.816425     14.285714      10.526316      91.712707
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         60.000000           35.483871          83.870968      64.556923
# 1         57.142857           55.555556          84.530387      40.976468
#
#    buy_n_hold profit
# 0        2068.314051
# 1        2331.201715
#
#
# Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1565 - accuracy: 0.7548 - mse: 8.7620 - weighted_accuracy: 0.7548 - weighted_mse: 8.7620
# Test loss: 0.15654096007347107
# Test accuracy: 0.754807710647583
#
#
# number of predictions: 208
# actual predicted buys: 0
# actual buys but predicted sell: 0
# actual buys but predicted hold: 10
# actual sells but predicted buy: 0
# actual predicted sells: 3
# actual sells but predicted hold: 5
# actual holds but predicted buy: 3
# actual holds but predicted sell: 33
# actual predicted holds: 154
# Percentage buys correct: 0.0%
# Percentage sells correct: 8.333333333333334%
# Percentage holds correct: 91.12426035502959%
# actual buys: 10
# actual sells: 8
# actual holds: 190
#
#
# Percentage low buys correct: 100.0%
# Percentage high sells correct: 52.77777777777778%
# Percentage mid holds correct: 85.71428571428571%
#
#
# Capital: 100
# Share price: $0.6486447370465204
# Shares owned at the moment: 153
# Cash capital at the moment: $0.4844379587700587
#
#
# Price increase from previously bought: 20.94756318051749%
# Share price: $0.786677433165122
# Shares owned at the moment: 0
# Cash capital at the moment: $120.51509070302949
#
#
# Share price: $0.8913284942808403
# Shares owned at the moment: 134
# Cash capital at the moment: $0.7486179192544
#
#
# Price increase from previously bought: 6.8344740842605%
# Share price: $0.954864786028471
# Shares owned at the moment: 0
# Cash capital at the moment: $128.348631573418
#
#
#
#
# Capital at the end of test period: $128.348631573418
# profit gained: 28.348631573418004%
#
#
# Capital at the end of test period if Buy and Hold: $704.110752699704
# profit gained: 604.110752699704%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.754808      4.166667      11.764706      92.215569
# 1       0.754808      0.000000       8.333333      91.124260
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         54.166667           58.823529          86.746988      -3.862105
# 1        100.000000           52.777778          85.714286      28.348632
#
#    buy_n_hold profit
# 0         400.940691
# 1         604.110753
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2218 - accuracy: 0.7585 - mse: 8.7871 - weighted_accuracy: 0.7585 - weighted_mse: 8.7871
# Test loss: 0.22177039086818695
# Test accuracy: 0.7584540843963623
#
#
# number of predictions: 207
# actual predicted buys: 2
# actual buys but predicted sell: 0
# actual buys but predicted hold: 9
# actual sells but predicted buy: 0
# actual predicted sells: 3
# actual sells but predicted hold: 8
# actual holds but predicted buy: 8
# actual holds but predicted sell: 25
# actual predicted holds: 152
# Percentage buys correct: 20.0%
# Percentage sells correct: 10.714285714285714%
# Percentage holds correct: 89.94082840236686%
# actual buys: 11
# actual sells: 11
# actual holds: 185
#
#
# Percentage low buys correct: 50.0%
# Percentage high sells correct: 46.42857142857143%
# Percentage mid holds correct: 86.9047619047619%
#
#
# Capital: 100
# Share price: $0.30474191934944006
# Shares owned at the moment: 327
# Cash capital at the moment: $0.07535320175811933
#
#
# Price increase from previously bought: 26.109428660666456%
# Share price: $0.385365141187926
# Shares owned at the moment: 0
# Cash capital at the moment: $125.74321476699667
#
#
# Share price: $0.5187633885102239
# Shares owned at the moment: 241
# Cash capital at the moment: $0.37742770029757367
#
#
# Price increase from previously bought: -6.440059400672027%
# Share price: $0.4866894436161149
# Shares owned at the moment: 0
# Cash capital at the moment: $117.34703018302469
#
#
# Share price: $0.4426776877814631
# Shares owned at the moment: 264
# Cash capital at the moment: $0.15873660738907347
#
#
# Price increase from previously bought: 43.99175188187645%
# Share price: $0.6391722610607355
# Shares owned at the moment: 0
# Cash capital at the moment: $168.43617446589317
#
#
# Share price: $0.6833203505355403
# Shares owned at the moment: 245
# Cash capital at the moment: $0.5623014985124826
#
#
# Price increase from previously bought: 19.76839530419552%
# Share price: $0.8206524236246349
# Shares owned at the moment: 0
# Cash capital at the moment: $201.06923071613093
#
#
# Share price: $0.8858130096762413
# Shares owned at the moment: 226
# Cash capital at the moment: $0.32495774378659803
#
#
#
#
# Capital at the end of test period: $194.44674036288063
# profit gained: 94.44674036288063%
#
#
# Capital at the end of test period if Buy and Hold: $1766.892280786996
# profit gained: 1666.8922807869963%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.739130     15.000000       9.677419      94.230769
# 1       0.816425     14.285714      10.526316      91.712707
# 2       0.758454     20.000000      10.714286      89.940828
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         60.000000           35.483871          83.870968      64.556923
# 1         57.142857           55.555556          84.530387      40.976468
# 2         50.000000           46.428571          86.904762      94.446740
#
#    buy_n_hold profit
# 0        2068.314051
# 1        2331.201715
# 2        1666.892281
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2077 - accuracy: 0.7067 - mse: 8.1270 - weighted_accuracy: 0.7067 - weighted_mse: 8.1270
# Test loss: 0.20769836008548737
# Test accuracy: 0.7067307829856873
#
#
# number of predictions: 208
# actual predicted buys: 0
# actual buys but predicted sell: 1
# actual buys but predicted hold: 8
# actual sells but predicted buy: 0
# actual predicted sells: 3
# actual sells but predicted hold: 7
# actual holds but predicted buy: 7
# actual holds but predicted sell: 38
# actual predicted holds: 144
# Percentage buys correct: 0.0%
# Percentage sells correct: 7.142857142857143%
# Percentage holds correct: 90.56603773584905%
# actual buys: 9
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 71.42857142857143%
# Percentage high sells correct: 40.476190476190474%
# Percentage mid holds correct: 85.44303797468355%
#
#
# Capital: 100
# Share price: $0.4102254098188045
# Shares owned at the moment: 243
# Cash capital at the moment: $0.04109228391908459
#
#
# Price increase from previously bought: 22.37194720206468%
# Share price: $0.5033813241731815
# Shares owned at the moment: 0
# Cash capital at the moment: $122.02636948812345
#
#
# Share price: $0.49345618842329086
# Shares owned at the moment: 246
# Cash capital at the moment: $0.3023240245255323
#
#
# Price increase from previously bought: -8.03029022616304%
# Share price: $0.455078257470912
# Shares owned at the moment: 0
# Cash capital at the moment: $111.94371492119082
#
#
# Share price: $0.4790917876756311
# Shares owned at the moment: 233
# Cash capital at the moment: $0.008350329815613122
#
#
# Price increase from previously bought: 32.740646334908384%
# Share price: $0.6376983967207195
# Shares owned at the moment: 0
# Cash capital at the moment: $148.18347151804446
#
#
# Share price: $0.7450231488695955
# Shares owned at the moment: 198
# Cash capital at the moment: $0.263222937305045
#
#
# Price increase from previously bought: 4.865949070371545%
# Share price: $0.7834241037446725
# Shares owned at the moment: 0
# Cash capital at the moment: $154.95462105426122
#
#
# Share price: $0.9680108229283453
# Shares owned at the moment: 159
# Cash capital at the moment: $0.6176374763289232
#
#
#
#
# Capital at the end of test period: $156.56993858274285
# profit gained: 56.56993858274285%
#
#
# Capital at the end of test period if Buy and Hold: $778.7940878989605
# profit gained: 678.7940878989605%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.754808      4.166667      11.764706      92.215569
# 1       0.754808      0.000000       8.333333      91.124260
# 2       0.706731      0.000000       7.142857      90.566038
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         54.166667           58.823529          86.746988      -3.862105
# 1        100.000000           52.777778          85.714286      28.348632
# 2         71.428571           40.476190          85.443038      56.569939
#
#    buy_n_hold profit
# 0         400.940691
# 1         604.110753
# 2         678.794088

# %%
df = nr_log_hist['0_epochs_logs']
df['Profit gained']
# Out:
# 0    116.310960
# 1    466.853189
# 2    487.582101
# Name: Profit gained, dtype: float64

# %%
Sichuan_Swellfun_data_acc = []
Wuliangye_Yibin_data_acc = []
Kweichow_Moutai_data_acc = []

Sichuan_Swellfun_data_correct_buys = []
Wuliangye_Yibin_data_correct_buys = []
Kweichow_Moutai_data_correct_buys = []

Sichuan_Swellfun_data_correct_sells = []
Wuliangye_Yibin_data_correct_sells = []
Kweichow_Moutai_data_correct_sells = []

Sichuan_Swellfun_data_correct_holds = []
Wuliangye_Yibin_data_correct_holds = []
Kweichow_Moutai_data_correct_holds = []

Sichuan_Swellfun_data_correct_low_buys = []
Wuliangye_Yibin_data_correct_low_buys = []
Kweichow_Moutai_data_correct_low_buys = []

Sichuan_Swellfun_data_correct_high_sells = []
Wuliangye_Yibin_data_correct_high_sells = []
Kweichow_Moutai_data_correct_high_sells = []

Sichuan_Swellfun_data_correct_mid_holds = []
Wuliangye_Yibin_data_correct_mid_holds = []
Kweichow_Moutai_data_correct_mid_holds = []

Sichuan_Swellfun_data_profit = []
Wuliangye_Yibin_data_profit = []
Kweichow_Moutai_data_profit = []

for key,value in nr_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    Sichuan_Swellfun_data_acc.append(acc[0])
    Wuliangye_Yibin_data_acc.append(acc[1])
    Kweichow_Moutai_data_acc.append(acc[2])
    
    Sichuan_Swellfun_data_correct_buys.append(correct_buys[0])
    Wuliangye_Yibin_data_correct_buys.append(correct_buys[1]) 
    Kweichow_Moutai_data_correct_buys.append(correct_buys[2]) 

    Sichuan_Swellfun_data_correct_sells.append(correct_sells[0]) 
    Wuliangye_Yibin_data_correct_sells.append(correct_sells[1]) 
    Kweichow_Moutai_data_correct_sells.append(correct_sells[2]) 

    Sichuan_Swellfun_data_correct_holds.append(correct_holds[0]) 
    Wuliangye_Yibin_data_correct_holds.append(correct_holds[1])  
    Kweichow_Moutai_data_correct_holds.append(correct_holds[2])  

    Sichuan_Swellfun_data_correct_low_buys.append(correct_low_buys[0])  
    Wuliangye_Yibin_data_correct_low_buys.append(correct_low_buys[1])  
    Kweichow_Moutai_data_correct_low_buys.append(correct_low_buys[2])  

    Sichuan_Swellfun_data_correct_high_sells.append(correct_high_sells[0]) 
    Wuliangye_Yibin_data_correct_high_sells.append(correct_high_sells[1]) 
    Kweichow_Moutai_data_correct_high_sells.append(correct_high_sells[2]) 

    Sichuan_Swellfun_data_correct_mid_holds.append(correct_mid_holds[0])  
    Wuliangye_Yibin_data_correct_mid_holds.append(correct_mid_holds[1])  
    Kweichow_Moutai_data_correct_mid_holds.append(correct_mid_holds[2])   

    Sichuan_Swellfun_data_profit.append(profit[0]) 
    Wuliangye_Yibin_data_profit.append(profit[1]) 
    Kweichow_Moutai_data_profit.append(profit[2])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(Sichuan_Swellfun_data_acc)
plt.plot(Wuliangye_Yibin_data_acc)
plt.plot(Kweichow_Moutai_data_acc)

plt.title('Non-Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Sichuan_Swellfun_data_acc','Wuliangye_Yibin_data_acc','Kweichow_Moutai_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_profit")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_profit")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_profit")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_profit')

# %%
Sichuan_Swellfun_data_acc = []
Wuliangye_Yibin_data_acc = []
Kweichow_Moutai_data_acc = []

Sichuan_Swellfun_data_correct_buys = []
Wuliangye_Yibin_data_correct_buys = []
Kweichow_Moutai_data_correct_buys = []

Sichuan_Swellfun_data_correct_sells = []
Wuliangye_Yibin_data_correct_sells = []
Kweichow_Moutai_data_correct_sells = []

Sichuan_Swellfun_data_correct_holds = []
Wuliangye_Yibin_data_correct_holds = []
Kweichow_Moutai_data_correct_holds = []

Sichuan_Swellfun_data_correct_low_buys = []
Wuliangye_Yibin_data_correct_low_buys = []
Kweichow_Moutai_data_correct_low_buys = []

Sichuan_Swellfun_data_correct_high_sells = []
Wuliangye_Yibin_data_correct_high_sells = []
Kweichow_Moutai_data_correct_high_sells = []

Sichuan_Swellfun_data_correct_mid_holds = []
Wuliangye_Yibin_data_correct_mid_holds = []
Kweichow_Moutai_data_correct_mid_holds = []

Sichuan_Swellfun_data_profit = []
Wuliangye_Yibin_data_profit = []
Kweichow_Moutai_data_profit = []

for key,value in r_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    Sichuan_Swellfun_data_acc.append(acc[0])
    Wuliangye_Yibin_data_acc.append(acc[1])
    Kweichow_Moutai_data_acc.append(acc[2])
    
    Sichuan_Swellfun_data_correct_buys.append(correct_buys[0])
    Wuliangye_Yibin_data_correct_buys.append(correct_buys[1]) 
    Kweichow_Moutai_data_correct_buys.append(correct_buys[2]) 

    Sichuan_Swellfun_data_correct_sells.append(correct_sells[0]) 
    Wuliangye_Yibin_data_correct_sells.append(correct_sells[1]) 
    Kweichow_Moutai_data_correct_sells.append(correct_sells[2]) 

    Sichuan_Swellfun_data_correct_holds.append(correct_holds[0]) 
    Wuliangye_Yibin_data_correct_holds.append(correct_holds[1])  
    Kweichow_Moutai_data_correct_holds.append(correct_holds[2])  

    Sichuan_Swellfun_data_correct_low_buys.append(correct_low_buys[0])  
    Wuliangye_Yibin_data_correct_low_buys.append(correct_low_buys[1])  
    Kweichow_Moutai_data_correct_low_buys.append(correct_low_buys[2])  

    Sichuan_Swellfun_data_correct_high_sells.append(correct_high_sells[0]) 
    Wuliangye_Yibin_data_correct_high_sells.append(correct_high_sells[1]) 
    Kweichow_Moutai_data_correct_high_sells.append(correct_high_sells[2]) 

    Sichuan_Swellfun_data_correct_mid_holds.append(correct_mid_holds[0])  
    Wuliangye_Yibin_data_correct_mid_holds.append(correct_mid_holds[1])  
    Kweichow_Moutai_data_correct_mid_holds.append(correct_mid_holds[2])   

    Sichuan_Swellfun_data_profit.append(profit[0]) 
    Wuliangye_Yibin_data_profit.append(profit[1]) 
    Kweichow_Moutai_data_profit.append(profit[2])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(Sichuan_Swellfun_data_acc)
plt.plot(Wuliangye_Yibin_data_acc)
plt.plot(Kweichow_Moutai_data_acc)

plt.title('Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Sichuan_Swellfun_data_acc','Wuliangye_Yibin_data_acc','Kweichow_Moutai_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_profit")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_profit")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_profit")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_profit')

# %% [markdown]
# ## Train Wuliangye Yibin Co.,Ltd Stock Data

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []

seed = 10
df = pd.read_csv('variation 7/initial_indicators/000858.SZ_data.csv')
df.set_index('Date', inplace=True)
print(df.head())

plt.figure(figsize=(15,5))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
plt.show()

labels = []
data_15 = []
sequential = []
count = 0

for i in df.values:
    if count == 14:
        data_15.append(np.array(i[0:-1]))
        labels.append(i[-1])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_arr = min_max_scaler.fit_transform(data_15)
        sequential.append(data_15_arr)
        data_15 = data_15[1:15]
    else:
        data_15.append(np.array(i[0:-1]))
        count+= 1
    
X = sequential
X  = np.array(X).reshape(-1, 15, 4)
y = labels
y = np.array(y)

X.shape
# Out:
#             previous_1d    EMA_12   willr_14        OBV_7  labels
# Date
# 2000-01-24     4.396951  4.259450 -20.237909   91957609.0     2.0
# 2000-01-25     4.523540  4.300079 -16.033642  115224048.0     2.0
# 2000-01-26     4.400991  4.315604 -35.231971  105394663.0     2.0
# 2000-01-27     4.399644  4.328533 -51.735021   77180955.0     2.0
# 2000-01-28     4.302682  4.324556 -63.091500   43145413.0     2.0
# (4498, 15, 4)

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization,Activation
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(LSTM(100, input_shape=(X_train.shape[1:]), return_sequences=True,kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(LSTM(100, kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# model.add(Dense(100, kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))

model.add(Dense(75, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(50, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "DBS_CNN_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))
print(d_class_weights)

epochs = 0 
histories = {}
nr_log_hist = {}
r_log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    nr_log  = pd.DataFrame(columns = column_names)
    r_log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['600779.SS','000858.SZ','600519.SS']
    for name in test_sets:
        
        print('\n')
        print("Non-Recession")
        print('\n')
        
        X = nr_test_data['{}_X'.format(name)]
        y = nr_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("variation 7/initial_indicators/{}_data_test.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(nr_log)
        nr_log.loc[df_length] = logger
        print(nr_log.head(20))
        logger = []
        
        print('\n')
        print("Recession")
        print('\n')
        
        X = r_test_data['{}_X'.format(name)]
        y = r_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("variation 7/initial_indicators/{}_data_test2.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(r_log)
        r_log.loc[df_length] = logger
        print(r_log.head(20))
        logger = []

    nr_log.to_csv('{}_{}_{}epochs.csv'.format(experiment,'WuliangyeModel',epochs))
    nr_log_hist['{}_epochs_logs'.format(epochs)] = nr_log
    r_log.to_csv('{}_{}_{}epochs.csv'.format(experiment,'WuliangyeModel',epochs))
    r_log_hist['{}_epochs_logs'.format(epochs)] = r_log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 2 ... 2 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# {0: 7.639065817409766, 1: 7.449275362318841, 2: 0.36565040650406505}
#
#
#
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  2/29 [=>............................] - ETA: 26s - loss: 0.2966 - accuracy: 0.5586 - mse: 0.3267 - weighted_accuracy: 0.3182 - weighted_mse: 0.4538WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0120s vs `on_train_batch_end` time: 1.9369s). Check your callbacks.
# 29/29 [==============================] - 3s 106ms/step - loss: 0.3035 - accuracy: 0.5422 - mse: 0.4218 - weighted_accuracy: 0.3030 - weighted_mse: 0.5316 - val_loss: 0.2998 - val_accuracy: 0.0422 - val_mse: 0.3536 - val_weighted_accuracy: 0.0422 - val_weighted_mse: 0.3536
# Epoch 2/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2170 - accuracy: 0.4227 - mse: 0.7123 - weighted_accuracy: 0.4231 - weighted_mse: 0.7213 - val_loss: 0.2917 - val_accuracy: 0.0444 - val_mse: 0.3842 - val_weighted_accuracy: 0.0444 - val_weighted_mse: 0.3842
# Epoch 3/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1925 - accuracy: 0.3152 - mse: 0.9691 - weighted_accuracy: 0.4639 - weighted_mse: 0.9466 - val_loss: 0.2816 - val_accuracy: 0.0444 - val_mse: 0.4241 - val_weighted_accuracy: 0.0444 - val_weighted_mse: 0.4241
# Epoch 4/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1851 - accuracy: 0.3054 - mse: 1.1324 - weighted_accuracy: 0.4728 - weighted_mse: 1.1031 - val_loss: 0.2712 - val_accuracy: 0.0444 - val_mse: 0.4672 - val_weighted_accuracy: 0.0444 - val_weighted_mse: 0.4672
# Epoch 5/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1798 - accuracy: 0.2840 - mse: 1.2067 - weighted_accuracy: 0.5184 - weighted_mse: 1.1769 - val_loss: 0.2620 - val_accuracy: 0.0444 - val_mse: 0.5163 - val_weighted_accuracy: 0.0444 - val_weighted_mse: 0.5163
# Epoch 6/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1758 - accuracy: 0.2788 - mse: 1.2550 - weighted_accuracy: 0.5408 - weighted_mse: 1.2144 - val_loss: 0.2525 - val_accuracy: 0.0444 - val_mse: 0.5707 - val_weighted_accuracy: 0.0444 - val_weighted_mse: 0.5707
# Epoch 7/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1729 - accuracy: 0.2929 - mse: 1.2698 - weighted_accuracy: 0.5378 - weighted_mse: 1.2267 - val_loss: 0.2448 - val_accuracy: 0.0444 - val_mse: 0.6342 - val_weighted_accuracy: 0.0444 - val_weighted_mse: 0.6342
# Epoch 8/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1701 - accuracy: 0.3182 - mse: 1.2867 - weighted_accuracy: 0.5749 - weighted_mse: 1.2451 - val_loss: 0.2401 - val_accuracy: 0.0444 - val_mse: 0.7092 - val_weighted_accuracy: 0.0444 - val_weighted_mse: 0.7092
# Epoch 9/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1677 - accuracy: 0.2690 - mse: 1.3404 - weighted_accuracy: 0.5749 - weighted_mse: 1.2731 - val_loss: 0.2353 - val_accuracy: 0.0444 - val_mse: 0.7828 - val_weighted_accuracy: 0.0444 - val_weighted_mse: 0.7828
# Epoch 10/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1650 - accuracy: 0.3619 - mse: 1.3168 - weighted_accuracy: 0.6129 - weighted_mse: 1.2711 - val_loss: 0.2308 - val_accuracy: 0.0444 - val_mse: 0.8680 - val_weighted_accuracy: 0.0444 - val_weighted_mse: 0.8680
# Epoch 11/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1635 - accuracy: 0.2818 - mse: 1.3619 - weighted_accuracy: 0.5993 - weighted_mse: 1.2829 - val_loss: 0.2304 - val_accuracy: 0.0489 - val_mse: 0.9511 - val_weighted_accuracy: 0.0489 - val_weighted_mse: 0.9511
# Epoch 12/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1614 - accuracy: 0.2988 - mse: 1.3616 - weighted_accuracy: 0.6057 - weighted_mse: 1.2877 - val_loss: 0.2255 - val_accuracy: 0.0544 - val_mse: 1.0313 - val_weighted_accuracy: 0.0544 - val_weighted_mse: 1.0313
# Epoch 13/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1584 - accuracy: 0.3274 - mse: 1.3732 - weighted_accuracy: 0.6379 - weighted_mse: 1.3090 - val_loss: 0.2207 - val_accuracy: 0.0644 - val_mse: 1.0883 - val_weighted_accuracy: 0.0644 - val_weighted_mse: 1.0883
# Epoch 14/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1570 - accuracy: 0.3482 - mse: 1.3662 - weighted_accuracy: 0.6335 - weighted_mse: 1.3067 - val_loss: 0.2141 - val_accuracy: 0.1222 - val_mse: 1.1599 - val_weighted_accuracy: 0.1222 - val_weighted_mse: 1.1599
# Epoch 15/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1555 - accuracy: 0.3499 - mse: 1.3914 - weighted_accuracy: 0.6481 - weighted_mse: 1.3187 - val_loss: 0.2150 - val_accuracy: 0.1244 - val_mse: 1.2222 - val_weighted_accuracy: 0.1244 - val_weighted_mse: 1.2222
# Epoch 16/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1534 - accuracy: 0.2788 - mse: 1.4490 - weighted_accuracy: 0.6343 - weighted_mse: 1.3554 - val_loss: 0.2113 - val_accuracy: 0.1644 - val_mse: 1.2606 - val_weighted_accuracy: 0.1644 - val_weighted_mse: 1.2606
# Epoch 17/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1528 - accuracy: 0.3491 - mse: 1.4234 - weighted_accuracy: 0.6538 - weighted_mse: 1.3528 - val_loss: 0.2050 - val_accuracy: 0.2422 - val_mse: 1.2711 - val_weighted_accuracy: 0.2422 - val_weighted_mse: 1.2711
# Epoch 18/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1506 - accuracy: 0.3232 - mse: 1.4530 - weighted_accuracy: 0.6526 - weighted_mse: 1.3681 - val_loss: 0.2017 - val_accuracy: 0.2533 - val_mse: 1.2829 - val_weighted_accuracy: 0.2533 - val_weighted_mse: 1.2829
# Epoch 19/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1516 - accuracy: 0.3616 - mse: 1.4485 - weighted_accuracy: 0.6510 - weighted_mse: 1.3719 - val_loss: 0.1975 - val_accuracy: 0.3178 - val_mse: 1.2952 - val_weighted_accuracy: 0.3178 - val_weighted_mse: 1.2952
# Epoch 20/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1501 - accuracy: 0.3191 - mse: 1.4901 - weighted_accuracy: 0.6590 - weighted_mse: 1.4011 - val_loss: 0.1914 - val_accuracy: 0.3111 - val_mse: 1.2981 - val_weighted_accuracy: 0.3111 - val_weighted_mse: 1.2981
# Validation loss: 0.19139127433300018
# Validation accuracy: 0.31111112236976624
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1838 - accuracy: 0.3720 - mse: 1.2353 - weighted_accuracy: 0.3720 - weighted_mse: 1.2353
# Test loss: 0.18376970291137695
# Test accuracy: 0.3719806671142578
#
#
# number of predictions: 207
# actual predicted buys: 3
# actual buys but predicted sell: 2
# actual buys but predicted hold: 2
# actual sells but predicted buy: 0
# actual predicted sells: 6
# actual sells but predicted hold: 4
# actual holds but predicted buy: 62
# actual holds but predicted sell: 60
# actual predicted holds: 68
# Percentage buys correct: 4.615384615384615%
# Percentage sells correct: 8.823529411764707%
# Percentage holds correct: 91.89189189189189%
# actual buys: 7
# actual sells: 10
# actual holds: 190
#
#
# Percentage low buys correct: 53.125%
# Percentage high sells correct: 44.11764705882353%
# Percentage mid holds correct: 87.83783783783784%
#
#
# Capital: 100
# Share price: $0.2903312641826963
# Shares owned at the moment: 343
# Cash capital at the moment: $0.14252142039484283
#
#
# Price increase from previously bought: 78.80659176627735%
# Share price: $0.5205590497723978
# Shares owned at the moment: 0
# Cash capital at the moment: $178.20325816862945
#
#
# Share price: $0.459689437854242
# Shares owned at the moment: 386
# Cash capital at the moment: $0.27517481860977
#
#
# Price increase from previously bought: 3.049521312952974%
# Share price: $0.4750104615893971
# Shares owned at the moment: 0
# Cash capital at the moment: $183.1249893871399
#
#
# Share price: $0.4895031511134966
# Shares owned at the moment: 373
# Cash capital at the moment: $0.0382061645509566
#
#
# Price increase from previously bought: -14.952835897270534%
# Share price: $0.41745339672312
# Shares owned at the moment: 0
# Cash capital at the moment: $155.32012032058594
#
#
# Share price: $0.45886126160165475
# Shares owned at the moment: 337
# Cash capital at the moment: $0.25862548663894813
#
#
# Price increase from previously bought: 8.365109108181802%
# Share price: $0.49861293193348466
# Shares owned at the moment: 0
# Cash capital at the moment: $167.8290940135539
#
#
# Share price: $0.4853624278090307
# Shares owned at the moment: 344
# Cash capital at the moment: $0.4052659905400162
#
#
# Price increase from previously bought: -29.54155283602041%
# Share price: $0.3429192715334515
# Shares owned at the moment: 0
# Cash capital at the moment: $118.04509376717667
#
#
# Share price: $0.35741211901602
# Shares owned at the moment: 329
# Cash capital at the moment: $0.13313799622633837
#
#
# Price increase from previously bought: 38.89277261853641%
# Share price: $0.4977847556808974
# Shares owned at the moment: 0
# Cash capital at the moment: $163.4539518575393
#
#
# Share price: $0.643540459008356
# Shares owned at the moment: 253
# Cash capital at the moment: $0.19047245407014657
#
#
# Price increase from previously bought: -40.6355340702958%
# Share price: $0.3830849510123402
# Shares owned at the moment: 0
# Cash capital at the moment: $96.84443370552538
#
#
# Share price: $0.40296070719902044
# Shares owned at the moment: 239
# Cash capital at the moment: $0.2719787601529191
#
#
# Price increase from previously bought: -3.1435963427993707%
# Share price: $0.3913665555797412
# Shares owned at the moment: 0
# Cash capital at the moment: $93.55135987505628
#
#
# Share price: $0.41289866427159505
# Shares owned at the moment: 225
# Cash capital at the moment: $0.39367936542933535
#
#
# Price increase from previously bought: 19.32785223360918%
# Share price: $0.49405804152349053
# Shares owned at the moment: 0
# Cash capital at the moment: $111.25104029502205
#
#
# Share price: $0.4265631775431078
# Shares owned at the moment: 260
# Cash capital at the moment: $0.03962146187069493
#
#
# Price increase from previously bought: 2.9204032121237455%
# Share price: $0.44022784877308885
# Shares owned at the moment: 0
# Cash capital at the moment: $114.18409923100103
#
#
# Share price: $0.4418840433197939
# Shares owned at the moment: 257
# Cash capital at the moment: $0.3075985501977243
#
#
# Price increase from previously bought: 55.6091769764441%
# Share price: $0.6895030563384155
# Shares owned at the moment: 0
# Cash capital at the moment: $177.02257774410333
#
#
# Share price: $0.949544555187372
# Shares owned at the moment: 185
# Cash capital at the moment: $0.8737542419879389
#
#
#
#
# Capital at the end of test period: $139.38735598148583
# profit gained: 39.387355981485825%
#
#
# Capital at the end of test period if Buy and Hold: $2168.3140506383515
# profit gained: 2068.3140506383515%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.371981      4.615385       8.823529      91.891892
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0            53.125           44.117647          87.837838      39.387356
#
#    buy_n_hold profit
# 0        2068.314051
#
#
# Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1886 - accuracy: 0.3606 - mse: 1.2565 - weighted_accuracy: 0.3606 - weighted_mse: 1.2565
# Test loss: 0.1886122226715088
# Test accuracy: 0.36057692766189575
#
#
# number of predictions: 208
# actual predicted buys: 6
# actual buys but predicted sell: 0
# actual buys but predicted hold: 2
# actual sells but predicted buy: 1
# actual predicted sells: 4
# actual sells but predicted hold: 3
# actual holds but predicted buy: 60
# actual holds but predicted sell: 67
# actual predicted holds: 65
# Percentage buys correct: 8.955223880597014%
# Percentage sells correct: 5.633802816901408%
# Percentage holds correct: 92.85714285714286%
# actual buys: 8
# actual sells: 8
# actual holds: 192
#
#
# Percentage low buys correct: 47.76119402985075%
# Percentage high sells correct: 54.285714285714285%
# Percentage mid holds correct: 87.14285714285714%
#
#
# Capital: 100
# Share price: $0.1797417091039999
# Shares owned at the moment: 554
# Cash capital at the moment: $0.14925666256411318
#
#
# Price increase from previously bought: 12.90546534172341%
# Share price: $0.20349629316299978
# Shares owned at the moment: 0
# Cash capital at the moment: $112.57617647223215
#
#
# Share price: $0.19011995533566695
# Shares owned at the moment: 590
# Cash capital at the moment: $0.09693319665653632
#
#
# Price increase from previously bought: 2.7500923744059103%
# Share price: $0.1958856379113334
# Shares owned at the moment: 0
# Cash capital at the moment: $115.3516351168321
#
#
# Share price: $0.18020297426733345
# Shares owned at the moment: 638
# Cash capital at the moment: $0.06597141592131095
#
#
# Price increase from previously bought: -42.392458613475036%
# Share price: $0.10409598186400025
# Shares owned at the moment: 0
# Cash capital at the moment: $66.29657144497308
#
#
# Share price: $0.15391147579866682
# Shares owned at the moment: 429
# Cash capital at the moment: $0.08697126377153097
#
#
# Price increase from previously bought: -0.12483772285337702%
# Share price: $0.15414206439166667
# Shares owned at the moment: 0
# Cash capital at the moment: $66.03206778733046
#
#
# Share price: $0.16751849019633358
# Shares owned at the moment: 393
# Cash capital at the moment: $0.01625553189167306
#
#
# Price increase from previously bought: 41.326177793950514%
# Share price: $0.23739853486066664
# Shares owned at the moment: 0
# Cash capital at the moment: $93.05731126558298
#
#
# Share price: $0.364474228095667
# Shares owned at the moment: 254
# Cash capital at the moment: $0.2262720809587364
#
#
# Price increase from previously bought: 49.95587729174276%
# Share price: $0.5480535401903337
# Shares owned at the moment: 0
# Cash capital at the moment: $139.04905589148052
#
#
# Share price: $0.6965775796450009
# Shares owned at the moment: 199
# Cash capital at the moment: $0.04891546166462035
#
#
# Price increase from previously bought: -14.802097086268951%
# Share price: $0.5951015311223335
# Shares owned at the moment: 0
# Cash capital at the moment: $118.14845084210229
#
#
# Share price: $0.5365221750390003
# Shares owned at the moment: 219
# Cash capital at the moment: $0.3269740286439742
#
#
# Price increase from previously bought: 27.718369317566772%
# Share price: $0.6871217757626666
# Shares owned at the moment: 0
# Cash capital at the moment: $150.3928238312149
#
#
# Share price: $0.7355534742073329
# Shares owned at the moment: 203
# Cash capital at the moment: $0.6648458401500932
#
#
# Price increase from previously bought: -4.151504134966066%
# Share price: $0.7069557378993334
# Shares owned at the moment: 0
# Cash capital at the moment: $143.78220259303245
#
#
# Share price: $0.8075092560953336
# Shares owned at the moment: 177
# Cash capital at the moment: $0.4600091337539993
#
#
# Price increase from previously bought: 9.381151737261618%
# Share price: $0.8856918977450001
# Shares owned at the moment: 0
# Cash capital at the moment: $156.79636450339166
#
#
# Share price: $0.833800754564
# Shares owned at the moment: 187
# Cash capital at the moment: $0.4468413618891134
#
#
# Price increase from previously bought: -2.0672039300709044%
# Share price: $0.8188099446763331
# Shares owned at the moment: 0
# Cash capital at the moment: $153.1432280023136
#
#
# Share price: $0.7623063258166671
# Shares owned at the moment: 200
# Cash capital at the moment: $0.2626943597810225
#
#
# Price increase from previously bought: -2.8689466225883753%
# Share price: $0.7424723636800004
# Shares owned at the moment: 0
# Cash capital at the moment: $148.34880729575707
#
#
#
#
# Capital at the end of test period: $148.34880729575707
# profit gained: 48.34880729575707%
#
#
# Capital at the end of test period if Buy and Hold: $500.9406907154986
# profit gained: 400.9406907154986%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.360577      8.955224       5.633803      92.857143
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.761194           54.285714          87.142857      48.348807
#
#    buy_n_hold profit
# 0         400.940691
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1825 - accuracy: 0.4155 - mse: 1.2383 - weighted_accuracy: 0.4155 - weighted_mse: 1.2383
# Test loss: 0.18246085941791534
# Test accuracy: 0.41545894742012024
#
#
# number of predictions: 207
# actual predicted buys: 6
# actual buys but predicted sell: 0
# actual buys but predicted hold: 2
# actual sells but predicted buy: 2
# actual predicted sells: 4
# actual sells but predicted hold: 4
# actual holds but predicted buy: 60
# actual holds but predicted sell: 53
# actual predicted holds: 76
# Percentage buys correct: 8.823529411764707%
# Percentage sells correct: 7.017543859649122%
# Percentage holds correct: 92.6829268292683%
# actual buys: 8
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 55.88235294117647%
# Percentage high sells correct: 48.214285714285715%
# Percentage mid holds correct: 82.92682926829268%
#
#
# Capital: 100
# Share price: $0.03722094537543363
# Shares owned at the moment: 2679
# Cash capital at the moment: $0.010871329396152873
#
#
# Price increase from previously bought: 279.48380263960615%
# Share price: $0.1416358894010512
# Shares owned at the moment: 0
# Cash capital at the moment: $378.4099520286224
#
#
# Share price: $0.11766518611218689
# Shares owned at the moment: 3207
# Cash capital at the moment: $0.019981474219093798
#
#
# Price increase from previously bought: 122.08168652310269%
# Share price: $0.2620314400503556
# Shares owned at the moment: 0
# Cash capital at the moment: $838.0438889380454
#
#
# Share price: $0.4508179447005256
# Shares owned at the moment: 1853
# Cash capital at the moment: $0.3809818662637099
#
#
# Price increase from previously bought: 27.82647967730709%
# Share price: $0.5778494364125477
# Shares owned at the moment: 0
# Cash capital at the moment: $1068.1914112731151
#
#
# Share price: $0.4317226562031815
# Shares owned at the moment: 2467
# Cash capital at the moment: $0.2027039895199323
#
#
# Price increase from previously bought: 26.066181694344404%
# Share price: $0.5457529729222608
# Shares owned at the moment: 0
# Cash capital at the moment: $1342.8727635821892
#
#
# Share price: $0.4928005913400997
# Shares owned at the moment: 2717
# Cash capital at the moment: $0.2514740927929324
#
#
# Price increase from previously bought: 25.15846883303179%
# Share price: $0.6184778241263289
# Shares owned at the moment: 0
# Cash capital at the moment: $1676.0346105616127
#
#
# Share price: $0.7425297808842741
# Shares owned at the moment: 2251
# Cash capital at the moment: $0.003628814992680418
#
#
# Price increase from previously bought: -2.8752312353024667%
# Share price: $0.7231635786077719
# Shares owned at the moment: 0
# Cash capital at the moment: $1623.3682809186105
#
#
# Share price: $0.700411677355121
# Shares owned at the moment: 2311
# Cash capital at the moment: $0.2656032384147693
#
#
# Price increase from previously bought: 6.031124593513759%
# Share price: $0.7446966778242088
# Shares owned at the moment: 0
# Cash capital at the moment: $1716.526892128419
#
#
# Share price: $0.8389544215980482
# Shares owned at the moment: 2040
# Cash capital at the moment: $0.3533377632354586
#
#
# Price increase from previously bought: 7.517301230710527%
# Share price: $0.904501710827748
# Shares owned at the moment: 0
# Cash capital at the moment: $1840.4625732540976
#
#
# Share price: $0.9004388307270363
# Shares owned at the moment: 2038
# Cash capital at the moment: $0.32172680558778666
#
#
# Price increase from previously bought: -2.854070560520905%
# Share price: $0.8771452052394026
# Shares owned at the moment: 0
# Cash capital at the moment: $1783.027694780726
#
#
# Share price: $0.8963759506263254
# Shares owned at the moment: 1983
# Cash capital at the moment: $0.6260225359699234
#
#
# Price increase from previously bought: -4.80939074765836%
# Share price: $0.8556122093462981
# Shares owned at the moment: 0
# Cash capital at the moment: $1692.6391663890613
#
#
# Share price: $0.842475680787109
# Shares owned at the moment: 2003
# Cash capital at the moment: $0.5198111037864237
#
#
# Price increase from previously bought: 0.2707993880427306%
# Share price: $0.8470801817994709
# Shares owned at the moment: 0
# Cash capital at the moment: $1692.5554858367295
#
#
#
#
# Capital at the end of test period: $1692.5554858367295
# profit gained: 1592.5554858367295%
#
#
# Capital at the end of test period if Buy and Hold: $2431.2017150969914
# profit gained: 2331.2017150969914%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.371981      4.615385       8.823529      91.891892
# 1       0.415459      8.823529       7.017544      92.682927
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         53.125000           44.117647          87.837838      39.387356
# 1         55.882353           48.214286          82.926829    1592.555486
#
#    buy_n_hold profit
# 0        2068.314051
# 1        2331.201715
#
#
# Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1822 - accuracy: 0.3510 - mse: 1.2240 - weighted_accuracy: 0.3510 - weighted_mse: 1.2240
# Test loss: 0.1822262704372406
# Test accuracy: 0.3509615361690521
#
#
# number of predictions: 208
# actual predicted buys: 6
# actual buys but predicted sell: 1
# actual buys but predicted hold: 3
# actual sells but predicted buy: 0
# actual predicted sells: 5
# actual sells but predicted hold: 3
# actual holds but predicted buy: 40
# actual holds but predicted sell: 88
# actual predicted holds: 62
# Percentage buys correct: 13.043478260869565%
# Percentage sells correct: 5.319148936170213%
# Percentage holds correct: 91.17647058823529%
# actual buys: 10
# actual sells: 8
# actual holds: 190
#
#
# Percentage low buys correct: 56.52173913043478%
# Percentage high sells correct: 49.46236559139785%
# Percentage mid holds correct: 83.82352941176471%
#
#
# Capital: 100
# Share price: $0.12394237638271631
# Shares owned at the moment: 804
# Cash capital at the moment: $0.07629279411389689
#
#
# Price increase from previously bought: 16.28894959383931%
# Share price: $0.1445276486379956
# Shares owned at the moment: 0
# Cash capital at the moment: $115.95697166792375
#
#
# Share price: $0.04338155010921151
# Shares owned at the moment: 2665
# Cash capital at the moment: $0.027208091512179067
#
#
# Price increase from previously bought: 97.43841425110196%
# Share price: $0.08588738718586063
# Shares owned at the moment: 0
# Cash capital at the moment: $228.28764775299237
#
#
# Share price: $0.09284187679194632
# Shares owned at the moment: 2452
# Cash capital at the moment: $0.013333083931883039
#
#
# Price increase from previously bought: 2.4747598417375283%
# Share price: $0.0954011238733654
# Shares owned at the moment: 0
# Cash capital at the moment: $233.29359904314575
#
#
# Share price: $0.2595827263789513
# Shares owned at the moment: 896
# Cash capital at the moment: $0.0678643698076371
#
#
# Price increase from previously bought: 24.861623396708588%
# Share price: $0.32501053403128377
# Shares owned at the moment: 0
# Cash capital at the moment: $290.4764769059848
#
#
# Share price: $0.30920995402073836
# Shares owned at the moment: 936
# Cash capital at the moment: $0.2600535209243162
#
#
# Price increase from previously bought: 12.375984054114575%
# Share price: $0.3484332923777962
# Shares owned at the moment: 0
# Cash capital at the moment: $325.4967478919611
#
#
# Share price: $0.5852754311516141
# Shares owned at the moment: 554
# Cash capital at the moment: $0.3624919146074035
#
#
# Price increase from previously bought: -4.227363463734612%
# Share price: $0.562075179119281
# Shares owned at the moment: 0
# Cash capital at the moment: $310.8958196113008
#
#
# Share price: $0.5770969445833632
# Shares owned at the moment: 537
# Cash capital at the moment: $0.14253245712126272
#
#
# Price increase from previously bought: 10.214850960183508%
# Share price: $0.6377956653460896
# Shares owned at the moment: 0
# Cash capital at the moment: $341.6969399991715
#
#
# Share price: $0.5875008338680928
# Shares owned at the moment: 580
# Cash capital at the moment: $0.009392525658029172
#
#
# Price increase from previously bought: 15.081626265538617%
# Share price: $0.6779648041023337
# Shares owned at the moment: 0
# Cash capital at the moment: $392.1476250424684
#
#
# Share price: $0.6762401042630121
# Shares owned at the moment: 578
# Cash capital at the moment: $0.20596113272137018
#
#
# Price increase from previously bought: 16.012049301843234%
# Share price: $0.786677433165122
# Shares owned at the moment: 0
# Cash capital at the moment: $453.65509372214586
#
#
# Share price: $0.7789996494740284
# Shares owned at the moment: 580
# Cash capital at the moment: $0.5927925862982875
#
#
# Price increase from previously bought: 2.3111826392143486%
# Share price: $0.7991955144560764
# Shares owned at the moment: 0
# Cash capital at the moment: $462.85147412526516
#
#
# Share price: $0.9008978787703085
# Shares owned at the moment: 512
# Cash capital at the moment: $0.3232959815586014
#
#
# Price increase from previously bought: 5.69967270073648%
# Share price: $0.954864786028471
# Shares owned at the moment: 0
# Cash capital at the moment: $487.86961680940766
#
#
#
#
# Capital at the end of test period: $487.86961680940766
# profit gained: 387.86961680940766%
#
#
# Capital at the end of test period if Buy and Hold: $704.110752699704
# profit gained: 604.110752699704%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.360577      8.955224       5.633803      92.857143
# 1       0.350962     13.043478       5.319149      91.176471
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.761194           54.285714          87.142857      48.348807
# 1         56.521739           49.462366          83.823529     387.869617
#
#    buy_n_hold profit
# 0         400.940691
# 1         604.110753
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1855 - accuracy: 0.3527 - mse: 1.2686 - weighted_accuracy: 0.3527 - weighted_mse: 1.2686
# Test loss: 0.1854666769504547
# Test accuracy: 0.3526569902896881
#
#
# number of predictions: 207
# actual predicted buys: 7
# actual buys but predicted sell: 0
# actual buys but predicted hold: 4
# actual sells but predicted buy: 1
# actual predicted sells: 5
# actual sells but predicted hold: 5
# actual holds but predicted buy: 55
# actual holds but predicted sell: 69
# actual predicted holds: 61
# Percentage buys correct: 11.11111111111111%
# Percentage sells correct: 6.756756756756757%
# Percentage holds correct: 87.14285714285714%
# actual buys: 11
# actual sells: 11
# actual holds: 185
#
#
# Percentage low buys correct: 57.142857142857146%
# Percentage high sells correct: 47.945205479452056%
# Percentage mid holds correct: 84.28571428571429%
#
#
# Capital: 100
# Share price: $0.021217156310856737
# Shares owned at the moment: 4700
# Cash capital at the moment: $0.005133593655514801
#
#
# Price increase from previously bought: 579.0405897142386%
# Share price: $0.14446930436800143
# Shares owned at the moment: 0
# Cash capital at the moment: $677.1435983643057
#
#
# Share price: $0.0845666563336782
# Shares owned at the moment: 7985
# Cash capital at the moment: $0.021869475118137416
#
#
# Price increase from previously bought: 118.11078810644476%
# Share price: $0.184956235356317
# Shares owned at the moment: 0
# Cash capital at the moment: $1472.8360010621786
#
#
# Share price: $0.14291139240506334
# Shares owned at the moment: 10277
# Cash capital at the moment: $0.09669527103869768
#
#
# Price increase from previously bought: 95.53096872134697%
# Share price: $0.2802044790652385
# Shares owned at the moment: 0
# Cash capital at the moment: $2871.8390576882725
#
#
# Share price: $0.340574488802337
# Shares owned at the moment: 8409
# Cash capital at the moment: $0.07248143948891084
#
#
# Price increase from previously bought: 9.300007092936124%
# Share price: $0.3732716222538339
# Shares owned at the moment: 0
# Cash capital at the moment: $3130.281740025264
#
#
# Share price: $0.3307595364608691
# Shares owned at the moment: 9437
# Cash capital at the moment: $0.3202056436939529
#
#
# Price increase from previously bought: 15.549616273397394%
# Share price: $0.3832424014499147
# Shares owned at the moment: 0
# Cash capital at the moment: $3607.0329371347116
#
#
# Share price: $0.30474191934944006
# Shares owned at the moment: 11803
# Cash capital at the moment: $0.27267364954650475
#
#
# Price increase from previously bought: 26.109428660666456%
# Share price: $0.385365141187926
# Shares owned at the moment: 0
# Cash capital at the moment: $4536.229156996675
#
#
# Share price: $0.5544401311085079
# Shares owned at the moment: 8159
# Cash capital at the moment: $0.11201545064432139
#
#
# Price increase from previously bought: -11.4200779894169%
# Share price: $0.4924732229795521
# Shares owned at the moment: 0
# Cash capital at the moment: $4007.151296918512
#
#
# Share price: $0.4688510128864414
# Shares owned at the moment: 8523
# Cash capital at the moment: $0.1450668345860322
#
#
# Price increase from previously bought: 8.233842652180655%
# Share price: $0.5088509700964581
# Shares owned at the moment: 0
# Cash capital at the moment: $4325.155308716835
#
#
# Share price: $0.4426776877814631
# Shares owned at the moment: 9743
# Cash capital at the moment: $0.285822703888698
#
#
# Price increase from previously bought: 32.85727275509718%
# Share price: $0.5897468592152508
# Shares owned at the moment: 0
# Cash capital at the moment: $5730.3882370024085
#
#
# Share price: $0.8352190847127554
# Shares owned at the moment: 6842
# Cash capital at the moment: $0.1041947093226554
#
#
# Price increase from previously bought: 2.846227038255411%
# Share price: $0.8613535422498781
# Shares owned at the moment: 0
# Cash capital at the moment: $5877.278333208786
#
#
# Share price: $0.8474294440725414
# Shares owned at the moment: 6916
# Cash capital at the moment: $0.33903740627374646
#
#
# Price increase from previously bought: 9.518309327425634%
# Share price: $0.9306426484907497
# Shares owned at the moment: 0
# Cash capital at the moment: $6418.963701836653
#
#
# Share price: $0.9423271665043815
# Shares owned at the moment: 6793
# Cash capital at the moment: $0.13188155671196
#
#
# Price increase from previously bought: -1.5108093154253877%
# Share price: $0.9306426484907497
# Shares owned at the moment: 0
# Cash capital at the moment: $6304.602290098581
#
#
# Share price: $0.9093379914191821
# Shares owned at the moment: 6914
# Cash capital at the moment: $0.14971952650648745
#
#
# Price increase from previously bought: -5.203472839232292%
# Share price: $0.8643913933179164
# Shares owned at the moment: 0
# Cash capital at the moment: $5960.11670716973
#
#
# Share price: $0.8428530553949609
# Shares owned at the moment: 7051
# Cash capital at the moment: $0.8166821224876912
#
#
# Price increase from previously bought: 4.352522716236584%
# Share price: $0.8819571567672835
# Shares owned at the moment: 0
# Cash capital at the moment: $6202.3952247295965
#
#
#
#
# Capital at the end of test period: $6202.3952247295965
# profit gained: 6102.3952247295965%
#
#
# Capital at the end of test period if Buy and Hold: $1766.892280786996
# profit gained: 1666.8922807869963%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.371981      4.615385       8.823529      91.891892
# 1       0.415459      8.823529       7.017544      92.682927
# 2       0.352657     11.111111       6.756757      87.142857
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         53.125000           44.117647          87.837838      39.387356
# 1         55.882353           48.214286          82.926829    1592.555486
# 2         57.142857           47.945205          84.285714    6102.395225
#
#    buy_n_hold profit
# 0        2068.314051
# 1        2331.201715
# 2        1666.892281
#
#
# Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1789 - accuracy: 0.4519 - mse: 1.2335 - weighted_accuracy: 0.4519 - weighted_mse: 1.2335
# Test loss: 0.17892907559871674
# Test accuracy: 0.45192307233810425
#
#
# number of predictions: 208
# actual predicted buys: 4
# actual buys but predicted sell: 0
# actual buys but predicted hold: 5
# actual sells but predicted buy: 1
# actual predicted sells: 6
# actual sells but predicted hold: 3
# actual holds but predicted buy: 34
# actual holds but predicted sell: 71
# actual predicted holds: 84
# Percentage buys correct: 10.256410256410257%
# Percentage sells correct: 7.792207792207792%
# Percentage holds correct: 91.30434782608695%
# actual buys: 9
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 56.41025641025641%
# Percentage high sells correct: 50.64935064935065%
# Percentage mid holds correct: 85.71428571428571%
#
#
# Capital: 100
# Share price: $0.11510518984487804
# Shares owned at the moment: 866
# Cash capital at the moment: $0.044782584720039154
#
#
# Price increase from previously bought: 67.59118724599227%
# Share price: $0.1934366461669521
# Shares owned at the moment: 0
# Cash capital at the moment: $167.10024879245395
#
#
# Share price: $0.06646855704303233
# Shares owned at the moment: 2507
# Cash capital at the moment: $0.005325436177997744
#
#
# Price increase from previously bought: 52.18118097152449%
# Share price: $0.10143080482929577
# Shares owned at the moment: 0
# Cash capital at the moment: $253.5930638170281
#
#
# Share price: $0.4319618179127802
# Shares owned at the moment: 585
# Cash capital at the moment: $0.20048176348450397
#
#
# Price increase from previously bought: 12.419960425646082%
# Share price: $0.4869467358395154
# Shares owned at the moment: 0
# Cash capital at the moment: $284.2809466683192
#
#
# Share price: $0.4790917876756311
# Shares owned at the moment: 591
# Cash capital at the moment: $0.35905622410137994
#
#
# Price increase from previously bought: 8.334368041216567%
# Share price: $0.5204483684321803
# Shares owned at the moment: 0
# Cash capital at the moment: $307.0981832567256
#
#
# Share price: $0.7471507558725743
# Shares owned at the moment: 409
# Cash capital at the moment: $0.6731662921750399
#
#
# Price increase from previously bought: 6.332645452186192%
# Share price: $0.7966499434369607
# Shares owned at the moment: 0
# Cash capital at the moment: $325.60696113401127
#
#
# Share price: $0.8327622642399453
# Shares owned at the moment: 389
# Cash capital at the moment: $0.7715929125018874
#
#
# Price increase from previously bought: -2.3952089364716156%
# Share price: $0.8150511117044918
# Shares owned at the moment: 0
# Cash capital at the moment: $316.9545744388034
#
#
# Share price: $0.7791804017000639
# Shares owned at the moment: 405
# Cash capital at the moment: $0.5186995778840924
#
#
# Price increase from previously bought: 4.996817991519209%
# Share price: $0.8203644434261506
# Shares owned at the moment: 0
# Cash capital at the moment: $331.85261826660917
#
#
# Share price: $0.8123484681931528
# Shares owned at the moment: 407
# Cash capital at the moment: $0.3175706889708181
#
#
# Price increase from previously bought: 9.587564292280671%
# Share price: $0.8926810403331393
# Shares owned at the moment: 0
# Cash capital at the moment: $362.63962085016567
#
#
#
#
# Capital at the end of test period: $362.63962085016567
# profit gained: 262.63962085016567%
#
#
# Capital at the end of test period if Buy and Hold: $778.7940878989605
# profit gained: 678.7940878989605%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.360577      8.955224       5.633803      92.857143
# 1       0.350962     13.043478       5.319149      91.176471
# 2       0.451923     10.256410       7.792208      91.304348
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.761194           54.285714          87.142857      48.348807
# 1         56.521739           49.462366          83.823529     387.869617
# 2         56.410256           50.649351          85.714286     262.639621
#
#    buy_n_hold profit
# 0         400.940691
# 1         604.110753
# 2         678.794088
#
#
#
# RUNNING EPOCHS 20 - 40
#
#
#
# Epoch 1/20
#  2/29 [=>............................] - ETA: 16s - loss: 0.1243 - accuracy: 0.3125 - mse: 1.5274 - weighted_accuracy: 0.6231 - weighted_mse: 1.4581WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0100s vs `on_train_batch_end` time: 1.1779s). Check your callbacks.
# 29/29 [==============================] - 2s 52ms/step - loss: 0.1473 - accuracy: 0.3335 - mse: 1.4975 - weighted_accuracy: 0.6621 - weighted_mse: 1.4064 - val_loss: 0.1872 - val_accuracy: 0.3156 - val_mse: 1.3155 - val_weighted_accuracy: 0.3156 - val_weighted_mse: 1.3155
# Epoch 2/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1465 - accuracy: 0.3488 - mse: 1.5153 - weighted_accuracy: 0.6800 - weighted_mse: 1.4271 - val_loss: 0.1857 - val_accuracy: 0.3100 - val_mse: 1.3496 - val_weighted_accuracy: 0.3100 - val_weighted_mse: 1.3496
# Epoch 3/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1448 - accuracy: 0.3516 - mse: 1.5354 - weighted_accuracy: 0.6869 - weighted_mse: 1.4450 - val_loss: 0.1904 - val_accuracy: 0.2833 - val_mse: 1.4107 - val_weighted_accuracy: 0.2833 - val_weighted_mse: 1.4107
# Epoch 4/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1445 - accuracy: 0.3627 - mse: 1.5410 - weighted_accuracy: 0.6792 - weighted_mse: 1.4516 - val_loss: 0.1840 - val_accuracy: 0.3478 - val_mse: 1.4170 - val_weighted_accuracy: 0.3478 - val_weighted_mse: 1.4170
# Epoch 5/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1424 - accuracy: 0.3577 - mse: 1.5408 - weighted_accuracy: 0.6832 - weighted_mse: 1.4552 - val_loss: 0.1814 - val_accuracy: 0.3667 - val_mse: 1.4116 - val_weighted_accuracy: 0.3667 - val_weighted_mse: 1.4116
# Epoch 6/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1412 - accuracy: 0.3722 - mse: 1.5671 - weighted_accuracy: 0.6967 - weighted_mse: 1.4818 - val_loss: 0.1821 - val_accuracy: 0.3678 - val_mse: 1.4806 - val_weighted_accuracy: 0.3678 - val_weighted_mse: 1.4806
# Epoch 7/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1409 - accuracy: 0.3805 - mse: 1.5838 - weighted_accuracy: 0.6797 - weighted_mse: 1.5055 - val_loss: 0.1844 - val_accuracy: 0.3511 - val_mse: 1.5164 - val_weighted_accuracy: 0.3511 - val_weighted_mse: 1.5164
# Epoch 8/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1391 - accuracy: 0.3872 - mse: 1.6029 - weighted_accuracy: 0.7000 - weighted_mse: 1.5222 - val_loss: 0.1925 - val_accuracy: 0.3122 - val_mse: 1.5364 - val_weighted_accuracy: 0.3122 - val_weighted_mse: 1.5364
# Epoch 9/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1388 - accuracy: 0.3555 - mse: 1.6646 - weighted_accuracy: 0.6886 - weighted_mse: 1.5646 - val_loss: 0.1868 - val_accuracy: 0.3556 - val_mse: 1.5774 - val_weighted_accuracy: 0.3556 - val_weighted_mse: 1.5774
# Epoch 10/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1374 - accuracy: 0.4130 - mse: 1.6404 - weighted_accuracy: 0.6933 - weighted_mse: 1.5658 - val_loss: 0.1964 - val_accuracy: 0.2956 - val_mse: 1.6446 - val_weighted_accuracy: 0.2956 - val_weighted_mse: 1.6446
# Epoch 11/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1370 - accuracy: 0.3630 - mse: 1.6827 - weighted_accuracy: 0.7032 - weighted_mse: 1.5839 - val_loss: 0.1929 - val_accuracy: 0.3500 - val_mse: 1.6189 - val_weighted_accuracy: 0.3500 - val_weighted_mse: 1.6189
# Epoch 12/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1363 - accuracy: 0.3919 - mse: 1.6955 - weighted_accuracy: 0.6977 - weighted_mse: 1.6044 - val_loss: 0.1844 - val_accuracy: 0.3767 - val_mse: 1.6001 - val_weighted_accuracy: 0.3767 - val_weighted_mse: 1.6001
# Epoch 13/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1344 - accuracy: 0.4133 - mse: 1.6788 - weighted_accuracy: 0.7176 - weighted_mse: 1.6026 - val_loss: 0.1905 - val_accuracy: 0.3633 - val_mse: 1.6589 - val_weighted_accuracy: 0.3633 - val_weighted_mse: 1.6589
# Epoch 14/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1325 - accuracy: 0.4344 - mse: 1.6906 - weighted_accuracy: 0.7253 - weighted_mse: 1.6196 - val_loss: 0.1887 - val_accuracy: 0.3689 - val_mse: 1.7471 - val_weighted_accuracy: 0.3689 - val_weighted_mse: 1.7471
# Epoch 15/20
# 29/29 [==============================] - 0s 9ms/step - loss: 0.1325 - accuracy: 0.4200 - mse: 1.7154 - weighted_accuracy: 0.7201 - weighted_mse: 1.6363 - val_loss: 0.1945 - val_accuracy: 0.3567 - val_mse: 1.7456 - val_weighted_accuracy: 0.3567 - val_weighted_mse: 1.7456
# Epoch 16/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1317 - accuracy: 0.3733 - mse: 1.7798 - weighted_accuracy: 0.7191 - weighted_mse: 1.6777 - val_loss: 0.1909 - val_accuracy: 0.3678 - val_mse: 1.7345 - val_weighted_accuracy: 0.3678 - val_weighted_mse: 1.7345
# Epoch 17/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1315 - accuracy: 0.4491 - mse: 1.7432 - weighted_accuracy: 0.7329 - weighted_mse: 1.6782 - val_loss: 0.1865 - val_accuracy: 0.3978 - val_mse: 1.7641 - val_weighted_accuracy: 0.3978 - val_weighted_mse: 1.7641
# Epoch 18/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1295 - accuracy: 0.4155 - mse: 1.7708 - weighted_accuracy: 0.7324 - weighted_mse: 1.6977 - val_loss: 0.1772 - val_accuracy: 0.4456 - val_mse: 1.7410 - val_weighted_accuracy: 0.4456 - val_weighted_mse: 1.7410
# Epoch 19/20
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1317 - accuracy: 0.4466 - mse: 1.7696 - weighted_accuracy: 0.7281 - weighted_mse: 1.6956 - val_loss: 0.1901 - val_accuracy: 0.3744 - val_mse: 1.7605 - val_weighted_accuracy: 0.3744 - val_weighted_mse: 1.7605
# Epoch 20/20
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1307 - accuracy: 0.3980 - mse: 1.7896 - weighted_accuracy: 0.7281 - weighted_mse: 1.7146 - val_loss: 0.1924 - val_accuracy: 0.3878 - val_mse: 1.8275 - val_weighted_accuracy: 0.3878 - val_weighted_mse: 1.8275
# Validation loss: 0.19240190088748932
# Validation accuracy: 0.38777777552604675
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1818 - accuracy: 0.4734 - mse: 1.7715 - weighted_accuracy: 0.4734 - weighted_mse: 1.7715
# Test loss: 0.18182936310768127
# Test accuracy: 0.47342994809150696
#
#
# number of predictions: 207
# actual predicted buys: 3
# actual buys but predicted sell: 3
# actual buys but predicted hold: 1
# actual sells but predicted buy: 0
# actual predicted sells: 7
# actual sells but predicted hold: 3
# actual holds but predicted buy: 56
# actual holds but predicted sell: 46
# actual predicted holds: 88
# Percentage buys correct: 5.084745762711864%
# Percentage sells correct: 12.5%
# Percentage holds correct: 95.65217391304348%
# actual buys: 7
# actual sells: 10
# actual holds: 190
#
#
# Percentage low buys correct: 48.275862068965516%
# Percentage high sells correct: 48.214285714285715%
# Percentage mid holds correct: 89.1304347826087%
#
#
# Capital: 100
# Share price: $0.28701871713081717
# Shares owned at the moment: 347
# Cash capital at the moment: $0.13061754478435716
#
#
# Price increase from previously bought: 80.87023853584314%
# Share price: $0.5205590497723978
# Shares owned at the moment: 0
# Cash capital at the moment: $180.26786434256104
#
#
# Share price: $0.459689437854242
# Shares owned at the moment: 391
# Cash capital at the moment: $0.03501307349964122
#
#
# Price increase from previously bought: -0.4539116909342389%
# Share price: $0.45886126160165475
# Shares owned at the moment: 0
# Cash capital at the moment: $178.95637578820944
#
#
# Share price: $0.46093178121235634
# Shares owned at the moment: 387
# Cash capital at the moment: $0.08522981087227777
#
#
# Price increase from previously bought: -9.68109269433748%
# Share price: $0.41745339672312
# Shares owned at the moment: 0
# Cash capital at the moment: $161.1954195652571
#
#
# Share price: $0.45886126160165475
# Shares owned at the moment: 350
# Cash capital at the moment: $0.15232404038636105
#
#
# Price increase from previously bought: -0.004243453548402609%
# Share price: $0.4601036049597693
# Shares owned at the moment: 0
# Cash capital at the moment: $160.74573605653183
#
#
# Share price: $0.4853624278090307
# Shares owned at the moment: 330
# Cash capital at the moment: $0.1356684763149758
#
#
# Price increase from previously bought: -21.373945860413336%
# Share price: $0.3826707839068122
# Shares owned at the moment: 0
# Cash capital at the moment: $126.06975342916756
#
#
# Share price: $0.40917195011418794
# Shares owned at the moment: 307
# Cash capital at the moment: $0.10852132522795443
#
#
# Price increase from previously bought: 21.322979651336603%
# Share price: $0.4977847556808974
# Shares owned at the moment: 0
# Cash capital at the moment: $152.50818653927985
#
#
# Share price: $0.6514078964702286
# Shares owned at the moment: 233
# Cash capital at the moment: $0.31275705205328563
#
#
# Price increase from previously bought: -40.08466104579511%
# Share price: $0.3913665555797412
# Shares owned at the moment: 0
# Cash capital at the moment: $91.25039638164526
#
#
# Share price: $0.45637689080236266
# Shares owned at the moment: 199
# Cash capital at the moment: $0.18164285848349948
#
#
# Price increase from previously bought: 8.412104495159078%
# Share price: $0.4961284031757236
# Shares owned at the moment: 0
# Cash capital at the moment: $98.63968882181457
#
#
# Share price: $0.47128374743199
# Shares owned at the moment: 208
# Cash capital at the moment: $0.34309505242956106
#
#
# Price increase from previously bought: 9.8897770994534%
# Share price: $0.5193168643727519
# Shares owned at the moment: 0
# Cash capital at the moment: $108.06395359554074
#
#
# Share price: $0.46879921867422936
# Shares owned at the moment: 229
# Cash capital at the moment: $0.4137062111821166
#
#
# Price increase from previously bought: 4.041947168425941%
# Share price: $0.4890891419664376
# Shares owned at the moment: 0
# Cash capital at the moment: $112.10711583434296
#
#
# Share price: $0.4265631775431078
# Shares owned at the moment: 262
# Cash capital at the moment: $0.040224548628899015
#
#
# Price increase from previously bought: 1.177874088600217%
# Share price: $0.43277442045827574
# Shares owned at the moment: 0
# Cash capital at the moment: $113.11530873875695
#
#
# Share price: $0.4418840433197939
# Shares owned at the moment: 255
# Cash capital at the moment: $0.1250065068314825
#
#
# Price increase from previously bought: 55.6091769764441%
# Share price: $0.6895030563384155
# Shares owned at the moment: 0
# Cash capital at the moment: $175.4647718548701
#
#
# Share price: $0.9400207652203254
# Shares owned at the moment: 186
# Cash capital at the moment: $0.1400889024793628
#
#
#
#
# Capital at the end of test period: $139.40241281354213
# profit gained: 39.40241281354213%
#
#
# Capital at the end of test period if Buy and Hold: $2168.3140506383515
# profit gained: 2068.3140506383515%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0        0.47343      5.084746           12.5      95.652174
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         48.275862           48.214286          89.130435      39.402413
#
#    buy_n_hold profit
# 0        2068.314051
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1893 - accuracy: 0.3558 - mse: 1.8387 - weighted_accuracy: 0.3558 - weighted_mse: 1.8387
# Test loss: 0.18931637704372406
# Test accuracy: 0.35576921701431274
#
#
# number of predictions: 208
# actual predicted buys: 5
# actual buys but predicted sell: 1
# actual buys but predicted hold: 2
# actual sells but predicted buy: 0
# actual predicted sells: 3
# actual sells but predicted hold: 5
# actual holds but predicted buy: 51
# actual holds but predicted sell: 75
# actual predicted holds: 66
# Percentage buys correct: 8.928571428571429%
# Percentage sells correct: 3.7974683544303796%
# Percentage holds correct: 90.41095890410959%
# actual buys: 8
# actual sells: 8
# actual holds: 192
#
#
# Percentage low buys correct: 48.214285714285715%
# Percentage high sells correct: 44.87179487179487%
# Percentage mid holds correct: 87.67123287671232%
#
#
# Capital: 100
# Share price: $0.1605996887010006
# Shares owned at the moment: 620
# Cash capital at the moment: $0.15437053614441254
#
#
# Price increase from previously bought: 36.530720300142704%
# Share price: $0.219870898540667
# Shares owned at the moment: 0
# Cash capital at the moment: $136.0994477493461
#
#
# Share price: $0.18043356286033307
# Shares owned at the moment: 752
# Cash capital at the moment: $0.04027187038045099
#
#
# Price increase from previously bought: -42.46607929525901%
# Share price: $0.10409598186400025
# Shares owned at the moment: 0
# Cash capital at the moment: $78.10517974161388
#
#
# Share price: $0.1486070583863337
# Shares owned at the moment: 524
# Cash capital at the moment: $0.020938376040319895
#
#
# ...
# profit gained: 2068.3140506383515%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.782609           0.0      21.428571      91.907514
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0              50.0           64.285714           82.55814       52.86142
#
#    buy_n_hold profit
# 0        2068.314051
#
#
# Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1765 - accuracy: 0.7740 - mse: 8.2164 - weighted_accuracy: 0.7740 - weighted_mse: 8.2164
# Test loss: 0.176492378115654
# Test accuracy: 0.7740384340286255
#
#
# number of predictions: 208
# actual predicted buys: 2
# actual buys but predicted sell: 1
# actual buys but predicted hold: 5
# actual sells but predicted buy: 0
# actual predicted sells: 0
# actual sells but predicted hold: 8
# actual holds but predicted buy: 17
# actual holds but predicted sell: 16
# actual predicted holds: 159
# Percentage buys correct: 10.526315789473685%
# Percentage sells correct: 0.0%
# Percentage holds correct: 92.44186046511628%
# actual buys: 8
# actual sells: 8
# actual holds: 192
#
#
# Percentage low buys correct: 68.42105263157895%
# Percentage high sells correct: 35.294117647058826%
# Percentage mid holds correct: 86.54970760233918%
#
#
# Capital: 100
# Share price: $0.1605996887010006
# Shares owned at the moment: 620
# Cash capital at the moment: $0.15437053614441254
#
#
# Price increase from previously bought: -35.36070722149771%
# Share price: $0.10409598186400025
# Shares owned at the moment: 0
# Cash capital at the moment: $64.51639564274645
#
#
# Share price: $0.4117528076206669
# Shares owned at the moment: 156
# Cash capital at the moment: $0.10631569945314823
#
#
# Price increase from previously bought: 39.44043883553032%
# Share price: $0.5757288341490006
# Shares owned at the moment: 0
# Cash capital at the moment: $89.6730261568473
#
#
# Share price: $0.6965775796450009
# Shares owned at the moment: 128
# Cash capital at the moment: $0.2659006542521496
#
#
# Price increase from previously bought: 13.692283143869588%
# Share price: $0.7941328302906665
# Shares owned at the moment: 0
# Cash capital at the moment: $101.63536817519514
#
#
# Share price: $0.8022047507056662
# Shares owned at the moment: 126
# Cash capital at the moment: $0.27960564016169087
#
#
# Price increase from previously bought: 1.7900220459171168%
# Share price: $0.8188099446763331
# Shares owned at the moment: 0
# Cash capital at the moment: $103.16594102354931
#
#
# Share price: $0.7242527856263334
# Shares owned at the moment: 142
# Cash capital at the moment: $0.03922475182287144
#
#
# Price increase from previously bought: 2.2344931111370814%
# Share price: $0.7424723636800004
# Shares owned at the moment: 0
# Cash capital at the moment: $105.18036493636588
#
#
#
#
# Capital at the end of test period: $105.18036493636588
# profit gained: 5.180364936365876%
#
#
# Capital at the end of test period if Buy and Hold: $500.9406907154986
# profit gained: 400.9406907154986%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.774038     10.526316            0.0       92.44186
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         68.421053           35.294118          86.549708       5.180365
#
#    buy_n_hold profit
# 0         400.940691
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1723 - accuracy: 0.8502 - mse: 8.9740 - weighted_accuracy: 0.8502 - weighted_mse: 8.9740
# Test loss: 0.17232009768486023
# Test accuracy: 0.8502415418624878
#
#
# number of predictions: 207
# actual predicted buys: 4
# actual buys but predicted sell: 0
# actual buys but predicted hold: 4
# actual sells but predicted buy: 0
# actual predicted sells: 0
# actual sells but predicted hold: 10
# actual holds but predicted buy: 13
# actual holds but predicted sell: 4
# actual predicted holds: 172
# Percentage buys correct: 23.529411764705884%
# Percentage sells correct: 0.0%
# Percentage holds correct: 92.47311827956989%
# actual buys: 8
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 52.94117647058823%
# Percentage high sells correct: 25.0%
# Percentage mid holds correct: 84.86486486486487%
#
#
# Capital: 100
# Share price: $0.4743823806439853
# Shares owned at the moment: 210
# Cash capital at the moment: $0.1057442399411741
#
#
# Price increase from previously bought: 32.40929705388853%
# Share price: $0.6298537230909877
# Shares owned at the moment: 0
# Cash capital at the moment: $132.01128556396353
#
#
# Share price: $0.7425297808842741
# Shares owned at the moment: 177
# Cash capital at the moment: $0.2220879766015571
#
#
# Price increase from previously bought: 14.913334193346328%
# Share price: $0.8556122093462981
# Shares owned at the moment: 0
# Cash capital at the moment: $151.248979787997
#
#
#
#
# Capital at the end of test period: $151.248979787997
# profit gained: 51.24897978799701%
#
#
# Capital at the end of test period if Buy and Hold: $2431.2017150969914
# profit gained: 2331.2017150969914%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.782609      0.000000      21.428571      91.907514
# 1       0.850242     23.529412       0.000000      92.473118
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         50.000000           64.285714          82.558140       52.86142
# 1         52.941176           25.000000          84.864865       51.24898
#
#    buy_n_hold profit
# 0        2068.314051
# 1        2331.201715
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1947 - accuracy: 0.7981 - mse: 9.1417 - weighted_accuracy: 0.7981 - weighted_mse: 9.1417
# Test loss: 0.19471611082553864
# Test accuracy: 0.7980769276618958
#
#
# number of predictions: 208
# actual predicted buys: 2
# actual buys but predicted sell: 0
# actual buys but predicted hold: 8
# actual sells but predicted buy: 0
# actual predicted sells: 2
# actual sells but predicted hold: 6
# actual holds but predicted buy: 13
# actual holds but predicted sell: 15
# actual predicted holds: 162
# Percentage buys correct: 13.333333333333334%
# Percentage sells correct: 11.764705882352942%
# Percentage holds correct: 92.04545454545455%
# actual buys: 10
# actual sells: 8
# actual holds: 190
#
#
# Percentage low buys correct: 66.66666666666667%
# Percentage high sells correct: 64.70588235294117%
# Percentage mid holds correct: 87.42857142857143%
#
#
# Capital: 100
# Share price: $0.12394237638271631
# Shares owned at the moment: 804
# Cash capital at the moment: $0.07629279411389689
#
#
# Price increase from previously bought: 32.18065673184552%
# Share price: $0.16427837365117748
# Shares owned at the moment: 0
# Cash capital at the moment: $131.79288572551783
#
#
# Share price: $0.08688883538701019
# Shares owned at the moment: 1512
# Cash capital at the moment: $0.05568284281923752
#
#
# Price increase from previously bought: -13.683900117009395%
# Share price: $0.0752053013381535
# Shares owned at the moment: 0
# Cash capital at the moment: $113.45339482314327
#
#
# Share price: $0.21490709194095037
# Shares owned at the moment: 526
# Cash capital at the moment: $0.1014013537107985
#
#
# Price increase from previously bought: 60.83544065480959%
# Share price: $0.3465972969345489
# Shares owned at the moment: 0
# Cash capital at the moment: $181.9102265512677
#
#
# Share price: $0.31883494386533284
# Shares owned at the moment: 568
# Cash capital at the moment: $0.31395825344100103
#
#
# Price increase from previously bought: 105.52931067351795%
# Share price: $0.6571013352840765
# Shares owned at the moment: 0
# Cash capital at the moment: $372.52112440908274
#
#
# Share price: $0.6833614948281502
# Shares owned at the moment: 543
# Cash capital at the moment: $0.4354031652450203
#
#
# Price increase from previously bought: 3.290072920205911%
# Share price: $0.7077856589289763
# Shares owned at the moment: 0
# Cash capital at the moment: $383.70611502848345
#
#
# Share price: $0.735714912957245
# Shares owned at the moment: 520
# Cash capital at the moment: $0.08228796518721992
#
#
# Price increase from previously bought: 29.273036307525736%
# Share price: $0.9536964793151054
# Shares owned at the moment: 0
# Cash capital at the moment: $494.6406712436214
#
#
# Share price: $0.8911615933217883
# Shares owned at the moment: 553
# Cash capital at the moment: $0.47307614362830464
#
#
# Price increase from previously bought: 5.758708036567217%
# Share price: $0.9450728103311524
# Shares owned at the moment: 0
# Cash capital at the moment: $521.6611207804444
#
#
#
#
# Capital at the end of test period: $521.6611207804444
# profit gained: 421.66112078044443%
#
#
# Capital at the end of test period if Buy and Hold: $704.110752699704
# profit gained: 604.110752699704%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.774038     10.526316       0.000000      92.441860
# 1       0.798077     13.333333      11.764706      92.045455
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         68.421053           35.294118          86.549708       5.180365
# 1         66.666667           64.705882          87.428571     421.661121
#
#    buy_n_hold profit
# 0         400.940691
# 1         604.110753
#
#
# Non-Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1501 - accuracy: 0.8019 - mse: 8.3581 - weighted_accuracy: 0.8019 - weighted_mse: 8.3581
# Test loss: 0.15011785924434662
# Test accuracy: 0.8019323945045471
#
#
# number of predictions: 207
# actual predicted buys: 4
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 0
# actual predicted sells: 4
# actual sells but predicted hold: 7
# actual holds but predicted buy: 16
# actual holds but predicted sell: 11
# actual predicted holds: 158
# Percentage buys correct: 20.0%
# Percentage sells correct: 26.666666666666668%
# Percentage holds correct: 91.86046511627907%
# actual buys: 11
# actual sells: 11
# actual holds: 185
#
#
# Percentage low buys correct: 60.0%
# Percentage high sells correct: 73.33333333333333%
# Percentage mid holds correct: 87.71929824561404%
#
#
# Capital: 100
# Share price: $0.021217156310856737
# Shares owned at the moment: 4700
# Cash capital at the moment: $0.005133593655514801
#
#
# Price increase from previously bought: 579.0405897142386%
# Share price: $0.14446930436800143
# Shares owned at the moment: 0
# Cash capital at the moment: $677.1435983643057
#
#
# Share price: $0.043592989289191746
# Shares owned at the moment: 15490
# Cash capital at the moment: $0.031241913479220784
#
#
# Price increase from previously bought: 856.9171628347334%
# Share price: $0.41829595549081056
# Shares owned at the moment: 0
# Cash capital at the moment: $6461.617230502114
#
#
# Share price: $0.30474191934944006
# Shares owned at the moment: 21145
# Cash capital at the moment: $0.12898417543237883
#
#
# Price increase from previously bought: 73.33233886059031%
# Share price: $0.5296688911118552
# Shares owned at the moment: 0
# Cash capital at the moment: $11169.17810280357
#
#
# Share price: $0.5277020970895205
# Shares owned at the moment: 21107
# Cash capital at the moment: $0.3398670860715356
#
#
# Price increase from previously bought: -3.8367536609238972%
# Share price: $0.5088509700964581
# Shares owned at the moment: 0
# Cash capital at the moment: $10711.12141999099
#
#
# Share price: $0.4502141923913705
# Shares owned at the moment: 23725
# Cash capital at the moment: $0.4160432908902294
#
#
# Price increase from previously bought: 85.43853665943126%
# Share price: $0.837166504381694
# Shares owned at the moment: 0
# Cash capital at the moment: $19807.57147762633
#
#
# Share price: $0.8802044315208128
# Shares owned at the moment: 22441
# Cash capital at the moment: $0.5839938364333648
#
#
# Price increase from previously bought: 2.194724561659922%
# Share price: $0.901996181231743
# Shares owned at the moment: 0
# Cash capital at the moment: $20186.61563202467
#
#
# Share price: $0.924702923411636
# Shares owned at the moment: 21770
# Cash capital at the moment: $0.4733370860085415
#
#
# Price increase from previously bought: -6.837431222003465%
# Share price: $0.8638460587573027
# Shares owned at the moment: 0
# Cash capital at the moment: $18754.685732309834
#
#
#
#
# Capital at the end of test period: $18754.685732309834
# profit gained: 18654.685732309834%
#
#
# Capital at the end of test period if Buy and Hold: $1766.892280786996
# profit gained: 1666.8922807869963%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.782609      0.000000      21.428571      91.907514
# 1       0.850242     23.529412       0.000000      92.473118
# 2       0.801932     20.000000      26.666667      91.860465
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         50.000000           64.285714          82.558140      52.861420
# 1         52.941176           25.000000          84.864865      51.248980
# 2         60.000000           73.333333          87.719298   18654.685732
#
#    buy_n_hold profit
# 0        2068.314051
# 1        2331.201715
# 2        1666.892281
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1644 - accuracy: 0.7788 - mse: 8.7352 - weighted_accuracy: 0.7788 - weighted_mse: 8.7352
# Test loss: 0.1643974632024765
# Test accuracy: 0.7788461446762085
#
#
# number of predictions: 208
# actual predicted buys: 2
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 2
# actual predicted sells: 0
# actual sells but predicted hold: 8
# actual holds but predicted buy: 18
# actual holds but predicted sell: 11
# actual predicted holds: 160
# Percentage buys correct: 9.090909090909092%
# Percentage sells correct: 0.0%
# Percentage holds correct: 91.42857142857143%
# actual buys: 9
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 59.09090909090909%
# Percentage high sells correct: 54.54545454545455%
# Percentage mid holds correct: 85.63218390804597%
#
#
# Capital: 100
# Share price: $0.09936061724328947
# Shares owned at the moment: 1003
# Cash capital at the moment: $0.06723948246934697
#
#
# Price increase from previously bought: -10.40888729821411%
# Share price: $0.08926308285270855
# Shares owned at the moment: 0
# Cash capital at the moment: $89.35190168545755
#
#
# Share price: $0.14225839692288078
# Shares owned at the moment: 626
# Cash capital at the moment: $0.05324738143143293
#
#
# Price increase from previously bought: 93.48945274560873%
# Share price: $0.2760119449234075
# Shares owned at the moment: 0
# Cash capital at the moment: $172.3615703402989
#
#
# Share price: $0.3745731463004627
# Shares owned at the moment: 458
# Cash capital at the moment: $0.33529445692155946
#
#
# Price increase from previously bought: 38.56333953513871%
# Share price: $0.5204483684321803
# Shares owned at the moment: 0
# Cash capital at the moment: $238.04514247881983
#
#
# Share price: $0.8466781196643112
# Shares owned at the moment: 280
# Cash capital at the moment: $0.3233268206711841
#
#
# Price increase from previously bought: -0.05751146654311423%
# Share price: $0.8485182084131098
# Shares owned at the moment: 0
# Cash capital at the moment: $237.25506615586383
#
#
# Share price: $0.7621247290126416
# Shares owned at the moment: 310
# Cash capital at the moment: $0.3466888304616589
#
#
# Price increase from previously bought: 13.122347536565492%
# Share price: $0.864504251423482
# Shares owned at the moment: 0
# Cash capital at the moment: $267.6060168974026
#
#
# Share price: $0.8579832868783575
# Shares owned at the moment: 311
# Cash capital at the moment: $0.03942447213069045
#
#
#
#
# Capital at the end of test period: $305.07820210794665
# profit gained: 205.07820210794665%
#
#
# Capital at the end of test period if Buy and Hold: $778.7940878989605
# profit gained: 678.7940878989605%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.774038     10.526316       0.000000      92.441860
# 1       0.798077     13.333333      11.764706      92.045455
# 2       0.778846      9.090909       0.000000      91.428571
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         68.421053           35.294118          86.549708       5.180365
# 1         66.666667           64.705882          87.428571     421.661121
# 2         59.090909           54.545455          85.632184     205.078202
#
#    buy_n_hold profit
# 0         400.940691
# 1         604.110753
# 2         678.794088

# %%
Sichuan_Swellfun_data_acc = []
Wuliangye_Yibin_data_acc = []
Kweichow_Moutai_data_acc = []

Sichuan_Swellfun_data_correct_buys = []
Wuliangye_Yibin_data_correct_buys = []
Kweichow_Moutai_data_correct_buys = []

Sichuan_Swellfun_data_correct_sells = []
Wuliangye_Yibin_data_correct_sells = []
Kweichow_Moutai_data_correct_sells = []

Sichuan_Swellfun_data_correct_holds = []
Wuliangye_Yibin_data_correct_holds = []
Kweichow_Moutai_data_correct_holds = []

Sichuan_Swellfun_data_correct_low_buys = []
Wuliangye_Yibin_data_correct_low_buys = []
Kweichow_Moutai_data_correct_low_buys = []

Sichuan_Swellfun_data_correct_high_sells = []
Wuliangye_Yibin_data_correct_high_sells = []
Kweichow_Moutai_data_correct_high_sells = []

Sichuan_Swellfun_data_correct_mid_holds = []
Wuliangye_Yibin_data_correct_mid_holds = []
Kweichow_Moutai_data_correct_mid_holds = []

Sichuan_Swellfun_data_profit = []
Wuliangye_Yibin_data_profit = []
Kweichow_Moutai_data_profit = []

for key,value in nr_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    Sichuan_Swellfun_data_acc.append(acc[0])
    Wuliangye_Yibin_data_acc.append(acc[1])
    Kweichow_Moutai_data_acc.append(acc[2])
    
    Sichuan_Swellfun_data_correct_buys.append(correct_buys[0])
    Wuliangye_Yibin_data_correct_buys.append(correct_buys[1]) 
    Kweichow_Moutai_data_correct_buys.append(correct_buys[2]) 

    Sichuan_Swellfun_data_correct_sells.append(correct_sells[0]) 
    Wuliangye_Yibin_data_correct_sells.append(correct_sells[1]) 
    Kweichow_Moutai_data_correct_sells.append(correct_sells[2]) 

    Sichuan_Swellfun_data_correct_holds.append(correct_holds[0]) 
    Wuliangye_Yibin_data_correct_holds.append(correct_holds[1])  
    Kweichow_Moutai_data_correct_holds.append(correct_holds[2])  

    Sichuan_Swellfun_data_correct_low_buys.append(correct_low_buys[0])  
    Wuliangye_Yibin_data_correct_low_buys.append(correct_low_buys[1])  
    Kweichow_Moutai_data_correct_low_buys.append(correct_low_buys[2])  

    Sichuan_Swellfun_data_correct_high_sells.append(correct_high_sells[0]) 
    Wuliangye_Yibin_data_correct_high_sells.append(correct_high_sells[1]) 
    Kweichow_Moutai_data_correct_high_sells.append(correct_high_sells[2]) 

    Sichuan_Swellfun_data_correct_mid_holds.append(correct_mid_holds[0])  
    Wuliangye_Yibin_data_correct_mid_holds.append(correct_mid_holds[1])  
    Kweichow_Moutai_data_correct_mid_holds.append(correct_mid_holds[2])   

    Sichuan_Swellfun_data_profit.append(profit[0]) 
    Wuliangye_Yibin_data_profit.append(profit[1]) 
    Kweichow_Moutai_data_profit.append(profit[2])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(Sichuan_Swellfun_data_acc)
plt.plot(Wuliangye_Yibin_data_acc)
plt.plot(Kweichow_Moutai_data_acc)

plt.title('Non-Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Sichuan_Swellfun_data_acc','Wuliangye_Yibin_data_acc','Kweichow_Moutai_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_profit")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_profit")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_profit")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_profit')

# %%
Sichuan_Swellfun_data_acc = []
Wuliangye_Yibin_data_acc = []
Kweichow_Moutai_data_acc = []

Sichuan_Swellfun_data_correct_buys = []
Wuliangye_Yibin_data_correct_buys = []
Kweichow_Moutai_data_correct_buys = []

Sichuan_Swellfun_data_correct_sells = []
Wuliangye_Yibin_data_correct_sells = []
Kweichow_Moutai_data_correct_sells = []

Sichuan_Swellfun_data_correct_holds = []
Wuliangye_Yibin_data_correct_holds = []
Kweichow_Moutai_data_correct_holds = []

Sichuan_Swellfun_data_correct_low_buys = []
Wuliangye_Yibin_data_correct_low_buys = []
Kweichow_Moutai_data_correct_low_buys = []

Sichuan_Swellfun_data_correct_high_sells = []
Wuliangye_Yibin_data_correct_high_sells = []
Kweichow_Moutai_data_correct_high_sells = []

Sichuan_Swellfun_data_correct_mid_holds = []
Wuliangye_Yibin_data_correct_mid_holds = []
Kweichow_Moutai_data_correct_mid_holds = []

Sichuan_Swellfun_data_profit = []
Wuliangye_Yibin_data_profit = []
Kweichow_Moutai_data_profit = []

for key,value in r_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    Sichuan_Swellfun_data_acc.append(acc[0])
    Wuliangye_Yibin_data_acc.append(acc[1])
    Kweichow_Moutai_data_acc.append(acc[2])
    
    Sichuan_Swellfun_data_correct_buys.append(correct_buys[0])
    Wuliangye_Yibin_data_correct_buys.append(correct_buys[1]) 
    Kweichow_Moutai_data_correct_buys.append(correct_buys[2]) 

    Sichuan_Swellfun_data_correct_sells.append(correct_sells[0]) 
    Wuliangye_Yibin_data_correct_sells.append(correct_sells[1]) 
    Kweichow_Moutai_data_correct_sells.append(correct_sells[2]) 

    Sichuan_Swellfun_data_correct_holds.append(correct_holds[0]) 
    Wuliangye_Yibin_data_correct_holds.append(correct_holds[1])  
    Kweichow_Moutai_data_correct_holds.append(correct_holds[2])  

    Sichuan_Swellfun_data_correct_low_buys.append(correct_low_buys[0])  
    Wuliangye_Yibin_data_correct_low_buys.append(correct_low_buys[1])  
    Kweichow_Moutai_data_correct_low_buys.append(correct_low_buys[2])  

    Sichuan_Swellfun_data_correct_high_sells.append(correct_high_sells[0]) 
    Wuliangye_Yibin_data_correct_high_sells.append(correct_high_sells[1]) 
    Kweichow_Moutai_data_correct_high_sells.append(correct_high_sells[2]) 

    Sichuan_Swellfun_data_correct_mid_holds.append(correct_mid_holds[0])  
    Wuliangye_Yibin_data_correct_mid_holds.append(correct_mid_holds[1])  
    Kweichow_Moutai_data_correct_mid_holds.append(correct_mid_holds[2])   

    Sichuan_Swellfun_data_profit.append(profit[0]) 
    Wuliangye_Yibin_data_profit.append(profit[1]) 
    Kweichow_Moutai_data_profit.append(profit[2])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(Sichuan_Swellfun_data_acc)
plt.plot(Wuliangye_Yibin_data_acc)
plt.plot(Kweichow_Moutai_data_acc)

plt.title('Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Sichuan_Swellfun_data_acc','Wuliangye_Yibin_data_acc','Kweichow_Moutai_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_profit")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_profit")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_profit")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_profit')

# %% [markdown]
# ## Kweichow Moutai Co., Ltd Stock Data

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []

seed = 10
df = pd.read_csv('variation 7/initial_indicators/600519.SS_data.csv')
df.set_index('Date', inplace=True)
print(df.head())

plt.figure(figsize=(15,5))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
plt.show()

labels = []
data_15 = []
sequential = []
count = 0

for i in df.values:
    if count == 14:
        data_15.append(np.array(i[0:-1]))
        labels.append(i[-1])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_arr = min_max_scaler.fit_transform(data_15)
        sequential.append(data_15_arr)
        data_15 = data_15[1:15]
    else:
        data_15.append(np.array(i[0:-1]))
        count+= 1
    
X = sequential
X  = np.array(X).reshape(-1, 15, 4)
y = labels
y = np.array(y)

X.shape
# Out:
#             previous_1d    EMA_12   willr_14        OBV_7  labels
# Date
# 2001-09-14     7.142585  7.257483 -41.873824  204624213.0     2.0
# 2001-09-17     7.224180  7.252359 -51.296847  208479649.0     2.0
# 2001-09-18     7.132634  7.233940 -72.964156  203965392.0     2.0
# 2001-09-19     7.214230  7.230908 -59.609037  209378730.0     2.0
# 2001-09-20     7.347568  7.248855 -37.785092  213725440.0     2.0
# (4106, 15, 4)

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization,Activation
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(LSTM(100, input_shape=(X_train.shape[1:]), return_sequences=True,kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(LSTM(100, kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# model.add(Dense(100, kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))

model.add(Dense(75, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(50, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "DBS_CNN_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))
print(d_class_weights)

epochs = 0 
histories = {}
nr_log_hist = {}
r_log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    nr_log  = pd.DataFrame(columns = column_names)
    r_log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['600779.SS','000858.SZ','600519.SS']
    for name in test_sets:
        
        print('\n')
        print("Non-Recession")
        print('\n')
        
        X = nr_test_data['{}_X'.format(name)]
        y = nr_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("variation 7/initial_indicators/{}_data_test.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(nr_log)
        nr_log.loc[df_length] = logger
        print(nr_log.head(20))
        logger = []
        
        print('\n')
        print("Recession")
        print('\n')
        
        X = r_test_data['{}_X'.format(name)]
        y = r_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("variation 7/initial_indicators/{}_data_test2.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(r_log)
        r_log.loc[df_length] = logger
        print(r_log.head(20))
        logger = []

    nr_log.to_csv('{}_{}_{}epochs.csv'.format(experiment,'MoutaiModel',epochs))
    nr_log_hist['{}_epochs_logs'.format(epochs)] = nr_log
    r_log.to_csv('{}_{}_{}epochs.csv'.format(experiment,'MoutaiModel',epochs))
    r_log_hist['{}_epochs_logs'.format(epochs)] = r_log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 2 ... 2 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# {0: 7.396396396396397, 1: 7.497716894977169, 2: 0.3661092530657748}
#
#
#
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  2/26 [=>............................] - ETA: 28s - loss: 0.3680 - accuracy: 0.5391 - mse: 0.3275 - weighted_accuracy: 0.2916 - weighted_mse: 0.4245WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0110s vs `on_train_batch_end` time: 2.3936s). Check your callbacks.
# 26/26 [==============================] - 4s 138ms/step - loss: 0.3042 - accuracy: 0.5250 - mse: 0.4305 - weighted_accuracy: 0.3198 - weighted_mse: 0.5168 - val_loss: 0.3008 - val_accuracy: 0.0426 - val_mse: 0.3515 - val_weighted_accuracy: 0.0426 - val_weighted_mse: 0.3515
# Epoch 2/20
# 26/26 [==============================] - 0s 11ms/step - loss: 0.2189 - accuracy: 0.4190 - mse: 0.6850 - weighted_accuracy: 0.4296 - weighted_mse: 0.6941 - val_loss: 0.2939 - val_accuracy: 0.0450 - val_mse: 0.3760 - val_weighted_accuracy: 0.0450 - val_weighted_mse: 0.3760
# Epoch 3/20
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1929 - accuracy: 0.3161 - mse: 0.9368 - weighted_accuracy: 0.4802 - weighted_mse: 0.9091 - val_loss: 0.2845 - val_accuracy: 0.0450 - val_mse: 0.4108 - val_weighted_accuracy: 0.0450 - val_weighted_mse: 0.4108
# Epoch 4/20
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1821 - accuracy: 0.2850 - mse: 1.1040 - weighted_accuracy: 0.5250 - weighted_mse: 1.0679 - val_loss: 0.2745 - val_accuracy: 0.0450 - val_mse: 0.4497 - val_weighted_accuracy: 0.0450 - val_weighted_mse: 0.4497
# Epoch 5/20
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1770 - accuracy: 0.2777 - mse: 1.2133 - weighted_accuracy: 0.5244 - weighted_mse: 1.1731 - val_loss: 0.2653 - val_accuracy: 0.0450 - val_mse: 0.4923 - val_weighted_accuracy: 0.0450 - val_weighted_mse: 0.4923
# Epoch 6/20
# 26/26 [==============================] - 0s 9ms/step - loss: 0.1732 - accuracy: 0.2951 - mse: 1.2640 - weighted_accuracy: 0.5741 - weighted_mse: 1.2187 - val_loss: 0.2575 - val_accuracy: 0.0450 - val_mse: 0.5384 - val_weighted_accuracy: 0.0450 - val_weighted_mse: 0.5384
# Epoch 7/20
# 26/26 [==============================] - 0s 9ms/step - loss: 0.1704 - accuracy: 0.3258 - mse: 1.2828 - weighted_accuracy: 0.5960 - weighted_mse: 1.2351 - val_loss: 0.2500 - val_accuracy: 0.0450 - val_mse: 0.5911 - val_weighted_accuracy: 0.0450 - val_weighted_mse: 0.5911
# Epoch 8/20
# 26/26 [==============================] - 0s 9ms/step - loss: 0.1670 - accuracy: 0.2777 - mse: 1.3119 - weighted_accuracy: 0.6065 - weighted_mse: 1.2454 - val_loss: 0.2434 - val_accuracy: 0.0450 - val_mse: 0.6529 - val_weighted_accuracy: 0.0450 - val_weighted_mse: 0.6529
# Epoch 9/20
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1640 - accuracy: 0.3143 - mse: 1.3345 - weighted_accuracy: 0.6329 - weighted_mse: 1.2700 - val_loss: 0.2369 - val_accuracy: 0.0450 - val_mse: 0.7156 - val_weighted_accuracy: 0.0450 - val_weighted_mse: 0.7156
# Epoch 10/20
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1619 - accuracy: 0.2948 - mse: 1.3632 - weighted_accuracy: 0.6299 - weighted_mse: 1.2888 - val_loss: 0.2305 - val_accuracy: 0.0450 - val_mse: 0.7888 - val_weighted_accuracy: 0.0450 - val_weighted_mse: 0.7888
# Epoch 11/20
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1603 - accuracy: 0.2984 - mse: 1.3820 - weighted_accuracy: 0.6333 - weighted_mse: 1.2970 - val_loss: 0.2221 - val_accuracy: 0.0450 - val_mse: 0.8643 - val_weighted_accuracy: 0.0450 - val_weighted_mse: 0.8643
# Epoch 12/20
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1581 - accuracy: 0.3310 - mse: 1.3839 - weighted_accuracy: 0.6562 - weighted_mse: 1.3068 - val_loss: 0.2218 - val_accuracy: 0.0450 - val_mse: 0.9463 - val_weighted_accuracy: 0.0450 - val_weighted_mse: 0.9463
# Epoch 13/20
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1560 - accuracy: 0.3362 - mse: 1.3995 - weighted_accuracy: 0.6473 - weighted_mse: 1.3248 - val_loss: 0.2174 - val_accuracy: 0.0462 - val_mse: 1.0231 - val_weighted_accuracy: 0.0462 - val_weighted_mse: 1.0231
# Epoch 14/20
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1546 - accuracy: 0.3054 - mse: 1.4267 - weighted_accuracy: 0.6532 - weighted_mse: 1.3384 - val_loss: 0.2163 - val_accuracy: 0.0487 - val_mse: 1.1049 - val_weighted_accuracy: 0.0487 - val_weighted_mse: 1.1049
# Epoch 15/20
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1517 - accuracy: 0.3176 - mse: 1.4465 - weighted_accuracy: 0.6620 - weighted_mse: 1.3539 - val_loss: 0.2102 - val_accuracy: 0.0693 - val_mse: 1.1988 - val_weighted_accuracy: 0.0693 - val_weighted_mse: 1.1988
# Epoch 16/20
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1506 - accuracy: 0.3337 - mse: 1.4645 - weighted_accuracy: 0.6614 - weighted_mse: 1.3789 - val_loss: 0.2044 - val_accuracy: 0.1545 - val_mse: 1.2449 - val_weighted_accuracy: 0.1545 - val_weighted_mse: 1.2449
# Epoch 17/20
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1494 - accuracy: 0.3611 - mse: 1.4724 - weighted_accuracy: 0.6715 - weighted_mse: 1.3908 - val_loss: 0.2007 - val_accuracy: 0.3163 - val_mse: 1.2856 - val_weighted_accuracy: 0.3163 - val_weighted_mse: 1.2856
# Epoch 18/20
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1485 - accuracy: 0.3383 - mse: 1.4993 - weighted_accuracy: 0.6631 - weighted_mse: 1.3997 - val_loss: 0.2013 - val_accuracy: 0.3212 - val_mse: 1.3298 - val_weighted_accuracy: 0.3212 - val_weighted_mse: 1.3298
# Epoch 19/20
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1467 - accuracy: 0.3511 - mse: 1.5255 - weighted_accuracy: 0.6785 - weighted_mse: 1.4347 - val_loss: 0.1996 - val_accuracy: 0.3443 - val_mse: 1.3532 - val_weighted_accuracy: 0.3443 - val_weighted_mse: 1.3532
# Epoch 20/20
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1448 - accuracy: 0.3675 - mse: 1.5306 - weighted_accuracy: 0.6846 - weighted_mse: 1.4502 - val_loss: 0.1948 - val_accuracy: 0.3528 - val_mse: 1.3681 - val_weighted_accuracy: 0.3528 - val_weighted_mse: 1.3681
# Validation loss: 0.19478699564933777
# Validation accuracy: 0.3527980446815491
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1907 - accuracy: 0.2802 - mse: 1.3109 - weighted_accuracy: 0.2802 - weighted_mse: 1.3109
# Test loss: 0.19071505963802338
# Test accuracy: 0.2801932394504547
#
#
# number of predictions: 207
# actual predicted buys: 6
# actual buys but predicted sell: 0
# actual buys but predicted hold: 1
# actual sells but predicted buy: 4
# actual predicted sells: 2
# actual sells but predicted hold: 4
# actual holds but predicted buy: 115
# actual holds but predicted sell: 25
# actual predicted holds: 50
# Percentage buys correct: 4.8%
# Percentage sells correct: 7.407407407407407%
# Percentage holds correct: 90.9090909090909%
# actual buys: 7
# actual sells: 10
# actual holds: 190
#
#
# Percentage low buys correct: 43.54838709677419%
# Percentage high sells correct: 29.62962962962963%
# Percentage mid holds correct: 83.63636363636364%
#
#
# Capital: 100
# Share price: $0.24146997098934775
# Shares owned at the moment: 412
# Cash capital at the moment: $0.24078647525779218
#
#
# Price increase from previously bought: 22.98342075295654%
# Share price: $0.29778469249750983
# Shares owned at the moment: 0
# Cash capital at the moment: $122.59068972763215
#
#
# Share price: $0.26879915549084177
# Shares owned at the moment: 454
# Cash capital at the moment: $0.22027738915967632
#
#
# Price increase from previously bought: 119.553403422469%
# Share price: $0.5917806279101878
# Shares owned at the moment: 0
# Cash capital at the moment: $268.14984434643907
#
#
# Share price: $0.5222154022775713
# Shares owned at the moment: 512
# Cash capital at the moment: $0.04027909391572848
#
#
# Price increase from previously bought: 4.312102107275084%
# Share price: $0.5462318817687177
# Shares owned at the moment: 0
# Cash capital at the moment: $278.94190806996886
#
#
# Share price: $0.6514078964702286
# Shares owned at the moment: 427
# Cash capital at the moment: $0.025820554751135205
#
#
# Price increase from previously bought: -26.138353876919464%
# Share price: $0.4824637319457419
# Shares owned at the moment: 0
# Cash capital at the moment: $205.47130105834563
#
#
# Share price: $0.47583847988351513
# Shares owned at the moment: 430
# Cash capital at the moment: $0.2980757059718542
#
#
# Price increase from previously bought: 63.25034797045574%
# Share price: $0.7789441961161803
# Shares owned at the moment: 0
# Cash capital at the moment: $334.322978524022
#
#
# Share price: $0.9640372447114718
# Shares owned at the moment: 345
# Cash capital at the moment: $0.8154987626442107
#
#
#
#
# Capital at the end of test period: $259.1246479525186
# profit gained: 159.12464795251861%
#
#
# Capital at the end of test period if Buy and Hold: $2168.3140506383515
# profit gained: 2068.3140506383515%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.280193           4.8       7.407407      90.909091
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.548387            29.62963          83.636364     159.124648
#
#    buy_n_hold profit
# 0        2068.314051
#
#
# Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1879 - accuracy: 0.4856 - mse: 1.2763 - weighted_accuracy: 0.4856 - weighted_mse: 1.2763
# Test loss: 0.18788209557533264
# Test accuracy: 0.48557692766189575
#
#
# number of predictions: 208
# actual predicted buys: 6
# actual buys but predicted sell: 0
# actual buys but predicted hold: 2
# actual sells but predicted buy: 1
# actual predicted sells: 2
# actual sells but predicted hold: 5
# actual holds but predicted buy: 83
# actual holds but predicted sell: 16
# actual predicted holds: 93
# Percentage buys correct: 6.666666666666667%
# Percentage sells correct: 11.11111111111111%
# Percentage holds correct: 93.0%
# actual buys: 8
# actual sells: 8
# actual holds: 192
#
#
# Percentage low buys correct: 43.333333333333336%
# Percentage high sells correct: 44.44444444444444%
# Percentage mid holds correct: 86.86868686868686%
#
#
# Capital: 100
# Share price: $0.1797417091039999
# Shares owned at the moment: 554
# Cash capital at the moment: $0.14925666256411318
#
#
# Price increase from previously bought: -36.10261955647602%
# Share price: $0.11516608185200015
# Shares owned at the moment: 0
# Cash capital at the moment: $63.775810482870675
#
#
# Share price: $0.13615316290833346
# Shares owned at the moment: 467
# Cash capital at the moment: $0.01742870521392348
#
#
# Price increase from previously bought: 51.07854247413957%
# Share price: $0.20626388414300045
# Shares owned at the moment: 0
# Cash capital at the moment: $96.07776820678447
#
#
# Share price: $0.2719926303146667
# Shares owned at the moment: 352
# Cash capital at the moment: $0.07307346987718688
#
#
# Price increase from previously bought: 151.93233073786055%
# Share price: $0.6871217757626666
# Shares owned at the moment: 0
# Cash capital at the moment: $241.27480465939757
#
#
# Share price: $0.6864299220063337
# Shares owned at the moment: 350
# Cash capital at the moment: $0.363643157249669
#
#
# Price increase from previously bought: 1.4345644183121786%
# Share price: $0.6981919637280007
# Shares owned at the moment: 0
# Cash capital at the moment: $244.05882069696173
#
#
# Share price: $0.7941328302906665
# Shares owned at the moment: 306
# Cash capital at the moment: $0.3859118513281885
#
#
# Price increase from previously bought: 14.583149446171806%
# Share price: $0.9124447493543344
# Shares owned at the moment: 0
# Cash capital at the moment: $278.8261828971729
#
#
#
#
# Capital at the end of test period: $278.8261828971729
# profit gained: 178.82618289717288%
#
#
# Capital at the end of test period if Buy and Hold: $500.9406907154986
# profit gained: 400.9406907154986%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.485577      6.666667      11.111111           93.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.333333           44.444444          86.868687     178.826183
#
#    buy_n_hold profit
# 0         400.940691
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1937 - accuracy: 0.3140 - mse: 1.3187 - weighted_accuracy: 0.3140 - weighted_mse: 1.3187
# Test loss: 0.1936662495136261
# Test accuracy: 0.3140096664428711
#
#
# number of predictions: 207
# actual predicted buys: 7
# actual buys but predicted sell: 0
# actual buys but predicted hold: 1
# actual sells but predicted buy: 4
# actual predicted sells: 0
# actual sells but predicted hold: 6
# actual holds but predicted buy: 109
# actual holds but predicted sell: 22
# actual predicted holds: 58
# Percentage buys correct: 5.833333333333333%
# Percentage sells correct: 0.0%
# Percentage holds correct: 89.23076923076923%
# actual buys: 8
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 46.21848739495798%
# Percentage high sells correct: 50.0%
# Percentage mid holds correct: 81.53846153846153%
#
#
# Capital: 100
# Share price: $0.03722094537543363
# Shares owned at the moment: 2679
# Cash capital at the moment: $0.010871329396152873
#
#
# Price increase from previously bought: 579.924620956508%
# Share price: $0.2537703262826869
# Shares owned at the moment: 0
# Cash capital at the moment: $677.9919860044083
#
#
# Share price: $0.4508179447005256
# Shares owned at the moment: 1499
# Cash capital at the moment: $0.3575026257785794
#
#
# Price increase from previously bought: 39.3303844582898%
# Share price: $0.6298537230909877
# Shares owned at the moment: 0
# Cash capital at the moment: $941.9118190291573
#
#
# Share price: $0.7609479915803883
# Shares owned at the moment: 1234
# Cash capital at the moment: $0.31972040953007763
#
#
# Price increase from previously bought: 7.535079493377728%
# Share price: $0.8205363142252673
# Shares owned at the moment: 0
# Cash capital at the moment: $1010.0770421811864
#
#
# Share price: $0.8389544215980482
# Shares owned at the moment: 1200
# Cash capital at the moment: $0.5631866722549148
#
#
# Price increase from previously bought: 6.873358526573314%
# Share price: $0.8990844684779113
# Shares owned at the moment: 0
# Cash capital at the moment: $1076.4975700997716
#
#
# Share price: $0.8896045526740286
# Shares owned at the moment: 1206
# Cash capital at the moment: $0.6841060759495576
#
#
# Price increase from previously bought: -5.041279607229299%
# Share price: $0.8470801817994709
# Shares owned at the moment: 0
# Cash capital at the moment: $1019.4534639031734
#
#
#
#
# Capital at the end of test period: $1019.4534639031734
# profit gained: 919.4534639031735%
#
#
# Capital at the end of test period if Buy and Hold: $2431.2017150969914
# profit gained: 2331.2017150969914%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.280193      4.800000       7.407407      90.909091
# 1       0.314010      5.833333       0.000000      89.230769
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.548387            29.62963          83.636364     159.124648
# 1         46.218487            50.00000          81.538462     919.453464
#
#    buy_n_hold profit
# 0        2068.314051
# 1        2331.201715
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1810 - accuracy: 0.5096 - mse: 1.2539 - weighted_accuracy: 0.5096 - weighted_mse: 1.2539
# Test loss: 0.18102627992630005
# Test accuracy: 0.5096153616905212
#
#
# number of predictions: 208
# actual predicted buys: 8
# actual buys but predicted sell: 1
# actual buys but predicted hold: 1
# actual sells but predicted buy: 3
# actual predicted sells: 3
# actual sells but predicted hold: 2
# actual holds but predicted buy: 72
# actual holds but predicted sell: 23
# actual predicted holds: 95
# Percentage buys correct: 9.63855421686747%
# Percentage sells correct: 11.11111111111111%
# Percentage holds correct: 96.93877551020408%
# actual buys: 10
# actual sells: 8
# actual holds: 190
#
#
# Percentage low buys correct: 48.19277108433735%
# Percentage high sells correct: 50.0%
# Percentage mid holds correct: 91.83673469387755%
#
#
# Capital: 100
# Share price: $0.14258040003765882
# Shares owned at the moment: 699
# Cash capital at the moment: $0.0622251997041019
#
#
# Price increase from previously bought: -33.27309346166775%
# Share price: $0.0954011238733654
# Shares owned at the moment: 0
# Cash capital at the moment: $66.56422597682094
#
#
# Share price: $0.16622566469835032
# Shares owned at the moment: 399
# Cash capital at the moment: $0.05779465158887831
#
#
# Price increase from previously bought: 70.42101580201022%
# Share price: $0.28406249583490417
# Shares owned at the moment: 0
# Cash capital at the moment: $113.0870429161608
#
#
# Share price: $0.2595827263789513
# Shares owned at the moment: 434
# Cash capital at the moment: $0.11832768376264369
#
#
# Price increase from previously bought: 33.15476462677742%
# Share price: $0.3465972969345489
# Shares owned at the moment: 0
# Cash capital at the moment: $150.12789067946545
#
#
# Share price: $0.31883494386533284
# Shares owned at the moment: 469
# Cash capital at the moment: $0.18308463777404427
#
#
# Price increase from previously bought: 78.57378477472344%
# Share price: $0.5709213544174127
# Shares owned at the moment: 0
# Cash capital at the moment: $267.20885404268074
#
#
# Share price: $0.5852754311516141
# Shares owned at the moment: 455
# Cash capital at the moment: $0.1762069854678998
#
#
# Price increase from previously bought: 4.892279283439516%
# Share price: $0.6155969888554133
# Shares owned at the moment: 0
# Cash capital at the moment: $279.50257118237556
#
#
# Share price: $0.5875008338680928
# Shares owned at the moment: 474
# Cash capital at the moment: $0.2613685919524755
#
#
# Price increase from previously bought: 32.326304558418116%
# Share price: $0.7795560425999842
# Shares owned at the moment: 0
# Cash capital at the moment: $368.75478148281593
#
#
# Share price: $0.6762401042630121
# Shares owned at the moment: 543
# Cash capital at the moment: $0.5466093323096288
#
#
# Price increase from previously bought: 16.422283309855533%
# Share price: $0.7894592290075563
# Shares owned at the moment: 0
# Cash capital at the moment: $428.04411068969716
#
#
# Share price: $0.7438377941703685
# Shares owned at the moment: 573
# Cash capital at the moment: $0.6529522259120313
#
#
# Price increase from previously bought: 25.70566432819095%
# Share price: $0.93761761784791
# Shares owned at the moment: 0
# Cash capital at the moment: $536.4303962914406
#
#
# Share price: $0.914250634643868
# Shares owned at the moment: 585
# Cash capital at the moment: $0.12297431629451694
#
#
#
#
# Capital at the end of test period: $589.3481368162944
# profit gained: 489.3481368162944%
#
#
# Capital at the end of test period if Buy and Hold: $704.110752699704
# profit gained: 604.110752699704%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.485577      6.666667      11.111111      93.000000
# 1       0.509615      9.638554      11.111111      96.938776
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.333333           44.444444          86.868687     178.826183
# 1         48.192771           50.000000          91.836735     489.348137
#
#    buy_n_hold profit
# 0         400.940691
# 1         604.110753
#
#
# Non-Recession
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1859 - accuracy: 0.4444 - mse: 1.3099 - weighted_accuracy: 0.4444 - weighted_mse: 1.3099
# Test loss: 0.18589581549167633
# Test accuracy: 0.4444444477558136
#
#
# number of predictions: 207
# actual predicted buys: 9
# actual buys but predicted sell: 0
# actual buys but predicted hold: 2
# actual sells but predicted buy: 4
# actual predicted sells: 1
# actual sells but predicted hold: 6
# actual holds but predicted buy: 88
# actual holds but predicted sell: 15
# actual predicted holds: 82
# Percentage buys correct: 8.910891089108912%
# Percentage sells correct: 6.25%
# Percentage holds correct: 91.11111111111111%
# actual buys: 11
# actual sells: 11
# actual holds: 185
#
#
# Percentage low buys correct: 49.0%
# Percentage high sells correct: 37.5%
# Percentage mid holds correct: 88.88888888888889%
#
#
# Capital: 100
# Share price: $0.021217156310856737
# Shares owned at the moment: 4700
# Cash capital at the moment: $0.005133593655514801
#
#
# Price increase from previously bought: 1720.4624911742117%
# Share price: $0.3873125608568646
# Shares owned at the moment: 0
# Cash capital at the moment: $1815.3681547718443
#
#
# Share price: $0.3717332035053553
# Shares owned at the moment: 4870
# Cash capital at the moment: $0.04901677281827688
#
#
# Price increase from previously bought: 5.472582349713129%
# Share price: $0.3931548198636807
# Shares owned at the moment: 0
# Cash capital at the moment: $1909.447663583919
#
#
# Share price: $0.5544401311085079
# Shares owned at the moment: 3434
# Cash capital at the moment: $0.26439797917964825
#
#
# Price increase from previously bought: 15.516269224571943%
# Share price: $0.6422298430653597
# Shares owned at the moment: 0
# Cash capital at the moment: $2199.616781542637
#
#
# Share price: $0.8313242453748781
# Shares owned at the moment: 2638
# Cash capital at the moment: $0.5525805056363424
#
#
# Price increase from previously bought: 21.159718699598386%
# Share price: $1.0100000000000002
# Shares owned at the moment: 0
# Cash capital at the moment: $2657.605535505637
#
#
# Share price: $0.9150632911392407
# Shares owned at the moment: 2896
# Cash capital at the moment: $0.2946803157628892
#
#
#
#
# Capital at the end of test period: $2487.802124850702
# profit gained: 2387.802124850702%
#
#
# Capital at the end of test period if Buy and Hold: $1766.892280786996
# profit gained: 1666.8922807869963%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.280193      4.800000       7.407407      90.909091
# 1       0.314010      5.833333       0.000000      89.230769
# 2       0.444444      8.910891       6.250000      91.111111
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.548387            29.62963          83.636364     159.124648
# 1         46.218487            50.00000          81.538462     919.453464
# 2         49.000000            37.50000          88.888889    2387.802125
#
#    buy_n_hold profit
# 0        2068.314051
# 1        2331.201715
# 2        1666.892281
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1789 - accuracy: 0.4856 - mse: 1.2419 - weighted_accuracy: 0.4856 - weighted_mse: 1.2419
# Test loss: 0.17888988554477692
# Test accuracy: 0.48557692766189575
#
#
# number of predictions: 208
# actual predicted buys: 8
# actual buys but predicted sell: 0
# actual buys but predicted hold: 1
# actual sells but predicted buy: 5
# actual predicted sells: 0
# actual sells but predicted hold: 5
# actual holds but predicted buy: 74
# actual holds but predicted sell: 22
# actual predicted holds: 93
# Percentage buys correct: 9.195402298850574%
# Percentage sells correct: 0.0%
# Percentage holds correct: 93.93939393939394%
# actual buys: 9
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 43.02325581395349%
# Percentage high sells correct: 54.54545454545455%
# Percentage mid holds correct: 86.86868686868686%
#
#
# Capital: 100
# Share price: $0.12558233818043063
# Shares owned at the moment: 794
# Cash capital at the moment: $0.013414449321103916
#
#
# Price increase from previously bought: 39.26170212565896%
# Share price: $0.175369043998997
# Shares owned at the moment: 0
# Cash capital at the moment: $138.8735170769529
#
#
# Share price: $0.4319618179127802
# Shares owned at the moment: 320
# Cash capital at the moment: $0.26560894509998434
#
#
# Price increase from previously bought: 62.679110961894224%
# Share price: $0.7046441020993044
# Shares owned at the moment: 0
# Cash capital at the moment: $225.13163480702997
#
#
# Share price: $0.7471507558725743
# Shares owned at the moment: 300
# Cash capital at the moment: $0.37000867166281637
#
#
# Price increase from previously bought: 23.985800823542867%
# Share price: $0.9289083403598413
# Shares owned at the moment: 0
# Cash capital at the moment: $278.2761613988183
#
#
# Share price: $0.8058505275707262
# Shares owned at the moment: 344
# Cash capital at the moment: $0.3012453154066179
#
#
# Price increase from previously bought: 5.5610396242042%
# Share price: $0.853003521256275
# Shares owned at the moment: 0
# Cash capital at the moment: $292.9275152964568
#
#
# Share price: $0.818501330754654
# Shares owned at the moment: 356
# Cash capital at the moment: $0.7397287449911687
#
#
# Price increase from previously bought: 4.258770790069688%
# Share price: $0.8557061647676141
# Shares owned at the moment: 0
# Cash capital at the moment: $304.5333870669543
#
#
# Share price: $0.8378226135914708
# Shares owned at the moment: 362
# Cash capital at the moment: $0.40754853501152866
#
#
#
#
# Capital at the end of test period: $355.46876237477153
# profit gained: 255.46876237477153%
#
#
# Capital at the end of test period if Buy and Hold: $778.7940878989605
# profit gained: 678.7940878989605%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.485577      6.666667      11.111111      93.000000
# 1       0.509615      9.638554      11.111111      96.938776
# 2       0.485577      9.195402       0.000000      93.939394
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.333333           44.444444          86.868687     178.826183
# 1         48.192771           50.000000          91.836735     489.348137
# 2         43.023256           54.545455          86.868687     255.468762
#
#    buy_n_hold profit
# 0         400.940691
# 1         604.110753
# 2         678.794088
#
#
#
# RUNNING EPOCHS 20 - 40
#
#
#
# Epoch 1/20
#  2/26 [=>............................] - ETA: 16s - loss: 0.1499 - accuracy: 0.3555 - mse: 1.5639 - weighted_accuracy: 0.6994 - weighted_mse: 1.4238WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0100s vs `on_train_batch_end` time: 1.3245s). Check your callbacks.
# 26/26 [==============================] - 2s 62ms/step - loss: 0.1432 - accuracy: 0.3374 - mse: 1.5767 - weighted_accuracy: 0.6929 - weighted_mse: 1.4715 - val_loss: 0.1951 - val_accuracy: 0.3528 - val_mse: 1.3871 - val_weighted_accuracy: 0.3528 - val_weighted_mse: 1.3871
# Epoch 2/20
# 26/26 [==============================] - 0s 9ms/step - loss: 0.1422 - accuracy: 0.3794 - mse: 1.5793 - weighted_accuracy: 0.6846 - weighted_mse: 1.4901 - val_loss: 0.1853 - val_accuracy: 0.4148 - val_mse: 1.4256 - val_weighted_accuracy: 0.4148 - val_weighted_mse: 1.4256
# Epoch 3/20
# 26/26 [==============================] - 0s 9ms/step - loss: 0.1414 - accuracy: 0.3727 - mse: 1.6187 - weighted_accuracy: 0.6993 - weighted_mse: 1.5221 - val_loss: 0.1869 - val_accuracy: 0.3869 - val_mse: 1.3918 - val_weighted_accuracy: 0.3869 - val_weighted_mse: 1.3918
# Epoch 4/20
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1404 - accuracy: 0.3685 - mse: 1.6246 - weighted_accuracy: 0.6956 - weighted_mse: 1.5347 - val_loss: 0.1907 - val_accuracy: 0.3345 - val_mse: 1.4948 - val_weighted_accuracy: 0.3345 - val_weighted_mse: 1.4948
# Epoch 5/20
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1390 - accuracy: 0.3782 - mse: 1.6562 - weighted_accuracy: 0.6928 - weighted_mse: 1.5596 - val_loss: 0.1898 - val_accuracy: 0.3321 - val_mse: 1.5079 - val_weighted_accuracy: 0.3321 - val_weighted_mse: 1.5079
# Epoch 6/20
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1382 - accuracy: 0.3864 - mse: 1.6741 - weighted_accuracy: 0.7044 - weighted_mse: 1.5857 - val_loss: 0.1809 - val_accuracy: 0.3942 - val_mse: 1.5088 - val_weighted_accuracy: 0.3942 - val_weighted_mse: 1.5088
# Epoch 7/20
# 26/26 [==============================] - 0s 9ms/step - loss: 0.1370 - accuracy: 0.4016 - mse: 1.6678 - weighted_accuracy: 0.7099 - weighted_mse: 1.5795 - val_loss: 0.1910 - val_accuracy: 0.3321 - val_mse: 1.5051 - val_weighted_accuracy: 0.3321 - val_weighted_mse: 1.5051
# Epoch 8/20
# 26/26 [==============================] - 0s 9ms/step - loss: 0.1353 - accuracy: 0.3721 - mse: 1.7018 - weighted_accuracy: 0.7121 - weighted_mse: 1.5953 - val_loss: 0.1849 - val_accuracy: 0.3832 - val_mse: 1.7004 - val_weighted_accuracy: 0.3832 - val_weighted_mse: 1.7004
# Epoch 9/20
# 26/26 [==============================] - 0s 9ms/step - loss: 0.1346 - accuracy: 0.4242 - mse: 1.7131 - weighted_accuracy: 0.7183 - weighted_mse: 1.6347 - val_loss: 0.1860 - val_accuracy: 0.3929 - val_mse: 1.5587 - val_weighted_accuracy: 0.3929 - val_weighted_mse: 1.5587
# Epoch 10/20
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1332 - accuracy: 0.3879 - mse: 1.7711 - weighted_accuracy: 0.7178 - weighted_mse: 1.6802 - val_loss: 0.1844 - val_accuracy: 0.4015 - val_mse: 1.6583 - val_weighted_accuracy: 0.4015 - val_weighted_mse: 1.6583
# Epoch 11/20
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1338 - accuracy: 0.4278 - mse: 1.7781 - weighted_accuracy: 0.7216 - weighted_mse: 1.6803 - val_loss: 0.1845 - val_accuracy: 0.4100 - val_mse: 1.7331 - val_weighted_accuracy: 0.4100 - val_weighted_mse: 1.7331
# Epoch 12/20
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1316 - accuracy: 0.4388 - mse: 1.7590 - weighted_accuracy: 0.7300 - weighted_mse: 1.6775 - val_loss: 0.1866 - val_accuracy: 0.4088 - val_mse: 1.7642 - val_weighted_accuracy: 0.4088 - val_weighted_mse: 1.7642
# Epoch 13/20
# 26/26 [==============================] - 0s 12ms/step - loss: 0.1306 - accuracy: 0.4659 - mse: 1.7721 - weighted_accuracy: 0.7442 - weighted_mse: 1.7042 - val_loss: 0.1839 - val_accuracy: 0.4063 - val_mse: 1.7396 - val_weighted_accuracy: 0.4063 - val_weighted_mse: 1.7396
# Epoch 14/20
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1302 - accuracy: 0.4023 - mse: 1.8280 - weighted_accuracy: 0.7252 - weighted_mse: 1.7316 - val_loss: 0.1868 - val_accuracy: 0.3954 - val_mse: 1.7944 - val_weighted_accuracy: 0.3954 - val_weighted_mse: 1.7944
# Epoch 15/20
# 26/26 [==============================] - 0s 12ms/step - loss: 0.1274 - accuracy: 0.4519 - mse: 1.8268 - weighted_accuracy: 0.7456 - weighted_mse: 1.7432 - val_loss: 0.1876 - val_accuracy: 0.4088 - val_mse: 1.8946 - val_weighted_accuracy: 0.4088 - val_weighted_mse: 1.8946
# Epoch 16/20
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1271 - accuracy: 0.4689 - mse: 1.8506 - weighted_accuracy: 0.7539 - weighted_mse: 1.7866 - val_loss: 0.1788 - val_accuracy: 0.4562 - val_mse: 1.8013 - val_weighted_accuracy: 0.4562 - val_weighted_mse: 1.8013
# Epoch 17/20
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1263 - accuracy: 0.4766 - mse: 1.8612 - weighted_accuracy: 0.7568 - weighted_mse: 1.7937 - val_loss: 0.1876 - val_accuracy: 0.4161 - val_mse: 1.8786 - val_weighted_accuracy: 0.4161 - val_weighted_mse: 1.8786
# Epoch 18/20
# 26/26 [==============================] - 0s 9ms/step - loss: 0.1266 - accuracy: 0.4674 - mse: 1.8742 - weighted_accuracy: 0.7427 - weighted_mse: 1.7965 - val_loss: 0.1811 - val_accuracy: 0.4538 - val_mse: 2.0025 - val_weighted_accuracy: 0.4538 - val_weighted_mse: 2.0025
# Epoch 19/20
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1242 - accuracy: 0.4747 - mse: 1.9093 - weighted_accuracy: 0.7561 - weighted_mse: 1.8435 - val_loss: 0.1820 - val_accuracy: 0.4477 - val_mse: 1.8899 - val_weighted_accuracy: 0.4477 - val_weighted_mse: 1.8899
# Epoch 20/20
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1228 - accuracy: 0.5055 - mse: 1.8971 - weighted_accuracy: 0.7631 - weighted_mse: 1.8636 - val_loss: 0.2026 - val_accuracy: 0.3674 - val_mse: 2.0200 - val_weighted_accuracy: 0.3674 - val_weighted_mse: 2.0200
# Validation loss: 0.20263196527957916
# Validation accuracy: 0.36739659309387207
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1900 - accuracy: 0.4058 - mse: 1.9251 - weighted_accuracy: 0.4058 - weighted_mse: 1.9251
# Test loss: 0.19000548124313354
# Test accuracy: 0.4057970941066742
#
#
# number of predictions: 207
# actual predicted buys: 4
# actual buys but predicted sell: 2
# actual buys but predicted hold: 1
# actual sells but predicted buy: 1
# actual predicted sells: 3
# actual sells but predicted hold: 6
# actual holds but predicted buy: 77
# actual holds but predicted sell: 36
# actual predicted holds: 77
# Percentage buys correct: 4.878048780487805%
# Percentage sells correct: 7.317073170731708%
# Percentage holds correct: 91.66666666666667%
# actual buys: 7
# actual sells: 10
# actual holds: 190
#
#
# Percentage low buys correct: 49.382716049382715%
# Percentage high sells correct: 41.46341463414634%
# Percentage mid holds correct: 83.33333333333333%
#
#
# Capital: 100
# Share price: $0.2402277855897017
# Shares owned at the moment: 415
# Cash capital at the moment: $0.03130901996954094
#
#
# Price increase from previously bought: 26.885426069294894%
# Share price: $0.3056522879178516
# Shares owned at the moment: 0
# Cash capital at the moment: $126.5281828322917
#
#
# Share price: $0.2712836842486026
# Shares owned at the moment: 465
# Cash capital at the moment: $0.03436564545857834
#
#
# Price increase from previously bought: 84.51126934011785%
# Share price: $0.5019254789853633
# Shares owned at the moment: 0
# Cash capital at the moment: $232.7878761674
#
#
# Share price: $0.459689437854242
# Shares owned at the moment: 505
# Cash capital at the moment: $0.006316344187695222
#
#
# Price increase from previously bought: 26.04620399840618%
# Share price: $0.581014494585026
# Shares owned at the moment: 0
# Cash capital at the moment: $292.6117522302708
#
#
# Share price: $0.5275983109816835
# Shares owned at the moment: 553
# Cash capital at the moment: $0.047541125974419174
#
#
# Price increase from previously bought: -27.66820565587644%
# Share price: $0.3826707839068122
# Shares owned at the moment: 0
# Cash capital at the moment: $211.08253803181526
#
#
# Share price: $0.35741211901602
# Shares owned at the moment: 588
# Cash capital at the moment: $0.3462766539466031
#
#
# Price increase from previously bought: 54.60580464743083%
# Share price: $0.5540994771890593
# Shares owned at the moment: 0
# Cash capital at the moment: $325.2607903864987
#
#
# Share price: $0.6282194352731998
# Shares owned at the moment: 516
# Cash capital at the moment: $0.20811840687491667
#
#
# Price increase from previously bought: -37.873101780930575%
# Share price: $0.3913665555797412
# Shares owned at the moment: 0
# Cash capital at the moment: $201.59791194365374
#
#
# Share price: $0.47128374743199
# Shares owned at the moment: 426
# Cash capital at the moment: $0.27892662750943487
#
#
# Price increase from previously bought: 7.69925462953398%
# Share price: $0.5089648981531183
# Shares owned at the moment: 0
# Cash capital at the moment: $216.50172086255142
#
#
# Share price: $0.4961284031757236
# Shares owned at the moment: 435
# Cash capital at the moment: $0.09237187881268483
#
#
# Price increase from previously bought: -8.597555933620804%
# Share price: $0.45472053829718884
# Shares owned at the moment: 0
# Cash capital at the moment: $197.35184659415182
#
#
# Share price: $0.46879921867422936
# Shares owned at the moment: 419
# Cash capital at the moment: $0.3848000699323393
#
#
# Price increase from previously bought: 4.041947168425941%
# Share price: $0.4890891419664376
# Shares owned at the moment: 0
# Cash capital at the moment: $204.74959759003886
#
#
# Share price: $0.41621121132347416
# Shares owned at the moment: 490
# Cash capital at the moment: $0.24525943427812535
#
#
# Price increase from previously bought: 3.6943606854149103%
# Share price: $0.43277442045827574
# Shares owned at the moment: 0
# Cash capital at the moment: $211.72156192726572
#
#
# Share price: $0.4418840433197939
# Shares owned at the moment: 477
# Cash capital at the moment: $0.3632318698992947
#
#
# Price increase from previously bought: 67.38396585578867%
# Share price: $0.7416770545421119
# Shares owned at the moment: 0
# Cash capital at the moment: $353.170292010191
#
#
# Share price: $0.9619668830592385
# Shares owned at the moment: 366
# Cash capital at the moment: $0.12219314271061421
#
#
#
#
# Capital at the end of test period: $274.15450793544693
# profit gained: 174.15450793544693%
#
#
# Capital at the end of test period if Buy and Hold: $2168.3140506383515
# profit gained: 2068.3140506383515%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.405797      4.878049       7.317073      91.666667
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         49.382716           41.463415          83.333333     174.154508
#
#    buy_n_hold profit
# 0        2068.314051
#
#
# Recession
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1982 - accuracy: 0.3990 - mse: 2.1456 - weighted_accuracy: 0.3990 - weighted_mse: 2.1456
# Test loss: 0.19820629060268402
# Test accuracy: 0.3990384638309479
#
#
# number of predictions: 208
# actual predicted buys: 7
# actual buys but predicted sell: 0
# actual buys but predicted hold: 1
# actual sells but predicted buy: 0
# actual predicted sells: 4
# actual sells but predicted hold: 4
# actual holds but predicted buy: 71
# actual holds but predicted sell: 49
# actual predicted holds: 72
# Percentage buys correct: 8.974358974358974%
# Percentage sells correct: 7.547169811320755%
# Percentage holds correct: 93.50649350649351%
# actual buys: 8
# actual sells: 8
# actual holds: 192
#
#
# Percentage low buys correct: 47.43589743589744%
# Percentage high sells correct: 56.60377358490566%
# Percentage mid holds correct: 89.47368421052632%
#
#
# Capital: 100
# Share price: $0.14722326289633325
# Shares owned at the moment: 677
# Cash capital at the moment: $0.05575810948514004
#
#
# Price increase from previously bought: 32.688561499367786%
# Share price: $0.1958856379113334
# Shares owned at the moment: 0
# Cash capital at the moment: $132.30564488907643
#
#
# Share price: $0.18020297426733345
# Shares owned at the moment: 732
# Cash capital at the moment: $0.03431913818820931
#
#
# Price increase from previously bought: -42.392458613475036%
# Share price: $0.10409598186400025
# Shares owned at the moment: 0
# Cash capital at the moment: $76.02303265114415
#
#
# Share price: $0.14376390613733392
# Shares owned at the moment: 527
# Cash capital at the moment: $0.05110427579964494
#
#
# Price increase from previously bought: 6.92484667898885%
# Share price: $0.15414206439166667
# Shares owned at the moment: 0
# Cash capital at the moment: $81.06058182338835
#
#
# Share price: $0.15575644847466652
# Shares owned at the moment: 519
# Cash capital at the moment: $0.0006816739509503122
#
#
# Price increase from previously bought: 60.85832941404534%
# Share price: $0.2512362258286671
# Shares owned at the moment: 0
# Cash capital at the moment: $130.03370597571524
#
#
# Share price: $0.2399354492703334
# Shares owned at the moment: 540
# Cash capital at the moment: $0.11225922756875661
#
#
# Price increase from previously bought: 13.049865165556596%
# Share price: $0.2719926303146667
# Shares owned at the moment: 0
# Cash capital at the moment: $146.5843705414715
#
#
# Share price: $0.38523063258166657
# Shares owned at the moment: 379
# Cash capital at the moment: $0.1804541662116037
#
#
# Price increase from previously bought: 59.19010755681193%
# Share price: $0.6149354932590005
# Shares owned at the moment: 0
# Cash capital at the moment: $232.6000895935236
#
#
# Share price: $0.6965775796450009
# Shares owned at the moment: 333
# Cash capital at the moment: $0.0018646531783872433
#
#
# Price increase from previously bought: -0.5053696426532306%
# Share price: $0.6949631955620013
# Shares owned at the moment: 0
# Cash capital at the moment: $230.78819622898888
#
#
# Share price: $0.7355534742073329
# Shares owned at the moment: 312
# Cash capital at the moment: $0.6644073954311125
#
#
# Price increase from previously bought: -19.848163197153458%
# Share price: $0.5911809092000013
# Shares owned at the moment: 0
# Cash capital at the moment: $184.60561784573792
#
#
# Share price: $0.7039576463036674
# Shares owned at the moment: 261
# Cash capital at the moment: $0.36740655984627324
#
#
# Price increase from previously bought: 41.77419545516936%
# Share price: $1.0007748726879997
# Shares owned at the moment: 0
# Cash capital at the moment: $260.8513421665424
#
#
# Share price: $0.8022047507056662
# Shares owned at the moment: 324
# Cash capital at the moment: $0.22223850502774667
#
#
# Price increase from previously bought: 16.98531018645344%
# Share price: $0.9410424856623338
# Shares owned at the moment: 0
# Cash capital at the moment: $304.2815350048988
#
#
#
#
# Capital at the end of test period: $304.2815350048988
# profit gained: 204.2815350048988%
#
#
# Capital at the end of test period if Buy and Hold: $500.9406907154986
# profit gained: 400.9406907154986%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.399038      8.974359        7.54717      93.506494
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.435897           56.603774          89.473684     204.281535
#
#    buy_n_hold profit
# 0         400.940691
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1940 - accuracy: 0.3720 - mse: 1.9604 - weighted_accuracy: 0.3720 - weighted_mse: 1.9604
# Test loss: 0.19404640793800354
# Test accuracy: 0.3719806671142578
#
#
# number of predictions: 207
# actual predicted buys: 5
# actual buys but predicted sell: 0
# actual buys but predicted hold: 3
# actual sells but predicted buy: 3
# actual predicted sells: 3
# actual sells but predicted hold: 4
# actual holds but predicted buy: 57
# actual holds but predicted sell: 63
# actual predicted holds: 69
# Percentage buys correct: 7.6923076923076925%
# Percentage sells correct: 4.545454545454546%
# Percentage holds correct: 90.78947368421052%
# actual buys: 8
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 47.69230769230769%
# Percentage high sells correct: 49.23076923076923%
# Percentage mid holds correct: 77.63157894736842%
#
#
# Capital: 100
# Share price: $0.016094216827733925
# Shares owned at the moment: 6196
# Cash capital at the moment: $0.006003174832841296
#
#
# Price increase from previously bought: 34.97040496653523%
# Share price: $0.02178216631006335
# Shares owned at the moment: 0
# Cash capital at the moment: $134.59715930022818
#
#
# Share price: $0.03722094537543363
# Shares owned at the moment: 3606
# Cash capital at the moment: $0.009328771599030006
#
#
# Price increase from previously bought: 211.63085234880842%
# Share price: $0.116310927186394
# Shares owned at the moment: 0
# Cash capital at the moment: $418.27313489629194
#
#
# Share price: $0.11766518611218689
# Shares owned at the moment: 3545
# Cash capital at the moment: $0.0029616454781944412
#
#
# Price increase from previously bought: 31.634687169508304%
# Share price: $0.155314142195224
# Shares owned at the moment: 0
# Cash capital at the moment: $549.0774769838215
#
#
# Share price: $0.4508179447005256
# Shares owned at the moment: 1214
# Cash capital at the moment: $0.27943640900059563
#
#
# Price increase from previously bought: 27.586809280313208%
# Share price: $0.5767659879425804
# Shares owned at the moment: 0
# Cash capital at the moment: $698.5478125205469
#
#
# Share price: $0.44039003731625503
# Shares owned at the moment: 1581
# Cash capital at the moment: $0.37645773880603883
#
#
# Price increase from previously bought: 4.724545988867845%
# Share price: $0.4624647574443428
# Shares owned at the moment: 0
# Cash capital at the moment: $729.5225581091332
#
#
# Share price: $0.4317226562031815
# Shares owned at the moment: 1685
# Cash capital at the moment: $0.06938754859095297
#
#
# Price increase from previously bought: 17.776135578501062%
# Share price: $0.5098645431104207
# Shares owned at the moment: 0
# Cash capital at the moment: $856.828557863012
#
#
# Share price: $0.7270910018189038
# Shares owned at the moment: 1175
# Cash capital at the moment: $0.14721792617262963
#
#
# Price increase from previously bought: 3.2549913297303057%
# Share price: $0.7528223347022986
# Shares owned at the moment: 0
# Cash capital at the moment: $882.2809040323667
#
#
# Share price: $0.730882968140457
# Shares owned at the moment: 1203
# Cash capital at the moment: $0.6107497800463761
#
#
# Price increase from previously bought: 1.6105738752430154%
# Share price: $0.7446966778242088
# Shares owned at the moment: 0
# Cash capital at the moment: $894.0172104181576
#
#
# Share price: $0.8812080853401136
# Shares owned at the moment: 1011
# Cash capital at the moment: $0.6658573600358295
#
#
# Price increase from previously bought: 13.703328022326588%
# Share price: $1.0047183178630752
# Shares owned at the moment: 0
# Cash capital at the moment: $1013.642708616366
#
#
# Share price: $0.9735698459531767
# Shares owned at the moment: 1038
# Cash capital at the moment: $0.29815339169510935
#
#
# Price increase from previously bought: -3.9642833539911604%
# Share price: $0.9375459592517568
# Shares owned at the moment: 0
# Cash capital at the moment: $970.7946341543345
#
#
# Share price: $0.9004388307270363
# Shares owned at the moment: 1075
# Cash capital at the moment: $0.1609688294336138
#
#
# Price increase from previously bought: -5.778865207579553%
# Share price: $0.8507367945547777
# Shares owned at the moment: 0
# Cash capital at the moment: $912.1880323269171
#
#
# Share price: $0.8235156425326782
# Shares owned at the moment: 1104
# Cash capital at the moment: $0.5265694801112204
#
#
# Price increase from previously bought: 5.268961697395569%
# Share price: $0.8692903588171379
# Shares owned at the moment: 0
# Cash capital at the moment: $957.5839600848626
#
#
# Share price: $0.8946153210317951
# Shares owned at the moment: 1067
# Cash capital at the moment: $0.4043875381996713
#
#
# Price increase from previously bought: -0.33462211379486906%
# Share price: $0.8940737001201449
# Shares owned at the moment: 0
# Cash capital at the moment: $951.7575898118166
#
#
# Share price: $0.8896045526740286
# Shares owned at the moment: 1066
# Cash capital at the moment: $0.8312609151381594
#
#
# Price increase from previously bought: -4.084828924507056%
# Share price: $0.8556122093462981
# Shares owned at the moment: 0
# Cash capital at the moment: $910.4056488865933
#
#
# Share price: $0.8523618639363959
# Shares owned at the moment: 1065
# Cash capital at the moment: $0.14390898532792562
#
#
# Price increase from previously bought: -0.8921990158248017%
# Share price: $0.8470801817994709
# Shares owned at the moment: 0
# Cash capital at the moment: $899.8034165193192
#
#
#
#
# Capital at the end of test period: $899.8034165193192
# profit gained: 799.8034165193192%
#
#
# Capital at the end of test period if Buy and Hold: $2431.2017150969914
# profit gained: 2331.2017150969914%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.405797      4.878049       7.317073      91.666667
# 1       0.371981      7.692308       4.545455      90.789474
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         49.382716           41.463415          83.333333     174.154508
# 1         47.692308           49.230769          77.631579     799.803417
#
#    buy_n_hold profit
# 0        2068.314051
# 1        2331.201715
#
#
# Recession
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2145 - accuracy: 0.2933 - mse: 2.1839 - weighted_accuracy: 0.2933 - weighted_mse: 2.1839
# Test loss: 0.21454419195652008
# Test accuracy: 0.29326921701431274
#
#
# number of predictions: 208
# actual predicted buys: 8
# actual buys but predicted sell: 1
# actual buys but predicted hold: 1
# actual sells but predicted buy: 1
# actual predicted sells: 4
# actual sells but predicted hold: 3
# actual holds but predicted buy: 54
# actual holds but predicted sell: 87
# actual predicted holds: 49
# Percentage buys correct: 12.698412698412698%
# Percentage sells correct: 4.3478260869565215%
# Percentage holds correct: 92.45283018867924%
# actual buys: 10
# actual sells: 8
# actual holds: 190
#
#
# Percentage low buys correct: 57.142857142857146%
# Percentage high sells correct: 53.84615384615385%
# Percentage mid holds correct: 86.79245283018868%
#
#
# Capital: 100
# Share price: $0.11253699645000136
# Shares owned at the moment: 886
# Cash capital at the moment: $0.01802475344835841
#
#
# Price increase from previously bought: 46.41508438238755%
# Share price: $0.16522425894403658
# Shares owned at the moment: 0
# Cash capital at the moment: $146.0041492709476
#
#
# Share price: $0.12366417981973842
# Shares owned at the moment: 1177
# Cash capital at the moment: $0.051139589083959436
#
#
# Price increase from previously bought: -30.738355489822077%
# Share price: $0.08588738718586063
# Shares owned at the moment: 0
# Cash capital at the moment: $100.86259830636808
#
#
# ...
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0232 - accuracy: 0.9479 - mse: 10.9193 - weighted_accuracy: 0.9809 - weighted_mse: 9.8203 - val_loss: 0.2361 - val_accuracy: 0.7701 - val_mse: 11.1805 - val_weighted_accuracy: 0.7701 - val_weighted_mse: 11.1805
# Epoch 17/20
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0236 - accuracy: 0.9400 - mse: 10.8537 - weighted_accuracy: 0.9780 - weighted_mse: 9.8166 - val_loss: 0.2488 - val_accuracy: 0.7543 - val_mse: 11.4001 - val_weighted_accuracy: 0.7543 - val_weighted_mse: 11.4001
# Epoch 18/20
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0237 - accuracy: 0.9476 - mse: 11.0831 - weighted_accuracy: 0.9808 - weighted_mse: 9.9331 - val_loss: 0.2451 - val_accuracy: 0.7336 - val_mse: 11.0333 - val_weighted_accuracy: 0.7336 - val_weighted_mse: 11.0333
# Epoch 19/20
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0230 - accuracy: 0.9428 - mse: 11.1750 - weighted_accuracy: 0.9790 - weighted_mse: 9.9499 - val_loss: 0.2427 - val_accuracy: 0.7445 - val_mse: 11.1956 - val_weighted_accuracy: 0.7445 - val_weighted_mse: 11.1956
# Epoch 20/20
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0232 - accuracy: 0.9446 - mse: 11.3900 - weighted_accuracy: 0.9754 - weighted_mse: 10.2801 - val_loss: 0.2488 - val_accuracy: 0.7457 - val_mse: 11.9733 - val_weighted_accuracy: 0.7457 - val_weighted_mse: 11.9733
# Validation loss: 0.24879615008831024
# Validation accuracy: 0.7457420825958252
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2423 - accuracy: 0.8309 - mse: 11.7001 - weighted_accuracy: 0.8309 - weighted_mse: 11.7001
# Test loss: 0.242272287607193
# Test accuracy: 0.8309178948402405
#
#
# number of predictions: 207
# actual predicted buys: 0
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 1
# actual predicted sells: 1
# actual sells but predicted hold: 8
# actual holds but predicted buy: 11
# actual holds but predicted sell: 8
# actual predicted holds: 171
# Percentage buys correct: 0.0%
# Percentage sells correct: 11.11111111111111%
# Percentage holds correct: 91.93548387096774%
# actual buys: 7
# actual sells: 10
# actual holds: 190
#
#
# Percentage low buys correct: 54.54545454545455%
# Percentage high sells correct: 44.44444444444444%
# Percentage mid holds correct: 83.87096774193549%
#
#
# Capital: 100
# Share price: $0.45886126160165475
# Shares owned at the moment: 217
# Cash capital at the moment: $0.153280774580125
#
#
# Price increase from previously bought: 37.702814861302556%
# Share price: $0.6336025019357812
# Shares owned at the moment: 0
# Cash capital at the moment: $137.26692140161447
#
#
# Share price: $0.6679711056050297
# Shares owned at the moment: 204
# Cash capital at the moment: $0.6260840679439923
#
#
# Price increase from previously bought: -26.980698517303857%
# Share price: $0.4890891419664376
# Shares owned at the moment: 0
# Cash capital at the moment: $100.12589002045408
#
#
# Share price: $0.8915734811740359
# Shares owned at the moment: 111
# Cash capital at the moment: $0.8890808050077226
#
#
#
#
# Capital at the end of test period: $83.99724184870645
# profit gained: -16.00275815129355%
#
#
# Capital at the end of test period if Buy and Hold: $2168.3140506383515
# profit gained: 2068.3140506383515%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.830918           0.0      11.111111      91.935484
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         54.545455           44.444444          83.870968     -16.002758
#
#    buy_n_hold profit
# 0        2068.314051
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2551 - accuracy: 0.7933 - mse: 12.7861 - weighted_accuracy: 0.7933 - weighted_mse: 12.7861
# Test loss: 0.2551027834415436
# Test accuracy: 0.7932692170143127
#
#
# number of predictions: 208
# actual predicted buys: 2
# actual buys but predicted sell: 0
# actual buys but predicted hold: 6
# actual sells but predicted buy: 0
# actual predicted sells: 1
# actual sells but predicted hold: 7
# actual holds but predicted buy: 20
# actual holds but predicted sell: 10
# actual predicted holds: 162
# Percentage buys correct: 9.090909090909092%
# Percentage sells correct: 9.090909090909092%
# Percentage holds correct: 92.57142857142857%
# actual buys: 8
# actual sells: 8
# actual holds: 192
#
#
# Percentage low buys correct: 54.54545454545455%
# Percentage high sells correct: 81.81818181818181%
# Percentage mid holds correct: 87.35632183908046%
#
#
# Capital: 100
# Share price: $0.18043356286033307
# Shares owned at the moment: 552
# Cash capital at the moment: $0.1267751526741563
#
#
# Price increase from previously bought: -42.46607929525901%
# Share price: $0.10409598186400025
# Shares owned at the moment: 0
# Cash capital at the moment: $57.42973944113274
#
#
# Share price: $0.7260978462796672
# Shares owned at the moment: 78
# Cash capital at the moment: $0.638359443291705
#
#
#
#
# Capital at the end of test period: $71.14690069984205
# profit gained: -28.853099300157954%
#
#
# Capital at the end of test period if Buy and Hold: $500.9406907154986
# profit gained: 400.9406907154986%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.793269      9.090909       9.090909      92.571429
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         54.545455           81.818182          87.356322     -28.853099
#
#    buy_n_hold profit
# 0         400.940691
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1928 - accuracy: 0.7923 - mse: 11.3915 - weighted_accuracy: 0.7923 - weighted_mse: 11.3915
# Test loss: 0.19279728829860687
# Test accuracy: 0.7922705411911011
#
#
# number of predictions: 207
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 0
# actual predicted sells: 0
# actual sells but predicted hold: 10
# actual holds but predicted buy: 6
# actual holds but predicted sell: 20
# actual predicted holds: 163
# Percentage buys correct: 14.285714285714286%
# Percentage sells correct: 0.0%
# Percentage holds correct: 90.55555555555556%
# actual buys: 8
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 71.42857142857143%
# Percentage high sells correct: 45.0%
# Percentage mid holds correct: 83.24022346368714%
#
#
# Capital: 100
# Share price: $0.4743823806439853
# Shares owned at the moment: 210
# Cash capital at the moment: $0.1057442399411741
#
#
# Price increase from previously bought: 67.08572961662651%
# Share price: $0.7948049813418725
# Shares owned at the moment: 0
# Cash capital at the moment: $166.55579044500948
#
#
# Share price: $0.8235156425326782
# Shares owned at the moment: 201
# Cash capital at the moment: $0.5739480245312052
#
#
# Price increase from previously bought: 5.268961697395569%
# Share price: $0.8692903588171379
# Shares owned at the moment: 0
# Cash capital at the moment: $174.82080990093976
#
#
# Share price: $0.8896045526740286
# Shares owned at the moment: 195
# Cash capital at the moment: $0.8708716881327234
#
#
# Price increase from previously bought: -4.084828924507056%
# Share price: $0.8556122093462981
# Shares owned at the moment: 0
# Cash capital at the moment: $167.2564304633989
# Capital at the end of test period: $167.2564304633989
# profit gained: 67.25643046339891%
#
#
# Capital at the end of test period if Buy and Hold: $2431.2017150969914
# profit gained: 2331.2017150969914%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.830918      0.000000      11.111111      91.935484
# 1       0.792271     14.285714       0.000000      90.555556
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         54.545455           44.444444          83.870968     -16.002758
# 1         71.428571           45.000000          83.240223      67.256430
#
#    buy_n_hold profit
# 0        2068.314051
# 1        2331.201715
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2262 - accuracy: 0.7788 - mse: 11.4977 - weighted_accuracy: 0.7788 - weighted_mse: 11.4977
# Test loss: 0.2261757254600525
# Test accuracy: 0.7788461446762085
#
#
# number of predictions: 208
# actual predicted buys: 1
# actual buys but predicted sell: 1
# actual buys but predicted hold: 8
# actual sells but predicted buy: 0
# actual predicted sells: 1
# actual sells but predicted hold: 7
# actual holds but predicted buy: 4
# actual holds but predicted sell: 26
# actual predicted holds: 160
# Percentage buys correct: 20.0%
# Percentage sells correct: 3.5714285714285716%
# Percentage holds correct: 91.42857142857143%
# actual buys: 10
# actual sells: 8
# actual holds: 190
#
#
# Percentage low buys correct: 60.0%
# Percentage high sells correct: 64.28571428571429%
# Percentage mid holds correct: 86.7816091954023%
#
#
# Capital: 100
# Share price: $0.26609211846300684
# Shares owned at the moment: 374
# Cash capital at the moment: $0.20787195099623546
#
#
# Price increase from previously bought: 19.492660730792878%
# Share price: $0.31883494386533284
# Shares owned at the moment: 0
# Cash capital at the moment: $119.12421921686521
#
#
# Share price: $0.36317677638522916
# Shares owned at the moment: 327
# Cash capital at the moment: $0.038826622730866234
#
#
# Price increase from previously bought: -4.322701445121291%
# Share price: $0.3484332923777962
# Shares owned at the moment: 0
# Cash capital at the moment: $113.66318459209948
#
#
# Share price: $0.7053376650046469
# Shares owned at the moment: 160
# Cash capital at the moment: $0.49880961875392416
#
#
# Price increase from previously bought: 1.5900539645585354%
# Share price: $0.718523435025482
# Shares owned at the moment: 0
# Cash capital at the moment: $115.14640891141983
#
#
# Share price: $0.6625537162586917
# Shares owned at the moment: 173
# Cash capital at the moment: $0.20940606815607055
#
#
# Price increase from previously bought: 0.8227676725348188%
# Share price: $0.6698420077828818
# Shares owned at the moment: 0
# Cash capital at the moment: $115.77339607939192
#
#
#
#
# Capital at the end of test period: $115.77339607939192
# profit gained: 15.773396079391915%
#
#
# Capital at the end of test period if Buy and Hold: $704.110752699704
# profit gained: 604.110752699704%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.793269      9.090909       9.090909      92.571429
# 1       0.778846     20.000000       3.571429      91.428571
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         54.545455           81.818182          87.356322     -28.853099
# 1         60.000000           64.285714          86.781609      15.773396
#
#    buy_n_hold profit
# 0         400.940691
# 1         604.110753
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2410 - accuracy: 0.7971 - mse: 13.4974 - weighted_accuracy: 0.7971 - weighted_mse: 13.4974
# Test loss: 0.24097473919391632
# Test accuracy: 0.7971014380455017
#
#
# number of predictions: 207
# actual predicted buys: 0
# actual buys but predicted sell: 0
# actual buys but predicted hold: 11
# actual sells but predicted buy: 0
# actual predicted sells: 4
# actual sells but predicted hold: 7
# actual holds but predicted buy: 9
# actual holds but predicted sell: 15
# actual predicted holds: 161
# Percentage buys correct: 0.0%
# Percentage sells correct: 21.05263157894737%
# Percentage holds correct: 89.94413407821229%
# actual buys: 11
# actual sells: 11
# actual holds: 185
#
#
# Percentage low buys correct: 66.66666666666667%
# Percentage high sells correct: 68.42105263157895%
# Percentage mid holds correct: 85.3932584269663%
#
#
# Capital: 100
# Share price: $0.07572541382667962
# Shares owned at the moment: 1316
# Cash capital at the moment: $0.07130513145085615
#
#
# Price increase from previously bought: 256.1633827262415%
# Share price: $0.2704478875060856
# Shares owned at the moment: 0
# Cash capital at the moment: $355.00197418457503
#
#
# Share price: $0.30474191934944006
# Shares owned at the moment: 1161
# Cash capital at the moment: $0.22364105687216806
#
#
# Price increase from previously bought: 59.26746119383797%
# Share price: $0.4866894436161149
# Shares owned at the moment: 0
# Cash capital at the moment: $563.7162073740762
#
#
# Share price: $0.4502141923913705
# Shares owned at the moment: 1248
# Cash capital at the moment: $0.3037601613585821
#
#
# Price increase from previously bought: 6.511187205957669%
# Share price: $0.480847184609299
# Shares owned at the moment: 0
# Cash capital at the moment: $598.7507790161847
#
#
# Share price: $0.8060077896786759
# Shares owned at the moment: 740
# Cash capital at the moment: $0.6647888019683705
#
#
# Price increase from previously bought: 9.122819575497964%
# Share price: $0.8819571567672835
# Shares owned at the moment: 0
# Cash capital at the moment: $651.5183019957367
#
#
#
#
# Capital at the end of test period: $651.5183019957367
# profit gained: 551.5183019957367%
#
#
# Capital at the end of test period if Buy and Hold: $1766.892280786996
# profit gained: 1666.8922807869963%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.830918      0.000000      11.111111      91.935484
# 1       0.792271     14.285714       0.000000      90.555556
# 2       0.797101      0.000000      21.052632      89.944134
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         54.545455           44.444444          83.870968     -16.002758
# 1         71.428571           45.000000          83.240223      67.256430
# 2         66.666667           68.421053          85.393258     551.518302
#
#    buy_n_hold profit
# 0        2068.314051
# 1        2331.201715
# 2        1666.892281
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1946 - accuracy: 0.7981 - mse: 11.7880 - weighted_accuracy: 0.7981 - weighted_mse: 11.7880
# Test loss: 0.1946105659008026
# Test accuracy: 0.7980769276618958
#
#
# number of predictions: 208
# actual predicted buys: 1
# actual buys but predicted sell: 1
# actual buys but predicted hold: 7
# actual sells but predicted buy: 0
# actual predicted sells: 1
# actual sells but predicted hold: 9
# actual holds but predicted buy: 2
# actual holds but predicted sell: 23
# actual predicted holds: 164
# Percentage buys correct: 33.333333333333336%
# Percentage sells correct: 4.0%
# Percentage holds correct: 91.11111111111111%
# actual buys: 9
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 100.0%
# Percentage high sells correct: 48.0%
# Percentage mid holds correct: 86.59217877094972%
#
#
# Capital: 100
# Share price: $0.01
# Shares owned at the moment: 9972
# Cash capital at the moment: $0.0057699999999982765
#
#
# Price increase from previously bought: 964.2843443356447%
# Share price: $0.10672111262825677
# Shares owned at the moment: 0
# Cash capital at the moment: $1061.302092057372
#
#
# Share price: $0.7305783047822652
# Shares owned at the moment: 1448
# Cash capital at the moment: $0.5155439230090906
#
#
# Price increase from previously bought: 7.488794449399583%
# Share price: $0.787449359303195
# Shares owned at the moment: 0
# Cash capital at the moment: $1137.6065928452902
#
#
# Share price: $0.8327622642399453
# Shares owned at the moment: 1362
# Cash capital at the moment: $0.2652778897738699
#
#
# Price increase from previously bought: 13.635944744651084%
# Share price: $0.948919638928736
# Shares owned at the moment: 0
# Cash capital at the moment: $1289.1396476031045
#
#
#
#
# Capital at the end of test period: $1289.1396476031045
# profit gained: 1189.1396476031045%
#
#
# Capital at the end of test period if Buy and Hold: $778.7940878989605
# profit gained: 678.7940878989605%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.793269      9.090909       9.090909      92.571429
# 1       0.778846     20.000000       3.571429      91.428571
# 2       0.798077     33.333333       4.000000      91.111111
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         54.545455           81.818182          87.356322     -28.853099
# 1         60.000000           64.285714          86.781609      15.773396
# 2        100.000000           48.000000          86.592179    1189.139648
#
#    buy_n_hold profit
# 0         400.940691
# 1         604.110753
# 2         678.794088

# %%
Sichuan_Swellfun_data_acc = []
Wuliangye_Yibin_data_acc = []
Kweichow_Moutai_data_acc = []

Sichuan_Swellfun_data_correct_buys = []
Wuliangye_Yibin_data_correct_buys = []
Kweichow_Moutai_data_correct_buys = []

Sichuan_Swellfun_data_correct_sells = []
Wuliangye_Yibin_data_correct_sells = []
Kweichow_Moutai_data_correct_sells = []

Sichuan_Swellfun_data_correct_holds = []
Wuliangye_Yibin_data_correct_holds = []
Kweichow_Moutai_data_correct_holds = []

Sichuan_Swellfun_data_correct_low_buys = []
Wuliangye_Yibin_data_correct_low_buys = []
Kweichow_Moutai_data_correct_low_buys = []

Sichuan_Swellfun_data_correct_high_sells = []
Wuliangye_Yibin_data_correct_high_sells = []
Kweichow_Moutai_data_correct_high_sells = []

Sichuan_Swellfun_data_correct_mid_holds = []
Wuliangye_Yibin_data_correct_mid_holds = []
Kweichow_Moutai_data_correct_mid_holds = []

Sichuan_Swellfun_data_profit = []
Wuliangye_Yibin_data_profit = []
Kweichow_Moutai_data_profit = []

for key,value in nr_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    Sichuan_Swellfun_data_acc.append(acc[0])
    Wuliangye_Yibin_data_acc.append(acc[1])
    Kweichow_Moutai_data_acc.append(acc[2])
    
    Sichuan_Swellfun_data_correct_buys.append(correct_buys[0])
    Wuliangye_Yibin_data_correct_buys.append(correct_buys[1]) 
    Kweichow_Moutai_data_correct_buys.append(correct_buys[2]) 

    Sichuan_Swellfun_data_correct_sells.append(correct_sells[0]) 
    Wuliangye_Yibin_data_correct_sells.append(correct_sells[1]) 
    Kweichow_Moutai_data_correct_sells.append(correct_sells[2]) 

    Sichuan_Swellfun_data_correct_holds.append(correct_holds[0]) 
    Wuliangye_Yibin_data_correct_holds.append(correct_holds[1])  
    Kweichow_Moutai_data_correct_holds.append(correct_holds[2])  

    Sichuan_Swellfun_data_correct_low_buys.append(correct_low_buys[0])  
    Wuliangye_Yibin_data_correct_low_buys.append(correct_low_buys[1])  
    Kweichow_Moutai_data_correct_low_buys.append(correct_low_buys[2])  

    Sichuan_Swellfun_data_correct_high_sells.append(correct_high_sells[0]) 
    Wuliangye_Yibin_data_correct_high_sells.append(correct_high_sells[1]) 
    Kweichow_Moutai_data_correct_high_sells.append(correct_high_sells[2]) 

    Sichuan_Swellfun_data_correct_mid_holds.append(correct_mid_holds[0])  
    Wuliangye_Yibin_data_correct_mid_holds.append(correct_mid_holds[1])  
    Kweichow_Moutai_data_correct_mid_holds.append(correct_mid_holds[2])   

    Sichuan_Swellfun_data_profit.append(profit[0]) 
    Wuliangye_Yibin_data_profit.append(profit[1]) 
    Kweichow_Moutai_data_profit.append(profit[2])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(Sichuan_Swellfun_data_acc)
plt.plot(Wuliangye_Yibin_data_acc)
plt.plot(Kweichow_Moutai_data_acc)

plt.title('Non-Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Sichuan_Swellfun_data_acc','Wuliangye_Yibin_data_acc','Kweichow_Moutai_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_profit")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_profit")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_profit")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_profit')

# %%
Sichuan_Swellfun_data_acc = []
Wuliangye_Yibin_data_acc = []
Kweichow_Moutai_data_acc = []

Sichuan_Swellfun_data_correct_buys = []
Wuliangye_Yibin_data_correct_buys = []
Kweichow_Moutai_data_correct_buys = []

Sichuan_Swellfun_data_correct_sells = []
Wuliangye_Yibin_data_correct_sells = []
Kweichow_Moutai_data_correct_sells = []

Sichuan_Swellfun_data_correct_holds = []
Wuliangye_Yibin_data_correct_holds = []
Kweichow_Moutai_data_correct_holds = []

Sichuan_Swellfun_data_correct_low_buys = []
Wuliangye_Yibin_data_correct_low_buys = []
Kweichow_Moutai_data_correct_low_buys = []

Sichuan_Swellfun_data_correct_high_sells = []
Wuliangye_Yibin_data_correct_high_sells = []
Kweichow_Moutai_data_correct_high_sells = []

Sichuan_Swellfun_data_correct_mid_holds = []
Wuliangye_Yibin_data_correct_mid_holds = []
Kweichow_Moutai_data_correct_mid_holds = []

Sichuan_Swellfun_data_profit = []
Wuliangye_Yibin_data_profit = []
Kweichow_Moutai_data_profit = []

for key,value in r_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    Sichuan_Swellfun_data_acc.append(acc[0])
    Wuliangye_Yibin_data_acc.append(acc[1])
    Kweichow_Moutai_data_acc.append(acc[2])
    
    Sichuan_Swellfun_data_correct_buys.append(correct_buys[0])
    Wuliangye_Yibin_data_correct_buys.append(correct_buys[1]) 
    Kweichow_Moutai_data_correct_buys.append(correct_buys[2]) 

    Sichuan_Swellfun_data_correct_sells.append(correct_sells[0]) 
    Wuliangye_Yibin_data_correct_sells.append(correct_sells[1]) 
    Kweichow_Moutai_data_correct_sells.append(correct_sells[2]) 

    Sichuan_Swellfun_data_correct_holds.append(correct_holds[0]) 
    Wuliangye_Yibin_data_correct_holds.append(correct_holds[1])  
    Kweichow_Moutai_data_correct_holds.append(correct_holds[2])  

    Sichuan_Swellfun_data_correct_low_buys.append(correct_low_buys[0])  
    Wuliangye_Yibin_data_correct_low_buys.append(correct_low_buys[1])  
    Kweichow_Moutai_data_correct_low_buys.append(correct_low_buys[2])  

    Sichuan_Swellfun_data_correct_high_sells.append(correct_high_sells[0]) 
    Wuliangye_Yibin_data_correct_high_sells.append(correct_high_sells[1]) 
    Kweichow_Moutai_data_correct_high_sells.append(correct_high_sells[2]) 

    Sichuan_Swellfun_data_correct_mid_holds.append(correct_mid_holds[0])  
    Wuliangye_Yibin_data_correct_mid_holds.append(correct_mid_holds[1])  
    Kweichow_Moutai_data_correct_mid_holds.append(correct_mid_holds[2])   

    Sichuan_Swellfun_data_profit.append(profit[0]) 
    Wuliangye_Yibin_data_profit.append(profit[1]) 
    Kweichow_Moutai_data_profit.append(profit[2])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(Sichuan_Swellfun_data_acc)
plt.plot(Wuliangye_Yibin_data_acc)
plt.plot(Kweichow_Moutai_data_acc)

plt.title('Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Sichuan_Swellfun_data_acc','Wuliangye_Yibin_data_acc','Kweichow_Moutai_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(Sichuan_Swellfun_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Sichuan_Swellfun_data_profit")

plt.subplot(3, 4, 2)
plt.plot(Wuliangye_Yibin_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Wuliangye_Yibin_data_profit")

plt.subplot(3, 4, 3)
plt.plot(Kweichow_Moutai_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Kweichow_Moutai_data_profit")
# Out:
# Text(0.5, 1.0, 'Kweichow_Moutai_data_profit')
