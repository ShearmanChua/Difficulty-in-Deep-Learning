# %%
import os
seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
experiment = 'Pharma LSTM Experiment'

# %%
import requests
import lxml
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.utils import compute_class_weight
import tensorflow as tf
from pil import Image
from sklearn import preprocessing
import tensorflow_addons as tfa
import glob
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
import math

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
# gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
np.random.seed(seed)
tf.random.set_seed(seed)

session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, 
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), 
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)

# %%
def pred_acc(actual, predictions, logger):

    hold = 0
    sell = 0
    buy = 0
    pred_hold = 0
    pred_sell = 0
    pred_buy = 0
    buy_buy = 0
    buy_sell = 0
    buy_hold = 0
    sell_buy = 0
    sell_sell = 0
    sell_hold = 0
    hold_buy = 0
    hold_sell = 0
    hold_hold = 0

    for i in range (0,len(actual)):
        if actual[i]==1 and predictions[i] == 1:
            buy_buy += 1
            buy += 1
            pred_buy += 1
        elif actual[i]==1 and predictions[i] == 0:
            buy_sell += 1
            buy += 1
            pred_sell += 1
        elif actual[i]==1 and predictions[i] == 2:
            buy_hold += 1
            buy += 1
            pred_hold += 1
        elif actual[i]==0 and predictions[i] == 1:
            sell_buy += 1
            sell += 1
            pred_buy += 1
        elif actual[i]==0 and predictions[i] == 0:
            sell_sell += 1
            sell += 1
            pred_sell += 1
        elif actual[i]==0 and predictions[i] == 2:
            sell_hold += 1
            sell += 1
            pred_hold += 1
        elif actual[i]==2 and predictions[i] == 1:
            hold_buy += 1
            hold += 1
            pred_buy += 1
        elif actual[i]==2 and predictions[i] == 0:
            hold_sell += 1
            hold += 1
            pred_sell += 1
        elif actual[i]==2 and predictions[i] == 2:
            hold_hold += 1
            hold += 1
            pred_hold += 1

    print("number of predictions: " + str(len(actual)))
    print("actual predicted buys: " + str(buy_buy) )
    print("actual buys but predicted sell: " + str(buy_sell) )
    print("actual buys but predicted hold: " + str(buy_hold))
    print("actual sells but predicted buy: " + str(sell_buy) )
    print("actual predicted sells: " + str(sell_sell))
    print("actual sells but predicted hold: " + str(sell_hold) )
    print("actual holds but predicted buy: " + str(hold_buy) )
    print("actual holds but predicted sell: " + str(hold_sell))
    print("actual predicted holds: " + str(hold_hold) )
    
    if pred_buy !=0:
        Percentage_buys_correct = 100*buy_buy/pred_buy
    else:
        Percentage_buys_correct = 0
        
    if pred_sell !=0:
        Percentage_sells_correct = 100*sell_sell/pred_sell
    else:
        Percentage_sells_correct = 0
        
    if pred_hold !=0:
        Percentage_holds_correct = 100*hold_hold/pred_hold
    else:
        Percentage_holds_correct = 0

    print("Percentage buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage holds correct: " + str(Percentage_holds_correct) + "%")

    print("actual buys: " + str(buy))
    print("actual sells: " + str(sell))
    print("actual holds: " + str(hold))
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def correct_maxima_minima(predictions, price, logger):
    correct_maxima = 0 
    correct_minima = 0
    correct_hold = 0

    hold = 0
    buy = 0
    sell = 0

#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):
        if i < 4:
            prices = price[i:i+9]
            prices.sort(key = float)
#             if i == 0:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1

        else:
            prices = price[i:i+5]
            prices = prices + price[i-4:i] 
            prices.sort(key = float)
#             if i == 10:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1
                    
    if buy !=0:
        Percentage_buys_correct = 100*correct_minima/buy
    else:
        Percentage_buys_correct = 0
        
    if sell !=0:
        Percentage_sells_correct = 100*correct_maxima/sell
    else:
        Percentage_sells_correct = 0
        
    if hold !=0:
        Percentage_holds_correct = 100*correct_hold/hold
    else:
        Percentage_holds_correct = 0

    print("Percentage low buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage high sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage mid holds correct: " + str(Percentage_holds_correct) + "%")
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %% [markdown]
# ## Prepare Test Data

# %%
nr_test_sets = ['VXRT','INO','NVAX']
nr_test_data = {}

for name in nr_test_sets:

    df = pd.read_csv("variation 7/initial_indicators/{}_data_test.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    labels = []
    data_15 = []
    sequential = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15.append(np.array(i[0:-1]))
            labels.append(i[-1])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_arr = min_max_scaler.fit_transform(data_15)
            sequential.append(data_15_arr)
            data_15 = data_15[1:15]
        else:
            data_15.append(np.array(i[0:-1]))
            count+= 1
        
    X = sequential
    X  = np.array(X).reshape(-1, 15, 4)
    y = labels
    y = np.array(y)
    
    y = to_categorical(y, 3)
    
    nr_test_data['{}_X'.format(name)] = X
    nr_test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d    EMA_12   willr_14    OBV_7  labels
# Date
# 2019-01-22         1.95  2.010695 -57.142843  16000.0     2.0
# 2019-01-23         1.85  1.985973 -69.230761    800.0     1.0
# 2019-01-24         1.81  1.958900 -75.384620 -18800.0     2.0
# 2019-01-25         1.83  1.939069 -72.307681  60700.0     2.0
# 2019-01-28         1.87  1.928443 -71.666669  82700.0     2.0
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2019-01-22         5.09  4.742046  -0.840315  6313800.0     2.0
# 2019-01-23         5.00  4.781732  -8.403355  5520600.0     2.0
# 2019-01-24         4.78  4.781465 -35.164808  4872000.0     2.0
# 2019-01-25         5.01  4.816624 -11.111072  6179900.0     0.0
# 2019-01-28         5.10  4.860221  -1.639381  7036300.0     2.0
#             previous_1d     EMA_12   willr_14      OBV_7  labels
# Date
# 2019-01-22    41.000000  42.251874 -47.761200  1797960.0     1.0
# 2019-01-23    40.400002  41.966970 -52.238800  1452070.0     2.0
# 2019-01-24    41.200001  41.848975 -68.888897  1666265.0     2.0
# 2019-01-25    41.799999  41.841440 -75.675691  1912795.0     2.0
# 2019-01-28    43.799999  42.142757 -48.648670  2352875.0     2.0

# %%
r_test_sets = ['VXRT','INO','NVAX']
r_test_data = {}

for name in r_test_sets:

    df = pd.read_csv("variation 7/initial_indicators/{}_data_test2.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    labels = []
    data_15 = []
    sequential = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15.append(np.array(i[0:-1]))
            labels.append(i[-1])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_arr = min_max_scaler.fit_transform(data_15)
            sequential.append(data_15_arr)
            data_15 = data_15[1:15]
        else:
            data_15.append(np.array(i[0:-1]))
            count+= 1
        
    X = sequential
    X  = np.array(X).reshape(-1, 15, 4)
    y = labels
    y = np.array(y)
    
    y = to_categorical(y, 3)
    
    r_test_data['{}_X'.format(name)] = X
    r_test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d    EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22         0.53  0.388757  -0.000000   7111600.0     2.0
# 2020-01-23         0.59  0.419718 -30.952393  27158800.0     2.0
# 2020-01-24         0.53  0.436684 -45.238107  23794300.0     2.0
# 2020-01-27         0.49  0.444887 -58.974362  21329000.0     2.0
# 2020-01-28         0.64  0.474904 -21.052641  31022300.0     2.0
#             previous_1d    EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22         3.56  3.271874 -23.750009   7769400.0     2.0
# 2020-01-23         3.44  3.297739 -38.749995   5767800.0     2.0
# 2020-01-24         3.84  3.381164 -22.608698  18081400.0     2.0
# 2020-01-27         4.24  3.513293 -26.285720  42708100.0     0.0
# 2020-01-28         5.32  3.791248 -21.649473  83567200.0     2.0
#             previous_1d    EMA_12   willr_14        OBV_7  labels
# Date
# 2020-01-22         9.82  5.323560  -2.681389   78304500.0     2.0
# 2020-01-23         7.09  5.595320 -45.741321   61383300.0     2.0
# 2020-01-24         7.66  5.912963 -36.750789   78092700.0     2.0
# 2020-01-27         7.80  6.203277 -34.542582   88646300.0     2.0
# 2020-01-28         8.50  6.556619 -23.501575  105388400.0     2.0

# %% [markdown]
# ## Train Vaxart, Inc Stock Data

# %% [markdown]
# ### Creating Training Data and Model

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []

seed = 10
df = pd.read_csv('variation 7/initial_indicators/VXRT_data.csv')
df.set_index('Date', inplace=True)
print(df.head())

plt.figure(figsize=(15,5))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
plt.show()

labels = []
data_15 = []
sequential = []
count = 0

for i in df.values:
    if count == 14:
        data_15.append(np.array(i[0:-1]))
        labels.append(i[-1])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_arr = min_max_scaler.fit_transform(data_15)
        sequential.append(data_15_arr)
        data_15 = data_15[1:15]
    else:
        data_15.append(np.array(i[0:-1]))
        count+= 1
        
X = sequential
X  = np.array(X).reshape(-1, 15, 4)
y = labels
y = np.array(y)

X.shape
# Out:
#             previous_1d      EMA_12   willr_14    OBV_7  labels
# Date
# 2000-01-21      437.250  350.035133  -6.976744  42909.0     0.0
# 2000-01-24      515.625  375.510497 -10.606061  67630.0     2.0
# 2000-01-25      424.875  383.105036 -43.939394  53407.0     2.0
# 2000-01-26      453.750  393.973492 -33.333333  57201.0     2.0
# 2000-01-27      420.750  398.092955 -50.000000  54669.0     2.0
# (4745, 15, 4)

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization,Activation
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(LSTM(100, input_shape=(X_train.shape[1:]), return_sequences=True,kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(LSTM(100, kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# model.add(Dense(100, kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))

model.add(Dense(75, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(50, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "DBS_CNN_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))
print(d_class_weights)

epochs = 0 
histories = {}
nr_log_hist = {}
r_log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    nr_log  = pd.DataFrame(columns = column_names)
    r_log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['VXRT','INO','NVAX']
    for name in test_sets:
        
        print('\n')
        print("Non-Recession")
        print('\n')
        
        X = nr_test_data['{}_X'.format(name)]
        y = nr_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("variation 7/initial_indicators/{}_data_test.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(nr_log)
        nr_log.loc[df_length] = logger
        print(nr_log.head(20))
        logger = []
        
        print('\n')
        print("Recession")
        print('\n')
        
        X = r_test_data['{}_X'.format(name)]
        y = r_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("variation 7/initial_indicators/{}_data_test2.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(r_log)
        r_log.loc[df_length] = logger
        print(r_log.head(20))
        logger = []

    nr_log.to_csv('{}_{}_{}epochs.csv'.format(experiment,'VaxartModel',epochs))
    nr_log_hist['{}_epochs_logs'.format(epochs)] = nr_log
    r_log.to_csv('{}_{}_{}epochs.csv'.format(experiment,'VaxartModel',epochs))
    r_log_hist['{}_epochs_logs'.format(epochs)] = r_log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 2 ... 0 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# {0: 6.8768115942028984, 1: 7.230476190476191, 2: 0.3681505188633498}
#
#
#
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  1/30 [>.............................] - ETA: 0s - loss: 0.3232 - accuracy: 0.5859 - mse: 0.3087 - weighted_accuracy: 0.2430 - weighted_mse: 0.4080WARNING:tensorflow:From C:\Users\Shearman Chua\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/30 [=>............................] - ETA: 1s - loss: 0.3336 - accuracy: 0.5781 - mse: 0.3190 - weighted_accuracy: 0.2992 - weighted_mse: 0.4622WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0109s vs `on_train_batch_end` time: 0.1207s). Check your callbacks.
# 30/30 [==============================] - 1s 49ms/step - loss: 0.2936 - accuracy: 0.5192 - mse: 0.4518 - weighted_accuracy: 0.3142 - weighted_mse: 0.5380 - val_loss: 0.2993 - val_accuracy: 0.0464 - val_mse: 0.3546 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.3546
# Epoch 2/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2119 - accuracy: 0.3596 - mse: 0.7794 - weighted_accuracy: 0.4162 - weighted_mse: 0.7783 - val_loss: 0.2902 - val_accuracy: 0.0464 - val_mse: 0.3837 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.3837
# Epoch 3/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1923 - accuracy: 0.3317 - mse: 1.0204 - weighted_accuracy: 0.4477 - weighted_mse: 1.0131 - val_loss: 0.2792 - val_accuracy: 0.0464 - val_mse: 0.4188 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.4188
# Epoch 4/20
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1853 - accuracy: 0.3274 - mse: 1.1493 - weighted_accuracy: 0.4973 - weighted_mse: 1.1380 - val_loss: 0.2689 - val_accuracy: 0.0464 - val_mse: 0.4611 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.4611
# Epoch 5/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1812 - accuracy: 0.3195 - mse: 1.2168 - weighted_accuracy: 0.4976 - weighted_mse: 1.1941 - val_loss: 0.2596 - val_accuracy: 0.0464 - val_mse: 0.5063 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.5063
# Epoch 6/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1782 - accuracy: 0.3080 - mse: 1.2523 - weighted_accuracy: 0.5096 - weighted_mse: 1.2274 - val_loss: 0.2504 - val_accuracy: 0.0464 - val_mse: 0.5575 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.5575
# Epoch 7/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1756 - accuracy: 0.3106 - mse: 1.2556 - weighted_accuracy: 0.5338 - weighted_mse: 1.2243 - val_loss: 0.2426 - val_accuracy: 0.0464 - val_mse: 0.6107 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.6107
# Epoch 8/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1732 - accuracy: 0.2943 - mse: 1.2889 - weighted_accuracy: 0.5349 - weighted_mse: 1.2512 - val_loss: 0.2330 - val_accuracy: 0.0464 - val_mse: 0.6624 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.6624
# Epoch 9/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1706 - accuracy: 0.3232 - mse: 1.2783 - weighted_accuracy: 0.5505 - weighted_mse: 1.2399 - val_loss: 0.2247 - val_accuracy: 0.0464 - val_mse: 0.7247 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.7247
# Epoch 10/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1694 - accuracy: 0.3396 - mse: 1.2890 - weighted_accuracy: 0.5744 - weighted_mse: 1.2591 - val_loss: 0.2165 - val_accuracy: 0.0474 - val_mse: 0.7928 - val_weighted_accuracy: 0.0474 - val_weighted_mse: 0.7928
# Epoch 11/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1674 - accuracy: 0.2985 - mse: 1.3013 - weighted_accuracy: 0.5735 - weighted_mse: 1.2489 - val_loss: 0.2117 - val_accuracy: 0.0548 - val_mse: 0.8602 - val_weighted_accuracy: 0.0548 - val_weighted_mse: 0.8602
# Epoch 12/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1657 - accuracy: 0.3606 - mse: 1.2913 - weighted_accuracy: 0.5981 - weighted_mse: 1.2519 - val_loss: 0.2047 - val_accuracy: 0.1317 - val_mse: 0.9108 - val_weighted_accuracy: 0.1317 - val_weighted_mse: 0.9108
# Epoch 13/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1635 - accuracy: 0.3646 - mse: 1.3131 - weighted_accuracy: 0.6194 - weighted_mse: 1.2648 - val_loss: 0.2043 - val_accuracy: 0.1486 - val_mse: 0.9952 - val_weighted_accuracy: 0.1486 - val_weighted_mse: 0.9952
# Epoch 14/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1630 - accuracy: 0.3467 - mse: 1.3242 - weighted_accuracy: 0.6105 - weighted_mse: 1.2724 - val_loss: 0.1998 - val_accuracy: 0.2129 - val_mse: 1.0509 - val_weighted_accuracy: 0.2129 - val_weighted_mse: 1.0509
# Epoch 15/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1605 - accuracy: 0.3338 - mse: 1.3409 - weighted_accuracy: 0.6232 - weighted_mse: 1.2767 - val_loss: 0.1977 - val_accuracy: 0.2813 - val_mse: 1.0853 - val_weighted_accuracy: 0.2813 - val_weighted_mse: 1.0853
# Epoch 16/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1589 - accuracy: 0.3981 - mse: 1.3270 - weighted_accuracy: 0.6399 - weighted_mse: 1.2874 - val_loss: 0.1944 - val_accuracy: 0.3087 - val_mse: 1.1286 - val_weighted_accuracy: 0.3087 - val_weighted_mse: 1.1286
# Epoch 17/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1580 - accuracy: 0.3651 - mse: 1.3443 - weighted_accuracy: 0.6491 - weighted_mse: 1.2869 - val_loss: 0.1951 - val_accuracy: 0.2898 - val_mse: 1.1534 - val_weighted_accuracy: 0.2898 - val_weighted_mse: 1.1534
# Epoch 18/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1562 - accuracy: 0.3601 - mse: 1.3537 - weighted_accuracy: 0.6611 - weighted_mse: 1.2883 - val_loss: 0.1935 - val_accuracy: 0.2982 - val_mse: 1.1825 - val_weighted_accuracy: 0.2982 - val_weighted_mse: 1.1825
# Epoch 19/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1538 - accuracy: 0.3770 - mse: 1.3680 - weighted_accuracy: 0.6601 - weighted_mse: 1.3016 - val_loss: 0.1910 - val_accuracy: 0.3193 - val_mse: 1.2039 - val_weighted_accuracy: 0.3193 - val_weighted_mse: 1.2039
# Epoch 20/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1521 - accuracy: 0.3923 - mse: 1.3743 - weighted_accuracy: 0.6555 - weighted_mse: 1.3194 - val_loss: 0.1915 - val_accuracy: 0.3119 - val_mse: 1.2573 - val_weighted_accuracy: 0.3119 - val_weighted_mse: 1.2573
# Validation loss: 0.19150269031524658
# Validation accuracy: 0.31190726161003113
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1865 - accuracy: 0.3670 - mse: 1.2714 - weighted_accuracy: 0.3670 - weighted_mse: 1.2714
# Test loss: 0.18650217354297638
# Test accuracy: 0.3669724762439728
#
#
# number of predictions: 218
# actual predicted buys: 5
# actual buys but predicted sell: 2
# actual buys but predicted hold: 1
# actual sells but predicted buy: 5
# actual predicted sells: 1
# actual sells but predicted hold: 2
# actual holds but predicted buy: 84
# actual holds but predicted sell: 44
# actual predicted holds: 74
# Percentage buys correct: 5.319148936170213%
# Percentage sells correct: 2.127659574468085%
# Percentage holds correct: 96.1038961038961%
# actual buys: 8
# actual sells: 8
# actual holds: 202
#
#
# Percentage low buys correct: 47.31182795698925%
# Percentage high sells correct: 46.808510638297875%
# Percentage mid holds correct: 79.22077922077922%
#
#
# Capital: 100
# Share price: $0.8158253039580221
# Shares owned at the moment: 122
# Cash capital at the moment: $0.19560352764338518
#
#
# Price increase from previously bought: -5.021398240979325%
# Share price: $0.7769903300284726
# Shares owned at the moment: 0
# Cash capital at the moment: $94.72774353539249
#
#
# Share price: $0.34980584827778816
# Shares owned at the moment: 270
# Cash capital at the moment: $0.020433658043430114
#
#
# Price increase from previously bought: -37.64027001755195%
# Share price: $0.21873786190057493
# Shares owned at the moment: 0
# Cash capital at the moment: $58.91724350873748
#
#
# Share price: $0.21873786190057493
# Shares owned at the moment: 268
# Cash capital at the moment: $0.13428671516267343
#
#
# Price increase from previously bought: -6.9137707424601675%
# Share price: $0.20417476837771503
# Shares owned at the moment: 0
# Cash capital at the moment: $54.70264783609593
#
#
# Share price: $0.20417476837771503
# Shares owned at the moment: 267
# Cash capital at the moment: $0.038069355564672946
#
#
# Price increase from previously bought: 6.838853880952711%
# Share price: $0.21873786190057493
# Shares owned at the moment: 0
# Cash capital at the moment: $58.28047020791768
#
#
# Share price: $0.21873786190057493
# Shares owned at the moment: 265
# Cash capital at the moment: $0.15553158740527806
#
#
# Price increase from previously bought: -2.4874207968094364%
# Share price: $0.21388349739295492
# Shares owned at the moment: 0
# Cash capital at the moment: $56.678790797813214
#
#
# Share price: $0.15077670092530576
# Shares owned at the moment: 374
# Cash capital at the moment: $0.13323081484718102
#
#
# Price increase from previously bought: 35.043959943572524%
# Share price: $0.20417476837771503
# Shares owned at the moment: 0
# Cash capital at the moment: $76.28460043883612
#
#
# Share price: $0.19446603936247508
# Shares owned at the moment: 391
# Cash capital at the moment: $0.039279439283859574
#
#
# Price increase from previously bought: 12.1727902537482%
# Share price: $0.21873786190057493
# Shares owned at the moment: 0
# Cash capital at the moment: $85.33058555640007
#
#
# Share price: $0.21388349739295492
# Shares owned at the moment: 397
# Cash capital at the moment: $0.18532978311820614
#
#
# Price increase from previously bought: -18.381506202845898%
# Share price: $0.1750485523977004
# Shares owned at the moment: 0
# Cash capital at the moment: $69.48849582792508
#
#
# Share price: $0.1896116459205603
# Shares owned at the moment: 365
# Cash capital at the moment: $0.0899223773278095
#
#
# Price increase from previously bought: -74.31537952798753%
# Share price: $0.048834959462401954
# Shares owned at the moment: 0
# Cash capital at the moment: $17.865664490544134
#
#
# Share price: $0.034271851472394664
# Shares owned at the moment: 519
# Cash capital at the moment: $0.029659076357329894
#
#
# Price increase from previously bought: 27.976644674746233%
# Share price: $0.043980580487634584
# Shares owned at the moment: 0
# Cash capital at the moment: $22.7928090659387
#
#
# Share price: $0.02456310799000732
# Shares owned at the moment: 925
# Cash capital at the moment: $0.00945176923234925
#
#
# Price increase from previously bought: -0.27424582398404285%
# Share price: $0.02456310799000732
# Shares owned at the moment: 0
# Cash capital at the moment: $22.66784425403954
#
#
#
#
# Capital at the end of test period: $22.66784425403954
# profit gained: -77.33215574596046%
#
#
# Capital at the end of test period if Buy and Hold: $2.5934579490563006
# profit gained: -97.4065420509437%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.366972      5.319149        2.12766      96.103896
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.311828           46.808511          79.220779     -77.332156
#
#    buy_n_hold profit
# 0         -97.406542
#
#
# Recession
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2001 - accuracy: 0.2329 - mse: 1.3018 - weighted_accuracy: 0.2329 - weighted_mse: 1.3018
# Test loss: 0.20012745261192322
# Test accuracy: 0.232876718044281
#
#
# number of predictions: 219
# actual predicted buys: 7
# actual buys but predicted sell: 0
# actual buys but predicted hold: 1
# actual sells but predicted buy: 2
# actual predicted sells: 5
# actual sells but predicted hold: 1
# actual holds but predicted buy: 102
# actual holds but predicted sell: 62
# actual predicted holds: 39
# Percentage buys correct: 6.306306306306307%
# Percentage sells correct: 7.462686567164179%
# Percentage holds correct: 95.1219512195122%
# actual buys: 8
# actual sells: 8
# actual holds: 203
#
#
# Percentage low buys correct: 41.81818181818182%
# Percentage high sells correct: 49.25373134328358%
# Percentage mid holds correct: 87.8048780487805%
#
#
# Capital: 100
# Share price: $0.013138736570059003
# Shares owned at the moment: 7590
# Cash capital at the moment: $0.002751154193603611
#
#
# Price increase from previously bought: 90.25552590774328%
# Share price: $0.025065914582985994
# Shares owned at the moment: 0
# Cash capital at the moment: $189.72985453692394
#
#
# Share price: $0.07465787905337797
# Shares owned at the moment: 2534
# Cash capital at the moment: $0.02653558548070123
#
#
# Price increase from previously bought: -25.429986495266654%
# Share price: $0.05582548956630568
# Shares owned at the moment: 0
# Cash capital at the moment: $141.0993062224565
#
#
# Share price: $0.05017576972685583
# Shares owned at the moment: 2804
# Cash capital at the moment: $0.019542547988976366
#
#
# Price increase from previously bought: 44.641647912735664%
# Share price: $0.07277464160133483
# Shares owned at the moment: 0
# Cash capital at the moment: $203.51847233674394
#
#
# Share price: $0.11483365626355417
# Shares owned at the moment: 1767
# Cash capital at the moment: $0.04939627484503717
#
#
# Price increase from previously bought: 11.719231426684518%
# Share price: $0.1286440792118447
# Shares owned at the moment: 0
# Cash capital at the moment: $226.73837050026447
#
#
# Share price: $0.11295041881151101
# Shares owned at the moment: 2001
# Cash capital at the moment: $0.10304454131588159
#
#
# Price increase from previously bought: -1.382739722892179%
# Share price: $0.1116949271768156
# Shares owned at the moment: 0
# Cash capital at the moment: $222.98996456160168
#
#
# Share price: $0.5015254389491263
# Shares owned at the moment: 443
# Cash capital at the moment: $0.203211741138972
#
#
# Price increase from previously bought: 78.6146108329034%
# Share price: $0.8982611547122618
# Shares owned at the moment: 0
# Cash capital at the moment: $397.03859662694265
#
#
# Share price: $0.7162147180150162
# Shares owned at the moment: 552
# Cash capital at the moment: $0.6008583407069068
#
#
# Price increase from previously bought: -39.694992658754224%
# Share price: $0.4331010999583029
# Shares owned at the moment: 0
# Cash capital at the moment: $239.0152180479534
#
#
# Share price: $0.40924672896580805
# Shares owned at the moment: 582
# Cash capital at the moment: $0.17862240014332542
#
#
# Price increase from previously bought: -3.0277110481333636%
# Share price: $0.39794727432026755
# Shares owned at the moment: 0
# Cash capital at the moment: $231.14702144198947
#
#
# Share price: $0.4023415100083424
# Shares owned at the moment: 572
# Cash capital at the moment: $0.37479452197447927
#
#
# Price increase from previously bought: -6.342464015233295%
# Share price: $0.37785940816514074
# Shares owned at the moment: 0
# Cash capital at the moment: $215.9160031433912
#
#
# Share price: $0.3401946291909961
# Shares owned at the moment: 632
# Cash capital at the moment: $0.3217392291477381
#
#
# Price increase from previously bought: -21.988566037367175%
# Share price: $0.26612053294412086
# Shares owned at the moment: 0
# Cash capital at the moment: $168.04739856357523
#
#
# Share price: $0.16442562073394612
# Shares owned at the moment: 1019
# Cash capital at the moment: $0.03692933998243575
#
#
# Price increase from previously bought: 59.50105646395565%
# Share price: $0.26298181882402316
# Shares owned at the moment: 0
# Cash capital at the moment: $267.27846191986237
#
#
# Share price: $0.43435659159299833
# Shares owned at the moment: 613
# Cash capital at the moment: $0.2856546490764913
#
#
#
#
# Capital at the end of test period: $249.31275279187426
# profit gained: 149.31275279187426%
#
#
# Capital at the end of test period if Buy and Hold: $3238.165410975435
# profit gained: 3138.165410975435%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.232877      6.306306       7.462687      95.121951
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         41.818182           49.253731          87.804878     149.312753
#
#    buy_n_hold profit
# 0        3138.165411
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1917 - accuracy: 0.2936 - mse: 1.2546 - weighted_accuracy: 0.2936 - weighted_mse: 1.2546
# Test loss: 0.1916513592004776
# Test accuracy: 0.29357796907424927
#
#
# number of predictions: 218
# actual predicted buys: 7
# actual buys but predicted sell: 2
# actual buys but predicted hold: 1
# actual sells but predicted buy: 2
# actual predicted sells: 3
# actual sells but predicted hold: 4
# actual holds but predicted buy: 97
# actual holds but predicted sell: 48
# actual predicted holds: 54
# Percentage buys correct: 6.60377358490566%
# Percentage sells correct: 5.660377358490566%
# Percentage holds correct: 91.52542372881356%
# actual buys: 10
# actual sells: 9
# actual holds: 199
#
#
# Percentage low buys correct: 47.61904761904762%
# Percentage high sells correct: 50.943396226415096%
# Percentage mid holds correct: 86.44067796610169%
#
#
# Capital: 100
# Share price: $0.9879411977395466
# Shares owned at the moment: 100
# Cash capital at the moment: $0.9341963966669624
#
#
# Price increase from previously bought: -48.14795776822605%
# Share price: $0.5136764232164649
# Shares owned at the moment: 0
# Cash capital at the moment: $52.16057770192892
#
#
# Share price: $0.5945587858253497
# Shares owned at the moment: 87
# Cash capital at the moment: $0.2917151456147806
#
#
# Price increase from previously bought: 5.27567599616785%
# Share price: $0.6276470768699184
# Shares owned at the moment: 0
# Cash capital at the moment: $54.746846270156546
#
#
# Share price: $0.6092646539989853
# Shares owned at the moment: 89
# Cash capital at the moment: $0.3731745401805924
#
#
# Price increase from previously bought: 7.548805360685473%
# Share price: $0.6570588132171898
# Shares owned at the moment: 0
# Cash capital at the moment: $58.69059377197558
#
#
# Share price: $0.6533823461737808
# Shares owned at the moment: 89
# Cash capital at the moment: $0.37964963328305856
#
#
# Price increase from previously bought: -67.04987780502599%
# Share price: $0.21588232973867671
# Shares owned at the moment: 0
# Cash capital at the moment: $19.540339779821746
#
#
# Share price: $0.34455885156576593
# Shares owned at the moment: 56
# Cash capital at the moment: $0.19198202899772454
#
#
# Price increase from previously bought: -27.940396622807917%
# Share price: $0.24897053312935702
# Shares owned at the moment: 0
# Cash capital at the moment: $14.095990422139796
#
#
# Share price: $0.14235290121660982
# Shares owned at the moment: 98
# Cash capital at the moment: $0.1070419960341571
#
#
# Price increase from previously bought: -51.78544727808438%
# Share price: $0.0688235603484315
# Shares owned at the moment: 0
# Cash capital at the moment: $6.833202960666541
#
#
# Share price: $0.13867643417320108
# Shares owned at the moment: 49
# Cash capital at the moment: $0.019371036674849407
#
#
# Price increase from previously bought: 52.60263810523658%
# Share price: $0.21220586269526776
# Shares owned at the moment: 0
# Cash capital at the moment: $10.388863568744782
#
#
# Share price: $0.09455882965229377
# Shares owned at the moment: 109
# Cash capital at the moment: $0.05360712745648577
#
#
# Price increase from previously bought: 123.80130735199214%
# Share price: $0.21220586269526776
# Shares owned at the moment: 0
# Cash capital at the moment: $23.120437453897765
#
#
# Share price: $0.23058819791231255
# Shares owned at the moment: 99
# Cash capital at the moment: $0.2294282236971945
#
#
# Price increase from previously bought: 9.265875712635086%
# Share price: $0.25264708782665435
# Shares owned at the moment: 0
# Cash capital at the moment: $25.172706748875168
#
#
#
#
# Capital at the end of test period: $25.172706748875168
# profit gained: -74.82729325112483%
#
#
# Capital at the end of test period if Buy and Hold: $26.129427230180067
# profit gained: -73.87057276981993%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.366972      5.319149       2.127660      96.103896
# 1       0.293578      6.603774       5.660377      91.525424
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.311828           46.808511          79.220779     -77.332156
# 1         47.619048           50.943396          86.440678     -74.827293
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
#
#
# Recession
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1907 - accuracy: 0.3242 - mse: 1.2566 - weighted_accuracy: 0.3242 - weighted_mse: 1.2566
# Test loss: 0.19073379039764404
# Test accuracy: 0.32420089840888977
#
#
# number of predictions: 219
# actual predicted buys: 6
# actual buys but predicted sell: 1
# actual buys but predicted hold: 1
# actual sells but predicted buy: 1
# actual predicted sells: 5
# actual sells but predicted hold: 5
# actual holds but predicted buy: 94
# actual holds but predicted sell: 46
# actual predicted holds: 60
# Percentage buys correct: 5.9405940594059405%
# Percentage sells correct: 9.615384615384615%
# Percentage holds correct: 90.9090909090909%
# actual buys: 8
# actual sells: 11
# actual holds: 200
#
#
# Percentage low buys correct: 49.504950495049506%
# Percentage high sells correct: 53.84615384615385%
# Percentage mid holds correct: 86.15384615384616%
#
#
# Capital: 100
# Share price: $0.011763675119632519
# Shares owned at the moment: 8477
# Cash capital at the moment: $0.005094157405039823
#
#
# Price increase from previously bought: 298.7532549584371%
# Share price: $0.04703703454523673
# Shares owned at the moment: 0
# Cash capital at the moment: $397.6415204073169
#
#
# Share price: $0.18566136408340334
# Shares owned at the moment: 2135
# Cash capital at the moment: $0.1644438053760382
#
#
# Price increase from previously bought: -5.958230127130615%
# Share price: $0.17507938064421824
# Shares owned at the moment: 0
# Cash capital at the moment: $372.93098666717464
#
#
# Share price: $0.15744267990685046
# Shares owned at the moment: 2362
# Cash capital at the moment: $0.02870779985886429
#
#
# Price increase from previously bought: 16.48264046758994%
# Share price: $0.1838977226030758
# Shares owned at the moment: 0
# Cash capital at the moment: $433.2006209311556
#
#
# Share price: $0.1440387960926704
# Shares owned at the moment: 2999
# Cash capital at the moment: $0.04034748816178535
#
#
# Price increase from previously bought: 119.14755644369967%
# Share price: $0.3165255600984224
# Shares owned at the moment: 0
# Cash capital at the moment: $946.690036797809
#
#
# Share price: $0.28830685910221704
# Shares owned at the moment: 3274
# Cash capital at the moment: $0.17760929122357538
#
#
# Price increase from previously bought: 25.83613011340502%
# Share price: $0.3637918783801879
# Shares owned at the moment: 0
# Cash capital at the moment: $1187.9568189309625
#
#
# Share price: $0.35744266140523284
# Shares owned at the moment: 3314
# Cash capital at the moment: $0.1342853393043697
#
#
# Price increase from previously bought: 5.925708641365768%
# Share price: $0.3796648871782706
# Shares owned at the moment: 0
# Cash capital at the moment: $1254.883645498794
#
#
# Share price: $0.630458554017336
# Shares owned at the moment: 1984
# Cash capital at the moment: $0.6140924576809539
#
#
# Price increase from previously bought: 19.70047565796409%
# Share price: $0.7567372081770326
# Shares owned at the moment: 0
# Cash capital at the moment: $1497.8519552730997
#
#
# Share price: $0.6357495457369284
# Shares owned at the moment: 2349
# Cash capital at the moment: $0.36948920898066717
#
#
# Price increase from previously bought: -14.438968392209484%
# Share price: $0.5454497429162375
# Shares owned at the moment: 0
# Cash capital at the moment: $1278.1074663424192
#
#
# Share price: $0.291128759477212
# Shares owned at the moment: 4378
# Cash capital at the moment: $0.04071265145921643
#
#
# Price increase from previously bought: 10.600308625901821%
# Share price: $0.3228747770733774
# Shares owned at the moment: 0
# Cash capital at the moment: $1409.6992358001305
#
#
# Share price: $0.2886596008540045
# Shares owned at the moment: 4870
# Cash capital at the moment: $0.061105936691319584
#
#
# Price increase from previously bought: 5.331405974433379%
# Share price: $0.3048853514038746
# Shares owned at the moment: 0
# Cash capital at the moment: $1480.7695902048845
#
#
# Share price: $0.2583245166256841
# Shares owned at the moment: 5716
# Cash capital at the moment: $0.12605009563480962
#
#
# Price increase from previously bought: 27.50489379221921%
# Share price: $0.33028218566439
# Shares owned at the moment: 0
# Cash capital at the moment: $1882.8273176768294
#
#
# Share price: $0.2823104175183544
# Shares owned at the moment: 6651
# Cash capital at the moment: $0.017202648239162954
#
#
#
#
# Capital at the end of test period: $1715.7483763917644
# profit gained: 1615.7483763917644%
#
#
# Capital at the end of test period if Buy and Hold: $2186.7819938452512
# profit gained: 2086.7819938452512%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.232877      6.306306       7.462687      95.121951
# 1       0.324201      5.940594       9.615385      90.909091
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         41.818182           49.253731          87.804878     149.312753
# 1         49.504950           53.846154          86.153846    1615.748376
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2001 - accuracy: 0.3073 - mse: 1.3119 - weighted_accuracy: 0.3073 - weighted_mse: 1.3119
# Test loss: 0.20014303922653198
# Test accuracy: 0.30733945965766907
#
#
# number of predictions: 218
# actual predicted buys: 7
# actual buys but predicted sell: 1
# actual buys but predicted hold: 1
# actual sells but predicted buy: 4
# actual predicted sells: 3
# actual sells but predicted hold: 1
# actual holds but predicted buy: 105
# actual holds but predicted sell: 39
# actual predicted holds: 57
# Percentage buys correct: 6.0344827586206895%
# Percentage sells correct: 6.976744186046512%
# Percentage holds correct: 96.61016949152543%
# actual buys: 9
# actual sells: 8
# actual holds: 201
#
#
# Percentage low buys correct: 43.96551724137931%
# Percentage high sells correct: 55.81395348837209%
# Percentage mid holds correct: 87.93103448275862%
#
#
# Capital: 100
# Share price: $1.0050384330631763
# Shares owned at the moment: 99
# Cash capital at the moment: $0.2275734133440892
#
#
# Price increase from previously bought: -82.98293390591998%
# Share price: $0.1714983815749365
# Shares owned at the moment: 0
# Cash capital at the moment: $17.159222754879025
#
#
# Share price: $0.17645992485325548
# Shares owned at the moment: 96
# Cash capital at the moment: $0.17248454880523667
#
#
# Price increase from previously bought: 30.56979528616126%
# Share price: $0.23103697189027797
# Shares owned at the moment: 0
# Cash capital at the moment: $22.29104008969289
#
#
# Share price: $0.186383035068398
# Shares owned at the moment: 119
# Cash capital at the moment: $0.05046506832739084
#
#
# Price increase from previously bought: 12.999336640164817%
# Share price: $0.21119077511849751
# Shares owned at the moment: 0
# Cash capital at the moment: $25.113055126271068
#
#
# Share price: $0.191344578346717
# Shares owned at the moment: 130
# Cash capital at the moment: $0.16985425443890634
#
#
# Price increase from previously bought: -20.96129071119427%
# Share price: $0.15165218480315598
# Shares owned at the moment: 0
# Cash capital at the moment: $19.830422622782056
#
#
# Share price: $0.146690641524837
# Shares owned at the moment: 134
# Cash capital at the moment: $0.11982115705199803
#
#
# Price increase from previously bought: -52.21913567252254%
# Share price: $0.07028280406321093
# Shares owned at the moment: 0
# Cash capital at the moment: $9.51181768822497
#
#
# Share price: $0.04497890968527956
# Shares owned at the moment: 210
# Cash capital at the moment: $0.040271333973011636
#
#
# Price increase from previously bought: 58.028827724042856%
# Share price: $0.0712751127188747
# Shares owned at the moment: 0
# Cash capital at the moment: $14.966883627341547
#
#
# Share price: $0.04572314709165353
# Shares owned at the moment: 326
# Cash capital at the moment: $0.020146874094827183
#
#
# Price increase from previously bought: -43.01926214072552%
# Share price: $0.026125033398415175
# Shares owned at the moment: 0
# Cash capital at the moment: $8.513486669536494
#
#
# Share price: $0.018186552323852474
# Shares owned at the moment: 466
# Cash capital at the moment: $0.015247219818222746
#
#
# Price increase from previously bought: 519.3716933584246%
# Share price: $0.11295212357376334
# Shares owned at the moment: 0
# Cash capital at the moment: $52.50618865883216
#
#
# Share price: $0.07499627609224012
# Shares owned at the moment: 698
# Cash capital at the moment: $0.014832594489497808
#
#
# Price increase from previously bought: -33.59202916632364%
# Share price: $0.049940464792850824
# Shares owned at the moment: 0
# Cash capital at the moment: $34.77741629772949
#
#
# Share price: $0.05192508210417842
# Shares owned at the moment: 667
# Cash capital at the moment: $0.04814295239289379
#
#
# Price increase from previously bought: 64.99940001749354%
# Share price: $0.08591168313379415
# Shares owned at the moment: 0
# Cash capital at the moment: $57.19365209784542
#
#
# Share price: $0.04274622112466215
# Shares owned at the moment: 1334
# Cash capital at the moment: $0.013378605350290229
#
#
# Price increase from previously bought: -22.267046147159096%
# Share price: $0.03331927706660379
# Shares owned at the moment: 0
# Cash capital at the moment: $44.33906244428091
#
#
# Share price: $0.027861567631200616
# Shares owned at the moment: 1587
# Cash capital at the moment: $0.001159767031062131
#
#
# Price increase from previously bought: 0.6137254644015044%
# Share price: $0.028109650709742716
# Shares owned at the moment: 0
# Cash capital at the moment: $44.48849790028276
#
#
# Share price: $0.02538079599204115
# Shares owned at the moment: 1748
# Cash capital at the moment: $0.0008610198610909947
#
#
# Price increase from previously bought: 10.447919660695938%
# Share price: $0.028109650709742716
# Shares owned at the moment: 0
# Cash capital at the moment: $49.00140736952962
#
#
# Share price: $0.021163478290843897
# Shares owned at the moment: 2309
# Cash capital at the moment: $0.0005531996937762074
#
#
# Price increase from previously bought: 125.97570266286762%
# Share price: $0.047955835652270955
# Shares owned at the moment: 0
# Cash capital at the moment: $110.4260701533544
#
#
# Share price: $0.017442320832104626
# Shares owned at the moment: 6313
# Cash capital at the moment: $0.009886968891933634
#
#
#
#
# Capital at the end of test period: $105.13503362004866
# profit gained: 5.1350336200486595%
#
#
# Capital at the end of test period if Buy and Hold: $2.3797176202777375
# profit gained: -97.62028237972227%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.366972      5.319149       2.127660      96.103896
# 1       0.293578      6.603774       5.660377      91.525424
# 2       0.307339      6.034483       6.976744      96.610169
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.311828           46.808511          79.220779     -77.332156
# 1         47.619048           50.943396          86.440678     -74.827293
# 2         43.965517           55.813953          87.931034       5.135034
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
# 2         -97.620282
#
#
# Recession
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1943 - accuracy: 0.2192 - mse: 1.2328 - weighted_accuracy: 0.2192 - weighted_mse: 1.2328
# Test loss: 0.1942659318447113
# Test accuracy: 0.21917808055877686
#
#
# number of predictions: 219
# actual predicted buys: 4
# actual buys but predicted sell: 1
# actual buys but predicted hold: 3
# actual sells but predicted buy: 3
# actual predicted sells: 7
# actual sells but predicted hold: 0
# actual holds but predicted buy: 79
# actual holds but predicted sell: 85
# actual predicted holds: 37
# Percentage buys correct: 4.651162790697675%
# Percentage sells correct: 7.526881720430108%
# Percentage holds correct: 92.5%
# actual buys: 8
# actual sells: 10
# actual holds: 201
#
#
# Percentage low buys correct: 41.86046511627907%
# Percentage high sells correct: 43.47826086956522%
# Percentage mid holds correct: 85.0%
#
#
# Capital: 100
# Share price: $0.04473193603517206
# Shares owned at the moment: 2229
# Cash capital at the moment: $0.018318992689884794
#
#
# Price increase from previously bought: -5.341087726547977%
# Share price: $0.04245920669099701
# Shares owned at the moment: 0
# Cash capital at the moment: $94.39962638470807
#
#
# Share price: $0.03179487113936676
# Shares owned at the moment: 2960
# Cash capital at the moment: $0.027997561108023206
#
#
# Price increase from previously bought: 37.92715671058302%
# Share price: $0.04397435958711371
# Shares owned at the moment: 0
# Cash capital at the moment: $129.83415065192548
#
#
# Share price: $0.09426574266811717
# Shares owned at the moment: 1373
# Cash capital at the moment: $0.05136209072145448
#
#
# Price increase from previously bought: -26.352390003840952%
# Share price: $0.06961538380312837
# Shares owned at the moment: 0
# Cash capital at the moment: $95.37043376702205
#
#
# Share price: $0.23470863970492212
# Shares owned at the moment: 405
# Cash capital at the moment: $0.05202793905723979
#
#
# Price increase from previously bought: -1.9579666763839376%
# Share price: $0.2307459338404762
# Shares owned at the moment: 0
# Cash capital at the moment: $93.24713786063526
#
#
# Share price: $0.5790559484281369
# Shares owned at the moment: 160
# Cash capital at the moment: $0.34340149482497395
#
#
# Price increase from previously bought: 6.339617380246754%
# Share price: $0.6174592361459739
# Shares owned at the moment: 0
# Cash capital at the moment: $98.86519721427656
#
#
# Share price: $0.7832518087745554
# Shares owned at the moment: 125
# Cash capital at the moment: $0.6894783081908855
#
#
# Price increase from previously bought: 24.87125059870168%
# Share price: $0.9807459838583614
# Shares owned at the moment: 0
# Cash capital at the moment: $122.94559485853475
#
#
# Share price: $0.6947902213211395
# Shares owned at the moment: 176
# Cash capital at the moment: $0.32623743889475065
#
#
# Price increase from previously bought: -3.8625871499642472%
# Share price: $0.6697902152078423
# Shares owned at the moment: 0
# Cash capital at the moment: $117.8851368513144
#
#
# Share price: $0.5988111902413817
# Shares owned at the moment: 196
# Cash capital at the moment: $0.19538433246347608
#
#
# Price increase from previously bought: 1.9288167179468685%
# Share price: $0.6120396537793102
# Shares owned at the moment: 0
# Cash capital at the moment: $119.82526709982123
#
#
# Share price: $0.5429254289572745
# Shares owned at the moment: 220
# Cash capital at the moment: $0.053202844701701224
#
#
# Price increase from previously bought: -9.372724926236554%
# Share price: $0.49339162788187224
# Shares owned at the moment: 0
# Cash capital at the moment: $108.30085904384505
#
#
# Share price: $0.465128232630917
# Shares owned at the moment: 232
# Cash capital at the moment: $0.09435726105377285
#
#
# Price increase from previously bought: 6.772626694462058%
# Share price: $0.49799536296412134
# Shares owned at the moment: 0
# Cash capital at the moment: $115.31156042715881
#
#
# Share price: $0.4936830209664527
# Shares owned at the moment: 232
# Cash capital at the moment: $0.4621297955651755
#
#
# Price increase from previously bought: 58.1019707680652%
# Share price: $0.7826690226053943
# Shares owned at the moment: 0
# Cash capital at the moment: $181.5420002035944
#
#
# Share price: $0.6697319721592003
# Shares owned at the moment: 270
# Cash capital at the moment: $0.21709173128209613
#
#
# Price increase from previously bought: 0.38523091310873614%
# Share price: $0.6741608447144954
# Shares owned at the moment: 0
# Cash capital at the moment: $181.73995537699534
#
#
# Share price: $0.7375058510366451
# Shares owned at the moment: 245
# Cash capital at the moment: $0.5541273058813374
#
#
# Price increase from previously bought: -5.711426640734452%
# Share price: $0.6972960506833676
# Shares owned at the moment: 0
# Cash capital at the moment: $170.9218565091585
#
#
#
#
# Capital at the end of test period: $170.9218565091585
# profit gained: 70.92185650915849%
#
#
# Capital at the end of test period if Buy and Hold: $5902.379195330377
# profit gained: 5802.379195330377%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.232877      6.306306       7.462687      95.121951
# 1       0.324201      5.940594       9.615385      90.909091
# 2       0.219178      4.651163       7.526882      92.500000
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         41.818182           49.253731          87.804878     149.312753
# 1         49.504950           53.846154          86.153846    1615.748376
# 2         41.860465           43.478261          85.000000      70.921857
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
# 2        5802.379195
#
#
#
# RUNNING EPOCHS 20 - 40
#
#
#
# Epoch 1/20
#  2/30 [=>............................] - ETA: 19s - loss: 0.1339 - accuracy: 0.3438 - mse: 1.3889 - weighted_accuracy: 0.6700 - weighted_mse: 1.2859WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0120s vs `on_train_batch_end` time: 1.3748s). Check your callbacks.
# 30/30 [==============================] - 2s 61ms/step - loss: 0.1515 - accuracy: 0.4046 - mse: 1.3817 - weighted_accuracy: 0.6619 - weighted_mse: 1.3206 - val_loss: 0.1864 - val_accuracy: 0.3583 - val_mse: 1.2329 - val_weighted_accuracy: 0.3583 - val_weighted_mse: 1.2329
# Epoch 2/20
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1495 - accuracy: 0.3867 - mse: 1.4046 - weighted_accuracy: 0.6690 - weighted_mse: 1.3323 - val_loss: 0.1848 - val_accuracy: 0.3836 - val_mse: 1.2941 - val_weighted_accuracy: 0.3836 - val_weighted_mse: 1.2941
# Epoch 3/20
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1490 - accuracy: 0.4276 - mse: 1.4120 - weighted_accuracy: 0.6825 - weighted_mse: 1.3512 - val_loss: 0.1850 - val_accuracy: 0.3825 - val_mse: 1.2474 - val_weighted_accuracy: 0.3825 - val_weighted_mse: 1.2474
# Epoch 4/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1478 - accuracy: 0.4154 - mse: 1.4274 - weighted_accuracy: 0.6851 - weighted_mse: 1.3602 - val_loss: 0.1801 - val_accuracy: 0.4204 - val_mse: 1.3171 - val_weighted_accuracy: 0.4204 - val_weighted_mse: 1.3171
# Epoch 5/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1455 - accuracy: 0.4094 - mse: 1.4391 - weighted_accuracy: 0.6945 - weighted_mse: 1.3629 - val_loss: 0.1893 - val_accuracy: 0.3414 - val_mse: 1.3705 - val_weighted_accuracy: 0.3414 - val_weighted_mse: 1.3705
# Epoch 6/20
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1443 - accuracy: 0.4218 - mse: 1.4656 - weighted_accuracy: 0.7117 - weighted_mse: 1.3916 - val_loss: 0.1745 - val_accuracy: 0.4605 - val_mse: 1.3502 - val_weighted_accuracy: 0.4605 - val_weighted_mse: 1.3502
# Epoch 7/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1431 - accuracy: 0.4352 - mse: 1.4635 - weighted_accuracy: 0.7114 - weighted_mse: 1.3848 - val_loss: 0.1938 - val_accuracy: 0.3246 - val_mse: 1.4834 - val_weighted_accuracy: 0.3246 - val_weighted_mse: 1.4834
# Epoch 8/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1411 - accuracy: 0.4452 - mse: 1.4827 - weighted_accuracy: 0.7257 - weighted_mse: 1.4138 - val_loss: 0.1773 - val_accuracy: 0.4457 - val_mse: 1.4028 - val_weighted_accuracy: 0.4457 - val_weighted_mse: 1.4028
# Epoch 9/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1396 - accuracy: 0.4476 - mse: 1.5056 - weighted_accuracy: 0.7246 - weighted_mse: 1.4333 - val_loss: 0.1847 - val_accuracy: 0.3888 - val_mse: 1.4998 - val_weighted_accuracy: 0.3888 - val_weighted_mse: 1.4998
# Epoch 10/20
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1392 - accuracy: 0.4708 - mse: 1.4948 - weighted_accuracy: 0.7196 - weighted_mse: 1.4361 - val_loss: 0.1840 - val_accuracy: 0.3952 - val_mse: 1.5115 - val_weighted_accuracy: 0.3952 - val_weighted_mse: 1.5115
# Epoch 11/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1383 - accuracy: 0.4344 - mse: 1.5200 - weighted_accuracy: 0.7249 - weighted_mse: 1.4392 - val_loss: 0.1917 - val_accuracy: 0.3646 - val_mse: 1.5318 - val_weighted_accuracy: 0.3646 - val_weighted_mse: 1.5318
# Epoch 12/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1367 - accuracy: 0.4939 - mse: 1.5156 - weighted_accuracy: 0.7453 - weighted_mse: 1.4478 - val_loss: 0.1851 - val_accuracy: 0.4173 - val_mse: 1.4881 - val_weighted_accuracy: 0.4173 - val_weighted_mse: 1.4881
# Epoch 13/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1348 - accuracy: 0.4863 - mse: 1.5656 - weighted_accuracy: 0.7442 - weighted_mse: 1.4910 - val_loss: 0.1795 - val_accuracy: 0.4278 - val_mse: 1.5851 - val_weighted_accuracy: 0.4278 - val_weighted_mse: 1.5851
# Epoch 14/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1351 - accuracy: 0.4763 - mse: 1.5706 - weighted_accuracy: 0.7331 - weighted_mse: 1.4914 - val_loss: 0.1914 - val_accuracy: 0.3941 - val_mse: 1.5395 - val_weighted_accuracy: 0.3941 - val_weighted_mse: 1.5395
# Epoch 15/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1335 - accuracy: 0.4768 - mse: 1.5874 - weighted_accuracy: 0.7478 - weighted_mse: 1.5083 - val_loss: 0.1777 - val_accuracy: 0.4647 - val_mse: 1.5442 - val_weighted_accuracy: 0.4647 - val_weighted_mse: 1.5442
# Epoch 16/20
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1323 - accuracy: 0.5213 - mse: 1.5663 - weighted_accuracy: 0.7485 - weighted_mse: 1.5105 - val_loss: 0.1885 - val_accuracy: 0.4036 - val_mse: 1.5588 - val_weighted_accuracy: 0.4036 - val_weighted_mse: 1.5588
# Epoch 17/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1332 - accuracy: 0.4852 - mse: 1.6057 - weighted_accuracy: 0.7438 - weighted_mse: 1.5308 - val_loss: 0.1887 - val_accuracy: 0.4141 - val_mse: 1.6031 - val_weighted_accuracy: 0.4141 - val_weighted_mse: 1.6031
# Epoch 18/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1308 - accuracy: 0.4821 - mse: 1.6121 - weighted_accuracy: 0.7567 - weighted_mse: 1.5340 - val_loss: 0.1856 - val_accuracy: 0.4226 - val_mse: 1.6180 - val_weighted_accuracy: 0.4226 - val_weighted_mse: 1.6180
# Epoch 19/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1292 - accuracy: 0.4995 - mse: 1.6225 - weighted_accuracy: 0.7560 - weighted_mse: 1.5572 - val_loss: 0.1831 - val_accuracy: 0.4457 - val_mse: 1.6477 - val_weighted_accuracy: 0.4457 - val_weighted_mse: 1.6477
# Epoch 20/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1279 - accuracy: 0.5190 - mse: 1.6387 - weighted_accuracy: 0.7739 - weighted_mse: 1.5882 - val_loss: 0.1801 - val_accuracy: 0.4795 - val_mse: 1.7282 - val_weighted_accuracy: 0.4795 - val_weighted_mse: 1.7282
# Validation loss: 0.1801431030035019
# Validation accuracy: 0.4794520437717438
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1540 - accuracy: 0.6101 - mse: 1.7077 - weighted_accuracy: 0.6101 - weighted_mse: 1.7077
# Test loss: 0.1539512276649475
# Test accuracy: 0.6100917458534241
#
#
# number of predictions: 218
# actual predicted buys: 3
# actual buys but predicted sell: 1
# actual buys but predicted hold: 4
# actual sells but predicted buy: 1
# actual predicted sells: 1
# actual sells but predicted hold: 6
# actual holds but predicted buy: 34
# actual holds but predicted sell: 39
# actual predicted holds: 129
# Percentage buys correct: 7.894736842105263%
# Percentage sells correct: 2.4390243902439024%
# Percentage holds correct: 92.80575539568345%
# actual buys: 8
# actual sells: 8
# actual holds: 202
#
#
# Percentage low buys correct: 59.45945945945946%
# Percentage high sells correct: 65.85365853658537%
# Percentage mid holds correct: 76.97841726618705%
#
#
# Capital: 100
# Share price: $0.7915534235513326
# Shares owned at the moment: 125
# Cash capital at the moment: $0.7837255667376581
#
#
# Price increase from previously bought: -13.117623961732184%
# Share price: $0.6896116531541341
# Shares owned at the moment: 0
# Cash capital at the moment: $86.74812820523267
#
#
# Share price: $0.7284466270836834
# Shares owned at the moment: 118
# Cash capital at the moment: $0.5550452788693718
#
#
# Price increase from previously bought: -6.25540087791141%
# Share price: $0.6847572886465141
# Shares owned at the moment: 0
# Cash capital at the moment: $81.13420159899223
#
#
# Share price: $0.602233034148385
# Shares owned at the moment: 134
# Cash capital at the moment: $0.21305215002495004
#
#
# Price increase from previously bought: -63.77847609151688%
# Share price: $0.21873786190057493
# Shares owned at the moment: 0
# Cash capital at the moment: $29.443320742591627
#
#
# Share price: $0.20417476837771503
# Shares owned at the moment: 143
# Cash capital at the moment: $0.1660371369138396
#
#
# Price increase from previously bought: 6.838853880952711%
# Share price: $0.21873786190057493
# Shares owned at the moment: 0
# Cash capital at the moment: $31.35953272450365
#
#
# Share price: $0.20417476837771503
# Shares owned at the moment: 153
# Cash capital at the moment: $0.03488662891832561
#
#
# Price increase from previously bought: 6.838853880952711%
# Share price: $0.21873786190057493
# Shares owned at the moment: 0
# Cash capital at the moment: $33.40974554431162
#
#
# Share price: $0.21388349739295492
# Shares owned at the moment: 155
# Cash capital at the moment: $0.1666356076398614
#
#
# Price increase from previously bought: -0.27424582398405395%
# Share price: $0.21388349739295492
# Shares owned at the moment: 0
# Cash capital at the moment: $33.22740986278413
#
#
# Share price: $0.21388349739295492
# Shares owned at the moment: 154
# Cash capital at the moment: $0.19877160312315567
#
#
# Price increase from previously bought: -11.591288619883866%
# Share price: $0.1896116459205603
# Shares owned at the moment: 0
# Cash capital at the moment: $29.318664542842082
#
#
# Share price: $0.21388349739295492
# Shares owned at the moment: 136
# Cash capital at the moment: $0.15051646937524765
#
#
# Price increase from previously bought: 11.042796971915791%
# Share price: $0.23815534886534961
# Shares owned at the moment: 0
# Cash capital at the moment: $32.45057381458715
#
#
# Share price: $0.1896116459205603
# Shares owned at the moment: 170
# Cash capital at the moment: $0.12795056362404011
#
#
# Price increase from previously bought: -76.86852757944051%
# Share price: $0.043980580487634584
# Shares owned at the moment: 0
# Cash capital at the moment: $7.58408832514395
#
#
# Share price: $0.029417472497627294
# Shares owned at the moment: 257
# Cash capital at the moment: $0.003007094566037871
#
#
# Price increase from previously bought: 49.09494888053651%
# Share price: $0.043980580487634584
# Shares owned at the moment: 0
# Cash capital at the moment: $11.27493300462849
#
#
# Share price: $0.01
# Shares owned at the moment: 1124
# Cash capital at the moment: $0.004023004628489701
#
#
# Price increase from previously bought: 241.77862350929607%
# Share price: $0.034271851472394664
# Shares owned at the moment: 0
# Cash capital at the moment: $38.41964976669891
#
#
#
#
# Capital at the end of test period: $38.41964976669891
# profit gained: -61.58035023330108%
#
#
# Capital at the end of test period if Buy and Hold: $2.5934579490563006
# profit gained: -97.4065420509437%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.610092      7.894737       2.439024      92.805755
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         59.459459           65.853659          76.978417      -61.58035
#
#    buy_n_hold profit
# 0         -97.406542
#
#
# Recession
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1914 - accuracy: 0.4566 - mse: 1.8357 - weighted_accuracy: 0.4566 - weighted_mse: 1.8357
# Test loss: 0.19137218594551086
# Test accuracy: 0.456620991230011
#
#
# number of predictions: 219
# actual predicted buys: 3
# actual buys but predicted sell: 1
# actual buys but predicted hold: 4
# actual sells but predicted buy: 2
# actual predicted sells: 4
# actual sells but predicted hold: 2
# actual holds but predicted buy: 39
# actual holds but predicted sell: 71
# actual predicted holds: 93
# Percentage buys correct: 6.818181818181818%
# Percentage sells correct: 5.2631578947368425%
# ...
# Share price: $0.13366604575062643
# Shares owned at the moment: 0
# Cash capital at the moment: $166.08950114479825
#
#
# Share price: $0.09097928527105935
# Shares owned at the moment: 1820
# Cash capital at the moment: $0.05185062868855539
#
#
# Price increase from previously bought: 504.100136990438%
# Share price: $0.5511174034195182
# Shares owned at the moment: 0
# Cash capital at the moment: $1000.327182248097
#
#
# Share price: $0.5184746209174371
# Shares owned at the moment: 1924
# Cash capital at the moment: $0.03876238367377027
#
#
# Price increase from previously bought: -51.107301576479756%
# Share price: $0.2541933474478734
# Shares owned at the moment: 0
# Cash capital at the moment: $487.76182587203556
#
#
# Share price: $0.3734651724770659
# Shares owned at the moment: 1302
# Cash capital at the moment: $0.172979256841586
#
#
# Price increase from previously bought: -28.938297851038598%
# Share price: $0.26612053294412086
# Shares owned at the moment: 0
# Cash capital at the moment: $345.7090685818805
#
#
# Share price: $0.41175771223519897
# Shares owned at the moment: 837
# Cash capital at the moment: $0.12010012688159577
#
#
#
#
# Capital at the end of test period: $340.14568111468213
# profit gained: 240.14568111468213%
#
#
# Capital at the end of test period if Buy and Hold: $3238.165410975435
# profit gained: 3138.165410975435%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.730594     11.764706       3.030303      92.899408
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0             68.75           42.424242          82.840237     240.145681
#
#    buy_n_hold profit
# 0        3138.165411
#
#
# Non-Recession
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1715 - accuracy: 0.7523 - mse: 7.8711 - weighted_accuracy: 0.7523 - weighted_mse: 7.8711
# Test loss: 0.17148855328559875
# Test accuracy: 0.752293586730957
#
#
# number of predictions: 218
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 9
# actual sells but predicted buy: 0
# actual predicted sells: 0
# actual sells but predicted hold: 9
# actual holds but predicted buy: 20
# actual holds but predicted sell: 16
# actual predicted holds: 163
# Percentage buys correct: 4.761904761904762%
# Percentage sells correct: 0.0%
# Percentage holds correct: 90.05524861878453%
# actual buys: 10
# actual sells: 9
# actual holds: 199
#
#
# Percentage low buys correct: 65.0%
# Percentage high sells correct: 68.75%
# Percentage mid holds correct: 80.11049723756906%
#
#
# Capital: 100
# Share price: $0.6570588132171898
# Shares owned at the moment: 151
# Cash capital at the moment: $0.5112755320158868
#
#
# Price increase from previously bought: -10.31824901445445%
# Share price: $0.5908823187819406
# Shares owned at the moment: 0
# Cash capital at the moment: $89.48914178521473
#
#
# Share price: $0.6092646539989853
# Shares owned at the moment: 146
# Cash capital at the moment: $0.2918825427822753
#
#
# Price increase from previously bought: 7.548805360685473%
# Share price: $0.6570588132171898
# Shares owned at the moment: 0
# Cash capital at the moment: $95.95866015898528
#
#
# Share price: $0.6460294120869631
# Shares owned at the moment: 148
# Cash capital at the moment: $0.08337319939533927
#
#
# Price increase from previously bought: 18.45413721921705%
# Share price: $0.7673529998272349
# Shares owned at the moment: 0
# Cash capital at the moment: $113.33930450289643
#
#
# Share price: $0.6533823461737808
# Shares owned at the moment: 172
# Cash capital at the moment: $0.6484911112659262
#
#
# Price increase from previously bought: -41.237447736481094%
# Share price: $0.38499998904326416
# Shares owned at the moment: 0
# Cash capital at the moment: $66.6863842318899
#
#
# Share price: $0.0761764944352493
# Shares owned at the moment: 873
# Cash capital at the moment: $0.0014238709018314921
#
#
# Price increase from previously bought: 225.93747412509998%
# Share price: $0.24897053312935702
# Shares owned at the moment: 0
# Cash capital at the moment: $216.75498328542022
#
#
# Share price: $0.09088236260888481
# Shares owned at the moment: 2378
# Cash capital at the moment: $0.04239979121135207
#
#
# Price increase from previously bought: 136.88895764204284%
# Share price: $0.21588232973867671
# Shares owned at the moment: 0
# Cash capital at the moment: $511.9988174144585
#
#
# Share price: $0.22323526382549452
# Shares owned at the moment: 2287
# Cash capital at the moment: $0.05578666253796882
#
#
#
#
# Capital at the end of test period: $576.2707158249827
# profit gained: 476.27071582498274%
#
#
# Capital at the end of test period if Buy and Hold: $26.129427230180067
# profit gained: -73.87057276981993%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.807339     10.000000            0.0      93.548387
# 1       0.752294      4.761905            0.0      90.055249
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0              45.0           41.666667          72.432432     -89.138962
# 1              65.0           68.750000          80.110497     476.270716
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2049 - accuracy: 0.7854 - mse: 10.8820 - weighted_accuracy: 0.7854 - weighted_mse: 10.8820
# Test loss: 0.20486024022102356
# Test accuracy: 0.7853881120681763
#
#
# number of predictions: 219
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 1
# actual predicted sells: 1
# actual sells but predicted hold: 9
# actual holds but predicted buy: 9
# actual holds but predicted sell: 21
# actual predicted holds: 170
# Percentage buys correct: 9.090909090909092%
# Percentage sells correct: 4.545454545454546%
# Percentage holds correct: 91.39784946236558%
# actual buys: 8
# actual sells: 11
# actual holds: 200
#
#
# Percentage low buys correct: 54.54545454545455%
# Percentage high sells correct: 45.45454545454545%
# Percentage mid holds correct: 85.4054054054054%
#
#
# Capital: 100
# Share price: $0.18989416418693827
# Shares owned at the moment: 525
# Cash capital at the moment: $0.03140410231250712
#
#
# Price increase from previously bought: -6.202027535566645%
# Share price: $0.17860669724417821
# Shares owned at the moment: 0
# Cash capital at the moment: $93.54205673635978
#
#
# Share price: $0.15462081317116044
# Shares owned at the moment: 603
# Cash capital at the moment: $0.049306430708952576
#
#
# Price increase from previously bought: 104.14942561360564%
# Share price: $0.3165255600984224
# Shares owned at the moment: 0
# Cash capital at the moment: $190.38934066002446
#
#
# Share price: $0.41246913002979846
# Shares owned at the moment: 460
# Cash capital at the moment: $0.13176739682944572
#
#
# Price increase from previously bought: -3.770850234420031%
# Share price: $0.39800705459956076
# Shares owned at the moment: 0
# Cash capital at the moment: $182.71153358855895
#
#
# Share price: $0.4078835881744759
# Shares owned at the moment: 446
# Cash capital at the moment: $0.29518404184671
#
#
# Price increase from previously bought: -19.3336933061805%
# Share price: $0.3299294439126025
# Shares owned at the moment: 0
# Cash capital at the moment: $147.03905756390859
#
#
# Share price: $0.23962964109191143
# Shares owned at the moment: 611
# Cash capital at the moment: $0.22270915230600963
#
#
#
#
# Capital at the end of test period: $157.83987155755244
# profit gained: 57.83987155755245%
#
#
# Capital at the end of test period if Buy and Hold: $2186.7819938452512
# profit gained: 2086.7819938452512%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.730594     11.764706       3.030303      92.899408
# 1       0.785388      9.090909       4.545455      91.397849
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         68.750000           42.424242          82.840237     240.145681
# 1         54.545455           45.454545          85.405405      57.839872
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1842 - accuracy: 0.7569 - mse: 9.6015 - weighted_accuracy: 0.7569 - weighted_mse: 9.6015
# Test loss: 0.18422459065914154
# Test accuracy: 0.7568807601928711
#
#
# number of predictions: 218
# actual predicted buys: 2
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 0
# actual predicted sells: 1
# actual sells but predicted hold: 7
# actual holds but predicted buy: 26
# actual holds but predicted sell: 13
# actual predicted holds: 162
# Percentage buys correct: 7.142857142857143%
# Percentage sells correct: 7.142857142857143%
# Percentage holds correct: 92.04545454545455%
# actual buys: 9
# actual sells: 8
# actual holds: 201
#
#
# Percentage low buys correct: 60.714285714285715%
# Percentage high sells correct: 35.714285714285715%
# Percentage mid holds correct: 84.57142857142857%
#
#
# Capital: 100
# Share price: $1.01
# Shares owned at the moment: 98
# Cash capital at the moment: $0.7478049999999996
#
#
# Price increase from previously bought: -14.97110078971906%
# Share price: $0.8611535596994031
# Shares owned at the moment: 0
# Cash capital at the moment: $84.9087729662025
#
#
# Share price: $0.8710766935730502
# Shares owned at the moment: 97
# Cash capital at the moment: $0.18197398160602063
#
#
# Price increase from previously bought: -74.68564274877487%
# Share price: $0.2211138616751354
# Shares owned at the moment: 0
# Cash capital at the moment: $21.57103644149231
#
#
# Share price: $0.1714983815749365
# Shares owned at the moment: 125
# Cash capital at the moment: $0.07478617595886305
#
#
# Price increase from previously bought: -60.14056580583569%
# Share price: $0.0685462698304254
# Shares owned at the moment: 0
# Cash capital at the moment: $8.619507124507829
#
#
# Share price: $0.06060778875586278
# Shares owned at the moment: 141
# Cash capital at the moment: $0.05030823984109034
#
#
# Price increase from previously bought: -49.25745890843854%
# Share price: $0.030838505427444297
# Shares owned at the moment: 0
# Cash capital at the moment: $4.386579874631245
#
#
# Share price: $0.030094268021070313
# Shares owned at the moment: 145
# Cash capital at the moment: $0.010910922202648443
#
#
# Price increase from previously bought: 19.45550383974104%
# Share price: $0.0360481199550531
# Shares owned at the moment: 0
# Cash capital at the moment: $5.22351412785327
#
#
# Share price: $0.027861567631200616
# Shares owned at the moment: 186
# Cash capital at the moment: $0.027011356606595704
#
#
# Price increase from previously bought: 0.6137254644015044%
# Share price: $0.028109650709742716
# Shares owned at the moment: 0
# Cash capital at the moment: $5.241028302280707
#
#
# Share price: $0.021163478290843897
# Shares owned at the moment: 246
# Cash capital at the moment: $0.020495549669352187
#
#
# Price increase from previously bought: -45.86449261282248%
# Share price: $0.011488462983495698
# Shares owned at the moment: 0
# Cash capital at the moment: $2.8388854984009586
#
#
#
#
# Capital at the end of test period: $2.8388854984009586
# profit gained: -97.16111450159904%
#
#
# Capital at the end of test period if Buy and Hold: $2.3797176202777375
# profit gained: -97.62028237972227%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.807339     10.000000       0.000000      93.548387
# 1       0.752294      4.761905       0.000000      90.055249
# 2       0.756881      7.142857       7.142857      92.045455
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         45.000000           41.666667          72.432432     -89.138962
# 1         65.000000           68.750000          80.110497     476.270716
# 2         60.714286           35.714286          84.571429     -97.161115
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
# 2         -97.620282
#
#
# Recession
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2187 - accuracy: 0.7489 - mse: 7.3238 - weighted_accuracy: 0.7489 - weighted_mse: 7.3238
# Test loss: 0.2186543494462967
# Test accuracy: 0.7488584518432617
#
#
# number of predictions: 219
# actual predicted buys: 2
# actual buys but predicted sell: 1
# actual buys but predicted hold: 5
# actual sells but predicted buy: 0
# actual predicted sells: 0
# actual sells but predicted hold: 10
# actual holds but predicted buy: 19
# actual holds but predicted sell: 20
# actual predicted holds: 162
# Percentage buys correct: 9.523809523809524%
# Percentage sells correct: 0.0%
# Percentage holds correct: 91.52542372881356%
# actual buys: 8
# actual sells: 10
# actual holds: 201
#
#
# Percentage low buys correct: 33.333333333333336%
# Percentage high sells correct: 42.857142857142854%
# Percentage mid holds correct: 85.22727272727273%
#
#
# Capital: 100
# Share price: $0.016060606026923996
# Shares owned at the moment: 6209
# Cash capital at the moment: $0.00546634607069052
#
#
# Price increase from previously bought: 184.2690782817791%
# Share price: $0.04578088889518252
# Shares owned at the moment: 0
# Cash capital at the moment: $283.47730826359594
#
#
# Share price: $0.060699301165667935
# Shares owned at the moment: 4657
# Cash capital at the moment: $0.023301959876960154
#
#
# Price increase from previously bought: 54.87364928440665%
# Share price: $0.09426574266811717
# Shares owned at the moment: 0
# Cash capital at the moment: $437.8116277653837
#
#
# Share price: $0.09216783694809629
# Shares owned at the moment: 4737
# Cash capital at the moment: $0.011936772287981512
#
#
# Price increase from previously bought: -14.650496663717727%
# Share price: $0.07888111924643988
# Shares owned at the moment: 0
# Cash capital at the moment: $372.64423402253016
#
#
# Share price: $0.22759907526044482
# Shares owned at the moment: 1632
# Cash capital at the moment: $0.18107854771528764
#
#
# Price increase from previously bought: 4.015473989210561%
# Share price: $0.23738928713376156
# Shares owned at the moment: 0
# Cash capital at the moment: $386.5349920293578
#
#
# Share price: $0.5790559484281369
# Shares owned at the moment: 665
# Cash capital at the moment: $0.4038377589587867
#
#
# Price increase from previously bought: 41.76741711944263%
# Share price: $0.8231701715829098
# Shares owned at the moment: 0
# Cash capital at the moment: $546.3066294103116
#
#
# Share price: $0.7832518087745554
# Shares owned at the moment: 695
# Cash capital at the moment: $0.4496322924753713
#
#
# Price increase from previously bought: -11.537416142354417%
# Share price: $0.6947902213211395
# Shares owned at the moment: 0
# Cash capital at the moment: $482.0009183001673
#
#
# Share price: $0.6376806891104106
# Shares owned at the moment: 753
# Cash capital at the moment: $0.5068821130527112
#
#
# Price increase from previously bought: -8.312382085237669%
# Share price: $0.5862820878905832
# Shares owned at the moment: 0
# Cash capital at the moment: $440.76325066116243
#
#
# Share price: $0.4803962699195395
# Shares owned at the moment: 914
# Cash capital at the moment: $0.4735839302605882
#
#
# Price increase from previously bought: 6.355108890071159%
# Share price: $0.5123310224107025
# Shares owned at the moment: 0
# Cash capital at the moment: $467.45639438881335
#
#
# Share price: $0.511048963975096
# Shares owned at the moment: 912
# Cash capital at the moment: $0.0980284418761812
#
#
# Price increase from previously bought: 36.06988652802545%
# Share price: $0.6972960506833676
# Shares owned at the moment: 0
# Cash capital at the moment: $634.2832081699935
#
#
#
#
# Capital at the end of test period: $634.2832081699935
# profit gained: 534.2832081699935%
#
#
# Capital at the end of test period if Buy and Hold: $5902.379195330377
# profit gained: 5802.379195330377%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.730594     11.764706       3.030303      92.899408
# 1       0.785388      9.090909       4.545455      91.397849
# 2       0.748858      9.523810       0.000000      91.525424
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         68.750000           42.424242          82.840237     240.145681
# 1         54.545455           45.454545          85.405405      57.839872
# 2         33.333333           42.857143          85.227273     534.283208
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
# 2        5802.379195

# %%
df = nr_log_hist['0_epochs_logs']
df['Profit gained']
# Out:
# 0   -77.332156
# 1   -74.827293
# 2     5.135034
# Name: Profit gained, dtype: float64

# %%
Vaxart_data_acc = []
Inovio_data_acc = []
Novavax_data_acc = []

Vaxart_data_correct_buys = []
Inovio_data_correct_buys = []
Novavax_data_correct_buys = []

Vaxart_data_correct_sells = []
Inovio_data_correct_sells = []
Novavax_data_correct_sells = []

Vaxart_data_correct_holds = []
Inovio_data_correct_holds = []
Novavax_data_correct_holds = []

Vaxart_data_correct_low_buys = []
Inovio_data_correct_low_buys = []
Novavax_data_correct_low_buys = []

Vaxart_data_correct_high_sells = []
Inovio_data_correct_high_sells = []
Novavax_data_correct_high_sells = []

Vaxart_data_correct_mid_holds = []
Inovio_data_correct_mid_holds = []
Novavax_data_correct_mid_holds = []

Vaxart_data_profit = []
Inovio_data_profit = []
Novavax_data_profit = []

for key,value in nr_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    Vaxart_data_acc.append(acc[0])
    Inovio_data_acc.append(acc[1])
    Novavax_data_acc.append(acc[2])
    
    Vaxart_data_correct_buys.append(correct_buys[0])
    Inovio_data_correct_buys.append(correct_buys[1]) 
    Novavax_data_correct_buys.append(correct_buys[2]) 

    Vaxart_data_correct_sells.append(correct_sells[0]) 
    Inovio_data_correct_sells.append(correct_sells[1]) 
    Novavax_data_correct_sells.append(correct_sells[2]) 

    Vaxart_data_correct_holds.append(correct_holds[0]) 
    Inovio_data_correct_holds.append(correct_holds[1])  
    Novavax_data_correct_holds.append(correct_holds[2])  

    Vaxart_data_correct_low_buys.append(correct_low_buys[0])  
    Inovio_data_correct_low_buys.append(correct_low_buys[1])  
    Novavax_data_correct_low_buys.append(correct_low_buys[2])  

    Vaxart_data_correct_high_sells.append(correct_high_sells[0]) 
    Inovio_data_correct_high_sells.append(correct_high_sells[1]) 
    Novavax_data_correct_high_sells.append(correct_high_sells[2]) 

    Vaxart_data_correct_mid_holds.append(correct_mid_holds[0])  
    Inovio_data_correct_mid_holds.append(correct_mid_holds[1])  
    Novavax_data_correct_mid_holds.append(correct_mid_holds[2])   

    Vaxart_data_profit.append(profit[0]) 
    Inovio_data_profit.append(profit[1]) 
    Novavax_data_profit.append(profit[2])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(Vaxart_data_acc)
plt.plot(Inovio_data_acc)
plt.plot(Novavax_data_acc)

plt.title('Non-Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Vaxart_data_acc','Inovio_data_acc','Novavax_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_profit")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_profit")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_profit")
# Out:
# Text(0.5, 1.0, 'Novavax_data_profit')

# %%
Vaxart_data_acc = []
Inovio_data_acc = []
Novavax_data_acc = []

Vaxart_data_correct_buys = []
Inovio_data_correct_buys = []
Novavax_data_correct_buys = []

Vaxart_data_correct_sells = []
Inovio_data_correct_sells = []
Novavax_data_correct_sells = []

Vaxart_data_correct_holds = []
Inovio_data_correct_holds = []
Novavax_data_correct_holds = []

Vaxart_data_correct_low_buys = []
Inovio_data_correct_low_buys = []
Novavax_data_correct_low_buys = []

Vaxart_data_correct_high_sells = []
Inovio_data_correct_high_sells = []
Novavax_data_correct_high_sells = []

Vaxart_data_correct_mid_holds = []
Inovio_data_correct_mid_holds = []
Novavax_data_correct_mid_holds = []

Vaxart_data_profit = []
Inovio_data_profit = []
Novavax_data_profit = []

for key,value in r_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    Vaxart_data_acc.append(acc[0])
    Inovio_data_acc.append(acc[1])
    Novavax_data_acc.append(acc[2])
    
    Vaxart_data_correct_buys.append(correct_buys[0])
    Inovio_data_correct_buys.append(correct_buys[1]) 
    Novavax_data_correct_buys.append(correct_buys[2]) 

    Vaxart_data_correct_sells.append(correct_sells[0]) 
    Inovio_data_correct_sells.append(correct_sells[1]) 
    Novavax_data_correct_sells.append(correct_sells[2]) 

    Vaxart_data_correct_holds.append(correct_holds[0]) 
    Inovio_data_correct_holds.append(correct_holds[1])  
    Novavax_data_correct_holds.append(correct_holds[2])  

    Vaxart_data_correct_low_buys.append(correct_low_buys[0])  
    Inovio_data_correct_low_buys.append(correct_low_buys[1])  
    Novavax_data_correct_low_buys.append(correct_low_buys[2])  

    Vaxart_data_correct_high_sells.append(correct_high_sells[0]) 
    Inovio_data_correct_high_sells.append(correct_high_sells[1]) 
    Novavax_data_correct_high_sells.append(correct_high_sells[2]) 

    Vaxart_data_correct_mid_holds.append(correct_mid_holds[0])  
    Inovio_data_correct_mid_holds.append(correct_mid_holds[1])  
    Novavax_data_correct_mid_holds.append(correct_mid_holds[2])   

    Vaxart_data_profit.append(profit[0]) 
    Inovio_data_profit.append(profit[1]) 
    Novavax_data_profit.append(profit[2])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(Vaxart_data_acc)
plt.plot(Inovio_data_acc)
plt.plot(Novavax_data_acc)

plt.title('Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Vaxart_data_acc','Inovio_data_acc','Novavax_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_profit")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_profit")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_profit")
# Out:
# Text(0.5, 1.0, 'Novavax_data_profit')

# %% [markdown]
# ## Train Inovio Pharmaceuticals, Inc. Stock Data

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []

seed = 10
df = pd.read_csv('variation 7/initial_indicators/INO_data.csv')
df.set_index('Date', inplace=True)
print(df.head())

plt.figure(figsize=(15,5))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
plt.show()

labels = []
data_15 = []
sequential = []
count = 0

for i in df.values:
    if count == 14:
        data_15.append(np.array(i[0:-1]))
        labels.append(i[-1])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_arr = min_max_scaler.fit_transform(data_15)
        sequential.append(data_15_arr)
        data_15 = data_15[1:15]
    else:
        data_15.append(np.array(i[0:-1]))
        count+= 1
    
X = sequential
X  = np.array(X).reshape(-1, 15, 4)
y = labels
y = np.array(y)

X.shape
# Out:
#             previous_1d     EMA_12   willr_14    OBV_7  labels
# Date
# 2000-01-21         51.0  54.535133 -80.952381 -17732.0     2.0
# 2000-01-24         56.0  54.760497 -57.142857 -10257.0     2.0
# 2000-01-25         58.0  55.258882 -47.619048  -8463.0     2.0
# 2000-01-26         59.0  55.834439 -42.857143  -4944.0     2.0
# 2000-01-27         57.0  56.013756 -52.380952  -5313.0     2.0
# (4745, 15, 4)

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization,Activation
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(LSTM(100, input_shape=(X_train.shape[1:]), return_sequences=True,kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(LSTM(100, kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# model.add(Dense(100, kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))

model.add(Dense(75, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(50, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "DBS_CNN_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))
print(d_class_weights)

epochs = 0 
histories = {}
nr_log_hist = {}
r_log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    nr_log  = pd.DataFrame(columns = column_names)
    r_log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['VXRT','INO','NVAX']
    for name in test_sets:
        
        print('\n')
        print("Non-Recession")
        print('\n')
        
        X = nr_test_data['{}_X'.format(name)]
        y = nr_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("variation 7/initial_indicators/{}_data_test.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(nr_log)
        nr_log.loc[df_length] = logger
        print(nr_log.head(20))
        logger = []
        
        print('\n')
        print("Recession")
        print('\n')
        
        X = r_test_data['{}_X'.format(name)]
        y = r_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("variation 7/initial_indicators/{}_data_test2.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(r_log)
        r_log.loc[df_length] = logger
        print(r_log.head(20))
        logger = []

    nr_log.to_csv('{}_{}_{}epochs.csv'.format(experiment,'InovioModel',epochs))
    nr_log_hist['{}_epochs_logs'.format(epochs)] = nr_log
    r_log.to_csv('{}_{}_{}epochs.csv'.format(experiment,'InovioModel',epochs))
    r_log_hist['{}_epochs_logs'.format(epochs)] = r_log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 2 ... 0 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# {0: 7.443137254901961, 1: 7.3140655105973025, 2: 0.3664446375132735}
#
#
#
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  2/30 [=>............................] - ETA: 29s - loss: 0.3581 - accuracy: 0.5742 - mse: 0.3244 - weighted_accuracy: 0.3111 - weighted_mse: 0.4718WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0099s vs `on_train_batch_end` time: 2.0842s). Check your callbacks.
# 30/30 [==============================] - 3s 105ms/step - loss: 0.2951 - accuracy: 0.5237 - mse: 0.4354 - weighted_accuracy: 0.3151 - weighted_mse: 0.5222 - val_loss: 0.2994 - val_accuracy: 0.0453 - val_mse: 0.3540 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.3540
# Epoch 2/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2117 - accuracy: 0.3570 - mse: 0.7499 - weighted_accuracy: 0.4501 - weighted_mse: 0.7368 - val_loss: 0.2906 - val_accuracy: 0.0453 - val_mse: 0.3842 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.3842
# Epoch 3/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1887 - accuracy: 0.2871 - mse: 1.0175 - weighted_accuracy: 0.4915 - weighted_mse: 0.9804 - val_loss: 0.2791 - val_accuracy: 0.0453 - val_mse: 0.4225 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.4225
# Epoch 4/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1803 - accuracy: 0.2903 - mse: 1.1754 - weighted_accuracy: 0.5146 - weighted_mse: 1.1321 - val_loss: 0.2689 - val_accuracy: 0.0453 - val_mse: 0.4687 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.4687
# Epoch 5/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1757 - accuracy: 0.3143 - mse: 1.2439 - weighted_accuracy: 0.5234 - weighted_mse: 1.2118 - val_loss: 0.2602 - val_accuracy: 0.0453 - val_mse: 0.5197 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.5197
# Epoch 6/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1731 - accuracy: 0.2806 - mse: 1.2818 - weighted_accuracy: 0.5446 - weighted_mse: 1.2367 - val_loss: 0.2522 - val_accuracy: 0.0453 - val_mse: 0.5773 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.5773
# Epoch 7/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1698 - accuracy: 0.3037 - mse: 1.3012 - weighted_accuracy: 0.5565 - weighted_mse: 1.2542 - val_loss: 0.2425 - val_accuracy: 0.0453 - val_mse: 0.6362 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.6362
# Epoch 8/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1680 - accuracy: 0.3340 - mse: 1.3111 - weighted_accuracy: 0.5714 - weighted_mse: 1.2687 - val_loss: 0.2366 - val_accuracy: 0.0453 - val_mse: 0.6974 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.6974
# Epoch 9/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1656 - accuracy: 0.2900 - mse: 1.3300 - weighted_accuracy: 0.5737 - weighted_mse: 1.2687 - val_loss: 0.2301 - val_accuracy: 0.0464 - val_mse: 0.7688 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.7688
# Epoch 10/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1629 - accuracy: 0.3361 - mse: 1.3331 - weighted_accuracy: 0.6054 - weighted_mse: 1.2799 - val_loss: 0.2229 - val_accuracy: 0.0527 - val_mse: 0.8412 - val_weighted_accuracy: 0.0527 - val_weighted_mse: 0.8412
# Epoch 11/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1611 - accuracy: 0.2995 - mse: 1.3601 - weighted_accuracy: 0.6104 - weighted_mse: 1.2880 - val_loss: 0.2166 - val_accuracy: 0.0674 - val_mse: 0.9099 - val_weighted_accuracy: 0.0674 - val_weighted_mse: 0.9099
# Epoch 12/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1593 - accuracy: 0.3330 - mse: 1.3767 - weighted_accuracy: 0.6226 - weighted_mse: 1.3153 - val_loss: 0.2114 - val_accuracy: 0.1412 - val_mse: 0.9704 - val_weighted_accuracy: 0.1412 - val_weighted_mse: 0.9704
# Epoch 13/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1576 - accuracy: 0.3364 - mse: 1.3727 - weighted_accuracy: 0.6276 - weighted_mse: 1.3103 - val_loss: 0.2052 - val_accuracy: 0.2508 - val_mse: 1.0394 - val_weighted_accuracy: 0.2508 - val_weighted_mse: 1.0394
# Epoch 14/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1553 - accuracy: 0.3398 - mse: 1.3986 - weighted_accuracy: 0.6400 - weighted_mse: 1.3324 - val_loss: 0.1963 - val_accuracy: 0.3488 - val_mse: 1.1010 - val_weighted_accuracy: 0.3488 - val_weighted_mse: 1.1010
# Epoch 15/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1542 - accuracy: 0.3691 - mse: 1.3959 - weighted_accuracy: 0.6377 - weighted_mse: 1.3377 - val_loss: 0.1986 - val_accuracy: 0.3172 - val_mse: 1.1460 - val_weighted_accuracy: 0.3172 - val_weighted_mse: 1.1460
# Epoch 16/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1533 - accuracy: 0.3404 - mse: 1.4151 - weighted_accuracy: 0.6548 - weighted_mse: 1.3437 - val_loss: 0.1949 - val_accuracy: 0.3551 - val_mse: 1.1782 - val_weighted_accuracy: 0.3551 - val_weighted_mse: 1.1782
# Epoch 17/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1513 - accuracy: 0.3464 - mse: 1.4478 - weighted_accuracy: 0.6533 - weighted_mse: 1.3690 - val_loss: 0.1895 - val_accuracy: 0.3825 - val_mse: 1.2031 - val_weighted_accuracy: 0.3825 - val_weighted_mse: 1.2031
# Epoch 18/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1497 - accuracy: 0.3643 - mse: 1.4376 - weighted_accuracy: 0.6581 - weighted_mse: 1.3750 - val_loss: 0.1911 - val_accuracy: 0.3446 - val_mse: 1.2376 - val_weighted_accuracy: 0.3446 - val_weighted_mse: 1.2376
# Epoch 19/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1475 - accuracy: 0.3722 - mse: 1.4539 - weighted_accuracy: 0.6757 - weighted_mse: 1.3839 - val_loss: 0.1849 - val_accuracy: 0.3930 - val_mse: 1.2779 - val_weighted_accuracy: 0.3930 - val_weighted_mse: 1.2779
# Epoch 20/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1455 - accuracy: 0.3762 - mse: 1.4751 - weighted_accuracy: 0.6790 - weighted_mse: 1.4088 - val_loss: 0.1810 - val_accuracy: 0.4373 - val_mse: 1.3017 - val_weighted_accuracy: 0.4373 - val_weighted_mse: 1.3017
# Validation loss: 0.1809903234243393
# Validation accuracy: 0.4373024106025696
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1880 - accuracy: 0.3991 - mse: 1.3847 - weighted_accuracy: 0.3991 - weighted_mse: 1.3847
# Test loss: 0.18800249695777893
# Test accuracy: 0.39908257126808167
#
#
# number of predictions: 218
# actual predicted buys: 3
# actual buys but predicted sell: 0
# actual buys but predicted hold: 5
# actual sells but predicted buy: 1
# actual predicted sells: 4
# actual sells but predicted hold: 3
# actual holds but predicted buy: 50
# actual holds but predicted sell: 72
# actual predicted holds: 80
# Percentage buys correct: 5.555555555555555%
# Percentage sells correct: 5.2631578947368425%
# Percentage holds correct: 90.9090909090909%
# actual buys: 8
# actual sells: 8
# actual holds: 202
#
#
# Percentage low buys correct: 40.74074074074074%
# Percentage high sells correct: 61.8421052631579%
# Percentage mid holds correct: 74.71264367816092%
#
#
# Capital: 100
# Share price: $0.7964077880589524
# Shares owned at the moment: 125
# Cash capital at the moment: $0.17526131548568458
#
#
# Price increase from previously bought: -13.647200303025608%
# Share price: $0.6896116531541341
# Shares owned at the moment: 0
# Cash capital at the moment: $86.1396639539807
#
#
# Share price: $1.01
# Shares owned at the moment: 85
# Cash capital at the moment: $0.053576453980710426
#
#
# Price increase from previously bought: -12.736370321743784%
# Share price: $0.8837864070647015
# Shares owned at the moment: 0
# Cash capital at the moment: $74.96883598182896
#
#
# Share price: $0.7769903300284726
# Shares owned at the moment: 96
# Cash capital at the moment: $0.17263885196807394
#
#
# Price increase from previously bought: -71.9252641868983%
# Share price: $0.21873786190057493
# Shares owned at the moment: 0
# Cash capital at the moment: $21.113726798881515
#
#
# Share price: $0.2333009843577296
# Shares owned at the moment: 90
# Cash capital at the moment: $0.05889621305730941
#
#
# Price increase from previously bought: -4.424293993737061%
# Share price: $0.22359225534248967
# Shares owned at the moment: 0
# Cash capital at the moment: $20.126860110684113
#
#
# Share price: $0.22359225534248967
# Shares owned at the moment: 89
# Cash capital at the moment: $0.17242518070746016
#
#
# Price increase from previously bought: -0.27424582398404285%
# Share price: $0.22359225534248967
# Shares owned at the moment: 0
# Cash capital at the moment: $20.017411701693966
#
#
# Share price: $0.21873786190057493
# Shares owned at the moment: 91
# Cash capital at the moment: $0.057527118801029786
#
#
# Price increase from previously bought: 4.152117313230086%
# Share price: $0.22844661985010967
# Shares owned at the moment: 0
# Cash capital at the moment: $20.78900075854352
#
#
# Share price: $0.20417476837771503
# Shares owned at the moment: 101
# Cash capital at the moment: $0.11063961047739213
#
#
# Price increase from previously bought: 9.209901248404462%
# Share price: $0.22359225534248967
# Shares owned at the moment: 0
# Cash capital at the moment: $22.631354651147472
#
#
# Share price: $0.1556310654329257
# Shares owned at the moment: 145
# Cash capital at the moment: $0.0027922760318652706
#
#
# Price increase from previously bought: 27.721143226254675%
# Share price: $0.19932040387009503
# Shares owned at the moment: 0
# Cash capital at the moment: $28.824771826152443
#
#
# Share price: $0.19446603936247508
# Shares owned at the moment: 147
# Cash capital at the moment: $0.1596511434563226
#
#
# Price increase from previously bought: 9.683383038201733%
# Share price: $0.21388349739295492
# Shares owned at the moment: 0
# Cash capital at the moment: $31.514062856399594
#
#
# Share price: $0.019708743482387346
# Shares owned at the moment: 1594
# Cash capital at the moment: $0.011932468419118436
#
#
# Price increase from previously bought: 171.66665033190262%
# Share price: $0.05368932397002193
# Shares owned at the moment: 0
# Cash capital at the moment: $85.35736772501149
#
#
# Share price: $0.03912621598001464
# Shares owned at the moment: 2175
# Cash capital at the moment: $0.023824289149189326
#
#
# Price increase from previously bought: 12.098664498214262%
# Share price: $0.043980580487634584
# Shares owned at the moment: 0
# Cash capital at the moment: $95.41852800271275
#
#
# Share price: $0.02456310799000732
# Shares owned at the moment: 3873
# Cash capital at the moment: $0.02399523498982603
#
#
# Price increase from previously bought: 39.1430692110857%
# Share price: $0.034271851472394664
# Shares owned at the moment: 0
# Cash capital at the moment: $132.39385506550474
#
#
#
#
# Capital at the end of test period: $132.39385506550474
# profit gained: 32.39385506550474%
#
#
# Capital at the end of test period if Buy and Hold: $2.5934579490563006
# profit gained: -97.4065420509437%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.399083      5.555556       5.263158      90.909091
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         40.740741           61.842105          74.712644      32.393855
#
#    buy_n_hold profit
# 0         -97.406542
#
#
# Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1901 - accuracy: 0.3836 - mse: 1.3393 - weighted_accuracy: 0.3836 - weighted_mse: 1.3393
# Test loss: 0.19013884663581848
# Test accuracy: 0.3835616409778595
#
#
# number of predictions: 219
# actual predicted buys: 3
# actual buys but predicted sell: 1
# actual buys but predicted hold: 4
# actual sells but predicted buy: 1
# actual predicted sells: 5
# actual sells but predicted hold: 2
# actual holds but predicted buy: 58
# actual holds but predicted sell: 69
# actual predicted holds: 76
# Percentage buys correct: 4.838709677419355%
# Percentage sells correct: 6.666666666666667%
# Percentage holds correct: 92.6829268292683%
# actual buys: 8
# actual sells: 8
# actual holds: 203
#
#
# Percentage low buys correct: 51.61290322580645%
# Percentage high sells correct: 48.0%
# Percentage mid holds correct: 83.95061728395062%
#
#
# Capital: 100
# Share price: $0.012510990752711301
# Shares owned at the moment: 7971
# Cash capital at the moment: $0.0006486650910915159
#
#
# Price increase from previously bought: 99.80170118486838%
# Share price: $0.025065914582985994
# Shares owned at the moment: 0
# Cash capital at the moment: $199.25160269193475
#
#
# Share price: $0.05143126884487168
# Shares owned at the moment: 3863
# Cash capital at the moment: $0.026243917439131792
#
#
# Price increase from previously bought: -2.708671402499363%
# Share price: $0.05017576972685583
# Shares owned at the moment: 0
# Cash capital at the moment: $193.32221262653235
#
#
# Share price: $0.052686760479567114
# Shares owned at the moment: 3659
# Cash capital at the moment: $0.01120867616074861
#
#
# Price increase from previously bought: 3.290355102094056%
# Share price: $0.05456999793161025
# Shares owned at the moment: 0
# Cash capital at the moment: $199.1337341462353
#
#
# Share price: $0.10855618312343616
# Shares owned at the moment: 1829
# Cash capital at the moment: $0.03846475140542793
#
#
# Price increase from previously bought: 18.179614007731935%
# Share price: $0.1286440792118447
# Shares owned at the moment: 0
# Cash capital at the moment: $234.6814380724536
#
#
# Share price: $0.08658506454962535
# Shares owned at the moment: 2702
# Cash capital at the moment: $0.08522333722990538
#
#
# Price increase from previously bought: 9.124985124778838%
# Share price: $0.09474577514178649
# Shares owned at the moment: 0
# Cash capital at the moment: $255.38429928814597
#
#
# Share price: $0.45883866350291824
# Shares owned at the moment: 555
# Cash capital at the moment: $0.028538533855027026
#
#
# Price increase from previously bought: 85.68094874687795%
# Share price: $0.8543189175646401
# Shares owned at the moment: 0
# Cash capital at the moment: $472.8716335342972
#
#
# Share price: $0.6471625883069226
# Shares owned at the moment: 728
# Cash capital at the moment: $0.4416497450670249
#
#
# Price increase from previously bought: -4.53052817507481%
# Share price: $0.6195417723436233
# Shares owned at the moment: 0
# Cash capital at the moment: $450.22773738299287
#
#
# Share price: $0.4977589939783217
# Shares owned at the moment: 902
# Cash capital at the moment: $0.014433629983443552
#
#
# Price increase from previously bought: -50.95902094659025%
# Share price: $0.24477717515429862
# Shares owned at the moment: 0
# Cash capital at the moment: $220.19627583619055
#
#
# Share price: $0.3753484248957497
# Shares owned at the moment: 585
# Cash capital at the moment: $0.01360549362593133
#
#
# Price increase from previously bought: 1.7271721944843943%
# Share price: $0.3828813747039225
# Shares owned at the moment: 0
# Cash capital at the moment: $223.38324928386564
#
#
# Share price: $0.3263841912760648
# Shares owned at the moment: 682
# Cash capital at the moment: $0.17709728285120718
#
#
# Price increase from previously bought: -18.6876339021939%
# Share price: $0.26612053294412086
# Shares owned at the moment: 0
# Cash capital at the moment: $181.17219169120494
#
#
# Share price: $0.16442562073394612
# Shares owned at the moment: 1098
# Cash capital at the moment: $0.1363769635259473
#
#
# Price increase from previously bought: 59.50105646395565%
# Share price: $0.26298181882402316
# Shares owned at the moment: 0
# Cash capital at the moment: $288.09634043036425
#
#
# Share price: $0.42807910348623956
# Shares owned at the moment: 671
# Cash capital at the moment: $0.06534902538953702
#
#
#
#
# Capital at the end of test period: $272.6545543334112
# profit gained: 172.65455433341123%
#
#
# Capital at the end of test period if Buy and Hold: $3238.165410975435
# profit gained: 3138.165410975435%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.383562       4.83871       6.666667      92.682927
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         51.612903                48.0          83.950617     172.654554
#
#    buy_n_hold profit
# 0        3138.165411
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1770 - accuracy: 0.5183 - mse: 1.2782 - weighted_accuracy: 0.5183 - weighted_mse: 1.2782
# Test loss: 0.17698653042316437
# Test accuracy: 0.5183486342430115
#
#
# number of predictions: 218
# actual predicted buys: 2
# actual buys but predicted sell: 0
# actual buys but predicted hold: 8
# actual sells but predicted buy: 3
# actual predicted sells: 5
# actual sells but predicted hold: 1
# actual holds but predicted buy: 30
# actual holds but predicted sell: 63
# actual predicted holds: 106
# Percentage buys correct: 5.714285714285714%
# Percentage sells correct: 7.352941176470588%
# Percentage holds correct: 92.17391304347827%
# actual buys: 10
# actual sells: 9
# actual holds: 199
#
#
# Percentage low buys correct: 40.0%
# Percentage high sells correct: 54.411764705882355%
# Percentage mid holds correct: 78.94736842105263%
#
#
# Capital: 100
# Share price: $0.6460294120869631
# Shares owned at the moment: 154
# Cash capital at the moment: $0.23787708258885232
#
#
# Price increase from previously bought: -1.9768236404776873%
# Share price: $0.6350000109567361
# Shares owned at the moment: 0
# Cash capital at the moment: $97.75895626528602
#
#
# Share price: $0.5908823187819406
# Shares owned at the moment: 164
# Cash capital at the moment: $0.5877680592770957
#
#
# Price increase from previously bought: 5.930700763316721%
# Share price: $0.6276470768699184
# Shares owned at the moment: 0
# Cash capital at the moment: $103.23881983427538
#
#
# Share price: $0.6239706098265095
# Shares owned at the moment: 165
# Cash capital at the moment: $0.0005425486925219047
#
#
# Price increase from previously bought: 2.663700634016264%
# Share price: $0.642352945043554
# Shares owned at the moment: 0
# Cash capital at the moment: $105.69731083206541
#
#
# Share price: $0.6386764780001449
# Shares owned at the moment: 165
# Cash capital at the moment: $0.025892510148935344
#
#
# Price increase from previously bought: 2.596052842370966%
# Share price: $0.6570588132171898
# Shares owned at the moment: 0
# Cash capital at the moment: $108.14245625448795
#
#
# Share price: $0.5982352528687588
# Shares owned at the moment: 180
# Cash capital at the moment: $0.16398428794133224
#
#
# Price increase from previously bought: -70.14110490022999%
# Share price: $0.17911765930458734
# Shares owned at the moment: 0
# Cash capital at the moment: $32.316499721411276
#
#
# Share price: $0.3960293901734909
# Shares owned at the moment: 81
# Cash capital at the moment: $0.1499035706973615
#
#
# Price increase from previously bought: -9.532105409774083%
# Share price: $0.35926471973940155
# Shares owned at the moment: 0
# Cash capital at the moment: $29.170319653266933
#
#
# Share price: $0.2820588241739258
# Shares owned at the moment: 103
# Cash capital at the moment: $0.03836760140531226
#
#
# Price increase from previously bought: 3.625349762301977%
# Share price: $0.29308822530415257
# Shares owned at the moment: 0
# Cash capital at the moment: $30.143437567915626
#
#
# Share price: $0.21588232973867671
# Shares owned at the moment: 139
# Cash capital at the moment: $0.05327271369695197
#
#
# Price increase from previously bought: -39.33577100542864%
# Share price: $0.13132350008638305
# Shares owned at the moment: 0
# Cash capital at the moment: $18.257040817796177
#
#
# Share price: $0.09455882965229377
# Shares owned at the moment: 192
# Cash capital at the moment: $0.05181846249936228
#
#
# Price increase from previously bought: -4.151603971873641%
# Share price: $0.09088236260888481
# Shares owned at the moment: 0
# Cash capital at the moment: $17.453246195947752
#
#
# Share price: $0.0761764944352493
# Shares owned at the moment: 228
# Cash capital at the moment: $0.037242802700006905
#
#
# Price increase from previously bought: -43.59147646420427%
# Share price: $0.04308820339068042
# Shares owned at the moment: 0
# Cash capital at the moment: $9.834336872249185
#
#
#
#
# Capital at the end of test period: $9.834336872249185
# profit gained: -90.16566312775082%
#
#
# Capital at the end of test period if Buy and Hold: $26.129427230180067
# profit gained: -73.87057276981993%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.399083      5.555556       5.263158      90.909091
# 1       0.518349      5.714286       7.352941      92.173913
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         40.740741           61.842105          74.712644      32.393855
# 1         40.000000           54.411765          78.947368     -90.165663
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
#
#
# Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1823 - accuracy: 0.4201 - mse: 1.2774 - weighted_accuracy: 0.4201 - weighted_mse: 1.2774
# Test loss: 0.18234451115131378
# Test accuracy: 0.42009133100509644
#
#
# number of predictions: 219
# actual predicted buys: 2
# actual buys but predicted sell: 1
# actual buys but predicted hold: 5
# actual sells but predicted buy: 1
# actual predicted sells: 8
# actual sells but predicted hold: 2
# actual holds but predicted buy: 53
# actual holds but predicted sell: 65
# actual predicted holds: 82
# Percentage buys correct: 3.5714285714285716%
# Percentage sells correct: 10.81081081081081%
# Percentage holds correct: 92.13483146067416%
# actual buys: 8
# actual sells: 11
# actual holds: 200
#
#
# Percentage low buys correct: 50.0%
# Percentage high sells correct: 54.054054054054056%
# Percentage mid holds correct: 82.95454545454545%
#
#
# Capital: 100
# Share price: $0.02410935049810265
# Shares owned at the moment: 4136
# Cash capital at the moment: $0.009506587282004375
#
#
# Price increase from previously bought: 78.5142241468006%
# Share price: $0.04315697619348919
# Shares owned at the moment: 0
# Cash capital at the moment: $178.01589267632855
#
#
# Share price: $0.15462081317116044
# Shares owned at the moment: 1148
# Cash capital at the moment: $0.023061248654983046
#
#
# Price increase from previously bought: 18.608476450983535%
# Share price: $0.1838977226030758
# Shares owned at the moment: 0
# Cash capital at the moment: $210.55708168672808
#
#
# Share price: $0.2614991251131616
# Shares owned at the moment: 802
# Cash capital at the moment: $0.2580470255354044
#
#
# Price increase from previously bought: 38.73629374046315%
# Share price: $0.3637918783801879
# Shares owned at the moment: 0
# Cash capital at the moment: $291.21679049867856
#
#
# Share price: $0.3630864285159178
# Shares owned at the moment: 799
# Cash capital at the moment: $0.3129424594036436
#
#
# Price increase from previously bought: 7.476327215915846%
# Share price: $0.3913050958728182
# Shares owned at the moment: 0
# Cash capital at the moment: $312.1059189398788
#
#
# Share price: $0.7419223909950073
# Shares owned at the moment: 419
# Cash capital at the moment: $0.3855570379466826
#
#
# Price increase from previously bought: 6.979918751148495%
# Share price: $0.7958906680035154
# Shares owned at the moment: 0
# Cash capital at the moment: $332.94668190921254
#
#
# Share price: $0.6357495457369284
# Shares owned at the moment: 522
# Cash capital at the moment: $0.17280056163053814
#
#
# Price increase from previously bought: -5.032711681573643%
# Share price: $0.6054144278693031
# Shares owned at the moment: 0
# Cash capital at the moment: $315.3300594982004
#
#
# Share price: $0.4078835881744759
# Shares owned at the moment: 770
# Cash capital at the moment: $0.3960031058945219
#
#
# Price increase from previously bought: -20.799805283631223%
# Share price: $0.32393296868943494
# Shares owned at the moment: 0
# Cash capital at the moment: $249.13846093555955
#
#
# Share price: $0.2946560760771721
# Shares owned at the moment: 843
# Cash capital at the moment: $0.06030235413757623
#
#
# Price increase from previously bought: -16.152051104065823%
# Share price: $0.24774249954719407
# Shares owned at the moment: 0
# Cash capital at the moment: $208.3329004228469
#
#
# Share price: $0.37296296209083296
# Shares owned at the moment: 557
# Cash capital at the moment: $0.02124452107031516
#
#
# Price increase from previously bought: 45.84661885055525%
# Share price: $0.5454497429162375
# Shares owned at the moment: 0
# Cash capital at the moment: $303.00125868170267
#
#
# Share price: $0.30135803480391465
# Shares owned at the moment: 1002
# Cash capital at the moment: $0.21011574327798144
#
#
# Price increase from previously bought: 8.013374629580007%
# Share price: $0.3264021273126424
# Shares owned at the moment: 0
# Cash capital at the moment: $326.36564624873563
#
#
# Share price: $0.3228747770733774
# Shares owned at the moment: 1008
# Cash capital at the moment: $0.012862076723763494
#
#
# Price increase from previously bought: -15.635943116987526%
# Share price: $0.27313933380770933
# Shares owned at the moment: 0
# Cash capital at the moment: $274.5801683215798
#
#
# Share price: $0.29818342631643713
# Shares owned at the moment: 918
# Cash capital at the moment: $0.09501890335462804
#
#
# Price increase from previously bought: 1.9671749753953138%
# Share price: $0.3048853514038746
# Shares owned at the moment: 0
# Cash capital at the moment: $279.21008842249245
#
#
# Share price: $0.2823104175183544
# Shares owned at the moment: 986
# Cash capital at the moment: $0.08653205229398964
#
#
#
#
# Capital at the end of test period: $254.4409054263905
# profit gained: 154.4409054263905%
#
#
# Capital at the end of test period if Buy and Hold: $2186.7819938452512
# profit gained: 2086.7819938452512%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.383562      4.838710       6.666667      92.682927
# 1       0.420091      3.571429      10.810811      92.134831
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         51.612903           48.000000          83.950617     172.654554
# 1         50.000000           54.054054          82.954545     154.440905
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1807 - accuracy: 0.4541 - mse: 1.3555 - weighted_accuracy: 0.4541 - weighted_mse: 1.3555
# Test loss: 0.18065223097801208
# Test accuracy: 0.4541284441947937
#
#
# number of predictions: 218
# actual predicted buys: 5
# actual buys but predicted sell: 1
# actual buys but predicted hold: 3
# actual sells but predicted buy: 2
# actual predicted sells: 6
# actual sells but predicted hold: 0
# actual holds but predicted buy: 60
# actual holds but predicted sell: 53
# actual predicted holds: 88
# Percentage buys correct: 7.462686567164179%
# Percentage sells correct: 10.0%
# Percentage holds correct: 96.7032967032967%
# actual buys: 9
# actual sells: 8
# actual holds: 201
#
#
# Percentage low buys correct: 43.28358208955224%
# Percentage high sells correct: 61.666666666666664%
# Percentage mid holds correct: 87.77777777777777%
#
#
# Capital: 100
# Share price: $1.01
# Shares owned at the moment: 98
# Cash capital at the moment: $0.7478049999999996
#
#
# Price increase from previously bought: -81.10694813552661%
# Share price: $0.191344578346717
# Shares owned at the moment: 0
# Cash capital at the moment: $19.448006314113826
#
#
# Share price: $0.18142149179007902
# Shares owned at the moment: 106
# Cash capital at the moment: $0.16444381950864084
#
#
# Price increase from previously bought: 16.089660138387597%
# Share price: $0.21119077511849751
# Shares owned at the moment: 0
# Cash capital at the moment: $22.489103871122335
#
#
# Share price: $0.201267664903355
# Shares owned at the moment: 111
# Cash capital at the moment: $0.0869561121381821
#
#
# Price increase from previously bought: -10.107790532616601%
# Share price: $0.18142149179007902
# Shares owned at the moment: 0
# Cash capital at the moment: $20.169362790468032
#
#
# Share price: $0.146690641524837
# Shares owned at the moment: 137
# Cash capital at the moment: $0.01747920237088252
#
#
# Price increase from previously bought: -52.21913567252254%
# Share price: $0.07028280406321093
# Shares owned at the moment: 0
# Cash capital at the moment: $9.619744312599964
#
#
# Share price: $0.07028280406321093
# Shares owned at the moment: 136
# Cash capital at the moment: $0.03499719128363843
#
#
# Price increase from previously bought: -8.018288155427221%
# Share price: $0.06482510645706006
# Shares owned at the moment: 0
# Cash capital at the moment: $8.826967079628865
#
#
# Share price: $0.06060778875586278
# Shares owned at the moment: 145
# Cash capital at the moment: $0.014670354262362295
#
#
# Price increase from previously bought: 23.4009744823084%
# Share price: $0.07499627609224012
# Shares owned at the moment: 0
# Cash capital at the moment: $10.859225622545399
#
#
# Share price: $0.04497890968527956
# Shares owned at the moment: 240
# Cash capital at the moment: $0.03460121768601887
#
#
# Price increase from previously bought: 28.877304063743313%
# Share price: $0.05812701711670328
# Shares owned at the moment: 0
# Cash capital at the moment: $13.946721494397782
#
#
# Share price: $0.04572314709165353
# Shares owned at the moment: 304
# Cash capital at the moment: $0.008660227566485545
#
#
# Price increase from previously bought: -32.19774882023013%
# Share price: $0.03108657667673411
# Shares owned at the moment: 0
# Cash capital at the moment: $9.432991159191905
#
#
# Share price: $0.018186552323852474
# Shares owned at the moment: 517
# Cash capital at the moment: $0.004686876993739375
#
#
# Price increase from previously bought: 353.4114430772702%
# Share price: $0.08268667408826068
# Shares owned at the moment: 0
# Cash capital at the moment: $42.63613760173952
#
#
# Share price: $0.06656164068984556
# Shares owned at the moment: 638
# Cash capital at the moment: $0.05302844302771348
#
#
# Price increase from previously bought: 59.19474923320542%
# Share price: $0.10625403423340656
# Shares owned at the moment: 0
# Cash capital at the moment: $67.65667958087857
#
#
# Share price: $0.04274622112466215
# Shares owned at the moment: 1578
# Cash capital at the moment: $0.01764541959123278
#
#
# Price increase from previously bought: -15.900730998860336%
# Share price: $0.0360481199550531
# Shares owned at the moment: 0
# Cash capital at the moment: $56.74514789212007
#
#
# Share price: $0.027861567631200616
# Shares owned at the moment: 2031
# Cash capital at the moment: $0.002690212539455672
#
#
# Price increase from previously bought: 0.6137254644015044%
# Share price: $0.028109650709742716
# Shares owned at the moment: 0
# Cash capital at the moment: $56.93639137740032
#
#
# Share price: $0.02538079599204115
# Shares owned at the moment: 2237
# Cash capital at the moment: $0.003414431460228684
#
#
# Price increase from previously bought: 29.94272374258764%
# Share price: $0.03307119398806171
# Shares owned at the moment: 0
# Cash capital at the moment: $73.78022966513821
#
#
# Share price: $0.022403870025049753
# Shares owned at the moment: 3284
# Cash capital at the moment: $0.003591152678595222
#
#
# Price increase from previously bought: 72.60692191040965%
# Share price: $0.038776974672754684
# Shares owned at the moment: 0
# Cash capital at the moment: $126.99698111973534
#
#
#
#
# Capital at the end of test period: $126.99698111973534
# profit gained: 26.996981119735334%
#
#
# Capital at the end of test period if Buy and Hold: $2.3797176202777375
# profit gained: -97.62028237972227%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.399083      5.555556       5.263158      90.909091
# 1       0.518349      5.714286       7.352941      92.173913
# 2       0.454128      7.462687      10.000000      96.703297
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         40.740741           61.842105          74.712644      32.393855
# 1         40.000000           54.411765          78.947368     -90.165663
# 2         43.283582           61.666667          87.777778      26.996981
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
# 2         -97.620282
#
#
# Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1790 - accuracy: 0.4932 - mse: 1.2647 - weighted_accuracy: 0.4932 - weighted_mse: 1.2647
# Test loss: 0.17898398637771606
# Test accuracy: 0.4931506812572479
#
#
# number of predictions: 219
# actual predicted buys: 2
# actual buys but predicted sell: 1
# actual buys but predicted hold: 5
# actual sells but predicted buy: 1
# actual predicted sells: 7
# actual sells but predicted hold: 2
# actual holds but predicted buy: 24
# actual holds but predicted sell: 78
# actual predicted holds: 99
# Percentage buys correct: 7.407407407407407%
# Percentage sells correct: 8.13953488372093%
# Percentage holds correct: 93.39622641509433%
# actual buys: 8
# actual sells: 10
# actual holds: 201
#
#
# Percentage low buys correct: 62.96296296296296%
# Percentage high sells correct: 47.05882352941177%
# Percentage mid holds correct: 86.79245283018868%
#
#
# Capital: 100
# Share price: $0.011748252914169829
# Shares owned at the moment: 8488
# Cash capital at the moment: $0.006601545003931619
#
#
# Price increase from previously bought: 22.97529799873046%
# Share price: $0.014487179515679708
# Shares owned at the moment: 0
# Cash capital at the moment: $122.6356215298383
#
#
# Share price: $0.023869464968017798
# Shares owned at the moment: 5123
# Cash capital at the moment: $0.016073508847455287
#
#
# Price increase from previously bought: 32.83781213994696%
# Share price: $0.03179487113936676
# Shares owned at the moment: 0
# Cash capital at the moment: $162.45326426249414
#
#
# Share price: $0.2775407999780544
# Shares owned at the moment: 583
# Cash capital at the moment: $0.20201058772360625
#
#
# Price increase from previously bought: -17.842360305316184%
# Share price: $0.22864802812045526
# Shares owned at the moment: 0
# Cash capital at the moment: $133.13723103086488
#
#
# Share price: $0.5790559484281369
# Shares owned at the moment: 229
# Cash capital at the moment: $0.16875835729891264
#
#
# Price increase from previously bought: 5.155344861121347%
# Share price: $0.6105827772770925
# Shares owned at the moment: 0
# Cash capital at the moment: $139.60769984976284
#
#
# Share price: $0.8780652675159911
# Shares owned at the moment: 158
# Cash capital at the moment: $0.49186822350051784
#
#
# Price increase from previously bought: 0.586168501346962%
# Share price: $0.8856410431116603
# Shares owned at the moment: 0
# Cash capital at the moment: $140.03834200191082
#
#
# Share price: $0.6288811425881197
# Shares owned at the moment: 222
# Cash capital at the moment: $0.042796409798199875
#
#
# Price increase from previously bought: -7.0294537149598995%
# Share price: $0.5862820878905832
# Shares owned at the moment: 0
# Cash capital at the moment: $129.83949470685047
#
#
# Share price: $0.5667016641439497
# Shares owned at the moment: 228
# Cash capital at the moment: $0.2761933386116766
#
#
# Price increase from previously bought: 4.822489332645885%
# Share price: $0.5956643761216928
# Shares owned at the moment: 0
# Cash capital at the moment: $135.71418953052932
#
#
# Share price: $0.4499184383909367
# Shares owned at the moment: 300
# Cash capital at the moment: $0.3674753015757801
#
#
# Price increase from previously bought: 13.55968824127627%
# Share price: $0.5123310224107025
# Shares owned at the moment: 0
# Cash capital at the moment: $153.6441089312977
#
#
# Share price: $0.47410259721981923
# Shares owned at the moment: 323
# Cash capital at the moment: $0.08784839731558236
#
#
# Price increase from previously bought: 19.39975284882671%
# Share price: $0.567634041985991
# Shares owned at the moment: 0
# Cash capital at the moment: $182.92944302099662
#
#
# Share price: $0.6404195795878922
# Shares owned at the moment: 284
# Cash capital at the moment: $0.5501147263770747
#
#
# Price increase from previously bought: 9.8257411355662%
# Share price: $0.7052797499212441
# Shares owned at the moment: 0
# Cash capital at the moment: $200.2987402193219
#
#
#
#
# Capital at the end of test period: $200.2987402193219
# profit gained: 100.2987402193219%
#
#
# Capital at the end of test period if Buy and Hold: $5902.379195330377
# profit gained: 5802.379195330377%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.383562      4.838710       6.666667      92.682927
# 1       0.420091      3.571429      10.810811      92.134831
# 2       0.493151      7.407407       8.139535      93.396226
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         51.612903           48.000000          83.950617     172.654554
# 1         50.000000           54.054054          82.954545     154.440905
# 2         62.962963           47.058824          86.792453     100.298740
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
# 2        5802.379195
#
#
#
# RUNNING EPOCHS 20 - 40
#
#
#
# Epoch 1/20
#  2/30 [=>............................] - ETA: 17s - loss: 0.1360 - accuracy: 0.4102 - mse: 1.4297 - weighted_accuracy: 0.6834 - weighted_mse: 1.3924WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0100s vs `on_train_batch_end` time: 1.2257s). Check your callbacks.
# 30/30 [==============================] - 2s 51ms/step - loss: 0.1453 - accuracy: 0.3973 - mse: 1.4834 - weighted_accuracy: 0.6811 - weighted_mse: 1.4251 - val_loss: 0.1855 - val_accuracy: 0.3720 - val_mse: 1.3449 - val_weighted_accuracy: 0.3720 - val_weighted_mse: 1.3449
# Epoch 2/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1430 - accuracy: 0.3846 - mse: 1.5061 - weighted_accuracy: 0.6949 - weighted_mse: 1.4377 - val_loss: 0.1837 - val_accuracy: 0.3804 - val_mse: 1.4286 - val_weighted_accuracy: 0.3804 - val_weighted_mse: 1.4286
# Epoch 3/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1426 - accuracy: 0.3904 - mse: 1.5438 - weighted_accuracy: 0.6897 - weighted_mse: 1.4836 - val_loss: 0.1805 - val_accuracy: 0.4046 - val_mse: 1.3774 - val_weighted_accuracy: 0.4046 - val_weighted_mse: 1.3774
# Epoch 4/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1410 - accuracy: 0.3944 - mse: 1.5519 - weighted_accuracy: 0.6799 - weighted_mse: 1.4814 - val_loss: 0.1703 - val_accuracy: 0.4963 - val_mse: 1.4656 - val_weighted_accuracy: 0.4963 - val_weighted_mse: 1.4656
# Epoch 5/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1386 - accuracy: 0.4223 - mse: 1.5497 - weighted_accuracy: 0.7106 - weighted_mse: 1.5000 - val_loss: 0.1887 - val_accuracy: 0.3667 - val_mse: 1.4815 - val_weighted_accuracy: 0.3667 - val_weighted_mse: 1.4815
# Epoch 6/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1380 - accuracy: 0.4065 - mse: 1.5609 - weighted_accuracy: 0.7049 - weighted_mse: 1.4998 - val_loss: 0.1882 - val_accuracy: 0.3867 - val_mse: 1.5348 - val_weighted_accuracy: 0.3867 - val_weighted_mse: 1.5348
# Epoch 7/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1360 - accuracy: 0.4449 - mse: 1.5988 - weighted_accuracy: 0.7171 - weighted_mse: 1.5567 - val_loss: 0.1795 - val_accuracy: 0.4447 - val_mse: 1.5436 - val_weighted_accuracy: 0.4447 - val_weighted_mse: 1.5436
# Epoch 8/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1356 - accuracy: 0.4613 - mse: 1.6005 - weighted_accuracy: 0.7157 - weighted_mse: 1.5635 - val_loss: 0.1950 - val_accuracy: 0.3562 - val_mse: 1.6629 - val_weighted_accuracy: 0.3562 - val_weighted_mse: 1.6629
# Epoch 9/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1342 - accuracy: 0.4228 - mse: 1.6298 - weighted_accuracy: 0.7107 - weighted_mse: 1.5773 - val_loss: 0.1789 - val_accuracy: 0.4499 - val_mse: 1.5758 - val_weighted_accuracy: 0.4499 - val_weighted_mse: 1.5758
# Epoch 10/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1326 - accuracy: 0.4826 - mse: 1.6388 - weighted_accuracy: 0.7346 - weighted_mse: 1.6079 - val_loss: 0.1956 - val_accuracy: 0.3667 - val_mse: 1.7373 - val_weighted_accuracy: 0.3667 - val_weighted_mse: 1.7373
# Epoch 11/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1320 - accuracy: 0.4455 - mse: 1.6741 - weighted_accuracy: 0.7210 - weighted_mse: 1.6259 - val_loss: 0.1807 - val_accuracy: 0.4457 - val_mse: 1.6820 - val_weighted_accuracy: 0.4457 - val_weighted_mse: 1.6820
# Epoch 12/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1312 - accuracy: 0.4665 - mse: 1.6837 - weighted_accuracy: 0.7268 - weighted_mse: 1.6435 - val_loss: 0.1900 - val_accuracy: 0.3899 - val_mse: 1.7588 - val_weighted_accuracy: 0.3899 - val_weighted_mse: 1.7588
# Epoch 13/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1301 - accuracy: 0.4600 - mse: 1.6916 - weighted_accuracy: 0.7392 - weighted_mse: 1.6523 - val_loss: 0.1898 - val_accuracy: 0.4025 - val_mse: 1.7901 - val_weighted_accuracy: 0.4025 - val_weighted_mse: 1.7901
# Epoch 14/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1275 - accuracy: 0.5005 - mse: 1.7116 - weighted_accuracy: 0.7523 - weighted_mse: 1.6934 - val_loss: 0.1893 - val_accuracy: 0.4310 - val_mse: 1.7930 - val_weighted_accuracy: 0.4310 - val_weighted_mse: 1.7930
# Epoch 15/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1272 - accuracy: 0.4955 - mse: 1.7391 - weighted_accuracy: 0.7541 - weighted_mse: 1.7168 - val_loss: 0.1987 - val_accuracy: 0.3635 - val_mse: 1.9218 - val_weighted_accuracy: 0.3635 - val_weighted_mse: 1.9218
# Epoch 16/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1274 - accuracy: 0.4821 - mse: 1.7435 - weighted_accuracy: 0.7436 - weighted_mse: 1.7152 - val_loss: 0.1862 - val_accuracy: 0.4352 - val_mse: 1.7789 - val_weighted_accuracy: 0.4352 - val_weighted_mse: 1.7789
# Epoch 17/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1258 - accuracy: 0.4789 - mse: 1.8107 - weighted_accuracy: 0.7479 - weighted_mse: 1.7700 - val_loss: 0.1757 - val_accuracy: 0.4889 - val_mse: 1.9554 - val_weighted_accuracy: 0.4889 - val_weighted_mse: 1.9554
# Epoch 18/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1252 - accuracy: 0.5018 - mse: 1.7633 - weighted_accuracy: 0.7453 - weighted_mse: 1.7479 - val_loss: 0.1969 - val_accuracy: 0.3962 - val_mse: 1.8688 - val_weighted_accuracy: 0.3962 - val_weighted_mse: 1.8688
# Epoch 19/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1226 - accuracy: 0.5253 - mse: 1.8089 - weighted_accuracy: 0.7742 - weighted_mse: 1.7910 - val_loss: 0.1841 - val_accuracy: 0.4689 - val_mse: 1.8668 - val_weighted_accuracy: 0.4689 - val_weighted_mse: 1.8668
# Epoch 20/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1212 - accuracy: 0.5213 - mse: 1.8316 - weighted_accuracy: 0.7783 - weighted_mse: 1.8307 - val_loss: 0.1789 - val_accuracy: 0.4795 - val_mse: 1.8250 - val_weighted_accuracy: 0.4795 - val_weighted_mse: 1.8250
# Validation loss: 0.1788730025291443
# Validation accuracy: 0.4794520437717438
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1930 - accuracy: 0.4633 - mse: 1.9026 - weighted_accuracy: 0.4633 - weighted_mse: 1.9026
# Test loss: 0.19298414885997772
# Test accuracy: 0.46330276131629944
#
#
# number of predictions: 218
# actual predicted buys: 4
# actual buys but predicted sell: 0
# actual buys but predicted hold: 4
# actual sells but predicted buy: 0
# actual predicted sells: 3
# actual sells but predicted hold: 5
# actual holds but predicted buy: 69
# actual holds but predicted sell: 39
# actual predicted holds: 94
# Percentage buys correct: 5.47945205479452%
# Percentage sells correct: 7.142857142857143%
# Percentage holds correct: 91.2621359223301%
# actual buys: 8
# actual sells: 8
# actual holds: 202
#
#
# Percentage low buys correct: 39.726027397260275%
# Percentage high sells correct: 64.28571428571429%
# Percentage mid holds correct: 70.58823529411765%
#
#
# Capital: 100
# Share price: $0.8158253039580221
# Shares owned at the moment: 122
# Cash capital at the moment: $0.19560352764338518
#
#
# Price increase from previously bought: 8.033258526599706%
# Share price: $0.8837864070647015
# Shares owned at the moment: 0
# Cash capital at the moment: $107.72103484996676
#
#
# Share price: $0.7769903300284726
# Shares owned at the moment: 138
# Cash capital at the moment: $0.20150147579172994
#
#
# Price increase from previously bought: -67.56389843303624%
# Share price: $0.2527184423882095
# Shares owned at the moment: 0
# Cash capital at the moment: $34.98073987647832
#
#
# Share price: $0.22359225534248967
# Shares owned at the moment: 156
# Cash capital at the moment: $0.004426965507995817
#
#
# Price increase from previously bought: -0.27424582398404285%
# Share price: $0.22359225534248967
# Shares owned at the moment: 0
# Cash capital at the moment: $34.788897721394456
#
#
# Share price: $0.20417476837771503
# Shares owned at the moment: 169
# Cash capital at the moment: $0.18847164195707222
#
#
# Price increase from previously bought: 4.467820645973775%
# Share price: $0.21388349739295492
# Shares owned at the moment: 0
# Cash capital at the moment: $36.23538034595308
#
#
# Share price: $0.22359225534248967
# Shares owned at the moment: 161
# Cash capital at the moment: $0.1380317647593614
#
#
# Price increase from previously bought: -11.099883275626233%
# Share price: $0.19932040387009503
# Shares owned at the moment: 0
# Cash capital at the moment: $32.14036767903118
#
#
# Share price: $0.21873786190057493
# Shares owned at the moment: 146
# Cash capital at the moment: $0.11681658999415845
#
#
# Price increase from previously bought: 8.57846725888085%
# Share price: $0.23815534886534961
# Shares owned at the moment: 0
# Cash capital at the moment: $34.791878151765765
#
#
# Share price: $0.1896116459205603
# Shares owned at the moment: 182
# Cash capital at the moment: $0.18765796544055036
#
#
# Price increase from previously bought: -79.42166802193478%
# Share price: $0.03912621598001464
# Shares owned at the moment: 0
# Cash capital at the moment: $7.289046602705217
#
#
# Share price: $0.029417472497627294
# Shares owned at the moment: 247
# Cash capital at the moment: $0.0029490775972620398
#
#
# Price increase from previously bought: 16.182185106780555%
# Share price: $0.034271851472394664
# Shares owned at the moment: 0
# Cash capital at the moment: $8.44481723616612
#
#
# Share price: $0.02456310799000732
# Shares owned at the moment: 342
# Cash capital at the moment: $0.021132700519014946
#
#
# Price increase from previously bought: 39.1430692110857%
# Share price: $0.034271851472394664
# Shares owned at the moment: 0
# Cash capital at the moment: $11.709873227768202
#
#
# Share price: $0.019708743482387346
# Shares owned at the moment: 592
# Cash capital at the moment: $0.01021125180556659
#
#
#
#
# Capital at the end of test period: $11.645701558989547
# profit gained: -88.35429844101046%
#
#
# Capital at the end of test period if Buy and Hold: $2.5934579490563006
# profit gained: -97.4065420509437%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.463303      5.479452       7.142857      91.262136
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         39.726027           64.285714          70.588235     -88.354298
#
#    buy_n_hold profit
# 0         -97.406542
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1804 - accuracy: 0.4338 - mse: 1.8807 - weighted_accuracy: 0.4338 - weighted_mse: 1.8807
# Test loss: 0.18037529289722443
# Test accuracy: 0.4337899684906006
#
#
# number of predictions: 219
# actual predicted buys: 3
# actual buys but predicted sell: 0
# actual buys but predicted hold: 5
# actual sells but predicted buy: 0
# actual predicted sells: 5
# actual sells but predicted hold: 3
# actual holds but predicted buy: 55
# actual holds but predicted sell: 61
# actual predicted holds: 87
# Percentage buys correct: 5.172413793103448%
# Percentage sells correct: 7.575757575757576%
# Percentage holds correct: 91.57894736842105%
# actual buys: 8
# actual sells: 8
# actual holds: 203
#
#
# Percentage low buys correct: 36.206896551724135%
# Percentage high sells correct: 43.93939393939394%
# Percentage mid holds correct: 81.91489361702128%
#
#
# Capital: 100
# Share price: $0.011883244935363585
# Shares owned at the moment: 8392
# Cash capital at the moment: $0.0015669758104763787
#
#
# Price increase from previously bought: 73.47957326909382%
# Share price: $0.020671693861552022
# Shares owned at the moment: 0
# Cash capital at the moment: $173.00136051101813
#
#
# Share price: $0.05017576972685583
# Shares owned at the moment: 3438
# Cash capital at the moment: $0.02267737520523383
#
#
# Price increase from previously bought: 2.22109400025865%
# Share price: $0.05143126884487168
# Shares owned at the moment: 0
# Cash capital at the moment: $176.35712273258025
#
#
# Share price: $0.11483365626355417
# Shares owned at the moment: 1531
# Cash capital at the moment: $0.06331659179517146
#
#
# Price increase from previously bought: 8.993444096436964%
# Share price: $0.12550535012510616
# Shares owned at the moment: 0
# ...
# 0         36.363636           72.727273          71.195652     -72.322171
#
#    buy_n_hold profit
# 0         -97.406542
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1719 - accuracy: 0.7854 - mse: 11.7108 - weighted_accuracy: 0.7854 - weighted_mse: 11.7108
# Test loss: 0.17189081013202667
# Test accuracy: 0.7853881120681763
#
#
# number of predictions: 219
# actual predicted buys: 0
# actual buys but predicted sell: 0
# actual buys but predicted hold: 8
# actual sells but predicted buy: 0
# actual predicted sells: 1
# actual sells but predicted hold: 7
# actual holds but predicted buy: 15
# actual holds but predicted sell: 17
# actual predicted holds: 171
# Percentage buys correct: 0.0%
# Percentage sells correct: 5.555555555555555%
# Percentage holds correct: 91.93548387096774%
# actual buys: 8
# actual sells: 8
# actual holds: 203
#
#
# Percentage low buys correct: 13.333333333333334%
# Percentage high sells correct: 50.0%
# Percentage mid holds correct: 83.78378378378379%
#
#
# Capital: 100
# Share price: $0.11483365626355417
# Shares owned at the moment: 868
# Cash capital at the moment: $0.05027842573387886
#
#
# Price increase from previously bought: 193.25684958728272%
# Share price: $0.3376836459216054
# Shares owned at the moment: 0
# Cash capital at the moment: $292.35363222287253
#
#
# Share price: $0.7162147180150162
# Shares owned at the moment: 407
# Cash capital at the moment: $0.05261866762259615
#
#
# Price increase from previously bought: -27.370551133137532%
# Share price: $0.5216133051042531
# Shares owned at the moment: 0
# Cash capital at the moment: $211.76541815331564
#
#
# Share price: $0.4977589939783217
# Shares owned at the moment: 424
# Cash capital at the moment: $0.13521771952849804
#
#
# Price increase from previously bought: -29.326812996670693%
# Share price: $0.35274954553795046
# Shares owned at the moment: 0
# Cash capital at the moment: $149.28971905752223
#
#
# Share price: $0.3006465977981677
# Shares owned at the moment: 495
# Cash capital at the moment: $0.06039796617648108
#
#
# Price increase from previously bought: -11.726688264764086%
# Share price: $0.26612053294412086
# Shares owned at the moment: 0
# Cash capital at the moment: $131.42780519804612
#
#
# Share price: $0.26612053294412086
# Shares owned at the moment: 492
# Cash capital at the moment: $0.13644190846522974
#
#
# Price increase from previously bought: 67.00470962326202%
# Share price: $0.4456560163052572
# Shares owned at the moment: 0
# Cash capital at the moment: $218.79622934059074
#
#
# Share price: $0.42933459512093497
# Shares owned at the moment: 508
# Cash capital at the moment: $0.09447458977183487
#
#
# Price increase from previously bought: 0.892262515519171%
# Share price: $0.43435659159299833
# Shares owned at the moment: 0
# Cash capital at the moment: $220.14082696055954
#
#
# Share price: $0.4073634765471241
# Shares owned at the moment: 538
# Cash capital at the moment: $0.37658231465528047
#
#
#
#
# Capital at the end of test period: $218.93543843345657
# profit gained: 118.93543843345657%
#
#
# Capital at the end of test period if Buy and Hold: $3238.165410975435
# profit gained: 3138.165410975435%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.785388           0.0       5.555556      91.935484
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         13.333333                50.0          83.783784     118.935438
#
#    buy_n_hold profit
# 0        3138.165411
#
#
# Non-Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1565 - accuracy: 0.8578 - mse: 10.3338 - weighted_accuracy: 0.8578 - weighted_mse: 10.3338
# Test loss: 0.1565379947423935
# Test accuracy: 0.857798159122467
#
#
# number of predictions: 218
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 9
# actual sells but predicted buy: 0
# actual predicted sells: 0
# actual sells but predicted hold: 9
# actual holds but predicted buy: 7
# actual holds but predicted sell: 6
# actual predicted holds: 186
# Percentage buys correct: 12.5%
# Percentage sells correct: 0.0%
# Percentage holds correct: 91.17647058823529%
# actual buys: 10
# actual sells: 9
# actual holds: 199
#
#
# Percentage low buys correct: 62.5%
# Percentage high sells correct: 50.0%
# Percentage mid holds correct: 80.29556650246306%
#
#
# Capital: 100
# Share price: $0.6570588132171898
# Shares owned at the moment: 151
# Cash capital at the moment: $0.5112755320158868
#
#
# Price increase from previously bought: 8.653758490184703%
# Share price: $0.7158823735656209
# Shares owned at the moment: 0
# Cash capital at the moment: $108.31224378480152
#
#
# Share price: $0.6533823461737808
# Shares owned at the moment: 165
# Cash capital at the moment: $0.20768442655133867
#
#
# Price increase from previously bought: -61.99962498324655%
# Share price: $0.24897053312935702
# Shares owned at the moment: 0
# Cash capital at the moment: $41.174852013487794
#
#
# Share price: $0.15705876939024555
# Shares owned at the moment: 261
# Cash capital at the moment: $0.06978427090385964
#
#
# Price increase from previously bought: -30.621483678949158%
# Share price: $0.1092646978259295
# Shares owned at the moment: 0
# Cash capital at the moment: $28.509445666606897
#
#
# Share price: $0.12397056599956523
# Shares owned at the moment: 229
# Cash capital at the moment: $0.04211558876823318
#
#
# Price increase from previously bought: 67.74748974948925%
# Share price: $0.2085293956518589
# Shares owned at the moment: 0
# Cash capital at the moment: $47.664025806132166
#
#
#
#
# Capital at the end of test period: $47.664025806132166
# profit gained: -52.33597419386783%
#
#
# Capital at the end of test period if Buy and Hold: $26.129427230180067
# profit gained: -73.87057276981993%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.802752      9.090909       9.090909      92.972973
# 1       0.857798     12.500000       0.000000      91.176471
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         36.363636           72.727273          71.195652     -72.322171
# 1         62.500000           50.000000          80.295567     -52.335974
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2142 - accuracy: 0.8356 - mse: 11.6844 - weighted_accuracy: 0.8356 - weighted_mse: 11.6844
# Test loss: 0.21418671309947968
# Test accuracy: 0.835616409778595
#
#
# number of predictions: 219
# actual predicted buys: 2
# actual buys but predicted sell: 0
# actual buys but predicted hold: 6
# actual sells but predicted buy: 1
# actual predicted sells: 1
# actual sells but predicted hold: 9
# actual holds but predicted buy: 9
# actual holds but predicted sell: 11
# actual predicted holds: 180
# Percentage buys correct: 16.666666666666668%
# Percentage sells correct: 8.333333333333334%
# Percentage holds correct: 92.3076923076923%
# actual buys: 8
# actual sells: 11
# actual holds: 200
#
#
# Percentage low buys correct: 72.72727272727273%
# Percentage high sells correct: 25.0%
# Percentage mid holds correct: 87.17948717948718%
#
#
# Capital: 100
# Share price: $0.02834215060163773
# Shares owned at the moment: 3518
# Cash capital at the moment: $0.018118047442911234
#
#
# Price increase from previously bought: 44.40685139688594%
# Share price: $0.04104055932206908
# Shares owned at the moment: 0
# Cash capital at the moment: $144.00175885132057
#
#
# Share price: $0.15462081317116044
# Shares owned at the moment: 928
# Cash capital at the moment: $0.11905191327088005
#
#
# Price increase from previously bought: 96.86935037329793%
# Share price: $0.3052380931556622
# Shares owned at the moment: 0
# Cash capital at the moment: $282.6010347479922
#
#
# Share price: $0.3129982434984622
# Shares owned at the moment: 900
# Cash capital at the moment: $0.12794494671749135
#
#
# Price increase from previously bought: 21.865795699244384%
# Share price: $0.3824867539139606
# Shares owned at the moment: 0
# Cash capital at the moment: $343.41936875334494
#
#
# Share price: $0.630458554017336
# Shares owned at the moment: 543
# Cash capital at the moment: $0.13894168614507407
#
#
# Price increase from previously bought: -48.76037544548667%
# Share price: $0.32393296868943494
# Shares owned at the moment: 0
# Cash capital at the moment: $175.55083077901273
#
#
# Share price: $0.2297530738776914
# Shares owned at the moment: 761
# Cash capital at the moment: $0.22792581273202472
#
#
# Price increase from previously bought: 2.0223567214137317%
# Share price: $0.2350440992365888
# Shares owned at the moment: 0
# Cash capital at the moment: $178.60459679309872
#
#
# Share price: $0.25867725837747163
# Shares owned at the moment: 688
# Cash capital at the moment: $0.14522565654806385
#
#
#
#
# Capital at the end of test period: $177.62576204739838
# profit gained: 77.62576204739838%
#
#
# Capital at the end of test period if Buy and Hold: $2186.7819938452512
# profit gained: 2086.7819938452512%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.785388      0.000000       5.555556      91.935484
# 1       0.835616     16.666667       8.333333      92.307692
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         13.333333                50.0          83.783784     118.935438
# 1         72.727273                25.0          87.179487      77.625762
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1988 - accuracy: 0.7752 - mse: 10.4469 - weighted_accuracy: 0.7752 - weighted_mse: 10.4469
# Test loss: 0.19880668818950653
# Test accuracy: 0.7752293348312378
#
#
# number of predictions: 218
# actual predicted buys: 0
# actual buys but predicted sell: 0
# actual buys but predicted hold: 9
# actual sells but predicted buy: 0
# actual predicted sells: 1
# actual sells but predicted hold: 7
# actual holds but predicted buy: 19
# actual holds but predicted sell: 14
# actual predicted holds: 168
# Percentage buys correct: 0.0%
# Percentage sells correct: 6.666666666666667%
# Percentage holds correct: 91.30434782608695%
# actual buys: 9
# actual sells: 8
# actual holds: 201
#
#
# Percentage low buys correct: 42.10526315789474%
# Percentage high sells correct: 53.333333333333336%
# Percentage mid holds correct: 81.9672131147541%
#
#
# Capital: 100
# Share price: $0.21615231839681645
# Shares owned at the moment: 461
# Cash capital at the moment: $0.07975411742005178
#
#
# Price increase from previously bought: -2.5633429244784622%
# Share price: $0.21119077511849751
# Shares owned at the moment: 0
# Cash capital at the moment: $97.17096434189092
#
#
# Share price: $0.08144629418330708
# Shares owned at the moment: 1189
# Cash capital at the moment: $0.0650115375329392
#
#
# Price increase from previously bought: -31.56100046502751%
# Share price: $0.055894316726833614
# Shares owned at the moment: 0
# Cash capital at the moment: $66.34059368362054
#
#
# Share price: $0.04547506401311146
# Shares owned at the moment: 1454
# Cash capital at the moment: $0.038018565100060187
#
#
# Price increase from previously bought: -22.035369019113414%
# Share price: $0.0355519656272212
# Shares owned at the moment: 0
# Cash capital at the moment: $51.58842205251924
#
#
# Share price: $0.03381543139443569
# Shares owned at the moment: 1521
# Cash capital at the moment: $0.013709405917474271
#
#
# Price increase from previously bought: 143.85289773695172%
# Share price: $0.08268667408826068
# Shares owned at the moment: 0
# Cash capital at the moment: $125.43428300811928
#
#
# Share price: $0.07499627609224012
# Shares owned at the moment: 1667
# Cash capital at the moment: $0.07168908367914639
#
#
# Price increase from previously bought: -30.952998691270494%
# Share price: $0.05192508210417842
# Shares owned at the moment: 0
# Cash capital at the moment: $86.39276339370849
#
#
# Share price: $0.03158273100456601
# Shares owned at the moment: 2727
# Cash capital at the moment: $0.029809148770993943
#
#
# Price increase from previously bought: 13.825683682181623%
# Share price: $0.0360481199550531
# Shares owned at the moment: 0
# Cash capital at the moment: $98.06269840262787
#
#
# Share price: $0.026125033398415175
# Shares owned at the moment: 3743
# Cash capital at the moment: $0.007786892331637318
#
#
# Price increase from previously bought: -38.15318190816712%
# Share price: $0.016201935012524878
# Shares owned at the moment: 0
# Cash capital at the moment: $60.48485907664458
#
#
#
#
# Capital at the end of test period: $60.48485907664458
# profit gained: -39.51514092335542%
#
#
# Capital at the end of test period if Buy and Hold: $2.3797176202777375
# profit gained: -97.62028237972227%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.802752      9.090909       9.090909      92.972973
# 1       0.857798     12.500000       0.000000      91.176471
# 2       0.775229      0.000000       6.666667      91.304348
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         36.363636           72.727273          71.195652     -72.322171
# 1         62.500000           50.000000          80.295567     -52.335974
# 2         42.105263           53.333333          81.967213     -39.515141
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
# 2         -97.620282
#
#
# Recession
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2288 - accuracy: 0.7900 - mse: 11.0341 - weighted_accuracy: 0.7900 - weighted_mse: 11.0341
# Test loss: 0.22876183688640594
# Test accuracy: 0.7899543642997742
#
#
# number of predictions: 219
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 1
# actual predicted sells: 0
# actual sells but predicted hold: 9
# actual holds but predicted buy: 14
# actual holds but predicted sell: 15
# actual predicted holds: 172
# Percentage buys correct: 6.25%
# Percentage sells correct: 0.0%
# Percentage holds correct: 91.48936170212765%
# actual buys: 8
# actual sells: 10
# actual holds: 201
#
#
# Percentage low buys correct: 62.5%
# Percentage high sells correct: 33.333333333333336%
# Percentage mid holds correct: 84.49197860962566%
#
#
# Capital: 100
# Share price: $0.023869464968017798
# Shares owned at the moment: 4177
# Cash capital at the moment: $0.023062251868267936
#
#
# Price increase from previously bought: 238.08393655656542%
# Share price: $0.08092074857256178
# Shares owned at the moment: 0
# Cash capital at the moment: $337.0995126307929
#
#
# Share price: $0.23803031635156474
# Shares owned at the moment: 1412
# Cash capital at the moment: $0.07643422399036126
#
#
# Price increase from previously bought: 14.643356970566067%
# Share price: $0.2736363816225931
# Shares owned at the moment: 0
# Cash capital at the moment: $385.3884750052512
#
#
# Share price: $0.7832518087745554
# Shares owned at the moment: 490
# Cash capital at the moment: $0.5396568933953745
#
#
# Price increase from previously bought: 3.9995200029510958%
# Share price: $0.816818211374205
# Shares owned at the moment: 0
# Cash capital at the moment: $399.679917926929
#
#
# Share price: $0.8780652675159911
# Shares owned at the moment: 453
# Cash capital at the moment: $0.8225019351770015
#
#
# Price increase from previously bought: -26.986733986314604%
# Share price: $0.6428671659014783
# Shares owned at the moment: 0
# Cash capital at the moment: $291.2404763166249
#
#
# Share price: $0.6404195795878922
# Shares owned at the moment: 453
# Cash capital at the moment: $0.3326040720381229
#
#
#
#
# Capital at the end of test period: $315.3390584764648
# profit gained: 215.33905847646483%
#
#
# Capital at the end of test period if Buy and Hold: $5902.379195330377
# profit gained: 5802.379195330377%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.785388      0.000000       5.555556      91.935484
# 1       0.835616     16.666667       8.333333      92.307692
# 2       0.789954      6.250000       0.000000      91.489362
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         13.333333           50.000000          83.783784     118.935438
# 1         72.727273           25.000000          87.179487      77.625762
# 2         62.500000           33.333333          84.491979     215.339058
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
# 2        5802.379195

# %%
Vaxart_data_acc = []
Inovio_data_acc = []
Novavax_data_acc = []

Vaxart_data_correct_buys = []
Inovio_data_correct_buys = []
Novavax_data_correct_buys = []

Vaxart_data_correct_sells = []
Inovio_data_correct_sells = []
Novavax_data_correct_sells = []

Vaxart_data_correct_holds = []
Inovio_data_correct_holds = []
Novavax_data_correct_holds = []

Vaxart_data_correct_low_buys = []
Inovio_data_correct_low_buys = []
Novavax_data_correct_low_buys = []

Vaxart_data_correct_high_sells = []
Inovio_data_correct_high_sells = []
Novavax_data_correct_high_sells = []

Vaxart_data_correct_mid_holds = []
Inovio_data_correct_mid_holds = []
Novavax_data_correct_mid_holds = []

Vaxart_data_profit = []
Inovio_data_profit = []
Novavax_data_profit = []

for key,value in nr_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    Vaxart_data_acc.append(acc[0])
    Inovio_data_acc.append(acc[1])
    Novavax_data_acc.append(acc[2])
    
    Vaxart_data_correct_buys.append(correct_buys[0])
    Inovio_data_correct_buys.append(correct_buys[1]) 
    Novavax_data_correct_buys.append(correct_buys[2]) 

    Vaxart_data_correct_sells.append(correct_sells[0]) 
    Inovio_data_correct_sells.append(correct_sells[1]) 
    Novavax_data_correct_sells.append(correct_sells[2]) 

    Vaxart_data_correct_holds.append(correct_holds[0]) 
    Inovio_data_correct_holds.append(correct_holds[1])  
    Novavax_data_correct_holds.append(correct_holds[2])  

    Vaxart_data_correct_low_buys.append(correct_low_buys[0])  
    Inovio_data_correct_low_buys.append(correct_low_buys[1])  
    Novavax_data_correct_low_buys.append(correct_low_buys[2])  

    Vaxart_data_correct_high_sells.append(correct_high_sells[0]) 
    Inovio_data_correct_high_sells.append(correct_high_sells[1]) 
    Novavax_data_correct_high_sells.append(correct_high_sells[2]) 

    Vaxart_data_correct_mid_holds.append(correct_mid_holds[0])  
    Inovio_data_correct_mid_holds.append(correct_mid_holds[1])  
    Novavax_data_correct_mid_holds.append(correct_mid_holds[2])   

    Vaxart_data_profit.append(profit[0]) 
    Inovio_data_profit.append(profit[1]) 
    Novavax_data_profit.append(profit[2])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(Vaxart_data_acc)
plt.plot(Inovio_data_acc)
plt.plot(Novavax_data_acc)

plt.title('Non-Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Vaxart_data_acc','Inovio_data_acc','Novavax_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_profit")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_profit")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_profit")
# Out:
# Text(0.5, 1.0, 'Novavax_data_profit')

# %%
Vaxart_data_acc = []
Inovio_data_acc = []
Novavax_data_acc = []

Vaxart_data_correct_buys = []
Inovio_data_correct_buys = []
Novavax_data_correct_buys = []

Vaxart_data_correct_sells = []
Inovio_data_correct_sells = []
Novavax_data_correct_sells = []

Vaxart_data_correct_holds = []
Inovio_data_correct_holds = []
Novavax_data_correct_holds = []

Vaxart_data_correct_low_buys = []
Inovio_data_correct_low_buys = []
Novavax_data_correct_low_buys = []

Vaxart_data_correct_high_sells = []
Inovio_data_correct_high_sells = []
Novavax_data_correct_high_sells = []

Vaxart_data_correct_mid_holds = []
Inovio_data_correct_mid_holds = []
Novavax_data_correct_mid_holds = []

Vaxart_data_profit = []
Inovio_data_profit = []
Novavax_data_profit = []

for key,value in r_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    Vaxart_data_acc.append(acc[0])
    Inovio_data_acc.append(acc[1])
    Novavax_data_acc.append(acc[2])
    
    Vaxart_data_correct_buys.append(correct_buys[0])
    Inovio_data_correct_buys.append(correct_buys[1]) 
    Novavax_data_correct_buys.append(correct_buys[2]) 

    Vaxart_data_correct_sells.append(correct_sells[0]) 
    Inovio_data_correct_sells.append(correct_sells[1]) 
    Novavax_data_correct_sells.append(correct_sells[2]) 

    Vaxart_data_correct_holds.append(correct_holds[0]) 
    Inovio_data_correct_holds.append(correct_holds[1])  
    Novavax_data_correct_holds.append(correct_holds[2])  

    Vaxart_data_correct_low_buys.append(correct_low_buys[0])  
    Inovio_data_correct_low_buys.append(correct_low_buys[1])  
    Novavax_data_correct_low_buys.append(correct_low_buys[2])  

    Vaxart_data_correct_high_sells.append(correct_high_sells[0]) 
    Inovio_data_correct_high_sells.append(correct_high_sells[1]) 
    Novavax_data_correct_high_sells.append(correct_high_sells[2]) 

    Vaxart_data_correct_mid_holds.append(correct_mid_holds[0])  
    Inovio_data_correct_mid_holds.append(correct_mid_holds[1])  
    Novavax_data_correct_mid_holds.append(correct_mid_holds[2])   

    Vaxart_data_profit.append(profit[0]) 
    Inovio_data_profit.append(profit[1]) 
    Novavax_data_profit.append(profit[2])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(Vaxart_data_acc)
plt.plot(Inovio_data_acc)
plt.plot(Novavax_data_acc)

plt.title('Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Vaxart_data_acc','Inovio_data_acc','Novavax_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_profit")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_profit")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_profit")
# Out:
# Text(0.5, 1.0, 'Novavax_data_profit')

# %% [markdown]
# ## Train Novavax, Inc Stock Data

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []

seed = 10
df = pd.read_csv('variation 7/initial_indicators/NVAX_data.csv')
df.set_index('Date', inplace=True)
print(df.head())

plt.figure(figsize=(15,5))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
plt.show()

labels = []
data_15 = []
sequential = []
count = 0

for i in df.values:
    if count == 14:
        data_15.append(np.array(i[0:-1]))
        labels.append(i[-1])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_arr = min_max_scaler.fit_transform(data_15)
        sequential.append(data_15_arr)
        data_15 = data_15[1:15]
    else:
        data_15.append(np.array(i[0:-1]))
        count+= 1
    
X = sequential
X  = np.array(X).reshape(-1, 15, 4)
y = labels
y = np.array(y)

X.shape
# Out:
#             previous_1d      EMA_12   willr_14    OBV_7  labels
# Date
# 2000-01-21       123.75  111.044132  -0.000000    330.0     0.0
# 2000-01-24       145.00  116.268112  -9.090909  10530.0     2.0
# 2000-01-25       130.00  118.380710 -36.363636   6930.0     2.0
# 2000-01-26       132.50  120.552908 -31.818182   9665.0     2.0
# 2000-01-27       140.00  123.544769 -18.181818  11870.0     2.0
# (4745, 15, 4)

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization,Activation
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(LSTM(100, input_shape=(X_train.shape[1:]), return_sequences=True,kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(LSTM(100, kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# model.add(Dense(100, kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))

model.add(Dense(75, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(50, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "DBS_CNN_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))
print(d_class_weights)

epochs = 0 
histories = {}
nr_log_hist = {}
r_log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    nr_log  = pd.DataFrame(columns = column_names)
    r_log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['VXRT','INO','NVAX']
    for name in test_sets:
        
        print('\n')
        print("Non-Recession")
        print('\n')
        
        X = nr_test_data['{}_X'.format(name)]
        y = nr_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("variation 7/initial_indicators/{}_data_test.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(nr_log)
        nr_log.loc[df_length] = logger
        print(nr_log.head(20))
        logger = []
        
        print('\n')
        print("Recession")
        print('\n')
        
        X = r_test_data['{}_X'.format(name)]
        y = r_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("variation 7/initial_indicators/{}_data_test2.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(r_log)
        r_log.loc[df_length] = logger
        print(r_log.head(20))
        logger = []

    nr_log.to_csv('{}_{}_{}epochs.csv'.format(experiment,'NovavaxModel',epochs))
    nr_log_hist['{}_epochs_logs'.format(epochs)] = nr_log
    r_log.to_csv('{}_{}_{}epochs.csv'.format(experiment,'NovavaxModel',epochs))
    r_log_hist['{}_epochs_logs'.format(epochs)] = r_log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 2 ... 0 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# {0: 7.57684630738523, 1: 7.272030651340996, 2: 0.36623251326579837}
#
#
#
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  2/30 [=>............................] - ETA: 59s - loss: 0.3758 - accuracy: 0.5625 - mse: 0.3539 - weighted_accuracy: 0.2552 - weighted_mse: 0.5528WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0303s vs `on_train_batch_end` time: 4.1762s). Check your callbacks.
# 30/30 [==============================] - 7s 218ms/step - loss: 0.2929 - accuracy: 0.5092 - mse: 0.4430 - weighted_accuracy: 0.3260 - weighted_mse: 0.5285 - val_loss: 0.2997 - val_accuracy: 0.0464 - val_mse: 0.3542 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.3542
# Epoch 2/20
# 30/30 [==============================] - 1s 37ms/step - loss: 0.2075 - accuracy: 0.3272 - mse: 0.7843 - weighted_accuracy: 0.4777 - weighted_mse: 0.7607 - val_loss: 0.2906 - val_accuracy: 0.0464 - val_mse: 0.3862 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.3862
# Epoch 3/20
# 30/30 [==============================] - 1s 36ms/step - loss: 0.1870 - accuracy: 0.2998 - mse: 1.0287 - weighted_accuracy: 0.4941 - weighted_mse: 1.0023 - val_loss: 0.2795 - val_accuracy: 0.0464 - val_mse: 0.4266 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.4266
# Epoch 4/20
# 30/30 [==============================] - 1s 39ms/step - loss: 0.1792 - accuracy: 0.2921 - mse: 1.1666 - weighted_accuracy: 0.5319 - weighted_mse: 1.1341 - val_loss: 0.2684 - val_accuracy: 0.0464 - val_mse: 0.4719 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.4719
# Epoch 5/20
# 30/30 [==============================] - 1s 38ms/step - loss: 0.1749 - accuracy: 0.2769 - mse: 1.2642 - weighted_accuracy: 0.5359 - weighted_mse: 1.2171 - val_loss: 0.2583 - val_accuracy: 0.0464 - val_mse: 0.5218 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.5218
# Epoch 6/20
# 30/30 [==============================] - 1s 38ms/step - loss: 0.1722 - accuracy: 0.2927 - mse: 1.2952 - weighted_accuracy: 0.5565 - weighted_mse: 1.2501 - val_loss: 0.2492 - val_accuracy: 0.0464 - val_mse: 0.5785 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.5785
# Epoch 7/20
# 30/30 [==============================] - 1s 35ms/step - loss: 0.1698 - accuracy: 0.2882 - mse: 1.3243 - weighted_accuracy: 0.5619 - weighted_mse: 1.2724 - val_loss: 0.2407 - val_accuracy: 0.0464 - val_mse: 0.6396 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.6396
# Epoch 8/20
# 30/30 [==============================] - 1s 36ms/step - loss: 0.1671 - accuracy: 0.3066 - mse: 1.3220 - weighted_accuracy: 0.5876 - weighted_mse: 1.2707 - val_loss: 0.2322 - val_accuracy: 0.0464 - val_mse: 0.7080 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.7080
# Epoch 9/20
# 30/30 [==============================] - 1s 39ms/step - loss: 0.1655 - accuracy: 0.2900 - mse: 1.3633 - weighted_accuracy: 0.5815 - weighted_mse: 1.2981 - val_loss: 0.2242 - val_accuracy: 0.0464 - val_mse: 0.7794 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.7794
# Epoch 10/20
# 30/30 [==============================] - 1s 39ms/step - loss: 0.1632 - accuracy: 0.3332 - mse: 1.3410 - weighted_accuracy: 0.6028 - weighted_mse: 1.2889 - val_loss: 0.2173 - val_accuracy: 0.0464 - val_mse: 0.8541 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.8541
# Epoch 11/20
# 30/30 [==============================] - 1s 39ms/step - loss: 0.1618 - accuracy: 0.3037 - mse: 1.3766 - weighted_accuracy: 0.6082 - weighted_mse: 1.3020 - val_loss: 0.2113 - val_accuracy: 0.0464 - val_mse: 0.9538 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 0.9538
# Epoch 12/20
# 30/30 [==============================] - 1s 40ms/step - loss: 0.1594 - accuracy: 0.3535 - mse: 1.3674 - weighted_accuracy: 0.6341 - weighted_mse: 1.3092 - val_loss: 0.2084 - val_accuracy: 0.0790 - val_mse: 1.0116 - val_weighted_accuracy: 0.0790 - val_weighted_mse: 1.0116
# Epoch 13/20
# 30/30 [==============================] - 1s 34ms/step - loss: 0.1584 - accuracy: 0.3385 - mse: 1.3889 - weighted_accuracy: 0.6311 - weighted_mse: 1.3278 - val_loss: 0.2053 - val_accuracy: 0.1033 - val_mse: 1.0874 - val_weighted_accuracy: 0.1033 - val_weighted_mse: 1.0874
# Epoch 14/20
# 30/30 [==============================] - 1s 29ms/step - loss: 0.1557 - accuracy: 0.3414 - mse: 1.4040 - weighted_accuracy: 0.6406 - weighted_mse: 1.3309 - val_loss: 0.1987 - val_accuracy: 0.1465 - val_mse: 1.1415 - val_weighted_accuracy: 0.1465 - val_weighted_mse: 1.1415
# Epoch 15/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.1541 - accuracy: 0.3317 - mse: 1.4047 - weighted_accuracy: 0.6429 - weighted_mse: 1.3265 - val_loss: 0.1970 - val_accuracy: 0.1981 - val_mse: 1.1764 - val_weighted_accuracy: 0.1981 - val_weighted_mse: 1.1764
# Epoch 16/20
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1533 - accuracy: 0.3709 - mse: 1.4098 - weighted_accuracy: 0.6519 - weighted_mse: 1.3419 - val_loss: 0.1947 - val_accuracy: 0.2381 - val_mse: 1.2147 - val_weighted_accuracy: 0.2381 - val_weighted_mse: 1.2147
# Epoch 17/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.1528 - accuracy: 0.3583 - mse: 1.4324 - weighted_accuracy: 0.6491 - weighted_mse: 1.3599 - val_loss: 0.1956 - val_accuracy: 0.2434 - val_mse: 1.2588 - val_weighted_accuracy: 0.2434 - val_weighted_mse: 1.2588
# Epoch 18/20
# 30/30 [==============================] - 1s 38ms/step - loss: 0.1500 - accuracy: 0.3409 - mse: 1.4689 - weighted_accuracy: 0.6595 - weighted_mse: 1.3800 - val_loss: 0.1874 - val_accuracy: 0.3446 - val_mse: 1.2841 - val_weighted_accuracy: 0.3446 - val_weighted_mse: 1.2841
# Epoch 19/20
# 30/30 [==============================] - 1s 37ms/step - loss: 0.1495 - accuracy: 0.3651 - mse: 1.4501 - weighted_accuracy: 0.6705 - weighted_mse: 1.3720 - val_loss: 0.1895 - val_accuracy: 0.3224 - val_mse: 1.2659 - val_weighted_accuracy: 0.3224 - val_weighted_mse: 1.2659
# Epoch 20/20
# 30/30 [==============================] - 1s 38ms/step - loss: 0.1479 - accuracy: 0.3770 - mse: 1.4724 - weighted_accuracy: 0.6769 - weighted_mse: 1.3946 - val_loss: 0.1859 - val_accuracy: 0.3751 - val_mse: 1.2398 - val_weighted_accuracy: 0.3751 - val_weighted_mse: 1.2398
# Validation loss: 0.18588082492351532
# Validation accuracy: 0.3751317262649536
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1817 - accuracy: 0.4128 - mse: 1.2783 - weighted_accuracy: 0.4128 - weighted_mse: 1.2783
# Test loss: 0.1817239224910736
# Test accuracy: 0.4128440320491791
#
#
# number of predictions: 218
# actual predicted buys: 5
# actual buys but predicted sell: 2
# actual buys but predicted hold: 1
# actual sells but predicted buy: 1
# actual predicted sells: 1
# actual sells but predicted hold: 6
# actual holds but predicted buy: 83
# actual holds but predicted sell: 35
# actual predicted holds: 84
# Percentage buys correct: 5.617977528089888%
# Percentage sells correct: 2.6315789473684212%
# Percentage holds correct: 92.3076923076923%
# actual buys: 8
# actual sells: 8
# actual holds: 202
#
#
# Percentage low buys correct: 43.18181818181818%
# Percentage high sells correct: 55.26315789473684%
# Percentage mid holds correct: 72.52747252747253%
#
#
# Capital: 100
# Share price: $0.8206796684656419
# Shares owned at the moment: 121
# Cash capital at the moment: $0.42467895597538075
#
#
# Price increase from previously bought: -12.071924193953965%
# Share price: $0.7235922625760633
# Shares owned at the moment: 0
# Cash capital at the moment: $87.73856740230686
#
#
# Share price: $0.8449514910037419
# Shares owned at the moment: 103
# Cash capital at the moment: $0.4692313190946322
#
#
# Price increase from previously bought: -74.18337209042518%
# Share price: $0.21873786190057493
# Shares owned at the moment: 0
# Cash capital at the moment: $22.93727359547051
#
#
# Share price: $0.21388349739295492
# Shares owned at the moment: 106
# Cash capital at the moment: $0.20327583232724322
#
#
# Price increase from previously bought: -7.064463406946075%
# Share price: $0.19932040387009503
# Shares owned at the moment: 0
# Cash capital at the moment: $21.273136744829184
#
#
# Share price: $0.19932040387009503
# Shares owned at the moment: 106
# Cash capital at the moment: $0.08707203687097831
#
#
# Price increase from previously bought: 11.869662407861359%
# Share price: $0.22359225534248967
# Shares owned at the moment: 0
# Cash capital at the moment: $23.722673960742547
#
#
# Share price: $0.21388349739295492
# Shares owned at the moment: 110
# Cash capital at the moment: $0.13078948955613612
#
#
# Price increase from previously bought: -0.27424582398405395%
# Share price: $0.21388349739295492
# Shares owned at the moment: 0
# Cash capital at the moment: $23.593274444819805
#
#
# Share price: $0.1896116459205603
# Shares owned at the moment: 124
# Cash capital at the moment: $0.016772779411414973
#
#
# Price increase from previously bought: -71.76223908549326%
# Share price: $0.05368932397002193
# Shares owned at the moment: 0
# Cash capital at the moment: $6.655940892220356
#
#
# Share price: $0.048834959462401954
# Shares owned at the moment: 135
# Cash capital at the moment: $0.04509138609567476
#
#
# Price increase from previously bought: 9.63884035233189%
# Share price: $0.05368932397002193
# Shares owned at the moment: 0
# Cash capital at the moment: $7.273217960524764
#
#
# Share price: $0.03912621598001464
# Shares owned at the moment: 185
# Cash capital at the moment: $0.01496254184222412
#
#
# Price increase from previously bought: 12.098664498214262%
# Share price: $0.043980580487634584
# Shares owned at the moment: 0
# Cash capital at the moment: $8.128994811731538
#
#
# Share price: $0.02456310799000732
# Shares owned at the moment: 330
# Cash capital at the moment: $0.000878154528189512
#
#
#
#
# Capital at the end of test period: $6.486877819005747
# profit gained: -93.51312218099426%
#
#
# Capital at the end of test period if Buy and Hold: $2.5934579490563006
# profit gained: -97.4065420509437%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.412844      5.617978       2.631579      92.307692
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.181818           55.263158          72.527473     -93.513122
#
#    buy_n_hold profit
# 0         -97.406542
#
#
# Recession
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1898 - accuracy: 0.3607 - mse: 1.2654 - weighted_accuracy: 0.3607 - weighted_mse: 1.2654
# Test loss: 0.18982325494289398
# Test accuracy: 0.3607305884361267
#
#
# number of predictions: 219
# actual predicted buys: 6
# actual buys but predicted sell: 1
# actual buys but predicted hold: 1
# actual sells but predicted buy: 1
# actual predicted sells: 3
# actual sells but predicted hold: 4
# actual holds but predicted buy: 74
# actual holds but predicted sell: 59
# actual predicted holds: 70
# Percentage buys correct: 7.407407407407407%
# Percentage sells correct: 4.761904761904762%
# Percentage holds correct: 93.33333333333333%
# actual buys: 8
# actual sells: 8
# actual holds: 203
#
#
# Percentage low buys correct: 49.382716049382715%
# Percentage high sells correct: 46.03174603174603%
# Percentage mid holds correct: 83.78378378378379%
#
#
# Capital: 100
# Share price: $0.06210295522310325
# Shares owned at the moment: 1605
# Cash capital at the moment: $0.050649948303302494
#
#
# Price increase from previously bought: 7.790107072062691%
# Share price: $0.06712492924520537
# Shares owned at the moment: 0
# Cash capital at the moment: $107.4898887304019
#
#
# Share price: $0.10730069148874076
# Shares owned at the moment: 999
# Cash capital at the moment: $0.0017161084574297547
#
#
# Price increase from previously bought: 19.562396492351873%
# Share price: $0.1286440792118447
# Shares owned at the moment: 0
# Cash capital at the moment: $128.16373379447555
#
#
# Share price: $0.11106718135946787
# Shares owned at the moment: 1150
# Cash capital at the moment: $0.08522527003816549
#
#
# Price increase from previously bought: -14.929020748031785%
# Share price: $0.09474577514178649
# Shares owned at the moment: 0
# Cash capital at the moment: $108.74323316920672
#
#
# Share price: $0.7055430241534643
# Shares owned at the moment: 153
# Cash capital at the moment: $0.49829324631411964
#
#
# Price increase from previously bought: 30.86981319760107%
# Share price: $0.9258820305421246
# Shares owned at the moment: 0
# Cash capital at the moment: $141.76867905490857
#
#
# Share price: $0.6452793658215203
# Shares owned at the moment: 219
# Cash capital at the moment: $0.06387844192960301
#
#
# Price increase from previously bought: -19.289400969631277%
# Share price: $0.5222410658882417
# Shares owned at the moment: 0
# Cash capital at the moment: $114.12015218952334
#
#
# Share price: $0.38099812228523844
# Shares owned at the moment: 298
# Cash capital at the moment: $0.27048378730953004
#
#
# Price increase from previously bought: 13.363639612554756%
# Share price: $0.4331010999583029
# Shares owned at the moment: 0
# Cash capital at the moment: $128.97968522346798
#
#
# Share price: $0.3734651724770659
# Shares owned at the moment: 344
# Cash capital at the moment: $0.15436783819399125
#
#
# Price increase from previously bought: 3.4135313452569482%
# Share price: $0.3872756103919972
# Shares owned at the moment: 0
# Cash capital at the moment: $133.0108150856102
#
#
# Share price: $0.3263841912760648
# Shares owned at the moment: 406
# Cash capital at the moment: $0.13442547796816484
#
#
# Price increase from previously bought: -21.372916996007884%
# Share price: $0.25733209150125286
# Shares owned at the moment: 0
# Cash capital at the moment: $104.32394334731568
#
#
# Share price: $0.18890773754378867
# Shares owned at the moment: 550
# Cash capital at the moment: $0.13896474519692958
#
#
# Price increase from previously bought: 38.829994778413536%
# Share price: $0.26298181882402316
# Shares owned at the moment: 0
# Cash capital at the moment: $144.38120509743834
#
#
# Share price: $0.2943691396246906
# Shares owned at the moment: 489
# Cash capital at the moment: $0.03884292045432858
#
#
# Price increase from previously bought: 1.8524181716255361%
# Share price: $0.3006465977981677
# Shares owned at the moment: 0
# Cash capital at the moment: $146.65073473136923
#
#
# Share price: $0.4130132038698944
# Shares owned at the moment: 354
# Cash capital at the moment: $0.041992207459287556
#
#
#
#
# Capital at the end of test period: $143.8520945607226
# profit gained: 43.852094560722605%
#
#
# Capital at the end of test period if Buy and Hold: $3238.165410975435
# profit gained: 3138.165410975435%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.360731      7.407407       4.761905      93.333333
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         49.382716           46.031746          83.783784      43.852095
#
#    buy_n_hold profit
# 0        3138.165411
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1882 - accuracy: 0.3165 - mse: 1.2710 - weighted_accuracy: 0.3165 - weighted_mse: 1.2710
# Test loss: 0.18820849061012268
# Test accuracy: 0.3165137469768524
#
#
# number of predictions: 218
# actual predicted buys: 5
# actual buys but predicted sell: 0
# actual buys but predicted hold: 5
# actual sells but predicted buy: 2
# actual predicted sells: 4
# actual sells but predicted hold: 3
# actual holds but predicted buy: 85
# actual holds but predicted sell: 54
# actual predicted holds: 60
# Percentage buys correct: 5.434782608695652%
# Percentage sells correct: 6.896551724137931%
# Percentage holds correct: 88.23529411764706%
# actual buys: 10
# actual sells: 9
# actual holds: 199
#
#
# Percentage low buys correct: 45.65217391304348%
# Percentage high sells correct: 51.724137931034484%
# Percentage mid holds correct: 74.6268656716418%
#
#
# Capital: 100
# Share price: $0.9879411977395466
# Shares owned at the moment: 100
# Cash capital at the moment: $0.9341963966669624
#
#
# Price increase from previously bought: -35.90119013223533%
# Share price: $0.6350000109567361
# Shares owned at the moment: 0
# Cash capital at the moment: $64.25957248932747
#
#
# Share price: $0.5136764232164649
# Shares owned at the moment: 124
# Cash capital at the moment: $0.388532350169001
#
#
# Price increase from previously bought: 21.85215296682548%
# Share price: $0.6276470768699184
# Shares owned at the moment: 0
# Cash capital at the moment: $78.00274222882624
#
#
# Share price: $0.6239706098265095
# Shares owned at the moment: 124
# Cash capital at the moment: $0.417612632388213
#
#
# Price increase from previously bought: 2.663700634016264%
# Share price: $0.642352945043554
# Shares owned at the moment: 0
# Cash capital at the moment: $79.85033546352905
#
#
# Share price: $0.6570588132171898
# Shares owned at the moment: 121
# Cash capital at the moment: $0.12758274415105575
#
#
# Price increase from previously bought: -69.46624267346311%
# Share price: $0.201176461565041
# Shares owned at the moment: 0
# Cash capital at the moment: $24.402993125935247
#
#
# Share price: $0.2342646649557213
# Shares owned at the moment: 103
# Cash capital at the moment: $0.20737716914724302
#
#
# Price increase from previously bought: 12.24627804914169%
# Share price: $0.2636764889568811
# Shares owned at the moment: 0
# Cash capital at the moment: $27.291369166208963
#
#
# Share price: $0.3960293901734909
# Shares owned at the moment: 68
# Cash capital at the moment: $0.28731313844913586
#
#
# Price increase from previously bought: -9.532105409774083%
# Share price: $0.35926471973940155
# Shares owned at the moment: 0
# Cash capital at the moment: $24.650131578137174
#
#
# Share price: $0.3629411867828104
# Shares owned at the moment: 67
# Cash capital at the moment: $0.26620015002414377
#
#
# Price increase from previously bought: -17.447447969825735%
# Share price: $0.3004411593909705
# Shares owned at the moment: 0
# Cash capital at the moment: $20.34040154560138
#
#
# Share price: $0.28573529121733454
# Shares owned at the moment: 70
# Cash capital at the moment: $0.2839271168286288
#
#
# Price increase from previously bought: -20.804520170122608%
# Share price: $0.22691173086890348
# Shares owned at the moment: 0
# Cash capital at the moment: $16.124067769459607
#
#
# Share price: $0.15705876939024555
# Shares owned at the moment: 102
# Cash capital at the moment: $0.060018306840596836
#
#
# Price increase from previously bought: -16.61506620742681%
# Share price: $0.13132350008638305
# Shares owned at the moment: 0
# Cash capital at the moment: $13.418179073877438
#
#
# Share price: $0.07250002739184046
# Shares owned at the moment: 184
# Cash capital at the moment: $0.041489019918522274
#
#
# Price increase from previously bought: 242.46572142294468%
# Share price: $0.24897053312935702
# Shares owned at the moment: 0
# Cash capital at the moment: $45.726088025956756
#
#
# Share price: $0.09088236260888481
# Shares owned at the moment: 501
# Cash capital at the moment: $0.06881118382107587
#
#
# Price increase from previously bought: -60.787477573097924%
# Share price: $0.03573526930386272
# Shares owned at the moment: 0
# Cash capital at the moment: $17.9229468377729
#
#
# Share price: $0.12397056599956523
# Shares owned at the moment: 144
# Cash capital at the moment: $0.022092989699679322
#
#
# Price increase from previously bought: 88.44973563791692%
# Share price: $0.2342646649557213
# Shares owned at the moment: 0
# Cash capital at the moment: $33.66343593600108
#
#
# Share price: $0.14970583530342763
# Shares owned at the moment: 224
# Cash capital at the moment: $0.03711003348638542
#
#
# Price increase from previously bought: 68.29952768922145%
# Share price: $0.25264708782665435
# Shares owned at the moment: 0
# Cash capital at the moment: $56.47442710055574
#
#
#
#
# Capital at the end of test period: $56.47442710055574
# profit gained: -43.52557289944426%
#
#
# Capital at the end of test period if Buy and Hold: $26.129427230180067
# profit gained: -73.87057276981993%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.412844      5.617978       2.631579      92.307692
# 1       0.316514      5.434783       6.896552      88.235294
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.181818           55.263158          72.527473     -93.513122
# 1         45.652174           51.724138          74.626866     -43.525573
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
#
#
# Recession
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1761 - accuracy: 0.4886 - mse: 1.1988 - weighted_accuracy: 0.4886 - weighted_mse: 1.1988
# Test loss: 0.17606221139431
# Test accuracy: 0.4885844886302948
#
#
# number of predictions: 219
# actual predicted buys: 5
# actual buys but predicted sell: 0
# actual buys but predicted hold: 3
# actual sells but predicted buy: 1
# actual predicted sells: 6
# actual sells but predicted hold: 4
# actual holds but predicted buy: 55
# actual holds but predicted sell: 49
# actual predicted holds: 96
# Percentage buys correct: 8.19672131147541%
# Percentage sells correct: 10.909090909090908%
# Percentage holds correct: 93.20388349514563%
# actual buys: 8
# actual sells: 11
# actual holds: 200
#
#
# Percentage low buys correct: 48.333333333333336%
# Percentage high sells correct: 47.27272727272727%
# Percentage mid holds correct: 87.37864077669903%
#
#
# Capital: 100
# Share price: $0.011763675119632519
# Shares owned at the moment: 8477
# Cash capital at the moment: $0.005094157405039823
#
#
# Price increase from previously bought: 247.9185448914977%
# Share price: $0.04104055932206908
# Shares owned at the moment: 0
# Cash capital at the moment: $346.94918827180834
#
#
# Share price: $0.1510934797515479
# Shares owned at the moment: 2289
# Cash capital at the moment: $0.14511743884912676
#
#
# Price increase from previously bought: 8.107039390218462%
# Share price: $0.16379188006215306
# Shares owned at the moment: 0
# Cash capital at the moment: $374.0337019640962
#
#
# Share price: $0.16520281342999804
# Shares owned at the moment: 2257
# Cash capital at the moment: $0.1455794903339438
#
#
# Price increase from previously bought: 91.07271566035709%
# Share price: $0.3165255600984224
# Shares owned at the moment: 0
# Cash capital at the moment: $712.5791736123324
#
#
# Share price: $0.26749560033632924
# Shares owned at the moment: 2656
# Cash capital at the moment: $0.15707125418532542
#
#
# Price increase from previously bought: 51.27516296302708%
# Share price: $0.40576720494236085
# Shares owned at the moment: 0
# Cash capital at the moment: $1074.9110439161964
#
#
# Share price: $0.41246913002979846
# Shares owned at the moment: 2598
# Cash capital at the moment: $0.3693583992821914
#
#
# Price increase from previously bought: -5.391233045692834%
# Share price: $0.3913050958728182
# Shares owned at the moment: 0
# Cash capital at the moment: $1014.1843182194006
#
#
# Share price: $0.7197001315826645
# Shares owned at the moment: 1405
# Cash capital at the moment: $0.22489196235437703
#
#
# Price increase from previously bought: -16.110324621536122%
# Share price: $0.6054144278693031
# Shares owned at the moment: 0
# Cash capital at the moment: $848.4929931230452
#
#
# Share price: $0.377195762194368
# Shares owned at the moment: 2243
# Cash capital at the moment: $0.11626076092227322
#
#
# Price increase from previously bought: -34.50003927651731%
# Share price: $0.24774249954719407
# Shares owned at the moment: 0
# Cash capital at the moment: $554.2745495724465
#
#
# Share price: $0.291128759477212
# Shares owned at the moment: 1898
# Cash capital at the moment: $0.19261752460681691
#
#
# Price increase from previously bought: 13.258537400155124%
# Share price: $0.3306349274161774
# Shares owned at the moment: 0
# Cash capital at the moment: $626.0119607568628
#
#
# Share price: $0.27701939215945687
# Shares owned at the moment: 2253
# Cash capital at the moment: $0.17092732263438393
#
#
# Price increase from previously bought: -1.671049644679179%
# Share price: $0.27313933380770933
# Shares owned at the moment: 0
# Cash capital at the moment: $613.8615433639643
#
#
# Share price: $0.29818342631643713
# Shares owned at the moment: 2053
# Cash capital at the moment: $0.007500057192828535
#
#
# Price increase from previously bought: 1.9671749753953138%
# Share price: $0.3048853514038746
# Shares owned at the moment: 0
# Cash capital at the moment: $624.215820016659
#
#
# Share price: $0.2583245166256841
# Shares owned at the moment: 2409
# Cash capital at the moment: $0.200724123869918
#
#
# Price increase from previously bought: 14.023843607826048%
# Share price: $0.295361559580747
# Shares owned at the moment: 0
# Cash capital at the moment: $709.7700246620569
#
#
# Share price: $0.2928924009575395
# Shares owned at the moment: 2416
# Cash capital at the moment: $0.196006836679544
#
#
#
#
# Capital at the end of test period: $623.441611371991
# profit gained: 523.441611371991%
#
#
# Capital at the end of test period if Buy and Hold: $2186.7819938452512
# profit gained: 2086.7819938452512%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.360731      7.407407       4.761905      93.333333
# 1       0.488584      8.196721      10.909091      93.203883
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         49.382716           46.031746          83.783784      43.852095
# 1         48.333333           47.272727          87.378641     523.441611
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1861 - accuracy: 0.3073 - mse: 1.3077 - weighted_accuracy: 0.3073 - weighted_mse: 1.3077
# Test loss: 0.18607282638549805
# Test accuracy: 0.30733945965766907
#
#
# number of predictions: 218
# actual predicted buys: 7
# actual buys but predicted sell: 2
# actual buys but predicted hold: 0
# actual sells but predicted buy: 0
# actual predicted sells: 6
# actual sells but predicted hold: 2
# actual holds but predicted buy: 91
# actual holds but predicted sell: 56
# actual predicted holds: 54
# Percentage buys correct: 7.142857142857143%
# Percentage sells correct: 9.375%
# Percentage holds correct: 96.42857142857143%
# actual buys: 9
# actual sells: 8
# actual holds: 201
#
#
# Percentage low buys correct: 43.29896907216495%
# Percentage high sells correct: 56.25%
# Percentage mid holds correct: 92.85714285714286%
#
#
# Capital: 100
# Share price: $1.01
# Shares owned at the moment: 98
# Cash capital at the moment: $0.7478049999999996
#
#
# Price increase from previously bought: -81.10694813552661%
# Share price: $0.191344578346717
# Shares owned at the moment: 0
# Cash capital at the moment: $19.448006314113826
#
#
# Share price: $0.18142149179007902
# Shares owned at the moment: 106
# Cash capital at the moment: $0.16444381950864084
#
#
# Price increase from previously bought: -16.638164791221797%
# Share price: $0.15165218480315598
# Shares owned at the moment: 0
# Cash capital at the moment: $16.195368796773057
#
#
# Share price: $0.146690641524837
# Shares owned at the moment: 110
# Cash capital at the moment: $0.015024309979722261
#
#
# Price increase from previously bought: -52.21913567252254%
# Share price: $0.07028280406321093
# Shares owned at the moment: 0
# Cash capital at the moment: $7.724872208703803
#
#
# Share price: $0.07028280406321093
# Shares owned at the moment: 109
# Cash capital at the moment: $0.042979295295864084
#
#
# Price increase from previously bought: -15.762347271646204%
# Share price: $0.05936739702165688
# Shares owned at the moment: 0
# Cash capital at the moment: $6.496230193399222
#
#
# Share price: $0.04497890968527956
# Shares owned at the moment: 144
# Cash capital at the moment: $0.0014555504835938038
#
#
# Price increase from previously bought: 16.776650816978012%
# Share price: $0.05266930768130009
# Shares owned at the moment: 0
# Cash capital at the moment: $7.564978810749012
#
#
# Share price: $0.04448275535744766
# Shares owned at the moment: 169
# Cash capital at the moment: $0.02671979478798292
#
#
# Price increase from previously bought: -39.205713183429445%
# Share price: $0.027117342054078918
# Shares owned at the moment: 0
# Cash capital at the moment: $4.5969478172076865
#
#
# Share price: $0.02165963261867574
# Shares owned at the moment: 211
# Cash capital at the moment: $0.01419733284011837
#
#
# Price increase from previously bought: 16.858815957546835%
# Share price: $0.02538079599204115
# Shares owned at the moment: 0
# Cash capital at the moment: $5.354818080286418
#
#
# Share price: $0.02513272474275132
# Shares owned at the moment: 212
# Cash capital at the moment: $0.012028056298113654
#
#
# Price increase from previously bought: 348.189992309723%
# Share price: $0.11295212357376334
# Shares owned at the moment: 0
# Cash capital at the moment: $23.892027165892436
#
#
# Share price: $0.07276357570237042
# Shares owned at the moment: 327
# Cash capital at the moment: $0.0329052657669493
#
#
# Price increase from previously bought: 45.625934348158914%
# Share price: $0.10625403423340656
# Shares owned at the moment: 0
# Cash capital at the moment: $34.6824255198065
#
#
# Share price: $0.04299429237395196
# Shares owned at the moment: 804
# Cash capital at the moment: $0.01995407071031252
#
#
# Price increase from previously bought: -16.38597240123104%
# Share price: $0.0360481199550531
# Shares owned at the moment: 0
# Cash capital at the moment: $28.922940121352386
#
#
# Share price: $0.022403870025049753
# Shares owned at the moment: 1287
# Cash capital at the moment: $0.009866502127195531
#
#
# Price increase from previously bought: 72.60692191040965%
# Share price: $0.038776974672754684
# Shares owned at the moment: 0
# Cash capital at the moment: $49.77859149835193
#
#
# Share price: $0.0184346354023946
# Shares owned at the moment: 2692
# Cash capital at the moment: $0.016081389221731968
#
#
#
#
# Capital at the end of test period: $44.84372193807551
# profit gained: -55.15627806192449%
#
#
# Capital at the end of test period if Buy and Hold: $2.3797176202777375
# profit gained: -97.62028237972227%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.412844      5.617978       2.631579      92.307692
# 1       0.316514      5.434783       6.896552      88.235294
# 2       0.307339      7.142857       9.375000      96.428571
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.181818           55.263158          72.527473     -93.513122
# 1         45.652174           51.724138          74.626866     -43.525573
# 2         43.298969           56.250000          92.857143     -55.156278
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
# 2         -97.620282
#
#
# Recession
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1808 - accuracy: 0.4384 - mse: 1.1734 - weighted_accuracy: 0.4384 - weighted_mse: 1.1734
# Test loss: 0.18084095418453217
# Test accuracy: 0.4383561611175537
#
#
# number of predictions: 219
# actual predicted buys: 3
# actual buys but predicted sell: 1
# actual buys but predicted hold: 4
# actual sells but predicted buy: 1
# actual predicted sells: 6
# actual sells but predicted hold: 3
# actual holds but predicted buy: 59
# actual holds but predicted sell: 55
# actual predicted holds: 87
# Percentage buys correct: 4.761904761904762%
# Percentage sells correct: 9.67741935483871%
# Percentage holds correct: 92.55319148936171%
# actual buys: 8
# actual sells: 10
# actual holds: 201
#
#
# Percentage low buys correct: 44.44444444444444%
# Percentage high sells correct: 53.225806451612904%
# Percentage mid holds correct: 83.87096774193549%
#
#
# Capital: 100
# Share price: $0.03179487113936676
# Shares owned at the moment: 3136
# Cash capital at the moment: $0.01708513823994906
#
#
# Price increase from previously bought: 38.47551471210724%
# Share price: $0.044149188768810646
# Shares owned at the moment: 0
# Cash capital at the moment: $138.08819851328792
#
#
# Share price: $0.07538461341810025
# Shares owned at the moment: 1826
# Cash capital at the moment: $0.05735057555787648
#
#
# Price increase from previously bought: 166.9375495596265%
# Share price: $0.2017832218627332
# Shares owned at the moment: 0
# Cash capital at the moment: $367.50025924832494
#
#
# Share price: $0.23103730469488548
# Shares owned at the moment: 1586
# Cash capital at the moment: $0.06742479780979238
#
#
# Price increase from previously bought: 36.02305160968451%
# Share price: $0.3151282181813057
# Shares owned at the moment: 0
# Cash capital at the moment: $498.4863471097629
#
#
# Share price: $0.7464219281165627
# Shares owned at the moment: 666
# Cash capital at the moment: $0.0022712227866463763
#
#
# Price increase from previously bought: -18.13497271294977%
# Share price: $0.6127389260457556
# Shares owned at the moment: 0
# Cash capital at the moment: $406.9641646262071
#
#
# Share price: $0.5667016641439497
# Shares owned at the moment: 716
# Cash capital at the moment: $0.08993752243964082
#
#
# Price increase from previously bought: 7.704141209766102%
# Share price: $0.6120396537793102
# Shares owned at the moment: 0
# Cash capital at the moment: $437.1052235501343
#
#
# Share price: $0.5429254289572745
# Shares owned at the moment: 802
# Cash capital at the moment: $0.4816074928349394
#
#
# Price increase from previously bought: -5.89389468125765%
# Share price: $0.5123310224107025
# Shares owned at the moment: 0
# Cash capital at the moment: $410.24114139629154
#
#
# Share price: $0.47410259721981923
# Shares owned at the moment: 862
# Cash capital at the moment: $0.4408423860977564
#
#
# Price increase from previously bought: 19.39975284882671%
# Share price: $0.567634041985991
# Shares owned at the moment: 0
# Cash capital at the moment: $488.3958100814942
#
#
# Share price: $0.6404195795878922
# Shares owned at the moment: 760
# Cash capital at the moment: $0.3384526733573807
#
#
#
#
# Capital at the end of test period: $528.8261024467886
# profit gained: 428.8261024467886%
#
#
# Capital at the end of test period if Buy and Hold: $5902.379195330377
# profit gained: 5802.379195330377%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.360731      7.407407       4.761905      93.333333
# 1       0.488584      8.196721      10.909091      93.203883
# 2       0.438356      4.761905       9.677419      92.553191
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         49.382716           46.031746          83.783784      43.852095
# 1         48.333333           47.272727          87.378641     523.441611
# 2         44.444444           53.225806          83.870968     428.826102
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
# 2        5802.379195
#
#
#
# RUNNING EPOCHS 20 - 40
#
#
#
# Epoch 1/20
#  2/30 [=>............................] - ETA: 32s - loss: 0.1303 - accuracy: 0.3555 - mse: 1.5257 - weighted_accuracy: 0.6814 - weighted_mse: 1.4427WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0250s vs `on_train_batch_end` time: 2.2551s). Check your callbacks.
# 30/30 [==============================] - 3s 115ms/step - loss: 0.1470 - accuracy: 0.3954 - mse: 1.4811 - weighted_accuracy: 0.6778 - weighted_mse: 1.4102 - val_loss: 0.1896 - val_accuracy: 0.3330 - val_mse: 1.2836 - val_weighted_accuracy: 0.3330 - val_weighted_mse: 1.2836
# Epoch 2/20
# 30/30 [==============================] - 1s 36ms/step - loss: 0.1451 - accuracy: 0.3656 - mse: 1.4918 - weighted_accuracy: 0.6801 - weighted_mse: 1.4074 - val_loss: 0.1737 - val_accuracy: 0.4457 - val_mse: 1.3278 - val_weighted_accuracy: 0.4457 - val_weighted_mse: 1.3278
# Epoch 3/20
# 30/30 [==============================] - 1s 39ms/step - loss: 0.1434 - accuracy: 0.4081 - mse: 1.4944 - weighted_accuracy: 0.7065 - weighted_mse: 1.4144 - val_loss: 0.1892 - val_accuracy: 0.3678 - val_mse: 1.3935 - val_weighted_accuracy: 0.3678 - val_weighted_mse: 1.3935
# Epoch 4/20
# 30/30 [==============================] - 1s 36ms/step - loss: 0.1426 - accuracy: 0.4036 - mse: 1.5148 - weighted_accuracy: 0.6976 - weighted_mse: 1.4359 - val_loss: 0.1865 - val_accuracy: 0.3656 - val_mse: 1.4423 - val_weighted_accuracy: 0.3656 - val_weighted_mse: 1.4423
# Epoch 5/20
# 30/30 [==============================] - 1s 34ms/step - loss: 0.1420 - accuracy: 0.3809 - mse: 1.5530 - weighted_accuracy: 0.6839 - weighted_mse: 1.4588 - val_loss: 0.1864 - val_accuracy: 0.3583 - val_mse: 1.4338 - val_weighted_accuracy: 0.3583 - val_weighted_mse: 1.4338
# Epoch 6/20
# 30/30 [==============================] - 1s 34ms/step - loss: 0.1413 - accuracy: 0.4210 - mse: 1.5294 - weighted_accuracy: 0.6965 - weighted_mse: 1.4480 - val_loss: 0.1846 - val_accuracy: 0.3656 - val_mse: 1.4633 - val_weighted_accuracy: 0.3656 - val_weighted_mse: 1.4633
# Epoch 7/20
# 30/30 [==============================] - 1s 34ms/step - loss: 0.1399 - accuracy: 0.4004 - mse: 1.5539 - weighted_accuracy: 0.7056 - weighted_mse: 1.4702 - val_loss: 0.1832 - val_accuracy: 0.4078 - val_mse: 1.4555 - val_weighted_accuracy: 0.4078 - val_weighted_mse: 1.4555
# Epoch 8/20
# 30/30 [==============================] - 1s 36ms/step - loss: 0.1377 - accuracy: 0.4291 - mse: 1.5494 - weighted_accuracy: 0.7219 - weighted_mse: 1.4632 - val_loss: 0.1845 - val_accuracy: 0.3994 - val_mse: 1.4664 - val_weighted_accuracy: 0.3994 - val_weighted_mse: 1.4664
# Epoch 9/20
# 30/30 [==============================] - 1s 38ms/step - loss: 0.1372 - accuracy: 0.4165 - mse: 1.5927 - weighted_accuracy: 0.7118 - weighted_mse: 1.5007 - val_loss: 0.1825 - val_accuracy: 0.4110 - val_mse: 1.5148 - val_weighted_accuracy: 0.4110 - val_weighted_mse: 1.5148
# Epoch 10/20
# 30/30 [==============================] - 1s 36ms/step - loss: 0.1359 - accuracy: 0.4523 - mse: 1.5709 - weighted_accuracy: 0.7190 - weighted_mse: 1.4988 - val_loss: 0.1911 - val_accuracy: 0.3783 - val_mse: 1.5217 - val_weighted_accuracy: 0.3783 - val_weighted_mse: 1.5217
# Epoch 11/20
# 30/30 [==============================] - 1s 36ms/step - loss: 0.1360 - accuracy: 0.4223 - mse: 1.6165 - weighted_accuracy: 0.7138 - weighted_mse: 1.5208 - val_loss: 0.1795 - val_accuracy: 0.4447 - val_mse: 1.5696 - val_weighted_accuracy: 0.4447 - val_weighted_mse: 1.5696
# Epoch 12/20
# 30/30 [==============================] - 1s 40ms/step - loss: 0.1344 - accuracy: 0.4629 - mse: 1.5985 - weighted_accuracy: 0.7209 - weighted_mse: 1.5200 - val_loss: 0.1778 - val_accuracy: 0.4594 - val_mse: 1.5233 - val_weighted_accuracy: 0.4594 - val_weighted_mse: 1.5233
# Epoch 13/20
# 30/30 [==============================] - 1s 35ms/step - loss: 0.1329 - accuracy: 0.4576 - mse: 1.6428 - weighted_accuracy: 0.7306 - weighted_mse: 1.5642 - val_loss: 0.1972 - val_accuracy: 0.3688 - val_mse: 1.6841 - val_weighted_accuracy: 0.3688 - val_weighted_mse: 1.6841
# Epoch 14/20
# 30/30 [==============================] - 1s 30ms/step - loss: 0.1316 - accuracy: 0.4647 - mse: 1.6436 - weighted_accuracy: 0.7387 - weighted_mse: 1.5648 - val_loss: 0.1892 - val_accuracy: 0.3867 - val_mse: 1.6513 - val_weighted_accuracy: 0.3867 - val_weighted_mse: 1.6513
# Epoch 15/20
# 30/30 [==============================] - 1s 27ms/step - loss: 0.1303 - accuracy: 0.4452 - mse: 1.6510 - weighted_accuracy: 0.7352 - weighted_mse: 1.5625 - val_loss: 0.1838 - val_accuracy: 0.4131 - val_mse: 1.5639 - val_weighted_accuracy: 0.4131 - val_weighted_mse: 1.5639
# Epoch 16/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.1302 - accuracy: 0.4884 - mse: 1.6705 - weighted_accuracy: 0.7511 - weighted_mse: 1.5968 - val_loss: 0.1899 - val_accuracy: 0.3952 - val_mse: 1.6915 - val_weighted_accuracy: 0.3952 - val_weighted_mse: 1.6915
# Epoch 17/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.1301 - accuracy: 0.4650 - mse: 1.6952 - weighted_accuracy: 0.7442 - weighted_mse: 1.6125 - val_loss: 0.2007 - val_accuracy: 0.3456 - val_mse: 1.7006 - val_weighted_accuracy: 0.3456 - val_weighted_mse: 1.7006
# Epoch 18/20
# 30/30 [==============================] - 1s 36ms/step - loss: 0.1280 - accuracy: 0.4663 - mse: 1.7064 - weighted_accuracy: 0.7449 - weighted_mse: 1.6237 - val_loss: 0.1852 - val_accuracy: 0.4226 - val_mse: 1.7167 - val_weighted_accuracy: 0.4226 - val_weighted_mse: 1.7167
# Epoch 19/20
# 30/30 [==============================] - 1s 37ms/step - loss: 0.1273 - accuracy: 0.4787 - mse: 1.7033 - weighted_accuracy: 0.7568 - weighted_mse: 1.6201 - val_loss: 0.1761 - val_accuracy: 0.4710 - val_mse: 1.6573 - val_weighted_accuracy: 0.4710 - val_weighted_mse: 1.6573
# Epoch 20/20
# 30/30 [==============================] - 1s 33ms/step - loss: 0.1257 - accuracy: 0.5026 - mse: 1.7224 - weighted_accuracy: 0.7583 - weighted_mse: 1.6478 - val_loss: 0.1893 - val_accuracy: 0.4089 - val_mse: 1.7169 - val_weighted_accuracy: 0.4089 - val_weighted_mse: 1.7169
# Validation loss: 0.18932580947875977
# Validation accuracy: 0.40885141491889954
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1789 - accuracy: 0.4633 - mse: 1.7789 - weighted_accuracy: 0.4633 - weighted_mse: 1.7789
# Test loss: 0.1788993924856186
# Test accuracy: 0.46330276131629944
#
#
# number of predictions: 218
# actual predicted buys: 1
# actual buys but predicted sell: 2
# actual buys but predicted hold: 5
# actual sells but predicted buy: 2
# actual predicted sells: 3
# actual sells but predicted hold: 3
# actual holds but predicted buy: 73
# actual holds but predicted sell: 32
# actual predicted holds: 97
# Percentage buys correct: 1.3157894736842106%
# Percentage sells correct: 8.108108108108109%
# Percentage holds correct: 92.38095238095238%
# actual buys: 8
# actual sells: 8
# actual holds: 202
#
#
# Percentage low buys correct: 42.10526315789474%
# Percentage high sells correct: 59.45945945945946%
# Percentage mid holds correct: 69.23076923076923%
#
#
# Capital: 100
# Share price: $0.8206796684656419
# Shares owned at the moment: 121
# Cash capital at the moment: $0.42467895597538075
#
#
# Price increase from previously bought: -16.201113733032212%
# Share price: $0.6896116531541341
# Shares owned at the moment: 0
# Cash capital at the moment: $83.63822071003855
#
#
# Share price: $0.34980584827778816
# Shares owned at the moment: 238
# Cash capital at the moment: $0.15548089222716044
#
#
# Price increase from previously bought: -33.48848588544645%
# Share price: $0.2333009843577296
# Shares owned at the moment: 0
# Cash capital at the moment: $55.52841967510467
#
#
# Share price: $0.22359225534248967
# Shares owned at the moment: 247
# Cash capital at the moment: $0.14925756606833573
#
#
# Price increase from previously bought: -0.27424582398404285%
# Share price: $0.22359225534248967
# Shares owned at the moment: 0
# Cash capital at the moment: $55.2246695962219
#
#
# Share price: $0.20417476837771503
# Shares owned at the moment: 269
# Cash capital at the moment: $0.1506186177091422
#
#
# Price increase from previously bought: 6.838853880952711%
# Share price: $0.21873786190057493
# Shares owned at the moment: 0
# Cash capital at the moment: $58.82929213562285
#
#
# Share price: $0.21388349739295492
# Shares owned at the moment: 274
# Cash capital at the moment: $0.06405263466760402
#
#
# Price increase from previously bought: 11.042796971915791%
# Share price: $0.23815534886534961
# Shares owned at the moment: 0
# Cash capital at the moment: $65.13916816840336
#
#
# Share price: $0.1896116459205603
# Shares owned at the moment: 342
# Cash capital at the moment: $0.11365551058345602
#
#
# Price increase from previously bought: -79.42166802193478%
# Share price: $0.03912621598001464
# Shares owned at the moment: 0
# Cash capital at the moment: $13.458023169619258
#
#
# Share price: $0.048834959462401954
# Shares owned at the moment: 274
# Cash capital at the moment: $0.040447134966202114
#
#
# Price increase from previously bought: 9.63884035233189%
# Share price: $0.05368932397002193
# Shares owned at the moment: 0
# Cash capital at the moment: $14.710866997140798
#
#
# Share price: $0.029417472497627294
# Shares owned at the moment: 498
# Cash capital at the moment: $0.02067846473690338
#
#
# Price increase from previously bought: 49.09494888053651%
# Share price: $0.043980580487634584
# Shares owned at the moment: 0
# Cash capital at the moment: $21.86277614260111
#
#
# Share price: $0.014854364507619946
# Shares owned at the moment: 1467
# Cash capital at the moment: $0.011497189907782257
#
#
# Price increase from previously bought: 130.0863314172555%
# Share price: $0.034271851472394664
# Shares owned at the moment: 0
# Cash capital at the moment: $50.15004208310825
#
#
# Share price: $0.029417472497627294
# Shares owned at the moment: 1700
# Cash capital at the moment: $0.002812153215437263
#
#
#
#
# Capital at the end of test period: $33.41553769749377
# profit gained: -66.58446230250624%
#
#
# Capital at the end of test period if Buy and Hold: $2.5934579490563006
# profit gained: -97.4065420509437%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.463303      1.315789       8.108108      92.380952
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         42.105263           59.459459          69.230769     -66.584462
#
#    buy_n_hold profit
# 0         -97.406542
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1951 - accuracy: 0.4749 - mse: 1.7834 - weighted_accuracy: 0.4749 - weighted_mse: 1.7834
# Test loss: 0.19509389996528625
# Test accuracy: 0.47488585114479065
#
#
# number of predictions: 219
# actual predicted buys: 5
# actual buys but predicted sell: 1
# actual buys but predicted hold: 2
# actual sells but predicted buy: 1
# actual predicted sells: 3
# actual sells but predicted hold: 4
# actual holds but predicted buy: 58
# actual holds but predicted sell: 49
# actual predicted holds: 96
# Percentage buys correct: 7.8125%
# Percentage sells correct: 5.660377358490566%
# Percentage holds correct: 94.11764705882354%
# actual buys: 8
# actual sells: 8
# actual holds: 203
#
#
# Percentage low buys correct: 50.0%
# Percentage high sells correct: 41.509433962264154%
# Percentage mid holds correct: 87.12871287128714%
#
#
# Capital: 100
# Share price: $0.025065914582985994
# Shares owned at the moment: 3978
# Cash capital at the moment: $0.013583216301142897
#
#
# Price increase from previously bought: 92.13379133766986%
# Share price: $0.04829253227481269
# Shares owned at the moment: 0
# Cash capital at the moment: $191.5929804486857
#
#
# Share price: $0.03636535426188572
# Shares owned at the moment: 5254
# Cash capital at the moment: $0.003984335685260021
#
#
# Price increase from previously bought: 78.91414241856312%
# Share price: $0.06524168430984181
# Shares owned at the moment: 0
# Cash capital at the moment: $341.84114922384344
#
#
# Share price: $0.05017576972685583
# Shares owned at the moment: 6794
# Cash capital at the moment: $0.009510705893205795
#
#
# Price increase from previously bought: 33.41268563353812%
# Share price: $0.06712492924520537
# Shares owned at the moment: 0
# Cash capital at the moment: $454.80215138226566
#
#
# Share price: $0.10981168972477247
# Shares owned at the moment: 4130
# Cash capital at the moment: $0.03268655290622746
#
#
# Price increase from previously bought: -13.95639294243215%
# Share price: $0.09474577514178649
# Shares owned at the moment: 0
# Cash capital at the moment: $390.25666274731157
#
#
# Share price: $0.6452793658215203
# Shares owned at the moment: 603
# Cash capital at the moment: $0.0831706485612358
#
#
# Price increase from previously bought: -19.289400969631277%
# Share price: $0.5222410658882417
# Shares owned at the moment: 0
# Cash capital at the moment: $314.1285271316618
#
#
# Share price: $0.36593222266889325
# Shares owned at the moment: 856
# Cash capital at the moment: $0.0291400749266586
#
#
# Price increase from previously bought: 18.030966261434365%
# Share price: $0.4331010999583029
# Shares owned at the moment: 0
# Cash capital at the moment: $369.7441616499321
#
#
# Share price: $0.3734651724770659
# Shares owned at the moment: 987
# Cash capital at the moment: $0.12035857067218103
#
#
# Price increase from previously bought: 6.263167166720596%
# Share price: $0.39794727432026755
# Shares owned at the moment: 0
# Cash capital at the moment: $391.8141899354524
#
#
# Share price: $0.3263841912760648
# Shares owned at the moment: 1197
# Cash capital at the moment: $0.05793781636987205
#
#
# Price increase from previously bought: -18.6876339021939%
# Share price: $0.26612053294412086
# Shares owned at the moment: 0
# Cash capital at the moment: $317.7282134861637
#
#
# Share price: $0.27804771844036824
# Shares owned at the moment: 1139
# Cash capital at the moment: $0.16094721649943722
#
#
# Price increase from previously bought: -5.677844206332894%
# Share price: $0.26298181882402316
# Shares owned at the moment: 0
# Cash capital at the moment: $298.87351405505024
#
#
# Share price: $0.42933459512093497
# Shares owned at the moment: 694
# Cash capital at the moment: $0.09591996633304234
#
#
# Price increase from previously bought: -5.377692866835959%
# Share price: $0.4073634765471241
# Shares owned at the moment: 0
# Cash capital at the moment: $282.02871949504697
#
#
#
#
# Capital at the end of test period: $282.02871949504697
# profit gained: 182.02871949504697%
#
#
# ...
# Share price: $0.20902913288533498
# Shares owned at the moment: 0
# Cash capital at the moment: $72.18738342641474
#
#
# Share price: $0.21388349739295492
# Shares owned at the moment: 336
# Cash capital at the moment: $0.12489995079079108
#
#
# Price increase from previously bought: -20.644912063833253%
# Share price: $0.1701941878900804
# Shares owned at the moment: 0
# Cash capital at the moment: $57.15288765224737
#
#
# Share price: $0.14592233641768576
# Shares owned at the moment: 390
# Cash capital at the moment: $0.08667474354195548
#
#
# Price increase from previously bought: -63.307822122686645%
# Share price: $0.05368932397002193
# Shares owned at the moment: 0
# Cash capital at the moment: $20.96792929189266
#
#
# Share price: $0.01
# Shares owned at the moment: 2091
# Cash capital at the moment: $0.00042679189265726336
#
#
# Price increase from previously bought: 144.95744692104034%
# Share price: $0.02456310799000732
# Shares owned at the moment: 0
# Cash capital at the moment: $51.22064158727842
#
#
#
#
# Capital at the end of test period: $51.22064158727842
# profit gained: -48.77935841272158%
#
#
# Capital at the end of test period if Buy and Hold: $2.5934579490563006
# profit gained: -97.4065420509437%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.784404           0.0       8.333333      92.391304
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         63.636364           58.333333          72.131148     -48.779358
#
#    buy_n_hold profit
# 0         -97.406542
#
#
# Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1793 - accuracy: 0.7808 - mse: 10.5832 - weighted_accuracy: 0.7808 - weighted_mse: 10.5832
# Test loss: 0.17930740118026733
# Test accuracy: 0.7808219194412231
#
#
# number of predictions: 219
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 0
# actual predicted sells: 2
# actual sells but predicted hold: 6
# actual holds but predicted buy: 19
# actual holds but predicted sell: 16
# actual predicted holds: 168
# Percentage buys correct: 5.0%
# Percentage sells correct: 11.11111111111111%
# Percentage holds correct: 92.81767955801105%
# actual buys: 8
# actual sells: 8
# actual holds: 203
#
#
# Percentage low buys correct: 60.0%
# Percentage high sells correct: 47.05882352941177%
# Percentage mid holds correct: 84.5303867403315%
#
#
# Capital: 100
# Share price: $0.05017576972685583
# Shares owned at the moment: 1987
# Cash capital at the moment: $0.026572603007494422
#
#
# Price increase from previously bought: 165.66502701945436%
# Share price: $0.13366604575062643
# Shares owned at the moment: 0
# Cash capital at the moment: $264.8906208190093
#
#
# Share price: $0.09662901259382962
# Shares owned at the moment: 2733
# Cash capital at the moment: $0.07728989867086966
#
#
# Price increase from previously bought: 942.3682185510393%
# Share price: $1.01
# Shares owned at the moment: 0
# Cash capital at the moment: $2752.8163823986706
#
#
# Share price: $0.6471625883069226
# Shares owned at the moment: 4242
# Cash capital at the moment: $0.003207626810308284
#
#
# Price increase from previously bought: -57.250437547296606%
# Share price: $0.27741998758966135
# Shares owned at the moment: 0
# Cash capital at the moment: $1173.5825521169265
#
#
# Share price: $0.2711424994829026
# Shares owned at the moment: 4316
# Cash capital at the moment: $0.1133340223561845
#
#
# Price increase from previously bought: -2.1213166501431346%
# Share price: $0.26612053294412086
# Shares owned at the moment: 0
# Cash capital at the moment: $1145.530969603668
#
#
# Share price: $0.26298181882402316
# Shares owned at the moment: 4343
# Cash capital at the moment: $0.2600728432653341
#
#
# Price increase from previously bought: 28.053552952925955%
# Share price: $0.3376836459216054
# Shares owned at the moment: 0
# Cash capital at the moment: $1462.7871068766444
#
#
#
#
# Capital at the end of test period: $1462.7871068766444
# profit gained: 1362.7871068766444%
#
#
# Capital at the end of test period if Buy and Hold: $3238.165410975435
# profit gained: 3138.165410975435%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.780822           5.0      11.111111       92.81768
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0              60.0           47.058824          84.530387    1362.787107
#
#    buy_n_hold profit
# 0        3138.165411
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1619 - accuracy: 0.8165 - mse: 7.8487 - weighted_accuracy: 0.8165 - weighted_mse: 7.8487
# Test loss: 0.16192133724689484
# Test accuracy: 0.8165137767791748
#
#
# number of predictions: 218
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 9
# actual sells but predicted buy: 0
# actual predicted sells: 2
# actual sells but predicted hold: 7
# actual holds but predicted buy: 12
# actual holds but predicted sell: 12
# actual predicted holds: 175
# Percentage buys correct: 7.6923076923076925%
# Percentage sells correct: 14.285714285714286%
# Percentage holds correct: 91.62303664921465%
# actual buys: 10
# actual sells: 9
# actual holds: 199
#
#
# Percentage low buys correct: 30.76923076923077%
# Percentage high sells correct: 57.142857142857146%
# Percentage mid holds correct: 81.05263157894737%
#
#
# Capital: 100
# Share price: $0.6607352802605987
# Shares owned at the moment: 150
# Cash capital at the moment: $0.6171546578027005
#
#
# Price increase from previously bought: -6.932994427360473%
# Share price: $0.6166175880858032
# Shares owned at the moment: 0
# Cash capital at the moment: $92.85543811558779
#
#
# Share price: $0.48426468686919344
# Shares owned at the moment: 191
# Cash capital at the moment: $0.10652289679379123
#
#
# Price increase from previously bought: -48.72891859109172%
# Share price: $0.24897053312935702
# Shares owned at the moment: 0
# Cash capital at the moment: $47.529122951974784
#
#
# Share price: $0.3629411867828104
# Shares owned at the moment: 130
# Cash capital at the moment: $0.2170171959345808
#
#
# Price increase from previously bought: -32.6002762261281%
# Share price: $0.24529406608594806
# Shares owned at the moment: 0
# Cash capital at the moment: $32.0175531584821
#
#
# Share price: $0.057794071564316145
# Shares owned at the moment: 552
# Cash capital at the moment: $0.027494254344954783
#
#
# Price increase from previously bought: -25.64975155897693%
# Share price: $0.04308820339068042
# Shares owned at the moment: 0
# Cash capital at the moment: $23.74677463325349
#
#
# Share price: $0.0688235603484315
# Shares owned at the moment: 344
# Cash capital at the moment: $0.00636278530343759
#
#
# Price increase from previously bought: 266.0871545489793%
# Share price: $0.25264708782665435
# Shares owned at the moment: 0
# Cash capital at the moment: $86.67795685258851
#
#
#
#
# Capital at the end of test period: $86.67795685258851
# profit gained: -13.322043147411492%
#
#
# Capital at the end of test period if Buy and Hold: $26.129427230180067
# profit gained: -73.87057276981993%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.784404      0.000000       8.333333      92.391304
# 1       0.816514      7.692308      14.285714      91.623037
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         63.636364           58.333333          72.131148     -48.779358
# 1         30.769231           57.142857          81.052632     -13.322043
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2228 - accuracy: 0.7854 - mse: 9.9357 - weighted_accuracy: 0.7854 - weighted_mse: 9.9357
# Test loss: 0.22277462482452393
# Test accuracy: 0.7853881120681763
#
#
# number of predictions: 219
# actual predicted buys: 0
# actual buys but predicted sell: 0
# actual buys but predicted hold: 8
# actual sells but predicted buy: 0
# actual predicted sells: 1
# actual sells but predicted hold: 10
# actual holds but predicted buy: 9
# actual holds but predicted sell: 20
# actual predicted holds: 171
# Percentage buys correct: 0.0%
# Percentage sells correct: 4.761904761904762%
# Percentage holds correct: 90.47619047619048%
# actual buys: 8
# actual sells: 11
# actual holds: 200
#
#
# Percentage low buys correct: 66.66666666666667%
# Percentage high sells correct: 38.095238095238095%
# Percentage mid holds correct: 85.63829787234043%
#
#
# Capital: 100
# Share price: $0.011763675119632519
# Shares owned at the moment: 8477
# Cash capital at the moment: $0.005094157405039823
#
#
# Price increase from previously bought: 265.86032469303035%
# Share price: $0.04315697619348919
# Shares owned at the moment: 0
# Cash capital at the moment: $364.84071670983434
#
#
# Share price: $0.3165255600984224
# Shares owned at the moment: 1149
# Cash capital at the moment: $0.15270651822595482
#
#
# Price increase from previously bought: 1.392764872139196%
# Share price: $0.32181658545731984
# Shares owned at the moment: 0
# Cash capital at the moment: $368.9031032527877
#
#
# Share price: $0.8159964769051328
# Shares owned at the moment: 450
# Cash capital at the moment: $0.6948930053077902
#
#
# Price increase from previously bought: -26.010207008128205%
# Share price: $0.6054144278693031
# Shares owned at the moment: 0
# Cash capital at the moment: $272.3821851920059
#
#
# Share price: $0.24774249954719407
# Shares owned at the moment: 1096
# Cash capital at the moment: $0.10970979464593711
#
#
# Price increase from previously bought: 17.33234805026602%
# Share price: $0.2914814675896946
# Shares owned at the moment: 0
# Cash capital at the moment: $318.6948731296359
#
#
# Share price: $0.2703174670720192
# Shares owned at the moment: 1175
# Cash capital at the moment: $0.19838600453681465
#
#
#
#
# Capital at the end of test period: $303.30831370693375
# profit gained: 203.30831370693377%
#
#
# Capital at the end of test period if Buy and Hold: $2186.7819938452512
# profit gained: 2086.7819938452512%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.780822           5.0      11.111111       92.81768
# 1       0.785388           0.0       4.761905       90.47619
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         60.000000           47.058824          84.530387    1362.787107
# 1         66.666667           38.095238          85.638298     203.308314
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1869 - accuracy: 0.8119 - mse: 9.3067 - weighted_accuracy: 0.8119 - weighted_mse: 9.3067
# Test loss: 0.18691487610340118
# Test accuracy: 0.8119266033172607
#
#
# number of predictions: 218
# actual predicted buys: 0
# actual buys but predicted sell: 0
# actual buys but predicted hold: 9
# actual sells but predicted buy: 1
# actual predicted sells: 0
# actual sells but predicted hold: 7
# actual holds but predicted buy: 16
# actual holds but predicted sell: 8
# actual predicted holds: 177
# Percentage buys correct: 0.0%
# Percentage sells correct: 0.0%
# Percentage holds correct: 91.70984455958549%
# actual buys: 9
# actual sells: 8
# actual holds: 201
#
#
# Percentage low buys correct: 43.75%
# Percentage high sells correct: 62.5%
# Percentage mid holds correct: 83.41968911917098%
#
#
# Capital: 100
# Share price: $1.01
# Shares owned at the moment: 98
# Cash capital at the moment: $0.7478049999999996
#
#
# Price increase from previously bought: -81.59684283385067%
# Share price: $0.186383035068398
# Shares owned at the moment: 0
# Cash capital at the moment: $18.963112208752072
#
#
# Share price: $0.1665368382966175
# Shares owned at the moment: 113
# Cash capital at the moment: $0.09269815873361864
#
#
# Price increase from previously bought: -3.2453220757502343%
# Share price: $0.1615752950182985
# Shares owned at the moment: 0
# Cash capital at the moment: $18.300496972874413
#
#
# Share price: $0.05118084469780442
# Shares owned at the moment: 356
# Cash capital at the moment: $0.030010213496886706
#
#
# Price increase from previously bought: -29.76032399677496%
# Share price: $0.0360481199550531
# Shares owned at the moment: 0
# Cash capital at the moment: $12.827849808059794
#
#
# Share price: $0.011488462983495698
# Shares owned at the moment: 1113
# Cash capital at the moment: $0.006027194352347109
#
#
#
#
# Capital at the end of test period: $18.539891953220945
# profit gained: -81.46010804677906%
#
#
# Capital at the end of test period if Buy and Hold: $2.3797176202777375
# profit gained: -97.62028237972227%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.784404      0.000000       8.333333      92.391304
# 1       0.816514      7.692308      14.285714      91.623037
# 2       0.811927      0.000000       0.000000      91.709845
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         63.636364           58.333333          72.131148     -48.779358
# 1         30.769231           57.142857          81.052632     -13.322043
# 2         43.750000           62.500000          83.419689     -81.460108
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
# 2         -97.620282
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2742 - accuracy: 0.7397 - mse: 9.2532 - weighted_accuracy: 0.7397 - weighted_mse: 9.2532
# Test loss: 0.2742172181606293
# Test accuracy: 0.7397260069847107
#
#
# number of predictions: 219
# actual predicted buys: 0
# actual buys but predicted sell: 0
# actual buys but predicted hold: 8
# actual sells but predicted buy: 0
# actual predicted sells: 0
# actual sells but predicted hold: 10
# actual holds but predicted buy: 14
# actual holds but predicted sell: 25
# actual predicted holds: 162
# Percentage buys correct: 0.0%
# Percentage sells correct: 0.0%
# Percentage holds correct: 90.0%
# actual buys: 8
# actual sells: 10
# actual holds: 201
#
#
# Percentage low buys correct: 50.0%
# Percentage high sells correct: 40.0%
# Percentage mid holds correct: 83.79888268156425%
#
#
# Capital: 100
# Share price: $0.03179487113936676
# Shares owned at the moment: 3136
# Cash capital at the moment: $0.01708513823994906
#
#
# Price increase from previously bought: 53.2808321246131%
# Share price: $0.04886946552377208
# Shares owned at the moment: 0
# Cash capital at the moment: $152.85027875011218
#
#
# Share price: $0.2307459338404762
# Shares owned at the moment: 660
# Cash capital at the moment: $0.13915854547741446
#
#
# Price increase from previously bought: 97.32078587846101%
# Share price: $0.45656179168422206
# Shares owned at the moment: 0
# Cash capital at the moment: $300.6412814051571
#
#
# Share price: $0.7464219281165627
# Shares owned at the moment: 401
# Cash capital at the moment: $0.5029714491848836
#
#
# Price increase from previously bought: -14.109687109150304%
# Share price: $0.6428671659014783
# Shares owned at the moment: 0
# Cash capital at the moment: $257.5837832084798
#
#
# Share price: $0.6117482606947298
# Shares owned at the moment: 419
# Cash capital at the moment: $0.5563750440024933
#
#
# Price increase from previously bought: 1.2362360708903175%
# Share price: $0.6210140183682126
# Shares owned at the moment: 0
# Cash capital at the moment: $260.0456853376188
#
#
# Share price: $0.5151282003971687
# Shares owned at the moment: 503
# Cash capital at the moment: $0.22364945464357788
#
#
# Price increase from previously bought: -0.8157628367389536%
# Share price: $0.5123310224107025
# Shares owned at the moment: 0
# Cash capital at the moment: $257.21747184047734
#
#
#
#
# Capital at the end of test period: $257.21747184047734
# profit gained: 157.21747184047734%
#
#
# Capital at the end of test period if Buy and Hold: $5902.379195330377
# profit gained: 5802.379195330377%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.780822           5.0      11.111111       92.81768
# 1       0.785388           0.0       4.761905       90.47619
# 2       0.739726           0.0       0.000000       90.00000
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         60.000000           47.058824          84.530387    1362.787107
# 1         66.666667           38.095238          85.638298     203.308314
# 2         50.000000           40.000000          83.798883     157.217472
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
# 2        5802.379195

# %%
Vaxart_data_acc = []
Inovio_data_acc = []
Novavax_data_acc = []

Vaxart_data_correct_buys = []
Inovio_data_correct_buys = []
Novavax_data_correct_buys = []

Vaxart_data_correct_sells = []
Inovio_data_correct_sells = []
Novavax_data_correct_sells = []

Vaxart_data_correct_holds = []
Inovio_data_correct_holds = []
Novavax_data_correct_holds = []

Vaxart_data_correct_low_buys = []
Inovio_data_correct_low_buys = []
Novavax_data_correct_low_buys = []

Vaxart_data_correct_high_sells = []
Inovio_data_correct_high_sells = []
Novavax_data_correct_high_sells = []

Vaxart_data_correct_mid_holds = []
Inovio_data_correct_mid_holds = []
Novavax_data_correct_mid_holds = []

Vaxart_data_profit = []
Inovio_data_profit = []
Novavax_data_profit = []

for key,value in nr_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    Vaxart_data_acc.append(acc[0])
    Inovio_data_acc.append(acc[1])
    Novavax_data_acc.append(acc[2])
    
    Vaxart_data_correct_buys.append(correct_buys[0])
    Inovio_data_correct_buys.append(correct_buys[1]) 
    Novavax_data_correct_buys.append(correct_buys[2]) 

    Vaxart_data_correct_sells.append(correct_sells[0]) 
    Inovio_data_correct_sells.append(correct_sells[1]) 
    Novavax_data_correct_sells.append(correct_sells[2]) 

    Vaxart_data_correct_holds.append(correct_holds[0]) 
    Inovio_data_correct_holds.append(correct_holds[1])  
    Novavax_data_correct_holds.append(correct_holds[2])  

    Vaxart_data_correct_low_buys.append(correct_low_buys[0])  
    Inovio_data_correct_low_buys.append(correct_low_buys[1])  
    Novavax_data_correct_low_buys.append(correct_low_buys[2])  

    Vaxart_data_correct_high_sells.append(correct_high_sells[0]) 
    Inovio_data_correct_high_sells.append(correct_high_sells[1]) 
    Novavax_data_correct_high_sells.append(correct_high_sells[2]) 

    Vaxart_data_correct_mid_holds.append(correct_mid_holds[0])  
    Inovio_data_correct_mid_holds.append(correct_mid_holds[1])  
    Novavax_data_correct_mid_holds.append(correct_mid_holds[2])   

    Vaxart_data_profit.append(profit[0]) 
    Inovio_data_profit.append(profit[1]) 
    Novavax_data_profit.append(profit[2])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(Vaxart_data_acc)
plt.plot(Inovio_data_acc)
plt.plot(Novavax_data_acc)

plt.title('Non-Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Vaxart_data_acc','Inovio_data_acc','Novavax_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_profit")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_profit")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_profit")
# Out:
# Text(0.5, 1.0, 'Novavax_data_profit')

# %%
Vaxart_data_acc = []
Inovio_data_acc = []
Novavax_data_acc = []

Vaxart_data_correct_buys = []
Inovio_data_correct_buys = []
Novavax_data_correct_buys = []

Vaxart_data_correct_sells = []
Inovio_data_correct_sells = []
Novavax_data_correct_sells = []

Vaxart_data_correct_holds = []
Inovio_data_correct_holds = []
Novavax_data_correct_holds = []

Vaxart_data_correct_low_buys = []
Inovio_data_correct_low_buys = []
Novavax_data_correct_low_buys = []

Vaxart_data_correct_high_sells = []
Inovio_data_correct_high_sells = []
Novavax_data_correct_high_sells = []

Vaxart_data_correct_mid_holds = []
Inovio_data_correct_mid_holds = []
Novavax_data_correct_mid_holds = []

Vaxart_data_profit = []
Inovio_data_profit = []
Novavax_data_profit = []

for key,value in r_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    Vaxart_data_acc.append(acc[0])
    Inovio_data_acc.append(acc[1])
    Novavax_data_acc.append(acc[2])
    
    Vaxart_data_correct_buys.append(correct_buys[0])
    Inovio_data_correct_buys.append(correct_buys[1]) 
    Novavax_data_correct_buys.append(correct_buys[2]) 

    Vaxart_data_correct_sells.append(correct_sells[0]) 
    Inovio_data_correct_sells.append(correct_sells[1]) 
    Novavax_data_correct_sells.append(correct_sells[2]) 

    Vaxart_data_correct_holds.append(correct_holds[0]) 
    Inovio_data_correct_holds.append(correct_holds[1])  
    Novavax_data_correct_holds.append(correct_holds[2])  

    Vaxart_data_correct_low_buys.append(correct_low_buys[0])  
    Inovio_data_correct_low_buys.append(correct_low_buys[1])  
    Novavax_data_correct_low_buys.append(correct_low_buys[2])  

    Vaxart_data_correct_high_sells.append(correct_high_sells[0]) 
    Inovio_data_correct_high_sells.append(correct_high_sells[1]) 
    Novavax_data_correct_high_sells.append(correct_high_sells[2]) 

    Vaxart_data_correct_mid_holds.append(correct_mid_holds[0])  
    Inovio_data_correct_mid_holds.append(correct_mid_holds[1])  
    Novavax_data_correct_mid_holds.append(correct_mid_holds[2])   

    Vaxart_data_profit.append(profit[0]) 
    Inovio_data_profit.append(profit[1]) 
    Novavax_data_profit.append(profit[2])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(Vaxart_data_acc)
plt.plot(Inovio_data_acc)
plt.plot(Novavax_data_acc)

plt.title('Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Vaxart_data_acc','Inovio_data_acc','Novavax_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_profit")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_profit")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_profit")
# Out:
# Text(0.5, 1.0, 'Novavax_data_profit')
