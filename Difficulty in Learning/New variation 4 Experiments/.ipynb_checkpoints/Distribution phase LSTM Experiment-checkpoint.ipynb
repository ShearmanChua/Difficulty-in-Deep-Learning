# %%
import os
seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
experiment = 'Distribution phase LSTM Experiment'

# %%
import requests
import lxml
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.utils import compute_class_weight
import tensorflow as tf
from pil import Image
from sklearn import preprocessing
import tensorflow_addons as tfa
import glob
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
import math

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
# gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
np.random.seed(seed)
tf.random.set_seed(seed)

session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, 
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), 
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)

# %% [markdown]
# ## Prepare Test Data

# %%
test_sets = ['accumulation phase data','mark up phase data','distribution phase data','mark down phase data','bull phase data','bear phase data','full cycle data']
test_data = {}

for name in test_sets:

    df = pd.read_csv("{}/test_data.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    labels = []
    data_15 = []
    sequential = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15.append(np.array(i[0:-1]))
            labels.append(i[-1])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_arr = min_max_scaler.fit_transform(data_15)
            sequential.append(data_15_arr)
            data_15 = data_15[1:15]
        else:
            data_15.append(np.array(i[0:-1]))
            count+= 1
            
    X = sequential
    X  = np.array(X).reshape(-1, 15, 4)
    y = labels
    y = np.array(y)
    print(X.shape)
    
    y = to_categorical(y, 3)
    
    test_data['{}_X'.format(name)] = X
    test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2004-06-14    93.010002  92.918784 -32.009897  48922600.0     2.0
# 2004-06-15    91.529999  92.705124 -68.734488  45879300.0     2.0
# 2004-06-16    90.209999  92.321259 -94.676024  40369000.0     2.0
# 2004-06-17    89.980003  91.961066 -87.983635  36219100.0     2.0
# 2004-06-18    89.339996  91.557824 -85.961924  32718400.0     2.0
# (248, 15, 4)
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22   115.589996  116.459043 -80.074504 -17684500.0     2.0
# 2020-01-23   116.099998  116.403805 -70.577262 -12758400.0     2.0
# 2020-01-24   115.809998  116.312450 -69.789236 -17063500.0     2.0
# 2020-01-27   114.370003  116.013612 -94.416205 -21446900.0     2.0
# 2020-01-28   115.860001  115.989979 -34.297465 -14428500.0     2.0
# (219, 15, 4)
#             previous_1d      EMA_12   willr_14        OBV_7  labels
# Date
# 2016-12-05   223.360001  213.378658 -16.514565 -283274800.0     2.0
# 2016-12-06   228.550003  215.712711  -2.667189 -278675500.0     2.0
# 2016-12-07   231.380005  218.123064  -4.633597 -273416200.0     2.0
# 2016-12-08   235.559998  220.805669  -1.742271 -266821000.0     2.0
# 2016-12-09   241.449997  223.981719  -2.918174 -259477300.0     2.0
# (470, 15, 4)
#             previous_1d      EMA_12   willr_14        OBV_7  labels
# Date
# 2007-10-01   216.740005  205.638670  -5.220429  161688200.0     2.0
# 2007-10-02   222.979996  208.306567  -1.526716  171593800.0     2.0
# 2007-10-03   228.020004  211.339403  -1.071898  181013600.0     2.0
# 2007-10-04   227.350006  213.802573  -7.282412  170892200.0     2.0
# 2007-10-05   225.949997  215.671407 -10.566735  160852300.0     2.0
# (278, 15, 4)
#             previous_1d       EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22  1075.300049  1097.577291 -89.711935   1200864.0     2.0
# 2020-01-23  1075.510010  1094.182325 -70.779503   4820868.0     2.0
# 2020-02-03  1052.800049  1087.815821 -81.895216   -525975.0     1.0
# 2020-02-04  1003.919983  1074.908769 -83.419991 -12870263.0     2.0
# 2020-02-05  1038.010010  1069.232037 -59.790669  -6607845.0     2.0
# (208, 15, 4)
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2018-01-22    32.830002  32.653718 -49.494874  128764966.0     2.0
# 2018-01-23    33.750000  32.822377 -18.518497  165063463.0     2.0
# 2018-01-24    33.970001  32.998934 -16.190425  201240854.0     2.0
# 2018-01-25    33.959999  33.146790 -17.627141  173336178.0     2.0
# 2018-01-26    34.880001  33.413438  -2.648942  221767625.0     0.0
# (595, 15, 4)
#             previous_1d    EMA_12   willr_14        OBV_7  labels
# Date
# 2002-11-11         8.74  8.763110 -71.929852 -553467352.0     2.0
# 2002-11-12         8.50  8.722632 -80.487816 -559735252.0     2.0
# 2002-11-13         8.63  8.708381 -69.918697 -552295352.0     2.0
# 2002-11-14         8.52  8.679399 -78.861762 -566378552.0     2.0
# 2002-11-15         8.80  8.697953 -56.097548 -558353452.0     2.0
# (917, 15, 4)

# %% [markdown]
# ## Train Accumulation Phase Stock Data

# %%
def pred_acc(actual, predictions, logger):

    hold = 0
    sell = 0
    buy = 0
    pred_hold = 0
    pred_sell = 0
    pred_buy = 0
    buy_buy = 0
    buy_sell = 0
    buy_hold = 0
    sell_buy = 0
    sell_sell = 0
    sell_hold = 0
    hold_buy = 0
    hold_sell = 0
    hold_hold = 0

    for i in range (0,len(actual)):
        if actual[i]==1 and predictions[i] == 1:
            buy_buy += 1
            buy += 1
            pred_buy += 1
        elif actual[i]==1 and predictions[i] == 0:
            buy_sell += 1
            buy += 1
            pred_sell += 1
        elif actual[i]==1 and predictions[i] == 2:
            buy_hold += 1
            buy += 1
            pred_hold += 1
        elif actual[i]==0 and predictions[i] == 1:
            sell_buy += 1
            sell += 1
            pred_buy += 1
        elif actual[i]==0 and predictions[i] == 0:
            sell_sell += 1
            sell += 1
            pred_sell += 1
        elif actual[i]==0 and predictions[i] == 2:
            sell_hold += 1
            sell += 1
            pred_hold += 1
        elif actual[i]==2 and predictions[i] == 1:
            hold_buy += 1
            hold += 1
            pred_buy += 1
        elif actual[i]==2 and predictions[i] == 0:
            hold_sell += 1
            hold += 1
            pred_sell += 1
        elif actual[i]==2 and predictions[i] == 2:
            hold_hold += 1
            hold += 1
            pred_hold += 1

    print("number of predictions: " + str(len(actual)))
    print("actual predicted buys: " + str(buy_buy) )
    print("actual buys but predicted sell: " + str(buy_sell) )
    print("actual buys but predicted hold: " + str(buy_hold))
    print("actual sells but predicted buy: " + str(sell_buy) )
    print("actual predicted sells: " + str(sell_sell))
    print("actual sells but predicted hold: " + str(sell_hold) )
    print("actual holds but predicted buy: " + str(hold_buy) )
    print("actual holds but predicted sell: " + str(hold_sell))
    print("actual predicted holds: " + str(hold_hold) )
    
    if pred_buy !=0:
        Percentage_buys_correct = 100*buy_buy/pred_buy
    else:
        Percentage_buys_correct = 0
        
    if pred_sell !=0:
        Percentage_sells_correct = 100*sell_sell/pred_sell
    else:
        Percentage_sells_correct = 0
        
    if pred_hold !=0:
        Percentage_holds_correct = 100*hold_hold/pred_hold
    else:
        Percentage_holds_correct = 0

    print("Percentage buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage holds correct: " + str(Percentage_holds_correct) + "%")

    print("actual buys: " + str(buy))
    print("actual sells: " + str(sell))
    print("actual holds: " + str(hold))
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def correct_maxima_minima(predictions, price, logger):
    correct_maxima = 0 
    correct_minima = 0
    correct_hold = 0

    hold = 0
    buy = 0
    sell = 0

#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):
        if i < 4:
            prices = price[i:i+9]
            prices.sort(key = float)
#             if i == 0:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1

        else:
            prices = price[i:i+5]
            prices = prices + price[i-4:i] 
            prices.sort(key = float)
#             if i == 10:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1
                    
    if buy !=0:
        Percentage_buys_correct = 100*correct_minima/buy
    else:
        Percentage_buys_correct = 0
        
    if sell !=0:
        Percentage_sells_correct = 100*correct_maxima/sell
    else:
        Percentage_sells_correct = 0
        
    if hold !=0:
        Percentage_holds_correct = 100*correct_hold/hold
    else:
        Percentage_holds_correct = 0

    print("Percentage low buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage high sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage mid holds correct: " + str(Percentage_holds_correct) + "%")
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %% [markdown]
# ### Creating Training Data and Model

# %%
labels = []
sequential = []

for filepath in glob.iglob('distribution phase data/*_acc_data.csv'):
    print(filepath)
    seed = 10
    df = pd.read_csv(filepath)
    df.set_index('Date', inplace=True)
    print(df.head())
    
    plt.figure(figsize=(15,5))
    plt.plot(df['previous_1d'].values)
    plt.plot(df['EMA_12'].values)
    plt.show()

    data_15 = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15.append(np.array(i[0:-1]))
            labels.append(i[-1])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_arr = min_max_scaler.fit_transform(data_15)
            sequential.append(data_15_arr)
            data_15 = data_15[1:15]
        else:
            data_15.append(np.array(i[0:-1]))
            count+= 1
# Out:
# distribution phase data\0_acc_data.csv
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2006-10-09    73.690002  71.134420 -19.770359  72131900.0     2.0
# 2006-10-10    74.919998  71.716816 -14.583357  74465400.0     2.0
# 2006-10-11    75.080002  72.234229 -12.622528  76502600.0     2.0
# 2006-10-12    75.500000  72.736656  -7.475494  78673900.0     2.0
# 2006-10-13    76.699997  73.346400  -0.000000  80474900.0     2.0
# distribution phase data\10_acc_data.csv
#             previous_1d    EMA_12   willr_14         OBV_7  labels
# Date
# 2009-09-07     5.523615  5.253749  -2.083310  2.905368e+10     2.0
# 2009-09-08     5.670780  5.317908  -1.587284  2.963190e+10     2.0
# 2009-09-09     5.778702  5.388799  -1.351401  3.022740e+10     2.0
# 2009-09-10     5.670780  5.432181 -17.333390  2.996536e+10     2.0
# 2009-09-11     5.798324  5.488511  -7.407383  3.040677e+10     2.0
# distribution phase data\11_acc_data.csv
#             previous_1d     EMA_12   willr_14         OBV_7  labels
# Date
# 2013-07-01    15.470000  15.294561 -17.605633  1.538258e+09     2.0
# 2013-07-02    15.740000  15.363090  -3.355718  1.574270e+09     2.0
# 2013-07-03    16.180000  15.488768  -1.570618  1.644546e+09     2.0
# 2013-07-05    16.430000  15.633573  -0.930254  1.682660e+09     2.0
# 2013-07-08    16.700001  15.797639  -1.639304  1.727389e+09     2.0
# distribution phase data\1_acc_data.csv
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2006-11-13    85.620003  82.836797 -14.766554  210361300.0     2.0
# 2006-11-14    85.690002  83.275752 -14.006514  213721400.0     2.0
# 2006-11-15    85.739998  83.654867 -13.463676  217184500.0     2.0
# 2006-11-16    87.080002  84.181810  -5.518761  223035400.0     2.0
# 2006-11-17    88.709999  84.878455  -6.976756  230002300.0     2.0
# distribution phase data\2_acc_data.csv
#             previous_1d     EMA_12   willr_14         OBV_7  labels
# Date
# 2017-05-22    28.480000  27.904435 -21.238934  1.403863e+10     2.0
# 2017-05-23    28.790001  28.040676  -7.870286  1.406287e+10     2.0
# 2017-05-24    29.230000  28.223649  -2.409692  1.409594e+10     2.0
# 2017-05-25    29.400000  28.404626  -5.109533  1.412556e+10     2.0
# 2017-05-26    29.340000  28.548530  -7.299293  1.410324e+10     2.0
# distribution phase data\3_acc_data.csv
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2014-11-17        10.24  10.065352  -0.000000  374065465.0     2.0
# 2014-11-18        10.19  10.084529  -8.333373  371334465.0     2.0
# 2014-11-19        10.26  10.111524  -6.060602  374567465.0     0.0
# 2014-11-20        10.50  10.171290  -0.000000  385737465.0     2.0
# 2014-11-21        10.35  10.198784 -24.590115  381908465.0     2.0
# distribution phase data\4_acc_data.csv
#             previous_1d     EMA_12   willr_14         OBV_7  labels
# Date
# 2017-09-25    71.400002  69.968115 -12.288727  1.293695e+09     2.0
# 2017-09-26    70.839996  70.102250 -20.890964  1.282932e+09     2.0
# 2017-09-27    70.940002  70.231135 -19.354771  1.294486e+09     2.0
# 2017-09-28    72.279999  70.546345  -9.718346  1.312578e+09     2.0
# 2017-09-29    72.650002  70.869985  -4.848481  1.326424e+09     2.0
# distribution phase data\5_acc_data.csv
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2009-08-03        13.50  13.432090 -36.956535  16473747.0     2.0
# 2009-08-04        13.74  13.479461 -11.363678  18073747.0     2.0
# 2009-08-05        13.54  13.488775 -36.585403  16633747.0     2.0
# 2009-08-06        13.54  13.496656 -36.585403  16633747.0     0.0
# 2009-08-07        13.84  13.549478  -0.000000  18804747.0     2.0
# distribution phase data\6_acc_data.csv
#             previous_1d      EMA_12  willr_14        OBV_7  labels
# Date
# 2009-07-20   156.839996  149.595381 -5.052762 -269164300.0     2.0
# 2009-07-21   160.029999  151.200707 -2.745086 -256730500.0     2.0
# 2009-07-22   159.800003  152.523675 -3.647030 -267617000.0     2.0
# 2009-07-23   160.460007  153.744650 -3.036100 -258117600.0     0.0
# 2009-07-24   165.449997  155.545472 -3.109975 -245825700.0     2.0
# distribution phase data\7_acc_data.csv
#             previous_1d      EMA_12  willr_14        OBV_7  labels
# Date
# 2014-09-15   183.169998  179.474733 -3.957823 -307548600.0     2.0
# 2014-09-16   183.979996  180.167851 -4.935352 -305240600.0     2.0
# 2014-09-17   184.039993  180.763565 -5.997744 -303103000.0     2.0
# 2014-09-18   184.820007  181.387633 -9.615349 -300282700.0     0.0
# 2014-09-19   187.889999  182.387997 -4.572340 -296716100.0     2.0
# distribution phase data\8_acc_data.csv
#             previous_1d     EMA_12   willr_14         OBV_7  labels
# Date
# 2010-11-01    16.059999  16.002080 -62.069028  9.662836e+09     2.0
# 2010-11-02    16.660000  16.103298 -10.344893  9.728221e+09     2.0
# 2010-11-03    16.879999  16.222791  -7.352971  9.772645e+09     2.0
# 2010-11-04    16.980000  16.339284 -12.820558  9.827731e+09     2.0
# 2010-11-05    17.000000  16.440933 -16.867503  9.878587e+09     2.0
# distribution phase data\9_acc_data.csv
#             previous_1d     EMA_12   willr_14         OBV_7  labels
# Date
# 2018-01-08        12.16  11.454592  -1.333364  9.131847e+09     2.0
# 2018-01-09        12.00  11.538501 -22.352950  9.055020e+09     2.0
# 2018-01-10        12.02  11.612578 -21.176453  9.134387e+09     2.0
# 2018-01-11        12.22  11.706027 -14.117635  9.225876e+09     2.0
# 2018-01-12        12.20  11.782023 -15.294133  9.141718e+09     2.0

# %%
X = sequential
X  = np.array(X).reshape(-1, 15, 4)
X.shape
# Out:
# (4020, 15, 4)

# %%
y = labels
y = np.array(y)
y.shape
# Out:
# (4020,)

# %%
from collections import Counter

Counter(y)
# Out:
# Counter({2.0: 3643, 0.0: 181, 1.0: 196})

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization,Activation
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(LSTM(100, input_shape=(X_train.shape[1:]), return_sequences=True,kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(LSTM(100, kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# model.add(Dense(100, kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))

model.add(Dense(75, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(50, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "LSTM_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))

epochs = 0 
histories = {}
log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['accumulation phase data','mark up phase data','distribution phase data','mark down phase data','bull phase data','bear phase data','full cycle data']
    
    for name in test_sets:
        
        print('\n')
        print(name)
        print('\n')
        
        X = test_data['{}_X'.format(name)]
        y = test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("{}/test_data.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(log)
        log.loc[df_length] = logger
        print(log.head(20))
        logger = []

    log.to_csv('{}_{}epochs.csv'.format(experiment,epochs))
    log_hist['{}_epochs_logs'.format(epochs)] = log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 2 ... 2 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  1/26 [>.............................] - ETA: 0s - loss: 0.2797 - accuracy: 0.5625 - mse: 0.3157 - weighted_accuracy: 0.3647 - weighted_mse: 0.4286WARNING:tensorflow:From C:\Users\Shearman Chua\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/26 [=>............................] - ETA: 1s - loss: 0.4038 - accuracy: 0.5000 - mse: 0.3520 - weighted_accuracy: 0.2399 - weighted_mse: 0.5253WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0120s vs `on_train_batch_end` time: 0.0947s). Check your callbacks.
# 26/26 [==============================] - 1s 39ms/step - loss: 0.3040 - accuracy: 0.5432 - mse: 0.4217 - weighted_accuracy: 0.2962 - weighted_mse: 0.5195 - val_loss: 0.3009 - val_accuracy: 0.0547 - val_mse: 0.3523 - val_weighted_accuracy: 0.0547 - val_weighted_mse: 0.3523
# Epoch 2/20
# 26/26 [==============================] - 0s 9ms/step - loss: 0.2192 - accuracy: 0.4173 - mse: 0.6956 - weighted_accuracy: 0.4243 - weighted_mse: 0.7010 - val_loss: 0.2943 - val_accuracy: 0.0485 - val_mse: 0.3771 - val_weighted_accuracy: 0.0485 - val_weighted_mse: 0.3771
# Epoch 3/20
# 26/26 [==============================] - 0s 7ms/step - loss: 0.1939 - accuracy: 0.3137 - mse: 0.9412 - weighted_accuracy: 0.4797 - weighted_mse: 0.9153 - val_loss: 0.2859 - val_accuracy: 0.0485 - val_mse: 0.4093 - val_weighted_accuracy: 0.0485 - val_weighted_mse: 0.4093
# Epoch 4/20
# 26/26 [==============================] - 0s 7ms/step - loss: 0.1836 - accuracy: 0.2811 - mse: 1.0923 - weighted_accuracy: 0.4936 - weighted_mse: 1.0564 - val_loss: 0.2771 - val_accuracy: 0.0485 - val_mse: 0.4463 - val_weighted_accuracy: 0.0485 - val_weighted_mse: 0.4463
# Epoch 5/20
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1773 - accuracy: 0.2743 - mse: 1.1923 - weighted_accuracy: 0.5281 - weighted_mse: 1.1527 - val_loss: 0.2693 - val_accuracy: 0.0485 - val_mse: 0.4912 - val_weighted_accuracy: 0.0485 - val_weighted_mse: 0.4912
# Epoch 6/20
# 26/26 [==============================] - 0s 7ms/step - loss: 0.1739 - accuracy: 0.2998 - mse: 1.2466 - weighted_accuracy: 0.5400 - weighted_mse: 1.2158 - val_loss: 0.2623 - val_accuracy: 0.0485 - val_mse: 0.5396 - val_weighted_accuracy: 0.0485 - val_weighted_mse: 0.5396
# Epoch 7/20
# 26/26 [==============================] - 0s 7ms/step - loss: 0.1711 - accuracy: 0.2631 - mse: 1.2868 - weighted_accuracy: 0.5639 - weighted_mse: 1.2427 - val_loss: 0.2564 - val_accuracy: 0.0485 - val_mse: 0.5907 - val_weighted_accuracy: 0.0485 - val_weighted_mse: 0.5907
# Epoch 8/20
# 26/26 [==============================] - 0s 7ms/step - loss: 0.1687 - accuracy: 0.2839 - mse: 1.2894 - weighted_accuracy: 0.5715 - weighted_mse: 1.2404 - val_loss: 0.2496 - val_accuracy: 0.0485 - val_mse: 0.6473 - val_weighted_accuracy: 0.0485 - val_weighted_mse: 0.6473
# Epoch 9/20
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1663 - accuracy: 0.3022 - mse: 1.3077 - weighted_accuracy: 0.5931 - weighted_mse: 1.2630 - val_loss: 0.2459 - val_accuracy: 0.0485 - val_mse: 0.7107 - val_weighted_accuracy: 0.0485 - val_weighted_mse: 0.7107
# Epoch 10/20
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1641 - accuracy: 0.2998 - mse: 1.3262 - weighted_accuracy: 0.6067 - weighted_mse: 1.2719 - val_loss: 0.2425 - val_accuracy: 0.0485 - val_mse: 0.7804 - val_weighted_accuracy: 0.0485 - val_weighted_mse: 0.7804
# Epoch 11/20
# 26/26 [==============================] - 0s 7ms/step - loss: 0.1619 - accuracy: 0.3106 - mse: 1.3374 - weighted_accuracy: 0.6027 - weighted_mse: 1.2793 - val_loss: 0.2388 - val_accuracy: 0.0485 - val_mse: 0.8544 - val_weighted_accuracy: 0.0485 - val_weighted_mse: 0.8544
# Epoch 12/20
# 26/26 [==============================] - 0s 7ms/step - loss: 0.1603 - accuracy: 0.3190 - mse: 1.3314 - weighted_accuracy: 0.6182 - weighted_mse: 1.2811 - val_loss: 0.2377 - val_accuracy: 0.0485 - val_mse: 0.9303 - val_weighted_accuracy: 0.0485 - val_weighted_mse: 0.9303
# Epoch 13/20
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1579 - accuracy: 0.3231 - mse: 1.3357 - weighted_accuracy: 0.6337 - weighted_mse: 1.2772 - val_loss: 0.2337 - val_accuracy: 0.0485 - val_mse: 1.0126 - val_weighted_accuracy: 0.0485 - val_weighted_mse: 1.0126
# Epoch 14/20
# 26/26 [==============================] - 0s 9ms/step - loss: 0.1563 - accuracy: 0.3405 - mse: 1.3545 - weighted_accuracy: 0.6361 - weighted_mse: 1.3034 - val_loss: 0.2284 - val_accuracy: 0.0498 - val_mse: 1.0740 - val_weighted_accuracy: 0.0498 - val_weighted_mse: 1.0740
# Epoch 15/20
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1561 - accuracy: 0.3349 - mse: 1.3790 - weighted_accuracy: 0.6319 - weighted_mse: 1.3176 - val_loss: 0.2260 - val_accuracy: 0.0597 - val_mse: 1.1465 - val_weighted_accuracy: 0.0597 - val_weighted_mse: 1.1465
# Epoch 16/20
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1544 - accuracy: 0.3368 - mse: 1.3705 - weighted_accuracy: 0.6463 - weighted_mse: 1.3075 - val_loss: 0.2245 - val_accuracy: 0.1082 - val_mse: 1.2152 - val_weighted_accuracy: 0.1082 - val_weighted_mse: 1.2152
# Epoch 17/20
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1524 - accuracy: 0.3451 - mse: 1.3860 - weighted_accuracy: 0.6559 - weighted_mse: 1.3213 - val_loss: 0.2167 - val_accuracy: 0.1754 - val_mse: 1.2698 - val_weighted_accuracy: 0.1754 - val_weighted_mse: 1.2698
# Epoch 18/20
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1508 - accuracy: 0.3424 - mse: 1.4373 - weighted_accuracy: 0.6554 - weighted_mse: 1.3665 - val_loss: 0.2101 - val_accuracy: 0.2512 - val_mse: 1.2599 - val_weighted_accuracy: 0.2512 - val_weighted_mse: 1.2599
# Epoch 19/20
# 26/26 [==============================] - 0s 7ms/step - loss: 0.1495 - accuracy: 0.3915 - mse: 1.4104 - weighted_accuracy: 0.6689 - weighted_mse: 1.3527 - val_loss: 0.2060 - val_accuracy: 0.2612 - val_mse: 1.3116 - val_weighted_accuracy: 0.2612 - val_weighted_mse: 1.3116
# Epoch 20/20
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1475 - accuracy: 0.3756 - mse: 1.4423 - weighted_accuracy: 0.6784 - weighted_mse: 1.3824 - val_loss: 0.2036 - val_accuracy: 0.2898 - val_mse: 1.3353 - val_weighted_accuracy: 0.2898 - val_weighted_mse: 1.3353
# Validation loss: 0.20364297926425934
# Validation accuracy: 0.2898010015487671
#
#
# accumulation phase data
#
#
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2001 - accuracy: 0.2863 - mse: 1.3263 - weighted_accuracy: 0.2863 - weighted_mse: 1.3263
# Test loss: 0.20010505616664886
# Test accuracy: 0.28629031777381897
#
#
# number of predictions: 248
# actual predicted buys: 6
# actual buys but predicted sell: 1
# actual buys but predicted hold: 4
# actual sells but predicted buy: 1
# actual predicted sells: 4
# actual sells but predicted hold: 3
# actual holds but predicted buy: 97
# actual holds but predicted sell: 71
# actual predicted holds: 61
# Percentage buys correct: 5.769230769230769%
# Percentage sells correct: 5.2631578947368425%
# Percentage holds correct: 89.70588235294117%
# actual buys: 11
# actual sells: 8
# actual holds: 229
#
#
# Percentage low buys correct: 42.30769230769231%
# Percentage high sells correct: 44.73684210526316%
# Percentage mid holds correct: 83.58208955223881%
#
#
# Capital: 100
# Share price: $0.23918784871632304
# Shares owned at the moment: 416
# Cash capital at the moment: $0.22422403507813726
#
#
# Price increase from previously bought: -51.28454918526906%
# Share price: $0.11684187275290302
# Shares owned at the moment: 0
# Cash capital at the moment: $48.69677599785647
#
#
# Share price: $0.17616112603390266
# Shares owned at the moment: 275
# Cash capital at the moment: $0.11924448697009637
#
#
# Price increase from previously bought: -11.722252606877426%
# Share price: $0.15593872929816288
# Shares owned at the moment: 0
# Cash capital at the moment: $42.88446637993315
#
#
# Share price: $0.16436474936653167
# Shares owned at the moment: 260
# Cash capital at the moment: $0.03211074883784448
#
#
# Price increase from previously bought: -42.19563209070857%
# Share price: $0.09527128194921651
# Shares owned at the moment: 0
# Cash capital at the moment: $24.734525089040446
#
#
# Share price: $0.35411862873517674
# Shares owned at the moment: 69
# Cash capital at the moment: $0.2331456965107499
#
#
# Price increase from previously bought: 7.1292180072272116%
# Share price: $0.3804077702058113
# Shares owned at the moment: 0
# Cash capital at the moment: $26.409099466315176
#
#
# Share price: $0.3338962319994365
# Shares owned at the moment: 78
# Cash capital at the moment: $0.29357262859524624
#
#
# Price increase from previously bought: 39.589066039164344%
# Share price: $0.46736435902539175
# Shares owned at the moment: 0
# Cash capital at the moment: $36.64774297756486
#
#
# Share price: $0.7228413492123498
# Shares owned at the moment: 50
# Cash capital at the moment: $0.40628483143066774
#
#
# Price increase from previously bought: -0.6927583636946233%
# Share price: $0.7198078482740391
# Shares owned at the moment: 0
# Cash capital at the moment: $36.29770366599494
#
#
# Share price: $0.6530739133319237
# Shares owned at the moment: 55
# Cash capital at the moment: $0.2798610033476834
#
#
# Price increase from previously bought: 24.995950419717737%
# Share price: $0.818560813760991
# Shares owned at the moment: 0
# Cash capital at the moment: $45.17689843712083
#
#
# Share price: $0.8188979265634091
# Shares owned at the moment: 55
# Cash capital at the moment: $0.01365416474061476
#
#
# Price increase from previously bought: 19.304195404880442%
# Share price: $0.9796662763255266
# Shares owned at the moment: 0
# Cash capital at the moment: $53.74712483835034
#
#
# Share price: $0.9358511262550444
# Shares owned at the moment: 57
# Cash capital at the moment: $0.2569159777723229
#
#
# Price increase from previously bought: -7.5651068364665175%
# Share price: $0.867431884442565
# Shares owned at the moment: 0
# Cash capital at the moment: $49.56456344311216
#
#
# Share price: $0.9247287180507835
# Shares owned at the moment: 53
# Cash capital at the moment: $0.4191621757647326
#
#
# Price increase from previously bought: -1.764509789973312%
# Share price: $0.9109099217106305
# Shares owned at the moment: 0
# Cash capital at the moment: $48.564622905338815
#
#
# Share price: $0.8017087736242534
# Shares owned at the moment: 60
# Cash capital at the moment: $0.32981454023560985
#
#
# Price increase from previously bought: 1.4446949337635573%
# Share price: $0.8155275699644069
# Shares owned at the moment: 0
# Cash capital at the moment: $49.12690668905589
#
#
# Share price: $0.7653083052148857
# Shares owned at the moment: 64
# Cash capital at the moment: $0.012480893585390618
#
#
# Price increase from previously bought: -16.216865284090932%
# Share price: $0.6429625863931914
# Shares owned at the moment: 0
# Cash capital at the moment: $41.04892500754443
#
#
#
#
# Capital at the end of test period: $41.04892500754443
# profit gained: -58.95107499245557%
#
#
# Capital at the end of test period if Buy and Hold: $182.55793694382942
# profit gained: 82.55793694382942%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0        0.28629      5.769231       5.263158      89.705882
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         42.307692           44.736842           83.58209     -58.951075
#
#    buy_n_hold profit
# 0          82.557937
#
#
# mark up phase data
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2009 - accuracy: 0.2968 - mse: 1.3753 - weighted_accuracy: 0.2968 - weighted_mse: 1.3753
# Test loss: 0.2008742094039917
# Test accuracy: 0.29680365324020386
#
#
# number of predictions: 219
# actual predicted buys: 6
# actual buys but predicted sell: 0
# actual buys but predicted hold: 1
# actual sells but predicted buy: 3
# actual predicted sells: 5
# actual sells but predicted hold: 3
# actual holds but predicted buy: 100
# actual holds but predicted sell: 47
# actual predicted holds: 54
# Percentage buys correct: 5.504587155963303%
# Percentage sells correct: 9.615384615384615%
# Percentage holds correct: 93.10344827586206%
# actual buys: 7
# actual sells: 11
# actual holds: 201
#
#
# Percentage low buys correct: 53.211009174311926%
# Percentage high sells correct: 50.0%
# Percentage mid holds correct: 89.47368421052632%
#
#
# Capital: 100
# Share price: $0.24286829602432447
# Shares owned at the moment: 410
# Cash capital at the moment: $0.15016462625953864
#
#
# Price increase from previously bought: 18.93391044098067%
# Share price: $0.2896471067777344
# Shares owned at the moment: 0
# Cash capital at the moment: $118.57890129223875
#
#
# Share price: $0.14028312979928814
# Shares owned at the moment: 842
# Cash capital at the moment: $0.13568041418788823
#
#
# Price increase from previously bought: 168.7697475276212%
# Share price: $0.37807546997330177
# Shares owned at the moment: 0
# Cash capital at the moment: $317.5997923809848
#
#
# Share price: $0.5122568861795547
# Shares owned at the moment: 618
# Cash capital at the moment: $0.15445614395787288
#
#
# Price increase from previously bought: -19.526478288278494%
# Share price: $0.41336479219992106
# Shares owned at the moment: 0
# Cash capital at the moment: $254.91138425916532
#
#
# Share price: $0.4396265697083235
# Shares owned at the moment: 578
# Cash capital at the moment: $0.10844053520295915
#
#
# Price increase from previously bought: -18.518403780563165%
# Share price: $0.3591998369557057
# Shares owned at the moment: 0
# Cash capital at the moment: $207.15499815475974
#
#
# Share price: $0.30277799553193563
# Shares owned at the moment: 682
# Cash capital at the moment: $0.09254507135949552
#
#
# Price increase from previously bought: 41.08277047520876%
# Share price: $0.4283422953430944
# Shares owned at the moment: 0
# Cash capital at the moment: $291.4186345204339
#
#
# Share price: $0.5785268159027048
# Shares owned at the moment: 502
# Cash capital at the moment: $0.19951666792240985
#
#
# Price increase from previously bought: 13.30672865941378%
# Share price: $0.6573124614929953
# Shares owned at the moment: 0
# Cash capital at the moment: $329.26295248431495
#
#
# Share price: $0.6796759525944329
# Shares owned at the moment: 483
# Cash capital at the moment: $0.07668779717027974
#
#
# Price increase from previously bought: 18.962021493596005%
# Share price: $0.8107797825074263
# Shares owned at the moment: 0
# Cash capital at the moment: $390.6064045021417
#
#
# Share price: $0.7919041494898293
# Shares owned at the moment: 491
# Cash capital at the moment: $0.7121985247867997
#
#
# Price increase from previously bought: 15.409052235643173%
# Share price: $0.9164423784931806
# Shares owned at the moment: 0
# Cash capital at the moment: $449.44798004337804
#
#
# Share price: $0.9139804346846059
# Shares owned at the moment: 490
# Cash capital at the moment: $0.36597841218360827
#
#
#
#
# Capital at the end of test period: $425.3292549471418
# profit gained: 325.3292549471418%
#
#
# Capital at the end of test period if Buy and Hold: $355.7316817269389
# profit gained: 255.73168172693892%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.286290      5.769231       5.263158      89.705882
# 1       0.296804      5.504587       9.615385      93.103448
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         42.307692           44.736842          83.582090     -58.951075
# 1         53.211009           50.000000          89.473684     325.329255
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
#
#
# distribution phase data
#
#
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2062 - accuracy: 0.2383 - mse: 1.3459 - weighted_accuracy: 0.2383 - weighted_mse: 1.3459
# Test loss: 0.2062406837940216
# Test accuracy: 0.23829787969589233
#
#
# number of predictions: 470
# actual predicted buys: 21
# actual buys but predicted sell: 1
# actual buys but predicted hold: 2
# actual sells but predicted buy: 11
# actual predicted sells: 7
# actual sells but predicted hold: 2
# actual holds but predicted buy: 244
# actual holds but predicted sell: 98
# actual predicted holds: 84
# Percentage buys correct: 7.608695652173913%
# Percentage sells correct: 6.60377358490566%
# Percentage holds correct: 95.45454545454545%
# actual buys: 24
# actual sells: 20
# actual holds: 426
#
#
# Percentage low buys correct: 40.72727272727273%
# Percentage high sells correct: 48.113207547169814%
# Percentage mid holds correct: 86.36363636363636%
#
#
# Capital: 100
# Share price: $0.5051713785101153
# Shares owned at the moment: 197
# Cash capital at the moment: $0.20756183919942828
#
#
# Price increase from previously bought: -3.3184311366461605%
# Share price: $0.48975073513123957
# Shares owned at the moment: 0
# Cash capital at the moment: $96.42313419929627
#
#
# Share price: $0.45470401282308415
# Shares owned at the moment: 211
# Cash capital at the moment: $0.21674549018491973
#
#
# Price increase from previously bought: 43.48728228755752%
# Share price: $0.6542366471360543
# Shares owned at the moment: 0
# Cash capital at the moment: $137.8810572213917
#
#
# Share price: $0.6880374729168433
# Shares owned at the moment: 199
# Cash capital at the moment: $0.5850716038861492
#
#
# Price increase from previously bought: -66.83033081638301%
# Share price: $0.22884735794830635
# Shares owned at the moment: 0
# Cash capital at the moment: $46.0004591189619
#
#
# Share price: $0.18289725845721816
# Shares owned at the moment: 250
# Cash capital at the moment: $0.15040263946801957
#
#
# Price increase from previously bought: 56.37455719753892%
# Share price: $0.2867912911785202
# Shares owned at the moment: 0
# Cash capital at the moment: $71.65105642141285
#
#
# Share price: $0.18133953128431446
# Shares owned at the moment: 394
# Cash capital at the moment: $0.00679971324639439
#
#
# Price increase from previously bought: 58.14616018548764%
# Share price: $0.28757015476497183
# Shares owned at the moment: 0
# Cash capital at the moment: $112.99785842795744
#
#
# Share price: $0.3310279858497338
# Shares owned at the moment: 340
# Cash capital at the moment: $0.13883207227843286
#
#
# Price increase from previously bought: 10.330928773919744%
# Share price: $0.3662306234806574
# Shares owned at the moment: 0
# Cash capital at the moment: $124.31481842274752
#
#
# Share price: $0.21202490271929686
# Shares owned at the moment: 584
# Cash capital at the moment: $0.1517632409109666
#
#
# Price increase from previously bought: -13.461516060093393%
# Share price: $0.18398771501340927
# Shares owned at the moment: 0
# Cash capital at the moment: $107.30510453843044
#
#
# Share price: $0.17791295932036122
# Shares owned at the moment: 601
# Cash capital at the moment: $0.08537034337662419
#
#
# Price increase from previously bought: 51.413335178859974%
# Share price: $0.27012475127227886
# Shares owned at the moment: 0
# Cash capital at the moment: $161.98389717535093
#
#
# Share price: $0.16031164050489966
# Shares owned at the moment: 1007
# Cash capital at the moment: $0.10613217644879569
#
#
# Price increase from previously bought: 77.43662219152283%
# Share price: $0.2852338016814133
# Shares owned at the moment: 0
# Cash capital at the moment: $286.5466867643258
#
#
# Share price: $0.527601318815462
# Shares owned at the moment: 541
# Cash capital at the moment: $0.32943442309311877
#
#
# Price increase from previously bought: 2.9054885227227434%
# Share price: $0.5444237740444724
# Shares owned at the moment: 0
# Cash capital at the moment: $294.052729711318
#
#
# Share price: $0.4528349303562387
# Shares owned at the moment: 647
# Cash capital at the moment: $0.26282322099524436
#
#
# Price increase from previously bought: -4.322028865989314%
# Share price: $0.4344547479543246
# Shares owned at the moment: 0
# Cash capital at the moment: $280.5820415371455
#
#
# Share price: $0.4138941277916215
# Shares owned at the moment: 676
# Cash capital at the moment: $0.020181966444795307
#
#
# Price increase from previously bought: 46.75131488736224%
# Share price: $0.6090654112314173
# Shares owned at the moment: 0
# Cash capital at the moment: $410.61614735940367
#
#
# Share price: $0.7199687408791926
# Shares owned at the moment: 568
# Cash capital at the moment: $0.5493113667689613
#
#
# Price increase from previously bought: 23.286071924761753%
# Share price: $0.8900621379603424
# Shares owned at the moment: 0
# Cash capital at the moment: $504.7143286687494
#
#
# Share price: $0.7564175127132773
# Shares owned at the moment: 665
# Cash capital at the moment: $0.3133841880455748
#
#
# Price increase from previously bought: 21.9659476870955%
# Share price: $0.9251088602684974
# Shares owned at the moment: 0
# Cash capital at the moment: $613.8189834383802
#
#
# Share price: $0.8501867941623023
# Shares owned at the moment: 720
# Cash capital at the moment: $0.0011217890811394682
#
#
# Price increase from previously bought: -24.300353279675434%
# Share price: $0.6453582677427361
# Shares owned at the moment: 0
# Cash capital at the moment: $463.3812651937205
#
#
# Share price: $0.7481620815836434
# Shares owned at the moment: 617
# Cash capital at the moment: $0.49581684468540743
#
#
# Price increase from previously bought: -7.810989313315497%
# Share price: $0.6916199602035646
# Shares owned at the moment: 0
# Cash capital at the moment: $426.05182612280936
#
#
# Share price: $0.7081308224628347
# Shares owned at the moment: 600
# Cash capital at the moment: $0.004916788044909026
#
#
# Price increase from previously bought: -37.56555600194357%
# Share price: $0.4433333650234397
# Shares owned at the moment: 0
# Cash capital at the moment: $265.27343574982
#
#
# Share price: $0.4433333650234397
# Shares owned at the moment: 596
# Cash capital at the moment: $0.32012681057653936
#
#
# Price increase from previously bought: -12.712817921605524%
# Share price: $0.38803737784652426
# Shares owned at the moment: 0
# Cash capital at the moment: $230.95441074481454
#
#
# Share price: $0.3980062137960345
# Shares owned at the moment: 578
# Cash capital at the moment: $0.27418829387778487
#
#
# Price increase from previously bought: -5.972380114272191%
# Share price: $0.37526491819674423
# Shares owned at the moment: 0
# Cash capital at the moment: $216.58082742412222
#
#
# Share price: $0.3642056256910424
# Shares owned at the moment: 593
# Cash capital at the moment: $0.012963065238380977
#
#
# Price increase from previously bought: -49.49305761384767%
# Share price: $0.18445498563012142
# Shares owned at the moment: 0
# Cash capital at the moment: $109.09396957608406
#
#
# Share price: $0.39286599933641075
# Shares owned at the moment: 276
# Cash capital at the moment: $0.36476846573835076
#
#
# Price increase from previously bought: 11.310768385426083%
# Share price: $0.4385047435335545
# Shares owned at the moment: 0
# Cash capital at the moment: $121.05925258065741
#
#
# Share price: $0.4562617399959883
# Shares owned at the moment: 264
# Cash capital at the moment: $0.2749071984794256
#
#
# Price increase from previously bought: 15.182333140157889%
# Share price: $0.5269781328759817
# Shares owned at the moment: 0
# Cash capital at the moment: $139.01454815327065
#
#
# Share price: $0.4047041554285624
# Shares owned at the moment: 342
# Cash capital at the moment: $0.22510273852174123
#
#
# Price increase from previously bought: 10.779907348750362%
# Share price: $0.44956379836345994
# Shares owned at the moment: 0
# Cash capital at the moment: $153.5531070264642
#
#
# Share price: $0.3168537143498191
# Shares owned at the moment: 483
# Cash capital at the moment: $0.09190204941640445
#
#
# Price increase from previously bought: -29.541894694426528%
# Share price: $0.22386305881144986
# Shares owned at the moment: 0
# Cash capital at the moment: $107.92041334748036
#
#
# Share price: $0.09894089763493573
# Shares owned at the moment: 1087
# Cash capital at the moment: $0.07589854004999097
#
#
# Price increase from previously bought: 157.6665230466736%
# Share price: $0.255638649126827
# Shares owned at the moment: 0
# Cash capital at the moment: $277.1909423090085
#
#
# Share price: $0.01
# Shares owned at the moment: 27643
# Cash capital at the moment: $0.000759809008513912
#
#
#
#
# Capital at the end of test period: $9082.507919925329
# profit gained: 8982.507919925329%
#
#
# Capital at the end of test period if Buy and Hold: $64.93475897926798
# profit gained: -35.06524102073202%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.286290      5.769231       5.263158      89.705882
# 1       0.296804      5.504587       9.615385      93.103448
# 2       0.238298      7.608696       6.603774      95.454545
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         42.307692           44.736842          83.582090     -58.951075
# 1         53.211009           50.000000          89.473684     325.329255
# 2         40.727273           48.113208          86.363636    8982.507920
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
#
#
# mark down phase data
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2121 - accuracy: 0.1871 - mse: 1.3839 - weighted_accuracy: 0.1871 - weighted_mse: 1.3839
# Test loss: 0.21206212043762207
# Test accuracy: 0.18705035746097565
#
#
# number of predictions: 278
# actual predicted buys: 14
# actual buys but predicted sell: 2
# actual buys but predicted hold: 0
# actual sells but predicted buy: 5
# actual predicted sells: 8
# actual sells but predicted hold: 0
# actual holds but predicted buy: 171
# actual holds but predicted sell: 48
# actual predicted holds: 30
# Percentage buys correct: 7.368421052631579%
# Percentage sells correct: 13.793103448275861%
# Percentage holds correct: 100.0%
# actual buys: 16
# actual sells: 13
# actual holds: 249
#
#
# Percentage low buys correct: 41.26984126984127%
# Percentage high sells correct: 51.724137931034484%
# Percentage mid holds correct: 90.0%
#
#
# Capital: 100
# Share price: $0.8557023478457203
# Shares owned at the moment: 116
# Cash capital at the moment: $0.4655586009336474
#
#
# Price increase from previously bought: 13.193107322016928%
# Share price: $0.9712597161656483
# Shares owned at the moment: 0
# Cash capital at the moment: $112.821853826692
#
#
# Share price: $0.8161453854507071
# Shares owned at the moment: 137
# Cash capital at the moment: $0.7024532459765709
#
#
# Price increase from previously bought: 3.9355865609639773%
# Share price: $0.8505982236657185
# Shares owned at the moment: 0
# Cash capital at the moment: $116.91394700741394
#
#
# Share price: $0.7650530525639275
# Shares owned at the moment: 152
# Cash capital at the moment: $0.30609084172522216
#
#
# Price increase from previously bought: -15.05786576712559%
# Share price: $0.6516394849364239
# Shares owned at the moment: 0
# Cash capital at the moment: $99.08290724735822
#
#
# Share price: $0.6674112099607681
# Shares owned at the moment: 148
# Cash capital at the moment: $0.03441181071050892
#
#
# Price increase from previously bought: -3.4011859652051224%
# Share price: $0.6464842696696596
# Shares owned at the moment: 0
# Cash capital at the moment: $95.45096462406457
#
#
# Share price: $0.5871743716205212
# Shares owned at the moment: 162
# Cash capital at the moment: $0.06713023898319648
#
#
# Price increase from previously bought: -7.400041275839975%
# Share price: $0.5452184646302871
# Shares owned at the moment: 0
# Cash capital at the moment: $88.14962668309691
#
#
# Share price: $0.5154103981109383
# Shares owned at the moment: 170
# Cash capital at the moment: $0.28890464312054576
#
#
# Price increase from previously bought: 15.00372700451642%
# Share price: $0.5943712054061847
# Shares owned at the moment: 0
# Cash capital at the moment: $101.05414102364455
#
#
# Share price: $0.5839587484646389
# Shares owned at the moment: 172
# Cash capital at the moment: $0.33702379970287666
#
#
# Price increase from previously bought: 20.941919978876978%
# Share price: $0.7081931123140189
# Shares owned at the moment: 0
# Cash capital at the moment: $121.8112637755896
#
#
# Share price: $0.7249857244805669
# Shares owned at the moment: 167
# Cash capital at the moment: $0.40569809336722074
#
#
# Price increase from previously bought: -14.13370793107015%
# Share price: $0.624230285129542
# Shares owned at the moment: 0
# Cash capital at the moment: $104.365477951555
#
#
# Share price: $0.6230053451713043
# Shares owned at the moment: 167
# Cash capital at the moment: $0.037470103177241754
#
#
# Price increase from previously bought: -2.4475425364798298%
# Share price: $0.6094283561606388
# Shares owned at the moment: 0
# Cash capital at the moment: $101.53212560943716
#
#
# Share price: $0.5980461810464062
# Shares owned at the moment: 169
# Cash capital at the moment: $0.18437904995319343
#
#
# Price increase from previously bought: 12.39049971144257%
# Share price: $0.6739954958845584
# Shares owned at the moment: 0
# Cash capital at the moment: $113.77637844773122
#
#
# Share price: $0.657151870514002
# Shares owned at the moment: 172
# Cash capital at the moment: $0.4354238845697438
#
#
# Price increase from previously bought: 1.2671603284209354%
# Share price: $0.6673091056699969
# Shares owned at the moment: 0
# Cash capital at the moment: $114.8969528528273
#
#
# Share price: $0.6610310547357661
# Shares owned at the moment: 173
# Cash capital at the moment: $0.22409485924922024
#
#
# Price increase from previously bought: -18.80883315219124%
# Share price: $0.5381747483394034
# Shares owned at the moment: 0
# Cash capital at the moment: $93.07228968544352
#
#
# Share price: $0.5489444534745171
# Shares owned at the moment: 169
# Cash capital at the moment: $0.045555113497840694
#
#
# Price increase from previously bought: -18.44847618294687%
# Share price: $0.44890366627613654
# Shares owned at the moment: 0
# Cash capital at the moment: $75.70164673526308
#
#
# Share price: $0.3979134376801282
# Shares owned at the moment: 189
# Cash capital at the moment: $0.28919150448460584
#
#
#
#
# Capital at the end of test period: $3.4342501735629734
# profit gained: -96.56574982643703%
#
#
# Capital at the end of test period if Buy and Hold: $2.3958591597330687
# profit gained: -97.60414084026694%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.286290      5.769231       5.263158      89.705882
# 1       0.296804      5.504587       9.615385      93.103448
# 2       0.238298      7.608696       6.603774      95.454545
# 3       0.187050      7.368421      13.793103     100.000000
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         42.307692           44.736842          83.582090     -58.951075
# 1         53.211009           50.000000          89.473684     325.329255
# 2         40.727273           48.113208          86.363636    8982.507920
# 3         41.269841           51.724138          90.000000     -96.565750
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
#
#
# bull phase data
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1849 - accuracy: 0.4375 - mse: 1.2760 - weighted_accuracy: 0.4375 - weighted_mse: 1.2760
# Test loss: 0.18487748503684998
# Test accuracy: 0.4375
#
#
# number of predictions: 208
# actual predicted buys: 5
# actual buys but predicted sell: 0
# actual buys but predicted hold: 4
# actual sells but predicted buy: 4
# actual predicted sells: 3
# actual sells but predicted hold: 3
# actual holds but predicted buy: 53
# actual holds but predicted sell: 53
# actual predicted holds: 83
# Percentage buys correct: 8.064516129032258%
# Percentage sells correct: 5.357142857142857%
# Percentage holds correct: 92.22222222222223%
# actual buys: 9
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 45.16129032258065%
# Percentage high sells correct: 46.42857142857143%
# Percentage mid holds correct: 86.51685393258427%
#
#
# Capital: 100
# Share price: $0.12558233818043063
# Shares owned at the moment: 794
# Cash capital at the moment: $0.013414449321103916
#
#
# Price increase from previously bought: 53.6093028986498%
# Share price: $0.1934366461669521
# Shares owned at the moment: 0
# Cash capital at the moment: $153.1797425889755
#
#
# Share price: $0.02378936423929944
# Shares owned at the moment: 6421
# Cash capital at the moment: $0.008168162037293314
#
#
# Price increase from previously bought: 731.430543283228%
# Share price: $0.19833596844936396
# Shares owned at the moment: 0
# Cash capital at the moment: $1270.0212546285165
#
#
# Share price: $0.4790917876756311
# Shares owned at the moment: 2643
# Cash capital at the moment: $0.29950091604996487
#
#
# Price increase from previously bought: 13.91945848033458%
# Share price: $0.5472796617617288
# Shares owned at the moment: 0
# Cash capital at the moment: $1442.7818815506994
#
#
# Share price: $0.7828490672363122
# Shares owned at the moment: 1837
# Cash capital at the moment: $0.7333872621827595
#
#
# Price increase from previously bought: 5.146467361674589%
# Share price: $0.8254017688549782
# Shares owned at the moment: 0
# Cash capital at the moment: $1512.8267132629646
#
#
# Share price: $0.8263218834242638
# Shares owned at the moment: 1825
# Cash capital at the moment: $0.642173061247604
#
#
# Price increase from previously bought: -1.6344738809274117%
# Share price: $0.8150511117044918
# Shares owned at the moment: 0
# Cash capital at the moment: $1484.0199141550784
#
#
# Share price: $0.7540972418182945
# Shares owned at the moment: 1962
# Cash capital at the moment: $0.4123940393540124
#
#
# Price increase from previously bought: 31.208727148302607%
# Share price: $0.9921623562794799
# Shares owned at the moment: 0
# Cash capital at the moment: $1941.6817250663876
#
#
#
#
# Capital at the end of test period: $1941.6817250663876
# profit gained: 1841.6817250663876%
#
#
# Capital at the end of test period if Buy and Hold: $778.7940878989605
# profit gained: 678.7940878989605%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.286290      5.769231       5.263158      89.705882
# 1       0.296804      5.504587       9.615385      93.103448
# 2       0.238298      7.608696       6.603774      95.454545
# 3       0.187050      7.368421      13.793103     100.000000
# 4       0.437500      8.064516       5.357143      92.222222
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         42.307692           44.736842          83.582090     -58.951075
# 1         53.211009           50.000000          89.473684     325.329255
# 2         40.727273           48.113208          86.363636    8982.507920
# 3         41.269841           51.724138          90.000000     -96.565750
# 4         45.161290           46.428571          86.516854    1841.681725
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
#
#
# bear phase data
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2087 - accuracy: 0.2420 - mse: 1.3506 - weighted_accuracy: 0.2420 - weighted_mse: 1.3506
# Test loss: 0.20871026813983917
# Test accuracy: 0.24201680719852448
#
#
# number of predictions: 595
# actual predicted buys: 25
# actual buys but predicted sell: 1
# actual buys but predicted hold: 6
# actual sells but predicted buy: 7
# actual predicted sells: 15
# actual sells but predicted hold: 5
# actual holds but predicted buy: 264
# actual holds but predicted sell: 168
# actual predicted holds: 104
# Percentage buys correct: 8.445945945945946%
# Percentage sells correct: 8.152173913043478%
# Percentage holds correct: 90.43478260869566%
# actual buys: 32
# actual sells: 27
# actual holds: 536
#
#
# Percentage low buys correct: 48.986486486486484%
# Percentage high sells correct: 53.26086956521739%
# Percentage mid holds correct: 81.57894736842105%
#
#
# Capital: 100
# Share price: $0.7488095723945759
# Shares owned at the moment: 133
# Cash capital at the moment: $0.1344497704180867
#
#
# Price increase from previously bought: 20.557502806529683%
# Share price: $0.9052286730886053
# Shares owned at the moment: 0
# Cash capital at the moment: $120.19877590402044
#
#
# Share price: $0.9229365241315254
# Shares owned at the moment: 129
# Cash capital at the moment: $0.8125525591179894
#
#
# Price increase from previously bought: -8.671835707909414%
# Share price: $0.8452189627794938
# Shares owned at the moment: 0
# Cash capital at the moment: $109.54595733062666
#
#
# Share price: $0.7955385820603212
# Shares owned at the moment: 137
# Cash capital at the moment: $0.2574524275714225
#
#
# Price increase from previously bought: -2.0624128178505785%
# Share price: $0.7812739034269881
# Shares owned at the moment: 0
# Cash capital at the moment: $106.99763225395267
#
#
# Share price: $0.8889966013918106
# Shares owned at the moment: 120
# Cash capital at the moment: $0.024671208476092943
#
#
# Price increase from previously bought: 5.9609300160388345%
# Share price: $0.9445795365790158
# Shares owned at the moment: 0
# Cash capital at the moment: $113.06250435088693
#
#
# Share price: $0.9032612800251435
# Shares owned at the moment: 124
# Cash capital at the moment: $0.7500935312805552
#
#
# Price increase from previously bought: -3.0439191838355306%
# Share price: $0.8781750951680661
# Shares owned at the moment: 0
# Cash capital at the moment: $109.34434762466843
#
#
# Share price: $0.7783227200123838
# Shares owned at the moment: 140
# Cash capital at the moment: $0.07951257572993597
#
#
# Price increase from previously bought: -14.454785597992748%
# Share price: $0.6676488386329572
# Shares owned at the moment: 0
# Cash capital at the moment: $93.29330518147025
#
#
# Share price: $0.604195768275435
# Shares owned at the moment: 153
# Cash capital at the moment: $0.5971372658268024
#
#
# Price increase from previously bought: -1.8979981408089985%
# Share price: $0.5943581462222441
# Shares owned at the moment: 0
# Cash capital at the moment: $91.28385744780715
#
#
# Share price: $0.5554992717268165
# Shares owned at the moment: 163
# Cash capital at the moment: $0.48847360778452753
#
#
# Price increase from previously bought: 15.355785094290319%
# Share price: $0.6425627475952914
# Shares owned at the moment: 0
# Cash capital at the moment: $104.93817271420744
#
#
# Share price: $0.5097540524122143
# Shares owned at the moment: 205
# Cash capital at the moment: $0.15121812265611823
#
#
# Price increase from previously bought: 5.7882374177608%
# Share price: $0.5407427917373245
# Shares owned at the moment: 0
# Cash capital at the moment: $110.69864667996573
#
#
# Share price: $0.5068027751781982
# Shares owned at the moment: 217
# Cash capital at the moment: $0.4200099102091457
#
#
# Price increase from previously bought: 5.629956583727025%
# Share price: $0.5368077241521655
# Shares owned at the moment: 0
# Cash capital at the moment: $116.58694604184124
#
#
# Share price: $0.5131972248218016
# Shares owned at the moment: 226
# Cash capital at the moment: $0.28542115688732395
#
#
# Price increase from previously bought: -22.92766720223989%
# Share price: $0.39662078897434283
# Shares owned at the moment: 0
# Cash capital at the moment: $89.67521964474125
#
#
# Share price: $0.39022624551132734
# Shares owned at the moment: 229
# Cash capital at the moment: $0.06766444453651843
#
#
# Price increase from previously bought: 3.2455103001292063%
# Share price: $0.4039990289690888
# Shares owned at the moment: 0
# Cash capital at the moment: $92.32902368996456
#
#
# Share price: $0.4138367448416912
# Shares owned at the moment: 222
# Cash capital at the moment: $0.2046190023832537
#
#
# Price increase from previously bought: -0.9854627659907522%
# Share price: $0.41088537378826373
# Shares owned at the moment: 0
# Cash capital at the moment: $91.17032646268007
#
#
# Share price: $0.5028677075930398
# Shares owned at the moment: 180
# Cash capital at the moment: $0.4052195806743413
#
#
# Price increase from previously bought: -8.468238466294832%
# Share price: $0.4615494510391672
# Shares owned at the moment: 0
# Cash capital at the moment: $83.25565378946006
#
#
# Share price: $0.4394146372355171
# Shares owned at the moment: 188
# Cash capital at the moment: $0.4185246217320753
#
#
# Price increase from previously bought: 7.540123736091209%
# Share price: $0.4738465489702147
# Shares owned at the moment: 0
# Cash capital at the moment: $89.25669716231485
#
#
# Share price: $0.5717314372430228
# Shares owned at the moment: 155
# Cash capital at the moment: $0.3946238645214777
#
#
# Price increase from previously bought: -20.694196242831953%
# Share price: $0.4546631062199925
# Shares owned at the moment: 0
# Cash capital at the moment: $70.67360517959405
#
#
# Share price: $0.32234630621248683
# Shares owned at the moment: 218
# Cash capital at the moment: $0.2088638146975228
#
#
# Price increase from previously bought: 14.182522071295868%
# Share price: $0.3690753158782317
# Shares owned at the moment: 0
# Cash capital at the moment: $80.44602202428304
#
#
# Share price: $0.3818642151654389
# Shares owned at the moment: 210
# Cash capital at the moment: $0.034010255282836965
#
#
# Price increase from previously bought: 9.10320321504543%
# Share price: $0.41777181242685024
# Shares owned at the moment: 0
# Cash capital at the moment: $87.52482764324488
#
#
# Share price: $0.36415645794192997
# Shares owned at the moment: 239
# Cash capital at the moment: $0.252092363141287
#
#
# Price increase from previously bought: 1.8810232868889498%
# Share price: $0.37202659311224806
# Shares owned at the moment: 0
# Cash capital at the moment: $88.92193363864554
#
#
# Share price: $0.3356271944946768
# Shares owned at the moment: 264
# Cash capital at the moment: $0.07268894884772692
#
#
# Price increase from previously bought: 27.348985070691214%
# Share price: $0.4285932248311838
# Shares owned at the moment: 0
# Cash capital at the moment: $112.91014162305281
#
#
# Share price: $0.3449729213722966
# Shares owned at the moment: 326
# Cash capital at the moment: $0.1397010316738374
#
#
# Price increase from previously bought: 1.5743070042313567%
# Share price: $0.35136746483531167
# Shares owned at the moment: 0
# Cash capital at the moment: $114.37049363576058
#
#
# Share price: $0.3134923806910269
# Shares owned at the moment: 363
# Cash capital at the moment: $0.2598156758929804
#
#
# Price increase from previously bought: 1.9163845482582875%
# Share price: $0.32037872551020186
# Shares owned at the moment: 0
# Cash capital at the moment: $116.23747497335569
#
#
# Share price: $0.31939502897847094
# Shares owned at the moment: 362
# Cash capital at the moment: $0.29851673180112925
#
#
# Price increase from previously bought: 0.8008271550863144%
# Share price: $0.3228382013880583
# Shares owned at the moment: 0
# Cash capital at the moment: $116.84456020479641
#
#
# Share price: $0.31595176274947157
# Shares owned at the moment: 368
# Cash capital at the moment: $0.2545683290884
#
#
# Price increase from previously bought: 9.19639659118252%
# Share price: $0.3459567117234391
# Shares owned at the moment: 0
# Cash capital at the moment: $127.21653005104986
#
#
# Share price: $0.34890798895745523
# Shares owned at the moment: 363
# Cash capital at the moment: $0.2146326595168233
#
#
# Price increase from previously bought: 19.6897470620774%
# Share price: $0.41875550895858116
# Shares owned at the moment: 0
# Cash capital at the moment: $151.80485972466386
#
#
# Share price: $0.28643880277048706
# Shares owned at the moment: 528
# Cash capital at the moment: $0.1492627202239305
#
#
# Price increase from previously bought: -16.714547566019313%
# Share price: $0.23921789792917092
# Shares owned at the moment: 0
# Cash capital at the moment: $126.10896843903302
#
#
# Share price: $0.33021644138280426
# Shares owned at the moment: 380
# Cash capital at the moment: $0.28164453232237463
#
#
# Price increase from previously bought: -44.39344373888483%
# Share price: $0.18412695173694915
# Shares owned at the moment: 0
# Cash capital at the moment: $70.05747352779794
#
#
# Share price: $0.12510084414015665
# Shares owned at the moment: 558
# Cash capital at the moment: $0.05923525225745152
#
#
# Price increase from previously bought: 12.273314038166628%
# Share price: $0.14084111448079162
# Shares owned at the moment: 0
# Cash capital at the moment: $78.43245644236839
#
#
# Share price: $0.08476637793742735
# Shares owned at the moment: 922
# Cash capital at the moment: $0.06293083280003486
#
#
# Price increase from previously bought: -16.477618562667264%
# Share price: $0.07099359447966579
# Shares owned at the moment: 0
# Cash capital at the moment: $65.3390206842487
#
#
# Share price: $0.07099359447966579
# Shares owned at the moment: 917
# Cash capital at the moment: $0.058866449516074226
#
#
# Price increase from previously bought: -7.87467910933739%
# Share price: $0.06558293518720491
# Shares owned at the moment: 0
# Cash capital at the moment: $60.033034249374644
#
#
# Share price: $0.022788993106618742
# Shares owned at the moment: 2627
# Cash capital at the moment: $0.0017159748367134853
#
#
# Price increase from previously bought: 540.005362549048%
# Share price: $0.1462518675926644
# Shares owned at the moment: 0
# Cash capital at the moment: $383.14881208630976
#
#
#
#
# Capital at the end of test period: $383.14881208630976
# profit gained: 283.14881208630976%
#
#
# Capital at the end of test period if Buy and Hold: $8.115342010843221
# profit gained: -91.88465798915678%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.286290      5.769231       5.263158      89.705882
# 1       0.296804      5.504587       9.615385      93.103448
# 2       0.238298      7.608696       6.603774      95.454545
# 3       0.187050      7.368421      13.793103     100.000000
# 4       0.437500      8.064516       5.357143      92.222222
# 5       0.242017      8.445946       8.152174      90.434783
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         42.307692           44.736842          83.582090     -58.951075
# 1         53.211009           50.000000          89.473684     325.329255
# 2         40.727273           48.113208          86.363636    8982.507920
# 3         41.269841           51.724138          90.000000     -96.565750
# 4         45.161290           46.428571          86.516854    1841.681725
# 5         48.986486           53.260870          81.578947     283.148812
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
# 5         -91.884658
#
#
# full cycle data
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2083 - accuracy: 0.2661 - mse: 1.3871 - weighted_accuracy: 0.2661 - weighted_mse: 1.3871
# Test loss: 0.20827282965183258
# Test accuracy: 0.26608505845069885
#
#
# number of predictions: 917
# actual predicted buys: 29
# actual buys but predicted sell: 4
# actual buys but predicted hold: 13
# actual sells but predicted buy: 11
# actual predicted sells: 21
# actual sells but predicted hold: 8
# actual holds but predicted buy: 413
# actual holds but predicted sell: 224
# actual predicted holds: 194
# Percentage buys correct: 6.401766004415011%
# Percentage sells correct: 8.433734939759036%
# Percentage holds correct: 90.23255813953489%
# actual buys: 46
# actual sells: 40
# actual holds: 831
#
#
# Percentage low buys correct: 45.575221238938056%
# Percentage high sells correct: 48.59437751004016%
# Percentage mid holds correct: 80.93023255813954%
#
#
# Capital: 100
# Share price: $0.3243904423829288
# Shares owned at the moment: 307
# Cash capital at the moment: $0.1382675574590735
#
#
# Price increase from previously bought: 4.234275045881231%
# Share price: $0.33905587250729685
# Shares owned at the moment: 0
# Cash capital at the moment: $103.94217249683491
#
#
# Share price: $0.32255730732381205
# Shares owned at the moment: 321
# Cash capital at the moment: $0.11653938285114407
#
#
# Price increase from previously bought: 25.230324197760613%
# Share price: $0.40505039547981114
# Shares owned at the moment: 0
# Cash capital at the moment: $129.78015809526073
#
#
# Share price: $0.3601374938707197
# Shares owned at the moment: 359
# Cash capital at the moment: $0.13525205484847902
#
#
# Price increase from previously bought: -26.16320522493707%
# Share price: $0.26664524570858594
# Shares owned at the moment: 0
# Cash capital at the moment: $95.59764974540504
#
#
# Share price: $0.24464710052203398
# Shares owned at the moment: 389
# Cash capital at the moment: $0.1682164065503713
#
#
# Price increase from previously bought: 2.341157308011854%
# Share price: $0.25106320434823026
# Shares owned at the moment: 0
# Cash capital at the moment: $97.56322803516042
#
#
# Share price: $0.2162327640964269
# Shares owned at the moment: 449
# Cash capital at the moment: $0.207723550396679
#
#
# Price increase from previously bought: -37.89701644279112%
# Share price: $0.13465628717641553
# Shares owned at the moment: 0
# Cash capital at the moment: $60.50212964201617
#
#
# Share price: $0.13740603347152003
# Shares owned at the moment: 439
# Cash capital at the moment: $0.014997514110383747
#
#
# ...
# Price increase from previously bought: 3.33660714045112%
# Share price: $0.8886557847746166
# Shares owned at the moment: 0
# Cash capital at the moment: $257.22105733862793
#
#
# Share price: $0.8139010386877712
# Shares owned at the moment: 315
# Cash capital at the moment: $0.13718837721671662
#
#
# Price increase from previously bought: -0.1333295534570178%
# Share price: $0.8150511117044918
# Shares owned at the moment: 0
# Cash capital at the moment: $256.1722505386176
#
#
# Share price: $0.7540972418182945
# Shares owned at the moment: 338
# Cash capital at the moment: $0.5864494177639585
#
#
# Price increase from previously bought: 8.489274702285066%
# Share price: $0.8203644434261506
# Shares owned at the moment: 0
# Cash capital at the moment: $277.1071025456382
#
#
# Share price: $0.8123484681931528
# Shares owned at the moment: 340
# Cash capital at the moment: $0.14907754220564584
#
#
# Price increase from previously bought: 5.846146118705398%
# Share price: $0.8622041053900407
# Shares owned at the moment: 0
# Cash capital at the moment: $292.49231253627977
#
#
#
#
# Capital at the end of test period: $292.49231253627977
# profit gained: 192.49231253627977%
#
#
# Capital at the end of test period if Buy and Hold: $778.7940878989605
# profit gained: 678.7940878989605%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.778226      3.571429       0.000000      91.866029
# 1       0.735160      7.407407       9.090909      92.352941
# 2       0.793617     16.071429       0.000000      91.919192
# 3       0.744604      9.756098      15.384615      89.732143
# 4       0.769231     12.500000       9.523810      91.228070
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         50.000000           27.272727          81.730769     -17.086113
# 1         37.037037           59.090909          85.798817      56.166488
# 2         55.357143           38.888889          85.822785     -62.105153
# 3         53.658537           30.769231          83.856502     -96.992902
# 4         50.000000           52.380952          85.294118     192.492313
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
#
#
# bear phase data
#
#
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1808 - accuracy: 0.8067 - mse: 8.3892 - weighted_accuracy: 0.8067 - weighted_mse: 8.3892
# Test loss: 0.1808256059885025
# Test accuracy: 0.8067227005958557
#
#
# number of predictions: 595
# actual predicted buys: 10
# actual buys but predicted sell: 2
# actual buys but predicted hold: 20
# actual sells but predicted buy: 0
# actual predicted sells: 4
# actual sells but predicted hold: 23
# actual holds but predicted buy: 40
# actual holds but predicted sell: 30
# actual predicted holds: 466
# Percentage buys correct: 20.0%
# Percentage sells correct: 11.11111111111111%
# Percentage holds correct: 91.55206286836935%
# actual buys: 32
# actual sells: 27
# actual holds: 536
#
#
# Percentage low buys correct: 50.0%
# Percentage high sells correct: 52.77777777777778%
# Percentage mid holds correct: 84.05511811023622%
#
#
# Capital: 100
# Share price: $0.7488095723945759
# Shares owned at the moment: 133
# Cash capital at the moment: $0.1344497704180867
#
#
# Price increase from previously bought: 34.51084952837831%
# Share price: $1.0099999999999998
# Shares owned at the moment: 0
# Cash capital at the moment: $134.09504227041808
#
#
# Share price: $0.851121517247526
# Shares owned at the moment: 157
# Cash capital at the moment: $0.10149234748487856
#
#
# Price increase from previously bought: -0.5047868988614423%
# Share price: $0.8491539365452413
# Shares owned at the moment: 0
# Cash capital at the moment: $133.05203817298437
#
#
# Share price: $0.716345335181576
# Shares owned at the moment: 185
# Cash capital at the moment: $0.16371047511918846
#
#
# Price increase from previously bought: 26.08957113707109%
# Share price: $0.9057206620835884
# Shares owned at the moment: 0
# Cash capital at the moment: $167.26124757374802
#
#
# Share price: $0.8889966013918106
# Shares owned at the moment: 187
# Cash capital at the moment: $0.5617166112136829
#
#
# Price increase from previously bought: -1.2674604197018158%
# Share price: $0.8801426758703509
# Shares owned at the moment: 0
# Cash capital at the moment: $164.69578362790298
#
#
# Share price: $0.7325775006977818
# Shares owned at the moment: 224
# Cash capital at the moment: $0.14715573117001668
#
#
# Price increase from previously bought: -23.107653755492652%
# Share price: $0.5648450924238478
# Shares owned at the moment: 0
# Cash capital at the moment: $126.32451185717885
#
#
# Share price: $0.5122135282900707
# Shares owned at the moment: 245
# Cash capital at the moment: $0.48709356142607874
#
#
# Price increase from previously bought: -2.2853763295818452%
# Share price: $0.5018839172418968
# Shares owned at the moment: 0
# Cash capital at the moment: $123.11050899644908
#
#
# Share price: $0.4581062786295801
# Shares owned at the moment: 268
# Cash capital at the moment: $0.00040199637162174895
#
#
# Price increase from previously bought: -14.94405759551245%
# Share price: $0.3907181406868988
# Shares owned at the moment: 0
# Cash capital at the moment: $104.42490443077425
#
#
# Share price: $0.5850123255252128
# Shares owned at the moment: 178
# Cash capital at the moment: $0.006346953941772426
#
#
# Price increase from previously bought: -5.305270675366536%
# Share price: $0.5554992717268165
# Shares owned at the moment: 0
# Cash capital at the moment: $98.61330042780482
#
#
# Share price: $0.45909006898072235
# Shares owned at the moment: 214
# Cash capital at the moment: $0.09785116033506824
#
#
# Price increase from previously bought: -15.019473293705033%
# Share price: $0.39121003586247005
# Shares owned at the moment: 0
# Cash capital at the moment: $83.5865717287986
#
#
# Share price: $0.3439892248405657
# Shares owned at the moment: 242
# Cash capital at the moment: $0.11225448825030071
#
#
# Price increase from previously bought: -7.119154565774344%
# Share price: $0.32037872551020186
# Shares owned at the moment: 0
# Cash capital at the moment: $77.43069401989212
#
#
# Share price: $0.310541103457011
# Shares owned at the moment: 248
# Cash capital at the moment: $0.20471132999568908
#
#
# Price increase from previously bought: 3.8327531159676465%
# Share price: $0.3233300965636293
# Shares owned at the moment: 0
# Cash capital at the moment: $80.17006415191936
#
#
# Share price: $0.310541103457011
# Shares owned at the moment: 257
# Cash capital at the moment: $0.14152563859927625
#
#
# Price increase from previously bought: -3.1175551000076074%
# Share price: $0.30168717793555067
# Shares owned at the moment: 0
# Cash capital at the moment: $77.46191295502985
#
#
# Share price: $0.26430398896683716
# Shares owned at the moment: 292
# Cash capital at the moment: $0.07291207357302198
#
#
# Price increase from previously bought: -30.52621264674862%
# Share price: $0.18412695173694915
# Shares owned at the moment: 0
# Cash capital at the moment: $53.6901280385174
#
#
# Share price: $0.05918839172418965
# Shares owned at the moment: 904
# Cash capital at the moment: $0.03667957802361599
#
#
# Price increase from previously bought: 98.34929012216531%
# Share price: $0.11772260414541068
# Shares owned at the moment: 0
# Cash capital at the moment: $106.16525533156937
#
#
# Share price: $0.11280374620910914
# Shares owned at the moment: 938
# Cash capital at the moment: $0.06436412407859393
#
#
#
#
# Capital at the end of test period: $56.35065676707693
# profit gained: -43.64934323292307%
#
#
# Capital at the end of test period if Buy and Hold: $8.115342010843221
# profit gained: -91.88465798915678%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.778226      3.571429       0.000000      91.866029
# 1       0.735160      7.407407       9.090909      92.352941
# 2       0.793617     16.071429       0.000000      91.919192
# 3       0.744604      9.756098      15.384615      89.732143
# 4       0.769231     12.500000       9.523810      91.228070
# 5       0.806723     20.000000      11.111111      91.552063
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         50.000000           27.272727          81.730769     -17.086113
# 1         37.037037           59.090909          85.798817      56.166488
# 2         55.357143           38.888889          85.822785     -62.105153
# 3         53.658537           30.769231          83.856502     -96.992902
# 4         50.000000           52.380952          85.294118     192.492313
# 5         50.000000           52.777778          84.055118     -43.649343
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
# 5         -91.884658
#
#
# full cycle data
# 29/29 [==============================] - 0s 4ms/step - loss: 0.1849 - accuracy: 0.7841 - mse: 8.0787 - weighted_accuracy: 0.7841 - weighted_mse: 8.0787
# Test loss: 0.1848931908607483
# Test accuracy: 0.7840785384178162
#
#
# number of predictions: 917
# actual predicted buys: 8
# actual buys but predicted sell: 0
# actual buys but predicted hold: 38
# actual sells but predicted buy: 1
# actual predicted sells: 1
# actual sells but predicted hold: 38
# actual holds but predicted buy: 85
# actual holds but predicted sell: 36
# actual predicted holds: 710
# Percentage buys correct: 8.51063829787234%
# Percentage sells correct: 2.7027027027027026%
# Percentage holds correct: 90.33078880407125%
# actual buys: 46
# actual sells: 40
# actual holds: 831
#
#
# Percentage low buys correct: 46.236559139784944%
# Percentage high sells correct: 40.54054054054054%
# Percentage mid holds correct: 83.96946564885496%
#
#
# Capital: 100
# Share price: $0.3610541051067073
# Shares owned at the moment: 276
# Cash capital at the moment: $0.07502692477278572
#
#
# Price increase from previously bought: 2.510602896982439%
# Share price: $0.3711365664639956
# Shares owned at the moment: 0
# Cash capital at the moment: $102.2270266148894
#
#
# Share price: $0.33630612621219236
# Shares owned at the moment: 303
# Cash capital at the moment: $0.04604329292880038
#
#
# Price increase from previously bought: -57.89562178831633%
# Share price: $0.14198900223859967
# Shares owned at the moment: 0
# Cash capital at the moment: $42.95039863510918
#
#
# Share price: $0.3638038514018116
# Shares owned at the moment: 117
# Cash capital at the moment: $0.26829413190868934
#
#
# Price increase from previously bought: 4.750855868290715%
# Share price: $0.38213563905727155
# Shares owned at the moment: 0
# Cash capital at the moment: $44.85521175974279
#
#
# Share price: $0.5058753587041289
# Shares owned at the moment: 88
# Cash capital at the moment: $0.21575835697304058
#
#
# Price increase from previously bought: 9.302427899513876%
# Share price: $0.5544546178443124
# Shares owned at the moment: 0
# Cash capital at the moment: $48.87358670975421
#
#
# Share price: $0.9632538759189331
# Shares owned at the moment: 50
# Cash capital at the moment: $0.5784455058687001
#
#
# Price increase from previously bought: -23.238755672582045%
# Share price: $0.7414390267557212
# Shares owned at the moment: 0
# Cash capital at the moment: $37.54844897747585
#
#
# Share price: $0.6653620424259183
# Shares owned at the moment: 56
# Cash capital at the moment: $0.18570884709083657
#
#
# Price increase from previously bought: 31.18584842414085%
# Share price: $0.8752612077598667
# Shares owned at the moment: 0
# Cash capital at the moment: $49.06554625564836
#
#
# Share price: $0.8129330423184442
# Shares owned at the moment: 60
# Cash capital at the moment: $0.1554297645591589
#
#
# Price increase from previously bought: 1.9745880333795762%
# Share price: $0.8312648299739043
# Shares owned at the moment: 0
# Cash capital at the moment: $49.89416086604772
#
#
# Share price: $0.8266819486196832
# Shares owned at the moment: 60
# Cash capital at the moment: $0.15684142734447448
#
#
# Price increase from previously bought: -1.0482551165791887%
# Share price: $0.8202657573806285
# Shares owned at the moment: 0
# Cash capital at the moment: $49.23744302021438
#
#
# Share price: $0.7891016746599171
# Shares owned at the moment: 62
# Cash capital at the moment: $0.1785973557700018
#
#
# Price increase from previously bought: -4.791905672332408%
# Share price: $0.7533547105849849
# Shares owned at the moment: 0
# Cash capital at the moment: $46.75814243388432
#
#
# Share price: $0.7551878456441017
# Shares owned at the moment: 61
# Cash capital at the moment: $0.5650010884873211
#
#
# Price increase from previously bought: -40.09628242228852%
# Share price: $0.45362965461999494
# Shares owned at the moment: 0
# Cash capital at the moment: $28.16031364574451
#
#
# Share price: $0.38763521906033893
# Shares owned at the moment: 72
# Cash capital at the moment: $0.1738261000261545
#
#
# Price increase from previously bought: 14.345874492570454%
# Share price: $0.44446380449869394
# Shares owned at the moment: 0
# Cash capital at the moment: $32.08721619064138
#
#
# Share price: $0.42521540560724624
# Shares owned at the moment: 75
# Cash capital at the moment: $0.108360092691413
#
#
# Price increase from previously bought: -21.12613600481047%
# Share price: $0.33630612621219236
# Shares owned at the moment: 0
# Cash capital at the moment: $25.261956420074576
#
#
# Share price: $0.35647113633962746
# Shares owned at the moment: 70
# Cash capital at the moment: $0.24035618255527424
#
#
# Price increase from previously bought: -44.12270282001709%
# Share price: $0.19973419891294242
# Shares owned at the moment: 0
# Cash capital at the moment: $14.183301273170501
#
#
# Share price: $0.15940422236450136
# Shares owned at the moment: 88
# Cash capital at the moment: $0.1171538832821728
#
#
# Price increase from previously bought: 17.502176461233265%
# Share price: $0.18781851508367886
# Shares owned at the moment: 0
# Cash capital at the moment: $16.59973112999566
#
#
# Share price: $0.1850687687885747
# Shares owned at the moment: 89
# Cash capital at the moment: $0.08331512665150953
#
#
# Price increase from previously bought: 27.38479039074715%
# Share price: $0.23639777422386254
# Shares owned at the moment: 0
# Cash capital at the moment: $21.064858677333987
#
#
# Share price: $0.19973419891294242
# Shares owned at the moment: 105
# Cash capital at the moment: $0.03509454153892122
#
#
# Price increase from previously bought: -60.225954938474715%
# Share price: $0.07966083679717727
# Shares owned at the moment: 0
# Cash capital at the moment: $8.376480338617348
#
#
# Share price: $0.06407883914325084
# Shares owned at the moment: 130
# Cash capital at the moment: $0.023323065001026322
#
#
# Price increase from previously bought: -34.50997804370656%
# Share price: $0.04208065025026963
# Shares owned at the moment: 0
# Cash capital at the moment: $5.478763765071606
#
#
# Share price: $0.018249326298171657
# Shares owned at the moment: 299
# Cash capital at the moment: $0.0072096933696084164
#
#
#
#
# Capital at the end of test period: $5.448752747974262
# profit gained: -94.55124725202573%
#
#
# Capital at the end of test period if Buy and Hold: $3.993306781778525
# profit gained: -96.00669321822147%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.778226      3.571429       0.000000      91.866029
# 1       0.735160      7.407407       9.090909      92.352941
# 2       0.793617     16.071429       0.000000      91.919192
# 3       0.744604      9.756098      15.384615      89.732143
# 4       0.769231     12.500000       9.523810      91.228070
# 5       0.806723     20.000000      11.111111      91.552063
# 6       0.784079      8.510638       2.702703      90.330789
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         50.000000           27.272727          81.730769     -17.086113
# 1         37.037037           59.090909          85.798817      56.166488
# 2         55.357143           38.888889          85.822785     -62.105153
# 3         53.658537           30.769231          83.856502     -96.992902
# 4         50.000000           52.380952          85.294118     192.492313
# 5         50.000000           52.777778          84.055118     -43.649343
# 6         46.236559           40.540541          83.969466     -94.551247
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
# 5         -91.884658
# 6         -96.006693

# %%
df = log_hist['0_epochs_logs']
df['Profit gained']
# Out:
# 0     -58.951075
# 1     325.329255
# 2    8982.507920
# 3     -96.565750
# 4    1841.681725
# 5     283.148812
# 6     -19.366131
# Name: Profit gained, dtype: float64

# %%
accumulation_phase_data_acc = []
mark_up_phase_data_acc = []
distribution_phase_data_acc = []
mark_down_phase_data_acc = []
bull_phase_data_acc = []
bear_phase_data_acc = []
full_cycle_data_acc = []

accumulation_phase_data_correct_buys = []
mark_up_phase_data_correct_buys = []
distribution_phase_data_correct_buys = []
mark_down_phase_data_correct_buys = []
bull_phase_data_correct_buys = []
bear_phase_data_correct_buys = []
full_cycle_data_correct_buys = []

accumulation_phase_data_correct_sells = []
mark_up_phase_data_correct_sells = []
distribution_phase_data_correct_sells = []
mark_down_phase_data_correct_sells = []
bull_phase_data_correct_sells = []
bear_phase_data_correct_sells = []
full_cycle_data_correct_sells = []

accumulation_phase_data_correct_holds = []
mark_up_phase_data_correct_holds = []
distribution_phase_data_correct_holds = []
mark_down_phase_data_correct_holds = []
bull_phase_data_correct_holds = []
bear_phase_data_correct_holds = []
full_cycle_data_correct_holds = []

accumulation_phase_data_correct_low_buys = []
mark_up_phase_data_correct_low_buys = []
distribution_phase_data_correct_low_buys = []
mark_down_phase_data_correct_low_buys = []
bull_phase_data_correct_low_buys = []
bear_phase_data_correct_low_buys = []
full_cycle_data_correct_low_buys = []

accumulation_phase_data_correct_high_sells = []
mark_up_phase_data_correct_high_sells = []
distribution_phase_data_correct_high_sells = []
mark_down_phase_data_correct_high_sells = []
bull_phase_data_correct_high_sells = []
bear_phase_data_correct_high_sells = []
full_cycle_data_correct_high_sells = []

accumulation_phase_data_correct_mid_holds = []
mark_up_phase_data_correct_mid_holds = []
distribution_phase_data_correct_mid_holds = []
mark_down_phase_data_correct_mid_holds = []
bull_phase_data_correct_mid_holds = []
bear_phase_data_correct_mid_holds = []
full_cycle_data_correct_mid_holds = []

accumulation_phase_data_profit = []
mark_up_phase_data_profit = []
distribution_phase_data_profit = []
mark_down_phase_data_profit = []
bull_phase_data_profit = []
bear_phase_data_profit = []
full_cycle_data_profit = []

for key,value in log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    accumulation_phase_data_acc.append(acc[0])
    mark_up_phase_data_acc.append(acc[1])
    distribution_phase_data_acc.append(acc[2])
    mark_down_phase_data_acc.append(acc[3]) 
    bull_phase_data_acc.append(acc[4]) 
    bear_phase_data_acc.append(acc[5]) 
    full_cycle_data_acc.append(acc[6]) 

    accumulation_phase_data_correct_buys.append(correct_buys[0])
    mark_up_phase_data_correct_buys.append(correct_buys[1]) 
    distribution_phase_data_correct_buys.append(correct_buys[2]) 
    mark_down_phase_data_correct_buys.append(correct_buys[3]) 
    bull_phase_data_correct_buys.append(correct_buys[4])
    bear_phase_data_correct_buys.append(correct_buys[5]) 
    full_cycle_data_correct_buys.append(correct_buys[6]) 

    accumulation_phase_data_correct_sells.append(correct_sells[0]) 
    mark_up_phase_data_correct_sells.append(correct_sells[1]) 
    distribution_phase_data_correct_sells.append(correct_sells[2]) 
    mark_down_phase_data_correct_sells.append(correct_sells[3]) 
    bull_phase_data_correct_sells.append(correct_sells[4]) 
    bear_phase_data_correct_sells.append(correct_sells[5]) 
    full_cycle_data_correct_sells.append(correct_sells[6])

    accumulation_phase_data_correct_holds.append(correct_holds[0]) 
    mark_up_phase_data_correct_holds.append(correct_holds[1])  
    distribution_phase_data_correct_holds.append(correct_holds[2])  
    mark_down_phase_data_correct_holds.append(correct_holds[3])  
    bull_phase_data_correct_holds.append(correct_holds[4])  
    bear_phase_data_correct_holds.append(correct_holds[5])  
    full_cycle_data_correct_holds.append(correct_holds[6])  

    accumulation_phase_data_correct_low_buys.append(correct_low_buys[0])  
    mark_up_phase_data_correct_low_buys.append(correct_low_buys[1])  
    distribution_phase_data_correct_low_buys.append(correct_low_buys[2])  
    mark_down_phase_data_correct_low_buys.append(correct_low_buys[3])   
    bull_phase_data_correct_low_buys.append(correct_low_buys[4])   
    bear_phase_data_correct_low_buys.append(correct_low_buys[5])  
    full_cycle_data_correct_low_buys.append(correct_low_buys[6])  

    accumulation_phase_data_correct_high_sells.append(correct_high_sells[0]) 
    mark_up_phase_data_correct_high_sells.append(correct_high_sells[1]) 
    distribution_phase_data_correct_high_sells.append(correct_high_sells[2]) 
    mark_down_phase_data_correct_high_sells.append(correct_high_sells[3]) 
    bull_phase_data_correct_high_sells.append(correct_high_sells[4]) 
    bear_phase_data_correct_high_sells.append(correct_high_sells[5]) 
    full_cycle_data_correct_high_sells.append(correct_high_sells[6]) 

    accumulation_phase_data_correct_mid_holds.append(correct_mid_holds[0])  
    mark_up_phase_data_correct_mid_holds.append(correct_mid_holds[1])  
    distribution_phase_data_correct_mid_holds.append(correct_mid_holds[2])   
    mark_down_phase_data_correct_mid_holds.append(correct_mid_holds[3])   
    bull_phase_data_correct_mid_holds.append(correct_mid_holds[4])   
    bear_phase_data_correct_mid_holds.append(correct_mid_holds[5])   
    full_cycle_data_correct_mid_holds.append(correct_mid_holds[6])   

    accumulation_phase_data_profit.append(profit[0]) 
    mark_up_phase_data_profit.append(profit[1]) 
    distribution_phase_data_profit.append(profit[2]) 
    mark_down_phase_data_profit.append(profit[3])  
    bull_phase_data_profit.append(profit[4])  
    bear_phase_data_profit.append(profit[5])  
    full_cycle_data_profit.append(profit[6])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(accumulation_phase_data_acc)
plt.plot(mark_up_phase_data_acc)
plt.plot(distribution_phase_data_acc)
plt.plot(mark_down_phase_data_acc)
plt.plot(bull_phase_data_acc)
plt.plot(bear_phase_data_acc)
plt.plot(full_cycle_data_acc)
plt.title('Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['accumulation_phase_data_acc','mark_up_phase_data_acc','distribution_phase_data_acc','mark_down_phase_data_acc','bull_phase_data_acc','bear_phase_data_acc','full_cycle_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct buys")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_buys")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_buys")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_buys")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_buys")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct sells")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_sells")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_sells")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_sells")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_sells")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct holds")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_holds")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_holds")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_holds")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_holds")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct low buys")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_low_buys")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_low_buys")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_low_buys")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_low_buys")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct high sells")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_high_sells")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_high_sells")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_high_sells")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_high_sells")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_mid_holds")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_mid_holds")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_mid_holds")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_mid_holds")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Profit")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_profit")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_profit")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_profit")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_profit")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_profit")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_profit")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_profit")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_profit')
