# %%
import os
seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
experiment = 'Bull phase LSTM Experiment'

# %%
import requests
import lxml
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.utils import compute_class_weight
import tensorflow as tf
from pil import Image
from sklearn import preprocessing
import tensorflow_addons as tfa
import glob
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
import math

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
# gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
np.random.seed(seed)
tf.random.set_seed(seed)

session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, 
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), 
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)

# %% [markdown]
# ## Prepare Test Data

# %%
test_sets = ['accumulation phase data','mark up phase data','distribution phase data','mark down phase data','bull phase data','bear phase data','full cycle data']
test_data = {}

for name in test_sets:

    df = pd.read_csv("{}/test_data.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    labels = []
    data_15 = []
    sequential = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15.append(np.array(i[0:-1]))
            labels.append(i[-1])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_arr = min_max_scaler.fit_transform(data_15)
            sequential.append(data_15_arr)
            data_15 = data_15[1:15]
        else:
            data_15.append(np.array(i[0:-1]))
            count+= 1
            
    X = sequential
    X  = np.array(X).reshape(-1, 15, 4)
    y = labels
    y = np.array(y)
    print(X.shape)
    
    y = to_categorical(y, 3)
    
    test_data['{}_X'.format(name)] = X
    test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2004-06-14    93.010002  92.918784 -32.009897  48922600.0     2.0
# 2004-06-15    91.529999  92.705124 -68.734488  45879300.0     2.0
# 2004-06-16    90.209999  92.321259 -94.676024  40369000.0     2.0
# 2004-06-17    89.980003  91.961066 -87.983635  36219100.0     2.0
# 2004-06-18    89.339996  91.557824 -85.961924  32718400.0     2.0
# (248, 15, 4)
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22   115.589996  116.459043 -80.074504 -17684500.0     2.0
# 2020-01-23   116.099998  116.403805 -70.577262 -12758400.0     2.0
# 2020-01-24   115.809998  116.312450 -69.789236 -17063500.0     2.0
# 2020-01-27   114.370003  116.013612 -94.416205 -21446900.0     2.0
# 2020-01-28   115.860001  115.989979 -34.297465 -14428500.0     2.0
# (219, 15, 4)
#             previous_1d      EMA_12   willr_14        OBV_7  labels
# Date
# 2016-12-05   223.360001  213.378658 -16.514565 -283274800.0     2.0
# 2016-12-06   228.550003  215.712711  -2.667189 -278675500.0     2.0
# 2016-12-07   231.380005  218.123064  -4.633597 -273416200.0     2.0
# 2016-12-08   235.559998  220.805669  -1.742271 -266821000.0     2.0
# 2016-12-09   241.449997  223.981719  -2.918174 -259477300.0     2.0
# (470, 15, 4)
#             previous_1d      EMA_12   willr_14        OBV_7  labels
# Date
# 2007-10-01   216.740005  205.638670  -5.220429  161688200.0     2.0
# 2007-10-02   222.979996  208.306567  -1.526716  171593800.0     2.0
# 2007-10-03   228.020004  211.339403  -1.071898  181013600.0     2.0
# 2007-10-04   227.350006  213.802573  -7.282412  170892200.0     2.0
# 2007-10-05   225.949997  215.671407 -10.566735  160852300.0     2.0
# (278, 15, 4)
#             previous_1d       EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22  1075.300049  1097.577291 -89.711935   1200864.0     2.0
# 2020-01-23  1075.510010  1094.182325 -70.779503   4820868.0     2.0
# 2020-02-03  1052.800049  1087.815821 -81.895216   -525975.0     1.0
# 2020-02-04  1003.919983  1074.908769 -83.419991 -12870263.0     2.0
# 2020-02-05  1038.010010  1069.232037 -59.790669  -6607845.0     2.0
# (208, 15, 4)
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2018-01-22    32.830002  32.653718 -49.494874  128764966.0     2.0
# 2018-01-23    33.750000  32.822377 -18.518497  165063463.0     2.0
# 2018-01-24    33.970001  32.998934 -16.190425  201240854.0     2.0
# 2018-01-25    33.959999  33.146790 -17.627141  173336178.0     2.0
# 2018-01-26    34.880001  33.413438  -2.648942  221767625.0     0.0
# (595, 15, 4)
#             previous_1d    EMA_12   willr_14        OBV_7  labels
# Date
# 2002-11-11         8.74  8.763110 -71.929852 -553467352.0     2.0
# 2002-11-12         8.50  8.722632 -80.487816 -559735252.0     2.0
# 2002-11-13         8.63  8.708381 -69.918697 -552295352.0     2.0
# 2002-11-14         8.52  8.679399 -78.861762 -566378552.0     2.0
# 2002-11-15         8.80  8.697953 -56.097548 -558353452.0     2.0
# (917, 15, 4)

# %% [markdown]
# ## Train Accumulation Phase Stock Data

# %%
def pred_acc(actual, predictions, logger):

    hold = 0
    sell = 0
    buy = 0
    pred_hold = 0
    pred_sell = 0
    pred_buy = 0
    buy_buy = 0
    buy_sell = 0
    buy_hold = 0
    sell_buy = 0
    sell_sell = 0
    sell_hold = 0
    hold_buy = 0
    hold_sell = 0
    hold_hold = 0

    for i in range (0,len(actual)):
        if actual[i]==1 and predictions[i] == 1:
            buy_buy += 1
            buy += 1
            pred_buy += 1
        elif actual[i]==1 and predictions[i] == 0:
            buy_sell += 1
            buy += 1
            pred_sell += 1
        elif actual[i]==1 and predictions[i] == 2:
            buy_hold += 1
            buy += 1
            pred_hold += 1
        elif actual[i]==0 and predictions[i] == 1:
            sell_buy += 1
            sell += 1
            pred_buy += 1
        elif actual[i]==0 and predictions[i] == 0:
            sell_sell += 1
            sell += 1
            pred_sell += 1
        elif actual[i]==0 and predictions[i] == 2:
            sell_hold += 1
            sell += 1
            pred_hold += 1
        elif actual[i]==2 and predictions[i] == 1:
            hold_buy += 1
            hold += 1
            pred_buy += 1
        elif actual[i]==2 and predictions[i] == 0:
            hold_sell += 1
            hold += 1
            pred_sell += 1
        elif actual[i]==2 and predictions[i] == 2:
            hold_hold += 1
            hold += 1
            pred_hold += 1

    print("number of predictions: " + str(len(actual)))
    print("actual predicted buys: " + str(buy_buy) )
    print("actual buys but predicted sell: " + str(buy_sell) )
    print("actual buys but predicted hold: " + str(buy_hold))
    print("actual sells but predicted buy: " + str(sell_buy) )
    print("actual predicted sells: " + str(sell_sell))
    print("actual sells but predicted hold: " + str(sell_hold) )
    print("actual holds but predicted buy: " + str(hold_buy) )
    print("actual holds but predicted sell: " + str(hold_sell))
    print("actual predicted holds: " + str(hold_hold) )
    
    if pred_buy !=0:
        Percentage_buys_correct = 100*buy_buy/pred_buy
    else:
        Percentage_buys_correct = 0
        
    if pred_sell !=0:
        Percentage_sells_correct = 100*sell_sell/pred_sell
    else:
        Percentage_sells_correct = 0
        
    if pred_hold !=0:
        Percentage_holds_correct = 100*hold_hold/pred_hold
    else:
        Percentage_holds_correct = 0

    print("Percentage buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage holds correct: " + str(Percentage_holds_correct) + "%")

    print("actual buys: " + str(buy))
    print("actual sells: " + str(sell))
    print("actual holds: " + str(hold))
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def correct_maxima_minima(predictions, price, logger):
    correct_maxima = 0 
    correct_minima = 0
    correct_hold = 0

    hold = 0
    buy = 0
    sell = 0

#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):
        if i < 4:
            prices = price[i:i+9]
            prices.sort(key = float)
#             if i == 0:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1

        else:
            prices = price[i:i+5]
            prices = prices + price[i-4:i] 
            prices.sort(key = float)
#             if i == 10:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1
                    
    if buy !=0:
        Percentage_buys_correct = 100*correct_minima/buy
    else:
        Percentage_buys_correct = 0
        
    if sell !=0:
        Percentage_sells_correct = 100*correct_maxima/sell
    else:
        Percentage_sells_correct = 0
        
    if hold !=0:
        Percentage_holds_correct = 100*correct_hold/hold
    else:
        Percentage_holds_correct = 0

    print("Percentage low buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage high sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage mid holds correct: " + str(Percentage_holds_correct) + "%")
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %% [markdown]
# ### Creating Training Data and Model

# %%
labels = []
sequential = []

for filepath in glob.iglob('bull phase data/*_acc_data.csv'):
    print(filepath)
    seed = 10
    df = pd.read_csv(filepath)
    df.set_index('Date', inplace=True)
    print(df.head())
    
    plt.figure(figsize=(15,5))
    plt.plot(df['previous_1d'].values)
    plt.plot(df['EMA_12'].values)
    plt.show()

    data_15 = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15.append(np.array(i[0:-1]))
            labels.append(i[-1])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_arr = min_max_scaler.fit_transform(data_15)
            sequential.append(data_15_arr)
            data_15 = data_15[1:15]
        else:
            data_15.append(np.array(i[0:-1]))
            count+= 1
# Out:
# accumulation phase data\0_acc_data.csv
#             previous_1d     EMA_12   willr_14      OBV_7  labels
# Date
# 2001-01-08      22.3125  19.936626 -15.972222   192400.0     2.0
# 2001-01-09      20.5625  20.032914 -35.416667 -1320000.0     2.0
# 2001-01-10      20.7500  20.143235 -33.333333  -439800.0     2.0
# 2001-01-11      21.1250  20.294276 -29.166667   290200.0     2.0
# 2001-01-12      22.6875  20.662464 -13.178295  1360200.0     2.0
# accumulation phase data\1_acc_data.csv
#             previous_1d      EMA_12   willr_14        OBV_7  labels
# Date
# 2013-10-21   122.519997  119.133586  -3.571469  268371800.0     2.0
# 2013-10-22   121.470001  119.493034 -14.600827  265163900.0     2.0
# 2013-10-23   122.480003  119.952568 -12.619492  269595100.0     2.0
# 2013-10-24   129.020004  121.347558  -5.825830  280361400.0     2.0
# 2013-10-25   128.979996  122.521779  -6.066121  275385200.0     2.0
# accumulation phase data\2_acc_data.csv
#             previous_1d     EMA_12   willr_14         OBV_7  labels
# Date
# 2011-06-02    16.940001  16.497632 -20.155042  9.557743e+09     2.0
# 2011-06-03    16.990000  16.573381 -24.475546  9.575374e+09     2.0
# 2011-06-07    17.440001  16.706707 -22.334963  9.601214e+09     2.0
# 2011-06-08    17.350000  16.805675 -26.903501  9.588997e+09     0.0
# 2011-06-09    17.760000  16.952494  -6.091318  9.611336e+09     2.0
# accumulation phase data\3_acc_data.csv
#             previous_1d    EMA_12   willr_14        OBV_7  labels
# Date
# 2004-08-30     6.405571  6.389804 -28.571449  273414472.0     2.0
# 2004-08-31     6.405571  6.392230 -28.571449  273414472.0     2.0
# 2004-09-01     6.454098  6.401748 -19.999921  278125245.0     2.0
# 2004-09-02     6.551152  6.424733  -0.000000  288787337.0     2.0
# 2004-09-03     6.599679  6.451648  -0.000000  306525894.0     2.0
# accumulation phase data\4_acc_data.csv
#             previous_1d     EMA_12   willr_14         OBV_7  labels
# Date
# 2009-08-03    38.650002  37.415266 -15.157111 -1.307058e+09     2.0
# 2009-08-04    39.599998  37.751379  -3.164588 -1.264100e+09     2.0
# 2009-08-05    40.209999  38.129628  -5.492443 -1.220737e+09     2.0
# 2009-08-06    41.779999  38.691224  -6.976777 -1.157402e+09     2.0
# 2009-08-07    40.750000  39.007958 -27.359985 -1.211578e+09     2.0

# %%
X = sequential
X  = np.array(X).reshape(-1, 15, 4)
X.shape
# Out:
# (4491, 15, 4)

# %%
y = labels
y = np.array(y)
y.shape
# Out:
# (4491,)

# %%
from collections import Counter

Counter(y)
# Out:
# Counter({2.0: 4094, 0.0: 194, 1.0: 203})

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization,Activation
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(LSTM(100, input_shape=(X_train.shape[1:]), return_sequences=True,kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(LSTM(100, kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# model.add(Dense(100, kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))

model.add(Dense(75, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(50, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "LSTM_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))

epochs = 0 
histories = {}
log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['accumulation phase data','mark up phase data','distribution phase data','mark down phase data','bull phase data','bear phase data','full cycle data']
    
    for name in test_sets:
        
        print('\n')
        print(name)
        print('\n')
        
        X = test_data['{}_X'.format(name)]
        y = test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("{}/test_data.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(log)
        log.loc[df_length] = logger
        print(log.head(20))
        logger = []

    log.to_csv('{}_{}epochs.csv'.format(experiment,epochs))
    log_hist['{}_epochs_logs'.format(epochs)] = log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 0 2 ... 2 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  1/29 [>.............................] - ETA: 0s - loss: 0.2868 - accuracy: 0.5078 - mse: 0.3225 - weighted_accuracy: 0.2134 - weighted_mse: 0.4658WARNING:tensorflow:From C:\Users\Shearman Chua\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/29 [=>............................] - ETA: 1s - loss: 0.2992 - accuracy: 0.5430 - mse: 0.3193 - weighted_accuracy: 0.2740 - weighted_mse: 0.4522WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0120s vs `on_train_batch_end` time: 0.0918s). Check your callbacks.
# 29/29 [==============================] - 1s 36ms/step - loss: 0.2953 - accuracy: 0.5078 - mse: 0.4427 - weighted_accuracy: 0.3022 - weighted_mse: 0.5274 - val_loss: 0.2997 - val_accuracy: 0.0456 - val_mse: 0.3538 - val_weighted_accuracy: 0.0456 - val_weighted_mse: 0.3538
# Epoch 2/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.2143 - accuracy: 0.3472 - mse: 0.7577 - weighted_accuracy: 0.4345 - weighted_mse: 0.7350 - val_loss: 0.2924 - val_accuracy: 0.0456 - val_mse: 0.3854 - val_weighted_accuracy: 0.0456 - val_weighted_mse: 0.3854
# Epoch 3/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1927 - accuracy: 0.2661 - mse: 0.9879 - weighted_accuracy: 0.4660 - weighted_mse: 0.9525 - val_loss: 0.2834 - val_accuracy: 0.0456 - val_mse: 0.4258 - val_weighted_accuracy: 0.0456 - val_weighted_mse: 0.4258
# Epoch 4/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1834 - accuracy: 0.2339 - mse: 1.1367 - weighted_accuracy: 0.4880 - weighted_mse: 1.0949 - val_loss: 0.2761 - val_accuracy: 0.0456 - val_mse: 0.4752 - val_weighted_accuracy: 0.0456 - val_weighted_mse: 0.4752
# Epoch 5/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1789 - accuracy: 0.2177 - mse: 1.2278 - weighted_accuracy: 0.5045 - weighted_mse: 1.1699 - val_loss: 0.2680 - val_accuracy: 0.0456 - val_mse: 0.5282 - val_weighted_accuracy: 0.0456 - val_weighted_mse: 0.5282
# Epoch 6/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1746 - accuracy: 0.2375 - mse: 1.2797 - weighted_accuracy: 0.5306 - weighted_mse: 1.2143 - val_loss: 0.2598 - val_accuracy: 0.0456 - val_mse: 0.5859 - val_weighted_accuracy: 0.0456 - val_weighted_mse: 0.5859
# Epoch 7/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1718 - accuracy: 0.2522 - mse: 1.2985 - weighted_accuracy: 0.5495 - weighted_mse: 1.2398 - val_loss: 0.2537 - val_accuracy: 0.0456 - val_mse: 0.6486 - val_weighted_accuracy: 0.0456 - val_weighted_mse: 0.6486
# Epoch 8/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1687 - accuracy: 0.2687 - mse: 1.3076 - weighted_accuracy: 0.5675 - weighted_mse: 1.2496 - val_loss: 0.2462 - val_accuracy: 0.0456 - val_mse: 0.7147 - val_weighted_accuracy: 0.0456 - val_weighted_mse: 0.7147
# Epoch 9/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1666 - accuracy: 0.2717 - mse: 1.3304 - weighted_accuracy: 0.5746 - weighted_mse: 1.2672 - val_loss: 0.2427 - val_accuracy: 0.0456 - val_mse: 0.7915 - val_weighted_accuracy: 0.0456 - val_weighted_mse: 0.7915
# Epoch 10/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1643 - accuracy: 0.2829 - mse: 1.3379 - weighted_accuracy: 0.5810 - weighted_mse: 1.2724 - val_loss: 0.2373 - val_accuracy: 0.0456 - val_mse: 0.8619 - val_weighted_accuracy: 0.0456 - val_weighted_mse: 0.8619
# Epoch 11/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1628 - accuracy: 0.2589 - mse: 1.3651 - weighted_accuracy: 0.6028 - weighted_mse: 1.2876 - val_loss: 0.2315 - val_accuracy: 0.0456 - val_mse: 0.9352 - val_weighted_accuracy: 0.0456 - val_weighted_mse: 0.9352
# Epoch 12/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1600 - accuracy: 0.3085 - mse: 1.3581 - weighted_accuracy: 0.6101 - weighted_mse: 1.2956 - val_loss: 0.2286 - val_accuracy: 0.0489 - val_mse: 1.0111 - val_weighted_accuracy: 0.0489 - val_weighted_mse: 1.0111
# Epoch 13/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1586 - accuracy: 0.2829 - mse: 1.3868 - weighted_accuracy: 0.6053 - weighted_mse: 1.3061 - val_loss: 0.2214 - val_accuracy: 0.0912 - val_mse: 1.0717 - val_weighted_accuracy: 0.0912 - val_weighted_mse: 1.0717
# Epoch 14/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1602 - accuracy: 0.2645 - mse: 1.4360 - weighted_accuracy: 0.6110 - weighted_mse: 1.3413 - val_loss: 0.2207 - val_accuracy: 0.0890 - val_mse: 1.1565 - val_weighted_accuracy: 0.0890 - val_weighted_mse: 1.1565
# Epoch 15/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1571 - accuracy: 0.2826 - mse: 1.4236 - weighted_accuracy: 0.6070 - weighted_mse: 1.3484 - val_loss: 0.2113 - val_accuracy: 0.1958 - val_mse: 1.1776 - val_weighted_accuracy: 0.1958 - val_weighted_mse: 1.1776
# Epoch 16/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1548 - accuracy: 0.3104 - mse: 1.4073 - weighted_accuracy: 0.6394 - weighted_mse: 1.3370 - val_loss: 0.2036 - val_accuracy: 0.2948 - val_mse: 1.2040 - val_weighted_accuracy: 0.2948 - val_weighted_mse: 1.2040
# Epoch 17/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1530 - accuracy: 0.2915 - mse: 1.4386 - weighted_accuracy: 0.6441 - weighted_mse: 1.3490 - val_loss: 0.1954 - val_accuracy: 0.3304 - val_mse: 1.2231 - val_weighted_accuracy: 0.3304 - val_weighted_mse: 1.2231
# Epoch 18/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1536 - accuracy: 0.2934 - mse: 1.4641 - weighted_accuracy: 0.6450 - weighted_mse: 1.3664 - val_loss: 0.1922 - val_accuracy: 0.3582 - val_mse: 1.2643 - val_weighted_accuracy: 0.3582 - val_weighted_mse: 1.2643
# Epoch 19/20
# 29/29 [==============================] - 0s 7ms/step - loss: 0.1510 - accuracy: 0.3299 - mse: 1.4630 - weighted_accuracy: 0.6464 - weighted_mse: 1.3728 - val_loss: 0.1929 - val_accuracy: 0.3370 - val_mse: 1.3079 - val_weighted_accuracy: 0.3370 - val_weighted_mse: 1.3079
# Epoch 20/20
# 29/29 [==============================] - 0s 8ms/step - loss: 0.1491 - accuracy: 0.3157 - mse: 1.5151 - weighted_accuracy: 0.6596 - weighted_mse: 1.4207 - val_loss: 0.1865 - val_accuracy: 0.3860 - val_mse: 1.3109 - val_weighted_accuracy: 0.3860 - val_weighted_mse: 1.3109
# Validation loss: 0.18653862178325653
# Validation accuracy: 0.3859844207763672
#
#
# accumulation phase data
#
#
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1878 - accuracy: 0.3387 - mse: 1.3049 - weighted_accuracy: 0.3387 - weighted_mse: 1.3049
# Test loss: 0.18778376281261444
# Test accuracy: 0.33870968222618103
#
#
# number of predictions: 248
# actual predicted buys: 7
# actual buys but predicted sell: 0
# actual buys but predicted hold: 4
# actual sells but predicted buy: 2
# actual predicted sells: 3
# actual sells but predicted hold: 3
# actual holds but predicted buy: 87
# actual holds but predicted sell: 68
# actual predicted holds: 74
# Percentage buys correct: 7.291666666666667%
# Percentage sells correct: 4.225352112676056%
# Percentage holds correct: 91.35802469135803%
# actual buys: 11
# actual sells: 8
# actual holds: 229
#
#
# Percentage low buys correct: 42.708333333333336%
# Percentage high sells correct: 46.478873239436616%
# Percentage mid holds correct: 82.5%
#
#
# Capital: 100
# Share price: $0.21694303230780076
# Shares owned at the moment: 459
# Cash capital at the moment: $0.14931182818891386
#
#
# Price increase from previously bought: -28.317092191996128%
# Share price: $0.15593872929816288
# Shares owned at the moment: 0
# Cash capital at the moment: $71.52835491498908
#
#
# Share price: $0.13773849509347902
# Shares owned at the moment: 517
# Cash capital at the moment: $0.12172324626126851
#
#
# Price increase from previously bought: -5.3987503086581405%
# Share price: $0.13066066909305607
# Shares owned at the moment: 0
# Cash capital at the moment: $67.4875223610882
#
#
# Share price: $0.34906296526581015
# Shares owned at the moment: 192
# Cash capital at the moment: $0.2831277843922919
#
#
# Price increase from previously bought: 2.807065644108242%
# Share price: $0.3598482606676525
# Shares owned at the moment: 0
# Cash capital at the moment: $69.18399395094906
#
#
# Share price: $0.34367044613575204
# Shares owned at the moment: 200
# Cash capital at the moment: $0.2608859784239854
#
#
# Price increase from previously bought: 35.619060943014325%
# Share price: $0.46736435902539175
# Shares owned at the moment: 0
# Cash capital at the moment: $93.47670738603837
#
#
# Share price: $0.6823962985991441
# Shares owned at the moment: 136
# Cash capital at the moment: $0.41559456087868796
#
#
# Price increase from previously bought: 5.981200894867711%
# Share price: $0.7252006245458233
# Shares owned at the moment: 0
# Cash capital at the moment: $98.77165446553053
#
#
# Share price: $0.6817223301360331
# Shares owned at the moment: 144
# Cash capital at the moment: $0.33367688320790023
#
#
# Price increase from previously bought: 4.606841164839981%
# Share price: $0.7150892976070906
# Shares owned at the moment: 0
# Cash capital at the moment: $103.02336037677654
#
#
# Share price: $0.6530739133319237
# Shares owned at the moment: 157
# Cash capital at the moment: $0.2087913215834618
#
#
# Price increase from previously bought: 24.995950419717737%
# Share price: $0.818560813760991
# Shares owned at the moment: 0
# Cash capital at the moment: $128.36942545071776
#
#
# Share price: $0.8573205575038327
# Shares owned at the moment: 149
# Cash capital at the moment: $0.27737528420948365
#
#
# Price increase from previously bought: 14.623841568388851%
# Share price: $0.985396165399729
# Shares owned at the moment: 0
# Cash capital at the moment: $146.69763784999654
#
#
# Share price: $0.8758579045109338
# Shares owned at the moment: 167
# Cash capital at the moment: $0.027130054023928096
#
#
# Price increase from previously bought: -1.2336379830232724%
# Share price: $0.867431884442565
# Shares owned at the moment: 0
# Cash capital at the moment: $144.48988666300204
#
#
# Share price: $0.9247287180507835
# Shares owned at the moment: 155
# Cash capital at the moment: $0.762769749061448
#
#
# Price increase from previously bought: -1.764509789973312%
# Share price: $0.9109099217106305
# Shares owned at the moment: 0
# Cash capital at the moment: $141.56553226008003
#
#
# Share price: $0.8017087736242534
# Shares owned at the moment: 176
# Cash capital at the moment: $0.07676105577729686
#
#
# Price increase from previously bought: -4.969826457354776%
# Share price: $0.7639603682886655
# Shares owned at the moment: 0
# Cash capital at the moment: $134.16402905633072
#
#
# Share price: $0.7012707584086637
# Shares owned at the moment: 190
# Cash capital at the moment: $0.556170987416067
#
#
# Price increase from previously bought: -25.77280771888375%
# Share price: $0.5219650616394429
# Shares owned at the moment: 0
# Cash capital at the moment: $99.4568059542036
#
#
#
#
# Capital at the end of test period: $99.4568059542036
# profit gained: -0.5431940457963975%
#
#
# Capital at the end of test period if Buy and Hold: $182.55793694382942
# profit gained: 82.55793694382942%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0        0.33871      7.291667       4.225352      91.358025
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         42.708333           46.478873               82.5      -0.543194
#
#    buy_n_hold profit
# 0          82.557937
#
#
# mark up phase data
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1851 - accuracy: 0.4247 - mse: 1.2777 - weighted_accuracy: 0.4247 - weighted_mse: 1.2777
# Test loss: 0.18509799242019653
# Test accuracy: 0.42465752363204956
#
#
# number of predictions: 219
# actual predicted buys: 4
# actual buys but predicted sell: 0
# actual buys but predicted hold: 3
# actual sells but predicted buy: 2
# actual predicted sells: 5
# actual sells but predicted hold: 4
# actual holds but predicted buy: 80
# actual holds but predicted sell: 37
# actual predicted holds: 84
# Percentage buys correct: 4.651162790697675%
# Percentage sells correct: 11.904761904761905%
# Percentage holds correct: 92.3076923076923%
# actual buys: 7
# actual sells: 11
# actual holds: 201
#
#
# Percentage low buys correct: 47.05882352941177%
# Percentage high sells correct: 57.142857142857146%
# Percentage mid holds correct: 85.71428571428571%
#
#
# Capital: 100
# Share price: $0.24286829602432447
# Shares owned at the moment: 410
# Cash capital at the moment: $0.15016462625953864
#
#
# Price increase from previously bought: 20.70307596276839%
# Share price: $0.2939556649752808
# Shares owned at the moment: 0
# Cash capital at the moment: $120.34055225386504
#
#
# Share price: $0.2096306458156978
# Shares owned at the moment: 572
# Cash capital at the moment: $0.10207384141780551
#
#
# Price increase from previously bought: 79.85853753314063%
# Share price: $0.37807546997330177
# Shares owned at the moment: 0
# Cash capital at the moment: $215.7665299518784
#
#
# Share price: $0.5075380561914253
# Shares owned at the moment: 423
# Cash capital at the moment: $0.48753853904079847
#
#
# Price increase from previously bought: -2.854323845798712%
# Share price: $0.49440716743722457
# Shares owned at the moment: 0
# Cash capital at the moment: $209.04665122746542
#
#
# Share price: $0.4396265697083235
# Shares owned at the moment: 474
# Cash capital at the moment: $0.09060395210528327
#
#
# Price increase from previously bought: -18.518403780563165%
# Share price: $0.3591998369557057
# Shares owned at the moment: 0
# Cash capital at the moment: $169.883109681638
#
#
# Share price: $0.31796055630412945
# Shares owned at the moment: 532
# Cash capital at the moment: $0.2629174339681697
#
#
# Price increase from previously bought: 34.346092940274175%
# Share price: $0.4283422953430944
# Shares owned at the moment: 0
# Cash capital at the moment: $227.51435377840744
#
#
# Share price: $0.5760648720941302
# Shares owned at the moment: 393
# Cash capital at the moment: $0.4982769348985414
#
#
# Price increase from previously bought: 3.135521689189247%
# Share price: $0.5957613617579736
# Shares owned at the moment: 0
# Cash capital at the moment: $233.9886230140622
#
#
# Share price: $0.5697046418785916
# Shares owned at the moment: 409
# Cash capital at the moment: $0.33864918976527747
#
#
# Price increase from previously bought: 26.73361710463351%
# Share price: $0.7239928195392686
# Shares owned at the moment: 0
# Cash capital at the moment: $295.63740145754934
#
#
# Share price: $0.6653140919359448
# Shares owned at the moment: 443
# Cash capital at the moment: $0.09273983742480141
#
#
# Price increase from previously bought: 3.2623929548179165%
# Share price: $0.6889085549416702
# Shares owned at the moment: 0
# Cash capital at the moment: $304.43996682952707
#
#
# Share price: $0.8064710677773383
# Shares owned at the moment: 376
# Cash capital at the moment: $0.3729542611661145
#
#
# Price increase from previously bought: 1.4255889742493366%
# Share price: $0.8202174424836832
# Shares owned at the moment: 0
# Cash capital at the moment: $307.92660779950285
#
#
# Share price: $0.8616619372968211
# Shares owned at the moment: 356
# Cash capital at the moment: $0.3313910852209574
#
#
# Price increase from previously bought: 6.065851812845846%
# Share price: $0.9164423784931806
# Shares owned at the moment: 0
# Cash capital at the moment: $325.6876807402484
#
#
# Share price: $0.9139804346846059
# Shares owned at the moment: 355
# Cash capital at the moment: $0.3323530278524345
#
#
#
#
# Capital at the end of test period: $308.213910517465
# profit gained: 208.213910517465%
#
#
# Capital at the end of test period if Buy and Hold: $355.7316817269389
# profit gained: 255.73168172693892%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.338710      7.291667       4.225352      91.358025
# 1       0.424658      4.651163      11.904762      92.307692
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         42.708333           46.478873          82.500000      -0.543194
# 1         47.058824           57.142857          85.714286     208.213911
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
#
#
# distribution phase data
#
#
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1855 - accuracy: 0.3872 - mse: 1.2681 - weighted_accuracy: 0.3872 - weighted_mse: 1.2681
# Test loss: 0.18553750216960907
# Test accuracy: 0.38723403215408325
#
#
# number of predictions: 470
# actual predicted buys: 16
# actual buys but predicted sell: 0
# actual buys but predicted hold: 8
# actual sells but predicted buy: 3
# actual predicted sells: 9
# actual sells but predicted hold: 8
# actual holds but predicted buy: 171
# actual holds but predicted sell: 98
# actual predicted holds: 157
# Percentage buys correct: 8.421052631578947%
# Percentage sells correct: 8.411214953271028%
# Percentage holds correct: 90.7514450867052%
# actual buys: 24
# actual sells: 20
# actual holds: 426
#
#
# Percentage low buys correct: 47.89473684210526%
# Percentage high sells correct: 52.83018867924528%
# Percentage mid holds correct: 84.97109826589596%
#
#
# Capital: 100
# Share price: $0.5051713785101153
# Shares owned at the moment: 197
# Cash capital at the moment: $0.20756183919942828
#
#
# Price increase from previously bought: 5.629590333087275%
# Share price: $0.5350778863586452
# Shares owned at the moment: 0
# Cash capital at the moment: $105.32802700691772
#
#
# Share price: $0.35626178753114757
# Shares owned at the moment: 294
# Cash capital at the moment: $0.2990238175414106
#
#
# Price increase from previously bought: 49.03921554651631%
# Share price: $0.5324299403053472
# Shares owned at the moment: 0
# Cash capital at the moment: $156.40295666057662
#
#
# Share price: $0.6880374729168433
# Shares owned at the moment: 226
# Cash capital at the moment: $0.4788724919522167
#
#
# Price increase from previously bought: -56.648224933970106%
# Share price: $0.2990967178873858
# Shares owned at the moment: 0
# Cash capital at the moment: $67.88884212433439
#
#
# Share price: $0.23024940747423828
# Shares owned at the moment: 294
# Cash capital at the moment: $0.009359680965403072
#
#
# Price increase from previously bought: 16.524286572924353%
# Share price: $0.26903429471608553
# Shares owned at the moment: 0
# Cash capital at the moment: $78.88792810021658
#
#
# Share price: $0.2855451569753569
# Shares owned at the moment: 275
# Cash capital at the moment: $0.1470664070308345
#
#
# Price increase from previously bought: -24.210131070421482%
# Share price: $0.21700943953194973
# Shares owned at the moment: 0
# Cash capital at the moment: $59.66054888967098
#
#
# Share price: $0.04239877625485832
# Shares owned at the moment: 1403
# Cash capital at the moment: $0.011480725619442467
#
#
# Price increase from previously bought: 389.9092343060544%
# Share price: $0.20828673778560325
# Shares owned at the moment: 0
# Cash capital at the moment: $291.4341515327595
#
#
# Share price: $0.18133953128431446
# Shares owned at the moment: 1602
# Cash capital at the moment: $0.12933111021465038
#
#
# Price increase from previously bought: 58.14616018548764%
# Share price: $0.28757015476497183
# Shares owned at the moment: 0
# Cash capital at the moment: $459.5498287268824
#
#
# Share price: $0.2006542549196515
# Shares owned at the moment: 2283
# Cash capital at the moment: $0.19640716936874014
#
#
# Price increase from previously bought: -28.453218506905397%
# Share price: $0.14395645589260098
# Shares owned at the moment: 0
# Cash capital at the moment: $327.94520135296904
#
#
# Share price: $0.16031164050489966
# Shares owned at the moment: 2040
# Cash capital at the moment: $0.010106419741248374
#
#
# Price increase from previously bought: 77.43662219152283%
# Share price: $0.2852338016814133
# Shares owned at the moment: 0
# Cash capital at the moment: $580.2869002223918
#
#
# Share price: $0.48694711143097025
# Shares owned at the moment: 1188
# Cash capital at the moment: $0.20287562935413916
#
#
# Price increase from previously bought: 5.818662234335159%
# Share price: $0.5166979416325288
# Shares owned at the moment: 0
# Cash capital at the moment: $612.3519781134848
#
#
# Share price: $0.5168536192795001
# Shares owned at the moment: 1181
# Cash capital at the moment: $0.2692424023802005
#
#
# Price increase from previously bought: 7.780248208028806%
# Share price: $0.5585980455443875
# Shares owned at the moment: 0
# Cash capital at the moment: $658.1593473878851
#
#
# Share price: $0.4923986811845389
# Shares owned at the moment: 1332
# Cash capital at the moment: $0.48064768090034704
#
#
# Price increase from previously bought: 23.354326074676713%
# Share price: $0.6090654112314173
# Shares owned at the moment: 0
# Cash capital at the moment: $809.5247688398075
#
#
# Share price: $0.6609345887685827
# Shares owned at the moment: 1221
# Cash capital at the moment: $0.3043828379303477
#
#
# Price increase from previously bought: 42.17123185967804%
# Share price: $0.9422429084672486
# Shares owned at the moment: 0
# Cash capital at the moment: $1147.6191579505348
#
#
# Share price: $0.781339721424952
# Shares owned at the moment: 1464
# Cash capital at the moment: $0.5921320659481353
#
#
# Price increase from previously bought: 17.45933087608462%
# Share price: $0.9202802387786131
# Shares owned at the moment: 0
# Cash capital at the moment: $1344.1773533965152
#
#
# Share price: $0.6863240680969678
# Shares owned at the moment: 1953
# Cash capital at the moment: $0.10037341440511227
#
#
# Price increase from previously bought: 8.711075860573402%
# Share price: $0.7481620815836434
# Shares owned at the moment: 0
# Cash capital at the moment: $1457.2427272475952
#
#
# Share price: $0.7107787685161331
# Shares owned at the moment: 2044
# Cash capital at the moment: $0.4156369427901154
#
#
# Price increase from previously bought: -23.72394744913069%
# Share price: $0.5436449104580203
# Shares owned at the moment: 0
# Cash capital at the moment: $1108.570005877299
#
#
# Share price: $0.4542367422063729
# Shares owned at the moment: 2433
# Cash capital at the moment: $0.3728276062765872
#
#
# Price increase from previously bought: -12.619420338486831%
# Share price: $0.3980062137960345
# Shares owned at the moment: 0
# Cash capital at the moment: $966.0589856970727
#
#
# Share price: $0.3081310126034722
# Shares owned at the moment: 3126
# Cash capital at the moment: $0.1925920487727808
#
#
# Price increase from previously bought: -13.683945209625048%
# Share price: $0.2666979416325288
# Shares owned at the moment: 0
# Cash capital at the moment: $831.5976887368138
#
#
# Share price: $0.42666658744140107
# Shares owned at the moment: 1943
# Cash capital at the moment: $0.30472309482524906
#
#
# Price increase from previously bought: 12.14051707873789%
# Share price: $0.47978189918172975
# Shares owned at the moment: 0
# Cash capital at the moment: $929.9573585721233
#
#
# Share price: $0.3952025900957643
# Shares owned at the moment: 2346
# Cash capital at the moment: $0.2624326974574842
#
#
# Price increase from previously bought: 13.443307219131807%
# Share price: $0.44956379836345994
# Shares owned at the moment: 0
# Cash capital at the moment: $1052.0387428129925
#
#
# Share price: $0.3168537143498191
# Shares owned at the moment: 3311
# Cash capital at the moment: $0.0510623181576193
#
#
# Price increase from previously bought: 3.6967289303636797%
# Share price: $0.3294704963526274
# Shares owned at the moment: 0
# Cash capital at the moment: $1087.927964504792
#
#
#
#
# Capital at the end of test period: $1087.927964504792
# profit gained: 987.9279645047922%
#
#
# Capital at the end of test period if Buy and Hold: $64.93475897926798
# profit gained: -35.06524102073202%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.338710      7.291667       4.225352      91.358025
# 1       0.424658      4.651163      11.904762      92.307692
# 2       0.387234      8.421053       8.411215      90.751445
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         42.708333           46.478873          82.500000      -0.543194
# 1         47.058824           57.142857          85.714286     208.213911
# 2         47.894737           52.830189          84.971098     987.927965
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
#
#
# mark down phase data
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1944 - accuracy: 0.3237 - mse: 1.3401 - weighted_accuracy: 0.3237 - weighted_mse: 1.3401
# Test loss: 0.19441011548042297
# Test accuracy: 0.32374101877212524
#
#
# number of predictions: 278
# actual predicted buys: 14
# actual buys but predicted sell: 0
# actual buys but predicted hold: 2
# actual sells but predicted buy: 4
# actual predicted sells: 5
# actual sells but predicted hold: 4
# actual holds but predicted buy: 137
# actual holds but predicted sell: 41
# actual predicted holds: 71
# Percentage buys correct: 9.03225806451613%
# Percentage sells correct: 10.869565217391305%
# Percentage holds correct: 92.20779220779221%
# actual buys: 16
# actual sells: 13
# actual holds: 249
#
#
# Percentage low buys correct: 46.753246753246756%
# Percentage high sells correct: 50.0%
# Percentage mid holds correct: 81.81818181818181%
#
#
# Capital: 100
# Share price: $0.8161453854507071
# Shares owned at the moment: 122
# Cash capital at the moment: $0.15644619819501315
#
#
# Price increase from previously bought: 10.378190449104174%
# Share price: $0.9033238357910663
# Shares owned at the moment: 0
# Cash capital at the moment: $110.0588890177972
#
#
# Share price: $0.8942895141852923
# Shares owned at the moment: 122
# Cash capital at the moment: $0.6555341551823659
#
#
# Price increase from previously bought: -5.983130932496817%
# Share price: $0.8430951548904956
# Shares owned at the moment: 0
# Cash capital at the moment: $103.23028462735707
#
#
# Share price: $0.8586116581292894
# Shares owned at the moment: 119
# Cash capital at the moment: $0.7745166448488163
#
#
# Price increase from previously bought: -4.015015522072895%
# Share price: $0.8264046470147189
# Shares owned at the moment: 0
# Cash capital at the moment: $98.84622871886481
#
#
# Share price: $0.7650530525639275
# Shares owned at the moment: 128
# Cash capital at the moment: $0.6501393161795761
#
#
# Price increase from previously bought: -1.1923941145369543%
# Share price: $0.7580094141557981
# Shares owned at the moment: 0
# Cash capital at the moment: $97.40852501433889
#
#
# Share price: $0.6457696953997695
# Shares owned at the moment: 150
# Cash capital at the moment: $0.27669070502106763
#
#
# Price increase from previously bought: -8.21167803028402%
# Share price: $0.5943712054061847
# Shares owned at the moment: 0
# Cash capital at the moment: $89.18719339371872
#
#
# Share price: $0.6614393940160966
# Shares owned at the moment: 134
# Cash capital at the moment: $0.3105741788668297
#
#
# Price increase from previously bought: -0.8514105323424004%
# Share price: $0.6576113008810954
# Shares owned at the moment: 0
# Cash capital at the moment: $88.18815873255893
#
#
# Share price: $0.5839587484646389
# Shares owned at the moment: 150
# Cash capital at the moment: $0.35346347912143017
#
#
# Price increase from previously bought: 9.270412588025456%
# Share price: $0.6398488926591065
# Shares owned at the moment: 0
# Cash capital at the moment: $96.06685970976552
#
#
# Share price: $0.5795691985545273
# Shares owned at the moment: 165
# Cash capital at the moment: $0.17496242442440746
#
#
# Price increase from previously bought: 13.56714549044582%
# Share price: $0.6600102454763165
# Shares owned at the moment: 0
# Cash capital at the moment: $108.77717327913174
#
#
# Share price: $0.7046202409645685
# Shares owned at the moment: 153
# Cash capital at the moment: $0.6738074451669149
#
#
# Price increase from previously bought: -6.522939680541395%
# Share price: $0.6604695979606556
# Shares owned at the moment: 0
# Cash capital at the moment: $101.44776334980527
#
#
# Share price: $0.6394916444655385
# Shares owned at the moment: 158
# Cash capital at the moment: $0.13022440472990127
#
#
# Price increase from previously bought: 9.70714339175096%
# Share price: $0.7034973274143479
# Shares owned at the moment: 0
# Cash capital at the moment: $110.97713254743533
#
#
# Share price: $0.5948815710945323
# Shares owned at the moment: 186
# Cash capital at the moment: $0.024878400237469123
#
#
# Price increase from previously bought: -1.3609166564143682%
# Share price: $0.5883993894615132
# Shares owned at the moment: 0
# Cash capital at the moment: $109.16619855236935
#
#
# Share price: $0.5460861563949568
# Shares owned at the moment: 199
# Cash capital at the moment: $0.19620778068579625
#
#
# Price increase from previously bought: -18.021623241098283%
# Share price: $0.44890366627613654
# Shares owned at the moment: 0
# Cash capital at the moment: $89.28237483826734
#
#
# Share price: $0.3979134376801282
# Shares owned at the moment: 223
# Cash capital at the moment: $0.3036578199414066
#
#
#
#
# Capital at the end of test period: $4.014494239012708
# profit gained: -95.9855057609873%
#
#
# Capital at the end of test period if Buy and Hold: $2.3958591597330687
# profit gained: -97.60414084026694%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.338710      7.291667       4.225352      91.358025
# 1       0.424658      4.651163      11.904762      92.307692
# 2       0.387234      8.421053       8.411215      90.751445
# 3       0.323741      9.032258      10.869565      92.207792
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         42.708333           46.478873          82.500000      -0.543194
# 1         47.058824           57.142857          85.714286     208.213911
# 2         47.894737           52.830189          84.971098     987.927965
# 3         46.753247           50.000000          81.818182     -95.985506
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
#
#
# bull phase data
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1722 - accuracy: 0.4856 - mse: 1.2117 - weighted_accuracy: 0.4856 - weighted_mse: 1.2117
# Test loss: 0.17224791646003723
# Test accuracy: 0.48557692766189575
#
#
# number of predictions: 208
# actual predicted buys: 4
# actual buys but predicted sell: 0
# actual buys but predicted hold: 5
# actual sells but predicted buy: 1
# actual predicted sells: 5
# actual sells but predicted hold: 4
# actual holds but predicted buy: 28
# actual holds but predicted sell: 69
# actual predicted holds: 92
# Percentage buys correct: 12.121212121212121%
# Percentage sells correct: 6.756756756756757%
# Percentage holds correct: 91.08910891089108%
# actual buys: 9
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 48.484848484848484%
# Percentage high sells correct: 48.648648648648646%
# Percentage mid holds correct: 86.0%
#
#
# Capital: 100
# Share price: $0.12558233818043063
# Shares owned at the moment: 794
# Cash capital at the moment: $0.013414449321103916
#
#
# Price increase from previously bought: 53.6093028986498%
# Share price: $0.1934366461669521
# Shares owned at the moment: 0
# Cash capital at the moment: $153.1797425889755
#
#
# Share price: $0.02378936423929944
# Shares owned at the moment: 6421
# Cash capital at the moment: $0.008168162037293314
#
#
# Price increase from previously bought: 308.3270895449117%
# Share price: $0.09740554927077326
# Shares owned at the moment: 0
# Cash capital at the moment: $623.7292371920364
#
#
# Share price: $0.4790917876756311
# Shares owned at the moment: 1298
# Cash capital at the moment: $0.15797865295905922
#
#
# Price increase from previously bought: 8.133284913801475%
# Share price: $0.5194823464072713
# Shares owned at the moment: 0
# Cash capital at the moment: $672.5917720540964
#
#
# Share price: $0.7828490672363122
# Shares owned at the moment: 856
# Cash capital at the moment: $0.6301437955388565
#
#
# Price increase from previously bought: 1.2171906998427406%
# Share price: $0.7945568723180287
# Shares owned at the moment: 0
# Cash capital at the moment: $678.9004396223348
#
#
# Share price: $0.7851377013084047
# Shares owned at the moment: 862
# Cash capital at the moment: $0.2505721735384441
#
#
# Price increase from previously bought: -4.953151036865167%
# Share price: $0.7483008288892949
# Shares owned at the moment: 0
# Cash capital at the moment: $643.5120395612286
#
#
# Share price: $0.8081506736041677
# Shares owned at the moment: 794
# Cash capital at the moment: $0.07580772370465638
#
#
# Price increase from previously bought: 1.8545384985939162%
# Share price: $0.8254017688549782
# Shares owned at the moment: 0
# Cash capital at the moment: $653.6425474322625
#
#
# Share price: $0.8058505275707262
# Shares owned at the moment: 808
# Cash capital at the moment: $0.7247212828535794
#
#
# Price increase from previously bought: 8.636659942680613%
# Share price: $0.8778565823008366
# Shares owned at the moment: 0
# Cash capital at the moment: $708.0822424560571
#
#
# Share price: $0.8191683225640338
# Shares owned at the moment: 862
# Cash capital at the moment: $0.017309897221821302
#
#
# Price increase from previously bought: -0.1286297744194198%
# Share price: $0.8203644434261506
# Shares owned at the moment: 0
# Cash capital at the moment: $705.2267862174218
#
#
# Share price: $0.8123484681931528
# Shares owned at the moment: 865
# Cash capital at the moment: $0.6129873116302633
#
#
# Price increase from previously bought: 19.385847786218037%
# Share price: $0.9724961357715107
# Shares owned at the moment: 0
# Cash capital at the moment: $839.5088195710205
#
#
#
#
# Capital at the end of test period: $839.5088195710205
# profit gained: 739.5088195710205%
#
#
# Capital at the end of test period if Buy and Hold: $778.7940878989605
# profit gained: 678.7940878989605%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.338710      7.291667       4.225352      91.358025
# 1       0.424658      4.651163      11.904762      92.307692
# 2       0.387234      8.421053       8.411215      90.751445
# 3       0.323741      9.032258      10.869565      92.207792
# 4       0.485577     12.121212       6.756757      91.089109
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         42.708333           46.478873          82.500000      -0.543194
# 1         47.058824           57.142857          85.714286     208.213911
# 2         47.894737           52.830189          84.971098     987.927965
# 3         46.753247           50.000000          81.818182     -95.985506
# 4         48.484848           48.648649          86.000000     739.508820
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
#
#
# bear phase data
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1932 - accuracy: 0.3647 - mse: 1.3136 - weighted_accuracy: 0.3647 - weighted_mse: 1.3136
# Test loss: 0.19322076439857483
# Test accuracy: 0.364705890417099
#
#
# number of predictions: 595
# actual predicted buys: 22
# actual buys but predicted sell: 3
# actual buys but predicted hold: 7
# actual sells but predicted buy: 9
# actual predicted sells: 12
# actual sells but predicted hold: 6
# actual holds but predicted buy: 240
# actual holds but predicted sell: 113
# actual predicted holds: 183
# Percentage buys correct: 8.118081180811808%
# Percentage sells correct: 9.375%
# Percentage holds correct: 93.36734693877551%
# actual buys: 32
# actual sells: 27
# actual holds: 536
#
#
# Percentage low buys correct: 47.97047970479705%
# Percentage high sells correct: 49.21875%
# Percentage mid holds correct: 84.1025641025641%
#
#
# Capital: 100
# Share price: $0.7488095723945759
# Shares owned at the moment: 133
# Cash capital at the moment: $0.1344497704180867
#
#
# Price increase from previously bought: 10.403669037589736%
# Share price: $0.8289867034438764
# Shares owned at the moment: 0
# Cash capital at the moment: $110.08647944166904
#
#
# Share price: $0.8968667365621285
# Shares owned at the moment: 122
# Cash capital at the moment: $0.36783879097278316
#
#
# Price increase from previously bought: 0.05392746214383237%
# Share price: $0.8998181076155566
# Shares owned at the moment: 0
# Cash capital at the moment: $109.84375894496566
#
#
# Share price: $0.851121517247526
# Shares owned at the moment: 128
# Cash capital at the moment: $0.6006099632111841
#
#
# Price increase from previously bought: -6.268181857155675%
# Share price: $0.7999655448210515
# Shares owned at the moment: 0
# Cash capital at the moment: $102.71461182852877
#
#
# Share price: $0.7950467807041611
# Shares owned at the moment: 128
# Cash capital at the moment: $0.6687674315882788
#
#
# Price increase from previously bought: -2.0018304227460204%
# Share price: $0.7812739034269881
# Shares owned at the moment: 0
# Cash capital at the moment: $100.39681865623645
#
#
# Share price: $0.8889966013918106
# Shares owned at the moment: 112
# Cash capital at the moment: $0.555388347124989
#
#
# Price increase from previously bought: 1.8777121170961086%
# Share price: $0.9081800441420332
# Shares owned at the moment: 0
# Cash capital at the moment: $101.99183383743697
#
#
# Share price: $0.9032612800251435
# Shares owned at the moment: 112
# Cash capital at the moment: $0.5483660003731501
#
#
# Price increase from previously bought: -4.401596516484951%
# Share price: $0.8658779972370186
# Shares owned at the moment: 0
# Cash capital at the moment: $97.26001126777024
#
#
# Share price: $0.7384800551658143
# Shares owned at the moment: 131
# Cash capital at the moment: $0.2530866011750845
#
#
# Price increase from previously bought: -17.87685284164987%
# Share price: $0.6081308358605938
# Shares owned at the moment: 0
# Cash capital at the moment: $79.69914696529409
#
#
# Share price: $0.5717314372430228
# Shares owned at the moment: 139
# Cash capital at the moment: $0.009932846627776826
#
#
# Price increase from previously bought: 7.533383721284004%
# Share price: $0.6164928662064825
# Shares owned at the moment: 0
# Cash capital at the moment: $85.46678685122141
#
#
# Share price: $0.5707476468918803
# Shares owned at the moment: 149
# Cash capital at the moment: $0.1915236160173066
#
#
# Price increase from previously bought: -6.806146101999078%
# Share price: $0.5333644579231666
# Shares owned at the moment: 0
# Cash capital at the moment: $79.44428175993511
#
#
# Share price: $0.5235268358699757
# Shares owned at the moment: 151
# Cash capital at the moment: $0.1743350249737574
#
#
# Price increase from previously bought: -23.04289849178469%
# Share price: $0.4039990289690888
# Shares owned at the moment: 0
# Cash capital at the moment: $61.01042780252675
#
#
# Share price: $0.38432369104329556
# Shares owned at the moment: 158
# Cash capital at the moment: $0.12029597392773184
#
#
# Price increase from previously bought: 5.214101146430217%
# Share price: $0.40547471449580297
# Shares owned at the moment: 0
# Cash capital at the moment: $64.00912210081617
#
#
# Share price: $0.5402508965617531
# Shares owned at the moment: 118
# Cash capital at the moment: $0.0842048905950179
#
#
# Price increase from previously bought: 7.352755486511731%
# Share price: $0.5815691531156252
# Shares owned at the moment: 0
# Cash capital at the moment: $68.52064576805277
#
#
# Share price: $0.572223332418594
# Shares owned at the moment: 119
# Cash capital at the moment: $0.23880912470609417
#
#
# Price increase from previously bought: -33.706753630609974%
# Share price: $0.3803886234581365
# Shares owned at the moment: 0
# Cash capital at the moment: $45.38057313919766
#
#
# Share price: $0.35972949518120056
# Shares owned at the moment: 125
# Cash capital at the moment: $0.2907292275790496
#
#
# Price increase from previously bought: 19.36191395378821%
# Share price: $0.430560805533469
# Shares owned at the moment: 0
# Cash capital at the moment: $53.96282464236054
#
#
# Share price: $0.43006891035789774
# Shares owned at the moment: 125
# Cash capital at the moment: $0.05637465968779054
#
#
# Price increase from previously bought: -13.733283950290431%
# Share price: $0.37202659311224806
# Shares owned at the moment: 0
# Cash capital at the moment: $46.43181465733646
#
#
# Share price: $0.3459567117234391
# Shares owned at the moment: 133
# Cash capital at the moment: $0.2930383308062119
#
#
# Price increase from previously bought: 9.3675359877603%
# Share price: $0.379404833106994
# Shares owned at the moment: 0
# Cash capital at the moment: $50.615113816327536
#
#
# Share price: $0.3592376000056291
# Shares owned at the moment: 140
# Cash capital at the moment: $0.18354333953729451
#
#
# Price increase from previously bought: 3.8222103819152142%
# Share price: $0.37399407999512146
# Shares owned at the moment: 0
# Cash capital at the moment: $52.398726818056176
#
#
# Share price: $0.3134923806910269
# Shares owned at the moment: 166
# Cash capital at the moment: $0.21588235156025348
#
#
# Price increase from previously bought: 10.522487865825303%
# Share price: $0.3474323972501533
# Shares owned at the moment: 0
# Cash capital at the moment: $57.731057405741
#
#
# Share price: $0.3041465599939953
# Shares owned at the moment: 189
# Cash capital at the moment: $0.08927739231900489
#
#
# Price increase from previously bought: 5.854503535691014%
# Share price: $0.3228382013880583
# Shares owned at the moment: 0
# Cash capital at the moment: $60.937902299490574
#
#
# Share price: $0.2957845296481071
# Shares owned at the moment: 205
# Cash capital at the moment: $0.13532519303949897
#
#
# Price increase from previously bought: 14.651558461593739%
# Share price: $0.34005415725540666
# Shares owned at the moment: 0
# Cash capital at the moment: $69.65472189924512
#
#
# Share price: $0.3380865765531217
# Shares owned at the moment: 205
# Cash capital at the moment: $0.1563773983233574
#
#
# Price increase from previously bought: 23.520754275478552%
# Share price: $0.41875550895858116
# Shares owned at the moment: 0
# Cash capital at the moment: $85.76518331665709
#
#
# Share price: $0.31595176274947157
# Shares owned at the moment: 270
# Cash capital at the moment: $0.22361319045828054
#
#
# Price increase from previously bought: -10.05537828881361%
# Share price: $0.2849631172437731
# Shares owned at the moment: 0
# Cash capital at the moment: $76.95206973172351
#
#
# Share price: $0.1929807834389975
# Shares owned at the moment: 397
# Cash capital at the moment: $0.12801193612197892
#
#
# Price increase from previously bought: 9.130749767324886%
# Share price: $0.21118052965748857
# Shares owned at the moment: 0
# Cash capital at the moment: $83.73612586689137
#
#
# Share price: $0.12952780690088683
# Shares owned at the moment: 644
# Cash capital at the moment: $0.0908244766987849
#
#
# Price increase from previously bought: 32.673568628064565%
# Share price: $0.172321748981473
# Shares owned at the moment: 0
# Cash capital at the moment: $110.76084900332121
#
#
# Share price: $0.06853421242122103
# Shares owned at the moment: 1611
# Cash capital at the moment: $0.04860909815502623
#
#
# Price increase from previously bought: 3.304459204067345%
# Share price: $0.07099359447966579
# Shares owned at the moment: 0
# Cash capital at the moment: $114.10477043295306
#
#
# Share price: $0.07099359447966579
# Shares owned at the moment: 1602
# Cash capital at the moment: $0.06026979604830274
#
#
# Price increase from previously bought: 4.562429482018371%
# Share price: $0.07443676688925314
# Shares owned at the moment: 0
# Cash capital at the moment: $118.98003917610123
#
#
# Share price: $0.06509104001163345
# Shares owned at the moment: 1822
# Cash capital at the moment: $0.05802561892679137
#
#
# Price increase from previously bought: -10.824934316549895%
# Share price: $0.05820460137304705
# Shares owned at the moment: 0
# Cash capital at the moment: $105.81517516543887
#
#
# Share price: $0.05279394208058618
# Shares owned at the moment: 1998
# Cash capital at the moment: $0.04280257366589524
#
#
# Price increase from previously bought: 176.26423071545227%
# Share price: $0.1462518675926644
# Shares owned at the moment: 0
# Cash capital at the moment: $291.45045313732146
#
#
#
#
# Capital at the end of test period: $291.45045313732146
# profit gained: 191.45045313732146%
#
#
# Capital at the end of test period if Buy and Hold: $8.115342010843221
# profit gained: -91.88465798915678%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.338710      7.291667       4.225352      91.358025
# 1       0.424658      4.651163      11.904762      92.307692
# 2       0.387234      8.421053       8.411215      90.751445
# 3       0.323741      9.032258      10.869565      92.207792
# 4       0.485577     12.121212       6.756757      91.089109
# 5       0.364706      8.118081       9.375000      93.367347
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         42.708333           46.478873          82.500000      -0.543194
# 1         47.058824           57.142857          85.714286     208.213911
# 2         47.894737           52.830189          84.971098     987.927965
# 3         46.753247           50.000000          81.818182     -95.985506
# 4         48.484848           48.648649          86.000000     739.508820
# 5         47.970480           49.218750          84.102564     191.450453
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
# 5         -91.884658
#
#
# full cycle data
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1954 - accuracy: 0.3446 - mse: 1.3360 - weighted_accuracy: 0.3446 - weighted_mse: 1.3360
# Test loss: 0.19542260468006134
# Test accuracy: 0.34460195899009705
#
#
# number of predictions: 917
# actual predicted buys: 29
# actual buys but predicted sell: 3
# actual buys but predicted hold: 14
# actual sells but predicted buy: 14
# actual predicted sells: 12
# actual sells but predicted hold: 14
# actual holds but predicted buy: 401
# actual holds but predicted sell: 155
# actual predicted holds: 275
# Percentage buys correct: 6.531531531531532%
# Percentage sells correct: 7.0588235294117645%
# Percentage holds correct: 90.75907590759076%
# actual buys: 46
# actual sells: 40
# actual holds: 831
#
#
# Percentage low buys correct: 45.598194130925506%
# Percentage high sells correct: 46.470588235294116%
# Percentage mid holds correct: 83.4983498349835%
#
#
# Capital: 100
# Share price: $0.33263976868110035
# Shares owned at the moment: 299
# Cash capital at the moment: $0.26719611455295933
#
#
# Price increase from previously bought: 7.9696012467749044%
# Share price: $0.3601374938707197
# Shares owned at the moment: 0
# Cash capital at the moment: $107.65218372756296
#
#
# Share price: $0.37205317769998325
# Shares owned at the moment: 288
# Cash capital at the moment: $0.20620243322939302
#
#
# Price increase from previously bought: -65.13493082699001%
# Share price: $0.130073318409336
# Shares owned at the moment: 0
# Cash capital at the moment: $37.56430006693797
#
#
# Share price: $0.131906497174882
# Shares owned at the moment: 283
# Cash capital at the moment: $0.1321051350200051
#
#
# Price increase from previously bought: 24.672795132591595%
# Share price: $0.16490375866113927
# Shares owned at the moment: 0
# Cash capital at the moment: $46.67153248594438
#
#
# Share price: $0.36288724016582397
# Shares owned at the moment: 128
# Cash capital at the moment: $0.09422943618054092
#
#
# Price increase from previously bought: 0.7333130797128717%
# Share price: $0.3665535976969161
# Shares owned at the moment: 0
# Cash capital at the moment: $46.88406307499648
#
#
# Share price: $0.47746102227852205
# Shares owned at the moment: 97
# Cash capital at the moment: $0.4429811862870494
#
#
# Price increase from previously bought: -6.017607595324559%
# Share price: $0.4499632970889027
# Shares owned at the moment: 0
# Cash capital at the moment: $43.96939329441214
#
#
# Share price: $0.4352978669645349
# Shares owned at the moment: 100
# Cash capital at the moment: $0.3198996845434081
#
#
# Price increase from previously bought: -6.783885836468439%
# Share price: $0.4068836179517865
# Shares owned at the moment: 0
# Cash capital at the moment: $40.89636848478531
#
#
# Share price: $0.41879921436819145
# Shares owned at the moment: 97
# Cash capital at the moment: $0.16113000063803185
#
#
# Price increase from previously bought: 8.892729806695222%
# Share price: $0.45729601215108695
# Shares owned at the moment: 0
# Cash capital at the moment: $44.39685946805216
#
#
# Share price: $0.4857103485766936
# Shares owned at the moment: 91
# Cash capital at the moment: $0.07566873284172715
#
#
# Price increase from previously bought: 1.984077089693792%
# Share price: $0.49670942116996963
# Shares owned at the moment: 0
# Cash capital at the moment: $45.151924526661176
#
#
# Share price: $0.5443721564870241
# Shares owned at the moment: 82
# Cash capital at the moment: $0.39065177343737645
#
#
# Price increase from previously bought: 1.9086208508131808%
# Share price: $0.5562877529034291
# Shares owned at the moment: 0
# Cash capital at the moment: $45.880804623238845
#
#
# ...
# Test loss: 0.20877023041248322
# Test accuracy: 0.7210084199905396
#
#
# number of predictions: 595
# actual predicted buys: 9
# actual buys but predicted sell: 0
# actual buys but predicted hold: 23
# actual sells but predicted buy: 1
# actual predicted sells: 3
# actual sells but predicted hold: 23
# actual holds but predicted buy: 49
# actual holds but predicted sell: 70
# actual predicted holds: 417
# Percentage buys correct: 15.254237288135593%
# Percentage sells correct: 4.109589041095891%
# Percentage holds correct: 90.06479481641469%
# actual buys: 32
# actual sells: 27
# actual holds: 536
#
#
# Percentage low buys correct: 45.76271186440678%
# Percentage high sells correct: 47.945205479452056%
# Percentage mid holds correct: 83.76623376623377%
#
#
# Capital: 100
# Share price: $1.0099999999999998
# Shares owned at the moment: 98
# Cash capital at the moment: $0.747805000000028
#
#
# Price increase from previously bought: -2.1683877011705155%
# Share price: $0.9908165572497777
# Shares owned at the moment: 0
# Cash capital at the moment: $97.58080254829943
#
#
# Share price: $0.9426119558767306
# Shares owned at the moment: 103
# Cash capital at the moment: $0.2247762564940814
#
#
# Price increase from previously bought: -10.474074495179009%
# Share price: $0.8462027531306368
# Shares owned at the moment: 0
# Cash capital at the moment: $87.1439728991254
#
#
# Share price: $0.7173291255327182
# Shares owned at the moment: 121
# Cash capital at the moment: $0.10845744314548256
#
#
# Price increase from previously bought: 8.615594242649394%
# Share price: $0.7812739034269881
# Shares owned at the moment: 0
# Cash capital at the moment: $94.38263086644571
#
#
# Share price: $0.8889966013918106
# Shares owned at the moment: 105
# Cash capital at the moment: $0.7812899516537044
#
#
# Price increase from previously bought: 8.168057190691957%
# Share price: $0.9642547806853977
# Shares owned at the moment: 0
# Cash capital at the moment: $101.74961335569755
#
#
# Share price: $0.9362174124137154
# Shares owned at the moment: 108
# Cash capital at the moment: $0.36007624352942
#
#
# Price increase from previously bought: -35.69354377991295%
# Share price: $0.603703873099864
# Shares owned at the moment: 0
# Cash capital at the moment: $65.38079448800407
#
#
# Share price: $0.5707476468918803
# Shares owned at the moment: 114
# Cash capital at the moment: $0.13663335502910456
#
#
# Price increase from previously bought: -5.51694253158349%
# Share price: $0.5407427917373245
# Shares owned at the moment: 0
# Cash capital at the moment: $61.61178874787445
#
#
# Share price: $0.529429390338008
# Shares owned at the moment: 116
# Cash capital at the moment: $0.029091493147703318
#
#
# Price increase from previously bought: -25.290684604607105%
# Share price: $0.39662078897434283
# Shares owned at the moment: 0
# Cash capital at the moment: $45.91058098248865
#
#
# Share price: $0.3695671172343916
# Shares owned at the moment: 123
# Cash capital at the moment: $0.3288194852539519
#
#
# Price increase from previously bought: 5.433247259222518%
# Share price: $0.3907181406868988
# Shares owned at the moment: 0
# Cash capital at the moment: $48.25499037865516
#
#
# Share price: $0.4217068800120086
# Shares owned at the moment: 114
# Cash capital at the moment: $0.04820095040241057
#
#
# Price increase from previously bought: 56.257893323240296%
# Share price: $0.6607623999943707
# Shares owned at the moment: 0
# Cash capital at the moment: $75.16796553736245
#
#
# Share price: $0.4615494510391672
# Shares owned at the moment: 162
# Cash capital at the moment: $0.19133418857940399
#
#
# Price increase from previously bought: -17.385338923673764%
# Share price: $0.38235611034101036
# Shares owned at the moment: 0
# Cash capital at the moment: $61.96268441666616
#
#
# Share price: $0.4379390455282145
# Shares owned at the moment: 141
# Cash capital at the moment: $0.043468132284345984
#
#
# Price increase from previously bought: -20.436034854686604%
# Share price: $0.3493998841330267
# Shares owned at the moment: 0
# Cash capital at the moment: $49.17337198996852
#
#
# Share price: $0.3744859751706927
# Shares owned at the moment: 130
# Cash capital at the moment: $0.3563164816549431
#
#
# Price increase from previously bought: 3.000475919042689%
# Share price: $0.3867830731017402
# Shares owned at the moment: 0
# Cash capital at the moment: $50.4998410362473
#
#
# Share price: $0.39317761656475547
# Shares owned at the moment: 128
# Cash capital at the moment: $0.03470759492780218
#
#
# Price increase from previously bought: -16.867546496631093%
# Share price: $0.3277570593243594
# Shares owned at the moment: 0
# Cash capital at the moment: $41.87224070356363
#
#
# Share price: $0.3134923806910269
# Shares owned at the moment: 133
# Cash capital at the moment: $0.06309423341930653
#
#
# Price increase from previously bought: 1.9163845482582875%
# Share price: $0.32037872551020186
# Shares owned at the moment: 0
# Cash capital at the moment: $42.5562862074208
#
#
# Share price: $0.2810280496586145
# Shares owned at the moment: 151
# Cash capital at the moment: $0.00435381134926871
#
#
# Price increase from previously bought: 17.529879786242386%
# Share price: $0.33120023173394697
# Shares owned at the moment: 0
# Cash capital at the moment: $49.87805790694774
#
#
# Share price: $0.3361190896702483
# Shares owned at the moment: 147
# Cash capital at the moment: $0.33267558342204495
#
#
# Price increase from previously bought: -32.673125051484256%
# Share price: $0.22692079999812365
# Shares owned at the moment: 0
# Cash capital at the moment: $33.59830044974698
#
#
# Share price: $0.29283325241409075
# Shares owned at the moment: 114
# Cash capital at the moment: $0.12350644990881676
#
#
# Price increase from previously bought: 15.80705747525668%
# Share price: $0.34005415725540666
# Shares owned at the moment: 0
# Cash capital at the moment: $38.783073398725605
#
#
# Share price: $0.20035911725315503
# Shares owned at the moment: 193
# Cash capital at the moment: $0.007423167384573048
#
#
# Price increase from previously bought: -67.357074825015%
# Share price: $0.06558293518720491
# Shares owned at the moment: 0
# Cash capital at the moment: $12.630121515664511
#
#
# Share price: $0.11280374620910914
# Shares owned at the moment: 111
# Cash capital at the moment: $0.07447234292306426
#
#
#
#
# Capital at the end of test period: $6.735216994706449
# profit gained: -93.26478300529355%
#
#
# Capital at the end of test period if Buy and Hold: $8.115342010843221
# profit gained: -91.88465798915678%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.745968     13.333333       0.000000      93.298969
# 1       0.803653      5.882353       8.333333      91.578947
# 2       0.751064     11.363636      10.000000      91.223404
# 3       0.784173      9.523810       0.000000      89.256198
# 4       0.721154     13.333333       8.571429      91.772152
# 5       0.721008     15.254237       4.109589      90.064795
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         46.666667           54.166667          83.419689    4311.081815
# 1         41.176471           58.333333          85.714286      96.201171
# 2         59.090909           66.000000          85.066667      73.186112
# 3         66.666667           33.333333          82.572614     -77.815589
# 4         46.666667           55.882353          86.075949      72.372171
# 5         45.762712           47.945205          83.766234     -93.264783
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
# 5         -91.884658
#
#
# full cycle data
#
#
# 29/29 [==============================] - 0s 4ms/step - loss: 0.2079 - accuracy: 0.7688 - mse: 7.5630 - weighted_accuracy: 0.7688 - weighted_mse: 7.5630
# Test loss: 0.2079135626554489
# Test accuracy: 0.7688113451004028
#
#
# number of predictions: 917
# actual predicted buys: 10
# actual buys but predicted sell: 3
# actual buys but predicted hold: 33
# actual sells but predicted buy: 2
# actual predicted sells: 3
# actual sells but predicted hold: 35
# actual holds but predicted buy: 76
# actual holds but predicted sell: 63
# actual predicted holds: 692
# Percentage buys correct: 11.363636363636363%
# Percentage sells correct: 4.3478260869565215%
# Percentage holds correct: 91.05263157894737%
# actual buys: 46
# actual sells: 40
# actual holds: 831
#
#
# Percentage low buys correct: 50.0%
# Percentage high sells correct: 47.82608695652174%
# Percentage mid holds correct: 84.32147562582345%
#
#
# Capital: 100
# Share price: $0.33905587250729685
# Shares owned at the moment: 294
# Cash capital at the moment: $0.04344680993257555
#
#
# Price increase from previously bought: -36.39993515636088%
# Share price: $0.2162327640964269
# Shares owned at the moment: 0
# Cash capital at the moment: $63.44105526451012
#
#
# Share price: $0.36288724016582397
# Shares owned at the moment: 174
# Cash capital at the moment: $0.1250339312374038
#
#
# Price increase from previously bought: 23.907191886840252%
# Share price: $0.45087990832489044
# Shares owned at the moment: 0
# Cash capital at the moment: $78.36239194363486
#
#
# Share price: $0.4829606022815893
# Shares owned at the moment: 161
# Cash capital at the moment: $0.39190416963880637
#
#
# Price increase from previously bought: -2.923965691703645%
# Share price: $0.470128307216338
# Shares owned at the moment: 0
# Cash capital at the moment: $75.87441232344919
#
#
# Share price: $0.47196144227545456
# Shares owned at the moment: 160
# Cash capital at the moment: $0.15291852477525936
#
#
# Price increase from previously bought: 7.666490064757658%
# Share price: $0.5095417162352209
# Shares owned at the moment: 0
# Cash capital at the moment: $81.45539476726711
#
#
# Share price: $0.4563794883279577
# Shares owned at the moment: 177
# Cash capital at the moment: $0.45408261727496324
#
#
# Price increase from previously bought: 2.930370327426468%
# Share price: $0.47104491845232555
# Shares owned at the moment: 0
# Cash capital at the moment: $83.59975206927992
#
#
# Share price: $0.46462872721327075
# Shares owned at the moment: 179
# Cash capital at the moment: $0.2024964071337223
#
#
# Price increase from previously bought: 23.136953584808474%
# Share price: $0.57370301673576
# Shares owned at the moment: 0
# Cash capital at the moment: $102.61293109284658
#
#
# Share price: $0.9165077518378664
# Shares owned at the moment: 111
# Cash capital at the moment: $0.6008066475948937
#
#
# Price increase from previously bought: -2.76761411401214%
# Share price: $0.8935929954153268
# Shares owned at the moment: 0
# Cash capital at the moment: $99.51685987684564
#
#
# Share price: $0.6516131361246795
# Shares owned at the moment: 152
# Cash capital at the moment: $0.19928889499423974
#
#
# Price increase from previously bought: -2.0978613608808705%
# Share price: $0.6396975397082745
# Shares owned at the moment: 0
# Cash capital at the moment: $97.1659213590539
#
#
# Share price: $0.6259486334070354
# Shares owned at the moment: 154
# Cash capital at the moment: $0.5047425681225519
#
#
# Price increase from previously bought: 38.715925547422444%
# Share price: $0.8706782389927872
# Shares owned at the moment: 0
# Cash capital at the moment: $134.22045913879833
#
#
# Share price: $0.7854353171288251
# Shares owned at the moment: 170
# Cash capital at the moment: $0.32926421614035917
#
#
# Price increase from previously bought: 6.010183834597771%
# Share price: $0.8349311875049963
# Shares owned at the moment: 0
# Cash capital at the moment: $141.87723576183114
#
#
# Share price: $0.7130246903301141
# Shares owned at the moment: 198
# Cash capital at the moment: $0.3101051325838
#
#
# Price increase from previously bought: 1.520517135204491%
# Share price: $0.7258569853953656
# Shares owned at the moment: 0
# Cash capital at the moment: $143.6345591123184
#
#
# Share price: $0.7075251977399057
# Shares owned at the moment: 202
# Cash capital at the moment: $0.32143892151293585
#
#
# Price increase from previously bought: 5.022685589112297%
# Share price: $0.7451053842868132
# Shares owned at the moment: 0
# Cash capital at the moment: $150.41882050647786
#
#
# Share price: $0.7909348971318924
# Shares owned at the moment: 189
# Cash capital at the moment: $0.5210365357659157
#
#
# Price increase from previously bought: -3.5101782608388032%
# Share price: $0.7652703944142483
# Shares owned at the moment: 0
# Cash capital at the moment: $144.759391792562
#
#
# Share price: $0.6543629698326423
# Shares owned at the moment: 220
# Cash capital at the moment: $0.4036488326319443
#
#
# Price increase from previously bought: -1.950518565825965%
# Share price: $0.6433638972393665
# Shares owned at the moment: 0
# Cash capital at the moment: $141.55447106746274
#
#
# Share price: $0.6167827832857349
# Shares owned at the moment: 228
# Cash capital at the moment: $0.5412736731950076
#
#
# Price increase from previously bought: -45.030871063264165%
# Share price: $0.33997248374328437
# Shares owned at the moment: 0
# Cash capital at the moment: $77.8418372193568
#
#
# Share price: $0.2950595821341928
# Shares owned at the moment: 263
# Cash capital at the moment: $0.027765275285545954
#
#
# Price increase from previously bought: 21.41132030828348%
# Share price: $0.35922088263473195
# Shares owned at the moment: 0
# Cash capital at the moment: $94.24305090485448
#
#
# Share price: $0.3610541051067073
# Shares owned at the moment: 260
# Cash capital at the moment: $0.11082989195928405
#
#
# Price increase from previously bought: -38.249574180748034%
# Share price: $0.22356556657146986
# Shares owned at the moment: 0
# Cash capital at the moment: $58.07802782044285
#
#
# Share price: $0.15940422236450136
# Shares owned at the moment: 363
# Cash capital at the moment: $0.05516983715349255
#
#
# Price increase from previously bought: 23.236474477008873%
# Share price: $0.1969843652049793
# Shares owned at the moment: 0
# Cash capital at the moment: $71.3638547639951
#
#
# Share price: $0.16032078989405962
# Shares owned at the moment: 443
# Cash capital at the moment: $0.14643403863824744
#
#
# Price increase from previously bought: 44.767974668013565%
# Share price: $0.2327314166927703
# Shares owned at the moment: 0
# Cash capital at the moment: $102.96292658514953
#
#
# Share price: $0.18323554631659922
# Shares owned at the moment: 560
# Cash capital at the moment: $0.06883790652641153
#
#
# Price increase from previously bought: -13.74328363101911%
# Share price: $0.15848761112851362
# Shares owned at the moment: 0
# Cash capital at the moment: $88.57782921735611
#
#
# Share price: $0.13648946594196176
# Shares owned at the moment: 647
# Cash capital at the moment: $0.026295870629610363
#
#
# Price increase from previously bought: -64.56591209700045%
# Share price: $0.048496797782894945
# Shares owned at the moment: 0
# Cash capital at the moment: $31.317436108707422
#
#
# Share price: $0.04666361901734949
# Shares owned at the moment: 669
# Cash capital at the moment: $0.013625593013440351
#
#
#
#
# Capital at the end of test period: $12.188850688433217
# profit gained: -87.81114931156678%
#
#
# Capital at the end of test period if Buy and Hold: $3.993306781778525
# profit gained: -96.00669321822147%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.745968     13.333333       0.000000      93.298969
# 1       0.803653      5.882353       8.333333      91.578947
# 2       0.751064     11.363636      10.000000      91.223404
# 3       0.784173      9.523810       0.000000      89.256198
# 4       0.721154     13.333333       8.571429      91.772152
# 5       0.721008     15.254237       4.109589      90.064795
# 6       0.768811     11.363636       4.347826      91.052632
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         46.666667           54.166667          83.419689    4311.081815
# 1         41.176471           58.333333          85.714286      96.201171
# 2         59.090909           66.000000          85.066667      73.186112
# 3         66.666667           33.333333          82.572614     -77.815589
# 4         46.666667           55.882353          86.075949      72.372171
# 5         45.762712           47.945205          83.766234     -93.264783
# 6         50.000000           47.826087          84.321476     -87.811149
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
# 5         -91.884658
# 6         -96.006693

# %%
df = log_hist['0_epochs_logs']
df['Profit gained']
# Out:
# 0     -0.543194
# 1    208.213911
# 2    987.927965
# 3    -95.985506
# 4    739.508820
# 5    191.450453
# 6    -60.537033
# Name: Profit gained, dtype: float64

# %%
accumulation_phase_data_acc = []
mark_up_phase_data_acc = []
distribution_phase_data_acc = []
mark_down_phase_data_acc = []
bull_phase_data_acc = []
bear_phase_data_acc = []
full_cycle_data_acc = []

accumulation_phase_data_correct_buys = []
mark_up_phase_data_correct_buys = []
distribution_phase_data_correct_buys = []
mark_down_phase_data_correct_buys = []
bull_phase_data_correct_buys = []
bear_phase_data_correct_buys = []
full_cycle_data_correct_buys = []

accumulation_phase_data_correct_sells = []
mark_up_phase_data_correct_sells = []
distribution_phase_data_correct_sells = []
mark_down_phase_data_correct_sells = []
bull_phase_data_correct_sells = []
bear_phase_data_correct_sells = []
full_cycle_data_correct_sells = []

accumulation_phase_data_correct_holds = []
mark_up_phase_data_correct_holds = []
distribution_phase_data_correct_holds = []
mark_down_phase_data_correct_holds = []
bull_phase_data_correct_holds = []
bear_phase_data_correct_holds = []
full_cycle_data_correct_holds = []

accumulation_phase_data_correct_low_buys = []
mark_up_phase_data_correct_low_buys = []
distribution_phase_data_correct_low_buys = []
mark_down_phase_data_correct_low_buys = []
bull_phase_data_correct_low_buys = []
bear_phase_data_correct_low_buys = []
full_cycle_data_correct_low_buys = []

accumulation_phase_data_correct_high_sells = []
mark_up_phase_data_correct_high_sells = []
distribution_phase_data_correct_high_sells = []
mark_down_phase_data_correct_high_sells = []
bull_phase_data_correct_high_sells = []
bear_phase_data_correct_high_sells = []
full_cycle_data_correct_high_sells = []

accumulation_phase_data_correct_mid_holds = []
mark_up_phase_data_correct_mid_holds = []
distribution_phase_data_correct_mid_holds = []
mark_down_phase_data_correct_mid_holds = []
bull_phase_data_correct_mid_holds = []
bear_phase_data_correct_mid_holds = []
full_cycle_data_correct_mid_holds = []

accumulation_phase_data_profit = []
mark_up_phase_data_profit = []
distribution_phase_data_profit = []
mark_down_phase_data_profit = []
bull_phase_data_profit = []
bear_phase_data_profit = []
full_cycle_data_profit = []

for key,value in log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    accumulation_phase_data_acc.append(acc[0])
    mark_up_phase_data_acc.append(acc[1])
    distribution_phase_data_acc.append(acc[2])
    mark_down_phase_data_acc.append(acc[3]) 
    bull_phase_data_acc.append(acc[4]) 
    bear_phase_data_acc.append(acc[5]) 
    full_cycle_data_acc.append(acc[6]) 

    accumulation_phase_data_correct_buys.append(correct_buys[0])
    mark_up_phase_data_correct_buys.append(correct_buys[1]) 
    distribution_phase_data_correct_buys.append(correct_buys[2]) 
    mark_down_phase_data_correct_buys.append(correct_buys[3]) 
    bull_phase_data_correct_buys.append(correct_buys[4])
    bear_phase_data_correct_buys.append(correct_buys[5]) 
    full_cycle_data_correct_buys.append(correct_buys[6]) 

    accumulation_phase_data_correct_sells.append(correct_sells[0]) 
    mark_up_phase_data_correct_sells.append(correct_sells[1]) 
    distribution_phase_data_correct_sells.append(correct_sells[2]) 
    mark_down_phase_data_correct_sells.append(correct_sells[3]) 
    bull_phase_data_correct_sells.append(correct_sells[4]) 
    bear_phase_data_correct_sells.append(correct_sells[5]) 
    full_cycle_data_correct_sells.append(correct_sells[6])

    accumulation_phase_data_correct_holds.append(correct_holds[0]) 
    mark_up_phase_data_correct_holds.append(correct_holds[1])  
    distribution_phase_data_correct_holds.append(correct_holds[2])  
    mark_down_phase_data_correct_holds.append(correct_holds[3])  
    bull_phase_data_correct_holds.append(correct_holds[4])  
    bear_phase_data_correct_holds.append(correct_holds[5])  
    full_cycle_data_correct_holds.append(correct_holds[6])  

    accumulation_phase_data_correct_low_buys.append(correct_low_buys[0])  
    mark_up_phase_data_correct_low_buys.append(correct_low_buys[1])  
    distribution_phase_data_correct_low_buys.append(correct_low_buys[2])  
    mark_down_phase_data_correct_low_buys.append(correct_low_buys[3])   
    bull_phase_data_correct_low_buys.append(correct_low_buys[4])   
    bear_phase_data_correct_low_buys.append(correct_low_buys[5])  
    full_cycle_data_correct_low_buys.append(correct_low_buys[6])  

    accumulation_phase_data_correct_high_sells.append(correct_high_sells[0]) 
    mark_up_phase_data_correct_high_sells.append(correct_high_sells[1]) 
    distribution_phase_data_correct_high_sells.append(correct_high_sells[2]) 
    mark_down_phase_data_correct_high_sells.append(correct_high_sells[3]) 
    bull_phase_data_correct_high_sells.append(correct_high_sells[4]) 
    bear_phase_data_correct_high_sells.append(correct_high_sells[5]) 
    full_cycle_data_correct_high_sells.append(correct_high_sells[6]) 

    accumulation_phase_data_correct_mid_holds.append(correct_mid_holds[0])  
    mark_up_phase_data_correct_mid_holds.append(correct_mid_holds[1])  
    distribution_phase_data_correct_mid_holds.append(correct_mid_holds[2])   
    mark_down_phase_data_correct_mid_holds.append(correct_mid_holds[3])   
    bull_phase_data_correct_mid_holds.append(correct_mid_holds[4])   
    bear_phase_data_correct_mid_holds.append(correct_mid_holds[5])   
    full_cycle_data_correct_mid_holds.append(correct_mid_holds[6])   

    accumulation_phase_data_profit.append(profit[0]) 
    mark_up_phase_data_profit.append(profit[1]) 
    distribution_phase_data_profit.append(profit[2]) 
    mark_down_phase_data_profit.append(profit[3])  
    bull_phase_data_profit.append(profit[4])  
    bear_phase_data_profit.append(profit[5])  
    full_cycle_data_profit.append(profit[6])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(accumulation_phase_data_acc)
plt.plot(mark_up_phase_data_acc)
plt.plot(distribution_phase_data_acc)
plt.plot(mark_down_phase_data_acc)
plt.plot(bull_phase_data_acc)
plt.plot(bear_phase_data_acc)
plt.plot(full_cycle_data_acc)
plt.title('Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['accumulation_phase_data_acc','mark_up_phase_data_acc','distribution_phase_data_acc','mark_down_phase_data_acc','bull_phase_data_acc','bear_phase_data_acc','full_cycle_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct buys")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_buys")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_buys")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_buys")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_buys")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct sells")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_sells")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_sells")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_sells")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_sells")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct holds")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_holds")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_holds")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_holds")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_holds")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct low buys")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_low_buys")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_low_buys")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_low_buys")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_low_buys")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct high sells")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_high_sells")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_high_sells")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_high_sells")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_high_sells")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_mid_holds")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_mid_holds")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_mid_holds")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_mid_holds")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Profit")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_profit")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_profit")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_profit")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_profit")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_profit")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_profit")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_profit")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_profit')
