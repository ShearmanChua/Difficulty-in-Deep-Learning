# %%
import os
seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
experiment = 'Full Cycle LSTM Experiment'

# %%
import requests
import lxml
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.utils import compute_class_weight
import tensorflow as tf
from pil import Image
from sklearn import preprocessing
import tensorflow_addons as tfa
import glob
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
import math

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
# gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
np.random.seed(seed)
tf.random.set_seed(seed)

session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, 
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), 
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)

# %% [markdown]
# ## Prepare Test Data

# %%
test_sets = ['accumulation phase data','mark up phase data','distribution phase data','mark down phase data','bull phase data','bear phase data','full cycle data']
test_data = {}

for name in test_sets:

    df = pd.read_csv("{}/test_data.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    labels = []
    data_15 = []
    sequential = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15.append(np.array(i[0:-1]))
            labels.append(i[-1])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_arr = min_max_scaler.fit_transform(data_15)
            sequential.append(data_15_arr)
            data_15 = data_15[1:15]
        else:
            data_15.append(np.array(i[0:-1]))
            count+= 1
            
    X = sequential
    X  = np.array(X).reshape(-1, 15, 4)
    y = labels
    y = np.array(y)
    print(X.shape)
    
    y = to_categorical(y, 3)
    
    test_data['{}_X'.format(name)] = X
    test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2004-06-14    93.010002  92.918784 -32.009897  48922600.0     2.0
# 2004-06-15    91.529999  92.705124 -68.734488  45879300.0     2.0
# 2004-06-16    90.209999  92.321259 -94.676024  40369000.0     2.0
# 2004-06-17    89.980003  91.961066 -87.983635  36219100.0     2.0
# 2004-06-18    89.339996  91.557824 -85.961924  32718400.0     2.0
# (248, 15, 4)
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22   115.589996  116.459043 -80.074504 -17684500.0     2.0
# 2020-01-23   116.099998  116.403805 -70.577262 -12758400.0     2.0
# 2020-01-24   115.809998  116.312450 -69.789236 -17063500.0     2.0
# 2020-01-27   114.370003  116.013612 -94.416205 -21446900.0     2.0
# 2020-01-28   115.860001  115.989979 -34.297465 -14428500.0     2.0
# (219, 15, 4)
#             previous_1d      EMA_12   willr_14        OBV_7  labels
# Date
# 2016-12-05   223.360001  213.378658 -16.514565 -283274800.0     2.0
# 2016-12-06   228.550003  215.712711  -2.667189 -278675500.0     2.0
# 2016-12-07   231.380005  218.123064  -4.633597 -273416200.0     2.0
# 2016-12-08   235.559998  220.805669  -1.742271 -266821000.0     2.0
# 2016-12-09   241.449997  223.981719  -2.918174 -259477300.0     2.0
# (470, 15, 4)
#             previous_1d      EMA_12   willr_14        OBV_7  labels
# Date
# 2007-10-01   216.740005  205.638670  -5.220429  161688200.0     2.0
# 2007-10-02   222.979996  208.306567  -1.526716  171593800.0     2.0
# 2007-10-03   228.020004  211.339403  -1.071898  181013600.0     2.0
# 2007-10-04   227.350006  213.802573  -7.282412  170892200.0     2.0
# 2007-10-05   225.949997  215.671407 -10.566735  160852300.0     2.0
# (278, 15, 4)
#             previous_1d       EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22  1075.300049  1097.577291 -89.711935   1200864.0     2.0
# 2020-01-23  1075.510010  1094.182325 -70.779503   4820868.0     2.0
# 2020-02-03  1052.800049  1087.815821 -81.895216   -525975.0     1.0
# 2020-02-04  1003.919983  1074.908769 -83.419991 -12870263.0     2.0
# 2020-02-05  1038.010010  1069.232037 -59.790669  -6607845.0     2.0
# (208, 15, 4)
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2018-01-22    32.830002  32.653718 -49.494874  128764966.0     2.0
# 2018-01-23    33.750000  32.822377 -18.518497  165063463.0     2.0
# 2018-01-24    33.970001  32.998934 -16.190425  201240854.0     2.0
# 2018-01-25    33.959999  33.146790 -17.627141  173336178.0     2.0
# 2018-01-26    34.880001  33.413438  -2.648942  221767625.0     0.0
# (595, 15, 4)
#             previous_1d    EMA_12   willr_14        OBV_7  labels
# Date
# 2002-11-11         8.74  8.763110 -71.929852 -553467352.0     2.0
# 2002-11-12         8.50  8.722632 -80.487816 -559735252.0     2.0
# 2002-11-13         8.63  8.708381 -69.918697 -552295352.0     2.0
# 2002-11-14         8.52  8.679399 -78.861762 -566378552.0     2.0
# 2002-11-15         8.80  8.697953 -56.097548 -558353452.0     2.0
# (917, 15, 4)

# %% [markdown]
# ## Train Accumulation Phase Stock Data

# %%
def pred_acc(actual, predictions, logger):

    hold = 0
    sell = 0
    buy = 0
    pred_hold = 0
    pred_sell = 0
    pred_buy = 0
    buy_buy = 0
    buy_sell = 0
    buy_hold = 0
    sell_buy = 0
    sell_sell = 0
    sell_hold = 0
    hold_buy = 0
    hold_sell = 0
    hold_hold = 0

    for i in range (0,len(actual)):
        if actual[i]==1 and predictions[i] == 1:
            buy_buy += 1
            buy += 1
            pred_buy += 1
        elif actual[i]==1 and predictions[i] == 0:
            buy_sell += 1
            buy += 1
            pred_sell += 1
        elif actual[i]==1 and predictions[i] == 2:
            buy_hold += 1
            buy += 1
            pred_hold += 1
        elif actual[i]==0 and predictions[i] == 1:
            sell_buy += 1
            sell += 1
            pred_buy += 1
        elif actual[i]==0 and predictions[i] == 0:
            sell_sell += 1
            sell += 1
            pred_sell += 1
        elif actual[i]==0 and predictions[i] == 2:
            sell_hold += 1
            sell += 1
            pred_hold += 1
        elif actual[i]==2 and predictions[i] == 1:
            hold_buy += 1
            hold += 1
            pred_buy += 1
        elif actual[i]==2 and predictions[i] == 0:
            hold_sell += 1
            hold += 1
            pred_sell += 1
        elif actual[i]==2 and predictions[i] == 2:
            hold_hold += 1
            hold += 1
            pred_hold += 1

    print("number of predictions: " + str(len(actual)))
    print("actual predicted buys: " + str(buy_buy) )
    print("actual buys but predicted sell: " + str(buy_sell) )
    print("actual buys but predicted hold: " + str(buy_hold))
    print("actual sells but predicted buy: " + str(sell_buy) )
    print("actual predicted sells: " + str(sell_sell))
    print("actual sells but predicted hold: " + str(sell_hold) )
    print("actual holds but predicted buy: " + str(hold_buy) )
    print("actual holds but predicted sell: " + str(hold_sell))
    print("actual predicted holds: " + str(hold_hold) )
    
    if pred_buy !=0:
        Percentage_buys_correct = 100*buy_buy/pred_buy
    else:
        Percentage_buys_correct = 0
        
    if pred_sell !=0:
        Percentage_sells_correct = 100*sell_sell/pred_sell
    else:
        Percentage_sells_correct = 0
        
    if pred_hold !=0:
        Percentage_holds_correct = 100*hold_hold/pred_hold
    else:
        Percentage_holds_correct = 0

    print("Percentage buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage holds correct: " + str(Percentage_holds_correct) + "%")

    print("actual buys: " + str(buy))
    print("actual sells: " + str(sell))
    print("actual holds: " + str(hold))
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def correct_maxima_minima(predictions, price, logger):
    correct_maxima = 0 
    correct_minima = 0
    correct_hold = 0

    hold = 0
    buy = 0
    sell = 0

#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):
        if i < 4:
            prices = price[i:i+9]
            prices.sort(key = float)
#             if i == 0:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1

        else:
            prices = price[i:i+5]
            prices = prices + price[i-4:i] 
            prices.sort(key = float)
#             if i == 10:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1
                    
    if buy !=0:
        Percentage_buys_correct = 100*correct_minima/buy
    else:
        Percentage_buys_correct = 0
        
    if sell !=0:
        Percentage_sells_correct = 100*correct_maxima/sell
    else:
        Percentage_sells_correct = 0
        
    if hold !=0:
        Percentage_holds_correct = 100*correct_hold/hold
    else:
        Percentage_holds_correct = 0

    print("Percentage low buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage high sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage mid holds correct: " + str(Percentage_holds_correct) + "%")
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %% [markdown]
# ### Creating Training Data and Model

# %%
labels = []
sequential = []

for filepath in glob.iglob('full cycle data/*_acc_data.csv'):
    print(filepath)
    seed = 10
    df = pd.read_csv(filepath)
    df.set_index('Date', inplace=True)
    print(df.head())
    
    plt.figure(figsize=(15,5))
    plt.plot(df['previous_1d'].values)
    plt.plot(df['EMA_12'].values)
    plt.show()

    data_15 = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15.append(np.array(i[0:-1]))
            labels.append(i[-1])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_arr = min_max_scaler.fit_transform(data_15)
            sequential.append(data_15_arr)
            data_15 = data_15[1:15]
        else:
            data_15.append(np.array(i[0:-1]))
            count+= 1
# Out:
# full cycle data\0_acc_data.csv
#             previous_1d     EMA_12   willr_14     OBV_7  labels
# Date
# 2000-01-21    17.562500  18.182877 -82.786885 -348800.0     2.0
# 2000-01-24    17.875000  18.135511 -64.957265 -264800.0     2.0
# 2000-01-25    17.546875  18.044952 -82.905983 -350800.0     2.0
# 2000-01-26    17.328125  17.934671 -94.871795 -460000.0     2.0
# 2000-01-27    17.250000  17.829337 -93.548387 -540800.0     2.0

# %%
X = sequential
X  = np.array(X).reshape(-1, 15, 4)
X.shape
# Out:
# (4745, 15, 4)

# %%
y = labels
y = np.array(y)
y.shape
# Out:
# (4745,)

# %%
from collections import Counter

Counter(y)
# Out:
# Counter({2.0: 4314, 1.0: 216, 0.0: 215})

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization,Activation
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(LSTM(100, input_shape=(X_train.shape[1:]), return_sequences=True,kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(LSTM(100, kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# model.add(Dense(100, kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))

model.add(Dense(75, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(50, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "LSTM_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))

epochs = 0 
histories = {}
log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['accumulation phase data','mark up phase data','distribution phase data','mark down phase data','bull phase data','bear phase data','full cycle data']
    
    for name in test_sets:
        
        print('\n')
        print(name)
        print('\n')
        
        X = test_data['{}_X'.format(name)]
        y = test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("{}/test_data.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(log)
        log.loc[df_length] = logger
        print(log.head(20))
        logger = []

    log.to_csv('{}_{}epochs.csv'.format(experiment,epochs))
    log_hist['{}_epochs_logs'.format(epochs)] = log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 1 ... 1 2 1] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  1/30 [>.............................] - ETA: 0s - loss: 0.3618 - accuracy: 0.5625 - mse: 0.3308 - weighted_accuracy: 0.4388 - weighted_mse: 0.4189WARNING:tensorflow:From C:\Users\Shearman Chua\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/30 [=>............................] - ETA: 1s - loss: 0.3461 - accuracy: 0.5430 - mse: 0.3438 - weighted_accuracy: 0.3484 - weighted_mse: 0.4760WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0110s vs `on_train_batch_end` time: 0.1047s). Check your callbacks.
# 30/30 [==============================] - 1s 40ms/step - loss: 0.2942 - accuracy: 0.5034 - mse: 0.4561 - weighted_accuracy: 0.2909 - weighted_mse: 0.5361 - val_loss: 0.2992 - val_accuracy: 0.0443 - val_mse: 0.3551 - val_weighted_accuracy: 0.0443 - val_weighted_mse: 0.3551
# Epoch 2/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2093 - accuracy: 0.3319 - mse: 0.7940 - weighted_accuracy: 0.4392 - weighted_mse: 0.7713 - val_loss: 0.2909 - val_accuracy: 0.0453 - val_mse: 0.3858 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.3858
# Epoch 3/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1874 - accuracy: 0.2482 - mse: 1.0621 - weighted_accuracy: 0.4894 - weighted_mse: 1.0199 - val_loss: 0.2809 - val_accuracy: 0.0453 - val_mse: 0.4252 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.4252
# Epoch 4/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1795 - accuracy: 0.2698 - mse: 1.1885 - weighted_accuracy: 0.5046 - weighted_mse: 1.1543 - val_loss: 0.2712 - val_accuracy: 0.0453 - val_mse: 0.4712 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.4712
# Epoch 5/20
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1760 - accuracy: 0.2326 - mse: 1.2833 - weighted_accuracy: 0.5386 - weighted_mse: 1.2260 - val_loss: 0.2642 - val_accuracy: 0.0453 - val_mse: 0.5251 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.5251
# Epoch 6/20
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1717 - accuracy: 0.2798 - mse: 1.2865 - weighted_accuracy: 0.5449 - weighted_mse: 1.2339 - val_loss: 0.2568 - val_accuracy: 0.0453 - val_mse: 0.5827 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.5827
# Epoch 7/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1695 - accuracy: 0.2677 - mse: 1.3210 - weighted_accuracy: 0.5460 - weighted_mse: 1.2580 - val_loss: 0.2505 - val_accuracy: 0.0453 - val_mse: 0.6466 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.6466
# Epoch 8/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1652 - accuracy: 0.2808 - mse: 1.3392 - weighted_accuracy: 0.5893 - weighted_mse: 1.2730 - val_loss: 0.2458 - val_accuracy: 0.0453 - val_mse: 0.7260 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.7260
# Epoch 9/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1640 - accuracy: 0.2864 - mse: 1.3539 - weighted_accuracy: 0.5969 - weighted_mse: 1.2881 - val_loss: 0.2410 - val_accuracy: 0.0453 - val_mse: 0.8018 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.8018
# Epoch 10/20
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1614 - accuracy: 0.2943 - mse: 1.3568 - weighted_accuracy: 0.6053 - weighted_mse: 1.2830 - val_loss: 0.2373 - val_accuracy: 0.0453 - val_mse: 0.8813 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.8813
# Epoch 11/20
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1601 - accuracy: 0.2990 - mse: 1.3796 - weighted_accuracy: 0.6217 - weighted_mse: 1.3151 - val_loss: 0.2330 - val_accuracy: 0.0453 - val_mse: 0.9685 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.9685
# Epoch 12/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1583 - accuracy: 0.3143 - mse: 1.3845 - weighted_accuracy: 0.6218 - weighted_mse: 1.3194 - val_loss: 0.2324 - val_accuracy: 0.0453 - val_mse: 1.0494 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 1.0494
# Epoch 13/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1565 - accuracy: 0.2919 - mse: 1.4091 - weighted_accuracy: 0.6228 - weighted_mse: 1.3259 - val_loss: 0.2233 - val_accuracy: 0.0748 - val_mse: 1.1373 - val_weighted_accuracy: 0.0748 - val_weighted_mse: 1.1373
# Epoch 14/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1550 - accuracy: 0.3153 - mse: 1.4346 - weighted_accuracy: 0.6351 - weighted_mse: 1.3564 - val_loss: 0.2170 - val_accuracy: 0.1128 - val_mse: 1.2120 - val_weighted_accuracy: 0.1128 - val_weighted_mse: 1.2120
# Epoch 15/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1535 - accuracy: 0.3209 - mse: 1.4424 - weighted_accuracy: 0.6371 - weighted_mse: 1.3567 - val_loss: 0.2150 - val_accuracy: 0.1675 - val_mse: 1.2574 - val_weighted_accuracy: 0.1675 - val_weighted_mse: 1.2574
# Epoch 16/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1503 - accuracy: 0.3338 - mse: 1.4447 - weighted_accuracy: 0.6455 - weighted_mse: 1.3721 - val_loss: 0.2144 - val_accuracy: 0.1665 - val_mse: 1.3143 - val_weighted_accuracy: 0.1665 - val_weighted_mse: 1.3143
# Epoch 17/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1498 - accuracy: 0.3327 - mse: 1.4843 - weighted_accuracy: 0.6488 - weighted_mse: 1.3983 - val_loss: 0.2108 - val_accuracy: 0.2055 - val_mse: 1.3196 - val_weighted_accuracy: 0.2055 - val_weighted_mse: 1.3196
# Epoch 18/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1487 - accuracy: 0.3238 - mse: 1.5035 - weighted_accuracy: 0.6638 - weighted_mse: 1.4104 - val_loss: 0.1975 - val_accuracy: 0.2655 - val_mse: 1.3219 - val_weighted_accuracy: 0.2655 - val_weighted_mse: 1.3219
# Epoch 19/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1471 - accuracy: 0.3593 - mse: 1.4977 - weighted_accuracy: 0.6715 - weighted_mse: 1.4170 - val_loss: 0.2016 - val_accuracy: 0.2645 - val_mse: 1.3664 - val_weighted_accuracy: 0.2645 - val_weighted_mse: 1.3664
# Epoch 20/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1452 - accuracy: 0.3277 - mse: 1.5328 - weighted_accuracy: 0.6672 - weighted_mse: 1.4426 - val_loss: 0.1835 - val_accuracy: 0.3815 - val_mse: 1.3309 - val_weighted_accuracy: 0.3815 - val_weighted_mse: 1.3309
# Validation loss: 0.18354879319667816
# Validation accuracy: 0.3814541697502136
#
#
# accumulation phase data
#
#
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1827 - accuracy: 0.3911 - mse: 1.3245 - weighted_accuracy: 0.3911 - weighted_mse: 1.3245
# Test loss: 0.18268772959709167
# Test accuracy: 0.3911290466785431
#
#
# number of predictions: 248
# actual predicted buys: 10
# actual buys but predicted sell: 0
# actual buys but predicted hold: 1
# actual sells but predicted buy: 4
# actual predicted sells: 2
# actual sells but predicted hold: 2
# actual holds but predicted buy: 104
# actual holds but predicted sell: 40
# actual predicted holds: 85
# Percentage buys correct: 8.474576271186441%
# Percentage sells correct: 4.761904761904762%
# Percentage holds correct: 96.5909090909091%
# actual buys: 11
# actual sells: 8
# actual holds: 229
#
#
# Percentage low buys correct: 44.067796610169495%
# Percentage high sells correct: 45.23809523809524%
# Percentage mid holds correct: 86.20689655172414%
#
#
# Capital: 100
# Share price: $0.2186283391781647
# Shares owned at the moment: 456
# Cash capital at the moment: $0.03131739742747186
#
#
# Price increase from previously bought: -53.3141859930496%
# Share price: $0.10234910794963946
# Shares owned at the moment: 0
# Cash capital at the moment: $46.574164841094216
#
#
# Share price: $0.27356589745290827
# Shares owned at the moment: 169
# Cash capital at the moment: $0.21438842071147945
#
#
# Price increase from previously bought: 82.04520361601901%
# Share price: $0.4993831324285025
# Shares owned at the moment: 0
# Cash capital at the moment: $84.37804949033227
#
#
# Share price: $0.6823962985991441
# Shares owned at the moment: 123
# Cash capital at the moment: $0.21248421463639033
#
#
# Price increase from previously bought: 4.799046151553088%
# Share price: $0.717111460138147
# Shares owned at the moment: 0
# Cash capital at the moment: $88.17463086023673
#
#
# Share price: $0.6817223301360331
# Shares owned at the moment: 128
# Cash capital at the moment: $0.6742063426165998
#
#
# Price increase from previously bought: 19.743172377761375%
# Share price: $0.818560813760991
# Shares owned at the moment: 0
# Cash capital at the moment: $105.16185709757957
#
#
# Share price: $0.8573205575038327
# Shares owned at the moment: 122
# Cash capital at the moment: $0.28111803506944
#
#
# Price increase from previously bought: 8.860633919700444%
# Share price: $0.9358511262550444
# Shares owned at the moment: 0
# Cash capital at the moment: $114.14097738532628
#
#
# Share price: $0.9092248719819918
# Shares owned at the moment: 125
# Cash capital at the moment: $0.17532233783349227
#
#
# Price increase from previously bought: -0.0894259183799817%
# Share price: $0.9109099217106305
# Shares owned at the moment: 0
# Cash capital at the moment: $113.72593726607427
#
#
# Share price: $0.7727232440177259
# Shares owned at the moment: 146
# Cash capital at the moment: $0.5980952570131706
#
#
# Price increase from previously bought: -28.721715467107288%
# Share price: $0.552298528172191
# Shares owned at the moment: 0
# Cash capital at the moment: $81.01193251109193
#
#
#
#
# Capital at the end of test period: $81.01193251109193
# profit gained: -18.988067488908072%
#
#
# Capital at the end of test period if Buy and Hold: $182.55793694382942
# profit gained: 82.55793694382942%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.391129      8.474576       4.761905      96.590909
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         44.067797           45.238095          86.206897     -18.988067
#
#    buy_n_hold profit
# 0          82.557937
#
#
# mark up phase data
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1858 - accuracy: 0.3242 - mse: 1.3647 - weighted_accuracy: 0.3242 - weighted_mse: 1.3647
# Test loss: 0.18582266569137573
# Test accuracy: 0.32420089840888977
#
#
# number of predictions: 219
# actual predicted buys: 6
# actual buys but predicted sell: 0
# actual buys but predicted hold: 1
# actual sells but predicted buy: 3
# actual predicted sells: 4
# actual sells but predicted hold: 4
# actual holds but predicted buy: 107
# actual holds but predicted sell: 33
# actual predicted holds: 61
# Percentage buys correct: 5.172413793103448%
# Percentage sells correct: 10.81081081081081%
# Percentage holds correct: 92.42424242424242%
# actual buys: 7
# actual sells: 11
# actual holds: 201
#
#
# Percentage low buys correct: 50.43478260869565%
# Percentage high sells correct: 56.75675675675676%
# Percentage mid holds correct: 84.84848484848484%
#
#
# Capital: 100
# Share price: $0.2847230626280439
# Shares owned at the moment: 350
# Cash capital at the moment: $0.07288213240512675
#
#
# Price increase from previously bought: 1.4504266064519378%
# Share price: $0.2896471067777344
# Shares owned at the moment: 0
# Cash capital at the moment: $101.1705841643386
#
#
# Share price: $0.2096306458156978
# Shares owned at the moment: 481
# Cash capital at the moment: $0.06095459023525507
#
#
# Price increase from previously bought: 58.38571189382462%
# Share price: $0.3329380594473028
# Shares owned at the moment: 0
# Cash capital at the moment: $159.763767366254
#
#
# Share price: $0.2161960901927984
# Shares owned at the moment: 736
# Cash capital at the moment: $0.20586409780415238
#
#
# Price increase from previously bought: 148.78359444101906%
# Share price: $0.5393395203342035
# Shares owned at the moment: 0
# Cash capital at the moment: $396.0681278746215
#
#
# Share price: $0.5309274615681303
# Shares owned at the moment: 743
# Cash capital at the moment: $0.5042063936516001
#
#
# Price increase from previously bought: -7.133966103243239%
# Share price: $0.49440716743722457
# Shares owned at the moment: 0
# Cash capital at the moment: $366.83853435464334
#
#
# Share price: $0.42608540916354065
# Shares owned at the moment: 858
# Cash capital at the moment: $0.2519047694040637
#
#
# Price increase from previously bought: 16.1487015998635%
# Share price: $0.4962536252936556
# Shares owned at the moment: 0
# Cash capital at the moment: $424.86660484248017
#
#
# Share price: $0.5785268159027048
# Shares owned at the moment: 732
# Cash capital at the moment: $0.22040112128809142
#
#
# Price increase from previously bought: 13.30672865941378%
# Share price: $0.6573124614929953
# Shares owned at the moment: 0
# Cash capital at the moment: $480.0499529491752
#
#
# Share price: $0.5697046418785916
# Shares owned at the moment: 840
# Cash capital at the moment: $0.18203604841869492
#
#
# Price increase from previously bought: 58.446240976220956%
# Share price: $0.9051579475954099
# Shares owned at the moment: 0
# Cash capital at the moment: $758.4237971696176
#
#
# Share price: $0.6798810102234543
# Shares owned at the moment: 1112
# Cash capital at the moment: $0.31703767187309495
#
#
# Price increase from previously bought: 9.386149993317572%
# Share price: $0.7457408246885631
# Shares owned at the moment: 0
# Cash capital at the moment: $827.3003592836575
#
#
# Share price: $0.8204228131777864
# Shares owned at the moment: 1005
# Cash capital at the moment: $0.5079884900619618
#
#
# Price increase from previously bought: -0.29920947324650893%
# Share price: $0.8202174424836832
# Shares owned at the moment: 0
# Cash capital at the moment: $822.5596422294993
#
#
# Share price: $0.8616619372968211
# Shares owned at the moment: 952
# Cash capital at the moment: $0.001646971082550408
#
#
# Price increase from previously bought: 6.065851812845846%
# Share price: $0.9164423784931806
# Shares owned at the moment: 0
# Cash capital at the moment: $870.0555451496953
#
#
# Share price: $0.9303941238936282
# Shares owned at the moment: 932
# Cash capital at the moment: $0.5436215412943284
#
#
#
#
# Capital at the end of test period: $808.8411189506435
# profit gained: 708.8411189506435%
#
#
# Capital at the end of test period if Buy and Hold: $355.7316817269389
# profit gained: 255.73168172693892%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.391129      8.474576       4.761905      96.590909
# 1       0.324201      5.172414      10.810811      92.424242
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         44.067797           45.238095          86.206897     -18.988067
# 1         50.434783           56.756757          84.848485     708.841119
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
#
#
# distribution phase data
#
#
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1817 - accuracy: 0.3617 - mse: 1.3304 - weighted_accuracy: 0.3617 - weighted_mse: 1.3304
# Test loss: 0.18168330192565918
# Test accuracy: 0.3617021143436432
#
#
# number of predictions: 470
# actual predicted buys: 17
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 5
# actual predicted sells: 8
# actual sells but predicted hold: 7
# actual holds but predicted buy: 214
# actual holds but predicted sell: 67
# actual predicted holds: 145
# Percentage buys correct: 7.203389830508475%
# Percentage sells correct: 10.666666666666666%
# Percentage holds correct: 91.19496855345912%
# actual buys: 24
# actual sells: 20
# actual holds: 426
#
#
# Percentage low buys correct: 43.829787234042556%
# Percentage high sells correct: 50.666666666666664%
# Percentage mid holds correct: 86.16352201257861%
#
#
# Capital: 100
# Share price: $0.5051713785101153
# Shares owned at the moment: 197
# Cash capital at the moment: $0.20756183919942828
#
#
# Price increase from previously bought: -3.3184311366461605%
# Share price: $0.48975073513123957
# Shares owned at the moment: 0
# Cash capital at the moment: $96.42313419929627
#
#
# Share price: $0.6156074375411762
# Shares owned at the moment: 156
# Cash capital at the moment: $0.12427835216762162
#
#
# Price increase from previously bought: -51.74948793939998%
# Share price: $0.297850583684222
# Shares owned at the moment: 0
# Cash capital at the moment: $46.46119150650573
#
#
# Share price: $0.3012773933239721
# Shares owned at the moment: 153
# Cash capital at the moment: $0.2389878646969379
#
#
# Price increase from previously bought: -21.310384810891247%
# Share price: $0.23772597501742188
# Shares owned at the moment: 0
# Cash capital at the moment: $36.5110388383739
#
#
# Share price: $0.258286595180125
# Shares owned at the moment: 140
# Cash capital at the moment: $0.2514751740120502
#
#
# Price increase from previously bought: 8.085343852007298%
# Share price: $0.2799376718990214
# Shares owned at the moment: 0
# Cash capital at the moment: $39.334973236193925
#
#
# Share price: $0.18538952686354482
# Shares owned at the moment: 211
# Cash capital at the moment: $0.11021079502339859
#
#
# Price increase from previously bought: 68.09761127926033%
# Share price: $0.3124923634766452
# Shares owned at the moment: 0
# Cash capital at the moment: $65.8647757946882
#
#
# Share price: $0.21436149347865174
# Shares owned at the moment: 306
# Cash capital at the moment: $0.08977359345847447
#
#
# Price increase from previously bought: 70.37866519901989%
# Share price: $0.3662306234806574
# Shares owned at the moment: 0
# Cash capital at the moment: $111.84816130888065
#
#
# Share price: $0.29317763984130907
# Shares owned at the moment: 380
# Cash capital at the moment: $0.13428753554903494
#
#
# Price increase from previously bought: -51.03253392664359%
# Share price: $0.14395645589260098
# Shares owned at the moment: 0
# Cash capital at the moment: $54.687306278329636
#
#
# Share price: $0.16031164050489966
# Shares owned at the moment: 340
# Cash capital at the moment: $0.031457122791671566
#
#
# Price increase from previously bought: 84.02549911526738%
# Share price: $0.29582558589460706
# Shares owned at the moment: 0
# Cash capital at the moment: $100.33555940414661
#
#
# Share price: $0.5274454034926939
# Shares owned at the moment: 189
# Cash capital at the moment: $0.3742383955621307
#
#
# Price increase from previously bought: -2.3063020944256496%
# Share price: $0.5166979416325288
# Shares owned at the moment: 0
# Cash capital at the moment: $97.76159560894656
#
#
# Share price: $0.5168536192795001
# Shares owned at the moment: 188
# Cash capital at the moment: $0.3259018632330424
#
#
# Price increase from previously bought: 15.233713983968912%
# Share price: $0.5972274928150607
# Shares owned at the moment: 0
# Cash capital at the moment: $112.29590389867906
#
#
# Share price: $0.4923986811845389
# Shares owned at the moment: 227
# Cash capital at the moment: $0.21402339305927853
#
#
# Price increase from previously bought: 23.354326074676713%
# Share price: $0.6090654112314173
# Shares owned at the moment: 0
# Cash capital at the moment: $138.0916626596298
#
#
# Share price: $0.7470716250274518
# Shares owned at the moment: 184
# Cash capital at the moment: $0.2524654123147627
#
#
# Price increase from previously bought: 25.778950124690205%
# Share price: $0.9422429084672486
# Shares owned at the moment: 0
# Cash capital at the moment: $173.14838565860407
#
#
# Share price: $0.781339721424952
# Shares owned at the moment: 220
# Cash capital at the moment: $0.7809364136525403
#
#
# Price increase from previously bought: 9.069660618251095%
# Share price: $0.8545481450354766
# Shares owned at the moment: 0
# Cash capital at the moment: $188.2645266937109
#
#
# Share price: $0.8501867941623023
# Shares owned at the moment: 220
# Cash capital at the moment: $0.7090689675362114
#
#
# Price increase from previously bought: -18.87391969849901%
# Share price: $0.6916199602035646
# Shares owned at the moment: 0
# Cash capital at the moment: $152.44703013639727
#
#
# Share price: $0.5288474530186258
# Shares owned at the moment: 287
# Cash capital at the moment: $0.2504182677567144
#
#
# Price increase from previously bought: 2.5161384250238505%
# Share price: $0.5436449104580203
# Shares owned at the moment: 0
# Cash capital at the moment: $155.84743582362955
#
#
# Share price: $0.4293147711704959
# Shares owned at the moment: 362
# Cash capital at the moment: $0.008105805209822847
#
#
# Price increase from previously bought: -12.829514621780758%
# Share price: $0.37526491819674423
# Shares owned at the moment: 0
# Cash capital at the moment: $135.48042996636636
#
#
# Share price: $0.28725856179523146
# Shares owned at the moment: 470
# Cash capital at the moment: $0.09762423148723087
#
#
# Price increase from previously bought: -0.9771691001924876%
# Share price: $0.2852338016814133
# Shares owned at the moment: 0
# Cash capital at the moment: $133.78884633307828
#
#
# Share price: $0.3980062137960345
# Shares owned at the moment: 335
# Cash capital at the moment: $0.09010148694710551
#
#
# Price increase from previously bought: 8.507176908700377%
# Share price: $0.4330529361041895
# Shares owned at the moment: 0
# Cash capital at the moment: $144.76388506446457
#
#
# Share price: $0.4047041554285624
# Shares owned at the moment: 356
# Cash capital at the moment: $0.2930003637317782
#
#
# Price increase from previously bought: -6.4922692113201785%
# Share price: $0.37947035374714955
# Shares owned at the moment: 0
# Cash capital at the moment: $135.01294482139855
#
#
# Share price: $0.2990967178873858
# Shares owned at the moment: 450
# Cash capital at the moment: $0.04928958368930125
#
#
# Price increase from previously bought: -14.76416972816963%
# Share price: $0.255638649126827
# Shares owned at the moment: 0
# Cash capital at the moment: $114.770328862467
#
#
# Share price: $0.08523365907593682
# Shares owned at the moment: 1342
# Cash capital at the moment: $0.07220356374004666
#
#
#
#
# Capital at the end of test period: $441.0056988021766
# profit gained: 341.0056988021766%
#
#
# Capital at the end of test period if Buy and Hold: $64.93475897926798
# profit gained: -35.06524102073202%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.391129      8.474576       4.761905      96.590909
# 1       0.324201      5.172414      10.810811      92.424242
# 2       0.361702      7.203390      10.666667      91.194969
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         44.067797           45.238095          86.206897     -18.988067
# 1         50.434783           56.756757          84.848485     708.841119
# 2         43.829787           50.666667          86.163522     341.005699
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
#
#
# mark down phase data
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1834 - accuracy: 0.3741 - mse: 1.3771 - weighted_accuracy: 0.3741 - weighted_mse: 1.3771
# Test loss: 0.18343786895275116
# Test accuracy: 0.3741007149219513
#
#
# number of predictions: 278
# actual predicted buys: 12
# actual buys but predicted sell: 0
# actual buys but predicted hold: 4
# actual sells but predicted buy: 3
# actual predicted sells: 6
# actual sells but predicted hold: 4
# actual holds but predicted buy: 126
# actual holds but predicted sell: 37
# actual predicted holds: 86
# Percentage buys correct: 8.51063829787234%
# Percentage sells correct: 13.953488372093023%
# Percentage holds correct: 91.48936170212765%
# actual buys: 16
# actual sells: 13
# actual holds: 249
#
#
# Percentage low buys correct: 46.42857142857143%
# Percentage high sells correct: 58.13953488372093%
# Percentage mid holds correct: 81.91489361702128%
#
#
# Capital: 100
# Share price: $0.8557023478457203
# Shares owned at the moment: 116
# Cash capital at the moment: $0.4655586009336474
#
#
# Price increase from previously bought: 15.263175019579256%
# Share price: $0.9890220465048826
# Shares owned at the moment: 0
# Cash capital at the moment: $114.87661796266497
#
#
# Share price: $0.8836219133409499
# Shares owned at the moment: 129
# Cash capital at the moment: $0.5759262679247286
#
#
# Price increase from previously bought: -6.731798483241869%
# Share price: $0.8264046470147189
# Shares owned at the moment: 0
# Cash capital at the moment: $106.88895868429499
#
#
# Share price: $0.7385116224044694
# Shares owned at the moment: 144
# Cash capital at the moment: $0.25083445557922346
#
#
# Price increase from previously bought: 3.909453278733732%
# Share price: $0.7694936935608018
# Shares owned at the moment: 0
# Cash capital at the moment: $110.75320682568459
#
#
# Share price: $0.6642466000088942
# Shares owned at the moment: 166
# Cash capital at the moment: $0.18504265130408726
#
#
# Price increase from previously bought: -10.764892558206874%
# Share price: $0.5943712054061847
# Shares owned at the moment: 0
# Cash capital at the moment: $98.57933229346283
#
#
# Share price: $0.6473009482303208
# Shares owned at the moment: 151
# Cash capital at the moment: $0.5680973919317438
#
#
# Price increase from previously bought: -0.5337466040533201%
# Share price: $0.6456165779049897
# Shares owned at the moment: 0
# Cash capital at the moment: $97.78810837161014
#
#
# Share price: $0.6150939371157509
# Shares owned at the moment: 158
# Cash capital at the moment: $0.3360079916446921
#
#
# Price increase from previously bought: 14.820010353125944%
# Share price: $0.7081931123140189
# Shares owned at the moment: 0
# Cash capital at the moment: $111.92280982995923
#
#
# Share price: $0.7046202409645685
# Shares owned at the moment: 158
# Cash capital at the moment: $0.286654262858292
#
#
# Price increase from previously bought: -4.117370123724362%
# Share price: $0.6774663408259917
# Shares owned at the moment: 0
# Cash capital at the moment: $107.03197698827607
#
#
# Share price: $0.6394916444655385
# Shares owned at the moment: 166
# Cash capital at the moment: $0.5844360712981569
#
#
# Price increase from previously bought: 4.06375815446538%
# Share price: $0.6673091056699969
# Shares owned at the moment: 0
# Cash capital at the moment: $111.05312100577929
#
#
# Share price: $0.6610310547357661
# Shares owned at the moment: 167
# Cash capital at the moment: $0.3573563530189432
#
#
# Price increase from previously bought: -12.271288476345743%
# Share price: $0.5815087906654093
# Shares owned at the moment: 0
# Cash capital at the moment: $97.2022664820292
#
#
# Share price: $0.5460861563949568
# Shares owned at the moment: 177
# Cash capital at the moment: $0.27920936349659087
#
#
# Price increase from previously bought: -33.53194828966172%
# Share price: $0.3639710040948416
# Shares owned at the moment: 0
# Cash capital at the moment: $64.52491420204039
#
#
# Share price: $0.22217844060501507
# Shares owned at the moment: 289
# Cash capital at the moment: $0.13876855152020084
#
#
#
#
# Capital at the end of test period: $4.947879426460139
# profit gained: -95.05212057353987%
#
#
# Capital at the end of test period if Buy and Hold: $2.3958591597330687
# profit gained: -97.60414084026694%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.391129      8.474576       4.761905      96.590909
# 1       0.324201      5.172414      10.810811      92.424242
# 2       0.361702      7.203390      10.666667      91.194969
# 3       0.374101      8.510638      13.953488      91.489362
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         44.067797           45.238095          86.206897     -18.988067
# 1         50.434783           56.756757          84.848485     708.841119
# 2         43.829787           50.666667          86.163522     341.005699
# 3         46.428571           58.139535          81.914894     -95.052121
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
#
#
# bull phase data
#
#
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1701 - accuracy: 0.5048 - mse: 1.2553 - weighted_accuracy: 0.5048 - weighted_mse: 1.2553
# Test loss: 0.17011655867099762
# Test accuracy: 0.504807710647583
#
#
# number of predictions: 208
# actual predicted buys: 5
# actual buys but predicted sell: 0
# actual buys but predicted hold: 4
# actual sells but predicted buy: 2
# actual predicted sells: 6
# actual sells but predicted hold: 2
# actual holds but predicted buy: 47
# actual holds but predicted sell: 48
# actual predicted holds: 94
# Percentage buys correct: 9.25925925925926%
# Percentage sells correct: 11.11111111111111%
# Percentage holds correct: 94.0%
# actual buys: 9
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 42.592592592592595%
# Percentage high sells correct: 59.25925925925926%
# Percentage mid holds correct: 89.8989898989899%
#
#
# Capital: 100
# Share price: $0.09936061724328947
# Shares owned at the moment: 1003
# Cash capital at the moment: $0.06723948246934697
#
#
# Price increase from previously bought: 46.255629846786285%
# Share price: $0.14572012793439182
# Shares owned at the moment: 0
# Cash capital at the moment: $145.8225952577893
#
#
# Share price: $0.06646855704303233
# Shares owned at the moment: 2187
# Cash capital at the moment: $0.056102485481517306
#
#
# Price increase from previously bought: 197.57233967089275%
# Share price: $0.19833596844936396
# Shares owned at the moment: 0
# Cash capital at the moment: $432.6240233859939
#
#
# Share price: $0.3596221970830935
# Shares owned at the moment: 1199
# Cash capital at the moment: $0.251244794032516
#
#
# Price increase from previously bought: 3.5528338128201664%
# Share price: $0.373423073283742
# Shares owned at the moment: 0
# Cash capital at the moment: $446.7542404328544
#
#
# Share price: $0.4319618179127802
# Shares owned at the moment: 1031
# Cash capital at the moment: $0.17688642054076809
#
#
# Price increase from previously bought: 16.214165487719722%
# Share price: $0.5033813241731815
# Shares owned at the moment: 0
# Cash capital at the moment: $517.7358197437288
#
#
# Share price: $0.4790917876756311
# Shares owned at the moment: 1077
# Cash capital at the moment: $0.3350143149258429
#
#
# Price increase from previously bought: 32.740646334908384%
# Share price: $0.6376983967207195
# Shares owned at the moment: 0
# Cash capital at the moment: $685.2474843566532
#
#
# Share price: $0.7471507558725743
# Shares owned at the moment: 914
# Cash capital at the moment: $0.4737300642345872
#
#
# Price increase from previously bought: 5.104599861135295%
# Share price: $0.787449359303195
# Shares owned at the moment: 0
# Cash capital at the moment: $718.2231905027463
#
#
# Share price: $0.7747985561192672
# Shares owned at the moment: 924
# Cash capital at the moment: $0.340561517444371
#
#
# Price increase from previously bought: 3.5744827895988207%
# Share price: $0.8047004545540055
# Shares owned at the moment: 0
# Cash capital at the moment: $741.8390376703237
#
#
# Share price: $0.8327622642399453
# Shares owned at the moment: 888
# Cash capital at the moment: $0.31254157597834364
#
#
# Price increase from previously bought: 3.526951404630463%
# Share price: $0.864504251423482
# Shares owned at the moment: 0
# Cash capital at the moment: $765.8811974580541
#
#
# Share price: $0.8139010386877712
# Shares owned at the moment: 938
# Cash capital at the moment: $0.34256543962953856
#
#
# Price increase from previously bought: 6.771567702367531%
# Share price: $0.8714046895238063
# Shares owned at the moment: 0
# Cash capital at the moment: $815.4723758163332
#
#
# Share price: $0.8123484681931528
# Shares owned at the moment: 1001
# Cash capital at the moment: $0.07536690916845146
#
#
# Price increase from previously bought: 19.385847786218037%
# Share price: $0.9724961357715107
# Shares owned at the moment: 0
# Cash capital at the moment: $970.8669600787056
#
#
#
#
# Capital at the end of test period: $970.8669600787056
# profit gained: 870.8669600787056%
#
#
# Capital at the end of test period if Buy and Hold: $778.7940878989605
# profit gained: 678.7940878989605%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.391129      8.474576       4.761905      96.590909
# 1       0.324201      5.172414      10.810811      92.424242
# 2       0.361702      7.203390      10.666667      91.194969
# 3       0.374101      8.510638      13.953488      91.489362
# 4       0.504808      9.259259      11.111111      94.000000
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         44.067797           45.238095          86.206897     -18.988067
# 1         50.434783           56.756757          84.848485     708.841119
# 2         43.829787           50.666667          86.163522     341.005699
# 3         46.428571           58.139535          81.914894     -95.052121
# 4         42.592593           59.259259          89.898990     870.866960
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
#
#
# bear phase data
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1933 - accuracy: 0.2706 - mse: 1.3906 - weighted_accuracy: 0.2706 - weighted_mse: 1.3906
# Test loss: 0.19328953325748444
# Test accuracy: 0.2705882489681244
#
#
# number of predictions: 595
# actual predicted buys: 22
# actual buys but predicted sell: 0
# actual buys but predicted hold: 10
# actual sells but predicted buy: 10
# actual predicted sells: 10
# actual sells but predicted hold: 7
# actual holds but predicted buy: 314
# actual holds but predicted sell: 93
# actual predicted holds: 129
# Percentage buys correct: 6.358381502890174%
# Percentage sells correct: 9.70873786407767%
# Percentage holds correct: 88.35616438356165%
# actual buys: 32
# actual sells: 27
# actual holds: 536
#
#
# Percentage low buys correct: 44.34782608695652%
# Percentage high sells correct: 56.310679611650485%
# Percentage mid holds correct: 79.45205479452055%
#
#
# Capital: 100
# Share price: $0.7488095723945759
# Shares owned at the moment: 133
# Cash capital at the moment: $0.1344497704180867
#
#
# Price increase from previously bought: 19.44386796902593%
# Share price: $0.8968667365621285
# Shares owned at the moment: 0
# Cash capital at the moment: $119.08969672428357
#
#
# Share price: $0.9539252634566354
# Shares owned at the moment: 124
# Cash capital at the moment: $0.4776755408220623
#
#
# Price increase from previously bought: -16.009625379784055%
# Share price: $0.8034087172306389
# Shares owned at the moment: 0
# Cash capital at the moment: $99.82639410484563
#
#
# Share price: $0.8889966013918106
# Shares owned at the moment: 111
# Cash capital at the moment: $0.8764051377798125
#
#
# Price increase from previously bought: 5.9609300160388345%
# Share price: $0.9445795365790158
# Shares owned at the moment: 0
# Cash capital at the moment: $105.43640079450982
#
#
# Share price: $0.9362174124137154
# Shares owned at the moment: 112
# Cash capital at the moment: $0.2916956411502838
#
#
# Price increase from previously bought: -4.308694746516717%
# Share price: $0.8983423282694308
# Shares owned at the moment: 0
# Cash capital at the moment: $100.62934697021956
#
#
# Share price: $0.7384800551658143
# Shares owned at the moment: 135
# Cash capital at the moment: $0.660378802354316
#
#
# Price increase from previously bought: -17.87685284164987%
# Share price: $0.6081308358605938
# Shares owned at the moment: 0
# Cash capital at the moment: $82.53227307072123
#
#
# Share price: $0.5717314372430228
# Shares owned at the moment: 143
# Cash capital at the moment: $0.5498441572731565
#
#
# Price increase from previously bought: 10.536321938240146%
# Share price: $0.6337088220738311
# Shares owned at the moment: 0
# Cash capital at the moment: $90.92099971955047
#
#
# Share price: $0.5741908193014676
# Shares owned at the moment: 157
# Cash capital at the moment: $0.525134202986635
#
#
# Price increase from previously bought: -6.766960844633962%
# Share price: $0.5368077241521655
# Shares owned at the moment: 0
# Cash capital at the moment: $84.57218015997391
#
#
# Share price: $0.5122135282900707
# Shares owned at the moment: 164
# Cash capital at the moment: $0.33815321914349283
#
#
# Price increase from previously bought: -21.438909731074418%
# Share price: $0.40350713379351755
# Shares owned at the moment: 0
# Cash capital at the moment: $66.3313414439395
#
#
# Share price: $0.39022624551132734
# Shares owned at the moment: 169
# Cash capital at the moment: $0.20174830492378248
#
#
# Price increase from previously bought: 8.022299919075637%
# Share price: $0.42269057654373976
# Shares owned at the moment: 0
# Cash capital at the moment: $71.4400102953671
#
#
# Share price: $0.38432369104329556
# Shares owned at the moment: 185
# Cash capital at the moment: $0.1446027745391376
#
#
# Price increase from previously bought: 10.064254082718872%
# Share price: $0.4241662620704537
# Shares owned at the moment: 0
# Cash capital at the moment: $78.39956667174472
#
#
# Share price: $0.578125980706038
# Shares owned at the moment: 135
# Cash capital at the moment: $0.13793000609247485
#
#
# Price increase from previously bought: -18.262271482684113%
# Share price: $0.4738465489702147
# Shares owned at the moment: 0
# Cash capital at the moment: $63.93129858576627
#
#
# Share price: $0.5717314372430228
# Shares owned at the moment: 111
# Cash capital at the moment: $0.29458803057231364
#
#
# Price increase from previously bought: -32.36274869057178%
# Share price: $0.3877668634528827
# Shares owned at the moment: 0
# Cash capital at the moment: $43.2183440387733
#
#
# Share price: $0.3754697655218352
# Shares owned at the moment: 114
# Cash capital at the moment: $0.2970809977929889
#
#
# Price increase from previously bought: 10.961288746765563%
# Share price: $0.41777181242685024
# Shares owned at the moment: 0
# Cash capital at the moment: $47.79209615125809
#
#
# Share price: $0.4379390455282145
# Shares owned at the moment: 108
# Cash capital at the moment: $0.3646113376890483
#
#
# Price increase from previously bought: -11.69925747163012%
# Share price: $0.3877668634528827
# Shares owned at the moment: 0
# Cash capital at the moment: $42.128265832154874
#
#
# Share price: $0.3361190896702483
# Shares owned at the moment: 124
# Cash capital at the moment: $0.33488210346653347
#
#
# Price increase from previously bought: 4.2499117143057985%
# Share price: $0.35136746483531167
# Shares owned at the moment: 0
# Cash capital at the moment: $43.78463143753634
#
#
# Share price: $0.31841123862732845
# Shares owned at the moment: 137
# Cash capital at the moment: $0.04233031143949262
#
#
# Price increase from previously bought: 8.96918277096923%
# Share price: $0.3479242924257241
# Shares owned at the moment: 0
# Cash capital at the moment: $47.5768778965923
#
#
# Share price: $0.30906541793029685
# Shares owned at the moment: 153
# Cash capital at the moment: $0.15982967866271025
#
#
# Price increase from previously bought: 2.5826393168989714%
# Share price: $0.31791934345175676
# Shares owned at the moment: 0
# Cash capital at the moment: $48.667724663024174
#
#
# Share price: $0.28988197518007464
# Shares owned at the moment: 167
# Cash capital at the moment: $0.12430651085026057
#
#
# Price increase from previously bought: 20.370442314884873%
# Share price: $0.34989177930859794
# Shares owned at the moment: 0
# Cash capital at the moment: $58.39554585573864
#
#
# Share price: $0.3380865765531217
# Shares owned at the moment: 172
# Cash capital at the moment: $0.08473973789207889
#
#
# Price increase from previously bought: 18.73273528780588%
# Share price: $0.40252334344237484
# Shares owned at the moment: 0
# Cash capital at the moment: $69.1283612685323
#
#
# Share price: $0.310541103457011
# Shares owned at the moment: 221
# Cash capital at the moment: $0.3100460489068553
#
#
# Price increase from previously bought: -5.960864376031017%
# Share price: $0.29283325241409075
# Shares owned at the moment: 0
# Cash capital at the moment: $64.84822542326624
#
#
# Share price: $0.3154599613933119
# Shares owned at the moment: 205
# Cash capital at the moment: $0.001092784401819813
#
#
# Price increase from previously bought: -4.628209513581194%
# Share price: $0.30168717793555067
# Shares owned at the moment: 0
# Cash capital at the moment: $61.67688811462853
#
#
# Share price: $0.2692228469031387
# Shares owned at the moment: 228
# Cash capital at the moment: $0.12527629570464427
#
#
# Price increase from previously bought: -46.554092673017%
# Share price: $0.14428428689037887
# Shares owned at the moment: 0
# Cash capital at the moment: $32.931627458830754
#
#
# Share price: $0.10640929656550589
# Shares owned at the moment: 308
# Cash capital at the moment: $0.06743544246395317
#
#
# Price increase from previously bought: 31.994917868300156%
# Share price: $0.14084111448079162
# Shares owned at the moment: 0
# Cash capital at the moment: $43.32720627858254
#
#
# Share price: $0.08329069241071317
# Shares owned at the moment: 518
# Cash capital at the moment: $0.06398001849404977
#
#
#
#
# Capital at the end of test period: $31.147455060149845
# profit gained: -68.85254493985016%
#
#
# Capital at the end of test period if Buy and Hold: $8.115342010843221
# profit gained: -91.88465798915678%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.391129      8.474576       4.761905      96.590909
# 1       0.324201      5.172414      10.810811      92.424242
# 2       0.361702      7.203390      10.666667      91.194969
# 3       0.374101      8.510638      13.953488      91.489362
# 4       0.504808      9.259259      11.111111      94.000000
# 5       0.270588      6.358382       9.708738      88.356164
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         44.067797           45.238095          86.206897     -18.988067
# 1         50.434783           56.756757          84.848485     708.841119
# 2         43.829787           50.666667          86.163522     341.005699
# 3         46.428571           58.139535          81.914894     -95.052121
# 4         42.592593           59.259259          89.898990     870.866960
# 5         44.347826           56.310680          79.452055     -68.852545
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
# 5         -91.884658
#
#
# full cycle data
# 29/29 [==============================] - 0s 4ms/step - loss: 0.1931 - accuracy: 0.3064 - mse: 1.4124 - weighted_accuracy: 0.3064 - weighted_mse: 1.4124
# Test loss: 0.19309042394161224
# Test accuracy: 0.3064340353012085
#
#
# number of predictions: 917
# actual predicted buys: 34
# actual buys but predicted sell: 1
# actual buys but predicted hold: 11
# actual sells but predicted buy: 15
# actual predicted sells: 17
# actual sells but predicted hold: 8
# actual holds but predicted buy: 477
# actual holds but predicted sell: 124
# actual predicted holds: 230
# Percentage buys correct: 6.4638783269961975%
# Percentage sells correct: 11.971830985915492%
# Percentage holds correct: 92.36947791164658%
# actual buys: 46
# actual sells: 40
# actual holds: 831
#
#
# Percentage low buys correct: 45.627376425855516%
# Percentage high sells correct: 53.521126760563384%
# Percentage mid holds correct: 87.5%
#
#
# Capital: 100
# Share price: $0.348221810041456
# Shares owned at the moment: 286
# Cash capital at the moment: $0.1346858745459656
#
#
# Price increase from previously bought: 16.00064959661418%
# Share price: $0.40505039547981114
# Shares owned at the moment: 0
# Cash capital at the moment: $115.66052684572708
#
#
# Share price: $0.33538951497620473
# Shares owned at the moment: 343
# Cash capital at the moment: $0.3055670488875535
#
#
# Price increase from previously bought: -61.3235977950342%
# Share price: $0.130073318409336
# Shares owned at the moment: 0
# Cash capital at the moment: $44.798023605700195
#
#
# Share price: $0.1850687687885747
# Shares owned at the moment: 241
# Cash capital at the moment: $0.07379600113906548
#
#
# Price increase from previously bought: 136.0453840119682%
# Share price: $0.43804761325963903
# Shares owned at the moment: 0
# Cash capital at the moment: $105.35295474102423
#
#
# Share price: $0.3573876601627567
# Shares owned at the moment: 293
# Cash capital at the moment: $0.3504052061603744
#
#
# Price increase from previously bought: 1.2603616193939793%
# Share price: $0.36288724016582397
# Shares owned at the moment: 0
# Cash capital at the moment: $106.38397018098318
#
#
# Share price: $0.3289734111500082
# Shares owned at the moment: 322
# Cash capital at the moment: $0.16322583510719824
#
#
# Price increase from previously bought: 28.06718215852042%
# Share price: $0.42246557189928347
# Shares owned at the moment: 0
# Cash capital at the moment: $135.82304672275964
#
#
# Share price: $0.470128307216338
# Shares owned at the moment: 288
# Cash capital at the moment: $0.05375262513894086
#
#
# Price increase from previously bought: 3.6143763271897944%
# Share price: $0.48846009487179787
# Shares owned at the moment: 0
# Cash capital at the moment: $140.34339955307826
#
#
# Share price: $0.5086251049992332
# Shares owned at the moment: 275
# Cash capital at the moment: $0.08684794263345452
#
#
# Price increase from previously bought: -4.04826538625731%
# Share price: $0.4893767061077856
# Shares owned at the moment: 0
# Cash capital at the moment: $134.2953509882805
#
#
# Share price: $0.5333729964808895
# Shares owned at the moment: 251
# Cash capital at the moment: $0.050568160756256475
#
#
# Price increase from previously bought: 4.010169362151728%
# Share price: $0.5562877529034291
# Shares owned at the moment: 0
# Cash capital at the moment: $139.29481651807538
#
#
# Share price: $0.5599541104345211
# Shares owned at the moment: 248
# Cash capital at the moment: $0.044308426997787365
#
#
# Price increase from previously bought: 15.886657839149642%
# Share price: $0.6506966123015503
# Shares owned at the moment: 0
# Cash capital at the moment: $160.9732931881926
#
#
# Share price: $0.9082584255396946
# Shares owned at the moment: 176
# Cash capital at the moment: $0.6802132152451179
#
#
# Price increase from previously bought: 5.4622641586655085%
# Share price: $0.9605040422109705
# Shares owned at the moment: 0
# Cash capital at the moment: $169.2640406879458
#
#
# Share price: $0.9137579181299034
# Shares owned at the moment: 184
# Cash capital at the moment: $0.6702222454698585
#
#
# Price increase from previously bought: -2.475006097260646%
# Share price: $0.8935929954153268
# Shares owned at the moment: 0
# Cash capital at the moment: $164.6391753462098
#
#
# Share price: $0.8028505809611559
# Shares owned at the moment: 204
# Cash capital at the moment: $0.40725765421478854
#
#
# Price increase from previously bought: -5.39766830492483%
# Share price: $0.7616040368831567
# Shares owned at the moment: 0
# Cash capital at the moment: $155.3472213136873
#
#
# Share price: $0.7414390267557212
# Shares owned at the moment: 208
# Cash capital at the moment: $0.7038006251930256
#
#
# Price increase from previously bought: -9.643841426720346%
# Share price: $0.6717781462521146
# Shares owned at the moment: 0
# Cash capital at the moment: $140.04939794597664
#
#
# Share price: $0.6561961048917591
# Shares owned at the moment: 212
# Cash capital at the moment: $0.5532613797718113
#
#
# Price increase from previously bought: 33.99338121994173%
# Share price: $0.881677311586063
# Shares owned at the moment: 0
# Cash capital at the moment: $186.95483356336248
#
#
# Share price: $0.7625205607062855
# Shares owned at the moment: 244
# Cash capital at the moment: $0.38816545479488695
#
#
# Price increase from previously bought: 7.397800461256621%
# Share price: $0.821182368616616
# Shares owned at the moment: 0
# Cash capital at the moment: $200.20565002790744
#
#
# Share price: $0.8770943428189835
# Shares owned at the moment: 227
# Cash capital at the moment: $0.5577080644934256
#
#
# Price increase from previously bought: -11.633830017838665%
# Share price: $0.777186078243512
# Shares owned at the moment: 0
# Cash capital at the moment: $176.49378941642715
#
#
# Share price: $0.7240237629233903
# Shares owned at the moment: 243
# Cash capital at the moment: $0.07218614646973265
#
#
# Price increase from previously bought: 2.2507542661607705%
# Share price: $0.7423556379917087
# Shares owned at the moment: 0
# Cash capital at the moment: $179.968527023367
#
#
# Share price: $0.6974426489697587
# Shares owned at the moment: 257
# Cash capital at the moment: $0.2328486459796011
#
#
# Price increase from previously bought: -6.171996300541382%
# Share price: $0.6561961048917591
# Shares owned at the moment: 0
# Cash capital at the moment: $168.41148100602942
#
#
# Share price: $0.7341063116935371
# Shares owned at the moment: 228
# Cash capital at the moment: $0.5749572824711038
#
#
# Price increase from previously bought: 2.5896062352051663%
# Share price: $0.7551878456441017
# Shares owned at the moment: 0
# Cash capital at the moment: $172.28428331010744
#
#
# Share price: $0.7570210681160767
# Shares owned at the moment: 226
# Cash capital at the moment: $0.7270333220399436
#
#
# Price increase from previously bought: 3.5896389239210125%
# Share price: $0.7863519283648126
# Shares owned at the moment: 0
# Cash capital at the moment: $177.95385140900885
#
#
# Share price: $0.7863519283648126
# Shares owned at the moment: 225
# ...
# actual buys: 32
# actual sells: 27
# actual holds: 536
#
#
# Percentage low buys correct: 48.148148148148145%
# Percentage high sells correct: 34.78260869565217%
# Percentage mid holds correct: 82.5910931174089%
#
#
# Capital: 100
# Share price: $0.7640580413790515
# Shares owned at the moment: 130
# Cash capital at the moment: $0.3993038709302823
#
#
# Price increase from previously bought: 8.200319511873788%
# Share price: $0.8289867034438764
# Shares owned at the moment: 0
# Cash capital at the moment: $107.87121257215301
#
#
# Share price: $0.9229365241315254
# Shares owned at the moment: 116
# Cash capital at the moment: $0.5161590216981153
#
#
# Price increase from previously bought: -21.427692567521383%
# Share price: $0.7271667475859093
# Shares owned at the moment: 0
# Cash capital at the moment: $84.63553554918369
#
#
# Share price: $0.8889966013918106
# Shares owned at the moment: 94
# Cash capital at the moment: $0.8400493968937042
#
#
# Price increase from previously bought: 9.602709850695646%
# Share price: $0.977043867611428
# Shares owned at the moment: 0
# Cash capital at the moment: $92.42960711259038
#
#
# Share price: $0.6499409875900374
# Shares owned at the moment: 141
# Cash capital at the moment: $0.5359132444570633
#
#
# Price increase from previously bought: -38.08660478212017%
# Share price: $0.40350713379351755
# Shares owned at the moment: 0
# Cash capital at the moment: $57.2739592182146
#
#
# Share price: $0.39022624551132734
# Shares owned at the moment: 146
# Cash capital at the moment: $0.14425153598801188
#
#
# Price increase from previously bought: -0.14853767922528016%
# Share price: $0.3907181406868988
# Shares owned at the moment: 0
# Cash capital at the moment: $57.03222674278945
#
#
# Share price: $0.4138367448416912
# Shares owned at the moment: 137
# Cash capital at the moment: $0.180679705858644
#
#
# Price increase from previously bought: 16.201895655349308%
# Share price: $0.4822085793161034
# Shares owned at the moment: 0
# Cash capital at the moment: $66.06158298990746
#
#
# Share price: $0.4615494510391672
# Shares owned at the moment: 142
# Cash capital at the moment: $0.34132588171492273
#
#
# Price increase from previously bought: -17.17277397641219%
# Share price: $0.3833399006921526
# Shares owned at the moment: 0
# Cash capital at the moment: $54.62589754878031
#
#
# Share price: $0.46450072827318334
# Shares owned at the moment: 117
# Cash capital at the moment: $0.12985923149596346
#
#
# Price increase from previously bought: -22.873661098172306%
# Share price: $0.3592376000056291
# Shares owned at the moment: 0
# Cash capital at the moment: $42.045073734352755
#
#
# Share price: $0.38481558621886636
# Shares owned at the moment: 108
# Cash capital at the moment: $0.3707001936081795
#
#
# Price increase from previously bought: -10.854481720141184%
# Share price: $0.3439892248405657
# Shares owned at the moment: 0
# Cash capital at the moment: $37.41937167661163
#
#
# Share price: $0.34005415725540666
# Shares owned at the moment: 109
# Cash capital at the moment: $0.2515373021349987
#
#
# Price increase from previously bought: -3.1592969660813264%
# Share price: $0.33021644138280426
# Shares owned at the moment: 0
# Cash capital at the moment: $36.146147034556165
#
#
# Share price: $0.28397932689263083
# Shares owned at the moment: 126
# Cash capital at the moment: $0.26635300931638284
#
#
# Price increase from previously bought: 10.435409755807656%
# Share price: $0.3144761710421694
# Shares owned at the moment: 0
# Cash capital at the moment: $39.78138456736362
#
#
# Share price: $0.3380865765531217
# Shares owned at the moment: 117
# Cash capital at the moment: $0.11647575464240845
#
#
# Price increase from previously bought: 2.482500767103546%
# Share price: $0.3474323972501533
# Shares owned at the moment: 0
# Cash capital at the moment: $40.654279859095105
#
#
# Share price: $0.3474323972501533
# Shares owned at the moment: 116
# Cash capital at the moment: $0.24129084335452688
#
#
# Price increase from previously bought: -18.20520479838128%
# Share price: $0.2849631172437731
# Shares owned at the moment: 0
# Cash capital at the moment: $33.20610920923144
#
#
# Share price: $0.08870144552258584
# Shares owned at the moment: 373
# Cash capital at the moment: $0.029484521562132215
#
#
# Price increase from previously bought: -18.523835089148612%
# Share price: $0.07246928000637985
# Shares owned at the moment: 0
# Cash capital at the moment: $26.986190599975274
#
#
# Share price: $0.06410724966049096
# Shares owned at the moment: 419
# Cash capital at the moment: $0.051385413808262115
#
#
# Price increase from previously bought: 61.70517873466459%
# Share price: $0.10394982068764934
# Shares owned at the moment: 0
# Cash capital at the moment: $43.48658410104599
#
#
# Share price: $0.05181015172944358
# Shares owned at the moment: 837
# Cash capital at the moment: $0.0022330867584656744
#
#
# Price increase from previously bought: 102.92621746252793%
# Share price: $0.1054255062143633
# Shares owned at the moment: 0
# Cash capital at the moment: $88.00071862925162
#
#
# Share price: $0.0872257599958721
# Shares owned at the moment: 1006
# Cash capital at the moment: $0.01029400837569483
#
#
#
#
# Capital at the end of test period: $60.37704283444854
# profit gained: -39.62295716555146%
#
#
# Capital at the end of test period if Buy and Hold: $8.115342010843221
# profit gained: -91.88465798915678%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.818548     10.000000       0.000000      92.237443
# 1       0.803653     16.666667      16.000000      93.406593
# 2       0.782979      6.250000       8.333333      90.298507
# 3       0.762590      8.333333       0.000000      88.607595
# 4       0.798077     16.666667      14.285714      92.528736
# 5       0.744538      5.555556       0.000000      88.888889
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         30.000000           52.631579          83.027523     766.944789
# 1         58.333333           52.000000          86.187845    1855.581501
# 2         46.875000           52.777778          84.039900      43.028575
# 3         33.333333           35.294118          82.627119     -96.446316
# 4         50.000000           57.142857          85.549133    2842.294702
# 5         48.148148           34.782609          82.591093     -39.622957
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
# 5         -91.884658
#
#
# full cycle data
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2119 - accuracy: 0.7917 - mse: 9.7501 - weighted_accuracy: 0.7917 - weighted_mse: 9.7501
# Test loss: 0.21188604831695557
# Test accuracy: 0.7917121052742004
#
#
# number of predictions: 917
# actual predicted buys: 10
# actual buys but predicted sell: 3
# actual buys but predicted hold: 33
# actual sells but predicted buy: 4
# actual predicted sells: 4
# actual sells but predicted hold: 32
# actual holds but predicted buy: 66
# actual holds but predicted sell: 53
# actual predicted holds: 712
# Percentage buys correct: 12.5%
# Percentage sells correct: 6.666666666666667%
# Percentage holds correct: 91.63449163449164%
# actual buys: 46
# actual sells: 40
# actual holds: 831
#
#
# Percentage low buys correct: 48.75%
# Percentage high sells correct: 40.0%
# Percentage mid holds correct: 85.18041237113403%
#
#
# Capital: 100
# Share price: $0.32989002238599585
# Shares owned at the moment: 302
# Cash capital at the moment: $0.09923957583767162
#
#
# Price increase from previously bought: -24.103593014465975%
# Share price: $0.25106320434823026
# Shares owned at the moment: 0
# Cash capital at the moment: $75.711819297792
#
#
# Share price: $0.1859852926117035
# Shares owned at the moment: 405
# Cash capital at the moment: $0.1806346704058086
#
#
# Price increase from previously bought: -27.30551436894686%
# Share price: $0.13557285470597402
# Shares owned at the moment: 0
# Cash capital at the moment: $54.93664655939651
#
#
# Share price: $0.12182399211116422
# Shares owned at the moment: 449
# Cash capital at the moment: $0.08725192722450714
#
#
# Price increase from previously bought: 197.06138404467345%
# Share price: $0.36288724016582397
# Shares owned at the moment: 0
# Cash capital at the moment: $162.57554774188472
#
#
# Share price: $0.3638038514018116
# Shares owned at the moment: 445
# Cash capital at the moment: $0.23762890492557176
#
#
# Price increase from previously bought: -1.028005087431516%
# Share price: $0.3610541051067073
# Shares owned at the moment: 0
# Cash capital at the moment: $160.464865716286
#
#
# Share price: $0.47196144227545456
# Shares owned at the moment: 339
# Cash capital at the moment: $0.029950730345603915
#
#
# Price increase from previously bought: 7.666490064757658%
# Share price: $0.5095417162352209
# Shares owned at the moment: 0
# Cash capital at the moment: $172.28957226912522
#
#
# Share price: $0.4096333642468908
# Shares owned at the moment: 419
# Cash capital at the moment: $0.18119260572450457
#
#
# Price increase from previously bought: -0.9436749940813893%
# Share price: $0.4068836179517865
# Shares owned at the moment: 0
# Cash capital at the moment: $170.19659687873812
#
#
# Share price: $0.4857103485766936
# Shares owned at the moment: 349
# Cash capital at the moment: $0.21752471842557952
#
#
# Price increase from previously bought: 1.984077089693792%
# Share price: $0.49670942116996963
# Shares owned at the moment: 0
# Cash capital at the moment: $173.0923958397771
#
#
# Share price: $0.5443721564870241
# Shares owned at the moment: 317
# Cash capital at the moment: $0.05186580597290913
#
#
# Price increase from previously bought: 2.244456347562207%
# Share price: $0.5581209753754044
# Shares owned at the moment: 0
# Cash capital at the moment: $176.48967303969258
#
#
# Share price: $0.5599541104345211
# Shares owned at the moment: 314
# Cash capital at the moment: $0.18056198889271968
#
#
# Price increase from previously bought: 15.233693135339731%
# Share price: $0.6470302547704587
# Shares owned at the moment: 0
# Cash capital at the moment: $202.78935136182247
#
#
# Share price: $0.581035731797944
# Shares owned at the moment: 348
# Cash capital at the moment: $0.03286550080733264
#
#
# Price increase from previously bought: 30.088224450349443%
# Share price: $0.7579376793520645
# Shares owned at the moment: 0
# Cash capital at the moment: $263.0698315561858
#
#
# Share price: $0.9091750367756823
# Shares owned at the moment: 288
# Cash capital at the moment: $0.5073543356629671
#
#
# Price increase from previously bought: 5.355939312084401%
# Share price: $0.9605040422109705
# Shares owned at the moment: 0
# Cash capital at the moment: $276.3717992909914
#
#
# Share price: $0.928423348254271
# Shares owned at the moment: 296
# Cash capital at the moment: $0.8027516022482359
#
#
# Price increase from previously bought: -2.7356042689014926%
# Share price: $0.9055086792445903
# Shares owned at the moment: 0
# Cash capital at the moment: $268.0962365937419
#
#
# Share price: $0.7240237629233903
# Shares owned at the moment: 369
# Cash capital at the moment: $0.19676496158433565
#
#
# Price increase from previously bought: -7.470464776655772%
# Share price: $0.6717781462521146
# Shares owned at the moment: 0
# Cash capital at the moment: $247.4012140547053
#
#
# Share price: $0.645197032298483
# Shares owned at the moment: 382
# Cash capital at the moment: $0.2581682342552085
#
#
# Price increase from previously bought: 24.235365959830958%
# Share price: $0.8037671921971437
# Shares owned at the moment: 0
# Cash capital at the moment: $306.452878218161
#
#
# Share price: $0.8193492335574992
# Shares owned at the moment: 372
# Cash capital at the moment: $0.8167690688420066
#
#
# Price increase from previously bought: 0.6182436173731043%
# Share price: $0.8266819486196832
# Shares owned at the moment: 0
# Cash capital at the moment: $307.4967583219262
#
#
# Share price: $0.6470302547704587
# Shares owned at the moment: 473
# Cash capital at the moment: $0.6098232116065674
#
#
# Price increase from previously bought: 1.1384722201440267%
# Share price: $0.6561961048917591
# Shares owned at the moment: 0
# Cash capital at the moment: $310.13703374197064
#
#
# Share price: $0.7331897004575496
# Shares owned at the moment: 421
# Cash capital at the moment: $0.6153194736374985
#
#
# Price increase from previously bought: 7.580042479298821%
# Share price: $0.7909348971318924
# Shares owned at the moment: 0
# Cash capital at the moment: $332.6832062890097
#
#
# Share price: $0.7331897004575496
# Shares owned at the moment: 452
# Cash capital at the moment: $0.3701068845285249
#
#
# Price increase from previously bought: -12.242683444761681%
# Share price: $0.645197032298483
# Shares owned at the moment: 0
# Cash capital at the moment: $291.1971855722958
#
#
# Share price: $0.6341979597052072
# Shares owned at the moment: 457
# Cash capital at the moment: $0.571689701156572
#
#
# Price increase from previously bought: -43.22530941782012%
# Share price: $0.3610541051067073
# Shares owned at the moment: 0
# Cash capital at the moment: $165.11966098832895
#
#
# Share price: $0.3894683541194557
# Shares owned at the moment: 422
# Cash capital at the moment: $0.3120375249630172
#
#
# Price increase from previously bought: 4.1850389971924695%
# Share price: $0.4068836179517865
# Shares owned at the moment: 0
# Cash capital at the moment: $171.54473586198387
#
#
# Share price: $0.39588445794565186
# Shares owned at the moment: 432
# Cash capital at the moment: $0.0523392934228184
#
#
# Price increase from previously bought: 11.27049315291806%
# Share price: $0.44171397079073105
# Shares owned at the moment: 0
# Cash capital at the moment: $190.34801847771925
#
#
# Share price: $0.3931347116505476
# Shares owned at the moment: 482
# Cash capital at the moment: $0.3359874018624964
#
#
# Price increase from previously bought: -15.154877988529103%
# Share price: $0.3344729037402171
# Shares owned at the moment: 0
# Cash capital at the moment: $161.10858317073945
#
#
# Share price: $0.3280567999140207
# Shares owned at the moment: 489
# Cash capital at the moment: $0.24765363109895588
#
#
# Price increase from previously bought: 6.134341317851044%
# Share price: $0.34913842127744366
# Shares owned at the moment: 0
# Cash capital at the moment: $170.50683774375605
#
#
# Share price: $0.21439962903731036
# Shares owned at the moment: 793
# Cash capital at the moment: $0.020379926145807303
#
#
# Price increase from previously bought: -4.5376861919952045%
# Share price: $0.20523369150315107
# Shares owned at the moment: 0
# Cash capital at the moment: $162.32313391539913
#
#
# Share price: $0.1933180076738873
# Shares owned at the moment: 837
# Cash capital at the moment: $0.07099176819210129
#
#
# Price increase from previously bought: -16.35064414437618%
# Share price: $0.16215396865960552
# Shares owned at the moment: 0
# Cash capital at the moment: $135.42062563891966
#
#
# Share price: $0.14382218100414568
# Shares owned at the moment: 939
# Cash capital at the moment: $0.00021284912892838292
#
#
#
#
# Capital at the end of test period: $17.089205920278662
# profit gained: -82.91079407972134%
#
#
# Capital at the end of test period if Buy and Hold: $3.993306781778525
# profit gained: -96.00669321822147%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.818548     10.000000       0.000000      92.237443
# 1       0.803653     16.666667      16.000000      93.406593
# 2       0.782979      6.250000       8.333333      90.298507
# 3       0.762590      8.333333       0.000000      88.607595
# 4       0.798077     16.666667      14.285714      92.528736
# 5       0.744538      5.555556       0.000000      88.888889
# 6       0.791712     12.500000       6.666667      91.634492
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         30.000000           52.631579          83.027523     766.944789
# 1         58.333333           52.000000          86.187845    1855.581501
# 2         46.875000           52.777778          84.039900      43.028575
# 3         33.333333           35.294118          82.627119     -96.446316
# 4         50.000000           57.142857          85.549133    2842.294702
# 5         48.148148           34.782609          82.591093     -39.622957
# 6         48.750000           40.000000          85.180412     -82.910794
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
# 5         -91.884658
# 6         -96.006693

# %%
df = log_hist['0_epochs_logs']
df['Profit gained']
# Out:
# 0    -18.988067
# 1    708.841119
# 2    341.005699
# 3    -95.052121
# 4    870.866960
# 5    -68.852545
# 6    -25.104354
# Name: Profit gained, dtype: float64

# %%
accumulation_phase_data_acc = []
mark_up_phase_data_acc = []
distribution_phase_data_acc = []
mark_down_phase_data_acc = []
bull_phase_data_acc = []
bear_phase_data_acc = []
full_cycle_data_acc = []

accumulation_phase_data_correct_buys = []
mark_up_phase_data_correct_buys = []
distribution_phase_data_correct_buys = []
mark_down_phase_data_correct_buys = []
bull_phase_data_correct_buys = []
bear_phase_data_correct_buys = []
full_cycle_data_correct_buys = []

accumulation_phase_data_correct_sells = []
mark_up_phase_data_correct_sells = []
distribution_phase_data_correct_sells = []
mark_down_phase_data_correct_sells = []
bull_phase_data_correct_sells = []
bear_phase_data_correct_sells = []
full_cycle_data_correct_sells = []

accumulation_phase_data_correct_holds = []
mark_up_phase_data_correct_holds = []
distribution_phase_data_correct_holds = []
mark_down_phase_data_correct_holds = []
bull_phase_data_correct_holds = []
bear_phase_data_correct_holds = []
full_cycle_data_correct_holds = []

accumulation_phase_data_correct_low_buys = []
mark_up_phase_data_correct_low_buys = []
distribution_phase_data_correct_low_buys = []
mark_down_phase_data_correct_low_buys = []
bull_phase_data_correct_low_buys = []
bear_phase_data_correct_low_buys = []
full_cycle_data_correct_low_buys = []

accumulation_phase_data_correct_high_sells = []
mark_up_phase_data_correct_high_sells = []
distribution_phase_data_correct_high_sells = []
mark_down_phase_data_correct_high_sells = []
bull_phase_data_correct_high_sells = []
bear_phase_data_correct_high_sells = []
full_cycle_data_correct_high_sells = []

accumulation_phase_data_correct_mid_holds = []
mark_up_phase_data_correct_mid_holds = []
distribution_phase_data_correct_mid_holds = []
mark_down_phase_data_correct_mid_holds = []
bull_phase_data_correct_mid_holds = []
bear_phase_data_correct_mid_holds = []
full_cycle_data_correct_mid_holds = []

accumulation_phase_data_profit = []
mark_up_phase_data_profit = []
distribution_phase_data_profit = []
mark_down_phase_data_profit = []
bull_phase_data_profit = []
bear_phase_data_profit = []
full_cycle_data_profit = []

for key,value in log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    accumulation_phase_data_acc.append(acc[0])
    mark_up_phase_data_acc.append(acc[1])
    distribution_phase_data_acc.append(acc[2])
    mark_down_phase_data_acc.append(acc[3]) 
    bull_phase_data_acc.append(acc[4]) 
    bear_phase_data_acc.append(acc[5]) 
    full_cycle_data_acc.append(acc[6]) 

    accumulation_phase_data_correct_buys.append(correct_buys[0])
    mark_up_phase_data_correct_buys.append(correct_buys[1]) 
    distribution_phase_data_correct_buys.append(correct_buys[2]) 
    mark_down_phase_data_correct_buys.append(correct_buys[3]) 
    bull_phase_data_correct_buys.append(correct_buys[4])
    bear_phase_data_correct_buys.append(correct_buys[5]) 
    full_cycle_data_correct_buys.append(correct_buys[6]) 

    accumulation_phase_data_correct_sells.append(correct_sells[0]) 
    mark_up_phase_data_correct_sells.append(correct_sells[1]) 
    distribution_phase_data_correct_sells.append(correct_sells[2]) 
    mark_down_phase_data_correct_sells.append(correct_sells[3]) 
    bull_phase_data_correct_sells.append(correct_sells[4]) 
    bear_phase_data_correct_sells.append(correct_sells[5]) 
    full_cycle_data_correct_sells.append(correct_sells[6])

    accumulation_phase_data_correct_holds.append(correct_holds[0]) 
    mark_up_phase_data_correct_holds.append(correct_holds[1])  
    distribution_phase_data_correct_holds.append(correct_holds[2])  
    mark_down_phase_data_correct_holds.append(correct_holds[3])  
    bull_phase_data_correct_holds.append(correct_holds[4])  
    bear_phase_data_correct_holds.append(correct_holds[5])  
    full_cycle_data_correct_holds.append(correct_holds[6])  

    accumulation_phase_data_correct_low_buys.append(correct_low_buys[0])  
    mark_up_phase_data_correct_low_buys.append(correct_low_buys[1])  
    distribution_phase_data_correct_low_buys.append(correct_low_buys[2])  
    mark_down_phase_data_correct_low_buys.append(correct_low_buys[3])   
    bull_phase_data_correct_low_buys.append(correct_low_buys[4])   
    bear_phase_data_correct_low_buys.append(correct_low_buys[5])  
    full_cycle_data_correct_low_buys.append(correct_low_buys[6])  

    accumulation_phase_data_correct_high_sells.append(correct_high_sells[0]) 
    mark_up_phase_data_correct_high_sells.append(correct_high_sells[1]) 
    distribution_phase_data_correct_high_sells.append(correct_high_sells[2]) 
    mark_down_phase_data_correct_high_sells.append(correct_high_sells[3]) 
    bull_phase_data_correct_high_sells.append(correct_high_sells[4]) 
    bear_phase_data_correct_high_sells.append(correct_high_sells[5]) 
    full_cycle_data_correct_high_sells.append(correct_high_sells[6]) 

    accumulation_phase_data_correct_mid_holds.append(correct_mid_holds[0])  
    mark_up_phase_data_correct_mid_holds.append(correct_mid_holds[1])  
    distribution_phase_data_correct_mid_holds.append(correct_mid_holds[2])   
    mark_down_phase_data_correct_mid_holds.append(correct_mid_holds[3])   
    bull_phase_data_correct_mid_holds.append(correct_mid_holds[4])   
    bear_phase_data_correct_mid_holds.append(correct_mid_holds[5])   
    full_cycle_data_correct_mid_holds.append(correct_mid_holds[6])   

    accumulation_phase_data_profit.append(profit[0]) 
    mark_up_phase_data_profit.append(profit[1]) 
    distribution_phase_data_profit.append(profit[2]) 
    mark_down_phase_data_profit.append(profit[3])  
    bull_phase_data_profit.append(profit[4])  
    bear_phase_data_profit.append(profit[5])  
    full_cycle_data_profit.append(profit[6])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(accumulation_phase_data_acc)
plt.plot(mark_up_phase_data_acc)
plt.plot(distribution_phase_data_acc)
plt.plot(mark_down_phase_data_acc)
plt.plot(bull_phase_data_acc)
plt.plot(bear_phase_data_acc)
plt.plot(full_cycle_data_acc)
plt.title('Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['accumulation_phase_data_acc','mark_up_phase_data_acc','distribution_phase_data_acc','mark_down_phase_data_acc','bull_phase_data_acc','bear_phase_data_acc','full_cycle_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct buys")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_buys")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_buys")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_buys")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_buys")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct sells")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_sells")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_sells")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_sells")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_sells")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct holds")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_holds")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_holds")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_holds")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_holds")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct low buys")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_low_buys")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_low_buys")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_low_buys")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_low_buys")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct high sells")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_high_sells")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_high_sells")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_high_sells")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_high_sells")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_mid_holds")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_mid_holds")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_mid_holds")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_mid_holds")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Profit")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_profit")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_profit")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_profit")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_profit")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_profit")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_profit")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_profit")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_profit')
