# %%
import os
seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
experiment = 'Bear phase CNN Images Experiment'

# %%
import requests
import lxml
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.utils import compute_class_weight
import tensorflow as tf
from pil import Image
from sklearn import preprocessing
import tensorflow_addons as tfa
import glob
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
import math

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
# gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
np.random.seed(seed)
tf.random.set_seed(seed)

session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, 
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), 
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)

# %% [markdown]
# ## Prepare Test Data

# %%
test_sets = ['accumulation phase data','mark up phase data','distribution phase data','mark down phase data','bull phase data','bear phase data','full cycle data']
test_data = {}

for name in test_sets:

    df = pd.read_csv("{}/test_data.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    willr_data = []
    price_data = []
    ema_data = []
    obv_data = []
    labels = []
    data_15_price = []
    data_15_willr = []
    data_15_ema = []
    data_15_obv = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
            data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
            data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
            data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
            price_data.append(data_15_price_arr)
            willr_data.append(data_15_willr_arr)
            ema_data.append(data_15_ema_arr)
            obv_data.append(data_15_obv_arr)
            labels.append(i[-1])
            data_15_price = data_15_price[1:]
            data_15_willr = data_15_willr[1:]
            data_15_obv = data_15_obv[1:]
            data_15_ema = data_15_ema[1:]

        else:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            count += 1

    willr_data = np.array(willr_data)
    price_data = np.array(price_data)
    ema_data = np.array(ema_data)
    obv_data = np.array(obv_data)
    
    sequential_data = []
    
    for i in range(0,len(willr_data)):
        j = willr_data[i]
        k = price_data[i]
        l = ema_data[i]
        m = obv_data[i]
        fig, ax = plt.subplots()
        fig.set_size_inches((5,5))

        ax.plot(k)
        ax.plot(j)
        ax.plot(l)
        ax.plot(m)

        ax.axis('off')

        fig.add_axes(ax)
        fig.canvas.draw()

        # this rasterized the figure
        X = np.array(fig.canvas.renderer._renderer)
        X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
        X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
        sequential_data.append(X)
        plt.close()
        
    X = sequential_data
    y = labels

    X  = np.array(X).reshape(-1, 64, 64, 1)
    X = X/255
    y = np.array(y)
    
    y = to_categorical(y, 3)
    
    test_data['{}_X'.format(name)] = X
    test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2004-06-14    93.010002  92.918784 -32.009897  48922600.0     2.0
# 2004-06-15    91.529999  92.705124 -68.734488  45879300.0     2.0
# 2004-06-16    90.209999  92.321259 -94.676024  40369000.0     2.0
# 2004-06-17    89.980003  91.961066 -87.983635  36219100.0     2.0
# 2004-06-18    89.339996  91.557824 -85.961924  32718400.0     2.0
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22   115.589996  116.459043 -80.074504 -17684500.0     2.0
# 2020-01-23   116.099998  116.403805 -70.577262 -12758400.0     2.0
# 2020-01-24   115.809998  116.312450 -69.789236 -17063500.0     2.0
# 2020-01-27   114.370003  116.013612 -94.416205 -21446900.0     2.0
# 2020-01-28   115.860001  115.989979 -34.297465 -14428500.0     2.0
#             previous_1d      EMA_12   willr_14        OBV_7  labels
# Date
# 2016-12-05   223.360001  213.378658 -16.514565 -283274800.0     2.0
# 2016-12-06   228.550003  215.712711  -2.667189 -278675500.0     2.0
# 2016-12-07   231.380005  218.123064  -4.633597 -273416200.0     2.0
# 2016-12-08   235.559998  220.805669  -1.742271 -266821000.0     2.0
# 2016-12-09   241.449997  223.981719  -2.918174 -259477300.0     2.0
#             previous_1d      EMA_12   willr_14        OBV_7  labels
# Date
# 2007-10-01   216.740005  205.638670  -5.220429  161688200.0     2.0
# 2007-10-02   222.979996  208.306567  -1.526716  171593800.0     2.0
# 2007-10-03   228.020004  211.339403  -1.071898  181013600.0     2.0
# 2007-10-04   227.350006  213.802573  -7.282412  170892200.0     2.0
# 2007-10-05   225.949997  215.671407 -10.566735  160852300.0     2.0
#             previous_1d       EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22  1075.300049  1097.577291 -89.711935   1200864.0     2.0
# 2020-01-23  1075.510010  1094.182325 -70.779503   4820868.0     2.0
# 2020-02-03  1052.800049  1087.815821 -81.895216   -525975.0     1.0
# 2020-02-04  1003.919983  1074.908769 -83.419991 -12870263.0     2.0
# 2020-02-05  1038.010010  1069.232037 -59.790669  -6607845.0     2.0
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2018-01-22    32.830002  32.653718 -49.494874  128764966.0     2.0
# 2018-01-23    33.750000  32.822377 -18.518497  165063463.0     2.0
# 2018-01-24    33.970001  32.998934 -16.190425  201240854.0     2.0
# 2018-01-25    33.959999  33.146790 -17.627141  173336178.0     2.0
# 2018-01-26    34.880001  33.413438  -2.648942  221767625.0     0.0
#             previous_1d    EMA_12   willr_14        OBV_7  labels
# Date
# 2002-11-11         8.74  8.763110 -71.929852 -553467352.0     2.0
# 2002-11-12         8.50  8.722632 -80.487816 -559735252.0     2.0
# 2002-11-13         8.63  8.708381 -69.918697 -552295352.0     2.0
# 2002-11-14         8.52  8.679399 -78.861762 -566378552.0     2.0
# 2002-11-15         8.80  8.697953 -56.097548 -558353452.0     2.0

# %% [markdown]
# ## Train Accumulation Phase Stock Data

# %%
def pred_acc(actual, predictions, logger):

    hold = 0
    sell = 0
    buy = 0
    pred_hold = 0
    pred_sell = 0
    pred_buy = 0
    buy_buy = 0
    buy_sell = 0
    buy_hold = 0
    sell_buy = 0
    sell_sell = 0
    sell_hold = 0
    hold_buy = 0
    hold_sell = 0
    hold_hold = 0

    for i in range (0,len(actual)):
        if actual[i]==1 and predictions[i] == 1:
            buy_buy += 1
            buy += 1
            pred_buy += 1
        elif actual[i]==1 and predictions[i] == 0:
            buy_sell += 1
            buy += 1
            pred_sell += 1
        elif actual[i]==1 and predictions[i] == 2:
            buy_hold += 1
            buy += 1
            pred_hold += 1
        elif actual[i]==0 and predictions[i] == 1:
            sell_buy += 1
            sell += 1
            pred_buy += 1
        elif actual[i]==0 and predictions[i] == 0:
            sell_sell += 1
            sell += 1
            pred_sell += 1
        elif actual[i]==0 and predictions[i] == 2:
            sell_hold += 1
            sell += 1
            pred_hold += 1
        elif actual[i]==2 and predictions[i] == 1:
            hold_buy += 1
            hold += 1
            pred_buy += 1
        elif actual[i]==2 and predictions[i] == 0:
            hold_sell += 1
            hold += 1
            pred_sell += 1
        elif actual[i]==2 and predictions[i] == 2:
            hold_hold += 1
            hold += 1
            pred_hold += 1

    print("number of predictions: " + str(len(actual)))
    print("actual predicted buys: " + str(buy_buy) )
    print("actual buys but predicted sell: " + str(buy_sell) )
    print("actual buys but predicted hold: " + str(buy_hold))
    print("actual sells but predicted buy: " + str(sell_buy) )
    print("actual predicted sells: " + str(sell_sell))
    print("actual sells but predicted hold: " + str(sell_hold) )
    print("actual holds but predicted buy: " + str(hold_buy) )
    print("actual holds but predicted sell: " + str(hold_sell))
    print("actual predicted holds: " + str(hold_hold) )
    
    if pred_buy !=0:
        Percentage_buys_correct = 100*buy_buy/pred_buy
    else:
        Percentage_buys_correct = 0
        
    if pred_sell !=0:
        Percentage_sells_correct = 100*sell_sell/pred_sell
    else:
        Percentage_sells_correct = 0
        
    if pred_hold !=0:
        Percentage_holds_correct = 100*hold_hold/pred_hold
    else:
        Percentage_holds_correct = 0

    print("Percentage buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage holds correct: " + str(Percentage_holds_correct) + "%")

    print("actual buys: " + str(buy))
    print("actual sells: " + str(sell))
    print("actual holds: " + str(hold))
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def correct_maxima_minima(predictions, price, logger):
    correct_maxima = 0 
    correct_minima = 0
    correct_hold = 0

    hold = 0
    buy = 0
    sell = 0

#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):
        if i < 4:
            prices = price[i:i+9]
            prices.sort(key = float)
#             if i == 0:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1

        else:
            prices = price[i:i+5]
            prices = prices + price[i-4:i] 
            prices.sort(key = float)
#             if i == 10:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1
                    
    if buy !=0:
        Percentage_buys_correct = 100*correct_minima/buy
    else:
        Percentage_buys_correct = 0
        
    if sell !=0:
        Percentage_sells_correct = 100*correct_maxima/sell
    else:
        Percentage_sells_correct = 0
        
    if hold !=0:
        Percentage_holds_correct = 100*correct_hold/hold
    else:
        Percentage_holds_correct = 0

    print("Percentage low buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage high sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage mid holds correct: " + str(Percentage_holds_correct) + "%")
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %% [markdown]
# ### Creating Training Data and Model

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []

for filepath in glob.iglob('bear phase data/*_acc_data.csv'):
    print(filepath)
    seed = 10
    df = pd.read_csv(filepath)
    df.set_index('Date', inplace=True)
    print(df.head())
    
    plt.figure(figsize=(15,5))
    plt.plot(df['previous_1d'].values)
    plt.plot(df['EMA_12'].values)
    plt.show()

    data_15_price = []
    data_15_willr = []
    data_15_ema = []
    data_15_obv = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
            data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
            data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
            data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
            price_data.append(data_15_price_arr)
            willr_data.append(data_15_willr_arr)
            ema_data.append(data_15_ema_arr)
            obv_data.append(data_15_obv_arr)
            labels.append(i[-1])
            data_15_price = data_15_price[1:]
            data_15_willr = data_15_willr[1:]
            data_15_obv = data_15_obv[1:]
            data_15_ema = data_15_ema[1:]

        else:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            count += 1
# Out:
# bear phase data\0_acc_data.csv
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2013-07-29    49.000000  49.438690 -80.861264  113567600.0     2.0
# 2013-07-30    48.910000  49.357353 -83.014377  111851600.0     2.0
# 2013-07-31    49.790001  49.423914 -61.961722  113019000.0     2.0
# 2013-08-01    49.869999  49.492543 -51.169618  113978800.0     2.0
# 2013-08-02    51.459999  49.795228 -19.306991  115490000.0     0.0
# bear phase data\1_acc_data.csv
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2000-01-21    49.375000  48.388499 -42.592593  -2894250.0     2.0
# 2000-01-24    48.625000  48.424884 -39.516144  -8054850.0     2.0
# 2000-01-25    48.666668  48.462081 -38.709668  -1595700.0     2.0
# 2000-01-26    49.750000  48.660222 -17.741956   5984250.0     2.0
# 2000-01-27    52.291668  49.218906  -5.232557  14370900.0     2.0
# bear phase data\2_acc_data.csv
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2001-04-16    29.000000  28.506905 -34.482761 -99375452.0     2.0
# 2001-04-17    29.180000  28.610458 -27.586194 -95843852.0     2.0
# 2001-04-18    28.879999  28.651926 -39.080497 -99108352.0     0.0
# 2001-04-19    30.709999  28.968553 -17.191311 -87511052.0     2.0
# 2001-04-20    30.299999  29.173391 -27.118670 -94318852.0     2.0
# bear phase data\3_acc_data.csv
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2011-01-03    36.860001  35.273652  -3.166198  661708900.0     2.0
# 2011-01-04    37.060001  35.548475 -19.542585  686583800.0     2.0
# 2011-01-05    37.900002  35.910248  -2.078970  718947200.0     2.0
# 2011-01-06    38.070000  36.242518  -4.500969  741451100.0     2.0
# 2011-01-07    38.900002  36.651361  -9.220953  780008000.0     0.0
# bear phase data\4_acc_data.csv
#             previous_1d    EMA_12   willr_14         OBV_7  labels
# Date
# 2018-01-22         7.19  6.771425  -1.136336  3.248229e+09     2.0
# 2018-01-23         7.09  6.820437 -14.666621  2.718594e+09     2.0
# 2018-01-24         7.33  6.898831  -8.333325  3.443507e+09     2.0
# 2018-01-25         7.28  6.957472 -13.541628  2.874295e+09     2.0
# 2018-01-26         7.06  6.973246 -36.458322  2.394853e+09     2.0
# bear phase data\5_acc_data.csv
#             previous_1d     EMA_12   willr_14      OBV_7  labels
# Date
# 2018-01-23    36.180000  35.813713 -13.991774 -1195100.0     0.0
# 2018-01-24    36.470001  35.914681  -2.403807  -818600.0     2.0
# 2018-01-25    36.330002  35.978576 -13.013613 -1233200.0     2.0
# 2018-01-26    35.900002  35.966488 -54.867110 -1638100.0     2.0
# 2018-01-29    36.209999  36.003951 -29.245375 -1229100.0     2.0
# bear phase data\6_acc_data.csv
#             previous_1d     EMA_12   willr_14      OBV_7  labels
# Date
# 2013-11-18    41.169998  40.276379  -1.421923  6585600.0     2.0
# 2013-11-19    41.230000  40.423090 -14.056307  6808000.0     2.0
# 2013-11-20    40.970001  40.507230 -24.498000  6523100.0     2.0
# 2013-11-21    41.189999  40.612271 -15.662769  6840300.0     2.0
# 2013-11-22    42.430000  40.891922  -0.595252  7413300.0     0.0

# %%
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)
obv_data.shape
# Out:
# (4476, 15, 1)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
y = np.array(y)

X.shape
# Out:
# (4476, 64, 64, 1)

# %%
from collections import Counter

Counter(y)
# Out:
# Counter({2.0: 4068, 1.0: 208, 0.0: 200})

# %%
# plot the image array X
i = X[0].reshape(64, 64)
fig2, ax2 = plt.subplots()
plt.imshow(i, interpolation="none", cmap="gray")

ax2.axis('off')

plt.show()

# %%
X = X/255

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten,BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.regularizers import l2
import efficientnet.tfkeras as efn
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(Conv2D(16, (3, 3), padding='same', kernel_initializer='he_uniform',kernel_regularizer=l2(1e-5), input_shape=X_train.shape[1:]))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))

model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_uniform',kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

# model.add(Dense(128, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))
# model.add(Dropout(0.25, seed=seed))

model.add(Dense(64, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))
model.add(Dropout(0.25, seed=seed))

model.add(Dense(32, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))
model.add(Dropout(0.25, seed=seed))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "DBS_CNN_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))
print(d_class_weights)

epochs = 0 
histories = {}
log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['accumulation phase data','mark up phase data','distribution phase data','mark down phase data','bull phase data','bear phase data','full cycle data']
    
    for name in test_sets:
        
        print('\n')
        print(name)
        print('\n')
        
        X = test_data['{}_X'.format(name)]
        y = test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("{}/test_data.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(log)
        log.loc[df_length] = logger
        print(log.head(20))
        logger = []

    log.to_csv('{}_{}epochs.csv'.format(experiment,epochs))
    log_hist['{}_epochs_logs'.format(epochs)] = log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 2 ... 2 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# {0: 7.458333333333333, 1: 7.188755020080321, 2: 0.3667281294816636}
#
#
#
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  1/28 [>.............................] - ETA: 0s - loss: 0.4015 - accuracy: 0.6953 - mse: 5.6165 - weighted_accuracy: 0.4265 - weighted_mse: 5.9597WARNING:tensorflow:From C:\Users\Shearman Chua\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/28 [=>............................] - ETA: 1s - loss: 0.3674 - accuracy: 0.6875 - mse: 4.3783 - weighted_accuracy: 0.4089 - weighted_mse: 4.7248WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0090s vs `on_train_batch_end` time: 0.0838s). Check your callbacks.
# 28/28 [==============================] - ETA: 0s - loss: 0.2464 - accuracy: 0.4964 - mse: 1.6051 - weighted_accuracy: 0.3516 - weighted_mse: 1.6962WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_test_batch_end` time: 0.0030s). Check your callbacks.
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2464 - accuracy: 0.4964 - mse: 1.6051 - weighted_accuracy: 0.3516 - weighted_mse: 1.6962 - val_loss: 0.1972 - val_accuracy: 0.2009 - val_mse: 0.8790 - val_weighted_accuracy: 0.2009 - val_weighted_mse: 0.8790
# Epoch 2/20
# 28/28 [==============================] - 0s 15ms/step - loss: 0.2070 - accuracy: 0.3525 - mse: 1.1758 - weighted_accuracy: 0.3392 - weighted_mse: 1.1854 - val_loss: 0.2039 - val_accuracy: 0.0569 - val_mse: 0.9160 - val_weighted_accuracy: 0.0569 - val_weighted_mse: 0.9160
# Epoch 3/20
# 28/28 [==============================] - 0s 15ms/step - loss: 0.2050 - accuracy: 0.3209 - mse: 1.1517 - weighted_accuracy: 0.3368 - weighted_mse: 1.1451 - val_loss: 0.2020 - val_accuracy: 0.0480 - val_mse: 0.9063 - val_weighted_accuracy: 0.0480 - val_weighted_mse: 0.9063
# Epoch 4/20
# 28/28 [==============================] - 0s 15ms/step - loss: 0.2039 - accuracy: 0.3832 - mse: 1.1395 - weighted_accuracy: 0.3359 - weighted_mse: 1.1698 - val_loss: 0.1984 - val_accuracy: 0.0670 - val_mse: 1.0403 - val_weighted_accuracy: 0.0670 - val_weighted_mse: 1.0403
# Epoch 5/20
# 28/28 [==============================] - 0s 14ms/step - loss: 0.2053 - accuracy: 0.3958 - mse: 1.1703 - weighted_accuracy: 0.3620 - weighted_mse: 1.1837 - val_loss: 0.2038 - val_accuracy: 0.0502 - val_mse: 1.0459 - val_weighted_accuracy: 0.0502 - val_weighted_mse: 1.0459
# Epoch 6/20
# 28/28 [==============================] - 0s 14ms/step - loss: 0.2038 - accuracy: 0.3145 - mse: 1.1658 - weighted_accuracy: 0.3588 - weighted_mse: 1.1710 - val_loss: 0.2014 - val_accuracy: 0.0569 - val_mse: 0.9529 - val_weighted_accuracy: 0.0569 - val_weighted_mse: 0.9529
# Epoch 7/20
# 28/28 [==============================] - 0s 15ms/step - loss: 0.2045 - accuracy: 0.2989 - mse: 1.1684 - weighted_accuracy: 0.3464 - weighted_mse: 1.1717 - val_loss: 0.1970 - val_accuracy: 0.0469 - val_mse: 1.1395 - val_weighted_accuracy: 0.0469 - val_weighted_mse: 1.1395
# Epoch 8/20
# 28/28 [==============================] - 0s 15ms/step - loss: 0.2033 - accuracy: 0.2718 - mse: 1.1765 - weighted_accuracy: 0.3432 - weighted_mse: 1.1553 - val_loss: 0.1987 - val_accuracy: 0.0469 - val_mse: 0.8858 - val_weighted_accuracy: 0.0469 - val_weighted_mse: 0.8858
# Epoch 9/20
# 28/28 [==============================] - 0s 13ms/step - loss: 0.2062 - accuracy: 0.2701 - mse: 1.1782 - weighted_accuracy: 0.3256 - weighted_mse: 1.1553 - val_loss: 0.2010 - val_accuracy: 0.0569 - val_mse: 0.9715 - val_weighted_accuracy: 0.0569 - val_weighted_mse: 0.9715
# Epoch 10/20
# 28/28 [==============================] - 0s 10ms/step - loss: 0.2033 - accuracy: 0.2735 - mse: 1.1773 - weighted_accuracy: 0.3356 - weighted_mse: 1.1571 - val_loss: 0.2032 - val_accuracy: 0.0625 - val_mse: 1.0034 - val_weighted_accuracy: 0.0625 - val_weighted_mse: 1.0034
# Epoch 11/20
# 28/28 [==============================] - 0s 11ms/step - loss: 0.2013 - accuracy: 0.2894 - mse: 1.1926 - weighted_accuracy: 0.3655 - weighted_mse: 1.1733 - val_loss: 0.2048 - val_accuracy: 0.0670 - val_mse: 0.9273 - val_weighted_accuracy: 0.0670 - val_weighted_mse: 0.9273
# Epoch 12/20
# 28/28 [==============================] - 0s 11ms/step - loss: 0.2036 - accuracy: 0.3014 - mse: 1.1570 - weighted_accuracy: 0.3642 - weighted_mse: 1.1625 - val_loss: 0.2021 - val_accuracy: 0.0625 - val_mse: 0.9382 - val_weighted_accuracy: 0.0625 - val_weighted_mse: 0.9382
# Epoch 13/20
# 28/28 [==============================] - 0s 11ms/step - loss: 0.2021 - accuracy: 0.3117 - mse: 1.2031 - weighted_accuracy: 0.3487 - weighted_mse: 1.1907 - val_loss: 0.2039 - val_accuracy: 0.0525 - val_mse: 0.9844 - val_weighted_accuracy: 0.0525 - val_weighted_mse: 0.9844
# Epoch 14/20
# 28/28 [==============================] - 0s 11ms/step - loss: 0.2023 - accuracy: 0.3003 - mse: 1.1665 - weighted_accuracy: 0.3371 - weighted_mse: 1.1633 - val_loss: 0.2018 - val_accuracy: 0.0592 - val_mse: 1.0627 - val_weighted_accuracy: 0.0592 - val_weighted_mse: 1.0627
# Epoch 15/20
# 28/28 [==============================] - 0s 15ms/step - loss: 0.2019 - accuracy: 0.3006 - mse: 1.1709 - weighted_accuracy: 0.3603 - weighted_mse: 1.1668 - val_loss: 0.1985 - val_accuracy: 0.0636 - val_mse: 0.9667 - val_weighted_accuracy: 0.0636 - val_weighted_mse: 0.9667
# Epoch 16/20
# 28/28 [==============================] - 0s 14ms/step - loss: 0.2012 - accuracy: 0.3075 - mse: 1.1718 - weighted_accuracy: 0.3438 - weighted_mse: 1.1904 - val_loss: 0.2005 - val_accuracy: 0.0625 - val_mse: 0.9707 - val_weighted_accuracy: 0.0625 - val_weighted_mse: 0.9707
# Epoch 17/20
# 28/28 [==============================] - 0s 16ms/step - loss: 0.2009 - accuracy: 0.2939 - mse: 1.1663 - weighted_accuracy: 0.3688 - weighted_mse: 1.1617 - val_loss: 0.2010 - val_accuracy: 0.0614 - val_mse: 0.9559 - val_weighted_accuracy: 0.0614 - val_weighted_mse: 0.9559
# Epoch 18/20
# 28/28 [==============================] - 0s 15ms/step - loss: 0.1992 - accuracy: 0.2763 - mse: 1.2010 - weighted_accuracy: 0.3539 - weighted_mse: 1.1952 - val_loss: 0.2011 - val_accuracy: 0.0681 - val_mse: 0.9370 - val_weighted_accuracy: 0.0681 - val_weighted_mse: 0.9370
# Epoch 19/20
# 28/28 [==============================] - 0s 14ms/step - loss: 0.2028 - accuracy: 0.3352 - mse: 1.1905 - weighted_accuracy: 0.3366 - weighted_mse: 1.1732 - val_loss: 0.1932 - val_accuracy: 0.0558 - val_mse: 1.0548 - val_weighted_accuracy: 0.0558 - val_weighted_mse: 1.0548
# Epoch 20/20
# 28/28 [==============================] - 0s 15ms/step - loss: 0.2010 - accuracy: 0.2542 - mse: 1.1814 - weighted_accuracy: 0.3459 - weighted_mse: 1.1784 - val_loss: 0.1976 - val_accuracy: 0.0658 - val_mse: 1.0482 - val_weighted_accuracy: 0.0658 - val_weighted_mse: 1.0482
# Validation loss: 0.19760547578334808
# Validation accuracy: 0.0658482164144516
#
#
# accumulation phase data
#
#
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1977 - accuracy: 0.0565 - mse: 1.0527 - weighted_accuracy: 0.0565 - weighted_mse: 1.0527
# Test loss: 0.19765961170196533
# Test accuracy: 0.05645161122083664
#
#
# number of predictions: 248
# actual predicted buys: 11
# actual buys but predicted sell: 0
# actual buys but predicted hold: 0
# actual sells but predicted buy: 5
# actual predicted sells: 3
# actual sells but predicted hold: 0
# actual holds but predicted buy: 141
# actual holds but predicted sell: 88
# actual predicted holds: 0
# Percentage buys correct: 7.006369426751593%
# Percentage sells correct: 3.2967032967032965%
# Percentage holds correct: 0%
# actual buys: 11
# actual sells: 8
# actual holds: 229
#
#
# Percentage low buys correct: 42.67515923566879%
# Percentage high sells correct: 47.77777777777778%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.21694303230780076
# Shares owned at the moment: 459
# Cash capital at the moment: $0.14931182818891386
#
#
# Price increase from previously bought: -28.317092191996128%
# Share price: $0.15593872929816288
# Shares owned at the moment: 0
# Cash capital at the moment: $71.52835491498908
#
#
# Share price: $0.13773849509347902
# Shares owned at the moment: 517
# Cash capital at the moment: $0.12172324626126851
#
#
# Price increase from previously bought: -25.89695442372022%
# Share price: $0.10234910794963946
# Shares owned at the moment: 0
# Cash capital at the moment: $52.89069721199747
#
#
# Share price: $0.2799697549902216
# Shares owned at the moment: 188
# Cash capital at the moment: $0.11163891050586017
#
#
# Price increase from previously bought: 20.49514330313178%
# Share price: $0.3382776698639669
# Shares owned at the moment: 0
# Cash capital at the moment: $63.532951289611965
#
#
# Share price: $0.27356589745290827
# Shares owned at the moment: 231
# Cash capital at the moment: $0.165446241633191
#
#
# Price increase from previously bought: 27.24746684495527%
# Share price: $0.34906296526581015
# Shares owned at the moment: 0
# Cash capital at the moment: $80.57724896935024
#
#
# Share price: $0.3810819958106475
# Shares owned at the moment: 210
# Cash capital at the moment: $0.3299549965336155
#
#
# Price increase from previously bought: -7.3303181293840725%
# Share price: $0.35411862873517674
# Shares owned at the moment: 0
# Cash capital at the moment: $74.49036352282617
#
#
# Share price: $0.3716446373350244
# Shares owned at the moment: 199
# Cash capital at the moment: $0.3296981653747224
#
#
# Price increase from previously bought: 34.00263181873795%
# Share price: $0.4993831324285025
# Shares owned at the moment: 0
# Cash capital at the moment: $99.43365409942523
#
#
# Share price: $0.7110449725449779
# Shares owned at the moment: 139
# Cash capital at the moment: $0.3266059749179817
#
#
# Price increase from previously bought: -0.03791357848468291%
# Share price: $0.7127300222736166
# Shares owned at the moment: 0
# Cash capital at the moment: $99.12363801993659
#
#
# Share price: $0.7167746044774546
# Shares owned at the moment: 137
# Cash capital at the moment: $0.6554723742884363
#
#
# Price increase from previously bought: -0.602494774867357%
# Share price: $0.714415329143981
# Shares owned at the moment: 0
# Cash capital at the moment: $98.26121649175883
#
#
# Share price: $0.7592415604799909
# Shares owned at the moment: 129
# Cash capital at the moment: $0.049714246259725314
#
#
# Price increase from previously bought: 16.504100388324193%
# Share price: $0.8869800555734695
# Shares owned at the moment: 0
# Cash capital at the moment: $114.15548524052261
#
#
# Share price: $0.6803741360680873
# Shares owned at the moment: 167
# Cash capital at the moment: $0.22054269516276293
#
#
# Price increase from previously bought: 2.2946267016762167%
# Share price: $0.6979001446679349
# Shares owned at the moment: 0
# Cash capital at the moment: $116.44935621326914
#
#
# Share price: $0.6820594429384508
# Shares owned at the moment: 170
# Cash capital at the moment: $0.1803881241587817
#
#
# Price increase from previously bought: 5.540753967053225%
# Share price: $0.7218302679468211
# Shares owned at the moment: 0
# Cash capital at the moment: $122.55407802485324
#
#
# Share price: $0.6530739133319237
# Shares owned at the moment: 187
# Cash capital at the moment: $0.09341297185257247
#
#
# Price increase from previously bought: 24.995950419717737%
# Share price: $0.818560813760991
# Shares owned at the moment: 0
# Cash capital at the moment: $152.74334024668127
#
#
# Share price: $0.9574217170587309
# Shares owned at the moment: 159
# Cash capital at the moment: $0.09465458855913766
#
#
# Price increase from previously bought: 2.0427639217414084%
# Share price: $0.9796662763255266
# Shares owned at the moment: 0
# Cash capital at the moment: $155.43323344499453
#
#
# Share price: $0.8910246377773083
# Shares owned at the moment: 173
# Cash capital at the moment: $0.8620661380976173
#
#
# Price increase from previously bought: -0.12335249903971945%
# Share price: $0.8923728318452542
# Shares owned at the moment: 0
# Cash capital at the moment: $154.8180196725762
#
#
# Share price: $0.877542954239573
# Shares owned at the moment: 175
# Cash capital at the moment: $0.8256851339231446
#
#
# Price increase from previously bought: 3.5176437690459084%
# Share price: $0.9109099217106305
# Shares owned at the moment: 0
# Cash capital at the moment: $159.7965460334602
#
#
# Share price: $0.8401314045646766
# Shares owned at the moment: 189
# Cash capital at the moment: $0.5750522732138279
#
#
# Price increase from previously bought: -7.075527043126084%
# Share price: $0.7828345709564595
# Shares owned at the moment: 0
# Cash capital at the moment: $148.12390791573006
#
#
# Share price: $0.7043040022052474
# Shares owned at the moment: 209
# Cash capital at the moment: $0.5195727295658799
#
#
# Price increase from previously bought: -18.265880208998865%
# Share price: $0.5772397327166041
# Shares owned at the moment: 0
# Cash capital at the moment: $120.83090833095727
#
#
# Share price: $0.4612976142904974
# Shares owned at the moment: 261
# Cash capital at the moment: $0.10113463848043125
#
#
# Price increase from previously bought: 12.84116330318592%
# Share price: $0.5219650616394429
# Shares owned at the moment: 0
# Cash capital at the moment: $135.9593753033833
#
#
#
#
# Capital at the end of test period: $135.9593753033833
# profit gained: 35.9593753033833%
#
#
# Capital at the end of test period if Buy and Hold: $182.55793694382942
# profit gained: 82.55793694382942%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.056452      7.006369       3.296703            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         42.675159           47.777778                0.0      35.959375
#
#    buy_n_hold profit
# 0          82.557937
#
#
# mark up phase data
# 1/7 [===>..........................] - ETA: 0s - loss: 0.1971 - accuracy: 0.0938 - mse: 1.0526 - weighted_accuracy: 0.0938 - weighted_mse: 1.0526WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_test_batch_end` time: 0.0050s). Check your callbacks.
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1973 - accuracy: 0.0685 - mse: 1.0475 - weighted_accuracy: 0.0685 - weighted_mse: 1.0475
# Test loss: 0.19734229147434235
# Test accuracy: 0.06849315017461777
#
#
# number of predictions: 219
# actual predicted buys: 7
# actual buys but predicted sell: 0
# actual buys but predicted hold: 0
# actual sells but predicted buy: 3
# actual predicted sells: 8
# actual sells but predicted hold: 0
# actual holds but predicted buy: 135
# actual holds but predicted sell: 66
# actual predicted holds: 0
# Percentage buys correct: 4.827586206896552%
# Percentage sells correct: 10.81081081081081%
# Percentage holds correct: 0%
# actual buys: 7
# actual sells: 11
# actual holds: 201
#
#
# Percentage low buys correct: 50.69444444444444%
# Percentage high sells correct: 51.351351351351354%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.2521008983715609
# Shares owned at the moment: 395
# Cash capital at the moment: $0.14630054237733248
#
#
# Price increase from previously bought: 30.404609953677554%
# Share price: $0.3296552589924817
# Shares owned at the moment: 0
# Cash capital at the moment: $130.00203981932702
#
#
# Share price: $0.22214604861775533
# Shares owned at the moment: 583
# Cash capital at the moment: $0.13473782272922108
#
#
# Price increase from previously bought: -4.142639777737466%
# Share price: $0.21352893222266256
# Shares owned at the moment: 0
# Cash capital at the moment: $124.27976504795551
#
#
# Share price: $0.23527693737195698
# Shares owned at the moment: 526
# Cash capital at the moment: $0.18376790039759783
#
#
# Price increase from previously bought: 38.425043614944855%
# Share price: $0.3265778292317638
# Shares owned at the moment: 0
# Cash capital at the moment: $171.49131124632163
#
#
# Share price: $0.5262086315800028
# Shares owned at the moment: 325
# Cash capital at the moment: $0.003207018346103041
#
#
# Price increase from previously bought: -12.989125184401596%
# Share price: $0.4591178452106053
# Shares owned at the moment: 0
# Cash capital at the moment: $148.80617013763583
#
#
# Share price: $0.41644237849318055
# Shares owned at the moment: 356
# Cash capital at the moment: $0.14498630551872793
#
#
# Price increase from previously bought: -10.985085721364552%
# Share price: $0.3717152397577632
# Shares owned at the moment: 0
# Cash capital at the moment: $132.1117024395596
#
#
# Share price: $0.31796055630412945
# Shares owned at the moment: 414
# Cash capital at the moment: $0.11403403629776676
#
#
# Price increase from previously bought: 74.50043861566162%
# Share price: $0.5563683824302863
# Shares owned at the moment: 0
# Cash capital at the moment: $229.8171189590394
#
#
# Share price: $0.5902216751235991
# Shares owned at the moment: 388
# Cash capital at the moment: $0.18134248372604134
#
#
# Price increase from previously bought: 0.6617574622322486%
# Share price: $0.5957613617579736
# Shares owned at the moment: 0
# Cash capital at the moment: $230.70107347282402
#
#
# Share price: $0.5758598144651097
# Shares owned at the moment: 399
# Cash capital at the moment: $0.3011453198234051
#
#
# Price increase from previously bought: 25.3790039397658%
# Share price: $0.7239928195392686
# Shares owned at the moment: 0
# Cash capital at the moment: $288.3798791947521
#
#
# Share price: $0.6821378964030085
# Shares owned at the moment: 421
# Cash capital at the moment: $0.4100796595249676
#
#
# Price increase from previously bought: 1.0455440749924216%
# Share price: $0.691165441121224
# Shares owned at the moment: 0
# Cash capital at the moment: $290.5905335821022
#
#
# Share price: $0.8081124680047489
# Shares owned at the moment: 358
# Cash capital at the moment: $0.4906833116513667
#
#
# Price increase from previously bought: 1.2195780643835086%
# Share price: $0.8202174424836832
# Shares owned at the moment: 0
# Cash capital at the moment: $293.3210236486848
#
#
# Share price: $0.9113131201819289
# Shares owned at the moment: 320
# Cash capital at the moment: $0.8988696447074176
#
#
# Price increase from previously bought: 0.28705318743702524%
# Share price: $0.9164423784931806
# Shares owned at the moment: 0
# Cash capital at the moment: $293.3539614694512
#
#
# Share price: $0.9718383056416837
# Shares owned at the moment: 301
# Cash capital at the moment: $0.0261923138094744
#
#
# Price increase from previously bought: -1.137422011934619%
# Share price: $0.9634265599406933
# Shares owned at the moment: 0
# Cash capital at the moment: $289.22011052096724
#
#
# Share price: $0.9383957543365777
# Shares owned at the moment: 307
# Cash capital at the moment: $0.3403733240392057
#
#
#
#
# Capital at the end of test period: $266.5928751530845
# profit gained: 166.5928751530845%
#
#
# Capital at the end of test period if Buy and Hold: $355.7316817269389
# profit gained: 255.73168172693892%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.056452      7.006369       3.296703            0.0
# 1       0.068493      4.827586      10.810811            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         42.675159           47.777778                0.0      35.959375
# 1         50.694444           51.351351                0.0     166.592875
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
#
#
# distribution phase data
#
#
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1974 - accuracy: 0.0702 - mse: 1.0538 - weighted_accuracy: 0.0702 - weighted_mse: 1.0538
# Test loss: 0.19740459322929382
# Test accuracy: 0.07021276652812958
#
#
# number of predictions: 470
# actual predicted buys: 20
# actual buys but predicted sell: 4
# actual buys but predicted hold: 0
# actual sells but predicted buy: 7
# actual predicted sells: 13
# actual sells but predicted hold: 0
# actual holds but predicted buy: 280
# actual holds but predicted sell: 146
# actual predicted holds: 0
# Percentage buys correct: 6.514657980456026%
# Percentage sells correct: 7.975460122699387%
# Percentage holds correct: 0%
# actual buys: 24
# actual sells: 20
# actual holds: 426
#
#
# Percentage low buys correct: 41.693811074918564%
# Percentage high sells correct: 47.53086419753087%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.5051713785101153
# Shares owned at the moment: 197
# Cash capital at the moment: $0.20756183919942828
#
#
# Price increase from previously bought: 5.629590333087275%
# Share price: $0.5350778863586452
# Shares owned at the moment: 0
# Cash capital at the moment: $105.32802700691772
#
#
# Share price: $0.5797818516465718
# Shares owned at the moment: 181
# Cash capital at the moment: $0.09892544223113475
#
#
# Price increase from previously bought: -32.0497399762007%
# Share price: $0.3950466747729966
# Shares owned at the moment: 0
# Cash capital at the moment: $71.40573909377525
#
#
# Share price: $0.32370733362931925
# Shares owned at the moment: 219
# Cash capital at the moment: $0.3188802872760732
#
#
# Price increase from previously bought: 49.151859488733194%
# Share price: $0.4841432500549032
# Shares owned at the moment: 0
# Cash capital at the moment: $106.05467677695431
#
#
# Share price: $0.5877259274822622
# Shares owned at the moment: 179
# Cash capital at the moment: $0.5624276698262349
#
#
# Price increase from previously bought: 8.156934619397616%
# Share price: $0.6374144295828412
# Shares owned at the moment: 0
# Cash capital at the moment: $114.34584331219266
#
#
# Share price: $0.6643613984083327
# Shares owned at the moment: 171
# Cash capital at the moment: $0.42762823676623896
#
#
# Price increase from previously bought: -9.252639382402506%
# Share price: $0.6045483827112721
# Shares owned at the moment: 0
# Cash capital at the moment: $103.52111280342379
#
#
# Share price: $0.6353894317932258
# Shares owned at the moment: 162
# Cash capital at the moment: $0.3049588610573295
#
#
# Price increase from previously bought: -50.0735364598476%
# Share price: $0.31809984855298246
# Shares owned at the moment: 0
# Cash capital at the moment: $51.69542084411013
#
#
# Share price: $0.297850583684222
# Shares owned at the moment: 173
# Cash capital at the moment: $0.02556745155195017
#
#
# Price increase from previously bought: 0.14298241064916173%
# Share price: $0.2990967178873858
# Shares owned at the moment: 0
# Cash capital at the moment: $51.627004382534764
#
#
# Share price: $0.2760435916425601
# Shares owned at the moment: 186
# Cash capital at the moment: $0.14170003989341495
#
#
# Price increase from previously bought: -0.6118657946463046%
# Share price: $0.27510905040913536
# Shares owned at the moment: 0
# Cash capital at the moment: $51.17126513670832
#
#
# Share price: $0.25408115962971967
# Shares owned at the moment: 200
# Cash capital at the moment: $0.21528857296804205
#
#
# Price increase from previously bought: 10.363425475892374%
# Share price: $0.2811838061021834
# Shares owned at the moment: 0
# Cash capital at the moment: $56.297398700048525
#
#
# Share price: $0.2224612469613152
# Shares owned at the moment: 252
# Cash capital at the moment: $0.08299882165290029
#
#
# Price increase from previously bought: 4.6833483568036405%
# Share price: $0.2335203017912202
# Shares owned at the moment: 0
# Cash capital at the moment: $58.76828530389907
#
#
# Share price: $0.10080998010178387
# Shares owned at the moment: 581
# Cash capital at the moment: $0.036617719055016096
#
#
# Price increase from previously bought: 114.21322654938476%
# Share price: $0.21654216891523848
# Shares owned at the moment: 0
# Cash capital at the moment: $125.50163760842425
#
#
# Share price: $0.17495342029732242
# Shares owned at the moment: 715
# Cash capital at the moment: $0.06593993317909508
#
#
# Price increase from previously bought: 73.15257317043053%
# Share price: $0.3037694240545019
# Shares owned at the moment: 0
# Cash capital at the moment: $216.6637915021008
#
#
# Share price: $0.2867912911785202
# Shares owned at the moment: 753
# Cash capital at the moment: $0.11607617846715357
#
#
# Price increase from previously bought: 18.41212531715042%
# Share price: $0.3405295511825328
# Shares owned at the moment: 0
# Cash capital at the moment: $255.82967665080312
#
#
# Share price: $0.22323987287197
# Shares owned at the moment: 1142
# Cash capital at the moment: $0.188657010258936
#
#
# Price increase from previously bought: 7.5190739814329%
# Share price: $0.24068551404046068
# Shares owned at the moment: 0
# Cash capital at the moment: $274.29564118762096
#
#
# Share price: $0.29317763984130907
# Shares owned at the moment: 933
# Cash capital at the moment: $0.00868268625674773
#
#
# Price increase from previously bought: -4.512949124906496%
# Share price: $0.2807165354854708
# Shares owned at the moment: 0
# Cash capital at the moment: $261.19696184327915
#
#
# Share price: $0.40844232036225736
# Shares owned at the moment: 637
# Cash capital at the moment: $0.3037149378266122
#
#
# Price increase from previously bought: 25.815247104060667%
# Share price: $0.5152958921065969
# Shares owned at the moment: 0
# Cash capital at the moment: $327.6445286307311
#
#
# Share price: $0.5305608578384999
# Shares owned at the moment: 615
# Cash capital at the moment: $0.45229000923421836
#
#
# Price increase from previously bought: -2.879959670556975%
# Share price: $0.5166979416325288
# Shares owned at the moment: 0
# Cash capital at the moment: $317.34765871945336
#
#
# Share price: $0.503925244306952
# Shares owned at the moment: 628
# Cash capital at the moment: $0.012326397769413688
#
#
# Price increase from previously bought: 10.545387440900722%
# Share price: $0.5585980455443875
# Shares owned at the moment: 0
# Cash capital at the moment: $349.8472001749896
#
#
# Share price: $0.5023675171340483
# Shares owned at the moment: 694
# Cash capital at the moment: $0.24537487750973241
#
#
# Price increase from previously bought: 24.95713520053826%
# Share price: $0.6294703537471491
# Shares owned at the moment: 0
# Cash capital at the moment: $435.89645620790475
#
#
# Share price: $0.7654515697535687
# Shares owned at the moment: 567
# Cash capital at the moment: $0.6918857974930575
#
#
# Price increase from previously bought: -4.576433593831341%
# Share price: $0.7324298452350269
# Shares owned at the moment: 0
# Cash capital at the moment: $414.8375668095706
#
#
# Share price: $0.7575079692694715
# Shares owned at the moment: 546
# Cash capital at the moment: $0.10081737258104795
#
#
# Price increase from previously bought: 3.4168436461905705%
# Share price: $0.7855451569753564
# Shares owned at the moment: 0
# Cash capital at the moment: $427.8289770279271
#
#
# Share price: $0.7385046009280767
# Shares owned at the moment: 577
# Cash capital at the moment: $0.5400001169041957
#
#
# Price increase from previously bought: 5.005241900030732%
# Share price: $0.7776010811396639
# Shares owned at the moment: 0
# Cash capital at the moment: $447.9819654189919
#
#
# Share price: $0.7411525469813751
# Shares owned at the moment: 602
# Cash capital at the moment: $0.5811540946763785
#
#
# Price increase from previously bought: 19.762278809038314%
# Share price: $0.8900621379603424
# Shares owned at the moment: 0
# Cash capital at the moment: $534.9250632774092
#
#
# Share price: $0.9920873258905945
# Shares owned at the moment: 537
# Cash capital at the moment: $0.709104315651075
#
#
# Price increase from previously bought: -7.492376456785744%
# Share price: $0.9202802387786131
# Shares owned at the moment: 0
# Cash capital at the moment: $493.54056869715
#
#
# Share price: $0.9070402708363254
# Shares owned at the moment: 542
# Cash capital at the moment: $0.5727983801800747
#
#
# Price increase from previously bought: 7.4151815179474%
# Share price: $0.97697827548146
# Shares owned at the moment: 0
# Cash capital at the moment: $528.6388375715262
#
#
# Share price: $0.7514329759006257
# Shares owned at the moment: 701
# Cash capital at the moment: $0.43574654589508555
#
#
# Price increase from previously bought: 28.645826871877333%
# Share price: $0.9693455549397119
# Shares owned at the moment: 0
# Cash capital at the moment: $678.078324665098
#
#
# Share price: $0.8705917366780345
# Shares owned at the moment: 776
# Cash capital at the moment: $0.6412942368723407
#
#
# Price increase from previously bought: 3.6154237748075913%
# Share price: $0.9045480024299979
# Shares owned at the moment: 0
# Cash capital at the moment: $700.640238685365
#
#
# Share price: $0.9199688834846687
# Shares owned at the moment: 759
# Cash capital at the moment: $0.46365106844814363
#
#
# Price increase from previously bought: -30.042373041365877%
# Share price: $0.6453582677427361
# Shares owned at the moment: 0
# Cash capital at the moment: $488.9435522408388
#
#
# Share price: $0.7107787685161331
# Shares owned at the moment: 686
# Cash capital at the moment: $0.00843289196581054
#
#
# Price increase from previously bought: -37.79815023083377%
# Share price: $0.4433333650234397
# Shares owned at the moment: 0
# Cash capital at the moment: $303.2987729049287
#
#
# Share price: $0.5170092969264715
# Shares owned at the moment: 585
# Cash capital at the moment: $0.016595496512366026
#
#
# Price increase from previously bought: 4.863488957896256%
# Share price: $0.5436449104580203
# Shares owned at the moment: 0
# Cash capital at the moment: $317.1742793647549
#
#
# Share price: $0.4433333650234397
# Shares owned at the moment: 713
# Cash capital at the moment: $0.20832420757272985
#
#
# Price increase from previously bought: -12.923038574199097%
# Share price: $0.38710283661310085
# Shares owned at the moment: 0
# Cash capital at the moment: $275.4536348258245
#
#
# Share price: $0.3081310126034722
# Shares owned at the moment: 891
# Cash capital at the moment: $0.1539045824990808
#
#
# Price increase from previously bought: -33.19357089187118%
# Share price: $0.20641741764295962
# Shares owned at the moment: 0
# Cash capital at the moment: $183.56604942479643
#
#
# Share price: $0.35018703183809863
# Shares owned at the moment: 522
# Cash capital at the moment: $0.2657253211053501
#
#
# Price increase from previously bought: 26.739772553153074%
# Share price: $0.44504676984331515
# Shares owned at the moment: 0
# Cash capital at the moment: $231.9412745412058
#
#
# Share price: $0.3980062137960345
# Shares owned at the moment: 581
# Cash capital at the moment: $0.06374989761710026
#
#
# Price increase from previously bought: 20.215740552279705%
# Share price: $0.47978189918172975
# Shares owned at the moment: 0
# Cash capital at the moment: $278.0504617927845
#
#
# Share price: $0.45361379394268986
# Shares owned at the moment: 611
# Cash capital at the moment: $0.1302491165288302
#
#
# Price increase from previously bought: -8.218905938301246%
# Share price: $0.4174766150783429
# Shares owned at the moment: 0
# Cash capital at the moment: $254.50699584691094
#
#
# Share price: $0.2990967178873858
# Shares owned at the moment: 848
# Cash capital at the moment: $0.17548553229440245
#
#
# Price increase from previously bought: -4.325173545313321%
# Share price: $0.2869472065012888
# Shares owned at the moment: 0
# Cash capital at the moment: $242.8375557598263
#
#
# Share price: $0.08523365907593682
# Shares owned at the moment: 2841
# Cash capital at the moment: $0.022821055144277125
#
#
# Price increase from previously bought: 235.9183679101005%
# Share price: $0.2871028841482606
# Shares owned at the moment: 0
# Cash capital at the moment: $813.4390518622232
#
#
#
#
# Capital at the end of test period: $813.4390518622232
# profit gained: 713.4390518622232%
#
#
# Capital at the end of test period if Buy and Hold: $64.93475897926798
# profit gained: -35.06524102073202%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.056452      7.006369       3.296703            0.0
# 1       0.068493      4.827586      10.810811            0.0
# 2       0.070213      6.514658       7.975460            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         42.675159           47.777778                0.0      35.959375
# 1         50.694444           51.351351                0.0     166.592875
# 2         41.693811           47.530864                0.0     713.439052
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
#
#
# mark down phase data
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1966 - accuracy: 0.0755 - mse: 1.0500 - weighted_accuracy: 0.0755 - weighted_mse: 1.0500
# Test loss: 0.1966024786233902
# Test accuracy: 0.07553956657648087
#
#
# number of predictions: 278
# actual predicted buys: 15
# actual buys but predicted sell: 1
# actual buys but predicted hold: 0
# actual sells but predicted buy: 7
# actual predicted sells: 6
# actual sells but predicted hold: 0
# actual holds but predicted buy: 183
# actual holds but predicted sell: 66
# actual predicted holds: 0
# Percentage buys correct: 7.317073170731708%
# Percentage sells correct: 8.219178082191782%
# Percentage holds correct: 0%
# actual buys: 16
# actual sells: 13
# actual holds: 249
#
#
# Percentage low buys correct: 39.21568627450981%
# Percentage high sells correct: 42.465753424657535%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.8557023478457203
# Shares owned at the moment: 116
# Cash capital at the moment: $0.4655586009336474
#
#
# Price increase from previously bought: 5.061539397569548%
# Share price: $0.9014863479709557
# Shares owned at the moment: 0
# Cash capital at the moment: $104.75040082056178
#
#
# Share price: $0.8836219133409499
# Shares owned at the moment: 118
# Cash capital at the moment: $0.19627973545055966
#
#
# Price increase from previously bought: 0.929701841175623%
# Share price: $0.8942895141852923
# Shares owned at the moment: 0
# Cash capital at the moment: $105.43224546196193
#
#
# Share price: $0.8138995583502656
# Shares owned at the moment: 129
# Cash capital at the moment: $0.15047156645289306
#
#
# Price increase from previously bought: 10.44510662419973%
# Share price: $0.9013842436801845
# Shares owned at the moment: 0
# Cash capital at the moment: $116.10927294075115
#
#
# Share price: $0.8803041858942965
# Shares owned at the moment: 131
# Cash capital at the moment: $0.47229500562988846
#
#
# Price increase from previously bought: -6.84286598636723%
# Share price: $0.822321332094167
# Shares owned at the moment: 0
# Cash capital at the moment: $107.90014825007884
#
#
# Share price: $0.8296202701706014
# Shares owned at the moment: 129
# Cash capital at the moment: $0.5848256072282396
#
#
# Price increase from previously bought: -0.6669167679352106%
# Share price: $0.8263536338107106
# Shares owned at the moment: 0
# Cash capital at the moment: $106.89129541721556
#
#
# Share price: $0.7901143209795968
# Shares owned at the moment: 134
# Cash capital at the moment: $0.7248192786686047
#
#
# Price increase from previously bought: -5.002866436032738%
# Share price: $0.7526500681902454
# Shares owned at the moment: 0
# Cash capital at the moment: $101.30257686603338
#
#
# Share price: $0.70012866464644
# Shares owned at the moment: 144
# Cash capital at the moment: $0.2067982057460256
#
#
# Price increase from previously bought: 6.298075835691486%
# Share price: $0.7462699129652434
# Shares owned at the moment: 0
# Cash capital at the moment: $107.37414278720684
#
#
# Share price: $0.7631135383357998
# Shares owned at the moment: 140
# Cash capital at the moment: $0.24444870793557527
#
#
# Price increase from previously bought: 5.215332838344944%
# Share price: $0.8051204585300425
# Shares owned at the moment: 0
# Cash capital at the moment: $112.65134152560746
#
#
# Share price: $0.7694936935608018
# Shares owned at the moment: 145
# Cash capital at the moment: $0.7679203489838358
#
#
# Price increase from previously bought: -7.5109515918875935%
# Share price: $0.7136545625703429
# Shares owned at the moment: 0
# Cash capital at the moment: $103.96326216485863
#
#
# Share price: $0.7167170682314454
# Shares owned at the moment: 144
# Cash capital at the moment: $0.4721843805108392
#
#
# Price increase from previously bought: -10.046608050195937%
# Share price: $0.6464842696696596
# Shares owned at the moment: 0
# Cash capital at the moment: $93.30991144215264
#
#
# Share price: $0.6103981522160797
# Shares owned at the moment: 152
# Cash capital at the moment: $0.27424587768219055
#
#
# Price increase from previously bought: -10.92318615555512%
# Share price: $0.5452184646302871
# Shares owned at the moment: 0
# Cash capital at the moment: $82.91955118327037
#
#
# Share price: $0.5154103981109383
# Shares owned at the moment: 160
# Cash capital at the moment: $0.22710691035143782
#
#
# Price increase from previously bought: 27.98062020429839%
# Share price: $0.6614393940160966
# Shares owned at the moment: 0
# Cash capital at the moment: $105.76637661955982
#
#
# Share price: $0.6576113008810954
# Shares owned at the moment: 160
# Cash capital at the moment: $0.25921950619687095
#
#
# Price increase from previously bought: 0.3062786810427598%
# Share price: $0.6614393940160966
# Shares owned at the moment: 0
# Cash capital at the moment: $105.79848921540525
#
#
# Share price: $0.6402572319394372
# Shares owned at the moment: 164
# Cash capital at the moment: $0.5075471657328734
#
#
# Price increase from previously bought: 2.3095454642138025%
# Share price: $0.6568456355244426
# Shares owned at the moment: 0
# Cash capital at the moment: $107.93399401011995
#
#
# Share price: $0.6577133272891124
# Shares owned at the moment: 163
# Cash capital at the moment: $0.43190166303728006
#
#
# Price increase from previously bought: 0.3913194870967196%
# Share price: $0.662102877199224
# Shares owned at the moment: 0
# Cash capital at the moment: $108.05788303180624
#
#
# Share price: $0.7507104760793634
# Shares owned at the moment: 143
# Cash capital at the moment: $0.4110680577390724
#
#
# Price increase from previously bought: -17.076105972081923%
# Share price: $0.624230285129542
# Shares owned at the moment: 0
# Cash capital at the moment: $89.43052027163638
#
#
# Share price: $0.6152470546105305
# Shares owned at the moment: 144
# Cash capital at the moment: $0.5913065740942187
#
#
# Price increase from previously bought: -1.217402051860006%
# Share price: $0.6094283561606388
# Shares owned at the moment: 0
# Cash capital at the moment: $88.1076562321866
#
#
# Share price: $0.5906451386792004
# Shares owned at the moment: 148
# Cash capital at the moment: $0.4517831362224882
#
#
# Price increase from previously bought: 11.515061165567996%
# Share price: $0.6604695979606556
# Shares owned at the moment: 0
# Cash capital at the moment: $97.93247250802952
#
#
# Share price: $0.6442384425692181
# Shares owned at the moment: 151
# Cash capital at the moment: $0.3849476668007128
#
#
# Price increase from previously bought: -1.6174129900190848%
# Share price: $0.6355614470397661
# Shares owned at the moment: 0
# Cash capital at the moment: $96.09080927892214
#
#
# Share price: $0.6372968305691057
# Shares owned at the moment: 150
# Cash capital at the moment: $0.23339975094653198
#
#
# Price increase from previously bought: -4.970627256456117%
# Share price: $0.6072846333509686
# Shares owned at the moment: 0
# Cash capital at the moment: $91.07558984233454
#
#
# Share price: $0.6131033318008603
# Shares owned at the moment: 148
# Cash capital at the moment: $0.08676367976426036
#
#
# Price increase from previously bought: -9.813515387327564%
# Share price: $0.5544569169348494
# Shares owned at the moment: 0
# Cash capital at the moment: $81.92072342092949
#
#
# Share price: $0.5500163538207293
# Shares owned at the moment: 148
# Cash capital at the moment: $0.2944463994565041
#
#
# Price increase from previously bought: 27.55402825726554%
# Share price: $0.7034973274143479
# Shares owned at the moment: 0
# Cash capital at the moment: $104.12572744452235
#
#
# Share price: $0.6716476423761001
# Shares owned at the moment: 154
# Cash capital at the moment: $0.40754774205665
#
#
# Price increase from previously bought: -13.657997065345617%
# Share price: $0.5815087906654093
# Shares owned at the moment: 0
# Cash capital at the moment: $89.71363253168288
#
#
# Share price: $0.5316925667063843
# Shares owned at the moment: 168
# Cash capital at the moment: $0.14363935919196535
#
#
# Price increase from previously bought: -32.35484912635284%
# Share price: $0.36065331558956515
# Shares owned at the moment: 0
# Cash capital at the moment: $60.56677454643653
#
#
# Share price: $0.3213515749801029
# Shares owned at the moment: 187
# Cash capital at the moment: $0.3087749777237647
#
#
#
#
# Capital at the end of test period: $3.420552602684901
# profit gained: -96.57944739731509%
#
#
# Capital at the end of test period if Buy and Hold: $2.3958591597330687
# profit gained: -97.60414084026694%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.056452      7.006369       3.296703            0.0
# 1       0.068493      4.827586      10.810811            0.0
# 2       0.070213      6.514658       7.975460            0.0
# 3       0.075540      7.317073       8.219178            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         42.675159           47.777778                0.0      35.959375
# 1         50.694444           51.351351                0.0     166.592875
# 2         41.693811           47.530864                0.0     713.439052
# 3         39.215686           42.465753                0.0     -96.579447
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
#
#
# bull phase data
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1986 - accuracy: 0.0625 - mse: 1.0415 - weighted_accuracy: 0.0625 - weighted_mse: 1.0415
# Test loss: 0.19857491552829742
# Test accuracy: 0.0625
#
#
# number of predictions: 208
# actual predicted buys: 8
# actual buys but predicted sell: 1
# actual buys but predicted hold: 0
# actual sells but predicted buy: 5
# actual predicted sells: 5
# actual sells but predicted hold: 0
# actual holds but predicted buy: 97
# actual holds but predicted sell: 92
# actual predicted holds: 0
# Percentage buys correct: 7.2727272727272725%
# Percentage sells correct: 5.1020408163265305%
# Percentage holds correct: 0%
# actual buys: 9
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 43.11926605504587%
# Percentage high sells correct: 47.95918367346939%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.12558233818043063
# Shares owned at the moment: 794
# Cash capital at the moment: $0.013414449321103916
#
#
# Price increase from previously bought: 19.361284642738497%
# Share price: $0.1503089080399258
# Shares owned at the moment: 0
# Cash capital at the moment: $119.03048793231702
#
#
# Share price: $0.14442053980990632
# Shares owned at the moment: 821
# Cash capital at the moment: $0.1351592746281085
#
#
# Price increase from previously bought: 33.57251987611829%
# Share price: $0.1934366461669521
# Shares owned at the moment: 0
# Cash capital at the moment: $158.50991418981235
#
#
# Share price: $0.06646855704303233
# Shares owned at the moment: 2378
# Cash capital at the moment: $0.013014412698566957
#
#
# Price increase from previously bought: 99.63259802397981%
# Share price: $0.1330578127891151
# Shares owned at the moment: 0
# Cash capital at the moment: $315.5543616584799
#
#
# Share price: $0.22747877938393035
# Shares owned at the moment: 1383
# Cash capital at the moment: $0.0860511028122346
#
#
# Price increase from previously bought: 5.776001109496409%
# Share price: $0.24127965558457887
# Shares owned at the moment: 0
# Cash capital at the moment: $332.8581679261827
#
#
# Share price: $0.27451679384576155
# Shares owned at the moment: 1209
# Cash capital at the moment: $0.0546644563182781
#
#
# Price increase from previously bought: 0.26890881051566673%
# Share price: $0.2760119449234075
# Shares owned at the moment: 0
# Cash capital at the moment: $332.8354351548339
#
#
# Share price: $0.3201746364536644
# Shares owned at the moment: 1036
# Cash capital at the moment: $0.22233424958108117
#
#
# Price increase from previously bought: 20.255173751078992%
# Share price: $0.38608538842901874
# Shares owned at the moment: 0
# Cash capital at the moment: $399.1068393904102
#
#
# Share price: $0.4127670262610301
# Shares owned at the moment: 964
# Cash capital at the moment: $0.10518068815912329
#
#
# Price increase from previously bought: 14.477424266410521%
# Share price: $0.47382450379936847
# Shares owned at the moment: 0
# Cash capital at the moment: $455.6158935911782
#
#
# Share price: $0.48164491607920557
# Shares owned at the moment: 943
# Cash capital at the moment: $0.1757120498649556
#
#
# Price increase from previously bought: 3.9072505409822877%
# Share price: $0.5018402656399119
# Shares owned at the moment: 0
# Cash capital at the moment: $472.1096852794311
#
#
# Share price: $0.4751584874181283
# Shares owned at the moment: 990
# Cash capital at the moment: $0.40916375348825795
#
#
# Price increase from previously bought: 17.59724948392698%
# Share price: $0.5603099385008563
# Shares owned at the moment: 0
# Cash capital at the moment: $553.5905590617674
#
#
# Share price: $0.7599051667086432
# Shares owned at the moment: 726
# Cash capital at the moment: $0.38225736595870785
#
#
# Price increase from previously bought: 2.7367848731378874%
# Share price: $0.7828490672363122
# Shares owned at the moment: 0
# Cash capital at the moment: $567.1677220167841
#
#
# Share price: $0.7402963656176462
# Shares owned at the moment: 764
# Cash capital at the moment: $0.025936020739663945
#
#
# Price increase from previously bought: 8.401666472085356%
# Share price: $0.8047004545540055
# Shares owned at the moment: 0
# Cash capital at the moment: $613.1264076449819
#
#
# Share price: $0.8466781196643112
# Shares owned at the moment: 722
# Cash capital at the moment: $0.1437258407556783
#
#
# Price increase from previously bought: 1.825400301782354%
# Share price: $0.864504251423482
# Shares owned at the moment: 0
# Cash capital at the moment: $622.5993221773083
#
#
# Share price: $0.8587538863398785
# Shares owned at the moment: 723
# Cash capital at the moment: $0.012844939060869365
#
#
# Price increase from previously bought: -0.36373434181230513%
# Share price: $0.8579832868783575
# Shares owned at the moment: 0
# Cash capital at the moment: $618.6288760819774
#
#
# Share price: $0.8685295069820047
# Shares owned at the moment: 710
# Cash capital at the moment: $0.2771222623716767
#
#
# Price increase from previously bought: -3.862130760064031%
# Share price: $0.837281972577385
# Shares owned at the moment: 0
# Cash capital at the moment: $593.1125297408577
#
#
# Share price: $0.7333959275173219
# Shares owned at the moment: 806
# Cash capital at the moment: $0.36984008855415595
#
#
# Price increase from previously bought: 11.5515641009994%
# Share price: $0.8203644434261506
# Shares owned at the moment: 0
# Cash capital at the moment: $659.7652437011774
#
#
# Share price: $0.8428713105918748
# Shares owned at the moment: 780
# Cash capital at the moment: $0.5176624782953922
#
#
# Price increase from previously bought: 1.657998570751995%
# Share price: $0.8592024316631723
# Shares owned at the moment: 0
# Cash capital at the moment: $668.8525699596522
#
#
# Share price: $0.8632391991830437
# Shares owned at the moment: 772
# Cash capital at the moment: $0.5992513704768498
#
#
# Price increase from previously bought: 1.2005218643393878%
# Share price: $0.876004981590689
# Shares owned at the moment: 0
# Cash capital at the moment: $675.0153385825718
#
#
#
#
# Capital at the end of test period: $675.0153385825718
# profit gained: 575.0153385825718%
#
#
# Capital at the end of test period if Buy and Hold: $778.7940878989605
# profit gained: 678.7940878989605%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.056452      7.006369       3.296703            0.0
# 1       0.068493      4.827586      10.810811            0.0
# 2       0.070213      6.514658       7.975460            0.0
# 3       0.075540      7.317073       8.219178            0.0
# 4       0.062500      7.272727       5.102041            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         42.675159           47.777778                0.0      35.959375
# 1         50.694444           51.351351                0.0     166.592875
# 2         41.693811           47.530864                0.0     713.439052
# 3         39.215686           42.465753                0.0     -96.579447
# 4         43.119266           47.959184                0.0     575.015339
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
#
#
# bear phase data
#
#
# 19/19 [==============================] - 0s 7ms/step - loss: 0.1976 - accuracy: 0.0756 - mse: 1.0454 - weighted_accuracy: 0.0756 - weighted_mse: 1.0454
# Test loss: 0.19760534167289734
# Test accuracy: 0.07563025504350662
#
#
# number of predictions: 595
# actual predicted buys: 27
# actual buys but predicted sell: 5
# actual buys but predicted hold: 0
# actual sells but predicted buy: 9
# actual predicted sells: 18
# actual sells but predicted hold: 0
# actual holds but predicted buy: 339
# actual holds but predicted sell: 197
# actual predicted holds: 0
# Percentage buys correct: 7.2%
# ...
#
#
# Share price: $0.11280374620910914
# Shares owned at the moment: 1243
# Cash capital at the moment: $0.07296539170232563
#
#
#
#
# Capital at the end of test period: $74.66130414996131
# profit gained: -25.33869585003869%
#
#
# Capital at the end of test period if Buy and Hold: $8.115342010843221
# profit gained: -91.88465798915678%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.729839     19.230769       5.555556      93.548387
# 1       0.753425     12.000000       9.523810      92.485549
# 2       0.727660      5.882353       6.521739      90.080429
# 3       0.658273      7.142857       4.545455      89.000000
# 4       0.740385     11.764706      10.344828      91.975309
# 5       0.739496      8.695652       9.803922      90.315789
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         46.153846           55.555556          83.783784     107.357920
# 1         56.000000           38.095238          87.209302      41.621153
# 2         50.980392           60.869565          83.602151    2061.380675
# 3         35.714286           45.454545          82.412060     -92.389196
# 4         52.941176           44.827586          85.093168    3106.331976
# 5         53.623188           54.901961          83.544304     -25.338696
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
# 5         -91.884658
#
#
# full cycle data
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1354 - accuracy: 0.7197 - mse: 2.3249 - weighted_accuracy: 0.7197 - weighted_mse: 2.3249
# Test loss: 0.13540123403072357
# Test accuracy: 0.7197383046150208
#
#
# number of predictions: 917
# actual predicted buys: 12
# actual buys but predicted sell: 2
# actual buys but predicted hold: 32
# actual sells but predicted buy: 1
# actual predicted sells: 8
# actual sells but predicted hold: 31
# actual holds but predicted buy: 98
# actual holds but predicted sell: 93
# actual predicted holds: 640
# Percentage buys correct: 10.81081081081081%
# Percentage sells correct: 7.766990291262136%
# Percentage holds correct: 91.03840682788051%
# actual buys: 46
# actual sells: 40
# actual holds: 831
#
#
# Percentage low buys correct: 52.252252252252255%
# Percentage high sells correct: 54.36893203883495%
# Percentage mid holds correct: 84.75783475783476%
#
#
# Capital: 100
# Share price: $0.3088084010225731
# Shares owned at the moment: 322
# Cash capital at the moment: $0.2902450316259575
#
#
# Price increase from previously bought: 12.453814442642486%
# Share price: $0.348221810041456
# Shares owned at the moment: 0
# Cash capital at the moment: $112.10931745218309
#
#
# Share price: $0.33263976868110035
# Shares owned at the moment: 336
# Cash capital at the moment: $0.03499602907204746
#
#
# Price increase from previously bought: 21.43453661201624%
# Share price: $0.40505039547981114
# Shares owned at the moment: 0
# Cash capital at the moment: $135.75766234486525
#
#
# Share price: $0.3738863127590999
# Shares owned at the moment: 362
# Cash capital at the moment: $0.038613301719408355
#
#
# Price increase from previously bought: -62.127631181653264%
# Share price: $0.14198900223859967
# Shares owned at the moment: 0
# Cash capital at the moment: $51.29728206036396
#
#
# Share price: $0.3573876601627567
# Shares owned at the moment: 143
# Cash capital at the moment: $0.050303959730754855
#
#
# Price increase from previously bought: 32.7196068787021%
# Share price: $0.4756278872194053
# Shares owned at the moment: 0
# Cash capital at the moment: $67.87805116545667
#
#
# Share price: $0.45362965461999494
# Shares owned at the moment: 149
# Cash capital at the moment: $0.10135787609688407
#
#
# Price increase from previously bought: 12.017438494549282%
# Share price: $0.5095417162352209
# Shares owned at the moment: 0
# Cash capital at the moment: $75.81428887691743
#
#
# Share price: $0.4563794883279577
# Shares owned at the moment: 165
# Cash capital at the moment: $0.304591109975604
#
#
# Price increase from previously bought: -0.07397164028505321%
# Share price: $0.45729601215108695
# Shares owned at the moment: 0
# Cash capital at the moment: $75.55093504939138
#
#
# Share price: $0.49120984116690236
# Shares owned at the moment: 153
# Cash capital at the moment: $0.18915281018433916
#
#
# Price increase from previously bought: 0.6561915947297159%
# Share price: $0.4957928099339819
# Shares owned at the moment: 0
# Cash capital at the moment: $75.83684790530384
#
#
# Share price: $0.46004584585904973
# Shares owned at the moment: 164
# Cash capital at the moment: $0.1818485079372465
#
#
# Price increase from previously bought: 11.845989246042855%
# Share price: $0.5159578200614172
# Shares owned at the moment: 0
# Cash capital at the moment: $84.56623402116196
#
#
# Share price: $0.5627039441424839
# Shares owned at the moment: 149
# Cash capital at the moment: $0.49277840281946794
#
#
# Price increase from previously bought: -0.27424582398404285%
# Share price: $0.5627039441424839
# Shares owned at the moment: 0
# Cash capital at the moment: $84.1050981389372
#
#
# Share price: $0.581035731797944
# Shares owned at the moment: 144
# Cash capital at the moment: $0.20586261024126884
#
#
# Price increase from previously bought: 3.029442729197629%
# Share price: $0.6002841306893916
# Shares owned at the moment: 0
# Cash capital at the moment: $86.40906491376066
#
#
# Share price: $0.6543629698326423
# Shares owned at the moment: 131
# Cash capital at the moment: $0.4517816058023101
#
#
# Price increase from previously bought: 1.262334192246528%
# Share price: $0.6644454311899308
# Shares owned at the moment: 0
# Cash capital at the moment: $87.25476662509708
#
#
# Share price: $0.9247570781360379
# Shares owned at the moment: 94
# Cash capital at the moment: $0.08855157561133353
#
#
# Price increase from previously bought: 2.2957275982068204%
# Share price: $0.9485884457945648
# Shares owned at the moment: 0
# Cash capital at the moment: $89.01065536706253
#
#
# Share price: $0.7001924826777215
# Shares owned at the moment: 126
# Cash capital at the moment: $0.5437858544217846
#
#
# Price increase from previously bought: 5.339243779205183%
# Share price: $0.7396058042837459
# Shares owned at the moment: 0
# Cash capital at the moment: $93.47784378298944
#
#
# Share price: $0.7350229229295249
# Shares owned at the moment: 126
# Cash capital at the moment: $0.6102700510742238
#
#
# Price increase from previously bought: -5.248664038604112%
# Share price: $0.6983592602057462
# Shares owned at the moment: 0
# Cash capital at the moment: $88.36155535333695
#
#
# Share price: $0.6827772188453909
# Shares owned at the moment: 129
# Cash capital at the moment: $0.04107890389612123
#
#
# Price increase from previously bought: 1.3322676614190954%
# Share price: $0.6937762914386667
# Shares owned at the moment: 0
# Cash capital at the moment: $89.29210336009626
#
#
# Share price: $0.645197032298483
# Shares owned at the moment: 138
# Cash capital at the moment: $0.010060629148327394
#
#
# Price increase from previously bought: 25.51042075400023%
# Share price: $0.8120164310824567
# Shares owned at the moment: 0
# Cash capital at the moment: $111.76016788293155
#
#
# Share price: $0.8807607003500755
# Shares owned at the moment: 126
# Cash capital at the moment: $0.47913605615073607
#
#
# Price increase from previously bought: -2.2461112828424445%
# Share price: $0.8633455239306032
# Shares owned at the moment: 0
# Cash capital at the moment: $108.96152284736478
#
#
# Share price: $0.8074335497282359
# Shares owned at the moment: 134
# Cash capital at the moment: $0.4678879207063176
#
#
# Price increase from previously bought: -0.27424582398404285%
# Share price: $0.8074335497282359
# Shares owned at the moment: 0
# Cash capital at the moment: $108.36644432121507
#
#
# Share price: $0.8550961976324316
# Shares owned at the moment: 126
# Cash capital at the moment: $0.32803258704905147
#
#
# Price increase from previously bought: 2.2912919778170338%
# Share price: $0.8770943428189835
# Shares owned at the moment: 0
# Cash capital at the moment: $110.53800659245418
#
#
# Share price: $0.8770943428189835
# Shares owned at the moment: 125
# Cash capital at the moment: $0.5997125597372133
#
#
# Price increase from previously bought: -8.298906947265184%
# Share price: $0.8065169384922479
# Shares owned at the moment: 0
# Cash capital at the moment: $101.13708967366149
#
#
# Share price: $0.7909348971318924
# Shares owned at the moment: 127
# Cash capital at the moment: $0.412123725087838
#
#
# Price increase from previously bought: -7.092826010647402%
# Share price: $0.7368560579886416
# Shares owned at the moment: 0
# Cash capital at the moment: $93.73549611139278
#
#
# Share price: $0.7350229229295249
# Shares owned at the moment: 127
# Cash capital at the moment: $0.13087814350998883
#
#
# Price increase from previously bought: -3.756342132194135%
# Share price: $0.7093583327990225
# Shares owned at the moment: 0
# Cash capital at the moment: $89.97164301125578
#
#
# Share price: $0.6571127161277468
# Shares owned at the moment: 136
# Cash capital at the moment: $0.3585534620504376
#
#
# Price increase from previously bought: -0.41335399302657727%
# Share price: $0.6561961048917591
# Shares owned at the moment: 0
# Cash capital at the moment: $89.35580638410015
#
#
# Share price: $0.7341063116935371
# Shares owned at the moment: 121
# Cash capital at the moment: $0.28466879396613365
#
#
# Price increase from previously bought: 2.465099705257212%
# Share price: $0.7542713218209725
# Shares owned at the moment: 0
# Cash capital at the moment: $91.30051495196787
#
#
# Share price: $0.7331897004575496
# Shares owned at the moment: 124
# Cash capital at the moment: $0.13497440737569377
#
#
# Price increase from previously bought: -13.738736661162099%
# Share price: $0.6341979597052072
# Shares owned at the moment: 0
# Cash capital at the moment: $78.5592599065619
#
#
# Share price: $0.6158661720497474
# Shares owned at the moment: 127
# Cash capital at the moment: $0.1291647956556119
#
#
# Price increase from previously bought: -24.318493872714164%
# Share price: $0.46737856092123353
# Shares owned at the moment: 0
# Cash capital at the moment: $59.323010070250525
#
#
# Share price: $0.459129234623062
# Shares owned at the moment: 128
# Cash capital at the moment: $0.39285454791126995
#
#
# Price increase from previously bought: -24.164941484717783%
# Share price: $0.34913842127744366
# Shares owned at the moment: 0
# Cash capital at the moment: $44.9596757471344
#
#
# Share price: $0.3051420434914811
# Shares owned at the moment: 146
# Cash capital at the moment: $0.28642286691632535
#
#
# Price increase from previously bought: 17.399664191220722%
# Share price: $0.35922088263473195
# Shares owned at the moment: 0
# Cash capital at the moment: $52.58844454720934
#
#
# Share price: $0.3894683541194557
# Shares owned at the moment: 134
# Cash capital at the moment: $0.2561660067092575
#
#
# Price increase from previously bought: 4.1850389971924695%
# Share price: $0.4068836179517865
# Shares owned at the moment: 0
# Cash capital at the moment: $54.62863419903342
#
#
# Share price: $0.370219955228008
# Shares owned at the moment: 147
# Cash capital at the moment: $0.05663936361531796
#
#
# Price increase from previously bought: 16.02121239286898%
# Share price: $0.43071489819745523
# Shares owned at the moment: 0
# Cash capital at the moment: $63.19761290104491
#
#
# Share price: $0.42521540560724624
# Shares owned at the moment: 148
# Cash capital at the moment: $0.09267020109031421
#
#
# Price increase from previously bought: -6.2933612479127765%
# Share price: $0.39955081547674387
# Shares owned at the moment: 0
# Cash capital at the moment: $59.06357370974937
#
#
# Share price: $0.3372227374481801
# Shares owned at the moment: 174
# Cash capital at the moment: $0.22545631389707665
#
#
# Price increase from previously bought: 5.418018910760747%
# Share price: $0.35647113633962746
# Shares owned at the moment: 0
# Cash capital at the moment: $62.080862598253745
#
#
# Share price: $0.33263976868110035
# Shares owned at the moment: 186
# Cash capital at the moment: $0.0397203818886922
#
#
# Price increase from previously bought: 3.847664608161705%
# Share price: $0.34638858756948065
# Shares owned at the moment: 0
# Cash capital at the moment: $64.2908199072703
#
#
# Share price: $0.2611457531183773
# Shares owned at the moment: 245
# Cash capital at the moment: $0.13416344210436648
#
#
# Price increase from previously bought: -20.925751560244276%
# Share price: $0.20706691397512622
# Shares owned at the moment: 0
# Cash capital at the moment: $50.72604603271955
#
#
# Share price: $0.15940422236450136
# Shares owned at the moment: 317
# Cash capital at the moment: $0.05594691232636251
#
#
# Price increase from previously bought: 34.70517988224109%
# Share price: $0.2153162402732981
# Shares owned at the moment: 0
# Cash capital at the moment: $68.1234931465036
#
#
# Share price: $0.19148487261477076
# Shares owned at the moment: 354
# Cash capital at the moment: $0.15143771738426892
#
#
# Price increase from previously bought: 16.433452051231747%
# Share price: $0.22356556657146986
# Shares owned at the moment: 0
# Cash capital at the moment: $79.07600720462727
#
#
# Share price: $0.19606784138185052
# Shares owned at the moment: 402
# Cash capital at the moment: $0.03998197047573626
#
#
# Price increase from previously bought: 20.704935087799846%
# Share price: $0.23731438545985006
# Shares owned at the moment: 0
# Cash capital at the moment: $95.17801387220959
#
#
# Share price: $0.23639777422386254
# Shares owned at the moment: 401
# Cash capital at the moment: $0.12181876291533911
#
#
# Price increase from previously bought: -33.14109407655017%
# Share price: $0.15848761112851362
# Shares owned at the moment: 0
# Cash capital at the moment: $63.50057861227733
#
#
# Share price: $0.14657192729924984
# Shares owned at the moment: 432
# Cash capital at the moment: $0.007378569369883792
#
#
# Price increase from previously bought: 16.56394786294344%
# Share price: $0.17131986248733566
# Shares owned at the moment: 0
# Cash capital at the moment: $73.81403116726392
#
#
# Share price: $0.1071585619867964
# Shares owned at the moment: 686
# Cash capital at the moment: $0.10110301713349656
#
#
# Price increase from previously bought: -10.510392980721218%
# Share price: $0.09615948939352047
# Shares owned at the moment: 0
# Cash capital at the moment: $65.88510786434765
#
#
# Share price: $0.07507791173652688
# Shares owned at the moment: 875
# Cash capital at the moment: $0.011278869770606548
#
#
# Price increase from previously bought: 5.813239129105918%
# Share price: $0.07966083679717727
# Shares owned at the moment: 0
# Cash capital at the moment: $69.52282717875751
#
#
# Share price: $0.06499540667280922
# Shares owned at the moment: 1066
# Cash capital at the moment: $0.04718963088154737
#
#
# Price increase from previously bought: -32.620781351447256%
# Share price: $0.043913829015815524
# Shares owned at the moment: 0
# Cash capital at the moment: $46.73059797198103
#
#
#
#
# Capital at the end of test period: $46.73059797198103
# profit gained: -53.26940202801897%
#
#
# Capital at the end of test period if Buy and Hold: $3.993306781778525
# profit gained: -96.00669321822147%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.729839     19.230769       5.555556      93.548387
# 1       0.753425     12.000000       9.523810      92.485549
# 2       0.727660      5.882353       6.521739      90.080429
# 3       0.658273      7.142857       4.545455      89.000000
# 4       0.740385     11.764706      10.344828      91.975309
# 5       0.739496      8.695652       9.803922      90.315789
# 6       0.719738     10.810811       7.766990      91.038407
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         46.153846           55.555556          83.783784     107.357920
# 1         56.000000           38.095238          87.209302      41.621153
# 2         50.980392           60.869565          83.602151    2061.380675
# 3         35.714286           45.454545          82.412060     -92.389196
# 4         52.941176           44.827586          85.093168    3106.331976
# 5         53.623188           54.901961          83.544304     -25.338696
# 6         52.252252           54.368932          84.757835     -53.269402
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
# 5         -91.884658
# 6         -96.006693

# %%
df = log_hist['0_epochs_logs']
df['Profit gained']
# Out:
# 0     35.959375
# 1    166.592875
# 2    713.439052
# 3    -96.579447
# 4    575.015339
# 5    -12.325167
# 6    -48.838052
# Name: Profit gained, dtype: float64

# %%
accumulation_phase_data_acc = []
mark_up_phase_data_acc = []
distribution_phase_data_acc = []
mark_down_phase_data_acc = []
bull_phase_data_acc = []
bear_phase_data_acc = []
full_cycle_data_acc = []

accumulation_phase_data_correct_buys = []
mark_up_phase_data_correct_buys = []
distribution_phase_data_correct_buys = []
mark_down_phase_data_correct_buys = []
bull_phase_data_correct_buys = []
bear_phase_data_correct_buys = []
full_cycle_data_correct_buys = []

accumulation_phase_data_correct_sells = []
mark_up_phase_data_correct_sells = []
distribution_phase_data_correct_sells = []
mark_down_phase_data_correct_sells = []
bull_phase_data_correct_sells = []
bear_phase_data_correct_sells = []
full_cycle_data_correct_sells = []

accumulation_phase_data_correct_holds = []
mark_up_phase_data_correct_holds = []
distribution_phase_data_correct_holds = []
mark_down_phase_data_correct_holds = []
bull_phase_data_correct_holds = []
bear_phase_data_correct_holds = []
full_cycle_data_correct_holds = []

accumulation_phase_data_correct_low_buys = []
mark_up_phase_data_correct_low_buys = []
distribution_phase_data_correct_low_buys = []
mark_down_phase_data_correct_low_buys = []
bull_phase_data_correct_low_buys = []
bear_phase_data_correct_low_buys = []
full_cycle_data_correct_low_buys = []

accumulation_phase_data_correct_high_sells = []
mark_up_phase_data_correct_high_sells = []
distribution_phase_data_correct_high_sells = []
mark_down_phase_data_correct_high_sells = []
bull_phase_data_correct_high_sells = []
bear_phase_data_correct_high_sells = []
full_cycle_data_correct_high_sells = []

accumulation_phase_data_correct_mid_holds = []
mark_up_phase_data_correct_mid_holds = []
distribution_phase_data_correct_mid_holds = []
mark_down_phase_data_correct_mid_holds = []
bull_phase_data_correct_mid_holds = []
bear_phase_data_correct_mid_holds = []
full_cycle_data_correct_mid_holds = []

accumulation_phase_data_profit = []
mark_up_phase_data_profit = []
distribution_phase_data_profit = []
mark_down_phase_data_profit = []
bull_phase_data_profit = []
bear_phase_data_profit = []
full_cycle_data_profit = []

for key,value in log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    accumulation_phase_data_acc.append(acc[0])
    mark_up_phase_data_acc.append(acc[1])
    distribution_phase_data_acc.append(acc[2])
    mark_down_phase_data_acc.append(acc[3]) 
    bull_phase_data_acc.append(acc[4]) 
    bear_phase_data_acc.append(acc[5]) 
    full_cycle_data_acc.append(acc[6]) 

    accumulation_phase_data_correct_buys.append(correct_buys[0])
    mark_up_phase_data_correct_buys.append(correct_buys[1]) 
    distribution_phase_data_correct_buys.append(correct_buys[2]) 
    mark_down_phase_data_correct_buys.append(correct_buys[3]) 
    bull_phase_data_correct_buys.append(correct_buys[4])
    bear_phase_data_correct_buys.append(correct_buys[5]) 
    full_cycle_data_correct_buys.append(correct_buys[6]) 

    accumulation_phase_data_correct_sells.append(correct_sells[0]) 
    mark_up_phase_data_correct_sells.append(correct_sells[1]) 
    distribution_phase_data_correct_sells.append(correct_sells[2]) 
    mark_down_phase_data_correct_sells.append(correct_sells[3]) 
    bull_phase_data_correct_sells.append(correct_sells[4]) 
    bear_phase_data_correct_sells.append(correct_sells[5]) 
    full_cycle_data_correct_sells.append(correct_sells[6])

    accumulation_phase_data_correct_holds.append(correct_holds[0]) 
    mark_up_phase_data_correct_holds.append(correct_holds[1])  
    distribution_phase_data_correct_holds.append(correct_holds[2])  
    mark_down_phase_data_correct_holds.append(correct_holds[3])  
    bull_phase_data_correct_holds.append(correct_holds[4])  
    bear_phase_data_correct_holds.append(correct_holds[5])  
    full_cycle_data_correct_holds.append(correct_holds[6])  

    accumulation_phase_data_correct_low_buys.append(correct_low_buys[0])  
    mark_up_phase_data_correct_low_buys.append(correct_low_buys[1])  
    distribution_phase_data_correct_low_buys.append(correct_low_buys[2])  
    mark_down_phase_data_correct_low_buys.append(correct_low_buys[3])   
    bull_phase_data_correct_low_buys.append(correct_low_buys[4])   
    bear_phase_data_correct_low_buys.append(correct_low_buys[5])  
    full_cycle_data_correct_low_buys.append(correct_low_buys[6])  

    accumulation_phase_data_correct_high_sells.append(correct_high_sells[0]) 
    mark_up_phase_data_correct_high_sells.append(correct_high_sells[1]) 
    distribution_phase_data_correct_high_sells.append(correct_high_sells[2]) 
    mark_down_phase_data_correct_high_sells.append(correct_high_sells[3]) 
    bull_phase_data_correct_high_sells.append(correct_high_sells[4]) 
    bear_phase_data_correct_high_sells.append(correct_high_sells[5]) 
    full_cycle_data_correct_high_sells.append(correct_high_sells[6]) 

    accumulation_phase_data_correct_mid_holds.append(correct_mid_holds[0])  
    mark_up_phase_data_correct_mid_holds.append(correct_mid_holds[1])  
    distribution_phase_data_correct_mid_holds.append(correct_mid_holds[2])   
    mark_down_phase_data_correct_mid_holds.append(correct_mid_holds[3])   
    bull_phase_data_correct_mid_holds.append(correct_mid_holds[4])   
    bear_phase_data_correct_mid_holds.append(correct_mid_holds[5])   
    full_cycle_data_correct_mid_holds.append(correct_mid_holds[6])   

    accumulation_phase_data_profit.append(profit[0]) 
    mark_up_phase_data_profit.append(profit[1]) 
    distribution_phase_data_profit.append(profit[2]) 
    mark_down_phase_data_profit.append(profit[3])  
    bull_phase_data_profit.append(profit[4])  
    bear_phase_data_profit.append(profit[5])  
    full_cycle_data_profit.append(profit[6])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(accumulation_phase_data_acc)
plt.plot(mark_up_phase_data_acc)
plt.plot(distribution_phase_data_acc)
plt.plot(mark_down_phase_data_acc)
plt.plot(bull_phase_data_acc)
plt.plot(bear_phase_data_acc)
plt.plot(full_cycle_data_acc)
plt.title('Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['accumulation_phase_data_acc','mark_up_phase_data_acc','distribution_phase_data_acc','mark_down_phase_data_acc','bull_phase_data_acc','bear_phase_data_acc','full_cycle_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct buys")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_buys")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_buys")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_buys")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_buys")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct sells")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_sells")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_sells")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_sells")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_sells")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct holds")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_holds")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_holds")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_holds")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_holds")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct low buys")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_low_buys")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_low_buys")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_low_buys")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_low_buys")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct high sells")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_high_sells")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_high_sells")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_high_sells")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_high_sells")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_mid_holds")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_mid_holds")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_mid_holds")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_mid_holds")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Profit")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_profit")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_profit")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_profit")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_profit")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_profit")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_profit")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_profit")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_profit')
