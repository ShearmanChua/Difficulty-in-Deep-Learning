# %%
import os
seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
experiment = 'Mark Up phase LSTM Experiment'

# %%
import requests
import lxml
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.utils import compute_class_weight
import tensorflow as tf
from pil import Image
from sklearn import preprocessing
import tensorflow_addons as tfa
import glob
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
import math

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
# gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
np.random.seed(seed)
tf.random.set_seed(seed)

session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, 
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), 
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)

# %% [markdown]
# ## Prepare Test Data

# %%
test_sets = ['accumulation phase data','mark up phase data','distribution phase data','mark down phase data','bull phase data','bear phase data','full cycle data']
test_data = {}

for name in test_sets:

    df = pd.read_csv("{}/test_data.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    labels = []
    data_15 = []
    sequential = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15.append(np.array(i[0:-1]))
            labels.append(i[-1])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_arr = min_max_scaler.fit_transform(data_15)
            sequential.append(data_15_arr)
            data_15 = data_15[1:15]
        else:
            data_15.append(np.array(i[0:-1]))
            count+= 1
            
    X = sequential
    X  = np.array(X).reshape(-1, 15, 4)
    y = labels
    y = np.array(y)
    print(X.shape)
    
    y = to_categorical(y, 3)
    
    test_data['{}_X'.format(name)] = X
    test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2004-06-14    93.010002  92.918784 -32.009897  48922600.0     2.0
# 2004-06-15    91.529999  92.705124 -68.734488  45879300.0     2.0
# 2004-06-16    90.209999  92.321259 -94.676024  40369000.0     2.0
# 2004-06-17    89.980003  91.961066 -87.983635  36219100.0     2.0
# 2004-06-18    89.339996  91.557824 -85.961924  32718400.0     2.0
# (248, 15, 4)
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22   115.589996  116.459043 -80.074504 -17684500.0     2.0
# 2020-01-23   116.099998  116.403805 -70.577262 -12758400.0     2.0
# 2020-01-24   115.809998  116.312450 -69.789236 -17063500.0     2.0
# 2020-01-27   114.370003  116.013612 -94.416205 -21446900.0     2.0
# 2020-01-28   115.860001  115.989979 -34.297465 -14428500.0     2.0
# (219, 15, 4)
#             previous_1d      EMA_12   willr_14        OBV_7  labels
# Date
# 2016-12-05   223.360001  213.378658 -16.514565 -283274800.0     2.0
# 2016-12-06   228.550003  215.712711  -2.667189 -278675500.0     2.0
# 2016-12-07   231.380005  218.123064  -4.633597 -273416200.0     2.0
# 2016-12-08   235.559998  220.805669  -1.742271 -266821000.0     2.0
# 2016-12-09   241.449997  223.981719  -2.918174 -259477300.0     2.0
# (470, 15, 4)
#             previous_1d      EMA_12   willr_14        OBV_7  labels
# Date
# 2007-10-01   216.740005  205.638670  -5.220429  161688200.0     2.0
# 2007-10-02   222.979996  208.306567  -1.526716  171593800.0     2.0
# 2007-10-03   228.020004  211.339403  -1.071898  181013600.0     2.0
# 2007-10-04   227.350006  213.802573  -7.282412  170892200.0     2.0
# 2007-10-05   225.949997  215.671407 -10.566735  160852300.0     2.0
# (278, 15, 4)
#             previous_1d       EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22  1075.300049  1097.577291 -89.711935   1200864.0     2.0
# 2020-01-23  1075.510010  1094.182325 -70.779503   4820868.0     2.0
# 2020-02-03  1052.800049  1087.815821 -81.895216   -525975.0     1.0
# 2020-02-04  1003.919983  1074.908769 -83.419991 -12870263.0     2.0
# 2020-02-05  1038.010010  1069.232037 -59.790669  -6607845.0     2.0
# (208, 15, 4)
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2018-01-22    32.830002  32.653718 -49.494874  128764966.0     2.0
# 2018-01-23    33.750000  32.822377 -18.518497  165063463.0     2.0
# 2018-01-24    33.970001  32.998934 -16.190425  201240854.0     2.0
# 2018-01-25    33.959999  33.146790 -17.627141  173336178.0     2.0
# 2018-01-26    34.880001  33.413438  -2.648942  221767625.0     0.0
# (595, 15, 4)
#             previous_1d    EMA_12   willr_14        OBV_7  labels
# Date
# 2002-11-11         8.74  8.763110 -71.929852 -553467352.0     2.0
# 2002-11-12         8.50  8.722632 -80.487816 -559735252.0     2.0
# 2002-11-13         8.63  8.708381 -69.918697 -552295352.0     2.0
# 2002-11-14         8.52  8.679399 -78.861762 -566378552.0     2.0
# 2002-11-15         8.80  8.697953 -56.097548 -558353452.0     2.0
# (917, 15, 4)

# %% [markdown]
# ## Train Accumulation Phase Stock Data

# %%
def pred_acc(actual, predictions, logger):

    hold = 0
    sell = 0
    buy = 0
    pred_hold = 0
    pred_sell = 0
    pred_buy = 0
    buy_buy = 0
    buy_sell = 0
    buy_hold = 0
    sell_buy = 0
    sell_sell = 0
    sell_hold = 0
    hold_buy = 0
    hold_sell = 0
    hold_hold = 0

    for i in range (0,len(actual)):
        if actual[i]==1 and predictions[i] == 1:
            buy_buy += 1
            buy += 1
            pred_buy += 1
        elif actual[i]==1 and predictions[i] == 0:
            buy_sell += 1
            buy += 1
            pred_sell += 1
        elif actual[i]==1 and predictions[i] == 2:
            buy_hold += 1
            buy += 1
            pred_hold += 1
        elif actual[i]==0 and predictions[i] == 1:
            sell_buy += 1
            sell += 1
            pred_buy += 1
        elif actual[i]==0 and predictions[i] == 0:
            sell_sell += 1
            sell += 1
            pred_sell += 1
        elif actual[i]==0 and predictions[i] == 2:
            sell_hold += 1
            sell += 1
            pred_hold += 1
        elif actual[i]==2 and predictions[i] == 1:
            hold_buy += 1
            hold += 1
            pred_buy += 1
        elif actual[i]==2 and predictions[i] == 0:
            hold_sell += 1
            hold += 1
            pred_sell += 1
        elif actual[i]==2 and predictions[i] == 2:
            hold_hold += 1
            hold += 1
            pred_hold += 1

    print("number of predictions: " + str(len(actual)))
    print("actual predicted buys: " + str(buy_buy) )
    print("actual buys but predicted sell: " + str(buy_sell) )
    print("actual buys but predicted hold: " + str(buy_hold))
    print("actual sells but predicted buy: " + str(sell_buy) )
    print("actual predicted sells: " + str(sell_sell))
    print("actual sells but predicted hold: " + str(sell_hold) )
    print("actual holds but predicted buy: " + str(hold_buy) )
    print("actual holds but predicted sell: " + str(hold_sell))
    print("actual predicted holds: " + str(hold_hold) )
    
    if pred_buy !=0:
        Percentage_buys_correct = 100*buy_buy/pred_buy
    else:
        Percentage_buys_correct = 0
        
    if pred_sell !=0:
        Percentage_sells_correct = 100*sell_sell/pred_sell
    else:
        Percentage_sells_correct = 0
        
    if pred_hold !=0:
        Percentage_holds_correct = 100*hold_hold/pred_hold
    else:
        Percentage_holds_correct = 0

    print("Percentage buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage holds correct: " + str(Percentage_holds_correct) + "%")

    print("actual buys: " + str(buy))
    print("actual sells: " + str(sell))
    print("actual holds: " + str(hold))
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def correct_maxima_minima(predictions, price, logger):
    correct_maxima = 0 
    correct_minima = 0
    correct_hold = 0

    hold = 0
    buy = 0
    sell = 0

#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):
        if i < 4:
            prices = price[i:i+9]
            prices.sort(key = float)
#             if i == 0:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1

        else:
            prices = price[i:i+5]
            prices = prices + price[i-4:i] 
            prices.sort(key = float)
#             if i == 10:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1
                    
    if buy !=0:
        Percentage_buys_correct = 100*correct_minima/buy
    else:
        Percentage_buys_correct = 0
        
    if sell !=0:
        Percentage_sells_correct = 100*correct_maxima/sell
    else:
        Percentage_sells_correct = 0
        
    if hold !=0:
        Percentage_holds_correct = 100*correct_hold/hold
    else:
        Percentage_holds_correct = 0

    print("Percentage low buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage high sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage mid holds correct: " + str(Percentage_holds_correct) + "%")
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %% [markdown]
# ### Creating Training Data and Model

# %%
labels = []
sequential = []

for filepath in glob.iglob('mark up phase data/*_acc_data.csv'):
    print(filepath)
    seed = 10
    df = pd.read_csv(filepath)
    df.set_index('Date', inplace=True)
    print(df.head())
    
    plt.figure(figsize=(15,5))
    plt.plot(df['previous_1d'].values)
    plt.plot(df['EMA_12'].values)
    plt.show()

    data_15 = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15.append(np.array(i[0:-1]))
            labels.append(i[-1])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_arr = min_max_scaler.fit_transform(data_15)
            sequential.append(data_15_arr)
            data_15 = data_15[1:15]
        else:
            data_15.append(np.array(i[0:-1]))
            count+= 1
# Out:
# mark up phase data\0_acc_data.csv
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2008-11-17    17.790001  23.793106 -99.509793 -20764000.0     2.0
# 2008-11-18    15.400000  22.501859 -98.846675 -32084400.0     2.0
# 2008-11-19    15.980000  21.498496 -94.911805 -25902800.0     2.0
# 2008-11-20    14.550000  20.429497 -99.036605 -31324000.0     1.0
# 2008-11-21    14.150000  19.463420 -99.684945 -38055900.0     2.0
# mark up phase data\10_acc_data.csv
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2006-01-17    20.655001  20.654687 -33.333333 -500723200.0     2.0
# 2006-01-18    20.514999  20.633197 -52.000173 -512297200.0     2.0
# 2006-01-19    20.410000  20.598859 -66.000112 -525203400.0     2.0
# 2006-01-20    20.465000  20.578265 -58.666738 -514295800.0     1.0
# 2006-01-23    20.045000  20.496224 -70.204110 -533267400.0     2.0
# mark up phase data\11_acc_data.csv
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2011-09-19    62.049999  62.040598 -50.530081 -129442400.0     2.0
# 2011-09-20    60.560001  61.812814 -76.855114 -143029400.0     2.0
# 2011-09-21    60.389999  61.593920 -79.751333 -152659600.0     2.0
# 2011-09-22    60.790001  61.470240 -72.646507 -138309200.0     2.0
# 2011-09-23    60.919998  61.385587 -65.637902 -121968200.0     2.0
# mark up phase data\1_acc_data.csv
#             previous_1d      EMA_12   willr_14        OBV_7  labels
# Date
# 2016-09-12   128.529999  131.714910 -97.877674  246447200.0     2.0
# 2016-09-13   130.119995  131.469539 -62.127252  252828300.0     2.0
# 2016-09-14   128.759995  131.052686 -70.623525  248275900.0     2.0
# 2016-09-15   127.669998  130.532272 -82.496784  244320500.0     2.0
# 2016-09-16   127.769997  130.107307 -81.209803  247782900.0     1.0
# mark up phase data\2_acc_data.csv
#             previous_1d      EMA_12   willr_14         OBV_7  labels
# Date
# 2015-08-17   209.979996  210.306242 -25.639489  1.091620e+09     2.0
# 2015-08-18   206.220001  209.677590 -66.365130  1.086234e+09     2.0
# 2015-08-19   201.059998  208.351806 -94.906800  1.081106e+09     2.0
# 2015-08-20   201.619995  207.316143 -78.646789  1.086132e+09     2.0
# 2015-08-21   195.070007  205.432122 -99.123190  1.082167e+09     2.0
# mark up phase data\3_acc_data.csv
#             previous_1d      EMA_12   willr_14        OBV_7  labels
# Date
# 2017-07-17   153.000000  155.694278 -80.508425  116165500.0     2.0
# 2017-07-18   152.839996  155.255158 -82.015049  113069000.0     2.0
# 2017-07-19   151.500000  154.677441 -94.529687  109812100.0     2.0
# 2017-07-20   151.240005  154.148605 -96.746304  105712100.0     2.0
# 2017-07-21   150.990005  153.662666 -98.949373  102504700.0     1.0
# mark up phase data\4_acc_data.csv
#             previous_1d     EMA_12   willr_14         OBV_7  labels
# Date
# 2016-06-20    62.279999  63.332285 -72.509996 -2.241342e+09     2.0
# 2016-06-21    62.369999  63.184241 -70.717164 -2.229129e+09     2.0
# 2016-06-22    62.950001  63.148204 -58.248454 -2.217517e+09     2.0
# 2016-06-23    62.709999  63.080788 -62.757257 -2.230161e+09     0.0
# 2016-06-24    64.050003  63.229898 -35.185162 -2.213577e+09     2.0
# mark up phase data\5_acc_data.csv
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22    91.419998  91.455093 -52.848110  -5093000.0     1.0
# 2019-01-23    90.440002  91.298925 -66.084726 -18611500.0     2.0
# 2019-01-24    94.839996  91.843705 -21.418921   4257500.0     2.0
# 2019-01-25    94.300003  92.221597 -28.785813  -7888900.0     2.0
# 2019-01-28    93.599998  92.433659 -38.335668 -18506900.0     2.0
# mark up phase data\6_acc_data.csv
#             previous_1d     EMA_12   willr_14        OBV_7  labels
# Date
# 2013-04-22       11.000  11.129454 -63.157884  265234002.0     2.0
# 2013-04-23       10.900  11.094154 -73.684232  253872304.0     1.0
# 2013-04-24       10.750  11.041207 -89.473653  235528586.0     2.0
# 2013-04-25       11.000  11.034867 -63.157884  241232586.0     2.0
# 2013-04-26       10.975  11.025657 -65.789421  237776586.0     2.0
# mark up phase data\7_acc_data.csv
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22   114.040001  121.098552 -98.547847 -39707800.0     2.0
# 2020-01-23   113.900002  119.991082 -99.140747 -44778400.0     2.0
# 2020-01-24   115.529999  119.304762 -80.714281 -40136900.0     2.0
# 2020-01-27   114.320000  118.537875 -90.317449 -44475800.0     2.0
# 2020-01-28   115.779999  118.113587 -75.552172 -37696600.0     2.0
# mark up phase data\8_acc_data.csv
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2016-10-31   123.580002  124.920987 -72.495976  70534500.0     2.0
# 2016-11-01   122.010002  124.473143 -94.018411  64863000.0     1.0
# 2016-11-02   119.889999  123.768044 -92.281854  57370400.0     2.0
# 2016-11-03   120.290001  123.232961 -87.807565  62216400.0     2.0
# 2016-11-04   120.180000  122.763274 -89.037997  57102900.0     2.0
# mark up phase data\9_acc_data.csv
#             previous_1d     EMA_12    willr_14        OBV_7  labels
# Date
# 2010-06-28    25.129999  25.907493 -100.000000  368525200.0     2.0
# 2010-06-29    25.540001  25.850956  -70.921898  392050600.0     2.0
# 2010-06-30    25.165001  25.745424  -92.281775  368548000.0     2.0
# 2010-07-01    25.059999  25.639974  -96.416922  346614200.0     1.0
# 2010-07-02    25.014999  25.543824  -84.487605  320583400.0     2.0

# %%
X = sequential
X  = np.array(X).reshape(-1, 15, 4)
X.shape
# Out:
# (4338, 15, 4)

# %%
y = labels
y = np.array(y)
y.shape
# Out:
# (4338,)

# %%
from collections import Counter

Counter(y)
# Out:
# Counter({2.0: 3973, 0.0: 184, 1.0: 181})

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization,Activation
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(LSTM(100, input_shape=(X_train.shape[1:]), return_sequences=True,kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(LSTM(100, kernel_regularizer=l2(1e-5)))
model.add(BatchNormalization())
model.add(Activation('relu'))

# model.add(Dense(100, kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))

model.add(Dense(75, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(50, kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "LSTM_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))

epochs = 0 
histories = {}
log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['accumulation phase data','mark up phase data','distribution phase data','mark down phase data','bull phase data','bear phase data','full cycle data']
    
    for name in test_sets:
        
        print('\n')
        print(name)
        print('\n')
        
        X = test_data['{}_X'.format(name)]
        y = test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("{}/test_data.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(log)
        log.loc[df_length] = logger
        print(log.head(20))
        logger = []

    log.to_csv('{}_{}epochs.csv'.format(experiment,epochs))
    log_hist['{}_epochs_logs'.format(epochs)] = log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 2 ... 2 2 0] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  1/28 [>.............................] - ETA: 0s - loss: 0.5913 - accuracy: 0.5547 - mse: 0.3498 - weighted_accuracy: 0.2547 - weighted_mse: 0.4888WARNING:tensorflow:From C:\Users\Shearman Chua\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/28 [=>............................] - ETA: 1s - loss: 0.4777 - accuracy: 0.5469 - mse: 0.3438 - weighted_accuracy: 0.2710 - weighted_mse: 0.4519WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0100s vs `on_train_batch_end` time: 0.1067s). Check your callbacks.
# 28/28 [==============================] - 1s 40ms/step - loss: 0.3095 - accuracy: 0.4862 - mse: 0.4373 - weighted_accuracy: 0.2925 - weighted_mse: 0.5202 - val_loss: 0.3000 - val_accuracy: 0.0426 - val_mse: 0.3515 - val_weighted_accuracy: 0.0426 - val_weighted_mse: 0.3515
# Epoch 2/20
# 28/28 [==============================] - 0s 12ms/step - loss: 0.2186 - accuracy: 0.3620 - mse: 0.7007 - weighted_accuracy: 0.4388 - weighted_mse: 0.6929 - val_loss: 0.2914 - val_accuracy: 0.0415 - val_mse: 0.3806 - val_weighted_accuracy: 0.0415 - val_weighted_mse: 0.3806
# Epoch 3/20
# 28/28 [==============================] - 0s 11ms/step - loss: 0.1912 - accuracy: 0.2908 - mse: 0.9415 - weighted_accuracy: 0.4916 - weighted_mse: 0.9168 - val_loss: 0.2808 - val_accuracy: 0.0415 - val_mse: 0.4185 - val_weighted_accuracy: 0.0415 - val_weighted_mse: 0.4185
# Epoch 4/20
# 28/28 [==============================] - 0s 11ms/step - loss: 0.1801 - accuracy: 0.2622 - mse: 1.1024 - weighted_accuracy: 0.5267 - weighted_mse: 1.0556 - val_loss: 0.2709 - val_accuracy: 0.0415 - val_mse: 0.4632 - val_weighted_accuracy: 0.0415 - val_weighted_mse: 0.4632
# Epoch 5/20
# 28/28 [==============================] - 0s 11ms/step - loss: 0.1745 - accuracy: 0.2620 - mse: 1.2089 - weighted_accuracy: 0.5332 - weighted_mse: 1.1598 - val_loss: 0.2617 - val_accuracy: 0.0415 - val_mse: 0.5121 - val_weighted_accuracy: 0.0415 - val_weighted_mse: 0.5121
# Epoch 6/20
# 28/28 [==============================] - 0s 11ms/step - loss: 0.1708 - accuracy: 0.2573 - mse: 1.2752 - weighted_accuracy: 0.5338 - weighted_mse: 1.2154 - val_loss: 0.2553 - val_accuracy: 0.0415 - val_mse: 0.5677 - val_weighted_accuracy: 0.0415 - val_weighted_mse: 0.5677
# Epoch 7/20
# 28/28 [==============================] - 0s 11ms/step - loss: 0.1678 - accuracy: 0.3153 - mse: 1.2718 - weighted_accuracy: 0.5657 - weighted_mse: 1.2270 - val_loss: 0.2484 - val_accuracy: 0.0415 - val_mse: 0.6291 - val_weighted_accuracy: 0.0415 - val_weighted_mse: 0.6291
# Epoch 8/20
# 28/28 [==============================] - 0s 11ms/step - loss: 0.1652 - accuracy: 0.2620 - mse: 1.3098 - weighted_accuracy: 0.5767 - weighted_mse: 1.2486 - val_loss: 0.2428 - val_accuracy: 0.0415 - val_mse: 0.6956 - val_weighted_accuracy: 0.0415 - val_weighted_mse: 0.6956
# Epoch 9/20
# 28/28 [==============================] - 0s 12ms/step - loss: 0.1620 - accuracy: 0.2795 - mse: 1.3040 - weighted_accuracy: 0.5876 - weighted_mse: 1.2367 - val_loss: 0.2385 - val_accuracy: 0.0415 - val_mse: 0.7660 - val_weighted_accuracy: 0.0415 - val_weighted_mse: 0.7660
# Epoch 10/20
# 28/28 [==============================] - 0s 11ms/step - loss: 0.1605 - accuracy: 0.2890 - mse: 1.3269 - weighted_accuracy: 0.6062 - weighted_mse: 1.2597 - val_loss: 0.2326 - val_accuracy: 0.0415 - val_mse: 0.8472 - val_weighted_accuracy: 0.0415 - val_weighted_mse: 0.8472
# Epoch 11/20
# 28/28 [==============================] - 0s 11ms/step - loss: 0.1592 - accuracy: 0.2890 - mse: 1.3397 - weighted_accuracy: 0.6193 - weighted_mse: 1.2651 - val_loss: 0.2271 - val_accuracy: 0.0415 - val_mse: 0.9288 - val_weighted_accuracy: 0.0415 - val_weighted_mse: 0.9288
# Epoch 12/20
# 28/28 [==============================] - 0s 11ms/step - loss: 0.1570 - accuracy: 0.2816 - mse: 1.3785 - weighted_accuracy: 0.6058 - weighted_mse: 1.3089 - val_loss: 0.2235 - val_accuracy: 0.0415 - val_mse: 1.0016 - val_weighted_accuracy: 0.0415 - val_weighted_mse: 1.0016
# Epoch 13/20
# 28/28 [==============================] - 0s 11ms/step - loss: 0.1556 - accuracy: 0.2905 - mse: 1.3894 - weighted_accuracy: 0.6221 - weighted_mse: 1.3227 - val_loss: 0.2189 - val_accuracy: 0.0484 - val_mse: 1.0616 - val_weighted_accuracy: 0.0484 - val_weighted_mse: 1.0616
# Epoch 14/20
# 28/28 [==============================] - 0s 12ms/step - loss: 0.1543 - accuracy: 0.3380 - mse: 1.3956 - weighted_accuracy: 0.6393 - weighted_mse: 1.3378 - val_loss: 0.2143 - val_accuracy: 0.1048 - val_mse: 1.1199 - val_weighted_accuracy: 0.1048 - val_weighted_mse: 1.1199
# Epoch 15/20
# 28/28 [==============================] - 0s 11ms/step - loss: 0.1517 - accuracy: 0.3274 - mse: 1.4046 - weighted_accuracy: 0.6422 - weighted_mse: 1.3388 - val_loss: 0.2124 - val_accuracy: 0.1359 - val_mse: 1.1788 - val_weighted_accuracy: 0.1359 - val_weighted_mse: 1.1788
# Epoch 16/20
# 28/28 [==============================] - 0s 11ms/step - loss: 0.1498 - accuracy: 0.2971 - mse: 1.4347 - weighted_accuracy: 0.6507 - weighted_mse: 1.3539 - val_loss: 0.2071 - val_accuracy: 0.1866 - val_mse: 1.2130 - val_weighted_accuracy: 0.1866 - val_weighted_mse: 1.2130
# Epoch 17/20
# 28/28 [==============================] - 0s 11ms/step - loss: 0.1498 - accuracy: 0.3504 - mse: 1.4245 - weighted_accuracy: 0.6592 - weighted_mse: 1.3636 - val_loss: 0.1996 - val_accuracy: 0.2984 - val_mse: 1.2624 - val_weighted_accuracy: 0.2984 - val_weighted_mse: 1.2624
# Epoch 18/20
# 28/28 [==============================] - 0s 11ms/step - loss: 0.1486 - accuracy: 0.3357 - mse: 1.4644 - weighted_accuracy: 0.6606 - weighted_mse: 1.3863 - val_loss: 0.1954 - val_accuracy: 0.3318 - val_mse: 1.3252 - val_weighted_accuracy: 0.3318 - val_weighted_mse: 1.3252
# Epoch 19/20
# 28/28 [==============================] - 0s 10ms/step - loss: 0.1470 - accuracy: 0.2968 - mse: 1.5007 - weighted_accuracy: 0.6723 - weighted_mse: 1.4071 - val_loss: 0.1979 - val_accuracy: 0.2742 - val_mse: 1.3153 - val_weighted_accuracy: 0.2742 - val_weighted_mse: 1.3153
# Epoch 20/20
# 28/28 [==============================] - 0s 9ms/step - loss: 0.1454 - accuracy: 0.3153 - mse: 1.5207 - weighted_accuracy: 0.6726 - weighted_mse: 1.4282 - val_loss: 0.1910 - val_accuracy: 0.3502 - val_mse: 1.3452 - val_weighted_accuracy: 0.3502 - val_weighted_mse: 1.3452
# Validation loss: 0.1909780502319336
# Validation accuracy: 0.3502304255962372
#
#
# accumulation phase data
#
#
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2014 - accuracy: 0.2702 - mse: 1.4109 - weighted_accuracy: 0.2702 - weighted_mse: 1.4109
# Test loss: 0.2014450877904892
# Test accuracy: 0.27016130089759827
#
#
# number of predictions: 248
# actual predicted buys: 9
# actual buys but predicted sell: 0
# actual buys but predicted hold: 2
# actual sells but predicted buy: 4
# actual predicted sells: 3
# actual sells but predicted hold: 1
# actual holds but predicted buy: 121
# actual holds but predicted sell: 53
# actual predicted holds: 55
# Percentage buys correct: 6.7164179104477615%
# Percentage sells correct: 5.357142857142857%
# Percentage holds correct: 94.82758620689656%
# actual buys: 11
# actual sells: 8
# actual holds: 229
#
#
# Percentage low buys correct: 43.28358208955224%
# Percentage high sells correct: 42.857142857142854%
# Percentage mid holds correct: 89.47368421052632%
#
#
# Capital: 100
# Share price: $0.21694303230780076
# Shares owned at the moment: 459
# Cash capital at the moment: $0.14931182818891386
#
#
# Price increase from previously bought: -39.00751128457347%
# Share price: $0.13268283162411243
# Shares owned at the moment: 0
# Cash capital at the moment: $60.88325263943898
#
#
# Share price: $0.38209307707617524
# Shares owned at the moment: 158
# Cash capital at the moment: $0.346527019413692
#
#
# Price increase from previously bought: 21.98143848993506%
# Share price: $0.46736435902539175
# Shares owned at the moment: 0
# Cash capital at the moment: $73.98702593142906
#
#
# Share price: $0.6823962985991441
# Shares owned at the moment: 108
# Cash capital at the moment: $0.0855539820375526
#
#
# Price increase from previously bought: 5.981200894867711%
# Share price: $0.7252006245458233
# Shares owned at the moment: 0
# Cash capital at the moment: $78.19183684749636
#
#
# Share price: $0.6817223301360331
# Shares owned at the moment: 114
# Cash capital at the moment: $0.2617712614909351
#
#
# Price increase from previously bought: 0.9583545601820953%
# Share price: $0.6901483502044019
# Shares owned at the moment: 0
# Cash capital at the moment: $78.72232167700366
#
#
# Share price: $0.6530739133319237
# Shares owned at the moment: 120
# Cash capital at the moment: $0.1379376857732808
#
#
# Price increase from previously bought: 24.995950419717737%
# Share price: $0.818560813760991
# Shares owned at the moment: 0
# Cash capital at the moment: $98.09511026855107
#
#
# Share price: $0.8573205575038327
# Shares owned at the moment: 114
# Cash capital at the moment: $0.09179671833668124
#
#
# Price increase from previously bought: 2.8622030727450065%
# Share price: $0.884283924579303
# Shares owned at the moment: 0
# Cash capital at the moment: $100.62294111002161
#
#
# Share price: $0.8906875249748898
# Shares owned at the moment: 112
# Cash capital at the moment: $0.5916065551416949
#
#
# Price increase from previously bought: 1.9899531337538967%
# Share price: $0.9109099217106305
# Shares owned at the moment: 0
# Cash capital at the moment: $102.33295753084542
#
#
# Share price: $0.7727232440177259
# Shares owned at the moment: 132
# Cash capital at the moment: $0.05299078292716786
#
#
# Price increase from previously bought: -35.89880181431835%
# Share price: $0.4966870014343361
# Shares owned at the moment: 0
# Cash capital at the moment: $65.43537759073887
#
#
#
#
# Capital at the end of test period: $65.43537759073887
# profit gained: -34.56462240926113%
#
#
# Capital at the end of test period if Buy and Hold: $182.55793694382942
# profit gained: 82.55793694382942%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.270161      6.716418       5.357143      94.827586
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.283582           42.857143          89.473684     -34.564622
#
#    buy_n_hold profit
# 0          82.557937
#
#
# mark up phase data
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2008 - accuracy: 0.2740 - mse: 1.4504 - weighted_accuracy: 0.2740 - weighted_mse: 1.4504
# Test loss: 0.20079290866851807
# Test accuracy: 0.27397260069847107
#
#
# number of predictions: 219
# actual predicted buys: 7
# actual buys but predicted sell: 0
# actual buys but predicted hold: 0
# actual sells but predicted buy: 5
# actual predicted sells: 2
# actual sells but predicted hold: 4
# actual holds but predicted buy: 113
# actual holds but predicted sell: 37
# actual predicted holds: 51
# Percentage buys correct: 5.6%
# Percentage sells correct: 5.128205128205129%
# Percentage holds correct: 92.72727272727273%
# actual buys: 7
# actual sells: 11
# actual holds: 201
#
#
# Percentage low buys correct: 48.38709677419355%
# Percentage high sells correct: 48.717948717948715%
# Percentage mid holds correct: 87.27272727272727%
#
#
# Capital: 100
# Share price: $0.24286829602432447
# Shares owned at the moment: 410
# Cash capital at the moment: $0.15016462625953864
#
#
# Price increase from previously bought: 55.24406435808715%
# Share price: $0.37807546997330177
# Shares owned at the moment: 0
# Cash capital at the moment: $154.73482722291837
#
#
# Share price: $0.5075380561914253
# Shares owned at the moment: 304
# Cash capital at the moment: $0.01895632574903061
#
#
# Price increase from previously bought: -13.779379204460895%
# Share price: $0.4388058695946191
# Shares owned at the moment: 0
# Cash capital at the moment: $133.04909897553213
#
#
# Share price: $0.42608540916354065
# Shares owned at the moment: 311
# Cash capital at the moment: $0.1721271794838799
#
#
# Price increase from previously bought: -22.459656007565123%
# Share price: $0.33129665921989226
# Shares owned at the moment: 0
# Cash capital at the moment: $102.92204672907256
#
#
# Share price: $0.30277799553193563
# Shares owned at the moment: 338
# Cash capital at the moment: $0.30165209243138236
#
#
# Price increase from previously bought: 41.08277047520876%
# Share price: $0.4283422953430944
# Shares owned at the moment: 0
# Cash capital at the moment: $144.68320375487588
#
#
# Share price: $0.5672426980700174
# Shares owned at the moment: 254
# Cash capital at the moment: $0.20733942048954646
#
#
# Price increase from previously bought: -3.917408385968635%
# Share price: $0.5465202941309071
# Shares owned at the moment: 0
# Cash capital at the moment: $138.6417497042895
#
#
# Share price: $0.5811941304053823
# Shares owned at the moment: 237
# Cash capital at the moment: $0.5199475237222089
#
#
# Price increase from previously bought: 9.653505911636806%
# Share price: $0.6390523144275428
# Shares owned at the moment: 0
# Cash capital at the moment: $151.5588436971217
#
#
# Share price: $0.5758598144651097
# Shares owned at the moment: 262
# Cash capital at the moment: $0.26866531094083257
#
#
# Price increase from previously bought: 56.75266220167223%
# Share price: $0.9051579475954099
# Shares owned at the moment: 0
# Cash capital at the moment: $236.76788127969573
#
#
# Share price: $0.692601783719615
# Shares owned at the moment: 340
# Cash capital at the moment: $0.6356921472487898
#
#
# Price increase from previously bought: -2.1058736950443135%
# Share price: $0.6798810102234543
# Shares owned at the moment: 0
# Cash capital at the moment: $231.15954687866432
#
#
# Share price: $0.691165441121224
# Shares owned at the moment: 333
# Cash capital at the moment: $0.3685202325899297
#
#
# Price increase from previously bought: 16.984473572714332%
# Share price: $0.8107797825074263
# Shares owned at the moment: 0
# Cash capital at the moment: $269.61571622173165
#
#
# Share price: $0.8204228131777864
# Shares owned at the moment: 327
# Cash capital at the moment: $0.5996910978453229
#
#
# Price increase from previously bought: 11.39732572781269%
# Share price: $0.9164423784931806
# Shares owned at the moment: 0
# Cash capital at the moment: $299.4522380562554
#
#
# Share price: $0.9139804346846059
# Shares owned at the moment: 326
# Cash capital at the moment: $0.6752328893791173
#
#
#
#
# Capital at the end of test period: $283.4059025840656
# profit gained: 183.4059025840656%
#
#
# Capital at the end of test period if Buy and Hold: $355.7316817269389
# profit gained: 255.73168172693892%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.270161      6.716418       5.357143      94.827586
# 1       0.273973      5.600000       5.128205      92.727273
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.283582           42.857143          89.473684     -34.564622
# 1         48.387097           48.717949          87.272727     183.405903
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
#
#
# distribution phase data
#
#
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2017 - accuracy: 0.2426 - mse: 1.4141 - weighted_accuracy: 0.2426 - weighted_mse: 1.4141
# Test loss: 0.2016548216342926
# Test accuracy: 0.24255318939685822
#
#
# number of predictions: 470
# actual predicted buys: 19
# actual buys but predicted sell: 1
# actual buys but predicted hold: 4
# actual sells but predicted buy: 6
# actual predicted sells: 8
# actual sells but predicted hold: 6
# actual holds but predicted buy: 258
# actual holds but predicted sell: 81
# actual predicted holds: 87
# Percentage buys correct: 6.713780918727915%
# Percentage sells correct: 8.88888888888889%
# Percentage holds correct: 89.69072164948453%
# actual buys: 24
# actual sells: 20
# actual holds: 426
#
#
# Percentage low buys correct: 43.262411347517734%
# Percentage high sells correct: 45.55555555555556%
# Percentage mid holds correct: 82.47422680412372%
#
#
# Capital: 100
# Share price: $0.5051713785101153
# Shares owned at the moment: 197
# Cash capital at the moment: $0.20756183919942828
#
#
# Price increase from previously bought: -12.635427703846736%
# Share price: $0.44255450143698805
# Shares owned at the moment: 0
# Cash capital at the moment: $87.15104472113258
#
#
# Share price: $0.32370733362931925
# Shares owned at the moment: 268
# Cash capital at the moment: $0.15890700359020116
#
#
# Price increase from previously bought: 50.879378825408935%
# Share price: $0.48975073513123957
# Shares owned at the moment: 0
# Cash capital at the moment: $131.05115772697067
#
#
# Share price: $0.6353894317932258
# Shares owned at the moment: 205
# Cash capital at the moment: $0.4381234171859205
#
#
# Price increase from previously bought: -59.4613567537654%
# Share price: $0.258286595180125
# Shares owned at the moment: 0
# Cash capital at the moment: $53.24126636107874
#
#
# Share price: $0.2224612469613152
# Shares owned at the moment: 238
# Cash capital at the moment: $0.14988869814954597
#
#
# Price increase from previously bought: 25.491499457712898%
# Share price: $0.2799376718990214
# Shares owned at the moment: 0
# Cash capital at the moment: $66.59183540385874
#
#
# Share price: $0.1347664835295428
# Shares owned at the moment: 492
# Cash capital at the moment: $0.10438645510821232
#
#
# Price increase from previously bought: 112.22248332703342%
# Share price: $0.2867912911785202
# Shares owned at the moment: 0
# Cash capital at the moment: $140.81767309797561
#
#
# Share price: $0.18133953128431446
# Shares owned at the moment: 774
# Cash capital at the moment: $0.0748946915775548
#
#
# Price increase from previously bought: 101.40465165148598%
# Share price: $0.3662306234806574
# Shares owned at the moment: 0
# Cash capital at the moment: $282.7578753835278
#
#
# Share price: $0.29676012712803046
# Shares owned at the moment: 950
# Cash capital at the moment: $0.06046877977684062
#
#
# Price increase from previously bought: -4.147648592632224%
# Share price: $0.2852338016814133
# Shares owned at the moment: 0
# Cash capital at the moment: $270.2874070702268
#
#
# Share price: $0.48694711143097025
# Shares owned at the moment: 553
# Cash capital at the moment: $0.2651296291915628
#
#
# Price increase from previously bought: 28.91421734571047%
# Share price: $0.6294703537471491
# Shares owned at the moment: 0
# Cash capital at the moment: $347.40496821090403
#
#
# Share price: $0.7470716250274518
# Shares owned at the moment: 463
# Cash capital at the moment: $0.5595968766276087
#
#
# Price increase from previously bought: 18.813397535143505%
# Share price: $0.8900621379603424
# Shares owned at the moment: 0
# Cash capital at the moment: $411.52509513510813
#
#
# Share price: $0.781339721424952
# Shares owned at the moment: 525
# Cash capital at the moment: $0.19368216420105
#
#
# Price increase from previously bought: 12.031930563787396%
# Share price: $0.8777571866030709
# Shares owned at the moment: 0
# Cash capital at the moment: $459.7489431926551
#
#
# Share price: $0.7723051890330688
# Shares owned at the moment: 593
# Cash capital at the moment: $0.5125294090295824
#
#
# Price increase from previously bought: 2.682411285349029%
# Share price: $0.7952023999551259
# Shares owned at the moment: 0
# Cash capital at the moment: $470.77077626869243
#
#
# Share price: $0.7081308224628347
# Shares owned at the moment: 662
# Cash capital at the moment: $0.6990196360022765
#
#
# Price increase from previously bought: -22.407727184616675%
# Share price: $0.5509658003542321
# Shares owned at the moment: 0
# Cash capital at the moment: $364.43534623095906
#
#
# Share price: $0.4542367422063729
# Shares owned at the moment: 800
# Cash capital at the moment: $0.04663163300671158
#
#
# Price increase from previously bought: -14.124103443080038%
# Share price: $0.39115259451653484
# Shares owned at the moment: 0
# Cash capital at the moment: $312.1081715382982
#
#
# Share price: $0.3081310126034722
# Shares owned at the moment: 1010
# Cash capital at the moment: $0.04001492128514883
#
#
# Price increase from previously bought: -7.684865120095418%
# Share price: $0.2852338016814133
# Shares owned at the moment: 0
# Cash capital at the moment: $287.3339177353425
#
#
# Share price: $0.42666658744140107
# Shares owned at the moment: 671
# Cash capital at the moment: $0.2533310416861241
#
#
# Price increase from previously bought: -3.259581935947442%
# Share price: $0.4138941277916215
# Shares owned at the moment: 0
# Cash capital at the moment: $277.21255265055663
#
#
# Share price: $0.45205606676978527
# Shares owned at the moment: 611
# Cash capital at the moment: $0.24672864802789718
#
#
# Price increase from previously bought: -0.8240522853945609%
# Share price: $0.44956379836345994
# Shares owned at the moment: 0
# Cash capital at the moment: $274.17482987590176
#
#
# Share price: $0.2990967178873858
# Shares owned at the moment: 914
# Cash capital at the moment: $0.04865012642119382
#
#
# Price increase from previously bought: -14.76416972816963%
# Share price: $0.255638649126827
# Shares owned at the moment: 0
# Cash capital at the moment: $233.05982768376077
#
#
# Share price: $0.01
# Shares owned at the moment: 23242
# Cash capital at the moment: $0.0006726837607402558
#
#
#
#
# Capital at the end of test period: $7636.4956774019
# profit gained: 7536.495677401901%
#
#
# Capital at the end of test period if Buy and Hold: $64.93475897926798
# profit gained: -35.06524102073202%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.270161      6.716418       5.357143      94.827586
# 1       0.273973      5.600000       5.128205      92.727273
# 2       0.242553      6.713781       8.888889      89.690722
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.283582           42.857143          89.473684     -34.564622
# 1         48.387097           48.717949          87.272727     183.405903
# 2         43.262411           45.555556          82.474227    7536.495677
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
#
#
# mark down phase data
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2063 - accuracy: 0.2194 - mse: 1.4587 - weighted_accuracy: 0.2194 - weighted_mse: 1.4587
# Test loss: 0.20625177025794983
# Test accuracy: 0.21942445635795593
#
#
# number of predictions: 278
# actual predicted buys: 15
# actual buys but predicted sell: 0
# actual buys but predicted hold: 1
# actual sells but predicted buy: 4
# actual predicted sells: 6
# actual sells but predicted hold: 3
# actual holds but predicted buy: 173
# actual holds but predicted sell: 36
# actual predicted holds: 40
# Percentage buys correct: 7.8125%
# Percentage sells correct: 14.285714285714286%
# Percentage holds correct: 90.9090909090909%
# actual buys: 16
# actual sells: 13
# actual holds: 249
#
#
# Percentage low buys correct: 42.40837696335078%
# Percentage high sells correct: 50.0%
# Percentage mid holds correct: 81.81818181818181%
#
#
# Capital: 100
# Share price: $0.8557023478457203
# Shares owned at the moment: 116
# Cash capital at the moment: $0.4655586009336474
#
#
# Price increase from previously bought: 15.263175019579256%
# Share price: $0.9890220465048826
# Shares owned at the moment: 0
# Cash capital at the moment: $114.87661796266497
#
#
# Share price: $0.8377868221289516
# Shares owned at the moment: 136
# Cash capital at the moment: $0.6242778816513237
#
#
# Price increase from previously bought: 1.250756296554445%
# Share price: $0.8505982236657185
# Shares owned at the moment: 0
# Cash capital at the moment: $115.98751256453805
#
#
# Share price: $0.8264046470147189
# Shares owned at the moment: 139
# Cash capital at the moment: $0.8013734531707399
#
#
# Price increase from previously bought: -4.653553401959954%
# Share price: $0.7901143209795968
# Shares owned at the moment: 0
# Cash capital at the moment: $110.32524287014023
#
#
# Share price: $0.7650530525639275
# Shares owned at the moment: 143
# Cash capital at the moment: $0.621799240577829
#
#
# Price increase from previously bought: -6.974112141673605%
# Share price: $0.7136545625703429
# Shares owned at the moment: 0
# Cash capital at the moment: $102.39375703140607
#
#
# Share price: $0.7167170682314454
# Shares owned at the moment: 142
# Cash capital at the moment: $0.34005532739644195
#
#
# Price increase from previously bought: -9.329298873108272%
# Share price: $0.6516394849364239
# Shares owned at the moment: 0
# Cash capital at the moment: $92.61839696950095
#
#
# Share price: $0.6674112099607681
# Shares owned at the moment: 138
# Cash capital at the moment: $0.26236744073483464
#
#
# Price increase from previously bought: -11.188011476277527%
# Share price: $0.5943712054061847
# Shares owned at the moment: 0
# Cash capital at the moment: $82.06002991433668
#
#
# Share price: $0.6614393940160966
# Shares owned at the moment: 123
# Cash capital at the moment: $0.47925257533084675
#
#
# Price increase from previously bought: -0.8514105323424004%
# Share price: $0.6576113008810954
# Shares owned at the moment: 0
# Cash capital at the moment: $81.14300556118255
#
#
# Share price: $0.5839587484646389
# Shares owned at the moment: 138
# Cash capital at the moment: $0.33508592802004955
#
#
# Price increase from previously bought: 20.941919978876978%
# Share price: $0.7081931123140189
# Shares owned at the moment: 0
# Cash capital at the moment: $97.7969761412315
#
#
# Share price: $0.7046202409645685
# Shares owned at the moment: 138
# Cash capital at the moment: $0.2919795066749771
#
#
# Price increase from previously bought: -6.522939680541395%
# Share price: $0.6604695979606556
# Shares owned at the moment: 0
# Cash capital at the moment: $91.18613581281939
#
#
# Share price: $0.6372968305691057
# Shares owned at the moment: 142
# Cash capital at the moment: $0.44112145966913374
#
#
# Price increase from previously bought: 4.422147795770348%
# Share price: $0.6673091056699969
# Shares owned at the moment: 0
# Cash capital at the moment: $94.93843025904457
#
#
# Share price: $0.6672580924659882
# Shares owned at the moment: 141
# Cash capital at the moment: $0.5963098959865363
#
#
# Price increase from previously bought: -10.313252009714112%
# Share price: $0.6000877995653052
# Shares owned at the moment: 0
# Cash capital at the moment: $84.97600559041312
#
#
# Share price: $0.5460861563949568
# Shares owned at the moment: 155
# Cash capital at the moment: $0.09988212503147054
#
#
# Price increase from previously bought: -31.06185407644818%
# Share price: $0.37749694096012143
# Shares owned at the moment: 0
# Cash capital at the moment: $58.45099990276604
#
#
# Share price: $0.3213515749801029
# Shares owned at the moment: 181
# Cash capital at the moment: $0.12641208492106415
#
#
#
#
# Capital at the end of test period: $3.1383465775305064
# profit gained: -96.86165342246949%
#
#
# Capital at the end of test period if Buy and Hold: $2.3958591597330687
# profit gained: -97.60414084026694%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.270161      6.716418       5.357143      94.827586
# 1       0.273973      5.600000       5.128205      92.727273
# 2       0.242553      6.713781       8.888889      89.690722
# 3       0.219424      7.812500      14.285714      90.909091
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.283582           42.857143          89.473684     -34.564622
# 1         48.387097           48.717949          87.272727     183.405903
# 2         43.262411           45.555556          82.474227    7536.495677
# 3         42.408377           50.000000          81.818182     -96.861653
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
#
#
# bull phase data
#
#
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1795 - accuracy: 0.4567 - mse: 1.3199 - weighted_accuracy: 0.4567 - weighted_mse: 1.3199
# Test loss: 0.1794896423816681
# Test accuracy: 0.45673078298568726
#
#
# number of predictions: 208
# actual predicted buys: 6
# actual buys but predicted sell: 0
# actual buys but predicted hold: 3
# actual sells but predicted buy: 5
# actual predicted sells: 2
# actual sells but predicted hold: 3
# actual holds but predicted buy: 61
# actual holds but predicted sell: 41
# actual predicted holds: 87
# Percentage buys correct: 8.333333333333334%
# Percentage sells correct: 4.651162790697675%
# Percentage holds correct: 93.54838709677419%
# actual buys: 9
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 45.833333333333336%
# Percentage high sells correct: 44.18604651162791%
# Percentage mid holds correct: 89.1304347826087%
#
#
# Capital: 100
# Share price: $0.1503089080399258
# Shares owned at the moment: 663
# Cash capital at the moment: $0.07114325294539015
#
#
# Price increase from previously bought: -3.3187730096297607%
# Share price: $0.14572012793439182
# Shares owned at the moment: 0
# Cash capital at the moment: $96.41790385019078
#
#
# Share price: $0.06646855704303233
# Shares owned at the moment: 1446
# Cash capital at the moment: $0.0400581488844125
#
#
# Price increase from previously bought: 163.1140339123729%
# Share price: $0.175369043998997
# Shares owned at the moment: 0
# Cash capital at the moment: $252.92634076797208
#
#
# Share price: $0.43621703191873795
# Shares owned at the moment: 578
# Cash capital at the moment: $0.09952934670667446
#
#
# Price increase from previously bought: 18.982300675607156%
# Share price: $0.5204483684321803
# Shares owned at the moment: 0
# Cash capital at the moment: $300.09143361888397
#
#
# Share price: $0.7471507558725743
# Shares owned at the moment: 400
# Cash capital at the moment: $0.40926543839441365
#
#
# Price increase from previously bought: 6.0532733251570825%
# Share price: $0.7945568723180287
# Shares owned at the moment: 0
# Cash capital at the moment: $317.35800180605605
#
#
# Share price: $0.7828490672363122
# Shares owned at the moment: 404
# Cash capital at the moment: $0.2172333288863797
#
#
# Price increase from previously bought: -4.675284630573106%
# Share price: $0.7483008288892949
# Shares owned at the moment: 0
# Cash capital at the moment: $301.6994059792655
#
#
# Share price: $0.7437350727064593
# Shares owned at the moment: 404
# Cash capital at the moment: $0.40414694007910157
#
#
# Price increase from previously bought: 10.67625679899631%
# Share price: $0.8254017688549782
# Shares owned at the moment: 0
# Cash capital at the moment: $332.9494401922924
#
#
# Share price: $0.8327622642399453
# Shares owned at the moment: 398
# Cash capital at the moment: $0.5986007265835838
#
#
# Price increase from previously bought: 3.526951404630463%
# Share price: $0.864504251423482
# Shares owned at the moment: 0
# Cash capital at the moment: $343.7250928899464
#
#
# Share price: $0.7333959275173219
# Shares owned at the moment: 467
# Cash capital at the moment: $0.28733101944294503
#
#
# Price increase from previously bought: 16.89523602532821%
# Share price: $0.859662488947815
# Shares owned at the moment: 0
# Cash capital at the moment: $400.64569180664137
#
#
# Share price: $0.8428713105918748
# Shares owned at the moment: 474
# Cash capital at the moment: $0.0260078327361839
#
#
# Price increase from previously bought: 15.062536064933196%
# Share price: $0.9724961357715107
# Shares owned at the moment: 0
# Cash capital at the moment: $459.7215274754541
#
#
#
#
# Capital at the end of test period: $459.7215274754541
# profit gained: 359.7215274754541%
#
#
# Capital at the end of test period if Buy and Hold: $778.7940878989605
# profit gained: 678.7940878989605%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.270161      6.716418       5.357143      94.827586
# 1       0.273973      5.600000       5.128205      92.727273
# 2       0.242553      6.713781       8.888889      89.690722
# 3       0.219424      7.812500      14.285714      90.909091
# 4       0.456731      8.333333       4.651163      93.548387
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.283582           42.857143          89.473684     -34.564622
# 1         48.387097           48.717949          87.272727     183.405903
# 2         43.262411           45.555556          82.474227    7536.495677
# 3         42.408377           50.000000          81.818182     -96.861653
# 4         45.833333           44.186047          89.130435     359.721527
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
#
#
# bear phase data
# 19/19 [==============================] - 0s 4ms/step - loss: 0.2043 - accuracy: 0.2336 - mse: 1.4277 - weighted_accuracy: 0.2336 - weighted_mse: 1.4277
# Test loss: 0.20433367788791656
# Test accuracy: 0.23361344635486603
#
#
# number of predictions: 595
# actual predicted buys: 27
# actual buys but predicted sell: 2
# actual buys but predicted hold: 3
# actual sells but predicted buy: 9
# actual predicted sells: 8
# actual sells but predicted hold: 10
# actual holds but predicted buy: 324
# actual holds but predicted sell: 108
# actual predicted holds: 104
# Percentage buys correct: 7.5%
# Percentage sells correct: 6.779661016949152%
# Percentage holds correct: 88.88888888888889%
# actual buys: 32
# actual sells: 27
# actual holds: 536
#
#
# Percentage low buys correct: 47.63231197771588%
# Percentage high sells correct: 55.932203389830505%
# Percentage mid holds correct: 82.05128205128206%
#
#
# Capital: 100
# Share price: $0.7488095723945759
# Shares owned at the moment: 133
# Cash capital at the moment: $0.1344497704180867
#
#
# Price increase from previously bought: 20.557502806529683%
# Share price: $0.9052286730886053
# Shares owned at the moment: 0
# Cash capital at the moment: $120.19877590402044
#
#
# Share price: $0.9539252634566354
# Shares owned at the moment: 125
# Cash capital at the moment: $0.6302061626277862
#
#
# Price increase from previously bought: -11.175870948164967%
# Share price: $0.8496459255402239
# Shares owned at the moment: 0
# Cash capital at the moment: $106.54388106825131
#
#
# Share price: $0.884569638631081
# Shares owned at the moment: 120
# Cash capital at the moment: $0.103616451773334
#
#
# Price increase from previously bought: 9.485762254021779%
# Share price: $0.9711411255045729
# Shares owned at the moment: 0
# Cash capital at the moment: $116.32007494090557
#
#
# Share price: $0.9032612800251435
# Shares owned at the moment: 128
# Cash capital at the moment: $0.3846831271183504
#
#
# Price increase from previously bought: -33.34727683424017%
# Share price: $0.603703873099864
# Shares owned at the moment: 0
# Cash capital at the moment: $77.44627512056978
#
#
# Share price: $0.5653369875994193
# Shares owned at the moment: 136
# Cash capital at the moment: $0.34900877368656325
#
#
# Price increase from previously bought: 8.749679173898638%
# Share price: $0.6164928662064825
# Shares owned at the moment: 0
# Cash capital at the moment: $83.96147024580695
#
#
# Share price: $0.5707476468918803
# Shares owned at the moment: 146
# Cash capital at the moment: $0.40315861936532826
#
#
# Price increase from previously bought: -5.51694253158349%
# Share price: $0.5407427917373245
# Shares owned at the moment: 0
# Cash capital at the moment: $79.13449798213216
#
#
# Share price: $0.5068027751781982
# Shares owned at the moment: 155
# Cash capital at the moment: $0.3640431465917402
#
#
# Price increase from previously bought: 5.629956583727025%
# Share price: $0.5368077241521655
# Shares owned at the moment: 0
# Cash capital at the moment: $83.34042609775751
#
#
# Share price: $0.5033596027686108
# Shares owned at the moment: 165
# Cash capital at the moment: $0.057692221180474235
#
#
# Price increase from previously bought: -15.086982852955478%
# Share price: $0.4285932248311838
# Shares owned at the moment: 0
# Cash capital at the moment: $70.58110014255864
#
#
# Share price: $0.38432369104329556
# Shares owned at the moment: 183
# Cash capital at the moment: $0.05645378411801971
#
#
# Price increase from previously bought: 38.01651981747762%
# Share price: $0.5318888662158646
# Shares owned at the moment: 0
# Cash capital at the moment: $97.1244432296981
#
#
# Share price: $0.5402508965617531
# Shares owned at the moment: 179
# Cash capital at the moment: $0.15359424131177946
#
#
# Price increase from previously bought: -14.801868192465184%
# Share price: $0.4615494510391672
# Shares owned at the moment: 0
# Cash capital at the moment: $82.54374826004867
#
#
# Share price: $0.4394146372355171
# Shares owned at the moment: 187
# Cash capital at the moment: $0.14724211980860957
#
#
# Price increase from previously bought: 31.987916389952243%
# Share price: $0.5815691531156252
# Shares owned at the moment: 0
# Cash capital at the moment: $108.6016018154408
#
#
# Share price: $0.5717314372430228
# Shares owned at the moment: 189
# Cash capital at the moment: $0.24720276200243063
#
#
# Price increase from previously bought: -20.694196242831953%
# Share price: $0.4546631062199925
# Shares owned at the moment: 0
# Cash capital at the moment: $85.94221868812316
#
#
# Share price: $0.398096380681645
# Shares owned at the moment: 215
# Cash capital at the moment: $0.1161223564914593
#
#
# Price increase from previously bought: -10.501517098699631%
# Share price: $0.3572700193033441
# Shares owned at the moment: 0
# Cash capital at the moment: $76.71794060779735
#
#
# Share price: $0.3877668634528827
# Shares owned at the moment: 197
# Cash capital at the moment: $0.11779580930385691
#
#
# Price increase from previously bought: -2.171779154748177%
# Share price: $0.3803886234581365
# Shares owned at the moment: 0
# Cash capital at the moment: $74.8482790937983
#
#
# Share price: $0.35972949518120056
# Shares owned at the moment: 207
# Cash capital at the moment: $0.17949757615788542
#
#
# Price increase from previously bought: 20.180079691897944%
# Share price: $0.4335120827674851
# Shares owned at the moment: 0
# Cash capital at the moment: $89.6697219559119
#
#
# Share price: $0.36415645794192997
# Shares owned at the moment: 245
# Cash capital at the moment: $0.2060393466006758
#
#
# Price increase from previously bought: 1.8810232868889498%
# Share price: $0.37202659311224806
# Shares owned at the moment: 0
# Cash capital at the moment: $91.10190174199208
#
#
# Share price: $0.3459567117234391
# Shares owned at the moment: 262
# Cash capital at the moment: $0.2119814596542966
#
#
# Price increase from previously bought: 1.2854621292267998%
# Share price: $0.35136746483531167
# Shares owned at the moment: 0
# Cash capital at the moment: $92.0170969880921
#
#
# Share price: $0.3621888772396452
# Shares owned at the moment: 253
# Cash capital at the moment: $0.13131813512238466
#
#
# Price increase from previously bought: -0.9514166207644004%
# Share price: $0.35972949518120056
# Shares owned at the moment: 0
# Cash capital at the moment: $90.89259861969381
#
#
# Share price: $0.31939502897847094
# Shares owned at the moment: 283
# Cash capital at the moment: $0.25523623748404134
#
#
# Price increase from previously bought: 0.8008271550863144%
# Share price: $0.3228382013880583
# Shares owned at the moment: 0
# Cash capital at the moment: $91.36719840007429
#
#
# Share price: $0.31791934345175676
# Shares owned at the moment: 286
# Cash capital at the moment: $0.1922226092470396
#
#
# Price increase from previously bought: -1.3543089669687758%
# Share price: $0.3144761710421694
# Shares owned at the moment: 0
# Cash capital at the moment: $89.88507201878282
#
#
# Share price: $0.2957845296481071
# Shares owned at the moment: 303
# Cash capital at the moment: $0.01589707607708135
#
#
# Price increase from previously bought: 17.968379255839718%
# Share price: $0.34989177930859794
# Shares owned at the moment: 0
# Cash capital at the moment: $105.74155888147337
#
#
# Share price: $0.3361190896702483
# Shares owned at the moment: 313
# Cash capital at the moment: $0.24696930825199104
#
#
# Price increase from previously bought: -4.068710410808551%
# Share price: $0.3233300965636293
# Shares owned at the moment: 0
# Cash capital at the moment: $101.17098315205081
#
#
# Share price: $0.3493998841330267
# Shares owned at the moment: 288
# Cash capital at the moment: $0.2670918135057576
#
#
# Price increase from previously bought: 14.888257899247348%
# Share price: $0.40252334344237484
# Shares owned at the moment: 0
# Cash capital at the moment: $115.87501623690335
#
#
# Share price: $0.31595176274947157
# Shares owned at the moment: 365
# Cash capital at the moment: $0.2354862514864493
#
#
# Price increase from previously bought: -24.494216852006858%
# Share price: $0.23921789792917092
# Shares owned at the moment: 0
# Cash capital at the moment: $87.30990403058743
#
#
# Share price: $0.3154599613933119
# Shares owned at the moment: 276
# Cash capital at the moment: $0.0035205753358127367
#
#
# Price increase from previously bought: -55.47616788339174%
# Share price: $0.14084111448079162
# Shares owned at the moment: 0
# Cash capital at the moment: $38.76876976614338
#
#
# Share price: $0.09460399999061807
# Shares owned at the moment: 408
# Cash capital at the moment: $0.0641920819817301
#
#
# Price increase from previously bought: -30.866478444152566%
# Share price: $0.06558293518720491
# Shares owned at the moment: 0
# Cash capital at the moment: $26.748445585081292
#
#
# Share price: $0.05869649654861841
# Shares owned at the moment: 454
# Cash capital at the moment: $0.02695357606758364
#
#
# Price increase from previously bought: -61.28134287219096%
# Share price: $0.022788993106618742
# Shares owned at the moment: 0
# Cash capital at the moment: $10.34470438857888
#
#
# Share price: $0.05279394208058618
# Shares owned at the moment: 195
# Cash capital at the moment: $0.021574931423858246
#
#
# Price increase from previously bought: 124.23187680538148%
# Share price: $0.11870639449655328
# Shares owned at the moment: 0
# Cash capital at the moment: $23.10566555420297
#
#
# Share price: $0.10591740138993443
# Shares owned at the moment: 217
# Cash capital at the moment: $0.0583832433077589
#
#
#
#
# Capital at the end of test period: $13.079839004001402
# profit gained: -86.9201609959986%
#
#
# Capital at the end of test period if Buy and Hold: $8.115342010843221
# profit gained: -91.88465798915678%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.270161      6.716418       5.357143      94.827586
# 1       0.273973      5.600000       5.128205      92.727273
# 2       0.242553      6.713781       8.888889      89.690722
# 3       0.219424      7.812500      14.285714      90.909091
# 4       0.456731      8.333333       4.651163      93.548387
# 5       0.233613      7.500000       6.779661      88.888889
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         43.283582           42.857143          89.473684     -34.564622
# 1         48.387097           48.717949          87.272727     183.405903
# 2         43.262411           45.555556          82.474227    7536.495677
# 3         42.408377           50.000000          81.818182     -96.861653
# 4         45.833333           44.186047          89.130435     359.721527
# 5         47.632312           55.932203          82.051282     -86.920161
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
# 5         -91.884658
#
#
# full cycle data
# 29/29 [==============================] - 0s 4ms/step - loss: 0.2113 - accuracy: 0.2279 - mse: 1.4545 - weighted_accuracy: 0.2279 - weighted_mse: 1.4545
# Test loss: 0.21128641068935394
# Test accuracy: 0.2279171198606491
#
#
# number of predictions: 917
# actual predicted buys: 38
# actual buys but predicted sell: 2
# actual buys but predicted hold: 6
# actual sells but predicted buy: 15
# actual predicted sells: 16
# actual sells but predicted hold: 9
# actual holds but predicted buy: 541
# actual holds but predicted sell: 135
# actual predicted holds: 155
# Percentage buys correct: 6.397306397306397%
# Percentage sells correct: 10.457516339869281%
# Percentage holds correct: 91.17647058823529%
# actual buys: 46
# actual sells: 40
# actual holds: 831
#
#
# Percentage low buys correct: 44.68802698145025%
# Percentage high sells correct: 52.94117647058823%
# Percentage mid holds correct: 85.88235294117646%
#
#
# Capital: 100
# Share price: $0.3088084010225731
# Shares owned at the moment: 322
# Cash capital at the moment: $0.2902450316259575
#
#
# Price increase from previously bought: 9.493791236351989%
# Share price: $0.33905587250729685
# Shares owned at the moment: 0
# Cash capital at the moment: $109.16600200387033
#
#
# Share price: $0.32255730732381205
# Shares owned at the moment: 337
# Cash capital at the moment: $0.1652594511833172
#
#
# Price increase from previously bought: 25.230324197760613%
# Share price: $0.40505039547981114
# Shares owned at the moment: 0
# Cash capital at the moment: $136.29186227386876
#
#
# Share price: $0.33538951497620473
# Shares owned at the moment: 405
# Cash capital at the moment: $0.08556863620108857
#
#
# Price increase from previously bought: -61.3235977950342%
# Share price: $0.130073318409336
# Shares owned at the moment: 0
# Cash capital at the moment: $52.62039343360377
#
#
# Share price: $0.131906497174882
# Shares owned at the moment: 397
# Cash capital at the moment: $0.10950513688493402
#
#
# Price increase from previously bought: 130.69766137185604%
# Share price: $0.3051420434914811
# Shares owned at the moment: 0
# Cash capital at the moment: $120.9177575770211
#
#
# Share price: $0.36288724016582397
# Shares owned at the moment: 332
# Cash capital at the moment: $0.10787779169615419
#
#
# Price increase from previously bought: -5.815831805366411%
# Share price: $0.34272223003838886
# Shares owned at the moment: 0
# Cash capital at the moment: $113.5787527684162
#
#
# Share price: $0.3243904423829288
# Shares owned at the moment: 349
# Cash capital at the moment: $0.05515464969703032
#
#
# Price increase from previously bought: 40.584258150300045%
# Share price: $0.45729601215108695
# Shares owned at the moment: 0
# Cash capital at the moment: $159.21257304276435
#
#
# Share price: $0.4829606022815893
# Shares owned at the moment: 328
# Cash capital at the moment: $0.36586503114503444
#
#
# Price increase from previously bought: -7.087806041051636%
# Share price: $0.4499632970889027
# Shares owned at the moment: 0
# Cash capital at the moment: $147.54795958233092
#
#
# Share price: $0.4352978669645349
# Shares owned at the moment: 338
# Cash capital at the moment: $0.012671180974592744
#
#
# Price increase from previously bought: -0.27424582398404285%
# Share price: $0.4352978669645349
# Shares owned at the moment: 0
# Cash capital at the moment: $146.73874084764384
#
#
# Share price: $0.4563794883279577
# Shares owned at the moment: 320
# Cash capital at the moment: $0.295690632968757
#
#
# Price increase from previously bought: 2.930370327426468%
# Share price: $0.47104491845232555
# Shares owned at the moment: 0
# Cash capital at the moment: $150.61554500947489
#
#
# Share price: $0.4857103485766936
# Shares owned at the moment: 309
# Cash capital at the moment: $0.1183149305735185
#
#
# Price increase from previously bought: 5.747948612490128%
# Share price: $0.5150412088254293
# Shares owned at the moment: 0
# Cash capital at the moment: $158.82839219043177
#
#
# Share price: $0.5443721564870241
# Shares owned at the moment: 290
# Cash capital at the moment: $0.5263300143963932
#
#
# Price increase from previously bought: 15.677571960683823%
# Share price: $0.6314482134101027
# Shares owned at the moment: 0
# Cash capital at the moment: $183.1427319531316
#
#
# Share price: $0.6543629698326423
# Shares owned at the moment: 279
# Cash capital at the moment: $0.07340338122031653
#
#
# Price increase from previously bought: 27.943031979769152%
# Share price: $0.8395141562720758
# Shares owned at the moment: 0
# Cash capital at the moment: $233.65373574472972
#
#
# Share price: $0.9082584255396946
# Shares owned at the moment: 256
# Cash capital at the moment: $0.500164874987945
#
#
# Price increase from previously bought: 10.89686468686011%
# Share price: $1.01
# Shares owned at the moment: 0
# Cash capital at the moment: $258.3491248749879
#
#
# Share price: $0.9137579181299034
# Shares owned at the moment: 281
# Cash capital at the moment: $0.8770434492501522
#
#
# Price increase from previously bought: -27.983899879916883%
# Share price: $0.6598624624228513
# Shares owned at the moment: 0
# Cash capital at the moment: $185.7884866722341
#
#
# Share price: $0.6717781462521146
# Shares owned at the moment: 275
# Cash capital at the moment: $0.5414642297994021
#
#
# Price increase from previously bought: 2.9913882717983453%
# Share price: $0.6937762914386667
# Shares owned at the moment: 0
# Cash capital at the moment: $190.80527605503224
#
#
# Share price: $0.645197032298483
# Shares owned at the moment: 294
# Cash capital at the moment: $0.5957067586649032
#
#
# Price increase from previously bought: 36.13597194968652%
# Share price: $0.8807607003500755
# Shares owned at the moment: 0
# Cash capital at the moment: $258.82725763535404
#
#
# Share price: $0.8074335497282359
# Shares owned at the moment: 319
# ...
# actual buys: 9
# actual sells: 10
# actual holds: 189
#
#
# Percentage low buys correct: 36.36363636363637%
# Percentage high sells correct: 47.36842105263158%
# Percentage mid holds correct: 83.61581920903954%
#
#
# Capital: 100
# Share price: $0.14225839692288078
# Shares owned at the moment: 701
# Cash capital at the moment: $0.0026251323924810777
#
#
# Price increase from previously bought: 22.936927100392523%
# Share price: $0.175369043998997
# Shares owned at the moment: 0
# Cash capital at the moment: $122.5982573011203
#
#
# Share price: $0.2760119449234075
# Shares owned at the moment: 442
# Cash capital at the moment: $0.2654851259197528
#
#
# Price increase from previously bought: 10.097426019540844%
# Share price: $0.30471772249602913
# Shares owned at the moment: 0
# Cash capital at the moment: $134.5803340774707
#
#
# Share price: $0.43621703191873795
# Shares owned at the moment: 307
# Cash capital at the moment: $0.2934290492207481
#
#
# Price increase from previously bought: 10.111249645086207%
# Share price: $0.48164491607920557
# Shares owned at the moment: 0
# Cash capital at the moment: $147.751789565137
#
#
# Share price: $0.4790917876756311
# Shares owned at the moment: 307
# Cash capital at the moment: $0.2661375069730809
#
#
# Price increase from previously bought: 67.50310020031871%
# Share price: $0.8047004545540055
# Shares owned at the moment: 0
# Cash capital at the moment: $246.62980869629556
#
#
# Share price: $0.8139010386877712
# Shares owned at the moment: 302
# Cash capital at the moment: $0.1557501999584474
#
#
# Price increase from previously bought: 9.37851870711761%
# Share price: $0.8926810403331393
# Shares owned at the moment: 0
# Cash capital at the moment: $269.00405277656984
#
#
#
#
# Capital at the end of test period: $269.00405277656984
# profit gained: 169.00405277656984%
#
#
# Capital at the end of test period if Buy and Hold: $778.7940878989605
# profit gained: 678.7940878989605%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.798387     14.285714       4.000000      93.301435
# 1       0.826484      0.000000      12.500000      92.746114
# 2       0.810638     11.428571      15.384615      91.198044
# 3       0.762590      7.407407       5.263158      90.086207
# 4       0.774038      9.090909       0.000000      89.887640
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         35.714286           44.000000          84.134615     -68.182879
# 1         20.000000           56.250000          86.458333      27.955098
# 2         68.571429           57.692308          85.539216     -58.010210
# 3         40.740741           36.842105          83.549784     -53.462933
# 4         36.363636           47.368421          83.615819     169.004053
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
#
#
# bear phase data
#
#
# 19/19 [==============================] - 0s 3ms/step - loss: 0.2464 - accuracy: 0.8067 - mse: 12.4525 - weighted_accuracy: 0.8067 - weighted_mse: 12.4525
# Test loss: 0.24637377262115479
# Test accuracy: 0.8067227005958557
#
#
# number of predictions: 595
# actual predicted buys: 3
# actual buys but predicted sell: 1
# actual buys but predicted hold: 28
# actual sells but predicted buy: 0
# actual predicted sells: 3
# actual sells but predicted hold: 24
# actual holds but predicted buy: 33
# actual holds but predicted sell: 29
# actual predicted holds: 474
# Percentage buys correct: 8.333333333333334%
# Percentage sells correct: 9.090909090909092%
# Percentage holds correct: 90.11406844106465%
# actual buys: 32
# actual sells: 27
# actual holds: 536
#
#
# Percentage low buys correct: 47.22222222222222%
# Percentage high sells correct: 57.57575757575758%
# Percentage mid holds correct: 83.04761904761905%
#
#
# Capital: 100
# Share price: $0.7488095723945759
# Shares owned at the moment: 133
# Cash capital at the moment: $0.1344497704180867
#
#
# Price increase from previously bought: 34.51084952837831%
# Share price: $1.0099999999999998
# Shares owned at the moment: 0
# Cash capital at the moment: $134.09504227041808
#
#
# Share price: $0.9229365241315254
# Shares owned at the moment: 144
# Cash capital at the moment: $0.8266999319223487
#
#
# Price increase from previously bought: -21.427692567521383%
# Share price: $0.7271667475859093
# Shares owned at the moment: 0
# Cash capital at the moment: $105.25075355224926
#
#
# Share price: $0.884569638631081
# Shares owned at the moment: 118
# Cash capital at the moment: $0.5844933460459174
#
#
# Price increase from previously bought: 7.877593648364112%
# Share price: $0.9568766345100633
# Shares owned at the moment: 0
# Cash capital at the moment: $113.18542975033488
#
#
# Share price: $0.7891442262361298
# Shares owned at the moment: 143
# Cash capital at the moment: $0.027474431600964522
#
#
# Price increase from previously bought: -18.798044161094563%
# Share price: $0.6425627475952914
# Shares owned at the moment: 0
# Cash capital at the moment: $91.66125953723578
#
#
# Share price: $0.5068027751781982
# Shares owned at the moment: 180
# Cash capital at the moment: $0.1858926314469045
#
#
# Price increase from previously bought: -16.14781739209524%
# Share price: $0.4261338427727387
# Shares owned at the moment: 0
# Cash capital at the moment: $76.67904807836737
#
#
# Share price: $0.4231824717193112
# Shares owned at the moment: 180
# Cash capital at the moment: $0.2967278453902793
#
#
# Price increase from previously bought: 30.907085050366966%
# Share price: $0.5554992717268165
# Shares owned at the moment: 0
# Cash capital at the moment: $100.01162461671245
#
#
# Share price: $0.5215592551676905
# Shares owned at the moment: 191
# Cash capital at the moment: $0.11985788090673566
#
#
# Price increase from previously bought: -23.88120543378146%
# Share price: $0.398096380681645
# Shares owned at the moment: 0
# Cash capital at the moment: $75.9471664671479
#
#
# Share price: $0.3754697655218352
# Shares owned at the moment: 201
# Cash capital at the moment: $0.27020268436682215
#
#
# Price increase from previously bought: 14.358078847659206%
# Share price: $0.430560805533469
# Shares owned at the moment: 0
# Cash capital at the moment: $86.57493211133546
#
#
# Share price: $0.43006891035789774
# Shares owned at the moment: 200
# Cash capital at the moment: $0.32461213905907016
#
#
# Price increase from previously bought: -14.759822231459252%
# Share price: $0.367599630351518
# Shares owned at the moment: 0
# Cash capital at the moment: $73.64235841266932
#
#
# Share price: $0.36464835311750166
# Shares owned at the moment: 201
# Cash capital at the moment: $0.14648005886579085
#
#
# Price increase from previously bought: -4.175417521663938%
# Share price: $0.3503836744841692
# Shares owned at the moment: 0
# Cash capital at the moment: $70.37992405411266
#
#
# Share price: $0.3361190896702483
# Shares owned at the moment: 208
# Cash capital at the moment: $0.27489328340962516
#
#
# Price increase from previously bought: -4.068710410808551%
# Share price: $0.3233300965636293
# Shares owned at the moment: 0
# Cash capital at the moment: $67.34260855341012
#
#
# Share price: $0.3154599613933119
# Shares owned at the moment: 212
# Cash capital at the moment: $0.28118358053569636
#
#
# Price increase from previously bought: -53.29917120911756%
# Share price: $0.14772755311937813
# Shares owned at the moment: 0
# Cash capital at the moment: $31.51329967837526
#
#
# Share price: $0.05918839172418965
# Shares owned at the moment: 530
# Cash capital at the moment: $0.057184983616739515
#
#
# Price increase from previously bought: -1.1030336306873334%
# Share price: $0.05869649654861841
# Shares owned at the moment: 0
# Cash capital at the moment: $31.080778010664883
#
#
# Share price: $0.10591740138993443
# Shares owned at the moment: 292
# Cash capital at the moment: $0.06784513148791049
#
#
#
#
# Capital at the end of test period: $17.589804035278434
# profit gained: -82.41019596472157%
#
#
# Capital at the end of test period if Buy and Hold: $8.115342010843221
# profit gained: -91.88465798915678%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.798387     14.285714       4.000000      93.301435
# 1       0.826484      0.000000      12.500000      92.746114
# 2       0.810638     11.428571      15.384615      91.198044
# 3       0.762590      7.407407       5.263158      90.086207
# 4       0.774038      9.090909       0.000000      89.887640
# 5       0.806723      8.333333       9.090909      90.114068
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         35.714286           44.000000          84.134615     -68.182879
# 1         20.000000           56.250000          86.458333      27.955098
# 2         68.571429           57.692308          85.539216     -58.010210
# 3         40.740741           36.842105          83.549784     -53.462933
# 4         36.363636           47.368421          83.615819     169.004053
# 5         47.222222           57.575758          83.047619     -82.410196
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
# 5         -91.884658
#
#
# full cycle data
#
#
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2059 - accuracy: 0.8037 - mse: 10.8477 - weighted_accuracy: 0.8037 - weighted_mse: 10.8477
# Test loss: 0.20588596165180206
# Test accuracy: 0.8037077188491821
#
#
# number of predictions: 917
# actual predicted buys: 4
# actual buys but predicted sell: 1
# actual buys but predicted hold: 41
# actual sells but predicted buy: 1
# actual predicted sells: 7
# actual sells but predicted hold: 32
# actual holds but predicted buy: 67
# actual holds but predicted sell: 38
# actual predicted holds: 726
# Percentage buys correct: 5.555555555555555%
# Percentage sells correct: 15.217391304347826%
# Percentage holds correct: 90.86357947434293%
# actual buys: 46
# actual sells: 40
# actual holds: 831
#
#
# Percentage low buys correct: 45.833333333333336%
# Percentage high sells correct: 67.3913043478261%
# Percentage mid holds correct: 84.3358395989975%
#
#
# Capital: 100
# Share price: $0.348221810041456
# Shares owned at the moment: 286
# Cash capital at the moment: $0.1346858745459656
#
#
# Price increase from previously bought: 10.750687369613864%
# Share price: $0.3867186078243512
# Shares owned at the moment: 0
# Cash capital at the moment: $110.43205352725654
#
#
# Share price: $0.31064162349454827
# Shares owned at the moment: 354
# Cash capital at the moment: $0.16250918971451256
#
#
# Price increase from previously bought: 12.967195129935583%
# Share price: $0.3518881675725478
# Shares owned at the moment: 0
# Cash capital at the moment: $124.38835737926456
#
#
# Share price: $0.34913842127744366
# Shares owned at the moment: 355
# Cash capital at the moment: $0.10337144199996828
#
#
# Price increase from previously bought: 30.619224107713517%
# Share price: $0.45729601215108695
# Shares owned at the moment: 0
# Cash capital at the moment: $161.99702052377333
#
#
# Share price: $0.4068836179517865
# Shares owned at the moment: 397
# Cash capital at the moment: $0.02000900701520436
#
#
# Price increase from previously bought: 31.62647066167077%
# Share price: $0.5370393540119816
# Shares owned at the moment: 0
# Cash capital at the moment: $212.6383198350293
#
#
# Share price: $0.49762603240595715
# Shares owned at the moment: 426
# Cash capital at the moment: $0.06666113312797961
#
#
# Price increase from previously bought: 14.420753308796485%
# Share price: $0.5709532704406557
# Shares owned at the moment: 0
# Cash capital at the moment: $242.62388258452606
#
#
# Share price: $0.7753528557715368
# Shares owned at the moment: 312
# Cash capital at the moment: $0.04853883355457356
#
#
# Price increase from previously bought: -17.722209807985756%
# Share price: $0.6396975397082745
# Shares owned at the moment: 0
# Cash capital at the moment: $199.0853107334665
#
#
# Share price: $0.8550961976324316
# Shares owned at the moment: 232
# Cash capital at the moment: $0.15744150865290862
#
#
# Price increase from previously bought: 2.2912919778170338%
# Share price: $0.8770943428189835
# Shares owned at the moment: 0
# Cash capital at the moment: $203.08374285193858
#
#
# Share price: $0.813849653554432
# Shares owned at the moment: 248
# Cash capital at the moment: $0.6939833067153245
#
#
# Price increase from previously bought: -8.248622663466564%
# Share price: $0.7487717418179052
# Shares owned at the moment: 0
# Cash capital at the moment: $185.878712949636
#
#
# Share price: $0.7075251977399057
# Shares owned at the moment: 261
# Cash capital at the moment: $0.7068101288427897
#
#
# Price increase from previously bought: 5.281066176631843%
# Share price: $0.7469385193459299
# Shares owned at the moment: 0
# Cash capital at the moment: $195.12164855586994
#
#
# Share price: $0.7341063116935371
# Shares owned at the moment: 265
# Cash capital at the moment: $0.0484959824359521
#
#
# Price increase from previously bought: 1.967037961279594%
# Share price: $0.7506049642898804
# Shares owned at the moment: 0
# Cash capital at the moment: $198.411808151528
#
#
# Share price: $0.767103529473365
# Shares owned at the moment: 257
# Cash capital at the moment: $0.7240506574178767
#
#
# Price increase from previously bought: -16.241617431471667%
# Share price: $0.6442804210624953
# Shares owned at the moment: 0
# Cash capital at the moment: $165.84877368289324
#
#
# Share price: $0.6433638972393665
# Shares owned at the moment: 257
# Cash capital at the moment: $0.049554658002108454
#
#
# Price increase from previously bought: -24.853692780147142%
# Share price: $0.48479373734070585
# Shares owned at the moment: 0
# Cash capital at the moment: $124.29891718069797
#
#
# Share price: $0.3931347116505476
# Shares owned at the moment: 315
# Cash capital at the moment: $0.12093006680818519
#
#
# Price increase from previously bought: -13.062286665124212%
# Share price: $0.34272223003838886
# Shares owned at the moment: 0
# Cash capital at the moment: $107.78154939712992
#
#
# Share price: $0.2308982816336539
# Shares owned at the moment: 465
# Cash capital at the moment: $0.11858725984183138
#
#
# Price increase from previously bought: 6.455690905163292%
# Share price: $0.24648032299400946
# Shares owned at the moment: 0
# Cash capital at the moment: $114.41675073902763
#
#
# Share price: $0.19148487261477076
# Shares owned at the moment: 595
# Cash capital at the moment: $0.1699344104231102
#
#
# Price increase from previously bought: -27.483903759065775%
# Share price: $0.13923921223706592
# Shares owned at the moment: 0
# Cash capital at the moment: $82.78943553045443
#
#
# Share price: $0.031998145186551856
# Shares owned at the moment: 2580
# Cash capital at the moment: $0.00719410905205109
#
#
# Price increase from previously bought: 31.148994979527856%
# Share price: $0.04208065025026963
# Shares owned at the moment: 0
# Cash capital at the moment: $108.27670954122202
#
#
#
#
# Capital at the end of test period: $108.27670954122202
# profit gained: 8.276709541222019%
#
#
# Capital at the end of test period if Buy and Hold: $3.993306781778525
# profit gained: -96.00669321822147%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.798387     14.285714       4.000000      93.301435
# 1       0.826484      0.000000      12.500000      92.746114
# 2       0.810638     11.428571      15.384615      91.198044
# 3       0.762590      7.407407       5.263158      90.086207
# 4       0.774038      9.090909       0.000000      89.887640
# 5       0.806723      8.333333       9.090909      90.114068
# 6       0.803708      5.555556      15.217391      90.863579
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         35.714286           44.000000          84.134615     -68.182879
# 1         20.000000           56.250000          86.458333      27.955098
# 2         68.571429           57.692308          85.539216     -58.010210
# 3         40.740741           36.842105          83.549784     -53.462933
# 4         36.363636           47.368421          83.615819     169.004053
# 5         47.222222           57.575758          83.047619     -82.410196
# 6         45.833333           67.391304          84.335840       8.276710
#
#    buy_n_hold profit
# 0          82.557937
# 1         255.731682
# 2         -35.065241
# 3         -97.604141
# 4         678.794088
# 5         -91.884658
# 6         -96.006693

# %%
df = log_hist['0_epochs_logs']
df['Profit gained']
# Out:
# 0     -34.564622
# 1     183.405903
# 2    7536.495677
# 3     -96.861653
# 4     359.721527
# 5     -86.920161
# 6     -45.596774
# Name: Profit gained, dtype: float64

# %%
accumulation_phase_data_acc = []
mark_up_phase_data_acc = []
distribution_phase_data_acc = []
mark_down_phase_data_acc = []
bull_phase_data_acc = []
bear_phase_data_acc = []
full_cycle_data_acc = []

accumulation_phase_data_correct_buys = []
mark_up_phase_data_correct_buys = []
distribution_phase_data_correct_buys = []
mark_down_phase_data_correct_buys = []
bull_phase_data_correct_buys = []
bear_phase_data_correct_buys = []
full_cycle_data_correct_buys = []

accumulation_phase_data_correct_sells = []
mark_up_phase_data_correct_sells = []
distribution_phase_data_correct_sells = []
mark_down_phase_data_correct_sells = []
bull_phase_data_correct_sells = []
bear_phase_data_correct_sells = []
full_cycle_data_correct_sells = []

accumulation_phase_data_correct_holds = []
mark_up_phase_data_correct_holds = []
distribution_phase_data_correct_holds = []
mark_down_phase_data_correct_holds = []
bull_phase_data_correct_holds = []
bear_phase_data_correct_holds = []
full_cycle_data_correct_holds = []

accumulation_phase_data_correct_low_buys = []
mark_up_phase_data_correct_low_buys = []
distribution_phase_data_correct_low_buys = []
mark_down_phase_data_correct_low_buys = []
bull_phase_data_correct_low_buys = []
bear_phase_data_correct_low_buys = []
full_cycle_data_correct_low_buys = []

accumulation_phase_data_correct_high_sells = []
mark_up_phase_data_correct_high_sells = []
distribution_phase_data_correct_high_sells = []
mark_down_phase_data_correct_high_sells = []
bull_phase_data_correct_high_sells = []
bear_phase_data_correct_high_sells = []
full_cycle_data_correct_high_sells = []

accumulation_phase_data_correct_mid_holds = []
mark_up_phase_data_correct_mid_holds = []
distribution_phase_data_correct_mid_holds = []
mark_down_phase_data_correct_mid_holds = []
bull_phase_data_correct_mid_holds = []
bear_phase_data_correct_mid_holds = []
full_cycle_data_correct_mid_holds = []

accumulation_phase_data_profit = []
mark_up_phase_data_profit = []
distribution_phase_data_profit = []
mark_down_phase_data_profit = []
bull_phase_data_profit = []
bear_phase_data_profit = []
full_cycle_data_profit = []

for key,value in log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    accumulation_phase_data_acc.append(acc[0])
    mark_up_phase_data_acc.append(acc[1])
    distribution_phase_data_acc.append(acc[2])
    mark_down_phase_data_acc.append(acc[3]) 
    bull_phase_data_acc.append(acc[4]) 
    bear_phase_data_acc.append(acc[5]) 
    full_cycle_data_acc.append(acc[6]) 

    accumulation_phase_data_correct_buys.append(correct_buys[0])
    mark_up_phase_data_correct_buys.append(correct_buys[1]) 
    distribution_phase_data_correct_buys.append(correct_buys[2]) 
    mark_down_phase_data_correct_buys.append(correct_buys[3]) 
    bull_phase_data_correct_buys.append(correct_buys[4])
    bear_phase_data_correct_buys.append(correct_buys[5]) 
    full_cycle_data_correct_buys.append(correct_buys[6]) 

    accumulation_phase_data_correct_sells.append(correct_sells[0]) 
    mark_up_phase_data_correct_sells.append(correct_sells[1]) 
    distribution_phase_data_correct_sells.append(correct_sells[2]) 
    mark_down_phase_data_correct_sells.append(correct_sells[3]) 
    bull_phase_data_correct_sells.append(correct_sells[4]) 
    bear_phase_data_correct_sells.append(correct_sells[5]) 
    full_cycle_data_correct_sells.append(correct_sells[6])

    accumulation_phase_data_correct_holds.append(correct_holds[0]) 
    mark_up_phase_data_correct_holds.append(correct_holds[1])  
    distribution_phase_data_correct_holds.append(correct_holds[2])  
    mark_down_phase_data_correct_holds.append(correct_holds[3])  
    bull_phase_data_correct_holds.append(correct_holds[4])  
    bear_phase_data_correct_holds.append(correct_holds[5])  
    full_cycle_data_correct_holds.append(correct_holds[6])  

    accumulation_phase_data_correct_low_buys.append(correct_low_buys[0])  
    mark_up_phase_data_correct_low_buys.append(correct_low_buys[1])  
    distribution_phase_data_correct_low_buys.append(correct_low_buys[2])  
    mark_down_phase_data_correct_low_buys.append(correct_low_buys[3])   
    bull_phase_data_correct_low_buys.append(correct_low_buys[4])   
    bear_phase_data_correct_low_buys.append(correct_low_buys[5])  
    full_cycle_data_correct_low_buys.append(correct_low_buys[6])  

    accumulation_phase_data_correct_high_sells.append(correct_high_sells[0]) 
    mark_up_phase_data_correct_high_sells.append(correct_high_sells[1]) 
    distribution_phase_data_correct_high_sells.append(correct_high_sells[2]) 
    mark_down_phase_data_correct_high_sells.append(correct_high_sells[3]) 
    bull_phase_data_correct_high_sells.append(correct_high_sells[4]) 
    bear_phase_data_correct_high_sells.append(correct_high_sells[5]) 
    full_cycle_data_correct_high_sells.append(correct_high_sells[6]) 

    accumulation_phase_data_correct_mid_holds.append(correct_mid_holds[0])  
    mark_up_phase_data_correct_mid_holds.append(correct_mid_holds[1])  
    distribution_phase_data_correct_mid_holds.append(correct_mid_holds[2])   
    mark_down_phase_data_correct_mid_holds.append(correct_mid_holds[3])   
    bull_phase_data_correct_mid_holds.append(correct_mid_holds[4])   
    bear_phase_data_correct_mid_holds.append(correct_mid_holds[5])   
    full_cycle_data_correct_mid_holds.append(correct_mid_holds[6])   

    accumulation_phase_data_profit.append(profit[0]) 
    mark_up_phase_data_profit.append(profit[1]) 
    distribution_phase_data_profit.append(profit[2]) 
    mark_down_phase_data_profit.append(profit[3])  
    bull_phase_data_profit.append(profit[4])  
    bear_phase_data_profit.append(profit[5])  
    full_cycle_data_profit.append(profit[6])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(accumulation_phase_data_acc)
plt.plot(mark_up_phase_data_acc)
plt.plot(distribution_phase_data_acc)
plt.plot(mark_down_phase_data_acc)
plt.plot(bull_phase_data_acc)
plt.plot(bear_phase_data_acc)
plt.plot(full_cycle_data_acc)
plt.title('Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['accumulation_phase_data_acc','mark_up_phase_data_acc','distribution_phase_data_acc','mark_down_phase_data_acc','bull_phase_data_acc','bear_phase_data_acc','full_cycle_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct buys")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_buys")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_buys")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_buys")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_buys")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct sells")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_sells")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_sells")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_sells")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_sells")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct holds")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_holds")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_holds")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_holds")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_holds")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct low buys")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_low_buys")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_low_buys")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_low_buys")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_low_buys")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct high sells")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_high_sells")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_high_sells")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_high_sells")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_high_sells")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_correct_mid_holds")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_correct_mid_holds")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_correct_mid_holds")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_correct_mid_holds")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Profit")

plt.subplot(3, 4, 1)
plt.plot(accumulation_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("accumulation_phase_data_profit")

plt.subplot(3, 4, 2)
plt.plot(mark_up_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_up_phase_data_profit")

plt.subplot(3, 4, 3)
plt.plot(distribution_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("distribution_phase_data_profit")

plt.subplot(3, 4, 4)
plt.plot(mark_down_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("mark_down_phase_data_profit")

plt.subplot(3, 4, 5)
plt.plot(bull_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bull_phase_data_profit")

plt.subplot(3, 4, 6)
plt.plot(bear_phase_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("bear_phase_data_profit")

plt.subplot(3, 4, 7)
plt.plot(full_cycle_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("full_cycle_data_profit")
# Out:
# Text(0.5, 1.0, 'full_cycle_data_profit')
