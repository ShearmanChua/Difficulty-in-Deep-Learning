# %%
import os
seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
experiment = 'Variation 7 Experiments results - HA'

# %%
import requests
import lxml
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.utils import compute_class_weight
import tensorflow as tf
from pil import Image
from sklearn import preprocessing
import tensorflow_addons as tfa

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
# gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
np.random.seed(seed)
tf.random.set_seed(seed)

session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, 
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), 
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)

# %% [markdown]
# ## Hawaiian Holdings, Inc.  (Small Cap)

# %% [markdown]
# ### Test Performance

# %% [markdown]
# ### non-recession

# %%
column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
log  = pd.DataFrame(columns = column_names)
logger = []

# %%
seed = 10
df = pd.read_csv("data/variation 7/initial_indicators/HA_data_test.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels
# Date
# 2019-01-22    33.520000  30.035257  -7.208249  8558300.0     2.0
# 2019-01-23    32.720001  30.448294 -16.361556  7905500.0     2.0
# 2019-01-24    31.150000  30.556249 -34.324958  7085300.0     2.0
# 2019-01-25    31.500000  30.701441 -32.121223  8087300.0     2.0
# 2019-01-28    30.950001  30.739681 -41.184038  6956000.0     2.0

# %%
#%matplotlib notebook
df['previous_1d'].shift(-1).plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['labels'].plot(figsize=(16,6),x='Date', y='labels')

# %%
# willr_data = []
# price_data = []
# ema_data = []
# obv_data = []
# labels = []
# data_15_price = []
# data_15_willr = []
# data_15_ema = []
# data_15_obv = []
# count = 0

# for i in df.values:
#     if count == 14:
#         data_15_price.append([i[0]])
#         data_15_ema.append([i[1]])
#         data_15_willr.append([i[2]])
#         data_15_obv.append([i[3]])
#         price_data.append(data_15_price)
#         willr_data.append(data_15_willr)
#         ema_data.append(data_15_ema)
#         obv_data.append(data_15_obv)
#         labels.append(i[-1])
#         data_15_price = data_15_price[1:]
#         data_15_willr = data_15_willr[1:]
#         data_15_obv = data_15_obv[1:]
#         data_15_ema = data_15_ema[1:]
    
#     else:
#         data_15_price.append([i[0]])
#         data_15_ema.append([i[1]])
#         data_15_willr.append([i[2]])
#         data_15_obv.append([i[3]])
#         count += 1

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1

# %%
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/HA_image_cnn_buy_hold_sell.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1]) ; logger.append(score[1])
# Out:
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1216 - accuracy: 0.7752 - mean_squared_error: 3.3365 - weighted_accuracy: 0.7752 - weighted_mean_squared_error: 3.3365
# Test loss: 0.12159634381532669
# Test accuracy: 0.7752293348312378

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 182, 1: 24, 0: 12})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]
Counter(actual)
# Out:
# Counter({2: 197, 0: 11, 1: 10})

# %%
df = pd.read_csv("data/variation 7/initial_indicators/HA_data_test.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels  predictions  \
# Date
# 2019-02-11    30.719999  30.888985 -60.332097  6702000.0     2.0            2
# 2019-02-12    30.549999  30.862987 -57.142873  7237200.0     2.0            2
# 2019-02-13    30.730000  30.814835 -60.424727  6747100.0     2.0            2
# 2019-02-14    31.280001  30.801783 -56.949818  7152700.0     2.0            2
# 2019-02-15    31.610001  30.875355 -46.332036  8003800.0     2.0            2
#
#             actual
# Date
# 2019-02-11       2
# 2019-02-12       2
# 2019-02-13       2
# 2019-02-14       2
# 2019-02-15       2

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['predictions'].plot(figsize=(16,6),x='Date', y='predictions')
#df['actual'].plot(figsize=(16,6),x='Date', y='actual')

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold)) ; logger.append(str(100*buy_buy/buy) + "%") ; logger.append(str(100*sell_sell/sell) + "%") ; logger.append(str(100*hold_hold/hold) + "%")
# Out:
# number of predictions: 218
# actual predicted buys: 3
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 0
# actual predicted sells: 1
# actual sells but predicted hold: 10
# actual holds but predicted buy: 21
# actual holds but predicted sell: 11
# actual predicted holds: 165
# Percentage buys correct: 30.0%
# Percentage sells correct: 9.090909090909092%
# Percentage holds correct: 83.75634517766497%
# actual buys: 10
# actual sells: 11
# actual holds: 197

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%") ; logger.append(str(100*correct_minima/buy) + "%") ; logger.append(str(100*correct_maxima/sell) + "%") ; logger.append(str(100*correct_hold/hold) + "%")
# Out:
# [30.54999923706055, 30.71999931335449, 30.729999542236328, 30.78000068664551, 31.28000068664551, 31.45000076293945, 31.61000061035156, 31.70000076293945, 32.439998626708984]
# [26.3799991607666, 29.479999542236328, 29.6200008392334, 29.75, 30.46999931335449, 30.78000068664551, 31.38999938964844, 31.45000076293945, 31.70000076293945]
# Percentage buys correct: 54.166666666666664%
# Percentage sells correct: 50.0%
# Percentage holds correct: 81.21546961325967%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $31.70000076293945
# Shares owned at the moment: 314
# Cash capital at the moment: $18.826809778214738
#
#
# Stop Loss Activated!
#
# Share price: $30.46999931335449
# Shares owned at the moment: 0
# Cash capital at the moment: $9560.095749764441
#
#
# Share price: $26.3799991607666
# Shares owned at the moment: 361
# Cash capital at the moment: $10.727308560846723
#
#
# Stop Loss Activated!
#
# Share price: $25.6200008392334
# Shares owned at the moment: 0
# Cash capital at the moment: $9234.113355690954
#
#
# Share price: $25.6200008392334
# Shares owned at the moment: 359
# Cash capital at the moment: $11.239708577630154
#
#
# Price increase from previously bought: 5.019543867376042%
# Share price: $26.979999542236328
# Shares owned at the moment: 0
# Cash capital at the moment: $9670.4235396924
#
#
# Share price: $25.96999931335449
# Shares owned at the moment: 371
# Cash capital at the moment: $9.057902638434825
#
#
# Stop Loss Activated!
#
# Share price: $24.489999771118164
# Shares owned at the moment: 0
# Cash capital at the moment: $9069.86189545679
#
#
# Share price: $26.709999084472656
# Shares owned at the moment: 338
# Cash capital at the moment: $17.05526075601483
#
#
# Stop Loss Activated!
#
# Share price: $25.479999542236328
# Shares owned at the moment: 0
# Cash capital at the moment: $8605.611446457386
#
#
# Share price: $25.51000022888184
# Shares owned at the moment: 336
# Cash capital at the moment: $10.68012934159924
#
#
# Price increase from previously bought: 8.09161270812535%
# Share price: $27.649999618530273
# Shares owned at the moment: 0
# Cash capital at the moment: $9275.53140152025
#
#
# Share price: $27.68000030517578
# Shares owned at the moment: 334
# Cash capital at the moment: $4.987219311233275
#
#
# Stop Loss Activated!
#
# Share price: $26.440000534057607
# Shares owned at the moment: 0
# Cash capital at the moment: $8811.662257195941
#
#
# Share price: $24.76000022888184
# Shares owned at the moment: 354
# Cash capital at the moment: $22.518315948953386
#
#
# Stop Loss Activated!
#
# Share price: $23.78000068664551
# Shares owned at the moment: 0
# Cash capital at the moment: $8417.488728353015
#
#
# Share price: $23.78000068664551
# Shares owned at the moment: 353
# Cash capital at the moment: $0.06405030058704142
#
#
# Price increase from previously bought: 13.56490065177507%
# Share price: $27.07999992370605
# Shares owned at the moment: 0
# Cash capital at the moment: $9533.016113442885
#
#
# Share price: $27.26000022888184
# Shares owned at the moment: 348
# Cash capital at the moment: $20.44821357296496
#
#
# Stop Loss Activated!
#
# Share price: $26.25
# Shares owned at the moment: 0
# Cash capital at the moment: $9130.326963572965
#
#
# Share price: $25.53000068664551
# Shares owned at the moment: 356
# Cash capital at the moment: $16.652848454936247
#
#
# Price increase from previously bought: 7.499127566039676%
# Share price: $27.520000457763672
# Shares owned at the moment: 0
# Cash capital at the moment: $9786.830930970653
#
#
# Share price: $30.770000457763672
# Shares owned at the moment: 317
# Cash capital at the moment: $5.917037960512971
#
#
# Stop Loss Activated!
#
# Share price: $29.07999992370605
# Shares owned at the moment: 0
# Cash capital at the moment: $9198.92652384184
#
#
# Share price: $29.07999992370605
# Shares owned at the moment: 315
# Cash capital at the moment: $13.535997940523885
#
#
#
#
# Capital at the end of test period: $9613.463230175003
# profit gained: -3.8653676982499747%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $9893.559570526126
# profit gained: -1.0644042947387424%

# %%
df_length = len(log)
log.loc[df_length] = logger
log.head(20)
# Out:
#    Test_accuracy correct_buys       correct_sells       correct_holds  \
# 0       0.775229        30.0%  9.090909090909092%  83.75634517766497%
#
#       correct_low_buys correct_high_sells   correct_mid_holds  \
# 0  54.166666666666664%              50.0%  81.21546961325967%
#
#           Profit gained     buy_n_hold profit
# 0  -3.8653676982499747%  -1.0644042947387424%

# %% [markdown]
# ### Recession

# %%
logger = []

# %%
seed = 10
df = pd.read_csv("data/variation 7/initial_indicators/HA_data_test2.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels
# Date
# 2020-01-22    28.400000  29.290794 -81.099682  -783800.0     2.0
# 2020-01-23    29.120001  29.264518 -56.357370   281600.0     2.0
# 2020-01-24    29.840000  29.353054 -31.615125  1057900.0     2.0
# 2020-01-27    29.020000  29.301815 -59.793810   234600.0     2.0
# 2020-01-28    27.430000  29.013843 -89.999979  -739100.0     2.0

# %%
#%matplotlib notebook
df['previous_1d'].shift(-1).plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['labels'].plot(figsize=(16,6),x='Date', y='labels')

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1

# %%
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/HA_image_cnn_buy_hold_sell.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1]) ; logger.append(score[1])
# Out:
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1310 - accuracy: 0.7534 - mean_squared_error: 3.3708 - weighted_accuracy: 0.7534 - weighted_mean_squared_error: 3.3708
# Test loss: 0.1310499906539917
# Test accuracy: 0.7534246444702148

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 183, 1: 26, 0: 10})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]

# %%
df = pd.read_csv("data/variation 7/initial_indicators/HA_data_test2.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels  predictions  \
# Date
# 2020-02-11    28.570000  28.557071 -64.175266 -2249000.0     2.0            2
# 2020-02-12    29.120001  28.559060 -56.185587 -1846100.0     2.0            2
# 2020-02-13    28.510000  28.645359 -42.010297 -1459400.0     2.0            2
# 2020-02-14    27.959999  28.624534 -57.731965 -2039100.0     2.0            2
# 2020-02-18    27.040001  28.522298 -71.907256 -2524200.0     2.0            2
#
#             actual
# Date
# 2020-02-11       2
# 2020-02-12       2
# 2020-02-13       2
# 2020-02-14       2
# 2020-02-18       2

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['predictions'].plot(figsize=(16,6),x='Date', y='predictions')
#df['actual'].plot(figsize=(16,6),x='Date', y='actual')

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold)) ; logger.append(str(100*buy_buy/buy) + "%") ; logger.append(str(100*sell_sell/sell) + "%") ; logger.append(str(100*hold_hold/hold) + "%")
# Out:
# number of predictions: 219
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 9
# actual sells but predicted buy: 0
# actual predicted sells: 0
# actual sells but predicted hold: 10
# actual holds but predicted buy: 25
# actual holds but predicted sell: 10
# actual predicted holds: 164
# Percentage buys correct: 10.0%
# Percentage sells correct: 0.0%
# Percentage holds correct: 82.41206030150754%
# actual buys: 10
# actual sells: 10
# actual holds: 199

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%") ; logger.append(str(100*correct_minima/buy) + "%") ; logger.append(str(100*correct_maxima/sell) + "%") ; logger.append(str(100*correct_hold/hold) + "%")
# Out:
# [25.36000061035156, 26.70000076293945, 26.790000915527344, 26.809999465942386, 27.040000915527344, 27.959999084472656, 28.51000022888184, 28.56999969482422, 29.1200008392334]
# [19.149999618530273, 19.96999931335449, 20.8799991607666, 22.06999969482422, 23.270000457763672, 24.190000534057607, 25.36000061035156, 26.790000915527344, 26.809999465942386]
# Percentage buys correct: 48.0%
# Percentage sells correct: 60.0%
# Percentage holds correct: 83.06010928961749%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $26.70000076293945
# Shares owned at the moment: 373
# Cash capital at the moment: $13.512189641000077
#
#
# Stop Loss Activated!
#
# Share price: $25.36000061035156
# Shares owned at the moment: 0
# Cash capital at the moment: $9446.779396676062
#
#
# Share price: $22.06999969482422
# Shares owned at the moment: 426
# Cash capital at the moment: $19.104522038458526
#
#
# Stop Loss Activated!
#
# Share price: $20.8799991607666
# Shares owned at the moment: 0
# Cash capital at the moment: $8889.523245508193
#
#
# Share price: $19.96999931335449
# Shares owned at the moment: 443
# Cash capital at the moment: $18.485098028661014
#
#
# Stop Loss Activated!
#
# Share price: $19.149999618530273
# Shares owned at the moment: 0
# Cash capital at the moment: $8478.605442002297
#
#
# Share price: $19.149999618530273
# Shares owned at the moment: 441
# Cash capital at the moment: $10.231448193073447
#
#
# Stop Loss Activated!
#
# Share price: $16.819999694824222
# Shares owned at the moment: 0
# Cash capital at the moment: $7407.452858980658
#
#
# Share price: $16.819999694824222
# Shares owned at the moment: 439
# Cash capital at the moment: $3.167048321247421
#
#
# Stop Loss Activated!
#
# Share price: $15.739999771118164
# Shares owned at the moment: 0
# Cash capital at the moment: $6894.024833118438
#
#
# Share price: $14.130000114440918
# Shares owned at the moment: 486
# Cash capital at the moment: $7.960032347201377
#
#
# Stop Loss Activated!
#
# Share price: $13.15999984741211
# Shares owned at the moment: 0
# Cash capital at the moment: $6386.1316183934205
#
#
# Share price: $10.4399995803833
# Shares owned at the moment: 610
# Cash capital at the moment: $0.21877506351393095
#
#
# Stop Loss Activated!
#
# Share price: $9.84000015258789
# Shares owned at the moment: 0
# Cash capital at the moment: $5986.112267886161
#
#
# Share price: $9.550000190734863
# Shares owned at the moment: 625
# Cash capital at the moment: $0.9480858490460378
#
#
# Price increase from previously bought: 17.060281234544263%
# Share price: $11.210000038146973
# Shares owned at the moment: 0
# Cash capital at the moment: $6987.930922125339
#
#
# Share price: $13.600000381469727
# Shares owned at the moment: 512
# Cash capital at the moment: $5.581926275729529
#
#
# Stop Loss Activated!
#
# Share price: $12.970000267028807
# Shares owned at the moment: 0
# Cash capital at the moment: $6627.960302618502
#
#
# Share price: $12.979999542236328
# Shares owned at the moment: 509
# Cash capital at the moment: $2.971781260966054
#
#
# Stop Loss Activated!
#
# Share price: $12.5600004196167
# Shares owned at the moment: 0
# Cash capital at the moment: $6378.431134258507
#
#
# Share price: $11.800000190734865
# Shares owned at the moment: 539
# Cash capital at the moment: $0.7404811696978868
#
#
# Stop Loss Activated!
#
# Share price: $11.470000267028807
# Shares owned at the moment: 0
# Cash capital at the moment: $6166.069217202421
#
#
# Share price: $13.3100004196167
# Shares owned at the moment: 461
# Cash capital at the moment: $13.285270727153147
#
#
# Stop Loss Activated!
#
# Share price: $12.43000030517578
# Shares owned at the moment: 0
# Cash capital at the moment: $5727.757278526301
#
#
# Share price: $14.960000038146973
# Shares owned at the moment: 381
# Cash capital at the moment: $12.322923952336168
#
#
# Stop Loss Activated!
#
# Share price: $14.539999961853027
# Shares owned at the moment: 0
# Cash capital at the moment: $5536.828624458308
#
#
# Share price: $13.6899995803833
# Shares owned at the moment: 403
# Cash capital at the moment: $4.58685152887756
#
#
# Stop Loss Activated!
#
# Share price: $12.81999969482422
# Shares owned at the moment: 0
# Cash capital at the moment: $5156.83896388125
#
#
# Share price: $13.260000228881836
# Shares owned at the moment: 387
# Cash capital at the moment: $11.10692006039153
#
#
# Stop Loss Activated!
#
# Share price: $12.140000343322756
# Shares owned at the moment: 0
# Cash capital at the moment: $4696.367057560917
#
#
# Share price: $13.010000228881836
# Shares owned at the moment: 359
# Cash capital at the moment: $12.932852666373947
#
#
# Stop Loss Activated!
#
# Share price: $12.520000457763672
# Shares owned at the moment: 0
# Cash capital at the moment: $4495.252646551605
#
#
# Share price: $13.329999923706055
# Shares owned at the moment: 336
# Cash capital at the moment: $4.0557522568660715
#
#
# Price increase from previously bought: 6.458923060468935%
# Share price: $14.229999542236328
# Shares owned at the moment: 0
# Cash capital at the moment: $4772.187078871246
#
#
# Share price: $14.300000190734865
# Shares owned at the moment: 332
# Cash capital at the moment: $11.531115373129069
#
#
# Stop Loss Activated!
#
# Share price: $13.850000381469727
# Shares owned at the moment: 0
# Cash capital at the moment: $4597.086191672796
#
#
# Share price: $18.8799991607666
# Shares owned at the moment: 242
# Cash capital at the moment: $15.561755325787999
#
#
# Stop Loss Activated!
#
# Share price: $18.25
# Shares owned at the moment: 0
# Cash capital at the moment: $4419.916380325788
#
#
#
#
# Capital at the end of test period: $4419.916380325788
# profit gained: -55.80083619674212%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $6353.38461179924
# profit gained: -36.4661538820076%

# %%
df_length = len(log)
log.loc[df_length] = logger
log.head()
# Out:
#    Test_accuracy correct_buys       correct_sells       correct_holds  \
# 0       0.775229        30.0%  9.090909090909092%  83.75634517766497%
# 1       0.753425        10.0%                0.0%  82.41206030150754%
#
#       correct_low_buys correct_high_sells   correct_mid_holds  \
# 0  54.166666666666664%              50.0%  81.21546961325967%
# 1                48.0%              60.0%  83.06010928961749%
#
#           Profit gained     buy_n_hold profit
# 0  -3.8653676982499747%  -1.0644042947387424%
# 1   -55.80083619674212%    -36.4661538820076%

# %% [markdown]
# ## JetBlue Airways Corporation (Mid Cap)

# %% [markdown]
# ### Test Performance

# %% [markdown]
# #### Non-Recession

# %%
logger = []

# %%
seed = 10
df = pd.read_csv("data/variation 7/initial_indicators/JBLU_data_test.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22    17.600000  17.005903  -4.149392  23132100.0     2.0
# 2019-01-23    17.370001  17.061918 -14.049519  19087600.0     2.0
# 2019-01-24    17.240000  17.089315 -19.421466  14999400.0     2.0
# 2019-01-25    18.120001  17.247882  -5.555506  23032100.0     2.0
# 2019-01-28    17.709999  17.318977 -26.363710  14531900.0     2.0

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['labels'].plot(figsize=(16,6),x='Date', y='labels')

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['labels'].shift(1).values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
# willr_data = []
# price_data = []
# ema_data = []
# obv_data = []
# labels = []
# data_15_price = []
# data_15_willr = []
# data_15_ema = []
# data_15_obv = []
# count = 0

# for i in df.values:
#     if count == 14:
#         data_15_price.append([i[0]])
#         data_15_ema.append([i[1]])
#         data_15_willr.append([i[2]])
#         data_15_obv.append([i[3]])
#         price_data.append(data_15_price)
#         willr_data.append(data_15_willr)
#         ema_data.append(data_15_ema)
#         obv_data.append(data_15_obv)
#         labels.append(i[-1])
#         data_15_price = data_15_price[1:]
#         data_15_willr = data_15_willr[1:]
#         data_15_obv = data_15_obv[1:]
#         data_15_ema = data_15_ema[1:]
    
#     else:
#         data_15_price.append([i[0]])
#         data_15_ema.append([i[1]])
#         data_15_willr.append([i[2]])
#         data_15_obv.append([i[3]])
#         count += 1
        
# willr_data = np.array(willr_data)
# price_data = np.array(price_data)
# ema_data = np.array(ema_data)
# obv_data = np.array(obv_data)

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/HA_image_cnn_buy_hold_sell.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1]) ; logger.append(score[1])
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1237 - accuracy: 0.7844 - mean_squared_error: 3.2140 - weighted_accuracy: 0.7844 - weighted_mean_squared_error: 3.2140
# Test loss: 0.12372356653213501
# Test accuracy: 0.7844036817550659

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 183, 1: 32, 0: 3})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]
Counter(actual)
# Out:
# Counter({0: 8, 2: 200, 1: 10})

# %%
df = pd.read_csv("data/variation 7/initial_indicators/JBLU_data_test.csv")
df.set_index('Date', inplace=True)

# %%
# df['previous_1d'] = df['previous_1d'].shift(-1)
# df.dropna(inplace=True)
# df = df.iloc[13:]
# df['predictions'] = predictions
# df['actual'] = actual
# df.head()

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels  \
# Date
# 2019-02-11    18.260000  17.940004 -24.657592  14449900.0     0.0
# 2019-02-12    17.889999  17.989234 -16.438351  18367600.0     2.0
# 2019-02-13    18.049999  17.973967 -53.508854  14230800.0     2.0
# 2019-02-14    18.080000  17.985665 -50.000106  18206400.0     2.0
# 2019-02-15    17.959999  18.000178 -46.666695  20743900.0     2.0
#
#             predictions  actual
# Date
# 2019-02-11            2       0
# 2019-02-12            2       2
# 2019-02-13            2       2
# 2019-02-14            2       2
# 2019-02-15            2       2

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['predictions'].plot(figsize=(16,6),x='Date', y='predictions')
#df['actual'].plot(figsize=(16,6),x='Date', y='actual')

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold)) ; logger.append(str(100*buy_buy/buy) + "%") ; logger.append(str(100*sell_sell/sell) + "%") ; logger.append(str(100*hold_hold/hold) + "%")
# Out:
# number of predictions: 218
# actual predicted buys: 3
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 0
# actual predicted sells: 0
# actual sells but predicted hold: 8
# actual holds but predicted buy: 29
# actual holds but predicted sell: 3
# actual predicted holds: 168
# Percentage buys correct: 30.0%
# Percentage sells correct: 0.0%
# Percentage holds correct: 84.0%
# actual buys: 10
# actual sells: 8
# actual holds: 200

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%") ; logger.append(str(100*correct_minima/buy) + "%") ; logger.append(str(100*correct_maxima/sell) + "%") ; logger.append(str(100*correct_hold/hold) + "%")
# Out:
# [17.219999313354492, 17.489999771118164, 17.559999465942386, 17.889999389648438, 17.93000030517578, 17.959999084472656, 18.049999237060547, 18.07999992370605, 18.26000022888184]
# [16.559999465942386, 16.700000762939453, 16.899999618530273, 16.930000305175778, 17.180000305175778, 17.219999313354492, 17.25, 17.489999771118164, 17.559999465942386]
# Percentage buys correct: 59.375%
# Percentage sells correct: 33.333333333333336%
# Percentage holds correct: 84.61538461538461%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
#         print(i)
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $17.219999313354492
# Shares owned at the moment: 579
# Cash capital at the moment: $2.201853661059431
#
#
# Stop Loss Activated!
#
# Share price: $16.700000762939453
# Shares owned at the moment: 0
# Cash capital at the moment: $9644.911719188212
#
#
# Share price: $16.079999923706055
# Shares owned at the moment: 598
# Cash capital at the moment: $2.6282049374567578
#
#
# Price increase from previously bought: 11.137159883194613%
# Share price: $17.920000076293945
# Shares owned at the moment: 0
# Cash capital at the moment: $10689.31881043577
#
#
# Share price: $18.100000381469727
# Shares owned at the moment: 588
# Cash capital at the moment: $17.250885514735273
#
#
# Stop Loss Activated!
#
# Share price: $17.219999313354492
# Shares owned at the moment: 0
# Cash capital at the moment: $10114.765742877482
#
#
# Share price: $16.549999237060547
# Shares owned at the moment: 609
# Cash capital at the moment: $8.099096285341147
#
#
# Stop Loss Activated!
#
# Share price: $16.020000457763672
# Shares owned at the moment: 0
# Cash capital at the moment: $9737.449879296777
#
#
# Share price: $17.190000534057614
# Shares owned at the moment: 564
# Cash capital at the moment: $15.627887259959607
#
#
#
#
# Capital at the end of test period: $10584.045112197398
# profit gained: 5.840451121973984%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $10233.749798190114
# profit gained: 2.337497981901142%

# %%
df_length = len(log)
log.loc[df_length] = logger
log.head()
# Out:
#    Test_accuracy correct_buys       correct_sells       correct_holds  \
# 0       0.775229        30.0%  9.090909090909092%  83.75634517766497%
# 1       0.753425        10.0%                0.0%  82.41206030150754%
# 2       0.784404        30.0%                0.0%               84.0%
#
#       correct_low_buys   correct_high_sells   correct_mid_holds  \
# 0  54.166666666666664%                50.0%  81.21546961325967%
# 1                48.0%                60.0%  83.06010928961749%
# 2              59.375%  33.333333333333336%  84.61538461538461%
#
#           Profit gained     buy_n_hold profit
# 0  -3.8653676982499747%  -1.0644042947387424%
# 1   -55.80083619674212%    -36.4661538820076%
# 2    5.840451121973984%    2.337497981901142%

# %% [markdown]
# #### Recession

# %%
logger = []

# %%
seed = 10
df = pd.read_csv("data/variation 7/initial_indicators/JBLU_data_test2.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22    19.049999  18.785034 -29.629734  -5172900.0     2.0
# 2020-01-23    19.790001  18.939644 -15.920381   7229600.0     0.0
# 2020-01-24    21.070000  19.267391  -2.622949  23219300.0     2.0
# 2020-01-27    20.650000  19.480100 -18.060233  11950900.0     2.0
# 2020-01-28    20.040001  19.566239 -38.461529   3416600.0     2.0

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['labels'].plot(figsize=(16,6),x='Date', y='labels')

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['labels'].shift(1).values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/HA_image_cnn_buy_hold_sell.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1]) ; logger.append(score[1])
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1212 - accuracy: 0.7945 - mean_squared_error: 3.1274 - weighted_accuracy: 0.7945 - weighted_mean_squared_error: 3.1274
# Test loss: 0.12120452523231506
# Test accuracy: 0.7945205569267273

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 191, 1: 23, 0: 5})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]
Counter(actual)
# Out:
# Counter({2: 197, 0: 12, 1: 10})

# %%
df = pd.read_csv("data/variation 7/initial_indicators/JBLU_data_test2.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels  \
# Date
# 2020-02-11    20.510000  20.028004 -60.309266   9053300.0     2.0
# 2020-02-12    21.129999  20.102157 -43.870955  13857200.0     2.0
# 2020-02-13    21.559999  20.260287 -12.352994  18449600.0     0.0
# 2020-02-14    21.270000  20.460243  -1.538496  23393200.0     2.0
# 2020-02-18    21.299999  20.584821 -18.905429  17925800.0     2.0
#
#             predictions  actual
# Date
# 2020-02-11            2       2
# 2020-02-12            2       2
# 2020-02-13            2       0
# 2020-02-14            2       2
# 2020-02-18            2       2

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['predictions'].plot(figsize=(16,6),x='Date', y='predictions')
#df['actual'].plot(figsize=(16,6),x='Date', y='actual')

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold)) ; logger.append(str(100*buy_buy/buy) + "%") ; logger.append(str(100*sell_sell/sell) + "%") ; logger.append(str(100*hold_hold/hold) + "%")
# Out:
# number of predictions: 219
# actual predicted buys: 2
# actual buys but predicted sell: 0
# actual buys but predicted hold: 8
# actual sells but predicted buy: 1
# actual predicted sells: 0
# actual sells but predicted hold: 11
# actual holds but predicted buy: 20
# actual holds but predicted sell: 5
# actual predicted holds: 172
# Percentage buys correct: 20.0%
# Percentage sells correct: 0.0%
# Percentage holds correct: 87.30964467005076%
# actual buys: 10
# actual sells: 12
# actual holds: 197

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%") ; logger.append(str(100*correct_minima/buy) + "%") ; logger.append(str(100*correct_maxima/sell) + "%") ; logger.append(str(100*correct_hold/hold) + "%")
# Out:
# [19.3799991607666, 20.51000022888184, 20.61000061035156, 20.809999465942386, 20.82999992370605, 21.1299991607666, 21.270000457763672, 21.299999237060547, 21.559999465942386]
# [15.010000228881836, 15.56999969482422, 15.779999732971193, 16.270000457763672, 17.120000839233402, 18.25, 19.3799991607666, 20.61000061035156, 20.82999992370605]
# Percentage buys correct: 40.90909090909091%
# Percentage sells correct: 60.0%
# Percentage holds correct: 85.86387434554973%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
#         print(i)
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
#         print(i)
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $16.270000457763672
# Shares owned at the moment: 612
# Cash capital at the moment: $15.377309078216058
#
#
# Stop Loss Activated!
#
# Share price: $15.779999732971193
# Shares owned at the moment: 0
# Cash capital at the moment: $9646.179406105995
#
#
# Share price: $15.56999969482422
# Shares owned at the moment: 617
# Cash capital at the moment: $13.071197417257281
#
#
# Stop Loss Activated!
#
# Share price: $15.010000228881836
# Shares owned at the moment: 0
# Cash capital at the moment: $9248.773120748994
#
#
# Share price: $15.010000228881836
# Shares owned at the moment: 614
# Cash capital at the moment: $7.288594829080466
#
#
# Stop Loss Activated!
#
# Share price: $13.859999656677244
# Shares owned at the moment: 0
# Cash capital at the moment: $8493.925774608608
#
#
# Share price: $13.399999618530273
# Shares owned at the moment: 632
# Cash capital at the moment: $1.8368163604682195
#
#
# Stop Loss Activated!
#
# Share price: $11.489999771118164
# Shares owned at the moment: 0
# Cash capital at the moment: $7243.547052104945
#
#
# Share price: $7.599999904632567
# Shares owned at the moment: 950
# Cash capital at the moment: $3.6921429531539616
#
#
# Stop Loss Activated!
#
# Share price: $7.1500000953674325
# Shares owned at the moment: 0
# Cash capital at the moment: $6777.512858303067
#
#
# Share price: $9.399999618530273
# Shares owned at the moment: 719
# Cash capital at the moment: $0.32698333406187885
#
#
# Stop Loss Activated!
#
# Share price: $8.789999961853027
# Shares owned at the moment: 0
# Cash capital at the moment: $6302.956928481814
#
#
# Share price: $8.949999809265137
# Shares owned at the moment: 702
# Cash capital at the moment: $2.779087745901961
#
#
# Stop Loss Activated!
#
# Share price: $8.109999656677246
# Shares owned at the moment: 0
# Cash capital at the moment: $5680.342492396113
#
#
# Share price: $8.760000228881836
# Shares owned at the moment: 646
# Cash capital at the moment: $5.820204131838182
#
#
# Stop Loss Activated!
#
# Share price: $8.329999923706055
# Shares owned at the moment: 0
# Cash capital at the moment: $5372.201909981485
#
#
# Share price: $7.860000133514402
# Shares owned at the moment: 681
# Cash capital at the moment: $4.822003808138106
#
#
# Price increase from previously bought: 23.578728543185967%
# Share price: $9.739999771118164
# Shares owned at the moment: 0
# Cash capital at the moment: $6619.521263368246
#
#
# Share price: $8.020000457763674
# Shares owned at the moment: 823
# Cash capital at the moment: $0.9096205927080518
#
#
# Price increase from previously bought: 40.884379390777845%
# Share price: $11.329999923706055
# Shares owned at the moment: 0
# Cash capital at the moment: $9299.856935475462
#
#
# Share price: $11.460000038146973
# Shares owned at the moment: 809
# Cash capital at the moment: $3.221269529693018
#
#
# Stop Loss Activated!
#
# Share price: $11.109999656677246
# Shares owned at the moment: 0
# Cash capital at the moment: $8966.494020045393
#
#
# Share price: $15.890000343322756
# Shares owned at the moment: 562
# Cash capital at the moment: $11.755831567397763
#
#
# Stop Loss Activated!
#
# Share price: $15.420000076293945
# Shares owned at the moment: 0
# Cash capital at the moment: $8653.964264326682
#
#
# Share price: $15.5
# Shares owned at the moment: 556
# Cash capital at the moment: $12.264764326680961
#
#
# Stop Loss Activated!
#
# Share price: $14.800000190734865
# Shares owned at the moment: 0
# Cash capital at the moment: $8218.435670083632
#
#
# Share price: $14.279999732971193
# Shares owned at the moment: 573
# Cash capital at the moment: $13.494113511909745
#
#
#
#
# Capital at the end of test period: $8213.432318992962
# profit gained: -17.86567681007038%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $6959.649683341978
# profit gained: -30.40350316658022%

# %%
df_length = len(log)
log.loc[df_length] = logger
log.head()
# Out:
#    Test_accuracy correct_buys       correct_sells       correct_holds  \
# 0       0.775229        30.0%  9.090909090909092%  83.75634517766497%
# 1       0.753425        10.0%                0.0%  82.41206030150754%
# 2       0.784404        30.0%                0.0%               84.0%
# 3       0.794521        20.0%                0.0%  87.30964467005076%
#
#       correct_low_buys   correct_high_sells   correct_mid_holds  \
# 0  54.166666666666664%                50.0%  81.21546961325967%
# 1                48.0%                60.0%  83.06010928961749%
# 2              59.375%  33.333333333333336%  84.61538461538461%
# 3   40.90909090909091%                60.0%  85.86387434554973%
#
#           Profit gained     buy_n_hold profit
# 0  -3.8653676982499747%  -1.0644042947387424%
# 1   -55.80083619674212%    -36.4661538820076%
# 2    5.840451121973984%    2.337497981901142%
# 3   -17.86567681007038%   -30.40350316658022%

# %% [markdown]
# ## American Airlines Group Inc. (Large Cap)

# %% [markdown]
# ### Test Performance

# %% [markdown]
# #### Non-Recession

# %%
logger = []

# %%
seed = 10
df = pd.read_csv("data/variation 7/initial_indicators/AAL_data_test.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22    33.970001  32.626297  -1.338426   6209200.0     2.0
# 2019-01-23    32.740002  32.643790 -24.856575  -8389000.0     1.0
# 2019-01-24    31.650000  32.490899 -45.697909 -22706900.0     2.0
# 2019-01-25    33.660000  32.670761 -15.098446  -7175800.0     2.0
# 2019-01-28    34.980000  33.026028  -9.090918   8635500.0     2.0

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['labels'].plot(figsize=(16,6),x='Date', y='labels')

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/HA_image_cnn_buy_hold_sell.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1]) ; logger.append(score[1])
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1177 - accuracy: 0.7615 - mean_squared_error: 3.2109 - weighted_accuracy: 0.7615 - weighted_mean_squared_error: 3.2109
# Test loss: 0.11774129420518875
# Test accuracy: 0.7614678740501404

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 177, 1: 31, 0: 10})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]

# %%
df = pd.read_csv("data/variation 7/initial_indicators/AAL_data_test.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels  \
# Date
# 2019-02-11    36.590000  35.736321 -21.061635  19534700.0     2.0
# 2019-02-12    35.750000  35.867656 -10.958893  24467300.0     2.0
# 2019-02-13    36.209999  35.849555 -33.636371  17584100.0     2.0
# 2019-02-14    36.110001  35.905008 -29.394816  23422000.0     2.0
# 2019-02-15    35.049999  35.936545 -41.025609  19352000.0     2.0
#
#             predictions  actual
# Date
# 2019-02-11            2       2
# 2019-02-12            2       2
# 2019-02-13            2       2
# 2019-02-14            2       2
# 2019-02-15            1       2

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['predictions'].plot(figsize=(16,6),x='Date', y='predictions')
#df['actual'].plot(figsize=(16,6),x='Date', y='actual')

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold)) ; logger.append(str(100*buy_buy/buy) + "%") ; logger.append(str(100*sell_sell/sell) + "%") ; logger.append(str(100*hold_hold/hold) + "%")
# Out:
# number of predictions: 218
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 0
# actual predicted sells: 1
# actual sells but predicted hold: 6
# actual holds but predicted buy: 30
# actual holds but predicted sell: 9
# actual predicted holds: 164
# Percentage buys correct: 12.5%
# Percentage sells correct: 14.285714285714286%
# Percentage holds correct: 80.78817733990148%
# actual buys: 8
# actual sells: 7
# actual holds: 203

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%") ; logger.append(str(100*correct_minima/buy) + "%") ; logger.append(str(100*correct_maxima/sell) + "%") ; logger.append(str(100*correct_hold/hold) + "%")
# Out:
# [34.97999954223633, 35.049999237060554, 35.060001373291016, 35.470001220703125, 35.4900016784668, 35.75, 36.11000061035156, 36.209999084472656, 36.59000015258789]
# [33.720001220703125, 34.639999389648445, 34.97999954223633, 35.060001373291016, 35.4900016784668, 35.630001068115234, 35.689998626708984, 35.900001525878906, 36.25]
# Percentage buys correct: 54.83870967741935%
# Percentage sells correct: 40.0%
# Percentage holds correct: 85.22727272727273%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
#         print(i)
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $35.049999237060554
# Shares owned at the moment: 284
# Cash capital at the moment: $18.42616727065797
#
#
# Stop Loss Activated!
#
# Share price: $33.720001220703125
# Shares owned at the moment: 0
# Cash capital at the moment: $9568.571192996977
#
#
# Share price: $32.220001220703125
# Shares owned at the moment: 296
# Cash capital at the moment: $5.223750675198971
#
#
# Stop Loss Activated!
#
# Share price: $30.920000076293945
# Shares owned at the moment: 0
# Cash capital at the moment: $9132.374893196104
#
#
# Share price: $32.130001068115234
# Shares owned at the moment: 283
# Cash capital at the moment: $14.579417588231081
#
#
# Stop Loss Activated!
#
# Share price: $30.959999084472656
# Shares owned at the moment: 0
# Cash capital at the moment: $8752.164539206502
#
#
# Share price: $30.209999084472656
# Shares owned at the moment: 288
# Cash capital at the moment: $27.758483603474815
#
#
# Price increase from previously bought: 10.289226507002747%
# Share price: $33.40999984741211
# Shares owned at the moment: 0
# Cash capital at the moment: $9623.377719779011
#
#
# Share price: $33.950000762939446
# Shares owned at the moment: 282
# Cash capital at the moment: $23.149279038427267
#
#
# Stop Loss Activated!
#
# Share price: $32.139999389648445
# Shares owned at the moment: 0
# Cash capital at the moment: $9061.704537392616
#
#
# Share price: $32.139999389648445
# Shares owned at the moment: 281
# Cash capital at the moment: $5.528524373052278
#
#
# Stop Loss Activated!
#
# Share price: $30.959999084472656
# Shares owned at the moment: 0
# Cash capital at the moment: $8681.363927817341
#
#
# Share price: $29.170000076293945
# Shares owned at the moment: 296
# Cash capital at the moment: $23.29952517222955
#
#
# Stop Loss Activated!
#
# Share price: $28.170000076293945
# Shares owned at the moment: 0
# Cash capital at the moment: $8338.689167693134
#
#
# Share price: $28.170000076293945
# Shares owned at the moment: 295
# Cash capital at the moment: $5.686232624526383
#
#
# Stop Loss Activated!
#
# Share price: $27.229999542236328
# Shares owned at the moment: 0
# Cash capital at the moment: $8016.445760455604
#
#
# Share price: $27.229999542236328
# Shares owned at the moment: 293
# Cash capital at the moment: $16.115322449202722
#
#
# Price increase from previously bought: 11.188909605209595%
# Share price: $30.36000061035156
# Shares owned at the moment: 0
# Cash capital at the moment: $8887.132930790418
#
#
# Share price: $31.459999084472656
# Shares owned at the moment: 281
# Cash capital at the moment: $22.562473761074216
#
#
# Stop Loss Activated!
#
# Share price: $30.51000022888184
# Shares owned at the moment: 0
# Cash capital at the moment: $8572.295935400003
#
#
# Share price: $29.84000015258789
# Shares owned at the moment: 286
# Cash capital at the moment: $14.586731639856225
#
#
# Stop Loss Activated!
#
# Share price: $28.53000068664551
# Shares owned at the moment: 0
# Cash capital at the moment: $8151.728082480426
#
#
# Share price: $28.53000068664551
# Shares owned at the moment: 284
# Cash capital at the moment: $26.925956936830516
#
#
# Stop Loss Activated!
#
# Share price: $27.63999938964844
# Shares owned at the moment: 0
# Cash capital at the moment: $7855.098944073672
#
#
# Share price: $26.31999969482422
# Shares owned at the moment: 297
# Cash capital at the moment: $16.562174960131415
#
#
# Price increase from previously bought: 13.479728278406334%
# Share price: $29.95000076293945
# Shares owned at the moment: 0
# Cash capital at the moment: $8887.250738430015
#
#
# Share price: $27.989999771118164
# Shares owned at the moment: 316
# Cash capital at the moment: $18.087500955572978
#
#
# Stop Loss Activated!
#
# Share price: $27.0
# Shares owned at the moment: 0
# Cash capital at the moment: $8526.624500955573
#
#
# Share price: $27.0
# Shares owned at the moment: 314
# Cash capital at the moment: $25.310000955572832
#
#
# Stop Loss Activated!
#
# Share price: $25.3700008392334
# Shares owned at the moment: 0
# Cash capital at the moment: $7969.583268750182
#
#
# Share price: $25.82999992370605
# Shares owned at the moment: 307
# Cash capital at the moment: $17.966314736834647
#
#
# Price increase from previously bought: 18.759745657774474%
# Share price: $30.76000022888184
# Shares owned at the moment: 0
# Cash capital at the moment: $9435.317254810325
#
#
# Share price: $29.520000457763672
# Shares owned at the moment: 318
# Cash capital at the moment: $22.14186884116316
#
#
# Stop Loss Activated!
#
# Share price: $28.65999984741211
# Shares owned at the moment: 0
# Cash capital at the moment: $9110.958650451652
#
#
# Share price: $28.770000457763672
# Shares owned at the moment: 315
# Cash capital at the moment: $23.486493359556334
#
#
# Stop Loss Activated!
#
# Share price: $27.93000030517578
# Shares owned at the moment: 0
# Cash capital at the moment: $8797.242226725568
#
#
# Share price: $27.290000915527344
# Shares owned at the moment: 321
# Cash capital at the moment: $13.061684533107837
#
#
#
#
# Capital at the end of test period: $8976.344684533107
# profit gained: -10.236553154668927%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $7615.206638381957
# profit gained: -23.847933616180423%

# %%
df_length = len(log)
log.loc[df_length] = logger
log.head(20)
# Out:
#    Test_accuracy correct_buys        correct_sells       correct_holds  \
# 0       0.775229        30.0%   9.090909090909092%  83.75634517766497%
# 1       0.753425        10.0%                 0.0%  82.41206030150754%
# 2       0.784404        30.0%                 0.0%               84.0%
# 3       0.794521        20.0%                 0.0%  87.30964467005076%
# 4       0.761468        12.5%  14.285714285714286%  80.78817733990148%
#
#       correct_low_buys   correct_high_sells   correct_mid_holds  \
# 0  54.166666666666664%                50.0%  81.21546961325967%
# 1                48.0%                60.0%  83.06010928961749%
# 2              59.375%  33.333333333333336%  84.61538461538461%
# 3   40.90909090909091%                60.0%  85.86387434554973%
# 4   54.83870967741935%                40.0%  85.22727272727273%
#
#           Profit gained     buy_n_hold profit
# 0  -3.8653676982499747%  -1.0644042947387424%
# 1   -55.80083619674212%    -36.4661538820076%
# 2    5.840451121973984%    2.337497981901142%
# 3   -17.86567681007038%   -30.40350316658022%
# 4  -10.236553154668927%  -23.847933616180423%

# %% [markdown]
# ### Recession

# %%
logger = []

# %%
seed = 10
df = pd.read_csv("data/variation 7/initial_indicators/AAL_data_test2.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22    27.200001  27.797732 -93.333266  11782200.0     2.0
# 2020-01-23    27.320000  27.724235 -87.999980  21634800.0     0.0
# 2020-01-24    28.799999  27.889737  -6.440699  47245900.0     2.0
# 2020-01-27    27.639999  27.851316 -45.762743  29178100.0     1.0
# 2020-01-28    26.110001  27.583421 -79.558011   7604300.0     2.0

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/HA_image_cnn_buy_hold_sell.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1]) ; logger.append(score[1])
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1423 - accuracy: 0.7260 - mean_squared_error: 3.4072 - weighted_accuracy: 0.7260 - weighted_mean_squared_error: 3.4072
# Test loss: 0.14231468737125397
# Test accuracy: 0.7260273694992065

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 173, 1: 35, 0: 11})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]

# %%
df = pd.read_csv("data/variation 7/initial_indicators/AAL_data_test2.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels  \
# Date
# 2020-02-11    29.840000  28.041035 -16.176467  50567200.0     2.0
# 2020-02-12    30.469999  28.317799  -2.188192  59544900.0     0.0
# 2020-02-13    30.090000  28.648906  -5.730155  68860300.0     2.0
# 2020-02-14    29.200001  28.870613 -12.754169  59740900.0     2.0
# 2020-02-18    28.629999  28.921288 -34.955747  54216100.0     2.0
#
#             predictions  actual
# Date
# 2020-02-11            2       2
# 2020-02-12            2       0
# 2020-02-13            2       2
# 2020-02-14            2       2
# 2020-02-18            2       2

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold)) ; logger.append(str(100*buy_buy/buy) + "%") ; logger.append(str(100*sell_sell/sell) + "%") ; logger.append(str(100*hold_hold/hold) + "%")
# Out:
# number of predictions: 219
# actual predicted buys: 3
# actual buys but predicted sell: 0
# actual buys but predicted hold: 6
# actual sells but predicted buy: 1
# actual predicted sells: 0
# actual sells but predicted hold: 11
# actual holds but predicted buy: 31
# actual holds but predicted sell: 11
# actual predicted holds: 156
# Percentage buys correct: 33.333333333333336%
# Percentage sells correct: 0.0%
# Percentage holds correct: 78.78787878787878%
# actual buys: 9
# actual sells: 12
# actual holds: 198

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%") ; logger.append(str(100*correct_minima/buy) + "%") ; logger.append(str(100*correct_maxima/sell) + "%") ; logger.append(str(100*correct_hold/hold) + "%")
# Out:
# [25.45000076293945, 27.81999969482422, 28.32999992370605, 28.51000022888184, 28.6299991607666, 29.20000076293945, 29.84000015258789, 30.09000015258789, 30.46999931335449]
# [17.850000381469727, 18.86000061035156, 19.049999237060547, 20.600000381469727, 22.309999465942386, 23.1200008392334, 25.45000076293945, 27.81999969482422, 28.51000022888184]
# Percentage buys correct: 47.05882352941177%
# Percentage sells correct: 54.54545454545455%
# Percentage holds correct: 82.65895953757226%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
#         print(i)
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $23.1200008392334
# Shares owned at the moment: 431
# Cash capital at the moment: $7.876657295702898
#
#
# Stop Loss Activated!
#
# Share price: $22.309999465942386
# Shares owned at the moment: 0
# Cash capital at the moment: $9597.043500249863
#
#
# Share price: $18.86000061035156
# Shares owned at the moment: 507
# Cash capital at the moment: $8.727634950641004
#
#
# Stop Loss Activated!
#
# Share price: $17.850000381469727
# Shares owned at the moment: 0
# Cash capital at the moment: $9033.790465323927
#
#
# Share price: $17.850000381469727
# Shares owned at the moment: 504
# Cash capital at the moment: $12.650172534467856
#
#
# Stop Loss Activated!
#
# Share price: $16.040000915527347
# Shares owned at the moment: 0
# Cash capital at the moment: $8074.57919269133
#
#
# Share price: $14.75
# Shares owned at the moment: 545
# Cash capital at the moment: $13.7226301913297
#
#
# Stop Loss Activated!
#
# Share price: $13.449999809265135
# Shares owned at the moment: 0
# Cash capital at the moment: $7323.814339026692
#
#
# Share price: $15.920000076293945
# Shares owned at the moment: 458
# Cash capital at the moment: $12.403063987972928
#
#
# Stop Loss Activated!
#
# Share price: $11.649999618530273
# Shares owned at the moment: 0
# Cash capital at the moment: $5333.429714755299
#
#
# Share price: $10.380000114440918
# Shares owned at the moment: 512
# Cash capital at the moment: $4.254616000415808
#
#
# Stop Loss Activated!
#
# Share price: $10.0600004196167
# Shares owned at the moment: 0
# Cash capital at the moment: $5140.810350253345
#
#
# Share price: $10.0600004196167
# Shares owned at the moment: 509
# Cash capital at the moment: $6.188651081086391
#
#
# Stop Loss Activated!
#
# Share price: $9.390000343322754
# Shares owned at the moment: 0
# Cash capital at the moment: $4772.555172851802
#
#
# Share price: $9.390000343322754
# Shares owned at the moment: 506
# Cash capital at the moment: $8.148813652755052
#
#
# Price increase from previously bought: 22.772067941522025%
# Share price: $11.5600004196167
# Shares owned at the moment: 0
# Cash capital at the moment: $5841.423285394908
#
#
# Share price: $10.3100004196167
# Shares owned at the moment: 565
# Cash capital at the moment: $0.25388515949362045
#
#
# Stop Loss Activated!
#
# Share price: $10.020000457763672
# Shares owned at the moment: 0
# Cash capital at the moment: $5645.985568084718
#
#
# Share price: $9.539999961853027
# Shares owned at the moment: 590
# Cash capital at the moment: $1.9069406533244546
#
#
# Stop Loss Activated!
#
# Share price: $9.109999656677246
# Shares owned at the moment: 0
# Cash capital at the moment: $5362.025763649941
#
#
# Share price: $10.979999542236328
# Shares owned at the moment: 487
# Cash capital at the moment: $0.06102219390868413
#
#
# Stop Loss Activated!
#
# Share price: $10.5
# Shares owned at the moment: 0
# Cash capital at the moment: $5099.498897193908
#
#
# Share price: $17.030000686645508
# Shares owned at the moment: 298
# Cash capital at the moment: $10.602607010840984
#
#
# Stop Loss Activated!
#
# Share price: $16.489999771118164
# Shares owned at the moment: 0
# Cash capital at the moment: $4911.108983991622
#
#
# Share price: $13.170000076293945
# Shares owned at the moment: 371
# Cash capital at the moment: $11.602263108728948
#
#
# Stop Loss Activated!
#
# Share price: $12.380000114440918
# Shares owned at the moment: 0
# Cash capital at the moment: $4591.9516104495515
#
#
# Share price: $12.380000114440918
# Shares owned at the moment: 369
# Cash capital at the moment: $11.168963104723844
#
#
# Stop Loss Activated!
#
# Share price: $11.90999984741211
# Shares owned at the moment: 0
# Cash capital at the moment: $4393.873234454631
#
#
# Share price: $11.9399995803833
# Shares owned at the moment: 366
# Cash capital at the moment: $11.81577845668653
#
#
# Stop Loss Activated!
#
# Share price: $11.56999969482422
# Shares owned at the moment: 0
# Cash capital at the moment: $4234.790462069511
#
#
# Share price: $11.079999923706056
# Shares owned at the moment: 381
# Cash capital at the moment: $1.701421217439929
#
#
# Price increase from previously bought: 17.276765273587145%
# Share price: $13.029999732971193
# Shares owned at the moment: 0
# Cash capital at the moment: $4952.479137259244
#
#
# Share price: $12.68000030517578
# Shares owned at the moment: 389
# Cash capital at the moment: $6.394588219404795
#
#
# Stop Loss Activated!
#
# Share price: $12.15999984741211
# Shares owned at the moment: 0
# Cash capital at the moment: $4723.626369025946
#
#
# Share price: $13.59000015258789
# Shares owned at the moment: 346
# Cash capital at the moment: $8.555431085347664
#
#
# Stop Loss Activated!
#
# Share price: $13.050000190734865
# Shares owned at the moment: 0
# Cash capital at the moment: $4511.438421898127
#
#
# Share price: $13.800000190734865
# Shares owned at the moment: 326
# Cash capital at the moment: $0.2666595475666327
#
#
# Stop Loss Activated!
#
# Share price: $13.1899995803833
# Shares owned at the moment: 0
# Cash capital at the moment: $4288.381688128709
#
#
# Share price: $12.289999961853027
# Shares owned at the moment: 347
# Cash capital at the moment: $12.023968902110937
#
#
# Stop Loss Activated!
#
# Share price: $11.800000190734865
# Shares owned at the moment: 0
# Cash capital at the moment: $4095.3638849051
#
#
# Share price: $10.949999809265137
# Shares owned at the moment: 372
# Cash capital at the moment: $10.762106053590742
#
#
# Price increase from previously bought: 12.749303161370529%
# Share price: $12.380000114440918
# Shares owned at the moment: 0
# Cash capital at the moment: $4603.457408508539
#
#
# Share price: $12.699999809265135
# Shares owned at the moment: 361
# Cash capital at the moment: $6.149552553177273
#
#
# Price increase from previously bought: 16.372887295357373%
# Share price: $14.81999969482422
# Shares owned at the moment: 0
# Cash capital at the moment: $5341.456887687685
#
#
# Share price: $16.510000228881836
# Shares owned at the moment: 322
# Cash capital at the moment: $10.61720878505821
#
#
#
#
# Capital at the end of test period: $5312.217677282334
# profit gained: -46.877823227176656%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $5505.207550131798
# profit gained: -44.94792449868202%

# %%
df_length = len(log)
log.loc[df_length] = logger
log.head(20)
# Out:
#    Test_accuracy         correct_buys        correct_sells  \
# 0       0.775229                30.0%   9.090909090909092%
# 1       0.753425                10.0%                 0.0%
# 2       0.784404                30.0%                 0.0%
# 3       0.794521                20.0%                 0.0%
# 4       0.761468                12.5%  14.285714285714286%
# 5       0.726027  33.333333333333336%                 0.0%
#
#         correct_holds     correct_low_buys   correct_high_sells  \
# 0  83.75634517766497%  54.166666666666664%                50.0%
# 1  82.41206030150754%                48.0%                60.0%
# 2               84.0%              59.375%  33.333333333333336%
# 3  87.30964467005076%   40.90909090909091%                60.0%
# 4  80.78817733990148%   54.83870967741935%                40.0%
# 5  78.78787878787878%   47.05882352941177%   54.54545454545455%
#
#     correct_mid_holds         Profit gained     buy_n_hold profit
# 0  81.21546961325967%  -3.8653676982499747%  -1.0644042947387424%
# 1  83.06010928961749%   -55.80083619674212%    -36.4661538820076%
# 2  84.61538461538461%    5.840451121973984%    2.337497981901142%
# 3  85.86387434554973%   -17.86567681007038%   -30.40350316658022%
# 4  85.22727272727273%  -10.236553154668927%  -23.847933616180423%
# 5  82.65895953757226%  -46.877823227176656%   -44.94792449868202%

# %%
experiment
# Out:
# 'Variation 7 Experiments results - HA'

# %%
log.to_csv('{}.csv'.format(experiment))
