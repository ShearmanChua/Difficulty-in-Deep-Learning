# %%
import os
seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
experiment = 'MFC Variation 6 CNN Images Experiment'

# %%
import requests
import lxml
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.utils import compute_class_weight
import tensorflow as tf
from pil import Image
from sklearn import preprocessing
import tensorflow_addons as tfa
import glob
import matplotlib.pyplot as plt

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
# gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
np.random.seed(seed)
tf.random.set_seed(seed)

session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, 
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), 
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)

# %% [markdown]
# ## Manulife Financial Corporation Stock Data

# %% [markdown]
# ### No other stock price

# %%
seed = 10
df = pd.read_csv("data/variation 6/initial_indicators/MFC_data.csv")
df.set_index('Date', inplace=True)
df.head()
# Out:
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2000-01-21      6.09375  6.133837 -56.250000  1982400.0     2.0
# 2000-01-24      6.06250  6.122862 -60.000000  1705200.0     2.0
# 2000-01-25      5.96875  6.099153 -80.000000   909600.0     2.0
# 2000-01-26      6.00000  6.083898 -73.333333  1179600.0     2.0
# 2000-01-27      5.96875  6.066183 -80.000000   783000.0     2.0

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['labels'].plot(figsize=(16,6),x='Date', y='labels')

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1

# %%
willr_data = np.array(willr_data)
willr_data.shape
# Out:
# (4745, 15, 1)

# %%
price_data = np.array(price_data)
price_data.shape
# Out:
# (4745, 15, 1)

# %%
ema_data = np.array(ema_data)
ema_data.shape
# Out:
# (4745, 15, 1)

# %%
obv_data = np.array(obv_data)
obv_data.shape
# Out:
# (4745, 15, 1)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
y = np.array(y)

X.shape
# Out:
# (4745, 64, 64, 1)

# %%
from collections import Counter

Counter(y)
# Out:
# Counter({2.0: 4303, 1.0: 214, 0.0: 228})

# %%
# plot the image array X
i = X[0].reshape(64, 64)
fig2, ax2 = plt.subplots()
plt.imshow(i, interpolation="none", cmap="gray")

ax2.axis('off')

plt.show()

# %%
X = X/255

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten,BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.regularizers import l2
import efficientnet.tfkeras as efn
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(Conv2D(16, (3, 3), padding='same', kernel_initializer='he_uniform',kernel_regularizer=l2(1e-5), input_shape=X_train.shape[1:]))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))

model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_uniform',kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

# model.add(Dense(128, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))
# model.add(Dropout(0.25, seed=seed))

model.add(Dense(64, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))
model.add(Dropout(0.25, seed=seed))

model.add(Dense(32, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))
model.add(Dropout(0.25, seed=seed))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "DBS_CNN_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))
print(d_class_weights)

# Train model
history = model.fit(
    train_x, train_y,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(validation_x, validation_y),
    shuffle=True,
    callbacks=[tensorboard],
    class_weight=d_class_weights
)
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 2 ... 0 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# {0: 6.9523809523809526, 1: 7.3996101364522415, 2: 0.3675089553683803}
# Epoch 1/200
#  1/30 [>.............................] - ETA: 0s - loss: 0.4614 - accuracy: 0.6719 - mse: 5.5666 - weighted_accuracy: 0.3982 - weighted_mse: 6.4582WARNING:tensorflow:From C:\Users\Shearman Chua\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/30 [=>............................] - ETA: 1s - loss: 0.4081 - accuracy: 0.6250 - mse: 4.4091 - weighted_accuracy: 0.3451 - weighted_mse: 5.3853WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0070s vs `on_train_batch_end` time: 0.0977s). Check your callbacks.
# 30/30 [==============================] - 1s 26ms/step - loss: 0.2469 - accuracy: 0.3501 - mse: 1.6065 - weighted_accuracy: 0.3019 - weighted_mse: 1.7280 - val_loss: 0.2252 - val_accuracy: 0.0453 - val_mse: 0.8594 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.8594
# Epoch 2/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2065 - accuracy: 0.2745 - mse: 1.1804 - weighted_accuracy: 0.3390 - weighted_mse: 1.1879 - val_loss: 0.1970 - val_accuracy: 0.5985 - val_mse: 0.8656 - val_weighted_accuracy: 0.5985 - val_weighted_mse: 0.8656
# Epoch 3/200
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2037 - accuracy: 0.3791 - mse: 1.1501 - weighted_accuracy: 0.3560 - weighted_mse: 1.1677 - val_loss: 0.2062 - val_accuracy: 0.0527 - val_mse: 0.8562 - val_weighted_accuracy: 0.0527 - val_weighted_mse: 0.8562
# Epoch 4/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2039 - accuracy: 0.3533 - mse: 1.1708 - weighted_accuracy: 0.3442 - weighted_mse: 1.1823 - val_loss: 0.2146 - val_accuracy: 0.0485 - val_mse: 0.8618 - val_weighted_accuracy: 0.0485 - val_weighted_mse: 0.8618
# Epoch 5/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2028 - accuracy: 0.2953 - mse: 1.1382 - weighted_accuracy: 0.3186 - weighted_mse: 1.1651 - val_loss: 0.2047 - val_accuracy: 0.0548 - val_mse: 0.9884 - val_weighted_accuracy: 0.0548 - val_weighted_mse: 0.9884
# Epoch 6/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2014 - accuracy: 0.3330 - mse: 1.1766 - weighted_accuracy: 0.3582 - weighted_mse: 1.1802 - val_loss: 0.2131 - val_accuracy: 0.0601 - val_mse: 0.9804 - val_weighted_accuracy: 0.0601 - val_weighted_mse: 0.9804
# Epoch 7/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1993 - accuracy: 0.2305 - mse: 1.2078 - weighted_accuracy: 0.3577 - weighted_mse: 1.1945 - val_loss: 0.2063 - val_accuracy: 0.1623 - val_mse: 0.8298 - val_weighted_accuracy: 0.1623 - val_weighted_mse: 0.8298
# Epoch 8/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2032 - accuracy: 0.4918 - mse: 1.1250 - weighted_accuracy: 0.3725 - weighted_mse: 1.1729 - val_loss: 0.1832 - val_accuracy: 0.9009 - val_mse: 0.9110 - val_weighted_accuracy: 0.9009 - val_weighted_mse: 0.9110
# Epoch 9/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2025 - accuracy: 0.4773 - mse: 1.1245 - weighted_accuracy: 0.3389 - weighted_mse: 1.1627 - val_loss: 0.1887 - val_accuracy: 0.8440 - val_mse: 0.8602 - val_weighted_accuracy: 0.8440 - val_weighted_mse: 0.8602
# Epoch 10/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1997 - accuracy: 0.3994 - mse: 1.1479 - weighted_accuracy: 0.3670 - weighted_mse: 1.1609 - val_loss: 0.2017 - val_accuracy: 0.1201 - val_mse: 0.9289 - val_weighted_accuracy: 0.1201 - val_weighted_mse: 0.9289
# Epoch 11/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1996 - accuracy: 0.3493 - mse: 1.1630 - weighted_accuracy: 0.3672 - weighted_mse: 1.1690 - val_loss: 0.2074 - val_accuracy: 0.0643 - val_mse: 0.9152 - val_weighted_accuracy: 0.0643 - val_weighted_mse: 0.9152
# Epoch 12/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1984 - accuracy: 0.3475 - mse: 1.1709 - weighted_accuracy: 0.3785 - weighted_mse: 1.1875 - val_loss: 0.2005 - val_accuracy: 0.0822 - val_mse: 0.9696 - val_weighted_accuracy: 0.0822 - val_weighted_mse: 0.9696
# Epoch 13/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2002 - accuracy: 0.3188 - mse: 1.1751 - weighted_accuracy: 0.3717 - weighted_mse: 1.1672 - val_loss: 0.2119 - val_accuracy: 0.0632 - val_mse: 0.8881 - val_weighted_accuracy: 0.0632 - val_weighted_mse: 0.8881
# Epoch 14/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1986 - accuracy: 0.2674 - mse: 1.2007 - weighted_accuracy: 0.4078 - weighted_mse: 1.1614 - val_loss: 0.2041 - val_accuracy: 0.0780 - val_mse: 0.9078 - val_weighted_accuracy: 0.0780 - val_weighted_mse: 0.9078
# Epoch 15/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2003 - accuracy: 0.3485 - mse: 1.1617 - weighted_accuracy: 0.3691 - weighted_mse: 1.1761 - val_loss: 0.1990 - val_accuracy: 0.0695 - val_mse: 1.0034 - val_weighted_accuracy: 0.0695 - val_weighted_mse: 1.0034
# Epoch 16/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1997 - accuracy: 0.3451 - mse: 1.2034 - weighted_accuracy: 0.3644 - weighted_mse: 1.1768 - val_loss: 0.1895 - val_accuracy: 0.5859 - val_mse: 0.9906 - val_weighted_accuracy: 0.5859 - val_weighted_mse: 0.9906
# Epoch 17/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1975 - accuracy: 0.2987 - mse: 1.2218 - weighted_accuracy: 0.4081 - weighted_mse: 1.2133 - val_loss: 0.2073 - val_accuracy: 0.0717 - val_mse: 0.8648 - val_weighted_accuracy: 0.0717 - val_weighted_mse: 0.8648
# Epoch 18/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1964 - accuracy: 0.2761 - mse: 1.2189 - weighted_accuracy: 0.4175 - weighted_mse: 1.1919 - val_loss: 0.1955 - val_accuracy: 0.1433 - val_mse: 0.9773 - val_weighted_accuracy: 0.1433 - val_weighted_mse: 0.9773
# Epoch 19/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1979 - accuracy: 0.2545 - mse: 1.2125 - weighted_accuracy: 0.4009 - weighted_mse: 1.2134 - val_loss: 0.1918 - val_accuracy: 0.4015 - val_mse: 0.9020 - val_weighted_accuracy: 0.4015 - val_weighted_mse: 0.9020
# Epoch 20/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1965 - accuracy: 0.3253 - mse: 1.1858 - weighted_accuracy: 0.4123 - weighted_mse: 1.1959 - val_loss: 0.2031 - val_accuracy: 0.0674 - val_mse: 0.9735 - val_weighted_accuracy: 0.0674 - val_weighted_mse: 0.9735
# Epoch 21/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1939 - accuracy: 0.2724 - mse: 1.2417 - weighted_accuracy: 0.4246 - weighted_mse: 1.2209 - val_loss: 0.2014 - val_accuracy: 0.0685 - val_mse: 0.9551 - val_weighted_accuracy: 0.0685 - val_weighted_mse: 0.9551
# Epoch 22/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1933 - accuracy: 0.3069 - mse: 1.1854 - weighted_accuracy: 0.4154 - weighted_mse: 1.1824 - val_loss: 0.2049 - val_accuracy: 0.0685 - val_mse: 0.9635 - val_weighted_accuracy: 0.0685 - val_weighted_mse: 0.9635
# Epoch 23/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1941 - accuracy: 0.2842 - mse: 1.2453 - weighted_accuracy: 0.4270 - weighted_mse: 1.2186 - val_loss: 0.2025 - val_accuracy: 0.0674 - val_mse: 0.9886 - val_weighted_accuracy: 0.0674 - val_weighted_mse: 0.9886
# Epoch 24/200
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1950 - accuracy: 0.2985 - mse: 1.2031 - weighted_accuracy: 0.4258 - weighted_mse: 1.1827 - val_loss: 0.1981 - val_accuracy: 0.0759 - val_mse: 0.9939 - val_weighted_accuracy: 0.0759 - val_weighted_mse: 0.9939
# Epoch 25/200
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1912 - accuracy: 0.2487 - mse: 1.2688 - weighted_accuracy: 0.4484 - weighted_mse: 1.2413 - val_loss: 0.2010 - val_accuracy: 0.0727 - val_mse: 0.9386 - val_weighted_accuracy: 0.0727 - val_weighted_mse: 0.9386
# Epoch 26/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1917 - accuracy: 0.2869 - mse: 1.2206 - weighted_accuracy: 0.4645 - weighted_mse: 1.2108 - val_loss: 0.1995 - val_accuracy: 0.0695 - val_mse: 1.0285 - val_weighted_accuracy: 0.0695 - val_weighted_mse: 1.0285
# Epoch 27/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1917 - accuracy: 0.2719 - mse: 1.2369 - weighted_accuracy: 0.4431 - weighted_mse: 1.2095 - val_loss: 0.1915 - val_accuracy: 0.2297 - val_mse: 0.9840 - val_weighted_accuracy: 0.2297 - val_weighted_mse: 0.9840
# Epoch 28/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1904 - accuracy: 0.2908 - mse: 1.2243 - weighted_accuracy: 0.4474 - weighted_mse: 1.2022 - val_loss: 0.2019 - val_accuracy: 0.0706 - val_mse: 1.0351 - val_weighted_accuracy: 0.0706 - val_weighted_mse: 1.0351
# Epoch 29/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1907 - accuracy: 0.2318 - mse: 1.2720 - weighted_accuracy: 0.4584 - weighted_mse: 1.2318 - val_loss: 0.1988 - val_accuracy: 0.0780 - val_mse: 0.9750 - val_weighted_accuracy: 0.0780 - val_weighted_mse: 0.9750
# Epoch 30/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1903 - accuracy: 0.2482 - mse: 1.2412 - weighted_accuracy: 0.4512 - weighted_mse: 1.2047 - val_loss: 0.1920 - val_accuracy: 0.1454 - val_mse: 1.0284 - val_weighted_accuracy: 0.1454 - val_weighted_mse: 1.0284
# Epoch 31/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1892 - accuracy: 0.2729 - mse: 1.2391 - weighted_accuracy: 0.4496 - weighted_mse: 1.2120 - val_loss: 0.1946 - val_accuracy: 0.1222 - val_mse: 1.0269 - val_weighted_accuracy: 0.1222 - val_weighted_mse: 1.0269
# Epoch 32/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1869 - accuracy: 0.2529 - mse: 1.2507 - weighted_accuracy: 0.4664 - weighted_mse: 1.2129 - val_loss: 0.1926 - val_accuracy: 0.0832 - val_mse: 1.1144 - val_weighted_accuracy: 0.0832 - val_weighted_mse: 1.1144
# Epoch 33/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1890 - accuracy: 0.2439 - mse: 1.2739 - weighted_accuracy: 0.4602 - weighted_mse: 1.2416 - val_loss: 0.1928 - val_accuracy: 0.1496 - val_mse: 1.0271 - val_weighted_accuracy: 0.1496 - val_weighted_mse: 1.0271
# Epoch 34/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1873 - accuracy: 0.2645 - mse: 1.2697 - weighted_accuracy: 0.4846 - weighted_mse: 1.2451 - val_loss: 0.2003 - val_accuracy: 0.0727 - val_mse: 1.0299 - val_weighted_accuracy: 0.0727 - val_weighted_mse: 1.0299
# Epoch 35/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1867 - accuracy: 0.2460 - mse: 1.2412 - weighted_accuracy: 0.4579 - weighted_mse: 1.2042 - val_loss: 0.1920 - val_accuracy: 0.1391 - val_mse: 1.1214 - val_weighted_accuracy: 0.1391 - val_weighted_mse: 1.1214
# Epoch 36/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1850 - accuracy: 0.2492 - mse: 1.2696 - weighted_accuracy: 0.4814 - weighted_mse: 1.2208 - val_loss: 0.1957 - val_accuracy: 0.1243 - val_mse: 1.0142 - val_weighted_accuracy: 0.1243 - val_weighted_mse: 1.0142
# Epoch 37/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1871 - accuracy: 0.2429 - mse: 1.2478 - weighted_accuracy: 0.4890 - weighted_mse: 1.2264 - val_loss: 0.1981 - val_accuracy: 0.0980 - val_mse: 0.9922 - val_weighted_accuracy: 0.0980 - val_weighted_mse: 0.9922
# Epoch 38/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1807 - accuracy: 0.2297 - mse: 1.3226 - weighted_accuracy: 0.5197 - weighted_mse: 1.2655 - val_loss: 0.1953 - val_accuracy: 0.1033 - val_mse: 1.0889 - val_weighted_accuracy: 0.1033 - val_weighted_mse: 1.0889
# Epoch 39/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1810 - accuracy: 0.2223 - mse: 1.2919 - weighted_accuracy: 0.4998 - weighted_mse: 1.2488 - val_loss: 0.1993 - val_accuracy: 0.0801 - val_mse: 1.0490 - val_weighted_accuracy: 0.0801 - val_weighted_mse: 1.0490
# Epoch 40/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1825 - accuracy: 0.2345 - mse: 1.3121 - weighted_accuracy: 0.4938 - weighted_mse: 1.2531 - val_loss: 0.1977 - val_accuracy: 0.0864 - val_mse: 1.0928 - val_weighted_accuracy: 0.0864 - val_weighted_mse: 1.0928
# Epoch 41/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1829 - accuracy: 0.2339 - mse: 1.3059 - weighted_accuracy: 0.4934 - weighted_mse: 1.2622 - val_loss: 0.1914 - val_accuracy: 0.1401 - val_mse: 1.1281 - val_weighted_accuracy: 0.1401 - val_weighted_mse: 1.1281
# Epoch 42/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1786 - accuracy: 0.2547 - mse: 1.3339 - weighted_accuracy: 0.5336 - weighted_mse: 1.2765 - val_loss: 0.1950 - val_accuracy: 0.1286 - val_mse: 1.0811 - val_weighted_accuracy: 0.1286 - val_weighted_mse: 1.0811
# Epoch 43/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1811 - accuracy: 0.2621 - mse: 1.2864 - weighted_accuracy: 0.5055 - weighted_mse: 1.2516 - val_loss: 0.1997 - val_accuracy: 0.0811 - val_mse: 1.1058 - val_weighted_accuracy: 0.0811 - val_weighted_mse: 1.1058
# Epoch 44/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1783 - accuracy: 0.2268 - mse: 1.3519 - weighted_accuracy: 0.5211 - weighted_mse: 1.2617 - val_loss: 0.1981 - val_accuracy: 0.0938 - val_mse: 1.1796 - val_weighted_accuracy: 0.0938 - val_weighted_mse: 1.1796
# Epoch 45/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1798 - accuracy: 0.2442 - mse: 1.3783 - weighted_accuracy: 0.5170 - weighted_mse: 1.3198 - val_loss: 0.1951 - val_accuracy: 0.1128 - val_mse: 1.1440 - val_weighted_accuracy: 0.1128 - val_weighted_mse: 1.1440
# Epoch 46/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1821 - accuracy: 0.2521 - mse: 1.3088 - weighted_accuracy: 0.4773 - weighted_mse: 1.2451 - val_loss: 0.1980 - val_accuracy: 0.1149 - val_mse: 1.0309 - val_weighted_accuracy: 0.1149 - val_weighted_mse: 1.0309
# Epoch 47/200
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1767 - accuracy: 0.2323 - mse: 1.3358 - weighted_accuracy: 0.5200 - weighted_mse: 1.2862 - val_loss: 0.1908 - val_accuracy: 0.1686 - val_mse: 1.1557 - val_weighted_accuracy: 0.1686 - val_weighted_mse: 1.1557
# Epoch 48/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1762 - accuracy: 0.2342 - mse: 1.3306 - weighted_accuracy: 0.5315 - weighted_mse: 1.2858 - val_loss: 0.1993 - val_accuracy: 0.0875 - val_mse: 1.1166 - val_weighted_accuracy: 0.0875 - val_weighted_mse: 1.1166
# Epoch 49/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1753 - accuracy: 0.2350 - mse: 1.3615 - weighted_accuracy: 0.5401 - weighted_mse: 1.3140 - val_loss: 0.1909 - val_accuracy: 0.1370 - val_mse: 1.1592 - val_weighted_accuracy: 0.1370 - val_weighted_mse: 1.1592
# Epoch 50/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1748 - accuracy: 0.2268 - mse: 1.3479 - weighted_accuracy: 0.5474 - weighted_mse: 1.3068 - val_loss: 0.1965 - val_accuracy: 0.1359 - val_mse: 1.0504 - val_weighted_accuracy: 0.1359 - val_weighted_mse: 1.0504
# Epoch 51/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1753 - accuracy: 0.2550 - mse: 1.3431 - weighted_accuracy: 0.5267 - weighted_mse: 1.2858 - val_loss: 0.1862 - val_accuracy: 0.2750 - val_mse: 1.0958 - val_weighted_accuracy: 0.2750 - val_weighted_mse: 1.0958
# Epoch 52/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1744 - accuracy: 0.2500 - mse: 1.3197 - weighted_accuracy: 0.5288 - weighted_mse: 1.2854 - val_loss: 0.1998 - val_accuracy: 0.1001 - val_mse: 1.1545 - val_weighted_accuracy: 0.1001 - val_weighted_mse: 1.1545
# Epoch 53/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1728 - accuracy: 0.2276 - mse: 1.3752 - weighted_accuracy: 0.5475 - weighted_mse: 1.3387 - val_loss: 0.1915 - val_accuracy: 0.2192 - val_mse: 1.0673 - val_weighted_accuracy: 0.2192 - val_weighted_mse: 1.0673
# Epoch 54/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1745 - accuracy: 0.2518 - mse: 1.3743 - weighted_accuracy: 0.5207 - weighted_mse: 1.2917 - val_loss: 0.1848 - val_accuracy: 0.2729 - val_mse: 1.1775 - val_weighted_accuracy: 0.2729 - val_weighted_mse: 1.1775
# Epoch 55/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1733 - accuracy: 0.2389 - mse: 1.3560 - weighted_accuracy: 0.5392 - weighted_mse: 1.3193 - val_loss: 0.2045 - val_accuracy: 0.0769 - val_mse: 1.0874 - val_weighted_accuracy: 0.0769 - val_weighted_mse: 1.0874
# Epoch 56/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1711 - accuracy: 0.2526 - mse: 1.4029 - weighted_accuracy: 0.5397 - weighted_mse: 1.3543 - val_loss: 0.1930 - val_accuracy: 0.1222 - val_mse: 1.1782 - val_weighted_accuracy: 0.1222 - val_weighted_mse: 1.1782
# Epoch 57/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1695 - accuracy: 0.2426 - mse: 1.4526 - weighted_accuracy: 0.5494 - weighted_mse: 1.3627 - val_loss: 0.1930 - val_accuracy: 0.1391 - val_mse: 1.1488 - val_weighted_accuracy: 0.1391 - val_weighted_mse: 1.1488
# Epoch 58/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1676 - accuracy: 0.2405 - mse: 1.4333 - weighted_accuracy: 0.5556 - weighted_mse: 1.3713 - val_loss: 0.1888 - val_accuracy: 0.2129 - val_mse: 1.1560 - val_weighted_accuracy: 0.2129 - val_weighted_mse: 1.1560
# Epoch 59/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1683 - accuracy: 0.2553 - mse: 1.3780 - weighted_accuracy: 0.5664 - weighted_mse: 1.3358 - val_loss: 0.1934 - val_accuracy: 0.1560 - val_mse: 1.2215 - val_weighted_accuracy: 0.1560 - val_weighted_mse: 1.2215
# Epoch 60/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1650 - accuracy: 0.2534 - mse: 1.4172 - weighted_accuracy: 0.5770 - weighted_mse: 1.3598 - val_loss: 0.1964 - val_accuracy: 0.1401 - val_mse: 1.2771 - val_weighted_accuracy: 0.1401 - val_weighted_mse: 1.2771
# Epoch 61/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1671 - accuracy: 0.2695 - mse: 1.3900 - weighted_accuracy: 0.5625 - weighted_mse: 1.3600 - val_loss: 0.1952 - val_accuracy: 0.1517 - val_mse: 1.1669 - val_weighted_accuracy: 0.1517 - val_weighted_mse: 1.1669
# Epoch 62/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1644 - accuracy: 0.2592 - mse: 1.4603 - weighted_accuracy: 0.5873 - weighted_mse: 1.4059 - val_loss: 0.1885 - val_accuracy: 0.2160 - val_mse: 1.2122 - val_weighted_accuracy: 0.2160 - val_weighted_mse: 1.2122
# Epoch 63/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1655 - accuracy: 0.2763 - mse: 1.3665 - weighted_accuracy: 0.5718 - weighted_mse: 1.3313 - val_loss: 0.1959 - val_accuracy: 0.1855 - val_mse: 1.2246 - val_weighted_accuracy: 0.1855 - val_weighted_mse: 1.2246
# Epoch 64/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1636 - accuracy: 0.2653 - mse: 1.4737 - weighted_accuracy: 0.5829 - weighted_mse: 1.4266 - val_loss: 0.1895 - val_accuracy: 0.1907 - val_mse: 1.3035 - val_weighted_accuracy: 0.1907 - val_weighted_mse: 1.3035
# Epoch 65/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1655 - accuracy: 0.2761 - mse: 1.4185 - weighted_accuracy: 0.5800 - weighted_mse: 1.3822 - val_loss: 0.1930 - val_accuracy: 0.1876 - val_mse: 1.1492 - val_weighted_accuracy: 0.1876 - val_weighted_mse: 1.1492
# Epoch 66/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1629 - accuracy: 0.2742 - mse: 1.3970 - weighted_accuracy: 0.5873 - weighted_mse: 1.3819 - val_loss: 0.1933 - val_accuracy: 0.1791 - val_mse: 1.1760 - val_weighted_accuracy: 0.1791 - val_weighted_mse: 1.1760
# Epoch 67/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1640 - accuracy: 0.2748 - mse: 1.4297 - weighted_accuracy: 0.5882 - weighted_mse: 1.3834 - val_loss: 0.1901 - val_accuracy: 0.1739 - val_mse: 1.2401 - val_weighted_accuracy: 0.1739 - val_weighted_mse: 1.2401
# Epoch 68/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1635 - accuracy: 0.2808 - mse: 1.4326 - weighted_accuracy: 0.5812 - weighted_mse: 1.3808 - val_loss: 0.1982 - val_accuracy: 0.1465 - val_mse: 1.1754 - val_weighted_accuracy: 0.1465 - val_weighted_mse: 1.1754
# Epoch 69/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1600 - accuracy: 0.2608 - mse: 1.4818 - weighted_accuracy: 0.6053 - weighted_mse: 1.4340 - val_loss: 0.1941 - val_accuracy: 0.1686 - val_mse: 1.3135 - val_weighted_accuracy: 0.1686 - val_weighted_mse: 1.3135
# Epoch 70/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1616 - accuracy: 0.2729 - mse: 1.4537 - weighted_accuracy: 0.5842 - weighted_mse: 1.4156 - val_loss: 0.1983 - val_accuracy: 0.1454 - val_mse: 1.2923 - val_weighted_accuracy: 0.1454 - val_weighted_mse: 1.2923
# Epoch 71/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1621 - accuracy: 0.2879 - mse: 1.4553 - weighted_accuracy: 0.5862 - weighted_mse: 1.4241 - val_loss: 0.1933 - val_accuracy: 0.1760 - val_mse: 1.1692 - val_weighted_accuracy: 0.1760 - val_weighted_mse: 1.1692
# Epoch 72/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1580 - accuracy: 0.2921 - mse: 1.4076 - weighted_accuracy: 0.6215 - weighted_mse: 1.3851 - val_loss: 0.1896 - val_accuracy: 0.2076 - val_mse: 1.3042 - val_weighted_accuracy: 0.2076 - val_weighted_mse: 1.3042
# Epoch 73/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1589 - accuracy: 0.3051 - mse: 1.5056 - weighted_accuracy: 0.6099 - weighted_mse: 1.4714 - val_loss: 0.1939 - val_accuracy: 0.1707 - val_mse: 1.2341 - val_weighted_accuracy: 0.1707 - val_weighted_mse: 1.2341
# Epoch 74/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1592 - accuracy: 0.3109 - mse: 1.4335 - weighted_accuracy: 0.6121 - weighted_mse: 1.4105 - val_loss: 0.1965 - val_accuracy: 0.1686 - val_mse: 1.2849 - val_weighted_accuracy: 0.1686 - val_weighted_mse: 1.2849
# Epoch 75/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1560 - accuracy: 0.2769 - mse: 1.5457 - weighted_accuracy: 0.6069 - weighted_mse: 1.5344 - val_loss: 0.1867 - val_accuracy: 0.2160 - val_mse: 1.3509 - val_weighted_accuracy: 0.2160 - val_weighted_mse: 1.3509
# Epoch 76/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1567 - accuracy: 0.2972 - mse: 1.5193 - weighted_accuracy: 0.6106 - weighted_mse: 1.4664 - val_loss: 0.1909 - val_accuracy: 0.2086 - val_mse: 1.2045 - val_weighted_accuracy: 0.2086 - val_weighted_mse: 1.2045
# Epoch 77/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1552 - accuracy: 0.3130 - mse: 1.5005 - weighted_accuracy: 0.6163 - weighted_mse: 1.4644 - val_loss: 0.1886 - val_accuracy: 0.2297 - val_mse: 1.2951 - val_weighted_accuracy: 0.2297 - val_weighted_mse: 1.2951
# Epoch 78/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1550 - accuracy: 0.3151 - mse: 1.4891 - weighted_accuracy: 0.6224 - weighted_mse: 1.4417 - val_loss: 0.1918 - val_accuracy: 0.2266 - val_mse: 1.1784 - val_weighted_accuracy: 0.2266 - val_weighted_mse: 1.1784
# Epoch 79/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1528 - accuracy: 0.3093 - mse: 1.5060 - weighted_accuracy: 0.6293 - weighted_mse: 1.4752 - val_loss: 0.1861 - val_accuracy: 0.2677 - val_mse: 1.2922 - val_weighted_accuracy: 0.2677 - val_weighted_mse: 1.2922
# Epoch 80/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1540 - accuracy: 0.2871 - mse: 1.5525 - weighted_accuracy: 0.6124 - weighted_mse: 1.5067 - val_loss: 0.1870 - val_accuracy: 0.2445 - val_mse: 1.3483 - val_weighted_accuracy: 0.2445 - val_weighted_mse: 1.3483
# Epoch 81/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1525 - accuracy: 0.3274 - mse: 1.5138 - weighted_accuracy: 0.6347 - weighted_mse: 1.4926 - val_loss: 0.1977 - val_accuracy: 0.1581 - val_mse: 1.3342 - val_weighted_accuracy: 0.1581 - val_weighted_mse: 1.3342
# Epoch 82/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1534 - accuracy: 0.2766 - mse: 1.5043 - weighted_accuracy: 0.6143 - weighted_mse: 1.4632 - val_loss: 0.1857 - val_accuracy: 0.2634 - val_mse: 1.3392 - val_weighted_accuracy: 0.2634 - val_weighted_mse: 1.3392
# Epoch 83/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1504 - accuracy: 0.3019 - mse: 1.5553 - weighted_accuracy: 0.6478 - weighted_mse: 1.5169 - val_loss: 0.1872 - val_accuracy: 0.2487 - val_mse: 1.4385 - val_weighted_accuracy: 0.2487 - val_weighted_mse: 1.4385
# Epoch 84/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1504 - accuracy: 0.3180 - mse: 1.5031 - weighted_accuracy: 0.6295 - weighted_mse: 1.5021 - val_loss: 0.1835 - val_accuracy: 0.2803 - val_mse: 1.2989 - val_weighted_accuracy: 0.2803 - val_weighted_mse: 1.2989
# Epoch 85/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1497 - accuracy: 0.3182 - mse: 1.5034 - weighted_accuracy: 0.6361 - weighted_mse: 1.5033 - val_loss: 0.1913 - val_accuracy: 0.2318 - val_mse: 1.3700 - val_weighted_accuracy: 0.2318 - val_weighted_mse: 1.3700
# Epoch 86/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1513 - accuracy: 0.3193 - mse: 1.5952 - weighted_accuracy: 0.6123 - weighted_mse: 1.5582 - val_loss: 0.1914 - val_accuracy: 0.2065 - val_mse: 1.3484 - val_weighted_accuracy: 0.2065 - val_weighted_mse: 1.3484
# Epoch 87/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1474 - accuracy: 0.3138 - mse: 1.5648 - weighted_accuracy: 0.6386 - weighted_mse: 1.5562 - val_loss: 0.1822 - val_accuracy: 0.3330 - val_mse: 1.3226 - val_weighted_accuracy: 0.3330 - val_weighted_mse: 1.3226
# Epoch 88/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1478 - accuracy: 0.3188 - mse: 1.5803 - weighted_accuracy: 0.6503 - weighted_mse: 1.5884 - val_loss: 0.1823 - val_accuracy: 0.3098 - val_mse: 1.3698 - val_weighted_accuracy: 0.3098 - val_weighted_mse: 1.3698
# Epoch 89/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1498 - accuracy: 0.3224 - mse: 1.5643 - weighted_accuracy: 0.6386 - weighted_mse: 1.5679 - val_loss: 0.1891 - val_accuracy: 0.2761 - val_mse: 1.3388 - val_weighted_accuracy: 0.2761 - val_weighted_mse: 1.3388
# Epoch 90/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1481 - accuracy: 0.3296 - mse: 1.5514 - weighted_accuracy: 0.6474 - weighted_mse: 1.5376 - val_loss: 0.1923 - val_accuracy: 0.2518 - val_mse: 1.3232 - val_weighted_accuracy: 0.2518 - val_weighted_mse: 1.3232
# Epoch 91/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1450 - accuracy: 0.3343 - mse: 1.5831 - weighted_accuracy: 0.6422 - weighted_mse: 1.6000 - val_loss: 0.1784 - val_accuracy: 0.3846 - val_mse: 1.2706 - val_weighted_accuracy: 0.3846 - val_weighted_mse: 1.2706
# Epoch 92/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1483 - accuracy: 0.3480 - mse: 1.5667 - weighted_accuracy: 0.6547 - weighted_mse: 1.5515 - val_loss: 0.1827 - val_accuracy: 0.3256 - val_mse: 1.2990 - val_weighted_accuracy: 0.3256 - val_weighted_mse: 1.2990
# Epoch 93/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1448 - accuracy: 0.3741 - mse: 1.5995 - weighted_accuracy: 0.6626 - weighted_mse: 1.6241 - val_loss: 0.1913 - val_accuracy: 0.2518 - val_mse: 1.3293 - val_weighted_accuracy: 0.2518 - val_weighted_mse: 1.3293
# Epoch 94/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1437 - accuracy: 0.3151 - mse: 1.5536 - weighted_accuracy: 0.6513 - weighted_mse: 1.5891 - val_loss: 0.1861 - val_accuracy: 0.2877 - val_mse: 1.3224 - val_weighted_accuracy: 0.2877 - val_weighted_mse: 1.3224
# Epoch 95/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1436 - accuracy: 0.3688 - mse: 1.5907 - weighted_accuracy: 0.6654 - weighted_mse: 1.6238 - val_loss: 0.1912 - val_accuracy: 0.2445 - val_mse: 1.3622 - val_weighted_accuracy: 0.2445 - val_weighted_mse: 1.3622
# Epoch 96/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1424 - accuracy: 0.3477 - mse: 1.5756 - weighted_accuracy: 0.6616 - weighted_mse: 1.6198 - val_loss: 0.1898 - val_accuracy: 0.2687 - val_mse: 1.4133 - val_weighted_accuracy: 0.2687 - val_weighted_mse: 1.4133
# Epoch 97/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1430 - accuracy: 0.3743 - mse: 1.6214 - weighted_accuracy: 0.6808 - weighted_mse: 1.6015 - val_loss: 0.1815 - val_accuracy: 0.3583 - val_mse: 1.3924 - val_weighted_accuracy: 0.3583 - val_weighted_mse: 1.3924
# Epoch 98/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1380 - accuracy: 0.3604 - mse: 1.6461 - weighted_accuracy: 0.6783 - weighted_mse: 1.7201 - val_loss: 0.1783 - val_accuracy: 0.3720 - val_mse: 1.4112 - val_weighted_accuracy: 0.3720 - val_weighted_mse: 1.4112
# Epoch 99/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1395 - accuracy: 0.3701 - mse: 1.6297 - weighted_accuracy: 0.6784 - weighted_mse: 1.6571 - val_loss: 0.1905 - val_accuracy: 0.2803 - val_mse: 1.3650 - val_weighted_accuracy: 0.2803 - val_weighted_mse: 1.3650
# Epoch 100/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1386 - accuracy: 0.3809 - mse: 1.6705 - weighted_accuracy: 0.6861 - weighted_mse: 1.7364 - val_loss: 0.1862 - val_accuracy: 0.3193 - val_mse: 1.4114 - val_weighted_accuracy: 0.3193 - val_weighted_mse: 1.4114
# Epoch 101/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1409 - accuracy: 0.3841 - mse: 1.6366 - weighted_accuracy: 0.6700 - weighted_mse: 1.6696 - val_loss: 0.1933 - val_accuracy: 0.2592 - val_mse: 1.4234 - val_weighted_accuracy: 0.2592 - val_weighted_mse: 1.4234
# Epoch 102/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1401 - accuracy: 0.3907 - mse: 1.6112 - weighted_accuracy: 0.6671 - weighted_mse: 1.6985 - val_loss: 0.1881 - val_accuracy: 0.3151 - val_mse: 1.3898 - val_weighted_accuracy: 0.3151 - val_weighted_mse: 1.3898
# Epoch 103/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1394 - accuracy: 0.3952 - mse: 1.6815 - weighted_accuracy: 0.6740 - weighted_mse: 1.7432 - val_loss: 0.1764 - val_accuracy: 0.4057 - val_mse: 1.4650 - val_weighted_accuracy: 0.4057 - val_weighted_mse: 1.4650
# Epoch 104/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1379 - accuracy: 0.3899 - mse: 1.6594 - weighted_accuracy: 0.6753 - weighted_mse: 1.7360 - val_loss: 0.1958 - val_accuracy: 0.2434 - val_mse: 1.4209 - val_weighted_accuracy: 0.2434 - val_weighted_mse: 1.4209
# Epoch 105/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1362 - accuracy: 0.3841 - mse: 1.6607 - weighted_accuracy: 0.6883 - weighted_mse: 1.7611 - val_loss: 0.1656 - val_accuracy: 0.5385 - val_mse: 1.4390 - val_weighted_accuracy: 0.5385 - val_weighted_mse: 1.4390
# Epoch 106/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1345 - accuracy: 0.4157 - mse: 1.6794 - weighted_accuracy: 0.7008 - weighted_mse: 1.7490 - val_loss: 0.1800 - val_accuracy: 0.4004 - val_mse: 1.4595 - val_weighted_accuracy: 0.4004 - val_weighted_mse: 1.4595
# Epoch 107/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1365 - accuracy: 0.4023 - mse: 1.6757 - weighted_accuracy: 0.6947 - weighted_mse: 1.7610 - val_loss: 0.1807 - val_accuracy: 0.4025 - val_mse: 1.4159 - val_weighted_accuracy: 0.4025 - val_weighted_mse: 1.4159
# Epoch 108/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1341 - accuracy: 0.4112 - mse: 1.6696 - weighted_accuracy: 0.6870 - weighted_mse: 1.7569 - val_loss: 0.1785 - val_accuracy: 0.4257 - val_mse: 1.4068 - val_weighted_accuracy: 0.4257 - val_weighted_mse: 1.4068
# Epoch 109/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1362 - accuracy: 0.4249 - mse: 1.6498 - weighted_accuracy: 0.6905 - weighted_mse: 1.7174 - val_loss: 0.1699 - val_accuracy: 0.4953 - val_mse: 1.4442 - val_weighted_accuracy: 0.4953 - val_weighted_mse: 1.4442
# Epoch 110/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1337 - accuracy: 0.4399 - mse: 1.6882 - weighted_accuracy: 0.6939 - weighted_mse: 1.7651 - val_loss: 0.1798 - val_accuracy: 0.3941 - val_mse: 1.5427 - val_weighted_accuracy: 0.3941 - val_weighted_mse: 1.5427
# Epoch 111/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1310 - accuracy: 0.4521 - mse: 1.6759 - weighted_accuracy: 0.7216 - weighted_mse: 1.8374 - val_loss: 0.1806 - val_accuracy: 0.3994 - val_mse: 1.5111 - val_weighted_accuracy: 0.3994 - val_weighted_mse: 1.5111
# Epoch 112/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1302 - accuracy: 0.4465 - mse: 1.7135 - weighted_accuracy: 0.7214 - weighted_mse: 1.8558 - val_loss: 0.1750 - val_accuracy: 0.4499 - val_mse: 1.5178 - val_weighted_accuracy: 0.4499 - val_weighted_mse: 1.5178
# Epoch 113/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1296 - accuracy: 0.4368 - mse: 1.7376 - weighted_accuracy: 0.7192 - weighted_mse: 1.8695 - val_loss: 0.1716 - val_accuracy: 0.5026 - val_mse: 1.3986 - val_weighted_accuracy: 0.5026 - val_weighted_mse: 1.3986
# Epoch 114/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1321 - accuracy: 0.4642 - mse: 1.7003 - weighted_accuracy: 0.7119 - weighted_mse: 1.8070 - val_loss: 0.1811 - val_accuracy: 0.4015 - val_mse: 1.5634 - val_weighted_accuracy: 0.4015 - val_weighted_mse: 1.5634
# Epoch 115/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1266 - accuracy: 0.4594 - mse: 1.7858 - weighted_accuracy: 0.7221 - weighted_mse: 1.9795 - val_loss: 0.1899 - val_accuracy: 0.3425 - val_mse: 1.6035 - val_weighted_accuracy: 0.3425 - val_weighted_mse: 1.6035
# Epoch 116/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1273 - accuracy: 0.4621 - mse: 1.7541 - weighted_accuracy: 0.7272 - weighted_mse: 1.9106 - val_loss: 0.1863 - val_accuracy: 0.3688 - val_mse: 1.4992 - val_weighted_accuracy: 0.3688 - val_weighted_mse: 1.4992
# Epoch 117/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1256 - accuracy: 0.4610 - mse: 1.7325 - weighted_accuracy: 0.7353 - weighted_mse: 1.8921 - val_loss: 0.1853 - val_accuracy: 0.4004 - val_mse: 1.5927 - val_weighted_accuracy: 0.4004 - val_weighted_mse: 1.5927
# Epoch 118/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1287 - accuracy: 0.4676 - mse: 1.7586 - weighted_accuracy: 0.7243 - weighted_mse: 1.9292 - val_loss: 0.1753 - val_accuracy: 0.4773 - val_mse: 1.5663 - val_weighted_accuracy: 0.4773 - val_weighted_mse: 1.5663
# Epoch 119/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1271 - accuracy: 0.4750 - mse: 1.8008 - weighted_accuracy: 0.7195 - weighted_mse: 1.9817 - val_loss: 0.1822 - val_accuracy: 0.4204 - val_mse: 1.5597 - val_weighted_accuracy: 0.4204 - val_weighted_mse: 1.5597
# Epoch 120/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1268 - accuracy: 0.4802 - mse: 1.7210 - weighted_accuracy: 0.7321 - weighted_mse: 1.8859 - val_loss: 0.1832 - val_accuracy: 0.4025 - val_mse: 1.6048 - val_weighted_accuracy: 0.4025 - val_weighted_mse: 1.6048
# Epoch 121/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1241 - accuracy: 0.4939 - mse: 1.7783 - weighted_accuracy: 0.7387 - weighted_mse: 1.9951 - val_loss: 0.1666 - val_accuracy: 0.5385 - val_mse: 1.5050 - val_weighted_accuracy: 0.5385 - val_weighted_mse: 1.5050
# Epoch 122/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1269 - accuracy: 0.4989 - mse: 1.7696 - weighted_accuracy: 0.7055 - weighted_mse: 1.9773 - val_loss: 0.1615 - val_accuracy: 0.5922 - val_mse: 1.4359 - val_weighted_accuracy: 0.5922 - val_weighted_mse: 1.4359
# Epoch 123/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1229 - accuracy: 0.4887 - mse: 1.7857 - weighted_accuracy: 0.7475 - weighted_mse: 2.0011 - val_loss: 0.1660 - val_accuracy: 0.5585 - val_mse: 1.5482 - val_weighted_accuracy: 0.5585 - val_weighted_mse: 1.5482
# Epoch 124/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1206 - accuracy: 0.5034 - mse: 1.8340 - weighted_accuracy: 0.7546 - weighted_mse: 2.0827 - val_loss: 0.1621 - val_accuracy: 0.5806 - val_mse: 1.4921 - val_weighted_accuracy: 0.5806 - val_weighted_mse: 1.4921
# Epoch 125/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1200 - accuracy: 0.5177 - mse: 1.8361 - weighted_accuracy: 0.7602 - weighted_mse: 2.1334 - val_loss: 0.1741 - val_accuracy: 0.4921 - val_mse: 1.5672 - val_weighted_accuracy: 0.4921 - val_weighted_mse: 1.5672
# Epoch 126/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1212 - accuracy: 0.5361 - mse: 1.8498 - weighted_accuracy: 0.7542 - weighted_mse: 2.0801 - val_loss: 0.1671 - val_accuracy: 0.5437 - val_mse: 1.4810 - val_weighted_accuracy: 0.5437 - val_weighted_mse: 1.4810
# Epoch 127/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1204 - accuracy: 0.5271 - mse: 1.7808 - weighted_accuracy: 0.7560 - weighted_mse: 2.0330 - val_loss: 0.1650 - val_accuracy: 0.5595 - val_mse: 1.5282 - val_weighted_accuracy: 0.5595 - val_weighted_mse: 1.5282
# Epoch 128/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1187 - accuracy: 0.5277 - mse: 1.8750 - weighted_accuracy: 0.7631 - weighted_mse: 2.1561 - val_loss: 0.1460 - val_accuracy: 0.7018 - val_mse: 1.5442 - val_weighted_accuracy: 0.7018 - val_weighted_mse: 1.5442
# Epoch 129/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1209 - accuracy: 0.5303 - mse: 1.7758 - weighted_accuracy: 0.7595 - weighted_mse: 1.9947 - val_loss: 0.1720 - val_accuracy: 0.5142 - val_mse: 1.6421 - val_weighted_accuracy: 0.5142 - val_weighted_mse: 1.6421
# Epoch 130/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1247 - accuracy: 0.5364 - mse: 1.8582 - weighted_accuracy: 0.7335 - weighted_mse: 2.0836 - val_loss: 0.1849 - val_accuracy: 0.4131 - val_mse: 1.5883 - val_weighted_accuracy: 0.4131 - val_weighted_mse: 1.5883
# Epoch 131/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1166 - accuracy: 0.5208 - mse: 1.8643 - weighted_accuracy: 0.7589 - weighted_mse: 2.1839 - val_loss: 0.1586 - val_accuracy: 0.6091 - val_mse: 1.6101 - val_weighted_accuracy: 0.6091 - val_weighted_mse: 1.6101
# Epoch 132/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1181 - accuracy: 0.5427 - mse: 1.8981 - weighted_accuracy: 0.7709 - weighted_mse: 2.1478 - val_loss: 0.1720 - val_accuracy: 0.5300 - val_mse: 1.6601 - val_weighted_accuracy: 0.5300 - val_weighted_mse: 1.6601
# Epoch 133/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1138 - accuracy: 0.5485 - mse: 1.9237 - weighted_accuracy: 0.7716 - weighted_mse: 2.2383 - val_loss: 0.1689 - val_accuracy: 0.5479 - val_mse: 1.6932 - val_weighted_accuracy: 0.5479 - val_weighted_mse: 1.6932
# Epoch 134/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1188 - accuracy: 0.5543 - mse: 1.8606 - weighted_accuracy: 0.7614 - weighted_mse: 2.1302 - val_loss: 0.1483 - val_accuracy: 0.6807 - val_mse: 1.6206 - val_weighted_accuracy: 0.6807 - val_weighted_mse: 1.6206
# Epoch 135/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1159 - accuracy: 0.5659 - mse: 1.8599 - weighted_accuracy: 0.7846 - weighted_mse: 2.1761 - val_loss: 0.1598 - val_accuracy: 0.6070 - val_mse: 1.7034 - val_weighted_accuracy: 0.6070 - val_weighted_mse: 1.7034
# Epoch 136/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1192 - accuracy: 0.5835 - mse: 1.8945 - weighted_accuracy: 0.7579 - weighted_mse: 2.1863 - val_loss: 0.1642 - val_accuracy: 0.5911 - val_mse: 1.6378 - val_weighted_accuracy: 0.5911 - val_weighted_mse: 1.6378
# Epoch 137/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1131 - accuracy: 0.5759 - mse: 1.8893 - weighted_accuracy: 0.7949 - weighted_mse: 2.1937 - val_loss: 0.1581 - val_accuracy: 0.6154 - val_mse: 1.5547 - val_weighted_accuracy: 0.6154 - val_weighted_mse: 1.5547
# Epoch 138/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1098 - accuracy: 0.5854 - mse: 1.9330 - weighted_accuracy: 0.7970 - weighted_mse: 2.3178 - val_loss: 0.1597 - val_accuracy: 0.6006 - val_mse: 1.6173 - val_weighted_accuracy: 0.6006 - val_weighted_mse: 1.6173
# Epoch 139/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1110 - accuracy: 0.5638 - mse: 1.9362 - weighted_accuracy: 0.7803 - weighted_mse: 2.3036 - val_loss: 0.1380 - val_accuracy: 0.7366 - val_mse: 1.6679 - val_weighted_accuracy: 0.7366 - val_weighted_mse: 1.6679
# Epoch 140/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1126 - accuracy: 0.5777 - mse: 1.9300 - weighted_accuracy: 0.7762 - weighted_mse: 2.2838 - val_loss: 0.1671 - val_accuracy: 0.5585 - val_mse: 1.6883 - val_weighted_accuracy: 0.5585 - val_weighted_mse: 1.6883
# Epoch 141/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1091 - accuracy: 0.5832 - mse: 1.9100 - weighted_accuracy: 0.7958 - weighted_mse: 2.3587 - val_loss: 0.1698 - val_accuracy: 0.5479 - val_mse: 1.6594 - val_weighted_accuracy: 0.5479 - val_weighted_mse: 1.6594
# Epoch 142/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1108 - accuracy: 0.5872 - mse: 1.9358 - weighted_accuracy: 0.7905 - weighted_mse: 2.3488 - val_loss: 0.1497 - val_accuracy: 0.6565 - val_mse: 1.6352 - val_weighted_accuracy: 0.6565 - val_weighted_mse: 1.6352
# Epoch 143/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1074 - accuracy: 0.5985 - mse: 1.9671 - weighted_accuracy: 0.8139 - weighted_mse: 2.4057 - val_loss: 0.1383 - val_accuracy: 0.7250 - val_mse: 1.6688 - val_weighted_accuracy: 0.7250 - val_weighted_mse: 1.6688
# Epoch 144/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1096 - accuracy: 0.6085 - mse: 1.9449 - weighted_accuracy: 0.7983 - weighted_mse: 2.3669 - val_loss: 0.1613 - val_accuracy: 0.5954 - val_mse: 1.7055 - val_weighted_accuracy: 0.5954 - val_weighted_mse: 1.7055
# Epoch 145/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1062 - accuracy: 0.5969 - mse: 2.0332 - weighted_accuracy: 0.8013 - weighted_mse: 2.5973 - val_loss: 0.1511 - val_accuracy: 0.6544 - val_mse: 1.5602 - val_weighted_accuracy: 0.6544 - val_weighted_mse: 1.5602
# Epoch 146/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1033 - accuracy: 0.6117 - mse: 2.0187 - weighted_accuracy: 0.8064 - weighted_mse: 2.5273 - val_loss: 0.1471 - val_accuracy: 0.6733 - val_mse: 1.5749 - val_weighted_accuracy: 0.6733 - val_weighted_mse: 1.5749
# Epoch 147/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1073 - accuracy: 0.6185 - mse: 2.0171 - weighted_accuracy: 0.8094 - weighted_mse: 2.4499 - val_loss: 0.1583 - val_accuracy: 0.6112 - val_mse: 1.7250 - val_weighted_accuracy: 0.6112 - val_weighted_mse: 1.7250
# Epoch 148/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1043 - accuracy: 0.5988 - mse: 2.0089 - weighted_accuracy: 0.7963 - weighted_mse: 2.4853 - val_loss: 0.1467 - val_accuracy: 0.6828 - val_mse: 1.6247 - val_weighted_accuracy: 0.6828 - val_weighted_mse: 1.6247
# Epoch 149/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1080 - accuracy: 0.6151 - mse: 2.0094 - weighted_accuracy: 0.7920 - weighted_mse: 2.4174 - val_loss: 0.1602 - val_accuracy: 0.6080 - val_mse: 1.7679 - val_weighted_accuracy: 0.6080 - val_weighted_mse: 1.7679
# Epoch 150/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1088 - accuracy: 0.6162 - mse: 2.0512 - weighted_accuracy: 0.8050 - weighted_mse: 2.5049 - val_loss: 0.1624 - val_accuracy: 0.5975 - val_mse: 1.8375 - val_weighted_accuracy: 0.5975 - val_weighted_mse: 1.8375
# Epoch 151/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1018 - accuracy: 0.6296 - mse: 2.0322 - weighted_accuracy: 0.8270 - weighted_mse: 2.5527 - val_loss: 0.1515 - val_accuracy: 0.6459 - val_mse: 1.7737 - val_weighted_accuracy: 0.6459 - val_weighted_mse: 1.7737
# Epoch 152/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1023 - accuracy: 0.6320 - mse: 2.0215 - weighted_accuracy: 0.8015 - weighted_mse: 2.5769 - val_loss: 0.1495 - val_accuracy: 0.6554 - val_mse: 1.7437 - val_weighted_accuracy: 0.6554 - val_weighted_mse: 1.7437
# Epoch 153/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1046 - accuracy: 0.6362 - mse: 2.0642 - weighted_accuracy: 0.8034 - weighted_mse: 2.5829 - val_loss: 0.1537 - val_accuracy: 0.6417 - val_mse: 1.7449 - val_weighted_accuracy: 0.6417 - val_weighted_mse: 1.7449
# Epoch 154/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1038 - accuracy: 0.6222 - mse: 2.0869 - weighted_accuracy: 0.8161 - weighted_mse: 2.6352 - val_loss: 0.1549 - val_accuracy: 0.6301 - val_mse: 1.7000 - val_weighted_accuracy: 0.6301 - val_weighted_mse: 1.7000
# Epoch 155/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0987 - accuracy: 0.6341 - mse: 2.0337 - weighted_accuracy: 0.8217 - weighted_mse: 2.6261 - val_loss: 0.1396 - val_accuracy: 0.7050 - val_mse: 1.6882 - val_weighted_accuracy: 0.7050 - val_weighted_mse: 1.6882
# Epoch 156/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1002 - accuracy: 0.6560 - mse: 2.1122 - weighted_accuracy: 0.8243 - weighted_mse: 2.6592 - val_loss: 0.1547 - val_accuracy: 0.6375 - val_mse: 1.7069 - val_weighted_accuracy: 0.6375 - val_weighted_mse: 1.7069
# Epoch 157/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1010 - accuracy: 0.6241 - mse: 2.0889 - weighted_accuracy: 0.8024 - weighted_mse: 2.7044 - val_loss: 0.1400 - val_accuracy: 0.7081 - val_mse: 1.6335 - val_weighted_accuracy: 0.7081 - val_weighted_mse: 1.6335
# Epoch 158/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0968 - accuracy: 0.6544 - mse: 2.0998 - weighted_accuracy: 0.8328 - weighted_mse: 2.7442 - val_loss: 0.1418 - val_accuracy: 0.6955 - val_mse: 1.8309 - val_weighted_accuracy: 0.6955 - val_weighted_mse: 1.8309
# Epoch 159/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0968 - accuracy: 0.6491 - mse: 2.1257 - weighted_accuracy: 0.8273 - weighted_mse: 2.7740 - val_loss: 0.1461 - val_accuracy: 0.6754 - val_mse: 1.8063 - val_weighted_accuracy: 0.6754 - val_weighted_mse: 1.8063
# Epoch 160/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0945 - accuracy: 0.6575 - mse: 2.1797 - weighted_accuracy: 0.8376 - weighted_mse: 2.9001 - val_loss: 0.1480 - val_accuracy: 0.6765 - val_mse: 1.7739 - val_weighted_accuracy: 0.6765 - val_weighted_mse: 1.7739
# Epoch 161/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0951 - accuracy: 0.6565 - mse: 2.1006 - weighted_accuracy: 0.8350 - weighted_mse: 2.7933 - val_loss: 0.1337 - val_accuracy: 0.7229 - val_mse: 1.7330 - val_weighted_accuracy: 0.7229 - val_weighted_mse: 1.7330
# Epoch 162/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0931 - accuracy: 0.6591 - mse: 2.1928 - weighted_accuracy: 0.8400 - weighted_mse: 2.8559 - val_loss: 0.1270 - val_accuracy: 0.7545 - val_mse: 1.7271 - val_weighted_accuracy: 0.7545 - val_weighted_mse: 1.7271
# Epoch 163/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0904 - accuracy: 0.6649 - mse: 2.2183 - weighted_accuracy: 0.8438 - weighted_mse: 2.9643 - val_loss: 0.1307 - val_accuracy: 0.7460 - val_mse: 1.7637 - val_weighted_accuracy: 0.7460 - val_weighted_mse: 1.7637
# Epoch 164/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0926 - accuracy: 0.6710 - mse: 2.1631 - weighted_accuracy: 0.8458 - weighted_mse: 2.8694 - val_loss: 0.1438 - val_accuracy: 0.6828 - val_mse: 1.9080 - val_weighted_accuracy: 0.6828 - val_weighted_mse: 1.9080
# Epoch 165/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0896 - accuracy: 0.6673 - mse: 2.2604 - weighted_accuracy: 0.8480 - weighted_mse: 3.0027 - val_loss: 0.1289 - val_accuracy: 0.7408 - val_mse: 1.8227 - val_weighted_accuracy: 0.7408 - val_weighted_mse: 1.8227
# Epoch 166/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0911 - accuracy: 0.6567 - mse: 2.2055 - weighted_accuracy: 0.8371 - weighted_mse: 2.9224 - val_loss: 0.1478 - val_accuracy: 0.6733 - val_mse: 1.8745 - val_weighted_accuracy: 0.6733 - val_weighted_mse: 1.8745
# Epoch 167/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0901 - accuracy: 0.6649 - mse: 2.2994 - weighted_accuracy: 0.8349 - weighted_mse: 3.1592 - val_loss: 0.1533 - val_accuracy: 0.6586 - val_mse: 1.9538 - val_weighted_accuracy: 0.6586 - val_weighted_mse: 1.9538
# Epoch 168/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0935 - accuracy: 0.6660 - mse: 2.2432 - weighted_accuracy: 0.8266 - weighted_mse: 3.0011 - val_loss: 0.1381 - val_accuracy: 0.7187 - val_mse: 1.8346 - val_weighted_accuracy: 0.7187 - val_weighted_mse: 1.8346
# Epoch 169/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0911 - accuracy: 0.6802 - mse: 2.1909 - weighted_accuracy: 0.8353 - weighted_mse: 2.9686 - val_loss: 0.1347 - val_accuracy: 0.7144 - val_mse: 1.9062 - val_weighted_accuracy: 0.7144 - val_weighted_mse: 1.9062
# Epoch 170/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0877 - accuracy: 0.6697 - mse: 2.2940 - weighted_accuracy: 0.8419 - weighted_mse: 3.0810 - val_loss: 0.1274 - val_accuracy: 0.7429 - val_mse: 1.8424 - val_weighted_accuracy: 0.7429 - val_weighted_mse: 1.8424
# Epoch 171/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0866 - accuracy: 0.6768 - mse: 2.3225 - weighted_accuracy: 0.8481 - weighted_mse: 3.1635 - val_loss: 0.1240 - val_accuracy: 0.7629 - val_mse: 1.8034 - val_weighted_accuracy: 0.7629 - val_weighted_mse: 1.8034
# Epoch 172/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0879 - accuracy: 0.6786 - mse: 2.2855 - weighted_accuracy: 0.8451 - weighted_mse: 3.1792 - val_loss: 0.1359 - val_accuracy: 0.7050 - val_mse: 1.9154 - val_weighted_accuracy: 0.7050 - val_weighted_mse: 1.9154
# Epoch 173/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0882 - accuracy: 0.6923 - mse: 2.3548 - weighted_accuracy: 0.8394 - weighted_mse: 3.1658 - val_loss: 0.1432 - val_accuracy: 0.6881 - val_mse: 1.8745 - val_weighted_accuracy: 0.6881 - val_weighted_mse: 1.8745
# Epoch 174/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0862 - accuracy: 0.6976 - mse: 2.3543 - weighted_accuracy: 0.8540 - weighted_mse: 3.2980 - val_loss: 0.1360 - val_accuracy: 0.7144 - val_mse: 1.8665 - val_weighted_accuracy: 0.7144 - val_weighted_mse: 1.8665
# Epoch 175/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0900 - accuracy: 0.6860 - mse: 2.3687 - weighted_accuracy: 0.8445 - weighted_mse: 3.1891 - val_loss: 0.1369 - val_accuracy: 0.7113 - val_mse: 1.7870 - val_weighted_accuracy: 0.7113 - val_weighted_mse: 1.7870
# Epoch 176/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0867 - accuracy: 0.6899 - mse: 2.2642 - weighted_accuracy: 0.8459 - weighted_mse: 3.1336 - val_loss: 0.1329 - val_accuracy: 0.7239 - val_mse: 1.9194 - val_weighted_accuracy: 0.7239 - val_weighted_mse: 1.9194
# Epoch 177/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0832 - accuracy: 0.7015 - mse: 2.3866 - weighted_accuracy: 0.8673 - weighted_mse: 3.2855 - val_loss: 0.1233 - val_accuracy: 0.7608 - val_mse: 2.0083 - val_weighted_accuracy: 0.7608 - val_weighted_mse: 2.0083
# Epoch 178/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0873 - accuracy: 0.6860 - mse: 2.4448 - weighted_accuracy: 0.8390 - weighted_mse: 3.2760 - val_loss: 0.1301 - val_accuracy: 0.7302 - val_mse: 1.9698 - val_weighted_accuracy: 0.7302 - val_weighted_mse: 1.9698
# Epoch 179/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0882 - accuracy: 0.6994 - mse: 2.4398 - weighted_accuracy: 0.8496 - weighted_mse: 3.3205 - val_loss: 0.1276 - val_accuracy: 0.7482 - val_mse: 1.7908 - val_weighted_accuracy: 0.7482 - val_weighted_mse: 1.7908
# Epoch 180/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0808 - accuracy: 0.6878 - mse: 2.4315 - weighted_accuracy: 0.8555 - weighted_mse: 3.4179 - val_loss: 0.1154 - val_accuracy: 0.7924 - val_mse: 1.8552 - val_weighted_accuracy: 0.7924 - val_weighted_mse: 1.8552
# Epoch 181/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0841 - accuracy: 0.6947 - mse: 2.4547 - weighted_accuracy: 0.8507 - weighted_mse: 3.2111 - val_loss: 0.1452 - val_accuracy: 0.6754 - val_mse: 1.9098 - val_weighted_accuracy: 0.6754 - val_weighted_mse: 1.9098
# Epoch 182/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0788 - accuracy: 0.7081 - mse: 2.4666 - weighted_accuracy: 0.8717 - weighted_mse: 3.4520 - val_loss: 0.1206 - val_accuracy: 0.7713 - val_mse: 1.9671 - val_weighted_accuracy: 0.7713 - val_weighted_mse: 1.9671
# Epoch 183/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0851 - accuracy: 0.6934 - mse: 2.4989 - weighted_accuracy: 0.8474 - weighted_mse: 3.4541 - val_loss: 0.1224 - val_accuracy: 0.7629 - val_mse: 2.0050 - val_weighted_accuracy: 0.7629 - val_weighted_mse: 2.0050
# Epoch 184/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0811 - accuracy: 0.7115 - mse: 2.4912 - weighted_accuracy: 0.8677 - weighted_mse: 3.5357 - val_loss: 0.1250 - val_accuracy: 0.7545 - val_mse: 2.0217 - val_weighted_accuracy: 0.7545 - val_weighted_mse: 2.0217
# Epoch 185/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0840 - accuracy: 0.6986 - mse: 2.4460 - weighted_accuracy: 0.8440 - weighted_mse: 3.4134 - val_loss: 0.1288 - val_accuracy: 0.7439 - val_mse: 2.0319 - val_weighted_accuracy: 0.7439 - val_weighted_mse: 2.0319
# Epoch 186/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0839 - accuracy: 0.7018 - mse: 2.4695 - weighted_accuracy: 0.8503 - weighted_mse: 3.4944 - val_loss: 0.1225 - val_accuracy: 0.7703 - val_mse: 1.9685 - val_weighted_accuracy: 0.7703 - val_weighted_mse: 1.9685
# Epoch 187/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0774 - accuracy: 0.7115 - mse: 2.4721 - weighted_accuracy: 0.8690 - weighted_mse: 3.5717 - val_loss: 0.1336 - val_accuracy: 0.7355 - val_mse: 2.1112 - val_weighted_accuracy: 0.7355 - val_weighted_mse: 2.1112
# Epoch 188/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0806 - accuracy: 0.7134 - mse: 2.5878 - weighted_accuracy: 0.8596 - weighted_mse: 3.6932 - val_loss: 0.1321 - val_accuracy: 0.7323 - val_mse: 2.0249 - val_weighted_accuracy: 0.7323 - val_weighted_mse: 2.0249
# Epoch 189/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0748 - accuracy: 0.7076 - mse: 2.6378 - weighted_accuracy: 0.8662 - weighted_mse: 3.8849 - val_loss: 0.1356 - val_accuracy: 0.7218 - val_mse: 2.1276 - val_weighted_accuracy: 0.7218 - val_weighted_mse: 2.1276
# Epoch 190/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0773 - accuracy: 0.7028 - mse: 2.6551 - weighted_accuracy: 0.8592 - weighted_mse: 3.8696 - val_loss: 0.1178 - val_accuracy: 0.7787 - val_mse: 2.0542 - val_weighted_accuracy: 0.7787 - val_weighted_mse: 2.0542
# Epoch 191/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0772 - accuracy: 0.7094 - mse: 2.6041 - weighted_accuracy: 0.8651 - weighted_mse: 3.7695 - val_loss: 0.1073 - val_accuracy: 0.8188 - val_mse: 2.0733 - val_weighted_accuracy: 0.8188 - val_weighted_mse: 2.0733
# Epoch 192/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0736 - accuracy: 0.7229 - mse: 2.6446 - weighted_accuracy: 0.8754 - weighted_mse: 3.8058 - val_loss: 0.1222 - val_accuracy: 0.7640 - val_mse: 1.9703 - val_weighted_accuracy: 0.7640 - val_weighted_mse: 1.9703
# Epoch 193/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0787 - accuracy: 0.7076 - mse: 2.6234 - weighted_accuracy: 0.8628 - weighted_mse: 3.8086 - val_loss: 0.1381 - val_accuracy: 0.7197 - val_mse: 2.1422 - val_weighted_accuracy: 0.7197 - val_weighted_mse: 2.1422
# Epoch 194/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0744 - accuracy: 0.7260 - mse: 2.6416 - weighted_accuracy: 0.8766 - weighted_mse: 3.8830 - val_loss: 0.1248 - val_accuracy: 0.7629 - val_mse: 2.0378 - val_weighted_accuracy: 0.7629 - val_weighted_mse: 2.0378
# Epoch 195/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0765 - accuracy: 0.7126 - mse: 2.6600 - weighted_accuracy: 0.8665 - weighted_mse: 3.7926 - val_loss: 0.1209 - val_accuracy: 0.7734 - val_mse: 2.1690 - val_weighted_accuracy: 0.7734 - val_weighted_mse: 2.1690
# Epoch 196/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0829 - accuracy: 0.7171 - mse: 2.5863 - weighted_accuracy: 0.8523 - weighted_mse: 3.5604 - val_loss: 0.1317 - val_accuracy: 0.7450 - val_mse: 2.1881 - val_weighted_accuracy: 0.7450 - val_weighted_mse: 2.1881
# Epoch 197/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0751 - accuracy: 0.7213 - mse: 2.7694 - weighted_accuracy: 0.8748 - weighted_mse: 3.9643 - val_loss: 0.1479 - val_accuracy: 0.6744 - val_mse: 2.0372 - val_weighted_accuracy: 0.6744 - val_weighted_mse: 2.0372
# Epoch 198/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0735 - accuracy: 0.7173 - mse: 2.6127 - weighted_accuracy: 0.8714 - weighted_mse: 3.8330 - val_loss: 0.1162 - val_accuracy: 0.7893 - val_mse: 2.2745 - val_weighted_accuracy: 0.7893 - val_weighted_mse: 2.2745
# Epoch 199/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0742 - accuracy: 0.7094 - mse: 2.6184 - weighted_accuracy: 0.8527 - weighted_mse: 3.8586 - val_loss: 0.1144 - val_accuracy: 0.7903 - val_mse: 2.1104 - val_weighted_accuracy: 0.7903 - val_weighted_mse: 2.1104
# Epoch 200/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0734 - accuracy: 0.7326 - mse: 2.7480 - weighted_accuracy: 0.8808 - weighted_mse: 3.8287 - val_loss: 0.1047 - val_accuracy: 0.8082 - val_mse: 2.1635 - val_weighted_accuracy: 0.8082 - val_weighted_mse: 2.1635

# %%
# Score model
score = model.evaluate(validation_x, validation_y, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.10468964278697968
# Test accuracy: 0.8082191944122314

# %%
predictions = model.predict(validation_x)
print(predictions)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
from collections import Counter

Counter(predictions)
# Out:
# [[-1.1878518  -2.4627972   0.43110242]
#  [-2.1586077  -0.03523654 -0.6821768 ]
#  [-1.2159747  -2.044114    0.41735482]
#  ...
#  [-1.2304941  -2.141972    0.44518414]
#  [-1.1169996  -2.2101092   0.3412421 ]
#  [-1.0012754  -1.8778174   0.20097432]]
# Counter({2: 839, 1: 69, 0: 41})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in validation_y]
Counter(actual)
# Out:
# Counter({2: 860, 0: 46, 1: 43})

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold))
# Out:
# number of predictions: 949
# actual predicted buys: 5
# actual buys but predicted sell: 1
# actual buys but predicted hold: 37
# actual sells but predicted buy: 2
# actual predicted sells: 2
# actual sells but predicted hold: 42
# actual holds but predicted buy: 62
# actual holds but predicted sell: 38
# actual predicted holds: 760
# Percentage buys correct: 11.627906976744185%
# Percentage sells correct: 4.3478260869565215%
# Percentage holds correct: 88.37209302325581%
# actual buys: 43
# actual sells: 46
# actual holds: 860

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.figure(figsize=(20,10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Save model
model.save("models/{}".format('MFC_no_support_image_cnn_buy_hold_sell.model'))
# Out:
# WARNING:tensorflow:From C:\Users\Shearman Chua\anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\Shearman Chua\anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: models/MFC_no_support_image_cnn_buy_hold_sell.model\assets

# %% [markdown]
# ### Test Performance

# %% [markdown]
# ### Non-Recession Test Data

# %%
column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
log  = pd.DataFrame(columns = column_names)
logger = []

# %%
seed = 10
df = pd.read_csv("data/variation 6/initial_indicators/MFC_data_test.csv")
df.set_index('Date', inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22        16.10  15.369379  -4.347841  12991200.0     2.0
# 2019-01-23        15.75  15.427936 -19.565241  11195700.0     2.0
# 2019-01-24        15.79  15.483638 -19.902947  12310800.0     2.0
# 2019-01-25        15.63  15.506155 -34.131754  10454700.0     2.0
# 2019-01-28        15.75  15.543670 -30.405447  11863600.0     2.0

# %%
#%matplotlib notebook
df['previous_1d'].shift(-1).plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['labels'].plot(figsize=(16,6),x='Date', y='labels')

# %%
# willr_data = []
# price_data = []
# ema_data = []
# obv_data = []
# labels = []
# data_15_price = []
# data_15_willr = []
# data_15_ema = []
# data_15_obv = []
# count = 0

# for i in df.values:
#     if count == 14:
#         data_15_price.append([i[0]])
#         data_15_ema.append([i[1]])
#         data_15_willr.append([i[2]])
#         data_15_obv.append([i[3]])
#         price_data.append(data_15_price)
#         willr_data.append(data_15_willr)
#         ema_data.append(data_15_ema)
#         obv_data.append(data_15_obv)
#         labels.append(i[-1])
#         data_15_price = data_15_price[1:]
#         data_15_willr = data_15_willr[1:]
#         data_15_obv = data_15_obv[1:]
#         data_15_ema = data_15_ema[1:]
    
#     else:
#         data_15_price.append([i[0]])
#         data_15_ema.append([i[1]])
#         data_15_willr.append([i[2]])
#         data_15_obv.append([i[3]])
#         count += 1

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1

# %%
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/MFC_no_support_image_cnn_buy_hold_sell.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1]) ; logger.append(score[1])
# Out:
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0995 - accuracy: 0.8486 - mean_squared_error: 2.0957 - weighted_accuracy: 0.8486 - weighted_mean_squared_error: 2.0957
# Test loss: 0.09946618229150772
# Test accuracy: 0.8486238718032837

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 201, 0: 7, 1: 10})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]
Counter(actual)
# Out:
# Counter({1: 10, 2: 198, 0: 10})

# %%
df = pd.read_csv("data/variation 6/initial_indicators/MFC_data_test.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels  \
# Date
# 2019-02-11    15.630000  15.794888 -75.000000  15118200.0     1.0
# 2019-02-12    15.960000  15.769520 -80.303008  13534100.0     2.0
# 2019-02-13    15.800000  15.798825 -30.303008  15499400.0     2.0
# 2019-02-14    16.040001  15.799006 -54.545415  12941900.0     2.0
# 2019-02-15    16.230000  15.836082 -41.935404  16615800.0     2.0
#
#             predictions  actual
# Date
# 2019-02-11            2       1
# 2019-02-12            2       2
# 2019-02-13            2       2
# 2019-02-14            2       2
# 2019-02-15            2       2

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['predictions'].plot(figsize=(16,6),x='Date', y='predictions')
#df['actual'].plot(figsize=(16,6),x='Date', y='actual')

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold)) ; logger.append(str(100*buy_buy/buy) + "%") ; logger.append(str(100*sell_sell/sell) + "%") ; logger.append(str(100*hold_hold/hold) + "%")
# Out:
# number of predictions: 218
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 9
# actual sells but predicted buy: 0
# actual predicted sells: 1
# actual sells but predicted hold: 9
# actual holds but predicted buy: 9
# actual holds but predicted sell: 6
# actual predicted holds: 183
# Percentage buys correct: 10.0%
# Percentage sells correct: 10.0%
# Percentage holds correct: 92.42424242424242%
# actual buys: 10
# actual sells: 10
# actual holds: 198

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%") ; logger.append(str(100*correct_minima/buy) + "%") ; logger.append(str(100*correct_maxima/sell) + "%") ; logger.append(str(100*correct_hold/hold) + "%")
# Out:
# [15.630000114440918, 15.800000190734865, 15.960000038146973, 16.040000915527347, 16.229999542236328, 16.530000686645508, 16.799999237060547, 16.879999160766598, 16.979999542236328]
# [16.799999237060547, 16.879999160766598, 16.879999160766598, 16.930000305175778, 16.979999542236328, 17.0, 17.09000015258789, 17.100000381469727, 17.280000686645508]
# Percentage buys correct: 40.0%
# Percentage sells correct: 50.0%
# Percentage holds correct: 85.07462686567165%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $17.180000305175778
# Shares owned at the moment: 580
# Cash capital at the moment: $8.19772251129325
#
#
# Price increase from previously bought: 8.200696388413053%
# Share price: $18.63999938964844
# Shares owned at the moment: 0
# Cash capital at the moment: $10789.6665694809
#
#
# Share price: $17.09000015258789
# Shares owned at the moment: 629
# Cash capital at the moment: $10.49504573917693
#
#
# Stop Loss Activated!
#
# Share price: $16.530000686645508
# Shares owned at the moment: 0
# Cash capital at the moment: $10379.272708951476
#
#
# Share price: $16.899999618530273
# Shares owned at the moment: 612
# Cash capital at the moment: $8.030243052960941
#
#
# Stop Loss Activated!
#
# Share price: $16.389999389648438
# Shares owned at the moment: 0
# Cash capital at the moment: $10011.125500545026
#
#
# Share price: $16.520000457763672
# Shares owned at the moment: 604
# Cash capital at the moment: $5.60550329542275
#
#
# Price increase from previously bought: 10.531383481011014%
# Share price: $18.309999465942386
# Shares owned at the moment: 0
# Cash capital at the moment: $11034.432271611693
#
#
# Share price: $18.8799991607666
# Shares owned at the moment: 582
# Cash capital at the moment: $16.055321388723314
#
#
#
#
# Capital at the end of test period: $11589.221661355496
# profit gained: 15.892216613554954%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $12687.37270157766
# profit gained: 26.873727015776605%

# %%
df_length = len(log)
log.loc[df_length] = logger
log.head(20)
# Out:
#    Test_accuracy correct_buys correct_sells       correct_holds  \
# 0       0.848624        10.0%         10.0%  92.42424242424242%
#
#   correct_low_buys correct_high_sells   correct_mid_holds  \
# 0            40.0%              50.0%  85.07462686567165%
#
#          Profit gained    buy_n_hold profit
# 0  15.892216613554954%  26.873727015776605%

# %% [markdown]
# ### Recession test data

# %%
logger = []

# %%
seed = 10
df = pd.read_csv("data/variation 6/initial_indicators/MFC_data_test2.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels
# Date
# 2020-01-22    20.620001  20.787224 -56.481365  5587900.0     2.0
# 2020-01-23    20.760000  20.783036 -48.453572  7034300.0     2.0
# 2020-01-24    20.799999  20.785645 -44.329960  8383300.0     2.0
# 2020-01-27    20.650000  20.764777 -59.793849  5159000.0     2.0
# 2020-01-28    20.030001  20.651734 -87.591226  2998800.0     2.0

# %%
#%matplotlib notebook
df['previous_1d'].shift(-1).plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['labels'].plot(figsize=(16,6),x='Date', y='labels')

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1

# %%
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/MFC_no_support_image_cnn_buy_hold_sell.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1]) ; logger.append(score[1])
# Out:
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1059 - accuracy: 0.7991 - mean_squared_error: 2.2888 - weighted_accuracy: 0.7991 - weighted_mean_squared_error: 2.2888
# Test loss: 0.10586494207382202
# Test accuracy: 0.7990867495536804

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 188, 1: 20, 0: 11})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]

# %%
df = pd.read_csv("data/variation 6/initial_indicators/MFC_data_test2.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels  predictions  \
# Date
# 2020-02-11    20.209999  20.036581 -63.157941 -1529300.0     0.0            2
# 2020-02-12    20.110001  20.063261 -43.421155  -126100.0     2.0            2
# 2020-02-13    19.719999  20.070452 -50.000000 -2453200.0     2.0            2
# 2020-02-14    19.709999  20.016536 -62.626362 -4848700.0     2.0            2
# 2020-02-18    19.580000  19.969377 -63.636486 -6866400.0     2.0            2
#
#             actual
# Date
# 2020-02-11       0
# 2020-02-12       2
# 2020-02-13       2
# 2020-02-14       2
# 2020-02-18       2

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['predictions'].plot(figsize=(16,6),x='Date', y='predictions')
#df['actual'].plot(figsize=(16,6),x='Date', y='actual')

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold)) ; logger.append(str(100*buy_buy/buy) + "%") ; logger.append(str(100*sell_sell/sell) + "%") ; logger.append(str(100*hold_hold/hold) + "%")
# Out:
# number of predictions: 219
# actual predicted buys: 2
# actual buys but predicted sell: 0
# actual buys but predicted hold: 6
# actual sells but predicted buy: 0
# actual predicted sells: 1
# actual sells but predicted hold: 10
# actual holds but predicted buy: 18
# actual holds but predicted sell: 10
# actual predicted holds: 172
# Percentage buys correct: 25.0%
# Percentage sells correct: 9.090909090909092%
# Percentage holds correct: 86.0%
# actual buys: 8
# actual sells: 11
# actual holds: 200

# %%
correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%") ; logger.append(str(100*correct_minima/buy) + "%") ; logger.append(str(100*correct_maxima/sell) + "%") ; logger.append(str(100*correct_hold/hold) + "%")
# Out:
# [17.979999542236328, 19.51000022888184, 19.57999992370605, 19.709999084472656, 19.71999931335449, 19.899999618530273, 20.030000686645508, 20.11000061035156, 20.209999084472656]
# [16.700000762939453, 16.84000015258789, 16.860000610351562, 17.200000762939453, 17.549999237060547, 17.639999389648438, 17.979999542236328, 19.51000022888184, 20.030000686645508]
# Percentage buys correct: 55.0%
# Percentage sells correct: 18.181818181818183%
# Percentage holds correct: 85.02673796791444%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $19.899999618530273
# Shares owned at the moment: 501
# Cash capital at the moment: $2.6829666419034766
#
#
# Stop Loss Activated!
#
# Share price: $17.979999542236328
# Shares owned at the moment: 0
# Cash capital at the moment: $8985.890792932987
#
#
# Share price: $17.639999389648438
# Shares owned at the moment: 508
# Cash capital at the moment: $0.12802384424139746
#
#
# Stop Loss Activated!
#
# Share price: $16.860000610351562
# Shares owned at the moment: 0
# Cash capital at the moment: $8541.454913050175
#
#
# Share price: $14.920000076293945
# Shares owned at the moment: 570
# Cash capital at the moment: $13.667769443034558
#
#
# Stop Loss Activated!
#
# Share price: $14.06999969482422
# Shares owned at the moment: 0
# Cash capital at the moment: $8011.512870971203
#
#
# Share price: $9.390000343322754
# Shares owned at the moment: 850
# Cash capital at the moment: $8.063453344344452
#
#
# Stop Loss Activated!
#
# Share price: $8.899999618530273
# Shares owned at the moment: 0
# Cash capital at the moment: $7552.259379986762
#
#
# Share price: $11.34000015258789
# Shares owned at the moment: 664
# Cash capital at the moment: $1.7924383897770895
#
#
# Price increase from previously bought: 17.13818318490119%
# Share price: $13.31999969482422
# Shares owned at the moment: 0
# Cash capital at the moment: $8821.94991631031
#
#
# Share price: $13.979999542236328
# Shares owned at the moment: 629
# Cash capital at the moment: $4.348300035475404
#
#
# Stop Loss Activated!
#
# Share price: $13.420000076293945
# Shares owned at the moment: 0
# Cash capital at the moment: $8422.315102892397
#
#
# Share price: $14.789999961853027
# Shares owned at the moment: 567
# Cash capital at the moment: $13.323817081211018
#
#
# Stop Loss Activated!
#
# Share price: $14.31999969482422
# Shares owned at the moment: 0
# Cash capital at the moment: $8110.435184522389
#
#
# Share price: $13.579999923706055
# Shares owned at the moment: 595
# Cash capital at the moment: $8.114955042122347
#
#
# Price increase from previously bought: 6.114663985136848%
# Share price: $14.449999809265135
# Shares owned at the moment: 0
# Cash capital at the moment: $8582.221029366967
#
#
#
#
# Capital at the end of test period: $8582.221029366967
# profit gained: -14.177789706330332%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $8544.015225172043
# profit gained: -14.559847748279573%

# %%
df_length = len(log)
log.loc[df_length] = logger
log.head()
# Out:
#    Test_accuracy correct_buys       correct_sells       correct_holds  \
# 0       0.848624        10.0%               10.0%  92.42424242424242%
# 1       0.799087        25.0%  9.090909090909092%               86.0%
#
#   correct_low_buys   correct_high_sells   correct_mid_holds  \
# 0            40.0%                50.0%  85.07462686567165%
# 1            55.0%  18.181818181818183%  85.02673796791444%
#
#           Profit gained     buy_n_hold profit
# 0   15.892216613554954%   26.873727015776605%
# 1  -14.177789706330332%  -14.559847748279573%

# %% [markdown]
# ### with JPM stock price

# %%
seed = 10
df = pd.read_csv("data/variation 6/initial_indicators/MFC_data.csv")
df.set_index('Date', inplace=True)
df.head()
# Out:
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2000-01-21      6.09375  6.133837 -56.250000  1982400.0     2.0
# 2000-01-24      6.06250  6.122862 -60.000000  1705200.0     2.0
# 2000-01-25      5.96875  6.099153 -80.000000   909600.0     2.0
# 2000-01-26      6.00000  6.083898 -73.333333  1179600.0     2.0
# 2000-01-27      5.96875  6.066183 -80.000000   783000.0     2.0

# %%
df2 = pd.read_csv("data/variation 6/initial_indicators/JPM_data.csv")
df2.set_index('Date', inplace=True)
df2.head()
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2000-01-21    49.375000  48.388499 -42.592593  -2894250.0     2.0
# 2000-01-24    48.625000  48.424884 -39.516144  -8054850.0     2.0
# 2000-01-25    48.666668  48.462081 -38.709668  -1595700.0     2.0
# 2000-01-26    49.750000  48.660222 -17.741956   5984250.0     2.0
# 2000-01-27    52.291668  49.218906  -5.232557  14370900.0     2.0

# %%
df['support'] = df2['previous_1d']
df.head()
# Out:
#             previous_1d    EMA_12   willr_14      OBV_7  labels    support
# Date
# 2000-01-21      6.09375  6.133837 -56.250000  1982400.0     2.0  49.375000
# 2000-01-24      6.06250  6.122862 -60.000000  1705200.0     2.0  48.625000
# 2000-01-25      5.96875  6.099153 -80.000000   909600.0     2.0  48.666668
# 2000-01-26      6.00000  6.083898 -73.333333  1179600.0     2.0  49.750000
# 2000-01-27      5.96875  6.066183 -80.000000   783000.0     2.0  52.291668

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['support'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['labels'].plot(figsize=(16,6),x='Date', y='labels')

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
support_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
data_15_support = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        data_15_support.append([i[-1]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        data_15_support_arr = min_max_scaler.fit_transform(data_15_support)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        support_data.append(data_15_support_arr)
        labels.append(i[4])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
        data_15_support = data_15_support[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        data_15_support.append([i[-1]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)
support_data = np.array(support_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    n = support_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)
    ax.plot(n)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
y = np.array(y)

X.shape
# Out:
# (4745, 64, 64, 1)

# %%
# plot the image array X
i = X[0].reshape(64, 64)
fig2, ax2 = plt.subplots()
plt.imshow(i, interpolation="none", cmap="gray")

ax2.axis('off')

plt.show()

# %%
X = X/255

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten,BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.regularizers import l2
import efficientnet.tfkeras as efn
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(Conv2D(16, (3, 3), padding='same', kernel_initializer='he_uniform',kernel_regularizer=l2(1e-5), input_shape=X_train.shape[1:]))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))

model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_uniform',kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

# model.add(Dense(128, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))
# model.add(Dropout(0.25, seed=seed))

model.add(Dense(64, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))
model.add(Dropout(0.25, seed=seed))

model.add(Dense(32, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))
model.add(Dropout(0.25, seed=seed))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "DBS_CNN_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))
print(d_class_weights)

# Train model
history = model.fit(
    train_x, train_y,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(validation_x, validation_y),
    shuffle=True,
    callbacks=[tensorboard],
    class_weight=d_class_weights
)
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 2 ... 0 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# {0: 6.9523809523809526, 1: 7.3996101364522415, 2: 0.3675089553683803}
# Epoch 1/200
#  2/30 [=>............................] - ETA: 25s - loss: 0.4075 - accuracy: 0.6211 - mse: 4.4157 - weighted_accuracy: 0.3435 - weighted_mse: 5.3973WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0100s vs `on_train_batch_end` time: 1.8151s). Check your callbacks.
# 30/30 [==============================] - 2s 83ms/step - loss: 0.2494 - accuracy: 0.3672 - mse: 1.6285 - weighted_accuracy: 0.2908 - weighted_mse: 1.7629 - val_loss: 0.2206 - val_accuracy: 0.0453 - val_mse: 0.8624 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.8624
# Epoch 2/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.2061 - accuracy: 0.3243 - mse: 1.1550 - weighted_accuracy: 0.3426 - weighted_mse: 1.1793 - val_loss: 0.2125 - val_accuracy: 0.0485 - val_mse: 0.8873 - val_weighted_accuracy: 0.0485 - val_weighted_mse: 0.8873
# Epoch 3/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.2046 - accuracy: 0.3654 - mse: 1.1631 - weighted_accuracy: 0.3521 - weighted_mse: 1.1787 - val_loss: 0.2009 - val_accuracy: 0.1602 - val_mse: 0.9062 - val_weighted_accuracy: 0.1602 - val_weighted_mse: 0.9062
# Epoch 4/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.2040 - accuracy: 0.3519 - mse: 1.1465 - weighted_accuracy: 0.3435 - weighted_mse: 1.1618 - val_loss: 0.2004 - val_accuracy: 0.0948 - val_mse: 0.9475 - val_weighted_accuracy: 0.0948 - val_weighted_mse: 0.9475
# Epoch 5/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.2028 - accuracy: 0.3738 - mse: 1.1245 - weighted_accuracy: 0.3554 - weighted_mse: 1.1589 - val_loss: 0.1985 - val_accuracy: 0.0980 - val_mse: 0.9962 - val_weighted_accuracy: 0.0980 - val_weighted_mse: 0.9962
# Epoch 6/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.2027 - accuracy: 0.4125 - mse: 1.1465 - weighted_accuracy: 0.3369 - weighted_mse: 1.1675 - val_loss: 0.1976 - val_accuracy: 0.0695 - val_mse: 1.0462 - val_weighted_accuracy: 0.0695 - val_weighted_mse: 1.0462
# Epoch 7/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.2010 - accuracy: 0.3638 - mse: 1.1583 - weighted_accuracy: 0.3569 - weighted_mse: 1.1802 - val_loss: 0.1932 - val_accuracy: 0.6459 - val_mse: 0.9386 - val_weighted_accuracy: 0.6459 - val_weighted_mse: 0.9386
# Epoch 8/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.2027 - accuracy: 0.4260 - mse: 1.1841 - weighted_accuracy: 0.3612 - weighted_mse: 1.1951 - val_loss: 0.2045 - val_accuracy: 0.0558 - val_mse: 0.9042 - val_weighted_accuracy: 0.0558 - val_weighted_mse: 0.9042
# Epoch 9/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.2023 - accuracy: 0.3859 - mse: 1.1535 - weighted_accuracy: 0.3357 - weighted_mse: 1.1655 - val_loss: 0.1953 - val_accuracy: 0.3730 - val_mse: 0.8883 - val_weighted_accuracy: 0.3730 - val_weighted_mse: 0.8883
# Epoch 10/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.2007 - accuracy: 0.3896 - mse: 1.1592 - weighted_accuracy: 0.3391 - weighted_mse: 1.1686 - val_loss: 0.2009 - val_accuracy: 0.0506 - val_mse: 0.9819 - val_weighted_accuracy: 0.0506 - val_weighted_mse: 0.9819
# Epoch 11/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.2026 - accuracy: 0.3037 - mse: 1.1599 - weighted_accuracy: 0.3393 - weighted_mse: 1.1534 - val_loss: 0.1916 - val_accuracy: 0.5943 - val_mse: 0.9335 - val_weighted_accuracy: 0.5943 - val_weighted_mse: 0.9335
# Epoch 12/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1997 - accuracy: 0.3601 - mse: 1.1705 - weighted_accuracy: 0.3566 - weighted_mse: 1.1962 - val_loss: 0.2014 - val_accuracy: 0.0695 - val_mse: 0.9077 - val_weighted_accuracy: 0.0695 - val_weighted_mse: 0.9077
# Epoch 13/200
# 30/30 [==============================] - 0s 12ms/step - loss: 0.2012 - accuracy: 0.3662 - mse: 1.1690 - weighted_accuracy: 0.3709 - weighted_mse: 1.1653 - val_loss: 0.1971 - val_accuracy: 0.1749 - val_mse: 0.9550 - val_weighted_accuracy: 0.1749 - val_weighted_mse: 0.9550
# Epoch 14/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2023 - accuracy: 0.3541 - mse: 1.1790 - weighted_accuracy: 0.3403 - weighted_mse: 1.1594 - val_loss: 0.2033 - val_accuracy: 0.0674 - val_mse: 1.0375 - val_weighted_accuracy: 0.0674 - val_weighted_mse: 1.0375
# Epoch 15/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2035 - accuracy: 0.2018 - mse: 1.1602 - weighted_accuracy: 0.3263 - weighted_mse: 1.1609 - val_loss: 0.2076 - val_accuracy: 0.0569 - val_mse: 0.9822 - val_weighted_accuracy: 0.0569 - val_weighted_mse: 0.9822
# Epoch 16/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2029 - accuracy: 0.2387 - mse: 1.1901 - weighted_accuracy: 0.3812 - weighted_mse: 1.1489 - val_loss: 0.2047 - val_accuracy: 0.0632 - val_mse: 1.1298 - val_weighted_accuracy: 0.0632 - val_weighted_mse: 1.1298
# Epoch 17/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2010 - accuracy: 0.2397 - mse: 1.1680 - weighted_accuracy: 0.3719 - weighted_mse: 1.1545 - val_loss: 0.2012 - val_accuracy: 0.0695 - val_mse: 0.9977 - val_weighted_accuracy: 0.0695 - val_weighted_mse: 0.9977
# Epoch 18/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2000 - accuracy: 0.2279 - mse: 1.1817 - weighted_accuracy: 0.4022 - weighted_mse: 1.1627 - val_loss: 0.2013 - val_accuracy: 0.0695 - val_mse: 1.1200 - val_weighted_accuracy: 0.0695 - val_weighted_mse: 1.1200
# Epoch 19/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1980 - accuracy: 0.2273 - mse: 1.1889 - weighted_accuracy: 0.3923 - weighted_mse: 1.1848 - val_loss: 0.2026 - val_accuracy: 0.0674 - val_mse: 1.1435 - val_weighted_accuracy: 0.0674 - val_weighted_mse: 1.1435
# Epoch 20/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1993 - accuracy: 0.2358 - mse: 1.1824 - weighted_accuracy: 0.3948 - weighted_mse: 1.1835 - val_loss: 0.2023 - val_accuracy: 0.0685 - val_mse: 0.9911 - val_weighted_accuracy: 0.0685 - val_weighted_mse: 0.9911
# Epoch 21/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1990 - accuracy: 0.2229 - mse: 1.2078 - weighted_accuracy: 0.4000 - weighted_mse: 1.1796 - val_loss: 0.2030 - val_accuracy: 0.0674 - val_mse: 0.8445 - val_weighted_accuracy: 0.0674 - val_weighted_mse: 0.8445
# Epoch 22/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1993 - accuracy: 0.2231 - mse: 1.1806 - weighted_accuracy: 0.3786 - weighted_mse: 1.1688 - val_loss: 0.1966 - val_accuracy: 0.0695 - val_mse: 1.0218 - val_weighted_accuracy: 0.0695 - val_weighted_mse: 1.0218
# Epoch 23/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1996 - accuracy: 0.2397 - mse: 1.1951 - weighted_accuracy: 0.4050 - weighted_mse: 1.1621 - val_loss: 0.2018 - val_accuracy: 0.0674 - val_mse: 1.0081 - val_weighted_accuracy: 0.0674 - val_weighted_mse: 1.0081
# Epoch 24/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1991 - accuracy: 0.2208 - mse: 1.1989 - weighted_accuracy: 0.3635 - weighted_mse: 1.1612 - val_loss: 0.1993 - val_accuracy: 0.0695 - val_mse: 1.0726 - val_weighted_accuracy: 0.0695 - val_weighted_mse: 1.0726
# Epoch 25/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1967 - accuracy: 0.2173 - mse: 1.2028 - weighted_accuracy: 0.4038 - weighted_mse: 1.1840 - val_loss: 0.1989 - val_accuracy: 0.0685 - val_mse: 0.9821 - val_weighted_accuracy: 0.0685 - val_weighted_mse: 0.9821
# Epoch 26/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1973 - accuracy: 0.2400 - mse: 1.2041 - weighted_accuracy: 0.4062 - weighted_mse: 1.2007 - val_loss: 0.2022 - val_accuracy: 0.0685 - val_mse: 0.9498 - val_weighted_accuracy: 0.0685 - val_weighted_mse: 0.9498
# Epoch 27/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1963 - accuracy: 0.2395 - mse: 1.1803 - weighted_accuracy: 0.4205 - weighted_mse: 1.1668 - val_loss: 0.2000 - val_accuracy: 0.0685 - val_mse: 0.9870 - val_weighted_accuracy: 0.0685 - val_weighted_mse: 0.9870
# Epoch 28/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1960 - accuracy: 0.2271 - mse: 1.1952 - weighted_accuracy: 0.4131 - weighted_mse: 1.1830 - val_loss: 0.1975 - val_accuracy: 0.0717 - val_mse: 1.0217 - val_weighted_accuracy: 0.0717 - val_weighted_mse: 1.0217
# Epoch 29/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1962 - accuracy: 0.2331 - mse: 1.2002 - weighted_accuracy: 0.4319 - weighted_mse: 1.1758 - val_loss: 0.1980 - val_accuracy: 0.0717 - val_mse: 1.0622 - val_weighted_accuracy: 0.0717 - val_weighted_mse: 1.0622
# Epoch 30/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1961 - accuracy: 0.2316 - mse: 1.1911 - weighted_accuracy: 0.4060 - weighted_mse: 1.1691 - val_loss: 0.1969 - val_accuracy: 0.0706 - val_mse: 0.9198 - val_weighted_accuracy: 0.0706 - val_weighted_mse: 0.9198
# Epoch 31/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1935 - accuracy: 0.2326 - mse: 1.1963 - weighted_accuracy: 0.4196 - weighted_mse: 1.1904 - val_loss: 0.1994 - val_accuracy: 0.0748 - val_mse: 1.0080 - val_weighted_accuracy: 0.0748 - val_weighted_mse: 1.0080
# Epoch 32/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1933 - accuracy: 0.2218 - mse: 1.1934 - weighted_accuracy: 0.4314 - weighted_mse: 1.1864 - val_loss: 0.2000 - val_accuracy: 0.0727 - val_mse: 0.9361 - val_weighted_accuracy: 0.0727 - val_weighted_mse: 0.9361
# Epoch 33/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1950 - accuracy: 0.2084 - mse: 1.1726 - weighted_accuracy: 0.3893 - weighted_mse: 1.1576 - val_loss: 0.1975 - val_accuracy: 0.0738 - val_mse: 1.0952 - val_weighted_accuracy: 0.0738 - val_weighted_mse: 1.0952
# Epoch 34/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1918 - accuracy: 0.2213 - mse: 1.2268 - weighted_accuracy: 0.4268 - weighted_mse: 1.2002 - val_loss: 0.1997 - val_accuracy: 0.0738 - val_mse: 1.0108 - val_weighted_accuracy: 0.0738 - val_weighted_mse: 1.0108
# Epoch 35/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1946 - accuracy: 0.2208 - mse: 1.2025 - weighted_accuracy: 0.4247 - weighted_mse: 1.1589 - val_loss: 0.1985 - val_accuracy: 0.0727 - val_mse: 1.0665 - val_weighted_accuracy: 0.0727 - val_weighted_mse: 1.0665
# Epoch 36/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1909 - accuracy: 0.2026 - mse: 1.2002 - weighted_accuracy: 0.4634 - weighted_mse: 1.1789 - val_loss: 0.1980 - val_accuracy: 0.0727 - val_mse: 1.0444 - val_weighted_accuracy: 0.0727 - val_weighted_mse: 1.0444
# Epoch 37/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1927 - accuracy: 0.2121 - mse: 1.2002 - weighted_accuracy: 0.4257 - weighted_mse: 1.2017 - val_loss: 0.1987 - val_accuracy: 0.0738 - val_mse: 0.9917 - val_weighted_accuracy: 0.0738 - val_weighted_mse: 0.9917
# Epoch 38/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1884 - accuracy: 0.2018 - mse: 1.2528 - weighted_accuracy: 0.4720 - weighted_mse: 1.2143 - val_loss: 0.1979 - val_accuracy: 0.0748 - val_mse: 0.9877 - val_weighted_accuracy: 0.0748 - val_weighted_mse: 0.9877
# Epoch 39/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1884 - accuracy: 0.2013 - mse: 1.2057 - weighted_accuracy: 0.4600 - weighted_mse: 1.1870 - val_loss: 0.1979 - val_accuracy: 0.0759 - val_mse: 1.0121 - val_weighted_accuracy: 0.0759 - val_weighted_mse: 1.0121
# Epoch 40/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1897 - accuracy: 0.1899 - mse: 1.2362 - weighted_accuracy: 0.4623 - weighted_mse: 1.1922 - val_loss: 0.1981 - val_accuracy: 0.0664 - val_mse: 1.0251 - val_weighted_accuracy: 0.0664 - val_weighted_mse: 1.0251
# Epoch 41/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1902 - accuracy: 0.1852 - mse: 1.2689 - weighted_accuracy: 0.4477 - weighted_mse: 1.2354 - val_loss: 0.1959 - val_accuracy: 0.0738 - val_mse: 1.0951 - val_weighted_accuracy: 0.0738 - val_weighted_mse: 1.0951
# Epoch 42/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1877 - accuracy: 0.1976 - mse: 1.2455 - weighted_accuracy: 0.4802 - weighted_mse: 1.2071 - val_loss: 0.1962 - val_accuracy: 0.0674 - val_mse: 1.0384 - val_weighted_accuracy: 0.0674 - val_weighted_mse: 1.0384
# Epoch 43/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1863 - accuracy: 0.1944 - mse: 1.2640 - weighted_accuracy: 0.4711 - weighted_mse: 1.2239 - val_loss: 0.1962 - val_accuracy: 0.0738 - val_mse: 1.0324 - val_weighted_accuracy: 0.0738 - val_weighted_mse: 1.0324
# Epoch 44/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1856 - accuracy: 0.1849 - mse: 1.2809 - weighted_accuracy: 0.4727 - weighted_mse: 1.2245 - val_loss: 0.1969 - val_accuracy: 0.0738 - val_mse: 1.0850 - val_weighted_accuracy: 0.0738 - val_weighted_mse: 1.0850
# Epoch 45/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1871 - accuracy: 0.1665 - mse: 1.2696 - weighted_accuracy: 0.4550 - weighted_mse: 1.2298 - val_loss: 0.1995 - val_accuracy: 0.0717 - val_mse: 0.9996 - val_weighted_accuracy: 0.0717 - val_weighted_mse: 0.9996
# Epoch 46/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1895 - accuracy: 0.1720 - mse: 1.2442 - weighted_accuracy: 0.4530 - weighted_mse: 1.1909 - val_loss: 0.1977 - val_accuracy: 0.0748 - val_mse: 1.0386 - val_weighted_accuracy: 0.0748 - val_weighted_mse: 1.0386
# Epoch 47/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1844 - accuracy: 0.1633 - mse: 1.2270 - weighted_accuracy: 0.4868 - weighted_mse: 1.2154 - val_loss: 0.1982 - val_accuracy: 0.0748 - val_mse: 1.0110 - val_weighted_accuracy: 0.0748 - val_weighted_mse: 1.0110
# Epoch 48/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1822 - accuracy: 0.1733 - mse: 1.2351 - weighted_accuracy: 0.4985 - weighted_mse: 1.1996 - val_loss: 0.1968 - val_accuracy: 0.0780 - val_mse: 1.0632 - val_weighted_accuracy: 0.0780 - val_weighted_mse: 1.0632
# Epoch 49/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1801 - accuracy: 0.1757 - mse: 1.2602 - weighted_accuracy: 0.5172 - weighted_mse: 1.2390 - val_loss: 0.1964 - val_accuracy: 0.0780 - val_mse: 1.0665 - val_weighted_accuracy: 0.0780 - val_weighted_mse: 1.0665
# Epoch 50/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1805 - accuracy: 0.1762 - mse: 1.2371 - weighted_accuracy: 0.5237 - weighted_mse: 1.2086 - val_loss: 0.1965 - val_accuracy: 0.0801 - val_mse: 1.0660 - val_weighted_accuracy: 0.0801 - val_weighted_mse: 1.0660
# Epoch 51/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1810 - accuracy: 0.1607 - mse: 1.2510 - weighted_accuracy: 0.5074 - weighted_mse: 1.2123 - val_loss: 0.1958 - val_accuracy: 0.0769 - val_mse: 1.0907 - val_weighted_accuracy: 0.0769 - val_weighted_mse: 1.0907
# Epoch 52/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1790 - accuracy: 0.1639 - mse: 1.2762 - weighted_accuracy: 0.5107 - weighted_mse: 1.2501 - val_loss: 0.1982 - val_accuracy: 0.0843 - val_mse: 1.0503 - val_weighted_accuracy: 0.0843 - val_weighted_mse: 1.0503
# Epoch 53/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1756 - accuracy: 0.1520 - mse: 1.2670 - weighted_accuracy: 0.5391 - weighted_mse: 1.2497 - val_loss: 0.1977 - val_accuracy: 0.0843 - val_mse: 1.1351 - val_weighted_accuracy: 0.0843 - val_weighted_mse: 1.1351
# Epoch 54/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1777 - accuracy: 0.1612 - mse: 1.2985 - weighted_accuracy: 0.5178 - weighted_mse: 1.2479 - val_loss: 0.1969 - val_accuracy: 0.0938 - val_mse: 1.1395 - val_weighted_accuracy: 0.0938 - val_weighted_mse: 1.1395
# Epoch 55/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1770 - accuracy: 0.1570 - mse: 1.2419 - weighted_accuracy: 0.5303 - weighted_mse: 1.2055 - val_loss: 0.2014 - val_accuracy: 0.0885 - val_mse: 1.0563 - val_weighted_accuracy: 0.0885 - val_weighted_mse: 1.0563
# Epoch 56/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1773 - accuracy: 0.1583 - mse: 1.2981 - weighted_accuracy: 0.5164 - weighted_mse: 1.2580 - val_loss: 0.1986 - val_accuracy: 0.0864 - val_mse: 1.0793 - val_weighted_accuracy: 0.0864 - val_weighted_mse: 1.0793
# Epoch 57/200
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1740 - accuracy: 0.1507 - mse: 1.3082 - weighted_accuracy: 0.5406 - weighted_mse: 1.2346 - val_loss: 0.1945 - val_accuracy: 0.0896 - val_mse: 1.1869 - val_weighted_accuracy: 0.0896 - val_weighted_mse: 1.1869
# Epoch 58/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1733 - accuracy: 0.1641 - mse: 1.3478 - weighted_accuracy: 0.5273 - weighted_mse: 1.2855 - val_loss: 0.2014 - val_accuracy: 0.0948 - val_mse: 1.0756 - val_weighted_accuracy: 0.0948 - val_weighted_mse: 1.0756
# Epoch 59/200
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1722 - accuracy: 0.1636 - mse: 1.3216 - weighted_accuracy: 0.5323 - weighted_mse: 1.2825 - val_loss: 0.1968 - val_accuracy: 0.1222 - val_mse: 1.1781 - val_weighted_accuracy: 0.1222 - val_weighted_mse: 1.1781
# Epoch 60/200
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1702 - accuracy: 0.1794 - mse: 1.3474 - weighted_accuracy: 0.5637 - weighted_mse: 1.2948 - val_loss: 0.1952 - val_accuracy: 0.1401 - val_mse: 1.2205 - val_weighted_accuracy: 0.1401 - val_weighted_mse: 1.2205
# Epoch 61/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1712 - accuracy: 0.1631 - mse: 1.3092 - weighted_accuracy: 0.5429 - weighted_mse: 1.2756 - val_loss: 0.1984 - val_accuracy: 0.1128 - val_mse: 1.1293 - val_weighted_accuracy: 0.1128 - val_weighted_mse: 1.1293
# Epoch 62/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.1690 - accuracy: 0.1702 - mse: 1.3881 - weighted_accuracy: 0.5490 - weighted_mse: 1.3238 - val_loss: 0.1975 - val_accuracy: 0.1286 - val_mse: 1.1567 - val_weighted_accuracy: 0.1286 - val_weighted_mse: 1.1567
# Epoch 63/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.1680 - accuracy: 0.1720 - mse: 1.3374 - weighted_accuracy: 0.5602 - weighted_mse: 1.2928 - val_loss: 0.2042 - val_accuracy: 0.1117 - val_mse: 1.1454 - val_weighted_accuracy: 0.1117 - val_weighted_mse: 1.1454
# Epoch 64/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1692 - accuracy: 0.1689 - mse: 1.3555 - weighted_accuracy: 0.5507 - weighted_mse: 1.3139 - val_loss: 0.1965 - val_accuracy: 0.1465 - val_mse: 1.2302 - val_weighted_accuracy: 0.1465 - val_weighted_mse: 1.2302
# Epoch 65/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1702 - accuracy: 0.1660 - mse: 1.3113 - weighted_accuracy: 0.5525 - weighted_mse: 1.2685 - val_loss: 0.1981 - val_accuracy: 0.1233 - val_mse: 1.1069 - val_weighted_accuracy: 0.1233 - val_weighted_mse: 1.1069
# Epoch 66/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1685 - accuracy: 0.1625 - mse: 1.2765 - weighted_accuracy: 0.5477 - weighted_mse: 1.2490 - val_loss: 0.1959 - val_accuracy: 0.1264 - val_mse: 1.1753 - val_weighted_accuracy: 0.1264 - val_weighted_mse: 1.1753
# Epoch 67/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1684 - accuracy: 0.1733 - mse: 1.3483 - weighted_accuracy: 0.5613 - weighted_mse: 1.3002 - val_loss: 0.1967 - val_accuracy: 0.1528 - val_mse: 1.2954 - val_weighted_accuracy: 0.1528 - val_weighted_mse: 1.2954
# Epoch 68/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1663 - accuracy: 0.1805 - mse: 1.3589 - weighted_accuracy: 0.5636 - weighted_mse: 1.3210 - val_loss: 0.1973 - val_accuracy: 0.1286 - val_mse: 1.1722 - val_weighted_accuracy: 0.1286 - val_weighted_mse: 1.1722
# Epoch 69/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1655 - accuracy: 0.1662 - mse: 1.3528 - weighted_accuracy: 0.5572 - weighted_mse: 1.3154 - val_loss: 0.1976 - val_accuracy: 0.1444 - val_mse: 1.2284 - val_weighted_accuracy: 0.1444 - val_weighted_mse: 1.2284
# Epoch 70/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1653 - accuracy: 0.1776 - mse: 1.3745 - weighted_accuracy: 0.5620 - weighted_mse: 1.3307 - val_loss: 0.1978 - val_accuracy: 0.1486 - val_mse: 1.2525 - val_weighted_accuracy: 0.1486 - val_weighted_mse: 1.2525
# Epoch 71/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1652 - accuracy: 0.1752 - mse: 1.3940 - weighted_accuracy: 0.5638 - weighted_mse: 1.3445 - val_loss: 0.1999 - val_accuracy: 0.1275 - val_mse: 1.1144 - val_weighted_accuracy: 0.1275 - val_weighted_mse: 1.1144
# Epoch 72/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1603 - accuracy: 0.1823 - mse: 1.3815 - weighted_accuracy: 0.5989 - weighted_mse: 1.3513 - val_loss: 0.1952 - val_accuracy: 0.1486 - val_mse: 1.2721 - val_weighted_accuracy: 0.1486 - val_weighted_mse: 1.2721
# Epoch 73/200
# 30/30 [==============================] - ETA: 0s - loss: 0.1626 - accuracy: 0.1797 - mse: 1.4094 - weighted_accuracy: 0.5664 - weighted_mse: 1.367 - 0s 16ms/step - loss: 0.1641 - accuracy: 0.1799 - mse: 1.4002 - weighted_accuracy: 0.5637 - weighted_mse: 1.3562 - val_loss: 0.1974 - val_accuracy: 0.1296 - val_mse: 1.1865 - val_weighted_accuracy: 0.1296 - val_weighted_mse: 1.1865
# Epoch 74/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1604 - accuracy: 0.1818 - mse: 1.4139 - weighted_accuracy: 0.5961 - weighted_mse: 1.3834 - val_loss: 0.1982 - val_accuracy: 0.1496 - val_mse: 1.2458 - val_weighted_accuracy: 0.1496 - val_weighted_mse: 1.2458
# Epoch 75/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1588 - accuracy: 0.1797 - mse: 1.4211 - weighted_accuracy: 0.5852 - weighted_mse: 1.3971 - val_loss: 0.1969 - val_accuracy: 0.1486 - val_mse: 1.2421 - val_weighted_accuracy: 0.1486 - val_weighted_mse: 1.2421
# Epoch 76/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1605 - accuracy: 0.1841 - mse: 1.3914 - weighted_accuracy: 0.5961 - weighted_mse: 1.3519 - val_loss: 0.1973 - val_accuracy: 0.1465 - val_mse: 1.2201 - val_weighted_accuracy: 0.1465 - val_weighted_mse: 1.2201
# Epoch 77/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1612 - accuracy: 0.1828 - mse: 1.4236 - weighted_accuracy: 0.5701 - weighted_mse: 1.3671 - val_loss: 0.1986 - val_accuracy: 0.1496 - val_mse: 1.2422 - val_weighted_accuracy: 0.1496 - val_weighted_mse: 1.2422
# Epoch 78/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.1612 - accuracy: 0.1942 - mse: 1.4069 - weighted_accuracy: 0.5903 - weighted_mse: 1.3631 - val_loss: 0.1971 - val_accuracy: 0.1517 - val_mse: 1.2033 - val_weighted_accuracy: 0.1517 - val_weighted_mse: 1.2033
# Epoch 79/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.1589 - accuracy: 0.1831 - mse: 1.4120 - weighted_accuracy: 0.5754 - weighted_mse: 1.3569 - val_loss: 0.1939 - val_accuracy: 0.1623 - val_mse: 1.2881 - val_weighted_accuracy: 0.1623 - val_weighted_mse: 1.2881
# Epoch 80/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.1577 - accuracy: 0.1860 - mse: 1.5062 - weighted_accuracy: 0.5872 - weighted_mse: 1.4803 - val_loss: 0.1977 - val_accuracy: 0.1370 - val_mse: 1.2040 - val_weighted_accuracy: 0.1370 - val_weighted_mse: 1.2040
# Epoch 81/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1578 - accuracy: 0.1976 - mse: 1.4223 - weighted_accuracy: 0.5898 - weighted_mse: 1.4053 - val_loss: 0.1946 - val_accuracy: 0.1517 - val_mse: 1.2420 - val_weighted_accuracy: 0.1517 - val_weighted_mse: 1.2420
# Epoch 82/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1566 - accuracy: 0.1934 - mse: 1.4367 - weighted_accuracy: 0.5925 - weighted_mse: 1.4053 - val_loss: 0.1946 - val_accuracy: 0.1697 - val_mse: 1.3187 - val_weighted_accuracy: 0.1697 - val_weighted_mse: 1.3187
# Epoch 83/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1553 - accuracy: 0.2110 - mse: 1.4508 - weighted_accuracy: 0.6236 - weighted_mse: 1.4189 - val_loss: 0.1963 - val_accuracy: 0.1697 - val_mse: 1.3718 - val_weighted_accuracy: 0.1697 - val_weighted_mse: 1.3718
# Epoch 84/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1535 - accuracy: 0.2005 - mse: 1.4566 - weighted_accuracy: 0.6146 - weighted_mse: 1.4283 - val_loss: 0.1953 - val_accuracy: 0.1697 - val_mse: 1.3397 - val_weighted_accuracy: 0.1697 - val_weighted_mse: 1.3397
# Epoch 85/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1552 - accuracy: 0.2073 - mse: 1.4276 - weighted_accuracy: 0.6067 - weighted_mse: 1.4172 - val_loss: 0.1952 - val_accuracy: 0.1865 - val_mse: 1.3589 - val_weighted_accuracy: 0.1865 - val_weighted_mse: 1.3589
# Epoch 86/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1537 - accuracy: 0.2155 - mse: 1.5245 - weighted_accuracy: 0.5952 - weighted_mse: 1.4882 - val_loss: 0.1966 - val_accuracy: 0.1528 - val_mse: 1.2825 - val_weighted_accuracy: 0.1528 - val_weighted_mse: 1.2825
# Epoch 87/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1511 - accuracy: 0.2026 - mse: 1.5002 - weighted_accuracy: 0.6274 - weighted_mse: 1.4834 - val_loss: 0.1933 - val_accuracy: 0.1823 - val_mse: 1.3474 - val_weighted_accuracy: 0.1823 - val_weighted_mse: 1.3474
# Epoch 88/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1542 - accuracy: 0.2229 - mse: 1.4589 - weighted_accuracy: 0.6171 - weighted_mse: 1.4387 - val_loss: 0.1967 - val_accuracy: 0.1865 - val_mse: 1.3196 - val_weighted_accuracy: 0.1865 - val_weighted_mse: 1.3196
# Epoch 89/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1513 - accuracy: 0.2071 - mse: 1.4973 - weighted_accuracy: 0.6273 - weighted_mse: 1.5080 - val_loss: 0.2014 - val_accuracy: 0.1981 - val_mse: 1.3768 - val_weighted_accuracy: 0.1981 - val_weighted_mse: 1.3768
# Epoch 90/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1523 - accuracy: 0.2210 - mse: 1.4943 - weighted_accuracy: 0.6218 - weighted_mse: 1.4799 - val_loss: 0.1953 - val_accuracy: 0.1855 - val_mse: 1.3362 - val_weighted_accuracy: 0.1855 - val_weighted_mse: 1.3362
# Epoch 91/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1500 - accuracy: 0.2165 - mse: 1.5242 - weighted_accuracy: 0.6240 - weighted_mse: 1.5316 - val_loss: 0.1969 - val_accuracy: 0.2034 - val_mse: 1.3748 - val_weighted_accuracy: 0.2034 - val_weighted_mse: 1.3748
# Epoch 92/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1553 - accuracy: 0.2158 - mse: 1.4824 - weighted_accuracy: 0.6060 - weighted_mse: 1.4443 - val_loss: 0.1941 - val_accuracy: 0.1855 - val_mse: 1.3414 - val_weighted_accuracy: 0.1855 - val_weighted_mse: 1.3414
# Epoch 93/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1506 - accuracy: 0.2252 - mse: 1.5099 - weighted_accuracy: 0.6173 - weighted_mse: 1.5119 - val_loss: 0.1950 - val_accuracy: 0.1886 - val_mse: 1.3544 - val_weighted_accuracy: 0.1886 - val_weighted_mse: 1.3544
# Epoch 94/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1514 - accuracy: 0.2302 - mse: 1.5286 - weighted_accuracy: 0.6127 - weighted_mse: 1.5416 - val_loss: 0.1958 - val_accuracy: 0.2044 - val_mse: 1.4023 - val_weighted_accuracy: 0.2044 - val_weighted_mse: 1.4023
# Epoch 95/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1485 - accuracy: 0.2244 - mse: 1.5409 - weighted_accuracy: 0.6430 - weighted_mse: 1.5381 - val_loss: 0.1949 - val_accuracy: 0.1928 - val_mse: 1.3877 - val_weighted_accuracy: 0.1928 - val_weighted_mse: 1.3877
# Epoch 96/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1473 - accuracy: 0.2355 - mse: 1.5283 - weighted_accuracy: 0.6383 - weighted_mse: 1.5457 - val_loss: 0.1946 - val_accuracy: 0.2023 - val_mse: 1.3973 - val_weighted_accuracy: 0.2023 - val_weighted_mse: 1.3973
# Epoch 97/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1484 - accuracy: 0.2302 - mse: 1.5644 - weighted_accuracy: 0.6290 - weighted_mse: 1.5706 - val_loss: 0.1921 - val_accuracy: 0.2139 - val_mse: 1.3764 - val_weighted_accuracy: 0.2139 - val_weighted_mse: 1.3764
# Epoch 98/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1446 - accuracy: 0.2421 - mse: 1.5701 - weighted_accuracy: 0.6439 - weighted_mse: 1.5960 - val_loss: 0.1953 - val_accuracy: 0.1981 - val_mse: 1.3560 - val_weighted_accuracy: 0.1981 - val_weighted_mse: 1.3560
# Epoch 99/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1474 - accuracy: 0.2403 - mse: 1.5193 - weighted_accuracy: 0.6382 - weighted_mse: 1.5135 - val_loss: 0.1930 - val_accuracy: 0.1886 - val_mse: 1.2883 - val_weighted_accuracy: 0.1886 - val_weighted_mse: 1.2883
# Epoch 100/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1465 - accuracy: 0.2366 - mse: 1.5923 - weighted_accuracy: 0.6331 - weighted_mse: 1.6275 - val_loss: 0.1951 - val_accuracy: 0.1834 - val_mse: 1.3303 - val_weighted_accuracy: 0.1834 - val_weighted_mse: 1.3303
# Epoch 101/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1473 - accuracy: 0.2503 - mse: 1.5653 - weighted_accuracy: 0.6307 - weighted_mse: 1.5870 - val_loss: 0.1924 - val_accuracy: 0.2255 - val_mse: 1.4332 - val_weighted_accuracy: 0.2255 - val_weighted_mse: 1.4332
# Epoch 102/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1460 - accuracy: 0.2487 - mse: 1.5461 - weighted_accuracy: 0.6344 - weighted_mse: 1.5920 - val_loss: 0.1928 - val_accuracy: 0.2013 - val_mse: 1.3465 - val_weighted_accuracy: 0.2013 - val_weighted_mse: 1.3465
# Epoch 103/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1449 - accuracy: 0.2463 - mse: 1.6029 - weighted_accuracy: 0.6354 - weighted_mse: 1.6555 - val_loss: 0.1932 - val_accuracy: 0.2076 - val_mse: 1.3712 - val_weighted_accuracy: 0.2076 - val_weighted_mse: 1.3712
# Epoch 104/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1452 - accuracy: 0.2460 - mse: 1.5969 - weighted_accuracy: 0.6583 - weighted_mse: 1.6251 - val_loss: 0.1915 - val_accuracy: 0.2360 - val_mse: 1.4052 - val_weighted_accuracy: 0.2360 - val_weighted_mse: 1.4052
# Epoch 105/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1417 - accuracy: 0.2700 - mse: 1.5823 - weighted_accuracy: 0.6711 - weighted_mse: 1.6431 - val_loss: 0.1949 - val_accuracy: 0.2540 - val_mse: 1.5154 - val_weighted_accuracy: 0.2540 - val_weighted_mse: 1.5154
# Epoch 106/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1420 - accuracy: 0.2550 - mse: 1.6165 - weighted_accuracy: 0.6689 - weighted_mse: 1.6519 - val_loss: 0.1913 - val_accuracy: 0.2645 - val_mse: 1.4836 - val_weighted_accuracy: 0.2645 - val_weighted_mse: 1.4836
# Epoch 107/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1427 - accuracy: 0.2703 - mse: 1.6407 - weighted_accuracy: 0.6639 - weighted_mse: 1.6867 - val_loss: 0.1873 - val_accuracy: 0.2497 - val_mse: 1.4103 - val_weighted_accuracy: 0.2497 - val_weighted_mse: 1.4103
# Epoch 108/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1412 - accuracy: 0.2611 - mse: 1.5895 - weighted_accuracy: 0.6563 - weighted_mse: 1.6628 - val_loss: 0.1947 - val_accuracy: 0.2582 - val_mse: 1.4825 - val_weighted_accuracy: 0.2582 - val_weighted_mse: 1.4825
# Epoch 109/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1423 - accuracy: 0.2811 - mse: 1.5992 - weighted_accuracy: 0.6728 - weighted_mse: 1.6354 - val_loss: 0.1910 - val_accuracy: 0.2645 - val_mse: 1.4540 - val_weighted_accuracy: 0.2645 - val_weighted_mse: 1.4540
# Epoch 110/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1398 - accuracy: 0.2779 - mse: 1.6486 - weighted_accuracy: 0.6755 - weighted_mse: 1.7344 - val_loss: 0.1906 - val_accuracy: 0.2750 - val_mse: 1.4755 - val_weighted_accuracy: 0.2750 - val_weighted_mse: 1.4755
# Epoch 111/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1412 - accuracy: 0.2574 - mse: 1.6402 - weighted_accuracy: 0.6574 - weighted_mse: 1.7600 - val_loss: 0.1941 - val_accuracy: 0.2592 - val_mse: 1.5155 - val_weighted_accuracy: 0.2592 - val_weighted_mse: 1.5155
# Epoch 112/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1422 - accuracy: 0.2756 - mse: 1.6335 - weighted_accuracy: 0.6670 - weighted_mse: 1.7058 - val_loss: 0.1940 - val_accuracy: 0.2729 - val_mse: 1.5493 - val_weighted_accuracy: 0.2729 - val_weighted_mse: 1.5493
# Epoch 113/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1399 - accuracy: 0.2956 - mse: 1.6628 - weighted_accuracy: 0.6862 - weighted_mse: 1.7510 - val_loss: 0.1906 - val_accuracy: 0.2887 - val_mse: 1.5077 - val_weighted_accuracy: 0.2887 - val_weighted_mse: 1.5077
# Epoch 114/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1392 - accuracy: 0.2919 - mse: 1.6395 - weighted_accuracy: 0.6787 - weighted_mse: 1.7150 - val_loss: 0.1919 - val_accuracy: 0.2813 - val_mse: 1.5153 - val_weighted_accuracy: 0.2813 - val_weighted_mse: 1.5153
# Epoch 115/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1371 - accuracy: 0.2985 - mse: 1.7121 - weighted_accuracy: 0.6766 - weighted_mse: 1.8390 - val_loss: 0.1910 - val_accuracy: 0.3024 - val_mse: 1.5637 - val_weighted_accuracy: 0.3024 - val_weighted_mse: 1.5637
# Epoch 116/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1358 - accuracy: 0.2958 - mse: 1.7000 - weighted_accuracy: 0.6841 - weighted_mse: 1.8125 - val_loss: 0.1902 - val_accuracy: 0.3003 - val_mse: 1.5294 - val_weighted_accuracy: 0.3003 - val_weighted_mse: 1.5294
# Epoch 117/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1370 - accuracy: 0.3016 - mse: 1.7160 - weighted_accuracy: 0.6899 - weighted_mse: 1.8148 - val_loss: 0.1918 - val_accuracy: 0.3130 - val_mse: 1.5612 - val_weighted_accuracy: 0.3130 - val_weighted_mse: 1.5612
# Epoch 118/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1392 - accuracy: 0.3024 - mse: 1.7031 - weighted_accuracy: 0.6718 - weighted_mse: 1.8160 - val_loss: 0.1896 - val_accuracy: 0.3140 - val_mse: 1.5421 - val_weighted_accuracy: 0.3140 - val_weighted_mse: 1.5421
# Epoch 119/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1371 - accuracy: 0.3043 - mse: 1.7067 - weighted_accuracy: 0.6750 - weighted_mse: 1.8313 - val_loss: 0.1882 - val_accuracy: 0.3024 - val_mse: 1.4859 - val_weighted_accuracy: 0.3024 - val_weighted_mse: 1.4859
# Epoch 120/200
# 30/30 [==============================] - ETA: 0s - loss: 0.1377 - accuracy: 0.3176 - mse: 1.6803 - weighted_accuracy: 0.6941 - weighted_mse: 1.783 - 0s 15ms/step - loss: 0.1376 - accuracy: 0.3174 - mse: 1.6790 - weighted_accuracy: 0.6958 - weighted_mse: 1.7840 - val_loss: 0.1898 - val_accuracy: 0.2856 - val_mse: 1.5332 - val_weighted_accuracy: 0.2856 - val_weighted_mse: 1.5332
# Epoch 121/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1357 - accuracy: 0.3224 - mse: 1.6721 - weighted_accuracy: 0.6901 - weighted_mse: 1.8090 - val_loss: 0.1921 - val_accuracy: 0.2761 - val_mse: 1.4813 - val_weighted_accuracy: 0.2761 - val_weighted_mse: 1.4813
# Epoch 122/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1372 - accuracy: 0.3145 - mse: 1.7350 - weighted_accuracy: 0.6824 - weighted_mse: 1.8616 - val_loss: 0.1861 - val_accuracy: 0.3246 - val_mse: 1.5439 - val_weighted_accuracy: 0.3246 - val_weighted_mse: 1.5439
# Epoch 123/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1313 - accuracy: 0.3383 - mse: 1.7508 - weighted_accuracy: 0.7141 - weighted_mse: 1.9360 - val_loss: 0.1839 - val_accuracy: 0.3614 - val_mse: 1.5741 - val_weighted_accuracy: 0.3614 - val_weighted_mse: 1.5741
# Epoch 124/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1337 - accuracy: 0.3422 - mse: 1.7427 - weighted_accuracy: 0.7124 - weighted_mse: 1.9137 - val_loss: 0.1866 - val_accuracy: 0.3372 - val_mse: 1.5928 - val_weighted_accuracy: 0.3372 - val_weighted_mse: 1.5928
# Epoch 125/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1333 - accuracy: 0.3372 - mse: 1.7459 - weighted_accuracy: 0.6941 - weighted_mse: 1.9421 - val_loss: 0.1856 - val_accuracy: 0.3309 - val_mse: 1.5650 - val_weighted_accuracy: 0.3309 - val_weighted_mse: 1.5650
# Epoch 126/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1337 - accuracy: 0.3425 - mse: 1.7551 - weighted_accuracy: 0.7050 - weighted_mse: 1.9059 - val_loss: 0.1877 - val_accuracy: 0.3182 - val_mse: 1.5353 - val_weighted_accuracy: 0.3182 - val_weighted_mse: 1.5353
# Epoch 127/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1310 - accuracy: 0.3583 - mse: 1.7608 - weighted_accuracy: 0.7126 - weighted_mse: 1.9567 - val_loss: 0.1835 - val_accuracy: 0.3720 - val_mse: 1.6032 - val_weighted_accuracy: 0.3720 - val_weighted_mse: 1.6032
# Epoch 128/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1311 - accuracy: 0.3472 - mse: 1.7998 - weighted_accuracy: 0.7062 - weighted_mse: 2.0565 - val_loss: 0.1778 - val_accuracy: 0.3909 - val_mse: 1.5455 - val_weighted_accuracy: 0.3909 - val_weighted_mse: 1.5455
# Epoch 129/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.1339 - accuracy: 0.3570 - mse: 1.7631 - weighted_accuracy: 0.7047 - weighted_mse: 1.9507 - val_loss: 0.1869 - val_accuracy: 0.3467 - val_mse: 1.6174 - val_weighted_accuracy: 0.3467 - val_weighted_mse: 1.6174
# Epoch 130/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1324 - accuracy: 0.3633 - mse: 1.8050 - weighted_accuracy: 0.7197 - weighted_mse: 2.0176 - val_loss: 0.1839 - val_accuracy: 0.3751 - val_mse: 1.5893 - val_weighted_accuracy: 0.3751 - val_weighted_mse: 1.5893
# Epoch 131/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1275 - accuracy: 0.3683 - mse: 1.8519 - weighted_accuracy: 0.7285 - weighted_mse: 2.1423 - val_loss: 0.1820 - val_accuracy: 0.3625 - val_mse: 1.5485 - val_weighted_accuracy: 0.3625 - val_weighted_mse: 1.5485
# Epoch 132/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1317 - accuracy: 0.3778 - mse: 1.8164 - weighted_accuracy: 0.7145 - weighted_mse: 1.9903 - val_loss: 0.1822 - val_accuracy: 0.3688 - val_mse: 1.5926 - val_weighted_accuracy: 0.3688 - val_weighted_mse: 1.5926
# Epoch 133/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1270 - accuracy: 0.3793 - mse: 1.8591 - weighted_accuracy: 0.7294 - weighted_mse: 2.1370 - val_loss: 0.1834 - val_accuracy: 0.3930 - val_mse: 1.6486 - val_weighted_accuracy: 0.3930 - val_weighted_mse: 1.6486
# Epoch 134/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1297 - accuracy: 0.3786 - mse: 1.8385 - weighted_accuracy: 0.7167 - weighted_mse: 2.0840 - val_loss: 0.1842 - val_accuracy: 0.3772 - val_mse: 1.5978 - val_weighted_accuracy: 0.3772 - val_weighted_mse: 1.5978
# Epoch 135/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1308 - accuracy: 0.4004 - mse: 1.8187 - weighted_accuracy: 0.7137 - weighted_mse: 2.0649 - val_loss: 0.1821 - val_accuracy: 0.3825 - val_mse: 1.5923 - val_weighted_accuracy: 0.3825 - val_weighted_mse: 1.5923
# Epoch 136/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1275 - accuracy: 0.4002 - mse: 1.8583 - weighted_accuracy: 0.7259 - weighted_mse: 2.1502 - val_loss: 0.1813 - val_accuracy: 0.3709 - val_mse: 1.5726 - val_weighted_accuracy: 0.3709 - val_weighted_mse: 1.5726
# Epoch 137/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1284 - accuracy: 0.3859 - mse: 1.8208 - weighted_accuracy: 0.7280 - weighted_mse: 2.0675 - val_loss: 0.1794 - val_accuracy: 0.4141 - val_mse: 1.6328 - val_weighted_accuracy: 0.4141 - val_weighted_mse: 1.6328
# Epoch 138/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1247 - accuracy: 0.3996 - mse: 1.8672 - weighted_accuracy: 0.7346 - weighted_mse: 2.1998 - val_loss: 0.1778 - val_accuracy: 0.4341 - val_mse: 1.6789 - val_weighted_accuracy: 0.4341 - val_weighted_mse: 1.6789
# Epoch 139/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1257 - accuracy: 0.4038 - mse: 1.8980 - weighted_accuracy: 0.7383 - weighted_mse: 2.1936 - val_loss: 0.1784 - val_accuracy: 0.4110 - val_mse: 1.6589 - val_weighted_accuracy: 0.4110 - val_weighted_mse: 1.6589
# Epoch 140/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1248 - accuracy: 0.4183 - mse: 1.9130 - weighted_accuracy: 0.7492 - weighted_mse: 2.2368 - val_loss: 0.1760 - val_accuracy: 0.4489 - val_mse: 1.6591 - val_weighted_accuracy: 0.4489 - val_weighted_mse: 1.6591
# Epoch 141/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1247 - accuracy: 0.4265 - mse: 1.9198 - weighted_accuracy: 0.7448 - weighted_mse: 2.2782 - val_loss: 0.1817 - val_accuracy: 0.4289 - val_mse: 1.6890 - val_weighted_accuracy: 0.4289 - val_weighted_mse: 1.6890
# Epoch 142/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1259 - accuracy: 0.4365 - mse: 1.9198 - weighted_accuracy: 0.7414 - weighted_mse: 2.2808 - val_loss: 0.1738 - val_accuracy: 0.4710 - val_mse: 1.7051 - val_weighted_accuracy: 0.4710 - val_weighted_mse: 1.7051
# Epoch 143/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1261 - accuracy: 0.4391 - mse: 1.8992 - weighted_accuracy: 0.7386 - weighted_mse: 2.2358 - val_loss: 0.1802 - val_accuracy: 0.4362 - val_mse: 1.6478 - val_weighted_accuracy: 0.4362 - val_weighted_mse: 1.6478
# Epoch 144/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1244 - accuracy: 0.4315 - mse: 1.9271 - weighted_accuracy: 0.7395 - weighted_mse: 2.3195 - val_loss: 0.1805 - val_accuracy: 0.4362 - val_mse: 1.7274 - val_weighted_accuracy: 0.4362 - val_weighted_mse: 1.7274
# Epoch 145/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1258 - accuracy: 0.4305 - mse: 1.9612 - weighted_accuracy: 0.7251 - weighted_mse: 2.3445 - val_loss: 0.1680 - val_accuracy: 0.5058 - val_mse: 1.6329 - val_weighted_accuracy: 0.5058 - val_weighted_mse: 1.6329
# Epoch 146/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1222 - accuracy: 0.4576 - mse: 1.9430 - weighted_accuracy: 0.7421 - weighted_mse: 2.3230 - val_loss: 0.1781 - val_accuracy: 0.4436 - val_mse: 1.6785 - val_weighted_accuracy: 0.4436 - val_weighted_mse: 1.6785
# Epoch 147/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1224 - accuracy: 0.4465 - mse: 1.9915 - weighted_accuracy: 0.7509 - weighted_mse: 2.4237 - val_loss: 0.1743 - val_accuracy: 0.4763 - val_mse: 1.7370 - val_weighted_accuracy: 0.4763 - val_weighted_mse: 1.7370
# Epoch 148/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1209 - accuracy: 0.4668 - mse: 2.0262 - weighted_accuracy: 0.7611 - weighted_mse: 2.4365 - val_loss: 0.1666 - val_accuracy: 0.5227 - val_mse: 1.7347 - val_weighted_accuracy: 0.5227 - val_weighted_mse: 1.7347
# Epoch 149/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1236 - accuracy: 0.4665 - mse: 2.0317 - weighted_accuracy: 0.7466 - weighted_mse: 2.4185 - val_loss: 0.1801 - val_accuracy: 0.4204 - val_mse: 1.7438 - val_weighted_accuracy: 0.4204 - val_weighted_mse: 1.7438
# Epoch 150/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1209 - accuracy: 0.4784 - mse: 1.9788 - weighted_accuracy: 0.7639 - weighted_mse: 2.3635 - val_loss: 0.1735 - val_accuracy: 0.4910 - val_mse: 1.7955 - val_weighted_accuracy: 0.4910 - val_weighted_mse: 1.7955
# Epoch 151/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1241 - accuracy: 0.4805 - mse: 1.9556 - weighted_accuracy: 0.7598 - weighted_mse: 2.3719 - val_loss: 0.1653 - val_accuracy: 0.5216 - val_mse: 1.6886 - val_weighted_accuracy: 0.5216 - val_weighted_mse: 1.6886
# Epoch 152/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1232 - accuracy: 0.4802 - mse: 2.0082 - weighted_accuracy: 0.7526 - weighted_mse: 2.4006 - val_loss: 0.1617 - val_accuracy: 0.5522 - val_mse: 1.7293 - val_weighted_accuracy: 0.5522 - val_weighted_mse: 1.7293
# Epoch 153/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1204 - accuracy: 0.4960 - mse: 2.0550 - weighted_accuracy: 0.7796 - weighted_mse: 2.4954 - val_loss: 0.1723 - val_accuracy: 0.5016 - val_mse: 1.7949 - val_weighted_accuracy: 0.5016 - val_weighted_mse: 1.7949
# Epoch 154/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1216 - accuracy: 0.4839 - mse: 2.0536 - weighted_accuracy: 0.7569 - weighted_mse: 2.4800 - val_loss: 0.1631 - val_accuracy: 0.5532 - val_mse: 1.7948 - val_weighted_accuracy: 0.5532 - val_weighted_mse: 1.7948
# Epoch 155/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1208 - accuracy: 0.5000 - mse: 2.0538 - weighted_accuracy: 0.7631 - weighted_mse: 2.5110 - val_loss: 0.1555 - val_accuracy: 0.6059 - val_mse: 1.7194 - val_weighted_accuracy: 0.6059 - val_weighted_mse: 1.7194
# Epoch 156/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1207 - accuracy: 0.4989 - mse: 2.0898 - weighted_accuracy: 0.7680 - weighted_mse: 2.5392 - val_loss: 0.1691 - val_accuracy: 0.5111 - val_mse: 1.7080 - val_weighted_accuracy: 0.5111 - val_weighted_mse: 1.7080
# Epoch 157/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1150 - accuracy: 0.5032 - mse: 2.1010 - weighted_accuracy: 0.7835 - weighted_mse: 2.6260 - val_loss: 0.1677 - val_accuracy: 0.5279 - val_mse: 1.7444 - val_weighted_accuracy: 0.5279 - val_weighted_mse: 1.7444
# Epoch 158/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1161 - accuracy: 0.5087 - mse: 2.1138 - weighted_accuracy: 0.7623 - weighted_mse: 2.7267 - val_loss: 0.1667 - val_accuracy: 0.5258 - val_mse: 1.7828 - val_weighted_accuracy: 0.5258 - val_weighted_mse: 1.7828
# Epoch 159/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1138 - accuracy: 0.5242 - mse: 2.1432 - weighted_accuracy: 0.7769 - weighted_mse: 2.7097 - val_loss: 0.1639 - val_accuracy: 0.5638 - val_mse: 1.8496 - val_weighted_accuracy: 0.5638 - val_weighted_mse: 1.8496
# Epoch 160/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1158 - accuracy: 0.5229 - mse: 2.1269 - weighted_accuracy: 0.7749 - weighted_mse: 2.6941 - val_loss: 0.1599 - val_accuracy: 0.5690 - val_mse: 1.7968 - val_weighted_accuracy: 0.5690 - val_weighted_mse: 1.7968
# Epoch 161/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1157 - accuracy: 0.5232 - mse: 2.1887 - weighted_accuracy: 0.7747 - weighted_mse: 2.7874 - val_loss: 0.1709 - val_accuracy: 0.5132 - val_mse: 1.8007 - val_weighted_accuracy: 0.5132 - val_weighted_mse: 1.8007
# Epoch 162/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1156 - accuracy: 0.5179 - mse: 2.1620 - weighted_accuracy: 0.7557 - weighted_mse: 2.7199 - val_loss: 0.1583 - val_accuracy: 0.5869 - val_mse: 1.7746 - val_weighted_accuracy: 0.5869 - val_weighted_mse: 1.7746
# Epoch 163/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1132 - accuracy: 0.5308 - mse: 2.1945 - weighted_accuracy: 0.7783 - weighted_mse: 2.8238 - val_loss: 0.1584 - val_accuracy: 0.5869 - val_mse: 1.8294 - val_weighted_accuracy: 0.5869 - val_weighted_mse: 1.8294
# Epoch 164/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1140 - accuracy: 0.5329 - mse: 2.2269 - weighted_accuracy: 0.7876 - weighted_mse: 2.8874 - val_loss: 0.1634 - val_accuracy: 0.5648 - val_mse: 1.8855 - val_weighted_accuracy: 0.5648 - val_weighted_mse: 1.8855
# Epoch 165/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1116 - accuracy: 0.5522 - mse: 2.2530 - weighted_accuracy: 0.8020 - weighted_mse: 2.9090 - val_loss: 0.1591 - val_accuracy: 0.5764 - val_mse: 1.8246 - val_weighted_accuracy: 0.5764 - val_weighted_mse: 1.8246
# Epoch 166/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1092 - accuracy: 0.5466 - mse: 2.2433 - weighted_accuracy: 0.7924 - weighted_mse: 2.9870 - val_loss: 0.1640 - val_accuracy: 0.5532 - val_mse: 1.8920 - val_weighted_accuracy: 0.5532 - val_weighted_mse: 1.8920
# Epoch 167/200
# 30/30 [==============================] - 0s 14ms/step - loss: 0.1109 - accuracy: 0.5556 - mse: 2.2334 - weighted_accuracy: 0.7943 - weighted_mse: 2.9155 - val_loss: 0.1591 - val_accuracy: 0.5901 - val_mse: 2.0196 - val_weighted_accuracy: 0.5901 - val_weighted_mse: 2.0196
# Epoch 168/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1120 - accuracy: 0.5672 - mse: 2.2689 - weighted_accuracy: 0.7861 - weighted_mse: 3.0222 - val_loss: 0.1510 - val_accuracy: 0.6407 - val_mse: 1.9914 - val_weighted_accuracy: 0.6407 - val_weighted_mse: 1.9914
# Epoch 169/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1113 - accuracy: 0.5593 - mse: 2.2740 - weighted_accuracy: 0.7917 - weighted_mse: 3.0228 - val_loss: 0.1542 - val_accuracy: 0.6322 - val_mse: 1.9342 - val_weighted_accuracy: 0.6322 - val_weighted_mse: 1.9342
# Epoch 170/200
# 30/30 [==============================] - 1s 18ms/step - loss: 0.1126 - accuracy: 0.5664 - mse: 2.2770 - weighted_accuracy: 0.7950 - weighted_mse: 2.9993 - val_loss: 0.1541 - val_accuracy: 0.6228 - val_mse: 1.9521 - val_weighted_accuracy: 0.6228 - val_weighted_mse: 1.9521
# Epoch 171/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1064 - accuracy: 0.5801 - mse: 2.3566 - weighted_accuracy: 0.8031 - weighted_mse: 3.1772 - val_loss: 0.1569 - val_accuracy: 0.6270 - val_mse: 2.0434 - val_weighted_accuracy: 0.6270 - val_weighted_mse: 2.0434
# Epoch 172/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1126 - accuracy: 0.5901 - mse: 2.3251 - weighted_accuracy: 0.7803 - weighted_mse: 3.1077 - val_loss: 0.1569 - val_accuracy: 0.6048 - val_mse: 2.0370 - val_weighted_accuracy: 0.6048 - val_weighted_mse: 2.0370
# Epoch 173/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1116 - accuracy: 0.5917 - mse: 2.4007 - weighted_accuracy: 0.8023 - weighted_mse: 3.1356 - val_loss: 0.1578 - val_accuracy: 0.5869 - val_mse: 1.9890 - val_weighted_accuracy: 0.5869 - val_weighted_mse: 1.9890
# Epoch 174/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.1118 - accuracy: 0.6101 - mse: 2.3734 - weighted_accuracy: 0.7970 - weighted_mse: 3.1403 - val_loss: 0.1539 - val_accuracy: 0.6249 - val_mse: 2.0454 - val_weighted_accuracy: 0.6249 - val_weighted_mse: 2.0454
# Epoch 175/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1114 - accuracy: 0.6141 - mse: 2.3907 - weighted_accuracy: 0.8000 - weighted_mse: 3.0642 - val_loss: 0.1524 - val_accuracy: 0.6375 - val_mse: 2.0453 - val_weighted_accuracy: 0.6375 - val_weighted_mse: 2.0453
# Epoch 176/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.1061 - accuracy: 0.5998 - mse: 2.4019 - weighted_accuracy: 0.8141 - weighted_mse: 3.2834 - val_loss: 0.1568 - val_accuracy: 0.6185 - val_mse: 2.0451 - val_weighted_accuracy: 0.6185 - val_weighted_mse: 2.0451
# Epoch 177/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.1082 - accuracy: 0.6149 - mse: 2.4501 - weighted_accuracy: 0.8095 - weighted_mse: 3.2858 - val_loss: 0.1510 - val_accuracy: 0.6491 - val_mse: 2.1603 - val_weighted_accuracy: 0.6491 - val_weighted_mse: 2.1603
# Epoch 178/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.1108 - accuracy: 0.5911 - mse: 2.4068 - weighted_accuracy: 0.8057 - weighted_mse: 3.1536 - val_loss: 0.1528 - val_accuracy: 0.6249 - val_mse: 1.9853 - val_weighted_accuracy: 0.6249 - val_weighted_mse: 1.9853
# Epoch 179/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1090 - accuracy: 0.6025 - mse: 2.4798 - weighted_accuracy: 0.8082 - weighted_mse: 3.3577 - val_loss: 0.1483 - val_accuracy: 0.6565 - val_mse: 2.0025 - val_weighted_accuracy: 0.6565 - val_weighted_mse: 2.0025
# Epoch 180/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.1032 - accuracy: 0.6027 - mse: 2.5048 - weighted_accuracy: 0.8135 - weighted_mse: 3.5290 - val_loss: 0.1512 - val_accuracy: 0.6512 - val_mse: 2.0302 - val_weighted_accuracy: 0.6512 - val_weighted_mse: 2.0302
# Epoch 181/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1065 - accuracy: 0.6167 - mse: 2.4679 - weighted_accuracy: 0.8006 - weighted_mse: 3.3382 - val_loss: 0.1547 - val_accuracy: 0.6322 - val_mse: 2.1083 - val_weighted_accuracy: 0.6322 - val_weighted_mse: 2.1083
# Epoch 182/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1046 - accuracy: 0.6043 - mse: 2.5614 - weighted_accuracy: 0.8069 - weighted_mse: 3.5885 - val_loss: 0.1509 - val_accuracy: 0.6449 - val_mse: 2.0247 - val_weighted_accuracy: 0.6449 - val_weighted_mse: 2.0247
# Epoch 183/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1069 - accuracy: 0.6172 - mse: 2.4906 - weighted_accuracy: 0.8084 - weighted_mse: 3.3304 - val_loss: 0.1475 - val_accuracy: 0.6596 - val_mse: 2.1060 - val_weighted_accuracy: 0.6596 - val_weighted_mse: 2.1060
# Epoch 184/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1082 - accuracy: 0.6059 - mse: 2.5422 - weighted_accuracy: 0.8022 - weighted_mse: 3.4308 - val_loss: 0.1585 - val_accuracy: 0.6101 - val_mse: 2.1171 - val_weighted_accuracy: 0.6101 - val_weighted_mse: 2.1171
# Epoch 185/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1041 - accuracy: 0.6043 - mse: 2.5301 - weighted_accuracy: 0.8228 - weighted_mse: 3.5576 - val_loss: 0.1505 - val_accuracy: 0.6438 - val_mse: 2.1399 - val_weighted_accuracy: 0.6438 - val_weighted_mse: 2.1399
# Epoch 186/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1073 - accuracy: 0.6164 - mse: 2.6046 - weighted_accuracy: 0.8133 - weighted_mse: 3.6052 - val_loss: 0.1450 - val_accuracy: 0.6702 - val_mse: 2.1736 - val_weighted_accuracy: 0.6702 - val_weighted_mse: 2.1736
# Epoch 187/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1036 - accuracy: 0.6159 - mse: 2.4948 - weighted_accuracy: 0.8130 - weighted_mse: 3.5534 - val_loss: 0.1538 - val_accuracy: 0.6344 - val_mse: 2.1794 - val_weighted_accuracy: 0.6344 - val_weighted_mse: 2.1794
# Epoch 188/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1037 - accuracy: 0.6146 - mse: 2.6518 - weighted_accuracy: 0.8180 - weighted_mse: 3.7334 - val_loss: 0.1457 - val_accuracy: 0.6702 - val_mse: 2.2577 - val_weighted_accuracy: 0.6702 - val_weighted_mse: 2.2577
# Epoch 189/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1017 - accuracy: 0.6272 - mse: 2.6619 - weighted_accuracy: 0.8119 - weighted_mse: 3.8206 - val_loss: 0.1511 - val_accuracy: 0.6470 - val_mse: 2.1052 - val_weighted_accuracy: 0.6470 - val_weighted_mse: 2.1052
# Epoch 190/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1004 - accuracy: 0.6338 - mse: 2.7054 - weighted_accuracy: 0.8233 - weighted_mse: 3.8161 - val_loss: 0.1396 - val_accuracy: 0.6955 - val_mse: 2.1999 - val_weighted_accuracy: 0.6955 - val_weighted_mse: 2.1999
# Epoch 191/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1035 - accuracy: 0.6212 - mse: 2.6652 - weighted_accuracy: 0.8272 - weighted_mse: 3.7459 - val_loss: 0.1438 - val_accuracy: 0.6913 - val_mse: 2.3956 - val_weighted_accuracy: 0.6913 - val_weighted_mse: 2.3956
# Epoch 192/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1020 - accuracy: 0.6164 - mse: 2.5920 - weighted_accuracy: 0.8095 - weighted_mse: 3.7745 - val_loss: 0.1481 - val_accuracy: 0.6617 - val_mse: 2.1310 - val_weighted_accuracy: 0.6617 - val_weighted_mse: 2.1310
# Epoch 193/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.1018 - accuracy: 0.6391 - mse: 2.6775 - weighted_accuracy: 0.8320 - weighted_mse: 3.7399 - val_loss: 0.1616 - val_accuracy: 0.6154 - val_mse: 2.4446 - val_weighted_accuracy: 0.6154 - val_weighted_mse: 2.4446
# Epoch 194/200
# 30/30 [==============================] - 0s 17ms/step - loss: 0.0983 - accuracy: 0.6238 - mse: 2.8497 - weighted_accuracy: 0.8245 - weighted_mse: 4.1944 - val_loss: 0.1401 - val_accuracy: 0.6986 - val_mse: 2.2292 - val_weighted_accuracy: 0.6986 - val_weighted_mse: 2.2292
# Epoch 195/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.1007 - accuracy: 0.6407 - mse: 2.7237 - weighted_accuracy: 0.8258 - weighted_mse: 3.8418 - val_loss: 0.1485 - val_accuracy: 0.6639 - val_mse: 2.2941 - val_weighted_accuracy: 0.6639 - val_weighted_mse: 2.2941
# Epoch 196/200
# 30/30 [==============================] - 1s 17ms/step - loss: 0.1015 - accuracy: 0.6509 - mse: 2.6966 - weighted_accuracy: 0.8241 - weighted_mse: 3.8525 - val_loss: 0.1505 - val_accuracy: 0.6712 - val_mse: 2.4465 - val_weighted_accuracy: 0.6712 - val_weighted_mse: 2.4465
# Epoch 197/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0993 - accuracy: 0.6502 - mse: 2.8371 - weighted_accuracy: 0.8255 - weighted_mse: 4.1371 - val_loss: 0.1524 - val_accuracy: 0.6544 - val_mse: 2.2695 - val_weighted_accuracy: 0.6544 - val_weighted_mse: 2.2695
# Epoch 198/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.1007 - accuracy: 0.6296 - mse: 2.8134 - weighted_accuracy: 0.8129 - weighted_mse: 4.0406 - val_loss: 0.1477 - val_accuracy: 0.6575 - val_mse: 2.3335 - val_weighted_accuracy: 0.6575 - val_weighted_mse: 2.3335
# Epoch 199/200
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0995 - accuracy: 0.6570 - mse: 2.8158 - weighted_accuracy: 0.8195 - weighted_mse: 4.0282 - val_loss: 0.1535 - val_accuracy: 0.6575 - val_mse: 2.3199 - val_weighted_accuracy: 0.6575 - val_weighted_mse: 2.3199
# Epoch 200/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.1005 - accuracy: 0.6554 - mse: 2.9041 - weighted_accuracy: 0.8398 - weighted_mse: 4.1023 - val_loss: 0.1304 - val_accuracy: 0.7355 - val_mse: 2.3272 - val_weighted_accuracy: 0.7355 - val_weighted_mse: 2.3272

# %%
# Score model
score = model.evaluate(validation_x, validation_y, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.13043057918548584
# Test accuracy: 0.735511064529419

# %%
predictions = model.predict(validation_x)
print(predictions)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
from collections import Counter

Counter(predictions)
# Out:
# [[-0.5592348  -2.0333884  -0.39339182]
#  [-2.678255   -0.22682706 -0.5698436 ]
#  [-1.330913   -1.1807383  -0.09590165]
#  ...
#  [-1.7733096  -1.302166   -0.05560493]
#  [-1.0692393  -1.2257258  -0.19914237]
#  [-0.73237836 -1.4384266  -0.35599083]]
# Counter({2: 753, 1: 92, 0: 104})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in validation_y]
Counter(actual)
# Out:
# Counter({2: 860, 0: 46, 1: 43})

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold))
# Out:
# number of predictions: 949
# actual predicted buys: 6
# actual buys but predicted sell: 2
# actual buys but predicted hold: 35
# actual sells but predicted buy: 4
# actual predicted sells: 8
# actual sells but predicted hold: 34
# actual holds but predicted buy: 82
# actual holds but predicted sell: 94
# actual predicted holds: 684
# Percentage buys correct: 13.953488372093023%
# Percentage sells correct: 17.391304347826086%
# Percentage holds correct: 79.53488372093024%
# actual buys: 43
# actual sells: 46
# actual holds: 860

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.figure(figsize=(20,10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Save model
model.save("models/{}".format('MFC_support_image_cnn_buy_hold_sell.model'))
# Out:
# INFO:tensorflow:Assets written to: models/MFC_support_image_cnn_buy_hold_sell.model\assets

# %% [markdown]
# ### Test Performance

# %% [markdown]
# ### non-recession

# %%
logger = []

# %%
seed = 10
df = pd.read_csv("data/variation 6/initial_indicators/MFC_data_test.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22        16.10  15.369379  -4.347841  12991200.0     2.0
# 2019-01-23        15.75  15.427936 -19.565241  11195700.0     2.0
# 2019-01-24        15.79  15.483638 -19.902947  12310800.0     2.0
# 2019-01-25        15.63  15.506155 -34.131754  10454700.0     2.0
# 2019-01-28        15.75  15.543670 -30.405447  11863600.0     2.0

# %%
df2 = pd.read_csv("data/variation 6/initial_indicators/JPM_data_test.csv")
df2.set_index('Date', inplace=True)
df2.head()
# Out:
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2019-01-22   104.589996  101.198442  -3.459880  84335200.0     2.0
# 2019-01-23   102.940002  101.466374 -21.874992  67251500.0     2.0
# 2019-01-24   102.680000  101.653086 -27.040213  55104800.0     2.0
# 2019-01-25   102.739998  101.820303 -32.628441  66401600.0     2.0
# 2019-01-28   103.389999  102.061795 -23.968276  80771000.0     2.0

# %%
df['support'] = df2['previous_1d']
df.head()
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels     support
# Date
# 2019-01-22        16.10  15.369379  -4.347841  12991200.0     2.0  104.589996
# 2019-01-23        15.75  15.427936 -19.565241  11195700.0     2.0  102.940002
# 2019-01-24        15.79  15.483638 -19.902947  12310800.0     2.0  102.680000
# 2019-01-25        15.63  15.506155 -34.131754  10454700.0     2.0  102.739998
# 2019-01-28        15.75  15.543670 -30.405447  11863600.0     2.0  103.389999

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['support'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['labels'].plot(figsize=(16,6),x='Date', y='labels')

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
support_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
data_15_support = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        data_15_support.append([i[-1]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        data_15_support_arr = min_max_scaler.fit_transform(data_15_support)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        support_data.append(data_15_support_arr)
        labels.append(i[4])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
        data_15_support = data_15_support[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        data_15_support.append([i[-1]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)
support_data = np.array(support_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/MFC_support_image_cnn_buy_hold_sell.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1]) ; logger.append(score[1])
# Out:
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1296 - accuracy: 0.7523 - mean_squared_error: 2.3381 - weighted_accuracy: 0.7523 - weighted_mean_squared_error: 2.3381
# Test loss: 0.12957729399204254
# Test accuracy: 0.752293586730957

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({1: 21, 2: 174, 0: 23})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]
Counter(actual)
# Out:
# Counter({1: 10, 2: 198, 0: 10})

# %%
df = pd.read_csv("data/variation 6/initial_indicators/MFC_data_test.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14       OBV_7  labels  \
# Date
# 2019-02-11    15.630000  15.794888 -75.000000  15118200.0     1.0
# 2019-02-12    15.960000  15.769520 -80.303008  13534100.0     2.0
# 2019-02-13    15.800000  15.798825 -30.303008  15499400.0     2.0
# 2019-02-14    16.040001  15.799006 -54.545415  12941900.0     2.0
# 2019-02-15    16.230000  15.836082 -41.935404  16615800.0     2.0
#
#             predictions  actual
# Date
# 2019-02-11            1       1
# 2019-02-12            1       2
# 2019-02-13            2       2
# 2019-02-14            2       2
# 2019-02-15            2       2

# %%
#%matplotlib notebook
df['previous_1d'].plot(figsize=(16,6),x='Date', y='Close')
df['EMA_12'].plot(figsize=(16,6),x='Date', y='EMA')
df['predictions'].plot(figsize=(16,6),x='Date', y='predictions')
#df['actual'].plot(figsize=(16,6),x='Date', y='actual')

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold)) ; logger.append(str(100*buy_buy/buy) + "%") ; logger.append(str(100*sell_sell/sell) + "%") ; logger.append(str(100*hold_hold/hold) + "%")

correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%") ; logger.append(str(100*correct_minima/buy) + "%") ; logger.append(str(100*correct_maxima/sell) + "%") ; logger.append(str(100*correct_hold/hold) + "%")
# Out:
# number of predictions: 218
# actual predicted buys: 3
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 0
# actual predicted sells: 2
# actual sells but predicted hold: 8
# actual holds but predicted buy: 18
# actual holds but predicted sell: 21
# actual predicted holds: 159
# Percentage buys correct: 30.0%
# Percentage sells correct: 20.0%
# Percentage holds correct: 80.3030303030303%
# actual buys: 10
# actual sells: 10
# actual holds: 198
# [15.630000114440918, 15.800000190734865, 15.960000038146973, 16.040000915527347, 16.229999542236328, 16.530000686645508, 16.799999237060547, 16.879999160766598, 16.979999542236328]
# [16.799999237060547, 16.879999160766598, 16.879999160766598, 16.930000305175778, 16.979999542236328, 17.0, 17.09000015258789, 17.100000381469727, 17.280000686645508]
# Percentage buys correct: 71.42857142857143%
# Percentage sells correct: 52.17391304347826%
# Percentage holds correct: 84.39306358381504%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $15.630000114440918
# Shares owned at the moment: 638
# Cash capital at the moment: $0.6370917859076144
#
#
# Price increase from previously bought: 8.33929928723447%
# Share price: $16.979999542236328
# Shares owned at the moment: 0
# Cash capital at the moment: $10804.08539053583
#
#
# Share price: $16.540000915527347
# Shares owned at the moment: 651
# Cash capital at the moment: $6.934057888505777
#
#
# Price increase from previously bought: 5.87570091532299%
# Share price: $17.559999465942386
# Shares owned at the moment: 0
# Cash capital at the moment: $11407.056921173094
#
#
# Share price: $17.760000228881836
# Shares owned at the moment: 640
# Cash capital at the moment: $9.399174285887057
#
#
# Stop Loss Activated!
#
# Share price: $17.180000305175778
# Shares owned at the moment: 0
# Cash capital at the moment: $10974.362569061275
#
#
# Share price: $17.180000305175778
# Shares owned at the moment: 637
# Cash capital at the moment: $0.6073091297130304
#
#
# Price increase from previously bought: 7.38803373015533%
# Share price: $18.5
# Shares owned at the moment: 0
# Cash capital at the moment: $11752.699934129712
#
#
# Share price: $18.399999618530273
# Shares owned at the moment: 636
# Cash capital at the moment: $18.118577411649312
#
#
# Stop Loss Activated!
#
# Share price: $17.479999542236328
# Shares owned at the moment: 0
# Cash capital at the moment: $11104.825767074582
#
#
# Share price: $16.530000686645508
# Shares owned at the moment: 669
# Cash capital at the moment: $15.844238945481266
#
#
# Price increase from previously bought: 9.197587032559728%
# Share price: $18.100000381469727
# Shares owned at the moment: 0
# Cash capital at the moment: $12091.445018446919
#
#
# Share price: $17.649999618530273
# Shares owned at the moment: 683
# Cash capital at the moment: $3.344167207236751
#
#
# Price increase from previously bought: 5.884456137384686%
# Share price: $18.739999771118164
# Shares owned at the moment: 0
# Cash capital at the moment: $12767.56560631084
#
#
# Share price: $18.76000022888184
# Shares owned at the moment: 678
# Cash capital at the moment: $13.307430702203419
#
#
# Price increase from previously bought: 5.998484395945014%
# Share price: $19.940000534057614
# Shares owned at the moment: 0
# Cash capital at the moment: $13495.449661797515
#
#
#
#
# Capital at the end of test period: $13495.449661797515
# profit gained: 34.954496617975146%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $12687.37270157766
# profit gained: 26.873727015776605%

# %%
df_length = len(log)
log.loc[df_length] = logger
log.head()
# Out:
#    Test_accuracy correct_buys       correct_sells       correct_holds  \
# 0       0.848624        10.0%               10.0%  92.42424242424242%
# 1       0.799087        25.0%  9.090909090909092%               86.0%
# 2       0.752294        30.0%               20.0%   80.3030303030303%
#
#      correct_low_buys   correct_high_sells   correct_mid_holds  \
# 0               40.0%                50.0%  85.07462686567165%
# 1               55.0%  18.181818181818183%  85.02673796791444%
# 2  71.42857142857143%   52.17391304347826%  84.39306358381504%
#
#           Profit gained     buy_n_hold profit
# 0   15.892216613554954%   26.873727015776605%
# 1  -14.177789706330332%  -14.559847748279573%
# 2   34.954496617975146%   26.873727015776605%

# %% [markdown]
# ### Recession

# %%
logger = []

# %%
seed = 10
df = pd.read_csv("data/variation 6/initial_indicators/MFC_data_test2.csv")
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels
# Date
# 2020-01-22    20.620001  20.787224 -56.481365  5587900.0     2.0
# 2020-01-23    20.760000  20.783036 -48.453572  7034300.0     2.0
# 2020-01-24    20.799999  20.785645 -44.329960  8383300.0     2.0
# 2020-01-27    20.650000  20.764777 -59.793849  5159000.0     2.0
# 2020-01-28    20.030001  20.651734 -87.591226  2998800.0     2.0

# %%
df2 = pd.read_csv("data/variation 6/initial_indicators/JPM_data_test2.csv")
df2.set_index('Date', inplace=True)
df2.head()
# Out:
#             previous_1d      EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22   136.839996  137.690058 -77.454723  33776700.0     2.0
# 2020-01-23   136.679993  137.534664 -80.363881  26227600.0     2.0
# 2020-01-24   136.539993  137.381637 -69.867648  16881900.0     2.0
# 2020-01-27   133.149994  136.730615 -90.166021   1715500.0     1.0
# 2020-01-28   132.029999  136.007444 -79.004573 -11145000.0     2.0

# %%
df['support'] = df2['previous_1d']
df.head()
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels     support
# Date
# 2020-01-22    20.620001  20.787224 -56.481365  5587900.0     2.0  136.839996
# 2020-01-23    20.760000  20.783036 -48.453572  7034300.0     2.0  136.679993
# 2020-01-24    20.799999  20.785645 -44.329960  8383300.0     2.0  136.539993
# 2020-01-27    20.650000  20.764777 -59.793849  5159000.0     2.0  133.149994
# 2020-01-28    20.030001  20.651734 -87.591226  2998800.0     2.0  132.029999

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
support_data = []
labels = []
data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
data_15_support = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        data_15_support.append([i[-1]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        data_15_support_arr = min_max_scaler.fit_transform(data_15_support)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        support_data.append(data_15_support_arr)
        labels.append(i[4])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]
        data_15_support = data_15_support[1:]
    
    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        data_15_support.append([i[-1]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)
support_data = np.array(support_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
X = X/255
y = np.array(y)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, 3)

# %%
model = tf.keras.models.load_model("models/MFC_support_image_cnn_buy_hold_sell.model")
score = model.evaluate(X, y)
print('Test loss:', score[0])
print('Test accuracy:', score[1]) ; logger.append(score[1])
# Out:
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1367 - accuracy: 0.6712 - mean_squared_error: 2.4701 - weighted_accuracy: 0.6712 - weighted_mean_squared_error: 2.4701
# Test loss: 0.13674311339855194
# Test accuracy: 0.6712328791618347

# %%
from collections import Counter

predictions = model.predict(X)
predictions = [np.argmax(y, axis=None, out=None) for y in predictions]

Counter(predictions)
# Out:
# Counter({2: 157, 1: 34, 0: 28})

# %%
actual = [np.argmax(i, axis=None, out=None) for i in y]
Counter(actual)
# Out:
# Counter({0: 11, 2: 200, 1: 8})

# %%
df = pd.read_csv("data/variation 6/initial_indicators/MFC_data_test2.csv")
df.set_index('Date', inplace=True)

# %%
df = df.iloc[14:]
df['predictions'] = predictions
df['actual'] = actual
df['previous_1d'] = df['previous_1d'].shift(-1)
df.dropna(inplace=True)
df.head()
# Out:
#             previous_1d     EMA_12   willr_14      OBV_7  labels  predictions  \
# Date
# 2020-02-11    20.209999  20.036581 -63.157941 -1529300.0     0.0            2
# 2020-02-12    20.110001  20.063261 -43.421155  -126100.0     2.0            2
# 2020-02-13    19.719999  20.070452 -50.000000 -2453200.0     2.0            2
# 2020-02-14    19.709999  20.016536 -62.626362 -4848700.0     2.0            2
# 2020-02-18    19.580000  19.969377 -63.636486 -6866400.0     2.0            2
#
#             actual
# Date
# 2020-02-11       0
# 2020-02-12       2
# 2020-02-13       2
# 2020-02-14       2
# 2020-02-18       2

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['predictions'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = df['previous_1d'].values
x = df.index.values
c = df['actual'].values

# plot the data
plt.figure(figsize=(20,10))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
#plt.plot(df['willr_6'].values)
plt.scatter(x, y, c=c,label=c)
plt.xticks(rotation=90)
plt.show()

# %%
hold = 0
sell = 0
buy = 0
buy_buy = 0
buy_sell = 0
buy_hold = 0
sell_buy = 0
sell_sell = 0
sell_hold = 0
hold_buy = 0
hold_sell = 0
hold_hold = 0

for i in range (0,len(actual)):
    if actual[i]==1 and predictions[i] == 1:
        buy_buy += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 0:
        buy_sell += 1
        buy += 1
    elif actual[i]==1 and predictions[i] == 2:
        buy_hold += 1
        buy += 1
    elif actual[i]==0 and predictions[i] == 1:
        sell_buy += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 0:
        sell_sell += 1
        sell += 1
    elif actual[i]==0 and predictions[i] == 2:
        sell_hold += 1
        sell += 1
    elif actual[i]==2 and predictions[i] == 1:
        hold_buy += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 0:
        hold_sell += 1
        hold += 1
    elif actual[i]==2 and predictions[i] == 2:
        hold_hold += 1
        hold += 1
        
print("number of predictions: " + str(len(actual)))
print("actual predicted buys: " + str(buy_buy) )
print("actual buys but predicted sell: " + str(buy_sell) )
print("actual buys but predicted hold: " + str(buy_hold))
print("actual sells but predicted buy: " + str(sell_buy) )
print("actual predicted sells: " + str(sell_sell))
print("actual sells but predicted hold: " + str(sell_hold) )
print("actual holds but predicted buy: " + str(hold_buy) )
print("actual holds but predicted sell: " + str(hold_sell))
print("actual predicted holds: " + str(hold_hold) )

print("Percentage buys correct: " + str(100*buy_buy/buy) + "%")
print("Percentage sells correct: " + str(100*sell_sell/sell) + "%")
print("Percentage holds correct: " + str(100*hold_hold/hold) + "%")

print("actual buys: " + str(buy))
print("actual sells: " + str(sell))
print("actual holds: " + str(hold)) ; logger.append(str(100*buy_buy/buy) + "%") ; logger.append(str(100*sell_sell/sell) + "%") ; logger.append(str(100*hold_hold/hold) + "%")

correct_maxima = 0 
correct_minima = 0
correct_hold = 0

hold = 0
buy = 0
sell = 0

predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    if i < 4:
        prices = price[i:i+9]
        prices.sort(key = float)
        if i == 0:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
    else:
        prices = price[i:i+5]
        prices = prices + price[i-4:i] 
        prices.sort(key = float)
        if i == 10:
            print(prices)
        highest_1 = prices[-1]
        highest_2 = prices[-2]
        highest_3 = prices[-3]
        highest_4 = prices[-4]
        lowest_1 = prices[0]
        lowest_2 = prices[1]
        lowest_3 = prices[2]
        lowest_4 = prices[3]
        if predictions[i] == 0:
            sell += 1
            if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                correct_maxima += 1
        elif predictions[i] == 1:
            buy += 1
            if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                correct_minima += 1
        elif predictions[i] == 2:
            hold += 1
            if price[i] != lowest_1 and price[i] != highest_1:
                correct_hold += 1
                
print("Percentage buys correct: " + str(100*correct_minima/buy) + "%")
print("Percentage sells correct: " + str(100*correct_maxima/sell) + "%")
print("Percentage holds correct: " + str(100*correct_hold/hold) + "%") ; logger.append(str(100*correct_minima/buy) + "%") ; logger.append(str(100*correct_maxima/sell) + "%") ; logger.append(str(100*correct_hold/hold) + "%")
# Out:
# number of predictions: 219
# actual predicted buys: 2
# actual buys but predicted sell: 0
# actual buys but predicted hold: 6
# actual sells but predicted buy: 3
# actual predicted sells: 1
# actual sells but predicted hold: 7
# actual holds but predicted buy: 29
# actual holds but predicted sell: 27
# actual predicted holds: 144
# Percentage buys correct: 25.0%
# Percentage sells correct: 9.090909090909092%
# Percentage holds correct: 72.0%
# actual buys: 8
# actual sells: 11
# actual holds: 200
# [17.979999542236328, 19.51000022888184, 19.57999992370605, 19.709999084472656, 19.71999931335449, 19.899999618530273, 20.030000686645508, 20.11000061035156, 20.209999084472656]
# [16.700000762939453, 16.84000015258789, 16.860000610351562, 17.200000762939453, 17.549999237060547, 17.639999389648438, 17.979999542236328, 19.51000022888184, 20.030000686645508]
# Percentage buys correct: 47.05882352941177%
# Percentage sells correct: 46.42857142857143%
# Percentage holds correct: 85.25641025641026%

# %%
from sklearn.preprocessing import MinMaxScaler
import math

capital = 10000
shares = 0

previously_buy = False
previously_sell = False
prev_buy_price = 0
bought_once = False


predictions = df['predictions'].values.tolist()
price = df['previous_1d'].values.tolist()

for i in range(0,len(predictions)):
    
    if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 3 and shares!=0:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Stop Loss Activated!\n")
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
    
    if predictions[i] == 1 and previously_buy != True:
        shares = math.floor(capital / (price[i]*1.00275))
        capital = capital - shares*price[i]*1.00275
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        prev_buy_price = price[i]*1.00275
        bought_once = True
        previously_buy = True
        previously_sell = False
        
    elif predictions[i] == 0 and previously_sell != True and shares!=0 and (price[i]/prev_buy_price-1)*100 >= 5:
        capital += 0.99725 * (shares*price[i])
        shares = 0
        print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
        print("Share price: $" + str(price[i]))
        print("Shares owned at the moment: " + str(shares))
        print("Cash capital at the moment: $" + str(capital))
        print("\n")
        previously_buy = False
        previously_sell = True
        
if shares!=0:
    capital += 0.99725 * (shares*price[i])
    
print('\n')
print("Capital at the end of test period: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Share price: $19.899999618530273
# Shares owned at the moment: 501
# Cash capital at the moment: $2.6829666419034766
#
#
# Stop Loss Activated!
#
# Share price: $17.979999542236328
# Shares owned at the moment: 0
# Cash capital at the moment: $8985.890792932987
#
#
# Share price: $17.979999542236328
# Shares owned at the moment: 498
# Cash capital at the moment: $7.227411526202559
#
#
# Stop Loss Activated!
#
# Share price: $16.860000610351562
# Shares owned at the moment: 0
# Cash capital at the moment: $8380.417944645404
#
#
# Share price: $14.920000076293945
# Shares owned at the moment: 560
# Cash capital at the moment: $2.241101803301717
#
#
# Stop Loss Activated!
#
# Share price: $14.06999969482422
# Shares owned at the moment: 0
# Cash capital at the moment: $7859.773131374835
#
#
# Share price: $12.960000038146973
# Shares owned at the moment: 604
# Cash capital at the moment: $10.406548270701933
#
#
# Stop Loss Activated!
#
# Share price: $10.479999542236328
# Shares owned at the moment: 0
# Cash capital at the moment: $6322.9189925417895
#
#
# Share price: $10.079999923706056
# Shares owned at the moment: 625
# Cash capital at the moment: $5.59404035663465
#
#
# Stop Loss Activated!
#
# Share price: $9.260000228881836
# Shares owned at the moment: 0
# Cash capital at the moment: $5777.1785580143915
#
#
# Share price: $9.260000228881836
# Shares owned at the moment: 622
# Cash capital at the moment: $1.6191852583870059
#
#
# Stop Loss Activated!
#
# Share price: $8.899999618530273
# Shares owned at the moment: 0
# Cash capital at the moment: $5522.195498636721
#
#
# Share price: $11.34000015258789
# Shares owned at the moment: 485
# Cash capital at the moment: $7.170699428079388
#
#
# Price increase from previously bought: 11.685806170398827%
# Share price: $12.699999809265135
# Shares owned at the moment: 0
# Cash capital at the moment: $6149.731982176062
#
#
# Share price: $12.369999885559082
# Shares owned at the moment: 495
# Cash capital at the moment: $9.74337648009896
#
#
# Stop Loss Activated!
#
# Share price: $11.460000038146973
# Shares owned at the moment: 0
# Cash capital at the moment: $5666.843470310922
#
#
# Share price: $11.56999969482422
# Shares owned at the moment: 488
# Cash capital at the moment: $5.156679646248449
#
#
# Price increase from previously bought: 8.603679671855646%
# Share price: $12.600000381469727
# Shares owned at the moment: 0
# Cash capital at the moment: $6137.047665291542
#
#
# Share price: $11.779999732971193
# Shares owned at the moment: 519
# Cash capital at the moment: $6.41479926060947
#
#
# Stop Loss Activated!
#
# Share price: $11.43000030517578
# Shares owned at the moment: 0
# Cash capital at the moment: $5922.271489711276
#
#
# Share price: $12.510000228881836
# Shares owned at the moment: 472
# Cash capital at the moment: $1.31340138196083
#
#
# Price increase from previously bought: 8.813467750186676%
# Share price: $13.649999618530273
# Shares owned at the moment: 0
# Cash capital at the moment: $6426.395521823398
#
#
# Share price: $15.039999961853027
# Shares owned at the moment: 426
# Cash capital at the moment: $1.736178118697353
#
#
# Stop Loss Activated!
#
# Share price: $13.739999771118164
# Shares owned at the moment: 0
# Cash capital at the moment: $5838.879670883171
#
#
# Share price: $13.949999809265135
# Shares owned at the moment: 417
# Cash capital at the moment: $5.732588138334904
#
#
# Stop Loss Activated!
#
# Share price: $13.329999923706055
# Shares owned at the moment: 0
# Cash capital at the moment: $5549.056378911249
#
#
# Share price: $13.489999771118164
# Shares owned at the moment: 410
# Cash capital at the moment: $2.94649801086598
#
#
# Price increase from previously bought: 10.223202726133751%
# Share price: $14.90999984741211
# Shares owned at the moment: 0
# Cash capital at the moment: $6099.235410621874
#
#
# Share price: $14.850000381469727
# Shares owned at the moment: 409
# Cash capital at the moment: $8.88271667169738
#
#
# Stop Loss Activated!
#
# Share price: $14.399999618530273
# Shares owned at the moment: 0
# Cash capital at the moment: $5882.286161079637
#
#
# Share price: $13.869999885559082
# Shares owned at the moment: 422
# Cash capital at the moment: $13.050074506512829
#
#
# Stop Loss Activated!
#
# Share price: $13.34000015258789
# Shares owned at the moment: 0
# Cash capital at the moment: $5627.049068721524
#
#
#
#
# Capital at the end of test period: $5627.049068721524
# profit gained: -43.72950931278476%

# %%
capital = 10000
shares = 0

shares = math.floor(capital / (price[0]*1.00275))
capital = capital - shares*price[0]*1.00275
capital += 0.99725 * (shares*price[-1])

print('\n')
print("Capital at the end of test period if Buy and Hold: $" +str(capital))
print("profit gained: " + str(((capital- 10000 )/ 10000) * 100 ) + '%') ; logger.append(str(((capital- 10000 )/ 10000) * 100 ) + '%')
# Out:
# Capital at the end of test period if Buy and Hold: $8544.015225172043
# profit gained: -14.559847748279573%

# %%
df_length = len(log)
log.loc[df_length] = logger
log.head()
# Out:
#    Test_accuracy correct_buys       correct_sells       correct_holds  \
# 0       0.848624        10.0%               10.0%  92.42424242424242%
# 1       0.799087        25.0%  9.090909090909092%               86.0%
# 2       0.752294        30.0%               20.0%   80.3030303030303%
# 3       0.671233        25.0%  9.090909090909092%               72.0%
#
#      correct_low_buys   correct_high_sells   correct_mid_holds  \
# 0               40.0%                50.0%  85.07462686567165%
# 1               55.0%  18.181818181818183%  85.02673796791444%
# 2  71.42857142857143%   52.17391304347826%  84.39306358381504%
# 3  47.05882352941177%   46.42857142857143%  85.25641025641026%
#
#           Profit gained     buy_n_hold profit
# 0   15.892216613554954%   26.873727015776605%
# 1  -14.177789706330332%  -14.559847748279573%
# 2   34.954496617975146%   26.873727015776605%
# 3   -43.72950931278476%  -14.559847748279573%

# %%
experiment
# Out:
# 'MFC Variation 6 CNN Images Experiment'

# %%
log.to_csv('{}.csv'.format(experiment))
