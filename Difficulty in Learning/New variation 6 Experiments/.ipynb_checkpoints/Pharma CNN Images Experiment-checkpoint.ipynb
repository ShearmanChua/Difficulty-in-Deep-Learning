# %%
import os
seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
experiment = 'Pharma CNN Images Experiment'

# %%
import requests
import lxml
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.utils import compute_class_weight
import tensorflow as tf
from pil import Image
from sklearn import preprocessing
import tensorflow_addons as tfa
import glob
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
import math

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
# gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
np.random.seed(seed)
tf.random.set_seed(seed)

session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1, 
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(), 
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)

# %%
def pred_acc(actual, predictions, logger):

    hold = 0
    sell = 0
    buy = 0
    pred_hold = 0
    pred_sell = 0
    pred_buy = 0
    buy_buy = 0
    buy_sell = 0
    buy_hold = 0
    sell_buy = 0
    sell_sell = 0
    sell_hold = 0
    hold_buy = 0
    hold_sell = 0
    hold_hold = 0

    for i in range (0,len(actual)):
        if actual[i]==1 and predictions[i] == 1:
            buy_buy += 1
            buy += 1
            pred_buy += 1
        elif actual[i]==1 and predictions[i] == 0:
            buy_sell += 1
            buy += 1
            pred_sell += 1
        elif actual[i]==1 and predictions[i] == 2:
            buy_hold += 1
            buy += 1
            pred_hold += 1
        elif actual[i]==0 and predictions[i] == 1:
            sell_buy += 1
            sell += 1
            pred_buy += 1
        elif actual[i]==0 and predictions[i] == 0:
            sell_sell += 1
            sell += 1
            pred_sell += 1
        elif actual[i]==0 and predictions[i] == 2:
            sell_hold += 1
            sell += 1
            pred_hold += 1
        elif actual[i]==2 and predictions[i] == 1:
            hold_buy += 1
            hold += 1
            pred_buy += 1
        elif actual[i]==2 and predictions[i] == 0:
            hold_sell += 1
            hold += 1
            pred_sell += 1
        elif actual[i]==2 and predictions[i] == 2:
            hold_hold += 1
            hold += 1
            pred_hold += 1

    print("number of predictions: " + str(len(actual)))
    print("actual predicted buys: " + str(buy_buy) )
    print("actual buys but predicted sell: " + str(buy_sell) )
    print("actual buys but predicted hold: " + str(buy_hold))
    print("actual sells but predicted buy: " + str(sell_buy) )
    print("actual predicted sells: " + str(sell_sell))
    print("actual sells but predicted hold: " + str(sell_hold) )
    print("actual holds but predicted buy: " + str(hold_buy) )
    print("actual holds but predicted sell: " + str(hold_sell))
    print("actual predicted holds: " + str(hold_hold) )
    
    if pred_buy !=0:
        Percentage_buys_correct = 100*buy_buy/pred_buy
    else:
        Percentage_buys_correct = 0
        
    if pred_sell !=0:
        Percentage_sells_correct = 100*sell_sell/pred_sell
    else:
        Percentage_sells_correct = 0
        
    if pred_hold !=0:
        Percentage_holds_correct = 100*hold_hold/pred_hold
    else:
        Percentage_holds_correct = 0

    print("Percentage buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage holds correct: " + str(Percentage_holds_correct) + "%")

    print("actual buys: " + str(buy))
    print("actual sells: " + str(sell))
    print("actual holds: " + str(hold))
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def correct_maxima_minima(predictions, price, logger):
    correct_maxima = 0 
    correct_minima = 0
    correct_hold = 0

    hold = 0
    buy = 0
    sell = 0

#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):
        if i < 4:
            prices = price[i:i+9]
            prices.sort(key = float)
#             if i == 0:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1

        else:
            prices = price[i:i+5]
            prices = prices + price[i-4:i] 
            prices.sort(key = float)
#             if i == 10:
#                 print(prices)
            highest_1 = prices[-1]
            highest_2 = prices[-2]
            highest_3 = prices[-3]
            highest_4 = prices[-4]
            lowest_1 = prices[0]
            lowest_2 = prices[1]
            lowest_3 = prices[2]
            lowest_4 = prices[3]
            if predictions[i] == 0:
                sell += 1
                if price[i] == highest_1 or price[i] == highest_2 or price[i] == highest_3 or price[i] == highest_4:
                    correct_maxima += 1
            elif predictions[i] == 1:
                buy += 1
                if price[i] == lowest_1 or price[i] == lowest_2 or price[i] == lowest_3 or price[i] == lowest_4:
                    correct_minima += 1
            elif predictions[i] == 2:
                hold += 1
                if price[i] != lowest_1 and price[i] != highest_1:
                    correct_hold += 1
                    
    if buy !=0:
        Percentage_buys_correct = 100*correct_minima/buy
    else:
        Percentage_buys_correct = 0
        
    if sell !=0:
        Percentage_sells_correct = 100*correct_maxima/sell
    else:
        Percentage_sells_correct = 0
        
    if hold !=0:
        Percentage_holds_correct = 100*correct_hold/hold
    else:
        Percentage_holds_correct = 0

    print("Percentage low buys correct: " + str(Percentage_buys_correct) + "%")
    print("Percentage high sells correct: " + str(Percentage_sells_correct) + "%")
    print("Percentage mid holds correct: " + str(Percentage_holds_correct) + "%")
    logger.append(Percentage_buys_correct) ; logger.append(Percentage_sells_correct) ; logger.append(Percentage_holds_correct)
    
    return logger

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %% [markdown]
# ## Prepare Test Data

# %%
nr_test_sets = ['VXRT','INO','NVAX']
nr_test_data = {}

for name in nr_test_sets:

    df = pd.read_csv("variation 7/initial_indicators/{}_data_test.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    willr_data = []
    price_data = []
    ema_data = []
    obv_data = []
    labels = []
    data_15_price = []
    data_15_willr = []
    data_15_ema = []
    data_15_obv = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
            data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
            data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
            data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
            price_data.append(data_15_price_arr)
            willr_data.append(data_15_willr_arr)
            ema_data.append(data_15_ema_arr)
            obv_data.append(data_15_obv_arr)
            labels.append(i[-1])
            data_15_price = data_15_price[1:]
            data_15_willr = data_15_willr[1:]
            data_15_obv = data_15_obv[1:]
            data_15_ema = data_15_ema[1:]

        else:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            count += 1

    willr_data = np.array(willr_data)
    price_data = np.array(price_data)
    ema_data = np.array(ema_data)
    obv_data = np.array(obv_data)
    
    sequential_data = []
    
    for i in range(0,len(willr_data)):
        j = willr_data[i]
        k = price_data[i]
        l = ema_data[i]
        m = obv_data[i]
        fig, ax = plt.subplots()
        fig.set_size_inches((5,5))

        ax.plot(k)
        ax.plot(j)
        ax.plot(l)
        ax.plot(m)

        ax.axis('off')

        fig.add_axes(ax)
        fig.canvas.draw()

        # this rasterized the figure
        X = np.array(fig.canvas.renderer._renderer)
        X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
        X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
        sequential_data.append(X)
        plt.close()
        
    X = sequential_data
    y = labels

    X  = np.array(X).reshape(-1, 64, 64, 1)
    X = X/255
    y = np.array(y)
    
    y = to_categorical(y, 3)
    
    nr_test_data['{}_X'.format(name)] = X
    nr_test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d    EMA_12   willr_14    OBV_7  labels
# Date
# 2019-01-22         1.95  2.010695 -57.142843  16000.0     2.0
# 2019-01-23         1.85  1.985973 -69.230761    800.0     1.0
# 2019-01-24         1.81  1.958900 -75.384620 -18800.0     2.0
# 2019-01-25         1.83  1.939069 -72.307681  60700.0     2.0
# 2019-01-28         1.87  1.928443 -71.666669  82700.0     2.0
#             previous_1d    EMA_12   willr_14      OBV_7  labels
# Date
# 2019-01-22         5.09  4.742046  -0.840315  6313800.0     2.0
# 2019-01-23         5.00  4.781732  -8.403355  5520600.0     2.0
# 2019-01-24         4.78  4.781465 -35.164808  4872000.0     2.0
# 2019-01-25         5.01  4.816624 -11.111072  6179900.0     0.0
# 2019-01-28         5.10  4.860221  -1.639381  7036300.0     2.0
#             previous_1d     EMA_12   willr_14      OBV_7  labels
# Date
# 2019-01-22    41.000000  42.251874 -47.761200  1797960.0     1.0
# 2019-01-23    40.400002  41.966970 -52.238800  1452070.0     2.0
# 2019-01-24    41.200001  41.848975 -68.888897  1666265.0     2.0
# 2019-01-25    41.799999  41.841440 -75.675691  1912795.0     2.0
# 2019-01-28    43.799999  42.142757 -48.648670  2352875.0     2.0

# %%
r_test_sets = ['VXRT','INO','NVAX']
r_test_data = {}

for name in r_test_sets:

    df = pd.read_csv("variation 7/initial_indicators/{}_data_test2.csv".format(name))
    df.set_index('Date', inplace=True)
    print(df.head())
    
    willr_data = []
    price_data = []
    ema_data = []
    obv_data = []
    labels = []
    data_15_price = []
    data_15_willr = []
    data_15_ema = []
    data_15_obv = []
    count = 0

    for i in df.values:
        if count == 14:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            min_max_scaler = preprocessing.MinMaxScaler()
            data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
            data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
            data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
            data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
            price_data.append(data_15_price_arr)
            willr_data.append(data_15_willr_arr)
            ema_data.append(data_15_ema_arr)
            obv_data.append(data_15_obv_arr)
            labels.append(i[-1])
            data_15_price = data_15_price[1:]
            data_15_willr = data_15_willr[1:]
            data_15_obv = data_15_obv[1:]
            data_15_ema = data_15_ema[1:]

        else:
            data_15_price.append([i[0]])
            data_15_ema.append([i[1]])
            data_15_willr.append([i[2]])
            data_15_obv.append([i[3]])
            count += 1

    willr_data = np.array(willr_data)
    price_data = np.array(price_data)
    ema_data = np.array(ema_data)
    obv_data = np.array(obv_data)
    
    sequential_data = []
    
    for i in range(0,len(willr_data)):
        j = willr_data[i]
        k = price_data[i]
        l = ema_data[i]
        m = obv_data[i]
        fig, ax = plt.subplots()
        fig.set_size_inches((5,5))

        ax.plot(k)
        ax.plot(j)
        ax.plot(l)
        ax.plot(m)

        ax.axis('off')

        fig.add_axes(ax)
        fig.canvas.draw()

        # this rasterized the figure
        X = np.array(fig.canvas.renderer._renderer)
        X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
        X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
        sequential_data.append(X)
        plt.close()
        
    X = sequential_data
    y = labels

    X  = np.array(X).reshape(-1, 64, 64, 1)
    X = X/255
    y = np.array(y)
    
    y = to_categorical(y, 3)
    
    r_test_data['{}_X'.format(name)] = X
    r_test_data['{}_y'.format(name)] = y
# Out:
#             previous_1d    EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22         0.53  0.388757  -0.000000   7111600.0     2.0
# 2020-01-23         0.59  0.419718 -30.952393  27158800.0     2.0
# 2020-01-24         0.53  0.436684 -45.238107  23794300.0     2.0
# 2020-01-27         0.49  0.444887 -58.974362  21329000.0     2.0
# 2020-01-28         0.64  0.474904 -21.052641  31022300.0     2.0
#             previous_1d    EMA_12   willr_14       OBV_7  labels
# Date
# 2020-01-22         3.56  3.271874 -23.750009   7769400.0     2.0
# 2020-01-23         3.44  3.297739 -38.749995   5767800.0     2.0
# 2020-01-24         3.84  3.381164 -22.608698  18081400.0     2.0
# 2020-01-27         4.24  3.513293 -26.285720  42708100.0     0.0
# 2020-01-28         5.32  3.791248 -21.649473  83567200.0     2.0
#             previous_1d    EMA_12   willr_14        OBV_7  labels
# Date
# 2020-01-22         9.82  5.323560  -2.681389   78304500.0     2.0
# 2020-01-23         7.09  5.595320 -45.741321   61383300.0     2.0
# 2020-01-24         7.66  5.912963 -36.750789   78092700.0     2.0
# 2020-01-27         7.80  6.203277 -34.542582   88646300.0     2.0
# 2020-01-28         8.50  6.556619 -23.501575  105388400.0     2.0

# %% [markdown]
# ## Train Vaxart, Inc Stock Data

# %% [markdown]
# ### Creating Training Data and Model

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []

seed = 10
df = pd.read_csv('variation 7/initial_indicators/VXRT_data.csv')
df.set_index('Date', inplace=True)
print(df.head())

plt.figure(figsize=(15,5))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
plt.show()

data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]

    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()
    
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
y = np.array(y)

X.shape
# Out:
#             previous_1d      EMA_12   willr_14    OBV_7  labels
# Date
# 2000-01-21      437.250  350.035133  -6.976744  42909.0     0.0
# 2000-01-24      515.625  375.510497 -10.606061  67630.0     2.0
# 2000-01-25      424.875  383.105036 -43.939394  53407.0     2.0
# 2000-01-26      453.750  393.973492 -33.333333  57201.0     2.0
# 2000-01-27      420.750  398.092955 -50.000000  54669.0     2.0
# (4745, 64, 64, 1)

# %%
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)
obv_data.shape
# Out:
# (4745, 15, 1)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
y = np.array(y)

X.shape
# Out:
# (4745, 64, 64, 1)

# %%
from collections import Counter

Counter(y)
# Out:
# Counter({2.0: 4296, 0.0: 230, 1.0: 219})

# %%
# plot the image array X
i = X[0].reshape(64, 64)
fig2, ax2 = plt.subplots()
plt.imshow(i, interpolation="none", cmap="gray")

ax2.axis('off')

plt.show()

# %%
X = X/255

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten,BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.regularizers import l2
import efficientnet.tfkeras as efn
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(Conv2D(16, (3, 3), padding='same', kernel_initializer='he_uniform',kernel_regularizer=l2(1e-5), input_shape=X_train.shape[1:]))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))

model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_uniform',kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

# model.add(Dense(128, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))
# model.add(Dropout(0.25, seed=seed))

model.add(Dense(64, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))
model.add(Dropout(0.25, seed=seed))

model.add(Dense(32, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))
model.add(Dropout(0.25, seed=seed))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "DBS_CNN_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))
print(d_class_weights)

epochs = 0 
histories = {}
nr_log_hist = {}
r_log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    nr_log  = pd.DataFrame(columns = column_names)
    r_log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['VXRT','INO','NVAX']
    for name in test_sets:
        
        print('\n')
        print("Non-Recession")
        print('\n')
        
        X = nr_test_data['{}_X'.format(name)]
        y = nr_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("variation 7/initial_indicators/{}_data_test.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(nr_log)
        nr_log.loc[df_length] = logger
        print(nr_log.head(20))
        logger = []
        
        print('\n')
        print("Recession")
        print('\n')
        
        X = r_test_data['{}_X'.format(name)]
        y = r_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("variation 7/initial_indicators/{}_data_test2.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(r_log)
        r_log.loc[df_length] = logger
        print(r_log.head(20))
        logger = []

    nr_log.to_csv('{}_{}_{}epochs.csv'.format(experiment,'VaxartModel',epochs))
    nr_log_hist['{}_epochs_logs'.format(epochs)] = nr_log
    r_log.to_csv('{}_{}_{}epochs.csv'.format(experiment,'VaxartModel',epochs))
    r_log_hist['{}_epochs_logs'.format(epochs)] = r_log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 2 ... 0 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# {0: 6.8768115942028984, 1: 7.230476190476191, 2: 0.3681505188633498}
#
#
#
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  1/30 [>.............................] - ETA: 0s - loss: 0.4679 - accuracy: 0.6484 - mse: 5.5827 - weighted_accuracy: 0.3897 - weighted_mse: 6.6151WARNING:tensorflow:From C:\Users\Shearman Chua\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/30 [=>............................] - ETA: 1s - loss: 0.4079 - accuracy: 0.6250 - mse: 4.3694 - weighted_accuracy: 0.3773 - weighted_mse: 5.3998WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0100s vs `on_train_batch_end` time: 0.1144s). Check your callbacks.
# 30/30 [==============================] - 1s 34ms/step - loss: 0.2475 - accuracy: 0.3870 - mse: 1.6242 - weighted_accuracy: 0.3275 - weighted_mse: 1.7275 - val_loss: 0.1967 - val_accuracy: 0.1454 - val_mse: 0.9680 - val_weighted_accuracy: 0.1454 - val_weighted_mse: 0.9680
# Epoch 2/20
# 30/30 [==============================] - 0s 15ms/step - loss: 0.2062 - accuracy: 0.3617 - mse: 1.1734 - weighted_accuracy: 0.3298 - weighted_mse: 1.1948 - val_loss: 0.2091 - val_accuracy: 0.0516 - val_mse: 0.8596 - val_weighted_accuracy: 0.0516 - val_weighted_mse: 0.8596
# Epoch 3/20
# 30/30 [==============================] - 0s 14ms/step - loss: 0.2043 - accuracy: 0.4204 - mse: 1.1612 - weighted_accuracy: 0.3498 - weighted_mse: 1.1830 - val_loss: 0.2022 - val_accuracy: 0.3130 - val_mse: 0.8269 - val_weighted_accuracy: 0.3130 - val_weighted_mse: 0.8269
# Epoch 4/20
# 30/30 [==============================] - 0s 16ms/step - loss: 0.2043 - accuracy: 0.3714 - mse: 1.1632 - weighted_accuracy: 0.3406 - weighted_mse: 1.1734 - val_loss: 0.2139 - val_accuracy: 0.0485 - val_mse: 0.9243 - val_weighted_accuracy: 0.0485 - val_weighted_mse: 0.9243
# Epoch 5/20
# 30/30 [==============================] - 0s 17ms/step - loss: 0.2033 - accuracy: 0.3246 - mse: 1.1465 - weighted_accuracy: 0.3276 - weighted_mse: 1.1770 - val_loss: 0.1999 - val_accuracy: 0.1623 - val_mse: 0.9500 - val_weighted_accuracy: 0.1623 - val_weighted_mse: 0.9500
# Epoch 6/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.2019 - accuracy: 0.3285 - mse: 1.1578 - weighted_accuracy: 0.3505 - weighted_mse: 1.1635 - val_loss: 0.2158 - val_accuracy: 0.0516 - val_mse: 1.0237 - val_weighted_accuracy: 0.0516 - val_weighted_mse: 1.0237
# Epoch 7/20
# 30/30 [==============================] - 1s 22ms/step - loss: 0.2004 - accuracy: 0.2540 - mse: 1.2202 - weighted_accuracy: 0.3487 - weighted_mse: 1.2031 - val_loss: 0.1979 - val_accuracy: 0.4489 - val_mse: 0.8802 - val_weighted_accuracy: 0.4489 - val_weighted_mse: 0.8802
# Epoch 8/20
# 30/30 [==============================] - 1s 39ms/step - loss: 0.2030 - accuracy: 0.3830 - mse: 1.1892 - weighted_accuracy: 0.3461 - weighted_mse: 1.2053 - val_loss: 0.2056 - val_accuracy: 0.0811 - val_mse: 0.8694 - val_weighted_accuracy: 0.0811 - val_weighted_mse: 0.8694
# Epoch 9/20
# 30/30 [==============================] - 1s 29ms/step - loss: 0.2018 - accuracy: 0.3683 - mse: 1.1574 - weighted_accuracy: 0.3398 - weighted_mse: 1.1656 - val_loss: 0.1963 - val_accuracy: 0.4362 - val_mse: 0.8989 - val_weighted_accuracy: 0.4362 - val_weighted_mse: 0.8989
# Epoch 10/20
# 30/30 [==============================] - 1s 22ms/step - loss: 0.2012 - accuracy: 0.3280 - mse: 1.1783 - weighted_accuracy: 0.3458 - weighted_mse: 1.1838 - val_loss: 0.2111 - val_accuracy: 0.0611 - val_mse: 0.8635 - val_weighted_accuracy: 0.0611 - val_weighted_mse: 0.8635
# Epoch 11/20
# 30/30 [==============================] - 1s 27ms/step - loss: 0.2003 - accuracy: 0.3506 - mse: 1.1653 - weighted_accuracy: 0.3613 - weighted_mse: 1.1722 - val_loss: 0.2023 - val_accuracy: 0.0685 - val_mse: 0.9037 - val_weighted_accuracy: 0.0685 - val_weighted_mse: 0.9037
# Epoch 12/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.2013 - accuracy: 0.3087 - mse: 1.1451 - weighted_accuracy: 0.3575 - weighted_mse: 1.1706 - val_loss: 0.2018 - val_accuracy: 0.0969 - val_mse: 0.9105 - val_weighted_accuracy: 0.0969 - val_weighted_mse: 0.9105
# Epoch 13/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.2016 - accuracy: 0.3056 - mse: 1.1682 - weighted_accuracy: 0.3517 - weighted_mse: 1.1713 - val_loss: 0.2085 - val_accuracy: 0.0558 - val_mse: 0.9733 - val_weighted_accuracy: 0.0558 - val_weighted_mse: 0.9733
# Epoch 14/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2001 - accuracy: 0.2057 - mse: 1.2276 - weighted_accuracy: 0.3904 - weighted_mse: 1.1763 - val_loss: 0.2188 - val_accuracy: 0.0695 - val_mse: 1.0348 - val_weighted_accuracy: 0.0695 - val_weighted_mse: 1.0348
# Epoch 15/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.2037 - accuracy: 0.2057 - mse: 1.1628 - weighted_accuracy: 0.3373 - weighted_mse: 1.1661 - val_loss: 0.2097 - val_accuracy: 0.0717 - val_mse: 1.0411 - val_weighted_accuracy: 0.0717 - val_weighted_mse: 1.0411
# Epoch 16/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2018 - accuracy: 0.1997 - mse: 1.2054 - weighted_accuracy: 0.3585 - weighted_mse: 1.1684 - val_loss: 0.2137 - val_accuracy: 0.0601 - val_mse: 1.0867 - val_weighted_accuracy: 0.0601 - val_weighted_mse: 1.0867
# Epoch 17/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.1995 - accuracy: 0.1942 - mse: 1.1871 - weighted_accuracy: 0.3879 - weighted_mse: 1.1751 - val_loss: 0.2105 - val_accuracy: 0.0685 - val_mse: 0.9262 - val_weighted_accuracy: 0.0685 - val_weighted_mse: 0.9262
# Epoch 18/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2003 - accuracy: 0.2034 - mse: 1.1878 - weighted_accuracy: 0.3684 - weighted_mse: 1.1804 - val_loss: 0.2138 - val_accuracy: 0.0685 - val_mse: 0.9227 - val_weighted_accuracy: 0.0685 - val_weighted_mse: 0.9227
# Epoch 19/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.1970 - accuracy: 0.1968 - mse: 1.1728 - weighted_accuracy: 0.3832 - weighted_mse: 1.1784 - val_loss: 0.2006 - val_accuracy: 0.0727 - val_mse: 1.0660 - val_weighted_accuracy: 0.0727 - val_weighted_mse: 1.0660
# Epoch 20/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.1981 - accuracy: 0.2255 - mse: 1.1866 - weighted_accuracy: 0.3824 - weighted_mse: 1.1799 - val_loss: 0.2129 - val_accuracy: 0.0727 - val_mse: 1.0064 - val_weighted_accuracy: 0.0727 - val_weighted_mse: 1.0064
# Validation loss: 0.21293291449546814
# Validation accuracy: 0.0727081149816513
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2134 - accuracy: 0.0596 - mse: 1.0108 - weighted_accuracy: 0.0596 - weighted_mse: 1.0108
# Test loss: 0.21340256929397583
# Test accuracy: 0.059633027762174606
#
#
# number of predictions: 218
# actual predicted buys: 6
# actual buys but predicted sell: 2
# actual buys but predicted hold: 0
# actual sells but predicted buy: 1
# actual predicted sells: 7
# actual sells but predicted hold: 0
# actual holds but predicted buy: 114
# actual holds but predicted sell: 88
# actual predicted holds: 0
# Percentage buys correct: 4.958677685950414%
# Percentage sells correct: 7.216494845360825%
# Percentage holds correct: 0%
# actual buys: 8
# actual sells: 8
# actual holds: 202
#
#
# Percentage low buys correct: 50.833333333333336%
# Percentage high sells correct: 60.824742268041234%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.8206796684656419
# Shares owned at the moment: 121
# Cash capital at the moment: $0.42467895597538075
#
#
# Price increase from previously bought: -16.201113733032212%
# Share price: $0.6896116531541341
# Shares owned at the moment: 0
# Cash capital at the moment: $83.63822071003855
#
#
# Share price: $0.7769903300284726
# Shares owned at the moment: 107
# Cash capital at the moment: $0.27162599238110374
#
#
# Price increase from previously bought: 2.841012776145191%
# Share price: $0.8012621525665726
# Shares owned at the moment: 0
# Cash capital at the moment: $85.77090492861166
#
#
# Share price: $0.8400971264961219
# Shares owned at the moment: 101
# Cash capital at the moment: $0.6877581756190381
#
#
# Price increase from previously bought: -72.3054443572259%
# Share price: $0.2333009843577296
# Shares owned at the moment: 0
# Cash capital at the moment: $24.18635824734437
#
#
# Share price: $0.21873786190057493
# Shares owned at the moment: 110
# Cash capital at the moment: $0.05902523505620039
#
#
# Price increase from previously bought: -17.979658798150457%
# Share price: $0.17990291690532034
# Shares owned at the moment: 0
# Cash capital at the moment: $19.793925462277578
#
#
# Share price: $0.19932040387009503
# Shares owned at the moment: 99
# Cash capital at the moment: $0.00694049918453743
#
#
# Price increase from previously bought: 16.72721990993422%
# Share price: $0.2333009843577296
# Shares owned at the moment: 0
# Cash capital at the moment: $23.040221757608375
#
#
# Share price: $0.21873786190057493
# Shares owned at the moment: 105
# Cash capital at the moment: $0.009585700424214139
#
#
# Price increase from previously bought: -9.126945715285562%
# Share price: $0.19932040387009503
# Shares owned at the moment: 0
# Cash capital at the moment: $20.8806743401667
#
#
# Share price: $0.19446603936247508
# Shares owned at the moment: 107
# Cash capital at the moment: $0.015586496299455632
#
#
# Price increase from previously bought: -0.27424582398405395%
# Share price: $0.19446603936247508
# Shares owned at the moment: 0
# Cash capital at the moment: $20.76623107600188
#
#
# Share price: $0.20417476837771503
# Shares owned at the moment: 101
# Cash capital at the moment: $0.08786992793575266
#
#
# Price increase from previously bought: 4.467820645973775%
# Share price: $0.21388349739295492
# Shares owned at the moment: 0
# Cash capital at the moment: $21.630697023223306
#
#
# Share price: $0.20902913288533498
# Shares owned at the moment: 103
# Cash capital at the moment: $0.041488834144029596
#
#
# Price increase from previously bought: 6.673677415950685%
# Share price: $0.22359225534248967
# Shares owned at the moment: 0
# Cash capital at the moment: $23.008158628094705
#
#
# Share price: $0.1896116459205603
# Shares owned at the moment: 121
# Cash capital at the moment: $0.0020561965268441895
#
#
# Price increase from previously bought: -71.76223908549326%
# Share price: $0.05368932397002193
# Shares owned at the moment: 0
# Cash capital at the moment: $6.480599274348473
#
#
# Share price: $0.03912621598001464
# Shares owned at the moment: 165
# Cash capital at the moment: $0.007020117145125404
#
#
# Price increase from previously bought: -0.27424582398404285%
# Share price: $0.03912621598001464
# Shares owned at the moment: 0
# Cash capital at the moment: $6.4450922333466085
#
#
# Share price: $0.034271851472394664
# Shares owned at the moment: 187
# Cash capital at the moment: $0.018631708389126977
#
#
# Price increase from previously bought: 27.976644674746233%
# Share price: $0.043980580487634584
# Shares owned at the moment: 0
# Cash capital at the moment: $8.220383246061026
#
#
# Share price: $0.014854364507619946
# Shares owned at the moment: 551
# Cash capital at the moment: $0.013120326542264138
#
#
# Price increase from previously bought: 130.0863314172555%
# Share price: $0.034271851472394664
# Shares owned at the moment: 0
# Cash capital at the moment: $18.84498006488818
#
#
# Share price: $0.029417472497627294
# Shares owned at the moment: 638
# Cash capital at the moment: $0.025019655904877425
#
#
# Price increase from previously bought: -0.27424582398405395%
# Share price: $0.029417472497627294
# Shares owned at the moment: 0
# Cash capital at the moment: $18.741754153894004
#
#
# Share price: $0.034271851472394664
# Shares owned at the moment: 545
# Cash capital at the moment: $0.012230164044659375
#
#
#
#
# Capital at the end of test period: $10.723956882651535
# profit gained: -89.27604311734846%
#
#
# Capital at the end of test period if Buy and Hold: $2.5934579490563006
# profit gained: -97.4065420509437%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.059633      4.958678       7.216495            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         50.833333           60.824742                0.0     -89.276043
#
#    buy_n_hold profit
# 0         -97.406542
#
#
# Recession
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2148 - accuracy: 0.0639 - mse: 1.0103 - weighted_accuracy: 0.0639 - weighted_mse: 1.0103
# Test loss: 0.2148044854402542
# Test accuracy: 0.06392694264650345
#
#
# number of predictions: 219
# actual predicted buys: 6
# actual buys but predicted sell: 2
# actual buys but predicted hold: 0
# actual sells but predicted buy: 0
# actual predicted sells: 8
# actual sells but predicted hold: 0
# actual holds but predicted buy: 114
# actual holds but predicted sell: 89
# actual predicted holds: 0
# Percentage buys correct: 5.0%
# Percentage sells correct: 8.080808080808081%
# Percentage holds correct: 0%
# actual buys: 8
# actual sells: 8
# actual holds: 203
#
#
# Percentage low buys correct: 47.89915966386555%
# Percentage high sells correct: 44.44444444444444%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.011255491634695433
# Shares owned at the moment: 8860
# Cash capital at the moment: $0.0021040629191020344
#
#
# Price increase from previously bought: -11.398135761028904%
# Share price: $0.01
# Shares owned at the moment: 0
# Cash capital at the moment: $88.35845406291911
#
#
# Share price: $0.013138736570059003
# Shares owned at the moment: 6706
# Cash capital at the moment: $0.007788613646681597
#
#
# Price increase from previously bought: 56.90247303814671%
# Share price: $0.020671693861552022
# Shares owned at the moment: 0
# Cash capital at the moment: $138.25095060686672
#
#
# Share price: $0.07465787905337797
# Shares owned at the moment: 1846
# Cash capital at the moment: $0.053505151316528554
#
#
# Price increase from previously bought: -18.721784318127057%
# Share price: $0.060847463588407806
# Shares owned at the moment: 0
# Cash capital at the moment: $112.06903078661078
#
#
# Share price: $0.05017576972685583
# Shares owned at the moment: 2227
# Cash capital at the moment: $0.02030264715314445
#
#
# Price increase from previously bought: 44.641647912735664%
# Share price: $0.07277464160133483
# Shares owned at the moment: 0
# Cash capital at the moment: $161.64373939449882
#
#
# Share price: $0.11483365626355417
# Shares owned at the moment: 1403
# Cash capital at the moment: $0.08906270245347514
#
#
# Price increase from previously bought: 8.4482736328082%
# Share price: $0.12487758934111758
# Shares owned at the moment: 0
# Cash capital at the moment: $174.81051158896605
#
#
# Share price: $0.11295041881151101
# Shares owned at the moment: 1543
# Cash capital at the moment: $0.04873849818261533
#
#
# Price increase from previously bought: -4.708234633906261%
# Share price: $0.10792843730608846
# Shares owned at the moment: 0
# Cash capital at the moment: $166.12434991987803
#
#
# Share price: $0.5015254389491263
# Shares owned at the moment: 330
# Cash capital at the moment: $0.16582073082003035
#
#
# Price increase from previously bought: -9.261587691274498%
# Share price: $0.4563276802335273
# Shares owned at the moment: 0
# Cash capital at the moment: $150.33983783807213
#
#
# Share price: $0.45883866350291824
# Shares owned at the moment: 326
# Cash capital at the moment: $0.34708467429041434
#
#
# Price increase from previously bought: 119.51727203811697%
# Share price: $1.01
# Shares owned at the moment: 0
# Cash capital at the moment: $328.70161967429044
#
#
# Share price: $0.6452793658215203
# Shares owned at the moment: 507
# Cash capital at the moment: $0.645300446982958
#
#
# Price increase from previously bought: -17.34908090419296%
# Share price: $0.534795982235196
# Shares owned at the moment: 0
# Cash capital at the moment: $271.0412241419959
#
#
# Share price: $0.40673574569641713
# Shares owned at the moment: 664
# Cash capital at the moment: $0.2259895279332227
#
#
# Price increase from previously bought: 6.1901597899913785%
# Share price: $0.4331010999583029
# Shares owned at the moment: 0
# Cash capital at the moment: $287.0142772917225
#
#
# Share price: $0.3841368663386179
# Shares owned at the moment: 745
# Cash capital at the moment: $0.04531146454098689
#
#
# Price increase from previously bought: 10.64469303514799%
# Share price: $0.4261958810008373
# Shares owned at the moment: 0
# Cash capital at the moment: $316.6880739989643
#
#
# Share price: $0.3006465977981677
# Shares owned at the moment: 1050
# Cash capital at the moment: $0.14102925974594882
#
#
# Price increase from previously bought: -14.64185164043661%
# Share price: $0.25733209150125286
# Shares owned at the moment: 0
# Cash capital at the moment: $269.5966789218516
#
#
# Share price: $0.18890773754378867
# Shares owned at the moment: 1423
# Cash capital at the moment: $0.04172519309707923
#
#
# Price increase from previously bought: 38.829994778413536%
# Share price: $0.26298181882402316
# Shares owned at the moment: 0
# Cash capital at the moment: $373.23573977716893
#
#
# Share price: $0.42494038936614176
# Shares owned at the moment: 875
# Cash capital at the moment: $0.3903862698825833
#
#
# Price increase from previously bought: -5.72510735176377%
# Share price: $0.4017137791576355
# Shares owned at the moment: 0
# Cash capital at the moment: $350.9233192517156
#
#
# Share price: $0.42933459512093497
# Shares owned at the moment: 815
# Cash capital at the moment: $0.05337806683883173
#
#
# Price increase from previously bought: -4.794442173532698%
# Share price: $0.40987445981651494
# Shares owned at the moment: 0
# Cash capital at the moment: $333.1824316842347
#
#
# Share price: $0.4130132038698944
# Shares owned at the moment: 804
# Cash capital at the moment: $0.20664357908327702
#
#
#
#
# Capital at the end of test period: $326.8261980763254
# profit gained: 226.8261980763254%
#
#
# Capital at the end of test period if Buy and Hold: $3238.165410975435
# profit gained: 3138.165410975435%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.063927           5.0       8.080808            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0          47.89916           44.444444                0.0     226.826198
#
#    buy_n_hold profit
# 0        3138.165411
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2121 - accuracy: 0.0596 - mse: 1.0142 - weighted_accuracy: 0.0596 - weighted_mse: 1.0142
# Test loss: 0.21205507218837738
# Test accuracy: 0.059633027762174606
#
#
# number of predictions: 218
# actual predicted buys: 9
# actual buys but predicted sell: 1
# actual buys but predicted hold: 0
# actual sells but predicted buy: 5
# actual predicted sells: 4
# actual sells but predicted hold: 0
# actual holds but predicted buy: 129
# actual holds but predicted sell: 70
# actual predicted holds: 0
# Percentage buys correct: 6.293706293706293%
# Percentage sells correct: 5.333333333333333%
# Percentage holds correct: 0%
# actual buys: 10
# actual sells: 9
# actual holds: 199
#
#
# Percentage low buys correct: 45.45454545454545%
# Percentage high sells correct: 59.45945945945946%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.9879411977395466
# Shares owned at the moment: 100
# Cash capital at the moment: $0.9341963966669624
#
#
# Price increase from previously bought: -31.818940152269725%
# Share price: $0.6754411484342343
# Shares owned at the moment: 0
# Cash capital at the moment: $68.29256492427098
#
#
# Share price: $0.6607352802605987
# Shares owned at the moment: 103
# Cash capital at the moment: $0.04967778929550093
#
#
# Price increase from previously bought: -18.030886716769267%
# Share price: $0.5430882472176247
# Shares owned at the moment: 0
# Cash capital at the moment: $55.83393750668645
#
#
# Share price: $0.5908823187819406
# Shares owned at the moment: 94
# Cash capital at the moment: $0.1382564617789015
#
#
# Price increase from previously bought: 4.069206431519468%
# Share price: $0.6166175880858032
# Shares owned at the moment: 0
# Cash capital at the moment: $57.940914095324224
#
#
# Share price: $0.6239706098265095
# Shares owned at the moment: 92
# Cash capital at the moment: $0.3777534269992415
#
#
# Price increase from previously bought: 14.41550047525142%
# Share price: $0.7158823735656209
# Shares owned at the moment: 0
# Cash capital at the moment: $66.05781355452424
#
#
# Share price: $0.7305882417392565
# Shares owned at the moment: 90
# Cash capital at the moment: $0.1240512081606795
#
#
# Price increase from previously bought: -5.794498471944021%
# Share price: $0.6901470166078701
# Shares owned at the moment: 0
# Cash capital at the moment: $62.06647131625854
#
#
# Share price: $0.6680882143474166
# Shares owned at the moment: 92
# Cash capital at the moment: $0.43332927806631716
#
#
# Price increase from previously bought: -3.018183231751026%
# Share price: $0.6497058791303719
# Shares owned at the moment: 0
# Cash capital at the moment: $60.04189457064055
#
#
# Share price: $0.5982352528687588
# Shares owned at the moment: 100
# Cash capital at the moment: $0.05385458922576447
#
#
# Price increase from previously bought: -78.72125292266234%
# Share price: $0.12764703304297442
# Shares owned at the moment: 0
# Cash capital at the moment: $12.783454959436387
#
#
# Share price: $0.18647059339140537
# Shares owned at the moment: 68
# Cash capital at the moment: $0.06858460785662857
#
#
# Price increase from previously bought: -4.206645479490589%
# Share price: $0.17911765930458734
# Shares owned at the moment: 0
# Cash capital at the moment: $12.21509043827861
#
#
# Share price: $0.201176461565041
# Shares owned at the moment: 60
# Cash capital at the moment: $0.11130862821791965
#
#
# Price increase from previously bought: 7.015641785231863%
# Share price: $0.21588232973867671
# Shares owned at the moment: 0
# Cash capital at the moment: $13.02862782813164
#
#
# Share price: $0.21220586269526776
# Shares owned at the moment: 61
# Cash capital at the moment: $0.04847267025317592
#
#
# Price increase from previously bought: 82.65778438631702%
# Share price: $0.388676456086673
# Shares owned at the moment: 0
# Cash capital at the moment: $23.69253601603169
#
#
# Share price: $0.3813235219998551
# Shares owned at the moment: 61
# Cash capital at the moment: $0.3678341532250542
#
#
# Price increase from previously bought: -21.42703117644934%
# Share price: $0.3004411593909705
# Shares owned at the moment: 0
# Cash capital at the moment: $18.644345871586417
#
#
# Share price: $0.29308822530415257
# Shares owned at the moment: 63
# Cash capital at the moment: $0.12901014239086095
#
#
# Price increase from previously bought: -41.55559560469477%
# Share price: $0.17176472521776964
# Shares owned at the moment: 0
# Cash capital at the moment: $10.92042959246637
#
#
# Share price: $0.14235290121660982
# Shares owned at the moment: 76
# Cash capital at the moment: $0.07185734364975005
#
#
# Price increase from previously bought: -38.907646914559535%
# Share price: $0.08720589556547574
# Shares owned at the moment: 0
# Cash capital at the moment: $6.681279374452722
#
#
# Share price: $0.15705876939024555
# Shares owned at the moment: 42
# Cash capital at the moment: $0.06667077219783568
#
#
# Price increase from previously bought: 32.40745059945704%
# Share price: $0.2085293956518589
# Shares owned at the moment: 0
# Cash capital at the moment: $8.80082024437812
#
#
# Share price: $0.09455882965229377
# Shares owned at the moment: 92
# Cash capital at the moment: $0.07748453246506237
#
#
# Price increase from previously bought: 123.80130735199214%
# Share price: $0.21220586269526776
# Shares owned at the moment: 0
# Cash capital at the moment: $19.546735817167793
#
#
# Share price: $0.19382352747822307
# Shares owned at the moment: 100
# Cash capital at the moment: $0.11108159928897621
#
#
# Price increase from previously bought: 47.016039704229364%
# Share price: $0.28573529121733454
# Shares owned at the moment: 0
# Cash capital at the moment: $28.606033515937664
#
#
#
#
# Capital at the end of test period: $28.606033515937664
# profit gained: -71.39396648406233%
#
#
# Capital at the end of test period if Buy and Hold: $26.129427230180067
# profit gained: -73.87057276981993%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.059633      4.958678       7.216495            0.0
# 1       0.059633      6.293706       5.333333            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         50.833333           60.824742                0.0     -89.276043
# 1         45.454545           59.459459                0.0     -71.393966
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
#
#
# Recession
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2130 - accuracy: 0.0685 - mse: 1.0206 - weighted_accuracy: 0.0685 - weighted_mse: 1.0206
# Test loss: 0.2129805088043213
# Test accuracy: 0.06849315017461777
#
#
# number of predictions: 219
# actual predicted buys: 6
# actual buys but predicted sell: 2
# actual buys but predicted hold: 0
# actual sells but predicted buy: 2
# actual predicted sells: 9
# actual sells but predicted hold: 0
# actual holds but predicted buy: 115
# actual holds but predicted sell: 85
# actual predicted holds: 0
# Percentage buys correct: 4.878048780487805%
# Percentage sells correct: 9.375%
# Percentage holds correct: 0%
# actual buys: 8
# actual sells: 11
# actual holds: 200
#
#
# Percentage low buys correct: 48.36065573770492%
# Percentage high sells correct: 42.708333333333336%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.011763675119632519
# Shares owned at the moment: 8477
# Cash capital at the moment: $0.005094157405039823
#
#
# Price increase from previously bought: 247.9185448914977%
# Share price: $0.04104055932206908
# Shares owned at the moment: 0
# Cash capital at the moment: $346.94918827180834
#
#
# Share price: $0.22728394889378878
# Shares owned at the moment: 1522
# Cash capital at the moment: $0.07172108736688187
#
#
# Price increase from previously bought: -18.537056203570458%
# Share price: $0.18566136408340334
# Shares owned at the moment: 0
# Cash capital at the moment: $281.87123158293565
#
#
# Share price: $0.15462081317116044
# Shares owned at the moment: 1817
# Cash capital at the moment: $0.15261250272413918
#
#
# Price increase from previously bought: 96.86935037329793%
# Share price: $0.3052380931556622
# Shares owned at the moment: 0
# Cash capital at the moment: $553.2450293245868
#
#
# Share price: $0.28830685910221704
# Shares owned at the moment: 1913
# Cash capital at the moment: $0.19729755302364538
#
#
# Price increase from previously bought: 25.83613011340502%
# Share price: $0.3637918783801879
# Shares owned at the moment: 0
# Cash capital at the moment: $694.2173427701346
#
#
# Share price: $0.41246913002979846
# Shares owned at the moment: 1678
# Cash capital at the moment: $0.19080377961017803
#
#
# Price increase from previously bought: -5.391233045692834%
# Share price: $0.3913050958728182
# Shares owned at the moment: 0
# Cash capital at the moment: $654.9950772892939
#
#
# Share price: $0.6488007214386262
# Shares owned at the moment: 1006
# Cash capital at the moment: $0.5066443261760014
#
#
# Price increase from previously bought: 16.641742544076756%
# Share price: $0.7588535914091475
# Shares owned at the moment: 0
# Cash capital at the moment: $761.813988823145
#
#
# Share price: $0.8435096607584583
# Shares owned at the moment: 900
# Cash capital at the moment: $0.5676077301553732
#
#
# Price increase from previously bought: -6.946671795913339%
# Share price: $0.7870723260446578
# Shares owned at the moment: 0
# Cash capital at the moment: $706.9846971633868
#
#
# Share price: $0.6357495457369284
# Shares owned at the moment: 1108
# Cash capital at the moment: $0.6370716210096816
#
#
# Price increase from previously bought: -11.838417114956712%
# Share price: $0.5620282015785902
# Shares owned at the moment: 0
# Cash capital at the moment: $621.6518190398776
#
#
# Share price: $0.4078835881744759
# Shares owned at the moment: 1519
# Cash capital at the moment: $0.37281688414691416
#
#
# Price increase from previously bought: -39.428041909284%
# Share price: $0.24774249954719407
# Shares owned at the moment: 0
# Cash capital at the moment: $375.6587913401012
#
#
# Share price: $0.291128759477212
# Shares owned at the moment: 1286
# Cash capital at the moment: $0.23762979451532829
#
#
# Price increase from previously bought: 10.600308625901821%
# Share price: $0.3228747770733774
# Shares owned at the moment: 0
# Cash capital at the moment: $414.3127464617587
#
#
# Share price: $0.2801940006469344
# Shares owned at the moment: 1474
# Cash capital at the moment: $0.17102312655504193
#
#
# Price increase from previously bought: -2.785120323002155%
# Share price: $0.27313933380770933
# Shares owned at the moment: 0
# Cash capital at the moment: $401.671230869529
#
#
# Share price: $0.29818342631643713
# Shares owned at the moment: 1343
# Cash capital at the moment: $0.10962338731070531
#
#
# Price increase from previously bought: -3.6953688864944767%
# Share price: $0.2879541509897344
# Shares owned at the moment: 0
# Cash capital at the moment: $385.7685614983812
#
#
# Share price: $0.2583245166256841
# Shares owned at the moment: 1489
# Cash capital at the moment: $0.06558192828453002
#
#
# Price increase from previously bought: 21.377144888985768%
# Share price: $0.3144091768663072
# Shares owned at the moment: 0
# Cash capital at the moment: $466.93341930524264
#
#
# Share price: $0.295361559580747
# Shares owned at the moment: 1576
# Cash capital at the moment: $0.1635044067623994
#
#
#
#
# Capital at the end of test period: $406.7177563718497
# profit gained: 306.7177563718497%
#
#
# Capital at the end of test period if Buy and Hold: $2186.7819938452512
# profit gained: 2086.7819938452512%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.063927      5.000000       8.080808            0.0
# 1       0.068493      4.878049       9.375000            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.899160           44.444444                0.0     226.826198
# 1         48.360656           42.708333                0.0     306.717756
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2118 - accuracy: 0.0596 - mse: 1.0112 - weighted_accuracy: 0.0596 - weighted_mse: 1.0112
# Test loss: 0.21176910400390625
# Test accuracy: 0.059633027762174606
#
#
# number of predictions: 218
# actual predicted buys: 8
# actual buys but predicted sell: 1
# actual buys but predicted hold: 0
# actual sells but predicted buy: 3
# actual predicted sells: 5
# actual sells but predicted hold: 0
# actual holds but predicted buy: 143
# actual holds but predicted sell: 58
# actual predicted holds: 0
# Percentage buys correct: 5.194805194805195%
# Percentage sells correct: 7.8125%
# Percentage holds correct: 0%
# actual buys: 9
# actual sells: 8
# actual holds: 201
#
#
# Percentage low buys correct: 42.48366013071895%
# Percentage high sells correct: 56.25%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $1.0050384330631763
# Shares owned at the moment: 99
# Cash capital at the moment: $0.2275734133440892
#
#
# Price increase from previously bought: -81.01367892473557%
# Share price: $0.191344578346717
# Shares owned at the moment: 0
# Cash capital at the moment: $19.11859310821418
#
#
# Share price: $0.191344578346717
# Shares owned at the moment: 99
# Cash capital at the moment: $0.12338629043430416
#
#
# Price increase from previously bought: 15.24103167620523%
# Share price: $0.2211138616751354
# Shares owned at the moment: 0
# Cash capital at the moment: $21.95346034743165
#
#
# Share price: $0.191344578346717
# Shares owned at the moment: 114
# Cash capital at the moment: $0.0801918905942145
#
#
# Price increase from previously bought: -20.96129071119427%
# Share price: $0.15165218480315598
# Shares owned at the moment: 0
# Cash capital at the moment: $17.320997998218207
#
#
# Share price: $0.146690641524837
# Shares owned at the moment: 117
# Cash capital at the moment: $0.11099522590166089
#
#
# Price increase from previously bought: -52.21913567252254%
# Share price: $0.07028280406321093
# Shares owned at the moment: 0
# Cash capital at the moment: $8.311469809090001
#
#
# Share price: $0.04497890968527956
# Shares owned at the moment: 184
# Cash capital at the moment: $0.0125910986978095
#
#
# Price increase from previously bought: 16.776650816978012%
# Share price: $0.05266930768130009
# Shares owned at the moment: 0
# Cash capital at the moment: $9.677093042370288
#
#
# Share price: $0.04448275535744766
# Shares owned at the moment: 216
# Cash capital at the moment: $0.04239512847926896
#
#
# Price increase from previously bought: -39.205713183429445%
# Share price: $0.027117342054078918
# Shares owned at the moment: 0
# Cash capital at the moment: $5.883633310980192
#
#
# Share price: $0.02389233300854545
# Shares owned at the moment: 245
# Cash capital at the moment: $0.013914264522049358
#
#
# Price increase from previously bought: 9.044966751414352%
# Share price: $0.026125033398415175
# Shares owned at the moment: 0
# Cash capital at the moment: $6.396945705881585
#
#
# Share price: $0.018186552323852474
# Shares owned at the moment: 350
# Cash capital at the moment: $0.014147835921510143
#
#
# Price increase from previously bought: 353.4114430772702%
# Share price: $0.08268667408826068
# Shares owned at the moment: 0
# Cash capital at the moment: $28.874897843002795
#
#
# Share price: $0.07499627609224012
# Shares owned at the moment: 383
# Cash capital at the moment: $0.07233427188067765
#
#
# Price increase from previously bought: 14.240437518670657%
# Share price: $0.08591168313379415
# Shares owned at the moment: 0
# Cash capital at the moment: $32.88602243186316
#
#
# Share price: $0.07450012176440822
# Shares owned at the moment: 440
# Cash capital at the moment: $0.01582370818860568
#
#
# Price increase from previously bought: -53.40641001049698%
# Share price: $0.03480774005009949
# Shares owned at the moment: 0
# Cash capital at the moment: $15.289111964771761
#
#
# Share price: $0.038280820344922785
# Shares owned at the moment: 398
# Cash capital at the moment: $0.011447109624974416
#
#
# Price increase from previously bought: -6.090676303336872%
# Share price: $0.0360481199550531
# Shares owned at the moment: 0
# Cash capital at the moment: $14.319144184445303
#
#
# Share price: $0.027861567631200616
# Shares owned at the moment: 512
# Cash capital at the moment: $0.014792470045856376
#
#
# Price increase from previously bought: 0.6137254644015044%
# Share price: $0.028109650709742716
# Shares owned at the moment: 0
# Cash capital at the moment: $14.367355245234808
#
#
# Share price: $0.02538079599204115
# Shares owned at the moment: 564
# Cash capital at the moment: $0.013220691139943952
#
#
# Price increase from previously bought: 14.346880477074286%
# Share price: $0.029101959365406514
# Shares owned at the moment: 0
# Cash capital at the moment: $16.38158863425347
#
#
# Share price: $0.021163478290843897
# Shares owned at the moment: 771
# Cash capital at the moment: $0.019675007166661374
#
#
# Price increase from previously bought: 125.97570266286762%
# Share price: $0.047955835652270955
# Shares owned at the moment: 0
# Cash capital at the moment: $36.89194593452584
#
#
# Share price: $0.0199230983858903
# Shares owned at the moment: 1846
# Cash capital at the moment: $0.012766705216378682
#
#
#
#
# Capital at the end of test period: $30.752671776978666
# profit gained: -69.24732822302133%
#
#
# Capital at the end of test period if Buy and Hold: $2.3797176202777375
# profit gained: -97.62028237972227%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.059633      4.958678       7.216495            0.0
# 1       0.059633      6.293706       5.333333            0.0
# 2       0.059633      5.194805       7.812500            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         50.833333           60.824742                0.0     -89.276043
# 1         45.454545           59.459459                0.0     -71.393966
# 2         42.483660           56.250000                0.0     -69.247328
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
# 2         -97.620282
#
#
# Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2150 - accuracy: 0.0594 - mse: 1.0068 - weighted_accuracy: 0.0594 - weighted_mse: 1.0068
# Test loss: 0.2149875909090042
# Test accuracy: 0.05936073139309883
#
#
# number of predictions: 219
# actual predicted buys: 6
# actual buys but predicted sell: 2
# actual buys but predicted hold: 0
# actual sells but predicted buy: 3
# actual predicted sells: 7
# actual sells but predicted hold: 0
# actual holds but predicted buy: 103
# actual holds but predicted sell: 98
# actual predicted holds: 0
# Percentage buys correct: 5.357142857142857%
# Percentage sells correct: 6.542056074766355%
# Percentage holds correct: 0%
# actual buys: 8
# actual sells: 10
# actual holds: 201
#
#
# Percentage low buys correct: 46.42857142857143%
# Percentage high sells correct: 48.113207547169814%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.011748252914169829
# Shares owned at the moment: 8488
# Cash capital at the moment: $0.006601545003931619
#
#
# Price increase from previously bought: 22.97529799873046%
# Share price: $0.014487179515679708
# Shares owned at the moment: 0
# Cash capital at the moment: $122.6356215298383
#
#
# Share price: $0.028123547244415785
# Shares owned at the moment: 4348
# Cash capital at the moment: $0.018164856716992972
#
#
# Price increase from previously bought: 15.017305512168623%
# Share price: $0.03243590035716995
# Shares owned at the moment: 0
# Cash capital at the moment: $140.66162354912123
#
#
# Share price: $0.0752097953514889
# Shares owned at the moment: 1865
# Cash capital at the moment: $0.009622980685492166
#
#
# Price increase from previously bought: 7.2982932897547315%
# Share price: $0.08092074857256178
# Shares owned at the moment: 0
# Cash capital at the moment: $150.51179677927166
#
#
# Share price: $0.09426574266811717
# Shares owned at the moment: 1592
# Cash capital at the moment: $0.028039030228086403
#
#
# Price increase from previously bought: 113.47080509591608%
# Share price: $0.2017832218627332
# Shares owned at the moment: 0
# Cash capital at the moment: $320.38352129038424
#
#
# Share price: $0.2504428881447364
# Shares owned at the moment: 1275
# Cash capital at the moment: $0.19072352928782266
#
#
# Price increase from previously bought: 3.1368903050632335%
# Share price: $0.2590093290914314
# Shares owned at the moment: 0
# Cash capital at the moment: $329.519466660736
#
#
# Share price: $0.22759907526044482
# Shares owned at the moment: 1443
# Cash capital at the moment: $0.19083102951179853
#
#
# Price increase from previously bought: 3.096246923459711%
# Share price: $0.23529138141374067
# Shares owned at the moment: 0
# Cash capital at the moment: $338.7825993852445
#
#
# Share price: $0.2673426644625304
# Shares owned at the moment: 1263
# Cash capital at the moment: $0.20026625972411694
#
#
# Price increase from previously bought: 2.073474064345815%
# Share price: $0.2736363816225931
# Shares owned at the moment: 0
# Cash capital at the moment: $344.8526086865885
#
#
# Share price: $0.4454895213752989
# Shares owned at the moment: 771
# Cash capital at the moment: $0.4356385485370424
#
#
# Price increase from previously bought: 38.22230387710803%
# Share price: $0.6174592361459739
# Shares owned at the moment: 0
# Cash capital at the moment: $475.1875416716444
#
#
# Share price: $0.7832518087745554
# Shares owned at the moment: 605
# Cash capital at the moment: $0.01706216618970302
#
#
# Price increase from previously bought: 20.42682261366513%
# Share price: $0.9458391908537784
# Shares owned at the moment: 0
# Cash capital at the moment: $570.6761326789427
#
#
# Share price: $1.01
# Shares owned at the moment: 563
# Cash capital at the moment: $0.4824001789427257
#
#
# Price increase from previously bought: -16.97806204461162%
# Share price: $0.8408275076761337
# Shares owned at the moment: 0
# Cash capital at the moment: $472.5664758118464
#
#
# Share price: $0.6947902213211395
# Shares owned at the moment: 678
# Cash capital at the moment: $0.2032693884604555
#
#
# Price increase from previously bought: 15.375608715145672%
# Share price: $0.8038228978722147
# Shares owned at the moment: 0
# Cash capital at the moment: $543.6964663527394
#
#
# Share price: $0.7717132828540979
# Shares owned at the moment: 702
# Cash capital at the moment: $0.46394929661278184
#
#
# Price increase from previously bought: -20.81793475561068%
# Share price: $0.6127389260457556
# Shares owned at the moment: 0
# Cash capital at the moment: $429.42378288400187
#
#
# Share price: $0.6315035025079746
# Shares owned at the moment: 678
# Cash capital at the moment: $0.08696990316894926
#
#
# Price increase from previously bought: -2.4644810099646697%
# Share price: $0.6176340542125852
# Shares owned at the moment: 0
# Cash capital at the moment: $417.69127996522235
#
#
# Share price: $0.5988111902413817
# Shares owned at the moment: 695
# Cash capital at the moment: $0.3730248601132189
#
#
# Price increase from previously bought: 1.9288167179468685%
# Share price: $0.6120396537793102
# Shares owned at the moment: 0
# Cash capital at the moment: $424.57082344844815
#
#
# Share price: $0.5429254289572745
# Shares owned at the moment: 779
# Cash capital at the moment: $0.4688322905475957
#
#
# Price increase from previously bought: -9.372724926236554%
# Share price: $0.49339162788187224
# Shares owned at the moment: 0
# Cash capital at the moment: $383.76394219569613
#
#
# Share price: $0.5174009686441434
# Shares owned at the moment: 739
# Cash capital at the moment: $0.3531382491470936
#
#
# Price increase from previously bought: 1.2420924582626558%
# Share price: $0.5252680928640505
# Shares owned at the moment: 0
# Cash capital at the moment: $387.4587827939574
#
#
# Share price: $0.6411771838236646
# Shares owned at the moment: 602
# Cash capital at the moment: $0.40864930429125934
#
#
#
#
# Capital at the end of test period: $419.02649820377223
# profit gained: 319.02649820377223%
#
#
# Capital at the end of test period if Buy and Hold: $5902.379195330377
# profit gained: 5802.379195330377%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.063927      5.000000       8.080808            0.0
# 1       0.068493      4.878049       9.375000            0.0
# 2       0.059361      5.357143       6.542056            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.899160           44.444444                0.0     226.826198
# 1         48.360656           42.708333                0.0     306.717756
# 2         46.428571           48.113208                0.0     319.026498
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
# 2        5802.379195
#
#
#
# RUNNING EPOCHS 20 - 40
#
#
#
# Epoch 1/20
#  2/30 [=>............................] - ETA: 6s - loss: 0.1759 - accuracy: 0.1367 - mse: 1.1917 - weighted_accuracy: 0.4386 - weighted_mse: 1.1531WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0070s vs `on_train_batch_end` time: 0.4547s). Check your callbacks.
# 30/30 [==============================] - 1s 31ms/step - loss: 0.1989 - accuracy: 0.1649 - mse: 1.2045 - weighted_accuracy: 0.3796 - weighted_mse: 1.1710 - val_loss: 0.2010 - val_accuracy: 0.0653 - val_mse: 1.0782 - val_weighted_accuracy: 0.0653 - val_weighted_mse: 1.0782
# Epoch 2/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.2001 - accuracy: 0.2184 - mse: 1.2079 - weighted_accuracy: 0.3589 - weighted_mse: 1.2081 - val_loss: 0.2078 - val_accuracy: 0.0727 - val_mse: 0.8117 - val_weighted_accuracy: 0.0727 - val_weighted_mse: 0.8117
# Epoch 3/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.1981 - accuracy: 0.2329 - mse: 1.1886 - weighted_accuracy: 0.3889 - weighted_mse: 1.1756 - val_loss: 0.2072 - val_accuracy: 0.0674 - val_mse: 1.0939 - val_weighted_accuracy: 0.0674 - val_weighted_mse: 1.0939
# Epoch 4/20
# 30/30 [==============================] - 1s 24ms/step - loss: 0.1988 - accuracy: 0.2297 - mse: 1.1852 - weighted_accuracy: 0.3655 - weighted_mse: 1.1674 - val_loss: 0.2077 - val_accuracy: 0.0664 - val_mse: 0.9850 - val_weighted_accuracy: 0.0664 - val_weighted_mse: 0.9850
# Epoch 5/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.1966 - accuracy: 0.2123 - mse: 1.2132 - weighted_accuracy: 0.3917 - weighted_mse: 1.1943 - val_loss: 0.1970 - val_accuracy: 0.0695 - val_mse: 0.9255 - val_weighted_accuracy: 0.0695 - val_weighted_mse: 0.9255
# Epoch 6/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.1980 - accuracy: 0.2995 - mse: 1.1339 - weighted_accuracy: 0.3705 - weighted_mse: 1.1515 - val_loss: 0.1986 - val_accuracy: 0.0748 - val_mse: 0.9528 - val_weighted_accuracy: 0.0748 - val_weighted_mse: 0.9528
# Epoch 7/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.1956 - accuracy: 0.2977 - mse: 1.1785 - weighted_accuracy: 0.4215 - weighted_mse: 1.1732 - val_loss: 0.1993 - val_accuracy: 0.0717 - val_mse: 0.9529 - val_weighted_accuracy: 0.0717 - val_weighted_mse: 0.9529
# Epoch 8/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.1987 - accuracy: 0.2608 - mse: 1.1813 - weighted_accuracy: 0.3801 - weighted_mse: 1.1678 - val_loss: 0.1971 - val_accuracy: 0.0959 - val_mse: 0.9251 - val_weighted_accuracy: 0.0959 - val_weighted_mse: 0.9251
# Epoch 9/20
# 30/30 [==============================] - 1s 27ms/step - loss: 0.1962 - accuracy: 0.2729 - mse: 1.1732 - weighted_accuracy: 0.3962 - weighted_mse: 1.1672 - val_loss: 0.1939 - val_accuracy: 0.0622 - val_mse: 0.9884 - val_weighted_accuracy: 0.0622 - val_weighted_mse: 0.9884
# Epoch 10/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.1957 - accuracy: 0.2874 - mse: 1.1729 - weighted_accuracy: 0.4073 - weighted_mse: 1.1737 - val_loss: 0.1979 - val_accuracy: 0.0664 - val_mse: 1.0001 - val_weighted_accuracy: 0.0664 - val_weighted_mse: 1.0001
# Epoch 11/20
# 30/30 [==============================] - 1s 27ms/step - loss: 0.1959 - accuracy: 0.2608 - mse: 1.1870 - weighted_accuracy: 0.3975 - weighted_mse: 1.1837 - val_loss: 0.1957 - val_accuracy: 0.0611 - val_mse: 0.9558 - val_weighted_accuracy: 0.0611 - val_weighted_mse: 0.9558
# Epoch 12/20
# 30/30 [==============================] - 1s 24ms/step - loss: 0.1961 - accuracy: 0.2447 - mse: 1.2191 - weighted_accuracy: 0.4040 - weighted_mse: 1.2180 - val_loss: 0.1989 - val_accuracy: 0.0738 - val_mse: 0.9493 - val_weighted_accuracy: 0.0738 - val_weighted_mse: 0.9493
# Epoch 13/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.1941 - accuracy: 0.2550 - mse: 1.1786 - weighted_accuracy: 0.4146 - weighted_mse: 1.1593 - val_loss: 0.1942 - val_accuracy: 0.0769 - val_mse: 0.9296 - val_weighted_accuracy: 0.0769 - val_weighted_mse: 0.9296
# Epoch 14/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.1930 - accuracy: 0.2516 - mse: 1.1743 - weighted_accuracy: 0.4257 - weighted_mse: 1.1753 - val_loss: 0.1969 - val_accuracy: 0.0759 - val_mse: 1.0028 - val_weighted_accuracy: 0.0759 - val_weighted_mse: 1.0028
# Epoch 15/20
# 30/30 [==============================] - 1s 24ms/step - loss: 0.1915 - accuracy: 0.2458 - mse: 1.1930 - weighted_accuracy: 0.4504 - weighted_mse: 1.1809 - val_loss: 0.1977 - val_accuracy: 0.0780 - val_mse: 0.9828 - val_weighted_accuracy: 0.0780 - val_weighted_mse: 0.9828
# Epoch 16/20
# 30/30 [==============================] - 1s 27ms/step - loss: 0.1928 - accuracy: 0.2447 - mse: 1.1857 - weighted_accuracy: 0.4465 - weighted_mse: 1.1716 - val_loss: 0.1978 - val_accuracy: 0.0727 - val_mse: 0.9968 - val_weighted_accuracy: 0.0727 - val_weighted_mse: 0.9968
# Epoch 17/20
# 30/30 [==============================] - 1s 27ms/step - loss: 0.1912 - accuracy: 0.2313 - mse: 1.2199 - weighted_accuracy: 0.4385 - weighted_mse: 1.2050 - val_loss: 0.1942 - val_accuracy: 0.2055 - val_mse: 1.2396 - val_weighted_accuracy: 0.2055 - val_weighted_mse: 1.2396
# Epoch 18/20
# 30/30 [==============================] - 1s 27ms/step - loss: 0.1914 - accuracy: 0.2136 - mse: 1.2529 - weighted_accuracy: 0.4239 - weighted_mse: 1.2347 - val_loss: 0.1976 - val_accuracy: 0.0717 - val_mse: 0.9843 - val_weighted_accuracy: 0.0717 - val_weighted_mse: 0.9843
# Epoch 19/20
# 30/30 [==============================] - 1s 27ms/step - loss: 0.1905 - accuracy: 0.2052 - mse: 1.1729 - weighted_accuracy: 0.4366 - weighted_mse: 1.1493 - val_loss: 0.1984 - val_accuracy: 0.0685 - val_mse: 1.0168 - val_weighted_accuracy: 0.0685 - val_weighted_mse: 1.0168
# Epoch 20/20
# ...
# Cash capital at the moment: $0.06587582493500577
#
#
# Price increase from previously bought: -19.320422245226798%
# Share price: $0.3114705605211977
# Shares owned at the moment: 0
# Cash capital at the moment: $30.19543542347215
#
#
# Share price: $0.21588232973867671
# Shares owned at the moment: 139
# Cash capital at the moment: $0.10527056925347722
#
#
# Price increase from previously bought: -68.20730316773007%
# Share price: $0.0688235603484315
# Shares owned at the moment: 0
# Cash capital at the moment: $9.645437651742267
#
#
# Share price: $0.15705876939024555
# Shares owned at the moment: 61
# Cash capital at the moment: $0.038506110372074076
#
#
# Price increase from previously bought: 34.74185351137737%
# Share price: $0.21220586269526776
# Shares owned at the moment: 0
# Cash capital at the moment: $12.947466201316276
#
#
# Share price: $0.21220586269526776
# Shares owned at the moment: 60
# Cash capital at the moment: $0.18010047225549108
#
#
# Price increase from previously bought: 18.7310334119676%
# Share price: $0.25264708782665435
# Shares owned at the moment: 0
# Cash capital at the moment: $15.297238972363353
#
#
#
#
# Capital at the end of test period: $15.297238972363353
# profit gained: -84.70276102763665%
#
#
# Capital at the end of test period if Buy and Hold: $26.129427230180067
# profit gained: -73.87057276981993%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.756881      8.823529       8.333333      93.604651
# 1       0.706422     12.195122       6.250000      91.925466
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.058824           58.333333          74.269006     -70.374815
# 1         56.097561           75.000000          81.875000     -84.702761
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
#
#
# Recession
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1417 - accuracy: 0.6849 - mse: 2.2738 - weighted_accuracy: 0.6849 - weighted_mse: 2.2738
# Test loss: 0.1416691541671753
# Test accuracy: 0.6849315166473389
#
#
# number of predictions: 219
# actual predicted buys: 2
# actual buys but predicted sell: 0
# actual buys but predicted hold: 6
# actual sells but predicted buy: 0
# actual predicted sells: 1
# actual sells but predicted hold: 10
# actual holds but predicted buy: 30
# actual holds but predicted sell: 23
# actual predicted holds: 147
# Percentage buys correct: 6.25%
# Percentage sells correct: 4.166666666666667%
# Percentage holds correct: 90.1840490797546%
# actual buys: 8
# actual sells: 11
# actual holds: 200
#
#
# Percentage low buys correct: 40.625%
# Percentage high sells correct: 58.333333333333336%
# Percentage mid holds correct: 85.80246913580247%
#
#
# Capital: 100
# Share price: $0.01
# Shares owned at the moment: 9972
# Cash capital at the moment: $0.0057699999999982765
#
#
# Price increase from previously bought: 165.05593509679818%
# Share price: $0.026578483891831435
# Shares owned at the moment: 0
# Cash capital at the moment: $264.31754960557737
#
#
# Share price: $0.031869492431076514
# Shares owned at the moment: 8271
# Cash capital at the moment: $9.813542556003085e-05
#
#
# Price increase from previously bought: -24.5572182764764%
# Share price: $0.02410935049810265
# Shares owned at the moment: 0
# Cash capital at the moment: $198.86016290081562
#
#
# Share price: $0.09324514439129225
# Shares owned at the moment: 2126
# Cash capital at the moment: $0.07582818824459991
#
#
# Price increase from previously bought: 57.067592687598804%
# Share price: $0.14686066282836036
# Shares owned at the moment: 0
# Cash capital at the moment: $311.4429764961127
#
#
# Share price: $0.16379188006215306
# Shares owned at the moment: 1896
# Cash capital at the moment: $0.03956103562637736
#
#
# Price increase from previously bought: 8.745852216875072%
# Share price: $0.17860669724417821
# Shares owned at the moment: 0
# Cash capital at the moment: $337.74660369115713
#
#
# Share price: $0.1835449808512883
# Shares owned at the moment: 1835
# Cash capital at the moment: $0.015349969422288723
#
#
# Price increase from previously bought: 121.04101840091413%
# Share price: $0.40682539655841843
# Shares owned at the moment: 0
# Cash capital at the moment: $744.4870099967372
#
#
# Share price: $0.3165255600984224
# Shares owned at the moment: 2345
# Cash capital at the moment: $0.19337736025192953
#
#
# Price increase from previously bought: 17.729399743861606%
# Share price: $0.37366841195510303
# Shares owned at the moment: 0
# Cash capital at the moment: $874.036109223373
#
#
# Share price: $0.40223985470309587
# Shares owned at the moment: 2166
# Cash capital at the moment: $0.38864224192832353
#
#
# Price increase from previously bought: -1.3236674008512472%
# Share price: $0.39800705459956076
# Shares owned at the moment: 0
# Cash capital at the moment: $860.1011934838546
#
#
# Share price: $0.39800705459956076
# Shares owned at the moment: 2155
# Cash capital at the moment: $0.03730151448041852
#
#
# Price increase from previously bought: 8.210419903645994%
# Share price: $0.4318694890671462
# Shares owned at the moment: 0
# Cash capital at the moment: $928.1566838945962
#
#
# Share price: $0.6255203040495309
# Shares owned at the moment: 1479
# Cash capital at the moment: $0.4680067486945063
#
#
# Price increase from previously bought: -62.52727543895187%
# Share price: $0.2350440992365888
# Shares owned at the moment: 0
# Cash capital at the moment: $347.14224640698933
#
#
# Share price: $0.30135803480391465
# Shares owned at the moment: 1148
# Cash capital at the moment: $0.23183513621933116
#
#
# Price increase from previously bought: 11.164998984957709%
# Share price: $0.3359259191357701
# Shares owned at the moment: 0
# Cash capital at the moment: $384.8142721773717
#
#
# Share price: $0.2801940006469344
# Shares owned at the moment: 1369
# Cash capital at the moment: $0.17382492778295955
#
#
# Price increase from previously bought: -6.049263158122731%
# Share price: $0.2639682500970642
# Shares owned at the moment: 0
# Cash capital at the moment: $360.5525848411109
#
#
# Share price: $0.25867725837747163
# Shares owned at the moment: 1390
# Cash capital at the moment: $0.002401876277417614
#
#
#
#
# Capital at the end of test period: $358.57499720081506
# profit gained: 258.57499720081506%
#
#
# Capital at the end of test period if Buy and Hold: $2186.7819938452512
# profit gained: 2086.7819938452512%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.730594          0.00       4.545455      91.379310
# 1       0.684932          6.25       4.166667      90.184049
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.826087           52.380952          81.609195      70.454076
# 1         40.625000           58.333333          85.802469     258.574997
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1377 - accuracy: 0.7339 - mse: 2.3493 - weighted_accuracy: 0.7339 - weighted_mse: 2.3493
# Test loss: 0.13767561316490173
# Test accuracy: 0.7339449524879456
#
#
# number of predictions: 218
# actual predicted buys: 1
# actual buys but predicted sell: 1
# actual buys but predicted hold: 7
# actual sells but predicted buy: 1
# actual predicted sells: 3
# actual sells but predicted hold: 4
# actual holds but predicted buy: 37
# actual holds but predicted sell: 8
# actual predicted holds: 156
# Percentage buys correct: 2.5641025641025643%
# Percentage sells correct: 25.0%
# Percentage holds correct: 93.41317365269461%
# actual buys: 9
# actual sells: 8
# actual holds: 201
#
#
# Percentage low buys correct: 34.21052631578947%
# Percentage high sells correct: 66.66666666666667%
# Percentage mid holds correct: 83.83233532934132%
#
#
# Capital: 100
# Share price: $1.0050384330631763
# Shares owned at the moment: 99
# Cash capital at the moment: $0.2275734133440892
#
#
# Price increase from previously bought: 0.21806968196280696%
# Share price: $1.01
# Shares owned at the moment: 0
# Cash capital at the moment: $99.94260091334408
#
#
# Share price: $0.27072934177533436
# Shares owned at the moment: 368
# Cash capital at the moment: $0.04022504614439981
#
#
# Price increase from previously bought: -36.826923412241285%
# Share price: $0.1714983815749365
# Shares owned at the moment: 0
# Cash capital at the moment: $62.97807310356719
#
#
# Share price: $0.18142149179007902
# Shares owned at the moment: 346
# Cash capital at the moment: $0.03361439476159234
#
#
# Price increase from previously bought: 2.4530696689335496%
# Share price: $0.186383035068398
# Shares owned at the moment: 0
# Cash capital at the moment: $64.34480107055973
#
#
# Share price: $0.191344578346717
# Shares owned at the moment: 335
# Cash capital at the moment: $0.06809113160760205
#
#
# Price increase from previously bought: -65.95559669478698%
# Share price: $0.06532126078489194
# Shares owned at the moment: 0
# Cash capital at the moment: $21.890536283048316
#
#
# Share price: $0.04497890968527956
# Shares owned at the moment: 485
# Cash capital at the moment: $0.015774464894988682
#
#
# Price increase from previously bought: -26.67564009360268%
# Share price: $0.03307119398806171
# Shares owned at the moment: 0
# Cash capital at the moment: $16.011194844123338
#
#
# Share price: $0.07499627609224012
# Shares owned at the moment: 212
# Cash capital at the moment: $0.06826148360665663
#
#
# Price increase from previously bought: 41.290531347690276%
# Share price: $0.10625403423340656
# Shares owned at the moment: 0
# Cash capital at the moment: $22.53217063913077
#
#
# Share price: $0.07574051349861415
# Shares owned at the moment: 296
# Cash capital at the moment: $0.05132586555310681
#
#
# Price increase from previously bought: -56.12929090944843%
# Share price: $0.03331927706660379
# Shares owned at the moment: 0
# Cash capital at the moment: $9.886709985735614
#
#
# Share price: $0.026125033398415175
# Shares owned at the moment: 377
# Cash capital at the moment: $0.010487266157285902
#
#
# Price increase from previously bought: -56.145677677034%
# Share price: $0.011488462983495698
# Shares owned at the moment: 0
# Cash capital at the moment: $4.329727146937024
#
#
# Share price: $0.016201935012524878
# Shares owned at the moment: 266
# Cash capital at the moment: $0.008160718143744639
#
#
# Price increase from previously bought: 138.6790862273737%
# Share price: $0.038776974672754684
# Shares owned at the moment: 0
# Cash capital at the moment: $10.29447062412337
#
#
# Share price: $0.017442320832104626
# Shares owned at the moment: 588
# Cash capital at the moment: $0.010181742060336063
#
#
#
#
# Capital at the end of test period: $9.801657463726762
# profit gained: -90.19834253627323%
#
#
# Capital at the end of test period if Buy and Hold: $2.3797176202777375
# profit gained: -97.62028237972227%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.756881      8.823529       8.333333      93.604651
# 1       0.706422     12.195122       6.250000      91.925466
# 2       0.733945      2.564103      25.000000      93.413174
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.058824           58.333333          74.269006     -70.374815
# 1         56.097561           75.000000          81.875000     -84.702761
# 2         34.210526           66.666667          83.832335     -90.198343
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
# 2         -97.620282
#
#
# Recession
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1317 - accuracy: 0.7215 - mse: 2.2117 - weighted_accuracy: 0.7215 - weighted_mse: 2.2117
# Test loss: 0.13170985877513885
# Test accuracy: 0.7214611768722534
#
#
# number of predictions: 219
# actual predicted buys: 2
# actual buys but predicted sell: 0
# actual buys but predicted hold: 6
# actual sells but predicted buy: 0
# actual predicted sells: 5
# actual sells but predicted hold: 5
# actual holds but predicted buy: 25
# actual holds but predicted sell: 25
# actual predicted holds: 151
# Percentage buys correct: 7.407407407407407%
# Percentage sells correct: 16.666666666666668%
# Percentage holds correct: 93.20987654320987%
# actual buys: 8
# actual sells: 10
# actual holds: 201
#
#
# Percentage low buys correct: 37.03703703703704%
# Percentage high sells correct: 63.333333333333336%
# Percentage mid holds correct: 85.09316770186335%
#
#
# Capital: 100
# Share price: $0.030979023854952235
# Shares owned at the moment: 3219
# Cash capital at the moment: $0.004288146988756125
#
#
# Price increase from previously bought: 42.122333061346986%
# Share price: $0.044149188768810646
# Shares owned at the moment: 0
# Cash capital at the moment: $141.7297071375115
#
#
# Share price: $0.0725291368075638
# Shares owned at the moment: 1948
# Cash capital at the moment: $0.05441005049908654
#
#
# Price increase from previously bought: 21.680482991656014%
# Share price: $0.08849650193805968
# Shares owned at the moment: 0
# Cash capital at the moment: $171.97152006495716
#
#
# Share price: $0.08529137807921493
# Shares owned at the moment: 2010
# Cash capital at the moment: $0.06440203340227413
#
#
# Price increase from previously bought: 4.631635182999028%
# Share price: $0.08948717840417116
# Shares owned at the moment: 0
# Cash capital at the moment: $179.43899024715722
#
#
# Share price: $0.07538461341810025
# Shares owned at the moment: 2373
# Cash capital at the moment: $0.05936146499215056
#
#
# Price increase from previously bought: 299.07263486388445%
# Share price: $0.3016666712979524
# Shares owned at the moment: 0
# Cash capital at the moment: $713.9457711748105
#
#
# Share price: $0.23470863970492212
# Shares owned at the moment: 3033
# Cash capital at the moment: $0.11682086316284312
#
#
# Price increase from previously bought: 10.050915529741445%
# Share price: $0.2590093290914314
# Shares owned at the moment: 0
# Cash capital at the moment: $783.5317839358548
#
#
# Share price: $0.22759907526044482
# Shares owned at the moment: 3433
# Cash capital at the moment: $0.035452596982736395
#
#
# Price increase from previously bought: 3.096246923459711%
# Share price: $0.23529138141374067
# Shares owned at the moment: 0
# Cash capital at the moment: $805.5694378812726
#
#
# Share price: $0.78960376898326
# Shares owned at the moment: 1017
# Cash capital at the moment: $0.3340804843933256
#
#
# Price increase from previously bought: 3.1628968272110036%
# Share price: $0.816818211374205
# Shares owned at the moment: 0
# Cash capital at the moment: $828.753765119299
#
#
# Share price: $0.7464219281165627
# Shares owned at the moment: 1107
# Cash capital at the moment: $0.19239573959521294
#
#
# Price increase from previously bought: -10.51263121400794%
# Share price: $0.6697902152078423
# Shares owned at the moment: 0
# Cash capital at the moment: $739.6111551120301
#
#
# Share price: $0.5988111902413817
# Shares owned at the moment: 1231
# Cash capital at the moment: $0.44745434312460475
#
#
# Price increase from previously bought: 8.780617111520495%
# Share price: $0.653181831974629
# Shares owned at the moment: 0
# Cash capital at the moment: $802.3031057072008
#
#
# Share price: $0.5644289403573175
# Shares owned at the moment: 1417
# Cash capital at the moment: $0.307858747544401
#
#
# Price increase from previously bought: -22.24653376198813%
# Share price: $0.44006993900863534
# Shares owned at the moment: 0
# Cash capital at the moment: $622.1721197879486
#
#
# Share price: $0.4992774213997277
# Shares owned at the moment: 1242
# Cash capital at the moment: $0.36428037669600144
#
#
# Price increase from previously bought: 6.395394756504746%
# Share price: $0.5326690059327659
# Shares owned at the moment: 0
# Cash capital at the moment: $660.1198547554279
#
#
#
#
# Capital at the end of test period: $660.1198547554279
# profit gained: 560.1198547554279%
#
#
# Capital at the end of test period if Buy and Hold: $5902.379195330377
# profit gained: 5802.379195330377%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.730594      0.000000       4.545455      91.379310
# 1       0.684932      6.250000       4.166667      90.184049
# 2       0.721461      7.407407      16.666667      93.209877
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.826087           52.380952          81.609195      70.454076
# 1         40.625000           58.333333          85.802469     258.574997
# 2         37.037037           63.333333          85.093168     560.119855
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
# 2        5802.379195

# %%
df = nr_log_hist['0_epochs_logs']
df['Profit gained']
# Out:
# 0   -89.276043
# 1   -71.393966
# 2   -69.247328
# Name: Profit gained, dtype: float64

# %%
Vaxart_data_acc = []
Inovio_data_acc = []
Novavax_data_acc = []

Vaxart_data_correct_buys = []
Inovio_data_correct_buys = []
Novavax_data_correct_buys = []

Vaxart_data_correct_sells = []
Inovio_data_correct_sells = []
Novavax_data_correct_sells = []

Vaxart_data_correct_holds = []
Inovio_data_correct_holds = []
Novavax_data_correct_holds = []

Vaxart_data_correct_low_buys = []
Inovio_data_correct_low_buys = []
Novavax_data_correct_low_buys = []

Vaxart_data_correct_high_sells = []
Inovio_data_correct_high_sells = []
Novavax_data_correct_high_sells = []

Vaxart_data_correct_mid_holds = []
Inovio_data_correct_mid_holds = []
Novavax_data_correct_mid_holds = []

Vaxart_data_profit = []
Inovio_data_profit = []
Novavax_data_profit = []

for key,value in nr_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    Vaxart_data_acc.append(acc[0])
    Inovio_data_acc.append(acc[1])
    Novavax_data_acc.append(acc[2])
    
    Vaxart_data_correct_buys.append(correct_buys[0])
    Inovio_data_correct_buys.append(correct_buys[1]) 
    Novavax_data_correct_buys.append(correct_buys[2]) 

    Vaxart_data_correct_sells.append(correct_sells[0]) 
    Inovio_data_correct_sells.append(correct_sells[1]) 
    Novavax_data_correct_sells.append(correct_sells[2]) 

    Vaxart_data_correct_holds.append(correct_holds[0]) 
    Inovio_data_correct_holds.append(correct_holds[1])  
    Novavax_data_correct_holds.append(correct_holds[2])  

    Vaxart_data_correct_low_buys.append(correct_low_buys[0])  
    Inovio_data_correct_low_buys.append(correct_low_buys[1])  
    Novavax_data_correct_low_buys.append(correct_low_buys[2])  

    Vaxart_data_correct_high_sells.append(correct_high_sells[0]) 
    Inovio_data_correct_high_sells.append(correct_high_sells[1]) 
    Novavax_data_correct_high_sells.append(correct_high_sells[2]) 

    Vaxart_data_correct_mid_holds.append(correct_mid_holds[0])  
    Inovio_data_correct_mid_holds.append(correct_mid_holds[1])  
    Novavax_data_correct_mid_holds.append(correct_mid_holds[2])   

    Vaxart_data_profit.append(profit[0]) 
    Inovio_data_profit.append(profit[1]) 
    Novavax_data_profit.append(profit[2])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(Vaxart_data_acc)
plt.plot(Inovio_data_acc)
plt.plot(Novavax_data_acc)

plt.title('Non-Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Vaxart_data_acc','Inovio_data_acc','Novavax_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_profit")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_profit")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_profit")
# Out:
# Text(0.5, 1.0, 'Novavax_data_profit')

# %%
Vaxart_data_acc = []
Inovio_data_acc = []
Novavax_data_acc = []

Vaxart_data_correct_buys = []
Inovio_data_correct_buys = []
Novavax_data_correct_buys = []

Vaxart_data_correct_sells = []
Inovio_data_correct_sells = []
Novavax_data_correct_sells = []

Vaxart_data_correct_holds = []
Inovio_data_correct_holds = []
Novavax_data_correct_holds = []

Vaxart_data_correct_low_buys = []
Inovio_data_correct_low_buys = []
Novavax_data_correct_low_buys = []

Vaxart_data_correct_high_sells = []
Inovio_data_correct_high_sells = []
Novavax_data_correct_high_sells = []

Vaxart_data_correct_mid_holds = []
Inovio_data_correct_mid_holds = []
Novavax_data_correct_mid_holds = []

Vaxart_data_profit = []
Inovio_data_profit = []
Novavax_data_profit = []

for key,value in r_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    Vaxart_data_acc.append(acc[0])
    Inovio_data_acc.append(acc[1])
    Novavax_data_acc.append(acc[2])
    
    Vaxart_data_correct_buys.append(correct_buys[0])
    Inovio_data_correct_buys.append(correct_buys[1]) 
    Novavax_data_correct_buys.append(correct_buys[2]) 

    Vaxart_data_correct_sells.append(correct_sells[0]) 
    Inovio_data_correct_sells.append(correct_sells[1]) 
    Novavax_data_correct_sells.append(correct_sells[2]) 

    Vaxart_data_correct_holds.append(correct_holds[0]) 
    Inovio_data_correct_holds.append(correct_holds[1])  
    Novavax_data_correct_holds.append(correct_holds[2])  

    Vaxart_data_correct_low_buys.append(correct_low_buys[0])  
    Inovio_data_correct_low_buys.append(correct_low_buys[1])  
    Novavax_data_correct_low_buys.append(correct_low_buys[2])  

    Vaxart_data_correct_high_sells.append(correct_high_sells[0]) 
    Inovio_data_correct_high_sells.append(correct_high_sells[1]) 
    Novavax_data_correct_high_sells.append(correct_high_sells[2]) 

    Vaxart_data_correct_mid_holds.append(correct_mid_holds[0])  
    Inovio_data_correct_mid_holds.append(correct_mid_holds[1])  
    Novavax_data_correct_mid_holds.append(correct_mid_holds[2])   

    Vaxart_data_profit.append(profit[0]) 
    Inovio_data_profit.append(profit[1]) 
    Novavax_data_profit.append(profit[2])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(Vaxart_data_acc)
plt.plot(Inovio_data_acc)
plt.plot(Novavax_data_acc)

plt.title('Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Vaxart_data_acc','Inovio_data_acc','Novavax_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_profit")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_profit")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_profit")
# Out:
# Text(0.5, 1.0, 'Novavax_data_profit')

# %% [markdown]
# ## Train Inovio Pharmaceuticals, Inc. Stock Data

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []

seed = 10
df = pd.read_csv('variation 7/initial_indicators/INO_data.csv')
df.set_index('Date', inplace=True)
print(df.head())

plt.figure(figsize=(15,5))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
plt.show()

data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]

    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()
    
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
y = np.array(y)

X.shape
# Out:
#             previous_1d     EMA_12   willr_14    OBV_7  labels
# Date
# 2000-01-21         51.0  54.535133 -80.952381 -17732.0     2.0
# 2000-01-24         56.0  54.760497 -57.142857 -10257.0     2.0
# 2000-01-25         58.0  55.258882 -47.619048  -8463.0     2.0
# 2000-01-26         59.0  55.834439 -42.857143  -4944.0     2.0
# 2000-01-27         57.0  56.013756 -52.380952  -5313.0     2.0
# (4745, 64, 64, 1)

# %%
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)
obv_data.shape
# Out:
# (4745, 15, 1)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
y = np.array(y)

X.shape
# Out:
# (4745, 64, 64, 1)

# %%
from collections import Counter

Counter(y)
# Out:
# Counter({2.0: 4316, 0.0: 213, 1.0: 216})

# %%
# plot the image array X
i = X[0].reshape(64, 64)
fig2, ax2 = plt.subplots()
plt.imshow(i, interpolation="none", cmap="gray")

ax2.axis('off')

plt.show()

# %%
X = X/255

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten,BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.regularizers import l2
import efficientnet.tfkeras as efn
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(Conv2D(16, (3, 3), padding='same', kernel_initializer='he_uniform',kernel_regularizer=l2(1e-5), input_shape=X_train.shape[1:]))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))

model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_uniform',kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

# model.add(Dense(128, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))
# model.add(Dropout(0.25, seed=seed))

model.add(Dense(64, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))
model.add(Dropout(0.25, seed=seed))

model.add(Dense(32, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))
model.add(Dropout(0.25, seed=seed))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "DBS_CNN_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))
print(d_class_weights)

epochs = 0 
histories = {}
nr_log_hist = {}
r_log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    nr_log  = pd.DataFrame(columns = column_names)
    r_log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['VXRT','INO','NVAX']
    for name in test_sets:
        
        print('\n')
        print("Non-Recession")
        print('\n')
        
        X = nr_test_data['{}_X'.format(name)]
        y = nr_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("variation 7/initial_indicators/{}_data_test.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(nr_log)
        nr_log.loc[df_length] = logger
        print(nr_log.head(20))
        logger = []
        
        print('\n')
        print("Recession")
        print('\n')
        
        X = r_test_data['{}_X'.format(name)]
        y = r_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("variation 7/initial_indicators/{}_data_test2.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(r_log)
        r_log.loc[df_length] = logger
        print(r_log.head(20))
        logger = []

    nr_log.to_csv('{}_{}_{}epochs.csv'.format(experiment,'InovioModel',epochs))
    nr_log_hist['{}_epochs_logs'.format(epochs)] = nr_log
    r_log.to_csv('{}_{}_{}epochs.csv'.format(experiment,'InovioModel',epochs))
    r_log_hist['{}_epochs_logs'.format(epochs)] = r_log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 2 ... 0 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# {0: 7.443137254901961, 1: 7.3140655105973025, 2: 0.3664446375132735}
#
#
#
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  2/30 [=>............................] - ETA: 11s - loss: 0.3948 - accuracy: 0.6133 - mse: 4.6151 - weighted_accuracy: 0.2970 - weighted_mse: 4.9629WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0080s vs `on_train_batch_end` time: 0.7851s). Check your callbacks.
# 30/30 [==============================] - 1s 45ms/step - loss: 0.2446 - accuracy: 0.4307 - mse: 1.5747 - weighted_accuracy: 0.3129 - weighted_mse: 1.6345 - val_loss: 0.2095 - val_accuracy: 0.0453 - val_mse: 0.9779 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 0.9779
# Epoch 2/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.2044 - accuracy: 0.3915 - mse: 1.1749 - weighted_accuracy: 0.3243 - weighted_mse: 1.1810 - val_loss: 0.2068 - val_accuracy: 0.0917 - val_mse: 0.8334 - val_weighted_accuracy: 0.0917 - val_weighted_mse: 0.8334
# Epoch 3/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.2052 - accuracy: 0.3801 - mse: 1.1689 - weighted_accuracy: 0.3109 - weighted_mse: 1.1863 - val_loss: 0.2031 - val_accuracy: 0.0453 - val_mse: 1.0335 - val_weighted_accuracy: 0.0453 - val_weighted_mse: 1.0335
# Epoch 4/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2020 - accuracy: 0.3654 - mse: 1.1612 - weighted_accuracy: 0.3382 - weighted_mse: 1.1807 - val_loss: 0.1979 - val_accuracy: 0.1054 - val_mse: 0.9246 - val_weighted_accuracy: 0.1054 - val_weighted_mse: 0.9246
# Epoch 5/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2038 - accuracy: 0.3614 - mse: 1.1661 - weighted_accuracy: 0.3338 - weighted_mse: 1.1683 - val_loss: 0.1956 - val_accuracy: 0.5237 - val_mse: 0.9025 - val_weighted_accuracy: 0.5237 - val_weighted_mse: 0.9025
# Epoch 6/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2039 - accuracy: 0.3941 - mse: 1.1693 - weighted_accuracy: 0.3191 - weighted_mse: 1.1576 - val_loss: 0.1915 - val_accuracy: 0.7777 - val_mse: 0.9500 - val_weighted_accuracy: 0.7777 - val_weighted_mse: 0.9500
# Epoch 7/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.2016 - accuracy: 0.4046 - mse: 1.1645 - weighted_accuracy: 0.3289 - weighted_mse: 1.1808 - val_loss: 0.2010 - val_accuracy: 0.0548 - val_mse: 0.9962 - val_weighted_accuracy: 0.0548 - val_weighted_mse: 0.9962
# Epoch 8/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2011 - accuracy: 0.3796 - mse: 1.1486 - weighted_accuracy: 0.3293 - weighted_mse: 1.1697 - val_loss: 0.1981 - val_accuracy: 0.2571 - val_mse: 0.9330 - val_weighted_accuracy: 0.2571 - val_weighted_mse: 0.9330
# Epoch 9/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2016 - accuracy: 0.3872 - mse: 1.1671 - weighted_accuracy: 0.3651 - weighted_mse: 1.1829 - val_loss: 0.1969 - val_accuracy: 0.0464 - val_mse: 1.0570 - val_weighted_accuracy: 0.0464 - val_weighted_mse: 1.0570
# Epoch 10/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2025 - accuracy: 0.3541 - mse: 1.1859 - weighted_accuracy: 0.3366 - weighted_mse: 1.1760 - val_loss: 0.1987 - val_accuracy: 0.5374 - val_mse: 0.8548 - val_weighted_accuracy: 0.5374 - val_weighted_mse: 0.8548
# Epoch 11/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.2020 - accuracy: 0.4102 - mse: 1.1720 - weighted_accuracy: 0.3384 - weighted_mse: 1.1815 - val_loss: 0.2021 - val_accuracy: 0.0558 - val_mse: 0.9465 - val_weighted_accuracy: 0.0558 - val_weighted_mse: 0.9465
# Epoch 12/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2053 - accuracy: 0.3904 - mse: 1.1534 - weighted_accuracy: 0.3200 - weighted_mse: 1.1732 - val_loss: 0.1910 - val_accuracy: 0.9009 - val_mse: 0.8569 - val_weighted_accuracy: 0.9009 - val_weighted_mse: 0.8569
# Epoch 13/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2010 - accuracy: 0.4194 - mse: 1.1733 - weighted_accuracy: 0.3637 - weighted_mse: 1.1917 - val_loss: 0.1883 - val_accuracy: 0.9094 - val_mse: 0.8788 - val_weighted_accuracy: 0.9094 - val_weighted_mse: 0.8788
# Epoch 14/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2042 - accuracy: 0.4644 - mse: 1.1206 - weighted_accuracy: 0.3194 - weighted_mse: 1.1410 - val_loss: 0.1869 - val_accuracy: 0.9083 - val_mse: 0.8557 - val_weighted_accuracy: 0.9083 - val_weighted_mse: 0.8557
# Epoch 15/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2011 - accuracy: 0.4586 - mse: 1.1744 - weighted_accuracy: 0.3547 - weighted_mse: 1.1793 - val_loss: 0.1935 - val_accuracy: 0.7387 - val_mse: 0.9065 - val_weighted_accuracy: 0.7387 - val_weighted_mse: 0.9065
# Epoch 16/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2027 - accuracy: 0.4565 - mse: 1.1195 - weighted_accuracy: 0.3260 - weighted_mse: 1.1508 - val_loss: 0.1856 - val_accuracy: 0.9104 - val_mse: 0.8982 - val_weighted_accuracy: 0.9104 - val_weighted_mse: 0.8982
# Epoch 17/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1988 - accuracy: 0.4283 - mse: 1.1669 - weighted_accuracy: 0.3750 - weighted_mse: 1.1891 - val_loss: 0.1911 - val_accuracy: 0.8282 - val_mse: 0.8519 - val_weighted_accuracy: 0.8282 - val_weighted_mse: 0.8519
# Epoch 18/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2021 - accuracy: 0.3973 - mse: 1.1655 - weighted_accuracy: 0.3483 - weighted_mse: 1.1566 - val_loss: 0.1850 - val_accuracy: 0.9062 - val_mse: 0.9137 - val_weighted_accuracy: 0.9062 - val_weighted_mse: 0.9137
# Epoch 19/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1989 - accuracy: 0.4270 - mse: 1.1676 - weighted_accuracy: 0.3685 - weighted_mse: 1.1865 - val_loss: 0.2010 - val_accuracy: 0.1243 - val_mse: 0.8839 - val_weighted_accuracy: 0.1243 - val_weighted_mse: 0.8839
# Epoch 20/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2010 - accuracy: 0.4197 - mse: 1.1546 - weighted_accuracy: 0.3532 - weighted_mse: 1.1682 - val_loss: 0.2001 - val_accuracy: 0.1728 - val_mse: 0.8704 - val_weighted_accuracy: 0.1728 - val_weighted_mse: 0.8704
# Validation loss: 0.20006336271762848
# Validation accuracy: 0.17281349003314972
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2000 - accuracy: 0.1422 - mse: 0.8710 - weighted_accuracy: 0.1422 - weighted_mse: 0.8710
# Test loss: 0.19997648894786835
# Test accuracy: 0.14220184087753296
#
#
# number of predictions: 218
# actual predicted buys: 6
# actual buys but predicted sell: 2
# actual buys but predicted hold: 0
# actual sells but predicted buy: 3
# actual predicted sells: 5
# actual sells but predicted hold: 0
# actual holds but predicted buy: 102
# actual holds but predicted sell: 80
# actual predicted holds: 20
# Percentage buys correct: 5.405405405405405%
# Percentage sells correct: 5.747126436781609%
# Percentage holds correct: 100.0%
# actual buys: 8
# actual sells: 8
# actual holds: 202
#
#
# Percentage low buys correct: 48.18181818181818%
# Percentage high sells correct: 56.32183908045977%
# Percentage mid holds correct: 75.0%
#
#
# Capital: 100
# Share price: $0.8109708815818126
# Shares owned at the moment: 122
# Cash capital at the moment: $0.7894717162481584
#
#
# Price increase from previously bought: -16.98872518905512%
# Share price: $0.6750485596312741
# Shares owned at the moment: 0
# Cash capital at the moment: $82.9189171995073
#
#
# Share price: $0.8158253039580221
# Shares owned at the moment: 101
# Cash capital at the moment: $0.29396602157272866
#
#
# Price increase from previously bought: -74.44846608628691%
# Share price: $0.20902913288533498
# Shares owned at the moment: 0
# Cash capital at the moment: $21.347850601332656
#
#
# Share price: $0.21873786190057493
# Shares owned at the moment: 97
# Cash capital at the moment: $0.07192967231490854
#
#
# Price increase from previously bought: -2.4874207968094364%
# Share price: $0.21388349739295492
# Shares owned at the moment: 0
# Cash capital at the moment: $20.761575496501965
#
#
# Share price: $0.24786407788058956
# Shares owned at the moment: 83
# Cash capital at the moment: $0.13228205663678594
#
#
# Price increase from previously bought: -4.180460598687363%
# Share price: $0.23815534886534961
# Shares owned at the moment: 0
# Cash capital at the moment: $19.844817054082288
#
#
# Share price: $0.22359225534248967
# Shares owned at the moment: 88
# Cash capital at the moment: $0.11458925815031407
#
#
# Price increase from previously bought: -15.430145999380551%
# Share price: $0.1896116459205603
# Shares owned at the moment: 0
# Cash capital at the moment: $16.754528080846846
#
#
# Share price: $0.20417476837771503
# Shares owned at the moment: 81
# Cash capital at the moment: $0.17089191259579195
#
#
# Price increase from previously bought: 13.951967718362312%
# Share price: $0.2333009843577296
# Shares owned at the moment: 0
# Cash capital at the moment: $19.016303851306205
#
#
# Share price: $0.21873786190057493
# Shares owned at the moment: 86
# Cash capital at the moment: $0.1531162235172765
#
#
# Price increase from previously bought: -4.700595769634807%
# Share price: $0.20902913288533498
# Shares owned at the moment: 0
# Cash capital at the moment: $18.080186261728702
#
#
# Share price: $0.20902913288533498
# Shares owned at the moment: 86
# Cash capital at the moment: $0.05424544366251283
#
#
# Price increase from previously bought: -4.9061854477612465%
# Share price: $0.19932040387009503
# Shares owned at the moment: 0
# Cash capital at the moment: $17.148660900975408
#
#
# Share price: $0.19446603936247508
# Shares owned at the moment: 87
# Cash capital at the moment: $0.18358947652260227
#
#
# Price increase from previously bought: 12.1727902537482%
# Share price: $0.21873786190057493
# Shares owned at the moment: 0
# Cash capital at the moment: $19.161450428412905
#
#
# Share price: $0.1896116459205603
# Shares owned at the moment: 100
# Cash capital at the moment: $0.14814263372872105
#
#
# Price increase from previously bought: -71.76223908549326%
# Share price: $0.05368932397002193
# Shares owned at the moment: 0
# Cash capital at the moment: $5.502310466639158
#
#
# Share price: $0.048834959462401954
# Shares owned at the moment: 112
# Cash capital at the moment: $0.017753839335719057
#
#
# Price increase from previously bought: -10.187361543627171%
# Share price: $0.043980580487634584
# Shares owned at the moment: 0
# Cash capital at the moment: $4.930032835160601
#
#
# Share price: $0.029417472497627294
# Shares owned at the moment: 167
# Cash capital at the moment: $0.0038049538123070548
#
#
# Price increase from previously bought: 16.182185106780555%
# Share price: $0.034271851472394664
# Shares owned at the moment: 0
# Cash capital at the moment: $5.711464801913519
#
#
# Share price: $0.014854364507619946
# Shares owned at the moment: 383
# Cash capital at the moment: $0.006597836077428809
#
#
# Price increase from previously bought: 130.0863314172555%
# Share price: $0.034271851472394664
# Shares owned at the moment: 0
# Cash capital at the moment: $13.096620122441285
#
#
# Share price: $0.029417472497627294
# Shares owned at the moment: 443
# Cash capital at the moment: $0.028841970122160276
#
#
#
#
# Capital at the end of test period: $8.735805156072336
# profit gained: -91.26419484392767%
#
#
# Capital at the end of test period if Buy and Hold: $2.5934579490563006
# profit gained: -97.4065420509437%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.142202      5.405405       5.747126          100.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         48.181818           56.321839               75.0     -91.264195
#
#    buy_n_hold profit
# 0         -97.406542
#
#
# Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2005 - accuracy: 0.1872 - mse: 0.8671 - weighted_accuracy: 0.1872 - weighted_mse: 0.8671
# Test loss: 0.20048552751541138
# Test accuracy: 0.18721461296081543
#
#
# number of predictions: 219
# actual predicted buys: 6
# actual buys but predicted sell: 2
# actual buys but predicted hold: 0
# actual sells but predicted buy: 1
# actual predicted sells: 7
# actual sells but predicted hold: 0
# actual holds but predicted buy: 81
# actual holds but predicted sell: 94
# actual predicted holds: 28
# Percentage buys correct: 6.818181818181818%
# Percentage sells correct: 6.796116504854369%
# Percentage holds correct: 100.0%
# actual buys: 8
# actual sells: 8
# actual holds: 203
#
#
# Percentage low buys correct: 44.827586206896555%
# Percentage high sells correct: 41.74757281553398%
# Percentage mid holds correct: 100.0%
#
#
# Capital: 100
# Share price: $0.011883244935363585
# Shares owned at the moment: 8392
# Cash capital at the moment: $0.0015669758104763787
#
#
# Price increase from previously bought: 305.2772814471938%
# Share price: $0.04829253227481269
# Shares owned at the moment: 0
# Cash capital at the moment: $404.15800276620047
#
#
# Share price: $0.03636535426188572
# Shares owned at the moment: 11083
# Cash capital at the moment: $0.012429123188724134
#
#
# Price increase from previously bought: 78.91414241856312%
# Share price: $0.06524168430984181
# Shares owned at the moment: 0
# Cash capital at the moment: $721.0975639643491
#
#
# Share price: $0.05143126884487168
# Shares owned at the moment: 13982
# Cash capital at the moment: $0.008004972633443685
#
#
# Price increase from previously bought: -0.27424582398404285%
# Share price: $0.05143126884487168
# Shares owned at the moment: 0
# Cash capital at the moment: $717.1424479589095
#
#
# Share price: $0.052686760479567114
# Shares owned at the moment: 13574
# Cash capital at the moment: $0.005643470703944331
#
#
# Price increase from previously bought: 37.74819238311253%
# Share price: $0.07277464160133483
# Shares owned at the moment: 0
# Cash capital at the moment: $985.1320603582075
#
#
# Share price: $0.10855618312343616
# Shares owned at the moment: 9049
# Cash capital at the moment: $0.10576579625262639
#
#
# Price increase from previously bought: 10.106048612707564%
# Share price: $0.11985562280233596
# Shares owned at the moment: 0
# Cash capital at the moment: $1081.6967193250603
#
#
# Share price: $0.12801633339449703
# Shares owned at the moment: 8426
# Cash capital at the moment: $0.06476367377763381
#
#
# Price increase from previously bought: -14.944840484016986%
# Share price: $0.1091839289407839
# Shares owned at the moment: 0
# Cash capital at the moment: $917.5185935193713
#
#
# Share price: $0.09474577514178649
# Shares owned at the moment: 9657
# Cash capital at the moment: $0.04250311114253691
#
#
# Price increase from previously bought: -0.27424582398404285%
# Share price: $0.09474577514178649
# Shares owned at the moment: 0
# Cash capital at the moment: $912.486313791378
#
#
# Share price: $0.4563276802335273
# Shares owned at the moment: 1994
# Cash capital at the moment: $0.0666465711640285
#
#
# Price increase from previously bought: 120.72518517007506%
# Share price: $1.01
# Shares owned at the moment: 0
# Cash capital at the moment: $2008.4683115711641
#
#
# Share price: $0.6471625883069226
# Shares owned at the moment: 3094
# Cash capital at the moment: $0.6408804669358688
#
#
# Price increase from previously bought: -19.524266237881605%
# Share price: $0.5222410658882417
# Shares owned at the moment: 0
# Cash capital at the moment: $1612.0112502160455
#
#
# Share price: $0.40673574569641713
# Shares owned at the moment: 3952
# Cash capital at the moment: $0.17117913957622477
#
#
# Price increase from previously bought: -37.36761914722136%
# Share price: $0.2554488390825688
# Shares owned at the moment: 0
# Cash capital at the moment: $1006.9287732107388
#
#
# Share price: $0.27741998758966135
# Shares owned at the moment: 3619
# Cash capital at the moment: $0.18488505226514462
#
#
# Price increase from previously bought: 55.68933660140301%
# Share price: $0.4331010999583029
# Shares owned at the moment: 0
# Cash capital at the moment: $1563.2674353793034
#
#
# Share price: $0.3734651724770659
# Shares owned at the moment: 4174
# Cash capital at the moment: $0.13698547775220504
#
#
# Price increase from previously bought: 7.4365522647576565%
# Share price: $0.4023415100083424
# Shares owned at the moment: 0
# Cash capital at the moment: $1674.8921712299425
#
#
# Share price: $0.3872756103919972
# Shares owned at the moment: 4312
# Cash capital at the moment: $0.3674250316223606
#
#
# Price increase from previously bought: 9.74795344457442%
# Share price: $0.4261958810008373
# Shares owned at the moment: 0
# Cash capital at the moment: $1833.0702331503248
#
#
# Share price: $0.3006465977981677
# Shares owned at the moment: 6080
# Cash capital at the moment: $0.11210742227967785
#
#
# Price increase from previously bought: -14.64185164043661%
# Share price: $0.25733209150125286
# Shares owned at the moment: 0
# Cash capital at the moment: $1560.388631179996
#
#
# Share price: $0.42807910348623956
# Shares owned at the moment: 3635
# Cash capital at the moment: $0.041904269290853335
#
#
# Price increase from previously bought: -4.515218589727288%
# Share price: $0.40987445981651494
# Shares owned at the moment: 0
# Cash capital at the moment: $1485.838358133382
#
#
# Share price: $0.42933459512093497
# Shares owned at the moment: 3451
# Cash capital at the moment: $0.13017772968873942
#
#
#
#
# Capital at the end of test period: $1402.0755540605126
# profit gained: 1302.0755540605126%
#
#
# Capital at the end of test period if Buy and Hold: $3238.165410975435
# profit gained: 3138.165410975435%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.187215      6.818182       6.796117          100.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         44.827586           41.747573              100.0    1302.075554
#
#    buy_n_hold profit
# 0        3138.165411
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1994 - accuracy: 0.1606 - mse: 0.8737 - weighted_accuracy: 0.1606 - weighted_mse: 0.8737
# Test loss: 0.19943276047706604
# Test accuracy: 0.16055046021938324
#
#
# number of predictions: 218
# actual predicted buys: 5
# actual buys but predicted sell: 2
# actual buys but predicted hold: 3
# actual sells but predicted buy: 3
# actual predicted sells: 6
# actual sells but predicted hold: 0
# actual holds but predicted buy: 88
# actual holds but predicted sell: 87
# actual predicted holds: 24
# Percentage buys correct: 5.208333333333333%
# Percentage sells correct: 6.315789473684211%
# Percentage holds correct: 88.88888888888889%
# actual buys: 10
# actual sells: 9
# actual holds: 199
#
#
# Percentage low buys correct: 44.791666666666664%
# Percentage high sells correct: 53.191489361702125%
# Percentage mid holds correct: 74.07407407407408%
#
#
# Capital: 100
# Share price: $0.9879411977395466
# Shares owned at the moment: 100
# Cash capital at the moment: $0.9341963966669624
#
#
# Price increase from previously bought: -45.17903984384045%
# Share price: $0.5430882472176247
# Shares owned at the moment: 0
# Cash capital at the moment: $55.093671850444586
#
#
# Share price: $0.5908823187819406
# Shares owned at the moment: 92
# Cash capital at the moment: $0.583005295854214
#
#
# Price increase from previously bought: 0.34624735537363005%
# Share price: $0.5945587858253497
# Shares owned at the moment: 0
# Cash capital at the moment: $55.131990218972575
#
#
# Share price: $0.6276470768699184
# Shares owned at the moment: 87
# Cash capital at the moment: $0.3765299681485459
#
#
# Price increase from previously bought: -2.0267021449106526%
# Share price: $0.6166175880858032
# Shares owned at the moment: 0
# Cash capital at the moment: $53.8747343736639
#
#
# Share price: $0.6827940825210522
# Shares owned at the moment: 78
# Cash capital at the moment: $0.47033660632106233
#
#
# Price increase from previously bought: 0.7996898119356555%
# Share price: $0.6901470166078701
# Shares owned at the moment: 0
# Cash capital at the moment: $54.15376736667255
#
#
# Share price: $0.6607352802605987
# Shares owned at the moment: 81
# Cash capital at the moment: $0.48703088188599963
#
#
# Price increase from previously bought: 8.604081237274164%
# Share price: $0.71955884060903
# Shares owned at the moment: 0
# Cash capital at the moment: $58.61101523947176
#
#
# Share price: $0.5872058517385322
# Shares owned at the moment: 99
# Cash capital at the moment: $0.31776912422125037
#
#
# Price increase from previously bought: -73.32655289277761%
# Share price: $0.15705876939024555
# Shares owned at the moment: 0
# Cash capital at the moment: $15.823828043889065
#
#
# Share price: $0.18647059339140537
# Shares owned at the moment: 84
# Cash capital at the moment: $0.11722349193759918
#
#
# Price increase from previously bought: 7.590553487028795%
# Share price: $0.201176461565041
# Shares owned at the moment: 0
# Cash capital at the moment: $16.969574500779515
#
#
# Share price: $0.3739705879130374
# Shares owned at the moment: 45
# Cash capital at the moment: $0.09461918443859219
#
#
# Price increase from previously bought: -19.882145350028424%
# Share price: $0.3004411593909705
# Shares owned at the moment: 0
# Cash capital at the moment: $13.577291763557632
#
#
# Share price: $0.28573529121733454
# Shares owned at the moment: 47
# Cash capital at the moment: $0.11080178995306866
#
#
# Price increase from previously bought: -69.56387967754696%
# Share price: $0.08720589556547574
# Shares owned at the moment: 0
# Cash capital at the moment: $4.198207519528591
#
#
# Share price: $0.09088236260888481
# Shares owned at the moment: 46
# Cash capital at the moment: $0.006122220649865895
#
#
# Price increase from previously bought: -16.411081974912832%
# Share price: $0.0761764944352493
# Shares owned at the moment: 0
# Cash capital at the moment: $3.500604638125275
#
#
# Share price: $0.0688235603484315
# Shares owned at the moment: 50
# Cash capital at the moment: $0.04996338115579091
#
#
# Price increase from previously bought: 148.8881231435538%
# Share price: $0.17176472521776964
# Shares owned at the moment: 0
# Cash capital at the moment: $8.61458199232683
#
#
# Share price: $0.09088236260888481
# Shares owned at the moment: 94
# Cash capital at the moment: $0.04814681635726181
#
#
# Price increase from previously bought: -60.787477573097924%
# Share price: $0.03573526930386272
# Shares owned at the moment: 0
# Cash capital at the moment: $3.398024563805309
#
#
# Share price: $0.04308820339068042
# Shares owned at the moment: 78
# Cash capital at the moment: $0.02790227970493575
#
#
# Price increase from previously bought: 101.83421492442557%
# Share price: $0.08720589556547574
# Shares owned at the moment: 0
# Cash capital at the moment: $6.811256469213249
#
#
# Share price: $0.13867643417320108
# Shares owned at the moment: 48
# Cash capital at the moment: $0.13648233958873401
#
#
# Price increase from previously bought: 49.958797060482716%
# Share price: $0.2085293956518589
# Shares owned at the moment: 0
# Cash capital at the moment: $10.118367450651917
#
#
# Share price: $0.12397056599956523
# Shares owned at the moment: 81
# Cash capital at the moment: $0.049137161110730077
#
#
# Price increase from previously bought: 64.79002605114242%
# Share price: $0.20485292860844995
# Shares owned at the moment: 0
# Cash capital at the moment: $16.596593388547646
#
#
# Share price: $0.16073532408754287
# Shares owned at the moment: 102
# Cash capital at the moment: $0.15650407321171755
#
#
# Price increase from previously bought: 59.0319985205763%
# Share price: $0.2563235548700633
# Shares owned at the moment: 0
# Cash capital at the moment: $26.229607912817123
#
#
#
#
# Capital at the end of test period: $26.229607912817123
# profit gained: -73.77039208718287%
#
#
# Capital at the end of test period if Buy and Hold: $26.129427230180067
# profit gained: -73.87057276981993%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.142202      5.405405       5.747126     100.000000
# 1       0.160550      5.208333       6.315789      88.888889
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         48.181818           56.321839          75.000000     -91.264195
# 1         44.791667           53.191489          74.074074     -73.770392
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
#
#
# Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1997 - accuracy: 0.2192 - mse: 0.8773 - weighted_accuracy: 0.2192 - weighted_mse: 0.8773
# Test loss: 0.19967715442180634
# Test accuracy: 0.21917808055877686
#
#
# number of predictions: 219
# actual predicted buys: 3
# actual buys but predicted sell: 2
# actual buys but predicted hold: 3
# actual sells but predicted buy: 2
# actual predicted sells: 9
# actual sells but predicted hold: 0
# actual holds but predicted buy: 74
# actual holds but predicted sell: 90
# actual predicted holds: 36
# Percentage buys correct: 3.7974683544303796%
# Percentage sells correct: 8.910891089108912%
# Percentage holds correct: 92.3076923076923%
# actual buys: 8
# actual sells: 11
# actual holds: 200
#
#
# Percentage low buys correct: 43.58974358974359%
# Percentage high sells correct: 42.57425742574257%
# Percentage mid holds correct: 87.17948717948718%
#
#
# Capital: 100
# Share price: $0.011763675119632519
# Shares owned at the moment: 8477
# Cash capital at the moment: $0.005094157405039823
#
#
# Price increase from previously bought: 125.3172859682631%
# Share price: $0.026578483891831435
# Shares owned at the moment: 0
# Cash capital at the moment: $224.6913111365947
#
#
# Share price: $0.12111110363571004
# Shares owned at the moment: 1850
# Cash capital at the moment: $0.019616670784415646
#
#
# Price increase from previously bought: 52.877969061013495%
# Share price: $0.18566136408340334
# Shares owned at the moment: 0
# Cash capital at the moment: $342.54858803530624
#
#
# Share price: $0.17049382196924323
# Shares owned at the moment: 2003
# Cash capital at the moment: $0.11034003604993359
#
#
# Price increase from previously bought: 41.196477851751155%
# Share price: $0.24139328257223897
# Shares owned at the moment: 0
# Cash capital at the moment: $482.291430479516
#
#
# Share price: $0.28830685910221704
# Shares owned at the moment: 1668
# Cash capital at the moment: $0.07312593431606729
#
#
# Price increase from previously bought: 29.252437177587453%
# Share price: $0.37366841195510303
# Shares owned at the moment: 0
# Cash capital at the moment: $621.6380200697898
#
#
# Share price: $0.31123456837882973
# Shares owned at the moment: 1991
# Cash capital at the moment: $0.26590735702370694
#
#
# Price increase from previously bought: 3.1164431966886674%
# Share price: $0.32181658545731984
# Shares owned at the moment: 0
# Cash capital at the moment: $639.2407027430223
#
#
# Share price: $0.7419223909950073
# Shares owned at the moment: 859
# Cash capital at the moment: $0.17676271018308398
#
#
# Price increase from previously bought: 9.777266757173674%
# Share price: $0.8167018931300982
# Shares owned at the moment: 0
# Cash capital at the moment: $699.7944348618909
#
#
# Share price: $0.6255203040495309
# Shares owned at the moment: 1115
# Cash capital at the moment: $0.4212942143720966
#
#
# Price increase from previously bought: -33.62207982199398%
# Share price: $0.416349188381546
# Shares owned at the moment: 0
# Cash capital at the moment: $463.3740085609209
#
#
# Share price: $0.34121691085536265
# Shares owned at the moment: 1354
# Cash capital at the moment: $0.09579009518995463
#
#
# Price increase from previously bought: -27.593542925931068%
# Share price: $0.24774249954719407
# Shares owned at the moment: 0
# Cash capital at the moment: $334.6166652850267
#
#
# Share price: $0.291128759477212
# Shares owned at the moment: 1146
# Cash capital at the moment: $0.06561463864932193
#
#
# Price increase from previously bought: 9.633682075827398%
# Share price: $0.32005291033768735
# Shares owned at the moment: 0
# Cash capital at the moment: $365.83760313870977
#
#
# Share price: $0.2886596008540045
# Shares owned at the moment: 1263
# Cash capital at the moment: $0.2579403014358945
#
#
# Price increase from previously bought: -5.636168072978521%
# Share price: $0.27313933380770933
# Shares owned at the moment: 0
# Cash capital at the moment: $344.28423770942516
#
#
# Share price: $0.29818342631643713
# Shares owned at the moment: 1151
# Cash capital at the moment: $0.13128892905791645
#
#
# Price increase from previously bought: -2.0437992186805753%
# Share price: $0.2928924009575395
# Shares owned at the moment: 0
# Cash capital at the moment: $336.32336475905504
#
#
# Share price: $0.25867725837747163
# Shares owned at the moment: 1296
# Cash capital at the moment: $0.1557121529945107
#
#
# Price increase from previously bought: 21.211630583694085%
# Share price: $0.3144091768663072
# Shares owned at the moment: 0
# Cash capital at the moment: $406.5094510653771
#
#
# Share price: $0.26044089985779917
# Shares owned at the moment: 1556
# Cash capital at the moment: $0.14898427615008814
#
#
#
#
# Capital at the end of test period: $401.5439183228987
# profit gained: 301.5439183228987%
#
#
# Capital at the end of test period if Buy and Hold: $2186.7819938452512
# profit gained: 2086.7819938452512%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.187215      6.818182       6.796117     100.000000
# 1       0.219178      3.797468       8.910891      92.307692
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         44.827586           41.747573         100.000000    1302.075554
# 1         43.589744           42.574257          87.179487     301.543918
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1999 - accuracy: 0.1101 - mse: 0.8720 - weighted_accuracy: 0.1101 - weighted_mse: 0.8720
# Test loss: 0.19989904761314392
# Test accuracy: 0.11009174585342407
#
#
# number of predictions: 218
# actual predicted buys: 4
# actual buys but predicted sell: 2
# actual buys but predicted hold: 3
# actual sells but predicted buy: 4
# actual predicted sells: 4
# actual sells but predicted hold: 0
# actual holds but predicted buy: 110
# actual holds but predicted sell: 75
# actual predicted holds: 16
# Percentage buys correct: 3.389830508474576%
# Percentage sells correct: 4.938271604938271%
# Percentage holds correct: 84.21052631578948%
# actual buys: 9
# actual sells: 8
# actual holds: 201
#
#
# Percentage low buys correct: 41.88034188034188%
# Percentage high sells correct: 46.91358024691358%
# Percentage mid holds correct: 73.6842105263158%
#
#
# Capital: 100
# Share price: $1.01
# Shares owned at the moment: 98
# Cash capital at the moment: $0.7478049999999996
#
#
# Price increase from previously bought: -73.26862595433505%
# Share price: $0.27072934177533436
# Shares owned at the moment: 0
# Cash capital at the moment: $27.206318936374313
#
#
# Share price: $0.23103697189027797
# Shares owned at the moment: 117
# Cash capital at the moment: $0.10065707950609237
#
#
# Price increase from previously bought: -0.27424582398404285%
# Share price: $0.23103697189027797
# Shares owned at the moment: 0
# Cash capital at the moment: $27.05764664496292
#
#
# Share price: $0.186383035068398
# Shares owned at the moment: 144
# Cash capital at the moment: $0.14468191322652046
#
#
# Price increase from previously bought: 5.035182098205615%
# Share price: $0.196306121625036
# Shares owned at the moment: 0
# Cash capital at the moment: $28.33502620306819
#
#
# Share price: $0.186383035068398
# Shares owned at the moment: 151
# Cash capital at the moment: $0.11379235242793584
#
#
# Price increase from previously bought: -2.9289597850788773%
# Share price: $0.18142149179007902
# Shares owned at the moment: 0
# Cash capital at the moment: $27.433102338264035
#
#
# Share price: $0.11692135819641851
# Shares owned at the moment: 233
# Cash capital at the moment: $0.11550851823416863
#
#
# Price increase from previously bought: -44.70871078908779%
# Share price: $0.06482510645706006
# Shares owned at the moment: 0
# Cash capital at the moment: $15.178221635766802
#
#
# Share price: $0.06829818675188333
# Shares owned at the moment: 221
# Cash capital at the moment: $0.04281414060212896
#
#
# Price increase from previously bought: 2.623597699181879%
# Share price: $0.07028280406321093
# Shares owned at the moment: 0
# Cash capital at the moment: $15.532599464402326
#
#
# Share price: $0.062096251739358475
# Shares owned at the moment: 249
# Cash capital at the moment: $0.028112372923539297
#
#
# Price increase from previously bought: 12.873248295699447%
# Share price: $0.07028280406321093
# Shares owned at the moment: 0
# Cash capital at the moment: $17.480404434580777
#
#
# Share price: $0.047459681324439056
# Shares owned at the moment: 367
# Cash capital at the moment: $0.014802705134954408
#
#
# Price increase from previously bought: 7.544934867183706%
# Share price: $0.05118084469780442
# Shares owned at the moment: 0
# Cash capital at the moment: $18.746518441717917
#
#
# Share price: $0.05812701711670328
# Shares owned at the moment: 321
# Cash capital at the moment: $0.03643432289639392
#
#
# Price increase from previously bought: -9.637777904537682%
# Share price: $0.05266930768130009
# Shares owned at the moment: 0
# Cash capital at the moment: $16.896788257238054
#
#
# Share price: $0.04175390063974608
# Shares owned at the moment: 403
# Cash capital at the moment: $0.023692539036382243
#
#
# Price increase from previously bought: -35.23246101185197%
# Share price: $0.027117342054078918
# Shares owned at the moment: 0
# Cash capital at the moment: $10.921928592498752
#
#
# Share price: $0.026373104647704947
# Shares owned at the moment: 412
# Cash capital at the moment: $0.02632875007846458
#
#
# Price increase from previously bought: -1.2122883015488473%
# Share price: $0.026125033398415175
# Shares owned at the moment: 0
# Cash capital at the moment: $10.760242847385113
#
#
# Share price: $0.06829818675188333
# Shares owned at the moment: 157
# Cash capital at the moment: $0.007939785209304162
#
#
# Price increase from previously bought: 20.735136991478754%
# Share price: $0.08268667408826068
# Shares owned at the moment: 0
# Cash capital at the moment: $12.954047645528624
#
#
# Share price: $0.07226742137453855
# Shares owned at the moment: 178
# Cash capital at the moment: $0.05507173809792398
#
#
# Price increase from previously bought: 18.554214749761265%
# Share price: $0.08591168313379415
# Shares owned at the moment: 0
# Cash capital at the moment: $15.305297567019288
#
#
# Share price: $0.04299429237395196
# Shares owned at the moment: 355
# Cash capital at the moment: $0.0003505963362702147
#
#
# Price increase from previously bought: -16.38597240123104%
# Share price: $0.0360481199550531
# Shares owned at the moment: 0
# Cash capital at the moment: $12.762241203274
#
#
# Share price: $0.02513272474275132
# Shares owned at the moment: 506
# Cash capital at the moment: $0.010110296962292153
#
#
# Price increase from previously bought: 11.538090093553354%
# Share price: $0.028109650709742716
# Shares owned at the moment: 0
# Cash capital at the moment: $14.1944789771295
#
#
# Share price: $0.023148095602171438
# Shares owned at the moment: 611
# Cash capital at the moment: $0.012097976567202906
#
#
# Price increase from previously bought: 106.6015260933678%
# Share price: $0.047955835652270955
# Shares owned at the moment: 0
# Cash capital at the moment: $29.232535767250027
#
#
# Share price: $0.017442320832104626
# Shares owned at the moment: 1671
# Cash capital at the moment: $0.006265831999471061
#
#
#
#
# Capital at the end of test period: $27.832041224694372
# profit gained: -72.16795877530564%
#
#
# Capital at the end of test period if Buy and Hold: $2.3797176202777375
# profit gained: -97.62028237972227%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.142202      5.405405       5.747126     100.000000
# 1       0.160550      5.208333       6.315789      88.888889
# 2       0.110092      3.389831       4.938272      84.210526
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         48.181818           56.321839          75.000000     -91.264195
# 1         44.791667           53.191489          74.074074     -73.770392
# 2         41.880342           46.913580          73.684211     -72.167959
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
# 2         -97.620282
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2004 - accuracy: 0.1781 - mse: 0.8699 - weighted_accuracy: 0.1781 - weighted_mse: 0.8699
# Test loss: 0.20044900476932526
# Test accuracy: 0.1780821979045868
#
#
# number of predictions: 219
# actual predicted buys: 5
# actual buys but predicted sell: 3
# actual buys but predicted hold: 0
# actual sells but predicted buy: 2
# actual predicted sells: 8
# actual sells but predicted hold: 0
# actual holds but predicted buy: 62
# actual holds but predicted sell: 113
# actual predicted holds: 26
# Percentage buys correct: 7.246376811594203%
# Percentage sells correct: 6.451612903225806%
# Percentage holds correct: 100.0%
# actual buys: 8
# actual sells: 10
# actual holds: 201
#
#
# Percentage low buys correct: 53.6231884057971%
# Percentage high sells correct: 46.34146341463415%
# Percentage mid holds correct: 92.3076923076923%
#
#
# Capital: 100
# Share price: $0.011748252914169829
# Shares owned at the moment: 8488
# Cash capital at the moment: $0.006601545003931619
#
#
# Price increase from previously bought: 22.97529799873046%
# Share price: $0.014487179515679708
# Shares owned at the moment: 0
# Cash capital at the moment: $122.6356215298383
#
#
# Share price: $0.030979023854952235
# Shares owned at the moment: 3947
# Cash capital at the moment: $0.025160304664211708
#
#
# Price increase from previously bought: -3.275770366220332%
# Share price: $0.030046623782739743
# Shares owned at the moment: 0
# Cash capital at the moment: $118.29305080894417
#
#
# Share price: $0.08849650193805968
# Shares owned at the moment: 1333
# Cash capital at the moment: $0.002807673531165733
#
#
# Price increase from previously bought: -14.918549590560081%
# Share price: $0.07550116620589821
# Shares owned at the moment: 0
# Cash capital at the moment: $100.3690938259742
#
#
# Share price: $0.07888111924643988
# Shares owned at the moment: 1268
# Cash capital at the moment: $0.072776158676092
#
#
# Price increase from previously bought: 155.10520353367863%
# Share price: $0.2017832218627332
# Shares owned at the moment: 0
# Cash capital at the moment: $255.23028338598647
#
#
# Share price: $0.23803031635156474
# Shares owned at the moment: 1069
# Cash capital at the moment: $0.0761255836692385
#
#
# Price increase from previously bought: -1.42175659698206%
# Share price: $0.23529138141374067
# Shares owned at the moment: 0
# Cash capital at the moment: $250.91091447644695
#
#
# Share price: $0.53092078080631
# Shares owned at the moment: 471
# Cash capital at the moment: $0.15955157533554143
#
#
# Price increase from previously bought: 15.980745572037215%
# Share price: $0.6174592361459739
# Shares owned at the moment: 0
# Cash capital at the moment: $290.1830877244711
#
#
# Share price: $0.816818211374205
# Shares owned at the moment: 354
# Cash capital at the moment: $0.23426836922971006
#
#
# Price increase from previously bought: 7.203438659231054%
# Share price: $0.8780652675159911
# Shares owned at the moment: 0
# Cash capital at the moment: $310.21457653196376
#
#
# Share price: $0.8760839368139394
# Shares owned at the moment: 353
# Cash capital at the moment: $0.10648835498102471
#
#
# Price increase from previously bought: -5.892841941399485%
# Share price: $0.8267249538051484
# Shares owned at the moment: 0
# Cash capital at the moment: $291.13785379929203
#
#
# Share price: $0.6288811425881197
# Shares owned at the moment: 461
# Cash capital at the moment: $0.4263829976527518
#
#
# Price increase from previously bought: -7.0294537149598995%
# Share price: $0.5862820878905832
# Shares owned at the moment: 0
# Cash capital at the moment: $269.95916639828835
#
#
# Share price: $0.5988111902413817
# Shares owned at the moment: 449
# Cash capital at the moment: $0.35355986275737905
#
#
# Price increase from previously bought: 2.705220520400542%
# Share price: $0.6167016319102014
# Shares owned at the moment: 0
# Cash capital at the moment: $276.49112025043667
#
#
# Share price: $0.5009674034775412
# Shares owned at the moment: 550
# Cash capital at the moment: $0.20133514002918673
#
#
# Price increase from previously bought: 1.9878683583195667%
# Share price: $0.5123310224107025
# Shares owned at the moment: 0
# Cash capital at the moment: $281.20849679451936
#
#
# Share price: $0.6404195795878922
# Shares owned at the moment: 437
# Cash capital at the moment: $0.5755162848407167
#
#
# Price increase from previously bought: 9.8257411355662%
# Share price: $0.7052797499212441
# Shares owned at the moment: 0
# Cash capital at the moment: $307.9351970609565
#
#
# Share price: $0.7375058510366451
# Shares owned at the moment: 416
# Cash capital at the moment: $0.28905633612617976
#
#
#
#
# Capital at the end of test period: $289.56650673842535
# profit gained: 189.56650673842535%
#
#
# Capital at the end of test period if Buy and Hold: $5902.379195330377
# profit gained: 5802.379195330377%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.187215      6.818182       6.796117     100.000000
# 1       0.219178      3.797468       8.910891      92.307692
# 2       0.178082      7.246377       6.451613     100.000000
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         44.827586           41.747573         100.000000    1302.075554
# 1         43.589744           42.574257          87.179487     301.543918
# 2         53.623188           46.341463          92.307692     189.566507
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
# 2        5802.379195
#
#
#
# RUNNING EPOCHS 20 - 40
#
#
#
# Epoch 1/20
#  2/30 [=>............................] - ETA: 5s - loss: 0.1813 - accuracy: 0.3594 - mse: 1.0874 - weighted_accuracy: 0.4893 - weighted_mse: 1.0814WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0090s vs `on_train_batch_end` time: 0.3457s). Check your callbacks.
# 30/30 [==============================] - 1s 25ms/step - loss: 0.1987 - accuracy: 0.3525 - mse: 1.1828 - weighted_accuracy: 0.3507 - weighted_mse: 1.1698 - val_loss: 0.1935 - val_accuracy: 0.4152 - val_mse: 0.9227 - val_weighted_accuracy: 0.4152 - val_weighted_mse: 0.9227
# Epoch 2/20
# 30/30 [==============================] - 0s 13ms/step - loss: 0.1996 - accuracy: 0.3693 - mse: 1.1732 - weighted_accuracy: 0.3606 - weighted_mse: 1.1803 - val_loss: 0.2011 - val_accuracy: 0.1106 - val_mse: 0.8890 - val_weighted_accuracy: 0.1106 - val_weighted_mse: 0.8890
# Epoch 3/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1978 - accuracy: 0.3543 - mse: 1.1832 - weighted_accuracy: 0.3752 - weighted_mse: 1.1720 - val_loss: 0.1895 - val_accuracy: 0.4679 - val_mse: 0.9958 - val_weighted_accuracy: 0.4679 - val_weighted_mse: 0.9958
# Epoch 4/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1995 - accuracy: 0.4170 - mse: 1.2054 - weighted_accuracy: 0.3709 - weighted_mse: 1.2118 - val_loss: 0.2012 - val_accuracy: 0.1391 - val_mse: 0.8653 - val_weighted_accuracy: 0.1391 - val_weighted_mse: 0.8653
# Epoch 5/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1969 - accuracy: 0.3327 - mse: 1.1615 - weighted_accuracy: 0.3990 - weighted_mse: 1.1625 - val_loss: 0.1965 - val_accuracy: 0.1043 - val_mse: 0.9981 - val_weighted_accuracy: 0.1043 - val_weighted_mse: 0.9981
# Epoch 6/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1975 - accuracy: 0.3641 - mse: 1.1669 - weighted_accuracy: 0.3806 - weighted_mse: 1.1745 - val_loss: 0.1882 - val_accuracy: 0.6006 - val_mse: 0.9801 - val_weighted_accuracy: 0.6006 - val_weighted_mse: 0.9801
# Epoch 7/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1965 - accuracy: 0.3193 - mse: 1.1888 - weighted_accuracy: 0.4012 - weighted_mse: 1.1774 - val_loss: 0.1975 - val_accuracy: 0.1296 - val_mse: 0.9632 - val_weighted_accuracy: 0.1296 - val_weighted_mse: 0.9632
# Epoch 8/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1948 - accuracy: 0.3406 - mse: 1.1668 - weighted_accuracy: 0.4199 - weighted_mse: 1.1848 - val_loss: 0.1929 - val_accuracy: 0.3288 - val_mse: 0.9509 - val_weighted_accuracy: 0.3288 - val_weighted_mse: 0.9509
# Epoch 9/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1952 - accuracy: 0.3174 - mse: 1.2100 - weighted_accuracy: 0.4209 - weighted_mse: 1.1987 - val_loss: 0.1994 - val_accuracy: 0.0875 - val_mse: 0.9958 - val_weighted_accuracy: 0.0875 - val_weighted_mse: 0.9958
# Epoch 10/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1976 - accuracy: 0.3209 - mse: 1.1883 - weighted_accuracy: 0.3909 - weighted_mse: 1.1737 - val_loss: 0.1960 - val_accuracy: 0.1307 - val_mse: 1.0079 - val_weighted_accuracy: 0.1307 - val_weighted_mse: 1.0079
# Epoch 11/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1961 - accuracy: 0.2879 - mse: 1.1924 - weighted_accuracy: 0.4063 - weighted_mse: 1.1926 - val_loss: 0.1942 - val_accuracy: 0.2339 - val_mse: 0.9508 - val_weighted_accuracy: 0.2339 - val_weighted_mse: 0.9508
# Epoch 12/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1938 - accuracy: 0.2943 - mse: 1.2109 - weighted_accuracy: 0.4124 - weighted_mse: 1.1958 - val_loss: 0.1867 - val_accuracy: 0.6122 - val_mse: 0.9863 - val_weighted_accuracy: 0.6122 - val_weighted_mse: 0.9863
# Epoch 13/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1963 - accuracy: 0.2813 - mse: 1.1674 - weighted_accuracy: 0.3837 - weighted_mse: 1.1574 - val_loss: 0.1951 - val_accuracy: 0.1380 - val_mse: 0.9838 - val_weighted_accuracy: 0.1380 - val_weighted_mse: 0.9838
# Epoch 14/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1945 - accuracy: 0.2740 - mse: 1.2079 - weighted_accuracy: 0.3903 - weighted_mse: 1.1843 - val_loss: 0.1981 - val_accuracy: 0.1075 - val_mse: 0.9460 - val_weighted_accuracy: 0.1075 - val_weighted_mse: 0.9460
# Epoch 15/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1954 - accuracy: 0.3206 - mse: 1.1961 - weighted_accuracy: 0.3941 - weighted_mse: 1.1755 - val_loss: 0.1893 - val_accuracy: 0.3762 - val_mse: 1.0040 - val_weighted_accuracy: 0.3762 - val_weighted_mse: 1.0040
# Epoch 16/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1930 - accuracy: 0.3182 - mse: 1.1966 - weighted_accuracy: 0.4268 - weighted_mse: 1.1971 - val_loss: 0.1886 - val_accuracy: 0.3815 - val_mse: 1.0198 - val_weighted_accuracy: 0.3815 - val_weighted_mse: 1.0198
# Epoch 17/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1926 - accuracy: 0.3072 - mse: 1.1893 - weighted_accuracy: 0.4391 - weighted_mse: 1.1732 - val_loss: 0.1929 - val_accuracy: 0.2086 - val_mse: 0.9947 - val_weighted_accuracy: 0.2086 - val_weighted_mse: 0.9947
# Epoch 18/20
# 30/30 [==============================] - 0s 12ms/step - loss: 0.1917 - accuracy: 0.2671 - mse: 1.2198 - weighted_accuracy: 0.4245 - weighted_mse: 1.1942 - val_loss: 0.1951 - val_accuracy: 0.0980 - val_mse: 1.0468 - val_weighted_accuracy: 0.0980 - val_weighted_mse: 1.0468
# Epoch 19/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1928 - accuracy: 0.2679 - mse: 1.2135 - weighted_accuracy: 0.4117 - weighted_mse: 1.2110 - val_loss: 0.1927 - val_accuracy: 0.2213 - val_mse: 0.9991 - val_weighted_accuracy: 0.2213 - val_weighted_mse: 0.9991
# Epoch 20/20
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1920 - accuracy: 0.3670 - mse: 1.2218 - weighted_accuracy: 0.4189 - weighted_mse: 1.2067 - val_loss: 0.1807 - val_accuracy: 0.5269 - val_mse: 1.0802 - val_weighted_accuracy: 0.5269 - val_weighted_mse: 1.0802
# Validation loss: 0.18072915077209473
# Validation accuracy: 0.5268703699111938
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1817 - accuracy: 0.5275 - mse: 1.0675 - weighted_accuracy: 0.5275 - weighted_mse: 1.0675
# Test loss: 0.18169178068637848
# Test accuracy: 0.5275229215621948
#
#
# number of predictions: 218
# actual predicted buys: 1
# actual buys but predicted sell: 2
# actual buys but predicted hold: 5
# actual sells but predicted buy: 1
# actual predicted sells: 4
# actual sells but predicted hold: 3
# actual holds but predicted buy: 30
# actual holds but predicted sell: 62
# actual predicted holds: 110
# Percentage buys correct: 3.125%
# Percentage sells correct: 5.882352941176471%
# Percentage holds correct: 93.22033898305085%
# actual buys: 8
# actual sells: 8
# actual holds: 202
#
#
# Percentage low buys correct: 45.16129032258065%
# Percentage high sells correct: 63.23529411764706%
# Percentage mid holds correct: 72.03389830508475%
#
#
# Capital: 100
# Share price: $0.34980584827778816
# Shares owned at the moment: 285
# Cash capital at the moment: $0.031172907242662973
#
#
# Price increase from previously bought: -33.48848588544645%
# Share price: $0.2333009843577296
# Shares owned at the moment: 0
# ...
# Test loss: 0.12230435013771057
# Test accuracy: 0.7808219194412231
#
#
# number of predictions: 219
# actual predicted buys: 0
# actual buys but predicted sell: 0
# actual buys but predicted hold: 8
# actual sells but predicted buy: 1
# actual predicted sells: 1
# actual sells but predicted hold: 6
# actual holds but predicted buy: 17
# actual holds but predicted sell: 16
# actual predicted holds: 170
# Percentage buys correct: 0.0%
# Percentage sells correct: 5.882352941176471%
# Percentage holds correct: 92.3913043478261%
# actual buys: 8
# actual sells: 8
# actual holds: 203
#
#
# Percentage low buys correct: 33.333333333333336%
# Percentage high sells correct: 47.05882352941177%
# Percentage mid holds correct: 83.60655737704919%
#
#
# Capital: 100
# Share price: $0.013138736570059003
# Shares owned at the moment: 7590
# Cash capital at the moment: $0.002751154193603611
#
#
# Price increase from previously bought: 595.3164951899258%
# Share price: $0.09160703108840705
# Shares owned at the moment: 0
# Cash capital at the moment: $693.3880493588102
#
#
# Share price: $0.06586943012718953
# Shares owned at the moment: 10497
# Cash capital at the moment: $0.055204941577699174
#
#
# Price increase from previously bought: -24.034313524334927%
# Share price: $0.05017576972685583
# Shares owned at the moment: 0
# Cash capital at the moment: $525.3018483636206
#
#
# Share price: $0.05143126884487168
# Shares owned at the moment: 10185
# Cash capital at the moment: $0.03384962734367036
#
#
# Price increase from previously bought: 30.15592154999489%
# Share price: $0.06712492924520537
# Shares owned at the moment: 0
# Cash capital at the moment: $681.8211686277638
#
#
# Share price: $0.10102323331526362
# Shares owned at the moment: 6730
# Cash capital at the moment: $0.06512092545733594
#
#
# Price increase from previously bought: 6.542272051416376%
# Share price: $0.10792843730608846
# Shares owned at the moment: 0
# Cash capital at the moment: $724.4260184419903
#
#
# Share price: $0.5341682813177707
# Shares owned at the moment: 1352
# Cash capital at the moment: $0.24446443042484134
#
#
# Price increase from previously bought: -13.986200374021774%
# Share price: $0.460721945854884
# Shares owned at the moment: 0
# Cash capital at the moment: $621.4275710315396
#
#
# Share price: $0.36781544515429554
# Shares owned at the moment: 1684
# Cash capital at the moment: $0.3230080651962908
#
#
# Price increase from previously bought: -22.400345573230464%
# Share price: $0.2862084290325294
# Shares owned at the moment: 0
# Cash capital at the moment: $480.97257132112617
#
#
# Share price: $0.27741998758966135
# Shares owned at the moment: 1728
# Cash capital at the moment: $0.2725329851652418
#
#
#
#
# Capital at the end of test period: $702.2608292180439
# profit gained: 602.2608292180439%
#
#
# Capital at the end of test period if Buy and Hold: $3238.165410975435
# profit gained: 3138.165410975435%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.780822           0.0       5.882353      92.391304
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         33.333333           47.058824          83.606557     602.260829
#
#    buy_n_hold profit
# 0        3138.165411
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1166 - accuracy: 0.7890 - mse: 2.1515 - weighted_accuracy: 0.7890 - weighted_mse: 2.1515
# Test loss: 0.1165856346487999
# Test accuracy: 0.78899085521698
#
#
# number of predictions: 218
# actual predicted buys: 0
# actual buys but predicted sell: 1
# actual buys but predicted hold: 9
# actual sells but predicted buy: 2
# actual predicted sells: 4
# actual sells but predicted hold: 3
# actual holds but predicted buy: 16
# actual holds but predicted sell: 15
# actual predicted holds: 168
# Percentage buys correct: 0.0%
# Percentage sells correct: 20.0%
# Percentage holds correct: 93.33333333333333%
# actual buys: 10
# actual sells: 9
# actual holds: 199
#
#
# Percentage low buys correct: 50.0%
# Percentage high sells correct: 65.0%
# Percentage mid holds correct: 81.00558659217877%
#
#
# Capital: 100
# Share price: $0.6460294120869631
# Shares owned at the moment: 154
# Cash capital at the moment: $0.23787708258885232
#
#
# Price increase from previously bought: -4.814466865519352%
# Share price: $0.6166175880858032
# Shares owned at the moment: 0
# Cash capital at the moment: $94.9358480992482
#
#
# Share price: $0.6166175880858032
# Shares owned at the moment: 153
# Cash capital at the moment: $0.3339152719332077
#
#
# Price increase from previously bought: 3.8879414557656755%
# Share price: $0.642352945043554
# Shares owned at the moment: 0
# Cash capital at the moment: $98.34364586196989
#
#
# Share price: $0.6607352802605987
# Shares owned at the moment: 148
# Cash capital at the moment: $0.28590512433521553
#
#
# Price increase from previously bought: -1.9389296673953615%
# Share price: $0.6497058791303719
# Shares owned at the moment: 0
# Cash capital at the moment: $96.1779449428242
#
#
# Share price: $0.5872058517385322
# Shares owned at the moment: 163
# Cash capital at the moment: $0.20017608640165463
#
#
# Price increase from previously bought: -57.71708658825574%
# Share price: $0.24897053312935702
# Shares owned at the moment: 0
# Cash capital at the moment: $40.670771945011616
#
#
# Share price: $0.22691173086890348
# Shares owned at the moment: 178
# Cash capital at the moment: $0.16941055808646865
#
#
# Price increase from previously bought: -26.126656165451678%
# Share price: $0.16808825817436068
# Shares owned at the moment: 0
# Cash capital at the moment: $30.006841310746317
#
#
# Share price: $0.09455882965229377
# Shares owned at the moment: 316
# Cash capital at the moment: $0.044079517653639044
#
#
# Price increase from previously bought: -50.67999419005837%
# Share price: $0.04676467043408949
# Shares owned at the moment: 0
# Cash capital at the moment: $14.781076876218693
#
#
# Share price: $0.09088236260888481
# Shares owned at the moment: 162
# Cash capital at the moment: $0.017646041037094662
#
#
# Price increase from previously bought: 201.4363984288891%
# Share price: $0.2747058900871079
# Shares owned at the moment: 0
# Cash capital at the moment: $44.397618761114764
#
#
#
#
# Capital at the end of test period: $44.397618761114764
# profit gained: -55.602381238885236%
#
#
# Capital at the end of test period if Buy and Hold: $26.129427230180067
# profit gained: -73.87057276981993%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.775229         3.125           20.0      92.265193
# 1       0.788991         0.000           20.0      93.333333
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         38.709677                40.0          72.928177     -96.519581
# 1         50.000000                65.0          81.005587     -55.602381
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1128 - accuracy: 0.8219 - mse: 2.1165 - weighted_accuracy: 0.8219 - weighted_mse: 2.1165
# Test loss: 0.11278833448886871
# Test accuracy: 0.8219178318977356
#
#
# number of predictions: 219
# actual predicted buys: 0
# actual buys but predicted sell: 0
# actual buys but predicted hold: 8
# actual sells but predicted buy: 0
# actual predicted sells: 2
# actual sells but predicted hold: 9
# actual holds but predicted buy: 8
# actual holds but predicted sell: 14
# actual predicted holds: 178
# Percentage buys correct: 0.0%
# Percentage sells correct: 12.5%
# Percentage holds correct: 91.28205128205128%
# actual buys: 8
# actual sells: 11
# actual holds: 200
#
#
# Percentage low buys correct: 62.5%
# Percentage high sells correct: 43.75%
# Percentage mid holds correct: 86.08247422680412%
#
#
# Capital: 100
# Share price: $0.17049382196924323
# Shares owned at the moment: 584
# Cash capital at the moment: $0.15779489187934814
#
#
# Price increase from previously bought: 78.54077462518707%
# Share price: $0.3052380931556622
# Shares owned at the moment: 0
# Cash capital at the moment: $177.92662891717808
#
#
# Share price: $0.7419223909950073
# Shares owned at the moment: 239
# Cash capital at the moment: $0.11954897788984908
#
#
# Price increase from previously bought: 2.0015673215674212%
# Share price: $0.7588535914091475
# Shares owned at the moment: 0
# Cash capital at the moment: $180.98680080172244
#
#
# Share price: $0.5779012440159778
# Shares owned at the moment: 312
# Cash capital at the moment: $0.18577340137167653
#
#
# Price increase from previously bought: -23.22209729204956%
# Share price: $0.44492063112953883
# Shares owned at the moment: 0
# Cash capital at the moment: $138.61926841227864
#
#
# Share price: $0.3133509516109448
# Shares owned at the moment: 441
# Cash capital at the moment: $0.05148238528582283
#
#
# Price increase from previously bought: 7.1348924742381525%
# Share price: $0.33663140263934505
# Shares owned at the moment: 0
# Cash capital at the moment: $148.09768121568612
#
#
# Share price: $0.2928924009575395
# Shares owned at the moment: 504
# Cash capital at the moment: $0.07396226535908568
#
#
#
#
# Capital at the end of test period: $130.08877380749362
# profit gained: 30.088773807493624%
#
#
# Capital at the end of test period if Buy and Hold: $2186.7819938452512
# profit gained: 2086.7819938452512%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.780822           0.0       5.882353      92.391304
# 1       0.821918           0.0      12.500000      91.282051
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         33.333333           47.058824          83.606557     602.260829
# 1         62.500000           43.750000          86.082474      30.088774
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
#
#
# Non-Recession
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1172 - accuracy: 0.7890 - mse: 2.0458 - weighted_accuracy: 0.7890 - weighted_mse: 2.0458
# Test loss: 0.11717282235622406
# Test accuracy: 0.78899085521698
#
#
# number of predictions: 218
# actual predicted buys: 3
# actual buys but predicted sell: 0
# actual buys but predicted hold: 6
# actual sells but predicted buy: 1
# actual predicted sells: 1
# actual sells but predicted hold: 6
# actual holds but predicted buy: 25
# actual holds but predicted sell: 8
# actual predicted holds: 168
# Percentage buys correct: 10.344827586206897%
# Percentage sells correct: 11.11111111111111%
# Percentage holds correct: 93.33333333333333%
# actual buys: 9
# actual sells: 8
# actual holds: 201
#
#
# Percentage low buys correct: 31.03448275862069%
# Percentage high sells correct: 55.55555555555556%
# Percentage mid holds correct: 84.91620111731844%
#
#
# Capital: 100
# Share price: $0.2657677984970155
# Shares owned at the moment: 375
# Cash capital at the moment: $0.06300252141915053
#
#
# Price increase from previously bought: -20.753532057624124%
# Share price: $0.21119077511849751
# Shares owned at the moment: 0
# Cash capital at the moment: $79.04175270401477
#
#
# Share price: $0.191344578346717
# Shares owned at the moment: 411
# Cash capital at the moment: $0.18286379383771134
#
#
# Price increase from previously bought: -5.446000880568258%
# Share price: $0.18142149179007902
# Shares owned at the moment: 0
# Cash capital at the moment: $74.54204527846446
#
#
# Share price: $0.08144629418330708
# Shares owned at the moment: 912
# Cash capital at the moment: $0.05875767747666316
#
#
# Price increase from previously bought: -35.50981682942168%
# Share price: $0.05266930768130009
# Shares owned at the moment: 0
# Cash capital at the moment: $47.961071659157646
#
#
# Share price: $0.04547506401311146
# Shares owned at the moment: 1051
# Cash capital at the moment: $0.035345077613605724
#
#
# Price increase from previously bought: -12.242849313604399%
# Share price: $0.04001736640696057
# Shares owned at the moment: 0
# Cash capital at the moment: $41.97793697807145
#
#
# Share price: $0.03381543139443569
# Shares owned at the moment: 1237
# Cash capital at the moment: $0.03321669940847727
#
#
# Price increase from previously bought: 147.5109614098502%
# Share price: $0.08392706582246655
# Shares owned at the moment: 0
# Cash capital at the moment: $103.56549822563801
#
#
# Share price: $0.055894316726833614
# Shares owned at the moment: 1847
# Cash capital at the moment: $0.04479402294155932
#
#
# Price increase from previously bought: -14.437957960261528%
# Share price: $0.047955835652270955
# Shares owned at the moment: 0
# Cash capital at the moment: $88.37564279444922
#
#
#
#
# Capital at the end of test period: $88.37564279444922
# profit gained: -11.62435720555078%
#
#
# Capital at the end of test period if Buy and Hold: $2.3797176202777375
# profit gained: -97.62028237972227%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.775229      3.125000      20.000000      92.265193
# 1       0.788991      0.000000      20.000000      93.333333
# 2       0.788991     10.344828      11.111111      93.333333
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         38.709677           40.000000          72.928177     -96.519581
# 1         50.000000           65.000000          81.005587     -55.602381
# 2         31.034483           55.555556          84.916201     -11.624357
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
# 2         -97.620282
#
#
# Recession
#
#
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1152 - accuracy: 0.7945 - mse: 2.1325 - weighted_accuracy: 0.7945 - weighted_mse: 2.1325
# Test loss: 0.11516960710287094
# Test accuracy: 0.7945205569267273
#
#
# number of predictions: 219
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 0
# actual predicted sells: 2
# actual sells but predicted hold: 8
# actual holds but predicted buy: 8
# actual holds but predicted sell: 22
# actual predicted holds: 171
# Percentage buys correct: 11.11111111111111%
# Percentage sells correct: 8.333333333333334%
# Percentage holds correct: 91.93548387096774%
# actual buys: 8
# actual sells: 10
# actual holds: 201
#
#
# Percentage low buys correct: 100.0%
# Percentage high sells correct: 45.833333333333336%
# Percentage mid holds correct: 85.94594594594595%
#
#
# Capital: 100
# Share price: $0.01600233241179641
# Shares owned at the moment: 6231
# Cash capital at the moment: $0.015262775637324921
#
#
# Price increase from previously bought: 164.6037027610829%
# Share price: $0.04245920669099701
# Shares owned at the moment: 0
# Cash capital at the moment: $263.8510305457878
#
#
# Share price: $0.07072261305703781
# Shares owned at the moment: 3720
# Cash capital at the moment: $0.039417642033697575
#
#
# Price increase from previously bought: 325.37930945359597%
# Share price: $0.3016666712979524
# Shares owned at the moment: 0
# Cash capital at the moment: $1119.1533848230383
#
#
# Share price: $0.6288811425881197
# Shares owned at the moment: 1774
# Cash capital at the moment: $0.4502412175979771
#
#
# Price increase from previously bought: 6.212970667917039%
# Share price: $0.6697902152078423
# Shares owned at the moment: 0
# Cash capital at the moment: $1185.3905114314186
#
#
# Share price: $0.581037323590531
# Shares owned at the moment: 2034
# Cash capital at the moment: $0.31056297877512407
#
#
# Price increase from previously bought: 6.047005912983816%
# Share price: $0.6178671597881812
# Shares owned at the moment: 0
# Cash capital at the moment: $1253.5963260296605
#
#
# Share price: $0.6697319721592003
# Shares owned at the moment: 1866
# Cash capital at the moment: $0.4397363654577475
#
#
#
#
# Capital at the end of test period: $1298.0159922565401
# profit gained: 1198.0159922565401%
#
#
# Capital at the end of test period if Buy and Hold: $5902.379195330377
# profit gained: 5802.379195330377%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.780822      0.000000       5.882353      92.391304
# 1       0.821918      0.000000      12.500000      91.282051
# 2       0.794521     11.111111       8.333333      91.935484
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         33.333333           47.058824          83.606557     602.260829
# 1         62.500000           43.750000          86.082474      30.088774
# 2        100.000000           45.833333          85.945946    1198.015992
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
# 2        5802.379195

# %%
Vaxart_data_acc = []
Inovio_data_acc = []
Novavax_data_acc = []

Vaxart_data_correct_buys = []
Inovio_data_correct_buys = []
Novavax_data_correct_buys = []

Vaxart_data_correct_sells = []
Inovio_data_correct_sells = []
Novavax_data_correct_sells = []

Vaxart_data_correct_holds = []
Inovio_data_correct_holds = []
Novavax_data_correct_holds = []

Vaxart_data_correct_low_buys = []
Inovio_data_correct_low_buys = []
Novavax_data_correct_low_buys = []

Vaxart_data_correct_high_sells = []
Inovio_data_correct_high_sells = []
Novavax_data_correct_high_sells = []

Vaxart_data_correct_mid_holds = []
Inovio_data_correct_mid_holds = []
Novavax_data_correct_mid_holds = []

Vaxart_data_profit = []
Inovio_data_profit = []
Novavax_data_profit = []

for key,value in nr_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    Vaxart_data_acc.append(acc[0])
    Inovio_data_acc.append(acc[1])
    Novavax_data_acc.append(acc[2])
    
    Vaxart_data_correct_buys.append(correct_buys[0])
    Inovio_data_correct_buys.append(correct_buys[1]) 
    Novavax_data_correct_buys.append(correct_buys[2]) 

    Vaxart_data_correct_sells.append(correct_sells[0]) 
    Inovio_data_correct_sells.append(correct_sells[1]) 
    Novavax_data_correct_sells.append(correct_sells[2]) 

    Vaxart_data_correct_holds.append(correct_holds[0]) 
    Inovio_data_correct_holds.append(correct_holds[1])  
    Novavax_data_correct_holds.append(correct_holds[2])  

    Vaxart_data_correct_low_buys.append(correct_low_buys[0])  
    Inovio_data_correct_low_buys.append(correct_low_buys[1])  
    Novavax_data_correct_low_buys.append(correct_low_buys[2])  

    Vaxart_data_correct_high_sells.append(correct_high_sells[0]) 
    Inovio_data_correct_high_sells.append(correct_high_sells[1]) 
    Novavax_data_correct_high_sells.append(correct_high_sells[2]) 

    Vaxart_data_correct_mid_holds.append(correct_mid_holds[0])  
    Inovio_data_correct_mid_holds.append(correct_mid_holds[1])  
    Novavax_data_correct_mid_holds.append(correct_mid_holds[2])   

    Vaxart_data_profit.append(profit[0]) 
    Inovio_data_profit.append(profit[1]) 
    Novavax_data_profit.append(profit[2])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(Vaxart_data_acc)
plt.plot(Inovio_data_acc)
plt.plot(Novavax_data_acc)

plt.title('Non-Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Vaxart_data_acc','Inovio_data_acc','Novavax_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_profit")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_profit")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_profit")
# Out:
# Text(0.5, 1.0, 'Novavax_data_profit')

# %%
Vaxart_data_acc = []
Inovio_data_acc = []
Novavax_data_acc = []

Vaxart_data_correct_buys = []
Inovio_data_correct_buys = []
Novavax_data_correct_buys = []

Vaxart_data_correct_sells = []
Inovio_data_correct_sells = []
Novavax_data_correct_sells = []

Vaxart_data_correct_holds = []
Inovio_data_correct_holds = []
Novavax_data_correct_holds = []

Vaxart_data_correct_low_buys = []
Inovio_data_correct_low_buys = []
Novavax_data_correct_low_buys = []

Vaxart_data_correct_high_sells = []
Inovio_data_correct_high_sells = []
Novavax_data_correct_high_sells = []

Vaxart_data_correct_mid_holds = []
Inovio_data_correct_mid_holds = []
Novavax_data_correct_mid_holds = []

Vaxart_data_profit = []
Inovio_data_profit = []
Novavax_data_profit = []

for key,value in r_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    Vaxart_data_acc.append(acc[0])
    Inovio_data_acc.append(acc[1])
    Novavax_data_acc.append(acc[2])
    
    Vaxart_data_correct_buys.append(correct_buys[0])
    Inovio_data_correct_buys.append(correct_buys[1]) 
    Novavax_data_correct_buys.append(correct_buys[2]) 

    Vaxart_data_correct_sells.append(correct_sells[0]) 
    Inovio_data_correct_sells.append(correct_sells[1]) 
    Novavax_data_correct_sells.append(correct_sells[2]) 

    Vaxart_data_correct_holds.append(correct_holds[0]) 
    Inovio_data_correct_holds.append(correct_holds[1])  
    Novavax_data_correct_holds.append(correct_holds[2])  

    Vaxart_data_correct_low_buys.append(correct_low_buys[0])  
    Inovio_data_correct_low_buys.append(correct_low_buys[1])  
    Novavax_data_correct_low_buys.append(correct_low_buys[2])  

    Vaxart_data_correct_high_sells.append(correct_high_sells[0]) 
    Inovio_data_correct_high_sells.append(correct_high_sells[1]) 
    Novavax_data_correct_high_sells.append(correct_high_sells[2]) 

    Vaxart_data_correct_mid_holds.append(correct_mid_holds[0])  
    Inovio_data_correct_mid_holds.append(correct_mid_holds[1])  
    Novavax_data_correct_mid_holds.append(correct_mid_holds[2])   

    Vaxart_data_profit.append(profit[0]) 
    Inovio_data_profit.append(profit[1]) 
    Novavax_data_profit.append(profit[2])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(Vaxart_data_acc)
plt.plot(Inovio_data_acc)
plt.plot(Novavax_data_acc)

plt.title('Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Vaxart_data_acc','Inovio_data_acc','Novavax_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_profit")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_profit")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_profit")
# Out:
# Text(0.5, 1.0, 'Novavax_data_profit')

# %% [markdown]
# ## Train Novavax, Inc Stock Data

# %%
def profit(predictions, price, logger):
    
    price = np.array([price]).reshape(-1, 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    price = min_max_scaler.fit_transform(price)
    price = price.flatten().tolist()
    price = [x + 0.01 for x in price]
    
#     avg_price = sum(price) / len(price)
#     avg_price = int(avg_price)
#     print("Avg price of stocks: " + str(avg_price))
    
#     tens = 1
#     while avg_price >= 10:
#         avg_price /= 10
#         tens += 1
    
    
#     capital = 100*pow(10,tens-1)
    capital = 100
    print("Capital: " + str(capital))
    shares = 0

    previously_buy = False
    previously_sell = False
    prev_buy_price = 0
    bought_once = False


#     predictions = df['predictions'].values.tolist()
#     price = df['previous_1d'].values.tolist()

    for i in range(0,len(predictions)):

#         if  bought_once==True and (1-price[i]/prev_buy_price)*100 >= 5 and shares!=0:
#             capital += 0.99725 * (shares*price[i])
#             shares = 0
#             print("Stop Loss Activated!\n")
#             print("Share price: $" + str(price[i]))
#             print("Shares owned at the moment: " + str(shares))
#             print("Cash capital at the moment: $" + str(capital))
#             print("\n")
#             previously_buy = False
#             previously_sell = True

        if predictions[i] == 1 and previously_buy != True:
            shares = math.floor(capital / (price[i]*1.00275))
            capital = capital - shares*price[i]*1.00275
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            prev_buy_price = price[i]*1.00275
            bought_once = True
            previously_buy = True
            previously_sell = False

        elif predictions[i] == 0 and previously_sell != True and shares!=0: #and (price[i]/prev_buy_price-1)*100 >= 2
            capital += 0.99725 * (shares*price[i])
            shares = 0
            print("Price increase from previously bought: " + str((price[i]/prev_buy_price-1)*100 ) + '%')
            print("Share price: $" + str(price[i]))
            print("Shares owned at the moment: " + str(shares))
            print("Cash capital at the moment: $" + str(capital))
            print("\n")
            previously_buy = False
            previously_sell = True

    if shares!=0:
        capital += 0.99725 * (shares*price[i])

    print('\n')
    print("Capital at the end of test period: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100)
    
    capital = 100
    shares = 0

    shares = math.floor(capital / (price[0]*1.00275))
    capital = capital - shares*price[0]*1.00275
    capital += 0.99725 * (shares*price[-1])

    print('\n')
    print("Capital at the end of test period if Buy and Hold: $" +str(capital))
    print("profit gained: " + str(((capital- 100 )/ 100) * 100 ) + '%') 
    logger.append(((capital- 100 )/ 100) * 100 )
    
    return logger

# %%
willr_data = []
price_data = []
ema_data = []
obv_data = []
labels = []

seed = 10
df = pd.read_csv('variation 7/initial_indicators/NVAX_data.csv')
df.set_index('Date', inplace=True)
print(df.head())

plt.figure(figsize=(15,5))
plt.plot(df['previous_1d'].values)
plt.plot(df['EMA_12'].values)
plt.show()

data_15_price = []
data_15_willr = []
data_15_ema = []
data_15_obv = []
count = 0

for i in df.values:
    if count == 14:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        min_max_scaler = preprocessing.MinMaxScaler()
        data_15_price_arr = min_max_scaler.fit_transform(data_15_price)
        data_15_ema_arr = min_max_scaler.fit_transform(data_15_ema)
        data_15_willr_arr = min_max_scaler.fit_transform(data_15_willr)
        data_15_obv_arr = min_max_scaler.fit_transform(data_15_obv)
        price_data.append(data_15_price_arr)
        willr_data.append(data_15_willr_arr)
        ema_data.append(data_15_ema_arr)
        obv_data.append(data_15_obv_arr)
        labels.append(i[-1])
        data_15_price = data_15_price[1:]
        data_15_willr = data_15_willr[1:]
        data_15_obv = data_15_obv[1:]
        data_15_ema = data_15_ema[1:]

    else:
        data_15_price.append([i[0]])
        data_15_ema.append([i[1]])
        data_15_willr.append([i[2]])
        data_15_obv.append([i[3]])
        count += 1
        
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)

import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()
    
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
y = np.array(y)

X.shape
# Out:
#             previous_1d      EMA_12   willr_14    OBV_7  labels
# Date
# 2000-01-21       123.75  111.044132  -0.000000    330.0     0.0
# 2000-01-24       145.00  116.268112  -9.090909  10530.0     2.0
# 2000-01-25       130.00  118.380710 -36.363636   6930.0     2.0
# 2000-01-26       132.50  120.552908 -31.818182   9665.0     2.0
# 2000-01-27       140.00  123.544769 -18.181818  11870.0     2.0
# (4745, 64, 64, 1)

# %%
willr_data = np.array(willr_data)
price_data = np.array(price_data)
ema_data = np.array(ema_data)
obv_data = np.array(obv_data)
obv_data.shape
# Out:
# (4745, 15, 1)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

sequential_data = []
    
for i in range(0,len(willr_data)):
    j = willr_data[i]
    k = price_data[i]
    l = ema_data[i]
    m = obv_data[i]
    fig, ax = plt.subplots()
    fig.set_size_inches((5,5))

    ax.plot(k)
    ax.plot(j)
    ax.plot(l)
    ax.plot(m)

    ax.axis('off')

    fig.add_axes(ax)
    fig.canvas.draw()

    # this rasterized the figure
    X = np.array(fig.canvas.renderer._renderer)
    X = 0.2989*X[:,:,1] + 0.5870*X[:,:,2] + 0.1140*X[:,:,3]
    X = cv2.resize(X, dsize=(64, 64), interpolation=cv2.INTER_CUBIC)
    sequential_data.append(X)
    plt.close()

# %%
X = sequential_data
y = labels

X  = np.array(X).reshape(-1, 64, 64, 1)
y = np.array(y)

X.shape
# Out:
# (4745, 64, 64, 1)

# %%
from collections import Counter

Counter(y)
# Out:
# Counter({2.0: 4319, 0.0: 208, 1.0: 218})

# %%
# plot the image array X
i = X[0].reshape(64, 64)
fig2, ax2 = plt.subplots()
plt.imshow(i, interpolation="none", cmap="gray")

ax2.axis('off')

plt.show()

# %%
X = X/255

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X,
                                                                    y,
                                                                    test_size = 0.2,
                                                                    random_state=seed,stratify=y)

# %%
import time

SEQ_LEN = 15  # how long of a preceeding sequence to collect for RNN
FUTURE_PERIOD_PREDICT = 1  # how far into the future are we trying to predict?
EPOCHS = 200  # how many passes through our data
BATCH_SIZE = 128  # how many batches? Try smaller batch if you're getting OOM (out of memory) errors.
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"  # a unique name for the model

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, 3)
y_test = to_categorical(y_test, 3)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten,BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.regularizers import l2
import efficientnet.tfkeras as efn
import pickle
import time
import random

seed = 10
os.environ['PYTHONHASHSEED']=str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

model = Sequential()

model.add(Conv2D(16, (3, 3), padding='same', kernel_initializer='he_uniform',kernel_regularizer=l2(1e-5), input_shape=X_train.shape[1:]))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))

model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_uniform',kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2), padding='valid'))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

# model.add(Dense(128, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
# model.add(Activation('relu'))
# model.add(Dropout(0.25, seed=seed))

model.add(Dense(64, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))
model.add(Dropout(0.25, seed=seed))

model.add(Dense(32, kernel_initializer='he_uniform', kernel_regularizer=l2(1e-5)))
model.add(Activation('relu'))
model.add(Dropout(0.25, seed=seed))

model.add(Dense(3, use_bias=True, activation=None))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import tensorflow_addons as tfa

opt = tf.keras.optimizers.Adam(lr=1e-4)

# Compile model
model.compile(
    loss=tfa.losses.SigmoidFocalCrossEntropy(from_logits=True,reduction=tf.keras.losses.Reduction.AUTO),
    optimizer=opt,
    metrics=['accuracy','mse'],
    weighted_metrics=['accuracy','mse']
)

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

filepath = "DBS_CNN_Final-{epoch:02d}-{val_accuracy:.3f}"  # unique file name that will include the epoch and the validation acc for that epoch
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')) # saves only the best ones

train_x = X_train
train_y = y_train
validation_x = X_test
validation_y = y_test

y_integers = np.argmax(train_y, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))
print(d_class_weights)

epochs = 0 
histories = {}
nr_log_hist = {}
r_log_hist = {}

while epochs < 200:
    
    print('\n\n')
    print("RUNNING EPOCHS {} - {}".format(epochs,epochs+20))
    print('\n\n')
    
    column_names = ["Test_accuracy","correct_buys","correct_sells","correct_holds","correct_low_buys","correct_high_sells","correct_mid_holds","Profit gained","buy_n_hold profit"]
    nr_log  = pd.DataFrame(columns = column_names)
    r_log  = pd.DataFrame(columns = column_names)
    logger = []

    # Train model
    histories['epochs{}-{}'.format(epochs,epochs+20)] = model.fit(
        train_x, train_y,
        batch_size=BATCH_SIZE,
        epochs=20,
        validation_data=(validation_x, validation_y),
        shuffle=True,
        callbacks=[tensorboard],
        class_weight=d_class_weights
    )
    
    score = model.evaluate(validation_x, validation_y, verbose=0)
    print('Validation loss:', score[0])
    print('Validation accuracy:', score[1])
    
    test_sets = ['VXRT','INO','NVAX']
    for name in test_sets:
        
        print('\n')
        print("Non-Recession")
        print('\n')
        
        X = nr_test_data['{}_X'.format(name)]
        y = nr_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("variation 7/initial_indicators/{}_data_test.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(nr_log)
        nr_log.loc[df_length] = logger
        print(nr_log.head(20))
        logger = []
        
        print('\n')
        print("Recession")
        print('\n')
        
        X = r_test_data['{}_X'.format(name)]
        y = r_test_data['{}_y'.format(name)]

        score = model.evaluate(X, y)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])
        print('\n')
        logger.append(score[1]) 
        
        predictions = model.predict(X)
        predictions = [np.argmax(y, axis=None, out=None) for y in predictions]
        actual = [np.argmax(i, axis=None, out=None) for i in y]
        
        df = pd.read_csv("variation 7/initial_indicators/{}_data_test2.csv".format(name))
        df.set_index('Date', inplace=True)
        df = df.iloc[14:]
        df['predictions'] = predictions
        df['actual'] = actual
        df['previous_1d'] = df['previous_1d'].shift(-1)
        df.dropna(inplace=True)
        
        prediction = df['predictions'].values.tolist()
        price = df['previous_1d'].values.tolist()
        
        logger = pred_acc(actual, predictions, logger)
        print('\n')
        logger = correct_maxima_minima(prediction, price, logger)
        print('\n')
        logger = profit(prediction, price, logger)
        
        df_length = len(r_log)
        r_log.loc[df_length] = logger
        print(r_log.head(20))
        logger = []

    nr_log.to_csv('{}_{}_{}epochs.csv'.format(experiment,'NovavaxModel',epochs))
    nr_log_hist['{}_epochs_logs'.format(epochs)] = nr_log
    r_log.to_csv('{}_{}_{}epochs.csv'.format(experiment,'NovavaxModel',epochs))
    r_log_hist['{}_epochs_logs'.format(epochs)] = r_log
    epochs = epochs + 20
# Out:
# C:\Users\Shearman Chua\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass classes=[0 1 2], y=[2 2 2 ... 0 2 2] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# {0: 7.57684630738523, 1: 7.272030651340996, 2: 0.36623251326579837}
#
#
#
# RUNNING EPOCHS 0 - 20
#
#
#
# Epoch 1/20
#  2/30 [=>............................] - ETA: 9s - loss: 0.4316 - accuracy: 0.5859 - mse: 4.4415 - weighted_accuracy: 0.3527 - weighted_mse: 5.5128WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0069s vs `on_train_batch_end` time: 0.6981s). Check your callbacks.
# 30/30 [==============================] - 1s 40ms/step - loss: 0.2521 - accuracy: 0.3970 - mse: 1.5810 - weighted_accuracy: 0.3026 - weighted_mse: 1.7209 - val_loss: 0.2161 - val_accuracy: 0.0485 - val_mse: 0.9019 - val_weighted_accuracy: 0.0485 - val_weighted_mse: 0.9019
# Epoch 2/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2057 - accuracy: 0.3938 - mse: 1.1614 - weighted_accuracy: 0.3601 - weighted_mse: 1.1973 - val_loss: 0.2119 - val_accuracy: 0.0432 - val_mse: 0.8710 - val_weighted_accuracy: 0.0432 - val_weighted_mse: 0.8710
# Epoch 3/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2038 - accuracy: 0.3103 - mse: 1.1761 - weighted_accuracy: 0.3319 - weighted_mse: 1.1793 - val_loss: 0.2085 - val_accuracy: 0.0432 - val_mse: 0.8313 - val_weighted_accuracy: 0.0432 - val_weighted_mse: 0.8313
# Epoch 4/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2040 - accuracy: 0.3936 - mse: 1.1657 - weighted_accuracy: 0.3485 - weighted_mse: 1.1799 - val_loss: 0.2149 - val_accuracy: 0.0432 - val_mse: 0.9318 - val_weighted_accuracy: 0.0432 - val_weighted_mse: 0.9318
# Epoch 5/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2039 - accuracy: 0.3172 - mse: 1.1375 - weighted_accuracy: 0.3052 - weighted_mse: 1.1620 - val_loss: 0.1968 - val_accuracy: 0.4036 - val_mse: 0.9369 - val_weighted_accuracy: 0.4036 - val_weighted_mse: 0.9369
# Epoch 6/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2011 - accuracy: 0.3464 - mse: 1.1715 - weighted_accuracy: 0.3564 - weighted_mse: 1.1734 - val_loss: 0.2088 - val_accuracy: 0.0443 - val_mse: 1.0172 - val_weighted_accuracy: 0.0443 - val_weighted_mse: 1.0172
# Epoch 7/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2006 - accuracy: 0.2761 - mse: 1.1964 - weighted_accuracy: 0.3446 - weighted_mse: 1.1919 - val_loss: 0.1989 - val_accuracy: 0.1928 - val_mse: 0.8933 - val_weighted_accuracy: 0.1928 - val_weighted_mse: 0.8933
# Epoch 8/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2019 - accuracy: 0.3472 - mse: 1.2109 - weighted_accuracy: 0.3595 - weighted_mse: 1.2049 - val_loss: 0.2181 - val_accuracy: 0.0432 - val_mse: 0.8863 - val_weighted_accuracy: 0.0432 - val_weighted_mse: 0.8863
# Epoch 9/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2016 - accuracy: 0.4025 - mse: 1.1511 - weighted_accuracy: 0.3503 - weighted_mse: 1.1688 - val_loss: 0.1988 - val_accuracy: 0.3572 - val_mse: 0.8528 - val_weighted_accuracy: 0.3572 - val_weighted_mse: 0.8528
# Epoch 10/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2008 - accuracy: 0.3309 - mse: 1.1767 - weighted_accuracy: 0.3619 - weighted_mse: 1.1781 - val_loss: 0.1991 - val_accuracy: 0.0664 - val_mse: 0.9244 - val_weighted_accuracy: 0.0664 - val_weighted_mse: 0.9244
# Epoch 11/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2006 - accuracy: 0.2829 - mse: 1.1790 - weighted_accuracy: 0.3488 - weighted_mse: 1.1755 - val_loss: 0.2038 - val_accuracy: 0.0580 - val_mse: 0.8933 - val_weighted_accuracy: 0.0580 - val_weighted_mse: 0.8933
# Epoch 12/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2012 - accuracy: 0.3543 - mse: 1.1568 - weighted_accuracy: 0.3687 - weighted_mse: 1.1782 - val_loss: 0.1924 - val_accuracy: 0.8556 - val_mse: 0.8116 - val_weighted_accuracy: 0.8556 - val_weighted_mse: 0.8116
# Epoch 13/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2014 - accuracy: 0.4181 - mse: 1.1605 - weighted_accuracy: 0.3595 - weighted_mse: 1.1694 - val_loss: 0.1991 - val_accuracy: 0.0822 - val_mse: 0.9035 - val_weighted_accuracy: 0.0822 - val_weighted_mse: 0.9035
# Epoch 14/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1993 - accuracy: 0.3066 - mse: 1.1927 - weighted_accuracy: 0.3949 - weighted_mse: 1.1658 - val_loss: 0.2061 - val_accuracy: 0.0695 - val_mse: 1.0063 - val_weighted_accuracy: 0.0695 - val_weighted_mse: 1.0063
# Epoch 15/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2031 - accuracy: 0.3274 - mse: 1.1614 - weighted_accuracy: 0.3524 - weighted_mse: 1.1840 - val_loss: 0.1919 - val_accuracy: 0.4668 - val_mse: 0.9428 - val_weighted_accuracy: 0.4668 - val_weighted_mse: 0.9428
# Epoch 16/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2005 - accuracy: 0.4089 - mse: 1.1845 - weighted_accuracy: 0.3638 - weighted_mse: 1.1646 - val_loss: 0.1928 - val_accuracy: 0.3182 - val_mse: 1.0227 - val_weighted_accuracy: 0.3182 - val_weighted_mse: 1.0227
# Epoch 17/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1979 - accuracy: 0.2819 - mse: 1.2253 - weighted_accuracy: 0.3926 - weighted_mse: 1.2264 - val_loss: 0.1996 - val_accuracy: 0.1370 - val_mse: 0.8579 - val_weighted_accuracy: 0.1370 - val_weighted_mse: 0.8579
# Epoch 18/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1980 - accuracy: 0.2432 - mse: 1.1856 - weighted_accuracy: 0.3867 - weighted_mse: 1.1647 - val_loss: 0.2017 - val_accuracy: 0.0706 - val_mse: 1.0118 - val_weighted_accuracy: 0.0706 - val_weighted_mse: 1.0118
# Epoch 19/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1964 - accuracy: 0.3030 - mse: 1.1961 - weighted_accuracy: 0.4117 - weighted_mse: 1.2038 - val_loss: 0.1929 - val_accuracy: 0.3056 - val_mse: 0.9037 - val_weighted_accuracy: 0.3056 - val_weighted_mse: 0.9037
# Epoch 20/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1963 - accuracy: 0.3222 - mse: 1.2097 - weighted_accuracy: 0.4114 - weighted_mse: 1.2087 - val_loss: 0.2029 - val_accuracy: 0.0717 - val_mse: 0.9894 - val_weighted_accuracy: 0.0717 - val_weighted_mse: 0.9894
# Validation loss: 0.2028852254152298
# Validation accuracy: 0.07165437191724777
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2042 - accuracy: 0.0550 - mse: 0.9796 - weighted_accuracy: 0.0550 - weighted_mse: 0.9796
# Test loss: 0.20415815711021423
# Test accuracy: 0.055045872926712036
#
#
# number of predictions: 218
# actual predicted buys: 7
# actual buys but predicted sell: 1
# actual buys but predicted hold: 0
# actual sells but predicted buy: 3
# actual predicted sells: 5
# actual sells but predicted hold: 0
# actual holds but predicted buy: 134
# actual holds but predicted sell: 68
# actual predicted holds: 0
# Percentage buys correct: 4.861111111111111%
# Percentage sells correct: 6.756756756756757%
# Percentage holds correct: 0%
# actual buys: 8
# actual sells: 8
# actual holds: 202
#
#
# Percentage low buys correct: 48.25174825174825%
# Percentage high sells correct: 58.108108108108105%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.7964077880589524
# Shares owned at the moment: 125
# Cash capital at the moment: $0.17526131548568458
#
#
# Price increase from previously bought: -13.647200303025608%
# Share price: $0.6896116531541341
# Shares owned at the moment: 0
# Cash capital at the moment: $86.1396639539807
#
#
# Share price: $0.7769903300284726
# Shares owned at the moment: 110
# Cash capital at the moment: $0.4356880760150972
#
#
# Price increase from previously bought: -70.05610531313961%
# Share price: $0.2333009843577296
# Shares owned at the moment: 0
# Cash capital at the moment: $26.028222807597142
#
#
# Share price: $0.24786407788058956
# Shares owned at the moment: 104
# Cash capital at the moment: $0.17946958174197647
#
#
# Price increase from previously bought: -4.180460598687363%
# Share price: $0.23815534886534961
# Shares owned at the moment: 0
# Cash capital at the moment: $24.87951343396285
#
#
# Share price: $0.22359225534248967
# Shares owned at the moment: 110
# Cash capital at the moment: $0.21672868904788345
#
#
# Price increase from previously bought: -19.760395817972466%
# Share price: $0.17990291690532034
# Shares owned at the moment: 0
# Cash capital at the moment: $19.95162891626926
#
#
# Share price: $0.21873786190057493
# Shares owned at the moment: 90
# Cash capital at the moment: $0.21108372439712753
#
#
# Price increase from previously bought: 1.9389423404047035%
# Share price: $0.22359225534248967
# Shares owned at the moment: 0
# Cash capital at the moment: $20.27904762202393
#
#
# Share price: $0.21388349739295492
# Shares owned at the moment: 94
# Cash capital at the moment: $0.1187099830100884
#
#
# Price increase from previously bought: -7.064463406946075%
# Share price: $0.19932040387009503
# Shares owned at the moment: 0
# Cash capital at the moment: $18.803303622398598
#
#
# Share price: $0.1896116459205603
# Shares owned at the moment: 98
# Cash capital at the moment: $0.17026198360809985
#
#
# Price increase from previously bought: -2.8273862664783045%
# Share price: $0.18475728141294034
# Shares owned at the moment: 0
# Cash capital at the moment: $18.226683474735466
#
#
# Share price: $0.19446603936247508
# Shares owned at the moment: 93
# Cash capital at the moment: $0.09160712445833141
#
#
# Price increase from previously bought: 9.683383038201733%
# Share price: $0.21388349739295492
# Shares owned at the moment: 0
# Cash capital at the moment: $19.928071677544892
#
#
# Share price: $0.20902913288533498
# Shares owned at the moment: 95
# Cash capital at the moment: $0.015695192471774533
#
#
# Price increase from previously bought: 13.621586851616495%
# Share price: $0.23815534886534961
# Shares owned at the moment: 0
# Cash capital at the moment: $22.578235249788918
#
#
# Share price: $0.1896116459205603
# Shares owned at the moment: 118
# Cash capital at the moment: $0.1425320520615827
#
#
# Price increase from previously bought: -71.76223908549326%
# Share price: $0.05368932397002193
# Shares owned at the moment: 0
# Cash capital at the moment: $6.460450094895898
#
#
# Share price: $0.0585436884776419
# Shares owned at the moment: 110
# Cash capital at the moment: $0.0029348965908022606
#
#
# Price increase from previously bought: -25.081649751136503%
# Share price: $0.043980580487634584
# Shares owned at the moment: 0
# Cash capital at the moment: $4.827494624633097
#
#
# Share price: $0.0585436884776419
# Shares owned at the moment: 82
# Cash capital at the moment: $0.013710567714752209
#
#
# Price increase from previously bought: -25.081649751136503%
# Share price: $0.043980580487634584
# Shares owned at the moment: 0
# Cash capital at the moment: $3.6102005468008262
#
#
# Share price: $0.03912621598001464
# Shares owned at the moment: 92
# Cash capital at the moment: $0.0006897439965354302
#
#
# Price increase from previously bought: 12.098664498214262%
# Share price: $0.043980580487634584
# Shares owned at the moment: 0
# Cash capital at the moment: $4.035776061995545
#
#
# Share price: $0.02456310799000732
# Shares owned at the moment: 163
# Cash capital at the moment: $0.020979046467830997
#
#
# Price increase from previously bought: 39.1430692110857%
# Share price: $0.034271851472394664
# Shares owned at the moment: 0
# Cash capital at the moment: $5.59192847904566
#
#
# Share price: $0.029417472497627294
# Shares owned at the moment: 189
# Cash capital at the moment: $0.016736445663459776
#
#
# Price increase from previously bought: -0.27424582398405395%
# Share price: $0.029417472497627294
# Shares owned at the moment: 0
# Cash capital at the moment: $5.5613490163843755
#
#
# Share price: $0.034271851472394664
# Shares owned at the moment: 161
# Cash capital at the moment: $0.028407067089431415
#
#
#
#
# Capital at the end of test period: $3.1927887215769672
# profit gained: -96.80721127842304%
#
#
# Capital at the end of test period if Buy and Hold: $2.5934579490563006
# profit gained: -97.4065420509437%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.055046      4.861111       6.756757            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         48.251748           58.108108                0.0     -96.807211
#
#    buy_n_hold profit
# 0         -97.406542
#
#
# Recession
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2033 - accuracy: 0.0594 - mse: 0.9719 - weighted_accuracy: 0.0594 - weighted_mse: 0.9719
# Test loss: 0.20331458747386932
# Test accuracy: 0.05936073139309883
#
#
# number of predictions: 219
# actual predicted buys: 7
# actual buys but predicted sell: 1
# actual buys but predicted hold: 0
# actual sells but predicted buy: 2
# actual predicted sells: 6
# actual sells but predicted hold: 0
# actual holds but predicted buy: 126
# actual holds but predicted sell: 77
# actual predicted holds: 0
# Percentage buys correct: 5.185185185185185%
# Percentage sells correct: 7.142857142857143%
# Percentage holds correct: 0%
# actual buys: 8
# actual sells: 8
# actual holds: 203
#
#
# Percentage low buys correct: 47.014925373134325%
# Percentage high sells correct: 45.23809523809524%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.011255491634695433
# Shares owned at the moment: 8860
# Cash capital at the moment: $0.0021040629191020344
#
#
# Price increase from previously bought: 83.15506131108043%
# Share price: $0.020671693861552022
# Shares owned at the moment: 0
# Cash capital at the moment: $182.6496458553333
#
#
# Share price: $0.07465787905337797
# Shares owned at the moment: 2439
# Cash capital at the moment: $0.05832978486367324
#
#
# Price increase from previously bought: -10.336534095701255%
# Share price: $0.06712492924520537
# Shares owned at the moment: 0
# Cash capital at the moment: $163.32580853223965
#
#
# Share price: $0.11483365626355417
# Shares owned at the moment: 1418
# Cash capital at the moment: $0.04389010792010595
#
#
# Price increase from previously bought: 8.4482736328082%
# Share price: $0.12487758934111758
# Shares owned at the moment: 0
# Cash capital at the moment: $176.63335163398915
#
#
# Share price: $0.11295041881151101
# Shares owned at the moment: 1559
# Cash capital at the moment: $0.059402023793836634
#
#
# Price increase from previously bought: -4.708234633906261%
# Share price: $0.10792843730608846
# Shares owned at the moment: 0
# Cash capital at the moment: $167.85711959114522
#
#
# Share price: $0.5015254389491263
# Shares owned at the moment: 333
# Cash capital at the moment: $0.3898765003685014
#
#
# Price increase from previously bought: 100.83330554243979%
# Share price: $1.01
# Shares owned at the moment: 0
# Cash capital at the moment: $335.7949690003685
#
#
# Share price: $0.8141431852543864
# Shares owned at the moment: 411
# Cash capital at the moment: $0.26193452568185194
#
#
# Price increase from previously bought: -36.0298223940569%
# Share price: $0.5222410658882417
# Shares owned at the moment: 0
# Cash capital at the moment: $214.312749641029
#
#
# Share price: $0.40673574569641713
# Shares owned at the moment: 525
# Cash capital at the moment: $0.18925841756077944
#
#
# Price increase from previously bought: 6.1901597899913785%
# Share price: $0.4331010999583029
# Shares owned at the moment: 0
# Cash capital at the moment: $226.94204618260503
#
#
# Share price: $0.40924672896580805
# Shares owned at the moment: 553
# Cash capital at the moment: $0.006243101438428766
#
#
# Price increase from previously bought: 3.8559447180605%
# Share price: $0.4261958810008373
# Shares owned at the moment: 0
# Cash capital at the moment: $235.0444279088694
#
#
# Share price: $0.3006465977981677
# Shares owned at the moment: 779
# Cash capital at the moment: $0.19666804996361975
#
#
# Price increase from previously bought: -14.64185164043661%
# Share price: $0.25733209150125286
# Shares owned at the moment: 0
# Cash capital at the moment: $200.10709765642102
#
#
# Share price: $0.18890773754378867
# Shares owned at the moment: 1056
# Cash capital at the moment: $0.07193874035300496
#
#
# Price increase from previously bought: 38.829994778413536%
# Share price: $0.26298181882402316
# Shares owned at the moment: 0
# Cash capital at the moment: $277.0170402166565
#
#
# Share price: $0.3464720873644733
# Shares owned at the moment: 797
# Cash capital at the moment: $0.11940638969014117
#
#
#
#
# Capital at the end of test period: $323.8952582980259
# profit gained: 223.8952582980259%
#
#
# Capital at the end of test period if Buy and Hold: $3238.165410975435
# profit gained: 3138.165410975435%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.059361      5.185185       7.142857            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.014925           45.238095                0.0     223.895258
#
#    buy_n_hold profit
# 0        3138.165411
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2033 - accuracy: 0.0596 - mse: 0.9929 - weighted_accuracy: 0.0596 - weighted_mse: 0.9929
# Test loss: 0.20332226157188416
# Test accuracy: 0.059633027762174606
#
#
# number of predictions: 218
# actual predicted buys: 9
# actual buys but predicted sell: 1
# actual buys but predicted hold: 0
# actual sells but predicted buy: 5
# actual predicted sells: 4
# actual sells but predicted hold: 0
# actual holds but predicted buy: 134
# actual holds but predicted sell: 65
# actual predicted holds: 0
# Percentage buys correct: 6.081081081081081%
# Percentage sells correct: 5.714285714285714%
# Percentage holds correct: 0%
# actual buys: 10
# actual sells: 9
# actual holds: 199
#
#
# Percentage low buys correct: 45.270270270270274%
# Percentage high sells correct: 59.42028985507246%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.9879411977395466
# Shares owned at the moment: 100
# Cash capital at the moment: $0.9341963966669624
#
#
# Price increase from previously bought: -33.30339469043903%
# Share price: $0.6607352802605987
# Shares owned at the moment: 0
# Cash capital at the moment: $66.82602222065518
#
#
# Share price: $0.6570588132171898
# Shares owned at the moment: 101
# Cash capital at the moment: $0.28058400034792896
#
#
# Price increase from previously bought: -3.6222424528888686%
# Share price: $0.6350000109567361
# Shares owned at the moment: 0
# Cash capital at the moment: $64.23921385393504
#
#
# Share price: $0.5908823187819406
# Shares owned at the moment: 108
# Cash capital at the moment: $0.24843137680721838
#
#
# Price increase from previously bought: 4.069206431519468%
# Share price: $0.6166175880858032
# Shares owned at the moment: 0
# Cash capital at the moment: $66.65999546641248
#
#
# Share price: $0.6533823461737808
# Shares owned at the moment: 101
# Cash capital at the moment: $0.48690155621085296
#
#
# Price increase from previously bought: -5.885651226797284%
# Share price: $0.6166175880858032
# Shares owned at the moment: 0
# Cash capital at the moment: $62.594012417786146
#
#
# Share price: $0.6166175880858032
# Shares owned at the moment: 101
# Cash capital at the moment: $0.14437048602918878
#
#
# Price increase from previously bought: 15.779878784796587%
# Share price: $0.7158823735656209
# Shares owned at the moment: 0
# Cash capital at the moment: $72.24965388689904
#
#
# Share price: $0.7305882417392565
# Shares owned at the moment: 98
# Cash capital at the moment: $0.45511266530317585
#
#
# Price increase from previously bought: -1.7797660102974122%
# Share price: $0.71955884060903
# Shares owned at the moment: 0
# Cash capital at the moment: $70.77795793744397
#
#
# Share price: $0.5982352528687588
# Shares owned at the moment: 117
# Cash capital at the moment: $0.5919511591886675
#
#
# Price increase from previously bought: -78.72125292266234%
# Share price: $0.12764703304297442
# Shares owned at the moment: 0
# Cash capital at the moment: $15.485583592335098
#
#
# Share price: $0.18647059339140537
# Shares owned at the moment: 82
# Cash capital at the moment: $0.15294581543009578
#
#
# Price increase from previously bought: -4.206645479490589%
# Share price: $0.17911765930458734
# Shares owned at the moment: 0
# Cash capital at the moment: $14.800202846233073
#
#
# Share price: $0.201176461565041
# Shares owned at the moment: 73
# Cash capital at the moment: $0.07393497732589793
#
#
# Price increase from previously bought: 7.015641785231863%
# Share price: $0.21588232973867671
# Shares owned at the moment: 0
# Cash capital at the moment: $15.790006670554257
#
#
# Share price: $0.21220586269526776
# Shares owned at the moment: 74
# Cash capital at the moment: $0.04358893804595709
#
#
# Price increase from previously bought: 72.29129090822522%
# Share price: $0.36661765382621947
# Shares owned at the moment: 0
# Cash capital at the moment: $27.098688628632562
#
#
# Share price: $0.3960293901734909
# Shares owned at the moment: 68
# Cash capital at the moment: $0.0946326008727354
#
#
# Price increase from previously bought: -24.344702819516396%
# Share price: $0.3004411593909705
# Shares owned at the moment: 0
# Cash capital at the moment: $20.468448942652618
#
#
# Share price: $0.29308822530415257
# Shares owned at the moment: 69
# Cash capital at the moment: $0.1897479059146292
#
#
# Price increase from previously bought: -41.55559560469477%
# Share price: $0.17176472521776964
# Shares owned at the moment: 0
# Cash capital at the moment: $12.008921589330662
#
#
# Share price: $0.14235290121660982
# Shares owned at the moment: 84
# Cash capital at the moment: $0.0183943669544
#
#
# Price increase from previously bought: -38.907646914559535%
# Share price: $0.08720589556547574
# Shares owned at the moment: 0
# Cash capital at the moment: $7.323545032578737
#
#
# Share price: $0.13132350008638305
# Shares owned at the moment: 55
# Cash capital at the moment: $0.0808898484396039
#
#
# Price increase from previously bought: 77.8982464991689%
# Share price: $0.2342646649557213
# Shares owned at the moment: 0
# Cash capital at the moment: $12.930013890429722
#
#
# Share price: $0.09455882965229377
# Shares owned at the moment: 136
# Cash capital at the moment: $0.034648055427810576
#
#
# Price increase from previously bought: 123.80130735199214%
# Share price: $0.21220586269526776
# Shares owned at the moment: 0
# Cash capital at the moment: $28.815280389336195
#
#
# Share price: $0.19382352747822307
# Shares owned at the moment: 148
# Cash capital at the moment: $0.05051214687554051
#
#
# Price increase from previously bought: 47.016039704229364%
# Share price: $0.28573529121733454
# Shares owned at the moment: 0
# Cash capital at the moment: $42.2230409835156
#
#
#
#
# Capital at the end of test period: $42.2230409835156
# profit gained: -57.7769590164844%
#
#
# Capital at the end of test period if Buy and Hold: $26.129427230180067
# profit gained: -73.87057276981993%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.055046      4.861111       6.756757            0.0
# 1       0.059633      6.081081       5.714286            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         48.251748           58.108108                0.0     -96.807211
# 1         45.270270           59.420290                0.0     -57.776959
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
#
#
# Recession
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2032 - accuracy: 0.0685 - mse: 0.9934 - weighted_accuracy: 0.0685 - weighted_mse: 0.9934
# Test loss: 0.20316852629184723
# Test accuracy: 0.06849315017461777
#
#
# number of predictions: 219
# actual predicted buys: 6
# actual buys but predicted sell: 2
# actual buys but predicted hold: 0
# actual sells but predicted buy: 2
# actual predicted sells: 9
# actual sells but predicted hold: 0
# actual holds but predicted buy: 119
# actual holds but predicted sell: 81
# actual predicted holds: 0
# Percentage buys correct: 4.724409448818897%
# Percentage sells correct: 9.782608695652174%
# Percentage holds correct: 0%
# actual buys: 8
# actual sells: 11
# actual holds: 200
#
#
# Percentage low buys correct: 47.61904761904762%
# Percentage high sells correct: 43.47826086956522%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.011763675119632519
# Shares owned at the moment: 8477
# Cash capital at the moment: $0.005094157405039823
#
#
# Price increase from previously bought: 247.9185448914977%
# Share price: $0.04104055932206908
# Shares owned at the moment: 0
# Cash capital at the moment: $346.94918827180834
#
#
# Share price: $0.15497353810329545
# Shares owned at the moment: 2232
# Cash capital at the moment: $0.0970236483748863
#
#
# Price increase from previously bought: 12.89086880287027%
# Share price: $0.1754320887567007
# Shares owned at the moment: 0
# Cash capital at the moment: $390.5846435925422
#
#
# Share price: $0.22728394889378878
# Shares owned at the moment: 1713
# Cash capital at the moment: $0.17656127523059695
#
#
# Price increase from previously bought: -23.180130579420865%
# Share price: $0.17507938064421824
# Shares owned at the moment: 0
# Cash capital at the moment: $299.2627851264067
#
#
# Share price: $0.15462081317116044
# Shares owned at the moment: 1930
# Cash capital at the moment: $0.023965740161088434
#
#
# Price increase from previously bought: 96.86935037329793%
# Share price: $0.3052380931556622
# Shares owned at the moment: 0
# Cash capital at the moment: $587.5134343511654
#
#
# Share price: $0.28830685910221704
# Shares owned at the moment: 2032
# Cash capital at the moment: $0.06283792679710132
#
#
# Price increase from previously bought: 29.252437177587453%
# Share price: $0.37366841195510303
# Shares owned at the moment: 0
# Cash capital at the moment: $757.2689919335613
#
#
# Share price: $0.3630864285159178
# Shares owned at the moment: 2079
# Cash capital at the moment: $0.33645116553555
#
#
# Price increase from previously bought: 7.476327215915846%
# Share price: $0.3913050958728182
# Shares owned at the moment: 0
# Cash capital at the moment: $811.6225564257456
#
#
# Share price: $0.6488007214386262
# Shares owned at the moment: 1247
# Cash capital at the moment: $0.3431569177853362
#
#
# Price increase from previously bought: 20.97918314861118%
# Share price: $0.7870723260446578
# Shares owned at the moment: 0
# Cash capital at the moment: $979.123279721385
#
#
# Share price: $0.6357495457369284
# Shares owned at the moment: 1535
# Cash capital at the moment: $0.5640692452578833
#
#
# Price increase from previously bought: -11.838417114956712%
# Share price: $0.5620282015785902
# Shares owned at the moment: 0
# Cash capital at the moment: $860.9048971224802
#
#
# Share price: $0.4078835881744759
# Shares owned at the moment: 2104
# Cash capital at the moment: $0.35781316220538883
#
#
# Price increase from previously bought: -20.799805283631223%
# Share price: $0.32393296868943494
# Shares owned at the moment: 0
# Cash capital at the moment: $680.0385031279394
#
#
# Share price: $0.33733685250361506
# Shares owned at the moment: 2010
# Cash capital at the moment: $0.12680014345937707
#
#
# Price increase from previously bought: -26.760721737241987%
# Share price: $0.24774249954719407
# Shares owned at the moment: 0
# Cash capital at the moment: $496.7198275670723
#
#
# Share price: $0.3204056520894749
# Shares owned at the moment: 1546
# Cash capital at the moment: $0.010484806885642683
#
#
# Price increase from previously bought: -0.38403613822156624%
# Share price: $0.32005291033768735
# Shares owned at the moment: 0
# Cash capital at the moment: $493.4515792406496
#
#
# Share price: $0.2801940006469344
# Shares owned at the moment: 1756
# Cash capital at the moment: $0.07785727550873389
#
#
# Price increase from previously bought: -2.785120323002155%
# Share price: $0.27313933380770933
# Shares owned at the moment: 0
# Cash capital at the moment: $478.3915375988889
#
#
# Share price: $0.29818342631643713
# Shares owned at the moment: 1599
# Cash capital at the moment: $0.2850518475359536
#
#
# Price increase from previously bought: -3.6953688864944767%
# Share price: $0.2879541509897344
# Shares owned at the moment: 0
# Cash capital at the moment: $459.4575328896817
#
#
# Share price: $0.2583245166256841
# Shares owned at the moment: 1773
# Cash capital at the moment: $0.18863915040606116
#
#
# Price increase from previously bought: 28.86662154244808%
# Share price: $0.33380953590365503
# Shares owned at the moment: 0
# Cash capital at the moment: $590.4053744629042
#
#
# Share price: $0.2928924009575395
# Shares owned at the moment: 2010
# Cash capital at the moment: $0.07268579195704206
#
#
#
#
# Capital at the end of test period: $518.5841365849935
# profit gained: 418.58413658499353%
#
#
# Capital at the end of test period if Buy and Hold: $2186.7819938452512
# profit gained: 2086.7819938452512%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.059361      5.185185       7.142857            0.0
# 1       0.068493      4.724409       9.782609            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.014925           45.238095                0.0     223.895258
# 1         47.619048           43.478261                0.0     418.584137
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2028 - accuracy: 0.0688 - mse: 0.9902 - weighted_accuracy: 0.0688 - weighted_mse: 0.9902
# Test loss: 0.2028093785047531
# Test accuracy: 0.06880734115839005
#
#
# number of predictions: 218
# actual predicted buys: 9
# actual buys but predicted sell: 0
# actual buys but predicted hold: 0
# actual sells but predicted buy: 2
# actual predicted sells: 6
# actual sells but predicted hold: 0
# actual holds but predicted buy: 146
# actual holds but predicted sell: 55
# actual predicted holds: 0
# Percentage buys correct: 5.732484076433121%
# Percentage sells correct: 9.836065573770492%
# Percentage holds correct: 0%
# actual buys: 9
# actual sells: 8
# actual holds: 201
#
#
# Percentage low buys correct: 41.666666666666664%
# Percentage high sells correct: 57.377049180327866%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $1.01
# Shares owned at the moment: 98
# Cash capital at the moment: $0.7478049999999996
#
#
# Price increase from previously bought: -81.10694813552661%
# Share price: $0.191344578346717
# Shares owned at the moment: 0
# Cash capital at the moment: $19.448006314113826
#
#
# Share price: $0.191344578346717
# Shares owned at the moment: 101
# Cash capital at the moment: $0.06905794445960467
#
#
# Price increase from previously bought: 15.24103167620523%
# Share price: $0.2211138616751354
# Shares owned at the moment: 0
# Cash capital at the moment: $22.34014359856801
#
#
# Share price: $0.201267664903355
# Shares owned at the moment: 110
# Cash capital at the moment: $0.13981699056569497
#
#
# Price increase from previously bought: -24.858131040585373%
# Share price: $0.15165218480315598
# Shares owned at the moment: 0
# Cash capital at the moment: $16.775682533009896
#
#
# Share price: $0.146690641524837
# Shares owned at the moment: 114
# Cash capital at the moment: $0.006961883060444762
#
#
# Price increase from previously bought: -49.01474207251974%
# Share price: $0.07499627609224012
# Shares owned at the moment: 0
# Cash capital at the moment: $8.5330260250209
#
#
# Share price: $0.04497890968527956
# Shares owned at the moment: 189
# Cash capital at the moment: $0.008634306194139185
#
#
# Price increase from previously bought: 16.776650816978012%
# Share price: $0.05266930768130009
# Shares owned at the moment: 0
# Cash capital at the moment: $9.9357585852925
#
#
# Share price: $0.04448275535744766
# Shares owned at the moment: 222
# Cash capital at the moment: $0.033430173793396634
#
#
# Price increase from previously bought: -41.43036694568536%
# Share price: $0.026125033398415175
# Shares owned at the moment: 0
# Cash capital at the moment: $5.817238255351833
#
#
# Share price: $0.018186552323852474
# Shares owned at the moment: 318
# Cash capital at the moment: $0.01801047635953701
#
#
# Price increase from previously bought: 353.4114430772702%
# Share price: $0.08268667408826068
# Shares owned at the moment: 0
# Cash capital at the moment: $26.24006333993625
#
#
# Share price: $0.07499627609224012
# Shares owned at the moment: 348
# Cash capital at the moment: $0.06958782361641269
#
#
# Price increase from previously bought: 14.240437518670657%
# Share price: $0.08591168313379415
# Shares owned at the moment: 0
# Cash capital at the moment: $29.884636073417735
#
#
# Share price: $0.07450012176440822
# Shares owned at the moment: 400
# Cash capital at the moment: $0.002637233713596032
#
#
# Price increase from previously bought: -53.40641001049698%
# Share price: $0.03480774005009949
# Shares owned at the moment: 0
# Cash capital at the moment: $13.887444739698283
#
#
# Share price: $0.027861567631200616
# Shares owned at the moment: 497
# Cash capital at the moment: $0.0021658294316342364
#
#
# Price increase from previously bought: 0.6137254644015044%
# Share price: $0.028109650709742716
# Shares owned at the moment: 0
# Cash capital at the moment: $13.934243367066223
#
#
# Share price: $0.021907715697217826
# Shares owned at the moment: 634
# Cash capital at the moment: $0.006555512712020928
#
#
# Price increase from previously bought: 32.47455306732425%
# Share price: $0.029101959365406514
# Shares owned at the moment: 0
# Cash capital at the moment: $18.406458484226164
#
#
# Share price: $0.030094268021070313
# Shares owned at the moment: 609
# Cash capital at the moment: $0.02864888402605459
#
#
# Price increase from previously bought: 7.124429899677032%
# Share price: $0.03232696841094004
# Shares owned at the moment: 0
# Cash capital at the moment: $19.661633055942318
#
#
# Share price: $0.026373104647704947
# Shares owned at the moment: 743
# Cash capital at the moment: $0.012529456626118929
#
#
# Price increase from previously bought: 81.33746259487027%
# Share price: $0.047955835652270955
# Shares owned at the moment: 0
# Cash capital at the moment: $35.54572958506694
#
#
# Share price: $0.021907715697217826
# Shares owned at the moment: 1618
# Cash capital at the moment: $0.0015672059737212862
#
#
#
#
# Capital at the end of test period: $26.944777610151068
# profit gained: -73.05522238984894%
#
#
# Capital at the end of test period if Buy and Hold: $2.3797176202777375
# profit gained: -97.62028237972227%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.055046      4.861111       6.756757            0.0
# 1       0.059633      6.081081       5.714286            0.0
# 2       0.068807      5.732484       9.836066            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         48.251748           58.108108                0.0     -96.807211
# 1         45.270270           59.420290                0.0     -57.776959
# 2         41.666667           57.377049                0.0     -73.055222
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
# 2         -97.620282
#
#
# Recession
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2045 - accuracy: 0.0594 - mse: 0.9716 - weighted_accuracy: 0.0594 - weighted_mse: 0.9716
# Test loss: 0.204471156001091
# Test accuracy: 0.05936073139309883
#
#
# number of predictions: 219
# actual predicted buys: 6
# actual buys but predicted sell: 2
# actual buys but predicted hold: 0
# actual sells but predicted buy: 3
# actual predicted sells: 7
# actual sells but predicted hold: 0
# actual holds but predicted buy: 128
# actual holds but predicted sell: 73
# actual predicted holds: 0
# Percentage buys correct: 4.37956204379562%
# Percentage sells correct: 8.536585365853659%
# Percentage holds correct: 0%
# actual buys: 8
# actual sells: 10
# actual holds: 201
#
#
# Percentage low buys correct: 47.05882352941177%
# Percentage high sells correct: 52.4390243902439%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.011748252914169829
# Shares owned at the moment: 8488
# Cash capital at the moment: $0.006601545003931619
#
#
# Price increase from previously bought: 38.310107513758204%
# Share price: $0.01629370604497711
# Shares owned at the moment: 0
# Cash capital at the moment: $137.9272507682678
#
#
# Share price: $0.02346154132581052
# Shares owned at the moment: 5862
# Cash capital at the moment: $0.017483739423823863
#
#
# Price increase from previously bought: 63.63345779299316%
# Share price: $0.03849650638409394
# Shares owned at the moment: 0
# Cash capital at the moment: $225.0634212318177
#
#
# Share price: $0.04245920669099701
# Shares owned at the moment: 5286
# Cash capital at the moment: $0.0068464051438184015
#
#
# Price increase from previously bought: -10.26597770437313%
# Share price: $0.03820512997214183
# Shares owned at the moment: 0
# Cash capital at the moment: $201.4037945660455
#
#
# Share price: $0.050501165650143925
# Shares owned at the moment: 3977
# Cash capital at the moment: $0.008340151998879719
#
#
# Price increase from previously bought: 114.11232036450141%
# Share price: $0.10842657293300147
# Shares owned at the moment: 0
# Cash capital at the moment: $430.0349863850207
#
#
# Share price: $0.09426574266811717
# Shares owned at the moment: 4549
# Cash capital at the moment: $0.040882113413204024
#
#
# Price increase from previously bought: 113.47080509591608%
# Share price: $0.2017832218627332
# Shares owned at the moment: 0
# Cash capital at the moment: $915.4285007072892
#
#
# Share price: $0.238438239993772
# Shares owned at the moment: 3828
# Cash capital at the moment: $0.1768786587156228
#
#
# Price increase from previously bought: 14.447223432038347%
# Share price: $0.2736363816225931
# Shares owned at the moment: 0
# Cash capital at the moment: $1044.7763773206607
#
#
# Share price: $0.4454895213752989
# Shares owned at the moment: 2338
# Cash capital at the moment: $0.35760146752932087
#
#
# Price increase from previously bought: 38.22230387710803%
# Share price: $0.6174592361459739
# Shares owned at the moment: 0
# Cash capital at the moment: $1440.0073414180156
#
#
# Share price: $0.7832518087745554
# Shares owned at the moment: 1833
# Cash capital at the moment: $0.3585993791753026
#
#
# Price increase from previously bought: 20.42682261366513%
# Share price: $0.9458391908537784
# Shares owned at the moment: 0
# Cash capital at the moment: $1729.314097312855
#
#
# Share price: $0.9620978934934268
# Shares owned at the moment: 1792
# Cash capital at the moment: $0.4934537534984429
#
#
# Price increase from previously bought: -36.48686695380179%
# Share price: $0.6127389260457556
# Shares owned at the moment: 0
# Cash capital at the moment: $1095.502031799939
#
#
# Share price: $0.5667016641439497
# Shares owned at the moment: 1927
# Cash capital at the moment: $0.4648312008330322
#
#
# Price increase from previously bought: 8.688620059345165%
# Share price: $0.6176340542125852
# Shares owned at the moment: 0
# Cash capital at the moment: $1187.3726564066988
#
#
# Share price: $0.5988111902413817
# Shares owned at the moment: 1977
# Cash capital at the moment: $0.2673465609420873
#
#
# Price increase from previously bought: 1.9288167179468685%
# Share price: $0.6120396537793102
# Shares owned at the moment: 0
# Cash capital at the moment: $1206.9422354949538
#
#
# Share price: $0.5429254289572745
# Shares owned at the moment: 2216
# Cash capital at the moment: $0.5108973615679133
#
#
# Price increase from previously bought: -16.03067211712509%
# Share price: $0.4571445333930407
# Shares owned at the moment: 0
# Cash capital at the moment: $1010.7573445740488
#
#
# Share price: $0.47410259721981923
# Shares owned at the moment: 2126
# Cash capital at the moment: $0.04338205006752105
#
#
# Price increase from previously bought: 47.70335639843286%
# Share price: $0.7021911788501972
# Shares owned at the moment: 0
# Cash capital at the moment: $1488.7964675584392
#
#
# Share price: $0.6872144901858129
# Shares owned at the moment: 2160
# Cash capital at the moment: $0.3311146853793616
#
#
#
#
# Capital at the end of test period: $1502.348645620394
# profit gained: 1402.348645620394%
#
#
# Capital at the end of test period if Buy and Hold: $5902.379195330377
# profit gained: 5802.379195330377%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.059361      5.185185       7.142857            0.0
# 1       0.068493      4.724409       9.782609            0.0
# 2       0.059361      4.379562       8.536585            0.0
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         47.014925           45.238095                0.0     223.895258
# 1         47.619048           43.478261                0.0     418.584137
# 2         47.058824           52.439024                0.0    1402.348646
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
# 2        5802.379195
#
#
#
# RUNNING EPOCHS 20 - 40
#
#
#
# Epoch 1/20
#  2/30 [=>............................] - ETA: 4s - loss: 0.1841 - accuracy: 0.1680 - mse: 1.1835 - weighted_accuracy: 0.3956 - weighted_mse: 1.2424WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0050s vs `on_train_batch_end` time: 0.3082s). Check your callbacks.
# 30/30 [==============================] - 1s 20ms/step - loss: 0.2002 - accuracy: 0.1876 - mse: 1.1644 - weighted_accuracy: 0.3758 - weighted_mse: 1.1469 - val_loss: 0.1963 - val_accuracy: 0.0685 - val_mse: 0.9861 - val_weighted_accuracy: 0.0685 - val_weighted_mse: 0.9861
# Epoch 2/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1976 - accuracy: 0.2100 - mse: 1.2373 - weighted_accuracy: 0.3928 - weighted_mse: 1.2125 - val_loss: 0.2034 - val_accuracy: 0.0727 - val_mse: 0.9126 - val_weighted_accuracy: 0.0727 - val_weighted_mse: 0.9126
# Epoch 3/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1979 - accuracy: 0.2013 - mse: 1.1701 - weighted_accuracy: 0.3881 - weighted_mse: 1.1427 - val_loss: 0.2028 - val_accuracy: 0.0706 - val_mse: 0.9425 - val_weighted_accuracy: 0.0706 - val_weighted_mse: 0.9425
# Epoch 4/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1969 - accuracy: 0.2110 - mse: 1.2155 - weighted_accuracy: 0.3832 - weighted_mse: 1.1846 - val_loss: 0.2028 - val_accuracy: 0.0717 - val_mse: 0.9703 - val_weighted_accuracy: 0.0717 - val_weighted_mse: 0.9703
# Epoch 5/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1954 - accuracy: 0.2084 - mse: 1.2319 - weighted_accuracy: 0.4229 - weighted_mse: 1.2027 - val_loss: 0.1988 - val_accuracy: 0.0717 - val_mse: 1.0270 - val_weighted_accuracy: 0.0717 - val_weighted_mse: 1.0270
# Epoch 6/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1949 - accuracy: 0.2252 - mse: 1.1576 - weighted_accuracy: 0.4110 - weighted_mse: 1.1419 - val_loss: 0.1996 - val_accuracy: 0.0717 - val_mse: 1.0273 - val_weighted_accuracy: 0.0717 - val_weighted_mse: 1.0273
# Epoch 7/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1948 - accuracy: 0.2084 - mse: 1.2208 - weighted_accuracy: 0.4286 - weighted_mse: 1.1994 - val_loss: 0.2006 - val_accuracy: 0.0717 - val_mse: 1.0384 - val_weighted_accuracy: 0.0717 - val_weighted_mse: 1.0384
# Epoch 8/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1946 - accuracy: 0.1970 - mse: 1.2213 - weighted_accuracy: 0.4082 - weighted_mse: 1.1714 - val_loss: 0.1993 - val_accuracy: 0.0748 - val_mse: 0.9844 - val_weighted_accuracy: 0.0748 - val_weighted_mse: 0.9844
# Epoch 9/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1928 - accuracy: 0.2060 - mse: 1.2229 - weighted_accuracy: 0.4264 - weighted_mse: 1.1903 - val_loss: 0.1963 - val_accuracy: 0.0738 - val_mse: 0.9942 - val_weighted_accuracy: 0.0738 - val_weighted_mse: 0.9942
# Epoch 10/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1920 - accuracy: 0.2168 - mse: 1.2138 - weighted_accuracy: 0.4392 - weighted_mse: 1.1940 - val_loss: 0.1993 - val_accuracy: 0.0727 - val_mse: 0.9896 - val_weighted_accuracy: 0.0727 - val_weighted_mse: 0.9896
# Epoch 11/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1913 - accuracy: 0.1905 - mse: 1.2195 - weighted_accuracy: 0.4529 - weighted_mse: 1.1958 - val_loss: 0.1979 - val_accuracy: 0.0748 - val_mse: 1.0135 - val_weighted_accuracy: 0.0748 - val_weighted_mse: 1.0135
# Epoch 12/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1915 - accuracy: 0.1931 - mse: 1.2237 - weighted_accuracy: 0.4545 - weighted_mse: 1.2014 - val_loss: 0.1978 - val_accuracy: 0.0748 - val_mse: 0.9741 - val_weighted_accuracy: 0.0748 - val_weighted_mse: 0.9741
# Epoch 13/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1897 - accuracy: 0.1844 - mse: 1.2274 - weighted_accuracy: 0.4535 - weighted_mse: 1.1826 - val_loss: 0.1946 - val_accuracy: 0.0727 - val_mse: 1.0121 - val_weighted_accuracy: 0.0727 - val_weighted_mse: 1.0121
# Epoch 14/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1897 - accuracy: 0.1970 - mse: 1.2415 - weighted_accuracy: 0.4601 - weighted_mse: 1.2069 - val_loss: 0.1962 - val_accuracy: 0.0748 - val_mse: 1.0674 - val_weighted_accuracy: 0.0748 - val_weighted_mse: 1.0674
# Epoch 15/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1880 - accuracy: 0.1857 - mse: 1.2454 - weighted_accuracy: 0.4800 - weighted_mse: 1.2117 - val_loss: 0.1978 - val_accuracy: 0.0727 - val_mse: 1.0335 - val_weighted_accuracy: 0.0727 - val_weighted_mse: 1.0335
# Epoch 16/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1860 - accuracy: 0.1744 - mse: 1.2368 - weighted_accuracy: 0.4647 - weighted_mse: 1.2064 - val_loss: 0.1985 - val_accuracy: 0.0695 - val_mse: 1.0334 - val_weighted_accuracy: 0.0695 - val_weighted_mse: 1.0334
# Epoch 17/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1878 - accuracy: 0.1902 - mse: 1.2686 - weighted_accuracy: 0.4648 - weighted_mse: 1.2288 - val_loss: 0.1963 - val_accuracy: 0.0738 - val_mse: 1.0299 - val_weighted_accuracy: 0.0738 - val_weighted_mse: 1.0299
# Epoch 18/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1864 - accuracy: 0.1731 - mse: 1.2752 - weighted_accuracy: 0.4570 - weighted_mse: 1.2332 - val_loss: 0.1973 - val_accuracy: 0.0706 - val_mse: 1.0831 - val_weighted_accuracy: 0.0706 - val_weighted_mse: 1.0831
# Epoch 19/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1871 - accuracy: 0.1702 - mse: 1.2520 - weighted_accuracy: 0.4666 - weighted_mse: 1.2135 - val_loss: 0.1984 - val_accuracy: 0.0727 - val_mse: 1.0124 - val_weighted_accuracy: 0.0727 - val_weighted_mse: 1.0124
# Epoch 20/20
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1837 - accuracy: 0.1689 - mse: 1.2278 - weighted_accuracy: 0.4761 - weighted_mse: 1.2073 - val_loss: 0.1968 - val_accuracy: 0.0748 - val_mse: 1.0200 - val_weighted_accuracy: 0.0748 - val_weighted_mse: 1.0200
# Validation loss: 0.19684015214443207
# Validation accuracy: 0.07481559365987778
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1993 - accuracy: 0.0413 - mse: 1.0007 - weighted_accuracy: 0.0413 - weighted_mse: 1.0007
# Test loss: 0.19931548833847046
# Test accuracy: 0.04128440469503403
#
#
# number of predictions: 218
# actual predicted buys: 6
# actual buys but predicted sell: 2
# actual buys but predicted hold: 0
# actual sells but predicted buy: 5
# actual predicted sells: 3
# actual sells but predicted hold: 0
# actual holds but predicted buy: 143
# actual holds but predicted sell: 59
# actual predicted holds: 0
# Percentage buys correct: 3.896103896103896%
# Percentage sells correct: 4.6875%
# Percentage holds correct: 0%
# actual buys: 8
# actual sells: 8
# actual holds: 202
#
#
# Percentage low buys correct: 50.98039215686274%
# Percentage high sells correct: 60.9375%
# Percentage mid holds correct: 0%
#
#
# Capital: 100
# Share price: $0.7964077880589524
# Shares owned at the moment: 125
# Cash capital at the moment: $0.17526131548568458
#
#
# Price increase from previously bought: -15.470783028456669%
# Share price: $0.6750485596312741
# Shares owned at the moment: 0
# Cash capital at the moment: $84.32428332702169
#
#
# Share price: $1.01
# Shares owned at the moment: 83
# Cash capital at the moment: $0.2637508270216813
#
#
# Price increase from previously bought: -10.339798688262647%
# Share price: $0.9080583453399809
# Shares owned at the moment: 0
# Cash capital at the moment: $75.42532917291625
#
#
# Share price: $0.8012621525665726
# Shares owned at the moment: 93
# Cash capital at the moment: $0.7030261887061044
#
#
# Price increase from previously bought: -70.96316537533147%
# Share price: $0.2333009843577296
# Shares owned at the moment: 0
# Cash capital at the moment: $22.34035100722547
#
#
# Share price: $0.22359225534248967
# Shares owned at the moment: 99
# Cash capital at the moment: $0.1438447368019986
#
#
# Price increase from previously bought: 6.221128903903828%
# Share price: $0.23815534886534961
# Shares owned at the moment: 0
# Cash capital at the moment: $23.656386480743016
#
#
# Share price: $0.21873786190057493
# Shares owned at the moment: 107
# Cash capital at the moment: $0.18707164151725308
#
#
# Price increase from previously bought: -13.5533088524997%
# Share price: $0.1896116459205603
# ...
#
#
# Capital: 100
# Share price: $0.6644117473040075
# Shares owned at the moment: 150
# Cash capital at the moment: $0.06416805863595698
#
#
# Price increase from previously bought: -0.8260699753403822%
# Share price: $0.6607352802605987
# Shares owned at the moment: 0
# Cash capital at the moment: $98.90190679461826
#
#
# Share price: $0.6791176154776434
# Shares owned at the moment: 145
# Cash capital at the moment: $0.1590544011882571
#
#
# Price increase from previously bought: -9.4521293387404%
# Share price: $0.6166175880858032
# Shares owned at the moment: 0
# Cash capital at the moment: $89.3227284103805
#
#
# Share price: $0.6570588132171898
# Shares owned at the moment: 135
# Cash capital at the moment: $0.37585554165298163
#
#
# Price increase from previously bought: 3.631750243071541%
# Share price: $0.6827940825210522
# Shares owned at the moment: 0
# Cash capital at the moment: $92.29956937885909
#
#
# Share price: $0.48426468686919344
# Shares owned at the moment: 190
# Cash capital at the moment: $0.03625057482317118
#
#
# Price increase from previously bought: -9.359486814259022%
# Share price: $0.44014708234828637
# Shares owned at the moment: 0
# Cash capital at the moment: $83.4342193704706
#
#
# Share price: $0.15705876939024555
# Shares owned at the moment: 529
# Cash capital at the moment: $0.12164911826023683
#
#
# Price increase from previously bought: 13.73222730409378%
# Share price: $0.17911765930458734
# Shares owned at the moment: 0
# Cash capital at the moment: $94.61431947551358
#
#
# Share price: $0.21220586269526776
# Shares owned at the moment: 444
# Cash capital at the moment: $0.13581308046377671
#
#
# Price increase from previously bought: 80.93003547330176%
# Share price: $0.38499998904326416
# Shares owned at the moment: 0
# Cash capital at the moment: $170.60572322905122
#
#
# Share price: $0.3629411867828104
# Shares owned at the moment: 468
# Cash capital at the moment: $0.2821425073064745
#
#
# Price increase from previously bought: -9.365952411668044%
# Share price: $0.3298528957382417
# Shares owned at the moment: 0
# Cash capital at the moment: $154.2287770359885
#
#
# Share price: $0.2636764889568811
# Shares owned at the moment: 583
# Cash capital at the moment: $0.0826446432066632
#
#
# Price increase from previously bought: -21.131567962241892%
# Share price: $0.2085293956518589
# Shares owned at the moment: 0
# Cash capital at the moment: $121.32095755466156
#
#
# Share price: $0.054117604520907185
# Shares owned at the moment: 2235
# Cash capital at the moment: $0.03549112364737539
#
#
# Price increase from previously bought: 26.825300594639543%
# Share price: $0.0688235603484315
# Shares owned at the moment: 0
# Cash capital at the moment: $153.4331416946002
#
#
# Share price: $0.13867643417320108
# Shares owned at the moment: 1103
# Cash capital at the moment: $0.05239450760353748
#
#
# Price increase from previously bought: 49.958797060482716%
# Share price: $0.2085293956518589
# Shares owned at the moment: 0
# Cash capital at the moment: $229.42779612224288
#
#
# Share price: $0.14970583530342763
# Shares owned at the moment: 1528
# Cash capital at the moment: $0.048215858660483946
#
#
# Price increase from previously bought: 41.35981843971006%
# Share price: $0.21220586269526776
# Shares owned at the moment: 0
# Cash capital at the moment: $323.407085021984
#
#
#
#
# Capital at the end of test period: $323.407085021984
# profit gained: 223.40708502198402%
#
#
# Capital at the end of test period if Buy and Hold: $26.129427230180067
# profit gained: -73.87057276981993%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.724771      6.896552       0.000000      92.307692
# 1       0.683486      3.703704       3.571429      90.184049
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         62.068966           65.000000          72.619048     -50.170376
# 1         70.370370           62.962963          79.141104     223.407085
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
#
#
# Recession
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1254 - accuracy: 0.7215 - mse: 2.1065 - weighted_accuracy: 0.7215 - weighted_mse: 2.1065
# Test loss: 0.12537498772144318
# Test accuracy: 0.7214611768722534
#
#
# number of predictions: 219
# actual predicted buys: 1
# actual buys but predicted sell: 0
# actual buys but predicted hold: 7
# actual sells but predicted buy: 0
# actual predicted sells: 3
# actual sells but predicted hold: 8
# actual holds but predicted buy: 19
# actual holds but predicted sell: 27
# actual predicted holds: 154
# Percentage buys correct: 5.0%
# Percentage sells correct: 10.0%
# Percentage holds correct: 91.12426035502959%
# actual buys: 8
# actual sells: 11
# actual holds: 200
#
#
# Percentage low buys correct: 63.1578947368421%
# Percentage high sells correct: 50.0%
# Percentage mid holds correct: 85.79881656804734%
#
#
# Capital: 100
# Share price: $0.22728394889378878
# Shares owned at the moment: 438
# Cash capital at the moment: $0.1758668680779465
#
#
# Price increase from previously bought: -35.8712428520027%
# Share price: $0.1461551961444379
# Shares owned at the moment: 0
# Cash capital at the moment: $64.01579884558576
#
#
# Share price: $0.14439153784445785
# Shares owned at the moment: 442
# Cash capital at the moment: $0.019231204085450315
#
#
# Price increase from previously bought: 14.09931223984513%
# Share price: $0.16520281342999804
# Shares owned at the moment: 0
# Cash capital at the moment: $72.83807072042043
#
#
# Share price: $0.2696119835684443
# Shares owned at the moment: 269
# Cash capital at the moment: $0.11300167566416519
#
#
# Price increase from previously bought: 66.1356593932427%
# Share price: $0.44915343123307383
# Shares owned at the moment: 0
# Cash capital at the moment: $120.60301342660635
#
#
# Share price: $0.416349188381546
# Shares owned at the moment: 288
# Cash capital at the moment: $0.3646986155229115
#
#
# Price increase from previously bought: -22.917102790961042%
# Share price: $0.32181658545731984
# Shares owned at the moment: 0
# Cash capital at the moment: $92.79299649154883
#
#
# Share price: $0.5793121437445179
# Shares owned at the moment: 159
# Cash capital at the moment: $0.4290614013181937
#
#
# Price increase from previously bought: -3.249591993133105%
# Share price: $0.5620282015785902
# Shares owned at the moment: 0
# Cash capital at the moment: $89.5457986211738
#
#
# Share price: $0.4078835881744759
# Shares owned at the moment: 218
# Cash capital at the moment: $0.3826501880274549
#
#
# Price increase from previously bought: -8.812186239964404%
# Share price: $0.37296296209083296
# Shares owned at the moment: 0
# Cash capital at the moment: $81.46498462805557
#
#
# Share price: $0.30135803480391465
# Shares owned at the moment: 269
# Cash capital at the moment: $0.17674365955633675
#
#
# Price increase from previously bought: 13.96644533017306%
# Share price: $0.34439151934284024
# Shares owned at the moment: 0
# Cash capital at the moment: $92.5632987363465
#
#
# Share price: $0.2801940006469344
# Shares owned at the moment: 329
# Cash capital at the moment: $0.1259670014197667
#
#
# Price increase from previously bought: -1.4041423417406995%
# Share price: $0.27701939215945687
# Shares owned at the moment: 0
# Cash capital at the moment: $91.0147137268248
#
#
# Share price: $0.2928924009575395
# Shares owned at the moment: 309
# Cash capital at the moment: $0.26207651323142045
#
#
# Price increase from previously bought: 7.051914560932415%
# Share price: $0.3144091768663072
# Shares owned at the moment: 0
# Cash capital at the moment: $97.1473429668782
#
#
# Share price: $0.25938270824174164
# Shares owned at the moment: 373
# Cash capital at the moment: $0.1315309797295896
#
#
#
#
# Capital at the end of test period: $96.35281015674582
# profit gained: -3.6471898432541816%
#
#
# Capital at the end of test period if Buy and Hold: $2186.7819938452512
# profit gained: 2086.7819938452512%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.739726           5.0            4.0      91.954023
# 1       0.721461           5.0           10.0      91.124260
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         50.000000                44.0          81.502890     -37.830016
# 1         63.157895                50.0          85.798817      -3.647190
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
#
#
# Non-Recession
#
#
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1236 - accuracy: 0.7569 - mse: 2.1004 - weighted_accuracy: 0.7569 - weighted_mse: 2.1004
# Test loss: 0.12358639389276505
# Test accuracy: 0.7568807601928711
#
#
# number of predictions: 218
# actual predicted buys: 3
# actual buys but predicted sell: 0
# actual buys but predicted hold: 6
# actual sells but predicted buy: 0
# actual predicted sells: 1
# actual sells but predicted hold: 7
# actual holds but predicted buy: 25
# actual holds but predicted sell: 15
# actual predicted holds: 161
# Percentage buys correct: 10.714285714285714%
# Percentage sells correct: 6.25%
# Percentage holds correct: 92.52873563218391%
# actual buys: 9
# actual sells: 8
# actual holds: 201
#
#
# Percentage low buys correct: 53.57142857142857%
# Percentage high sells correct: 68.75%
# Percentage mid holds correct: 82.65895953757226%
#
#
# Capital: 100
# Share price: $0.9554229529629775
# Shares owned at the moment: 104
# Cash capital at the moment: $0.3627619273029268
#
#
# Price increase from previously bought: -75.36679453155209%
# Share price: $0.23599851516859702
# Shares owned at the moment: 0
# Cash capital at the moment: $24.839111929498795
#
#
# Share price: $0.186383035068398
# Shares owned at the moment: 132
# Cash capital at the moment: $0.1688942587404263
#
#
# Price increase from previously bought: -62.39461580697656%
# Share price: $0.07028280406321093
# Shares owned at the moment: 0
# Cash capital at the moment: $9.420711737209322
#
#
# Share price: $0.04076159198408228
# Shares owned at the moment: 230
# Cash capital at the moment: $0.01976387394046597
#
#
# Price increase from previously bought: 42.21134008281873%
# Share price: $0.05812701711670328
# Shares owned at the moment: 0
# Cash capital at the moment: $13.352212472455905
#
#
# Share price: $0.0355519656272212
# Shares owned at the moment: 374
# Cash capital at the moment: $0.0192121312275777
#
#
# Price increase from previously bought: -26.717451129179782%
# Share price: $0.026125033398415175
# Shares owned at the moment: 0
# Cash capital at the moment: $9.763105025384583
#
#
# Share price: $0.02513272474275132
# Shares owned at the moment: 387
# Cash capital at the moment: $0.00999304763234754
#
#
# Price increase from previously bought: 248.76938099199012%
# Share price: $0.08789630044512174
# Shares owned at the moment: 0
# Cash capital at the moment: $33.93231768214574
#
#
# Share price: $0.07276357570237042
# Shares owned at the moment: 465
# Cash capital at the moment: $0.004208558114079608
#
#
# Price increase from previously bought: 17.745826951841572%
# Share price: $0.08591168313379415
# Shares owned at the moment: 0
# Cash capital at the moment: $39.84328165052102
#
#
# Share price: $0.04299429237395196
# Shares owned at the moment: 924
# Cash capital at the moment: $0.007307000067193314
#
#
# Price increase from previously bought: -16.38597240123104%
# Share price: $0.0360481199550531
# Shares owned at the moment: 0
# Cash capital at the moment: $33.22417156573047
#
#
# Share price: $0.02513272474275132
# Shares owned at the moment: 1318
# Cash capital at the moment: $0.008146793954125542
#
#
#
#
# Capital at the end of test period: $21.955706319730233
# profit gained: -78.04429368026976%
#
#
# Capital at the end of test period if Buy and Hold: $2.3797176202777375
# profit gained: -97.62028237972227%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.724771      6.896552       0.000000      92.307692
# 1       0.683486      3.703704       3.571429      90.184049
# 2       0.756881     10.714286       6.250000      92.528736
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         62.068966           65.000000          72.619048     -50.170376
# 1         70.370370           62.962963          79.141104     223.407085
# 2         53.571429           68.750000          82.658960     -78.044294
#
#    buy_n_hold profit
# 0         -97.406542
# 1         -73.870573
# 2         -97.620282
#
#
# Recession
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1266 - accuracy: 0.7306 - mse: 2.0497 - weighted_accuracy: 0.7306 - weighted_mse: 2.0497
# Test loss: 0.1265738308429718
# Test accuracy: 0.7305936217308044
#
#
# number of predictions: 219
# actual predicted buys: 1
# actual buys but predicted sell: 1
# actual buys but predicted hold: 6
# actual sells but predicted buy: 1
# actual predicted sells: 2
# actual sells but predicted hold: 7
# actual holds but predicted buy: 18
# actual holds but predicted sell: 26
# actual predicted holds: 157
# Percentage buys correct: 5.0%
# Percentage sells correct: 6.896551724137931%
# Percentage holds correct: 92.3529411764706%
# actual buys: 8
# actual sells: 10
# actual holds: 201
#
#
# Percentage low buys correct: 45.0%
# Percentage high sells correct: 57.142857142857146%
# Percentage mid holds correct: 85.88235294117646%
#
#
# Capital: 100
# Share price: $0.09426574266811717
# Shares owned at the moment: 1057
# Cash capital at the moment: $0.08710305229959658
#
#
# Price increase from previously bought: 113.47080509591608%
# Share price: $0.2017832218627332
# Shares owned at the moment: 0
# Cash capital at the moment: $212.78543518105909
#
#
# Share price: $0.22998835183487504
# Shares owned at the moment: 922
# Cash capital at the moment: $0.15303932322697733
#
#
# Price increase from previously bought: 50.49072704694901%
# Share price: $0.34706294844229746
# Shares owned at the moment: 0
# Cash capital at the moment: $319.2650996812498
#
#
# Share price: $0.5790559484281369
# Shares owned at the moment: 549
# Cash capital at the moment: $0.48915427606328876
#
#
# Price increase from previously bought: 6.339617380246754%
# Share price: $0.6174592361459739
# Shares owned at the moment: 0
# Cash capital at the moment: $338.54206583843154
#
#
# Share price: $0.7464219281165627
# Shares owned at the moment: 452
# Cash capital at the moment: $0.23155187309629355
#
#
# Price increase from previously bought: -10.51263121400794%
# Share price: $0.6697902152078423
# Shares owned at the moment: 0
# Cash capital at the moment: $302.1441799095376
#
#
# Share price: $0.5667016641439497
# Shares owned at the moment: 531
# Cash capital at the moment: $0.3980701440340795
#
#
# Price increase from previously bought: 8.524536339110789%
# Share price: $0.6167016319102014
# Shares owned at the moment: 0
# Cash capital at the moment: $326.96609813035417
#
#
# Share price: $0.6190326432058183
# Shares owned at the moment: 526
# Cash capital at the moment: $0.45949708569651193
#
#
# Price increase from previously bought: -4.386219695798865%
# Share price: $0.5935081828926873
# Shares owned at the moment: 0
# Cash capital at the moment: $311.7862917006957
#
#
# Share price: $0.5009674034775412
# Shares owned at the moment: 620
# Cash capital at the moment: $0.33235212169097395
#
#
# Price increase from previously bought: -1.7823278458919067%
# Share price: $0.49339162788187224
# Shares owned at the moment: 0
# Cash capital at the moment: $305.39392868291316
#
#
# Share price: $0.7375058510366451
# Shares owned at the moment: 412
# Cash capital at the moment: $0.7059239265907991
#
#
# Price increase from previously bought: -5.711426640734452%
# Share price: $0.6972960506833676
# Shares owned at the moment: 0
# Cash capital at the moment: $287.201860382714
#
#
#
#
# Capital at the end of test period: $287.201860382714
# profit gained: 187.20186038271402%
#
#
# Capital at the end of test period if Buy and Hold: $5902.379195330377
# profit gained: 5802.379195330377%
#    Test_accuracy  correct_buys  correct_sells  correct_holds  \
# 0       0.739726           5.0       4.000000      91.954023
# 1       0.721461           5.0      10.000000      91.124260
# 2       0.730594           5.0       6.896552      92.352941
#
#    correct_low_buys  correct_high_sells  correct_mid_holds  Profit gained  \
# 0         50.000000           44.000000          81.502890     -37.830016
# 1         63.157895           50.000000          85.798817      -3.647190
# 2         45.000000           57.142857          85.882353     187.201860
#
#    buy_n_hold profit
# 0        3138.165411
# 1        2086.781994
# 2        5802.379195

# %%
Vaxart_data_acc = []
Inovio_data_acc = []
Novavax_data_acc = []

Vaxart_data_correct_buys = []
Inovio_data_correct_buys = []
Novavax_data_correct_buys = []

Vaxart_data_correct_sells = []
Inovio_data_correct_sells = []
Novavax_data_correct_sells = []

Vaxart_data_correct_holds = []
Inovio_data_correct_holds = []
Novavax_data_correct_holds = []

Vaxart_data_correct_low_buys = []
Inovio_data_correct_low_buys = []
Novavax_data_correct_low_buys = []

Vaxart_data_correct_high_sells = []
Inovio_data_correct_high_sells = []
Novavax_data_correct_high_sells = []

Vaxart_data_correct_mid_holds = []
Inovio_data_correct_mid_holds = []
Novavax_data_correct_mid_holds = []

Vaxart_data_profit = []
Inovio_data_profit = []
Novavax_data_profit = []

for key,value in nr_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    Vaxart_data_acc.append(acc[0])
    Inovio_data_acc.append(acc[1])
    Novavax_data_acc.append(acc[2])
    
    Vaxart_data_correct_buys.append(correct_buys[0])
    Inovio_data_correct_buys.append(correct_buys[1]) 
    Novavax_data_correct_buys.append(correct_buys[2]) 

    Vaxart_data_correct_sells.append(correct_sells[0]) 
    Inovio_data_correct_sells.append(correct_sells[1]) 
    Novavax_data_correct_sells.append(correct_sells[2]) 

    Vaxart_data_correct_holds.append(correct_holds[0]) 
    Inovio_data_correct_holds.append(correct_holds[1])  
    Novavax_data_correct_holds.append(correct_holds[2])  

    Vaxart_data_correct_low_buys.append(correct_low_buys[0])  
    Inovio_data_correct_low_buys.append(correct_low_buys[1])  
    Novavax_data_correct_low_buys.append(correct_low_buys[2])  

    Vaxart_data_correct_high_sells.append(correct_high_sells[0]) 
    Inovio_data_correct_high_sells.append(correct_high_sells[1]) 
    Novavax_data_correct_high_sells.append(correct_high_sells[2]) 

    Vaxart_data_correct_mid_holds.append(correct_mid_holds[0])  
    Inovio_data_correct_mid_holds.append(correct_mid_holds[1])  
    Novavax_data_correct_mid_holds.append(correct_mid_holds[2])   

    Vaxart_data_profit.append(profit[0]) 
    Inovio_data_profit.append(profit[1]) 
    Novavax_data_profit.append(profit[2])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(Vaxart_data_acc)
plt.plot(Inovio_data_acc)
plt.plot(Novavax_data_acc)

plt.title('Non-Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Vaxart_data_acc','Inovio_data_acc','Novavax_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Non-Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_profit")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_profit")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_profit")
# Out:
# Text(0.5, 1.0, 'Novavax_data_profit')

# %%
Vaxart_data_acc = []
Inovio_data_acc = []
Novavax_data_acc = []

Vaxart_data_correct_buys = []
Inovio_data_correct_buys = []
Novavax_data_correct_buys = []

Vaxart_data_correct_sells = []
Inovio_data_correct_sells = []
Novavax_data_correct_sells = []

Vaxart_data_correct_holds = []
Inovio_data_correct_holds = []
Novavax_data_correct_holds = []

Vaxart_data_correct_low_buys = []
Inovio_data_correct_low_buys = []
Novavax_data_correct_low_buys = []

Vaxart_data_correct_high_sells = []
Inovio_data_correct_high_sells = []
Novavax_data_correct_high_sells = []

Vaxart_data_correct_mid_holds = []
Inovio_data_correct_mid_holds = []
Novavax_data_correct_mid_holds = []

Vaxart_data_profit = []
Inovio_data_profit = []
Novavax_data_profit = []

for key,value in r_log_hist.items():
    print(key)
    df = value
    acc = df['Test_accuracy'].values.tolist()
    correct_buys = df['correct_buys'].values.tolist()
    correct_sells = df['correct_sells'].values.tolist()
    correct_holds = df['correct_holds'].values.tolist()
    correct_low_buys = df['correct_low_buys'].values.tolist()
    correct_high_sells = df['correct_high_sells'].values.tolist()
    correct_mid_holds = df['correct_mid_holds'].values.tolist()
    profit = df['Profit gained'].values.tolist()
    
    Vaxart_data_acc.append(acc[0])
    Inovio_data_acc.append(acc[1])
    Novavax_data_acc.append(acc[2])
    
    Vaxart_data_correct_buys.append(correct_buys[0])
    Inovio_data_correct_buys.append(correct_buys[1]) 
    Novavax_data_correct_buys.append(correct_buys[2]) 

    Vaxart_data_correct_sells.append(correct_sells[0]) 
    Inovio_data_correct_sells.append(correct_sells[1]) 
    Novavax_data_correct_sells.append(correct_sells[2]) 

    Vaxart_data_correct_holds.append(correct_holds[0]) 
    Inovio_data_correct_holds.append(correct_holds[1])  
    Novavax_data_correct_holds.append(correct_holds[2])  

    Vaxart_data_correct_low_buys.append(correct_low_buys[0])  
    Inovio_data_correct_low_buys.append(correct_low_buys[1])  
    Novavax_data_correct_low_buys.append(correct_low_buys[2])  

    Vaxart_data_correct_high_sells.append(correct_high_sells[0]) 
    Inovio_data_correct_high_sells.append(correct_high_sells[1]) 
    Novavax_data_correct_high_sells.append(correct_high_sells[2]) 

    Vaxart_data_correct_mid_holds.append(correct_mid_holds[0])  
    Inovio_data_correct_mid_holds.append(correct_mid_holds[1])  
    Novavax_data_correct_mid_holds.append(correct_mid_holds[2])   

    Vaxart_data_profit.append(profit[0]) 
    Inovio_data_profit.append(profit[1]) 
    Novavax_data_profit.append(profit[2])
# Out:
# 0_epochs_logs
# 20_epochs_logs
# 40_epochs_logs
# 60_epochs_logs
# 80_epochs_logs
# 100_epochs_logs
# 120_epochs_logs
# 140_epochs_logs
# 160_epochs_logs
# 180_epochs_logs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
labels=[0,20,40,80,100,120,140,160,180,200]
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.plot(Vaxart_data_acc)
plt.plot(Inovio_data_acc)
plt.plot(Novavax_data_acc)

plt.title('Recession Accuracy plot')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Vaxart_data_acc','Inovio_data_acc','Novavax_data_acc'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct low buys")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_low_buys")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_low_buys")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_low_buys)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_low_buys")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_low_buys')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct high sells")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_high_sells")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_high_sells")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_high_sells)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_high_sells")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_high_sells')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession correct mid holds")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_correct_mid_holds")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_correct_mid_holds")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_correct_mid_holds)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_correct_mid_holds")
# Out:
# Text(0.5, 1.0, 'Novavax_data_correct_mid_holds')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.suptitle("Recession Profit")

plt.subplot(3, 4, 1)
plt.plot(Vaxart_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Vaxart_data_profit")

plt.subplot(3, 4, 2)
plt.plot(Inovio_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Inovio_data_profit")

plt.subplot(3, 4, 3)
plt.plot(Novavax_data_profit)
plt.xticks(np.arange(10), (0,20,40,80,100,120,140,160,180,200))
plt.title("Novavax_data_profit")
# Out:
# Text(0.5, 1.0, 'Novavax_data_profit')
